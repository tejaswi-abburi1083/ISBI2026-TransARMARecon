# %%
import os
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, log_loss
from torch_geometric.data import Data
from torch_geometric.nn import GCNConv

device = 'cuda' if torch.cuda.is_available() else 'cpu'
print("Device:", device)

cn_path = "/home/snu/Downloads/Histogram_CN_FA_20bin_updated.npy"
mci_path = "/home/snu/Downloads/Histogram_MCI_FA_20bin_updated.npy"

Histogram_feature_CN_FA_array = np.load(cn_path, allow_pickle=True)
Histogram_feature_MCI_FA_array = np.load(mci_path, allow_pickle=True)

X = np.vstack([Histogram_feature_CN_FA_array, Histogram_feature_MCI_FA_array])
y = np.hstack([
    np.zeros(Histogram_feature_CN_FA_array.shape[0], dtype=np.int64),
    np.ones(Histogram_feature_MCI_FA_array.shape[0], dtype=np.int64)
])

num_nodes, num_feats = X.shape
print(f"Features: {X.shape}, Labels: {y.shape}")

rng = np.random.RandomState(42)
perm = rng.permutation(num_nodes)
X = X[perm]
y = y[perm]

def create_adj(F_data, alpha=1):
    norms = np.linalg.norm(F_data, axis=1, keepdims=True)
    norms[norms == 0] = 1.0
    F_norm = F_data / norms
    W = np.dot(F_norm, F_norm.T)
    W = np.where(W >= alpha, 1.0, 0.0).astype(np.float32)
    if W.max() > 0:
        W = W / W.max()
    return W

alpha = 0.92
W = create_adj(X, alpha=alpha)
np.fill_diagonal(W, 1.0)

def load_data(adj, node_feats):
    node_feats = torch.from_numpy(node_feats).float()
    rows, cols = np.nonzero(adj > 0)
    edge_index = torch.from_numpy(np.vstack([rows, cols]).astype(np.int64))
    return Data(x=node_feats, edge_index=edge_index)

data = load_data(W, X).to(device)
print(data)

class GCN_AE(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim, num_nodes, device, activ="RELU", dropout=0.25):
        super(GCN_AE, self).__init__()
        self.device = device
        self.dropout = dropout
        self.conv1 = GCNConv(input_dim, hidden_dim)
        self.conv2 = GCNConv(hidden_dim, output_dim)
        self.conv3 = GCNConv(hidden_dim, num_nodes)
        activations = {
            "SELU": F.selu,
            "SiLU": F.silu,
            "GELU": F.gelu,
            "RELU": F.relu,
            "ELU": F.elu
        }
        self.act = activations.get(activ, F.relu)

    def forward(self, x, edge_index):
        h = self.conv1(x, edge_index)
        h1 = self.act(h)
        logits = self.conv2(h1, edge_index)
        h2 = torch.sigmoid(logits)
        A_hat = self.conv3(h1, edge_index)
        A_pred = torch.sigmoid(A_hat)
        return h2, A_pred, h1

def auto_loss(A_pred: torch.Tensor, A_tilde: torch.Tensor, eps: float = 1e-12) -> torch.Tensor:
    if A_pred.dim() not in (2, 3):
        raise ValueError("A_pred must be shape (n,n) or (B,n,n)")
    if A_pred.shape != A_tilde.shape:
        raise ValueError("A_pred and A_tilde must have the same shape")
    if A_pred.dim() == 2:
        n = A_pred.size(0)
        D = A_tilde.sum(dim=1)
        D_inv_sqrt = torch.rsqrt(D + eps)
        D_inv_sqrt_mat = torch.diag(D_inv_sqrt)
        S = D_inv_sqrt_mat @ A_tilde @ D_inv_sqrt_mat
        A_pred_clamped = A_pred.clamp(min=eps, max=1.0)
        loss = - (S * torch.log(A_pred_clamped)).mean()
        return loss
    else:
        B, n, _ = A_pred.shape
        D = A_tilde.sum(dim=2)
        D_inv_sqrt = torch.rsqrt(D + eps)
        D_inv_sqrt_mat = torch.diag_embed(D_inv_sqrt)
        S = D_inv_sqrt_mat.bmm(A_tilde).bmm(D_inv_sqrt_mat)
        A_pred_clamped = A_pred.clamp(min=eps, max=1.0)
        loss = - (S * torch.log(A_pred_clamped)).mean()
        return loss

feats_dim = num_feats
hidden_dim = 512
num_classes = 2
num_epochs = 2000
lr = 1e-4
weight_decay = 1e-4
batch_print_freq = 100
lambda_recon = 0.05

sss = StratifiedShuffleSplit(n_splits=20, test_size=0.1, random_state=42)
accuracies, precisions, recalls, f1_scores, aucs, ce_losses = [], [], [], [], [], []
y_all = y.copy()

for fold, (train_val_idx, test_idx_global) in enumerate(sss.split(X, y_all), start=1):
    print(f"\n=== Fold {fold} ===")
    cn_idx = np.where(y_all == 0)[0]
    mci_idx = np.where(y_all == 1)[0]
    sss_class = StratifiedShuffleSplit(n_splits=20, test_size=0.1, random_state=fold)
    cn_train_idx, _ = next(sss_class.split(X[cn_idx], y_all[cn_idx]))
    mci_train_idx, _ = next(sss_class.split(X[mci_idx], y_all[mci_idx]))
    cn_train = cn_idx[cn_train_idx]
    mci_train = mci_idx[mci_train_idx]
    train_idx_final = np.concatenate([cn_train, mci_train])
    np.random.shuffle(train_idx_final)
    print(f"Train CN: {len(cn_train)}, Train MCI: {len(mci_train)}")

    train_idx_t = torch.from_numpy(train_idx_final).long().to(device)
    y_train_tensor = torch.from_numpy(y_all[train_idx_final]).long().to(device)

    model = GCN_AE(feats_dim, hidden_dim, num_classes, num_nodes, device, activ="RELU", dropout=0.25).to(device)
    optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
    ce_loss_fn = nn.CrossEntropyLoss()
    data = load_data(W, X).to(device)
    A_tilde = torch.from_numpy(W).float().to(device)

    for epoch in range(1, num_epochs + 1):
        model.train()
        optimizer.zero_grad()
        logits, recon_x, _ = model(data.x, data.edge_index)
        loss_sup = ce_loss_fn(logits[train_idx_t], y_train_tensor)
        loss_recon = auto_loss(recon_x, A_tilde)
        total_loss = loss_sup + lambda_recon * loss_recon
        if torch.isnan(total_loss) or torch.isinf(total_loss):
            print(f"NaN/Inf detected at fold {fold} epoch {epoch}. Aborting epoch.")
            break
        total_loss.backward()
        optimizer.step()
        if epoch % batch_print_freq == 0 or epoch == 1:
            model.eval()
            with torch.no_grad():
                logits_eval, _, _ = model(data.x, data.edge_index)
                preds_train = logits_eval[train_idx_t].argmax(dim=1)
                acc_train = accuracy_score(y_train_tensor.cpu(), preds_train.cpu())
            print(f"Fold {fold} Epoch {epoch}: TotalLoss={total_loss.item():.6f} | Sup={loss_sup.item():.6f} | Recon={loss_recon.item():.6f} | TrainAcc={acc_train:.4f}")

    model.eval()
    with torch.no_grad():
        out_logits, _, _ = model(data.x, data.edge_index)
        preds = out_logits.argmax(dim=1).cpu().numpy()
        probs = F.softmax(out_logits, dim=1)[:, 1].cpu().numpy()

    y_test = y_all[test_idx_global]
    y_pred_test = preds[test_idx_global]
    y_prob_test = probs[test_idx_global]

    acc = accuracy_score(y_test, y_pred_test)
    prec = precision_score(y_test, y_pred_test, zero_division=0)
    rec = recall_score(y_test, y_pred_test, zero_division=0)
    f1 = f1_score(y_test, y_pred_test, zero_division=0)
    try:
        auc = roc_auc_score(y_test, y_prob_test)
    except ValueError:
        auc = float('nan')
    ce = log_loss(y_test, y_prob_test)

    accuracies.append(acc)
    precisions.append(prec)
    recalls.append(rec)
    f1_scores.append(f1)
    aucs.append(auc)
    ce_losses.append(ce)

    print(f"Fold {fold} → Acc={acc:.4f} | Prec={prec:.4f} | Rec={rec:.4f} | F1={f1:.4f} | AUC={auc:.4f} | CE Loss={ce:.4f}")

print("\n=== Average Results Across 20 Folds ===")
print(f"Accuracy:  {np.mean(accuracies):.4f} ± {np.std(accuracies):.4f}")
print(f"Precision: {np.mean(precisions):.4f} ± {np.std(precisions):.4f}")
print(f"Recall:    {np.mean(recalls):.4f} ± {np.std(recalls):.4f}")
print(f"F1-score:  {np.mean(f1_scores):.4f} ± {np.std(f1_scores):.4f}")
print(f"AUC:       {np.nanmean(aucs):.4f} ± {np.nanstd(aucs):.4f}")
print(f"CE Loss:   {np.mean(ce_losses):.4f} ± {np.std(ce_losses):.4f}")
# Out:
# Device: cuda
# Features: (300, 180), Labels: (300,)
# Data(x=[300, 180], edge_index=[2, 13604])
#
# === Fold 1 ===
# Train CN: 119, Train MCI: 150
# Fold 1 Epoch 1: TotalLoss=0.693127 | Sup=0.693021 | Recon=0.002108 | TrainAcc=0.6952
# Fold 1 Epoch 100: TotalLoss=0.666731 | Sup=0.666626 | Recon=0.002104 | TrainAcc=0.5576
# Fold 1 Epoch 200: TotalLoss=0.648135 | Sup=0.648030 | Recon=0.002102 | TrainAcc=0.5576
# Fold 1 Epoch 300: TotalLoss=0.624282 | Sup=0.624177 | Recon=0.002100 | TrainAcc=0.6654
# Fold 1 Epoch 400: TotalLoss=0.599803 | Sup=0.599698 | Recon=0.002097 | TrainAcc=0.7398
# Fold 1 Epoch 500: TotalLoss=0.578826 | Sup=0.578722 | Recon=0.002095 | TrainAcc=0.7770
# Fold 1 Epoch 600: TotalLoss=0.562271 | Sup=0.562167 | Recon=0.002093 | TrainAcc=0.7807
# Fold 1 Epoch 700: TotalLoss=0.549589 | Sup=0.549485 | Recon=0.002091 | TrainAcc=0.7695
# Fold 1 Epoch 800: TotalLoss=0.539977 | Sup=0.539873 | Recon=0.002089 | TrainAcc=0.7732
# Fold 1 Epoch 900: TotalLoss=0.532770 | Sup=0.532666 | Recon=0.002087 | TrainAcc=0.7770
# Fold 1 Epoch 1000: TotalLoss=0.527095 | Sup=0.526991 | Recon=0.002085 | TrainAcc=0.7844
# Fold 1 Epoch 1100: TotalLoss=0.522425 | Sup=0.522320 | Recon=0.002084 | TrainAcc=0.7955
# Fold 1 Epoch 1200: TotalLoss=0.518484 | Sup=0.518380 | Recon=0.002082 | TrainAcc=0.7955
# Fold 1 Epoch 1300: TotalLoss=0.515356 | Sup=0.515252 | Recon=0.002081 | TrainAcc=0.7993
# Fold 1 Epoch 1400: TotalLoss=0.512961 | Sup=0.512857 | Recon=0.002081 | TrainAcc=0.8030
# Fold 1 Epoch 1500: TotalLoss=0.511088 | Sup=0.510984 | Recon=0.002080 | TrainAcc=0.8067
# Fold 1 Epoch 1600: TotalLoss=0.509554 | Sup=0.509450 | Recon=0.002080 | TrainAcc=0.8067
# Fold 1 Epoch 1700: TotalLoss=0.508256 | Sup=0.508152 | Recon=0.002080 | TrainAcc=0.8067
# Fold 1 Epoch 1800: TotalLoss=0.507119 | Sup=0.507015 | Recon=0.002080 | TrainAcc=0.8067
# Fold 1 Epoch 1900: TotalLoss=0.506109 | Sup=0.506005 | Recon=0.002081 | TrainAcc=0.8067
# Fold 1 Epoch 2000: TotalLoss=0.505188 | Sup=0.505084 | Recon=0.002081 | TrainAcc=0.8141
# Fold 1 → Acc=0.8667 | Prec=0.8824 | Rec=0.8824 | F1=0.8824 | AUC=0.9502 | CE Loss=0.4555
#
# === Fold 2 ===
# Train CN: 119, Train MCI: 150
# Fold 2 Epoch 1: TotalLoss=0.692245 | Sup=0.692140 | Recon=0.002110 | TrainAcc=0.5576
# Fold 2 Epoch 100: TotalLoss=0.667436 | Sup=0.667331 | Recon=0.002105 | TrainAcc=0.5576
# Fold 2 Epoch 200: TotalLoss=0.650806 | Sup=0.650701 | Recon=0.002105 | TrainAcc=0.5539
# Fold 2 Epoch 300: TotalLoss=0.628868 | Sup=0.628762 | Recon=0.002104 | TrainAcc=0.6394
# Fold 2 Epoch 400: TotalLoss=0.604770 | Sup=0.604665 | Recon=0.002102 | TrainAcc=0.7361
# Fold 2 Epoch 500: TotalLoss=0.583630 | Sup=0.583525 | Recon=0.002100 | TrainAcc=0.7770
# Fold 2 Epoch 600: TotalLoss=0.566777 | Sup=0.566672 | Recon=0.002097 | TrainAcc=0.7844
# Fold 2 Epoch 700: TotalLoss=0.553712 | Sup=0.553608 | Recon=0.002095 | TrainAcc=0.7770
# Fold 2 Epoch 800: TotalLoss=0.544469 | Sup=0.544364 | Recon=0.002092 | TrainAcc=0.7807
# Fold 2 Epoch 900: TotalLoss=0.537701 | Sup=0.537596 | Recon=0.002089 | TrainAcc=0.7844
# Fold 2 Epoch 1000: TotalLoss=0.532425 | Sup=0.532321 | Recon=0.002087 | TrainAcc=0.7881
# Fold 2 Epoch 1100: TotalLoss=0.528105 | Sup=0.528001 | Recon=0.002084 | TrainAcc=0.7918
# Fold 2 Epoch 1200: TotalLoss=0.524619 | Sup=0.524514 | Recon=0.002082 | TrainAcc=0.7844
# Fold 2 Epoch 1300: TotalLoss=0.521931 | Sup=0.521827 | Recon=0.002081 | TrainAcc=0.7881
# Fold 2 Epoch 1400: TotalLoss=0.519840 | Sup=0.519736 | Recon=0.002080 | TrainAcc=0.7881
# Fold 2 Epoch 1500: TotalLoss=0.518163 | Sup=0.518059 | Recon=0.002079 | TrainAcc=0.7955
# Fold 2 Epoch 1600: TotalLoss=0.516773 | Sup=0.516669 | Recon=0.002079 | TrainAcc=0.7955
# Fold 2 Epoch 1700: TotalLoss=0.515580 | Sup=0.515476 | Recon=0.002079 | TrainAcc=0.7955
# Fold 2 Epoch 1800: TotalLoss=0.514515 | Sup=0.514411 | Recon=0.002079 | TrainAcc=0.7955
# Fold 2 Epoch 1900: TotalLoss=0.513512 | Sup=0.513408 | Recon=0.002079 | TrainAcc=0.7955
# Fold 2 Epoch 2000: TotalLoss=0.512499 | Sup=0.512395 | Recon=0.002079 | TrainAcc=0.8030
# Fold 2 → Acc=0.8333 | Prec=0.8750 | Rec=0.8235 | F1=0.8485 | AUC=0.9005 | CE Loss=0.4783
#
# === Fold 3 ===
# Train CN: 119, Train MCI: 150
# Fold 3 Epoch 1: TotalLoss=0.692378 | Sup=0.692272 | Recon=0.002106 | TrainAcc=0.5576
# Fold 3 Epoch 100: TotalLoss=0.667840 | Sup=0.667735 | Recon=0.002101 | TrainAcc=0.5576
# Fold 3 Epoch 200: TotalLoss=0.649272 | Sup=0.649167 | Recon=0.002098 | TrainAcc=0.5539
# Fold 3 Epoch 300: TotalLoss=0.624155 | Sup=0.624050 | Recon=0.002096 | TrainAcc=0.6654
# Fold 3 Epoch 400: TotalLoss=0.597299 | Sup=0.597194 | Recon=0.002094 | TrainAcc=0.7546
# Fold 3 Epoch 500: TotalLoss=0.574141 | Sup=0.574037 | Recon=0.002091 | TrainAcc=0.7955
# Fold 3 Epoch 600: TotalLoss=0.556613 | Sup=0.556508 | Recon=0.002089 | TrainAcc=0.7993
# Fold 3 Epoch 700: TotalLoss=0.543431 | Sup=0.543327 | Recon=0.002087 | TrainAcc=0.7844
# Fold 3 Epoch 800: TotalLoss=0.533429 | Sup=0.533325 | Recon=0.002085 | TrainAcc=0.7844
# Fold 3 Epoch 900: TotalLoss=0.525845 | Sup=0.525741 | Recon=0.002083 | TrainAcc=0.7807
# Fold 3 Epoch 1000: TotalLoss=0.520026 | Sup=0.519922 | Recon=0.002081 | TrainAcc=0.7918
# Fold 3 Epoch 1100: TotalLoss=0.515302 | Sup=0.515198 | Recon=0.002079 | TrainAcc=0.7993
# Fold 3 Epoch 1200: TotalLoss=0.511213 | Sup=0.511109 | Recon=0.002077 | TrainAcc=0.8067
# Fold 3 Epoch 1300: TotalLoss=0.507652 | Sup=0.507548 | Recon=0.002076 | TrainAcc=0.8104
# Fold 3 Epoch 1400: TotalLoss=0.504830 | Sup=0.504726 | Recon=0.002075 | TrainAcc=0.8141
# Fold 3 Epoch 1500: TotalLoss=0.502628 | Sup=0.502524 | Recon=0.002074 | TrainAcc=0.8178
# Fold 3 Epoch 1600: TotalLoss=0.500876 | Sup=0.500773 | Recon=0.002074 | TrainAcc=0.8216
# Fold 3 Epoch 1700: TotalLoss=0.499443 | Sup=0.499339 | Recon=0.002074 | TrainAcc=0.8216
# Fold 3 Epoch 1800: TotalLoss=0.498225 | Sup=0.498122 | Recon=0.002075 | TrainAcc=0.8216
# Fold 3 Epoch 1900: TotalLoss=0.497160 | Sup=0.497056 | Recon=0.002075 | TrainAcc=0.8216
# Fold 3 Epoch 2000: TotalLoss=0.496218 | Sup=0.496114 | Recon=0.002076 | TrainAcc=0.8216
# Fold 3 → Acc=0.8333 | Prec=0.9286 | Rec=0.7647 | F1=0.8387 | AUC=0.8009 | CE Loss=0.5092
#
# === Fold 4 ===
# Train CN: 119, Train MCI: 150
# Fold 4 Epoch 1: TotalLoss=0.691045 | Sup=0.690940 | Recon=0.002106 | TrainAcc=0.5576
# Fold 4 Epoch 100: TotalLoss=0.666276 | Sup=0.666171 | Recon=0.002101 | TrainAcc=0.5576
# Fold 4 Epoch 200: TotalLoss=0.649281 | Sup=0.649176 | Recon=0.002099 | TrainAcc=0.5539
# Fold 4 Epoch 300: TotalLoss=0.626326 | Sup=0.626221 | Recon=0.002097 | TrainAcc=0.6431
# Fold 4 Epoch 400: TotalLoss=0.601967 | Sup=0.601862 | Recon=0.002095 | TrainAcc=0.7509
# Fold 4 Epoch 500: TotalLoss=0.581054 | Sup=0.580949 | Recon=0.002093 | TrainAcc=0.7807
# Fold 4 Epoch 600: TotalLoss=0.564491 | Sup=0.564386 | Recon=0.002091 | TrainAcc=0.7807
# Fold 4 Epoch 700: TotalLoss=0.551543 | Sup=0.551439 | Recon=0.002090 | TrainAcc=0.7844
# Fold 4 Epoch 800: TotalLoss=0.541486 | Sup=0.541382 | Recon=0.002088 | TrainAcc=0.7844
# Fold 4 Epoch 900: TotalLoss=0.533466 | Sup=0.533362 | Recon=0.002087 | TrainAcc=0.7955
# Fold 4 Epoch 1000: TotalLoss=0.527005 | Sup=0.526901 | Recon=0.002086 | TrainAcc=0.7955
# Fold 4 Epoch 1100: TotalLoss=0.521684 | Sup=0.521580 | Recon=0.002084 | TrainAcc=0.7993
# Fold 4 Epoch 1200: TotalLoss=0.517400 | Sup=0.517295 | Recon=0.002083 | TrainAcc=0.7955
# Fold 4 Epoch 1300: TotalLoss=0.514049 | Sup=0.513945 | Recon=0.002082 | TrainAcc=0.7955
# Fold 4 Epoch 1400: TotalLoss=0.511423 | Sup=0.511319 | Recon=0.002082 | TrainAcc=0.7993
# Fold 4 Epoch 1500: TotalLoss=0.509331 | Sup=0.509227 | Recon=0.002081 | TrainAcc=0.7993
# Fold 4 Epoch 1600: TotalLoss=0.507619 | Sup=0.507515 | Recon=0.002081 | TrainAcc=0.7993
# Fold 4 Epoch 1700: TotalLoss=0.506178 | Sup=0.506074 | Recon=0.002081 | TrainAcc=0.7993
# Fold 4 Epoch 1800: TotalLoss=0.504924 | Sup=0.504820 | Recon=0.002082 | TrainAcc=0.7993
# Fold 4 Epoch 1900: TotalLoss=0.503787 | Sup=0.503683 | Recon=0.002082 | TrainAcc=0.7993
# Fold 4 Epoch 2000: TotalLoss=0.502740 | Sup=0.502635 | Recon=0.002083 | TrainAcc=0.7993
# Fold 4 → Acc=0.7333 | Prec=0.7647 | Rec=0.7647 | F1=0.7647 | AUC=0.9050 | CE Loss=0.4967
#
# === Fold 5 ===
# Train CN: 119, Train MCI: 150
# Fold 5 Epoch 1: TotalLoss=0.693262 | Sup=0.693157 | Recon=0.002111 | TrainAcc=0.5613
# Fold 5 Epoch 100: TotalLoss=0.667545 | Sup=0.667440 | Recon=0.002106 | TrainAcc=0.5576
# Fold 5 Epoch 200: TotalLoss=0.649226 | Sup=0.649121 | Recon=0.002103 | TrainAcc=0.5539
# Fold 5 Epoch 300: TotalLoss=0.624160 | Sup=0.624055 | Recon=0.002101 | TrainAcc=0.6766
# Fold 5 Epoch 400: TotalLoss=0.598229 | Sup=0.598124 | Recon=0.002100 | TrainAcc=0.7435
# Fold 5 Epoch 500: TotalLoss=0.576620 | Sup=0.576515 | Recon=0.002098 | TrainAcc=0.7844
# Fold 5 Epoch 600: TotalLoss=0.559869 | Sup=0.559764 | Recon=0.002095 | TrainAcc=0.7881
# Fold 5 Epoch 700: TotalLoss=0.547450 | Sup=0.547345 | Recon=0.002093 | TrainAcc=0.7807
# Fold 5 Epoch 800: TotalLoss=0.538628 | Sup=0.538524 | Recon=0.002091 | TrainAcc=0.7770
# Fold 5 Epoch 900: TotalLoss=0.532116 | Sup=0.532011 | Recon=0.002088 | TrainAcc=0.7807
# Fold 5 Epoch 1000: TotalLoss=0.527152 | Sup=0.527048 | Recon=0.002086 | TrainAcc=0.7881
# Fold 5 Epoch 1100: TotalLoss=0.523192 | Sup=0.523087 | Recon=0.002084 | TrainAcc=0.7881
# Fold 5 Epoch 1200: TotalLoss=0.519839 | Sup=0.519735 | Recon=0.002082 | TrainAcc=0.7918
# Fold 5 Epoch 1300: TotalLoss=0.517025 | Sup=0.516921 | Recon=0.002081 | TrainAcc=0.7918
# Fold 5 Epoch 1400: TotalLoss=0.514776 | Sup=0.514672 | Recon=0.002080 | TrainAcc=0.8030
# Fold 5 Epoch 1500: TotalLoss=0.513018 | Sup=0.512914 | Recon=0.002079 | TrainAcc=0.8030
# Fold 5 Epoch 1600: TotalLoss=0.511602 | Sup=0.511498 | Recon=0.002079 | TrainAcc=0.8067
# Fold 5 Epoch 1700: TotalLoss=0.510364 | Sup=0.510260 | Recon=0.002079 | TrainAcc=0.8067
# Fold 5 Epoch 1800: TotalLoss=0.509090 | Sup=0.508986 | Recon=0.002078 | TrainAcc=0.8067
# Fold 5 Epoch 1900: TotalLoss=0.507610 | Sup=0.507506 | Recon=0.002076 | TrainAcc=0.8067
# Fold 5 Epoch 2000: TotalLoss=0.506013 | Sup=0.505909 | Recon=0.002074 | TrainAcc=0.8067
# Fold 5 → Acc=0.9000 | Prec=0.9375 | Rec=0.8824 | F1=0.9091 | AUC=0.9140 | CE Loss=0.4469
#
# === Fold 6 ===
# Train CN: 119, Train MCI: 150
# Fold 6 Epoch 1: TotalLoss=0.693828 | Sup=0.693723 | Recon=0.002111 | TrainAcc=0.4424
# Fold 6 Epoch 100: TotalLoss=0.668154 | Sup=0.668049 | Recon=0.002106 | TrainAcc=0.5576
# Fold 6 Epoch 200: TotalLoss=0.650211 | Sup=0.650105 | Recon=0.002104 | TrainAcc=0.5539
# Fold 6 Epoch 300: TotalLoss=0.626994 | Sup=0.626889 | Recon=0.002102 | TrainAcc=0.6654
# Fold 6 Epoch 400: TotalLoss=0.602819 | Sup=0.602714 | Recon=0.002100 | TrainAcc=0.7435
# Fold 6 Epoch 500: TotalLoss=0.581937 | Sup=0.581832 | Recon=0.002097 | TrainAcc=0.7844
# Fold 6 Epoch 600: TotalLoss=0.565316 | Sup=0.565211 | Recon=0.002094 | TrainAcc=0.7918
# Fold 6 Epoch 700: TotalLoss=0.552430 | Sup=0.552325 | Recon=0.002092 | TrainAcc=0.7807
# Fold 6 Epoch 800: TotalLoss=0.542856 | Sup=0.542751 | Recon=0.002090 | TrainAcc=0.7732
# Fold 6 Epoch 900: TotalLoss=0.535954 | Sup=0.535849 | Recon=0.002088 | TrainAcc=0.7807
# Fold 6 Epoch 1000: TotalLoss=0.530690 | Sup=0.530585 | Recon=0.002086 | TrainAcc=0.7881
# Fold 6 Epoch 1100: TotalLoss=0.526426 | Sup=0.526322 | Recon=0.002084 | TrainAcc=0.7918
# Fold 6 Epoch 1200: TotalLoss=0.522708 | Sup=0.522604 | Recon=0.002082 | TrainAcc=0.7993
# Fold 6 Epoch 1300: TotalLoss=0.519583 | Sup=0.519479 | Recon=0.002081 | TrainAcc=0.7993
# Fold 6 Epoch 1400: TotalLoss=0.517188 | Sup=0.517084 | Recon=0.002080 | TrainAcc=0.7993
# Fold 6 Epoch 1500: TotalLoss=0.515349 | Sup=0.515245 | Recon=0.002079 | TrainAcc=0.7955
# Fold 6 Epoch 1600: TotalLoss=0.513890 | Sup=0.513786 | Recon=0.002079 | TrainAcc=0.7955
# Fold 6 Epoch 1700: TotalLoss=0.512683 | Sup=0.512579 | Recon=0.002079 | TrainAcc=0.7955
# Fold 6 Epoch 1800: TotalLoss=0.511645 | Sup=0.511541 | Recon=0.002079 | TrainAcc=0.7955
# Fold 6 Epoch 1900: TotalLoss=0.510724 | Sup=0.510620 | Recon=0.002080 | TrainAcc=0.7993
# Fold 6 Epoch 2000: TotalLoss=0.509892 | Sup=0.509788 | Recon=0.002080 | TrainAcc=0.8067
# Fold 6 → Acc=0.7667 | Prec=0.7500 | Rec=0.8824 | F1=0.8108 | AUC=0.8778 | CE Loss=0.5040
#
# === Fold 7 ===
# Train CN: 119, Train MCI: 150
# Fold 7 Epoch 1: TotalLoss=0.694306 | Sup=0.694200 | Recon=0.002113 | TrainAcc=0.4424
# Fold 7 Epoch 100: TotalLoss=0.668411 | Sup=0.668306 | Recon=0.002108 | TrainAcc=0.5576
# Fold 7 Epoch 200: TotalLoss=0.650438 | Sup=0.650332 | Recon=0.002106 | TrainAcc=0.5539
# Fold 7 Epoch 300: TotalLoss=0.626411 | Sup=0.626305 | Recon=0.002105 | TrainAcc=0.6580
# Fold 7 Epoch 400: TotalLoss=0.601297 | Sup=0.601192 | Recon=0.002103 | TrainAcc=0.7546
# Fold 7 Epoch 500: TotalLoss=0.579376 | Sup=0.579271 | Recon=0.002101 | TrainAcc=0.7844
# Fold 7 Epoch 600: TotalLoss=0.561848 | Sup=0.561743 | Recon=0.002098 | TrainAcc=0.7918
# Fold 7 Epoch 700: TotalLoss=0.548113 | Sup=0.548008 | Recon=0.002096 | TrainAcc=0.7918
# Fold 7 Epoch 800: TotalLoss=0.538329 | Sup=0.538224 | Recon=0.002093 | TrainAcc=0.7918
# Fold 7 Epoch 900: TotalLoss=0.530959 | Sup=0.530855 | Recon=0.002090 | TrainAcc=0.7918
# Fold 7 Epoch 1000: TotalLoss=0.525224 | Sup=0.525120 | Recon=0.002087 | TrainAcc=0.7993
# Fold 7 Epoch 1100: TotalLoss=0.520521 | Sup=0.520417 | Recon=0.002085 | TrainAcc=0.8030
# Fold 7 Epoch 1200: TotalLoss=0.516601 | Sup=0.516497 | Recon=0.002083 | TrainAcc=0.8030
# Fold 7 Epoch 1300: TotalLoss=0.513536 | Sup=0.513432 | Recon=0.002081 | TrainAcc=0.7993
# Fold 7 Epoch 1400: TotalLoss=0.511173 | Sup=0.511069 | Recon=0.002080 | TrainAcc=0.7993
# Fold 7 Epoch 1500: TotalLoss=0.509313 | Sup=0.509209 | Recon=0.002080 | TrainAcc=0.7955
# Fold 7 Epoch 1600: TotalLoss=0.507801 | Sup=0.507697 | Recon=0.002079 | TrainAcc=0.7955
# Fold 7 Epoch 1700: TotalLoss=0.506514 | Sup=0.506410 | Recon=0.002080 | TrainAcc=0.7955
# Fold 7 Epoch 1800: TotalLoss=0.505399 | Sup=0.505295 | Recon=0.002080 | TrainAcc=0.7993
# Fold 7 Epoch 1900: TotalLoss=0.504410 | Sup=0.504306 | Recon=0.002081 | TrainAcc=0.7993
# Fold 7 Epoch 2000: TotalLoss=0.503502 | Sup=0.503398 | Recon=0.002081 | TrainAcc=0.7993
# Fold 7 → Acc=0.7333 | Prec=0.7647 | Rec=0.7647 | F1=0.7647 | AUC=0.8688 | CE Loss=0.5289
#
# === Fold 8 ===
# Train CN: 119, Train MCI: 150
# Fold 8 Epoch 1: TotalLoss=0.694619 | Sup=0.694514 | Recon=0.002111 | TrainAcc=0.4387
# Fold 8 Epoch 100: TotalLoss=0.667975 | Sup=0.667870 | Recon=0.002103 | TrainAcc=0.5576
# Fold 8 Epoch 200: TotalLoss=0.649601 | Sup=0.649496 | Recon=0.002100 | TrainAcc=0.5539
# Fold 8 Epoch 300: TotalLoss=0.624838 | Sup=0.624733 | Recon=0.002099 | TrainAcc=0.6468
# Fold 8 Epoch 400: TotalLoss=0.598105 | Sup=0.598000 | Recon=0.002097 | TrainAcc=0.7621
# Fold 8 Epoch 500: TotalLoss=0.574110 | Sup=0.574005 | Recon=0.002095 | TrainAcc=0.7918
# Fold 8 Epoch 600: TotalLoss=0.555621 | Sup=0.555517 | Recon=0.002092 | TrainAcc=0.7918
# Fold 8 Epoch 700: TotalLoss=0.542027 | Sup=0.541922 | Recon=0.002090 | TrainAcc=0.7918
# Fold 8 Epoch 800: TotalLoss=0.532054 | Sup=0.531950 | Recon=0.002088 | TrainAcc=0.7918
# Fold 8 Epoch 900: TotalLoss=0.524485 | Sup=0.524381 | Recon=0.002086 | TrainAcc=0.8030
# Fold 8 Epoch 1000: TotalLoss=0.518493 | Sup=0.518388 | Recon=0.002085 | TrainAcc=0.8030
# Fold 8 Epoch 1100: TotalLoss=0.513570 | Sup=0.513466 | Recon=0.002083 | TrainAcc=0.8067
# Fold 8 Epoch 1200: TotalLoss=0.509592 | Sup=0.509488 | Recon=0.002082 | TrainAcc=0.7993
# Fold 8 Epoch 1300: TotalLoss=0.506474 | Sup=0.506370 | Recon=0.002081 | TrainAcc=0.8030
# Fold 8 Epoch 1400: TotalLoss=0.504011 | Sup=0.503907 | Recon=0.002081 | TrainAcc=0.8030
# Fold 8 Epoch 1500: TotalLoss=0.502026 | Sup=0.501922 | Recon=0.002080 | TrainAcc=0.8067
# Fold 8 Epoch 1600: TotalLoss=0.500382 | Sup=0.500278 | Recon=0.002080 | TrainAcc=0.8067
# Fold 8 Epoch 1700: TotalLoss=0.498984 | Sup=0.498880 | Recon=0.002081 | TrainAcc=0.8067
# Fold 8 Epoch 1800: TotalLoss=0.497763 | Sup=0.497659 | Recon=0.002081 | TrainAcc=0.8067
# Fold 8 Epoch 1900: TotalLoss=0.496657 | Sup=0.496553 | Recon=0.002082 | TrainAcc=0.8067
# Fold 8 Epoch 2000: TotalLoss=0.495637 | Sup=0.495533 | Recon=0.002083 | TrainAcc=0.8067
# Fold 8 → Acc=0.8000 | Prec=0.9231 | Rec=0.7059 | F1=0.8000 | AUC=0.9412 | CE Loss=0.4776
#
# === Fold 9 ===
# Train CN: 119, Train MCI: 150
# Fold 9 Epoch 1: TotalLoss=0.693325 | Sup=0.693219 | Recon=0.002112 | TrainAcc=0.5576
# Fold 9 Epoch 100: TotalLoss=0.666499 | Sup=0.666394 | Recon=0.002107 | TrainAcc=0.5576
# Fold 9 Epoch 200: TotalLoss=0.647158 | Sup=0.647053 | Recon=0.002106 | TrainAcc=0.5576
# Fold 9 Epoch 300: TotalLoss=0.620776 | Sup=0.620671 | Recon=0.002104 | TrainAcc=0.6877
# Fold 9 Epoch 400: TotalLoss=0.593695 | Sup=0.593590 | Recon=0.002102 | TrainAcc=0.7732
# Fold 9 Epoch 500: TotalLoss=0.570989 | Sup=0.570884 | Recon=0.002100 | TrainAcc=0.7993
# Fold 9 Epoch 600: TotalLoss=0.553180 | Sup=0.553075 | Recon=0.002098 | TrainAcc=0.7993
# Fold 9 Epoch 700: TotalLoss=0.539691 | Sup=0.539587 | Recon=0.002095 | TrainAcc=0.7993
# Fold 9 Epoch 800: TotalLoss=0.529686 | Sup=0.529581 | Recon=0.002092 | TrainAcc=0.8067
# Fold 9 Epoch 900: TotalLoss=0.522103 | Sup=0.521999 | Recon=0.002089 | TrainAcc=0.8104
# Fold 9 Epoch 1000: TotalLoss=0.516133 | Sup=0.516029 | Recon=0.002086 | TrainAcc=0.8141
# Fold 9 Epoch 1100: TotalLoss=0.511263 | Sup=0.511159 | Recon=0.002083 | TrainAcc=0.8178
# Fold 9 Epoch 1200: TotalLoss=0.507272 | Sup=0.507168 | Recon=0.002081 | TrainAcc=0.8141
# Fold 9 Epoch 1300: TotalLoss=0.504135 | Sup=0.504031 | Recon=0.002080 | TrainAcc=0.8178
# Fold 9 Epoch 1400: TotalLoss=0.501699 | Sup=0.501595 | Recon=0.002078 | TrainAcc=0.8141
# Fold 9 Epoch 1500: TotalLoss=0.499783 | Sup=0.499679 | Recon=0.002078 | TrainAcc=0.8141
# Fold 9 Epoch 1600: TotalLoss=0.498234 | Sup=0.498130 | Recon=0.002078 | TrainAcc=0.8104
# Fold 9 Epoch 1700: TotalLoss=0.496936 | Sup=0.496832 | Recon=0.002078 | TrainAcc=0.8104
# Fold 9 Epoch 1800: TotalLoss=0.495818 | Sup=0.495714 | Recon=0.002078 | TrainAcc=0.8141
# Fold 9 Epoch 1900: TotalLoss=0.494836 | Sup=0.494732 | Recon=0.002079 | TrainAcc=0.8141
# Fold 9 Epoch 2000: TotalLoss=0.493954 | Sup=0.493850 | Recon=0.002079 | TrainAcc=0.8178
# Fold 9 → Acc=0.7333 | Prec=0.9091 | Rec=0.5882 | F1=0.7143 | AUC=0.9186 | CE Loss=0.5209
#
# === Fold 10 ===
# Train CN: 119, Train MCI: 150
# Fold 10 Epoch 1: TotalLoss=0.693075 | Sup=0.692969 | Recon=0.002108 | TrainAcc=0.6803
# Fold 10 Epoch 100: TotalLoss=0.665724 | Sup=0.665618 | Recon=0.002109 | TrainAcc=0.5576
# Fold 10 Epoch 200: TotalLoss=0.646017 | Sup=0.645911 | Recon=0.002108 | TrainAcc=0.5576
# Fold 10 Epoch 300: TotalLoss=0.620145 | Sup=0.620040 | Recon=0.002106 | TrainAcc=0.6840
# Fold 10 Epoch 400: TotalLoss=0.593257 | Sup=0.593152 | Recon=0.002104 | TrainAcc=0.7546
# Fold 10 Epoch 500: TotalLoss=0.570418 | Sup=0.570313 | Recon=0.002101 | TrainAcc=0.8030
# Fold 10 Epoch 600: TotalLoss=0.552720 | Sup=0.552616 | Recon=0.002098 | TrainAcc=0.8030
# Fold 10 Epoch 700: TotalLoss=0.539169 | Sup=0.539064 | Recon=0.002095 | TrainAcc=0.8067
# Fold 10 Epoch 800: TotalLoss=0.529121 | Sup=0.529017 | Recon=0.002092 | TrainAcc=0.8067
# Fold 10 Epoch 900: TotalLoss=0.521591 | Sup=0.521487 | Recon=0.002089 | TrainAcc=0.8067
# Fold 10 Epoch 1000: TotalLoss=0.515874 | Sup=0.515770 | Recon=0.002086 | TrainAcc=0.8067
# Fold 10 Epoch 1100: TotalLoss=0.511438 | Sup=0.511334 | Recon=0.002084 | TrainAcc=0.8104
# Fold 10 Epoch 1200: TotalLoss=0.507963 | Sup=0.507859 | Recon=0.002082 | TrainAcc=0.8141
# Fold 10 Epoch 1300: TotalLoss=0.505194 | Sup=0.505090 | Recon=0.002080 | TrainAcc=0.8141
# Fold 10 Epoch 1400: TotalLoss=0.502965 | Sup=0.502861 | Recon=0.002079 | TrainAcc=0.8216
# Fold 10 Epoch 1500: TotalLoss=0.501150 | Sup=0.501046 | Recon=0.002078 | TrainAcc=0.8216
# Fold 10 Epoch 1600: TotalLoss=0.499626 | Sup=0.499522 | Recon=0.002077 | TrainAcc=0.8216
# Fold 10 Epoch 1700: TotalLoss=0.498313 | Sup=0.498210 | Recon=0.002077 | TrainAcc=0.8253
# Fold 10 Epoch 1800: TotalLoss=0.497159 | Sup=0.497055 | Recon=0.002077 | TrainAcc=0.8253
# Fold 10 Epoch 1900: TotalLoss=0.496125 | Sup=0.496021 | Recon=0.002078 | TrainAcc=0.8253
# Fold 10 Epoch 2000: TotalLoss=0.495190 | Sup=0.495086 | Recon=0.002078 | TrainAcc=0.8216
# Fold 10 → Acc=0.7667 | Prec=0.7500 | Rec=0.8824 | F1=0.8108 | AUC=0.8507 | CE Loss=0.5199
#
# === Fold 11 ===
# Train CN: 119, Train MCI: 150
# Fold 11 Epoch 1: TotalLoss=0.693830 | Sup=0.693725 | Recon=0.002110 | TrainAcc=0.5613
# Fold 11 Epoch 100: TotalLoss=0.666797 | Sup=0.666691 | Recon=0.002104 | TrainAcc=0.5576
# Fold 11 Epoch 200: TotalLoss=0.648459 | Sup=0.648353 | Recon=0.002103 | TrainAcc=0.5539
# Fold 11 Epoch 300: TotalLoss=0.623106 | Sup=0.623001 | Recon=0.002101 | TrainAcc=0.6580
# Fold 11 Epoch 400: TotalLoss=0.596217 | Sup=0.596112 | Recon=0.002099 | TrainAcc=0.7584
# Fold 11 Epoch 500: TotalLoss=0.573344 | Sup=0.573239 | Recon=0.002096 | TrainAcc=0.7918
# Fold 11 Epoch 600: TotalLoss=0.555918 | Sup=0.555814 | Recon=0.002094 | TrainAcc=0.7955
# Fold 11 Epoch 700: TotalLoss=0.542929 | Sup=0.542825 | Recon=0.002092 | TrainAcc=0.7918
# Fold 11 Epoch 800: TotalLoss=0.532960 | Sup=0.532856 | Recon=0.002089 | TrainAcc=0.7881
# Fold 11 Epoch 900: TotalLoss=0.525351 | Sup=0.525246 | Recon=0.002086 | TrainAcc=0.7844
# Fold 11 Epoch 1000: TotalLoss=0.519478 | Sup=0.519374 | Recon=0.002083 | TrainAcc=0.8030
# Fold 11 Epoch 1100: TotalLoss=0.514796 | Sup=0.514692 | Recon=0.002081 | TrainAcc=0.8104
# Fold 11 Epoch 1200: TotalLoss=0.510806 | Sup=0.510702 | Recon=0.002078 | TrainAcc=0.8141
# Fold 11 Epoch 1300: TotalLoss=0.507310 | Sup=0.507207 | Recon=0.002077 | TrainAcc=0.8216
# Fold 11 Epoch 1400: TotalLoss=0.504504 | Sup=0.504400 | Recon=0.002075 | TrainAcc=0.8216
# Fold 11 Epoch 1500: TotalLoss=0.502313 | Sup=0.502210 | Recon=0.002074 | TrainAcc=0.8216
# Fold 11 Epoch 1600: TotalLoss=0.500550 | Sup=0.500446 | Recon=0.002074 | TrainAcc=0.8178
# Fold 11 Epoch 1700: TotalLoss=0.499077 | Sup=0.498974 | Recon=0.002074 | TrainAcc=0.8141
# Fold 11 Epoch 1800: TotalLoss=0.497805 | Sup=0.497702 | Recon=0.002074 | TrainAcc=0.8141
# Fold 11 Epoch 1900: TotalLoss=0.496671 | Sup=0.496568 | Recon=0.002075 | TrainAcc=0.8178
# Fold 11 Epoch 2000: TotalLoss=0.495633 | Sup=0.495529 | Recon=0.002076 | TrainAcc=0.8216
# Fold 11 → Acc=0.9000 | Prec=0.8889 | Rec=0.9412 | F1=0.9143 | AUC=0.9729 | CE Loss=0.4340
#
# === Fold 12 ===
# Train CN: 119, Train MCI: 150
# Fold 12 Epoch 1: TotalLoss=0.692630 | Sup=0.692525 | Recon=0.002107 | TrainAcc=0.5576
# Fold 12 Epoch 100: TotalLoss=0.666586 | Sup=0.666481 | Recon=0.002101 | TrainAcc=0.5576
# Fold 12 Epoch 200: TotalLoss=0.649015 | Sup=0.648910 | Recon=0.002100 | TrainAcc=0.5539
# Fold 12 Epoch 300: TotalLoss=0.624510 | Sup=0.624405 | Recon=0.002099 | TrainAcc=0.6468
# Fold 12 Epoch 400: TotalLoss=0.597453 | Sup=0.597348 | Recon=0.002098 | TrainAcc=0.7658
# Fold 12 Epoch 500: TotalLoss=0.574324 | Sup=0.574220 | Recon=0.002096 | TrainAcc=0.7993
# Fold 12 Epoch 600: TotalLoss=0.556185 | Sup=0.556080 | Recon=0.002095 | TrainAcc=0.7993
# Fold 12 Epoch 700: TotalLoss=0.542001 | Sup=0.541897 | Recon=0.002093 | TrainAcc=0.8030
# Fold 12 Epoch 800: TotalLoss=0.531574 | Sup=0.531470 | Recon=0.002090 | TrainAcc=0.8030
# Fold 12 Epoch 900: TotalLoss=0.523694 | Sup=0.523589 | Recon=0.002088 | TrainAcc=0.8067
# Fold 12 Epoch 1000: TotalLoss=0.517729 | Sup=0.517624 | Recon=0.002085 | TrainAcc=0.8067
# Fold 12 Epoch 1100: TotalLoss=0.513081 | Sup=0.512977 | Recon=0.002082 | TrainAcc=0.8104
# Fold 12 Epoch 1200: TotalLoss=0.509188 | Sup=0.509084 | Recon=0.002079 | TrainAcc=0.8141
# Fold 12 Epoch 1300: TotalLoss=0.505824 | Sup=0.505720 | Recon=0.002077 | TrainAcc=0.8178
# Fold 12 Epoch 1400: TotalLoss=0.503152 | Sup=0.503048 | Recon=0.002076 | TrainAcc=0.8141
# Fold 12 Epoch 1500: TotalLoss=0.501109 | Sup=0.501005 | Recon=0.002075 | TrainAcc=0.8141
# Fold 12 Epoch 1600: TotalLoss=0.499499 | Sup=0.499396 | Recon=0.002075 | TrainAcc=0.8216
# Fold 12 Epoch 1700: TotalLoss=0.498177 | Sup=0.498074 | Recon=0.002075 | TrainAcc=0.8216
# Fold 12 Epoch 1800: TotalLoss=0.497047 | Sup=0.496943 | Recon=0.002075 | TrainAcc=0.8216
# Fold 12 Epoch 1900: TotalLoss=0.496044 | Sup=0.495940 | Recon=0.002075 | TrainAcc=0.8178
# Fold 12 Epoch 2000: TotalLoss=0.495116 | Sup=0.495012 | Recon=0.002076 | TrainAcc=0.8178
# Fold 12 → Acc=0.9333 | Prec=0.8947 | Rec=1.0000 | F1=0.9444 | AUC=0.9321 | CE Loss=0.4319
#
# === Fold 13 ===
# Train CN: 119, Train MCI: 150
# Fold 13 Epoch 1: TotalLoss=0.693380 | Sup=0.693274 | Recon=0.002106 | TrainAcc=0.5539
# Fold 13 Epoch 100: TotalLoss=0.667798 | Sup=0.667693 | Recon=0.002097 | TrainAcc=0.5576
# Fold 13 Epoch 200: TotalLoss=0.650856 | Sup=0.650751 | Recon=0.002098 | TrainAcc=0.5539
# Fold 13 Epoch 300: TotalLoss=0.628327 | Sup=0.628222 | Recon=0.002097 | TrainAcc=0.6431
# Fold 13 Epoch 400: TotalLoss=0.604035 | Sup=0.603930 | Recon=0.002096 | TrainAcc=0.7435
# Fold 13 Epoch 500: TotalLoss=0.582476 | Sup=0.582372 | Recon=0.002094 | TrainAcc=0.7844
# Fold 13 Epoch 600: TotalLoss=0.564787 | Sup=0.564682 | Recon=0.002092 | TrainAcc=0.7918
# Fold 13 Epoch 700: TotalLoss=0.550279 | Sup=0.550175 | Recon=0.002090 | TrainAcc=0.7807
# Fold 13 Epoch 800: TotalLoss=0.538923 | Sup=0.538818 | Recon=0.002089 | TrainAcc=0.7844
# Fold 13 Epoch 900: TotalLoss=0.530640 | Sup=0.530536 | Recon=0.002086 | TrainAcc=0.7881
# Fold 13 Epoch 1000: TotalLoss=0.524302 | Sup=0.524198 | Recon=0.002084 | TrainAcc=0.7918
# Fold 13 Epoch 1100: TotalLoss=0.519188 | Sup=0.519083 | Recon=0.002082 | TrainAcc=0.8030
# Fold 13 Epoch 1200: TotalLoss=0.514940 | Sup=0.514836 | Recon=0.002080 | TrainAcc=0.8030
# Fold 13 Epoch 1300: TotalLoss=0.511555 | Sup=0.511451 | Recon=0.002079 | TrainAcc=0.8030
# Fold 13 Epoch 1400: TotalLoss=0.508947 | Sup=0.508843 | Recon=0.002078 | TrainAcc=0.8067
# Fold 13 Epoch 1500: TotalLoss=0.506904 | Sup=0.506800 | Recon=0.002078 | TrainAcc=0.8141
# Fold 13 Epoch 1600: TotalLoss=0.505251 | Sup=0.505148 | Recon=0.002077 | TrainAcc=0.8141
# Fold 13 Epoch 1700: TotalLoss=0.503868 | Sup=0.503764 | Recon=0.002078 | TrainAcc=0.8141
# Fold 13 Epoch 1800: TotalLoss=0.502669 | Sup=0.502565 | Recon=0.002078 | TrainAcc=0.8141
# Fold 13 Epoch 1900: TotalLoss=0.501596 | Sup=0.501492 | Recon=0.002078 | TrainAcc=0.8178
# Fold 13 Epoch 2000: TotalLoss=0.500598 | Sup=0.500494 | Recon=0.002079 | TrainAcc=0.8178
# Fold 13 → Acc=0.8333 | Prec=0.9286 | Rec=0.7647 | F1=0.8387 | AUC=0.8824 | CE Loss=0.4867
#
# === Fold 14 ===
# Train CN: 119, Train MCI: 150
# Fold 14 Epoch 1: TotalLoss=0.690875 | Sup=0.690769 | Recon=0.002108 | TrainAcc=0.5539
# Fold 14 Epoch 100: TotalLoss=0.664964 | Sup=0.664859 | Recon=0.002104 | TrainAcc=0.5576
# Fold 14 Epoch 200: TotalLoss=0.646100 | Sup=0.645994 | Recon=0.002103 | TrainAcc=0.5539
# Fold 14 Epoch 300: TotalLoss=0.620088 | Sup=0.619983 | Recon=0.002102 | TrainAcc=0.6580
# Fold 14 Epoch 400: TotalLoss=0.592086 | Sup=0.591981 | Recon=0.002100 | TrainAcc=0.7770
# Fold 14 Epoch 500: TotalLoss=0.567542 | Sup=0.567437 | Recon=0.002098 | TrainAcc=0.8030
# Fold 14 Epoch 600: TotalLoss=0.548354 | Sup=0.548249 | Recon=0.002095 | TrainAcc=0.8104
# Fold 14 Epoch 700: TotalLoss=0.533766 | Sup=0.533662 | Recon=0.002092 | TrainAcc=0.8141
# Fold 14 Epoch 800: TotalLoss=0.523095 | Sup=0.522990 | Recon=0.002090 | TrainAcc=0.8030
# Fold 14 Epoch 900: TotalLoss=0.515404 | Sup=0.515300 | Recon=0.002087 | TrainAcc=0.8067
# Fold 14 Epoch 1000: TotalLoss=0.509589 | Sup=0.509485 | Recon=0.002084 | TrainAcc=0.8104
# Fold 14 Epoch 1100: TotalLoss=0.505023 | Sup=0.504918 | Recon=0.002082 | TrainAcc=0.8178
# Fold 14 Epoch 1200: TotalLoss=0.501244 | Sup=0.501140 | Recon=0.002080 | TrainAcc=0.8253
# Fold 14 Epoch 1300: TotalLoss=0.497841 | Sup=0.497737 | Recon=0.002078 | TrainAcc=0.8253
# Fold 14 Epoch 1400: TotalLoss=0.494817 | Sup=0.494713 | Recon=0.002077 | TrainAcc=0.8253
# Fold 14 Epoch 1500: TotalLoss=0.492393 | Sup=0.492289 | Recon=0.002076 | TrainAcc=0.8253
# Fold 14 Epoch 1600: TotalLoss=0.490446 | Sup=0.490342 | Recon=0.002076 | TrainAcc=0.8290
# Fold 14 Epoch 1700: TotalLoss=0.488843 | Sup=0.488739 | Recon=0.002076 | TrainAcc=0.8253
# Fold 14 Epoch 1800: TotalLoss=0.487476 | Sup=0.487373 | Recon=0.002076 | TrainAcc=0.8216
# Fold 14 Epoch 1900: TotalLoss=0.486271 | Sup=0.486167 | Recon=0.002077 | TrainAcc=0.8253
# Fold 14 Epoch 2000: TotalLoss=0.485184 | Sup=0.485080 | Recon=0.002077 | TrainAcc=0.8290
# Fold 14 → Acc=0.8667 | Prec=0.8824 | Rec=0.8824 | F1=0.8824 | AUC=0.9005 | CE Loss=0.4896
#
# === Fold 15 ===
# Train CN: 119, Train MCI: 150
# Fold 15 Epoch 1: TotalLoss=0.693052 | Sup=0.692947 | Recon=0.002107 | TrainAcc=0.5613
# Fold 15 Epoch 100: TotalLoss=0.667909 | Sup=0.667804 | Recon=0.002101 | TrainAcc=0.5576
# Fold 15 Epoch 200: TotalLoss=0.650154 | Sup=0.650049 | Recon=0.002103 | TrainAcc=0.5539
# Fold 15 Epoch 300: TotalLoss=0.625380 | Sup=0.625274 | Recon=0.002104 | TrainAcc=0.6617
# Fold 15 Epoch 400: TotalLoss=0.599535 | Sup=0.599430 | Recon=0.002103 | TrainAcc=0.7509
# Fold 15 Epoch 500: TotalLoss=0.577679 | Sup=0.577574 | Recon=0.002101 | TrainAcc=0.7844
# Fold 15 Epoch 600: TotalLoss=0.560975 | Sup=0.560870 | Recon=0.002098 | TrainAcc=0.7881
# Fold 15 Epoch 700: TotalLoss=0.548046 | Sup=0.547941 | Recon=0.002096 | TrainAcc=0.7770
# Fold 15 Epoch 800: TotalLoss=0.537896 | Sup=0.537792 | Recon=0.002093 | TrainAcc=0.7807
# Fold 15 Epoch 900: TotalLoss=0.530048 | Sup=0.529943 | Recon=0.002089 | TrainAcc=0.7770
# Fold 15 Epoch 1000: TotalLoss=0.523822 | Sup=0.523718 | Recon=0.002086 | TrainAcc=0.7881
# Fold 15 Epoch 1100: TotalLoss=0.518615 | Sup=0.518511 | Recon=0.002082 | TrainAcc=0.7955
# Fold 15 Epoch 1200: TotalLoss=0.514115 | Sup=0.514011 | Recon=0.002079 | TrainAcc=0.8030
# Fold 15 Epoch 1300: TotalLoss=0.510455 | Sup=0.510352 | Recon=0.002076 | TrainAcc=0.8067
# Fold 15 Epoch 1400: TotalLoss=0.507667 | Sup=0.507564 | Recon=0.002074 | TrainAcc=0.8104
# Fold 15 Epoch 1500: TotalLoss=0.505502 | Sup=0.505398 | Recon=0.002073 | TrainAcc=0.8104
# Fold 15 Epoch 1600: TotalLoss=0.503757 | Sup=0.503653 | Recon=0.002073 | TrainAcc=0.8104
# Fold 15 Epoch 1700: TotalLoss=0.502317 | Sup=0.502213 | Recon=0.002072 | TrainAcc=0.8104
# Fold 15 Epoch 1800: TotalLoss=0.501104 | Sup=0.501001 | Recon=0.002072 | TrainAcc=0.8141
# Fold 15 Epoch 1900: TotalLoss=0.500046 | Sup=0.499942 | Recon=0.002073 | TrainAcc=0.8141
# Fold 15 Epoch 2000: TotalLoss=0.499096 | Sup=0.498993 | Recon=0.002073 | TrainAcc=0.8178
# Fold 15 → Acc=0.7667 | Prec=0.8125 | Rec=0.7647 | F1=0.7879 | AUC=0.8190 | CE Loss=0.5422
#
# === Fold 16 ===
# Train CN: 119, Train MCI: 150
# Fold 16 Epoch 1: TotalLoss=0.694024 | Sup=0.693919 | Recon=0.002107 | TrainAcc=0.4647
# Fold 16 Epoch 100: TotalLoss=0.667285 | Sup=0.667180 | Recon=0.002105 | TrainAcc=0.5576
# Fold 16 Epoch 200: TotalLoss=0.649006 | Sup=0.648901 | Recon=0.002104 | TrainAcc=0.5539
# Fold 16 Epoch 300: TotalLoss=0.624296 | Sup=0.624191 | Recon=0.002103 | TrainAcc=0.6617
# Fold 16 Epoch 400: TotalLoss=0.597994 | Sup=0.597889 | Recon=0.002102 | TrainAcc=0.7584
# Fold 16 Epoch 500: TotalLoss=0.575267 | Sup=0.575162 | Recon=0.002100 | TrainAcc=0.7955
# Fold 16 Epoch 600: TotalLoss=0.557314 | Sup=0.557209 | Recon=0.002097 | TrainAcc=0.7955
# Fold 16 Epoch 700: TotalLoss=0.543754 | Sup=0.543649 | Recon=0.002094 | TrainAcc=0.7918
# Fold 16 Epoch 800: TotalLoss=0.533521 | Sup=0.533417 | Recon=0.002092 | TrainAcc=0.7918
# Fold 16 Epoch 900: TotalLoss=0.525685 | Sup=0.525580 | Recon=0.002089 | TrainAcc=0.7881
# Fold 16 Epoch 1000: TotalLoss=0.519495 | Sup=0.519391 | Recon=0.002087 | TrainAcc=0.8030
# Fold 16 Epoch 1100: TotalLoss=0.514467 | Sup=0.514362 | Recon=0.002085 | TrainAcc=0.8067
# Fold 16 Epoch 1200: TotalLoss=0.510223 | Sup=0.510119 | Recon=0.002083 | TrainAcc=0.8067
# Fold 16 Epoch 1300: TotalLoss=0.506501 | Sup=0.506397 | Recon=0.002081 | TrainAcc=0.8104
# Fold 16 Epoch 1400: TotalLoss=0.503368 | Sup=0.503264 | Recon=0.002080 | TrainAcc=0.8178
# Fold 16 Epoch 1500: TotalLoss=0.500896 | Sup=0.500792 | Recon=0.002079 | TrainAcc=0.8178
# Fold 16 Epoch 1600: TotalLoss=0.498945 | Sup=0.498842 | Recon=0.002078 | TrainAcc=0.8178
# Fold 16 Epoch 1700: TotalLoss=0.497362 | Sup=0.497258 | Recon=0.002078 | TrainAcc=0.8216
# Fold 16 Epoch 1800: TotalLoss=0.496036 | Sup=0.495932 | Recon=0.002078 | TrainAcc=0.8216
# Fold 16 Epoch 1900: TotalLoss=0.494908 | Sup=0.494804 | Recon=0.002078 | TrainAcc=0.8216
# Fold 16 Epoch 2000: TotalLoss=0.493934 | Sup=0.493830 | Recon=0.002078 | TrainAcc=0.8216
# Fold 16 → Acc=0.7333 | Prec=0.8462 | Rec=0.6471 | F1=0.7333 | AUC=0.8281 | CE Loss=0.5326
#
# === Fold 17 ===
# Train CN: 119, Train MCI: 150
# Fold 17 Epoch 1: TotalLoss=0.694056 | Sup=0.693950 | Recon=0.002112 | TrainAcc=0.3643
# Fold 17 Epoch 100: TotalLoss=0.668184 | Sup=0.668079 | Recon=0.002108 | TrainAcc=0.5576
# Fold 17 Epoch 200: TotalLoss=0.650000 | Sup=0.649894 | Recon=0.002107 | TrainAcc=0.5539
# Fold 17 Epoch 300: TotalLoss=0.625678 | Sup=0.625572 | Recon=0.002105 | TrainAcc=0.6729
# Fold 17 Epoch 400: TotalLoss=0.600432 | Sup=0.600327 | Recon=0.002103 | TrainAcc=0.7472
# Fold 17 Epoch 500: TotalLoss=0.579305 | Sup=0.579200 | Recon=0.002099 | TrainAcc=0.7770
# Fold 17 Epoch 600: TotalLoss=0.563059 | Sup=0.562954 | Recon=0.002096 | TrainAcc=0.7770
# Fold 17 Epoch 700: TotalLoss=0.550862 | Sup=0.550757 | Recon=0.002094 | TrainAcc=0.7732
# Fold 17 Epoch 800: TotalLoss=0.541772 | Sup=0.541668 | Recon=0.002091 | TrainAcc=0.7770
# Fold 17 Epoch 900: TotalLoss=0.534781 | Sup=0.534676 | Recon=0.002089 | TrainAcc=0.7844
# Fold 17 Epoch 1000: TotalLoss=0.529145 | Sup=0.529040 | Recon=0.002086 | TrainAcc=0.7918
# Fold 17 Epoch 1100: TotalLoss=0.524440 | Sup=0.524336 | Recon=0.002084 | TrainAcc=0.7955
# Fold 17 Epoch 1200: TotalLoss=0.520625 | Sup=0.520521 | Recon=0.002083 | TrainAcc=0.7918
# Fold 17 Epoch 1300: TotalLoss=0.517700 | Sup=0.517596 | Recon=0.002081 | TrainAcc=0.7918
# Fold 17 Epoch 1400: TotalLoss=0.515434 | Sup=0.515330 | Recon=0.002080 | TrainAcc=0.7918
# Fold 17 Epoch 1500: TotalLoss=0.513638 | Sup=0.513534 | Recon=0.002079 | TrainAcc=0.7955
# Fold 17 Epoch 1600: TotalLoss=0.512180 | Sup=0.512076 | Recon=0.002079 | TrainAcc=0.7955
# Fold 17 Epoch 1700: TotalLoss=0.510949 | Sup=0.510845 | Recon=0.002079 | TrainAcc=0.7918
# Fold 17 Epoch 1800: TotalLoss=0.509851 | Sup=0.509747 | Recon=0.002079 | TrainAcc=0.7918
# Fold 17 Epoch 1900: TotalLoss=0.508784 | Sup=0.508680 | Recon=0.002078 | TrainAcc=0.7918
# Fold 17 Epoch 2000: TotalLoss=0.507686 | Sup=0.507582 | Recon=0.002077 | TrainAcc=0.7918
# Fold 17 → Acc=0.8333 | Prec=0.8000 | Rec=0.9412 | F1=0.8649 | AUC=0.8824 | CE Loss=0.4874
#
# === Fold 18 ===
# Train CN: 119, Train MCI: 150
# Fold 18 Epoch 1: TotalLoss=0.692528 | Sup=0.692422 | Recon=0.002107 | TrainAcc=0.5613
# Fold 18 Epoch 100: TotalLoss=0.668585 | Sup=0.668480 | Recon=0.002102 | TrainAcc=0.5576
# Fold 18 Epoch 200: TotalLoss=0.651776 | Sup=0.651671 | Recon=0.002100 | TrainAcc=0.5539
# Fold 18 Epoch 300: TotalLoss=0.629255 | Sup=0.629150 | Recon=0.002098 | TrainAcc=0.6394
# Fold 18 Epoch 400: TotalLoss=0.604530 | Sup=0.604425 | Recon=0.002097 | TrainAcc=0.7509
# Fold 18 Epoch 500: TotalLoss=0.582967 | Sup=0.582862 | Recon=0.002095 | TrainAcc=0.7955
# Fold 18 Epoch 600: TotalLoss=0.565598 | Sup=0.565493 | Recon=0.002093 | TrainAcc=0.7918
# Fold 18 Epoch 700: TotalLoss=0.550903 | Sup=0.550798 | Recon=0.002091 | TrainAcc=0.7918
# Fold 18 Epoch 800: TotalLoss=0.539765 | Sup=0.539660 | Recon=0.002089 | TrainAcc=0.7881
# Fold 18 Epoch 900: TotalLoss=0.531921 | Sup=0.531816 | Recon=0.002087 | TrainAcc=0.7881
# Fold 18 Epoch 1000: TotalLoss=0.526194 | Sup=0.526090 | Recon=0.002084 | TrainAcc=0.7918
# Fold 18 Epoch 1100: TotalLoss=0.521681 | Sup=0.521577 | Recon=0.002082 | TrainAcc=0.7955
# Fold 18 Epoch 1200: TotalLoss=0.517793 | Sup=0.517689 | Recon=0.002079 | TrainAcc=0.8030
# Fold 18 Epoch 1300: TotalLoss=0.514542 | Sup=0.514438 | Recon=0.002078 | TrainAcc=0.8030
# Fold 18 Epoch 1400: TotalLoss=0.512059 | Sup=0.511955 | Recon=0.002076 | TrainAcc=0.8067
# Fold 18 Epoch 1500: TotalLoss=0.510172 | Sup=0.510068 | Recon=0.002075 | TrainAcc=0.8067
# Fold 18 Epoch 1600: TotalLoss=0.508692 | Sup=0.508588 | Recon=0.002075 | TrainAcc=0.8067
# Fold 18 Epoch 1700: TotalLoss=0.507485 | Sup=0.507382 | Recon=0.002074 | TrainAcc=0.8067
# Fold 18 Epoch 1800: TotalLoss=0.506474 | Sup=0.506370 | Recon=0.002075 | TrainAcc=0.8030
# Fold 18 Epoch 1900: TotalLoss=0.505600 | Sup=0.505497 | Recon=0.002075 | TrainAcc=0.8030
# Fold 18 Epoch 2000: TotalLoss=0.504822 | Sup=0.504718 | Recon=0.002075 | TrainAcc=0.8030
# Fold 18 → Acc=0.8000 | Prec=0.8235 | Rec=0.8235 | F1=0.8235 | AUC=0.9231 | CE Loss=0.4895
#
# === Fold 19 ===
# Train CN: 119, Train MCI: 150
# Fold 19 Epoch 1: TotalLoss=0.692808 | Sup=0.692702 | Recon=0.002104 | TrainAcc=0.5539
# Fold 19 Epoch 100: TotalLoss=0.667412 | Sup=0.667307 | Recon=0.002102 | TrainAcc=0.5576
# Fold 19 Epoch 200: TotalLoss=0.650034 | Sup=0.649929 | Recon=0.002100 | TrainAcc=0.5539
# Fold 19 Epoch 300: TotalLoss=0.626501 | Sup=0.626396 | Recon=0.002100 | TrainAcc=0.6431
# Fold 19 Epoch 400: TotalLoss=0.600907 | Sup=0.600802 | Recon=0.002099 | TrainAcc=0.7509
# Fold 19 Epoch 500: TotalLoss=0.578147 | Sup=0.578043 | Recon=0.002097 | TrainAcc=0.7918
# Fold 19 Epoch 600: TotalLoss=0.560043 | Sup=0.559938 | Recon=0.002095 | TrainAcc=0.7881
# Fold 19 Epoch 700: TotalLoss=0.546263 | Sup=0.546158 | Recon=0.002093 | TrainAcc=0.7918
# Fold 19 Epoch 800: TotalLoss=0.535584 | Sup=0.535479 | Recon=0.002091 | TrainAcc=0.7918
# Fold 19 Epoch 900: TotalLoss=0.527628 | Sup=0.527524 | Recon=0.002088 | TrainAcc=0.7918
# Fold 19 Epoch 1000: TotalLoss=0.521607 | Sup=0.521503 | Recon=0.002086 | TrainAcc=0.7955
# Fold 19 Epoch 1100: TotalLoss=0.517004 | Sup=0.516900 | Recon=0.002083 | TrainAcc=0.8030
# Fold 19 Epoch 1200: TotalLoss=0.513396 | Sup=0.513292 | Recon=0.002081 | TrainAcc=0.8067
# Fold 19 Epoch 1300: TotalLoss=0.510519 | Sup=0.510415 | Recon=0.002079 | TrainAcc=0.8030
# Fold 19 Epoch 1400: TotalLoss=0.508200 | Sup=0.508096 | Recon=0.002078 | TrainAcc=0.8030
# Fold 19 Epoch 1500: TotalLoss=0.506287 | Sup=0.506184 | Recon=0.002077 | TrainAcc=0.8067
# Fold 19 Epoch 1600: TotalLoss=0.504699 | Sup=0.504595 | Recon=0.002076 | TrainAcc=0.8104
# Fold 19 Epoch 1700: TotalLoss=0.503371 | Sup=0.503267 | Recon=0.002076 | TrainAcc=0.8067
# Fold 19 Epoch 1800: TotalLoss=0.502240 | Sup=0.502136 | Recon=0.002076 | TrainAcc=0.8030
# Fold 19 Epoch 1900: TotalLoss=0.501257 | Sup=0.501153 | Recon=0.002077 | TrainAcc=0.8030
# Fold 19 Epoch 2000: TotalLoss=0.500376 | Sup=0.500272 | Recon=0.002077 | TrainAcc=0.8030
# Fold 19 → Acc=0.8000 | Prec=0.8235 | Rec=0.8235 | F1=0.8235 | AUC=0.8462 | CE Loss=0.5119
#
# === Fold 20 ===
# Train CN: 119, Train MCI: 150
# Fold 20 Epoch 1: TotalLoss=0.690010 | Sup=0.689905 | Recon=0.002110 | TrainAcc=0.5576
# Fold 20 Epoch 100: TotalLoss=0.664896 | Sup=0.664791 | Recon=0.002109 | TrainAcc=0.5576
# Fold 20 Epoch 200: TotalLoss=0.645133 | Sup=0.645027 | Recon=0.002106 | TrainAcc=0.5613
# Fold 20 Epoch 300: TotalLoss=0.619430 | Sup=0.619325 | Recon=0.002103 | TrainAcc=0.6989
# Fold 20 Epoch 400: TotalLoss=0.593459 | Sup=0.593354 | Recon=0.002099 | TrainAcc=0.7621
# Fold 20 Epoch 500: TotalLoss=0.572034 | Sup=0.571929 | Recon=0.002096 | TrainAcc=0.8067
# Fold 20 Epoch 600: TotalLoss=0.555494 | Sup=0.555390 | Recon=0.002094 | TrainAcc=0.7918
# Fold 20 Epoch 700: TotalLoss=0.542783 | Sup=0.542679 | Recon=0.002091 | TrainAcc=0.7881
# Fold 20 Epoch 800: TotalLoss=0.533128 | Sup=0.533024 | Recon=0.002089 | TrainAcc=0.7881
# Fold 20 Epoch 900: TotalLoss=0.525893 | Sup=0.525789 | Recon=0.002087 | TrainAcc=0.7844
# Fold 20 Epoch 1000: TotalLoss=0.520411 | Sup=0.520307 | Recon=0.002085 | TrainAcc=0.7918
# Fold 20 Epoch 1100: TotalLoss=0.516212 | Sup=0.516108 | Recon=0.002083 | TrainAcc=0.7955
# Fold 20 Epoch 1200: TotalLoss=0.512687 | Sup=0.512583 | Recon=0.002082 | TrainAcc=0.7955
# Fold 20 Epoch 1300: TotalLoss=0.509578 | Sup=0.509474 | Recon=0.002080 | TrainAcc=0.7993
# Fold 20 Epoch 1400: TotalLoss=0.507089 | Sup=0.506985 | Recon=0.002080 | TrainAcc=0.8067
# Fold 20 Epoch 1500: TotalLoss=0.505208 | Sup=0.505104 | Recon=0.002079 | TrainAcc=0.8067
# Fold 20 Epoch 1600: TotalLoss=0.503740 | Sup=0.503636 | Recon=0.002079 | TrainAcc=0.8067
# Fold 20 Epoch 1700: TotalLoss=0.502524 | Sup=0.502420 | Recon=0.002079 | TrainAcc=0.8067
# Fold 20 Epoch 1800: TotalLoss=0.501423 | Sup=0.501319 | Recon=0.002078 | TrainAcc=0.8067
# Fold 20 Epoch 1900: TotalLoss=0.500304 | Sup=0.500200 | Recon=0.002078 | TrainAcc=0.8067
# Fold 20 Epoch 2000: TotalLoss=0.499084 | Sup=0.498980 | Recon=0.002076 | TrainAcc=0.8067
# Fold 20 → Acc=0.7333 | Prec=0.7647 | Rec=0.7647 | F1=0.7647 | AUC=0.7964 | CE Loss=0.5731
#
# === Average Results Across 20 Folds ===
# Accuracy:  0.8083 ± 0.0614
# Precision: 0.8475 ± 0.0641
# Recall:    0.8147 ± 0.0989
# F1-score:  0.8261 ± 0.0601
# AUC:       0.8855 ± 0.0486
# CE Loss:   0.4958 ± 0.0354
