# %%
import torch
import torch.nn as nn
import torch.nn.functional as nnFn
import torch.optim as optim
import numpy as np
import random
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from torch_geometric.data import Data
from torch_geometric.nn import GATConv
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score,
    f1_score, roc_auc_score, log_loss
)

# %%
fa_feature_path = "Histogram_CN_FA_20bin_updated.npy"
Histogram_feature_CN_FA_array = np.load(fa_feature_path, allow_pickle=True)

fa_feature_path = "Histogram_MCI_FA_20bin_updated.npy"
Histogram_feature_MCI_FA_array = np.load(fa_feature_path, allow_pickle=True)

X = np.vstack([Histogram_feature_CN_FA_array, Histogram_feature_MCI_FA_array])
y = np.hstack([
    np.zeros(Histogram_feature_CN_FA_array.shape[0], dtype=np.int64),
    np.ones(Histogram_feature_MCI_FA_array.shape[0], dtype=np.int64)
])

num_nodes, num_feats = X.shape
print(f"Features: {X.shape}, Labels: {y.shape}")
# Out:
# Features: (300, 180), Labels: (300,)

# %%
class GAT_Supervised(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim, heads=4, activ="RELU", dropout=0.2):
        super(GAT_Supervised, self).__init__()
        self.conv1 = GATConv(input_dim, hidden_dim, heads=heads, concat=True, dropout=dropout)
        self.bn1 = nn.BatchNorm1d(hidden_dim * heads)
        self.dropout = nn.Dropout(dropout)
        self.fc = nn.Linear(hidden_dim * heads, output_dim)
        activations = {
            "SELU": nnFn.selu,
            "SiLU": nnFn.silu,
            "GELU": nnFn.gelu,
            "RELU": nnFn.relu,
            "ELU": nnFn.elu
        }
        self.act = activations.get(activ, nnFn.elu)

    def forward(self, data):
        x, edge_index = data.x, data.edge_index
        x = self.conv1(x, edge_index)
        x = self.bn1(x)
        x = self.act(x)
        x = self.dropout(x)
        logits = self.fc(x)
        return logits

# %%
def create_adj(F, alpha=1):
    F_norm = F / np.linalg.norm(F, axis=1, keepdims=True)
    W = np.dot(F_norm, F_norm.T)
    W = np.where(W >= alpha, 1, 0).astype(np.float32)
    W = W / W.max()
    return W

def load_data(adj, node_feats):
    node_feats = torch.from_numpy(node_feats).float()
    edge_index = torch.from_numpy(np.array(np.nonzero((adj > 0))))
    return Data(x=node_feats, edge_index=edge_index)

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
alpha = 0.8
feats_dim = num_feats
hidden_dim = 512
num_classes = 2
num_epochs = 2000
lr = 0.0001
weight_decay = 1e-4
batch_print_freq = 100

# %%
W = create_adj(X, alpha)
data = load_data(W, X).to(device)
A_tensor = torch.from_numpy(W).float().to(device)
print(data)
# Out:
# Data(x=[300, 180], edge_index=[2, 79964])

# %%
sss = StratifiedShuffleSplit(n_splits=20, test_size=0.5, random_state=42)

accuracies, precisions, recalls, f1_scores, aucs, ce_losses = [], [], [], [], [], []

for fold, (train_idx, test_idx) in enumerate(sss.split(X, y), start=1):
    print(f"\n=== Fold {fold} ===")

    train_idx_t = torch.from_numpy(train_idx).long().to(device)
    y_train_tensor = torch.from_numpy(y[train_idx]).long().to(device)

    model = GAT_Supervised(feats_dim, hidden_dim, num_classes).to(device)
    optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
    ce_loss = nn.CrossEntropyLoss()


    for epoch in range(1, num_epochs + 1):
        model.train()
        optimizer.zero_grad()

        logits = model(data)
        loss = ce_loss(logits[train_idx_t], y_train_tensor)
        loss.backward()
        optimizer.step()

        if epoch % batch_print_freq == 0 or epoch == 1:
            model.eval()
            with torch.no_grad():
                preds_train = logits[train_idx_t].argmax(dim=1)
                acc_train = accuracy_score(y_train_tensor.cpu(), preds_train.cpu())
            print(f"Fold {fold} Epoch {epoch}: "
                  f"Loss={loss.item():.6f} | TrainAcc={acc_train:.4f}")


    model.eval()
    with torch.no_grad():
        out = model(data)
        preds = out.argmax(dim=1).cpu().numpy()
        probs = torch.softmax(out, dim=1)[:, 1].cpu().numpy()  # Probability for class 1

    y_test = y[test_idx]
    y_pred_test = preds[test_idx]
    y_prob_test = probs[test_idx]


    acc = accuracy_score(y_test, y_pred_test)
    prec = precision_score(y_test, y_pred_test, zero_division=0)
    rec = recall_score(y_test, y_pred_test, zero_division=0)
    f1 = f1_score(y_test, y_pred_test, zero_division=0)
    auc = roc_auc_score(y_test, y_prob_test)
    ce = log_loss(y_test, y_prob_test)

    accuracies.append(acc)
    precisions.append(prec)
    recalls.append(rec)
    f1_scores.append(f1)
    aucs.append(auc)
    ce_losses.append(ce)

    print(f"Fold {fold} → "
          f"Acc={acc:.4f} | Prec={prec:.4f} | Rec={rec:.4f} | "
          f"F1={f1:.4f} | AUC={auc:.4f} | CE Loss={ce:.4f}")


print("\n=== Average Results Across 20 Folds ===")
print(f"Accuracy:  {np.mean(accuracies):.4f} ± {np.std(accuracies):.4f}")
print(f"Precision: {np.mean(precisions):.4f} ± {np.std(precisions):.4f}")
print(f"Recall:    {np.mean(recalls):.4f} ± {np.std(recalls):.4f}")
print(f"F1-score:  {np.mean(f1_scores):.4f} ± {np.std(f1_scores):.4f}")
print(f"CE Loss:   {np.mean(ce_losses):.4f} ± {np.std(ce_losses):.4f}")
print(f"AUC:       {np.mean(aucs):.4f} ± {np.std(aucs):.4f}")
# Out:
# === Fold 1 ===
# Fold 1 Epoch 1: Loss=0.664624 | TrainAcc=0.6067
# Fold 1 Epoch 100: Loss=0.489848 | TrainAcc=0.7733
# Fold 1 Epoch 200: Loss=0.357672 | TrainAcc=0.8400
# Fold 1 Epoch 300: Loss=0.254751 | TrainAcc=0.8933
# Fold 1 Epoch 400: Loss=0.181660 | TrainAcc=0.9400
# Fold 1 Epoch 500: Loss=0.084677 | TrainAcc=0.9800
# Fold 1 Epoch 600: Loss=0.047681 | TrainAcc=0.9867
# Fold 1 Epoch 700: Loss=0.018139 | TrainAcc=1.0000
# Fold 1 Epoch 800: Loss=0.014575 | TrainAcc=1.0000
# Fold 1 Epoch 900: Loss=0.008201 | TrainAcc=1.0000
# Fold 1 Epoch 1000: Loss=0.006218 | TrainAcc=1.0000
# Fold 1 Epoch 1100: Loss=0.005758 | TrainAcc=1.0000
# Fold 1 Epoch 1200: Loss=0.003628 | TrainAcc=1.0000
# Fold 1 Epoch 1300: Loss=0.004309 | TrainAcc=1.0000
# Fold 1 Epoch 1400: Loss=0.003211 | TrainAcc=1.0000
# Fold 1 Epoch 1500: Loss=0.001929 | TrainAcc=1.0000
# Fold 1 Epoch 1600: Loss=0.001808 | TrainAcc=1.0000
# Fold 1 Epoch 1700: Loss=0.002277 | TrainAcc=1.0000
# Fold 1 Epoch 1800: Loss=0.001198 | TrainAcc=1.0000
# Fold 1 Epoch 1900: Loss=0.000893 | TrainAcc=1.0000
# Fold 1 Epoch 2000: Loss=0.001505 | TrainAcc=1.0000
# Fold 1 → Acc=0.7733 | Prec=0.7475 | Rec=0.8916 | F1=0.8132 | AUC=0.8632 | CE Loss=1.4205
#
# === Fold 2 ===
# Fold 2 Epoch 1: Loss=0.679368 | TrainAcc=0.5467
# Fold 2 Epoch 100: Loss=0.498866 | TrainAcc=0.7333
# Fold 2 Epoch 200: Loss=0.336445 | TrainAcc=0.8400
# Fold 2 Epoch 300: Loss=0.155280 | TrainAcc=0.9400
# Fold 2 Epoch 400: Loss=0.086722 | TrainAcc=0.9667
# Fold 2 Epoch 500: Loss=0.084711 | TrainAcc=0.9667
# Fold 2 Epoch 600: Loss=0.055143 | TrainAcc=0.9933
# Fold 2 Epoch 700: Loss=0.020607 | TrainAcc=0.9933
# Fold 2 Epoch 800: Loss=0.017131 | TrainAcc=1.0000
# Fold 2 Epoch 900: Loss=0.006524 | TrainAcc=1.0000
# Fold 2 Epoch 1000: Loss=0.012294 | TrainAcc=0.9933
# Fold 2 Epoch 1100: Loss=0.008138 | TrainAcc=0.9933
# Fold 2 Epoch 1200: Loss=0.003730 | TrainAcc=1.0000
# Fold 2 Epoch 1300: Loss=0.003406 | TrainAcc=1.0000
# Fold 2 Epoch 1400: Loss=0.005044 | TrainAcc=1.0000
# Fold 2 Epoch 1500: Loss=0.009434 | TrainAcc=0.9933
# Fold 2 Epoch 1600: Loss=0.001935 | TrainAcc=1.0000
# Fold 2 Epoch 1700: Loss=0.001934 | TrainAcc=1.0000
# Fold 2 Epoch 1800: Loss=0.002184 | TrainAcc=1.0000
# Fold 2 Epoch 1900: Loss=0.001364 | TrainAcc=1.0000
# Fold 2 Epoch 2000: Loss=0.000817 | TrainAcc=1.0000
# Fold 2 → Acc=0.8000 | Prec=0.8293 | Rec=0.8095 | F1=0.8193 | AUC=0.8584 | CE Loss=1.8406
#
# === Fold 3 ===
# Fold 3 Epoch 1: Loss=0.768845 | TrainAcc=0.4667
# Fold 3 Epoch 100: Loss=0.545536 | TrainAcc=0.7467
# Fold 3 Epoch 200: Loss=0.389358 | TrainAcc=0.8200
# Fold 3 Epoch 300: Loss=0.179447 | TrainAcc=0.9600
# Fold 3 Epoch 400: Loss=0.099080 | TrainAcc=0.9733
# Fold 3 Epoch 500: Loss=0.057321 | TrainAcc=0.9800
# Fold 3 Epoch 600: Loss=0.031343 | TrainAcc=1.0000
# Fold 3 Epoch 700: Loss=0.021295 | TrainAcc=1.0000
# Fold 3 Epoch 800: Loss=0.012439 | TrainAcc=1.0000
# Fold 3 Epoch 900: Loss=0.007271 | TrainAcc=1.0000
# Fold 3 Epoch 1000: Loss=0.006481 | TrainAcc=1.0000
# Fold 3 Epoch 1100: Loss=0.002769 | TrainAcc=1.0000
# Fold 3 Epoch 1200: Loss=0.004866 | TrainAcc=1.0000
# Fold 3 Epoch 1300: Loss=0.003987 | TrainAcc=1.0000
# Fold 3 Epoch 1400: Loss=0.001777 | TrainAcc=1.0000
# Fold 3 Epoch 1500: Loss=0.001669 | TrainAcc=1.0000
# Fold 3 Epoch 1600: Loss=0.003290 | TrainAcc=1.0000
# Fold 3 Epoch 1700: Loss=0.001637 | TrainAcc=1.0000
# Fold 3 Epoch 1800: Loss=0.001214 | TrainAcc=1.0000
# Fold 3 Epoch 1900: Loss=0.007582 | TrainAcc=0.9933
# Fold 3 Epoch 2000: Loss=0.000662 | TrainAcc=1.0000
# Fold 3 → Acc=0.7800 | Prec=0.7604 | Rec=0.8795 | F1=0.8156 | AUC=0.8799 | CE Loss=1.2844
#
# === Fold 4 ===
# Fold 4 Epoch 1: Loss=0.705523 | TrainAcc=0.4533
# Fold 4 Epoch 100: Loss=0.533164 | TrainAcc=0.7533
# Fold 4 Epoch 200: Loss=0.433052 | TrainAcc=0.7933
# Fold 4 Epoch 300: Loss=0.278632 | TrainAcc=0.8867
# Fold 4 Epoch 400: Loss=0.178276 | TrainAcc=0.9533
# Fold 4 Epoch 500: Loss=0.079890 | TrainAcc=0.9867
# Fold 4 Epoch 600: Loss=0.045660 | TrainAcc=0.9933
# Fold 4 Epoch 700: Loss=0.060005 | TrainAcc=0.9733
# Fold 4 Epoch 800: Loss=0.015313 | TrainAcc=1.0000
# Fold 4 Epoch 900: Loss=0.011551 | TrainAcc=1.0000
# Fold 4 Epoch 1000: Loss=0.013589 | TrainAcc=1.0000
# Fold 4 Epoch 1100: Loss=0.003868 | TrainAcc=1.0000
# Fold 4 Epoch 1200: Loss=0.004229 | TrainAcc=1.0000
# Fold 4 Epoch 1300: Loss=0.007229 | TrainAcc=1.0000
# Fold 4 Epoch 1400: Loss=0.002858 | TrainAcc=1.0000
# Fold 4 Epoch 1500: Loss=0.002341 | TrainAcc=1.0000
# Fold 4 Epoch 1600: Loss=0.004334 | TrainAcc=1.0000
# Fold 4 Epoch 1700: Loss=0.001753 | TrainAcc=1.0000
# Fold 4 Epoch 1800: Loss=0.002290 | TrainAcc=1.0000
# Fold 4 Epoch 1900: Loss=0.002810 | TrainAcc=1.0000
# Fold 4 Epoch 2000: Loss=0.003131 | TrainAcc=1.0000
# Fold 4 → Acc=0.7800 | Prec=0.7717 | Rec=0.8554 | F1=0.8114 | AUC=0.8776 | CE Loss=1.2574
#
# === Fold 5 ===
# Fold 5 Epoch 1: Loss=0.687230 | TrainAcc=0.5467
# Fold 5 Epoch 100: Loss=0.551501 | TrainAcc=0.7400
# Fold 5 Epoch 200: Loss=0.401863 | TrainAcc=0.8467
# Fold 5 Epoch 300: Loss=0.272797 | TrainAcc=0.8933
# Fold 5 Epoch 400: Loss=0.197726 | TrainAcc=0.9267
# Fold 5 Epoch 500: Loss=0.120618 | TrainAcc=0.9533
# Fold 5 Epoch 600: Loss=0.081939 | TrainAcc=0.9733
# Fold 5 Epoch 700: Loss=0.044352 | TrainAcc=0.9800
# Fold 5 Epoch 800: Loss=0.027561 | TrainAcc=1.0000
# Fold 5 Epoch 900: Loss=0.014155 | TrainAcc=0.9933
# Fold 5 Epoch 1000: Loss=0.009730 | TrainAcc=1.0000
# Fold 5 Epoch 1100: Loss=0.005391 | TrainAcc=1.0000
# Fold 5 Epoch 1200: Loss=0.005519 | TrainAcc=1.0000
# Fold 5 Epoch 1300: Loss=0.004269 | TrainAcc=1.0000
# Fold 5 Epoch 1400: Loss=0.001610 | TrainAcc=1.0000
# Fold 5 Epoch 1500: Loss=0.001620 | TrainAcc=1.0000
# Fold 5 Epoch 1600: Loss=0.001965 | TrainAcc=1.0000
# Fold 5 Epoch 1700: Loss=0.001656 | TrainAcc=1.0000
# Fold 5 Epoch 1800: Loss=0.003461 | TrainAcc=1.0000
# Fold 5 Epoch 1900: Loss=0.003238 | TrainAcc=1.0000
# Fold 5 Epoch 2000: Loss=0.001356 | TrainAcc=1.0000
# Fold 5 → Acc=0.8267 | Prec=0.8295 | Rec=0.8690 | F1=0.8488 | AUC=0.8758 | CE Loss=0.9604
#
# === Fold 6 ===
# Fold 6 Epoch 1: Loss=0.686737 | TrainAcc=0.5400
# Fold 6 Epoch 100: Loss=0.514336 | TrainAcc=0.7867
# Fold 6 Epoch 200: Loss=0.403666 | TrainAcc=0.8067
# Fold 6 Epoch 300: Loss=0.279454 | TrainAcc=0.8800
# Fold 6 Epoch 400: Loss=0.130738 | TrainAcc=0.9333
# Fold 6 Epoch 500: Loss=0.081220 | TrainAcc=0.9733
# Fold 6 Epoch 600: Loss=0.027864 | TrainAcc=1.0000
# Fold 6 Epoch 700: Loss=0.021380 | TrainAcc=0.9933
# Fold 6 Epoch 800: Loss=0.018505 | TrainAcc=0.9933
# Fold 6 Epoch 900: Loss=0.008266 | TrainAcc=1.0000
# Fold 6 Epoch 1000: Loss=0.010845 | TrainAcc=1.0000
# Fold 6 Epoch 1100: Loss=0.004223 | TrainAcc=1.0000
# Fold 6 Epoch 1200: Loss=0.002726 | TrainAcc=1.0000
# Fold 6 Epoch 1300: Loss=0.008563 | TrainAcc=0.9933
# Fold 6 Epoch 1400: Loss=0.008554 | TrainAcc=0.9933
# Fold 6 Epoch 1500: Loss=0.002024 | TrainAcc=1.0000
# Fold 6 Epoch 1600: Loss=0.004950 | TrainAcc=1.0000
# Fold 6 Epoch 1700: Loss=0.000657 | TrainAcc=1.0000
# Fold 6 Epoch 1800: Loss=0.002802 | TrainAcc=1.0000
# Fold 6 Epoch 1900: Loss=0.001091 | TrainAcc=1.0000
# Fold 6 Epoch 2000: Loss=0.003870 | TrainAcc=1.0000
# Fold 6 → Acc=0.7800 | Prec=0.7717 | Rec=0.8554 | F1=0.8114 | AUC=0.8654 | CE Loss=1.2956
#
# === Fold 7 ===
# Fold 7 Epoch 1: Loss=0.705448 | TrainAcc=0.5533
# Fold 7 Epoch 100: Loss=0.534113 | TrainAcc=0.7600
# Fold 7 Epoch 200: Loss=0.416119 | TrainAcc=0.8000
# Fold 7 Epoch 300: Loss=0.263248 | TrainAcc=0.8933
# Fold 7 Epoch 400: Loss=0.136083 | TrainAcc=0.9533
# Fold 7 Epoch 500: Loss=0.072159 | TrainAcc=0.9733
# Fold 7 Epoch 600: Loss=0.023890 | TrainAcc=1.0000
# Fold 7 Epoch 700: Loss=0.019309 | TrainAcc=1.0000
# Fold 7 Epoch 800: Loss=0.012727 | TrainAcc=0.9933
# Fold 7 Epoch 900: Loss=0.012976 | TrainAcc=1.0000
# Fold 7 Epoch 1000: Loss=0.005373 | TrainAcc=1.0000
# Fold 7 Epoch 1100: Loss=0.006486 | TrainAcc=1.0000
# Fold 7 Epoch 1200: Loss=0.005459 | TrainAcc=1.0000
# Fold 7 Epoch 1300: Loss=0.003057 | TrainAcc=1.0000
# Fold 7 Epoch 1400: Loss=0.002139 | TrainAcc=1.0000
# Fold 7 Epoch 1500: Loss=0.001846 | TrainAcc=1.0000
# Fold 7 Epoch 1600: Loss=0.001849 | TrainAcc=1.0000
# Fold 7 Epoch 1700: Loss=0.001768 | TrainAcc=1.0000
# Fold 7 Epoch 1800: Loss=0.000916 | TrainAcc=1.0000
# Fold 7 Epoch 1900: Loss=0.000670 | TrainAcc=1.0000
# Fold 7 Epoch 2000: Loss=0.000778 | TrainAcc=1.0000
# Fold 7 → Acc=0.7533 | Prec=0.7556 | Rec=0.8193 | F1=0.7861 | AUC=0.8424 | CE Loss=1.4649
#
# === Fold 8 ===
# Fold 8 Epoch 1: Loss=0.686755 | TrainAcc=0.6133
# Fold 8 Epoch 100: Loss=0.506782 | TrainAcc=0.8000
# Fold 8 Epoch 200: Loss=0.369525 | TrainAcc=0.8267
# Fold 8 Epoch 300: Loss=0.242675 | TrainAcc=0.9267
# Fold 8 Epoch 400: Loss=0.139989 | TrainAcc=0.9467
# Fold 8 Epoch 500: Loss=0.058859 | TrainAcc=0.9867
# Fold 8 Epoch 600: Loss=0.037607 | TrainAcc=0.9933
# Fold 8 Epoch 700: Loss=0.027321 | TrainAcc=0.9933
# Fold 8 Epoch 800: Loss=0.013747 | TrainAcc=1.0000
# Fold 8 Epoch 900: Loss=0.007195 | TrainAcc=1.0000
# Fold 8 Epoch 1000: Loss=0.002598 | TrainAcc=1.0000
# Fold 8 Epoch 1100: Loss=0.005035 | TrainAcc=1.0000
# Fold 8 Epoch 1200: Loss=0.007477 | TrainAcc=0.9933
# Fold 8 Epoch 1300: Loss=0.005790 | TrainAcc=1.0000
# Fold 8 Epoch 1400: Loss=0.003029 | TrainAcc=1.0000
# Fold 8 Epoch 1500: Loss=0.003238 | TrainAcc=1.0000
# Fold 8 Epoch 1600: Loss=0.002868 | TrainAcc=1.0000
# Fold 8 Epoch 1700: Loss=0.001358 | TrainAcc=1.0000
# Fold 8 Epoch 1800: Loss=0.001399 | TrainAcc=1.0000
# Fold 8 Epoch 1900: Loss=0.002066 | TrainAcc=1.0000
# Fold 8 Epoch 2000: Loss=0.000724 | TrainAcc=1.0000
# Fold 8 → Acc=0.7933 | Prec=0.8023 | Rec=0.8313 | F1=0.8166 | AUC=0.8426 | CE Loss=1.3712
#
# === Fold 9 ===
# Fold 9 Epoch 1: Loss=0.706725 | TrainAcc=0.5467
# Fold 9 Epoch 100: Loss=0.547218 | TrainAcc=0.7200
# Fold 9 Epoch 200: Loss=0.457877 | TrainAcc=0.8000
# Fold 9 Epoch 300: Loss=0.294099 | TrainAcc=0.9133
# Fold 9 Epoch 400: Loss=0.250689 | TrainAcc=0.8933
# Fold 9 Epoch 500: Loss=0.150786 | TrainAcc=0.9533
# Fold 9 Epoch 600: Loss=0.098148 | TrainAcc=0.9733
# Fold 9 Epoch 700: Loss=0.063888 | TrainAcc=0.9867
# Fold 9 Epoch 800: Loss=0.039467 | TrainAcc=0.9933
# Fold 9 Epoch 900: Loss=0.013560 | TrainAcc=1.0000
# Fold 9 Epoch 1000: Loss=0.010069 | TrainAcc=1.0000
# Fold 9 Epoch 1100: Loss=0.011592 | TrainAcc=1.0000
# Fold 9 Epoch 1200: Loss=0.008311 | TrainAcc=1.0000
# Fold 9 Epoch 1300: Loss=0.004112 | TrainAcc=1.0000
# Fold 9 Epoch 1400: Loss=0.004372 | TrainAcc=1.0000
# Fold 9 Epoch 1500: Loss=0.003310 | TrainAcc=1.0000
# Fold 9 Epoch 1600: Loss=0.001851 | TrainAcc=1.0000
# Fold 9 Epoch 1700: Loss=0.003858 | TrainAcc=1.0000
# Fold 9 Epoch 1800: Loss=0.002352 | TrainAcc=1.0000
# Fold 9 Epoch 1900: Loss=0.004107 | TrainAcc=1.0000
# Fold 9 Epoch 2000: Loss=0.003774 | TrainAcc=1.0000
# Fold 9 → Acc=0.7733 | Prec=0.7841 | Rec=0.8214 | F1=0.8023 | AUC=0.8702 | CE Loss=1.4106
#
# === Fold 10 ===
# Fold 10 Epoch 1: Loss=0.727052 | TrainAcc=0.4733
# Fold 10 Epoch 100: Loss=0.464093 | TrainAcc=0.8067
# Fold 10 Epoch 200: Loss=0.297640 | TrainAcc=0.8933
# Fold 10 Epoch 300: Loss=0.181088 | TrainAcc=0.9267
# Fold 10 Epoch 400: Loss=0.104890 | TrainAcc=0.9600
# Fold 10 Epoch 500: Loss=0.058878 | TrainAcc=0.9733
# Fold 10 Epoch 600: Loss=0.024371 | TrainAcc=1.0000
# Fold 10 Epoch 700: Loss=0.017425 | TrainAcc=1.0000
# Fold 10 Epoch 800: Loss=0.015999 | TrainAcc=1.0000
# Fold 10 Epoch 900: Loss=0.013308 | TrainAcc=0.9933
# Fold 10 Epoch 1000: Loss=0.005906 | TrainAcc=1.0000
# Fold 10 Epoch 1100: Loss=0.003321 | TrainAcc=1.0000
# Fold 10 Epoch 1200: Loss=0.002971 | TrainAcc=1.0000
# Fold 10 Epoch 1300: Loss=0.006271 | TrainAcc=1.0000
# Fold 10 Epoch 1400: Loss=0.002078 | TrainAcc=1.0000
# Fold 10 Epoch 1500: Loss=0.005035 | TrainAcc=1.0000
# Fold 10 Epoch 1600: Loss=0.001566 | TrainAcc=1.0000
# Fold 10 Epoch 1700: Loss=0.000825 | TrainAcc=1.0000
# Fold 10 Epoch 1800: Loss=0.001163 | TrainAcc=1.0000
# Fold 10 Epoch 1900: Loss=0.001082 | TrainAcc=1.0000
# Fold 10 Epoch 2000: Loss=0.000795 | TrainAcc=1.0000
# Fold 10 → Acc=0.7933 | Prec=0.8118 | Rec=0.8214 | F1=0.8166 | AUC=0.8078 | CE Loss=2.0195
#
# === Fold 11 ===
# Fold 11 Epoch 1: Loss=0.702959 | TrainAcc=0.5467
# Fold 11 Epoch 100: Loss=0.525805 | TrainAcc=0.7533
# Fold 11 Epoch 200: Loss=0.374745 | TrainAcc=0.8467
# Fold 11 Epoch 300: Loss=0.209730 | TrainAcc=0.9467
# Fold 11 Epoch 400: Loss=0.096211 | TrainAcc=0.9733
# Fold 11 Epoch 500: Loss=0.051543 | TrainAcc=0.9867
# Fold 11 Epoch 600: Loss=0.026920 | TrainAcc=0.9933
# Fold 11 Epoch 700: Loss=0.019280 | TrainAcc=0.9933
# Fold 11 Epoch 800: Loss=0.024508 | TrainAcc=0.9933
# Fold 11 Epoch 900: Loss=0.004577 | TrainAcc=1.0000
# Fold 11 Epoch 1000: Loss=0.005185 | TrainAcc=1.0000
# Fold 11 Epoch 1100: Loss=0.001329 | TrainAcc=1.0000
# Fold 11 Epoch 1200: Loss=0.003076 | TrainAcc=1.0000
# Fold 11 Epoch 1300: Loss=0.002838 | TrainAcc=1.0000
# Fold 11 Epoch 1400: Loss=0.003790 | TrainAcc=1.0000
# Fold 11 Epoch 1500: Loss=0.002350 | TrainAcc=1.0000
# Fold 11 Epoch 1600: Loss=0.001753 | TrainAcc=1.0000
# Fold 11 Epoch 1700: Loss=0.003637 | TrainAcc=1.0000
# Fold 11 Epoch 1800: Loss=0.002439 | TrainAcc=1.0000
# Fold 11 Epoch 1900: Loss=0.001684 | TrainAcc=1.0000
# Fold 11 Epoch 2000: Loss=0.003430 | TrainAcc=1.0000
# Fold 11 → Acc=0.8133 | Prec=0.7917 | Rec=0.9048 | F1=0.8444 | AUC=0.8520 | CE Loss=1.8680
#
# === Fold 12 ===
# Fold 12 Epoch 1: Loss=0.697017 | TrainAcc=0.5000
# Fold 12 Epoch 100: Loss=0.494442 | TrainAcc=0.7867
# Fold 12 Epoch 200: Loss=0.333003 | TrainAcc=0.8600
# Fold 12 Epoch 300: Loss=0.227156 | TrainAcc=0.9133
# Fold 12 Epoch 400: Loss=0.144757 | TrainAcc=0.9533
# Fold 12 Epoch 500: Loss=0.073475 | TrainAcc=0.9800
# Fold 12 Epoch 600: Loss=0.060495 | TrainAcc=0.9800
# Fold 12 Epoch 700: Loss=0.023403 | TrainAcc=1.0000
# Fold 12 Epoch 800: Loss=0.037743 | TrainAcc=0.9867
# Fold 12 Epoch 900: Loss=0.010359 | TrainAcc=1.0000
# Fold 12 Epoch 1000: Loss=0.010617 | TrainAcc=1.0000
# Fold 12 Epoch 1100: Loss=0.013862 | TrainAcc=1.0000
# Fold 12 Epoch 1200: Loss=0.004072 | TrainAcc=1.0000
# Fold 12 Epoch 1300: Loss=0.004213 | TrainAcc=1.0000
# Fold 12 Epoch 1400: Loss=0.003846 | TrainAcc=1.0000
# Fold 12 Epoch 1500: Loss=0.001835 | TrainAcc=1.0000
# Fold 12 Epoch 1600: Loss=0.001355 | TrainAcc=1.0000
# Fold 12 Epoch 1700: Loss=0.001556 | TrainAcc=1.0000
# Fold 12 Epoch 1800: Loss=0.004222 | TrainAcc=1.0000
# Fold 12 Epoch 1900: Loss=0.001643 | TrainAcc=1.0000
# Fold 12 Epoch 2000: Loss=0.004361 | TrainAcc=1.0000
# Fold 12 → Acc=0.7200 | Prec=0.7158 | Rec=0.8193 | F1=0.7640 | AUC=0.8210 | CE Loss=1.8716
#
# === Fold 13 ===
# Fold 13 Epoch 1: Loss=0.714237 | TrainAcc=0.4200
# Fold 13 Epoch 100: Loss=0.463867 | TrainAcc=0.8000
# Fold 13 Epoch 200: Loss=0.318508 | TrainAcc=0.8400
# Fold 13 Epoch 300: Loss=0.181992 | TrainAcc=0.9333
# Fold 13 Epoch 400: Loss=0.111234 | TrainAcc=0.9733
# Fold 13 Epoch 500: Loss=0.058017 | TrainAcc=0.9867
# Fold 13 Epoch 600: Loss=0.041563 | TrainAcc=0.9933
# Fold 13 Epoch 700: Loss=0.035699 | TrainAcc=0.9867
# Fold 13 Epoch 800: Loss=0.014857 | TrainAcc=1.0000
# Fold 13 Epoch 900: Loss=0.009705 | TrainAcc=1.0000
# Fold 13 Epoch 1000: Loss=0.006443 | TrainAcc=1.0000
# Fold 13 Epoch 1100: Loss=0.009874 | TrainAcc=1.0000
# Fold 13 Epoch 1200: Loss=0.003248 | TrainAcc=1.0000
# Fold 13 Epoch 1300: Loss=0.002006 | TrainAcc=1.0000
# Fold 13 Epoch 1400: Loss=0.003063 | TrainAcc=1.0000
# Fold 13 Epoch 1500: Loss=0.003605 | TrainAcc=1.0000
# Fold 13 Epoch 1600: Loss=0.002063 | TrainAcc=1.0000
# Fold 13 Epoch 1700: Loss=0.000896 | TrainAcc=1.0000
# Fold 13 Epoch 1800: Loss=0.002566 | TrainAcc=1.0000
# Fold 13 Epoch 1900: Loss=0.004415 | TrainAcc=1.0000
# Fold 13 Epoch 2000: Loss=0.001636 | TrainAcc=1.0000
# Fold 13 → Acc=0.7533 | Prec=0.7765 | Rec=0.7857 | F1=0.7811 | AUC=0.8085 | CE Loss=1.9115
#
# === Fold 14 ===
# Fold 14 Epoch 1: Loss=0.736678 | TrainAcc=0.4267
# Fold 14 Epoch 100: Loss=0.549740 | TrainAcc=0.7267
# Fold 14 Epoch 200: Loss=0.376412 | TrainAcc=0.8267
# Fold 14 Epoch 300: Loss=0.255272 | TrainAcc=0.9267
# Fold 14 Epoch 400: Loss=0.132470 | TrainAcc=0.9533
# Fold 14 Epoch 500: Loss=0.071896 | TrainAcc=0.9733
# Fold 14 Epoch 600: Loss=0.058860 | TrainAcc=0.9733
# Fold 14 Epoch 700: Loss=0.018502 | TrainAcc=1.0000
# Fold 14 Epoch 800: Loss=0.011054 | TrainAcc=1.0000
# Fold 14 Epoch 900: Loss=0.021436 | TrainAcc=0.9933
# Fold 14 Epoch 1000: Loss=0.003910 | TrainAcc=1.0000
# Fold 14 Epoch 1100: Loss=0.010925 | TrainAcc=1.0000
# Fold 14 Epoch 1200: Loss=0.002788 | TrainAcc=1.0000
# Fold 14 Epoch 1300: Loss=0.012552 | TrainAcc=0.9933
# Fold 14 Epoch 1400: Loss=0.000893 | TrainAcc=1.0000
# Fold 14 Epoch 1500: Loss=0.002982 | TrainAcc=1.0000
# Fold 14 Epoch 1600: Loss=0.000787 | TrainAcc=1.0000
# Fold 14 Epoch 1700: Loss=0.001012 | TrainAcc=1.0000
# Fold 14 Epoch 1800: Loss=0.002155 | TrainAcc=1.0000
# Fold 14 Epoch 1900: Loss=0.000798 | TrainAcc=1.0000
# Fold 14 Epoch 2000: Loss=0.000590 | TrainAcc=1.0000
# Fold 14 → Acc=0.7667 | Prec=0.7667 | Rec=0.8313 | F1=0.7977 | AUC=0.8784 | CE Loss=1.0831
#
# === Fold 15 ===
# Fold 15 Epoch 1: Loss=0.755334 | TrainAcc=0.4200
# Fold 15 Epoch 100: Loss=0.464228 | TrainAcc=0.8067
# Fold 15 Epoch 200: Loss=0.333472 | TrainAcc=0.8267
# Fold 15 Epoch 300: Loss=0.207580 | TrainAcc=0.9000
# Fold 15 Epoch 400: Loss=0.121094 | TrainAcc=0.9667
# Fold 15 Epoch 500: Loss=0.069118 | TrainAcc=0.9667
# Fold 15 Epoch 600: Loss=0.028464 | TrainAcc=1.0000
# Fold 15 Epoch 700: Loss=0.023044 | TrainAcc=0.9933
# Fold 15 Epoch 800: Loss=0.010711 | TrainAcc=1.0000
# Fold 15 Epoch 900: Loss=0.010933 | TrainAcc=0.9933
# Fold 15 Epoch 1000: Loss=0.008599 | TrainAcc=1.0000
# Fold 15 Epoch 1100: Loss=0.007793 | TrainAcc=0.9933
# Fold 15 Epoch 1200: Loss=0.002485 | TrainAcc=1.0000
# Fold 15 Epoch 1300: Loss=0.002824 | TrainAcc=1.0000
# Fold 15 Epoch 1400: Loss=0.001622 | TrainAcc=1.0000
# Fold 15 Epoch 1500: Loss=0.003534 | TrainAcc=1.0000
# Fold 15 Epoch 1600: Loss=0.002966 | TrainAcc=1.0000
# Fold 15 Epoch 1700: Loss=0.001569 | TrainAcc=1.0000
# Fold 15 Epoch 1800: Loss=0.002134 | TrainAcc=1.0000
# Fold 15 Epoch 1900: Loss=0.002827 | TrainAcc=1.0000
# Fold 15 Epoch 2000: Loss=0.001240 | TrainAcc=1.0000
# Fold 15 → Acc=0.7600 | Prec=0.8133 | Rec=0.7349 | F1=0.7722 | AUC=0.8232 | CE Loss=1.7306
#
# === Fold 16 ===
# Fold 16 Epoch 1: Loss=0.699060 | TrainAcc=0.4133
# Fold 16 Epoch 100: Loss=0.518722 | TrainAcc=0.7667
# Fold 16 Epoch 200: Loss=0.413033 | TrainAcc=0.7800
# Fold 16 Epoch 300: Loss=0.234164 | TrainAcc=0.9400
# Fold 16 Epoch 400: Loss=0.125171 | TrainAcc=0.9600
# Fold 16 Epoch 500: Loss=0.070440 | TrainAcc=0.9867
# Fold 16 Epoch 600: Loss=0.029580 | TrainAcc=0.9933
# Fold 16 Epoch 700: Loss=0.019403 | TrainAcc=1.0000
# Fold 16 Epoch 800: Loss=0.014445 | TrainAcc=1.0000
# Fold 16 Epoch 900: Loss=0.009000 | TrainAcc=1.0000
# Fold 16 Epoch 1000: Loss=0.008479 | TrainAcc=1.0000
# Fold 16 Epoch 1100: Loss=0.007304 | TrainAcc=1.0000
# Fold 16 Epoch 1200: Loss=0.003964 | TrainAcc=1.0000
# Fold 16 Epoch 1300: Loss=0.001756 | TrainAcc=1.0000
# Fold 16 Epoch 1400: Loss=0.003007 | TrainAcc=1.0000
# Fold 16 Epoch 1500: Loss=0.001646 | TrainAcc=1.0000
# Fold 16 Epoch 1600: Loss=0.005687 | TrainAcc=1.0000
# Fold 16 Epoch 1700: Loss=0.000975 | TrainAcc=1.0000
# Fold 16 Epoch 1800: Loss=0.001673 | TrainAcc=1.0000
# Fold 16 Epoch 1900: Loss=0.005992 | TrainAcc=1.0000
# Fold 16 Epoch 2000: Loss=0.001221 | TrainAcc=1.0000
# Fold 16 → Acc=0.7933 | Prec=0.8023 | Rec=0.8313 | F1=0.8166 | AUC=0.8683 | CE Loss=1.2989
#
# === Fold 17 ===
# Fold 17 Epoch 1: Loss=0.690140 | TrainAcc=0.5933
# Fold 17 Epoch 100: Loss=0.483407 | TrainAcc=0.7867
# Fold 17 Epoch 200: Loss=0.330644 | TrainAcc=0.8600
# Fold 17 Epoch 300: Loss=0.178140 | TrainAcc=0.9333
# Fold 17 Epoch 400: Loss=0.095047 | TrainAcc=0.9600
# Fold 17 Epoch 500: Loss=0.070231 | TrainAcc=0.9800
# Fold 17 Epoch 600: Loss=0.021916 | TrainAcc=0.9933
# Fold 17 Epoch 700: Loss=0.017686 | TrainAcc=1.0000
# Fold 17 Epoch 800: Loss=0.012498 | TrainAcc=1.0000
# Fold 17 Epoch 900: Loss=0.004671 | TrainAcc=1.0000
# Fold 17 Epoch 1000: Loss=0.004962 | TrainAcc=1.0000
# Fold 17 Epoch 1100: Loss=0.009124 | TrainAcc=1.0000
# Fold 17 Epoch 1200: Loss=0.003749 | TrainAcc=1.0000
# Fold 17 Epoch 1300: Loss=0.000988 | TrainAcc=1.0000
# Fold 17 Epoch 1400: Loss=0.002763 | TrainAcc=1.0000
# Fold 17 Epoch 1500: Loss=0.004401 | TrainAcc=1.0000
# Fold 17 Epoch 1600: Loss=0.001532 | TrainAcc=1.0000
# Fold 17 Epoch 1700: Loss=0.003352 | TrainAcc=1.0000
# Fold 17 Epoch 1800: Loss=0.000974 | TrainAcc=1.0000
# Fold 17 Epoch 1900: Loss=0.000986 | TrainAcc=1.0000
# Fold 17 Epoch 2000: Loss=0.000775 | TrainAcc=1.0000
# Fold 17 → Acc=0.7733 | Prec=0.8788 | Rec=0.6905 | F1=0.7733 | AUC=0.8589 | CE Loss=1.8839
#
# === Fold 18 ===
# Fold 18 Epoch 1: Loss=0.687978 | TrainAcc=0.5667
# Fold 18 Epoch 100: Loss=0.524932 | TrainAcc=0.7600
# Fold 18 Epoch 200: Loss=0.353033 | TrainAcc=0.8400
# Fold 18 Epoch 300: Loss=0.148905 | TrainAcc=0.9400
# Fold 18 Epoch 400: Loss=0.081741 | TrainAcc=0.9733
# Fold 18 Epoch 500: Loss=0.036015 | TrainAcc=1.0000
# Fold 18 Epoch 600: Loss=0.018799 | TrainAcc=1.0000
# Fold 18 Epoch 700: Loss=0.016318 | TrainAcc=1.0000
# Fold 18 Epoch 800: Loss=0.019263 | TrainAcc=0.9933
# Fold 18 Epoch 900: Loss=0.005362 | TrainAcc=1.0000
# Fold 18 Epoch 1000: Loss=0.006723 | TrainAcc=1.0000
# Fold 18 Epoch 1100: Loss=0.001371 | TrainAcc=1.0000
# Fold 18 Epoch 1200: Loss=0.002625 | TrainAcc=1.0000
# Fold 18 Epoch 1300: Loss=0.028161 | TrainAcc=0.9933
# Fold 18 Epoch 1400: Loss=0.006818 | TrainAcc=1.0000
# Fold 18 Epoch 1500: Loss=0.001824 | TrainAcc=1.0000
# Fold 18 Epoch 1600: Loss=0.002176 | TrainAcc=1.0000
# Fold 18 Epoch 1700: Loss=0.001419 | TrainAcc=1.0000
# Fold 18 Epoch 1800: Loss=0.001081 | TrainAcc=1.0000
# Fold 18 Epoch 1900: Loss=0.001660 | TrainAcc=1.0000
# Fold 18 Epoch 2000: Loss=0.003212 | TrainAcc=1.0000
# Fold 18 → Acc=0.7600 | Prec=0.7857 | Rec=0.7857 | F1=0.7857 | AUC=0.8080 | CE Loss=2.2954
#
# === Fold 19 ===
# Fold 19 Epoch 1: Loss=0.697874 | TrainAcc=0.4867
# Fold 19 Epoch 100: Loss=0.514350 | TrainAcc=0.7800
# Fold 19 Epoch 200: Loss=0.363361 | TrainAcc=0.8533
# Fold 19 Epoch 300: Loss=0.195803 | TrainAcc=0.9333
# Fold 19 Epoch 400: Loss=0.074046 | TrainAcc=0.9867
# Fold 19 Epoch 500: Loss=0.047028 | TrainAcc=0.9867
# Fold 19 Epoch 600: Loss=0.028182 | TrainAcc=0.9933
# Fold 19 Epoch 700: Loss=0.013811 | TrainAcc=1.0000
# Fold 19 Epoch 800: Loss=0.007550 | TrainAcc=1.0000
# Fold 19 Epoch 900: Loss=0.007841 | TrainAcc=0.9933
# Fold 19 Epoch 1000: Loss=0.002011 | TrainAcc=1.0000
# Fold 19 Epoch 1100: Loss=0.003031 | TrainAcc=1.0000
# Fold 19 Epoch 1200: Loss=0.001518 | TrainAcc=1.0000
# Fold 19 Epoch 1300: Loss=0.002606 | TrainAcc=1.0000
# Fold 19 Epoch 1400: Loss=0.001747 | TrainAcc=1.0000
# Fold 19 Epoch 1500: Loss=0.001739 | TrainAcc=1.0000
# Fold 19 Epoch 1600: Loss=0.002310 | TrainAcc=1.0000
# Fold 19 Epoch 1700: Loss=0.002184 | TrainAcc=1.0000
# Fold 19 Epoch 1800: Loss=0.000986 | TrainAcc=1.0000
# Fold 19 Epoch 1900: Loss=0.001313 | TrainAcc=1.0000
# Fold 19 Epoch 2000: Loss=0.000550 | TrainAcc=1.0000
# Fold 19 → Acc=0.7867 | Prec=0.7629 | Rec=0.8916 | F1=0.8222 | AUC=0.8463 | CE Loss=1.8425
#
# === Fold 20 ===
# Fold 20 Epoch 1: Loss=0.747520 | TrainAcc=0.3467
# Fold 20 Epoch 100: Loss=0.550476 | TrainAcc=0.7333
# Fold 20 Epoch 200: Loss=0.427399 | TrainAcc=0.7733
# Fold 20 Epoch 300: Loss=0.239876 | TrainAcc=0.9133
# Fold 20 Epoch 400: Loss=0.127784 | TrainAcc=0.9600
# Fold 20 Epoch 500: Loss=0.061352 | TrainAcc=0.9933
# Fold 20 Epoch 600: Loss=0.036818 | TrainAcc=0.9867
# Fold 20 Epoch 700: Loss=0.023840 | TrainAcc=0.9933
# Fold 20 Epoch 800: Loss=0.012549 | TrainAcc=1.0000
# Fold 20 Epoch 900: Loss=0.009941 | TrainAcc=1.0000
# Fold 20 Epoch 1000: Loss=0.005278 | TrainAcc=1.0000
# Fold 20 Epoch 1100: Loss=0.004396 | TrainAcc=1.0000
# Fold 20 Epoch 1200: Loss=0.003163 | TrainAcc=1.0000
# Fold 20 Epoch 1300: Loss=0.004992 | TrainAcc=1.0000
# Fold 20 Epoch 1400: Loss=0.002914 | TrainAcc=1.0000
# Fold 20 Epoch 1500: Loss=0.002106 | TrainAcc=1.0000
# Fold 20 Epoch 1600: Loss=0.002174 | TrainAcc=1.0000
# Fold 20 Epoch 1700: Loss=0.002357 | TrainAcc=1.0000
# Fold 20 Epoch 1800: Loss=0.000803 | TrainAcc=1.0000
# Fold 20 Epoch 1900: Loss=0.003296 | TrainAcc=1.0000
# Fold 20 Epoch 2000: Loss=0.004726 | TrainAcc=1.0000
# Fold 20 → Acc=0.7600 | Prec=0.7791 | Rec=0.7976 | F1=0.7882 | AUC=0.8422 | CE Loss=1.7539
#
# === Average Results Across 20 Folds ===
# Accuracy:  0.7770 ± 0.0230
# Precision: 0.7868 ± 0.0345
# Recall:    0.8263 ± 0.0512
# F1-score:  0.8043 ± 0.0224
# CE Loss:   1.5932 ± 0.3431
# AUC:       0.8495 ± 0.0239
