# %%
import torch
import torch.nn as nn
import torch.nn.functional as nnFn
import torch.optim as optim
import numpy as np
import random
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from torch_geometric.data import Data
from torch_geometric.nn import ARMAConv
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score,
    f1_score, roc_auc_score, log_loss
)

# %%
fa_feature_path = "/home/snu/Downloads/Histogram_CN_FA_20bin_updated.npy"
Histogram_feature_CN_FA_array = np.load(fa_feature_path, allow_pickle=True)

fa_feature_path = "/home/snu/Downloads/Histogram_MCI_FA_20bin_updated.npy"
Histogram_feature_MCI_FA_array = np.load(fa_feature_path, allow_pickle=True)

X = np.vstack([Histogram_feature_CN_FA_array, Histogram_feature_MCI_FA_array])
y = np.hstack([
    np.zeros(Histogram_feature_CN_FA_array.shape[0], dtype=np.int64),
    np.ones(Histogram_feature_MCI_FA_array.shape[0], dtype=np.int64)
])

num_nodes, num_feats = X.shape
print(f"Features: {X.shape}, Labels: {y.shape}")
# Out:
# Features: (300, 180), Labels: (300,)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch_geometric.nn import ARMAConv

class ARMA_Supervised(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim, activ="SELU"):
        super(ARMA_Supervised, self).__init__()
        self.conv1 = ARMAConv(input_dim, hidden_dim, num_stacks=1, num_layers=1)
        self.bn1 = nn.BatchNorm1d(hidden_dim)
        self.dropout = nn.Dropout(0.2)
        self.fc = nn.Linear(hidden_dim, output_dim)
        activations = {
            "SELU": F.selu,
            "SiLU": F.silu,
            "GELU": F.gelu,
            "RELU": F.relu,
            "ELU": F.elu
        }
        self.act = activations.get(activ, F.elu)

    def forward(self, data):
        x, edge_index = data.x, data.edge_index
        x = self.conv1(x, edge_index)
        x = self.bn1(x)
        x = self.act(x)
        x = self.dropout(x)
        logits = self.fc(x)
        return logits

# %%
def create_adj(F, alpha=1):
    F_norm = F / np.linalg.norm(F, axis=1, keepdims=True)
    W = np.dot(F_norm, F_norm.T)
    W = np.where(W >= alpha, 1, 0).astype(np.float32)
    W = W / W.max()
    return W

def load_data(adj, node_feats):
    node_feats = torch.from_numpy(node_feats).float()
    edge_index = torch.from_numpy(np.array(np.nonzero((adj > 0))))
    return Data(x=node_feats, edge_index=edge_index)

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
alpha = 0.92
feats_dim = num_feats
hidden_dim = 512
num_classes = 2
num_epochs = 2000
lr = 0.0001
weight_decay = 1e-4
batch_print_freq = 100

# %%
W = create_adj(X, alpha)
data = load_data(W, X).to(device)
A_tensor = torch.from_numpy(W).float().to(device)
print(data)
# Out:
# Data(x=[300, 180], edge_index=[2, 13604])

# %%
sss = StratifiedShuffleSplit(n_splits=20, test_size=0.1, random_state=42)

accuracies, precisions, recalls, f1_scores, aucs, ce_losses = [], [], [], [], [], []

for fold, (train_idx, test_idx) in enumerate(sss.split(X, y), start=1):
    print(f"\n=== Fold {fold} ===")

    train_idx_t = torch.from_numpy(train_idx).long().to(device)
    y_train_tensor = torch.from_numpy(y[train_idx]).long().to(device)

    model = ARMA_Supervised(feats_dim, hidden_dim, num_classes, "SELU").to(device)
    optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
    ce_loss = nn.CrossEntropyLoss()


    for epoch in range(1, num_epochs + 1):
        model.train()
        optimizer.zero_grad()

        logits = model(data)
        loss = ce_loss(logits[train_idx_t], y_train_tensor)
        loss.backward()
        optimizer.step()

        if epoch % batch_print_freq == 0 or epoch == 1:
            model.eval()
            with torch.no_grad():
                preds_train = logits[train_idx_t].argmax(dim=1)
                acc_train = accuracy_score(y_train_tensor.cpu(), preds_train.cpu())
            print(f"Fold {fold} Epoch {epoch}: "
                  f"Loss={loss.item():.6f} | TrainAcc={acc_train:.4f}")


    model.eval()
    with torch.no_grad():
        out = model(data)
        preds = out.argmax(dim=1).cpu().numpy()
        probs = torch.softmax(out, dim=1)[:, 1].cpu().numpy()  # Probability for class 1

    y_test = y[test_idx]
    y_pred_test = preds[test_idx]
    y_prob_test = probs[test_idx]


    acc = accuracy_score(y_test, y_pred_test)
    prec = precision_score(y_test, y_pred_test, zero_division=0)
    rec = recall_score(y_test, y_pred_test, zero_division=0)
    f1 = f1_score(y_test, y_pred_test, zero_division=0)
    auc = roc_auc_score(y_test, y_prob_test)
    ce = log_loss(y_test, y_prob_test)

    accuracies.append(acc)
    precisions.append(prec)
    recalls.append(rec)
    f1_scores.append(f1)
    aucs.append(auc)
    ce_losses.append(ce)

    print(f"Fold {fold} → "
          f"Acc={acc:.4f} | Prec={prec:.4f} | Rec={rec:.4f} | "
          f"F1={f1:.4f} | AUC={auc:.4f} | CE Loss={ce:.4f}")


print("\n=== Average Results Across 20 Folds ===")
print(f"Accuracy:  {np.mean(accuracies):.4f} ± {np.std(accuracies):.4f}")
print(f"Precision: {np.mean(precisions):.4f} ± {np.std(precisions):.4f}")
print(f"Recall:    {np.mean(recalls):.4f} ± {np.std(recalls):.4f}")
print(f"F1-score:  {np.mean(f1_scores):.4f} ± {np.std(f1_scores):.4f}")
print(f"CE Loss:   {np.mean(ce_losses):.4f} ± {np.std(ce_losses):.4f}")
print(f"AUC:       {np.mean(aucs):.4f} ± {np.std(aucs):.4f}")
# Out:
# === Fold 1 ===
# Fold 1 Epoch 1: Loss=0.683374 | TrainAcc=0.6000
# Fold 1 Epoch 100: Loss=0.192769 | TrainAcc=0.9556
# Fold 1 Epoch 200: Loss=0.076202 | TrainAcc=0.9889
# Fold 1 Epoch 300: Loss=0.032853 | TrainAcc=0.9963
# Fold 1 Epoch 400: Loss=0.014425 | TrainAcc=1.0000
# Fold 1 Epoch 500: Loss=0.007584 | TrainAcc=1.0000
# Fold 1 Epoch 600: Loss=0.005994 | TrainAcc=1.0000
# Fold 1 Epoch 700: Loss=0.003783 | TrainAcc=1.0000
# Fold 1 Epoch 800: Loss=0.002986 | TrainAcc=1.0000
# Fold 1 Epoch 900: Loss=0.001865 | TrainAcc=1.0000
# Fold 1 Epoch 1000: Loss=0.001771 | TrainAcc=1.0000
# Fold 1 Epoch 1100: Loss=0.001278 | TrainAcc=1.0000
# Fold 1 Epoch 1200: Loss=0.000934 | TrainAcc=1.0000
# Fold 1 Epoch 1300: Loss=0.000694 | TrainAcc=1.0000
# Fold 1 Epoch 1400: Loss=0.000746 | TrainAcc=1.0000
# Fold 1 Epoch 1500: Loss=0.000546 | TrainAcc=1.0000
# Fold 1 Epoch 1600: Loss=0.000477 | TrainAcc=1.0000
# Fold 1 Epoch 1700: Loss=0.000405 | TrainAcc=1.0000
# Fold 1 Epoch 1800: Loss=0.000434 | TrainAcc=1.0000
# Fold 1 Epoch 1900: Loss=0.000303 | TrainAcc=1.0000
# Fold 1 Epoch 2000: Loss=0.000289 | TrainAcc=1.0000
# Fold 1 → Acc=0.8333 | Prec=0.8333 | Rec=0.8824 | F1=0.8571 | AUC=0.8733 | CE Loss=0.9824
#
# === Fold 2 ===
# Fold 2 Epoch 1: Loss=0.714985 | TrainAcc=0.5926
# Fold 2 Epoch 100: Loss=0.181168 | TrainAcc=0.9556
# Fold 2 Epoch 200: Loss=0.073156 | TrainAcc=0.9852
# Fold 2 Epoch 300: Loss=0.031877 | TrainAcc=1.0000
# Fold 2 Epoch 400: Loss=0.017206 | TrainAcc=1.0000
# Fold 2 Epoch 500: Loss=0.008796 | TrainAcc=1.0000
# Fold 2 Epoch 600: Loss=0.005929 | TrainAcc=1.0000
# Fold 2 Epoch 700: Loss=0.004227 | TrainAcc=1.0000
# Fold 2 Epoch 800: Loss=0.002916 | TrainAcc=1.0000
# Fold 2 Epoch 900: Loss=0.002510 | TrainAcc=1.0000
# Fold 2 Epoch 1000: Loss=0.001602 | TrainAcc=1.0000
# Fold 2 Epoch 1100: Loss=0.001586 | TrainAcc=1.0000
# Fold 2 Epoch 1200: Loss=0.001030 | TrainAcc=1.0000
# Fold 2 Epoch 1300: Loss=0.000809 | TrainAcc=1.0000
# Fold 2 Epoch 1400: Loss=0.000919 | TrainAcc=1.0000
# Fold 2 Epoch 1500: Loss=0.001335 | TrainAcc=1.0000
# Fold 2 Epoch 1600: Loss=0.000458 | TrainAcc=1.0000
# Fold 2 Epoch 1700: Loss=0.000503 | TrainAcc=1.0000
# Fold 2 Epoch 1800: Loss=0.000471 | TrainAcc=1.0000
# Fold 2 Epoch 1900: Loss=0.000450 | TrainAcc=1.0000
# Fold 2 Epoch 2000: Loss=0.000416 | TrainAcc=1.0000
# Fold 2 → Acc=0.7333 | Prec=0.8000 | Rec=0.7059 | F1=0.7500 | AUC=0.7557 | CE Loss=1.3785
#
# === Fold 3 ===
# Fold 3 Epoch 1: Loss=0.708845 | TrainAcc=0.5852
# Fold 3 Epoch 100: Loss=0.209306 | TrainAcc=0.9296
# Fold 3 Epoch 200: Loss=0.083889 | TrainAcc=0.9889
# Fold 3 Epoch 300: Loss=0.041430 | TrainAcc=1.0000
# Fold 3 Epoch 400: Loss=0.017917 | TrainAcc=1.0000
# Fold 3 Epoch 500: Loss=0.010277 | TrainAcc=1.0000
# Fold 3 Epoch 600: Loss=0.007646 | TrainAcc=1.0000
# Fold 3 Epoch 700: Loss=0.004247 | TrainAcc=1.0000
# Fold 3 Epoch 800: Loss=0.002939 | TrainAcc=1.0000
# Fold 3 Epoch 900: Loss=0.002341 | TrainAcc=1.0000
# Fold 3 Epoch 1000: Loss=0.001596 | TrainAcc=1.0000
# Fold 3 Epoch 1100: Loss=0.001448 | TrainAcc=1.0000
# Fold 3 Epoch 1200: Loss=0.001074 | TrainAcc=1.0000
# Fold 3 Epoch 1300: Loss=0.000925 | TrainAcc=1.0000
# Fold 3 Epoch 1400: Loss=0.000781 | TrainAcc=1.0000
# Fold 3 Epoch 1500: Loss=0.000804 | TrainAcc=1.0000
# Fold 3 Epoch 1600: Loss=0.000549 | TrainAcc=1.0000
# Fold 3 Epoch 1700: Loss=0.000459 | TrainAcc=1.0000
# Fold 3 Epoch 1800: Loss=0.000538 | TrainAcc=1.0000
# Fold 3 Epoch 1900: Loss=0.000381 | TrainAcc=1.0000
# Fold 3 Epoch 2000: Loss=0.000341 | TrainAcc=1.0000
# Fold 3 → Acc=0.8667 | Prec=0.9333 | Rec=0.8235 | F1=0.8750 | AUC=0.9231 | CE Loss=0.5393
#
# === Fold 4 ===
# Fold 4 Epoch 1: Loss=0.654782 | TrainAcc=0.6519
# Fold 4 Epoch 100: Loss=0.187025 | TrainAcc=0.9704
# Fold 4 Epoch 200: Loss=0.079216 | TrainAcc=0.9889
# Fold 4 Epoch 300: Loss=0.034558 | TrainAcc=1.0000
# Fold 4 Epoch 400: Loss=0.016880 | TrainAcc=1.0000
# Fold 4 Epoch 500: Loss=0.010623 | TrainAcc=1.0000
# Fold 4 Epoch 600: Loss=0.006344 | TrainAcc=1.0000
# Fold 4 Epoch 700: Loss=0.004467 | TrainAcc=1.0000
# Fold 4 Epoch 800: Loss=0.003269 | TrainAcc=1.0000
# Fold 4 Epoch 900: Loss=0.002715 | TrainAcc=1.0000
# Fold 4 Epoch 1000: Loss=0.002054 | TrainAcc=1.0000
# Fold 4 Epoch 1100: Loss=0.001411 | TrainAcc=1.0000
# Fold 4 Epoch 1200: Loss=0.001237 | TrainAcc=1.0000
# Fold 4 Epoch 1300: Loss=0.001047 | TrainAcc=1.0000
# Fold 4 Epoch 1400: Loss=0.000849 | TrainAcc=1.0000
# Fold 4 Epoch 1500: Loss=0.000796 | TrainAcc=1.0000
# Fold 4 Epoch 1600: Loss=0.000686 | TrainAcc=1.0000
# Fold 4 Epoch 1700: Loss=0.000614 | TrainAcc=1.0000
# Fold 4 Epoch 1800: Loss=0.000441 | TrainAcc=1.0000
# Fold 4 Epoch 1900: Loss=0.000433 | TrainAcc=1.0000
# Fold 4 Epoch 2000: Loss=0.000384 | TrainAcc=1.0000
# Fold 4 → Acc=0.9000 | Prec=1.0000 | Rec=0.8235 | F1=0.9032 | AUC=0.9548 | CE Loss=0.5216
#
# === Fold 5 ===
# Fold 5 Epoch 1: Loss=0.787354 | TrainAcc=0.4852
# Fold 5 Epoch 100: Loss=0.193508 | TrainAcc=0.9407
# Fold 5 Epoch 200: Loss=0.089803 | TrainAcc=0.9741
# Fold 5 Epoch 300: Loss=0.040971 | TrainAcc=1.0000
# Fold 5 Epoch 400: Loss=0.019461 | TrainAcc=1.0000
# Fold 5 Epoch 500: Loss=0.011702 | TrainAcc=1.0000
# Fold 5 Epoch 600: Loss=0.007170 | TrainAcc=1.0000
# Fold 5 Epoch 700: Loss=0.004847 | TrainAcc=1.0000
# Fold 5 Epoch 800: Loss=0.003247 | TrainAcc=1.0000
# Fold 5 Epoch 900: Loss=0.002655 | TrainAcc=1.0000
# Fold 5 Epoch 1000: Loss=0.001851 | TrainAcc=1.0000
# Fold 5 Epoch 1100: Loss=0.001455 | TrainAcc=1.0000
# Fold 5 Epoch 1200: Loss=0.001368 | TrainAcc=1.0000
# Fold 5 Epoch 1300: Loss=0.001131 | TrainAcc=1.0000
# Fold 5 Epoch 1400: Loss=0.000950 | TrainAcc=1.0000
# Fold 5 Epoch 1500: Loss=0.000768 | TrainAcc=1.0000
# Fold 5 Epoch 1600: Loss=0.000725 | TrainAcc=1.0000
# Fold 5 Epoch 1700: Loss=0.000678 | TrainAcc=1.0000
# Fold 5 Epoch 1800: Loss=0.000482 | TrainAcc=1.0000
# Fold 5 Epoch 1900: Loss=0.000420 | TrainAcc=1.0000
# Fold 5 Epoch 2000: Loss=0.000440 | TrainAcc=1.0000
# Fold 5 → Acc=0.7667 | Prec=0.7778 | Rec=0.8235 | F1=0.8000 | AUC=0.8733 | CE Loss=0.8043
#
# === Fold 6 ===
# Fold 6 Epoch 1: Loss=0.767426 | TrainAcc=0.5000
# Fold 6 Epoch 100: Loss=0.220071 | TrainAcc=0.9259
# Fold 6 Epoch 200: Loss=0.088335 | TrainAcc=0.9889
# Fold 6 Epoch 300: Loss=0.034255 | TrainAcc=1.0000
# Fold 6 Epoch 400: Loss=0.016636 | TrainAcc=1.0000
# Fold 6 Epoch 500: Loss=0.009788 | TrainAcc=1.0000
# Fold 6 Epoch 600: Loss=0.006296 | TrainAcc=1.0000
# Fold 6 Epoch 700: Loss=0.005308 | TrainAcc=1.0000
# Fold 6 Epoch 800: Loss=0.003367 | TrainAcc=1.0000
# Fold 6 Epoch 900: Loss=0.002431 | TrainAcc=1.0000
# Fold 6 Epoch 1000: Loss=0.002104 | TrainAcc=1.0000
# Fold 6 Epoch 1100: Loss=0.001490 | TrainAcc=1.0000
# Fold 6 Epoch 1200: Loss=0.001388 | TrainAcc=1.0000
# Fold 6 Epoch 1300: Loss=0.001335 | TrainAcc=1.0000
# Fold 6 Epoch 1400: Loss=0.000968 | TrainAcc=1.0000
# Fold 6 Epoch 1500: Loss=0.000934 | TrainAcc=1.0000
# Fold 6 Epoch 1600: Loss=0.000742 | TrainAcc=1.0000
# Fold 6 Epoch 1700: Loss=0.000612 | TrainAcc=1.0000
# Fold 6 Epoch 1800: Loss=0.000522 | TrainAcc=1.0000
# Fold 6 Epoch 1900: Loss=0.000571 | TrainAcc=1.0000
# Fold 6 Epoch 2000: Loss=0.000517 | TrainAcc=1.0000
# Fold 6 → Acc=0.8667 | Prec=0.8824 | Rec=0.8824 | F1=0.8824 | AUC=0.9321 | CE Loss=0.4827
#
# === Fold 7 ===
# Fold 7 Epoch 1: Loss=0.697690 | TrainAcc=0.5630
# Fold 7 Epoch 100: Loss=0.202803 | TrainAcc=0.9370
# Fold 7 Epoch 200: Loss=0.088451 | TrainAcc=0.9889
# Fold 7 Epoch 300: Loss=0.034739 | TrainAcc=1.0000
# Fold 7 Epoch 400: Loss=0.019016 | TrainAcc=1.0000
# Fold 7 Epoch 500: Loss=0.010833 | TrainAcc=1.0000
# Fold 7 Epoch 600: Loss=0.006561 | TrainAcc=1.0000
# Fold 7 Epoch 700: Loss=0.004446 | TrainAcc=1.0000
# Fold 7 Epoch 800: Loss=0.003221 | TrainAcc=1.0000
# Fold 7 Epoch 900: Loss=0.002647 | TrainAcc=1.0000
# Fold 7 Epoch 1000: Loss=0.002208 | TrainAcc=1.0000
# Fold 7 Epoch 1100: Loss=0.001686 | TrainAcc=1.0000
# Fold 7 Epoch 1200: Loss=0.001550 | TrainAcc=1.0000
# Fold 7 Epoch 1300: Loss=0.001230 | TrainAcc=1.0000
# Fold 7 Epoch 1400: Loss=0.001128 | TrainAcc=1.0000
# Fold 7 Epoch 1500: Loss=0.001065 | TrainAcc=1.0000
# Fold 7 Epoch 1600: Loss=0.000805 | TrainAcc=1.0000
# Fold 7 Epoch 1700: Loss=0.000675 | TrainAcc=1.0000
# Fold 7 Epoch 1800: Loss=0.000530 | TrainAcc=1.0000
# Fold 7 Epoch 1900: Loss=0.000475 | TrainAcc=1.0000
# Fold 7 Epoch 2000: Loss=0.000652 | TrainAcc=1.0000
# Fold 7 → Acc=0.8000 | Prec=0.8235 | Rec=0.8235 | F1=0.8235 | AUC=0.9548 | CE Loss=0.4753
#
# === Fold 8 ===
# Fold 8 Epoch 1: Loss=0.786543 | TrainAcc=0.4074
# Fold 8 Epoch 100: Loss=0.200938 | TrainAcc=0.9407
# Fold 8 Epoch 200: Loss=0.093124 | TrainAcc=0.9852
# Fold 8 Epoch 300: Loss=0.035995 | TrainAcc=1.0000
# Fold 8 Epoch 400: Loss=0.017210 | TrainAcc=1.0000
# Fold 8 Epoch 500: Loss=0.010239 | TrainAcc=1.0000
# Fold 8 Epoch 600: Loss=0.005795 | TrainAcc=1.0000
# Fold 8 Epoch 700: Loss=0.004223 | TrainAcc=1.0000
# Fold 8 Epoch 800: Loss=0.003136 | TrainAcc=1.0000
# Fold 8 Epoch 900: Loss=0.002060 | TrainAcc=1.0000
# Fold 8 Epoch 1000: Loss=0.001599 | TrainAcc=1.0000
# Fold 8 Epoch 1100: Loss=0.001526 | TrainAcc=1.0000
# Fold 8 Epoch 1200: Loss=0.001237 | TrainAcc=1.0000
# Fold 8 Epoch 1300: Loss=0.000941 | TrainAcc=1.0000
# Fold 8 Epoch 1400: Loss=0.000890 | TrainAcc=1.0000
# Fold 8 Epoch 1500: Loss=0.000826 | TrainAcc=1.0000
# Fold 8 Epoch 1600: Loss=0.000714 | TrainAcc=1.0000
# Fold 8 Epoch 1700: Loss=0.000611 | TrainAcc=1.0000
# Fold 8 Epoch 1800: Loss=0.000472 | TrainAcc=1.0000
# Fold 8 Epoch 1900: Loss=0.000455 | TrainAcc=1.0000
# Fold 8 Epoch 2000: Loss=0.000455 | TrainAcc=1.0000
# Fold 8 → Acc=0.7333 | Prec=0.8000 | Rec=0.7059 | F1=0.7500 | AUC=0.7511 | CE Loss=1.4878
#
# === Fold 9 ===
# Fold 9 Epoch 1: Loss=0.842557 | TrainAcc=0.4185
# Fold 9 Epoch 100: Loss=0.211184 | TrainAcc=0.9444
# Fold 9 Epoch 200: Loss=0.095706 | TrainAcc=0.9889
# Fold 9 Epoch 300: Loss=0.046004 | TrainAcc=1.0000
# Fold 9 Epoch 400: Loss=0.022700 | TrainAcc=1.0000
# Fold 9 Epoch 500: Loss=0.011822 | TrainAcc=1.0000
# Fold 9 Epoch 600: Loss=0.008679 | TrainAcc=1.0000
# Fold 9 Epoch 700: Loss=0.005663 | TrainAcc=1.0000
# Fold 9 Epoch 800: Loss=0.003824 | TrainAcc=1.0000
# Fold 9 Epoch 900: Loss=0.003324 | TrainAcc=1.0000
# Fold 9 Epoch 1000: Loss=0.002138 | TrainAcc=1.0000
# Fold 9 Epoch 1100: Loss=0.001613 | TrainAcc=1.0000
# Fold 9 Epoch 1200: Loss=0.001369 | TrainAcc=1.0000
# Fold 9 Epoch 1300: Loss=0.001002 | TrainAcc=1.0000
# Fold 9 Epoch 1400: Loss=0.001038 | TrainAcc=1.0000
# Fold 9 Epoch 1500: Loss=0.000756 | TrainAcc=1.0000
# Fold 9 Epoch 1600: Loss=0.000644 | TrainAcc=1.0000
# Fold 9 Epoch 1700: Loss=0.000618 | TrainAcc=1.0000
# Fold 9 Epoch 1800: Loss=0.000484 | TrainAcc=1.0000
# Fold 9 Epoch 1900: Loss=0.000414 | TrainAcc=1.0000
# Fold 9 Epoch 2000: Loss=0.000323 | TrainAcc=1.0000
# Fold 9 → Acc=0.8333 | Prec=0.8750 | Rec=0.8235 | F1=0.8485 | AUC=0.8959 | CE Loss=0.8150
#
# === Fold 10 ===
# Fold 10 Epoch 1: Loss=0.693014 | TrainAcc=0.5630
# Fold 10 Epoch 100: Loss=0.192033 | TrainAcc=0.9593
# Fold 10 Epoch 200: Loss=0.076393 | TrainAcc=1.0000
# Fold 10 Epoch 300: Loss=0.031562 | TrainAcc=1.0000
# Fold 10 Epoch 400: Loss=0.015917 | TrainAcc=1.0000
# Fold 10 Epoch 500: Loss=0.008525 | TrainAcc=1.0000
# Fold 10 Epoch 600: Loss=0.006997 | TrainAcc=1.0000
# Fold 10 Epoch 700: Loss=0.004470 | TrainAcc=1.0000
# Fold 10 Epoch 800: Loss=0.002718 | TrainAcc=1.0000
# Fold 10 Epoch 900: Loss=0.002365 | TrainAcc=1.0000
# Fold 10 Epoch 1000: Loss=0.001525 | TrainAcc=1.0000
# Fold 10 Epoch 1100: Loss=0.001359 | TrainAcc=1.0000
# Fold 10 Epoch 1200: Loss=0.001005 | TrainAcc=1.0000
# Fold 10 Epoch 1300: Loss=0.000797 | TrainAcc=1.0000
# Fold 10 Epoch 1400: Loss=0.000748 | TrainAcc=1.0000
# Fold 10 Epoch 1500: Loss=0.000582 | TrainAcc=1.0000
# Fold 10 Epoch 1600: Loss=0.000563 | TrainAcc=1.0000
# Fold 10 Epoch 1700: Loss=0.000472 | TrainAcc=1.0000
# Fold 10 Epoch 1800: Loss=0.000424 | TrainAcc=1.0000
# Fold 10 Epoch 1900: Loss=0.000328 | TrainAcc=1.0000
# Fold 10 Epoch 2000: Loss=0.000296 | TrainAcc=1.0000
# Fold 10 → Acc=0.8000 | Prec=0.7895 | Rec=0.8824 | F1=0.8333 | AUC=0.8326 | CE Loss=1.0649
#
# === Fold 11 ===
# Fold 11 Epoch 1: Loss=0.845818 | TrainAcc=0.4185
# Fold 11 Epoch 100: Loss=0.200170 | TrainAcc=0.9370
# Fold 11 Epoch 200: Loss=0.094515 | TrainAcc=0.9926
# Fold 11 Epoch 300: Loss=0.038418 | TrainAcc=1.0000
# Fold 11 Epoch 400: Loss=0.019289 | TrainAcc=1.0000
# Fold 11 Epoch 500: Loss=0.012322 | TrainAcc=1.0000
# Fold 11 Epoch 600: Loss=0.007137 | TrainAcc=1.0000
# Fold 11 Epoch 700: Loss=0.004476 | TrainAcc=1.0000
# Fold 11 Epoch 800: Loss=0.003416 | TrainAcc=1.0000
# Fold 11 Epoch 900: Loss=0.002946 | TrainAcc=1.0000
# Fold 11 Epoch 1000: Loss=0.001958 | TrainAcc=1.0000
# Fold 11 Epoch 1100: Loss=0.001944 | TrainAcc=1.0000
# Fold 11 Epoch 1200: Loss=0.001201 | TrainAcc=1.0000
# Fold 11 Epoch 1300: Loss=0.001252 | TrainAcc=1.0000
# Fold 11 Epoch 1400: Loss=0.000836 | TrainAcc=1.0000
# Fold 11 Epoch 1500: Loss=0.000733 | TrainAcc=1.0000
# Fold 11 Epoch 1600: Loss=0.000771 | TrainAcc=1.0000
# Fold 11 Epoch 1700: Loss=0.000598 | TrainAcc=1.0000
# Fold 11 Epoch 1800: Loss=0.000491 | TrainAcc=1.0000
# Fold 11 Epoch 1900: Loss=0.000459 | TrainAcc=1.0000
# Fold 11 Epoch 2000: Loss=0.000425 | TrainAcc=1.0000
# Fold 11 → Acc=0.8000 | Prec=0.8667 | Rec=0.7647 | F1=0.8125 | AUC=0.9095 | CE Loss=0.6771
#
# === Fold 12 ===
# Fold 12 Epoch 1: Loss=0.733638 | TrainAcc=0.5370
# Fold 12 Epoch 100: Loss=0.194573 | TrainAcc=0.9556
# Fold 12 Epoch 200: Loss=0.077745 | TrainAcc=0.9963
# Fold 12 Epoch 300: Loss=0.032147 | TrainAcc=1.0000
# Fold 12 Epoch 400: Loss=0.017193 | TrainAcc=1.0000
# Fold 12 Epoch 500: Loss=0.010259 | TrainAcc=1.0000
# Fold 12 Epoch 600: Loss=0.006062 | TrainAcc=1.0000
# Fold 12 Epoch 700: Loss=0.004336 | TrainAcc=1.0000
# Fold 12 Epoch 800: Loss=0.002891 | TrainAcc=1.0000
# Fold 12 Epoch 900: Loss=0.002904 | TrainAcc=1.0000
# Fold 12 Epoch 1000: Loss=0.001927 | TrainAcc=1.0000
# Fold 12 Epoch 1100: Loss=0.001370 | TrainAcc=1.0000
# Fold 12 Epoch 1200: Loss=0.001109 | TrainAcc=1.0000
# Fold 12 Epoch 1300: Loss=0.000997 | TrainAcc=1.0000
# Fold 12 Epoch 1400: Loss=0.000844 | TrainAcc=1.0000
# Fold 12 Epoch 1500: Loss=0.000684 | TrainAcc=1.0000
# Fold 12 Epoch 1600: Loss=0.000637 | TrainAcc=1.0000
# Fold 12 Epoch 1700: Loss=0.000489 | TrainAcc=1.0000
# Fold 12 Epoch 1800: Loss=0.000474 | TrainAcc=1.0000
# Fold 12 Epoch 1900: Loss=0.000387 | TrainAcc=1.0000
# Fold 12 Epoch 2000: Loss=0.000412 | TrainAcc=1.0000
# Fold 12 → Acc=0.8333 | Prec=0.8000 | Rec=0.9412 | F1=0.8649 | AUC=0.8824 | CE Loss=0.6475
#
# === Fold 13 ===
# Fold 13 Epoch 1: Loss=0.804438 | TrainAcc=0.3815
# Fold 13 Epoch 100: Loss=0.230636 | TrainAcc=0.9296
# Fold 13 Epoch 200: Loss=0.096501 | TrainAcc=0.9889
# Fold 13 Epoch 300: Loss=0.045734 | TrainAcc=1.0000
# Fold 13 Epoch 400: Loss=0.021771 | TrainAcc=1.0000
# Fold 13 Epoch 500: Loss=0.013704 | TrainAcc=1.0000
# Fold 13 Epoch 600: Loss=0.007804 | TrainAcc=1.0000
# Fold 13 Epoch 700: Loss=0.006394 | TrainAcc=1.0000
# Fold 13 Epoch 800: Loss=0.004432 | TrainAcc=1.0000
# Fold 13 Epoch 900: Loss=0.002535 | TrainAcc=1.0000
# Fold 13 Epoch 1000: Loss=0.002744 | TrainAcc=1.0000
# Fold 13 Epoch 1100: Loss=0.001939 | TrainAcc=1.0000
# Fold 13 Epoch 1200: Loss=0.001978 | TrainAcc=1.0000
# Fold 13 Epoch 1300: Loss=0.001185 | TrainAcc=1.0000
# Fold 13 Epoch 1400: Loss=0.000973 | TrainAcc=1.0000
# Fold 13 Epoch 1500: Loss=0.000749 | TrainAcc=1.0000
# Fold 13 Epoch 1600: Loss=0.000796 | TrainAcc=1.0000
# Fold 13 Epoch 1700: Loss=0.000703 | TrainAcc=1.0000
# Fold 13 Epoch 1800: Loss=0.000483 | TrainAcc=1.0000
# Fold 13 Epoch 1900: Loss=0.000486 | TrainAcc=1.0000
# Fold 13 Epoch 2000: Loss=0.000449 | TrainAcc=1.0000
# Fold 13 → Acc=0.9000 | Prec=0.8889 | Rec=0.9412 | F1=0.9143 | AUC=0.9140 | CE Loss=0.6124
#
# === Fold 14 ===
# Fold 14 Epoch 1: Loss=0.672922 | TrainAcc=0.5963
# Fold 14 Epoch 100: Loss=0.183715 | TrainAcc=0.9481
# Fold 14 Epoch 200: Loss=0.074451 | TrainAcc=0.9963
# Fold 14 Epoch 300: Loss=0.030028 | TrainAcc=1.0000
# Fold 14 Epoch 400: Loss=0.014566 | TrainAcc=1.0000
# Fold 14 Epoch 500: Loss=0.007284 | TrainAcc=1.0000
# Fold 14 Epoch 600: Loss=0.004964 | TrainAcc=1.0000
# Fold 14 Epoch 700: Loss=0.003384 | TrainAcc=1.0000
# Fold 14 Epoch 800: Loss=0.002646 | TrainAcc=1.0000
# Fold 14 Epoch 900: Loss=0.001951 | TrainAcc=1.0000
# Fold 14 Epoch 1000: Loss=0.001795 | TrainAcc=1.0000
# Fold 14 Epoch 1100: Loss=0.001309 | TrainAcc=1.0000
# Fold 14 Epoch 1200: Loss=0.000928 | TrainAcc=1.0000
# Fold 14 Epoch 1300: Loss=0.000850 | TrainAcc=1.0000
# Fold 14 Epoch 1400: Loss=0.000844 | TrainAcc=1.0000
# Fold 14 Epoch 1500: Loss=0.000654 | TrainAcc=1.0000
# Fold 14 Epoch 1600: Loss=0.000458 | TrainAcc=1.0000
# Fold 14 Epoch 1700: Loss=0.000389 | TrainAcc=1.0000
# Fold 14 Epoch 1800: Loss=0.000348 | TrainAcc=1.0000
# Fold 14 Epoch 1900: Loss=0.000347 | TrainAcc=1.0000
# Fold 14 Epoch 2000: Loss=0.000264 | TrainAcc=1.0000
# Fold 14 → Acc=0.6333 | Prec=0.7143 | Rec=0.5882 | F1=0.6452 | AUC=0.6923 | CE Loss=1.8097
#
# === Fold 15 ===
# Fold 15 Epoch 1: Loss=0.850390 | TrainAcc=0.4963
# Fold 15 Epoch 100: Loss=0.194957 | TrainAcc=0.9407
# Fold 15 Epoch 200: Loss=0.078458 | TrainAcc=0.9889
# Fold 15 Epoch 300: Loss=0.032638 | TrainAcc=0.9963
# Fold 15 Epoch 400: Loss=0.017369 | TrainAcc=1.0000
# Fold 15 Epoch 500: Loss=0.009497 | TrainAcc=1.0000
# Fold 15 Epoch 600: Loss=0.005958 | TrainAcc=1.0000
# Fold 15 Epoch 700: Loss=0.004063 | TrainAcc=1.0000
# Fold 15 Epoch 800: Loss=0.002462 | TrainAcc=1.0000
# Fold 15 Epoch 900: Loss=0.002159 | TrainAcc=1.0000
# Fold 15 Epoch 1000: Loss=0.001482 | TrainAcc=1.0000
# Fold 15 Epoch 1100: Loss=0.001337 | TrainAcc=1.0000
# Fold 15 Epoch 1200: Loss=0.000924 | TrainAcc=1.0000
# Fold 15 Epoch 1300: Loss=0.000751 | TrainAcc=1.0000
# Fold 15 Epoch 1400: Loss=0.000626 | TrainAcc=1.0000
# Fold 15 Epoch 1500: Loss=0.000559 | TrainAcc=1.0000
# Fold 15 Epoch 1600: Loss=0.000409 | TrainAcc=1.0000
# Fold 15 Epoch 1700: Loss=0.000418 | TrainAcc=1.0000
# Fold 15 Epoch 1800: Loss=0.000371 | TrainAcc=1.0000
# Fold 15 Epoch 1900: Loss=0.000328 | TrainAcc=1.0000
# Fold 15 Epoch 2000: Loss=0.000303 | TrainAcc=1.0000
# Fold 15 → Acc=0.5667 | Prec=0.6250 | Rec=0.5882 | F1=0.6061 | AUC=0.6290 | CE Loss=2.7447
#
# === Fold 16 ===
# Fold 16 Epoch 1: Loss=0.682250 | TrainAcc=0.5815
# Fold 16 Epoch 100: Loss=0.171049 | TrainAcc=0.9519
# Fold 16 Epoch 200: Loss=0.068518 | TrainAcc=0.9963
# Fold 16 Epoch 300: Loss=0.032044 | TrainAcc=1.0000
# Fold 16 Epoch 400: Loss=0.014182 | TrainAcc=1.0000
# Fold 16 Epoch 500: Loss=0.008476 | TrainAcc=1.0000
# Fold 16 Epoch 600: Loss=0.005149 | TrainAcc=1.0000
# Fold 16 Epoch 700: Loss=0.004561 | TrainAcc=1.0000
# Fold 16 Epoch 800: Loss=0.003090 | TrainAcc=1.0000
# Fold 16 Epoch 900: Loss=0.002901 | TrainAcc=1.0000
# Fold 16 Epoch 1000: Loss=0.001924 | TrainAcc=1.0000
# Fold 16 Epoch 1100: Loss=0.001322 | TrainAcc=1.0000
# Fold 16 Epoch 1200: Loss=0.001103 | TrainAcc=1.0000
# Fold 16 Epoch 1300: Loss=0.000904 | TrainAcc=1.0000
# Fold 16 Epoch 1400: Loss=0.000758 | TrainAcc=1.0000
# Fold 16 Epoch 1500: Loss=0.000690 | TrainAcc=1.0000
# Fold 16 Epoch 1600: Loss=0.000618 | TrainAcc=1.0000
# Fold 16 Epoch 1700: Loss=0.000457 | TrainAcc=1.0000
# Fold 16 Epoch 1800: Loss=0.000398 | TrainAcc=1.0000
# Fold 16 Epoch 1900: Loss=0.000331 | TrainAcc=1.0000
# Fold 16 Epoch 2000: Loss=0.000306 | TrainAcc=1.0000
# Fold 16 → Acc=0.7000 | Prec=0.6818 | Rec=0.8824 | F1=0.7692 | AUC=0.8733 | CE Loss=1.1856
#
# === Fold 17 ===
# Fold 17 Epoch 1: Loss=0.742676 | TrainAcc=0.5000
# Fold 17 Epoch 100: Loss=0.166286 | TrainAcc=0.9630
# Fold 17 Epoch 200: Loss=0.071517 | TrainAcc=0.9926
# Fold 17 Epoch 300: Loss=0.030481 | TrainAcc=1.0000
# Fold 17 Epoch 400: Loss=0.015308 | TrainAcc=1.0000
# Fold 17 Epoch 500: Loss=0.009054 | TrainAcc=1.0000
# Fold 17 Epoch 600: Loss=0.005322 | TrainAcc=1.0000
# Fold 17 Epoch 700: Loss=0.003908 | TrainAcc=1.0000
# Fold 17 Epoch 800: Loss=0.002473 | TrainAcc=1.0000
# Fold 17 Epoch 900: Loss=0.001981 | TrainAcc=1.0000
# Fold 17 Epoch 1000: Loss=0.001589 | TrainAcc=1.0000
# Fold 17 Epoch 1100: Loss=0.001228 | TrainAcc=1.0000
# Fold 17 Epoch 1200: Loss=0.000878 | TrainAcc=1.0000
# Fold 17 Epoch 1300: Loss=0.000717 | TrainAcc=1.0000
# Fold 17 Epoch 1400: Loss=0.000539 | TrainAcc=1.0000
# Fold 17 Epoch 1500: Loss=0.000492 | TrainAcc=1.0000
# Fold 17 Epoch 1600: Loss=0.000560 | TrainAcc=1.0000
# Fold 17 Epoch 1700: Loss=0.000400 | TrainAcc=1.0000
# Fold 17 Epoch 1800: Loss=0.000386 | TrainAcc=1.0000
# Fold 17 Epoch 1900: Loss=0.000277 | TrainAcc=1.0000
# Fold 17 Epoch 2000: Loss=0.000280 | TrainAcc=1.0000
# Fold 17 → Acc=0.7667 | Prec=0.7273 | Rec=0.9412 | F1=0.8205 | AUC=0.7873 | CE Loss=1.7157
#
# === Fold 18 ===
# Fold 18 Epoch 1: Loss=0.669972 | TrainAcc=0.6296
# Fold 18 Epoch 100: Loss=0.206053 | TrainAcc=0.9259
# Fold 18 Epoch 200: Loss=0.084303 | TrainAcc=0.9889
# Fold 18 Epoch 300: Loss=0.039562 | TrainAcc=1.0000
# Fold 18 Epoch 400: Loss=0.017908 | TrainAcc=1.0000
# Fold 18 Epoch 500: Loss=0.010528 | TrainAcc=1.0000
# Fold 18 Epoch 600: Loss=0.006958 | TrainAcc=1.0000
# Fold 18 Epoch 700: Loss=0.005707 | TrainAcc=1.0000
# Fold 18 Epoch 800: Loss=0.003381 | TrainAcc=1.0000
# Fold 18 Epoch 900: Loss=0.002973 | TrainAcc=1.0000
# Fold 18 Epoch 1000: Loss=0.002276 | TrainAcc=1.0000
# Fold 18 Epoch 1100: Loss=0.001588 | TrainAcc=1.0000
# Fold 18 Epoch 1200: Loss=0.001466 | TrainAcc=1.0000
# Fold 18 Epoch 1300: Loss=0.001251 | TrainAcc=1.0000
# Fold 18 Epoch 1400: Loss=0.001128 | TrainAcc=1.0000
# Fold 18 Epoch 1500: Loss=0.001006 | TrainAcc=1.0000
# Fold 18 Epoch 1600: Loss=0.000836 | TrainAcc=1.0000
# Fold 18 Epoch 1700: Loss=0.000680 | TrainAcc=1.0000
# Fold 18 Epoch 1800: Loss=0.000746 | TrainAcc=1.0000
# Fold 18 Epoch 1900: Loss=0.000592 | TrainAcc=1.0000
# Fold 18 Epoch 2000: Loss=0.000471 | TrainAcc=1.0000
# Fold 18 → Acc=0.9000 | Prec=0.8889 | Rec=0.9412 | F1=0.9143 | AUC=0.9412 | CE Loss=0.3872
#
# === Fold 19 ===
# Fold 19 Epoch 1: Loss=0.750498 | TrainAcc=0.4889
# Fold 19 Epoch 100: Loss=0.219175 | TrainAcc=0.9407
# Fold 19 Epoch 200: Loss=0.097775 | TrainAcc=0.9852
# Fold 19 Epoch 300: Loss=0.041195 | TrainAcc=1.0000
# Fold 19 Epoch 400: Loss=0.018814 | TrainAcc=1.0000
# Fold 19 Epoch 500: Loss=0.011810 | TrainAcc=1.0000
# Fold 19 Epoch 600: Loss=0.006500 | TrainAcc=1.0000
# Fold 19 Epoch 700: Loss=0.004588 | TrainAcc=1.0000
# Fold 19 Epoch 800: Loss=0.003618 | TrainAcc=1.0000
# Fold 19 Epoch 900: Loss=0.002510 | TrainAcc=1.0000
# Fold 19 Epoch 1000: Loss=0.001965 | TrainAcc=1.0000
# Fold 19 Epoch 1100: Loss=0.002370 | TrainAcc=1.0000
# Fold 19 Epoch 1200: Loss=0.001147 | TrainAcc=1.0000
# Fold 19 Epoch 1300: Loss=0.001220 | TrainAcc=1.0000
# Fold 19 Epoch 1400: Loss=0.000988 | TrainAcc=1.0000
# Fold 19 Epoch 1500: Loss=0.000807 | TrainAcc=1.0000
# Fold 19 Epoch 1600: Loss=0.000709 | TrainAcc=1.0000
# Fold 19 Epoch 1700: Loss=0.000639 | TrainAcc=1.0000
# Fold 19 Epoch 1800: Loss=0.000552 | TrainAcc=1.0000
# Fold 19 Epoch 1900: Loss=0.000524 | TrainAcc=1.0000
# Fold 19 Epoch 2000: Loss=0.000410 | TrainAcc=1.0000
# Fold 19 → Acc=0.8000 | Prec=0.8667 | Rec=0.7647 | F1=0.8125 | AUC=0.9231 | CE Loss=0.6828
#
# === Fold 20 ===
# Fold 20 Epoch 1: Loss=0.730756 | TrainAcc=0.5222
# Fold 20 Epoch 100: Loss=0.184675 | TrainAcc=0.9444
# Fold 20 Epoch 200: Loss=0.077553 | TrainAcc=0.9889
# Fold 20 Epoch 300: Loss=0.031883 | TrainAcc=1.0000
# Fold 20 Epoch 400: Loss=0.015954 | TrainAcc=1.0000
# Fold 20 Epoch 500: Loss=0.009196 | TrainAcc=1.0000
# Fold 20 Epoch 600: Loss=0.006186 | TrainAcc=1.0000
# Fold 20 Epoch 700: Loss=0.004746 | TrainAcc=1.0000
# Fold 20 Epoch 800: Loss=0.003450 | TrainAcc=1.0000
# Fold 20 Epoch 900: Loss=0.002475 | TrainAcc=1.0000
# Fold 20 Epoch 1000: Loss=0.001993 | TrainAcc=1.0000
# Fold 20 Epoch 1100: Loss=0.001474 | TrainAcc=1.0000
# Fold 20 Epoch 1200: Loss=0.001225 | TrainAcc=1.0000
# Fold 20 Epoch 1300: Loss=0.001043 | TrainAcc=1.0000
# Fold 20 Epoch 1400: Loss=0.001085 | TrainAcc=1.0000
# Fold 20 Epoch 1500: Loss=0.000849 | TrainAcc=1.0000
# Fold 20 Epoch 1600: Loss=0.000699 | TrainAcc=1.0000
# Fold 20 Epoch 1700: Loss=0.000659 | TrainAcc=1.0000
# Fold 20 Epoch 1800: Loss=0.000589 | TrainAcc=1.0000
# Fold 20 Epoch 1900: Loss=0.000590 | TrainAcc=1.0000
# Fold 20 Epoch 2000: Loss=0.000482 | TrainAcc=1.0000
# Fold 20 → Acc=0.8333 | Prec=0.8000 | Rec=0.9412 | F1=0.8649 | AUC=0.8597 | CE Loss=0.9966
#
# === Average Results Across 20 Folds ===
# Accuracy:  0.7933 ± 0.0854
# Precision: 0.8187 ± 0.0858
# Recall:    0.8235 ± 0.1069
# F1-score:  0.8174 ± 0.0797
# CE Loss:   1.0006 ± 0.5720
# AUC:       0.8579 ± 0.0882
