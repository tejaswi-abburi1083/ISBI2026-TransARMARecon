# %%
import os
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as nnFn
import torch.optim as optim
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, log_loss
from torch_geometric.data import Data
from torch_geometric.nn import GCNConv

device = 'cuda' if torch.cuda.is_available() else 'cpu'
print("Device:", device)

cn_path = "/home/snu/Downloads/Histogram_CN_FA_20bin_updated.npy"
mci_path = "/home/snu/Downloads/Histogram_MCI_FA_20bin_updated.npy"

Histogram_feature_CN_FA_array = np.load(cn_path, allow_pickle=True)
Histogram_feature_MCI_FA_array = np.load(mci_path, allow_pickle=True)

X = np.vstack([Histogram_feature_CN_FA_array, Histogram_feature_MCI_FA_array])
y = np.hstack([
    np.zeros(Histogram_feature_CN_FA_array.shape[0], dtype=np.int64),
    np.ones(Histogram_feature_MCI_FA_array.shape[0], dtype=np.int64)
])

num_nodes, num_feats = X.shape
print(f"Features: {X.shape}, Labels: {y.shape}")

rng = np.random.RandomState(42)
perm = rng.permutation(num_nodes)
X = X[perm]
y = y[perm]

def create_adj(F_data, alpha=1):
    norms = np.linalg.norm(F_data, axis=1, keepdims=True)
    norms[norms == 0] = 1.0
    F_norm = F_data / norms
    W = np.dot(F_norm, F_norm.T)
    W = np.where(W >= alpha, 1.0, 0.0).astype(np.float32)
    if W.max() > 0:
        W = W / W.max()
    return W

alpha = 0.92
W = create_adj(X, alpha=alpha)
np.fill_diagonal(W, 1.0)

def load_data(adj, node_feats):
    node_feats = torch.from_numpy(node_feats).float()
    rows, cols = np.nonzero(adj > 0)
    edge_index = torch.from_numpy(np.vstack([rows, cols]).astype(np.int64))
    return Data(x=node_feats, edge_index=edge_index)

data = load_data(W, X).to(device)
print(data)

class GCN_AE(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim, device, activ="RELU", dropout=0.25):
        super(GCN_AE, self).__init__()
        self.device = device

        self.conv1 = GCNConv(input_dim, hidden_dim)
        self.bn1 = nn.BatchNorm1d(hidden_dim)
        self.dropout = nn.Dropout(dropout)
        self.fc = nn.Linear(hidden_dim, output_dim)

        self.decoder = nn.Sequential(
            nn.Linear(hidden_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, input_dim)
        )

        activations = {
            "SELU": nnFn.selu,
            "SiLU": nnFn.silu,
            "GELU": nnFn.gelu,
            "RELU": nnFn.relu,
            "ELU": nnFn.elu
        }
        self.act = activations.get(activ, nnFn.relu)

    def forward(self, x, edge_index):
        h = self.conv1(x, edge_index)
        h = self.bn1(h)
        h = self.act(h)
        h = self.dropout(h)

        logits = self.fc(h)

        # Reconstruction
        recon = self.decoder(h)

        return logits, recon, h


feats_dim = num_feats
hidden_dim = 512
num_classes = 2
num_epochs = 2000
lr = 1e-4
weight_decay = 1e-4
batch_print_freq = 100
lambda_recon = 8

sss = StratifiedShuffleSplit(n_splits=20, test_size=0.1, random_state=42)
accuracies, precisions, recalls, f1_scores, aucs, ce_losses = [], [], [], [], [], []
y_all = y.copy()

for fold, (train_val_idx, test_idx_global) in enumerate(sss.split(X, y_all), start=1):
    print(f"\n=== Fold {fold} ===")
    cn_idx = np.where(y_all == 0)[0]
    mci_idx = np.where(y_all == 1)[0]
    sss_class = StratifiedShuffleSplit(n_splits=20, test_size=0.1, random_state=fold)
    cn_train_idx, _ = next(sss_class.split(X[cn_idx], y_all[cn_idx]))
    mci_train_idx, _ = next(sss_class.split(X[mci_idx], y_all[mci_idx]))
    cn_train = cn_idx[cn_train_idx]
    mci_train = mci_idx[mci_train_idx]
    train_idx_final = np.concatenate([cn_train, mci_train])
    np.random.shuffle(train_idx_final)

    print(f"Train CN: {len(cn_train)}, Train MCI: {len(mci_train)}")
    train_idx_t = torch.from_numpy(train_idx_final).long().to(device)
    y_train_tensor = torch.from_numpy(y_all[train_idx_final]).long().to(device)

    model = GCN_AE(feats_dim, hidden_dim, num_classes, device, activ="RELU", dropout=0.25).to(device)
    optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
    ce_loss_fn = nn.CrossEntropyLoss()
    recon_loss_fn = nn.MSELoss()
    data = load_data(W, X).to(device)

    for epoch in range(1, num_epochs + 1):
        model.train()
        optimizer.zero_grad()
        logits, recon_x, _ = model(data.x, data.edge_index)

        loss_sup = ce_loss_fn(logits[train_idx_t], y_train_tensor)
        loss_recon = recon_loss_fn(recon_x, data.x)
        total_loss = loss_sup + lambda_recon * loss_recon

        if torch.isnan(total_loss) or torch.isinf(total_loss):
            print(f"NaN/Inf detected at fold {fold} epoch {epoch}. Aborting epoch.")
            break

        total_loss.backward()
        optimizer.step()

        if epoch % batch_print_freq == 0 or epoch == 1:
            model.eval()
            with torch.no_grad():
                logits_eval, _, _ = model(data.x, data.edge_index)
                preds_train = logits_eval[train_idx_t].argmax(dim=1)
                acc_train = accuracy_score(y_train_tensor.cpu(), preds_train.cpu())
            print(f"Fold {fold} Epoch {epoch}: TotalLoss={total_loss.item():.6f} | Sup={loss_sup.item():.6f} | Recon={loss_recon.item():.6f} | TrainAcc={acc_train:.4f}")

    model.eval()
    with torch.no_grad():
        out_logits, _, _ = model(data.x, data.edge_index)
        preds = out_logits.argmax(dim=1).cpu().numpy()
        probs = nnFn.softmax(out_logits, dim=1)[:, 1].cpu().numpy()

    y_test = y_all[test_idx_global]
    y_pred_test = preds[test_idx_global]
    y_prob_test = probs[test_idx_global]

    acc = accuracy_score(y_test, y_pred_test)
    prec = precision_score(y_test, y_pred_test, zero_division=0)
    rec = recall_score(y_test, y_pred_test, zero_division=0)
    f1 = f1_score(y_test, y_pred_test, zero_division=0)
    try:
        auc = roc_auc_score(y_test, y_prob_test)
    except ValueError:
        auc = float('nan')
    ce = log_loss(y_test, y_prob_test)

    accuracies.append(acc)
    precisions.append(prec)
    recalls.append(rec)
    f1_scores.append(f1)
    aucs.append(auc)
    ce_losses.append(ce)

    print(f"Fold {fold} → Acc={acc:.4f} | Prec={prec:.4f} | Rec={rec:.4f} | F1={f1:.4f} | AUC={auc:.4f} | CE Loss={ce:.4f}")

print("\n=== Average Results Across 20 Folds ===")
print(f"Accuracy:  {np.mean(accuracies):.4f} ± {np.std(accuracies):.4f}")
print(f"Precision: {np.mean(precisions):.4f} ± {np.std(precisions):.4f}")
print(f"Recall:    {np.mean(recalls):.4f} ± {np.std(recalls):.4f}")
print(f"F1-score:  {np.mean(f1_scores):.4f} ± {np.std(f1_scores):.4f}")
print(f"AUC:       {np.nanmean(aucs):.4f} ± {np.nanstd(aucs):.4f}")
print(f"CE Loss:   {np.mean(ce_losses):.4f} ± {np.std(ce_losses):.4f}")
# Out:
# Device: cuda
# Features: (300, 180), Labels: (300,)
# Data(x=[300, 180], edge_index=[2, 13604])
#
# === Fold 1 ===
# Train CN: 119, Train MCI: 150
# Fold 1 Epoch 1: TotalLoss=1.035523 | Sup=0.719258 | Recon=0.039533 | TrainAcc=0.5539
# Fold 1 Epoch 100: TotalLoss=0.377959 | Sup=0.358403 | Recon=0.002445 | TrainAcc=0.8662
# Fold 1 Epoch 200: TotalLoss=0.310105 | Sup=0.300932 | Recon=0.001147 | TrainAcc=0.8885
# Fold 1 Epoch 300: TotalLoss=0.266816 | Sup=0.260782 | Recon=0.000754 | TrainAcc=0.8959
# Fold 1 Epoch 400: TotalLoss=0.227903 | Sup=0.223099 | Recon=0.000600 | TrainAcc=0.9033
# Fold 1 Epoch 500: TotalLoss=0.210604 | Sup=0.206315 | Recon=0.000536 | TrainAcc=0.9331
# Fold 1 Epoch 600: TotalLoss=0.179582 | Sup=0.175909 | Recon=0.000459 | TrainAcc=0.9368
# Fold 1 Epoch 700: TotalLoss=0.162872 | Sup=0.159670 | Recon=0.000400 | TrainAcc=0.9405
# Fold 1 Epoch 800: TotalLoss=0.142692 | Sup=0.139815 | Recon=0.000360 | TrainAcc=0.9368
# Fold 1 Epoch 900: TotalLoss=0.124391 | Sup=0.121764 | Recon=0.000328 | TrainAcc=0.9517
# Fold 1 Epoch 1000: TotalLoss=0.113283 | Sup=0.110782 | Recon=0.000313 | TrainAcc=0.9480
# Fold 1 Epoch 1100: TotalLoss=0.093152 | Sup=0.090759 | Recon=0.000299 | TrainAcc=0.9665
# Fold 1 Epoch 1200: TotalLoss=0.089434 | Sup=0.087159 | Recon=0.000284 | TrainAcc=0.9814
# Fold 1 Epoch 1300: TotalLoss=0.078752 | Sup=0.076575 | Recon=0.000272 | TrainAcc=0.9814
# Fold 1 Epoch 1400: TotalLoss=0.071141 | Sup=0.069037 | Recon=0.000263 | TrainAcc=0.9888
# Fold 1 Epoch 1500: TotalLoss=0.063558 | Sup=0.061520 | Recon=0.000255 | TrainAcc=0.9888
# Fold 1 Epoch 1600: TotalLoss=0.058397 | Sup=0.056469 | Recon=0.000241 | TrainAcc=0.9740
# Fold 1 Epoch 1700: TotalLoss=0.047316 | Sup=0.045429 | Recon=0.000236 | TrainAcc=0.9926
# Fold 1 Epoch 1800: TotalLoss=0.044781 | Sup=0.042996 | Recon=0.000223 | TrainAcc=0.9926
# Fold 1 Epoch 1900: TotalLoss=0.046742 | Sup=0.044999 | Recon=0.000218 | TrainAcc=0.9888
# Fold 1 Epoch 2000: TotalLoss=0.038441 | Sup=0.036763 | Recon=0.000210 | TrainAcc=1.0000
# Fold 1 → Acc=0.9667 | Prec=0.9444 | Rec=1.0000 | F1=0.9714 | AUC=0.9864 | CE Loss=0.1368
#
# === Fold 2 ===
# Train CN: 119, Train MCI: 150
# Fold 2 Epoch 1: TotalLoss=1.131124 | Sup=0.832588 | Recon=0.037317 | TrainAcc=0.5613
# Fold 2 Epoch 100: TotalLoss=0.380341 | Sup=0.361302 | Recon=0.002380 | TrainAcc=0.8625
# Fold 2 Epoch 200: TotalLoss=0.310512 | Sup=0.300435 | Recon=0.001260 | TrainAcc=0.8848
# Fold 2 Epoch 300: TotalLoss=0.262602 | Sup=0.255985 | Recon=0.000827 | TrainAcc=0.8996
# Fold 2 Epoch 400: TotalLoss=0.239999 | Sup=0.234639 | Recon=0.000670 | TrainAcc=0.8959
# Fold 2 Epoch 500: TotalLoss=0.211336 | Sup=0.207084 | Recon=0.000531 | TrainAcc=0.9219
# Fold 2 Epoch 600: TotalLoss=0.184724 | Sup=0.181208 | Recon=0.000439 | TrainAcc=0.9294
# Fold 2 Epoch 700: TotalLoss=0.157929 | Sup=0.154625 | Recon=0.000413 | TrainAcc=0.9442
# Fold 2 Epoch 800: TotalLoss=0.136453 | Sup=0.133504 | Recon=0.000369 | TrainAcc=0.9294
# Fold 2 Epoch 900: TotalLoss=0.118483 | Sup=0.115659 | Recon=0.000353 | TrainAcc=0.9554
# Fold 2 Epoch 1000: TotalLoss=0.113163 | Sup=0.110483 | Recon=0.000335 | TrainAcc=0.9591
# Fold 2 Epoch 1100: TotalLoss=0.092806 | Sup=0.090291 | Recon=0.000314 | TrainAcc=0.9703
# Fold 2 Epoch 1200: TotalLoss=0.084345 | Sup=0.081974 | Recon=0.000296 | TrainAcc=0.9814
# Fold 2 Epoch 1300: TotalLoss=0.074221 | Sup=0.071960 | Recon=0.000283 | TrainAcc=0.9888
# Fold 2 Epoch 1400: TotalLoss=0.064713 | Sup=0.062511 | Recon=0.000275 | TrainAcc=0.9888
# Fold 2 Epoch 1500: TotalLoss=0.058790 | Sup=0.056640 | Recon=0.000269 | TrainAcc=0.9851
# Fold 2 Epoch 1600: TotalLoss=0.048685 | Sup=0.046642 | Recon=0.000255 | TrainAcc=0.9926
# Fold 2 Epoch 1700: TotalLoss=0.047357 | Sup=0.045429 | Recon=0.000241 | TrainAcc=0.9926
# Fold 2 Epoch 1800: TotalLoss=0.045617 | Sup=0.043738 | Recon=0.000235 | TrainAcc=0.9851
# Fold 2 Epoch 1900: TotalLoss=0.034458 | Sup=0.032619 | Recon=0.000230 | TrainAcc=0.9888
# Fold 2 Epoch 2000: TotalLoss=0.031501 | Sup=0.029732 | Recon=0.000221 | TrainAcc=1.0000
# Fold 2 → Acc=1.0000 | Prec=1.0000 | Rec=1.0000 | F1=1.0000 | AUC=1.0000 | CE Loss=0.0161
#
# === Fold 3 ===
# Train CN: 119, Train MCI: 150
# Fold 3 Epoch 1: TotalLoss=0.964107 | Sup=0.648214 | Recon=0.039487 | TrainAcc=0.4610
# Fold 3 Epoch 100: TotalLoss=0.357769 | Sup=0.338351 | Recon=0.002427 | TrainAcc=0.8587
# Fold 3 Epoch 200: TotalLoss=0.300874 | Sup=0.291516 | Recon=0.001170 | TrainAcc=0.8773
# Fold 3 Epoch 300: TotalLoss=0.254074 | Sup=0.248181 | Recon=0.000737 | TrainAcc=0.8996
# Fold 3 Epoch 400: TotalLoss=0.232664 | Sup=0.227727 | Recon=0.000617 | TrainAcc=0.9108
# Fold 3 Epoch 500: TotalLoss=0.189119 | Sup=0.185039 | Recon=0.000510 | TrainAcc=0.9219
# Fold 3 Epoch 600: TotalLoss=0.172607 | Sup=0.169014 | Recon=0.000449 | TrainAcc=0.9405
# Fold 3 Epoch 700: TotalLoss=0.138585 | Sup=0.135456 | Recon=0.000391 | TrainAcc=0.9517
# Fold 3 Epoch 800: TotalLoss=0.118941 | Sup=0.116137 | Recon=0.000351 | TrainAcc=0.9665
# Fold 3 Epoch 900: TotalLoss=0.100823 | Sup=0.098161 | Recon=0.000333 | TrainAcc=0.9703
# Fold 3 Epoch 1000: TotalLoss=0.093784 | Sup=0.091351 | Recon=0.000304 | TrainAcc=0.9703
# Fold 3 Epoch 1100: TotalLoss=0.082967 | Sup=0.080680 | Recon=0.000286 | TrainAcc=0.9703
# Fold 3 Epoch 1200: TotalLoss=0.068426 | Sup=0.066224 | Recon=0.000275 | TrainAcc=0.9888
# Fold 3 Epoch 1300: TotalLoss=0.060149 | Sup=0.057999 | Recon=0.000269 | TrainAcc=0.9777
# Fold 3 Epoch 1400: TotalLoss=0.061522 | Sup=0.059495 | Recon=0.000253 | TrainAcc=0.9926
# Fold 3 Epoch 1500: TotalLoss=0.048688 | Sup=0.046736 | Recon=0.000244 | TrainAcc=0.9963
# Fold 3 Epoch 1600: TotalLoss=0.044152 | Sup=0.042265 | Recon=0.000236 | TrainAcc=0.9963
# Fold 3 Epoch 1700: TotalLoss=0.037809 | Sup=0.036007 | Recon=0.000225 | TrainAcc=1.0000
# Fold 3 Epoch 1800: TotalLoss=0.035667 | Sup=0.033939 | Recon=0.000216 | TrainAcc=1.0000
# Fold 3 Epoch 1900: TotalLoss=0.032069 | Sup=0.030400 | Recon=0.000209 | TrainAcc=0.9963
# Fold 3 Epoch 2000: TotalLoss=0.025853 | Sup=0.024222 | Recon=0.000204 | TrainAcc=1.0000
# Fold 3 → Acc=0.9000 | Prec=0.9375 | Rec=0.8824 | F1=0.9091 | AUC=0.9774 | CE Loss=0.2032
#
# === Fold 4 ===
# Train CN: 119, Train MCI: 150
# Fold 4 Epoch 1: TotalLoss=0.996435 | Sup=0.696962 | Recon=0.037434 | TrainAcc=0.5576
# Fold 4 Epoch 100: TotalLoss=0.362390 | Sup=0.344639 | Recon=0.002219 | TrainAcc=0.8662
# Fold 4 Epoch 200: TotalLoss=0.294697 | Sup=0.287108 | Recon=0.000949 | TrainAcc=0.8848
# Fold 4 Epoch 300: TotalLoss=0.246942 | Sup=0.241580 | Recon=0.000670 | TrainAcc=0.9033
# Fold 4 Epoch 400: TotalLoss=0.217806 | Sup=0.213328 | Recon=0.000560 | TrainAcc=0.9108
# Fold 4 Epoch 500: TotalLoss=0.187184 | Sup=0.183298 | Recon=0.000486 | TrainAcc=0.9219
# Fold 4 Epoch 600: TotalLoss=0.156031 | Sup=0.152472 | Recon=0.000445 | TrainAcc=0.9294
# Fold 4 Epoch 700: TotalLoss=0.139013 | Sup=0.135820 | Recon=0.000399 | TrainAcc=0.9480
# Fold 4 Epoch 800: TotalLoss=0.119585 | Sup=0.116533 | Recon=0.000382 | TrainAcc=0.9703
# Fold 4 Epoch 900: TotalLoss=0.106580 | Sup=0.103813 | Recon=0.000346 | TrainAcc=0.9628
# Fold 4 Epoch 1000: TotalLoss=0.096163 | Sup=0.093533 | Recon=0.000329 | TrainAcc=0.9665
# Fold 4 Epoch 1100: TotalLoss=0.083138 | Sup=0.080664 | Recon=0.000309 | TrainAcc=0.9703
# Fold 4 Epoch 1200: TotalLoss=0.076727 | Sup=0.074371 | Recon=0.000295 | TrainAcc=0.9740
# Fold 4 Epoch 1300: TotalLoss=0.068001 | Sup=0.065683 | Recon=0.000290 | TrainAcc=0.9814
# Fold 4 Epoch 1400: TotalLoss=0.062275 | Sup=0.060021 | Recon=0.000282 | TrainAcc=0.9888
# Fold 4 Epoch 1500: TotalLoss=0.053272 | Sup=0.051138 | Recon=0.000267 | TrainAcc=0.9888
# Fold 4 Epoch 1600: TotalLoss=0.047611 | Sup=0.045604 | Recon=0.000251 | TrainAcc=0.9926
# Fold 4 Epoch 1700: TotalLoss=0.039133 | Sup=0.037145 | Recon=0.000249 | TrainAcc=0.9926
# Fold 4 Epoch 1800: TotalLoss=0.040310 | Sup=0.038410 | Recon=0.000237 | TrainAcc=0.9926
# Fold 4 Epoch 1900: TotalLoss=0.035591 | Sup=0.033785 | Recon=0.000226 | TrainAcc=0.9963
# Fold 4 Epoch 2000: TotalLoss=0.030515 | Sup=0.028744 | Recon=0.000221 | TrainAcc=1.0000
# Fold 4 → Acc=1.0000 | Prec=1.0000 | Rec=1.0000 | F1=1.0000 | AUC=1.0000 | CE Loss=0.0561
#
# === Fold 5 ===
# Train CN: 119, Train MCI: 150
# Fold 5 Epoch 1: TotalLoss=1.147690 | Sup=0.834185 | Recon=0.039188 | TrainAcc=0.5576
# Fold 5 Epoch 100: TotalLoss=0.370653 | Sup=0.351551 | Recon=0.002388 | TrainAcc=0.8773
# Fold 5 Epoch 200: TotalLoss=0.307894 | Sup=0.299143 | Recon=0.001094 | TrainAcc=0.8885
# Fold 5 Epoch 300: TotalLoss=0.267009 | Sup=0.261035 | Recon=0.000747 | TrainAcc=0.8996
# Fold 5 Epoch 400: TotalLoss=0.232138 | Sup=0.227358 | Recon=0.000597 | TrainAcc=0.9182
# Fold 5 Epoch 500: TotalLoss=0.195556 | Sup=0.191489 | Recon=0.000508 | TrainAcc=0.9257
# Fold 5 Epoch 600: TotalLoss=0.176718 | Sup=0.173020 | Recon=0.000462 | TrainAcc=0.9331
# Fold 5 Epoch 700: TotalLoss=0.163480 | Sup=0.160198 | Recon=0.000410 | TrainAcc=0.9368
# Fold 5 Epoch 800: TotalLoss=0.133851 | Sup=0.130925 | Recon=0.000366 | TrainAcc=0.9405
# Fold 5 Epoch 900: TotalLoss=0.121270 | Sup=0.118660 | Recon=0.000326 | TrainAcc=0.9591
# Fold 5 Epoch 1000: TotalLoss=0.104086 | Sup=0.101662 | Recon=0.000303 | TrainAcc=0.9517
# Fold 5 Epoch 1100: TotalLoss=0.093653 | Sup=0.091367 | Recon=0.000286 | TrainAcc=0.9703
# Fold 5 Epoch 1200: TotalLoss=0.079924 | Sup=0.077733 | Recon=0.000274 | TrainAcc=0.9814
# Fold 5 Epoch 1300: TotalLoss=0.069611 | Sup=0.067503 | Recon=0.000264 | TrainAcc=0.9963
# Fold 5 Epoch 1400: TotalLoss=0.070466 | Sup=0.068455 | Recon=0.000251 | TrainAcc=0.9926
# Fold 5 Epoch 1500: TotalLoss=0.053987 | Sup=0.051973 | Recon=0.000252 | TrainAcc=0.9926
# Fold 5 Epoch 1600: TotalLoss=0.048572 | Sup=0.046648 | Recon=0.000241 | TrainAcc=0.9926
# Fold 5 Epoch 1700: TotalLoss=0.045405 | Sup=0.043556 | Recon=0.000231 | TrainAcc=0.9963
# Fold 5 Epoch 1800: TotalLoss=0.040829 | Sup=0.039025 | Recon=0.000225 | TrainAcc=0.9963
# Fold 5 Epoch 1900: TotalLoss=0.034138 | Sup=0.032387 | Recon=0.000219 | TrainAcc=0.9963
# Fold 5 Epoch 2000: TotalLoss=0.035764 | Sup=0.034068 | Recon=0.000212 | TrainAcc=0.9963
# Fold 5 → Acc=0.9333 | Prec=0.8947 | Rec=1.0000 | F1=0.9444 | AUC=1.0000 | CE Loss=0.0865
#
# === Fold 6 ===
# Train CN: 119, Train MCI: 150
# Fold 6 Epoch 1: TotalLoss=1.072756 | Sup=0.784343 | Recon=0.036052 | TrainAcc=0.4424
# Fold 6 Epoch 100: TotalLoss=0.395560 | Sup=0.377410 | Recon=0.002269 | TrainAcc=0.8550
# Fold 6 Epoch 200: TotalLoss=0.325918 | Sup=0.317073 | Recon=0.001106 | TrainAcc=0.8773
# Fold 6 Epoch 300: TotalLoss=0.278717 | Sup=0.272827 | Recon=0.000736 | TrainAcc=0.8885
# Fold 6 Epoch 400: TotalLoss=0.249918 | Sup=0.245175 | Recon=0.000593 | TrainAcc=0.9033
# Fold 6 Epoch 500: TotalLoss=0.220479 | Sup=0.216451 | Recon=0.000503 | TrainAcc=0.9145
# Fold 6 Epoch 600: TotalLoss=0.186308 | Sup=0.182922 | Recon=0.000423 | TrainAcc=0.9219
# Fold 6 Epoch 700: TotalLoss=0.167125 | Sup=0.164060 | Recon=0.000383 | TrainAcc=0.9257
# Fold 6 Epoch 800: TotalLoss=0.147283 | Sup=0.144465 | Recon=0.000352 | TrainAcc=0.9405
# Fold 6 Epoch 900: TotalLoss=0.136623 | Sup=0.133959 | Recon=0.000333 | TrainAcc=0.9294
# Fold 6 Epoch 1000: TotalLoss=0.116886 | Sup=0.114301 | Recon=0.000323 | TrainAcc=0.9628
# Fold 6 Epoch 1100: TotalLoss=0.096980 | Sup=0.094572 | Recon=0.000301 | TrainAcc=0.9740
# Fold 6 Epoch 1200: TotalLoss=0.090660 | Sup=0.088292 | Recon=0.000296 | TrainAcc=0.9851
# Fold 6 Epoch 1300: TotalLoss=0.075954 | Sup=0.073663 | Recon=0.000286 | TrainAcc=0.9926
# Fold 6 Epoch 1400: TotalLoss=0.062704 | Sup=0.060466 | Recon=0.000280 | TrainAcc=0.9926
# Fold 6 Epoch 1500: TotalLoss=0.060126 | Sup=0.058031 | Recon=0.000262 | TrainAcc=0.9777
# Fold 6 Epoch 1600: TotalLoss=0.054448 | Sup=0.052420 | Recon=0.000254 | TrainAcc=1.0000
# Fold 6 Epoch 1700: TotalLoss=0.046600 | Sup=0.044659 | Recon=0.000243 | TrainAcc=0.9963
# Fold 6 Epoch 1800: TotalLoss=0.040393 | Sup=0.038487 | Recon=0.000238 | TrainAcc=1.0000
# Fold 6 Epoch 1900: TotalLoss=0.038954 | Sup=0.037124 | Recon=0.000229 | TrainAcc=0.9963
# Fold 6 Epoch 2000: TotalLoss=0.033101 | Sup=0.031322 | Recon=0.000222 | TrainAcc=1.0000
# Fold 6 → Acc=0.9667 | Prec=0.9444 | Rec=1.0000 | F1=0.9714 | AUC=1.0000 | CE Loss=0.0701
#
# === Fold 7 ===
# Train CN: 119, Train MCI: 150
# Fold 7 Epoch 1: TotalLoss=0.954757 | Sup=0.641641 | Recon=0.039139 | TrainAcc=0.5576
# Fold 7 Epoch 100: TotalLoss=0.353047 | Sup=0.333029 | Recon=0.002502 | TrainAcc=0.8625
# Fold 7 Epoch 200: TotalLoss=0.293562 | Sup=0.284632 | Recon=0.001116 | TrainAcc=0.8773
# Fold 7 Epoch 300: TotalLoss=0.247680 | Sup=0.241629 | Recon=0.000756 | TrainAcc=0.9108
# Fold 7 Epoch 400: TotalLoss=0.213330 | Sup=0.208146 | Recon=0.000648 | TrainAcc=0.9145
# Fold 7 Epoch 500: TotalLoss=0.180695 | Sup=0.176590 | Recon=0.000513 | TrainAcc=0.9257
# Fold 7 Epoch 600: TotalLoss=0.161491 | Sup=0.158122 | Recon=0.000421 | TrainAcc=0.9219
# Fold 7 Epoch 700: TotalLoss=0.135464 | Sup=0.132336 | Recon=0.000391 | TrainAcc=0.9480
# Fold 7 Epoch 800: TotalLoss=0.119888 | Sup=0.116943 | Recon=0.000368 | TrainAcc=0.9665
# Fold 7 Epoch 900: TotalLoss=0.113779 | Sup=0.110990 | Recon=0.000349 | TrainAcc=0.9628
# Fold 7 Epoch 1000: TotalLoss=0.097507 | Sup=0.094901 | Recon=0.000326 | TrainAcc=0.9740
# Fold 7 Epoch 1100: TotalLoss=0.090342 | Sup=0.087923 | Recon=0.000302 | TrainAcc=0.9665
# Fold 7 Epoch 1200: TotalLoss=0.067303 | Sup=0.064988 | Recon=0.000289 | TrainAcc=0.9851
# Fold 7 Epoch 1300: TotalLoss=0.062713 | Sup=0.060493 | Recon=0.000278 | TrainAcc=0.9851
# Fold 7 Epoch 1400: TotalLoss=0.053722 | Sup=0.051523 | Recon=0.000275 | TrainAcc=0.9888
# Fold 7 Epoch 1500: TotalLoss=0.057830 | Sup=0.055731 | Recon=0.000262 | TrainAcc=0.9926
# Fold 7 Epoch 1600: TotalLoss=0.045295 | Sup=0.043281 | Recon=0.000252 | TrainAcc=0.9926
# Fold 7 Epoch 1700: TotalLoss=0.037809 | Sup=0.035876 | Recon=0.000242 | TrainAcc=0.9963
# Fold 7 Epoch 1800: TotalLoss=0.036586 | Sup=0.034680 | Recon=0.000238 | TrainAcc=0.9926
# Fold 7 Epoch 1900: TotalLoss=0.033595 | Sup=0.031772 | Recon=0.000228 | TrainAcc=0.9963
# Fold 7 Epoch 2000: TotalLoss=0.030369 | Sup=0.028596 | Recon=0.000222 | TrainAcc=1.0000
# Fold 7 → Acc=1.0000 | Prec=1.0000 | Rec=1.0000 | F1=1.0000 | AUC=1.0000 | CE Loss=0.0217
#
# === Fold 8 ===
# Train CN: 119, Train MCI: 150
# Fold 8 Epoch 1: TotalLoss=0.991932 | Sup=0.700010 | Recon=0.036490 | TrainAcc=0.4424
# Fold 8 Epoch 100: TotalLoss=0.360629 | Sup=0.341838 | Recon=0.002349 | TrainAcc=0.8587
# Fold 8 Epoch 200: TotalLoss=0.286454 | Sup=0.277873 | Recon=0.001073 | TrainAcc=0.8773
# Fold 8 Epoch 300: TotalLoss=0.247014 | Sup=0.241174 | Recon=0.000730 | TrainAcc=0.8959
# Fold 8 Epoch 400: TotalLoss=0.213524 | Sup=0.208791 | Recon=0.000592 | TrainAcc=0.9145
# Fold 8 Epoch 500: TotalLoss=0.181428 | Sup=0.177151 | Recon=0.000535 | TrainAcc=0.9294
# Fold 8 Epoch 600: TotalLoss=0.163235 | Sup=0.159410 | Recon=0.000478 | TrainAcc=0.9368
# Fold 8 Epoch 700: TotalLoss=0.130257 | Sup=0.126795 | Recon=0.000433 | TrainAcc=0.9442
# Fold 8 Epoch 800: TotalLoss=0.115375 | Sup=0.112300 | Recon=0.000384 | TrainAcc=0.9628
# Fold 8 Epoch 900: TotalLoss=0.109255 | Sup=0.106493 | Recon=0.000345 | TrainAcc=0.9517
# Fold 8 Epoch 1000: TotalLoss=0.091184 | Sup=0.088628 | Recon=0.000319 | TrainAcc=0.9814
# Fold 8 Epoch 1100: TotalLoss=0.084217 | Sup=0.081731 | Recon=0.000311 | TrainAcc=0.9591
# Fold 8 Epoch 1200: TotalLoss=0.066520 | Sup=0.064114 | Recon=0.000301 | TrainAcc=0.9628
# Fold 8 Epoch 1300: TotalLoss=0.062339 | Sup=0.060030 | Recon=0.000289 | TrainAcc=0.9963
# Fold 8 Epoch 1400: TotalLoss=0.048800 | Sup=0.046633 | Recon=0.000271 | TrainAcc=0.9888
# Fold 8 Epoch 1500: TotalLoss=0.047209 | Sup=0.045082 | Recon=0.000266 | TrainAcc=0.9926
# Fold 8 Epoch 1600: TotalLoss=0.042368 | Sup=0.040325 | Recon=0.000255 | TrainAcc=1.0000
# Fold 8 Epoch 1700: TotalLoss=0.038354 | Sup=0.036386 | Recon=0.000246 | TrainAcc=1.0000
# Fold 8 Epoch 1800: TotalLoss=0.033674 | Sup=0.031779 | Recon=0.000237 | TrainAcc=1.0000
# Fold 8 Epoch 1900: TotalLoss=0.030713 | Sup=0.028864 | Recon=0.000231 | TrainAcc=1.0000
# Fold 8 Epoch 2000: TotalLoss=0.025349 | Sup=0.023587 | Recon=0.000220 | TrainAcc=1.0000
# Fold 8 → Acc=0.9667 | Prec=0.9444 | Rec=1.0000 | F1=0.9714 | AUC=1.0000 | CE Loss=0.0646
#
# === Fold 9 ===
# Train CN: 119, Train MCI: 150
# Fold 9 Epoch 1: TotalLoss=1.137678 | Sup=0.805999 | Recon=0.041460 | TrainAcc=0.1933
# Fold 9 Epoch 100: TotalLoss=0.376654 | Sup=0.356899 | Recon=0.002469 | TrainAcc=0.8513
# Fold 9 Epoch 200: TotalLoss=0.312351 | Sup=0.303525 | Recon=0.001103 | TrainAcc=0.8810
# Fold 9 Epoch 300: TotalLoss=0.265330 | Sup=0.259422 | Recon=0.000739 | TrainAcc=0.8996
# Fold 9 Epoch 400: TotalLoss=0.231008 | Sup=0.226052 | Recon=0.000620 | TrainAcc=0.9033
# Fold 9 Epoch 500: TotalLoss=0.208429 | Sup=0.203996 | Recon=0.000554 | TrainAcc=0.9033
# Fold 9 Epoch 600: TotalLoss=0.177414 | Sup=0.173426 | Recon=0.000498 | TrainAcc=0.9145
# Fold 9 Epoch 700: TotalLoss=0.157319 | Sup=0.153891 | Recon=0.000428 | TrainAcc=0.9294
# Fold 9 Epoch 800: TotalLoss=0.136908 | Sup=0.133797 | Recon=0.000389 | TrainAcc=0.9517
# Fold 9 Epoch 900: TotalLoss=0.118992 | Sup=0.116014 | Recon=0.000372 | TrainAcc=0.9628
# Fold 9 Epoch 1000: TotalLoss=0.107092 | Sup=0.104177 | Recon=0.000364 | TrainAcc=0.9628
# Fold 9 Epoch 1100: TotalLoss=0.093429 | Sup=0.090722 | Recon=0.000338 | TrainAcc=0.9814
# Fold 9 Epoch 1200: TotalLoss=0.081159 | Sup=0.078592 | Recon=0.000321 | TrainAcc=0.9851
# Fold 9 Epoch 1300: TotalLoss=0.071168 | Sup=0.068734 | Recon=0.000304 | TrainAcc=0.9851
# Fold 9 Epoch 1400: TotalLoss=0.060586 | Sup=0.058256 | Recon=0.000291 | TrainAcc=0.9963
# Fold 9 Epoch 1500: TotalLoss=0.050051 | Sup=0.047786 | Recon=0.000283 | TrainAcc=0.9888
# Fold 9 Epoch 1600: TotalLoss=0.052082 | Sup=0.049975 | Recon=0.000263 | TrainAcc=1.0000
# Fold 9 Epoch 1700: TotalLoss=0.044494 | Sup=0.042447 | Recon=0.000256 | TrainAcc=0.9963
# Fold 9 Epoch 1800: TotalLoss=0.041089 | Sup=0.039159 | Recon=0.000241 | TrainAcc=0.9963
# Fold 9 Epoch 1900: TotalLoss=0.038414 | Sup=0.036555 | Recon=0.000232 | TrainAcc=1.0000
# Fold 9 Epoch 2000: TotalLoss=0.031459 | Sup=0.029641 | Recon=0.000227 | TrainAcc=1.0000
# Fold 9 → Acc=0.9667 | Prec=1.0000 | Rec=0.9412 | F1=0.9697 | AUC=0.9638 | CE Loss=0.4541
#
# === Fold 10 ===
# Train CN: 119, Train MCI: 150
# Fold 10 Epoch 1: TotalLoss=0.984574 | Sup=0.692904 | Recon=0.036459 | TrainAcc=0.5576
# Fold 10 Epoch 100: TotalLoss=0.357045 | Sup=0.337837 | Recon=0.002401 | TrainAcc=0.8625
# Fold 10 Epoch 200: TotalLoss=0.289287 | Sup=0.280511 | Recon=0.001097 | TrainAcc=0.8810
# Fold 10 Epoch 300: TotalLoss=0.260324 | Sup=0.254447 | Recon=0.000735 | TrainAcc=0.8959
# Fold 10 Epoch 400: TotalLoss=0.219335 | Sup=0.214562 | Recon=0.000597 | TrainAcc=0.9145
# Fold 10 Epoch 500: TotalLoss=0.191670 | Sup=0.187637 | Recon=0.000504 | TrainAcc=0.9182
# Fold 10 Epoch 600: TotalLoss=0.159989 | Sup=0.156681 | Recon=0.000414 | TrainAcc=0.9294
# Fold 10 Epoch 700: TotalLoss=0.151529 | Sup=0.148532 | Recon=0.000375 | TrainAcc=0.9480
# Fold 10 Epoch 800: TotalLoss=0.131875 | Sup=0.129099 | Recon=0.000347 | TrainAcc=0.9517
# Fold 10 Epoch 900: TotalLoss=0.115644 | Sup=0.112939 | Recon=0.000338 | TrainAcc=0.9554
# Fold 10 Epoch 1000: TotalLoss=0.100005 | Sup=0.097546 | Recon=0.000307 | TrainAcc=0.9665
# Fold 10 Epoch 1100: TotalLoss=0.087027 | Sup=0.084643 | Recon=0.000298 | TrainAcc=0.9628
# Fold 10 Epoch 1200: TotalLoss=0.081907 | Sup=0.079666 | Recon=0.000280 | TrainAcc=0.9814
# Fold 10 Epoch 1300: TotalLoss=0.072951 | Sup=0.070796 | Recon=0.000269 | TrainAcc=0.9888
# Fold 10 Epoch 1400: TotalLoss=0.064004 | Sup=0.061889 | Recon=0.000264 | TrainAcc=0.9814
# Fold 10 Epoch 1500: TotalLoss=0.055968 | Sup=0.053918 | Recon=0.000256 | TrainAcc=0.9926
# Fold 10 Epoch 1600: TotalLoss=0.053852 | Sup=0.051867 | Recon=0.000248 | TrainAcc=0.9926
# Fold 10 Epoch 1700: TotalLoss=0.045560 | Sup=0.043642 | Recon=0.000240 | TrainAcc=0.9963
# Fold 10 Epoch 1800: TotalLoss=0.044291 | Sup=0.042419 | Recon=0.000234 | TrainAcc=0.9963
# Fold 10 Epoch 1900: TotalLoss=0.036368 | Sup=0.034589 | Recon=0.000222 | TrainAcc=0.9963
# Fold 10 Epoch 2000: TotalLoss=0.029524 | Sup=0.027787 | Recon=0.000217 | TrainAcc=0.9888
# Fold 10 → Acc=0.9667 | Prec=0.9444 | Rec=1.0000 | F1=0.9714 | AUC=0.9910 | CE Loss=0.1858
#
# === Fold 11 ===
# Train CN: 119, Train MCI: 150
# Fold 11 Epoch 1: TotalLoss=1.150453 | Sup=0.817969 | Recon=0.041560 | TrainAcc=0.5576
# Fold 11 Epoch 100: TotalLoss=0.352049 | Sup=0.331587 | Recon=0.002558 | TrainAcc=0.8625
# Fold 11 Epoch 200: TotalLoss=0.290568 | Sup=0.280589 | Recon=0.001247 | TrainAcc=0.8922
# Fold 11 Epoch 300: TotalLoss=0.244206 | Sup=0.237779 | Recon=0.000803 | TrainAcc=0.9033
# Fold 11 Epoch 400: TotalLoss=0.200760 | Sup=0.195786 | Recon=0.000622 | TrainAcc=0.9145
# Fold 11 Epoch 500: TotalLoss=0.178978 | Sup=0.174898 | Recon=0.000510 | TrainAcc=0.9368
# Fold 11 Epoch 600: TotalLoss=0.159300 | Sup=0.155900 | Recon=0.000425 | TrainAcc=0.9331
# Fold 11 Epoch 700: TotalLoss=0.149957 | Sup=0.146780 | Recon=0.000397 | TrainAcc=0.9480
# Fold 11 Epoch 800: TotalLoss=0.122533 | Sup=0.119492 | Recon=0.000380 | TrainAcc=0.9517
# Fold 11 Epoch 900: TotalLoss=0.112487 | Sup=0.109705 | Recon=0.000348 | TrainAcc=0.9628
# Fold 11 Epoch 1000: TotalLoss=0.098243 | Sup=0.095592 | Recon=0.000331 | TrainAcc=0.9740
# Fold 11 Epoch 1100: TotalLoss=0.082784 | Sup=0.080210 | Recon=0.000322 | TrainAcc=0.9628
# Fold 11 Epoch 1200: TotalLoss=0.073179 | Sup=0.070765 | Recon=0.000302 | TrainAcc=0.9851
# Fold 11 Epoch 1300: TotalLoss=0.067652 | Sup=0.065314 | Recon=0.000292 | TrainAcc=0.9851
# Fold 11 Epoch 1400: TotalLoss=0.055521 | Sup=0.053234 | Recon=0.000286 | TrainAcc=0.9963
# Fold 11 Epoch 1500: TotalLoss=0.049291 | Sup=0.047070 | Recon=0.000278 | TrainAcc=0.9888
# Fold 11 Epoch 1600: TotalLoss=0.045567 | Sup=0.043430 | Recon=0.000267 | TrainAcc=1.0000
# Fold 11 Epoch 1700: TotalLoss=0.040925 | Sup=0.038862 | Recon=0.000258 | TrainAcc=1.0000
# Fold 11 Epoch 1800: TotalLoss=0.040714 | Sup=0.038721 | Recon=0.000249 | TrainAcc=0.9926
# Fold 11 Epoch 1900: TotalLoss=0.028412 | Sup=0.026487 | Recon=0.000241 | TrainAcc=1.0000
# Fold 11 Epoch 2000: TotalLoss=0.026275 | Sup=0.024400 | Recon=0.000234 | TrainAcc=1.0000
# Fold 11 → Acc=0.9667 | Prec=0.9444 | Rec=1.0000 | F1=0.9714 | AUC=0.9955 | CE Loss=0.0939
#
# === Fold 12 ===
# Train CN: 119, Train MCI: 150
# Fold 12 Epoch 1: TotalLoss=1.086397 | Sup=0.776861 | Recon=0.038692 | TrainAcc=0.5725
# Fold 12 Epoch 100: TotalLoss=0.354771 | Sup=0.334717 | Recon=0.002507 | TrainAcc=0.8550
# Fold 12 Epoch 200: TotalLoss=0.298984 | Sup=0.290042 | Recon=0.001118 | TrainAcc=0.8885
# Fold 12 Epoch 300: TotalLoss=0.240558 | Sup=0.234297 | Recon=0.000783 | TrainAcc=0.9071
# Fold 12 Epoch 400: TotalLoss=0.210361 | Sup=0.205478 | Recon=0.000610 | TrainAcc=0.9182
# Fold 12 Epoch 500: TotalLoss=0.186820 | Sup=0.182563 | Recon=0.000532 | TrainAcc=0.9331
# Fold 12 Epoch 600: TotalLoss=0.160868 | Sup=0.157428 | Recon=0.000430 | TrainAcc=0.9294
# Fold 12 Epoch 700: TotalLoss=0.139641 | Sup=0.136544 | Recon=0.000387 | TrainAcc=0.9405
# Fold 12 Epoch 800: TotalLoss=0.128436 | Sup=0.125637 | Recon=0.000350 | TrainAcc=0.9480
# Fold 12 Epoch 900: TotalLoss=0.106955 | Sup=0.104341 | Recon=0.000327 | TrainAcc=0.9628
# Fold 12 Epoch 1000: TotalLoss=0.088884 | Sup=0.086376 | Recon=0.000314 | TrainAcc=0.9740
# Fold 12 Epoch 1100: TotalLoss=0.080591 | Sup=0.078231 | Recon=0.000295 | TrainAcc=0.9665
# Fold 12 Epoch 1200: TotalLoss=0.072138 | Sup=0.069854 | Recon=0.000285 | TrainAcc=0.9703
# Fold 12 Epoch 1300: TotalLoss=0.065779 | Sup=0.063618 | Recon=0.000270 | TrainAcc=0.9926
# Fold 12 Epoch 1400: TotalLoss=0.058635 | Sup=0.056571 | Recon=0.000258 | TrainAcc=0.9963
# Fold 12 Epoch 1500: TotalLoss=0.044649 | Sup=0.042631 | Recon=0.000252 | TrainAcc=0.9814
# Fold 12 Epoch 1600: TotalLoss=0.043734 | Sup=0.041764 | Recon=0.000246 | TrainAcc=0.9963
# Fold 12 Epoch 1700: TotalLoss=0.037245 | Sup=0.035320 | Recon=0.000241 | TrainAcc=0.9963
# Fold 12 Epoch 1800: TotalLoss=0.039811 | Sup=0.037961 | Recon=0.000231 | TrainAcc=0.9963
# Fold 12 Epoch 1900: TotalLoss=0.033770 | Sup=0.031985 | Recon=0.000223 | TrainAcc=1.0000
# Fold 12 Epoch 2000: TotalLoss=0.028943 | Sup=0.027216 | Recon=0.000216 | TrainAcc=1.0000
# Fold 12 → Acc=1.0000 | Prec=1.0000 | Rec=1.0000 | F1=1.0000 | AUC=1.0000 | CE Loss=0.0091
#
# === Fold 13 ===
# Train CN: 119, Train MCI: 150
# Fold 13 Epoch 1: TotalLoss=1.041623 | Sup=0.736233 | Recon=0.038174 | TrainAcc=0.5539
# Fold 13 Epoch 100: TotalLoss=0.360872 | Sup=0.342033 | Recon=0.002355 | TrainAcc=0.8699
# Fold 13 Epoch 200: TotalLoss=0.290669 | Sup=0.281451 | Recon=0.001152 | TrainAcc=0.8996
# Fold 13 Epoch 300: TotalLoss=0.257506 | Sup=0.251321 | Recon=0.000773 | TrainAcc=0.9071
# Fold 13 Epoch 400: TotalLoss=0.225875 | Sup=0.220937 | Recon=0.000617 | TrainAcc=0.9145
# Fold 13 Epoch 500: TotalLoss=0.195841 | Sup=0.191782 | Recon=0.000507 | TrainAcc=0.9257
# Fold 13 Epoch 600: TotalLoss=0.175180 | Sup=0.171733 | Recon=0.000431 | TrainAcc=0.9294
# Fold 13 Epoch 700: TotalLoss=0.153504 | Sup=0.150319 | Recon=0.000398 | TrainAcc=0.9219
# Fold 13 Epoch 800: TotalLoss=0.121183 | Sup=0.118250 | Recon=0.000367 | TrainAcc=0.9517
# Fold 13 Epoch 900: TotalLoss=0.118502 | Sup=0.115905 | Recon=0.000325 | TrainAcc=0.9517
# Fold 13 Epoch 1000: TotalLoss=0.105482 | Sup=0.102921 | Recon=0.000320 | TrainAcc=0.9591
# Fold 13 Epoch 1100: TotalLoss=0.097762 | Sup=0.095342 | Recon=0.000302 | TrainAcc=0.9703
# Fold 13 Epoch 1200: TotalLoss=0.079093 | Sup=0.076754 | Recon=0.000292 | TrainAcc=0.9703
# Fold 13 Epoch 1300: TotalLoss=0.080908 | Sup=0.078698 | Recon=0.000276 | TrainAcc=0.9814
# Fold 13 Epoch 1400: TotalLoss=0.065151 | Sup=0.063018 | Recon=0.000267 | TrainAcc=0.9628
# Fold 13 Epoch 1500: TotalLoss=0.060358 | Sup=0.058289 | Recon=0.000259 | TrainAcc=0.9888
# Fold 13 Epoch 1600: TotalLoss=0.053312 | Sup=0.051306 | Recon=0.000251 | TrainAcc=0.9926
# Fold 13 Epoch 1700: TotalLoss=0.046838 | Sup=0.044913 | Recon=0.000241 | TrainAcc=0.9926
# Fold 13 Epoch 1800: TotalLoss=0.049316 | Sup=0.047451 | Recon=0.000233 | TrainAcc=0.9926
# Fold 13 Epoch 1900: TotalLoss=0.039209 | Sup=0.037364 | Recon=0.000231 | TrainAcc=0.9926
# Fold 13 Epoch 2000: TotalLoss=0.034446 | Sup=0.032692 | Recon=0.000219 | TrainAcc=0.9963
# Fold 13 → Acc=0.9667 | Prec=1.0000 | Rec=0.9412 | F1=0.9697 | AUC=0.9638 | CE Loss=0.3765
#
# === Fold 14 ===
# Train CN: 119, Train MCI: 150
# Fold 14 Epoch 1: TotalLoss=1.103822 | Sup=0.754233 | Recon=0.043699 | TrainAcc=0.5576
# Fold 14 Epoch 100: TotalLoss=0.333636 | Sup=0.314689 | Recon=0.002368 | TrainAcc=0.8699
# Fold 14 Epoch 200: TotalLoss=0.276662 | Sup=0.267922 | Recon=0.001092 | TrainAcc=0.8959
# Fold 14 Epoch 300: TotalLoss=0.245634 | Sup=0.239665 | Recon=0.000746 | TrainAcc=0.9108
# Fold 14 Epoch 400: TotalLoss=0.223200 | Sup=0.218463 | Recon=0.000592 | TrainAcc=0.9331
# Fold 14 Epoch 500: TotalLoss=0.182849 | Sup=0.178727 | Recon=0.000515 | TrainAcc=0.9405
# Fold 14 Epoch 600: TotalLoss=0.156401 | Sup=0.152918 | Recon=0.000435 | TrainAcc=0.9442
# Fold 14 Epoch 700: TotalLoss=0.137353 | Sup=0.134218 | Recon=0.000392 | TrainAcc=0.9517
# Fold 14 Epoch 800: TotalLoss=0.112275 | Sup=0.109350 | Recon=0.000366 | TrainAcc=0.9703
# Fold 14 Epoch 900: TotalLoss=0.101593 | Sup=0.098835 | Recon=0.000345 | TrainAcc=0.9740
# Fold 14 Epoch 1000: TotalLoss=0.086784 | Sup=0.084167 | Recon=0.000327 | TrainAcc=0.9740
# Fold 14 Epoch 1100: TotalLoss=0.076886 | Sup=0.074344 | Recon=0.000318 | TrainAcc=0.9740
# Fold 14 Epoch 1200: TotalLoss=0.066628 | Sup=0.064258 | Recon=0.000296 | TrainAcc=0.9851
# Fold 14 Epoch 1300: TotalLoss=0.058700 | Sup=0.056441 | Recon=0.000282 | TrainAcc=0.9814
# Fold 14 Epoch 1400: TotalLoss=0.048249 | Sup=0.046042 | Recon=0.000276 | TrainAcc=0.9888
# Fold 14 Epoch 1500: TotalLoss=0.043195 | Sup=0.041068 | Recon=0.000266 | TrainAcc=0.9851
# Fold 14 Epoch 1600: TotalLoss=0.042679 | Sup=0.040647 | Recon=0.000254 | TrainAcc=0.9963
# Fold 14 Epoch 1700: TotalLoss=0.033804 | Sup=0.031847 | Recon=0.000245 | TrainAcc=1.0000
# Fold 14 Epoch 1800: TotalLoss=0.034410 | Sup=0.032496 | Recon=0.000239 | TrainAcc=0.9851
# Fold 14 Epoch 1900: TotalLoss=0.027354 | Sup=0.025495 | Recon=0.000232 | TrainAcc=1.0000
# Fold 14 Epoch 2000: TotalLoss=0.025415 | Sup=0.023594 | Recon=0.000228 | TrainAcc=1.0000
# Fold 14 → Acc=0.9667 | Prec=0.9444 | Rec=1.0000 | F1=0.9714 | AUC=0.9955 | CE Loss=0.0628
#
# === Fold 15 ===
# Train CN: 119, Train MCI: 150
# Fold 15 Epoch 1: TotalLoss=1.184365 | Sup=0.855185 | Recon=0.041148 | TrainAcc=0.4424
# Fold 15 Epoch 100: TotalLoss=0.361575 | Sup=0.341275 | Recon=0.002538 | TrainAcc=0.8550
# Fold 15 Epoch 200: TotalLoss=0.308430 | Sup=0.298996 | Recon=0.001179 | TrainAcc=0.8625
# Fold 15 Epoch 300: TotalLoss=0.272197 | Sup=0.265641 | Recon=0.000819 | TrainAcc=0.8996
# Fold 15 Epoch 400: TotalLoss=0.240984 | Sup=0.235991 | Recon=0.000624 | TrainAcc=0.9033
# Fold 15 Epoch 500: TotalLoss=0.206788 | Sup=0.202640 | Recon=0.000519 | TrainAcc=0.9182
# Fold 15 Epoch 600: TotalLoss=0.182774 | Sup=0.179159 | Recon=0.000452 | TrainAcc=0.9257
# Fold 15 Epoch 700: TotalLoss=0.169424 | Sup=0.166080 | Recon=0.000418 | TrainAcc=0.9368
# Fold 15 Epoch 800: TotalLoss=0.144143 | Sup=0.141074 | Recon=0.000384 | TrainAcc=0.9480
# Fold 15 Epoch 900: TotalLoss=0.123037 | Sup=0.120134 | Recon=0.000363 | TrainAcc=0.9517
# Fold 15 Epoch 1000: TotalLoss=0.106149 | Sup=0.103489 | Recon=0.000332 | TrainAcc=0.9665
# Fold 15 Epoch 1100: TotalLoss=0.103321 | Sup=0.100840 | Recon=0.000310 | TrainAcc=0.9740
# Fold 15 Epoch 1200: TotalLoss=0.089308 | Sup=0.086986 | Recon=0.000290 | TrainAcc=0.9740
# Fold 15 Epoch 1300: TotalLoss=0.081249 | Sup=0.079009 | Recon=0.000280 | TrainAcc=0.9777
# Fold 15 Epoch 1400: TotalLoss=0.077170 | Sup=0.075005 | Recon=0.000271 | TrainAcc=0.9851
# Fold 15 Epoch 1500: TotalLoss=0.061092 | Sup=0.058995 | Recon=0.000262 | TrainAcc=0.9926
# Fold 15 Epoch 1600: TotalLoss=0.055887 | Sup=0.053862 | Recon=0.000253 | TrainAcc=0.9963
# Fold 15 Epoch 1700: TotalLoss=0.050552 | Sup=0.048568 | Recon=0.000248 | TrainAcc=0.9926
# Fold 15 Epoch 1800: TotalLoss=0.041711 | Sup=0.039802 | Recon=0.000239 | TrainAcc=1.0000
# Fold 15 Epoch 1900: TotalLoss=0.040715 | Sup=0.038892 | Recon=0.000228 | TrainAcc=1.0000
# Fold 15 Epoch 2000: TotalLoss=0.035229 | Sup=0.033440 | Recon=0.000224 | TrainAcc=1.0000
# Fold 15 → Acc=1.0000 | Prec=1.0000 | Rec=1.0000 | F1=1.0000 | AUC=1.0000 | CE Loss=0.0431
#
# === Fold 16 ===
# Train CN: 119, Train MCI: 150
# Fold 16 Epoch 1: TotalLoss=1.101383 | Sup=0.770324 | Recon=0.041382 | TrainAcc=0.5502
# Fold 16 Epoch 100: TotalLoss=0.367103 | Sup=0.348372 | Recon=0.002341 | TrainAcc=0.8587
# Fold 16 Epoch 200: TotalLoss=0.289979 | Sup=0.280985 | Recon=0.001124 | TrainAcc=0.8885
# Fold 16 Epoch 300: TotalLoss=0.252603 | Sup=0.246973 | Recon=0.000704 | TrainAcc=0.8959
# Fold 16 Epoch 400: TotalLoss=0.211765 | Sup=0.207360 | Recon=0.000551 | TrainAcc=0.9219
# Fold 16 Epoch 500: TotalLoss=0.184539 | Sup=0.180660 | Recon=0.000485 | TrainAcc=0.9294
# Fold 16 Epoch 600: TotalLoss=0.163338 | Sup=0.159866 | Recon=0.000434 | TrainAcc=0.9480
# Fold 16 Epoch 700: TotalLoss=0.124490 | Sup=0.121349 | Recon=0.000393 | TrainAcc=0.9517
# Fold 16 Epoch 800: TotalLoss=0.110345 | Sup=0.107380 | Recon=0.000371 | TrainAcc=0.9665
# Fold 16 Epoch 900: TotalLoss=0.096115 | Sup=0.093343 | Recon=0.000347 | TrainAcc=0.9703
# Fold 16 Epoch 1000: TotalLoss=0.087760 | Sup=0.085200 | Recon=0.000320 | TrainAcc=0.9814
# Fold 16 Epoch 1100: TotalLoss=0.078086 | Sup=0.075681 | Recon=0.000301 | TrainAcc=0.9814
# Fold 16 Epoch 1200: TotalLoss=0.062816 | Sup=0.060506 | Recon=0.000289 | TrainAcc=0.9851
# Fold 16 Epoch 1300: TotalLoss=0.050728 | Sup=0.048475 | Recon=0.000282 | TrainAcc=0.9926
# Fold 16 Epoch 1400: TotalLoss=0.049787 | Sup=0.047633 | Recon=0.000269 | TrainAcc=0.9963
# Fold 16 Epoch 1500: TotalLoss=0.043951 | Sup=0.041895 | Recon=0.000257 | TrainAcc=0.9963
# Fold 16 Epoch 1600: TotalLoss=0.039949 | Sup=0.037931 | Recon=0.000252 | TrainAcc=0.9963
# Fold 16 Epoch 1700: TotalLoss=0.033712 | Sup=0.031767 | Recon=0.000243 | TrainAcc=0.9963
# Fold 16 Epoch 1800: TotalLoss=0.030803 | Sup=0.028912 | Recon=0.000236 | TrainAcc=0.9888
# Fold 16 Epoch 1900: TotalLoss=0.028728 | Sup=0.026898 | Recon=0.000229 | TrainAcc=1.0000
# Fold 16 Epoch 2000: TotalLoss=0.024302 | Sup=0.022535 | Recon=0.000221 | TrainAcc=1.0000
# Fold 16 → Acc=0.9667 | Prec=1.0000 | Rec=0.9412 | F1=0.9697 | AUC=0.9910 | CE Loss=0.1826
#
# === Fold 17 ===
# Train CN: 119, Train MCI: 150
# Fold 17 Epoch 1: TotalLoss=1.151467 | Sup=0.832018 | Recon=0.039931 | TrainAcc=0.4424
# Fold 17 Epoch 100: TotalLoss=0.384016 | Sup=0.364897 | Recon=0.002390 | TrainAcc=0.8401
# Fold 17 Epoch 200: TotalLoss=0.321626 | Sup=0.312801 | Recon=0.001103 | TrainAcc=0.8773
# Fold 17 Epoch 300: TotalLoss=0.282678 | Sup=0.277047 | Recon=0.000704 | TrainAcc=0.8885
# Fold 17 Epoch 400: TotalLoss=0.248791 | Sup=0.244154 | Recon=0.000580 | TrainAcc=0.8996
# Fold 17 Epoch 500: TotalLoss=0.218842 | Sup=0.214848 | Recon=0.000499 | TrainAcc=0.9182
# Fold 17 Epoch 600: TotalLoss=0.189991 | Sup=0.186586 | Recon=0.000426 | TrainAcc=0.9331
# Fold 17 Epoch 700: TotalLoss=0.163829 | Sup=0.160749 | Recon=0.000385 | TrainAcc=0.9294
# Fold 17 Epoch 800: TotalLoss=0.146689 | Sup=0.143771 | Recon=0.000365 | TrainAcc=0.9368
# Fold 17 Epoch 900: TotalLoss=0.129318 | Sup=0.126640 | Recon=0.000335 | TrainAcc=0.9554
# Fold 17 Epoch 1000: TotalLoss=0.121230 | Sup=0.118654 | Recon=0.000322 | TrainAcc=0.9665
# Fold 17 Epoch 1100: TotalLoss=0.100817 | Sup=0.098383 | Recon=0.000304 | TrainAcc=0.9628
# Fold 17 Epoch 1200: TotalLoss=0.089946 | Sup=0.087572 | Recon=0.000297 | TrainAcc=0.9665
# Fold 17 Epoch 1300: TotalLoss=0.073320 | Sup=0.071095 | Recon=0.000278 | TrainAcc=0.9851
# Fold 17 Epoch 1400: TotalLoss=0.071546 | Sup=0.069418 | Recon=0.000266 | TrainAcc=0.9851
# Fold 17 Epoch 1500: TotalLoss=0.061685 | Sup=0.059663 | Recon=0.000253 | TrainAcc=0.9926
# Fold 17 Epoch 1600: TotalLoss=0.053929 | Sup=0.051972 | Recon=0.000245 | TrainAcc=0.9888
# Fold 17 Epoch 1700: TotalLoss=0.047772 | Sup=0.045886 | Recon=0.000236 | TrainAcc=0.9926
# Fold 17 Epoch 1800: TotalLoss=0.042478 | Sup=0.040626 | Recon=0.000231 | TrainAcc=0.9963
# Fold 17 Epoch 1900: TotalLoss=0.036722 | Sup=0.034951 | Recon=0.000221 | TrainAcc=0.9963
# Fold 17 Epoch 2000: TotalLoss=0.037840 | Sup=0.036139 | Recon=0.000213 | TrainAcc=1.0000
# Fold 17 → Acc=1.0000 | Prec=1.0000 | Rec=1.0000 | F1=1.0000 | AUC=1.0000 | CE Loss=0.0401
#
# === Fold 18 ===
# Train CN: 119, Train MCI: 150
# Fold 18 Epoch 1: TotalLoss=1.016252 | Sup=0.683459 | Recon=0.041599 | TrainAcc=0.4349
# Fold 18 Epoch 100: TotalLoss=0.380715 | Sup=0.360370 | Recon=0.002543 | TrainAcc=0.8625
# Fold 18 Epoch 200: TotalLoss=0.309169 | Sup=0.299707 | Recon=0.001183 | TrainAcc=0.8699
# Fold 18 Epoch 300: TotalLoss=0.270155 | Sup=0.264144 | Recon=0.000751 | TrainAcc=0.8885
# Fold 18 Epoch 400: TotalLoss=0.232660 | Sup=0.228084 | Recon=0.000572 | TrainAcc=0.8996
# Fold 18 Epoch 500: TotalLoss=0.209606 | Sup=0.205609 | Recon=0.000500 | TrainAcc=0.9219
# Fold 18 Epoch 600: TotalLoss=0.175542 | Sup=0.172008 | Recon=0.000442 | TrainAcc=0.9294
# Fold 18 Epoch 700: TotalLoss=0.160163 | Sup=0.156928 | Recon=0.000404 | TrainAcc=0.9368
# Fold 18 Epoch 800: TotalLoss=0.131087 | Sup=0.128024 | Recon=0.000383 | TrainAcc=0.9405
# Fold 18 Epoch 900: TotalLoss=0.125565 | Sup=0.122679 | Recon=0.000361 | TrainAcc=0.9703
# Fold 18 Epoch 1000: TotalLoss=0.099085 | Sup=0.096286 | Recon=0.000350 | TrainAcc=0.9405
# Fold 18 Epoch 1100: TotalLoss=0.092341 | Sup=0.089689 | Recon=0.000331 | TrainAcc=0.9777
# Fold 18 Epoch 1200: TotalLoss=0.073830 | Sup=0.071360 | Recon=0.000309 | TrainAcc=0.9851
# Fold 18 Epoch 1300: TotalLoss=0.071133 | Sup=0.068801 | Recon=0.000291 | TrainAcc=0.9888
# Fold 18 Epoch 1400: TotalLoss=0.056360 | Sup=0.054083 | Recon=0.000285 | TrainAcc=0.9851
# Fold 18 Epoch 1500: TotalLoss=0.053287 | Sup=0.051060 | Recon=0.000278 | TrainAcc=0.9963
# Fold 18 Epoch 1600: TotalLoss=0.050327 | Sup=0.048212 | Recon=0.000264 | TrainAcc=0.9851
# Fold 18 Epoch 1700: TotalLoss=0.037090 | Sup=0.035070 | Recon=0.000252 | TrainAcc=1.0000
# Fold 18 Epoch 1800: TotalLoss=0.037795 | Sup=0.035835 | Recon=0.000245 | TrainAcc=1.0000
# Fold 18 Epoch 1900: TotalLoss=0.029926 | Sup=0.028040 | Recon=0.000236 | TrainAcc=1.0000
# Fold 18 Epoch 2000: TotalLoss=0.031326 | Sup=0.029533 | Recon=0.000224 | TrainAcc=1.0000
# Fold 18 → Acc=0.9667 | Prec=1.0000 | Rec=0.9412 | F1=0.9697 | AUC=1.0000 | CE Loss=0.0946
#
# === Fold 19 ===
# Train CN: 119, Train MCI: 150
# Fold 19 Epoch 1: TotalLoss=1.144874 | Sup=0.811622 | Recon=0.041656 | TrainAcc=0.4424
# Fold 19 Epoch 100: TotalLoss=0.380042 | Sup=0.359627 | Recon=0.002552 | TrainAcc=0.8476
# Fold 19 Epoch 200: TotalLoss=0.313384 | Sup=0.302973 | Recon=0.001301 | TrainAcc=0.8625
# Fold 19 Epoch 300: TotalLoss=0.276345 | Sup=0.269430 | Recon=0.000864 | TrainAcc=0.8848
# Fold 19 Epoch 400: TotalLoss=0.238216 | Sup=0.232869 | Recon=0.000668 | TrainAcc=0.8996
# Fold 19 Epoch 500: TotalLoss=0.215599 | Sup=0.211225 | Recon=0.000547 | TrainAcc=0.9182
# Fold 19 Epoch 600: TotalLoss=0.182169 | Sup=0.178530 | Recon=0.000455 | TrainAcc=0.9294
# Fold 19 Epoch 700: TotalLoss=0.175289 | Sup=0.172077 | Recon=0.000401 | TrainAcc=0.9331
# Fold 19 Epoch 800: TotalLoss=0.140735 | Sup=0.137806 | Recon=0.000366 | TrainAcc=0.9405
# Fold 19 Epoch 900: TotalLoss=0.117204 | Sup=0.114410 | Recon=0.000349 | TrainAcc=0.9405
# Fold 19 Epoch 1000: TotalLoss=0.106778 | Sup=0.104211 | Recon=0.000321 | TrainAcc=0.9628
# Fold 19 Epoch 1100: TotalLoss=0.101352 | Sup=0.098898 | Recon=0.000307 | TrainAcc=0.9665
# Fold 19 Epoch 1200: TotalLoss=0.089874 | Sup=0.087456 | Recon=0.000302 | TrainAcc=0.9740
# Fold 19 Epoch 1300: TotalLoss=0.081752 | Sup=0.079481 | Recon=0.000284 | TrainAcc=0.9740
# Fold 19 Epoch 1400: TotalLoss=0.066264 | Sup=0.064056 | Recon=0.000276 | TrainAcc=0.9888
# Fold 19 Epoch 1500: TotalLoss=0.059055 | Sup=0.056958 | Recon=0.000262 | TrainAcc=0.9888
# Fold 19 Epoch 1600: TotalLoss=0.050986 | Sup=0.048955 | Recon=0.000254 | TrainAcc=0.9851
# Fold 19 Epoch 1700: TotalLoss=0.044279 | Sup=0.042325 | Recon=0.000244 | TrainAcc=0.9963
# Fold 19 Epoch 1800: TotalLoss=0.042106 | Sup=0.040185 | Recon=0.000240 | TrainAcc=0.9963
# Fold 19 Epoch 1900: TotalLoss=0.037887 | Sup=0.036004 | Recon=0.000235 | TrainAcc=1.0000
# Fold 19 Epoch 2000: TotalLoss=0.032770 | Sup=0.030931 | Recon=0.000230 | TrainAcc=0.9963
# Fold 19 → Acc=1.0000 | Prec=1.0000 | Rec=1.0000 | F1=1.0000 | AUC=1.0000 | CE Loss=0.0190
#
# === Fold 20 ===
# Train CN: 119, Train MCI: 150
# Fold 20 Epoch 1: TotalLoss=0.957386 | Sup=0.627547 | Recon=0.041230 | TrainAcc=0.5576
# Fold 20 Epoch 100: TotalLoss=0.351695 | Sup=0.331901 | Recon=0.002474 | TrainAcc=0.8699
# Fold 20 Epoch 200: TotalLoss=0.301375 | Sup=0.291839 | Recon=0.001192 | TrainAcc=0.8885
# Fold 20 Epoch 300: TotalLoss=0.256162 | Sup=0.250461 | Recon=0.000713 | TrainAcc=0.8996
# Fold 20 Epoch 400: TotalLoss=0.212522 | Sup=0.208180 | Recon=0.000543 | TrainAcc=0.9219
# Fold 20 Epoch 500: TotalLoss=0.193081 | Sup=0.189283 | Recon=0.000475 | TrainAcc=0.9257
# Fold 20 Epoch 600: TotalLoss=0.161007 | Sup=0.157736 | Recon=0.000409 | TrainAcc=0.9442
# Fold 20 Epoch 700: TotalLoss=0.145698 | Sup=0.142794 | Recon=0.000363 | TrainAcc=0.9442
# Fold 20 Epoch 800: TotalLoss=0.128410 | Sup=0.125663 | Recon=0.000343 | TrainAcc=0.9480
# Fold 20 Epoch 900: TotalLoss=0.112446 | Sup=0.109735 | Recon=0.000339 | TrainAcc=0.9628
# Fold 20 Epoch 1000: TotalLoss=0.095478 | Sup=0.092950 | Recon=0.000316 | TrainAcc=0.9665
# Fold 20 Epoch 1100: TotalLoss=0.087994 | Sup=0.085494 | Recon=0.000312 | TrainAcc=0.9777
# Fold 20 Epoch 1200: TotalLoss=0.079524 | Sup=0.077106 | Recon=0.000302 | TrainAcc=0.9665
# Fold 20 Epoch 1300: TotalLoss=0.074304 | Sup=0.072053 | Recon=0.000281 | TrainAcc=0.9888
# Fold 20 Epoch 1400: TotalLoss=0.061010 | Sup=0.058847 | Recon=0.000270 | TrainAcc=0.9926
# Fold 20 Epoch 1500: TotalLoss=0.052888 | Sup=0.050846 | Recon=0.000255 | TrainAcc=0.9963
# Fold 20 Epoch 1600: TotalLoss=0.047199 | Sup=0.045236 | Recon=0.000245 | TrainAcc=0.9926
# Fold 20 Epoch 1700: TotalLoss=0.043368 | Sup=0.041465 | Recon=0.000238 | TrainAcc=0.9963
# Fold 20 Epoch 1800: TotalLoss=0.037815 | Sup=0.035978 | Recon=0.000230 | TrainAcc=0.9963
# Fold 20 Epoch 1900: TotalLoss=0.035588 | Sup=0.033778 | Recon=0.000226 | TrainAcc=1.0000
# Fold 20 Epoch 2000: TotalLoss=0.036596 | Sup=0.034858 | Recon=0.000217 | TrainAcc=1.0000
# Fold 20 → Acc=1.0000 | Prec=1.0000 | Rec=1.0000 | F1=1.0000 | AUC=1.0000 | CE Loss=0.0442
#
# === Average Results Across 20 Folds ===
# Accuracy:  0.9750 ± 0.0255
# Precision: 0.9749 ± 0.0324
# Recall:    0.9824 ± 0.0328
# F1-score:  0.9780 ± 0.0227
# AUC:       0.9932 ± 0.0114
# CE Loss:   0.1130 ± 0.1158

# %%
feats_dim = num_feats
hidden_dim = 512
num_classes = 2
num_epochs = 2000
lr = 1e-4
weight_decay = 1e-4
batch_print_freq = 100

# Lambda values to test
lambda_list = [0.001, 0.005, 0.009, 0.01, 0.05, 0.09, 0.1, 0.3, 0.5, 0.9, 1, 2, 5, 8]

# === Cross-validation setup ===
sss = StratifiedShuffleSplit(n_splits=20, test_size=0.3, random_state=42)
y_all = y.copy()

# To store all results for each lambda
lambda_results = []

# === Outer loop for lambda sweep ===
for lambda_recon in lambda_list:
    print(f"\n\n====================== λ_recon = {lambda_recon} ======================")

    accuracies, precisions, recalls, f1_scores, aucs, ce_losses = [], [], [], [], [], []

    for fold, (train_val_idx, test_idx_global) in enumerate(sss.split(X, y_all), start=1):
        print(f"\n=== Fold {fold} ===")

        control_idx = np.where(y_all == 0)[0]
        patient_idx = np.where(y_all == 1)[0]
        sss_class = StratifiedShuffleSplit(n_splits=20, test_size=0.3, random_state=fold)
        control_train_idx, _ = next(sss_class.split(X[control_idx], y_all[control_idx]))
        patient_train_idx, _ = next(sss_class.split(X[patient_idx], y_all[patient_idx]))
        control_train = control_idx[control_train_idx]
        patient_train = patient_idx[patient_train_idx]
        train_idx_final = np.concatenate([control_train, patient_train])
        np.random.shuffle(train_idx_final)

        print(f"Train Control: {len(control_train)}, Train Patient: {len(patient_train)}")

        train_idx_t = torch.from_numpy(train_idx_final).long().to(device)
        y_train_tensor = torch.from_numpy(y_all[train_idx_final]).long().to(device)

        model = GCN_AE(feats_dim, hidden_dim, num_classes, device, activ="RELU", dropout=0.25).to(device)
        optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
        ce_loss_fn = nn.CrossEntropyLoss()
        recon_loss_fn = nn.MSELoss()
        data = load_data(W, X).to(device)

        for epoch in range(1, num_epochs + 1):
            model.train()
            optimizer.zero_grad()
            logits, recon_x, _ = model(data.x, data.edge_index)

            loss_sup = ce_loss_fn(logits[train_idx_t], y_train_tensor)
            loss_recon = recon_loss_fn(recon_x, data.x)
            total_loss = loss_sup + lambda_recon * loss_recon

            if torch.isnan(total_loss) or torch.isinf(total_loss):
                print(f"NaN/Inf detected at fold {fold} epoch {epoch}. Aborting epoch.")
                break

            total_loss.backward()
            optimizer.step()

            if epoch % batch_print_freq == 0 or epoch == 1:
                model.eval()
                with torch.no_grad():
                    logits_eval, _, _ = model(data.x, data.edge_index)
                    preds_train = logits_eval[train_idx_t].argmax(dim=1)
                    acc_train = accuracy_score(y_train_tensor.cpu(), preds_train.cpu())
                print(f"Fold {fold} Epoch {epoch}: TotalLoss={total_loss.item():.6f} | Sup={loss_sup.item():.6f} | Recon={loss_recon.item():.6f} | TrainAcc={acc_train:.4f}")

        # === Evaluation ===
        model.eval()
        with torch.no_grad():
            out_logits, _, _ = model(data.x, data.edge_index)
            preds = out_logits.argmax(dim=1).cpu().numpy()
            probs = nnFn.softmax(out_logits, dim=1)[:, 1].cpu().numpy()

        y_test = y_all[test_idx_global]
        y_pred_test = preds[test_idx_global]
        y_prob_test = probs[test_idx_global]

        acc = accuracy_score(y_test, y_pred_test)
        prec = precision_score(y_test, y_pred_test, zero_division=0)
        rec = recall_score(y_test, y_pred_test, zero_division=0)
        f1 = f1_score(y_test, y_pred_test, zero_division=0)
        try:
            auc = roc_auc_score(y_test, y_prob_test)
        except ValueError:
            auc = float('nan')
        ce = log_loss(y_test, y_prob_test)

        accuracies.append(acc)
        precisions.append(prec)
        recalls.append(rec)
        f1_scores.append(f1)
        aucs.append(auc)
        ce_losses.append(ce)

        print(f"Fold {fold} → Acc={acc:.4f} | Prec={prec:.4f} | Rec={rec:.4f} | F1={f1:.4f} | AUC={auc:.4f} | CE Loss={ce:.4f}")

    # === Store average results for this λ ===
    avg_results = {
        "lambda": lambda_recon,
        "Accuracy": np.mean(accuracies),
        "Precision": np.mean(precisions),
        "Recall": np.mean(recalls),
        "F1-score": np.mean(f1_scores),
        "CE Loss": np.mean(ce_losses),
        "AUC": np.nanmean(aucs)
    }
    lambda_results.append(avg_results)

    print("\n=== Average Results for λ =", lambda_recon, "===")
    print(f"Accuracy:  {avg_results['Accuracy']:.4f}")
    print(f"Precision: {avg_results['Precision']:.4f}")
    print(f"Recall:    {avg_results['Recall']:.4f}")
    print(f"F1-score:  {avg_results['F1-score']:.4f}")
    print(f"CE Loss:   {avg_results['CE Loss']:.4f}")
    print(f"AUC:       {avg_results['AUC']:.4f}")


# === FINAL SUMMARY ACROSS ALL λ ===
print("\n\n====================== FINAL SUMMARY ACROSS ALL λ ======================")
print(f"{'Lambda':<8} | {'Accuracy':<9} | {'Precision':<9} | {'Recall':<8} | {'F1-score':<9} | {'AUC':<8} | {'CE Loss':<8}")
print("-" * 72)
for res in lambda_results:
    print(f"{res['lambda']:<8} | {res['Accuracy']:<9.4f} | {res['Precision']:<9.4f} | {res['Recall']:<8.4f} | {res['F1-score']:<9.4f} | {res['AUC']:<8.4f} | {res['CE Loss']:<8.4f}")
# Out:
# Streaming output truncated to the last 5000 lines.
# === Fold 6 ===
# Train Control: 93, Train Patient: 116
# Fold 6 Epoch 1: TotalLoss=0.706757 | Sup=0.705077 | Recon=0.033597 | TrainAcc=0.4450
# Fold 6 Epoch 100: TotalLoss=0.500451 | Sup=0.500314 | Recon=0.002738 | TrainAcc=0.7799
# Fold 6 Epoch 200: TotalLoss=0.481114 | Sup=0.481048 | Recon=0.001317 | TrainAcc=0.7895
# Fold 6 Epoch 300: TotalLoss=0.462489 | Sup=0.462450 | Recon=0.000778 | TrainAcc=0.7895
# Fold 6 Epoch 400: TotalLoss=0.440178 | Sup=0.440148 | Recon=0.000607 | TrainAcc=0.7895
# Fold 6 Epoch 500: TotalLoss=0.438125 | Sup=0.438099 | Recon=0.000524 | TrainAcc=0.7895
# Fold 6 Epoch 600: TotalLoss=0.432046 | Sup=0.432022 | Recon=0.000497 | TrainAcc=0.7799
# Fold 6 Epoch 700: TotalLoss=0.425562 | Sup=0.425538 | Recon=0.000485 | TrainAcc=0.7847
# Fold 6 Epoch 800: TotalLoss=0.425625 | Sup=0.425601 | Recon=0.000481 | TrainAcc=0.7943
# Fold 6 Epoch 900: TotalLoss=0.409092 | Sup=0.409068 | Recon=0.000475 | TrainAcc=0.7990
# Fold 6 Epoch 1000: TotalLoss=0.410591 | Sup=0.410567 | Recon=0.000477 | TrainAcc=0.8086
# Fold 6 Epoch 1100: TotalLoss=0.395688 | Sup=0.395664 | Recon=0.000484 | TrainAcc=0.8134
# Fold 6 Epoch 1200: TotalLoss=0.393193 | Sup=0.393169 | Recon=0.000477 | TrainAcc=0.7368
# Fold 6 Epoch 1300: TotalLoss=0.386350 | Sup=0.386327 | Recon=0.000474 | TrainAcc=0.8134
# Fold 6 Epoch 1400: TotalLoss=0.377086 | Sup=0.377062 | Recon=0.000479 | TrainAcc=0.8230
# Fold 6 Epoch 1500: TotalLoss=0.361694 | Sup=0.361671 | Recon=0.000471 | TrainAcc=0.7656
# Fold 6 Epoch 1600: TotalLoss=0.355012 | Sup=0.354988 | Recon=0.000474 | TrainAcc=0.8086
# Fold 6 Epoch 1700: TotalLoss=0.355825 | Sup=0.355801 | Recon=0.000478 | TrainAcc=0.8373
# Fold 6 Epoch 1800: TotalLoss=0.353604 | Sup=0.353580 | Recon=0.000484 | TrainAcc=0.7895
# Fold 6 Epoch 1900: TotalLoss=0.334611 | Sup=0.334587 | Recon=0.000479 | TrainAcc=0.8086
# Fold 6 Epoch 2000: TotalLoss=0.329969 | Sup=0.329945 | Recon=0.000481 | TrainAcc=0.6316
# Fold 6 → Acc=0.6333 | Prec=0.6024 | Rec=1.0000 | F1=0.7519 | AUC=0.8385 | CE Loss=0.8180
#
# === Fold 7 ===
# Train Control: 93, Train Patient: 116
# Fold 7 Epoch 1: TotalLoss=0.721801 | Sup=0.719934 | Recon=0.037323 | TrainAcc=0.4450
# Fold 7 Epoch 100: TotalLoss=0.525843 | Sup=0.525697 | Recon=0.002927 | TrainAcc=0.7464
# Fold 7 Epoch 200: TotalLoss=0.489896 | Sup=0.489839 | Recon=0.001141 | TrainAcc=0.7464
# Fold 7 Epoch 300: TotalLoss=0.463863 | Sup=0.463825 | Recon=0.000763 | TrainAcc=0.7751
# Fold 7 Epoch 400: TotalLoss=0.445593 | Sup=0.445564 | Recon=0.000584 | TrainAcc=0.7799
# Fold 7 Epoch 500: TotalLoss=0.434554 | Sup=0.434527 | Recon=0.000536 | TrainAcc=0.7799
# Fold 7 Epoch 600: TotalLoss=0.425259 | Sup=0.425235 | Recon=0.000480 | TrainAcc=0.7990
# Fold 7 Epoch 700: TotalLoss=0.414782 | Sup=0.414759 | Recon=0.000476 | TrainAcc=0.7895
# Fold 7 Epoch 800: TotalLoss=0.415563 | Sup=0.415540 | Recon=0.000463 | TrainAcc=0.8182
# Fold 7 Epoch 900: TotalLoss=0.402146 | Sup=0.402123 | Recon=0.000469 | TrainAcc=0.7895
# Fold 7 Epoch 1000: TotalLoss=0.404643 | Sup=0.404620 | Recon=0.000459 | TrainAcc=0.7943
# Fold 7 Epoch 1100: TotalLoss=0.396605 | Sup=0.396582 | Recon=0.000464 | TrainAcc=0.7847
# Fold 7 Epoch 1200: TotalLoss=0.385719 | Sup=0.385696 | Recon=0.000461 | TrainAcc=0.8421
# Fold 7 Epoch 1300: TotalLoss=0.379414 | Sup=0.379390 | Recon=0.000467 | TrainAcc=0.8230
# Fold 7 Epoch 1400: TotalLoss=0.378262 | Sup=0.378238 | Recon=0.000474 | TrainAcc=0.7656
# Fold 7 Epoch 1500: TotalLoss=0.356878 | Sup=0.356855 | Recon=0.000463 | TrainAcc=0.7656
# Fold 7 Epoch 1600: TotalLoss=0.357882 | Sup=0.357859 | Recon=0.000463 | TrainAcc=0.7895
# Fold 7 Epoch 1700: TotalLoss=0.351478 | Sup=0.351455 | Recon=0.000471 | TrainAcc=0.8325
# Fold 7 Epoch 1800: TotalLoss=0.338228 | Sup=0.338204 | Recon=0.000466 | TrainAcc=0.8182
# Fold 7 Epoch 1900: TotalLoss=0.330507 | Sup=0.330484 | Recon=0.000468 | TrainAcc=0.8421
# Fold 7 Epoch 2000: TotalLoss=0.337745 | Sup=0.337722 | Recon=0.000470 | TrainAcc=0.7368
# Fold 7 → Acc=0.7444 | Prec=0.7015 | Rec=0.9400 | F1=0.8034 | AUC=0.8140 | CE Loss=0.7612
#
# === Fold 8 ===
# Train Control: 93, Train Patient: 116
# Fold 8 Epoch 1: TotalLoss=0.790260 | Sup=0.788493 | Recon=0.035346 | TrainAcc=0.5550
# Fold 8 Epoch 100: TotalLoss=0.544465 | Sup=0.544340 | Recon=0.002490 | TrainAcc=0.7273
# Fold 8 Epoch 200: TotalLoss=0.504948 | Sup=0.504889 | Recon=0.001179 | TrainAcc=0.7368
# Fold 8 Epoch 300: TotalLoss=0.475347 | Sup=0.475308 | Recon=0.000777 | TrainAcc=0.7608
# Fold 8 Epoch 400: TotalLoss=0.446372 | Sup=0.446342 | Recon=0.000594 | TrainAcc=0.7656
# Fold 8 Epoch 500: TotalLoss=0.432044 | Sup=0.432018 | Recon=0.000517 | TrainAcc=0.7847
# Fold 8 Epoch 600: TotalLoss=0.421398 | Sup=0.421374 | Recon=0.000494 | TrainAcc=0.7895
# Fold 8 Epoch 700: TotalLoss=0.414665 | Sup=0.414641 | Recon=0.000468 | TrainAcc=0.8038
# Fold 8 Epoch 800: TotalLoss=0.403473 | Sup=0.403450 | Recon=0.000471 | TrainAcc=0.7847
# Fold 8 Epoch 900: TotalLoss=0.389239 | Sup=0.389216 | Recon=0.000463 | TrainAcc=0.8278
# Fold 8 Epoch 1000: TotalLoss=0.386004 | Sup=0.385981 | Recon=0.000462 | TrainAcc=0.8182
# Fold 8 Epoch 1100: TotalLoss=0.374253 | Sup=0.374230 | Recon=0.000458 | TrainAcc=0.8134
# Fold 8 Epoch 1200: TotalLoss=0.366411 | Sup=0.366388 | Recon=0.000472 | TrainAcc=0.8182
# Fold 8 Epoch 1300: TotalLoss=0.361220 | Sup=0.361197 | Recon=0.000465 | TrainAcc=0.8086
# Fold 8 Epoch 1400: TotalLoss=0.352602 | Sup=0.352579 | Recon=0.000467 | TrainAcc=0.8325
# Fold 8 Epoch 1500: TotalLoss=0.349305 | Sup=0.349281 | Recon=0.000472 | TrainAcc=0.8134
# Fold 8 Epoch 1600: TotalLoss=0.350762 | Sup=0.350739 | Recon=0.000469 | TrainAcc=0.8182
# Fold 8 Epoch 1700: TotalLoss=0.342193 | Sup=0.342170 | Recon=0.000467 | TrainAcc=0.8230
# Fold 8 Epoch 1800: TotalLoss=0.338263 | Sup=0.338240 | Recon=0.000469 | TrainAcc=0.7990
# Fold 8 Epoch 1900: TotalLoss=0.331660 | Sup=0.331637 | Recon=0.000467 | TrainAcc=0.8325
# Fold 8 Epoch 2000: TotalLoss=0.318063 | Sup=0.318040 | Recon=0.000474 | TrainAcc=0.8325
# Fold 8 → Acc=0.8111 | Prec=0.8113 | Rec=0.8600 | F1=0.8350 | AUC=0.9078 | CE Loss=0.3981
#
# === Fold 9 ===
# Train Control: 93, Train Patient: 116
# Fold 9 Epoch 1: TotalLoss=0.696575 | Sup=0.694901 | Recon=0.033494 | TrainAcc=0.5455
# Fold 9 Epoch 100: TotalLoss=0.520470 | Sup=0.520340 | Recon=0.002608 | TrainAcc=0.7464
# Fold 9 Epoch 200: TotalLoss=0.480703 | Sup=0.480644 | Recon=0.001181 | TrainAcc=0.7608
# Fold 9 Epoch 300: TotalLoss=0.466088 | Sup=0.466051 | Recon=0.000726 | TrainAcc=0.7608
# Fold 9 Epoch 400: TotalLoss=0.453440 | Sup=0.453411 | Recon=0.000578 | TrainAcc=0.7560
# Fold 9 Epoch 500: TotalLoss=0.445485 | Sup=0.445460 | Recon=0.000518 | TrainAcc=0.7799
# Fold 9 Epoch 600: TotalLoss=0.441632 | Sup=0.441608 | Recon=0.000489 | TrainAcc=0.7799
# Fold 9 Epoch 700: TotalLoss=0.439107 | Sup=0.439083 | Recon=0.000482 | TrainAcc=0.7847
# Fold 9 Epoch 800: TotalLoss=0.429378 | Sup=0.429354 | Recon=0.000476 | TrainAcc=0.7751
# Fold 9 Epoch 900: TotalLoss=0.426520 | Sup=0.426497 | Recon=0.000470 | TrainAcc=0.7129
# Fold 9 Epoch 1000: TotalLoss=0.409521 | Sup=0.409497 | Recon=0.000477 | TrainAcc=0.7273
# Fold 9 Epoch 1100: TotalLoss=0.400717 | Sup=0.400694 | Recon=0.000474 | TrainAcc=0.7464
# Fold 9 Epoch 1200: TotalLoss=0.390077 | Sup=0.390053 | Recon=0.000470 | TrainAcc=0.7512
# Fold 9 Epoch 1300: TotalLoss=0.390472 | Sup=0.390448 | Recon=0.000480 | TrainAcc=0.7560
# Fold 9 Epoch 1400: TotalLoss=0.388579 | Sup=0.388555 | Recon=0.000480 | TrainAcc=0.7416
# Fold 9 Epoch 1500: TotalLoss=0.374324 | Sup=0.374300 | Recon=0.000478 | TrainAcc=0.7847
# Fold 9 Epoch 1600: TotalLoss=0.359982 | Sup=0.359958 | Recon=0.000484 | TrainAcc=0.6603
# Fold 9 Epoch 1700: TotalLoss=0.357594 | Sup=0.357570 | Recon=0.000478 | TrainAcc=0.7943
# Fold 9 Epoch 1800: TotalLoss=0.349865 | Sup=0.349841 | Recon=0.000479 | TrainAcc=0.7512
# Fold 9 Epoch 1900: TotalLoss=0.343494 | Sup=0.343469 | Recon=0.000488 | TrainAcc=0.6938
# Fold 9 Epoch 2000: TotalLoss=0.323126 | Sup=0.323101 | Recon=0.000493 | TrainAcc=0.7703
# Fold 9 → Acc=0.7667 | Prec=0.7458 | Rec=0.8800 | F1=0.8073 | AUC=0.8930 | CE Loss=0.4206
#
# === Fold 10 ===
# Train Control: 93, Train Patient: 116
# Fold 10 Epoch 1: TotalLoss=0.722545 | Sup=0.720978 | Recon=0.031333 | TrainAcc=0.5502
# Fold 10 Epoch 100: TotalLoss=0.515815 | Sup=0.515687 | Recon=0.002552 | TrainAcc=0.7512
# Fold 10 Epoch 200: TotalLoss=0.476425 | Sup=0.476367 | Recon=0.001162 | TrainAcc=0.7703
# Fold 10 Epoch 300: TotalLoss=0.459487 | Sup=0.459448 | Recon=0.000783 | TrainAcc=0.7799
# Fold 10 Epoch 400: TotalLoss=0.434167 | Sup=0.434137 | Recon=0.000590 | TrainAcc=0.7895
# Fold 10 Epoch 500: TotalLoss=0.423451 | Sup=0.423426 | Recon=0.000504 | TrainAcc=0.7751
# Fold 10 Epoch 600: TotalLoss=0.413419 | Sup=0.413395 | Recon=0.000484 | TrainAcc=0.7943
# Fold 10 Epoch 700: TotalLoss=0.409689 | Sup=0.409665 | Recon=0.000476 | TrainAcc=0.8086
# Fold 10 Epoch 800: TotalLoss=0.396799 | Sup=0.396776 | Recon=0.000465 | TrainAcc=0.8038
# Fold 10 Epoch 900: TotalLoss=0.391036 | Sup=0.391013 | Recon=0.000464 | TrainAcc=0.8134
# Fold 10 Epoch 1000: TotalLoss=0.380232 | Sup=0.380209 | Recon=0.000467 | TrainAcc=0.8038
# Fold 10 Epoch 1100: TotalLoss=0.369516 | Sup=0.369493 | Recon=0.000465 | TrainAcc=0.8086
# Fold 10 Epoch 1200: TotalLoss=0.367082 | Sup=0.367059 | Recon=0.000465 | TrainAcc=0.8134
# Fold 10 Epoch 1300: TotalLoss=0.353109 | Sup=0.353086 | Recon=0.000470 | TrainAcc=0.8086
# Fold 10 Epoch 1400: TotalLoss=0.346052 | Sup=0.346029 | Recon=0.000469 | TrainAcc=0.8230
# Fold 10 Epoch 1500: TotalLoss=0.337149 | Sup=0.337125 | Recon=0.000468 | TrainAcc=0.8230
# Fold 10 Epoch 1600: TotalLoss=0.325813 | Sup=0.325789 | Recon=0.000470 | TrainAcc=0.7943
# Fold 10 Epoch 1700: TotalLoss=0.327637 | Sup=0.327613 | Recon=0.000472 | TrainAcc=0.8182
# Fold 10 Epoch 1800: TotalLoss=0.334427 | Sup=0.334403 | Recon=0.000473 | TrainAcc=0.6507
# Fold 10 Epoch 1900: TotalLoss=0.317822 | Sup=0.317799 | Recon=0.000469 | TrainAcc=0.8278
# Fold 10 Epoch 2000: TotalLoss=0.316063 | Sup=0.316039 | Recon=0.000474 | TrainAcc=0.8421
# Fold 10 → Acc=0.8000 | Prec=0.7963 | Rec=0.8600 | F1=0.8269 | AUC=0.8617 | CE Loss=0.5173
#
# === Fold 11 ===
# Train Control: 93, Train Patient: 116
# Fold 11 Epoch 1: TotalLoss=0.691533 | Sup=0.689804 | Recon=0.034575 | TrainAcc=0.4498
# Fold 11 Epoch 100: TotalLoss=0.525146 | Sup=0.525015 | Recon=0.002632 | TrainAcc=0.7560
# Fold 11 Epoch 200: TotalLoss=0.486100 | Sup=0.486042 | Recon=0.001153 | TrainAcc=0.7703
# Fold 11 Epoch 300: TotalLoss=0.457277 | Sup=0.457243 | Recon=0.000681 | TrainAcc=0.8038
# Fold 11 Epoch 400: TotalLoss=0.442083 | Sup=0.442054 | Recon=0.000568 | TrainAcc=0.7895
# Fold 11 Epoch 500: TotalLoss=0.427419 | Sup=0.427393 | Recon=0.000520 | TrainAcc=0.7943
# Fold 11 Epoch 600: TotalLoss=0.421679 | Sup=0.421654 | Recon=0.000492 | TrainAcc=0.8038
# Fold 11 Epoch 700: TotalLoss=0.409785 | Sup=0.409761 | Recon=0.000478 | TrainAcc=0.7990
# Fold 11 Epoch 800: TotalLoss=0.396493 | Sup=0.396469 | Recon=0.000481 | TrainAcc=0.7895
# Fold 11 Epoch 900: TotalLoss=0.399549 | Sup=0.399525 | Recon=0.000473 | TrainAcc=0.8134
# Fold 11 Epoch 1000: TotalLoss=0.391037 | Sup=0.391013 | Recon=0.000475 | TrainAcc=0.8086
# Fold 11 Epoch 1100: TotalLoss=0.383292 | Sup=0.383268 | Recon=0.000483 | TrainAcc=0.6938
# Fold 11 Epoch 1200: TotalLoss=0.374125 | Sup=0.374101 | Recon=0.000482 | TrainAcc=0.8182
# Fold 11 Epoch 1300: TotalLoss=0.363127 | Sup=0.363103 | Recon=0.000483 | TrainAcc=0.8230
# Fold 11 Epoch 1400: TotalLoss=0.366076 | Sup=0.366052 | Recon=0.000482 | TrainAcc=0.8182
# Fold 11 Epoch 1500: TotalLoss=0.350860 | Sup=0.350836 | Recon=0.000484 | TrainAcc=0.8086
# Fold 11 Epoch 1600: TotalLoss=0.345221 | Sup=0.345197 | Recon=0.000484 | TrainAcc=0.8278
# Fold 11 Epoch 1700: TotalLoss=0.326805 | Sup=0.326781 | Recon=0.000484 | TrainAcc=0.8278
# Fold 11 Epoch 1800: TotalLoss=0.320173 | Sup=0.320149 | Recon=0.000483 | TrainAcc=0.8517
# Fold 11 Epoch 1900: TotalLoss=0.308918 | Sup=0.308893 | Recon=0.000486 | TrainAcc=0.8325
# Fold 11 Epoch 2000: TotalLoss=0.322227 | Sup=0.322203 | Recon=0.000493 | TrainAcc=0.8038
# Fold 11 → Acc=0.7444 | Prec=0.8293 | Rec=0.6800 | F1=0.7473 | AUC=0.8465 | CE Loss=0.5390
#
# === Fold 12 ===
# Train Control: 93, Train Patient: 116
# Fold 12 Epoch 1: TotalLoss=0.699978 | Sup=0.698370 | Recon=0.032163 | TrainAcc=0.5550
# Fold 12 Epoch 100: TotalLoss=0.530612 | Sup=0.530471 | Recon=0.002815 | TrainAcc=0.7368
# Fold 12 Epoch 200: TotalLoss=0.508145 | Sup=0.508081 | Recon=0.001272 | TrainAcc=0.7512
# Fold 12 Epoch 300: TotalLoss=0.476286 | Sup=0.476248 | Recon=0.000756 | TrainAcc=0.7368
# Fold 12 Epoch 400: TotalLoss=0.473193 | Sup=0.473163 | Recon=0.000617 | TrainAcc=0.7560
# Fold 12 Epoch 500: TotalLoss=0.448248 | Sup=0.448222 | Recon=0.000524 | TrainAcc=0.7703
# Fold 12 Epoch 600: TotalLoss=0.439873 | Sup=0.439848 | Recon=0.000498 | TrainAcc=0.7560
# Fold 12 Epoch 700: TotalLoss=0.432754 | Sup=0.432731 | Recon=0.000476 | TrainAcc=0.7656
# Fold 12 Epoch 800: TotalLoss=0.414571 | Sup=0.414547 | Recon=0.000472 | TrainAcc=0.7799
# Fold 12 Epoch 900: TotalLoss=0.409987 | Sup=0.409963 | Recon=0.000484 | TrainAcc=0.7608
# Fold 12 Epoch 1000: TotalLoss=0.403814 | Sup=0.403791 | Recon=0.000474 | TrainAcc=0.8134
# Fold 12 Epoch 1100: TotalLoss=0.390040 | Sup=0.390016 | Recon=0.000469 | TrainAcc=0.7703
# Fold 12 Epoch 1200: TotalLoss=0.374629 | Sup=0.374606 | Recon=0.000473 | TrainAcc=0.8038
# Fold 12 Epoch 1300: TotalLoss=0.366321 | Sup=0.366298 | Recon=0.000470 | TrainAcc=0.7081
# Fold 12 Epoch 1400: TotalLoss=0.368663 | Sup=0.368640 | Recon=0.000472 | TrainAcc=0.7656
# Fold 12 Epoch 1500: TotalLoss=0.352395 | Sup=0.352372 | Recon=0.000473 | TrainAcc=0.8469
# Fold 12 Epoch 1600: TotalLoss=0.338269 | Sup=0.338245 | Recon=0.000477 | TrainAcc=0.7895
# Fold 12 Epoch 1700: TotalLoss=0.331015 | Sup=0.330992 | Recon=0.000473 | TrainAcc=0.8373
# Fold 12 Epoch 1800: TotalLoss=0.326135 | Sup=0.326111 | Recon=0.000483 | TrainAcc=0.8517
# Fold 12 Epoch 1900: TotalLoss=0.313758 | Sup=0.313734 | Recon=0.000480 | TrainAcc=0.8038
# Fold 12 Epoch 2000: TotalLoss=0.291073 | Sup=0.291049 | Recon=0.000482 | TrainAcc=0.8038
# Fold 12 → Acc=0.7333 | Prec=0.9062 | Rec=0.5800 | F1=0.7073 | AUC=0.8337 | CE Loss=0.6235
#
# === Fold 13 ===
# Train Control: 93, Train Patient: 116
# Fold 13 Epoch 1: TotalLoss=0.684135 | Sup=0.682522 | Recon=0.032270 | TrainAcc=0.4498
# Fold 13 Epoch 100: TotalLoss=0.523016 | Sup=0.522878 | Recon=0.002753 | TrainAcc=0.7560
# Fold 13 Epoch 200: TotalLoss=0.500598 | Sup=0.500541 | Recon=0.001131 | TrainAcc=0.7512
# Fold 13 Epoch 300: TotalLoss=0.486655 | Sup=0.486620 | Recon=0.000715 | TrainAcc=0.7656
# Fold 13 Epoch 400: TotalLoss=0.465860 | Sup=0.465831 | Recon=0.000580 | TrainAcc=0.7608
# Fold 13 Epoch 500: TotalLoss=0.455194 | Sup=0.455168 | Recon=0.000510 | TrainAcc=0.7512
# Fold 13 Epoch 600: TotalLoss=0.450401 | Sup=0.450376 | Recon=0.000488 | TrainAcc=0.7608
# Fold 13 Epoch 700: TotalLoss=0.430682 | Sup=0.430658 | Recon=0.000475 | TrainAcc=0.7656
# Fold 13 Epoch 800: TotalLoss=0.437797 | Sup=0.437773 | Recon=0.000468 | TrainAcc=0.7799
# Fold 13 Epoch 900: TotalLoss=0.430728 | Sup=0.430705 | Recon=0.000469 | TrainAcc=0.7703
# Fold 13 Epoch 1000: TotalLoss=0.417016 | Sup=0.416992 | Recon=0.000465 | TrainAcc=0.7799
# Fold 13 Epoch 1100: TotalLoss=0.403903 | Sup=0.403879 | Recon=0.000472 | TrainAcc=0.7847
# Fold 13 Epoch 1200: TotalLoss=0.396936 | Sup=0.396912 | Recon=0.000468 | TrainAcc=0.7990
# Fold 13 Epoch 1300: TotalLoss=0.397978 | Sup=0.397955 | Recon=0.000465 | TrainAcc=0.7560
# Fold 13 Epoch 1400: TotalLoss=0.388979 | Sup=0.388955 | Recon=0.000471 | TrainAcc=0.8038
# Fold 13 Epoch 1500: TotalLoss=0.375402 | Sup=0.375378 | Recon=0.000474 | TrainAcc=0.7943
# Fold 13 Epoch 1600: TotalLoss=0.371585 | Sup=0.371561 | Recon=0.000470 | TrainAcc=0.7464
# Fold 13 Epoch 1700: TotalLoss=0.363198 | Sup=0.363174 | Recon=0.000473 | TrainAcc=0.7895
# Fold 13 Epoch 1800: TotalLoss=0.357838 | Sup=0.357814 | Recon=0.000478 | TrainAcc=0.8182
# Fold 13 Epoch 1900: TotalLoss=0.350659 | Sup=0.350635 | Recon=0.000474 | TrainAcc=0.8278
# Fold 13 Epoch 2000: TotalLoss=0.339118 | Sup=0.339094 | Recon=0.000481 | TrainAcc=0.8278
# Fold 13 → Acc=0.8000 | Prec=0.8333 | Rec=0.8000 | F1=0.8163 | AUC=0.8925 | CE Loss=0.4059
#
# === Fold 14 ===
# Train Control: 93, Train Patient: 116
# Fold 14 Epoch 1: TotalLoss=0.708435 | Sup=0.706871 | Recon=0.031275 | TrainAcc=0.4450
# Fold 14 Epoch 100: TotalLoss=0.538458 | Sup=0.538333 | Recon=0.002492 | TrainAcc=0.7368
# Fold 14 Epoch 200: TotalLoss=0.509606 | Sup=0.509551 | Recon=0.001101 | TrainAcc=0.7560
# Fold 14 Epoch 300: TotalLoss=0.481405 | Sup=0.481367 | Recon=0.000759 | TrainAcc=0.7512
# Fold 14 Epoch 400: TotalLoss=0.451848 | Sup=0.451819 | Recon=0.000570 | TrainAcc=0.7656
# Fold 14 Epoch 500: TotalLoss=0.458360 | Sup=0.458334 | Recon=0.000510 | TrainAcc=0.7799
# Fold 14 Epoch 600: TotalLoss=0.426363 | Sup=0.426338 | Recon=0.000493 | TrainAcc=0.8086
# Fold 14 Epoch 700: TotalLoss=0.429382 | Sup=0.429358 | Recon=0.000473 | TrainAcc=0.7990
# Fold 14 Epoch 800: TotalLoss=0.425178 | Sup=0.425155 | Recon=0.000468 | TrainAcc=0.7416
# Fold 14 Epoch 900: TotalLoss=0.414064 | Sup=0.414040 | Recon=0.000470 | TrainAcc=0.7990
# Fold 14 Epoch 1000: TotalLoss=0.396211 | Sup=0.396187 | Recon=0.000467 | TrainAcc=0.8086
# Fold 14 Epoch 1100: TotalLoss=0.391171 | Sup=0.391148 | Recon=0.000464 | TrainAcc=0.8038
# Fold 14 Epoch 1200: TotalLoss=0.390712 | Sup=0.390689 | Recon=0.000464 | TrainAcc=0.7560
# Fold 14 Epoch 1300: TotalLoss=0.385174 | Sup=0.385150 | Recon=0.000475 | TrainAcc=0.7990
# Fold 14 Epoch 1400: TotalLoss=0.360219 | Sup=0.360195 | Recon=0.000471 | TrainAcc=0.8230
# Fold 14 Epoch 1500: TotalLoss=0.351879 | Sup=0.351856 | Recon=0.000468 | TrainAcc=0.7895
# Fold 14 Epoch 1600: TotalLoss=0.356124 | Sup=0.356101 | Recon=0.000470 | TrainAcc=0.8086
# Fold 14 Epoch 1700: TotalLoss=0.352064 | Sup=0.352041 | Recon=0.000465 | TrainAcc=0.8038
# Fold 14 Epoch 1800: TotalLoss=0.340404 | Sup=0.340381 | Recon=0.000473 | TrainAcc=0.8038
# Fold 14 Epoch 1900: TotalLoss=0.334818 | Sup=0.334794 | Recon=0.000473 | TrainAcc=0.8278
# Fold 14 Epoch 2000: TotalLoss=0.331116 | Sup=0.331093 | Recon=0.000472 | TrainAcc=0.8325
# Fold 14 → Acc=0.7778 | Prec=0.7778 | Rec=0.8400 | F1=0.8077 | AUC=0.8650 | CE Loss=0.6349
#
# === Fold 15 ===
# Train Control: 93, Train Patient: 116
# Fold 15 Epoch 1: TotalLoss=0.699164 | Sup=0.697600 | Recon=0.031283 | TrainAcc=0.5263
# Fold 15 Epoch 100: TotalLoss=0.548265 | Sup=0.548139 | Recon=0.002528 | TrainAcc=0.7273
# Fold 15 Epoch 200: TotalLoss=0.517923 | Sup=0.517860 | Recon=0.001267 | TrainAcc=0.7416
# Fold 15 Epoch 300: TotalLoss=0.491060 | Sup=0.491020 | Recon=0.000790 | TrainAcc=0.7512
# Fold 15 Epoch 400: TotalLoss=0.483679 | Sup=0.483649 | Recon=0.000582 | TrainAcc=0.7703
# Fold 15 Epoch 500: TotalLoss=0.471005 | Sup=0.470979 | Recon=0.000524 | TrainAcc=0.7703
# Fold 15 Epoch 600: TotalLoss=0.455815 | Sup=0.455791 | Recon=0.000486 | TrainAcc=0.7608
# Fold 15 Epoch 700: TotalLoss=0.446744 | Sup=0.446719 | Recon=0.000487 | TrainAcc=0.7751
# Fold 15 Epoch 800: TotalLoss=0.440417 | Sup=0.440393 | Recon=0.000478 | TrainAcc=0.7703
# Fold 15 Epoch 900: TotalLoss=0.423494 | Sup=0.423470 | Recon=0.000472 | TrainAcc=0.7129
# Fold 15 Epoch 1000: TotalLoss=0.424693 | Sup=0.424668 | Recon=0.000489 | TrainAcc=0.6746
# Fold 15 Epoch 1100: TotalLoss=0.418486 | Sup=0.418463 | Recon=0.000475 | TrainAcc=0.7129
# Fold 15 Epoch 1200: TotalLoss=0.408944 | Sup=0.408920 | Recon=0.000480 | TrainAcc=0.7895
# Fold 15 Epoch 1300: TotalLoss=0.395960 | Sup=0.395936 | Recon=0.000483 | TrainAcc=0.7751
# Fold 15 Epoch 1400: TotalLoss=0.394562 | Sup=0.394537 | Recon=0.000483 | TrainAcc=0.7512
# Fold 15 Epoch 1500: TotalLoss=0.381138 | Sup=0.381114 | Recon=0.000484 | TrainAcc=0.7321
# Fold 15 Epoch 1600: TotalLoss=0.365331 | Sup=0.365306 | Recon=0.000490 | TrainAcc=0.7847
# Fold 15 Epoch 1700: TotalLoss=0.358735 | Sup=0.358710 | Recon=0.000491 | TrainAcc=0.7129
# Fold 15 Epoch 1800: TotalLoss=0.364235 | Sup=0.364211 | Recon=0.000488 | TrainAcc=0.7321
# Fold 15 Epoch 1900: TotalLoss=0.358903 | Sup=0.358879 | Recon=0.000495 | TrainAcc=0.7273
# Fold 15 Epoch 2000: TotalLoss=0.330302 | Sup=0.330277 | Recon=0.000489 | TrainAcc=0.7321
# Fold 15 → Acc=0.7333 | Prec=0.7031 | Rec=0.9000 | F1=0.7895 | AUC=0.8752 | CE Loss=0.4983
#
# === Fold 16 ===
# Train Control: 93, Train Patient: 116
# Fold 16 Epoch 1: TotalLoss=0.702648 | Sup=0.701043 | Recon=0.032094 | TrainAcc=0.4450
# Fold 16 Epoch 100: TotalLoss=0.483963 | Sup=0.483837 | Recon=0.002524 | TrainAcc=0.7847
# Fold 16 Epoch 200: TotalLoss=0.466404 | Sup=0.466349 | Recon=0.001094 | TrainAcc=0.7799
# Fold 16 Epoch 300: TotalLoss=0.441080 | Sup=0.441044 | Recon=0.000719 | TrainAcc=0.7943
# Fold 16 Epoch 400: TotalLoss=0.427669 | Sup=0.427640 | Recon=0.000565 | TrainAcc=0.8038
# Fold 16 Epoch 500: TotalLoss=0.419234 | Sup=0.419209 | Recon=0.000501 | TrainAcc=0.8038
# Fold 16 Epoch 600: TotalLoss=0.408996 | Sup=0.408971 | Recon=0.000488 | TrainAcc=0.8182
# Fold 16 Epoch 700: TotalLoss=0.406852 | Sup=0.406829 | Recon=0.000472 | TrainAcc=0.8230
# Fold 16 Epoch 800: TotalLoss=0.400068 | Sup=0.400045 | Recon=0.000464 | TrainAcc=0.8086
# Fold 16 Epoch 900: TotalLoss=0.391629 | Sup=0.391606 | Recon=0.000463 | TrainAcc=0.8230
# Fold 16 Epoch 1000: TotalLoss=0.391229 | Sup=0.391206 | Recon=0.000462 | TrainAcc=0.8182
# Fold 16 Epoch 1100: TotalLoss=0.373466 | Sup=0.373443 | Recon=0.000460 | TrainAcc=0.8134
# Fold 16 Epoch 1200: TotalLoss=0.381540 | Sup=0.381516 | Recon=0.000463 | TrainAcc=0.8278
# Fold 16 Epoch 1300: TotalLoss=0.361404 | Sup=0.361381 | Recon=0.000464 | TrainAcc=0.8278
# Fold 16 Epoch 1400: TotalLoss=0.365802 | Sup=0.365779 | Recon=0.000464 | TrainAcc=0.8278
# Fold 16 Epoch 1500: TotalLoss=0.353422 | Sup=0.353398 | Recon=0.000469 | TrainAcc=0.7799
# Fold 16 Epoch 1600: TotalLoss=0.341208 | Sup=0.341185 | Recon=0.000475 | TrainAcc=0.8421
# Fold 16 Epoch 1700: TotalLoss=0.342874 | Sup=0.342851 | Recon=0.000470 | TrainAcc=0.8373
# Fold 16 Epoch 1800: TotalLoss=0.325030 | Sup=0.325007 | Recon=0.000476 | TrainAcc=0.8373
# Fold 16 Epoch 1900: TotalLoss=0.330787 | Sup=0.330763 | Recon=0.000474 | TrainAcc=0.8278
# Fold 16 Epoch 2000: TotalLoss=0.311255 | Sup=0.311231 | Recon=0.000476 | TrainAcc=0.8373
# Fold 16 → Acc=0.8667 | Prec=0.9130 | Rec=0.8400 | F1=0.8750 | AUC=0.8880 | CE Loss=0.3943
#
# === Fold 17 ===
# Train Control: 93, Train Patient: 116
# Fold 17 Epoch 1: TotalLoss=0.663232 | Sup=0.661383 | Recon=0.036980 | TrainAcc=0.5502
# Fold 17 Epoch 100: TotalLoss=0.526515 | Sup=0.526380 | Recon=0.002707 | TrainAcc=0.7368
# Fold 17 Epoch 200: TotalLoss=0.487763 | Sup=0.487694 | Recon=0.001366 | TrainAcc=0.7416
# Fold 17 Epoch 300: TotalLoss=0.460905 | Sup=0.460866 | Recon=0.000783 | TrainAcc=0.7799
# Fold 17 Epoch 400: TotalLoss=0.450299 | Sup=0.450269 | Recon=0.000605 | TrainAcc=0.7751
# Fold 17 Epoch 500: TotalLoss=0.429753 | Sup=0.429727 | Recon=0.000526 | TrainAcc=0.7751
# Fold 17 Epoch 600: TotalLoss=0.419731 | Sup=0.419707 | Recon=0.000483 | TrainAcc=0.7943
# Fold 17 Epoch 700: TotalLoss=0.412607 | Sup=0.412584 | Recon=0.000466 | TrainAcc=0.8086
# Fold 17 Epoch 800: TotalLoss=0.396693 | Sup=0.396669 | Recon=0.000467 | TrainAcc=0.7751
# Fold 17 Epoch 900: TotalLoss=0.389854 | Sup=0.389831 | Recon=0.000460 | TrainAcc=0.7799
# Fold 17 Epoch 1000: TotalLoss=0.370948 | Sup=0.370925 | Recon=0.000462 | TrainAcc=0.6651
# Fold 17 Epoch 1100: TotalLoss=0.367719 | Sup=0.367696 | Recon=0.000463 | TrainAcc=0.7799
# Fold 17 Epoch 1200: TotalLoss=0.367216 | Sup=0.367193 | Recon=0.000459 | TrainAcc=0.7943
# Fold 17 Epoch 1300: TotalLoss=0.346607 | Sup=0.346583 | Recon=0.000463 | TrainAcc=0.8086
# Fold 17 Epoch 1400: TotalLoss=0.338682 | Sup=0.338659 | Recon=0.000464 | TrainAcc=0.7751
# Fold 17 Epoch 1500: TotalLoss=0.328870 | Sup=0.328846 | Recon=0.000473 | TrainAcc=0.8230
# Fold 17 Epoch 1600: TotalLoss=0.324502 | Sup=0.324479 | Recon=0.000470 | TrainAcc=0.8230
# Fold 17 Epoch 1700: TotalLoss=0.323015 | Sup=0.322991 | Recon=0.000470 | TrainAcc=0.7847
# Fold 17 Epoch 1800: TotalLoss=0.302274 | Sup=0.302250 | Recon=0.000476 | TrainAcc=0.8182
# Fold 17 Epoch 1900: TotalLoss=0.295936 | Sup=0.295912 | Recon=0.000476 | TrainAcc=0.8278
# Fold 17 Epoch 2000: TotalLoss=0.290262 | Sup=0.290239 | Recon=0.000476 | TrainAcc=0.8278
# Fold 17 → Acc=0.8333 | Prec=0.7869 | Rec=0.9600 | F1=0.8649 | AUC=0.9135 | CE Loss=0.4367
#
# === Fold 18 ===
# Train Control: 93, Train Patient: 116
# Fold 18 Epoch 1: TotalLoss=0.680361 | Sup=0.678775 | Recon=0.031704 | TrainAcc=0.5550
# Fold 18 Epoch 100: TotalLoss=0.518957 | Sup=0.518829 | Recon=0.002558 | TrainAcc=0.7560
# Fold 18 Epoch 200: TotalLoss=0.487441 | Sup=0.487382 | Recon=0.001178 | TrainAcc=0.7751
# Fold 18 Epoch 300: TotalLoss=0.461785 | Sup=0.461746 | Recon=0.000780 | TrainAcc=0.7608
# Fold 18 Epoch 400: TotalLoss=0.443525 | Sup=0.443496 | Recon=0.000578 | TrainAcc=0.7751
# Fold 18 Epoch 500: TotalLoss=0.438484 | Sup=0.438459 | Recon=0.000504 | TrainAcc=0.7847
# Fold 18 Epoch 600: TotalLoss=0.428673 | Sup=0.428648 | Recon=0.000485 | TrainAcc=0.7990
# Fold 18 Epoch 700: TotalLoss=0.421650 | Sup=0.421626 | Recon=0.000473 | TrainAcc=0.7990
# Fold 18 Epoch 800: TotalLoss=0.411495 | Sup=0.411471 | Recon=0.000469 | TrainAcc=0.7943
# Fold 18 Epoch 900: TotalLoss=0.408283 | Sup=0.408260 | Recon=0.000468 | TrainAcc=0.8038
# Fold 18 Epoch 1000: TotalLoss=0.394592 | Sup=0.394568 | Recon=0.000468 | TrainAcc=0.8038
# Fold 18 Epoch 1100: TotalLoss=0.401235 | Sup=0.401211 | Recon=0.000466 | TrainAcc=0.7943
# Fold 18 Epoch 1200: TotalLoss=0.391136 | Sup=0.391113 | Recon=0.000467 | TrainAcc=0.7943
# Fold 18 Epoch 1300: TotalLoss=0.379524 | Sup=0.379501 | Recon=0.000470 | TrainAcc=0.7751
# Fold 18 Epoch 1400: TotalLoss=0.374543 | Sup=0.374519 | Recon=0.000468 | TrainAcc=0.7608
# Fold 18 Epoch 1500: TotalLoss=0.364593 | Sup=0.364570 | Recon=0.000467 | TrainAcc=0.8038
# Fold 18 Epoch 1600: TotalLoss=0.368443 | Sup=0.368420 | Recon=0.000473 | TrainAcc=0.7990
# Fold 18 Epoch 1700: TotalLoss=0.358588 | Sup=0.358564 | Recon=0.000475 | TrainAcc=0.7990
# Fold 18 Epoch 1800: TotalLoss=0.353209 | Sup=0.353185 | Recon=0.000476 | TrainAcc=0.7990
# Fold 18 Epoch 1900: TotalLoss=0.361447 | Sup=0.361423 | Recon=0.000473 | TrainAcc=0.7751
# Fold 18 Epoch 2000: TotalLoss=0.348769 | Sup=0.348746 | Recon=0.000475 | TrainAcc=0.8086
# Fold 18 → Acc=0.7889 | Prec=0.8298 | Rec=0.7800 | F1=0.8041 | AUC=0.8578 | CE Loss=0.4575
#
# === Fold 19 ===
# Train Control: 93, Train Patient: 116
# Fold 19 Epoch 1: TotalLoss=0.698035 | Sup=0.696625 | Recon=0.028202 | TrainAcc=0.4450
# Fold 19 Epoch 100: TotalLoss=0.506514 | Sup=0.506378 | Recon=0.002713 | TrainAcc=0.7656
# Fold 19 Epoch 200: TotalLoss=0.469622 | Sup=0.469564 | Recon=0.001161 | TrainAcc=0.7560
# Fold 19 Epoch 300: TotalLoss=0.454555 | Sup=0.454519 | Recon=0.000735 | TrainAcc=0.7847
# Fold 19 Epoch 400: TotalLoss=0.436512 | Sup=0.436483 | Recon=0.000589 | TrainAcc=0.7847
# Fold 19 Epoch 500: TotalLoss=0.424934 | Sup=0.424909 | Recon=0.000513 | TrainAcc=0.7990
# Fold 19 Epoch 600: TotalLoss=0.404443 | Sup=0.404419 | Recon=0.000487 | TrainAcc=0.8278
# Fold 19 Epoch 700: TotalLoss=0.407104 | Sup=0.407080 | Recon=0.000471 | TrainAcc=0.8230
# Fold 19 Epoch 800: TotalLoss=0.400400 | Sup=0.400376 | Recon=0.000471 | TrainAcc=0.7990
# Fold 19 Epoch 900: TotalLoss=0.387867 | Sup=0.387843 | Recon=0.000465 | TrainAcc=0.8230
# Fold 19 Epoch 1000: TotalLoss=0.375525 | Sup=0.375502 | Recon=0.000464 | TrainAcc=0.8517
# Fold 19 Epoch 1100: TotalLoss=0.369573 | Sup=0.369550 | Recon=0.000464 | TrainAcc=0.7656
# Fold 19 Epoch 1200: TotalLoss=0.364012 | Sup=0.363989 | Recon=0.000464 | TrainAcc=0.8230
# Fold 19 Epoch 1300: TotalLoss=0.353957 | Sup=0.353934 | Recon=0.000470 | TrainAcc=0.8230
# Fold 19 Epoch 1400: TotalLoss=0.349362 | Sup=0.349339 | Recon=0.000462 | TrainAcc=0.8182
# Fold 19 Epoch 1500: TotalLoss=0.350061 | Sup=0.350038 | Recon=0.000463 | TrainAcc=0.8278
# Fold 19 Epoch 1600: TotalLoss=0.340101 | Sup=0.340078 | Recon=0.000465 | TrainAcc=0.8421
# Fold 19 Epoch 1700: TotalLoss=0.331777 | Sup=0.331753 | Recon=0.000465 | TrainAcc=0.8086
# Fold 19 Epoch 1800: TotalLoss=0.332106 | Sup=0.332082 | Recon=0.000472 | TrainAcc=0.8182
# Fold 19 Epoch 1900: TotalLoss=0.312916 | Sup=0.312893 | Recon=0.000467 | TrainAcc=0.7847
# Fold 19 Epoch 2000: TotalLoss=0.321616 | Sup=0.321592 | Recon=0.000472 | TrainAcc=0.8278
# Fold 19 → Acc=0.7778 | Prec=0.7885 | Rec=0.8200 | F1=0.8039 | AUC=0.8645 | CE Loss=0.4402
#
# === Fold 20 ===
# Train Control: 93, Train Patient: 116
# Fold 20 Epoch 1: TotalLoss=0.807985 | Sup=0.806481 | Recon=0.030092 | TrainAcc=0.5502
# Fold 20 Epoch 100: TotalLoss=0.498630 | Sup=0.498519 | Recon=0.002226 | TrainAcc=0.7751
# Fold 20 Epoch 200: TotalLoss=0.456479 | Sup=0.456424 | Recon=0.001110 | TrainAcc=0.7799
# Fold 20 Epoch 300: TotalLoss=0.431892 | Sup=0.431856 | Recon=0.000728 | TrainAcc=0.7990
# Fold 20 Epoch 400: TotalLoss=0.418588 | Sup=0.418560 | Recon=0.000571 | TrainAcc=0.8182
# Fold 20 Epoch 500: TotalLoss=0.397321 | Sup=0.397295 | Recon=0.000516 | TrainAcc=0.8038
# Fold 20 Epoch 600: TotalLoss=0.394073 | Sup=0.394048 | Recon=0.000500 | TrainAcc=0.8086
# Fold 20 Epoch 700: TotalLoss=0.391770 | Sup=0.391746 | Recon=0.000479 | TrainAcc=0.8134
# Fold 20 Epoch 800: TotalLoss=0.382355 | Sup=0.382331 | Recon=0.000480 | TrainAcc=0.8373
# Fold 20 Epoch 900: TotalLoss=0.367574 | Sup=0.367550 | Recon=0.000476 | TrainAcc=0.8278
# Fold 20 Epoch 1000: TotalLoss=0.361530 | Sup=0.361507 | Recon=0.000474 | TrainAcc=0.8230
# Fold 20 Epoch 1100: TotalLoss=0.348716 | Sup=0.348693 | Recon=0.000477 | TrainAcc=0.8325
# Fold 20 Epoch 1200: TotalLoss=0.350369 | Sup=0.350345 | Recon=0.000479 | TrainAcc=0.8421
# Fold 20 Epoch 1300: TotalLoss=0.341927 | Sup=0.341903 | Recon=0.000484 | TrainAcc=0.8325
# Fold 20 Epoch 1400: TotalLoss=0.333970 | Sup=0.333945 | Recon=0.000488 | TrainAcc=0.8086
# Fold 20 Epoch 1500: TotalLoss=0.333784 | Sup=0.333760 | Recon=0.000487 | TrainAcc=0.8421
# Fold 20 Epoch 1600: TotalLoss=0.326173 | Sup=0.326148 | Recon=0.000489 | TrainAcc=0.8469
# Fold 20 Epoch 1700: TotalLoss=0.316353 | Sup=0.316328 | Recon=0.000488 | TrainAcc=0.7990
# Fold 20 Epoch 1800: TotalLoss=0.314786 | Sup=0.314762 | Recon=0.000488 | TrainAcc=0.8278
# Fold 20 Epoch 1900: TotalLoss=0.307880 | Sup=0.307856 | Recon=0.000490 | TrainAcc=0.8517
# Fold 20 Epoch 2000: TotalLoss=0.303199 | Sup=0.303174 | Recon=0.000496 | TrainAcc=0.8421
# Fold 20 → Acc=0.8222 | Prec=0.8400 | Rec=0.8400 | F1=0.8400 | AUC=0.8715 | CE Loss=0.4909
#
# === Average Results for λ = 0.05 ===
# Accuracy:  0.7633
# Precision: 0.7772
# Recall:    0.8410
# F1-score:  0.7985
# CE Loss:   0.5225
# AUC:       0.8678
#
#
# ====================== λ_recon = 0.09 ======================
#
# === Fold 1 ===
# Train Control: 93, Train Patient: 116
# Fold 1 Epoch 1: TotalLoss=0.805368 | Sup=0.802934 | Recon=0.027041 | TrainAcc=0.4450
# Fold 1 Epoch 100: TotalLoss=0.506775 | Sup=0.506569 | Recon=0.002286 | TrainAcc=0.7751
# Fold 1 Epoch 200: TotalLoss=0.485187 | Sup=0.485095 | Recon=0.001023 | TrainAcc=0.7943
# Fold 1 Epoch 300: TotalLoss=0.458724 | Sup=0.458663 | Recon=0.000672 | TrainAcc=0.7895
# Fold 1 Epoch 400: TotalLoss=0.445163 | Sup=0.445116 | Recon=0.000531 | TrainAcc=0.7847
# Fold 1 Epoch 500: TotalLoss=0.419736 | Sup=0.419693 | Recon=0.000479 | TrainAcc=0.7751
# Fold 1 Epoch 600: TotalLoss=0.410881 | Sup=0.410841 | Recon=0.000438 | TrainAcc=0.8086
# Fold 1 Epoch 700: TotalLoss=0.403382 | Sup=0.403344 | Recon=0.000429 | TrainAcc=0.8230
# Fold 1 Epoch 800: TotalLoss=0.402769 | Sup=0.402730 | Recon=0.000427 | TrainAcc=0.8182
# Fold 1 Epoch 900: TotalLoss=0.390749 | Sup=0.390712 | Recon=0.000414 | TrainAcc=0.8230
# Fold 1 Epoch 1000: TotalLoss=0.379589 | Sup=0.379552 | Recon=0.000415 | TrainAcc=0.8373
# Fold 1 Epoch 1100: TotalLoss=0.372186 | Sup=0.372149 | Recon=0.000414 | TrainAcc=0.8134
# Fold 1 Epoch 1200: TotalLoss=0.367501 | Sup=0.367463 | Recon=0.000413 | TrainAcc=0.8325
# Fold 1 Epoch 1300: TotalLoss=0.358283 | Sup=0.358245 | Recon=0.000413 | TrainAcc=0.8086
# Fold 1 Epoch 1400: TotalLoss=0.346582 | Sup=0.346544 | Recon=0.000414 | TrainAcc=0.8230
# Fold 1 Epoch 1500: TotalLoss=0.345343 | Sup=0.345305 | Recon=0.000416 | TrainAcc=0.8325
# Fold 1 Epoch 1600: TotalLoss=0.341051 | Sup=0.341013 | Recon=0.000412 | TrainAcc=0.8278
# Fold 1 Epoch 1700: TotalLoss=0.342121 | Sup=0.342084 | Recon=0.000413 | TrainAcc=0.6316
# Fold 1 Epoch 1800: TotalLoss=0.341142 | Sup=0.341105 | Recon=0.000412 | TrainAcc=0.7943
# Fold 1 Epoch 1900: TotalLoss=0.333339 | Sup=0.333302 | Recon=0.000415 | TrainAcc=0.8373
# Fold 1 Epoch 2000: TotalLoss=0.320671 | Sup=0.320634 | Recon=0.000413 | TrainAcc=0.8325
# Fold 1 → Acc=0.7667 | Prec=0.8919 | Rec=0.6600 | F1=0.7586 | AUC=0.8285 | CE Loss=0.5273
#
# === Fold 2 ===
# Train Control: 93, Train Patient: 116
# Fold 2 Epoch 1: TotalLoss=0.718882 | Sup=0.716303 | Recon=0.028660 | TrainAcc=0.4450
# Fold 2 Epoch 100: TotalLoss=0.552352 | Sup=0.552143 | Recon=0.002328 | TrainAcc=0.7225
# Fold 2 Epoch 200: TotalLoss=0.529512 | Sup=0.529424 | Recon=0.000982 | TrainAcc=0.7225
# Fold 2 Epoch 300: TotalLoss=0.502439 | Sup=0.502382 | Recon=0.000629 | TrainAcc=0.7225
# Fold 2 Epoch 400: TotalLoss=0.485434 | Sup=0.485386 | Recon=0.000536 | TrainAcc=0.7464
# Fold 2 Epoch 500: TotalLoss=0.479636 | Sup=0.479594 | Recon=0.000469 | TrainAcc=0.7464
# Fold 2 Epoch 600: TotalLoss=0.468580 | Sup=0.468540 | Recon=0.000441 | TrainAcc=0.7512
# Fold 2 Epoch 700: TotalLoss=0.458619 | Sup=0.458581 | Recon=0.000423 | TrainAcc=0.7560
# Fold 2 Epoch 800: TotalLoss=0.446630 | Sup=0.446592 | Recon=0.000423 | TrainAcc=0.7799
# Fold 2 Epoch 900: TotalLoss=0.433915 | Sup=0.433878 | Recon=0.000420 | TrainAcc=0.7895
# Fold 2 Epoch 1000: TotalLoss=0.425255 | Sup=0.425217 | Recon=0.000418 | TrainAcc=0.7799
# Fold 2 Epoch 1100: TotalLoss=0.413999 | Sup=0.413962 | Recon=0.000414 | TrainAcc=0.7608
# Fold 2 Epoch 1200: TotalLoss=0.408528 | Sup=0.408490 | Recon=0.000415 | TrainAcc=0.7751
# Fold 2 Epoch 1300: TotalLoss=0.389789 | Sup=0.389751 | Recon=0.000418 | TrainAcc=0.7608
# Fold 2 Epoch 1400: TotalLoss=0.389113 | Sup=0.389076 | Recon=0.000414 | TrainAcc=0.7560
# Fold 2 Epoch 1500: TotalLoss=0.377456 | Sup=0.377419 | Recon=0.000416 | TrainAcc=0.7943
# Fold 2 Epoch 1600: TotalLoss=0.362089 | Sup=0.362052 | Recon=0.000413 | TrainAcc=0.7943
# Fold 2 Epoch 1700: TotalLoss=0.336988 | Sup=0.336951 | Recon=0.000417 | TrainAcc=0.7847
# Fold 2 Epoch 1800: TotalLoss=0.335347 | Sup=0.335310 | Recon=0.000416 | TrainAcc=0.8134
# Fold 2 Epoch 1900: TotalLoss=0.335639 | Sup=0.335601 | Recon=0.000421 | TrainAcc=0.7847
# Fold 2 Epoch 2000: TotalLoss=0.330810 | Sup=0.330772 | Recon=0.000418 | TrainAcc=0.7799
# Fold 2 → Acc=0.7000 | Prec=0.6825 | Rec=0.8600 | F1=0.7611 | AUC=0.8427 | CE Loss=0.5595
#
# === Fold 3 ===
# Train Control: 93, Train Patient: 116
# Fold 3 Epoch 1: TotalLoss=0.713895 | Sup=0.710953 | Recon=0.032696 | TrainAcc=0.4545
# Fold 3 Epoch 100: TotalLoss=0.539891 | Sup=0.539626 | Recon=0.002944 | TrainAcc=0.7368
# Fold 3 Epoch 200: TotalLoss=0.512365 | Sup=0.512239 | Recon=0.001393 | TrainAcc=0.7464
# Fold 3 Epoch 300: TotalLoss=0.488461 | Sup=0.488391 | Recon=0.000777 | TrainAcc=0.7560
# Fold 3 Epoch 400: TotalLoss=0.467569 | Sup=0.467518 | Recon=0.000569 | TrainAcc=0.7416
# Fold 3 Epoch 500: TotalLoss=0.450646 | Sup=0.450603 | Recon=0.000478 | TrainAcc=0.7799
# Fold 3 Epoch 600: TotalLoss=0.435233 | Sup=0.435193 | Recon=0.000440 | TrainAcc=0.7847
# Fold 3 Epoch 700: TotalLoss=0.429114 | Sup=0.429075 | Recon=0.000433 | TrainAcc=0.7847
# Fold 3 Epoch 800: TotalLoss=0.422698 | Sup=0.422659 | Recon=0.000428 | TrainAcc=0.7416
# Fold 3 Epoch 900: TotalLoss=0.409546 | Sup=0.409508 | Recon=0.000421 | TrainAcc=0.8038
# Fold 3 Epoch 1000: TotalLoss=0.405455 | Sup=0.405418 | Recon=0.000419 | TrainAcc=0.7799
# Fold 3 Epoch 1100: TotalLoss=0.395128 | Sup=0.395091 | Recon=0.000417 | TrainAcc=0.7895
# Fold 3 Epoch 1200: TotalLoss=0.386642 | Sup=0.386605 | Recon=0.000416 | TrainAcc=0.7895
# Fold 3 Epoch 1300: TotalLoss=0.374872 | Sup=0.374834 | Recon=0.000420 | TrainAcc=0.8038
# Fold 3 Epoch 1400: TotalLoss=0.370470 | Sup=0.370432 | Recon=0.000425 | TrainAcc=0.7368
# Fold 3 Epoch 1500: TotalLoss=0.365451 | Sup=0.365413 | Recon=0.000419 | TrainAcc=0.7895
# Fold 3 Epoch 1600: TotalLoss=0.354061 | Sup=0.354023 | Recon=0.000419 | TrainAcc=0.7943
# Fold 3 Epoch 1700: TotalLoss=0.357687 | Sup=0.357649 | Recon=0.000419 | TrainAcc=0.7895
# Fold 3 Epoch 1800: TotalLoss=0.345270 | Sup=0.345232 | Recon=0.000419 | TrainAcc=0.7512
# Fold 3 Epoch 1900: TotalLoss=0.334526 | Sup=0.334488 | Recon=0.000423 | TrainAcc=0.8182
# Fold 3 Epoch 2000: TotalLoss=0.321168 | Sup=0.321130 | Recon=0.000421 | TrainAcc=0.7273
# Fold 3 → Acc=0.6556 | Prec=0.6267 | Rec=0.9400 | F1=0.7520 | AUC=0.8435 | CE Loss=0.6796
#
# === Fold 4 ===
# Train Control: 93, Train Patient: 116
# Fold 4 Epoch 1: TotalLoss=0.689703 | Sup=0.686817 | Recon=0.032068 | TrainAcc=0.5550
# Fold 4 Epoch 100: TotalLoss=0.550712 | Sup=0.550492 | Recon=0.002439 | TrainAcc=0.7177
# Fold 4 Epoch 200: TotalLoss=0.515087 | Sup=0.514990 | Recon=0.001079 | TrainAcc=0.7081
# Fold 4 Epoch 300: TotalLoss=0.508535 | Sup=0.508471 | Recon=0.000707 | TrainAcc=0.7321
# Fold 4 Epoch 400: TotalLoss=0.488859 | Sup=0.488809 | Recon=0.000560 | TrainAcc=0.7608
# Fold 4 Epoch 500: TotalLoss=0.480604 | Sup=0.480561 | Recon=0.000477 | TrainAcc=0.7656
# Fold 4 Epoch 600: TotalLoss=0.473004 | Sup=0.472964 | Recon=0.000441 | TrainAcc=0.7512
# Fold 4 Epoch 700: TotalLoss=0.465342 | Sup=0.465303 | Recon=0.000428 | TrainAcc=0.7656
# Fold 4 Epoch 800: TotalLoss=0.460519 | Sup=0.460481 | Recon=0.000423 | TrainAcc=0.7656
# Fold 4 Epoch 900: TotalLoss=0.453420 | Sup=0.453382 | Recon=0.000422 | TrainAcc=0.7560
# Fold 4 Epoch 1000: TotalLoss=0.444747 | Sup=0.444709 | Recon=0.000423 | TrainAcc=0.7656
# Fold 4 Epoch 1100: TotalLoss=0.429103 | Sup=0.429065 | Recon=0.000424 | TrainAcc=0.7751
# Fold 4 Epoch 1200: TotalLoss=0.428494 | Sup=0.428456 | Recon=0.000419 | TrainAcc=0.7560
# Fold 4 Epoch 1300: TotalLoss=0.415933 | Sup=0.415895 | Recon=0.000422 | TrainAcc=0.7847
# Fold 4 Epoch 1400: TotalLoss=0.401665 | Sup=0.401627 | Recon=0.000425 | TrainAcc=0.7321
# Fold 4 Epoch 1500: TotalLoss=0.408651 | Sup=0.408613 | Recon=0.000428 | TrainAcc=0.7703
# Fold 4 Epoch 1600: TotalLoss=0.385831 | Sup=0.385793 | Recon=0.000425 | TrainAcc=0.7751
# Fold 4 Epoch 1700: TotalLoss=0.371279 | Sup=0.371241 | Recon=0.000426 | TrainAcc=0.7656
# Fold 4 Epoch 1800: TotalLoss=0.372075 | Sup=0.372037 | Recon=0.000424 | TrainAcc=0.7273
# Fold 4 Epoch 1900: TotalLoss=0.359600 | Sup=0.359562 | Recon=0.000423 | TrainAcc=0.7990
# Fold 4 Epoch 2000: TotalLoss=0.359242 | Sup=0.359204 | Recon=0.000421 | TrainAcc=0.8086
# Fold 4 → Acc=0.8222 | Prec=0.8400 | Rec=0.8400 | F1=0.8400 | AUC=0.8955 | CE Loss=0.4112
#
# === Fold 5 ===
# Train Control: 93, Train Patient: 116
# Fold 5 Epoch 1: TotalLoss=0.689599 | Sup=0.686577 | Recon=0.033580 | TrainAcc=0.4450
# Fold 5 Epoch 100: TotalLoss=0.513362 | Sup=0.513160 | Recon=0.002250 | TrainAcc=0.7656
# Fold 5 Epoch 200: TotalLoss=0.490488 | Sup=0.490397 | Recon=0.001014 | TrainAcc=0.7799
# Fold 5 Epoch 300: TotalLoss=0.471437 | Sup=0.471375 | Recon=0.000685 | TrainAcc=0.7847
# Fold 5 Epoch 400: TotalLoss=0.457461 | Sup=0.457412 | Recon=0.000545 | TrainAcc=0.7751
# Fold 5 Epoch 500: TotalLoss=0.456213 | Sup=0.456169 | Recon=0.000493 | TrainAcc=0.7895
# Fold 5 Epoch 600: TotalLoss=0.443055 | Sup=0.443014 | Recon=0.000455 | TrainAcc=0.7799
# Fold 5 Epoch 700: TotalLoss=0.444545 | Sup=0.444506 | Recon=0.000438 | TrainAcc=0.7895
# Fold 5 Epoch 800: TotalLoss=0.437280 | Sup=0.437241 | Recon=0.000428 | TrainAcc=0.7943
# Fold 5 Epoch 900: TotalLoss=0.417652 | Sup=0.417613 | Recon=0.000427 | TrainAcc=0.7847
# Fold 5 Epoch 1000: TotalLoss=0.410625 | Sup=0.410587 | Recon=0.000422 | TrainAcc=0.7943
# Fold 5 Epoch 1100: TotalLoss=0.409347 | Sup=0.409309 | Recon=0.000423 | TrainAcc=0.8134
# Fold 5 Epoch 1200: TotalLoss=0.392761 | Sup=0.392722 | Recon=0.000426 | TrainAcc=0.8134
# Fold 5 Epoch 1300: TotalLoss=0.380506 | Sup=0.380468 | Recon=0.000422 | TrainAcc=0.8086
# Fold 5 Epoch 1400: TotalLoss=0.369724 | Sup=0.369686 | Recon=0.000419 | TrainAcc=0.7847
# Fold 5 Epoch 1500: TotalLoss=0.361510 | Sup=0.361472 | Recon=0.000424 | TrainAcc=0.8134
# Fold 5 Epoch 1600: TotalLoss=0.359456 | Sup=0.359418 | Recon=0.000421 | TrainAcc=0.8182
# Fold 5 Epoch 1700: TotalLoss=0.352884 | Sup=0.352846 | Recon=0.000423 | TrainAcc=0.8086
# Fold 5 Epoch 1800: TotalLoss=0.343575 | Sup=0.343537 | Recon=0.000427 | TrainAcc=0.7656
# Fold 5 Epoch 1900: TotalLoss=0.340574 | Sup=0.340536 | Recon=0.000423 | TrainAcc=0.8325
# Fold 5 Epoch 2000: TotalLoss=0.324841 | Sup=0.324802 | Recon=0.000426 | TrainAcc=0.7847
# Fold 5 → Acc=0.7667 | Prec=0.7544 | Rec=0.8600 | F1=0.8037 | AUC=0.8825 | CE Loss=0.4444
#
# === Fold 6 ===
# Train Control: 93, Train Patient: 116
# Fold 6 Epoch 1: TotalLoss=0.772724 | Sup=0.769745 | Recon=0.033096 | TrainAcc=0.4450
# Fold 6 Epoch 100: TotalLoss=0.504438 | Sup=0.504232 | Recon=0.002291 | TrainAcc=0.7847
# Fold 6 Epoch 200: TotalLoss=0.480284 | Sup=0.480195 | Recon=0.000988 | TrainAcc=0.7847
# Fold 6 Epoch 300: TotalLoss=0.462064 | Sup=0.462004 | Recon=0.000670 | TrainAcc=0.7799
# Fold 6 Epoch 400: TotalLoss=0.437971 | Sup=0.437920 | Recon=0.000559 | TrainAcc=0.7895
# Fold 6 Epoch 500: TotalLoss=0.439911 | Sup=0.439868 | Recon=0.000479 | TrainAcc=0.7751
# Fold 6 Epoch 600: TotalLoss=0.433184 | Sup=0.433143 | Recon=0.000450 | TrainAcc=0.7799
# Fold 6 Epoch 700: TotalLoss=0.424967 | Sup=0.424929 | Recon=0.000431 | TrainAcc=0.7799
# Fold 6 Epoch 800: TotalLoss=0.417062 | Sup=0.417024 | Recon=0.000429 | TrainAcc=0.8086
# Fold 6 Epoch 900: TotalLoss=0.411481 | Sup=0.411442 | Recon=0.000429 | TrainAcc=0.8134
# Fold 6 Epoch 1000: TotalLoss=0.407176 | Sup=0.407138 | Recon=0.000421 | TrainAcc=0.7895
# Fold 6 Epoch 1100: TotalLoss=0.401102 | Sup=0.401064 | Recon=0.000421 | TrainAcc=0.7321
# Fold 6 Epoch 1200: TotalLoss=0.381415 | Sup=0.381377 | Recon=0.000420 | TrainAcc=0.8086
# Fold 6 Epoch 1300: TotalLoss=0.384707 | Sup=0.384670 | Recon=0.000420 | TrainAcc=0.7273
# Fold 6 Epoch 1400: TotalLoss=0.373410 | Sup=0.373372 | Recon=0.000420 | TrainAcc=0.8325
# Fold 6 Epoch 1500: TotalLoss=0.365716 | Sup=0.365678 | Recon=0.000419 | TrainAcc=0.7799
# Fold 6 Epoch 1600: TotalLoss=0.370940 | Sup=0.370902 | Recon=0.000420 | TrainAcc=0.6651
# Fold 6 Epoch 1700: TotalLoss=0.356000 | Sup=0.355963 | Recon=0.000419 | TrainAcc=0.8182
# Fold 6 Epoch 1800: TotalLoss=0.344370 | Sup=0.344332 | Recon=0.000417 | TrainAcc=0.8230
# Fold 6 Epoch 1900: TotalLoss=0.337425 | Sup=0.337387 | Recon=0.000416 | TrainAcc=0.8373
# Fold 6 Epoch 2000: TotalLoss=0.328787 | Sup=0.328749 | Recon=0.000418 | TrainAcc=0.7321
# Fold 6 → Acc=0.6556 | Prec=0.6301 | Rec=0.9200 | F1=0.7480 | AUC=0.8350 | CE Loss=0.5532
#
# === Fold 7 ===
# Train Control: 93, Train Patient: 116
# Fold 7 Epoch 1: TotalLoss=0.732298 | Sup=0.729306 | Recon=0.033245 | TrainAcc=0.4450
# Fold 7 Epoch 100: TotalLoss=0.524305 | Sup=0.524066 | Recon=0.002655 | TrainAcc=0.7512
# Fold 7 Epoch 200: TotalLoss=0.491321 | Sup=0.491223 | Recon=0.001084 | TrainAcc=0.7512
# Fold 7 Epoch 300: TotalLoss=0.463843 | Sup=0.463782 | Recon=0.000687 | TrainAcc=0.7799
# Fold 7 Epoch 400: TotalLoss=0.444324 | Sup=0.444275 | Recon=0.000547 | TrainAcc=0.7799
# Fold 7 Epoch 500: TotalLoss=0.439505 | Sup=0.439462 | Recon=0.000477 | TrainAcc=0.8086
# Fold 7 Epoch 600: TotalLoss=0.423838 | Sup=0.423798 | Recon=0.000439 | TrainAcc=0.8038
# Fold 7 Epoch 700: TotalLoss=0.422194 | Sup=0.422156 | Recon=0.000424 | TrainAcc=0.8182
# Fold 7 Epoch 800: TotalLoss=0.409760 | Sup=0.409721 | Recon=0.000423 | TrainAcc=0.8230
# Fold 7 Epoch 900: TotalLoss=0.406379 | Sup=0.406342 | Recon=0.000413 | TrainAcc=0.8230
# Fold 7 Epoch 1000: TotalLoss=0.399418 | Sup=0.399380 | Recon=0.000416 | TrainAcc=0.8134
# Fold 7 Epoch 1100: TotalLoss=0.393746 | Sup=0.393708 | Recon=0.000418 | TrainAcc=0.7847
# Fold 7 Epoch 1200: TotalLoss=0.382529 | Sup=0.382492 | Recon=0.000412 | TrainAcc=0.8182
# Fold 7 Epoch 1300: TotalLoss=0.372372 | Sup=0.372335 | Recon=0.000412 | TrainAcc=0.8230
# Fold 7 Epoch 1400: TotalLoss=0.373574 | Sup=0.373537 | Recon=0.000410 | TrainAcc=0.8230
# Fold 7 Epoch 1500: TotalLoss=0.366330 | Sup=0.366293 | Recon=0.000409 | TrainAcc=0.8182
# Fold 7 Epoch 1600: TotalLoss=0.356003 | Sup=0.355965 | Recon=0.000414 | TrainAcc=0.7751
# Fold 7 Epoch 1700: TotalLoss=0.354028 | Sup=0.353991 | Recon=0.000420 | TrainAcc=0.7177
# Fold 7 Epoch 1800: TotalLoss=0.346881 | Sup=0.346844 | Recon=0.000413 | TrainAcc=0.8421
# Fold 7 Epoch 1900: TotalLoss=0.331047 | Sup=0.331010 | Recon=0.000419 | TrainAcc=0.8230
# Fold 7 Epoch 2000: TotalLoss=0.333444 | Sup=0.333406 | Recon=0.000416 | TrainAcc=0.7273
# Fold 7 → Acc=0.7444 | Prec=0.7015 | Rec=0.9400 | F1=0.8034 | AUC=0.8130 | CE Loss=0.7780
#
# === Fold 8 ===
# Train Control: 93, Train Patient: 116
# Fold 8 Epoch 1: TotalLoss=0.705904 | Sup=0.703169 | Recon=0.030394 | TrainAcc=0.4545
# Fold 8 Epoch 100: TotalLoss=0.526282 | Sup=0.526052 | Recon=0.002553 | TrainAcc=0.7368
# Fold 8 Epoch 200: TotalLoss=0.489490 | Sup=0.489391 | Recon=0.001102 | TrainAcc=0.7512
# Fold 8 Epoch 300: TotalLoss=0.458924 | Sup=0.458855 | Recon=0.000759 | TrainAcc=0.7703
# Fold 8 Epoch 400: TotalLoss=0.431739 | Sup=0.431690 | Recon=0.000552 | TrainAcc=0.7990
# Fold 8 Epoch 500: TotalLoss=0.426241 | Sup=0.426197 | Recon=0.000489 | TrainAcc=0.8038
# Fold 8 Epoch 600: TotalLoss=0.399999 | Sup=0.399959 | Recon=0.000445 | TrainAcc=0.7943
# Fold 8 Epoch 700: TotalLoss=0.408061 | Sup=0.408023 | Recon=0.000425 | TrainAcc=0.8038
# Fold 8 Epoch 800: TotalLoss=0.379964 | Sup=0.379926 | Recon=0.000424 | TrainAcc=0.8182
# Fold 8 Epoch 900: TotalLoss=0.381497 | Sup=0.381459 | Recon=0.000417 | TrainAcc=0.7656
# Fold 8 Epoch 1000: TotalLoss=0.372565 | Sup=0.372528 | Recon=0.000416 | TrainAcc=0.8134
# Fold 8 Epoch 1100: TotalLoss=0.362903 | Sup=0.362866 | Recon=0.000414 | TrainAcc=0.7512
# Fold 8 Epoch 1200: TotalLoss=0.353631 | Sup=0.353594 | Recon=0.000413 | TrainAcc=0.8038
# Fold 8 Epoch 1300: TotalLoss=0.353745 | Sup=0.353707 | Recon=0.000420 | TrainAcc=0.8230
# Fold 8 Epoch 1400: TotalLoss=0.343002 | Sup=0.342965 | Recon=0.000415 | TrainAcc=0.8278
# Fold 8 Epoch 1500: TotalLoss=0.332339 | Sup=0.332302 | Recon=0.000414 | TrainAcc=0.7703
# Fold 8 Epoch 1600: TotalLoss=0.329497 | Sup=0.329459 | Recon=0.000418 | TrainAcc=0.7656
# Fold 8 Epoch 1700: TotalLoss=0.330092 | Sup=0.330055 | Recon=0.000415 | TrainAcc=0.8325
# Fold 8 Epoch 1800: TotalLoss=0.323985 | Sup=0.323947 | Recon=0.000420 | TrainAcc=0.8278
# Fold 8 Epoch 1900: TotalLoss=0.318618 | Sup=0.318581 | Recon=0.000416 | TrainAcc=0.7943
# Fold 8 Epoch 2000: TotalLoss=0.300900 | Sup=0.300863 | Recon=0.000421 | TrainAcc=0.8230
# Fold 8 → Acc=0.8000 | Prec=0.7963 | Rec=0.8600 | F1=0.8269 | AUC=0.9107 | CE Loss=0.3960
#
# === Fold 9 ===
# Train Control: 93, Train Patient: 116
# Fold 9 Epoch 1: TotalLoss=0.701782 | Sup=0.698831 | Recon=0.032787 | TrainAcc=0.5550
# Fold 9 Epoch 100: TotalLoss=0.520334 | Sup=0.520104 | Recon=0.002559 | TrainAcc=0.7321
# Fold 9 Epoch 200: TotalLoss=0.495638 | Sup=0.495530 | Recon=0.001201 | TrainAcc=0.7703
# Fold 9 Epoch 300: TotalLoss=0.469247 | Sup=0.469179 | Recon=0.000755 | TrainAcc=0.7560
# Fold 9 Epoch 400: TotalLoss=0.453147 | Sup=0.453096 | Recon=0.000564 | TrainAcc=0.7656
# Fold 9 Epoch 500: TotalLoss=0.442120 | Sup=0.442075 | Recon=0.000500 | TrainAcc=0.7799
# Fold 9 Epoch 600: TotalLoss=0.439310 | Sup=0.439269 | Recon=0.000453 | TrainAcc=0.7799
# Fold 9 Epoch 700: TotalLoss=0.438767 | Sup=0.438727 | Recon=0.000440 | TrainAcc=0.7847
# Fold 9 Epoch 800: TotalLoss=0.431422 | Sup=0.431382 | Recon=0.000443 | TrainAcc=0.7847
# Fold 9 Epoch 900: TotalLoss=0.420059 | Sup=0.420019 | Recon=0.000436 | TrainAcc=0.7799
# Fold 9 Epoch 1000: TotalLoss=0.420253 | Sup=0.420214 | Recon=0.000423 | TrainAcc=0.7751
# Fold 9 Epoch 1100: TotalLoss=0.401719 | Sup=0.401681 | Recon=0.000420 | TrainAcc=0.7608
# Fold 9 Epoch 1200: TotalLoss=0.406308 | Sup=0.406270 | Recon=0.000423 | TrainAcc=0.7703
# Fold 9 Epoch 1300: TotalLoss=0.390213 | Sup=0.390175 | Recon=0.000422 | TrainAcc=0.7847
# Fold 9 Epoch 1400: TotalLoss=0.381555 | Sup=0.381517 | Recon=0.000421 | TrainAcc=0.7895
# Fold 9 Epoch 1500: TotalLoss=0.373103 | Sup=0.373065 | Recon=0.000419 | TrainAcc=0.7895
# Fold 9 Epoch 1600: TotalLoss=0.362586 | Sup=0.362548 | Recon=0.000425 | TrainAcc=0.7608
# Fold 9 Epoch 1700: TotalLoss=0.358904 | Sup=0.358866 | Recon=0.000423 | TrainAcc=0.7943
# Fold 9 Epoch 1800: TotalLoss=0.353342 | Sup=0.353304 | Recon=0.000423 | TrainAcc=0.7943
# Fold 9 Epoch 1900: TotalLoss=0.335429 | Sup=0.335391 | Recon=0.000421 | TrainAcc=0.7560
# Fold 9 Epoch 2000: TotalLoss=0.337630 | Sup=0.337592 | Recon=0.000424 | TrainAcc=0.8038
# ...
# Fold 13 Epoch 1700: TotalLoss=0.373488 | Sup=0.371083 | Recon=0.000301 | TrainAcc=0.8086
# Fold 13 Epoch 1800: TotalLoss=0.372866 | Sup=0.370496 | Recon=0.000296 | TrainAcc=0.7943
# Fold 13 Epoch 1900: TotalLoss=0.363980 | Sup=0.361636 | Recon=0.000293 | TrainAcc=0.7990
# Fold 13 Epoch 2000: TotalLoss=0.360468 | Sup=0.358101 | Recon=0.000296 | TrainAcc=0.8086
# Fold 13 → Acc=0.7889 | Prec=0.8039 | Rec=0.8200 | F1=0.8119 | AUC=0.8880 | CE Loss=0.4135
#
# === Fold 14 ===
# Train Control: 93, Train Patient: 116
# Fold 14 Epoch 1: TotalLoss=0.941839 | Sup=0.682268 | Recon=0.032446 | TrainAcc=0.5550
# Fold 14 Epoch 100: TotalLoss=0.546890 | Sup=0.527557 | Recon=0.002417 | TrainAcc=0.7416
# Fold 14 Epoch 200: TotalLoss=0.519064 | Sup=0.508327 | Recon=0.001342 | TrainAcc=0.7464
# Fold 14 Epoch 300: TotalLoss=0.498238 | Sup=0.491981 | Recon=0.000782 | TrainAcc=0.7656
# Fold 14 Epoch 400: TotalLoss=0.473551 | Sup=0.468813 | Recon=0.000592 | TrainAcc=0.7751
# Fold 14 Epoch 500: TotalLoss=0.463009 | Sup=0.458751 | Recon=0.000532 | TrainAcc=0.7703
# Fold 14 Epoch 600: TotalLoss=0.451128 | Sup=0.447306 | Recon=0.000478 | TrainAcc=0.7656
# Fold 14 Epoch 700: TotalLoss=0.446711 | Sup=0.443226 | Recon=0.000436 | TrainAcc=0.7895
# Fold 14 Epoch 800: TotalLoss=0.434146 | Sup=0.431034 | Recon=0.000389 | TrainAcc=0.8086
# Fold 14 Epoch 900: TotalLoss=0.425709 | Sup=0.422707 | Recon=0.000375 | TrainAcc=0.7943
# Fold 14 Epoch 1000: TotalLoss=0.406980 | Sup=0.404078 | Recon=0.000363 | TrainAcc=0.7895
# Fold 14 Epoch 1100: TotalLoss=0.402701 | Sup=0.399877 | Recon=0.000353 | TrainAcc=0.8134
# Fold 14 Epoch 1200: TotalLoss=0.396516 | Sup=0.393800 | Recon=0.000340 | TrainAcc=0.8182
# Fold 14 Epoch 1300: TotalLoss=0.390150 | Sup=0.387543 | Recon=0.000326 | TrainAcc=0.7990
# Fold 14 Epoch 1400: TotalLoss=0.369533 | Sup=0.366982 | Recon=0.000319 | TrainAcc=0.8086
# Fold 14 Epoch 1500: TotalLoss=0.370054 | Sup=0.367497 | Recon=0.000320 | TrainAcc=0.8134
# Fold 14 Epoch 1600: TotalLoss=0.366711 | Sup=0.364211 | Recon=0.000313 | TrainAcc=0.7799
# Fold 14 Epoch 1700: TotalLoss=0.351758 | Sup=0.349293 | Recon=0.000308 | TrainAcc=0.8230
# Fold 14 Epoch 1800: TotalLoss=0.343792 | Sup=0.341389 | Recon=0.000300 | TrainAcc=0.7177
# Fold 14 Epoch 1900: TotalLoss=0.329736 | Sup=0.327341 | Recon=0.000299 | TrainAcc=0.8325
# Fold 14 Epoch 2000: TotalLoss=0.337367 | Sup=0.335006 | Recon=0.000295 | TrainAcc=0.8230
# Fold 14 → Acc=0.7778 | Prec=0.8125 | Rec=0.7800 | F1=0.7959 | AUC=0.8610 | CE Loss=0.6378
#
# === Fold 15 ===
# Train Control: 93, Train Patient: 116
# Fold 15 Epoch 1: TotalLoss=0.965335 | Sup=0.685421 | Recon=0.034989 | TrainAcc=0.5455
# Fold 15 Epoch 100: TotalLoss=0.570342 | Sup=0.552601 | Recon=0.002218 | TrainAcc=0.7321
# Fold 15 Epoch 200: TotalLoss=0.532026 | Sup=0.523617 | Recon=0.001051 | TrainAcc=0.7464
# Fold 15 Epoch 300: TotalLoss=0.506125 | Sup=0.500202 | Recon=0.000740 | TrainAcc=0.7608
# Fold 15 Epoch 400: TotalLoss=0.484933 | Sup=0.480338 | Recon=0.000574 | TrainAcc=0.7799
# Fold 15 Epoch 500: TotalLoss=0.476705 | Sup=0.472754 | Recon=0.000494 | TrainAcc=0.7608
# Fold 15 Epoch 600: TotalLoss=0.464289 | Sup=0.460747 | Recon=0.000443 | TrainAcc=0.7656
# Fold 15 Epoch 700: TotalLoss=0.456319 | Sup=0.453121 | Recon=0.000400 | TrainAcc=0.7751
# Fold 15 Epoch 800: TotalLoss=0.453705 | Sup=0.450690 | Recon=0.000377 | TrainAcc=0.7799
# Fold 15 Epoch 900: TotalLoss=0.435291 | Sup=0.432421 | Recon=0.000359 | TrainAcc=0.6986
# Fold 15 Epoch 1000: TotalLoss=0.430737 | Sup=0.427906 | Recon=0.000354 | TrainAcc=0.7847
# Fold 15 Epoch 1100: TotalLoss=0.425553 | Sup=0.422855 | Recon=0.000337 | TrainAcc=0.7943
# Fold 15 Epoch 1200: TotalLoss=0.410427 | Sup=0.407773 | Recon=0.000332 | TrainAcc=0.7847
# Fold 15 Epoch 1300: TotalLoss=0.401514 | Sup=0.398902 | Recon=0.000327 | TrainAcc=0.7177
# Fold 15 Epoch 1400: TotalLoss=0.394114 | Sup=0.391572 | Recon=0.000318 | TrainAcc=0.7943
# Fold 15 Epoch 1500: TotalLoss=0.389804 | Sup=0.387269 | Recon=0.000317 | TrainAcc=0.8038
# Fold 15 Epoch 1600: TotalLoss=0.375896 | Sup=0.373407 | Recon=0.000311 | TrainAcc=0.8182
# Fold 15 Epoch 1700: TotalLoss=0.365753 | Sup=0.363312 | Recon=0.000305 | TrainAcc=0.8038
# Fold 15 Epoch 1800: TotalLoss=0.364952 | Sup=0.362547 | Recon=0.000301 | TrainAcc=0.7273
# Fold 15 Epoch 1900: TotalLoss=0.350858 | Sup=0.348482 | Recon=0.000297 | TrainAcc=0.7368
# Fold 15 Epoch 2000: TotalLoss=0.336399 | Sup=0.334044 | Recon=0.000294 | TrainAcc=0.8038
# Fold 15 → Acc=0.8111 | Prec=0.8667 | Rec=0.7800 | F1=0.8211 | AUC=0.8880 | CE Loss=0.4364
#
# === Fold 16 ===
# Train Control: 93, Train Patient: 116
# Fold 16 Epoch 1: TotalLoss=1.001776 | Sup=0.747724 | Recon=0.031756 | TrainAcc=0.4450
# Fold 16 Epoch 100: TotalLoss=0.514148 | Sup=0.495453 | Recon=0.002337 | TrainAcc=0.7847
# Fold 16 Epoch 200: TotalLoss=0.478680 | Sup=0.470724 | Recon=0.000995 | TrainAcc=0.7895
# Fold 16 Epoch 300: TotalLoss=0.454866 | Sup=0.449025 | Recon=0.000730 | TrainAcc=0.8086
# Fold 16 Epoch 400: TotalLoss=0.438415 | Sup=0.433543 | Recon=0.000609 | TrainAcc=0.8038
# Fold 16 Epoch 500: TotalLoss=0.424437 | Sup=0.420133 | Recon=0.000538 | TrainAcc=0.8086
# Fold 16 Epoch 600: TotalLoss=0.413373 | Sup=0.409574 | Recon=0.000475 | TrainAcc=0.8086
# Fold 16 Epoch 700: TotalLoss=0.402084 | Sup=0.398734 | Recon=0.000419 | TrainAcc=0.8134
# Fold 16 Epoch 800: TotalLoss=0.404755 | Sup=0.401585 | Recon=0.000396 | TrainAcc=0.8230
# Fold 16 Epoch 900: TotalLoss=0.399881 | Sup=0.396966 | Recon=0.000364 | TrainAcc=0.8230
# Fold 16 Epoch 1000: TotalLoss=0.393790 | Sup=0.390976 | Recon=0.000352 | TrainAcc=0.8325
# Fold 16 Epoch 1100: TotalLoss=0.386443 | Sup=0.383702 | Recon=0.000343 | TrainAcc=0.8230
# Fold 16 Epoch 1200: TotalLoss=0.385936 | Sup=0.383236 | Recon=0.000338 | TrainAcc=0.8182
# Fold 16 Epoch 1300: TotalLoss=0.369097 | Sup=0.366370 | Recon=0.000341 | TrainAcc=0.8230
# Fold 16 Epoch 1400: TotalLoss=0.360790 | Sup=0.358215 | Recon=0.000322 | TrainAcc=0.8230
# Fold 16 Epoch 1500: TotalLoss=0.354113 | Sup=0.351581 | Recon=0.000316 | TrainAcc=0.8325
# Fold 16 Epoch 1600: TotalLoss=0.340125 | Sup=0.337633 | Recon=0.000312 | TrainAcc=0.8373
# Fold 16 Epoch 1700: TotalLoss=0.337726 | Sup=0.335138 | Recon=0.000324 | TrainAcc=0.8325
# Fold 16 Epoch 1800: TotalLoss=0.335253 | Sup=0.332795 | Recon=0.000307 | TrainAcc=0.7943
# Fold 16 Epoch 1900: TotalLoss=0.334569 | Sup=0.332136 | Recon=0.000304 | TrainAcc=0.7751
# Fold 16 Epoch 2000: TotalLoss=0.316580 | Sup=0.314164 | Recon=0.000302 | TrainAcc=0.8517
# Fold 16 → Acc=0.8556 | Prec=0.9111 | Rec=0.8200 | F1=0.8632 | AUC=0.9030 | CE Loss=0.3735
#
# === Fold 17 ===
# Train Control: 93, Train Patient: 116
# Fold 17 Epoch 1: TotalLoss=0.994500 | Sup=0.733529 | Recon=0.032621 | TrainAcc=0.5502
# Fold 17 Epoch 100: TotalLoss=0.549851 | Sup=0.532554 | Recon=0.002162 | TrainAcc=0.7273
# Fold 17 Epoch 200: TotalLoss=0.506506 | Sup=0.499549 | Recon=0.000870 | TrainAcc=0.7368
# Fold 17 Epoch 300: TotalLoss=0.480403 | Sup=0.474509 | Recon=0.000737 | TrainAcc=0.7321
# Fold 17 Epoch 400: TotalLoss=0.454448 | Sup=0.449810 | Recon=0.000580 | TrainAcc=0.7416
# Fold 17 Epoch 500: TotalLoss=0.442195 | Sup=0.438439 | Recon=0.000470 | TrainAcc=0.7703
# Fold 17 Epoch 600: TotalLoss=0.434051 | Sup=0.430784 | Recon=0.000408 | TrainAcc=0.7703
# Fold 17 Epoch 700: TotalLoss=0.428141 | Sup=0.425076 | Recon=0.000383 | TrainAcc=0.7799
# Fold 17 Epoch 800: TotalLoss=0.412541 | Sup=0.409560 | Recon=0.000373 | TrainAcc=0.7895
# Fold 17 Epoch 900: TotalLoss=0.399071 | Sup=0.396168 | Recon=0.000363 | TrainAcc=0.7847
# Fold 17 Epoch 1000: TotalLoss=0.391854 | Sup=0.389109 | Recon=0.000343 | TrainAcc=0.8278
# Fold 17 Epoch 1100: TotalLoss=0.373364 | Sup=0.370675 | Recon=0.000336 | TrainAcc=0.8086
# Fold 17 Epoch 1200: TotalLoss=0.374687 | Sup=0.372085 | Recon=0.000325 | TrainAcc=0.8038
# Fold 17 Epoch 1300: TotalLoss=0.354282 | Sup=0.351712 | Recon=0.000321 | TrainAcc=0.8038
# Fold 17 Epoch 1400: TotalLoss=0.352934 | Sup=0.350443 | Recon=0.000311 | TrainAcc=0.7990
# Fold 17 Epoch 1500: TotalLoss=0.346653 | Sup=0.344157 | Recon=0.000312 | TrainAcc=0.8086
# Fold 17 Epoch 1600: TotalLoss=0.335189 | Sup=0.332710 | Recon=0.000310 | TrainAcc=0.7990
# Fold 17 Epoch 1700: TotalLoss=0.321743 | Sup=0.319312 | Recon=0.000304 | TrainAcc=0.8230
# Fold 17 Epoch 1800: TotalLoss=0.309743 | Sup=0.307348 | Recon=0.000299 | TrainAcc=0.8134
# Fold 17 Epoch 1900: TotalLoss=0.305449 | Sup=0.303057 | Recon=0.000299 | TrainAcc=0.8517
# Fold 17 Epoch 2000: TotalLoss=0.301341 | Sup=0.299014 | Recon=0.000291 | TrainAcc=0.7703
# Fold 17 → Acc=0.7889 | Prec=0.7385 | Rec=0.9600 | F1=0.8348 | AUC=0.9050 | CE Loss=0.4692
#
# === Fold 18 ===
# Train Control: 93, Train Patient: 116
# Fold 18 Epoch 1: TotalLoss=1.037754 | Sup=0.747640 | Recon=0.036264 | TrainAcc=0.5550
# Fold 18 Epoch 100: TotalLoss=0.533315 | Sup=0.515190 | Recon=0.002266 | TrainAcc=0.7512
# Fold 18 Epoch 200: TotalLoss=0.509013 | Sup=0.501250 | Recon=0.000970 | TrainAcc=0.7656
# Fold 18 Epoch 300: TotalLoss=0.485567 | Sup=0.479740 | Recon=0.000728 | TrainAcc=0.7656
# Fold 18 Epoch 400: TotalLoss=0.463307 | Sup=0.458620 | Recon=0.000586 | TrainAcc=0.7703
# Fold 18 Epoch 500: TotalLoss=0.455706 | Sup=0.451738 | Recon=0.000496 | TrainAcc=0.7847
# Fold 18 Epoch 600: TotalLoss=0.442375 | Sup=0.438970 | Recon=0.000426 | TrainAcc=0.8038
# Fold 18 Epoch 700: TotalLoss=0.428094 | Sup=0.424960 | Recon=0.000392 | TrainAcc=0.7895
# Fold 18 Epoch 800: TotalLoss=0.419696 | Sup=0.416701 | Recon=0.000374 | TrainAcc=0.8086
# Fold 18 Epoch 900: TotalLoss=0.421625 | Sup=0.418704 | Recon=0.000365 | TrainAcc=0.8038
# Fold 18 Epoch 1000: TotalLoss=0.413626 | Sup=0.410774 | Recon=0.000356 | TrainAcc=0.8134
# Fold 18 Epoch 1100: TotalLoss=0.407098 | Sup=0.404368 | Recon=0.000341 | TrainAcc=0.7847
# Fold 18 Epoch 1200: TotalLoss=0.401413 | Sup=0.398758 | Recon=0.000332 | TrainAcc=0.8086
# Fold 18 Epoch 1300: TotalLoss=0.395017 | Sup=0.392377 | Recon=0.000330 | TrainAcc=0.7895
# Fold 18 Epoch 1400: TotalLoss=0.396176 | Sup=0.393565 | Recon=0.000326 | TrainAcc=0.7033
# Fold 18 Epoch 1500: TotalLoss=0.382295 | Sup=0.379736 | Recon=0.000320 | TrainAcc=0.7990
# Fold 18 Epoch 1600: TotalLoss=0.378558 | Sup=0.376045 | Recon=0.000314 | TrainAcc=0.7895
# Fold 18 Epoch 1700: TotalLoss=0.370990 | Sup=0.368536 | Recon=0.000307 | TrainAcc=0.8038
# Fold 18 Epoch 1800: TotalLoss=0.371569 | Sup=0.369117 | Recon=0.000306 | TrainAcc=0.7608
# Fold 18 Epoch 1900: TotalLoss=0.350994 | Sup=0.348583 | Recon=0.000301 | TrainAcc=0.8182
# Fold 18 Epoch 2000: TotalLoss=0.360161 | Sup=0.357777 | Recon=0.000298 | TrainAcc=0.8086
# Fold 18 → Acc=0.8000 | Prec=0.8478 | Rec=0.7800 | F1=0.8125 | AUC=0.8615 | CE Loss=0.4565
#
# === Fold 19 ===
# Train Control: 93, Train Patient: 116
# Fold 19 Epoch 1: TotalLoss=1.050685 | Sup=0.764444 | Recon=0.035780 | TrainAcc=0.5502
# Fold 19 Epoch 100: TotalLoss=0.529594 | Sup=0.510149 | Recon=0.002431 | TrainAcc=0.7560
# Fold 19 Epoch 200: TotalLoss=0.485568 | Sup=0.475989 | Recon=0.001197 | TrainAcc=0.7703
# Fold 19 Epoch 300: TotalLoss=0.458740 | Sup=0.452866 | Recon=0.000734 | TrainAcc=0.7656
# Fold 19 Epoch 400: TotalLoss=0.436329 | Sup=0.431487 | Recon=0.000605 | TrainAcc=0.7990
# Fold 19 Epoch 500: TotalLoss=0.428909 | Sup=0.424701 | Recon=0.000526 | TrainAcc=0.8086
# Fold 19 Epoch 600: TotalLoss=0.416569 | Sup=0.412999 | Recon=0.000446 | TrainAcc=0.7990
# Fold 19 Epoch 700: TotalLoss=0.412876 | Sup=0.409742 | Recon=0.000392 | TrainAcc=0.8182
# Fold 19 Epoch 800: TotalLoss=0.405488 | Sup=0.402475 | Recon=0.000377 | TrainAcc=0.8134
# Fold 19 Epoch 900: TotalLoss=0.396539 | Sup=0.393657 | Recon=0.000360 | TrainAcc=0.8182
# Fold 19 Epoch 1000: TotalLoss=0.383352 | Sup=0.380557 | Recon=0.000349 | TrainAcc=0.8565
# Fold 19 Epoch 1100: TotalLoss=0.382579 | Sup=0.379844 | Recon=0.000342 | TrainAcc=0.8517
# Fold 19 Epoch 1200: TotalLoss=0.366755 | Sup=0.364070 | Recon=0.000336 | TrainAcc=0.7943
# Fold 19 Epoch 1300: TotalLoss=0.367800 | Sup=0.365261 | Recon=0.000317 | TrainAcc=0.8278
# Fold 19 Epoch 1400: TotalLoss=0.370359 | Sup=0.367821 | Recon=0.000317 | TrainAcc=0.7943
# Fold 19 Epoch 1500: TotalLoss=0.354375 | Sup=0.351867 | Recon=0.000314 | TrainAcc=0.7990
# Fold 19 Epoch 1600: TotalLoss=0.343959 | Sup=0.341498 | Recon=0.000308 | TrainAcc=0.7847
# Fold 19 Epoch 1700: TotalLoss=0.339915 | Sup=0.337449 | Recon=0.000308 | TrainAcc=0.8086
# Fold 19 Epoch 1800: TotalLoss=0.341067 | Sup=0.338656 | Recon=0.000301 | TrainAcc=0.7895
# Fold 19 Epoch 1900: TotalLoss=0.328942 | Sup=0.326569 | Recon=0.000297 | TrainAcc=0.7512
# Fold 19 Epoch 2000: TotalLoss=0.327769 | Sup=0.325373 | Recon=0.000299 | TrainAcc=0.7129
# Fold 19 → Acc=0.7111 | Prec=0.6579 | Rec=1.0000 | F1=0.7937 | AUC=0.8690 | CE Loss=0.6130
#
# === Fold 20 ===
# Train Control: 93, Train Patient: 116
# Fold 20 Epoch 1: TotalLoss=1.017685 | Sup=0.761740 | Recon=0.031993 | TrainAcc=0.4450
# Fold 20 Epoch 100: TotalLoss=0.535218 | Sup=0.516018 | Recon=0.002400 | TrainAcc=0.7751
# Fold 20 Epoch 200: TotalLoss=0.476245 | Sup=0.467126 | Recon=0.001140 | TrainAcc=0.7799
# Fold 20 Epoch 300: TotalLoss=0.445484 | Sup=0.439393 | Recon=0.000761 | TrainAcc=0.7943
# Fold 20 Epoch 400: TotalLoss=0.419439 | Sup=0.414289 | Recon=0.000644 | TrainAcc=0.8038
# Fold 20 Epoch 500: TotalLoss=0.417180 | Sup=0.413064 | Recon=0.000514 | TrainAcc=0.8086
# Fold 20 Epoch 600: TotalLoss=0.395149 | Sup=0.391465 | Recon=0.000461 | TrainAcc=0.8086
# Fold 20 Epoch 700: TotalLoss=0.396662 | Sup=0.393317 | Recon=0.000418 | TrainAcc=0.8182
# Fold 20 Epoch 800: TotalLoss=0.384005 | Sup=0.380889 | Recon=0.000390 | TrainAcc=0.8134
# Fold 20 Epoch 900: TotalLoss=0.371768 | Sup=0.368796 | Recon=0.000371 | TrainAcc=0.8182
# Fold 20 Epoch 1000: TotalLoss=0.375498 | Sup=0.372589 | Recon=0.000364 | TrainAcc=0.8278
# Fold 20 Epoch 1100: TotalLoss=0.364891 | Sup=0.362046 | Recon=0.000356 | TrainAcc=0.8278
# Fold 20 Epoch 1200: TotalLoss=0.347564 | Sup=0.344810 | Recon=0.000344 | TrainAcc=0.8278
# Fold 20 Epoch 1300: TotalLoss=0.351102 | Sup=0.348482 | Recon=0.000328 | TrainAcc=0.7512
# Fold 20 Epoch 1400: TotalLoss=0.342748 | Sup=0.340149 | Recon=0.000325 | TrainAcc=0.8325
# Fold 20 Epoch 1500: TotalLoss=0.331584 | Sup=0.329054 | Recon=0.000316 | TrainAcc=0.8325
# Fold 20 Epoch 1600: TotalLoss=0.329031 | Sup=0.326535 | Recon=0.000312 | TrainAcc=0.8373
# Fold 20 Epoch 1700: TotalLoss=0.327127 | Sup=0.324669 | Recon=0.000307 | TrainAcc=0.8373
# Fold 20 Epoch 1800: TotalLoss=0.314781 | Sup=0.312294 | Recon=0.000311 | TrainAcc=0.8517
# Fold 20 Epoch 1900: TotalLoss=0.316591 | Sup=0.314180 | Recon=0.000301 | TrainAcc=0.8373
# Fold 20 Epoch 2000: TotalLoss=0.312192 | Sup=0.309799 | Recon=0.000299 | TrainAcc=0.8182
# Fold 20 → Acc=0.7333 | Prec=0.8611 | Rec=0.6200 | F1=0.7209 | AUC=0.8865 | CE Loss=0.5010
#
# === Average Results for λ = 8 ===
# Accuracy:  0.7850
# Precision: 0.8214
# Recall:    0.7980
# F1-score:  0.8039
# CE Loss:   0.4874
# AUC:       0.8718
#
#
# ====================== FINAL SUMMARY ACROSS ALL λ ======================
# Lambda   | Accuracy  | Precision | Recall   | F1-score  | AUC      | CE Loss
# ------------------------------------------------------------------------
# 0.001    | 0.7594    | 0.7872    | 0.8170   | 0.7884    | 0.8669   | 0.5154
# 0.005    | 0.7550    | 0.7705    | 0.8290   | 0.7896    | 0.8672   | 0.5102
# 0.009    | 0.7456    | 0.7500    | 0.8610   | 0.7921    | 0.8702   | 0.5481
# 0.01     | 0.7539    | 0.7937    | 0.7900   | 0.7756    | 0.8693   | 0.5173
# 0.05     | 0.7633    | 0.7772    | 0.8410   | 0.7985    | 0.8678   | 0.5225
# 0.09     | 0.7539    | 0.7572    | 0.8610   | 0.7974    | 0.8673   | 0.5258
# 0.1      | 0.7728    | 0.8061    | 0.8080   | 0.7988    | 0.8695   | 0.4954
# 0.3      | 0.7633    | 0.7837    | 0.8270   | 0.7940    | 0.8715   | 0.4996
# 0.5      | 0.7694    | 0.7924    | 0.8310   | 0.8000    | 0.8706   | 0.5129
# 0.9      | 0.7567    | 0.7876    | 0.8070   | 0.7844    | 0.8684   | 0.5175
# 1        | 0.7756    | 0.8146    | 0.7990   | 0.7976    | 0.8722   | 0.4928
# 2        | 0.7500    | 0.7699    | 0.8240   | 0.7862    | 0.8679   | 0.5152
# 5        | 0.7772    | 0.7914    | 0.8330   | 0.8055    | 0.8696   | 0.4884
# 8        | 0.7850    | 0.8214    | 0.7980   | 0.8039    | 0.8718   | 0.4874
