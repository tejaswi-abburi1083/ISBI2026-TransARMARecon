# %%
import torch
import torch.nn as nn
import torch.nn.functional as nnFn
import torch.optim as optim
import numpy as np
import random
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from torch_geometric.data import Data
from torch_geometric.nn import ChebConv
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score,
    f1_score, roc_auc_score, log_loss
)

# %%
fa_feature_path = "/home/snu/Downloads/Histogram_CN_FA_20bin_updated.npy"
Histogram_feature_CN_FA_array = np.load(fa_feature_path, allow_pickle=True)

fa_feature_path = "/home/snu/Downloads/Histogram_MCI_FA_20bin_updated.npy"
Histogram_feature_MCI_FA_array = np.load(fa_feature_path, allow_pickle=True)

X = np.vstack([Histogram_feature_CN_FA_array, Histogram_feature_MCI_FA_array])
y = np.hstack([
    np.zeros(Histogram_feature_CN_FA_array.shape[0], dtype=np.int64),
    np.ones(Histogram_feature_MCI_FA_array.shape[0], dtype=np.int64)
])

num_nodes, num_feats = X.shape
print(f"Features: {X.shape}, Labels: {y.shape}")
# Out:
# Features: (300, 180), Labels: (300,)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch_geometric.nn import ChebConv

class Cheb_Supervised(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim, K=3, activ="SELU"):
        super(Cheb_Supervised, self).__init__()
        self.conv1 = ChebConv(input_dim, hidden_dim, K=K)
        self.bn1 = nn.BatchNorm1d(hidden_dim)
        self.dropout = nn.Dropout(0.2)
        self.fc = nn.Linear(hidden_dim, output_dim)
        activations = {
            "SELU": F.selu,
            "SiLU": F.silu,
            "GELU": F.gelu,
            "RELU": F.relu,
            "ELU": F.elu
        }
        self.act = activations.get(activ, F.elu)

    def forward(self, data):
        x, edge_index = data.x, data.edge_index
        x = self.conv1(x, edge_index)
        x = self.bn1(x)
        x = self.act(x)
        x = self.dropout(x)
        logits = self.fc(x)
        return logits

# %%
def create_adj(F, alpha=1):
    F_norm = F / np.linalg.norm(F, axis=1, keepdims=True)
    W = np.dot(F_norm, F_norm.T)
    W = np.where(W >= alpha, 1, 0).astype(np.float32)
    W = W / W.max()
    return W

def load_data(adj, node_feats):
    node_feats = torch.from_numpy(node_feats).float()
    edge_index = torch.from_numpy(np.array(np.nonzero((adj > 0))))
    return Data(x=node_feats, edge_index=edge_index)

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
alpha = 0.92
feats_dim = num_feats
hidden_dim = 512
num_classes = 2
num_epochs = 2000
lr = 0.0001
weight_decay = 1e-4
batch_print_freq = 100
lambda_mod = 0.005 #0.01  # weight for modularity loss
# lambda_sup = 5

# %%
W = create_adj(X, alpha)
data = load_data(W, X).to(device)
A_tensor = torch.from_numpy(W).float().to(device)
print(data)
# Out:
# Data(x=[300, 180], edge_index=[2, 13604])

# %%
sss = StratifiedShuffleSplit(n_splits=20, test_size=0.3, random_state=42)

accuracies, precisions, recalls, f1_scores, aucs, ce_losses = [], [], [], [], [], []

for fold, (train_idx, test_idx) in enumerate(sss.split(X, y), start=1):
    print(f"\n=== Fold {fold} ===")

    train_idx_t = torch.from_numpy(train_idx).long().to(device)
    y_train_tensor = torch.from_numpy(y[train_idx]).long().to(device)

    model = Cheb_Supervised(feats_dim, hidden_dim, num_classes, K=3, activ="SELU").to(device)
    optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
    ce_loss = nn.CrossEntropyLoss()


    for epoch in range(1, num_epochs + 1):
        model.train()
        optimizer.zero_grad()

        logits = model(data)
        loss = ce_loss(logits[train_idx_t], y_train_tensor)
        loss.backward()
        optimizer.step()

        if epoch % batch_print_freq == 0 or epoch == 1:
            model.eval()
            with torch.no_grad():
                preds_train = logits[train_idx_t].argmax(dim=1)
                acc_train = accuracy_score(y_train_tensor.cpu(), preds_train.cpu())
            print(f"Fold {fold} Epoch {epoch}: "
                  f"Loss={loss.item():.6f} | TrainAcc={acc_train:.4f}")


    model.eval()
    with torch.no_grad():
        out = model(data)
        preds = out.argmax(dim=1).cpu().numpy()
        probs = torch.softmax(out, dim=1)[:, 1].cpu().numpy()  # Probability for class 1

    y_test = y[test_idx]
    y_pred_test = preds[test_idx]
    y_prob_test = probs[test_idx]


    acc = accuracy_score(y_test, y_pred_test)
    prec = precision_score(y_test, y_pred_test, zero_division=0)
    rec = recall_score(y_test, y_pred_test, zero_division=0)
    f1 = f1_score(y_test, y_pred_test, zero_division=0)
    auc = roc_auc_score(y_test, y_prob_test)
    ce = log_loss(y_test, y_prob_test)

    accuracies.append(acc)
    precisions.append(prec)
    recalls.append(rec)
    f1_scores.append(f1)
    aucs.append(auc)
    ce_losses.append(ce)

    print(f"Fold {fold} → "
          f"Acc={acc:.4f} | Prec={prec:.4f} | Rec={rec:.4f} | "
          f"F1={f1:.4f} | AUC={auc:.4f} | CE Loss={ce:.4f}")


print("\n=== Average Results Across 20 Folds ===")
print(f"Accuracy:  {np.mean(accuracies):.4f} ± {np.std(accuracies):.4f}")
print(f"Precision: {np.mean(precisions):.4f} ± {np.std(precisions):.4f}")
print(f"Recall:    {np.mean(recalls):.4f} ± {np.std(recalls):.4f}")
print(f"F1-score:  {np.mean(f1_scores):.4f} ± {np.std(f1_scores):.4f}")
print(f"CE Loss:   {np.mean(ce_losses):.4f} ± {np.std(ce_losses):.4f}")
print(f"AUC:       {np.mean(aucs):.4f} ± {np.std(aucs):.4f}")
# Out:
# === Fold 1 ===
# Fold 1 Epoch 1: Loss=0.641606 | TrainAcc=0.6429
# Fold 1 Epoch 100: Loss=0.178384 | TrainAcc=0.9571
# Fold 1 Epoch 200: Loss=0.073294 | TrainAcc=0.9952
# Fold 1 Epoch 300: Loss=0.032816 | TrainAcc=1.0000
# Fold 1 Epoch 400: Loss=0.015444 | TrainAcc=1.0000
# Fold 1 Epoch 500: Loss=0.009744 | TrainAcc=1.0000
# Fold 1 Epoch 600: Loss=0.007209 | TrainAcc=1.0000
# Fold 1 Epoch 700: Loss=0.004208 | TrainAcc=1.0000
# Fold 1 Epoch 800: Loss=0.003324 | TrainAcc=1.0000
# Fold 1 Epoch 900: Loss=0.002669 | TrainAcc=1.0000
# Fold 1 Epoch 1000: Loss=0.002081 | TrainAcc=1.0000
# Fold 1 Epoch 1100: Loss=0.001713 | TrainAcc=1.0000
# Fold 1 Epoch 1200: Loss=0.001536 | TrainAcc=1.0000
# Fold 1 Epoch 1300: Loss=0.001246 | TrainAcc=1.0000
# Fold 1 Epoch 1400: Loss=0.001126 | TrainAcc=1.0000
# Fold 1 Epoch 1500: Loss=0.000762 | TrainAcc=1.0000
# Fold 1 Epoch 1600: Loss=0.000882 | TrainAcc=1.0000
# Fold 1 Epoch 1700: Loss=0.000650 | TrainAcc=1.0000
# Fold 1 Epoch 1800: Loss=0.000678 | TrainAcc=1.0000
# Fold 1 Epoch 1900: Loss=0.000646 | TrainAcc=1.0000
# Fold 1 Epoch 2000: Loss=0.000556 | TrainAcc=1.0000
# Fold 1 → Acc=0.7556 | Prec=0.7800 | Rec=0.7800 | F1=0.7800 | AUC=0.8140 | CE Loss=1.7472
#
# === Fold 2 ===
# Fold 2 Epoch 1: Loss=0.784691 | TrainAcc=0.5048
# Fold 2 Epoch 100: Loss=0.231128 | TrainAcc=0.9238
# Fold 2 Epoch 200: Loss=0.114158 | TrainAcc=0.9810
# Fold 2 Epoch 300: Loss=0.056406 | TrainAcc=0.9952
# Fold 2 Epoch 400: Loss=0.027304 | TrainAcc=1.0000
# Fold 2 Epoch 500: Loss=0.016746 | TrainAcc=1.0000
# Fold 2 Epoch 600: Loss=0.010072 | TrainAcc=1.0000
# Fold 2 Epoch 700: Loss=0.006942 | TrainAcc=1.0000
# Fold 2 Epoch 800: Loss=0.005419 | TrainAcc=1.0000
# Fold 2 Epoch 900: Loss=0.003743 | TrainAcc=1.0000
# Fold 2 Epoch 1000: Loss=0.002585 | TrainAcc=1.0000
# Fold 2 Epoch 1100: Loss=0.002421 | TrainAcc=1.0000
# Fold 2 Epoch 1200: Loss=0.002226 | TrainAcc=1.0000
# Fold 2 Epoch 1300: Loss=0.001627 | TrainAcc=1.0000
# Fold 2 Epoch 1400: Loss=0.001801 | TrainAcc=1.0000
# Fold 2 Epoch 1500: Loss=0.001226 | TrainAcc=1.0000
# Fold 2 Epoch 1600: Loss=0.001114 | TrainAcc=1.0000
# Fold 2 Epoch 1700: Loss=0.001446 | TrainAcc=1.0000
# Fold 2 Epoch 1800: Loss=0.001006 | TrainAcc=1.0000
# Fold 2 Epoch 1900: Loss=0.000858 | TrainAcc=1.0000
# Fold 2 Epoch 2000: Loss=0.000783 | TrainAcc=1.0000
# Fold 2 → Acc=0.8000 | Prec=0.8200 | Rec=0.8200 | F1=0.8200 | AUC=0.8413 | CE Loss=1.5164
#
# === Fold 3 ===
# Fold 3 Epoch 1: Loss=0.755131 | TrainAcc=0.4857
# Fold 3 Epoch 100: Loss=0.185866 | TrainAcc=0.9429
# Fold 3 Epoch 200: Loss=0.088234 | TrainAcc=0.9905
# Fold 3 Epoch 300: Loss=0.038016 | TrainAcc=1.0000
# Fold 3 Epoch 400: Loss=0.021074 | TrainAcc=1.0000
# Fold 3 Epoch 500: Loss=0.012624 | TrainAcc=1.0000
# Fold 3 Epoch 600: Loss=0.008212 | TrainAcc=1.0000
# Fold 3 Epoch 700: Loss=0.005644 | TrainAcc=1.0000
# Fold 3 Epoch 800: Loss=0.004233 | TrainAcc=1.0000
# Fold 3 Epoch 900: Loss=0.003394 | TrainAcc=1.0000
# Fold 3 Epoch 1000: Loss=0.002294 | TrainAcc=1.0000
# Fold 3 Epoch 1100: Loss=0.002230 | TrainAcc=1.0000
# Fold 3 Epoch 1200: Loss=0.001983 | TrainAcc=1.0000
# Fold 3 Epoch 1300: Loss=0.001560 | TrainAcc=1.0000
# Fold 3 Epoch 1400: Loss=0.001194 | TrainAcc=1.0000
# Fold 3 Epoch 1500: Loss=0.001022 | TrainAcc=1.0000
# Fold 3 Epoch 1600: Loss=0.001033 | TrainAcc=1.0000
# Fold 3 Epoch 1700: Loss=0.000972 | TrainAcc=1.0000
# Fold 3 Epoch 1800: Loss=0.000846 | TrainAcc=1.0000
# Fold 3 Epoch 1900: Loss=0.000763 | TrainAcc=1.0000
# Fold 3 Epoch 2000: Loss=0.000713 | TrainAcc=1.0000
# Fold 3 → Acc=0.7444 | Prec=0.7647 | Rec=0.7800 | F1=0.7723 | AUC=0.8433 | CE Loss=1.3983
#
# === Fold 4 ===
# Fold 4 Epoch 1: Loss=0.747106 | TrainAcc=0.5143
# Fold 4 Epoch 100: Loss=0.178004 | TrainAcc=0.9667
# Fold 4 Epoch 200: Loss=0.082187 | TrainAcc=0.9905
# Fold 4 Epoch 300: Loss=0.031868 | TrainAcc=1.0000
# Fold 4 Epoch 400: Loss=0.017684 | TrainAcc=1.0000
# Fold 4 Epoch 500: Loss=0.008724 | TrainAcc=1.0000
# Fold 4 Epoch 600: Loss=0.007192 | TrainAcc=1.0000
# Fold 4 Epoch 700: Loss=0.004616 | TrainAcc=1.0000
# Fold 4 Epoch 800: Loss=0.003632 | TrainAcc=1.0000
# Fold 4 Epoch 900: Loss=0.002470 | TrainAcc=1.0000
# Fold 4 Epoch 1000: Loss=0.002284 | TrainAcc=1.0000
# Fold 4 Epoch 1100: Loss=0.001522 | TrainAcc=1.0000
# Fold 4 Epoch 1200: Loss=0.001346 | TrainAcc=1.0000
# Fold 4 Epoch 1300: Loss=0.001158 | TrainAcc=1.0000
# Fold 4 Epoch 1400: Loss=0.001068 | TrainAcc=1.0000
# Fold 4 Epoch 1500: Loss=0.000935 | TrainAcc=1.0000
# Fold 4 Epoch 1600: Loss=0.001216 | TrainAcc=1.0000
# Fold 4 Epoch 1700: Loss=0.000782 | TrainAcc=1.0000
# Fold 4 Epoch 1800: Loss=0.000651 | TrainAcc=1.0000
# Fold 4 Epoch 1900: Loss=0.000712 | TrainAcc=1.0000
# Fold 4 Epoch 2000: Loss=0.000674 | TrainAcc=1.0000
# Fold 4 → Acc=0.7222 | Prec=0.7551 | Rec=0.7400 | F1=0.7475 | AUC=0.7985 | CE Loss=1.7479
#
# === Fold 5 ===
# Fold 5 Epoch 1: Loss=0.939272 | TrainAcc=0.3429
# Fold 5 Epoch 100: Loss=0.206599 | TrainAcc=0.9429
# Fold 5 Epoch 200: Loss=0.089074 | TrainAcc=0.9905
# Fold 5 Epoch 300: Loss=0.037977 | TrainAcc=1.0000
# Fold 5 Epoch 400: Loss=0.021927 | TrainAcc=1.0000
# Fold 5 Epoch 500: Loss=0.013837 | TrainAcc=1.0000
# Fold 5 Epoch 600: Loss=0.008415 | TrainAcc=1.0000
# Fold 5 Epoch 700: Loss=0.005426 | TrainAcc=1.0000
# Fold 5 Epoch 800: Loss=0.004365 | TrainAcc=1.0000
# Fold 5 Epoch 900: Loss=0.003606 | TrainAcc=1.0000
# Fold 5 Epoch 1000: Loss=0.002540 | TrainAcc=1.0000
# Fold 5 Epoch 1100: Loss=0.002018 | TrainAcc=1.0000
# Fold 5 Epoch 1200: Loss=0.001608 | TrainAcc=1.0000
# Fold 5 Epoch 1300: Loss=0.001620 | TrainAcc=1.0000
# Fold 5 Epoch 1400: Loss=0.001196 | TrainAcc=1.0000
# Fold 5 Epoch 1500: Loss=0.001179 | TrainAcc=1.0000
# Fold 5 Epoch 1600: Loss=0.001076 | TrainAcc=1.0000
# Fold 5 Epoch 1700: Loss=0.000904 | TrainAcc=1.0000
# Fold 5 Epoch 1800: Loss=0.000830 | TrainAcc=1.0000
# Fold 5 Epoch 1900: Loss=0.000670 | TrainAcc=1.0000
# Fold 5 Epoch 2000: Loss=0.000780 | TrainAcc=1.0000
# Fold 5 → Acc=0.7556 | Prec=0.7692 | Rec=0.8000 | F1=0.7843 | AUC=0.8083 | CE Loss=1.5307
#
# === Fold 6 ===
# Fold 6 Epoch 1: Loss=0.720811 | TrainAcc=0.5762
# Fold 6 Epoch 100: Loss=0.155519 | TrainAcc=0.9524
# Fold 6 Epoch 200: Loss=0.058611 | TrainAcc=1.0000
# Fold 6 Epoch 300: Loss=0.023889 | TrainAcc=1.0000
# Fold 6 Epoch 400: Loss=0.014368 | TrainAcc=1.0000
# Fold 6 Epoch 500: Loss=0.007735 | TrainAcc=1.0000
# Fold 6 Epoch 600: Loss=0.004677 | TrainAcc=1.0000
# Fold 6 Epoch 700: Loss=0.003242 | TrainAcc=1.0000
# Fold 6 Epoch 800: Loss=0.003107 | TrainAcc=1.0000
# Fold 6 Epoch 900: Loss=0.002072 | TrainAcc=1.0000
# Fold 6 Epoch 1000: Loss=0.001571 | TrainAcc=1.0000
# Fold 6 Epoch 1100: Loss=0.001321 | TrainAcc=1.0000
# Fold 6 Epoch 1200: Loss=0.001251 | TrainAcc=1.0000
# Fold 6 Epoch 1300: Loss=0.001173 | TrainAcc=1.0000
# Fold 6 Epoch 1400: Loss=0.000799 | TrainAcc=1.0000
# Fold 6 Epoch 1500: Loss=0.000790 | TrainAcc=1.0000
# Fold 6 Epoch 1600: Loss=0.000758 | TrainAcc=1.0000
# Fold 6 Epoch 1700: Loss=0.000625 | TrainAcc=1.0000
# Fold 6 Epoch 1800: Loss=0.000641 | TrainAcc=1.0000
# Fold 6 Epoch 1900: Loss=0.000537 | TrainAcc=1.0000
# Fold 6 Epoch 2000: Loss=0.000478 | TrainAcc=1.0000
# Fold 6 → Acc=0.7000 | Prec=0.7091 | Rec=0.7800 | F1=0.7429 | AUC=0.7510 | CE Loss=2.1863
#
# === Fold 7 ===
# Fold 7 Epoch 1: Loss=0.748653 | TrainAcc=0.5095
# Fold 7 Epoch 100: Loss=0.188602 | TrainAcc=0.9476
# Fold 7 Epoch 200: Loss=0.092825 | TrainAcc=0.9857
# Fold 7 Epoch 300: Loss=0.040403 | TrainAcc=1.0000
# Fold 7 Epoch 400: Loss=0.020559 | TrainAcc=1.0000
# Fold 7 Epoch 500: Loss=0.012864 | TrainAcc=1.0000
# Fold 7 Epoch 600: Loss=0.008434 | TrainAcc=1.0000
# Fold 7 Epoch 700: Loss=0.005594 | TrainAcc=1.0000
# Fold 7 Epoch 800: Loss=0.004380 | TrainAcc=1.0000
# Fold 7 Epoch 900: Loss=0.003295 | TrainAcc=1.0000
# Fold 7 Epoch 1000: Loss=0.002738 | TrainAcc=1.0000
# Fold 7 Epoch 1100: Loss=0.001977 | TrainAcc=1.0000
# Fold 7 Epoch 1200: Loss=0.001696 | TrainAcc=1.0000
# Fold 7 Epoch 1300: Loss=0.001491 | TrainAcc=1.0000
# Fold 7 Epoch 1400: Loss=0.001291 | TrainAcc=1.0000
# Fold 7 Epoch 1500: Loss=0.001069 | TrainAcc=1.0000
# Fold 7 Epoch 1600: Loss=0.001016 | TrainAcc=1.0000
# Fold 7 Epoch 1700: Loss=0.000974 | TrainAcc=1.0000
# Fold 7 Epoch 1800: Loss=0.000877 | TrainAcc=1.0000
# Fold 7 Epoch 1900: Loss=0.000713 | TrainAcc=1.0000
# Fold 7 Epoch 2000: Loss=0.000659 | TrainAcc=1.0000
# Fold 7 → Acc=0.7778 | Prec=0.8000 | Rec=0.8000 | F1=0.8000 | AUC=0.8265 | CE Loss=1.5467
#
# === Fold 8 ===
# Fold 8 Epoch 1: Loss=0.748894 | TrainAcc=0.6143
# Fold 8 Epoch 100: Loss=0.195612 | TrainAcc=0.9143
# Fold 8 Epoch 200: Loss=0.081208 | TrainAcc=0.9857
# Fold 8 Epoch 300: Loss=0.030988 | TrainAcc=1.0000
# Fold 8 Epoch 400: Loss=0.015563 | TrainAcc=1.0000
# Fold 8 Epoch 500: Loss=0.009428 | TrainAcc=1.0000
# Fold 8 Epoch 600: Loss=0.006000 | TrainAcc=1.0000
# Fold 8 Epoch 700: Loss=0.004013 | TrainAcc=1.0000
# Fold 8 Epoch 800: Loss=0.003141 | TrainAcc=1.0000
# Fold 8 Epoch 900: Loss=0.002518 | TrainAcc=1.0000
# Fold 8 Epoch 1000: Loss=0.001739 | TrainAcc=1.0000
# Fold 8 Epoch 1100: Loss=0.001730 | TrainAcc=1.0000
# Fold 8 Epoch 1200: Loss=0.001405 | TrainAcc=1.0000
# Fold 8 Epoch 1300: Loss=0.001152 | TrainAcc=1.0000
# Fold 8 Epoch 1400: Loss=0.001060 | TrainAcc=1.0000
# Fold 8 Epoch 1500: Loss=0.000836 | TrainAcc=1.0000
# Fold 8 Epoch 1600: Loss=0.000841 | TrainAcc=1.0000
# Fold 8 Epoch 1700: Loss=0.000839 | TrainAcc=1.0000
# Fold 8 Epoch 1800: Loss=0.001001 | TrainAcc=1.0000
# Fold 8 Epoch 1900: Loss=0.000555 | TrainAcc=1.0000
# Fold 8 Epoch 2000: Loss=0.000515 | TrainAcc=1.0000
# Fold 8 → Acc=0.7444 | Prec=0.7872 | Rec=0.7400 | F1=0.7629 | AUC=0.7887 | CE Loss=1.9067
#
# === Fold 9 ===
# Fold 9 Epoch 1: Loss=0.717176 | TrainAcc=0.5333
# Fold 9 Epoch 100: Loss=0.187653 | TrainAcc=0.9381
# Fold 9 Epoch 200: Loss=0.088547 | TrainAcc=0.9810
# Fold 9 Epoch 300: Loss=0.036239 | TrainAcc=1.0000
# Fold 9 Epoch 400: Loss=0.016340 | TrainAcc=1.0000
# Fold 9 Epoch 500: Loss=0.010084 | TrainAcc=1.0000
# Fold 9 Epoch 600: Loss=0.006876 | TrainAcc=1.0000
# Fold 9 Epoch 700: Loss=0.004705 | TrainAcc=1.0000
# Fold 9 Epoch 800: Loss=0.003466 | TrainAcc=1.0000
# Fold 9 Epoch 900: Loss=0.002532 | TrainAcc=1.0000
# Fold 9 Epoch 1000: Loss=0.002353 | TrainAcc=1.0000
# Fold 9 Epoch 1100: Loss=0.001648 | TrainAcc=1.0000
# Fold 9 Epoch 1200: Loss=0.001785 | TrainAcc=1.0000
# Fold 9 Epoch 1300: Loss=0.001377 | TrainAcc=1.0000
# Fold 9 Epoch 1400: Loss=0.001195 | TrainAcc=1.0000
# Fold 9 Epoch 1500: Loss=0.001110 | TrainAcc=1.0000
# Fold 9 Epoch 1600: Loss=0.000888 | TrainAcc=1.0000
# Fold 9 Epoch 1700: Loss=0.000873 | TrainAcc=1.0000
# Fold 9 Epoch 1800: Loss=0.000734 | TrainAcc=1.0000
# Fold 9 Epoch 1900: Loss=0.000737 | TrainAcc=1.0000
# Fold 9 Epoch 2000: Loss=0.000564 | TrainAcc=1.0000
# Fold 9 → Acc=0.6667 | Prec=0.6786 | Rec=0.7600 | F1=0.7170 | AUC=0.8250 | CE Loss=1.5187
#
# === Fold 10 ===
# Fold 10 Epoch 1: Loss=0.745238 | TrainAcc=0.5952
# Fold 10 Epoch 100: Loss=0.189067 | TrainAcc=0.9286
# Fold 10 Epoch 200: Loss=0.089227 | TrainAcc=0.9762
# Fold 10 Epoch 300: Loss=0.030855 | TrainAcc=1.0000
# Fold 10 Epoch 400: Loss=0.015163 | TrainAcc=1.0000
# Fold 10 Epoch 500: Loss=0.010911 | TrainAcc=1.0000
# Fold 10 Epoch 600: Loss=0.006379 | TrainAcc=1.0000
# Fold 10 Epoch 700: Loss=0.005044 | TrainAcc=1.0000
# Fold 10 Epoch 800: Loss=0.003287 | TrainAcc=1.0000
# Fold 10 Epoch 900: Loss=0.002578 | TrainAcc=1.0000
# Fold 10 Epoch 1000: Loss=0.002143 | TrainAcc=1.0000
# Fold 10 Epoch 1100: Loss=0.001545 | TrainAcc=1.0000
# Fold 10 Epoch 1200: Loss=0.001465 | TrainAcc=1.0000
# Fold 10 Epoch 1300: Loss=0.001264 | TrainAcc=1.0000
# Fold 10 Epoch 1400: Loss=0.000948 | TrainAcc=1.0000
# Fold 10 Epoch 1500: Loss=0.000828 | TrainAcc=1.0000
# Fold 10 Epoch 1600: Loss=0.000831 | TrainAcc=1.0000
# Fold 10 Epoch 1700: Loss=0.000742 | TrainAcc=1.0000
# Fold 10 Epoch 1800: Loss=0.000825 | TrainAcc=1.0000
# Fold 10 Epoch 1900: Loss=0.000691 | TrainAcc=1.0000
# Fold 10 Epoch 2000: Loss=0.000602 | TrainAcc=1.0000
# Fold 10 → Acc=0.7778 | Prec=0.8750 | Rec=0.7000 | F1=0.7778 | AUC=0.8482 | CE Loss=1.6172
#
# === Fold 11 ===
# Fold 11 Epoch 1: Loss=0.625401 | TrainAcc=0.6524
# Fold 11 Epoch 100: Loss=0.163245 | TrainAcc=0.9571
# Fold 11 Epoch 200: Loss=0.063100 | TrainAcc=0.9952
# Fold 11 Epoch 300: Loss=0.025822 | TrainAcc=1.0000
# Fold 11 Epoch 400: Loss=0.013257 | TrainAcc=1.0000
# Fold 11 Epoch 500: Loss=0.006937 | TrainAcc=1.0000
# Fold 11 Epoch 600: Loss=0.006242 | TrainAcc=1.0000
# Fold 11 Epoch 700: Loss=0.004007 | TrainAcc=1.0000
# Fold 11 Epoch 800: Loss=0.002941 | TrainAcc=1.0000
# Fold 11 Epoch 900: Loss=0.002370 | TrainAcc=1.0000
# Fold 11 Epoch 1000: Loss=0.001813 | TrainAcc=1.0000
# Fold 11 Epoch 1100: Loss=0.001545 | TrainAcc=1.0000
# Fold 11 Epoch 1200: Loss=0.001220 | TrainAcc=1.0000
# Fold 11 Epoch 1300: Loss=0.001083 | TrainAcc=1.0000
# Fold 11 Epoch 1400: Loss=0.001000 | TrainAcc=1.0000
# Fold 11 Epoch 1500: Loss=0.000845 | TrainAcc=1.0000
# Fold 11 Epoch 1600: Loss=0.000737 | TrainAcc=1.0000
# Fold 11 Epoch 1700: Loss=0.000701 | TrainAcc=1.0000
# Fold 11 Epoch 1800: Loss=0.000688 | TrainAcc=1.0000
# Fold 11 Epoch 1900: Loss=0.000666 | TrainAcc=1.0000
# Fold 11 Epoch 2000: Loss=0.000594 | TrainAcc=1.0000
# Fold 11 → Acc=0.8000 | Prec=0.8200 | Rec=0.8200 | F1=0.8200 | AUC=0.8445 | CE Loss=1.4976
#
# === Fold 12 ===
# Fold 12 Epoch 1: Loss=0.708652 | TrainAcc=0.5190
# Fold 12 Epoch 100: Loss=0.213009 | TrainAcc=0.9333
# Fold 12 Epoch 200: Loss=0.099817 | TrainAcc=0.9810
# Fold 12 Epoch 300: Loss=0.045555 | TrainAcc=1.0000
# Fold 12 Epoch 400: Loss=0.024363 | TrainAcc=1.0000
# Fold 12 Epoch 500: Loss=0.012696 | TrainAcc=1.0000
# Fold 12 Epoch 600: Loss=0.009495 | TrainAcc=1.0000
# Fold 12 Epoch 700: Loss=0.006388 | TrainAcc=1.0000
# Fold 12 Epoch 800: Loss=0.005040 | TrainAcc=1.0000
# Fold 12 Epoch 900: Loss=0.003509 | TrainAcc=1.0000
# Fold 12 Epoch 1000: Loss=0.002759 | TrainAcc=1.0000
# Fold 12 Epoch 1100: Loss=0.002358 | TrainAcc=1.0000
# Fold 12 Epoch 1200: Loss=0.001923 | TrainAcc=1.0000
# Fold 12 Epoch 1300: Loss=0.001659 | TrainAcc=1.0000
# Fold 12 Epoch 1400: Loss=0.001530 | TrainAcc=1.0000
# Fold 12 Epoch 1500: Loss=0.001159 | TrainAcc=1.0000
# Fold 12 Epoch 1600: Loss=0.001026 | TrainAcc=1.0000
# Fold 12 Epoch 1700: Loss=0.001054 | TrainAcc=1.0000
# Fold 12 Epoch 1800: Loss=0.000817 | TrainAcc=1.0000
# Fold 12 Epoch 1900: Loss=0.000767 | TrainAcc=1.0000
# Fold 12 Epoch 2000: Loss=0.000721 | TrainAcc=1.0000
# Fold 12 → Acc=0.7667 | Prec=0.7843 | Rec=0.8000 | F1=0.7921 | AUC=0.8685 | CE Loss=1.2319
#
# === Fold 13 ===
# Fold 13 Epoch 1: Loss=0.823123 | TrainAcc=0.4476
# Fold 13 Epoch 100: Loss=0.185929 | TrainAcc=0.9286
# Fold 13 Epoch 200: Loss=0.087360 | TrainAcc=0.9905
# Fold 13 Epoch 300: Loss=0.045378 | TrainAcc=1.0000
# Fold 13 Epoch 400: Loss=0.023700 | TrainAcc=1.0000
# Fold 13 Epoch 500: Loss=0.012819 | TrainAcc=1.0000
# Fold 13 Epoch 600: Loss=0.007701 | TrainAcc=1.0000
# Fold 13 Epoch 700: Loss=0.005898 | TrainAcc=1.0000
# Fold 13 Epoch 800: Loss=0.004695 | TrainAcc=1.0000
# Fold 13 Epoch 900: Loss=0.003197 | TrainAcc=1.0000
# Fold 13 Epoch 1000: Loss=0.002907 | TrainAcc=1.0000
# Fold 13 Epoch 1100: Loss=0.001913 | TrainAcc=1.0000
# Fold 13 Epoch 1200: Loss=0.001702 | TrainAcc=1.0000
# Fold 13 Epoch 1300: Loss=0.001618 | TrainAcc=1.0000
# Fold 13 Epoch 1400: Loss=0.001379 | TrainAcc=1.0000
# Fold 13 Epoch 1500: Loss=0.001273 | TrainAcc=1.0000
# Fold 13 Epoch 1600: Loss=0.001086 | TrainAcc=1.0000
# Fold 13 Epoch 1700: Loss=0.001031 | TrainAcc=1.0000
# Fold 13 Epoch 1800: Loss=0.000918 | TrainAcc=1.0000
# Fold 13 Epoch 1900: Loss=0.000739 | TrainAcc=1.0000
# Fold 13 Epoch 2000: Loss=0.000790 | TrainAcc=1.0000
# Fold 13 → Acc=0.8222 | Prec=0.8542 | Rec=0.8200 | F1=0.8367 | AUC=0.8350 | CE Loss=1.5639
#
# === Fold 14 ===
# Fold 14 Epoch 1: Loss=0.770113 | TrainAcc=0.5143
# Fold 14 Epoch 100: Loss=0.211869 | TrainAcc=0.9190
# Fold 14 Epoch 200: Loss=0.108603 | TrainAcc=0.9762
# Fold 14 Epoch 300: Loss=0.048452 | TrainAcc=0.9952
# Fold 14 Epoch 400: Loss=0.023774 | TrainAcc=1.0000
# Fold 14 Epoch 500: Loss=0.012928 | TrainAcc=1.0000
# Fold 14 Epoch 600: Loss=0.008066 | TrainAcc=1.0000
# Fold 14 Epoch 700: Loss=0.005249 | TrainAcc=1.0000
# Fold 14 Epoch 800: Loss=0.004365 | TrainAcc=1.0000
# Fold 14 Epoch 900: Loss=0.003329 | TrainAcc=1.0000
# Fold 14 Epoch 1000: Loss=0.002624 | TrainAcc=1.0000
# Fold 14 Epoch 1100: Loss=0.002389 | TrainAcc=1.0000
# Fold 14 Epoch 1200: Loss=0.001902 | TrainAcc=1.0000
# Fold 14 Epoch 1300: Loss=0.001536 | TrainAcc=1.0000
# Fold 14 Epoch 1400: Loss=0.001684 | TrainAcc=1.0000
# Fold 14 Epoch 1500: Loss=0.001075 | TrainAcc=1.0000
# Fold 14 Epoch 1600: Loss=0.001071 | TrainAcc=1.0000
# Fold 14 Epoch 1700: Loss=0.001010 | TrainAcc=1.0000
# Fold 14 Epoch 1800: Loss=0.000806 | TrainAcc=1.0000
# Fold 14 Epoch 1900: Loss=0.000894 | TrainAcc=1.0000
# Fold 14 Epoch 2000: Loss=0.000625 | TrainAcc=1.0000
# Fold 14 → Acc=0.7222 | Prec=0.7193 | Rec=0.8200 | F1=0.7664 | AUC=0.8245 | CE Loss=1.2411
#
# === Fold 15 ===
# Fold 15 Epoch 1: Loss=0.971745 | TrainAcc=0.3048
# Fold 15 Epoch 100: Loss=0.211462 | TrainAcc=0.9143
# Fold 15 Epoch 200: Loss=0.103258 | TrainAcc=0.9810
# Fold 15 Epoch 300: Loss=0.055170 | TrainAcc=0.9952
# Fold 15 Epoch 400: Loss=0.032314 | TrainAcc=0.9952
# Fold 15 Epoch 500: Loss=0.016436 | TrainAcc=1.0000
# Fold 15 Epoch 600: Loss=0.012271 | TrainAcc=1.0000
# Fold 15 Epoch 700: Loss=0.007960 | TrainAcc=1.0000
# Fold 15 Epoch 800: Loss=0.005295 | TrainAcc=1.0000
# Fold 15 Epoch 900: Loss=0.004184 | TrainAcc=1.0000
# Fold 15 Epoch 1000: Loss=0.004078 | TrainAcc=1.0000
# Fold 15 Epoch 1100: Loss=0.002953 | TrainAcc=1.0000
# Fold 15 Epoch 1200: Loss=0.002452 | TrainAcc=1.0000
# Fold 15 Epoch 1300: Loss=0.001995 | TrainAcc=1.0000
# Fold 15 Epoch 1400: Loss=0.001877 | TrainAcc=1.0000
# Fold 15 Epoch 1500: Loss=0.001510 | TrainAcc=1.0000
# Fold 15 Epoch 1600: Loss=0.001042 | TrainAcc=1.0000
# Fold 15 Epoch 1700: Loss=0.001227 | TrainAcc=1.0000
# Fold 15 Epoch 1800: Loss=0.000924 | TrainAcc=1.0000
# Fold 15 Epoch 1900: Loss=0.001149 | TrainAcc=1.0000
# Fold 15 Epoch 2000: Loss=0.000731 | TrainAcc=1.0000
# Fold 15 → Acc=0.7778 | Prec=0.8125 | Rec=0.7800 | F1=0.7959 | AUC=0.8570 | CE Loss=1.4414
#
# === Fold 16 ===
# Fold 16 Epoch 1: Loss=0.798416 | TrainAcc=0.4381
# Fold 16 Epoch 100: Loss=0.232781 | TrainAcc=0.9238
# Fold 16 Epoch 200: Loss=0.112952 | TrainAcc=0.9810
# Fold 16 Epoch 300: Loss=0.048729 | TrainAcc=0.9952
# Fold 16 Epoch 400: Loss=0.024045 | TrainAcc=1.0000
# Fold 16 Epoch 500: Loss=0.015162 | TrainAcc=1.0000
# Fold 16 Epoch 600: Loss=0.009848 | TrainAcc=1.0000
# Fold 16 Epoch 700: Loss=0.006466 | TrainAcc=1.0000
# Fold 16 Epoch 800: Loss=0.004935 | TrainAcc=1.0000
# Fold 16 Epoch 900: Loss=0.003750 | TrainAcc=1.0000
# Fold 16 Epoch 1000: Loss=0.003206 | TrainAcc=1.0000
# Fold 16 Epoch 1100: Loss=0.002248 | TrainAcc=1.0000
# Fold 16 Epoch 1200: Loss=0.001777 | TrainAcc=1.0000
# Fold 16 Epoch 1300: Loss=0.001479 | TrainAcc=1.0000
# Fold 16 Epoch 1400: Loss=0.001277 | TrainAcc=1.0000
# Fold 16 Epoch 1500: Loss=0.001271 | TrainAcc=1.0000
# Fold 16 Epoch 1600: Loss=0.001135 | TrainAcc=1.0000
# Fold 16 Epoch 1700: Loss=0.001181 | TrainAcc=1.0000
# Fold 16 Epoch 1800: Loss=0.000960 | TrainAcc=1.0000
# Fold 16 Epoch 1900: Loss=0.000774 | TrainAcc=1.0000
# Fold 16 Epoch 2000: Loss=0.000768 | TrainAcc=1.0000
# Fold 16 → Acc=0.7556 | Prec=0.7593 | Rec=0.8200 | F1=0.7885 | AUC=0.8607 | CE Loss=1.2477
#
# === Fold 17 ===
# Fold 17 Epoch 1: Loss=1.221628 | TrainAcc=0.3095
# Fold 17 Epoch 100: Loss=0.230299 | TrainAcc=0.8905
# Fold 17 Epoch 200: Loss=0.137833 | TrainAcc=0.9714
# Fold 17 Epoch 300: Loss=0.075978 | TrainAcc=0.9905
# Fold 17 Epoch 400: Loss=0.041426 | TrainAcc=0.9952
# Fold 17 Epoch 500: Loss=0.026354 | TrainAcc=1.0000
# Fold 17 Epoch 600: Loss=0.015734 | TrainAcc=1.0000
# Fold 17 Epoch 700: Loss=0.010453 | TrainAcc=1.0000
# Fold 17 Epoch 800: Loss=0.007205 | TrainAcc=1.0000
# Fold 17 Epoch 900: Loss=0.006358 | TrainAcc=1.0000
# Fold 17 Epoch 1000: Loss=0.004770 | TrainAcc=1.0000
# Fold 17 Epoch 1100: Loss=0.003841 | TrainAcc=1.0000
# Fold 17 Epoch 1200: Loss=0.003348 | TrainAcc=1.0000
# Fold 17 Epoch 1300: Loss=0.002358 | TrainAcc=1.0000
# Fold 17 Epoch 1400: Loss=0.001934 | TrainAcc=1.0000
# Fold 17 Epoch 1500: Loss=0.002091 | TrainAcc=1.0000
# Fold 17 Epoch 1600: Loss=0.001775 | TrainAcc=1.0000
# Fold 17 Epoch 1700: Loss=0.001324 | TrainAcc=1.0000
# Fold 17 Epoch 1800: Loss=0.001283 | TrainAcc=1.0000
# Fold 17 Epoch 1900: Loss=0.001195 | TrainAcc=1.0000
# Fold 17 Epoch 2000: Loss=0.001201 | TrainAcc=1.0000
# Fold 17 → Acc=0.8222 | Prec=0.8542 | Rec=0.8200 | F1=0.8367 | AUC=0.8410 | CE Loss=1.4460
#
# === Fold 18 ===
# Fold 18 Epoch 1: Loss=0.953914 | TrainAcc=0.3762
# Fold 18 Epoch 100: Loss=0.208102 | TrainAcc=0.9333
# Fold 18 Epoch 200: Loss=0.116837 | TrainAcc=0.9905
# Fold 18 Epoch 300: Loss=0.056372 | TrainAcc=0.9952
# Fold 18 Epoch 400: Loss=0.029515 | TrainAcc=1.0000
# Fold 18 Epoch 500: Loss=0.015926 | TrainAcc=1.0000
# Fold 18 Epoch 600: Loss=0.010996 | TrainAcc=1.0000
# Fold 18 Epoch 700: Loss=0.007534 | TrainAcc=1.0000
# Fold 18 Epoch 800: Loss=0.006439 | TrainAcc=1.0000
# Fold 18 Epoch 900: Loss=0.004176 | TrainAcc=1.0000
# Fold 18 Epoch 1000: Loss=0.003602 | TrainAcc=1.0000
# Fold 18 Epoch 1100: Loss=0.002602 | TrainAcc=1.0000
# Fold 18 Epoch 1200: Loss=0.002446 | TrainAcc=1.0000
# Fold 18 Epoch 1300: Loss=0.001770 | TrainAcc=1.0000
# Fold 18 Epoch 1400: Loss=0.001565 | TrainAcc=1.0000
# Fold 18 Epoch 1500: Loss=0.001436 | TrainAcc=1.0000
# Fold 18 Epoch 1600: Loss=0.001303 | TrainAcc=1.0000
# Fold 18 Epoch 1700: Loss=0.001038 | TrainAcc=1.0000
# Fold 18 Epoch 1800: Loss=0.001237 | TrainAcc=1.0000
# Fold 18 Epoch 1900: Loss=0.001065 | TrainAcc=1.0000
# Fold 18 Epoch 2000: Loss=0.000955 | TrainAcc=1.0000
# Fold 18 → Acc=0.7111 | Prec=0.7857 | Rec=0.6600 | F1=0.7174 | AUC=0.8210 | CE Loss=1.6325
#
# === Fold 19 ===
# Fold 19 Epoch 1: Loss=0.857485 | TrainAcc=0.4095
# Fold 19 Epoch 100: Loss=0.220666 | TrainAcc=0.9286
# Fold 19 Epoch 200: Loss=0.093899 | TrainAcc=0.9952
# Fold 19 Epoch 300: Loss=0.042145 | TrainAcc=1.0000
# Fold 19 Epoch 400: Loss=0.020602 | TrainAcc=1.0000
# Fold 19 Epoch 500: Loss=0.012180 | TrainAcc=1.0000
# Fold 19 Epoch 600: Loss=0.008723 | TrainAcc=1.0000
# Fold 19 Epoch 700: Loss=0.005436 | TrainAcc=1.0000
# Fold 19 Epoch 800: Loss=0.004124 | TrainAcc=1.0000
# Fold 19 Epoch 900: Loss=0.003828 | TrainAcc=1.0000
# Fold 19 Epoch 1000: Loss=0.002795 | TrainAcc=1.0000
# Fold 19 Epoch 1100: Loss=0.002342 | TrainAcc=1.0000
# Fold 19 Epoch 1200: Loss=0.001868 | TrainAcc=1.0000
# Fold 19 Epoch 1300: Loss=0.001593 | TrainAcc=1.0000
# Fold 19 Epoch 1400: Loss=0.001344 | TrainAcc=1.0000
# Fold 19 Epoch 1500: Loss=0.001119 | TrainAcc=1.0000
# Fold 19 Epoch 1600: Loss=0.001128 | TrainAcc=1.0000
# Fold 19 Epoch 1700: Loss=0.000984 | TrainAcc=1.0000
# Fold 19 Epoch 1800: Loss=0.000797 | TrainAcc=1.0000
# Fold 19 Epoch 1900: Loss=0.000682 | TrainAcc=1.0000
# Fold 19 Epoch 2000: Loss=0.000744 | TrainAcc=1.0000
# Fold 19 → Acc=0.8000 | Prec=0.8200 | Rec=0.8200 | F1=0.8200 | AUC=0.8510 | CE Loss=1.3960
#
# === Fold 20 ===
# Fold 20 Epoch 1: Loss=0.820620 | TrainAcc=0.4238
# Fold 20 Epoch 100: Loss=0.193701 | TrainAcc=0.9429
# Fold 20 Epoch 200: Loss=0.080817 | TrainAcc=0.9857
# Fold 20 Epoch 300: Loss=0.033040 | TrainAcc=1.0000
# Fold 20 Epoch 400: Loss=0.018582 | TrainAcc=1.0000
# Fold 20 Epoch 500: Loss=0.010226 | TrainAcc=1.0000
# Fold 20 Epoch 600: Loss=0.006980 | TrainAcc=1.0000
# Fold 20 Epoch 700: Loss=0.005448 | TrainAcc=1.0000
# Fold 20 Epoch 800: Loss=0.003962 | TrainAcc=1.0000
# Fold 20 Epoch 900: Loss=0.002994 | TrainAcc=1.0000
# Fold 20 Epoch 1000: Loss=0.002381 | TrainAcc=1.0000
# Fold 20 Epoch 1100: Loss=0.001964 | TrainAcc=1.0000
# Fold 20 Epoch 1200: Loss=0.001539 | TrainAcc=1.0000
# Fold 20 Epoch 1300: Loss=0.001358 | TrainAcc=1.0000
# Fold 20 Epoch 1400: Loss=0.001057 | TrainAcc=1.0000
# Fold 20 Epoch 1500: Loss=0.001114 | TrainAcc=1.0000
# Fold 20 Epoch 1600: Loss=0.000887 | TrainAcc=1.0000
# Fold 20 Epoch 1700: Loss=0.000880 | TrainAcc=1.0000
# Fold 20 Epoch 1800: Loss=0.000629 | TrainAcc=1.0000
# Fold 20 Epoch 1900: Loss=0.000677 | TrainAcc=1.0000
# Fold 20 Epoch 2000: Loss=0.000611 | TrainAcc=1.0000
# Fold 20 → Acc=0.6778 | Prec=0.7442 | Rec=0.6400 | F1=0.6882 | AUC=0.7420 | CE Loss=2.1728
#
# === Average Results Across 20 Folds ===
# Accuracy:  0.7550 ± 0.0435
# Precision: 0.7846 ± 0.0488
# Recall:    0.7750 ± 0.0529
# F1-score:  0.7783 ± 0.0396
# CE Loss:   1.5793 ± 0.2603
# AUC:       0.8245 ± 0.0328
