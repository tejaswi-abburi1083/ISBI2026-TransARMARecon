# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install numpy scikit-learn
# !pip install -q torch_geometric
# !pip install -q class_resolver
# !pip3 install pymatting
# !pip install opencv-python
# !pip install matplotlib
# !pip install tqdm
# Out:
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (2.0.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (1.6.1)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (3.6.0)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.7/63.7 kB 1.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 17.4 MB/s eta 0:00:00
# Collecting pymatting
#   Downloading pymatting-1.1.14-py3-none-any.whl.metadata (7.7 kB)
# Requirement already satisfied: numpy>=1.16.0 in /usr/local/lib/python3.12/dist-packages (from pymatting) (2.0.2)
# Requirement already satisfied: pillow>=5.2.0 in /usr/local/lib/python3.12/dist-packages (from pymatting) (11.3.0)
# Requirement already satisfied: numba!=0.49.0 in /usr/local/lib/python3.12/dist-packages (from pymatting) (0.60.0)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from pymatting) (1.16.3)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba!=0.49.0->pymatting) (0.43.0)
# Downloading pymatting-1.1.14-py3-none-any.whl (54 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.7/54.7 kB 1.5 MB/s eta 0:00:00
# Installing collected packages: pymatting
# Successfully installed pymatting-1.1.14
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.12/dist-packages (4.12.0.88)
# Requirement already satisfied: numpy<2.3.0,>=2 in /usr/local/lib/python3.12/dist-packages (from opencv-python) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (4.67.1)

# %%
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, log_loss
from sklearn.model_selection import StratifiedShuffleSplit
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc, roc_auc_score

# %%
# === Load Patients ===
fa_patients_path = "/home/snu/Downloads/NIFD_Patients_FA_Histogram_Feature.npy"
Patients_FA_array = np.load(fa_patients_path, allow_pickle=True)

# === Load Controls ===
fa_controls_path = "/home/snu/Downloads/NIFD_Control_FA_Histogram_Feature.npy"
Controls_FA_array = np.load(fa_controls_path, allow_pickle=True)

print("Patients Shape:", Patients_FA_array.shape)
print("Controls Shape:", Controls_FA_array.shape)

# === Combine features and labels ===
X = np.vstack([Controls_FA_array, Patients_FA_array])
y = np.hstack([
    np.zeros(Controls_FA_array.shape[0], dtype=np.int64),  # 0 = Control
    np.ones(Patients_FA_array.shape[0], dtype=np.int64)    # 1 = Patient
])

# Shuffle
np.random.seed(42)
perm = np.random.permutation(X.shape[0])
X = X[perm]
y = y[perm]
# Out:
# Patients Shape: (98, 180)
# Controls Shape: (48, 180)

# %%
scaler = StandardScaler()
X = scaler.fit_transform(X)

# %%
# Stratified split
sss = StratifiedShuffleSplit(n_splits=20, test_size=0.3, random_state=42)

# %%
# Storage for metrics
accuracies, precisions, recalls, f1_scores, losses = [], [], [], [], []

# %%
all_y_true = []
all_y_proba = []
all_fpr = []
all_tpr = []
all_auc = []

for fold, (train_idx, test_idx) in enumerate(sss.split(X, y)):
    print(f"\nTraining fold {fold + 1}")

    X_train, X_test = X[train_idx], X[test_idx]
    y_train, y_test = y[train_idx], y[test_idx]

    clf = SVC(kernel='rbf', C=10, gamma='scale', probability=True)
    clf.fit(X_train, y_train)

    y_pred = clf.predict(X_test)
    y_pred_proba = clf.predict_proba(X_test)[:, 1]

    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)
    loss = log_loss(y_test, y_pred_proba)
    auc_score = roc_auc_score(y_test, y_pred_proba)

    accuracies.append(accuracy)
    precisions.append(precision)
    recalls.append(recall)
    f1_scores.append(f1)
    losses.append(loss)
    all_y_true.extend(y_test)
    all_y_proba.extend(y_pred_proba)

    fpr, tpr, _ = roc_curve(y_test, y_pred_proba)
    all_fpr.append(fpr)
    all_tpr.append(tpr)
    all_auc.append(auc_score)

    print(f"Accuracy: {accuracy:.4f} | Precision: {precision:.4f} | Recall: {recall:.4f} | F1: {f1:.4f} | Loss: {loss:.4f} | AUC: {auc_score:.4f}")

# Final average results
print("\nAverage Results across 20 folds:")
print(f"Accuracy: {np.mean(accuracies):.4f} ± {np.std(accuracies):.4f}")
print(f"Precision: {np.mean(precisions):.4f} ± {np.std(precisions):.4f}")
print(f"Recall: {np.mean(recalls):.4f} ± {np.std(recalls):.4f}")
print(f"F1 Score: {np.mean(f1_scores):.4f} ± {np.std(f1_scores):.4f}")
print(f"Cross-Entropy Loss: {np.mean(losses):.4f} ± {np.std(losses):.4f}")
print(f"Average AUC: {np.mean(all_auc):.4f} ± {np.std(all_auc):.4f}")
# Out:
# Training fold 1
# Accuracy: 0.7500 | Precision: 0.7714 | Recall: 0.9000 | F1: 0.8308 | Loss: 0.5279 | AUC: 0.7571
#
# Training fold 2
# Accuracy: 0.7955 | Precision: 0.8000 | Recall: 0.9333 | F1: 0.8615 | Loss: 0.4750 | AUC: 0.9286
#
# Training fold 3
# Accuracy: 0.7273 | Precision: 0.8000 | Recall: 0.8000 | F1: 0.8000 | Loss: 0.5552 | AUC: 0.7310
#
# Training fold 4
# Accuracy: 0.7273 | Precision: 0.7500 | Recall: 0.9000 | F1: 0.8182 | Loss: 0.5591 | AUC: 0.7381
#
# Training fold 5
# Accuracy: 0.7045 | Precision: 0.7742 | Recall: 0.8000 | F1: 0.7869 | Loss: 0.4896 | AUC: 0.7929
#
# Training fold 6
# Accuracy: 0.7045 | Precision: 0.7576 | Recall: 0.8333 | F1: 0.7937 | Loss: 0.5162 | AUC: 0.7929
#
# Training fold 7
# Accuracy: 0.7727 | Precision: 0.7941 | Recall: 0.9000 | F1: 0.8438 | Loss: 0.4742 | AUC: 0.8357
#
# Training fold 8
# Accuracy: 0.6818 | Precision: 0.7667 | Recall: 0.7667 | F1: 0.7667 | Loss: 0.5116 | AUC: 0.7833
#
# Training fold 9
# Accuracy: 0.7955 | Precision: 0.8182 | Recall: 0.9000 | F1: 0.8571 | Loss: 0.4998 | AUC: 0.8143
#
# Training fold 10
# Accuracy: 0.7955 | Precision: 0.8889 | Recall: 0.8000 | F1: 0.8421 | Loss: 0.4936 | AUC: 0.8929
#
# Training fold 11
# Accuracy: 0.7273 | Precision: 0.8000 | Recall: 0.8000 | F1: 0.8000 | Loss: 0.4890 | AUC: 0.8083
#
# Training fold 12
# Accuracy: 0.7500 | Precision: 0.8065 | Recall: 0.8333 | F1: 0.8197 | Loss: 0.4897 | AUC: 0.8333
#
# Training fold 13
# Accuracy: 0.7273 | Precision: 0.7647 | Recall: 0.8667 | F1: 0.8125 | Loss: 0.4716 | AUC: 0.8238
#
# Training fold 14
# Accuracy: 0.6818 | Precision: 0.7500 | Recall: 0.8000 | F1: 0.7742 | Loss: 0.5125 | AUC: 0.8048
#
# Training fold 15
# Accuracy: 0.6818 | Precision: 0.8077 | Recall: 0.7000 | F1: 0.7500 | Loss: 0.5006 | AUC: 0.8167
#
# Training fold 16
# Accuracy: 0.7045 | Precision: 0.7576 | Recall: 0.8333 | F1: 0.7937 | Loss: 0.5555 | AUC: 0.7690
#
# Training fold 17
# Accuracy: 0.7273 | Precision: 0.7500 | Recall: 0.9000 | F1: 0.8182 | Loss: 0.5167 | AUC: 0.7810
#
# Training fold 18
# Accuracy: 0.7045 | Precision: 0.7742 | Recall: 0.8000 | F1: 0.7869 | Loss: 0.4921 | AUC: 0.8095
#
# Training fold 19
# Accuracy: 0.6591 | Precision: 0.7419 | Recall: 0.7667 | F1: 0.7541 | Loss: 0.5773 | AUC: 0.7071
#
# Training fold 20
# Accuracy: 0.7273 | Precision: 0.7812 | Recall: 0.8333 | F1: 0.8065 | Loss: 0.4905 | AUC: 0.8405
#
# Average Results across 20 folds:
# Accuracy: 0.7273 ± 0.0387
# Precision: 0.7827 ± 0.0330
# Recall: 0.8333 ± 0.0577
# F1 Score: 0.8058 ± 0.0309
# Cross-Entropy Loss: 0.5099 ± 0.0299
# Average AUC: 0.8030 ± 0.0505

# %%
all_y_true = []
all_y_proba = []
all_fpr = []
all_tpr = []
all_auc = []

for fold, (train_idx, test_idx) in enumerate(sss.split(X, y)):
    print(f"\nTraining fold {fold + 1}")

    X_train, X_test = X[train_idx], X[test_idx]
    y_train, y_test = y[train_idx], y[test_idx]

    clf = SVC(kernel='rbf', C=10, gamma='scale', probability=True)
    clf.fit(X_train, y_train)

    y_pred = clf.predict(X_test)
    y_pred_proba = clf.predict_proba(X_test)[:, 1]

    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)
    loss = log_loss(y_test, y_pred_proba)
    auc_score = roc_auc_score(y_test, y_pred_proba)

    accuracies.append(accuracy)
    precisions.append(precision)
    recalls.append(recall)
    f1_scores.append(f1)
    losses.append(loss)
    all_y_true.extend(y_test)
    all_y_proba.extend(y_pred_proba)

    fpr, tpr, _ = roc_curve(y_test, y_pred_proba)
    all_fpr.append(fpr)
    all_tpr.append(tpr)
    all_auc.append(auc_score)

    print(f"Accuracy: {accuracy:.4f} | Precision: {precision:.4f} | Recall: {recall:.4f} | F1: {f1:.4f} | Loss: {loss:.4f} | AUC: {auc_score:.4f}")

# Final average results
print("\nAverage Results across 20 folds:")
print(f"Accuracy: {np.mean(accuracies):.4f} ± {np.std(accuracies):.4f}")
print(f"Precision: {np.mean(precisions):.4f} ± {np.std(precisions):.4f}")
print(f"Recall: {np.mean(recalls):.4f} ± {np.std(recalls):.4f}")
print(f"F1 Score: {np.mean(f1_scores):.4f} ± {np.std(f1_scores):.4f}")
print(f"Cross-Entropy Loss: {np.mean(losses):.4f} ± {np.std(losses):.4f}")
print(f"Average AUC: {np.mean(all_auc):.4f} ± {np.std(all_auc):.4f}")
# Out:
# Training fold 1
# Accuracy: 0.6667 | Precision: 0.7273 | Recall: 0.8000 | F1: 0.7619 | Loss: 0.5884 | AUC: 0.7000
#
# Training fold 2
# Accuracy: 0.8000 | Precision: 0.8889 | Recall: 0.8000 | F1: 0.8421 | Loss: 0.5610 | AUC: 0.7400
#
# Training fold 3
# Accuracy: 0.8000 | Precision: 0.8889 | Recall: 0.8000 | F1: 0.8421 | Loss: 0.3862 | AUC: 0.9400
#
# Training fold 4
# Accuracy: 0.8000 | Precision: 0.8889 | Recall: 0.8000 | F1: 0.8421 | Loss: 0.4952 | AUC: 0.8400
#
# Training fold 5
# Accuracy: 0.8000 | Precision: 0.8889 | Recall: 0.8000 | F1: 0.8421 | Loss: 0.4903 | AUC: 0.8400
#
# Training fold 6
# Accuracy: 0.6000 | Precision: 0.6667 | Recall: 0.8000 | F1: 0.7273 | Loss: 0.6265 | AUC: 0.6800
#
# Training fold 7
# Accuracy: 0.6667 | Precision: 0.7273 | Recall: 0.8000 | F1: 0.7619 | Loss: 0.5962 | AUC: 0.6800
#
# Training fold 8
# Accuracy: 0.8667 | Precision: 0.8333 | Recall: 1.0000 | F1: 0.9091 | Loss: 0.4236 | AUC: 0.9400
#
# Training fold 9
# Accuracy: 0.6000 | Precision: 0.7000 | Recall: 0.7000 | F1: 0.7000 | Loss: 0.6185 | AUC: 0.6800
#
# Training fold 10
# Accuracy: 0.8000 | Precision: 0.8182 | Recall: 0.9000 | F1: 0.8571 | Loss: 0.4852 | AUC: 0.8200
#
# Training fold 11
# Accuracy: 0.8000 | Precision: 0.8182 | Recall: 0.9000 | F1: 0.8571 | Loss: 0.5360 | AUC: 0.8000
#
# Training fold 12
# Accuracy: 0.8667 | Precision: 0.9000 | Recall: 0.9000 | F1: 0.9000 | Loss: 0.4801 | AUC: 0.8400
#
# Training fold 13
# Accuracy: 0.7333 | Precision: 0.7143 | Recall: 1.0000 | F1: 0.8333 | Loss: 0.4753 | AUC: 0.9000
#
# Training fold 14
# Accuracy: 0.6667 | Precision: 0.7778 | Recall: 0.7000 | F1: 0.7368 | Loss: 0.6869 | AUC: 0.6600
#
# Training fold 15
# Accuracy: 0.7333 | Precision: 0.8000 | Recall: 0.8000 | F1: 0.8000 | Loss: 0.4551 | AUC: 0.9200
#
# Training fold 16
# Accuracy: 0.6667 | Precision: 0.7273 | Recall: 0.8000 | F1: 0.7619 | Loss: 0.4959 | AUC: 0.8600
#
# Training fold 17
# Accuracy: 0.4000 | Precision: 0.5455 | Recall: 0.6000 | F1: 0.5714 | Loss: 0.6669 | AUC: 0.5600
#
# Training fold 18
# Accuracy: 0.8000 | Precision: 0.8889 | Recall: 0.8000 | F1: 0.8421 | Loss: 0.4850 | AUC: 0.8600
#
# Training fold 19
# Accuracy: 0.6667 | Precision: 0.7778 | Recall: 0.7000 | F1: 0.7368 | Loss: 0.5413 | AUC: 0.8000
#
# Training fold 20
# Accuracy: 0.6667 | Precision: 0.7273 | Recall: 0.8000 | F1: 0.7619 | Loss: 0.5958 | AUC: 0.7200
#
# Average Results across 20 folds:
# Accuracy: 0.7200 ± 0.1087
# Precision: 0.7853 ± 0.0919
# Recall: 0.8100 ± 0.0943
# F1 Score: 0.7944 ± 0.0772
# Cross-Entropy Loss: 0.5345 ± 0.0789
# Average AUC: 0.7890 ± 0.1034

# %%
plt.figure(figsize=(8, 6))

for i in range(len(all_fpr)):
    plt.plot(all_fpr[i], all_tpr[i], alpha=0.3, label=f"Fold {i+1} AUC = {all_auc[i]:.2f}")

# Average ROC Curve
fpr_avg, tpr_avg, _ = roc_curve(all_y_true, all_y_proba)
auc_avg = roc_auc_score(all_y_true, all_y_proba)
plt.plot(fpr_avg, tpr_avg, color='blue', lw=2, label=f"Mean ROC (AUC = {auc_avg:.2f})")

# Diagonal line
plt.plot([0, 1], [0, 1], 'k--', label="Chance")
plt.xlabel("False Positive Rate", fontsize=16)
plt.ylabel("True Positive Rate", fontsize=16)
plt.title("ROC Curve Across 20 Folds (SVC)", fontsize=18)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.legend(loc="lower right", fontsize=9)
plt.grid(True)
