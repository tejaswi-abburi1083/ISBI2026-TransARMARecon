# %%
import torch
import torch.nn as nn
import torch.nn.functional as nnFn
import torch.optim as optim
import numpy as np
import random
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from torch_geometric.data import Data
from torch_geometric.nn import ChebConv
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score,
    f1_score, roc_auc_score, log_loss
)

# %%
# === Load Patients ===
fa_patients_path = "/home/snu/Downloads/NIFD_Patients_FA_Histogram_Feature.npy"
Patients_FA_array = np.load(fa_patients_path, allow_pickle=True)

# === Load Controls ===
fa_controls_path = "/home/snu/Downloads/NIFD_Control_FA_Histogram_Feature.npy"
Controls_FA_array = np.load(fa_controls_path, allow_pickle=True)

print("Patients Shape:", Patients_FA_array.shape)
print("Controls Shape:", Controls_FA_array.shape)

# === Combine features and labels ===
X = np.vstack([Controls_FA_array, Patients_FA_array])
y = np.hstack([
    np.zeros(Controls_FA_array.shape[0], dtype=np.int64),  # 0 = Control
    np.ones(Patients_FA_array.shape[0], dtype=np.int64)    # 1 = Patient
])

# Shuffle
np.random.seed(42)
perm = np.random.permutation(X.shape[0])
X = X[perm]
y = y[perm]
# Out:
# Patients Shape: (98, 180)
# Controls Shape: (48, 180)

# %%
class Cheb_Supervised(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim, K=3, activ="SELU"):
        """
        K: Chebyshev polynomial order (controls neighborhood size)
        """
        super(Cheb_Supervised, self).__init__()
        self.conv1 = ChebConv(input_dim, hidden_dim, K=K)
        self.bn1 = nn.BatchNorm1d(hidden_dim)
        self.dropout = nn.Dropout(0.2)
        self.fc = nn.Linear(hidden_dim, output_dim)

        activations = {
            "SELU": nnFn.selu,
            "SiLU": nnFn.silu,
            "GELU": nnFn.gelu,
            "RELU": nnFn.relu,
            "ELU": nnFn.elu
        }
        self.act = activations.get(activ, nnFn.elu)

    def forward(self, data):
        x, edge_index = data.x, data.edge_index
        x_in = x

        # Chebyshev convolution layer
        x = self.conv1(x, edge_index)
        x = self.bn1(x)

        # Residual connection (optional, if dims match)
        if x_in.shape[1] == x.shape[1]:
            x = x + x_in

        x = self.act(x)
        x = self.dropout(x)
        logits = self.fc(x)
        return logits

# %%
def create_adj(F, alpha=1):
    F_norm = F / np.linalg.norm(F, axis=1, keepdims=True)
    W = np.dot(F_norm, F_norm.T)
    W = np.where(W >= alpha, 1, 0).astype(np.float32)
    W = W / W.max()
    return W

def load_data(adj, node_feats):
    node_feats = torch.from_numpy(node_feats).float()
    edge_index = torch.from_numpy(np.array(np.nonzero((adj > 0))))
    return Data(x=node_feats, edge_index=edge_index)

# %%
num_nodes, num_feats = X.shape
print(f"Number of features: {num_feats}")
# Out:
# Number of features: 180

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
alpha = 0.5
feats_dim = num_feats
hidden_dim = 512
num_classes = 2
num_epochs = 2000
lr = 0.0001
weight_decay = 1e-4
batch_print_freq = 100

# %%
W = create_adj(X, alpha)
data = load_data(W, X).to(device)
A_tensor = torch.from_numpy(W).float().to(device)
print(data)
# Out:
# Data(x=[146, 180], edge_index=[2, 21256])

# %%
sss = StratifiedShuffleSplit(n_splits=20, test_size=0.3, random_state=42)

accuracies, precisions, recalls, f1_scores, aucs, ce_losses = [], [], [], [], [], []

for fold, (train_idx, test_idx) in enumerate(sss.split(X, y), start=1):
    print(f"\n=== Fold {fold} ===")

    train_idx_t = torch.from_numpy(train_idx).long().to(device)
    y_train_tensor = torch.from_numpy(y[train_idx]).long().to(device)

    model = Cheb_Supervised(feats_dim, hidden_dim, num_classes, K=3, activ="SELU").to(device)
    optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
    ce_loss = nn.CrossEntropyLoss()


    for epoch in range(1, num_epochs + 1):
        model.train()
        optimizer.zero_grad()

        logits = model(data)
        loss = ce_loss(logits[train_idx_t], y_train_tensor)
        loss.backward()
        optimizer.step()

        if epoch % batch_print_freq == 0 or epoch == 1:
            model.eval()
            with torch.no_grad():
                preds_train = logits[train_idx_t].argmax(dim=1)
                acc_train = accuracy_score(y_train_tensor.cpu(), preds_train.cpu())
            print(f"Fold {fold} Epoch {epoch}: "
                  f"Loss={loss.item():.6f} | TrainAcc={acc_train:.4f}")


    model.eval()
    with torch.no_grad():
        out = model(data)
        preds = out.argmax(dim=1).cpu().numpy()
        probs = torch.softmax(out, dim=1)[:, 1].cpu().numpy()  # Probability for class 1

    y_test = y[test_idx]
    y_pred_test = preds[test_idx]
    y_prob_test = probs[test_idx]


    acc = accuracy_score(y_test, y_pred_test)
    prec = precision_score(y_test, y_pred_test, zero_division=0)
    rec = recall_score(y_test, y_pred_test, zero_division=0)
    f1 = f1_score(y_test, y_pred_test, zero_division=0)
    auc = roc_auc_score(y_test, y_prob_test)
    ce = log_loss(y_test, y_prob_test)

    accuracies.append(acc)
    precisions.append(prec)
    recalls.append(rec)
    f1_scores.append(f1)
    aucs.append(auc)
    ce_losses.append(ce)

    print(f"Fold {fold} → "
          f"Acc={acc:.4f} | Prec={prec:.4f} | Rec={rec:.4f} | "
          f"F1={f1:.4f} | AUC={auc:.4f} | CE Loss={ce:.4f}")


print("\n=== Average Results Across 20 Folds ===")
print(f"Accuracy:  {np.mean(accuracies):.4f} ± {np.std(accuracies):.4f}")
print(f"Precision: {np.mean(precisions):.4f} ± {np.std(precisions):.4f}")
print(f"Recall:    {np.mean(recalls):.4f} ± {np.std(recalls):.4f}")
print(f"F1-score:  {np.mean(f1_scores):.4f} ± {np.std(f1_scores):.4f}")
print(f"CE Loss:   {np.mean(ce_losses):.4f} ± {np.std(ce_losses):.4f}")
print(f"AUC:       {np.mean(aucs):.4f} ± {np.std(aucs):.4f}")
# Out:
# === Fold 1 ===
# Fold 1 Epoch 1: Loss=0.745715 | TrainAcc=0.5490
# Fold 1 Epoch 100: Loss=0.175024 | TrainAcc=0.9804
# Fold 1 Epoch 200: Loss=0.061413 | TrainAcc=0.9902
# Fold 1 Epoch 300: Loss=0.022284 | TrainAcc=1.0000
# Fold 1 Epoch 400: Loss=0.012668 | TrainAcc=1.0000
# Fold 1 Epoch 500: Loss=0.006227 | TrainAcc=1.0000
# Fold 1 Epoch 600: Loss=0.004605 | TrainAcc=1.0000
# Fold 1 Epoch 700: Loss=0.003275 | TrainAcc=1.0000
# Fold 1 Epoch 800: Loss=0.002517 | TrainAcc=1.0000
# Fold 1 Epoch 900: Loss=0.002181 | TrainAcc=1.0000
# Fold 1 Epoch 1000: Loss=0.001625 | TrainAcc=1.0000
# Fold 1 Epoch 1100: Loss=0.001194 | TrainAcc=1.0000
# Fold 1 Epoch 1200: Loss=0.001260 | TrainAcc=1.0000
# Fold 1 Epoch 1300: Loss=0.000864 | TrainAcc=1.0000
# Fold 1 Epoch 1400: Loss=0.000885 | TrainAcc=1.0000
# Fold 1 Epoch 1500: Loss=0.000716 | TrainAcc=1.0000
# Fold 1 Epoch 1600: Loss=0.000574 | TrainAcc=1.0000
# Fold 1 Epoch 1700: Loss=0.000549 | TrainAcc=1.0000
# Fold 1 Epoch 1800: Loss=0.000399 | TrainAcc=1.0000
# Fold 1 Epoch 1900: Loss=0.000433 | TrainAcc=1.0000
# Fold 1 Epoch 2000: Loss=0.000399 | TrainAcc=1.0000
# Fold 1 → Acc=0.7500 | Prec=0.9130 | Rec=0.7000 | F1=0.7925 | AUC=0.8381 | CE Loss=1.3639
#
# === Fold 2 ===
# Fold 2 Epoch 1: Loss=0.691034 | TrainAcc=0.5882
# Fold 2 Epoch 100: Loss=0.152214 | TrainAcc=0.9902
# Fold 2 Epoch 200: Loss=0.039024 | TrainAcc=1.0000
# Fold 2 Epoch 300: Loss=0.015767 | TrainAcc=1.0000
# Fold 2 Epoch 400: Loss=0.007431 | TrainAcc=1.0000
# Fold 2 Epoch 500: Loss=0.005989 | TrainAcc=1.0000
# Fold 2 Epoch 600: Loss=0.003170 | TrainAcc=1.0000
# Fold 2 Epoch 700: Loss=0.002538 | TrainAcc=1.0000
# Fold 2 Epoch 800: Loss=0.001935 | TrainAcc=1.0000
# Fold 2 Epoch 900: Loss=0.001356 | TrainAcc=1.0000
# Fold 2 Epoch 1000: Loss=0.001120 | TrainAcc=1.0000
# Fold 2 Epoch 1100: Loss=0.000929 | TrainAcc=1.0000
# Fold 2 Epoch 1200: Loss=0.000766 | TrainAcc=1.0000
# Fold 2 Epoch 1300: Loss=0.000732 | TrainAcc=1.0000
# Fold 2 Epoch 1400: Loss=0.000581 | TrainAcc=1.0000
# Fold 2 Epoch 1500: Loss=0.000520 | TrainAcc=1.0000
# Fold 2 Epoch 1600: Loss=0.000502 | TrainAcc=1.0000
# Fold 2 Epoch 1700: Loss=0.000421 | TrainAcc=1.0000
# Fold 2 Epoch 1800: Loss=0.000324 | TrainAcc=1.0000
# Fold 2 Epoch 1900: Loss=0.000366 | TrainAcc=1.0000
# Fold 2 Epoch 2000: Loss=0.000352 | TrainAcc=1.0000
# Fold 2 → Acc=0.5227 | Prec=0.7647 | Rec=0.4333 | F1=0.5532 | AUC=0.6762 | CE Loss=2.9829
#
# === Fold 3 ===
# Fold 3 Epoch 1: Loss=0.737177 | TrainAcc=0.5490
# Fold 3 Epoch 100: Loss=0.138233 | TrainAcc=1.0000
# Fold 3 Epoch 200: Loss=0.037640 | TrainAcc=1.0000
# Fold 3 Epoch 300: Loss=0.016369 | TrainAcc=1.0000
# Fold 3 Epoch 400: Loss=0.008323 | TrainAcc=1.0000
# Fold 3 Epoch 500: Loss=0.005214 | TrainAcc=1.0000
# Fold 3 Epoch 600: Loss=0.003529 | TrainAcc=1.0000
# Fold 3 Epoch 700: Loss=0.002329 | TrainAcc=1.0000
# Fold 3 Epoch 800: Loss=0.001507 | TrainAcc=1.0000
# Fold 3 Epoch 900: Loss=0.001558 | TrainAcc=1.0000
# Fold 3 Epoch 1000: Loss=0.001205 | TrainAcc=1.0000
# Fold 3 Epoch 1100: Loss=0.000903 | TrainAcc=1.0000
# Fold 3 Epoch 1200: Loss=0.000907 | TrainAcc=1.0000
# Fold 3 Epoch 1300: Loss=0.000741 | TrainAcc=1.0000
# Fold 3 Epoch 1400: Loss=0.000626 | TrainAcc=1.0000
# Fold 3 Epoch 1500: Loss=0.000501 | TrainAcc=1.0000
# Fold 3 Epoch 1600: Loss=0.000440 | TrainAcc=1.0000
# Fold 3 Epoch 1700: Loss=0.000425 | TrainAcc=1.0000
# Fold 3 Epoch 1800: Loss=0.000369 | TrainAcc=1.0000
# Fold 3 Epoch 1900: Loss=0.000291 | TrainAcc=1.0000
# Fold 3 Epoch 2000: Loss=0.000268 | TrainAcc=1.0000
# Fold 3 → Acc=0.5455 | Prec=0.7500 | Rec=0.5000 | F1=0.6000 | AUC=0.7119 | CE Loss=3.0971
#
# === Fold 4 ===
# Fold 4 Epoch 1: Loss=0.896550 | TrainAcc=0.3824
# Fold 4 Epoch 100: Loss=0.179386 | TrainAcc=0.9804
# Fold 4 Epoch 200: Loss=0.059337 | TrainAcc=1.0000
# Fold 4 Epoch 300: Loss=0.024292 | TrainAcc=1.0000
# Fold 4 Epoch 400: Loss=0.011338 | TrainAcc=1.0000
# Fold 4 Epoch 500: Loss=0.007093 | TrainAcc=1.0000
# Fold 4 Epoch 600: Loss=0.004317 | TrainAcc=1.0000
# Fold 4 Epoch 700: Loss=0.003054 | TrainAcc=1.0000
# Fold 4 Epoch 800: Loss=0.002391 | TrainAcc=1.0000
# Fold 4 Epoch 900: Loss=0.002456 | TrainAcc=1.0000
# Fold 4 Epoch 1000: Loss=0.001654 | TrainAcc=1.0000
# Fold 4 Epoch 1100: Loss=0.001091 | TrainAcc=1.0000
# Fold 4 Epoch 1200: Loss=0.001032 | TrainAcc=1.0000
# Fold 4 Epoch 1300: Loss=0.000906 | TrainAcc=1.0000
# Fold 4 Epoch 1400: Loss=0.000780 | TrainAcc=1.0000
# Fold 4 Epoch 1500: Loss=0.000700 | TrainAcc=1.0000
# Fold 4 Epoch 1600: Loss=0.000582 | TrainAcc=1.0000
# Fold 4 Epoch 1700: Loss=0.000504 | TrainAcc=1.0000
# Fold 4 Epoch 1800: Loss=0.000536 | TrainAcc=1.0000
# Fold 4 Epoch 1900: Loss=0.000396 | TrainAcc=1.0000
# Fold 4 Epoch 2000: Loss=0.000434 | TrainAcc=1.0000
# Fold 4 → Acc=0.6364 | Prec=0.8500 | Rec=0.5667 | F1=0.6800 | AUC=0.7405 | CE Loss=2.2182
#
# === Fold 5 ===
# Fold 5 Epoch 1: Loss=0.698522 | TrainAcc=0.5980
# Fold 5 Epoch 100: Loss=0.140264 | TrainAcc=1.0000
# Fold 5 Epoch 200: Loss=0.041163 | TrainAcc=1.0000
# Fold 5 Epoch 300: Loss=0.015010 | TrainAcc=1.0000
# Fold 5 Epoch 400: Loss=0.008134 | TrainAcc=1.0000
# Fold 5 Epoch 500: Loss=0.005754 | TrainAcc=1.0000
# Fold 5 Epoch 600: Loss=0.003719 | TrainAcc=1.0000
# Fold 5 Epoch 700: Loss=0.002371 | TrainAcc=1.0000
# Fold 5 Epoch 800: Loss=0.002293 | TrainAcc=1.0000
# Fold 5 Epoch 900: Loss=0.001617 | TrainAcc=1.0000
# Fold 5 Epoch 1000: Loss=0.001237 | TrainAcc=1.0000
# Fold 5 Epoch 1100: Loss=0.000922 | TrainAcc=1.0000
# Fold 5 Epoch 1200: Loss=0.000900 | TrainAcc=1.0000
# Fold 5 Epoch 1300: Loss=0.000855 | TrainAcc=1.0000
# Fold 5 Epoch 1400: Loss=0.000645 | TrainAcc=1.0000
# Fold 5 Epoch 1500: Loss=0.000451 | TrainAcc=1.0000
# Fold 5 Epoch 1600: Loss=0.000564 | TrainAcc=1.0000
# Fold 5 Epoch 1700: Loss=0.000492 | TrainAcc=1.0000
# Fold 5 Epoch 1800: Loss=0.000449 | TrainAcc=1.0000
# Fold 5 Epoch 1900: Loss=0.000336 | TrainAcc=1.0000
# Fold 5 Epoch 2000: Loss=0.000331 | TrainAcc=1.0000
# Fold 5 → Acc=0.6136 | Prec=0.8421 | Rec=0.5333 | F1=0.6531 | AUC=0.7333 | CE Loss=2.3896
#
# === Fold 6 ===
# Fold 6 Epoch 1: Loss=0.839456 | TrainAcc=0.4902
# Fold 6 Epoch 100: Loss=0.189366 | TrainAcc=0.9412
# Fold 6 Epoch 200: Loss=0.052834 | TrainAcc=1.0000
# Fold 6 Epoch 300: Loss=0.020232 | TrainAcc=1.0000
# Fold 6 Epoch 400: Loss=0.011695 | TrainAcc=1.0000
# Fold 6 Epoch 500: Loss=0.006249 | TrainAcc=1.0000
# Fold 6 Epoch 600: Loss=0.004318 | TrainAcc=1.0000
# Fold 6 Epoch 700: Loss=0.002759 | TrainAcc=1.0000
# Fold 6 Epoch 800: Loss=0.001974 | TrainAcc=1.0000
# Fold 6 Epoch 900: Loss=0.002089 | TrainAcc=1.0000
# Fold 6 Epoch 1000: Loss=0.001453 | TrainAcc=1.0000
# Fold 6 Epoch 1100: Loss=0.001111 | TrainAcc=1.0000
# Fold 6 Epoch 1200: Loss=0.001028 | TrainAcc=1.0000
# Fold 6 Epoch 1300: Loss=0.000871 | TrainAcc=1.0000
# Fold 6 Epoch 1400: Loss=0.000893 | TrainAcc=1.0000
# Fold 6 Epoch 1500: Loss=0.000608 | TrainAcc=1.0000
# Fold 6 Epoch 1600: Loss=0.000641 | TrainAcc=1.0000
# Fold 6 Epoch 1700: Loss=0.000435 | TrainAcc=1.0000
# Fold 6 Epoch 1800: Loss=0.000471 | TrainAcc=1.0000
# Fold 6 Epoch 1900: Loss=0.000428 | TrainAcc=1.0000
# Fold 6 Epoch 2000: Loss=0.000411 | TrainAcc=1.0000
# Fold 6 → Acc=0.6136 | Prec=0.7826 | Rec=0.6000 | F1=0.6792 | AUC=0.7476 | CE Loss=2.3805
#
# === Fold 7 ===
# Fold 7 Epoch 1: Loss=0.718744 | TrainAcc=0.5294
# Fold 7 Epoch 100: Loss=0.139827 | TrainAcc=0.9804
# Fold 7 Epoch 200: Loss=0.041082 | TrainAcc=1.0000
# Fold 7 Epoch 300: Loss=0.016135 | TrainAcc=1.0000
# Fold 7 Epoch 400: Loss=0.006242 | TrainAcc=1.0000
# Fold 7 Epoch 500: Loss=0.005126 | TrainAcc=1.0000
# Fold 7 Epoch 600: Loss=0.003236 | TrainAcc=1.0000
# Fold 7 Epoch 700: Loss=0.002596 | TrainAcc=1.0000
# Fold 7 Epoch 800: Loss=0.001621 | TrainAcc=1.0000
# Fold 7 Epoch 900: Loss=0.001203 | TrainAcc=1.0000
# Fold 7 Epoch 1000: Loss=0.001022 | TrainAcc=1.0000
# Fold 7 Epoch 1100: Loss=0.000955 | TrainAcc=1.0000
# Fold 7 Epoch 1200: Loss=0.000592 | TrainAcc=1.0000
# Fold 7 Epoch 1300: Loss=0.000537 | TrainAcc=1.0000
# Fold 7 Epoch 1400: Loss=0.000629 | TrainAcc=1.0000
# Fold 7 Epoch 1500: Loss=0.000480 | TrainAcc=1.0000
# Fold 7 Epoch 1600: Loss=0.000384 | TrainAcc=1.0000
# Fold 7 Epoch 1700: Loss=0.000365 | TrainAcc=1.0000
# Fold 7 Epoch 1800: Loss=0.000354 | TrainAcc=1.0000
# Fold 7 Epoch 1900: Loss=0.000288 | TrainAcc=1.0000
# Fold 7 Epoch 2000: Loss=0.000260 | TrainAcc=1.0000
# Fold 7 → Acc=0.5909 | Prec=0.8750 | Rec=0.4667 | F1=0.6087 | AUC=0.7333 | CE Loss=2.6178
#
# === Fold 8 ===
# Fold 8 Epoch 1: Loss=0.712835 | TrainAcc=0.6176
# Fold 8 Epoch 100: Loss=0.118890 | TrainAcc=1.0000
# Fold 8 Epoch 200: Loss=0.029151 | TrainAcc=1.0000
# Fold 8 Epoch 300: Loss=0.011892 | TrainAcc=1.0000
# Fold 8 Epoch 400: Loss=0.007324 | TrainAcc=1.0000
# Fold 8 Epoch 500: Loss=0.003732 | TrainAcc=1.0000
# Fold 8 Epoch 600: Loss=0.002605 | TrainAcc=1.0000
# Fold 8 Epoch 700: Loss=0.001799 | TrainAcc=1.0000
# Fold 8 Epoch 800: Loss=0.001395 | TrainAcc=1.0000
# Fold 8 Epoch 900: Loss=0.001233 | TrainAcc=1.0000
# Fold 8 Epoch 1000: Loss=0.000868 | TrainAcc=1.0000
# Fold 8 Epoch 1100: Loss=0.000732 | TrainAcc=1.0000
# Fold 8 Epoch 1200: Loss=0.000648 | TrainAcc=1.0000
# Fold 8 Epoch 1300: Loss=0.000596 | TrainAcc=1.0000
# Fold 8 Epoch 1400: Loss=0.000571 | TrainAcc=1.0000
# Fold 8 Epoch 1500: Loss=0.000359 | TrainAcc=1.0000
# Fold 8 Epoch 1600: Loss=0.000367 | TrainAcc=1.0000
# Fold 8 Epoch 1700: Loss=0.000349 | TrainAcc=1.0000
# Fold 8 Epoch 1800: Loss=0.000313 | TrainAcc=1.0000
# Fold 8 Epoch 1900: Loss=0.000249 | TrainAcc=1.0000
# Fold 8 Epoch 2000: Loss=0.000251 | TrainAcc=1.0000
# Fold 8 → Acc=0.5455 | Prec=0.8125 | Rec=0.4333 | F1=0.5652 | AUC=0.6500 | CE Loss=3.2069
#
# === Fold 9 ===
# Fold 9 Epoch 1: Loss=0.832365 | TrainAcc=0.4902
# Fold 9 Epoch 100: Loss=0.162269 | TrainAcc=1.0000
# Fold 9 Epoch 200: Loss=0.041686 | TrainAcc=1.0000
# Fold 9 Epoch 300: Loss=0.019441 | TrainAcc=1.0000
# Fold 9 Epoch 400: Loss=0.008357 | TrainAcc=1.0000
# Fold 9 Epoch 500: Loss=0.005679 | TrainAcc=1.0000
# Fold 9 Epoch 600: Loss=0.004039 | TrainAcc=1.0000
# Fold 9 Epoch 700: Loss=0.003139 | TrainAcc=1.0000
# Fold 9 Epoch 800: Loss=0.002392 | TrainAcc=1.0000
# Fold 9 Epoch 900: Loss=0.001462 | TrainAcc=1.0000
# Fold 9 Epoch 1000: Loss=0.001229 | TrainAcc=1.0000
# Fold 9 Epoch 1100: Loss=0.000997 | TrainAcc=1.0000
# Fold 9 Epoch 1200: Loss=0.000960 | TrainAcc=1.0000
# Fold 9 Epoch 1300: Loss=0.000780 | TrainAcc=1.0000
# Fold 9 Epoch 1400: Loss=0.000592 | TrainAcc=1.0000
# Fold 9 Epoch 1500: Loss=0.000504 | TrainAcc=1.0000
# Fold 9 Epoch 1600: Loss=0.000503 | TrainAcc=1.0000
# Fold 9 Epoch 1700: Loss=0.000501 | TrainAcc=1.0000
# Fold 9 Epoch 1800: Loss=0.000362 | TrainAcc=1.0000
# Fold 9 Epoch 1900: Loss=0.000299 | TrainAcc=1.0000
# Fold 9 Epoch 2000: Loss=0.000298 | TrainAcc=1.0000
# Fold 9 → Acc=0.5682 | Prec=0.7895 | Rec=0.5000 | F1=0.6122 | AUC=0.6857 | CE Loss=2.4240
#
# === Fold 10 ===
# Fold 10 Epoch 1: Loss=0.833426 | TrainAcc=0.4804
# Fold 10 Epoch 100: Loss=0.184236 | TrainAcc=0.9902
# Fold 10 Epoch 200: Loss=0.063371 | TrainAcc=1.0000
# Fold 10 Epoch 300: Loss=0.023325 | TrainAcc=1.0000
# Fold 10 Epoch 400: Loss=0.013648 | TrainAcc=1.0000
# Fold 10 Epoch 500: Loss=0.006225 | TrainAcc=1.0000
# Fold 10 Epoch 600: Loss=0.004077 | TrainAcc=1.0000
# Fold 10 Epoch 700: Loss=0.003516 | TrainAcc=1.0000
# Fold 10 Epoch 800: Loss=0.002711 | TrainAcc=1.0000
# Fold 10 Epoch 900: Loss=0.001907 | TrainAcc=1.0000
# Fold 10 Epoch 1000: Loss=0.001643 | TrainAcc=1.0000
# Fold 10 Epoch 1100: Loss=0.001221 | TrainAcc=1.0000
# Fold 10 Epoch 1200: Loss=0.001034 | TrainAcc=1.0000
# Fold 10 Epoch 1300: Loss=0.000889 | TrainAcc=1.0000
# Fold 10 Epoch 1400: Loss=0.000738 | TrainAcc=1.0000
# Fold 10 Epoch 1500: Loss=0.000689 | TrainAcc=1.0000
# Fold 10 Epoch 1600: Loss=0.000589 | TrainAcc=1.0000
# Fold 10 Epoch 1700: Loss=0.000473 | TrainAcc=1.0000
# Fold 10 Epoch 1800: Loss=0.000462 | TrainAcc=1.0000
# Fold 10 Epoch 1900: Loss=0.000488 | TrainAcc=1.0000
# Fold 10 Epoch 2000: Loss=0.000335 | TrainAcc=1.0000
# Fold 10 → Acc=0.6818 | Prec=0.9444 | Rec=0.5667 | F1=0.7083 | AUC=0.8595 | CE Loss=1.6152
#
# === Fold 11 ===
# Fold 11 Epoch 1: Loss=0.728817 | TrainAcc=0.5196
# Fold 11 Epoch 100: Loss=0.142938 | TrainAcc=0.9902
# Fold 11 Epoch 200: Loss=0.046465 | TrainAcc=1.0000
# Fold 11 Epoch 300: Loss=0.018499 | TrainAcc=1.0000
# Fold 11 Epoch 400: Loss=0.008435 | TrainAcc=1.0000
# Fold 11 Epoch 500: Loss=0.006308 | TrainAcc=1.0000
# Fold 11 Epoch 600: Loss=0.003369 | TrainAcc=1.0000
# Fold 11 Epoch 700: Loss=0.002474 | TrainAcc=1.0000
# Fold 11 Epoch 800: Loss=0.001904 | TrainAcc=1.0000
# Fold 11 Epoch 900: Loss=0.001247 | TrainAcc=1.0000
# Fold 11 Epoch 1000: Loss=0.001219 | TrainAcc=1.0000
# Fold 11 Epoch 1100: Loss=0.001110 | TrainAcc=1.0000
# Fold 11 Epoch 1200: Loss=0.000916 | TrainAcc=1.0000
# Fold 11 Epoch 1300: Loss=0.000698 | TrainAcc=1.0000
# Fold 11 Epoch 1400: Loss=0.000538 | TrainAcc=1.0000
# Fold 11 Epoch 1500: Loss=0.000548 | TrainAcc=1.0000
# Fold 11 Epoch 1600: Loss=0.000465 | TrainAcc=1.0000
# Fold 11 Epoch 1700: Loss=0.000413 | TrainAcc=1.0000
# Fold 11 Epoch 1800: Loss=0.000492 | TrainAcc=1.0000
# Fold 11 Epoch 1900: Loss=0.000342 | TrainAcc=1.0000
# Fold 11 Epoch 2000: Loss=0.000330 | TrainAcc=1.0000
# Fold 11 → Acc=0.5909 | Prec=0.8000 | Rec=0.5333 | F1=0.6400 | AUC=0.7024 | CE Loss=2.9724
#
# === Fold 12 ===
# Fold 12 Epoch 1: Loss=1.004176 | TrainAcc=0.3137
# Fold 12 Epoch 100: Loss=0.165179 | TrainAcc=0.9902
# Fold 12 Epoch 200: Loss=0.045981 | TrainAcc=1.0000
# Fold 12 Epoch 300: Loss=0.020449 | TrainAcc=1.0000
# Fold 12 Epoch 400: Loss=0.009698 | TrainAcc=1.0000
# Fold 12 Epoch 500: Loss=0.006383 | TrainAcc=1.0000
# Fold 12 Epoch 600: Loss=0.004059 | TrainAcc=1.0000
# Fold 12 Epoch 700: Loss=0.002640 | TrainAcc=1.0000
# Fold 12 Epoch 800: Loss=0.001921 | TrainAcc=1.0000
# Fold 12 Epoch 900: Loss=0.001565 | TrainAcc=1.0000
# Fold 12 Epoch 1000: Loss=0.001491 | TrainAcc=1.0000
# Fold 12 Epoch 1100: Loss=0.001036 | TrainAcc=1.0000
# Fold 12 Epoch 1200: Loss=0.000865 | TrainAcc=1.0000
# Fold 12 Epoch 1300: Loss=0.000624 | TrainAcc=1.0000
# Fold 12 Epoch 1400: Loss=0.000704 | TrainAcc=1.0000
# Fold 12 Epoch 1500: Loss=0.000616 | TrainAcc=1.0000
# Fold 12 Epoch 1600: Loss=0.000425 | TrainAcc=1.0000
# Fold 12 Epoch 1700: Loss=0.000402 | TrainAcc=1.0000
# Fold 12 Epoch 1800: Loss=0.000384 | TrainAcc=1.0000
# Fold 12 Epoch 1900: Loss=0.000384 | TrainAcc=1.0000
# Fold 12 Epoch 2000: Loss=0.000292 | TrainAcc=1.0000
# Fold 12 → Acc=0.6591 | Prec=0.8947 | Rec=0.5667 | F1=0.6939 | AUC=0.7429 | CE Loss=2.3604
#
# === Fold 13 ===
# Fold 13 Epoch 1: Loss=0.724903 | TrainAcc=0.5294
# Fold 13 Epoch 100: Loss=0.176121 | TrainAcc=0.9706
# Fold 13 Epoch 200: Loss=0.053724 | TrainAcc=1.0000
# Fold 13 Epoch 300: Loss=0.020804 | TrainAcc=1.0000
# Fold 13 Epoch 400: Loss=0.009682 | TrainAcc=1.0000
# Fold 13 Epoch 500: Loss=0.006489 | TrainAcc=1.0000
# Fold 13 Epoch 600: Loss=0.003860 | TrainAcc=1.0000
# Fold 13 Epoch 700: Loss=0.002586 | TrainAcc=1.0000
# Fold 13 Epoch 800: Loss=0.002081 | TrainAcc=1.0000
# Fold 13 Epoch 900: Loss=0.001799 | TrainAcc=1.0000
# Fold 13 Epoch 1000: Loss=0.001319 | TrainAcc=1.0000
# Fold 13 Epoch 1100: Loss=0.001110 | TrainAcc=1.0000
# Fold 13 Epoch 1200: Loss=0.000884 | TrainAcc=1.0000
# Fold 13 Epoch 1300: Loss=0.000800 | TrainAcc=1.0000
# Fold 13 Epoch 1400: Loss=0.000735 | TrainAcc=1.0000
# Fold 13 Epoch 1500: Loss=0.000651 | TrainAcc=1.0000
# Fold 13 Epoch 1600: Loss=0.000521 | TrainAcc=1.0000
# Fold 13 Epoch 1700: Loss=0.000418 | TrainAcc=1.0000
# Fold 13 Epoch 1800: Loss=0.000516 | TrainAcc=1.0000
# Fold 13 Epoch 1900: Loss=0.000393 | TrainAcc=1.0000
# Fold 13 Epoch 2000: Loss=0.000335 | TrainAcc=1.0000
# Fold 13 → Acc=0.6591 | Prec=0.8947 | Rec=0.5667 | F1=0.6939 | AUC=0.8548 | CE Loss=2.0497
#
# === Fold 14 ===
# Fold 14 Epoch 1: Loss=0.777745 | TrainAcc=0.4804
# Fold 14 Epoch 100: Loss=0.165321 | TrainAcc=0.9706
# Fold 14 Epoch 200: Loss=0.050719 | TrainAcc=1.0000
# Fold 14 Epoch 300: Loss=0.023019 | TrainAcc=1.0000
# Fold 14 Epoch 400: Loss=0.010451 | TrainAcc=1.0000
# Fold 14 Epoch 500: Loss=0.006664 | TrainAcc=1.0000
# Fold 14 Epoch 600: Loss=0.004772 | TrainAcc=1.0000
# Fold 14 Epoch 700: Loss=0.003473 | TrainAcc=1.0000
# Fold 14 Epoch 800: Loss=0.002787 | TrainAcc=1.0000
# Fold 14 Epoch 900: Loss=0.001853 | TrainAcc=1.0000
# Fold 14 Epoch 1000: Loss=0.001438 | TrainAcc=1.0000
# Fold 14 Epoch 1100: Loss=0.001443 | TrainAcc=1.0000
# Fold 14 Epoch 1200: Loss=0.001099 | TrainAcc=1.0000
# Fold 14 Epoch 1300: Loss=0.000962 | TrainAcc=1.0000
# Fold 14 Epoch 1400: Loss=0.000798 | TrainAcc=1.0000
# Fold 14 Epoch 1500: Loss=0.000651 | TrainAcc=1.0000
# Fold 14 Epoch 1600: Loss=0.000566 | TrainAcc=1.0000
# Fold 14 Epoch 1700: Loss=0.000531 | TrainAcc=1.0000
# Fold 14 Epoch 1800: Loss=0.000476 | TrainAcc=1.0000
# Fold 14 Epoch 1900: Loss=0.000468 | TrainAcc=1.0000
# Fold 14 Epoch 2000: Loss=0.000494 | TrainAcc=1.0000
# Fold 14 → Acc=0.5000 | Prec=0.6818 | Rec=0.5000 | F1=0.5769 | AUC=0.6048 | CE Loss=2.8635
#
# === Fold 15 ===
# Fold 15 Epoch 1: Loss=0.855652 | TrainAcc=0.4314
# Fold 15 Epoch 100: Loss=0.185940 | TrainAcc=0.9706
# Fold 15 Epoch 200: Loss=0.050430 | TrainAcc=1.0000
# Fold 15 Epoch 300: Loss=0.019103 | TrainAcc=1.0000
# Fold 15 Epoch 400: Loss=0.010954 | TrainAcc=1.0000
# Fold 15 Epoch 500: Loss=0.005663 | TrainAcc=1.0000
# Fold 15 Epoch 600: Loss=0.003880 | TrainAcc=1.0000
# Fold 15 Epoch 700: Loss=0.002776 | TrainAcc=1.0000
# Fold 15 Epoch 800: Loss=0.002047 | TrainAcc=1.0000
# Fold 15 Epoch 900: Loss=0.001853 | TrainAcc=1.0000
# Fold 15 Epoch 1000: Loss=0.001209 | TrainAcc=1.0000
# Fold 15 Epoch 1100: Loss=0.000973 | TrainAcc=1.0000
# Fold 15 Epoch 1200: Loss=0.000780 | TrainAcc=1.0000
# Fold 15 Epoch 1300: Loss=0.000836 | TrainAcc=1.0000
# Fold 15 Epoch 1400: Loss=0.000641 | TrainAcc=1.0000
# Fold 15 Epoch 1500: Loss=0.000652 | TrainAcc=1.0000
# Fold 15 Epoch 1600: Loss=0.000576 | TrainAcc=1.0000
# Fold 15 Epoch 1700: Loss=0.000542 | TrainAcc=1.0000
# Fold 15 Epoch 1800: Loss=0.000430 | TrainAcc=1.0000
# Fold 15 Epoch 1900: Loss=0.000412 | TrainAcc=1.0000
# Fold 15 Epoch 2000: Loss=0.000335 | TrainAcc=1.0000
# Fold 15 → Acc=0.6591 | Prec=0.8947 | Rec=0.5667 | F1=0.6939 | AUC=0.7762 | CE Loss=2.8288
#
# === Fold 16 ===
# Fold 16 Epoch 1: Loss=0.675281 | TrainAcc=0.5882
# Fold 16 Epoch 100: Loss=0.150978 | TrainAcc=0.9706
# Fold 16 Epoch 200: Loss=0.045164 | TrainAcc=1.0000
# Fold 16 Epoch 300: Loss=0.016747 | TrainAcc=1.0000
# Fold 16 Epoch 400: Loss=0.008194 | TrainAcc=1.0000
# Fold 16 Epoch 500: Loss=0.004898 | TrainAcc=1.0000
# Fold 16 Epoch 600: Loss=0.003343 | TrainAcc=1.0000
# Fold 16 Epoch 700: Loss=0.002944 | TrainAcc=1.0000
# Fold 16 Epoch 800: Loss=0.001975 | TrainAcc=1.0000
# Fold 16 Epoch 900: Loss=0.001379 | TrainAcc=1.0000
# Fold 16 Epoch 1000: Loss=0.001086 | TrainAcc=1.0000
# Fold 16 Epoch 1100: Loss=0.000924 | TrainAcc=1.0000
# Fold 16 Epoch 1200: Loss=0.000884 | TrainAcc=1.0000
# Fold 16 Epoch 1300: Loss=0.000694 | TrainAcc=1.0000
# Fold 16 Epoch 1400: Loss=0.000607 | TrainAcc=1.0000
# Fold 16 Epoch 1500: Loss=0.000559 | TrainAcc=1.0000
# Fold 16 Epoch 1600: Loss=0.000396 | TrainAcc=1.0000
# Fold 16 Epoch 1700: Loss=0.000445 | TrainAcc=1.0000
# Fold 16 Epoch 1800: Loss=0.000334 | TrainAcc=1.0000
# Fold 16 Epoch 1900: Loss=0.000361 | TrainAcc=1.0000
# Fold 16 Epoch 2000: Loss=0.000315 | TrainAcc=1.0000
# Fold 16 → Acc=0.6364 | Prec=0.8500 | Rec=0.5667 | F1=0.6800 | AUC=0.7095 | CE Loss=2.2587
#
# === Fold 17 ===
# Fold 17 Epoch 1: Loss=0.676410 | TrainAcc=0.6176
# Fold 17 Epoch 100: Loss=0.133911 | TrainAcc=1.0000
# Fold 17 Epoch 200: Loss=0.038471 | TrainAcc=1.0000
# Fold 17 Epoch 300: Loss=0.015044 | TrainAcc=1.0000
# Fold 17 Epoch 400: Loss=0.007515 | TrainAcc=1.0000
# Fold 17 Epoch 500: Loss=0.004480 | TrainAcc=1.0000
# Fold 17 Epoch 600: Loss=0.003833 | TrainAcc=1.0000
# Fold 17 Epoch 700: Loss=0.002197 | TrainAcc=1.0000
# Fold 17 Epoch 800: Loss=0.001520 | TrainAcc=1.0000
# Fold 17 Epoch 900: Loss=0.001287 | TrainAcc=1.0000
# Fold 17 Epoch 1000: Loss=0.001236 | TrainAcc=1.0000
# Fold 17 Epoch 1100: Loss=0.001050 | TrainAcc=1.0000
# Fold 17 Epoch 1200: Loss=0.000750 | TrainAcc=1.0000
# Fold 17 Epoch 1300: Loss=0.000750 | TrainAcc=1.0000
# Fold 17 Epoch 1400: Loss=0.000723 | TrainAcc=1.0000
# Fold 17 Epoch 1500: Loss=0.000492 | TrainAcc=1.0000
# Fold 17 Epoch 1600: Loss=0.000477 | TrainAcc=1.0000
# Fold 17 Epoch 1700: Loss=0.000427 | TrainAcc=1.0000
# Fold 17 Epoch 1800: Loss=0.000374 | TrainAcc=1.0000
# Fold 17 Epoch 1900: Loss=0.000385 | TrainAcc=1.0000
# Fold 17 Epoch 2000: Loss=0.000293 | TrainAcc=1.0000
# Fold 17 → Acc=0.5455 | Prec=0.7500 | Rec=0.5000 | F1=0.6000 | AUC=0.6119 | CE Loss=2.7912
#
# === Fold 18 ===
# Fold 18 Epoch 1: Loss=0.735367 | TrainAcc=0.5686
# Fold 18 Epoch 100: Loss=0.168334 | TrainAcc=0.9804
# Fold 18 Epoch 200: Loss=0.046554 | TrainAcc=1.0000
# Fold 18 Epoch 300: Loss=0.018287 | TrainAcc=1.0000
# Fold 18 Epoch 400: Loss=0.009798 | TrainAcc=1.0000
# Fold 18 Epoch 500: Loss=0.004627 | TrainAcc=1.0000
# Fold 18 Epoch 600: Loss=0.004060 | TrainAcc=1.0000
# Fold 18 Epoch 700: Loss=0.002893 | TrainAcc=1.0000
# Fold 18 Epoch 800: Loss=0.001632 | TrainAcc=1.0000
# Fold 18 Epoch 900: Loss=0.001368 | TrainAcc=1.0000
# Fold 18 Epoch 1000: Loss=0.001237 | TrainAcc=1.0000
# Fold 18 Epoch 1100: Loss=0.001144 | TrainAcc=1.0000
# Fold 18 Epoch 1200: Loss=0.000971 | TrainAcc=1.0000
# Fold 18 Epoch 1300: Loss=0.000685 | TrainAcc=1.0000
# Fold 18 Epoch 1400: Loss=0.000805 | TrainAcc=1.0000
# Fold 18 Epoch 1500: Loss=0.000531 | TrainAcc=1.0000
# Fold 18 Epoch 1600: Loss=0.000500 | TrainAcc=1.0000
# Fold 18 Epoch 1700: Loss=0.000419 | TrainAcc=1.0000
# Fold 18 Epoch 1800: Loss=0.000377 | TrainAcc=1.0000
# Fold 18 Epoch 1900: Loss=0.000353 | TrainAcc=1.0000
# Fold 18 Epoch 2000: Loss=0.000347 | TrainAcc=1.0000
# Fold 18 → Acc=0.5909 | Prec=0.7500 | Rec=0.6000 | F1=0.6667 | AUC=0.6976 | CE Loss=2.4699
#
# === Fold 19 ===
# Fold 19 Epoch 1: Loss=0.802229 | TrainAcc=0.4314
# Fold 19 Epoch 100: Loss=0.135408 | TrainAcc=0.9706
# Fold 19 Epoch 200: Loss=0.038408 | TrainAcc=1.0000
# Fold 19 Epoch 300: Loss=0.018080 | TrainAcc=1.0000
# Fold 19 Epoch 400: Loss=0.009536 | TrainAcc=1.0000
# Fold 19 Epoch 500: Loss=0.004920 | TrainAcc=1.0000
# Fold 19 Epoch 600: Loss=0.003983 | TrainAcc=1.0000
# Fold 19 Epoch 700: Loss=0.002909 | TrainAcc=1.0000
# Fold 19 Epoch 800: Loss=0.001760 | TrainAcc=1.0000
# Fold 19 Epoch 900: Loss=0.001361 | TrainAcc=1.0000
# Fold 19 Epoch 1000: Loss=0.001174 | TrainAcc=1.0000
# Fold 19 Epoch 1100: Loss=0.000987 | TrainAcc=1.0000
# Fold 19 Epoch 1200: Loss=0.000792 | TrainAcc=1.0000
# Fold 19 Epoch 1300: Loss=0.000643 | TrainAcc=1.0000
# Fold 19 Epoch 1400: Loss=0.000582 | TrainAcc=1.0000
# Fold 19 Epoch 1500: Loss=0.000561 | TrainAcc=1.0000
# Fold 19 Epoch 1600: Loss=0.000499 | TrainAcc=1.0000
# Fold 19 Epoch 1700: Loss=0.000442 | TrainAcc=1.0000
# Fold 19 Epoch 1800: Loss=0.000415 | TrainAcc=1.0000
# Fold 19 Epoch 1900: Loss=0.000344 | TrainAcc=1.0000
# Fold 19 Epoch 2000: Loss=0.000325 | TrainAcc=1.0000
# Fold 19 → Acc=0.5227 | Prec=0.7368 | Rec=0.4667 | F1=0.5714 | AUC=0.6643 | CE Loss=2.5786
#
# === Fold 20 ===
# Fold 20 Epoch 1: Loss=0.808507 | TrainAcc=0.4510
# Fold 20 Epoch 100: Loss=0.189252 | TrainAcc=0.9804
# Fold 20 Epoch 200: Loss=0.058130 | TrainAcc=1.0000
# Fold 20 Epoch 300: Loss=0.022811 | TrainAcc=1.0000
# Fold 20 Epoch 400: Loss=0.010179 | TrainAcc=1.0000
# Fold 20 Epoch 500: Loss=0.006960 | TrainAcc=1.0000
# Fold 20 Epoch 600: Loss=0.004039 | TrainAcc=1.0000
# Fold 20 Epoch 700: Loss=0.002896 | TrainAcc=1.0000
# Fold 20 Epoch 800: Loss=0.002068 | TrainAcc=1.0000
# Fold 20 Epoch 900: Loss=0.001806 | TrainAcc=1.0000
# Fold 20 Epoch 1000: Loss=0.001351 | TrainAcc=1.0000
# Fold 20 Epoch 1100: Loss=0.001135 | TrainAcc=1.0000
# Fold 20 Epoch 1200: Loss=0.000869 | TrainAcc=1.0000
# Fold 20 Epoch 1300: Loss=0.000939 | TrainAcc=1.0000
# Fold 20 Epoch 1400: Loss=0.000837 | TrainAcc=1.0000
# Fold 20 Epoch 1500: Loss=0.000679 | TrainAcc=1.0000
# Fold 20 Epoch 1600: Loss=0.000697 | TrainAcc=1.0000
# Fold 20 Epoch 1700: Loss=0.000484 | TrainAcc=1.0000
# Fold 20 Epoch 1800: Loss=0.000371 | TrainAcc=1.0000
# Fold 20 Epoch 1900: Loss=0.000361 | TrainAcc=1.0000
# Fold 20 Epoch 2000: Loss=0.000393 | TrainAcc=1.0000
# Fold 20 → Acc=0.6591 | Prec=0.8947 | Rec=0.5667 | F1=0.6939 | AUC=0.7214 | CE Loss=2.1218
#
# === Average Results Across 20 Folds ===
# Accuracy:  0.6045 ± 0.0624
# Precision: 0.8236 ± 0.0700
# Recall:    0.5367 ± 0.0623
# F1-score:  0.6481 ± 0.0594
# CE Loss:   2.4796 ± 0.4615
# AUC:       0.7231 ± 0.0684
