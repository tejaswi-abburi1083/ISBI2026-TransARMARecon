# %%
import os
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as nnFn
import torch.optim as optim
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, log_loss
from torch_geometric.data import Data
from torch_geometric.nn import GCNConv

device = 'cuda' if torch.cuda.is_available() else 'cpu'
print("Device:", device)

control_path = "/home/snu/Downloads/NIFD_Patients_FA_Histogram_Feature.npy"
patient_path = "/home/snu/Downloads/NIFD_Control_FA_Histogram_Feature.npy"

Histogram_feature_Control_FA_array = np.load(control_path, allow_pickle=True)
Histogram_feature_Patient_FA_array = np.load(patient_path, allow_pickle=True)

X = np.vstack([Histogram_feature_Control_FA_array, Histogram_feature_Patient_FA_array])
y = np.hstack([
    np.zeros(Histogram_feature_Control_FA_array.shape[0], dtype=np.int64),
    np.ones(Histogram_feature_Patient_FA_array.shape[0], dtype=np.int64)
])

num_nodes, num_feats = X.shape
print(f"Features: {X.shape}, Labels: {y.shape}")

# Shuffle for reproducibility
rng = np.random.RandomState(42)
perm = rng.permutation(num_nodes)
X = X[perm]
y = y[perm]

def create_adj(F_data, alpha=1):
    norms = np.linalg.norm(F_data, axis=1, keepdims=True)
    norms[norms == 0] = 1.0
    F_norm = F_data / norms
    W = np.dot(F_norm, F_norm.T)
    W = np.where(W >= alpha, 1.0, 0.0).astype(np.float32)
    if W.max() > 0:
        W = W / W.max()
    return W

alpha = 0.7
W = create_adj(X, alpha=alpha)
np.fill_diagonal(W, 1.0)

def load_data(adj, node_feats):
    node_feats = torch.from_numpy(node_feats).float()
    rows, cols = np.nonzero(adj > 0)
    edge_index = torch.from_numpy(np.vstack([rows, cols]).astype(np.int64))
    return Data(x=node_feats, edge_index=edge_index)

data = load_data(W, X).to(device)
print(data)

class GCN_AE(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim, device, activ="RELU", dropout=0.25):
        super(GCN_AE, self).__init__()
        self.device = device

        # --- Encoder ---
        self.conv1 = GCNConv(input_dim, hidden_dim)
        self.bn1 = nn.BatchNorm1d(hidden_dim)
        self.dropout = nn.Dropout(dropout)
        self.fc = nn.Linear(hidden_dim, output_dim)

        # --- Decoder ---
        self.decoder = nn.Sequential(
            nn.Linear(hidden_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, input_dim)
        )

        # --- Activation ---
        activations = {
            "SELU": nnFn.selu,
            "SiLU": nnFn.silu,
            "GELU": nnFn.gelu,
            "RELU": nnFn.relu,
            "ELU": nnFn.elu
        }
        self.act = activations.get(activ, nnFn.relu)

    def forward(self, x, edge_index):
        # Encoder
        h = self.conv1(x, edge_index)
        h = self.bn1(h)
        h = self.act(h)
        h = self.dropout(h)

        # Classification
        logits = self.fc(h)

        # Reconstruction
        recon = self.decoder(h)

        return logits, recon, h



feats_dim = num_feats
hidden_dim = 512
num_classes = 2
num_epochs = 2000
lr = 1e-4
weight_decay = 1e-4
batch_print_freq = 100
lambda_recon = 0.05

sss = StratifiedShuffleSplit(n_splits=20, test_size=0.3, random_state=42)
accuracies, precisions, recalls, f1_scores, aucs, ce_losses = [], [], [], [], [], []
y_all = y.copy()

for fold, (train_val_idx, test_idx_global) in enumerate(sss.split(X, y_all), start=1):
    print(f"\n=== Fold {fold} ===")
    control_idx = np.where(y_all == 0)[0]
    patient_idx = np.where(y_all == 1)[0]
    sss_class = StratifiedShuffleSplit(n_splits=20, test_size=0.3, random_state=fold)
    control_train_idx, _ = next(sss_class.split(X[control_idx], y_all[control_idx]))
    patient_train_idx, _ = next(sss_class.split(X[patient_idx], y_all[patient_idx]))
    control_train = control_idx[control_train_idx]
    patient_train = patient_idx[patient_train_idx]
    train_idx_final = np.concatenate([control_train, patient_train])
    np.random.shuffle(train_idx_final)

    print(f"Train Control: {len(control_train)}, Train Patient: {len(patient_train)}")
    train_idx_t = torch.from_numpy(train_idx_final).long().to(device)
    y_train_tensor = torch.from_numpy(y_all[train_idx_final]).long().to(device)

    model = GCN_AE(feats_dim, hidden_dim, num_classes, device, activ="RELU", dropout=0.25).to(device)
    optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
    ce_loss_fn = nn.CrossEntropyLoss()
    recon_loss_fn = nn.MSELoss()
    data = load_data(W, X).to(device)

    for epoch in range(1, num_epochs + 1):
        model.train()
        optimizer.zero_grad()
        logits, recon_x, _ = model(data.x, data.edge_index)

        loss_sup = ce_loss_fn(logits[train_idx_t], y_train_tensor)
        loss_recon = recon_loss_fn(recon_x, data.x)
        total_loss = loss_sup + lambda_recon * loss_recon

        if torch.isnan(total_loss) or torch.isinf(total_loss):
            print(f"NaN/Inf detected at fold {fold} epoch {epoch}. Aborting epoch.")
            break

        total_loss.backward()
        optimizer.step()

        if epoch % batch_print_freq == 0 or epoch == 1:
            model.eval()
            with torch.no_grad():
                logits_eval, _, _ = model(data.x, data.edge_index)
                preds_train = logits_eval[train_idx_t].argmax(dim=1)
                acc_train = accuracy_score(y_train_tensor.cpu(), preds_train.cpu())
            print(f"Fold {fold} Epoch {epoch}: TotalLoss={total_loss.item():.6f} | Sup={loss_sup.item():.6f} | Recon={loss_recon.item():.6f} | TrainAcc={acc_train:.4f}")

    model.eval()
    with torch.no_grad():
        out_logits, _, _ = model(data.x, data.edge_index)
        preds = out_logits.argmax(dim=1).cpu().numpy()
        probs = nnFn.softmax(out_logits, dim=1)[:, 1].cpu().numpy()

    y_test = y_all[test_idx_global]
    y_pred_test = preds[test_idx_global]
    y_prob_test = probs[test_idx_global]

    acc = accuracy_score(y_test, y_pred_test)
    prec = precision_score(y_test, y_pred_test, zero_division=0)
    rec = recall_score(y_test, y_pred_test, zero_division=0)
    f1 = f1_score(y_test, y_pred_test, zero_division=0)
    try:
        auc = roc_auc_score(y_test, y_prob_test)
    except ValueError:
        auc = float('nan')
    ce = log_loss(y_test, y_prob_test)

    accuracies.append(acc)
    precisions.append(prec)
    recalls.append(rec)
    f1_scores.append(f1)
    aucs.append(auc)
    ce_losses.append(ce)

    print(f"Fold {fold} → Acc={acc:.4f} | Prec={prec:.4f} | Rec={rec:.4f} | F1={f1:.4f} | AUC={auc:.4f} | CE Loss={ce:.4f}")


print("\n=== Average Results Across 20 Folds ===")
print(f"Accuracy:  {np.mean(accuracies):.4f} ± {np.std(accuracies):.4f}")
print(f"Precision: {np.mean(precisions):.4f} ± {np.std(precisions):.4f}")
print(f"Recall:    {np.mean(recalls):.4f} ± {np.std(recalls):.4f}")
print(f"F1-score:  {np.mean(f1_scores):.4f} ± {np.std(f1_scores):.4f}")
print(f"CE Loss:   {np.mean(ce_losses):.4f} ± {np.std(ce_losses):.4f}")
print(f"AUC:       {np.nanmean(aucs):.4f} ± {np.nanstd(aucs):.4f}")
# Out:
# Device: cuda
# Features: (146, 180), Labels: (146,)
# Data(x=[146, 180], edge_index=[2, 18460])
#
# === Fold 1 ===
# Train Control: 68, Train Patient: 33
# Fold 1 Epoch 1: TotalLoss=0.677385 | Sup=0.675963 | Recon=0.028439 | TrainAcc=0.6733
# Fold 1 Epoch 100: TotalLoss=0.493195 | Sup=0.493077 | Recon=0.002359 | TrainAcc=0.7228
# Fold 1 Epoch 200: TotalLoss=0.445542 | Sup=0.445481 | Recon=0.001221 | TrainAcc=0.7723
# Fold 1 Epoch 300: TotalLoss=0.426342 | Sup=0.426298 | Recon=0.000873 | TrainAcc=0.7822
# Fold 1 Epoch 400: TotalLoss=0.395021 | Sup=0.394982 | Recon=0.000772 | TrainAcc=0.8317
# Fold 1 Epoch 500: TotalLoss=0.363250 | Sup=0.363213 | Recon=0.000735 | TrainAcc=0.8119
# Fold 1 Epoch 600: TotalLoss=0.359740 | Sup=0.359704 | Recon=0.000720 | TrainAcc=0.8119
# Fold 1 Epoch 700: TotalLoss=0.340147 | Sup=0.340111 | Recon=0.000717 | TrainAcc=0.7921
# Fold 1 Epoch 800: TotalLoss=0.315346 | Sup=0.315310 | Recon=0.000720 | TrainAcc=0.7822
# Fold 1 Epoch 900: TotalLoss=0.306510 | Sup=0.306475 | Recon=0.000717 | TrainAcc=0.8317
# Fold 1 Epoch 1000: TotalLoss=0.292869 | Sup=0.292833 | Recon=0.000713 | TrainAcc=0.8515
# Fold 1 Epoch 1100: TotalLoss=0.283317 | Sup=0.283281 | Recon=0.000719 | TrainAcc=0.8416
# Fold 1 Epoch 1200: TotalLoss=0.264893 | Sup=0.264857 | Recon=0.000725 | TrainAcc=0.8416
# Fold 1 Epoch 1300: TotalLoss=0.252331 | Sup=0.252294 | Recon=0.000727 | TrainAcc=0.8416
# Fold 1 Epoch 1400: TotalLoss=0.241177 | Sup=0.241141 | Recon=0.000730 | TrainAcc=0.8416
# Fold 1 Epoch 1500: TotalLoss=0.226666 | Sup=0.226629 | Recon=0.000728 | TrainAcc=0.8713
# Fold 1 Epoch 1600: TotalLoss=0.221061 | Sup=0.221025 | Recon=0.000730 | TrainAcc=0.8812
# Fold 1 Epoch 1700: TotalLoss=0.202062 | Sup=0.202026 | Recon=0.000734 | TrainAcc=0.7129
# Fold 1 Epoch 1800: TotalLoss=0.200439 | Sup=0.200403 | Recon=0.000733 | TrainAcc=0.8515
# Fold 1 Epoch 1900: TotalLoss=0.184443 | Sup=0.184406 | Recon=0.000734 | TrainAcc=0.8416
# Fold 1 Epoch 2000: TotalLoss=0.172407 | Sup=0.172371 | Recon=0.000737 | TrainAcc=0.8911
# Fold 1 → Acc=0.7273 | Prec=0.6000 | Rec=0.4286 | F1=0.5000 | AUC=0.8738 | CE Loss=0.6447
#
# === Fold 2 ===
# Train Control: 68, Train Patient: 33
# Fold 2 Epoch 1: TotalLoss=0.663924 | Sup=0.662585 | Recon=0.026771 | TrainAcc=0.4455
# Fold 2 Epoch 100: TotalLoss=0.476255 | Sup=0.476133 | Recon=0.002450 | TrainAcc=0.7723
# Fold 2 Epoch 200: TotalLoss=0.423920 | Sup=0.423857 | Recon=0.001256 | TrainAcc=0.7921
# Fold 2 Epoch 300: TotalLoss=0.402657 | Sup=0.402612 | Recon=0.000908 | TrainAcc=0.8020
# Fold 2 Epoch 400: TotalLoss=0.375438 | Sup=0.375398 | Recon=0.000788 | TrainAcc=0.7624
# Fold 2 Epoch 500: TotalLoss=0.365193 | Sup=0.365155 | Recon=0.000744 | TrainAcc=0.8218
# Fold 2 Epoch 600: TotalLoss=0.335828 | Sup=0.335792 | Recon=0.000732 | TrainAcc=0.8119
# Fold 2 Epoch 700: TotalLoss=0.321983 | Sup=0.321947 | Recon=0.000725 | TrainAcc=0.8119
# Fold 2 Epoch 800: TotalLoss=0.309783 | Sup=0.309746 | Recon=0.000727 | TrainAcc=0.8317
# Fold 2 Epoch 900: TotalLoss=0.300365 | Sup=0.300329 | Recon=0.000721 | TrainAcc=0.8317
# Fold 2 Epoch 1000: TotalLoss=0.302837 | Sup=0.302801 | Recon=0.000718 | TrainAcc=0.8812
# Fold 2 Epoch 1100: TotalLoss=0.295199 | Sup=0.295162 | Recon=0.000727 | TrainAcc=0.8218
# Fold 2 Epoch 1200: TotalLoss=0.263647 | Sup=0.263611 | Recon=0.000725 | TrainAcc=0.8218
# Fold 2 Epoch 1300: TotalLoss=0.254803 | Sup=0.254767 | Recon=0.000723 | TrainAcc=0.8614
# Fold 2 Epoch 1400: TotalLoss=0.243435 | Sup=0.243398 | Recon=0.000730 | TrainAcc=0.8614
# Fold 2 Epoch 1500: TotalLoss=0.255556 | Sup=0.255520 | Recon=0.000728 | TrainAcc=0.8515
# Fold 2 Epoch 1600: TotalLoss=0.226967 | Sup=0.226931 | Recon=0.000729 | TrainAcc=0.8812
# Fold 2 Epoch 1700: TotalLoss=0.217666 | Sup=0.217629 | Recon=0.000730 | TrainAcc=0.9109
# Fold 2 Epoch 1800: TotalLoss=0.223257 | Sup=0.223220 | Recon=0.000734 | TrainAcc=0.9109
# Fold 2 Epoch 1900: TotalLoss=0.195021 | Sup=0.194984 | Recon=0.000740 | TrainAcc=0.9307
# Fold 2 Epoch 2000: TotalLoss=0.196485 | Sup=0.196448 | Recon=0.000739 | TrainAcc=0.9109
# Fold 2 → Acc=0.8636 | Prec=0.7500 | Rec=0.8571 | F1=0.8000 | AUC=0.9095 | CE Loss=0.3497
#
# === Fold 3 ===
# Train Control: 68, Train Patient: 33
# Fold 3 Epoch 1: TotalLoss=0.740965 | Sup=0.739487 | Recon=0.029563 | TrainAcc=0.6733
# Fold 3 Epoch 100: TotalLoss=0.493488 | Sup=0.493369 | Recon=0.002382 | TrainAcc=0.7129
# Fold 3 Epoch 200: TotalLoss=0.473682 | Sup=0.473620 | Recon=0.001256 | TrainAcc=0.7624
# Fold 3 Epoch 300: TotalLoss=0.432863 | Sup=0.432818 | Recon=0.000906 | TrainAcc=0.7624
# Fold 3 Epoch 400: TotalLoss=0.391052 | Sup=0.391013 | Recon=0.000783 | TrainAcc=0.7426
# Fold 3 Epoch 500: TotalLoss=0.371149 | Sup=0.371112 | Recon=0.000744 | TrainAcc=0.7921
# Fold 3 Epoch 600: TotalLoss=0.340056 | Sup=0.340019 | Recon=0.000737 | TrainAcc=0.8119
# Fold 3 Epoch 700: TotalLoss=0.311972 | Sup=0.311936 | Recon=0.000715 | TrainAcc=0.8119
# Fold 3 Epoch 800: TotalLoss=0.314125 | Sup=0.314089 | Recon=0.000721 | TrainAcc=0.8416
# Fold 3 Epoch 900: TotalLoss=0.286614 | Sup=0.286578 | Recon=0.000721 | TrainAcc=0.8416
# Fold 3 Epoch 1000: TotalLoss=0.283975 | Sup=0.283939 | Recon=0.000716 | TrainAcc=0.8317
# Fold 3 Epoch 1100: TotalLoss=0.250025 | Sup=0.249989 | Recon=0.000724 | TrainAcc=0.8020
# Fold 3 Epoch 1200: TotalLoss=0.244654 | Sup=0.244617 | Recon=0.000729 | TrainAcc=0.8416
# Fold 3 Epoch 1300: TotalLoss=0.244311 | Sup=0.244275 | Recon=0.000726 | TrainAcc=0.7723
# Fold 3 Epoch 1400: TotalLoss=0.217145 | Sup=0.217108 | Recon=0.000733 | TrainAcc=0.8614
# Fold 3 Epoch 1500: TotalLoss=0.196625 | Sup=0.196588 | Recon=0.000728 | TrainAcc=0.8614
# Fold 3 Epoch 1600: TotalLoss=0.193703 | Sup=0.193667 | Recon=0.000736 | TrainAcc=0.9010
# Fold 3 Epoch 1700: TotalLoss=0.179047 | Sup=0.179010 | Recon=0.000729 | TrainAcc=0.9109
# Fold 3 Epoch 1800: TotalLoss=0.168548 | Sup=0.168511 | Recon=0.000731 | TrainAcc=0.9208
# Fold 3 Epoch 1900: TotalLoss=0.166387 | Sup=0.166350 | Recon=0.000740 | TrainAcc=0.9208
# Fold 3 Epoch 2000: TotalLoss=0.140851 | Sup=0.140814 | Recon=0.000741 | TrainAcc=0.8713
# Fold 3 → Acc=0.8182 | Prec=0.6500 | Rec=0.9286 | F1=0.7647 | AUC=0.9310 | CE Loss=0.3498
#
# === Fold 4 ===
# Train Control: 68, Train Patient: 33
# Fold 4 Epoch 1: TotalLoss=0.749070 | Sup=0.747477 | Recon=0.031864 | TrainAcc=0.3267
# Fold 4 Epoch 100: TotalLoss=0.508800 | Sup=0.508669 | Recon=0.002615 | TrainAcc=0.7030
# Fold 4 Epoch 200: TotalLoss=0.506435 | Sup=0.506367 | Recon=0.001363 | TrainAcc=0.7624
# Fold 4 Epoch 300: TotalLoss=0.473172 | Sup=0.473125 | Recon=0.000936 | TrainAcc=0.7327
# Fold 4 Epoch 400: TotalLoss=0.445470 | Sup=0.445431 | Recon=0.000787 | TrainAcc=0.7525
# Fold 4 Epoch 500: TotalLoss=0.423316 | Sup=0.423279 | Recon=0.000743 | TrainAcc=0.8020
# Fold 4 Epoch 600: TotalLoss=0.402601 | Sup=0.402564 | Recon=0.000738 | TrainAcc=0.7624
# Fold 4 Epoch 700: TotalLoss=0.385559 | Sup=0.385523 | Recon=0.000724 | TrainAcc=0.8119
# Fold 4 Epoch 800: TotalLoss=0.366134 | Sup=0.366098 | Recon=0.000724 | TrainAcc=0.8218
# Fold 4 Epoch 900: TotalLoss=0.352675 | Sup=0.352639 | Recon=0.000715 | TrainAcc=0.8218
# Fold 4 Epoch 1000: TotalLoss=0.332645 | Sup=0.332609 | Recon=0.000718 | TrainAcc=0.8119
# Fold 4 Epoch 1100: TotalLoss=0.316458 | Sup=0.316423 | Recon=0.000714 | TrainAcc=0.8020
# Fold 4 Epoch 1200: TotalLoss=0.299806 | Sup=0.299770 | Recon=0.000719 | TrainAcc=0.7723
# Fold 4 Epoch 1300: TotalLoss=0.287212 | Sup=0.287176 | Recon=0.000719 | TrainAcc=0.8218
# Fold 4 Epoch 1400: TotalLoss=0.275796 | Sup=0.275760 | Recon=0.000716 | TrainAcc=0.7723
# Fold 4 Epoch 1500: TotalLoss=0.252153 | Sup=0.252117 | Recon=0.000722 | TrainAcc=0.8416
# Fold 4 Epoch 1600: TotalLoss=0.250667 | Sup=0.250631 | Recon=0.000720 | TrainAcc=0.8713
# Fold 4 Epoch 1700: TotalLoss=0.230139 | Sup=0.230103 | Recon=0.000720 | TrainAcc=0.8614
# Fold 4 Epoch 1800: TotalLoss=0.233844 | Sup=0.233808 | Recon=0.000720 | TrainAcc=0.8614
# Fold 4 Epoch 1900: TotalLoss=0.217201 | Sup=0.217164 | Recon=0.000729 | TrainAcc=0.8713
# Fold 4 Epoch 2000: TotalLoss=0.196251 | Sup=0.196214 | Recon=0.000725 | TrainAcc=0.8713
# Fold 4 → Acc=0.8182 | Prec=0.7143 | Rec=0.7143 | F1=0.7143 | AUC=0.8702 | CE Loss=0.4020
#
# === Fold 5 ===
# Train Control: 68, Train Patient: 33
# Fold 5 Epoch 1: TotalLoss=0.734425 | Sup=0.732819 | Recon=0.032112 | TrainAcc=0.6733
# Fold 5 Epoch 100: TotalLoss=0.519157 | Sup=0.519033 | Recon=0.002473 | TrainAcc=0.7327
# Fold 5 Epoch 200: TotalLoss=0.460468 | Sup=0.460403 | Recon=0.001291 | TrainAcc=0.7822
# Fold 5 Epoch 300: TotalLoss=0.432892 | Sup=0.432845 | Recon=0.000930 | TrainAcc=0.7921
# Fold 5 Epoch 400: TotalLoss=0.400086 | Sup=0.400047 | Recon=0.000788 | TrainAcc=0.8020
# Fold 5 Epoch 500: TotalLoss=0.388956 | Sup=0.388920 | Recon=0.000724 | TrainAcc=0.8317
# Fold 5 Epoch 600: TotalLoss=0.355837 | Sup=0.355802 | Recon=0.000711 | TrainAcc=0.8020
# Fold 5 Epoch 700: TotalLoss=0.350303 | Sup=0.350267 | Recon=0.000707 | TrainAcc=0.7921
# Fold 5 Epoch 800: TotalLoss=0.324857 | Sup=0.324821 | Recon=0.000706 | TrainAcc=0.8119
# Fold 5 Epoch 900: TotalLoss=0.306203 | Sup=0.306168 | Recon=0.000707 | TrainAcc=0.7624
# Fold 5 Epoch 1000: TotalLoss=0.286044 | Sup=0.286009 | Recon=0.000709 | TrainAcc=0.8713
# Fold 5 Epoch 1100: TotalLoss=0.275009 | Sup=0.274974 | Recon=0.000707 | TrainAcc=0.8515
# Fold 5 Epoch 1200: TotalLoss=0.256517 | Sup=0.256482 | Recon=0.000708 | TrainAcc=0.8515
# Fold 5 Epoch 1300: TotalLoss=0.248613 | Sup=0.248577 | Recon=0.000712 | TrainAcc=0.8515
# Fold 5 Epoch 1400: TotalLoss=0.229490 | Sup=0.229455 | Recon=0.000706 | TrainAcc=0.8317
# Fold 5 Epoch 1500: TotalLoss=0.208250 | Sup=0.208214 | Recon=0.000716 | TrainAcc=0.8713
# Fold 5 Epoch 1600: TotalLoss=0.197448 | Sup=0.197412 | Recon=0.000716 | TrainAcc=0.8614
# Fold 5 Epoch 1700: TotalLoss=0.185814 | Sup=0.185779 | Recon=0.000716 | TrainAcc=0.9010
# Fold 5 Epoch 1800: TotalLoss=0.186606 | Sup=0.186570 | Recon=0.000724 | TrainAcc=0.8614
# Fold 5 Epoch 1900: TotalLoss=0.159322 | Sup=0.159285 | Recon=0.000726 | TrainAcc=0.9010
# Fold 5 Epoch 2000: TotalLoss=0.146862 | Sup=0.146826 | Recon=0.000726 | TrainAcc=0.8713
# Fold 5 → Acc=0.7727 | Prec=0.6000 | Rec=0.8571 | F1=0.7059 | AUC=0.8667 | CE Loss=0.7160
#
# === Fold 6 ===
# Train Control: 68, Train Patient: 33
# Fold 6 Epoch 1: TotalLoss=0.811322 | Sup=0.809899 | Recon=0.028454 | TrainAcc=0.3267
# Fold 6 Epoch 100: TotalLoss=0.476297 | Sup=0.476175 | Recon=0.002437 | TrainAcc=0.7723
# Fold 6 Epoch 200: TotalLoss=0.453276 | Sup=0.453212 | Recon=0.001279 | TrainAcc=0.7822
# Fold 6 Epoch 300: TotalLoss=0.419296 | Sup=0.419251 | Recon=0.000898 | TrainAcc=0.7822
# Fold 6 Epoch 400: TotalLoss=0.411241 | Sup=0.411203 | Recon=0.000768 | TrainAcc=0.7822
# Fold 6 Epoch 500: TotalLoss=0.384659 | Sup=0.384622 | Recon=0.000740 | TrainAcc=0.7921
# Fold 6 Epoch 600: TotalLoss=0.367968 | Sup=0.367932 | Recon=0.000718 | TrainAcc=0.7921
# Fold 6 Epoch 700: TotalLoss=0.355633 | Sup=0.355597 | Recon=0.000714 | TrainAcc=0.7921
# Fold 6 Epoch 800: TotalLoss=0.347669 | Sup=0.347633 | Recon=0.000718 | TrainAcc=0.8218
# Fold 6 Epoch 900: TotalLoss=0.307128 | Sup=0.307092 | Recon=0.000713 | TrainAcc=0.8515
# Fold 6 Epoch 1000: TotalLoss=0.290739 | Sup=0.290703 | Recon=0.000716 | TrainAcc=0.8416
# Fold 6 Epoch 1100: TotalLoss=0.287589 | Sup=0.287553 | Recon=0.000715 | TrainAcc=0.8416
# Fold 6 Epoch 1200: TotalLoss=0.270246 | Sup=0.270210 | Recon=0.000712 | TrainAcc=0.8515
# Fold 6 Epoch 1300: TotalLoss=0.245311 | Sup=0.245274 | Recon=0.000726 | TrainAcc=0.8515
# Fold 6 Epoch 1400: TotalLoss=0.234041 | Sup=0.234005 | Recon=0.000714 | TrainAcc=0.8515
# Fold 6 Epoch 1500: TotalLoss=0.220596 | Sup=0.220560 | Recon=0.000721 | TrainAcc=0.8614
# Fold 6 Epoch 1600: TotalLoss=0.216265 | Sup=0.216229 | Recon=0.000724 | TrainAcc=0.8218
# Fold 6 Epoch 1700: TotalLoss=0.197332 | Sup=0.197295 | Recon=0.000726 | TrainAcc=0.8614
# Fold 6 Epoch 1800: TotalLoss=0.192313 | Sup=0.192277 | Recon=0.000723 | TrainAcc=0.7723
# Fold 6 Epoch 1900: TotalLoss=0.196696 | Sup=0.196660 | Recon=0.000726 | TrainAcc=0.8515
# Fold 6 Epoch 2000: TotalLoss=0.174770 | Sup=0.174733 | Recon=0.000735 | TrainAcc=0.8218
# Fold 6 → Acc=0.7727 | Prec=0.6111 | Rec=0.7857 | F1=0.6875 | AUC=0.8881 | CE Loss=0.4136
#
# === Fold 7 ===
# Train Control: 68, Train Patient: 33
# Fold 7 Epoch 1: TotalLoss=0.748917 | Sup=0.747545 | Recon=0.027439 | TrainAcc=0.6733
# Fold 7 Epoch 100: TotalLoss=0.490233 | Sup=0.490122 | Recon=0.002213 | TrainAcc=0.7327
# Fold 7 Epoch 200: TotalLoss=0.450175 | Sup=0.450113 | Recon=0.001233 | TrainAcc=0.7525
# Fold 7 Epoch 300: TotalLoss=0.420894 | Sup=0.420849 | Recon=0.000891 | TrainAcc=0.7723
# Fold 7 Epoch 400: TotalLoss=0.388141 | Sup=0.388103 | Recon=0.000772 | TrainAcc=0.7921
# Fold 7 Epoch 500: TotalLoss=0.374511 | Sup=0.374474 | Recon=0.000731 | TrainAcc=0.8218
# Fold 7 Epoch 600: TotalLoss=0.340894 | Sup=0.340858 | Recon=0.000721 | TrainAcc=0.8317
# Fold 7 Epoch 700: TotalLoss=0.313274 | Sup=0.313238 | Recon=0.000717 | TrainAcc=0.8416
# Fold 7 Epoch 800: TotalLoss=0.287731 | Sup=0.287695 | Recon=0.000726 | TrainAcc=0.8515
# Fold 7 Epoch 900: TotalLoss=0.281342 | Sup=0.281306 | Recon=0.000726 | TrainAcc=0.8713
# Fold 7 Epoch 1000: TotalLoss=0.255025 | Sup=0.254989 | Recon=0.000727 | TrainAcc=0.8911
# Fold 7 Epoch 1100: TotalLoss=0.242215 | Sup=0.242179 | Recon=0.000732 | TrainAcc=0.8317
# Fold 7 Epoch 1200: TotalLoss=0.240217 | Sup=0.240180 | Recon=0.000729 | TrainAcc=0.9010
# Fold 7 Epoch 1300: TotalLoss=0.212868 | Sup=0.212831 | Recon=0.000735 | TrainAcc=0.8812
# Fold 7 Epoch 1400: TotalLoss=0.210906 | Sup=0.210869 | Recon=0.000732 | TrainAcc=0.9010
# Fold 7 Epoch 1500: TotalLoss=0.204358 | Sup=0.204321 | Recon=0.000738 | TrainAcc=0.9208
# Fold 7 Epoch 1600: TotalLoss=0.178755 | Sup=0.178718 | Recon=0.000744 | TrainAcc=0.9109
# Fold 7 Epoch 1700: TotalLoss=0.174788 | Sup=0.174750 | Recon=0.000746 | TrainAcc=0.9208
# Fold 7 Epoch 1800: TotalLoss=0.152774 | Sup=0.152737 | Recon=0.000736 | TrainAcc=0.8812
# Fold 7 Epoch 1900: TotalLoss=0.166437 | Sup=0.166400 | Recon=0.000741 | TrainAcc=0.8911
# Fold 7 Epoch 2000: TotalLoss=0.157450 | Sup=0.157413 | Recon=0.000742 | TrainAcc=0.8020
# Fold 7 → Acc=0.7273 | Prec=0.6000 | Rec=0.4286 | F1=0.5000 | AUC=0.8095 | CE Loss=0.8587
#
# === Fold 8 ===
# Train Control: 68, Train Patient: 33
# Fold 8 Epoch 1: TotalLoss=0.839138 | Sup=0.837568 | Recon=0.031405 | TrainAcc=0.6733
# Fold 8 Epoch 100: TotalLoss=0.500744 | Sup=0.500624 | Recon=0.002391 | TrainAcc=0.7129
# Fold 8 Epoch 200: TotalLoss=0.486368 | Sup=0.486304 | Recon=0.001274 | TrainAcc=0.7327
# Fold 8 Epoch 300: TotalLoss=0.461117 | Sup=0.461072 | Recon=0.000904 | TrainAcc=0.7723
# Fold 8 Epoch 400: TotalLoss=0.442703 | Sup=0.442664 | Recon=0.000774 | TrainAcc=0.7525
# Fold 8 Epoch 500: TotalLoss=0.417852 | Sup=0.417816 | Recon=0.000729 | TrainAcc=0.7525
# Fold 8 Epoch 600: TotalLoss=0.394177 | Sup=0.394141 | Recon=0.000713 | TrainAcc=0.7822
# Fold 8 Epoch 700: TotalLoss=0.374492 | Sup=0.374456 | Recon=0.000712 | TrainAcc=0.7723
# Fold 8 Epoch 800: TotalLoss=0.354101 | Sup=0.354065 | Recon=0.000717 | TrainAcc=0.8119
# Fold 8 Epoch 900: TotalLoss=0.336743 | Sup=0.336707 | Recon=0.000717 | TrainAcc=0.7822
# Fold 8 Epoch 1000: TotalLoss=0.326465 | Sup=0.326429 | Recon=0.000716 | TrainAcc=0.8317
# Fold 8 Epoch 1100: TotalLoss=0.311561 | Sup=0.311525 | Recon=0.000714 | TrainAcc=0.8119
# Fold 8 Epoch 1200: TotalLoss=0.306325 | Sup=0.306289 | Recon=0.000715 | TrainAcc=0.8317
# Fold 8 Epoch 1300: TotalLoss=0.272569 | Sup=0.272533 | Recon=0.000719 | TrainAcc=0.8218
# Fold 8 Epoch 1400: TotalLoss=0.281145 | Sup=0.281109 | Recon=0.000720 | TrainAcc=0.8317
# Fold 8 Epoch 1500: TotalLoss=0.262154 | Sup=0.262118 | Recon=0.000718 | TrainAcc=0.7723
# Fold 8 Epoch 1600: TotalLoss=0.246422 | Sup=0.246386 | Recon=0.000722 | TrainAcc=0.8614
# Fold 8 Epoch 1700: TotalLoss=0.230998 | Sup=0.230962 | Recon=0.000717 | TrainAcc=0.8416
# Fold 8 Epoch 1800: TotalLoss=0.214395 | Sup=0.214359 | Recon=0.000718 | TrainAcc=0.8713
# Fold 8 Epoch 1900: TotalLoss=0.206782 | Sup=0.206746 | Recon=0.000726 | TrainAcc=0.8416
# Fold 8 Epoch 2000: TotalLoss=0.205718 | Sup=0.205682 | Recon=0.000725 | TrainAcc=0.8812
# Fold 8 → Acc=0.8409 | Prec=0.8182 | Rec=0.6429 | F1=0.7200 | AUC=0.9476 | CE Loss=0.2942
#
# === Fold 9 ===
# Train Control: 68, Train Patient: 33
# Fold 9 Epoch 1: TotalLoss=0.719628 | Sup=0.718134 | Recon=0.029880 | TrainAcc=0.3267
# Fold 9 Epoch 100: TotalLoss=0.479959 | Sup=0.479838 | Recon=0.002404 | TrainAcc=0.7327
# Fold 9 Epoch 200: TotalLoss=0.452477 | Sup=0.452412 | Recon=0.001307 | TrainAcc=0.7525
# Fold 9 Epoch 300: TotalLoss=0.437618 | Sup=0.437574 | Recon=0.000893 | TrainAcc=0.7624
# Fold 9 Epoch 400: TotalLoss=0.418382 | Sup=0.418344 | Recon=0.000777 | TrainAcc=0.7426
# Fold 9 Epoch 500: TotalLoss=0.403066 | Sup=0.403030 | Recon=0.000726 | TrainAcc=0.8020
# Fold 9 Epoch 600: TotalLoss=0.394714 | Sup=0.394678 | Recon=0.000713 | TrainAcc=0.7822
# Fold 9 Epoch 700: TotalLoss=0.367863 | Sup=0.367828 | Recon=0.000707 | TrainAcc=0.7723
# Fold 9 Epoch 800: TotalLoss=0.332930 | Sup=0.332895 | Recon=0.000716 | TrainAcc=0.7822
# Fold 9 Epoch 900: TotalLoss=0.331973 | Sup=0.331937 | Recon=0.000716 | TrainAcc=0.8317
# Fold 9 Epoch 1000: TotalLoss=0.309199 | Sup=0.309163 | Recon=0.000719 | TrainAcc=0.8218
# Fold 9 Epoch 1100: TotalLoss=0.298778 | Sup=0.298742 | Recon=0.000722 | TrainAcc=0.8020
# Fold 9 Epoch 1200: TotalLoss=0.275386 | Sup=0.275350 | Recon=0.000723 | TrainAcc=0.8218
# Fold 9 Epoch 1300: TotalLoss=0.267658 | Sup=0.267622 | Recon=0.000723 | TrainAcc=0.8317
# Fold 9 Epoch 1400: TotalLoss=0.252959 | Sup=0.252923 | Recon=0.000728 | TrainAcc=0.8119
# Fold 9 Epoch 1500: TotalLoss=0.230820 | Sup=0.230783 | Recon=0.000735 | TrainAcc=0.8812
# Fold 9 Epoch 1600: TotalLoss=0.217723 | Sup=0.217686 | Recon=0.000735 | TrainAcc=0.8218
# Fold 9 Epoch 1700: TotalLoss=0.217370 | Sup=0.217333 | Recon=0.000737 | TrainAcc=0.8614
# Fold 9 Epoch 1800: TotalLoss=0.202570 | Sup=0.202533 | Recon=0.000738 | TrainAcc=0.8614
# Fold 9 Epoch 1900: TotalLoss=0.203814 | Sup=0.203777 | Recon=0.000739 | TrainAcc=0.8812
# Fold 9 Epoch 2000: TotalLoss=0.181320 | Sup=0.181283 | Recon=0.000741 | TrainAcc=0.8416
# Fold 9 → Acc=0.7727 | Prec=0.8333 | Rec=0.3571 | F1=0.5000 | AUC=0.8810 | CE Loss=0.4584
#
# === Fold 10 ===
# Train Control: 68, Train Patient: 33
# Fold 10 Epoch 1: TotalLoss=0.744332 | Sup=0.742994 | Recon=0.026774 | TrainAcc=0.6733
# Fold 10 Epoch 100: TotalLoss=0.486137 | Sup=0.486024 | Recon=0.002268 | TrainAcc=0.7525
# Fold 10 Epoch 200: TotalLoss=0.468331 | Sup=0.468268 | Recon=0.001248 | TrainAcc=0.7822
# Fold 10 Epoch 300: TotalLoss=0.435155 | Sup=0.435111 | Recon=0.000882 | TrainAcc=0.7921
# Fold 10 Epoch 400: TotalLoss=0.431743 | Sup=0.431705 | Recon=0.000757 | TrainAcc=0.7921
# Fold 10 Epoch 500: TotalLoss=0.386647 | Sup=0.386610 | Recon=0.000724 | TrainAcc=0.8119
# Fold 10 Epoch 600: TotalLoss=0.377377 | Sup=0.377342 | Recon=0.000708 | TrainAcc=0.8119
# Fold 10 Epoch 700: TotalLoss=0.351666 | Sup=0.351631 | Recon=0.000713 | TrainAcc=0.8416
# Fold 10 Epoch 800: TotalLoss=0.344943 | Sup=0.344908 | Recon=0.000712 | TrainAcc=0.8119
# Fold 10 Epoch 900: TotalLoss=0.322579 | Sup=0.322543 | Recon=0.000707 | TrainAcc=0.8020
# Fold 10 Epoch 1000: TotalLoss=0.308829 | Sup=0.308793 | Recon=0.000715 | TrainAcc=0.8614
# Fold 10 Epoch 1100: TotalLoss=0.292868 | Sup=0.292832 | Recon=0.000718 | TrainAcc=0.8317
# Fold 10 Epoch 1200: TotalLoss=0.273470 | Sup=0.273434 | Recon=0.000717 | TrainAcc=0.8317
# Fold 10 Epoch 1300: TotalLoss=0.260571 | Sup=0.260535 | Recon=0.000724 | TrainAcc=0.8317
# Fold 10 Epoch 1400: TotalLoss=0.250008 | Sup=0.249971 | Recon=0.000724 | TrainAcc=0.8614
# Fold 10 Epoch 1500: TotalLoss=0.250061 | Sup=0.250025 | Recon=0.000727 | TrainAcc=0.8812
# Fold 10 Epoch 1600: TotalLoss=0.209766 | Sup=0.209730 | Recon=0.000725 | TrainAcc=0.8515
# Fold 10 Epoch 1700: TotalLoss=0.214738 | Sup=0.214701 | Recon=0.000736 | TrainAcc=0.8713
# Fold 10 Epoch 1800: TotalLoss=0.209969 | Sup=0.209932 | Recon=0.000731 | TrainAcc=0.8911
# Fold 10 Epoch 1900: TotalLoss=0.189413 | Sup=0.189376 | Recon=0.000738 | TrainAcc=0.8218
# Fold 10 Epoch 2000: TotalLoss=0.171924 | Sup=0.171887 | Recon=0.000738 | TrainAcc=0.8416
# Fold 10 → Acc=0.8409 | Prec=0.8182 | Rec=0.6429 | F1=0.7200 | AUC=0.9429 | CE Loss=0.3324
#
# === Fold 11 ===
# Train Control: 68, Train Patient: 33
# Fold 11 Epoch 1: TotalLoss=0.682915 | Sup=0.681488 | Recon=0.028531 | TrainAcc=0.6733
# Fold 11 Epoch 100: TotalLoss=0.462821 | Sup=0.462704 | Recon=0.002343 | TrainAcc=0.7327
# Fold 11 Epoch 200: TotalLoss=0.449642 | Sup=0.449579 | Recon=0.001252 | TrainAcc=0.7723
# Fold 11 Epoch 300: TotalLoss=0.410805 | Sup=0.410760 | Recon=0.000893 | TrainAcc=0.7822
# Fold 11 Epoch 400: TotalLoss=0.391590 | Sup=0.391552 | Recon=0.000766 | TrainAcc=0.7921
# Fold 11 Epoch 500: TotalLoss=0.372613 | Sup=0.372577 | Recon=0.000730 | TrainAcc=0.8020
# Fold 11 Epoch 600: TotalLoss=0.325053 | Sup=0.325017 | Recon=0.000721 | TrainAcc=0.8119
# Fold 11 Epoch 700: TotalLoss=0.304506 | Sup=0.304470 | Recon=0.000721 | TrainAcc=0.8119
# Fold 11 Epoch 800: TotalLoss=0.308334 | Sup=0.308298 | Recon=0.000725 | TrainAcc=0.8614
# Fold 11 Epoch 900: TotalLoss=0.276494 | Sup=0.276457 | Recon=0.000727 | TrainAcc=0.8515
# Fold 11 Epoch 1000: TotalLoss=0.267204 | Sup=0.267168 | Recon=0.000727 | TrainAcc=0.8218
# Fold 11 Epoch 1100: TotalLoss=0.253381 | Sup=0.253345 | Recon=0.000718 | TrainAcc=0.8416
# Fold 11 Epoch 1200: TotalLoss=0.242528 | Sup=0.242492 | Recon=0.000720 | TrainAcc=0.8020
# Fold 11 Epoch 1300: TotalLoss=0.253141 | Sup=0.253105 | Recon=0.000720 | TrainAcc=0.8911
# Fold 11 Epoch 1400: TotalLoss=0.237031 | Sup=0.236995 | Recon=0.000727 | TrainAcc=0.9010
# Fold 11 Epoch 1500: TotalLoss=0.227453 | Sup=0.227417 | Recon=0.000728 | TrainAcc=0.8911
# Fold 11 Epoch 1600: TotalLoss=0.219423 | Sup=0.219387 | Recon=0.000728 | TrainAcc=0.8614
# Fold 11 Epoch 1700: TotalLoss=0.198454 | Sup=0.198418 | Recon=0.000734 | TrainAcc=0.8911
# Fold 11 Epoch 1800: TotalLoss=0.181147 | Sup=0.181110 | Recon=0.000727 | TrainAcc=0.8911
# Fold 11 Epoch 1900: TotalLoss=0.171619 | Sup=0.171583 | Recon=0.000724 | TrainAcc=0.8020
# Fold 11 Epoch 2000: TotalLoss=0.190942 | Sup=0.190905 | Recon=0.000736 | TrainAcc=0.8911
# Fold 11 → Acc=0.7955 | Prec=0.7778 | Rec=0.5000 | F1=0.6087 | AUC=0.8321 | CE Loss=0.6852
#
# === Fold 12 ===
# Train Control: 68, Train Patient: 33
# Fold 12 Epoch 1: TotalLoss=0.802404 | Sup=0.800816 | Recon=0.031773 | TrainAcc=0.3267
# Fold 12 Epoch 100: TotalLoss=0.445259 | Sup=0.445134 | Recon=0.002501 | TrainAcc=0.7723
# Fold 12 Epoch 200: TotalLoss=0.421700 | Sup=0.421633 | Recon=0.001356 | TrainAcc=0.8020
# Fold 12 Epoch 300: TotalLoss=0.398765 | Sup=0.398719 | Recon=0.000919 | TrainAcc=0.8317
# Fold 12 Epoch 400: TotalLoss=0.397094 | Sup=0.397055 | Recon=0.000779 | TrainAcc=0.8317
# Fold 12 Epoch 500: TotalLoss=0.382927 | Sup=0.382890 | Recon=0.000737 | TrainAcc=0.8317
# Fold 12 Epoch 600: TotalLoss=0.339249 | Sup=0.339213 | Recon=0.000714 | TrainAcc=0.8317
# Fold 12 Epoch 700: TotalLoss=0.331936 | Sup=0.331900 | Recon=0.000718 | TrainAcc=0.8416
# Fold 12 Epoch 800: TotalLoss=0.315174 | Sup=0.315139 | Recon=0.000714 | TrainAcc=0.8416
# Fold 12 Epoch 900: TotalLoss=0.301122 | Sup=0.301086 | Recon=0.000721 | TrainAcc=0.8416
# Fold 12 Epoch 1000: TotalLoss=0.293175 | Sup=0.293139 | Recon=0.000729 | TrainAcc=0.8317
# Fold 12 Epoch 1100: TotalLoss=0.277516 | Sup=0.277480 | Recon=0.000716 | TrainAcc=0.8515
# Fold 12 Epoch 1200: TotalLoss=0.261606 | Sup=0.261570 | Recon=0.000723 | TrainAcc=0.8713
# Fold 12 Epoch 1300: TotalLoss=0.247185 | Sup=0.247149 | Recon=0.000722 | TrainAcc=0.8614
# Fold 12 Epoch 1400: TotalLoss=0.228365 | Sup=0.228330 | Recon=0.000717 | TrainAcc=0.8515
# Fold 12 Epoch 1500: TotalLoss=0.220745 | Sup=0.220709 | Recon=0.000720 | TrainAcc=0.8812
# Fold 12 Epoch 1600: TotalLoss=0.219144 | Sup=0.219108 | Recon=0.000724 | TrainAcc=0.8614
# Fold 12 Epoch 1700: TotalLoss=0.213630 | Sup=0.213593 | Recon=0.000726 | TrainAcc=0.8713
# Fold 12 Epoch 1800: TotalLoss=0.195374 | Sup=0.195338 | Recon=0.000719 | TrainAcc=0.8812
# Fold 12 Epoch 1900: TotalLoss=0.204255 | Sup=0.204219 | Recon=0.000727 | TrainAcc=0.8812
# Fold 12 Epoch 2000: TotalLoss=0.184626 | Sup=0.184589 | Recon=0.000727 | TrainAcc=0.9010
# Fold 12 → Acc=0.9091 | Prec=0.9167 | Rec=0.7857 | F1=0.8462 | AUC=0.8786 | CE Loss=0.4688
#
# === Fold 13 ===
# Train Control: 68, Train Patient: 33
# Fold 13 Epoch 1: TotalLoss=0.645519 | Sup=0.643980 | Recon=0.030789 | TrainAcc=0.6733
# Fold 13 Epoch 100: TotalLoss=0.463183 | Sup=0.463065 | Recon=0.002356 | TrainAcc=0.7129
# Fold 13 Epoch 200: TotalLoss=0.442518 | Sup=0.442454 | Recon=0.001280 | TrainAcc=0.7921
# Fold 13 Epoch 300: TotalLoss=0.419741 | Sup=0.419696 | Recon=0.000903 | TrainAcc=0.8119
# Fold 13 Epoch 400: TotalLoss=0.393470 | Sup=0.393431 | Recon=0.000786 | TrainAcc=0.8119
# Fold 13 Epoch 500: TotalLoss=0.358657 | Sup=0.358620 | Recon=0.000740 | TrainAcc=0.8020
# Fold 13 Epoch 600: TotalLoss=0.344709 | Sup=0.344674 | Recon=0.000712 | TrainAcc=0.8218
# Fold 13 Epoch 700: TotalLoss=0.314898 | Sup=0.314862 | Recon=0.000716 | TrainAcc=0.8119
# Fold 13 Epoch 800: TotalLoss=0.288179 | Sup=0.288143 | Recon=0.000719 | TrainAcc=0.8614
# Fold 13 Epoch 900: TotalLoss=0.268996 | Sup=0.268959 | Recon=0.000731 | TrainAcc=0.8317
# Fold 13 Epoch 1000: TotalLoss=0.265373 | Sup=0.265337 | Recon=0.000725 | TrainAcc=0.8416
# Fold 13 Epoch 1100: TotalLoss=0.251447 | Sup=0.251410 | Recon=0.000731 | TrainAcc=0.8713
# Fold 13 Epoch 1200: TotalLoss=0.230345 | Sup=0.230309 | Recon=0.000730 | TrainAcc=0.9208
# Fold 13 Epoch 1300: TotalLoss=0.213085 | Sup=0.213048 | Recon=0.000739 | TrainAcc=0.8911
# Fold 13 Epoch 1400: TotalLoss=0.197974 | Sup=0.197938 | Recon=0.000729 | TrainAcc=0.9307
# Fold 13 Epoch 1500: TotalLoss=0.187558 | Sup=0.187521 | Recon=0.000735 | TrainAcc=0.9208
# Fold 13 Epoch 1600: TotalLoss=0.175780 | Sup=0.175743 | Recon=0.000740 | TrainAcc=0.9109
# Fold 13 Epoch 1700: TotalLoss=0.164889 | Sup=0.164852 | Recon=0.000738 | TrainAcc=0.8416
# Fold 13 Epoch 1800: TotalLoss=0.143453 | Sup=0.143416 | Recon=0.000741 | TrainAcc=0.8713
# Fold 13 Epoch 1900: TotalLoss=0.142456 | Sup=0.142419 | Recon=0.000745 | TrainAcc=0.8515
# Fold 13 Epoch 2000: TotalLoss=0.134931 | Sup=0.134894 | Recon=0.000742 | TrainAcc=0.9208
# Fold 13 → Acc=0.9091 | Prec=0.9167 | Rec=0.7857 | F1=0.8462 | AUC=0.9548 | CE Loss=0.2402
#
# === Fold 14 ===
# Train Control: 68, Train Patient: 33
# Fold 14 Epoch 1: TotalLoss=0.758312 | Sup=0.756516 | Recon=0.035903 | TrainAcc=0.6733
# Fold 14 Epoch 100: TotalLoss=0.486900 | Sup=0.486767 | Recon=0.002654 | TrainAcc=0.7129
# Fold 14 Epoch 200: TotalLoss=0.478318 | Sup=0.478248 | Recon=0.001410 | TrainAcc=0.7426
# Fold 14 Epoch 300: TotalLoss=0.447942 | Sup=0.447894 | Recon=0.000958 | TrainAcc=0.7426
# Fold 14 Epoch 400: TotalLoss=0.425503 | Sup=0.425462 | Recon=0.000810 | TrainAcc=0.7525
# Fold 14 Epoch 500: TotalLoss=0.414218 | Sup=0.414181 | Recon=0.000744 | TrainAcc=0.7723
# Fold 14 Epoch 600: TotalLoss=0.374649 | Sup=0.374612 | Recon=0.000732 | TrainAcc=0.7723
# Fold 14 Epoch 700: TotalLoss=0.374416 | Sup=0.374379 | Recon=0.000730 | TrainAcc=0.8218
# Fold 14 Epoch 800: TotalLoss=0.349040 | Sup=0.349004 | Recon=0.000723 | TrainAcc=0.7921
# Fold 14 Epoch 900: TotalLoss=0.332000 | Sup=0.331964 | Recon=0.000724 | TrainAcc=0.8119
# Fold 14 Epoch 1000: TotalLoss=0.313847 | Sup=0.313811 | Recon=0.000723 | TrainAcc=0.8218
# Fold 14 Epoch 1100: TotalLoss=0.291073 | Sup=0.291037 | Recon=0.000727 | TrainAcc=0.8317
# Fold 14 Epoch 1200: TotalLoss=0.272974 | Sup=0.272937 | Recon=0.000728 | TrainAcc=0.8119
# Fold 14 Epoch 1300: TotalLoss=0.261082 | Sup=0.261045 | Recon=0.000726 | TrainAcc=0.8119
# Fold 14 Epoch 1400: TotalLoss=0.229884 | Sup=0.229847 | Recon=0.000729 | TrainAcc=0.8119
# Fold 14 Epoch 1500: TotalLoss=0.236301 | Sup=0.236264 | Recon=0.000732 | TrainAcc=0.8713
# Fold 14 Epoch 1600: TotalLoss=0.213331 | Sup=0.213295 | Recon=0.000738 | TrainAcc=0.8713
# Fold 14 Epoch 1700: TotalLoss=0.207306 | Sup=0.207269 | Recon=0.000739 | TrainAcc=0.8614
# Fold 14 Epoch 1800: TotalLoss=0.195797 | Sup=0.195760 | Recon=0.000739 | TrainAcc=0.8119
# Fold 14 Epoch 1900: TotalLoss=0.179649 | Sup=0.179612 | Recon=0.000743 | TrainAcc=0.9010
# Fold 14 Epoch 2000: TotalLoss=0.167213 | Sup=0.167176 | Recon=0.000745 | TrainAcc=0.9010
# Fold 14 → Acc=0.9091 | Prec=0.8125 | Rec=0.9286 | F1=0.8667 | AUC=0.9214 | CE Loss=0.3834
#
# === Fold 15 ===
# Train Control: 68, Train Patient: 33
# Fold 15 Epoch 1: TotalLoss=0.757550 | Sup=0.755970 | Recon=0.031610 | TrainAcc=0.3267
# Fold 15 Epoch 100: TotalLoss=0.481565 | Sup=0.481442 | Recon=0.002457 | TrainAcc=0.7723
# Fold 15 Epoch 200: TotalLoss=0.457322 | Sup=0.457257 | Recon=0.001304 | TrainAcc=0.7921
# Fold 15 Epoch 300: TotalLoss=0.441965 | Sup=0.441920 | Recon=0.000905 | TrainAcc=0.7921
# Fold 15 Epoch 400: TotalLoss=0.404375 | Sup=0.404336 | Recon=0.000780 | TrainAcc=0.8119
# Fold 15 Epoch 500: TotalLoss=0.375462 | Sup=0.375425 | Recon=0.000740 | TrainAcc=0.8317
# Fold 15 Epoch 600: TotalLoss=0.365379 | Sup=0.365343 | Recon=0.000722 | TrainAcc=0.8317
# Fold 15 Epoch 700: TotalLoss=0.324981 | Sup=0.324945 | Recon=0.000717 | TrainAcc=0.8416
# Fold 15 Epoch 800: TotalLoss=0.323681 | Sup=0.323646 | Recon=0.000714 | TrainAcc=0.8713
# Fold 15 Epoch 900: TotalLoss=0.293771 | Sup=0.293736 | Recon=0.000713 | TrainAcc=0.8812
# Fold 15 Epoch 1000: TotalLoss=0.275533 | Sup=0.275498 | Recon=0.000711 | TrainAcc=0.8911
# Fold 15 Epoch 1100: TotalLoss=0.264030 | Sup=0.263995 | Recon=0.000709 | TrainAcc=0.8218
# Fold 15 Epoch 1200: TotalLoss=0.250584 | Sup=0.250548 | Recon=0.000710 | TrainAcc=0.9208
# Fold 15 Epoch 1300: TotalLoss=0.248542 | Sup=0.248506 | Recon=0.000713 | TrainAcc=0.8812
# Fold 15 Epoch 1400: TotalLoss=0.209812 | Sup=0.209776 | Recon=0.000720 | TrainAcc=0.9307
# Fold 15 Epoch 1500: TotalLoss=0.209664 | Sup=0.209628 | Recon=0.000722 | TrainAcc=0.9109
# Fold 15 Epoch 1600: TotalLoss=0.187958 | Sup=0.187922 | Recon=0.000718 | TrainAcc=0.9109
# Fold 15 Epoch 1700: TotalLoss=0.170207 | Sup=0.170171 | Recon=0.000723 | TrainAcc=0.9010
# Fold 15 Epoch 1800: TotalLoss=0.178993 | Sup=0.178957 | Recon=0.000729 | TrainAcc=0.8911
# Fold 15 Epoch 1900: TotalLoss=0.154477 | Sup=0.154440 | Recon=0.000727 | TrainAcc=0.8317
# Fold 15 Epoch 2000: TotalLoss=0.146277 | Sup=0.146240 | Recon=0.000728 | TrainAcc=0.8515
# Fold 15 → Acc=0.8864 | Prec=0.8462 | Rec=0.7857 | F1=0.8148 | AUC=0.9548 | CE Loss=0.2534
#
# === Fold 16 ===
# Train Control: 68, Train Patient: 33
# Fold 16 Epoch 1: TotalLoss=0.699491 | Sup=0.697855 | Recon=0.032724 | TrainAcc=0.6733
# Fold 16 Epoch 100: TotalLoss=0.467272 | Sup=0.467145 | Recon=0.002557 | TrainAcc=0.7624
# Fold 16 Epoch 200: TotalLoss=0.451778 | Sup=0.451714 | Recon=0.001290 | TrainAcc=0.7624
# Fold 16 Epoch 300: TotalLoss=0.427465 | Sup=0.427419 | Recon=0.000919 | TrainAcc=0.7921
# Fold 16 Epoch 400: TotalLoss=0.391176 | Sup=0.391137 | Recon=0.000788 | TrainAcc=0.7624
# Fold 16 Epoch 500: TotalLoss=0.362011 | Sup=0.361975 | Recon=0.000733 | TrainAcc=0.7822
# Fold 16 Epoch 600: TotalLoss=0.349345 | Sup=0.349309 | Recon=0.000712 | TrainAcc=0.8218
# Fold 16 Epoch 700: TotalLoss=0.340562 | Sup=0.340527 | Recon=0.000713 | TrainAcc=0.8119
# Fold 16 Epoch 800: TotalLoss=0.329521 | Sup=0.329485 | Recon=0.000717 | TrainAcc=0.8218
# Fold 16 Epoch 900: TotalLoss=0.302313 | Sup=0.302277 | Recon=0.000710 | TrainAcc=0.8119
# Fold 16 Epoch 1000: TotalLoss=0.305985 | Sup=0.305950 | Recon=0.000710 | TrainAcc=0.8416
# Fold 16 Epoch 1100: TotalLoss=0.273085 | Sup=0.273049 | Recon=0.000714 | TrainAcc=0.8317
# Fold 16 Epoch 1200: TotalLoss=0.287490 | Sup=0.287455 | Recon=0.000714 | TrainAcc=0.8317
# Fold 16 Epoch 1300: TotalLoss=0.263557 | Sup=0.263521 | Recon=0.000713 | TrainAcc=0.8416
# Fold 16 Epoch 1400: TotalLoss=0.238939 | Sup=0.238903 | Recon=0.000715 | TrainAcc=0.8515
# Fold 16 Epoch 1500: TotalLoss=0.237823 | Sup=0.237788 | Recon=0.000712 | TrainAcc=0.8614
# Fold 16 Epoch 1600: TotalLoss=0.222985 | Sup=0.222949 | Recon=0.000720 | TrainAcc=0.8911
# Fold 16 Epoch 1700: TotalLoss=0.202205 | Sup=0.202169 | Recon=0.000719 | TrainAcc=0.8812
# Fold 16 Epoch 1800: TotalLoss=0.196438 | Sup=0.196402 | Recon=0.000723 | TrainAcc=0.8713
# Fold 16 Epoch 1900: TotalLoss=0.193842 | Sup=0.193806 | Recon=0.000724 | TrainAcc=0.8614
# Fold 16 Epoch 2000: TotalLoss=0.174354 | Sup=0.174318 | Recon=0.000725 | TrainAcc=0.8614
# Fold 16 → Acc=0.8636 | Prec=0.9000 | Rec=0.6429 | F1=0.7500 | AUC=0.9214 | CE Loss=0.4518
#
# === Fold 17 ===
# Train Control: 68, Train Patient: 33
# Fold 17 Epoch 1: TotalLoss=0.657922 | Sup=0.656574 | Recon=0.026958 | TrainAcc=0.6733
# Fold 17 Epoch 100: TotalLoss=0.524808 | Sup=0.524692 | Recon=0.002328 | TrainAcc=0.6931
# Fold 17 Epoch 200: TotalLoss=0.487277 | Sup=0.487215 | Recon=0.001246 | TrainAcc=0.7228
# Fold 17 Epoch 300: TotalLoss=0.458588 | Sup=0.458544 | Recon=0.000888 | TrainAcc=0.7723
# Fold 17 Epoch 400: TotalLoss=0.412362 | Sup=0.412324 | Recon=0.000771 | TrainAcc=0.7822
# Fold 17 Epoch 500: TotalLoss=0.399317 | Sup=0.399280 | Recon=0.000727 | TrainAcc=0.7723
# Fold 17 Epoch 600: TotalLoss=0.366634 | Sup=0.366599 | Recon=0.000718 | TrainAcc=0.7822
# Fold 17 Epoch 700: TotalLoss=0.341264 | Sup=0.341228 | Recon=0.000712 | TrainAcc=0.8218
# Fold 17 Epoch 800: TotalLoss=0.316837 | Sup=0.316801 | Recon=0.000713 | TrainAcc=0.7921
# Fold 17 Epoch 900: TotalLoss=0.301892 | Sup=0.301856 | Recon=0.000711 | TrainAcc=0.8317
# Fold 17 Epoch 1000: TotalLoss=0.291473 | Sup=0.291438 | Recon=0.000710 | TrainAcc=0.8218
# Fold 17 Epoch 1100: TotalLoss=0.269128 | Sup=0.269092 | Recon=0.000715 | TrainAcc=0.8317
# Fold 17 Epoch 1200: TotalLoss=0.243211 | Sup=0.243175 | Recon=0.000722 | TrainAcc=0.8812
# Fold 17 Epoch 1300: TotalLoss=0.253849 | Sup=0.253813 | Recon=0.000720 | TrainAcc=0.8218
# Fold 17 Epoch 1400: TotalLoss=0.237945 | Sup=0.237909 | Recon=0.000718 | TrainAcc=0.8416
# Fold 17 Epoch 1500: TotalLoss=0.222411 | Sup=0.222374 | Recon=0.000729 | TrainAcc=0.8812
# Fold 17 Epoch 1600: TotalLoss=0.220046 | Sup=0.220010 | Recon=0.000718 | TrainAcc=0.8614
# Fold 17 Epoch 1700: TotalLoss=0.200337 | Sup=0.200301 | Recon=0.000729 | TrainAcc=0.8812
# Fold 17 Epoch 1800: TotalLoss=0.180919 | Sup=0.180883 | Recon=0.000720 | TrainAcc=0.8218
# Fold 17 Epoch 1900: TotalLoss=0.176425 | Sup=0.176389 | Recon=0.000729 | TrainAcc=0.8812
# Fold 17 Epoch 2000: TotalLoss=0.184774 | Sup=0.184737 | Recon=0.000731 | TrainAcc=0.9010
# Fold 17 → Acc=0.8409 | Prec=0.7059 | Rec=0.8571 | F1=0.7742 | AUC=0.9512 | CE Loss=0.2707
#
# === Fold 18 ===
# Train Control: 68, Train Patient: 33
# Fold 18 Epoch 1: TotalLoss=0.722987 | Sup=0.721364 | Recon=0.032445 | TrainAcc=0.6733
# Fold 18 Epoch 100: TotalLoss=0.485139 | Sup=0.485007 | Recon=0.002628 | TrainAcc=0.7723
# Fold 18 Epoch 200: TotalLoss=0.461155 | Sup=0.461087 | Recon=0.001354 | TrainAcc=0.7822
# Fold 18 Epoch 300: TotalLoss=0.430564 | Sup=0.430517 | Recon=0.000946 | TrainAcc=0.7822
# Fold 18 Epoch 400: TotalLoss=0.406619 | Sup=0.406580 | Recon=0.000791 | TrainAcc=0.8218
# Fold 18 Epoch 500: TotalLoss=0.381110 | Sup=0.381073 | Recon=0.000733 | TrainAcc=0.8119
# Fold 18 Epoch 600: TotalLoss=0.348513 | Sup=0.348477 | Recon=0.000722 | TrainAcc=0.7921
# Fold 18 Epoch 700: TotalLoss=0.322264 | Sup=0.322228 | Recon=0.000725 | TrainAcc=0.8218
# Fold 18 Epoch 800: TotalLoss=0.307439 | Sup=0.307403 | Recon=0.000722 | TrainAcc=0.8119
# Fold 18 Epoch 900: TotalLoss=0.288319 | Sup=0.288283 | Recon=0.000720 | TrainAcc=0.8317
# Fold 18 Epoch 1000: TotalLoss=0.290914 | Sup=0.290878 | Recon=0.000714 | TrainAcc=0.8416
# Fold 18 Epoch 1100: TotalLoss=0.276953 | Sup=0.276917 | Recon=0.000715 | TrainAcc=0.8416
# Fold 18 Epoch 1200: TotalLoss=0.253971 | Sup=0.253935 | Recon=0.000721 | TrainAcc=0.8911
# Fold 18 Epoch 1300: TotalLoss=0.247016 | Sup=0.246980 | Recon=0.000713 | TrainAcc=0.8812
# Fold 18 Epoch 1400: TotalLoss=0.230687 | Sup=0.230651 | Recon=0.000721 | TrainAcc=0.8812
# Fold 18 Epoch 1500: TotalLoss=0.215912 | Sup=0.215876 | Recon=0.000724 | TrainAcc=0.9109
# Fold 18 Epoch 1600: TotalLoss=0.210968 | Sup=0.210933 | Recon=0.000714 | TrainAcc=0.8317
# Fold 18 Epoch 1700: TotalLoss=0.195277 | Sup=0.195241 | Recon=0.000723 | TrainAcc=0.9109
# Fold 18 Epoch 1800: TotalLoss=0.187471 | Sup=0.187435 | Recon=0.000718 | TrainAcc=0.8614
# Fold 18 Epoch 1900: TotalLoss=0.178810 | Sup=0.178775 | Recon=0.000718 | TrainAcc=0.9109
# Fold 18 Epoch 2000: TotalLoss=0.167884 | Sup=0.167848 | Recon=0.000720 | TrainAcc=0.8713
# Fold 18 → Acc=0.8409 | Prec=0.7692 | Rec=0.7143 | F1=0.7407 | AUC=0.9214 | CE Loss=0.3391
#
# === Fold 19 ===
# Train Control: 68, Train Patient: 33
# Fold 19 Epoch 1: TotalLoss=0.772819 | Sup=0.771393 | Recon=0.028515 | TrainAcc=0.6733
# Fold 19 Epoch 100: TotalLoss=0.475061 | Sup=0.474940 | Recon=0.002416 | TrainAcc=0.7525
# Fold 19 Epoch 200: TotalLoss=0.444889 | Sup=0.444826 | Recon=0.001272 | TrainAcc=0.7723
# Fold 19 Epoch 300: TotalLoss=0.420844 | Sup=0.420800 | Recon=0.000892 | TrainAcc=0.8020
# Fold 19 Epoch 400: TotalLoss=0.401708 | Sup=0.401669 | Recon=0.000778 | TrainAcc=0.7723
# Fold 19 Epoch 500: TotalLoss=0.360432 | Sup=0.360395 | Recon=0.000734 | TrainAcc=0.8416
# Fold 19 Epoch 600: TotalLoss=0.339249 | Sup=0.339213 | Recon=0.000718 | TrainAcc=0.8515
# Fold 19 Epoch 700: TotalLoss=0.324884 | Sup=0.324849 | Recon=0.000709 | TrainAcc=0.8614
# Fold 19 Epoch 800: TotalLoss=0.301715 | Sup=0.301679 | Recon=0.000717 | TrainAcc=0.8614
# Fold 19 Epoch 900: TotalLoss=0.282649 | Sup=0.282613 | Recon=0.000713 | TrainAcc=0.8713
# Fold 19 Epoch 1000: TotalLoss=0.267359 | Sup=0.267323 | Recon=0.000722 | TrainAcc=0.8713
# Fold 19 Epoch 1100: TotalLoss=0.250317 | Sup=0.250282 | Recon=0.000716 | TrainAcc=0.8515
# Fold 19 Epoch 1200: TotalLoss=0.237470 | Sup=0.237434 | Recon=0.000721 | TrainAcc=0.8416
# Fold 19 Epoch 1300: TotalLoss=0.227299 | Sup=0.227263 | Recon=0.000721 | TrainAcc=0.8911
# Fold 19 Epoch 1400: TotalLoss=0.216373 | Sup=0.216337 | Recon=0.000722 | TrainAcc=0.8812
# Fold 19 Epoch 1500: TotalLoss=0.205024 | Sup=0.204988 | Recon=0.000717 | TrainAcc=0.8911
# Fold 19 Epoch 1600: TotalLoss=0.190840 | Sup=0.190804 | Recon=0.000716 | TrainAcc=0.8614
# Fold 19 Epoch 1700: TotalLoss=0.178684 | Sup=0.178648 | Recon=0.000717 | TrainAcc=0.8713
# Fold 19 Epoch 1800: TotalLoss=0.185108 | Sup=0.185072 | Recon=0.000716 | TrainAcc=0.9208
# Fold 19 Epoch 1900: TotalLoss=0.153777 | Sup=0.153741 | Recon=0.000720 | TrainAcc=0.8614
# Fold 19 Epoch 2000: TotalLoss=0.156613 | Sup=0.156576 | Recon=0.000724 | TrainAcc=0.9109
# Fold 19 → Acc=0.8409 | Prec=0.7692 | Rec=0.7143 | F1=0.7407 | AUC=0.8571 | CE Loss=0.4566
#
# === Fold 20 ===
# Train Control: 68, Train Patient: 33
# Fold 20 Epoch 1: TotalLoss=0.886405 | Sup=0.885048 | Recon=0.027127 | TrainAcc=0.3267
# Fold 20 Epoch 100: TotalLoss=0.513988 | Sup=0.513863 | Recon=0.002494 | TrainAcc=0.7327
# Fold 20 Epoch 200: TotalLoss=0.482291 | Sup=0.482227 | Recon=0.001284 | TrainAcc=0.7525
# Fold 20 Epoch 300: TotalLoss=0.441827 | Sup=0.441781 | Recon=0.000918 | TrainAcc=0.7723
# Fold 20 Epoch 400: TotalLoss=0.421241 | Sup=0.421202 | Recon=0.000784 | TrainAcc=0.8020
# Fold 20 Epoch 500: TotalLoss=0.406422 | Sup=0.406385 | Recon=0.000740 | TrainAcc=0.8020
# Fold 20 Epoch 600: TotalLoss=0.362142 | Sup=0.362106 | Recon=0.000723 | TrainAcc=0.8119
# Fold 20 Epoch 700: TotalLoss=0.353630 | Sup=0.353594 | Recon=0.000724 | TrainAcc=0.8218
# Fold 20 Epoch 800: TotalLoss=0.336529 | Sup=0.336493 | Recon=0.000723 | TrainAcc=0.8119
# Fold 20 Epoch 900: TotalLoss=0.331624 | Sup=0.331588 | Recon=0.000718 | TrainAcc=0.8416
# Fold 20 Epoch 1000: TotalLoss=0.317126 | Sup=0.317090 | Recon=0.000720 | TrainAcc=0.8416
# Fold 20 Epoch 1100: TotalLoss=0.304104 | Sup=0.304068 | Recon=0.000716 | TrainAcc=0.8218
# Fold 20 Epoch 1200: TotalLoss=0.291643 | Sup=0.291606 | Recon=0.000723 | TrainAcc=0.8218
# Fold 20 Epoch 1300: TotalLoss=0.271798 | Sup=0.271761 | Recon=0.000727 | TrainAcc=0.8119
# Fold 20 Epoch 1400: TotalLoss=0.267457 | Sup=0.267421 | Recon=0.000724 | TrainAcc=0.8515
# Fold 20 Epoch 1500: TotalLoss=0.241068 | Sup=0.241032 | Recon=0.000724 | TrainAcc=0.8416
# Fold 20 Epoch 1600: TotalLoss=0.240785 | Sup=0.240749 | Recon=0.000720 | TrainAcc=0.8218
# Fold 20 Epoch 1700: TotalLoss=0.229555 | Sup=0.229519 | Recon=0.000716 | TrainAcc=0.8515
# Fold 20 Epoch 1800: TotalLoss=0.229644 | Sup=0.229608 | Recon=0.000724 | TrainAcc=0.8812
# Fold 20 Epoch 1900: TotalLoss=0.219367 | Sup=0.219330 | Recon=0.000729 | TrainAcc=0.8911
# Fold 20 Epoch 2000: TotalLoss=0.215149 | Sup=0.215113 | Recon=0.000724 | TrainAcc=0.8614
# Fold 20 → Acc=0.8182 | Prec=1.0000 | Rec=0.4286 | F1=0.6000 | AUC=0.8857 | CE Loss=0.4973
#
# === Average Results Across 20 Folds ===
# Accuracy:  0.8284 ± 0.0535
# Precision: 0.7705 ± 0.1147
# Recall:    0.6893 ± 0.1724
# F1-score:  0.7100 ± 0.1111
# CE Loss:   0.4433 ± 0.1622
# AUC:       0.8999 ± 0.0410

# %%
feats_dim = num_feats
hidden_dim = 512
num_classes = 2
num_epochs = 2000
lr = 1e-4
weight_decay = 1e-4
batch_print_freq = 100

# Lambda values to test
lambda_list = [0.001, 0.005, 0.009, 0.01, 0.05, 0.09, 0.1, 0.3, 0.5, 0.9, 1, 2, 5, 8]

# === Cross-validation setup ===
sss = StratifiedShuffleSplit(n_splits=20, test_size=0.3, random_state=42)
y_all = y.copy()

# To store all results for each lambda
lambda_results = []

# === Outer loop for lambda sweep ===
for lambda_recon in lambda_list:
    print(f"\n\n====================== λ_recon = {lambda_recon} ======================")

    accuracies, precisions, recalls, f1_scores, aucs, ce_losses = [], [], [], [], [], []

    for fold, (train_val_idx, test_idx_global) in enumerate(sss.split(X, y_all), start=1):
        print(f"\n=== Fold {fold} ===")

        control_idx = np.where(y_all == 0)[0]
        patient_idx = np.where(y_all == 1)[0]
        sss_class = StratifiedShuffleSplit(n_splits=20, test_size=0.3, random_state=fold)
        control_train_idx, _ = next(sss_class.split(X[control_idx], y_all[control_idx]))
        patient_train_idx, _ = next(sss_class.split(X[patient_idx], y_all[patient_idx]))
        control_train = control_idx[control_train_idx]
        patient_train = patient_idx[patient_train_idx]
        train_idx_final = np.concatenate([control_train, patient_train])
        np.random.shuffle(train_idx_final)

        print(f"Train Control: {len(control_train)}, Train Patient: {len(patient_train)}")

        train_idx_t = torch.from_numpy(train_idx_final).long().to(device)
        y_train_tensor = torch.from_numpy(y_all[train_idx_final]).long().to(device)

        model = GCN_AE(feats_dim, hidden_dim, num_classes, device, activ="RELU", dropout=0.25).to(device)
        optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
        ce_loss_fn = nn.CrossEntropyLoss()
        recon_loss_fn = nn.MSELoss()
        data = load_data(W, X).to(device)

        for epoch in range(1, num_epochs + 1):
            model.train()
            optimizer.zero_grad()
            logits, recon_x, _ = model(data.x, data.edge_index)

            loss_sup = ce_loss_fn(logits[train_idx_t], y_train_tensor)
            loss_recon = recon_loss_fn(recon_x, data.x)
            total_loss = loss_sup + lambda_recon * loss_recon

            if torch.isnan(total_loss) or torch.isinf(total_loss):
                print(f"NaN/Inf detected at fold {fold} epoch {epoch}. Aborting epoch.")
                break

            total_loss.backward()
            optimizer.step()

            if epoch % batch_print_freq == 0 or epoch == 1:
                model.eval()
                with torch.no_grad():
                    logits_eval, _, _ = model(data.x, data.edge_index)
                    preds_train = logits_eval[train_idx_t].argmax(dim=1)
                    acc_train = accuracy_score(y_train_tensor.cpu(), preds_train.cpu())
                print(f"Fold {fold} Epoch {epoch}: TotalLoss={total_loss.item():.6f} | Sup={loss_sup.item():.6f} | Recon={loss_recon.item():.6f} | TrainAcc={acc_train:.4f}")

        # === Evaluation ===
        model.eval()
        with torch.no_grad():
            out_logits, _, _ = model(data.x, data.edge_index)
            preds = out_logits.argmax(dim=1).cpu().numpy()
            probs = nnFn.softmax(out_logits, dim=1)[:, 1].cpu().numpy()

        y_test = y_all[test_idx_global]
        y_pred_test = preds[test_idx_global]
        y_prob_test = probs[test_idx_global]

        acc = accuracy_score(y_test, y_pred_test)
        prec = precision_score(y_test, y_pred_test, zero_division=0)
        rec = recall_score(y_test, y_pred_test, zero_division=0)
        f1 = f1_score(y_test, y_pred_test, zero_division=0)
        try:
            auc = roc_auc_score(y_test, y_prob_test)
        except ValueError:
            auc = float('nan')
        ce = log_loss(y_test, y_prob_test)

        accuracies.append(acc)
        precisions.append(prec)
        recalls.append(rec)
        f1_scores.append(f1)
        aucs.append(auc)
        ce_losses.append(ce)

        print(f"Fold {fold} → Acc={acc:.4f} | Prec={prec:.4f} | Rec={rec:.4f} | F1={f1:.4f} | AUC={auc:.4f} | CE Loss={ce:.4f}")

    # === Store average results for this λ ===
    avg_results = {
        "lambda": lambda_recon,
        "Accuracy": np.mean(accuracies),
        "Precision": np.mean(precisions),
        "Recall": np.mean(recalls),
        "F1-score": np.mean(f1_scores),
        "CE Loss": np.mean(ce_losses),
        "AUC": np.nanmean(aucs)
    }
    lambda_results.append(avg_results)

    print("\n=== Average Results for λ =", lambda_recon, "===")
    print(f"Accuracy:  {avg_results['Accuracy']:.4f}")
    print(f"Precision: {avg_results['Precision']:.4f}")
    print(f"Recall:    {avg_results['Recall']:.4f}")
    print(f"F1-score:  {avg_results['F1-score']:.4f}")
    print(f"CE Loss:   {avg_results['CE Loss']:.4f}")
    print(f"AUC:       {avg_results['AUC']:.4f}")


# === FINAL SUMMARY ACROSS ALL λ ===
print("\n\n====================== FINAL SUMMARY ACROSS ALL λ ======================")
print(f"{'Lambda':<8} | {'Accuracy':<9} | {'Precision':<9} | {'Recall':<8} | {'F1-score':<9} | {'AUC':<8} | {'CE Loss':<8}")
print("-" * 72)
for res in lambda_results:
    print(f"{res['lambda']:<8} | {res['Accuracy']:<9.4f} | {res['Precision']:<9.4f} | {res['Recall']:<8.4f} | {res['F1-score']:<9.4f} | {res['AUC']:<8.4f} | {res['CE Loss']:<8.4f}")
# Out:
# Streaming output truncated to the last 5000 lines.
# === Fold 6 ===
# Train Control: 68, Train Patient: 33
# Fold 6 Epoch 1: TotalLoss=0.829217 | Sup=0.827738 | Recon=0.029582 | TrainAcc=0.6733
# Fold 6 Epoch 100: TotalLoss=0.484853 | Sup=0.484733 | Recon=0.002407 | TrainAcc=0.7624
# Fold 6 Epoch 200: TotalLoss=0.448755 | Sup=0.448692 | Recon=0.001257 | TrainAcc=0.7624
# Fold 6 Epoch 300: TotalLoss=0.429129 | Sup=0.429085 | Recon=0.000893 | TrainAcc=0.7921
# Fold 6 Epoch 400: TotalLoss=0.414909 | Sup=0.414871 | Recon=0.000765 | TrainAcc=0.7921
# Fold 6 Epoch 500: TotalLoss=0.393942 | Sup=0.393905 | Recon=0.000737 | TrainAcc=0.7921
# Fold 6 Epoch 600: TotalLoss=0.383784 | Sup=0.383749 | Recon=0.000709 | TrainAcc=0.8119
# Fold 6 Epoch 700: TotalLoss=0.355647 | Sup=0.355611 | Recon=0.000714 | TrainAcc=0.8119
# Fold 6 Epoch 800: TotalLoss=0.319685 | Sup=0.319650 | Recon=0.000708 | TrainAcc=0.7921
# Fold 6 Epoch 900: TotalLoss=0.311710 | Sup=0.311675 | Recon=0.000714 | TrainAcc=0.7822
# Fold 6 Epoch 1000: TotalLoss=0.305112 | Sup=0.305076 | Recon=0.000715 | TrainAcc=0.8515
# Fold 6 Epoch 1100: TotalLoss=0.288127 | Sup=0.288092 | Recon=0.000717 | TrainAcc=0.8515
# Fold 6 Epoch 1200: TotalLoss=0.280544 | Sup=0.280508 | Recon=0.000718 | TrainAcc=0.7624
# Fold 6 Epoch 1300: TotalLoss=0.256821 | Sup=0.256785 | Recon=0.000718 | TrainAcc=0.8515
# Fold 6 Epoch 1400: TotalLoss=0.245461 | Sup=0.245425 | Recon=0.000716 | TrainAcc=0.8614
# Fold 6 Epoch 1500: TotalLoss=0.237439 | Sup=0.237403 | Recon=0.000714 | TrainAcc=0.8812
# Fold 6 Epoch 1600: TotalLoss=0.214822 | Sup=0.214786 | Recon=0.000727 | TrainAcc=0.8812
# Fold 6 Epoch 1700: TotalLoss=0.217715 | Sup=0.217679 | Recon=0.000725 | TrainAcc=0.8218
# Fold 6 Epoch 1800: TotalLoss=0.199968 | Sup=0.199932 | Recon=0.000722 | TrainAcc=0.8515
# Fold 6 Epoch 1900: TotalLoss=0.193012 | Sup=0.192975 | Recon=0.000728 | TrainAcc=0.8515
# Fold 6 Epoch 2000: TotalLoss=0.191163 | Sup=0.191127 | Recon=0.000730 | TrainAcc=0.9010
# Fold 6 → Acc=0.8409 | Prec=1.0000 | Rec=0.5000 | F1=0.6667 | AUC=0.9095 | CE Loss=0.3668
#
# === Fold 7 ===
# Train Control: 68, Train Patient: 33
# Fold 7 Epoch 1: TotalLoss=0.763132 | Sup=0.761662 | Recon=0.029391 | TrainAcc=0.3267
# Fold 7 Epoch 100: TotalLoss=0.476728 | Sup=0.476608 | Recon=0.002406 | TrainAcc=0.7228
# Fold 7 Epoch 200: TotalLoss=0.445567 | Sup=0.445506 | Recon=0.001217 | TrainAcc=0.7525
# Fold 7 Epoch 300: TotalLoss=0.425018 | Sup=0.424974 | Recon=0.000877 | TrainAcc=0.7624
# Fold 7 Epoch 400: TotalLoss=0.393252 | Sup=0.393214 | Recon=0.000770 | TrainAcc=0.7426
# Fold 7 Epoch 500: TotalLoss=0.378420 | Sup=0.378384 | Recon=0.000724 | TrainAcc=0.8020
# Fold 7 Epoch 600: TotalLoss=0.342149 | Sup=0.342113 | Recon=0.000721 | TrainAcc=0.7921
# Fold 7 Epoch 700: TotalLoss=0.320564 | Sup=0.320528 | Recon=0.000713 | TrainAcc=0.8119
# Fold 7 Epoch 800: TotalLoss=0.294940 | Sup=0.294904 | Recon=0.000716 | TrainAcc=0.8614
# Fold 7 Epoch 900: TotalLoss=0.281165 | Sup=0.281128 | Recon=0.000725 | TrainAcc=0.8713
# Fold 7 Epoch 1000: TotalLoss=0.257627 | Sup=0.257591 | Recon=0.000726 | TrainAcc=0.8713
# Fold 7 Epoch 1100: TotalLoss=0.248174 | Sup=0.248138 | Recon=0.000726 | TrainAcc=0.8713
# Fold 7 Epoch 1200: TotalLoss=0.238028 | Sup=0.237992 | Recon=0.000727 | TrainAcc=0.8812
# Fold 7 Epoch 1300: TotalLoss=0.222289 | Sup=0.222252 | Recon=0.000734 | TrainAcc=0.8614
# Fold 7 Epoch 1400: TotalLoss=0.210385 | Sup=0.210348 | Recon=0.000731 | TrainAcc=0.8317
# Fold 7 Epoch 1500: TotalLoss=0.196261 | Sup=0.196224 | Recon=0.000742 | TrainAcc=0.8812
# Fold 7 Epoch 1600: TotalLoss=0.187755 | Sup=0.187718 | Recon=0.000737 | TrainAcc=0.9010
# Fold 7 Epoch 1700: TotalLoss=0.165631 | Sup=0.165594 | Recon=0.000739 | TrainAcc=0.9010
# Fold 7 Epoch 1800: TotalLoss=0.160902 | Sup=0.160865 | Recon=0.000739 | TrainAcc=0.8911
# Fold 7 Epoch 1900: TotalLoss=0.163416 | Sup=0.163379 | Recon=0.000746 | TrainAcc=0.9406
# Fold 7 Epoch 2000: TotalLoss=0.151404 | Sup=0.151367 | Recon=0.000748 | TrainAcc=0.9010
# Fold 7 → Acc=0.8182 | Prec=0.6667 | Rec=0.8571 | F1=0.7500 | AUC=0.8095 | CE Loss=0.8404
#
# === Fold 8 ===
# Train Control: 68, Train Patient: 33
# Fold 8 Epoch 1: TotalLoss=0.876795 | Sup=0.875028 | Recon=0.035338 | TrainAcc=0.3267
# Fold 8 Epoch 100: TotalLoss=0.498700 | Sup=0.498576 | Recon=0.002488 | TrainAcc=0.7030
# Fold 8 Epoch 200: TotalLoss=0.478493 | Sup=0.478426 | Recon=0.001344 | TrainAcc=0.7228
# Fold 8 Epoch 300: TotalLoss=0.465209 | Sup=0.465162 | Recon=0.000939 | TrainAcc=0.7525
# Fold 8 Epoch 400: TotalLoss=0.446676 | Sup=0.446637 | Recon=0.000789 | TrainAcc=0.7723
# Fold 8 Epoch 500: TotalLoss=0.420042 | Sup=0.420005 | Recon=0.000734 | TrainAcc=0.7921
# Fold 8 Epoch 600: TotalLoss=0.409652 | Sup=0.409616 | Recon=0.000727 | TrainAcc=0.7822
# Fold 8 Epoch 700: TotalLoss=0.374571 | Sup=0.374535 | Recon=0.000722 | TrainAcc=0.8020
# Fold 8 Epoch 800: TotalLoss=0.366623 | Sup=0.366587 | Recon=0.000726 | TrainAcc=0.8317
# Fold 8 Epoch 900: TotalLoss=0.347545 | Sup=0.347508 | Recon=0.000728 | TrainAcc=0.8119
# Fold 8 Epoch 1000: TotalLoss=0.322662 | Sup=0.322626 | Recon=0.000728 | TrainAcc=0.7723
# Fold 8 Epoch 1100: TotalLoss=0.304635 | Sup=0.304599 | Recon=0.000718 | TrainAcc=0.8218
# Fold 8 Epoch 1200: TotalLoss=0.311650 | Sup=0.311614 | Recon=0.000725 | TrainAcc=0.8218
# Fold 8 Epoch 1300: TotalLoss=0.285457 | Sup=0.285420 | Recon=0.000727 | TrainAcc=0.8218
# Fold 8 Epoch 1400: TotalLoss=0.279124 | Sup=0.279088 | Recon=0.000724 | TrainAcc=0.8713
# Fold 8 Epoch 1500: TotalLoss=0.262549 | Sup=0.262513 | Recon=0.000721 | TrainAcc=0.8317
# Fold 8 Epoch 1600: TotalLoss=0.254468 | Sup=0.254432 | Recon=0.000721 | TrainAcc=0.8119
# Fold 8 Epoch 1700: TotalLoss=0.230496 | Sup=0.230459 | Recon=0.000728 | TrainAcc=0.8812
# Fold 8 Epoch 1800: TotalLoss=0.213996 | Sup=0.213960 | Recon=0.000724 | TrainAcc=0.7921
# Fold 8 Epoch 1900: TotalLoss=0.203964 | Sup=0.203928 | Recon=0.000721 | TrainAcc=0.8614
# Fold 8 Epoch 2000: TotalLoss=0.202118 | Sup=0.202082 | Recon=0.000726 | TrainAcc=0.8218
# Fold 8 → Acc=0.8409 | Prec=1.0000 | Rec=0.5000 | F1=0.6667 | AUC=0.9500 | CE Loss=0.3032
#
# === Fold 9 ===
# Train Control: 68, Train Patient: 33
# Fold 9 Epoch 1: TotalLoss=0.780376 | Sup=0.778910 | Recon=0.029326 | TrainAcc=0.3267
# Fold 9 Epoch 100: TotalLoss=0.472854 | Sup=0.472738 | Recon=0.002326 | TrainAcc=0.7228
# Fold 9 Epoch 200: TotalLoss=0.456709 | Sup=0.456647 | Recon=0.001258 | TrainAcc=0.7921
# Fold 9 Epoch 300: TotalLoss=0.441218 | Sup=0.441172 | Recon=0.000918 | TrainAcc=0.7525
# Fold 9 Epoch 400: TotalLoss=0.434555 | Sup=0.434516 | Recon=0.000783 | TrainAcc=0.7822
# Fold 9 Epoch 500: TotalLoss=0.395466 | Sup=0.395429 | Recon=0.000731 | TrainAcc=0.7426
# Fold 9 Epoch 600: TotalLoss=0.397803 | Sup=0.397767 | Recon=0.000723 | TrainAcc=0.7723
# Fold 9 Epoch 700: TotalLoss=0.355042 | Sup=0.355006 | Recon=0.000720 | TrainAcc=0.7525
# Fold 9 Epoch 800: TotalLoss=0.335512 | Sup=0.335476 | Recon=0.000717 | TrainAcc=0.8020
# Fold 9 Epoch 900: TotalLoss=0.325683 | Sup=0.325647 | Recon=0.000723 | TrainAcc=0.8119
# Fold 9 Epoch 1000: TotalLoss=0.300834 | Sup=0.300798 | Recon=0.000725 | TrainAcc=0.8317
# Fold 9 Epoch 1100: TotalLoss=0.292231 | Sup=0.292195 | Recon=0.000724 | TrainAcc=0.8218
# Fold 9 Epoch 1200: TotalLoss=0.292934 | Sup=0.292898 | Recon=0.000730 | TrainAcc=0.8515
# Fold 9 Epoch 1300: TotalLoss=0.261147 | Sup=0.261111 | Recon=0.000729 | TrainAcc=0.8317
# Fold 9 Epoch 1400: TotalLoss=0.252333 | Sup=0.252296 | Recon=0.000734 | TrainAcc=0.8119
# Fold 9 Epoch 1500: TotalLoss=0.239847 | Sup=0.239810 | Recon=0.000731 | TrainAcc=0.8515
# Fold 9 Epoch 1600: TotalLoss=0.234905 | Sup=0.234868 | Recon=0.000729 | TrainAcc=0.8614
# Fold 9 Epoch 1700: TotalLoss=0.217113 | Sup=0.217076 | Recon=0.000737 | TrainAcc=0.8614
# Fold 9 Epoch 1800: TotalLoss=0.192326 | Sup=0.192290 | Recon=0.000732 | TrainAcc=0.8317
# Fold 9 Epoch 1900: TotalLoss=0.195693 | Sup=0.195657 | Recon=0.000737 | TrainAcc=0.8812
# Fold 9 Epoch 2000: TotalLoss=0.185509 | Sup=0.185472 | Recon=0.000740 | TrainAcc=0.8515
# Fold 9 → Acc=0.7727 | Prec=0.8333 | Rec=0.3571 | F1=0.5000 | AUC=0.8786 | CE Loss=0.4178
#
# === Fold 10 ===
# Train Control: 68, Train Patient: 33
# Fold 10 Epoch 1: TotalLoss=0.720154 | Sup=0.718741 | Recon=0.028247 | TrainAcc=0.6733
# Fold 10 Epoch 100: TotalLoss=0.490373 | Sup=0.490255 | Recon=0.002342 | TrainAcc=0.7723
# Fold 10 Epoch 200: TotalLoss=0.473528 | Sup=0.473467 | Recon=0.001225 | TrainAcc=0.7624
# Fold 10 Epoch 300: TotalLoss=0.441894 | Sup=0.441849 | Recon=0.000884 | TrainAcc=0.7723
# Fold 10 Epoch 400: TotalLoss=0.419434 | Sup=0.419396 | Recon=0.000768 | TrainAcc=0.8020
# Fold 10 Epoch 500: TotalLoss=0.413348 | Sup=0.413312 | Recon=0.000722 | TrainAcc=0.8119
# Fold 10 Epoch 600: TotalLoss=0.372601 | Sup=0.372565 | Recon=0.000715 | TrainAcc=0.8020
# Fold 10 Epoch 700: TotalLoss=0.361696 | Sup=0.361661 | Recon=0.000710 | TrainAcc=0.8218
# Fold 10 Epoch 800: TotalLoss=0.347341 | Sup=0.347305 | Recon=0.000718 | TrainAcc=0.8218
# Fold 10 Epoch 900: TotalLoss=0.319717 | Sup=0.319682 | Recon=0.000709 | TrainAcc=0.8119
# Fold 10 Epoch 1000: TotalLoss=0.292894 | Sup=0.292858 | Recon=0.000714 | TrainAcc=0.8317
# Fold 10 Epoch 1100: TotalLoss=0.287693 | Sup=0.287657 | Recon=0.000720 | TrainAcc=0.7129
# Fold 10 Epoch 1200: TotalLoss=0.276711 | Sup=0.276675 | Recon=0.000722 | TrainAcc=0.8614
# Fold 10 Epoch 1300: TotalLoss=0.276286 | Sup=0.276250 | Recon=0.000722 | TrainAcc=0.8416
# Fold 10 Epoch 1400: TotalLoss=0.254700 | Sup=0.254664 | Recon=0.000720 | TrainAcc=0.8614
# Fold 10 Epoch 1500: TotalLoss=0.236496 | Sup=0.236460 | Recon=0.000732 | TrainAcc=0.8713
# Fold 10 Epoch 1600: TotalLoss=0.223963 | Sup=0.223926 | Recon=0.000733 | TrainAcc=0.7624
# Fold 10 Epoch 1700: TotalLoss=0.217812 | Sup=0.217775 | Recon=0.000733 | TrainAcc=0.9010
# Fold 10 Epoch 1800: TotalLoss=0.210973 | Sup=0.210937 | Recon=0.000734 | TrainAcc=0.7624
# Fold 10 Epoch 1900: TotalLoss=0.182598 | Sup=0.182561 | Recon=0.000734 | TrainAcc=0.8713
# Fold 10 Epoch 2000: TotalLoss=0.179434 | Sup=0.179397 | Recon=0.000741 | TrainAcc=0.8713
# Fold 10 → Acc=0.8409 | Prec=0.6667 | Rec=1.0000 | F1=0.8000 | AUC=0.9357 | CE Loss=0.3838
#
# === Fold 11 ===
# Train Control: 68, Train Patient: 33
# Fold 11 Epoch 1: TotalLoss=0.622151 | Sup=0.620711 | Recon=0.028786 | TrainAcc=0.7030
# Fold 11 Epoch 100: TotalLoss=0.475063 | Sup=0.474946 | Recon=0.002343 | TrainAcc=0.7426
# Fold 11 Epoch 200: TotalLoss=0.441777 | Sup=0.441714 | Recon=0.001275 | TrainAcc=0.7624
# Fold 11 Epoch 300: TotalLoss=0.413967 | Sup=0.413920 | Recon=0.000930 | TrainAcc=0.7822
# Fold 11 Epoch 400: TotalLoss=0.375530 | Sup=0.375490 | Recon=0.000799 | TrainAcc=0.7723
# Fold 11 Epoch 500: TotalLoss=0.350436 | Sup=0.350398 | Recon=0.000756 | TrainAcc=0.8218
# Fold 11 Epoch 600: TotalLoss=0.335540 | Sup=0.335502 | Recon=0.000750 | TrainAcc=0.8119
# Fold 11 Epoch 700: TotalLoss=0.314855 | Sup=0.314818 | Recon=0.000737 | TrainAcc=0.8119
# Fold 11 Epoch 800: TotalLoss=0.294428 | Sup=0.294392 | Recon=0.000732 | TrainAcc=0.8515
# Fold 11 Epoch 900: TotalLoss=0.262680 | Sup=0.262643 | Recon=0.000735 | TrainAcc=0.8812
# Fold 11 Epoch 1000: TotalLoss=0.259755 | Sup=0.259718 | Recon=0.000727 | TrainAcc=0.8218
# Fold 11 Epoch 1100: TotalLoss=0.253763 | Sup=0.253726 | Recon=0.000731 | TrainAcc=0.8614
# Fold 11 Epoch 1200: TotalLoss=0.238102 | Sup=0.238065 | Recon=0.000736 | TrainAcc=0.8812
# Fold 11 Epoch 1300: TotalLoss=0.232202 | Sup=0.232166 | Recon=0.000733 | TrainAcc=0.9010
# Fold 11 Epoch 1400: TotalLoss=0.211782 | Sup=0.211746 | Recon=0.000735 | TrainAcc=0.8614
# Fold 11 Epoch 1500: TotalLoss=0.209333 | Sup=0.209296 | Recon=0.000735 | TrainAcc=0.8416
# Fold 11 Epoch 1600: TotalLoss=0.203401 | Sup=0.203364 | Recon=0.000738 | TrainAcc=0.8317
# Fold 11 Epoch 1700: TotalLoss=0.206531 | Sup=0.206494 | Recon=0.000733 | TrainAcc=0.9010
# Fold 11 Epoch 1800: TotalLoss=0.197698 | Sup=0.197661 | Recon=0.000740 | TrainAcc=0.8317
# Fold 11 Epoch 1900: TotalLoss=0.170833 | Sup=0.170796 | Recon=0.000738 | TrainAcc=0.8218
# Fold 11 Epoch 2000: TotalLoss=0.170504 | Sup=0.170467 | Recon=0.000735 | TrainAcc=0.8515
# Fold 11 → Acc=0.7955 | Prec=0.6471 | Rec=0.7857 | F1=0.7097 | AUC=0.8429 | CE Loss=0.6757
#
# === Fold 12 ===
# Train Control: 68, Train Patient: 33
# Fold 12 Epoch 1: TotalLoss=0.688746 | Sup=0.687029 | Recon=0.034350 | TrainAcc=0.3267
# Fold 12 Epoch 100: TotalLoss=0.435744 | Sup=0.435615 | Recon=0.002584 | TrainAcc=0.7624
# Fold 12 Epoch 200: TotalLoss=0.416638 | Sup=0.416570 | Recon=0.001365 | TrainAcc=0.7822
# Fold 12 Epoch 300: TotalLoss=0.394108 | Sup=0.394061 | Recon=0.000931 | TrainAcc=0.8218
# Fold 12 Epoch 400: TotalLoss=0.365641 | Sup=0.365600 | Recon=0.000820 | TrainAcc=0.8218
# Fold 12 Epoch 500: TotalLoss=0.357863 | Sup=0.357826 | Recon=0.000745 | TrainAcc=0.8218
# Fold 12 Epoch 600: TotalLoss=0.346981 | Sup=0.346944 | Recon=0.000725 | TrainAcc=0.8317
# Fold 12 Epoch 700: TotalLoss=0.314876 | Sup=0.314840 | Recon=0.000717 | TrainAcc=0.8515
# Fold 12 Epoch 800: TotalLoss=0.301304 | Sup=0.301268 | Recon=0.000717 | TrainAcc=0.8020
# Fold 12 Epoch 900: TotalLoss=0.275369 | Sup=0.275333 | Recon=0.000714 | TrainAcc=0.8515
# Fold 12 Epoch 1000: TotalLoss=0.255141 | Sup=0.255104 | Recon=0.000728 | TrainAcc=0.8317
# Fold 12 Epoch 1100: TotalLoss=0.246768 | Sup=0.246732 | Recon=0.000711 | TrainAcc=0.8515
# Fold 12 Epoch 1200: TotalLoss=0.243996 | Sup=0.243960 | Recon=0.000720 | TrainAcc=0.8614
# Fold 12 Epoch 1300: TotalLoss=0.236796 | Sup=0.236760 | Recon=0.000725 | TrainAcc=0.8812
# Fold 12 Epoch 1400: TotalLoss=0.219268 | Sup=0.219233 | Recon=0.000715 | TrainAcc=0.8713
# Fold 12 Epoch 1500: TotalLoss=0.223382 | Sup=0.223346 | Recon=0.000726 | TrainAcc=0.8713
# Fold 12 Epoch 1600: TotalLoss=0.203581 | Sup=0.203544 | Recon=0.000723 | TrainAcc=0.8812
# Fold 12 Epoch 1700: TotalLoss=0.200066 | Sup=0.200030 | Recon=0.000728 | TrainAcc=0.8911
# Fold 12 Epoch 1800: TotalLoss=0.184446 | Sup=0.184410 | Recon=0.000725 | TrainAcc=0.8614
# Fold 12 Epoch 1900: TotalLoss=0.183108 | Sup=0.183071 | Recon=0.000729 | TrainAcc=0.8812
# Fold 12 Epoch 2000: TotalLoss=0.179305 | Sup=0.179269 | Recon=0.000726 | TrainAcc=0.8911
# Fold 12 → Acc=0.8636 | Prec=0.7857 | Rec=0.7857 | F1=0.7857 | AUC=0.8857 | CE Loss=0.4428
#
# === Fold 13 ===
# Train Control: 68, Train Patient: 33
# Fold 13 Epoch 1: TotalLoss=0.685962 | Sup=0.684310 | Recon=0.033047 | TrainAcc=0.6733
# Fold 13 Epoch 100: TotalLoss=0.482001 | Sup=0.481880 | Recon=0.002412 | TrainAcc=0.7030
# Fold 13 Epoch 200: TotalLoss=0.456038 | Sup=0.455973 | Recon=0.001295 | TrainAcc=0.7921
# Fold 13 Epoch 300: TotalLoss=0.421983 | Sup=0.421937 | Recon=0.000915 | TrainAcc=0.7723
# Fold 13 Epoch 400: TotalLoss=0.400058 | Sup=0.400020 | Recon=0.000777 | TrainAcc=0.7822
# Fold 13 Epoch 500: TotalLoss=0.366979 | Sup=0.366942 | Recon=0.000734 | TrainAcc=0.8119
# Fold 13 Epoch 600: TotalLoss=0.350569 | Sup=0.350533 | Recon=0.000727 | TrainAcc=0.8020
# Fold 13 Epoch 700: TotalLoss=0.323445 | Sup=0.323409 | Recon=0.000721 | TrainAcc=0.8614
# Fold 13 Epoch 800: TotalLoss=0.304223 | Sup=0.304187 | Recon=0.000718 | TrainAcc=0.8416
# Fold 13 Epoch 900: TotalLoss=0.290774 | Sup=0.290738 | Recon=0.000729 | TrainAcc=0.8317
# Fold 13 Epoch 1000: TotalLoss=0.257933 | Sup=0.257897 | Recon=0.000723 | TrainAcc=0.8416
# Fold 13 Epoch 1100: TotalLoss=0.241481 | Sup=0.241444 | Recon=0.000733 | TrainAcc=0.8416
# Fold 13 Epoch 1200: TotalLoss=0.223905 | Sup=0.223869 | Recon=0.000732 | TrainAcc=0.9010
# Fold 13 Epoch 1300: TotalLoss=0.213100 | Sup=0.213064 | Recon=0.000735 | TrainAcc=0.8416
# Fold 13 Epoch 1400: TotalLoss=0.201218 | Sup=0.201181 | Recon=0.000741 | TrainAcc=0.9010
# Fold 13 Epoch 1500: TotalLoss=0.195573 | Sup=0.195537 | Recon=0.000732 | TrainAcc=0.9010
# Fold 13 Epoch 1600: TotalLoss=0.177246 | Sup=0.177209 | Recon=0.000742 | TrainAcc=0.9208
# Fold 13 Epoch 1700: TotalLoss=0.161451 | Sup=0.161414 | Recon=0.000740 | TrainAcc=0.8515
# Fold 13 Epoch 1800: TotalLoss=0.155261 | Sup=0.155224 | Recon=0.000748 | TrainAcc=0.9307
# Fold 13 Epoch 1900: TotalLoss=0.141540 | Sup=0.141503 | Recon=0.000752 | TrainAcc=0.9307
# Fold 13 Epoch 2000: TotalLoss=0.148995 | Sup=0.148958 | Recon=0.000751 | TrainAcc=0.9307
# Fold 13 → Acc=0.9091 | Prec=1.0000 | Rec=0.7143 | F1=0.8333 | AUC=0.9667 | CE Loss=0.2456
#
# === Fold 14 ===
# Train Control: 68, Train Patient: 33
# Fold 14 Epoch 1: TotalLoss=0.818394 | Sup=0.816827 | Recon=0.031336 | TrainAcc=0.3267
# Fold 14 Epoch 100: TotalLoss=0.490307 | Sup=0.490193 | Recon=0.002286 | TrainAcc=0.7426
# Fold 14 Epoch 200: TotalLoss=0.474781 | Sup=0.474719 | Recon=0.001244 | TrainAcc=0.7228
# Fold 14 Epoch 300: TotalLoss=0.457044 | Sup=0.457000 | Recon=0.000889 | TrainAcc=0.7723
# Fold 14 Epoch 400: TotalLoss=0.432224 | Sup=0.432186 | Recon=0.000765 | TrainAcc=0.7921
# Fold 14 Epoch 500: TotalLoss=0.408337 | Sup=0.408301 | Recon=0.000718 | TrainAcc=0.7822
# Fold 14 Epoch 600: TotalLoss=0.382451 | Sup=0.382415 | Recon=0.000711 | TrainAcc=0.7624
# Fold 14 Epoch 700: TotalLoss=0.376143 | Sup=0.376107 | Recon=0.000717 | TrainAcc=0.7723
# Fold 14 Epoch 800: TotalLoss=0.351567 | Sup=0.351531 | Recon=0.000721 | TrainAcc=0.8020
# Fold 14 Epoch 900: TotalLoss=0.336636 | Sup=0.336600 | Recon=0.000721 | TrainAcc=0.8119
# Fold 14 Epoch 1000: TotalLoss=0.311469 | Sup=0.311433 | Recon=0.000718 | TrainAcc=0.8416
# Fold 14 Epoch 1100: TotalLoss=0.294026 | Sup=0.293990 | Recon=0.000716 | TrainAcc=0.8317
# Fold 14 Epoch 1200: TotalLoss=0.271747 | Sup=0.271710 | Recon=0.000732 | TrainAcc=0.8119
# Fold 14 Epoch 1300: TotalLoss=0.270432 | Sup=0.270395 | Recon=0.000726 | TrainAcc=0.8515
# Fold 14 Epoch 1400: TotalLoss=0.244630 | Sup=0.244594 | Recon=0.000724 | TrainAcc=0.8515
# Fold 14 Epoch 1500: TotalLoss=0.230198 | Sup=0.230161 | Recon=0.000734 | TrainAcc=0.8515
# Fold 14 Epoch 1600: TotalLoss=0.226174 | Sup=0.226137 | Recon=0.000736 | TrainAcc=0.8614
# Fold 14 Epoch 1700: TotalLoss=0.204386 | Sup=0.204349 | Recon=0.000734 | TrainAcc=0.8713
# Fold 14 Epoch 1800: TotalLoss=0.188701 | Sup=0.188664 | Recon=0.000739 | TrainAcc=0.8911
# Fold 14 Epoch 1900: TotalLoss=0.185284 | Sup=0.185247 | Recon=0.000731 | TrainAcc=0.9109
# Fold 14 Epoch 2000: TotalLoss=0.167661 | Sup=0.167624 | Recon=0.000740 | TrainAcc=0.8416
# Fold 14 → Acc=0.8636 | Prec=0.7222 | Rec=0.9286 | F1=0.8125 | AUC=0.9262 | CE Loss=0.4157
#
# === Fold 15 ===
# Train Control: 68, Train Patient: 33
# Fold 15 Epoch 1: TotalLoss=0.757641 | Sup=0.756248 | Recon=0.027847 | TrainAcc=0.3267
# Fold 15 Epoch 100: TotalLoss=0.487367 | Sup=0.487256 | Recon=0.002210 | TrainAcc=0.7525
# Fold 15 Epoch 200: TotalLoss=0.455736 | Sup=0.455675 | Recon=0.001232 | TrainAcc=0.7525
# Fold 15 Epoch 300: TotalLoss=0.430174 | Sup=0.430129 | Recon=0.000893 | TrainAcc=0.7921
# Fold 15 Epoch 400: TotalLoss=0.406851 | Sup=0.406812 | Recon=0.000771 | TrainAcc=0.8218
# Fold 15 Epoch 500: TotalLoss=0.371793 | Sup=0.371757 | Recon=0.000725 | TrainAcc=0.8317
# Fold 15 Epoch 600: TotalLoss=0.347602 | Sup=0.347566 | Recon=0.000720 | TrainAcc=0.7921
# Fold 15 Epoch 700: TotalLoss=0.325009 | Sup=0.324974 | Recon=0.000713 | TrainAcc=0.8020
# Fold 15 Epoch 800: TotalLoss=0.316303 | Sup=0.316267 | Recon=0.000721 | TrainAcc=0.8416
# Fold 15 Epoch 900: TotalLoss=0.306074 | Sup=0.306038 | Recon=0.000721 | TrainAcc=0.8218
# Fold 15 Epoch 1000: TotalLoss=0.271525 | Sup=0.271489 | Recon=0.000722 | TrainAcc=0.8416
# Fold 15 Epoch 1100: TotalLoss=0.255492 | Sup=0.255456 | Recon=0.000722 | TrainAcc=0.8812
# Fold 15 Epoch 1200: TotalLoss=0.239226 | Sup=0.239190 | Recon=0.000715 | TrainAcc=0.8020
# Fold 15 Epoch 1300: TotalLoss=0.229841 | Sup=0.229805 | Recon=0.000722 | TrainAcc=0.9307
# Fold 15 Epoch 1400: TotalLoss=0.202866 | Sup=0.202830 | Recon=0.000718 | TrainAcc=0.8812
# Fold 15 Epoch 1500: TotalLoss=0.203937 | Sup=0.203901 | Recon=0.000725 | TrainAcc=0.8911
# Fold 15 Epoch 1600: TotalLoss=0.180426 | Sup=0.180390 | Recon=0.000722 | TrainAcc=0.8713
# Fold 15 Epoch 1700: TotalLoss=0.178384 | Sup=0.178348 | Recon=0.000727 | TrainAcc=0.8317
# Fold 15 Epoch 1800: TotalLoss=0.164065 | Sup=0.164028 | Recon=0.000733 | TrainAcc=0.9505
# Fold 15 Epoch 1900: TotalLoss=0.152036 | Sup=0.152000 | Recon=0.000730 | TrainAcc=0.8515
# Fold 15 Epoch 2000: TotalLoss=0.136263 | Sup=0.136226 | Recon=0.000737 | TrainAcc=0.9505
# Fold 15 → Acc=0.8864 | Prec=0.7647 | Rec=0.9286 | F1=0.8387 | AUC=0.9667 | CE Loss=0.2589
#
# === Fold 16 ===
# Train Control: 68, Train Patient: 33
# Fold 16 Epoch 1: TotalLoss=0.678257 | Sup=0.676951 | Recon=0.026107 | TrainAcc=0.5941
# Fold 16 Epoch 100: TotalLoss=0.463852 | Sup=0.463737 | Recon=0.002288 | TrainAcc=0.7228
# Fold 16 Epoch 200: TotalLoss=0.435875 | Sup=0.435813 | Recon=0.001242 | TrainAcc=0.7426
# Fold 16 Epoch 300: TotalLoss=0.411276 | Sup=0.411232 | Recon=0.000893 | TrainAcc=0.7327
# Fold 16 Epoch 400: TotalLoss=0.383011 | Sup=0.382973 | Recon=0.000763 | TrainAcc=0.7822
# Fold 16 Epoch 500: TotalLoss=0.368678 | Sup=0.368642 | Recon=0.000734 | TrainAcc=0.8020
# Fold 16 Epoch 600: TotalLoss=0.357727 | Sup=0.357691 | Recon=0.000723 | TrainAcc=0.8416
# Fold 16 Epoch 700: TotalLoss=0.333435 | Sup=0.333399 | Recon=0.000715 | TrainAcc=0.7921
# Fold 16 Epoch 800: TotalLoss=0.317688 | Sup=0.317652 | Recon=0.000719 | TrainAcc=0.8515
# Fold 16 Epoch 900: TotalLoss=0.298464 | Sup=0.298429 | Recon=0.000716 | TrainAcc=0.8317
# Fold 16 Epoch 1000: TotalLoss=0.283652 | Sup=0.283616 | Recon=0.000720 | TrainAcc=0.8416
# Fold 16 Epoch 1100: TotalLoss=0.264594 | Sup=0.264558 | Recon=0.000715 | TrainAcc=0.8416
# Fold 16 Epoch 1200: TotalLoss=0.260553 | Sup=0.260517 | Recon=0.000715 | TrainAcc=0.8515
# Fold 16 Epoch 1300: TotalLoss=0.250749 | Sup=0.250712 | Recon=0.000722 | TrainAcc=0.8515
# Fold 16 Epoch 1400: TotalLoss=0.235557 | Sup=0.235521 | Recon=0.000716 | TrainAcc=0.8515
# Fold 16 Epoch 1500: TotalLoss=0.234578 | Sup=0.234542 | Recon=0.000720 | TrainAcc=0.8020
# Fold 16 Epoch 1600: TotalLoss=0.216970 | Sup=0.216933 | Recon=0.000729 | TrainAcc=0.8812
# Fold 16 Epoch 1700: TotalLoss=0.205020 | Sup=0.204983 | Recon=0.000727 | TrainAcc=0.8911
# Fold 16 Epoch 1800: TotalLoss=0.191767 | Sup=0.191731 | Recon=0.000728 | TrainAcc=0.8515
# Fold 16 Epoch 1900: TotalLoss=0.184665 | Sup=0.184629 | Recon=0.000721 | TrainAcc=0.8614
# Fold 16 Epoch 2000: TotalLoss=0.182794 | Sup=0.182758 | Recon=0.000723 | TrainAcc=0.9010
# Fold 16 → Acc=0.8409 | Prec=0.7692 | Rec=0.7143 | F1=0.7407 | AUC=0.9143 | CE Loss=0.4513
#
# === Fold 17 ===
# Train Control: 68, Train Patient: 33
# Fold 17 Epoch 1: TotalLoss=0.727378 | Sup=0.725770 | Recon=0.032165 | TrainAcc=0.3267
# Fold 17 Epoch 100: TotalLoss=0.515766 | Sup=0.515645 | Recon=0.002431 | TrainAcc=0.6832
# Fold 17 Epoch 200: TotalLoss=0.494544 | Sup=0.494479 | Recon=0.001284 | TrainAcc=0.7030
# Fold 17 Epoch 300: TotalLoss=0.460882 | Sup=0.460836 | Recon=0.000918 | TrainAcc=0.7525
# Fold 17 Epoch 400: TotalLoss=0.427822 | Sup=0.427783 | Recon=0.000776 | TrainAcc=0.7327
# Fold 17 Epoch 500: TotalLoss=0.404556 | Sup=0.404519 | Recon=0.000733 | TrainAcc=0.7921
# Fold 17 Epoch 600: TotalLoss=0.369835 | Sup=0.369800 | Recon=0.000719 | TrainAcc=0.8119
# Fold 17 Epoch 700: TotalLoss=0.345845 | Sup=0.345809 | Recon=0.000719 | TrainAcc=0.8119
# Fold 17 Epoch 800: TotalLoss=0.324246 | Sup=0.324210 | Recon=0.000713 | TrainAcc=0.8416
# Fold 17 Epoch 900: TotalLoss=0.321326 | Sup=0.321290 | Recon=0.000716 | TrainAcc=0.8317
# Fold 17 Epoch 1000: TotalLoss=0.294741 | Sup=0.294706 | Recon=0.000713 | TrainAcc=0.8317
# Fold 17 Epoch 1100: TotalLoss=0.278646 | Sup=0.278610 | Recon=0.000716 | TrainAcc=0.8713
# Fold 17 Epoch 1200: TotalLoss=0.265820 | Sup=0.265784 | Recon=0.000720 | TrainAcc=0.8713
# Fold 17 Epoch 1300: TotalLoss=0.254574 | Sup=0.254537 | Recon=0.000724 | TrainAcc=0.8812
# Fold 17 Epoch 1400: TotalLoss=0.234574 | Sup=0.234538 | Recon=0.000721 | TrainAcc=0.8317
# Fold 17 Epoch 1500: TotalLoss=0.212085 | Sup=0.212049 | Recon=0.000716 | TrainAcc=0.8515
# Fold 17 Epoch 1600: TotalLoss=0.211861 | Sup=0.211824 | Recon=0.000725 | TrainAcc=0.8416
# Fold 17 Epoch 1700: TotalLoss=0.223371 | Sup=0.223334 | Recon=0.000724 | TrainAcc=0.8614
# Fold 17 Epoch 1800: TotalLoss=0.194932 | Sup=0.194896 | Recon=0.000722 | TrainAcc=0.8515
# Fold 17 Epoch 1900: TotalLoss=0.197998 | Sup=0.197962 | Recon=0.000725 | TrainAcc=0.8812
# Fold 17 Epoch 2000: TotalLoss=0.187291 | Sup=0.187254 | Recon=0.000732 | TrainAcc=0.8812
# Fold 17 → Acc=0.8409 | Prec=0.7059 | Rec=0.8571 | F1=0.7742 | AUC=0.9393 | CE Loss=0.2872
#
# === Fold 18 ===
# Train Control: 68, Train Patient: 33
# Fold 18 Epoch 1: TotalLoss=0.677945 | Sup=0.676202 | Recon=0.034880 | TrainAcc=0.6733
# Fold 18 Epoch 100: TotalLoss=0.472679 | Sup=0.472552 | Recon=0.002544 | TrainAcc=0.7525
# Fold 18 Epoch 200: TotalLoss=0.449409 | Sup=0.449344 | Recon=0.001292 | TrainAcc=0.7921
# Fold 18 Epoch 300: TotalLoss=0.416209 | Sup=0.416163 | Recon=0.000927 | TrainAcc=0.7921
# Fold 18 Epoch 400: TotalLoss=0.406667 | Sup=0.406628 | Recon=0.000781 | TrainAcc=0.8119
# Fold 18 Epoch 500: TotalLoss=0.384113 | Sup=0.384076 | Recon=0.000739 | TrainAcc=0.8119
# Fold 18 Epoch 600: TotalLoss=0.360040 | Sup=0.360004 | Recon=0.000722 | TrainAcc=0.8317
# Fold 18 Epoch 700: TotalLoss=0.324081 | Sup=0.324045 | Recon=0.000719 | TrainAcc=0.8515
# Fold 18 Epoch 800: TotalLoss=0.310570 | Sup=0.310534 | Recon=0.000716 | TrainAcc=0.8218
# Fold 18 Epoch 900: TotalLoss=0.301516 | Sup=0.301480 | Recon=0.000726 | TrainAcc=0.8614
# Fold 18 Epoch 1000: TotalLoss=0.288308 | Sup=0.288272 | Recon=0.000717 | TrainAcc=0.8416
# Fold 18 Epoch 1100: TotalLoss=0.261423 | Sup=0.261387 | Recon=0.000721 | TrainAcc=0.8317
# Fold 18 Epoch 1200: TotalLoss=0.253799 | Sup=0.253764 | Recon=0.000716 | TrainAcc=0.8515
# Fold 18 Epoch 1300: TotalLoss=0.225300 | Sup=0.225264 | Recon=0.000721 | TrainAcc=0.8812
# Fold 18 Epoch 1400: TotalLoss=0.228629 | Sup=0.228593 | Recon=0.000718 | TrainAcc=0.8515
# Fold 18 Epoch 1500: TotalLoss=0.209344 | Sup=0.209308 | Recon=0.000718 | TrainAcc=0.8911
# Fold 18 Epoch 1600: TotalLoss=0.215353 | Sup=0.215317 | Recon=0.000727 | TrainAcc=0.8812
# Fold 18 Epoch 1700: TotalLoss=0.201700 | Sup=0.201664 | Recon=0.000723 | TrainAcc=0.8812
# Fold 18 Epoch 1800: TotalLoss=0.181317 | Sup=0.181281 | Recon=0.000726 | TrainAcc=0.8911
# Fold 18 Epoch 1900: TotalLoss=0.184505 | Sup=0.184469 | Recon=0.000728 | TrainAcc=0.8911
# Fold 18 Epoch 2000: TotalLoss=0.164596 | Sup=0.164559 | Recon=0.000728 | TrainAcc=0.9010
# Fold 18 → Acc=0.8182 | Prec=0.6500 | Rec=0.9286 | F1=0.7647 | AUC=0.9274 | CE Loss=0.4097
#
# === Fold 19 ===
# Train Control: 68, Train Patient: 33
# Fold 19 Epoch 1: TotalLoss=0.728467 | Sup=0.726743 | Recon=0.034494 | TrainAcc=0.3267
# Fold 19 Epoch 100: TotalLoss=0.469311 | Sup=0.469179 | Recon=0.002628 | TrainAcc=0.7228
# Fold 19 Epoch 200: TotalLoss=0.447787 | Sup=0.447720 | Recon=0.001347 | TrainAcc=0.7327
# Fold 19 Epoch 300: TotalLoss=0.414842 | Sup=0.414794 | Recon=0.000953 | TrainAcc=0.8119
# Fold 19 Epoch 400: TotalLoss=0.393347 | Sup=0.393307 | Recon=0.000809 | TrainAcc=0.7822
# Fold 19 Epoch 500: TotalLoss=0.355500 | Sup=0.355462 | Recon=0.000755 | TrainAcc=0.8218
# Fold 19 Epoch 600: TotalLoss=0.317419 | Sup=0.317382 | Recon=0.000732 | TrainAcc=0.8416
# Fold 19 Epoch 700: TotalLoss=0.316007 | Sup=0.315971 | Recon=0.000728 | TrainAcc=0.8812
# Fold 19 Epoch 800: TotalLoss=0.294962 | Sup=0.294926 | Recon=0.000727 | TrainAcc=0.8614
# Fold 19 Epoch 900: TotalLoss=0.278941 | Sup=0.278905 | Recon=0.000724 | TrainAcc=0.8119
# Fold 19 Epoch 1000: TotalLoss=0.272111 | Sup=0.272075 | Recon=0.000724 | TrainAcc=0.8614
# Fold 19 Epoch 1100: TotalLoss=0.264717 | Sup=0.264681 | Recon=0.000728 | TrainAcc=0.8119
# Fold 19 Epoch 1200: TotalLoss=0.227574 | Sup=0.227538 | Recon=0.000721 | TrainAcc=0.8416
# Fold 19 Epoch 1300: TotalLoss=0.231536 | Sup=0.231499 | Recon=0.000731 | TrainAcc=0.8812
# Fold 19 Epoch 1400: TotalLoss=0.215498 | Sup=0.215461 | Recon=0.000728 | TrainAcc=0.8812
# Fold 19 Epoch 1500: TotalLoss=0.210795 | Sup=0.210759 | Recon=0.000726 | TrainAcc=0.8713
# Fold 19 Epoch 1600: TotalLoss=0.195232 | Sup=0.195195 | Recon=0.000737 | TrainAcc=0.9109
# Fold 19 Epoch 1700: TotalLoss=0.189297 | Sup=0.189261 | Recon=0.000727 | TrainAcc=0.8911
# Fold 19 Epoch 1800: TotalLoss=0.168903 | Sup=0.168866 | Recon=0.000732 | TrainAcc=0.8713
# Fold 19 Epoch 1900: TotalLoss=0.171732 | Sup=0.171696 | Recon=0.000726 | TrainAcc=0.8614
# Fold 19 Epoch 2000: TotalLoss=0.153276 | Sup=0.153239 | Recon=0.000730 | TrainAcc=0.9010
# Fold 19 → Acc=0.8409 | Prec=0.8182 | Rec=0.6429 | F1=0.7200 | AUC=0.8548 | CE Loss=0.5239
#
# === Fold 20 ===
# Train Control: 68, Train Patient: 33
# Fold 20 Epoch 1: TotalLoss=0.668164 | Sup=0.666580 | Recon=0.031690 | TrainAcc=0.3267
# Fold 20 Epoch 100: TotalLoss=0.495177 | Sup=0.495061 | Recon=0.002324 | TrainAcc=0.7426
# Fold 20 Epoch 200: TotalLoss=0.469414 | Sup=0.469351 | Recon=0.001250 | TrainAcc=0.7624
# Fold 20 Epoch 300: TotalLoss=0.442443 | Sup=0.442399 | Recon=0.000888 | TrainAcc=0.7921
# Fold 20 Epoch 400: TotalLoss=0.409895 | Sup=0.409856 | Recon=0.000772 | TrainAcc=0.7822
# Fold 20 Epoch 500: TotalLoss=0.372623 | Sup=0.372587 | Recon=0.000731 | TrainAcc=0.7921
# Fold 20 Epoch 600: TotalLoss=0.360179 | Sup=0.360143 | Recon=0.000718 | TrainAcc=0.8218
# Fold 20 Epoch 700: TotalLoss=0.345305 | Sup=0.345270 | Recon=0.000704 | TrainAcc=0.8119
# Fold 20 Epoch 800: TotalLoss=0.312168 | Sup=0.312133 | Recon=0.000705 | TrainAcc=0.8119
# Fold 20 Epoch 900: TotalLoss=0.301707 | Sup=0.301672 | Recon=0.000709 | TrainAcc=0.8218
# Fold 20 Epoch 1000: TotalLoss=0.302232 | Sup=0.302196 | Recon=0.000708 | TrainAcc=0.8218
# Fold 20 Epoch 1100: TotalLoss=0.267347 | Sup=0.267311 | Recon=0.000711 | TrainAcc=0.8515
# Fold 20 Epoch 1200: TotalLoss=0.273439 | Sup=0.273403 | Recon=0.000714 | TrainAcc=0.8317
# Fold 20 Epoch 1300: TotalLoss=0.266757 | Sup=0.266721 | Recon=0.000718 | TrainAcc=0.8317
# Fold 20 Epoch 1400: TotalLoss=0.232302 | Sup=0.232267 | Recon=0.000710 | TrainAcc=0.7921
# Fold 20 Epoch 1500: TotalLoss=0.222079 | Sup=0.222043 | Recon=0.000718 | TrainAcc=0.8713
# Fold 20 Epoch 1600: TotalLoss=0.216542 | Sup=0.216506 | Recon=0.000717 | TrainAcc=0.8911
# Fold 20 Epoch 1700: TotalLoss=0.199130 | Sup=0.199094 | Recon=0.000727 | TrainAcc=0.8911
# Fold 20 Epoch 1800: TotalLoss=0.204899 | Sup=0.204863 | Recon=0.000721 | TrainAcc=0.9109
# Fold 20 Epoch 1900: TotalLoss=0.193837 | Sup=0.193801 | Recon=0.000726 | TrainAcc=0.8812
# Fold 20 Epoch 2000: TotalLoss=0.175168 | Sup=0.175131 | Recon=0.000729 | TrainAcc=0.8416
# Fold 20 → Acc=0.7500 | Prec=0.8000 | Rec=0.2857 | F1=0.4211 | AUC=0.8786 | CE Loss=0.5494
#
# === Average Results for λ = 0.05 ===
# Accuracy:  0.8330
# Precision: 0.7762
# Recall:    0.7321
# F1-score:  0.7231
# CE Loss:   0.4436
# AUC:       0.9044
#
#
# ====================== λ_recon = 0.09 ======================
#
# === Fold 1 ===
# Train Control: 68, Train Patient: 33
# Fold 1 Epoch 1: TotalLoss=0.715030 | Sup=0.712090 | Recon=0.032672 | TrainAcc=0.3762
# Fold 1 Epoch 100: TotalLoss=0.497390 | Sup=0.497193 | Recon=0.002192 | TrainAcc=0.7228
# Fold 1 Epoch 200: TotalLoss=0.463123 | Sup=0.463014 | Recon=0.001213 | TrainAcc=0.7426
# Fold 1 Epoch 300: TotalLoss=0.434995 | Sup=0.434918 | Recon=0.000859 | TrainAcc=0.8119
# Fold 1 Epoch 400: TotalLoss=0.408392 | Sup=0.408326 | Recon=0.000735 | TrainAcc=0.7921
# Fold 1 Epoch 500: TotalLoss=0.386716 | Sup=0.386655 | Recon=0.000675 | TrainAcc=0.8020
# Fold 1 Epoch 600: TotalLoss=0.353026 | Sup=0.352967 | Recon=0.000657 | TrainAcc=0.7921
# Fold 1 Epoch 700: TotalLoss=0.338160 | Sup=0.338102 | Recon=0.000646 | TrainAcc=0.8218
# Fold 1 Epoch 800: TotalLoss=0.332985 | Sup=0.332926 | Recon=0.000652 | TrainAcc=0.8119
# Fold 1 Epoch 900: TotalLoss=0.309869 | Sup=0.309811 | Recon=0.000641 | TrainAcc=0.8317
# Fold 1 Epoch 1000: TotalLoss=0.290835 | Sup=0.290777 | Recon=0.000650 | TrainAcc=0.8218
# Fold 1 Epoch 1100: TotalLoss=0.294472 | Sup=0.294414 | Recon=0.000653 | TrainAcc=0.8317
# Fold 1 Epoch 1200: TotalLoss=0.280562 | Sup=0.280503 | Recon=0.000652 | TrainAcc=0.8614
# Fold 1 Epoch 1300: TotalLoss=0.271861 | Sup=0.271802 | Recon=0.000652 | TrainAcc=0.8317
# Fold 1 Epoch 1400: TotalLoss=0.246627 | Sup=0.246569 | Recon=0.000646 | TrainAcc=0.8812
# Fold 1 Epoch 1500: TotalLoss=0.230092 | Sup=0.230033 | Recon=0.000656 | TrainAcc=0.8416
# Fold 1 Epoch 1600: TotalLoss=0.229576 | Sup=0.229517 | Recon=0.000654 | TrainAcc=0.8020
# Fold 1 Epoch 1700: TotalLoss=0.213531 | Sup=0.213472 | Recon=0.000657 | TrainAcc=0.8614
# Fold 1 Epoch 1800: TotalLoss=0.213798 | Sup=0.213739 | Recon=0.000655 | TrainAcc=0.8812
# Fold 1 Epoch 1900: TotalLoss=0.198836 | Sup=0.198777 | Recon=0.000650 | TrainAcc=0.8218
# Fold 1 Epoch 2000: TotalLoss=0.193308 | Sup=0.193249 | Recon=0.000658 | TrainAcc=0.8614
# Fold 1 → Acc=0.7500 | Prec=0.7143 | Rec=0.3571 | F1=0.4762 | AUC=0.8738 | CE Loss=0.6428
#
# === Fold 2 ===
# Train Control: 68, Train Patient: 33
# Fold 2 Epoch 1: TotalLoss=0.826490 | Sup=0.823717 | Recon=0.030814 | TrainAcc=0.3267
# Fold 2 Epoch 100: TotalLoss=0.472386 | Sup=0.472183 | Recon=0.002252 | TrainAcc=0.7426
# Fold 2 Epoch 200: TotalLoss=0.440787 | Sup=0.440677 | Recon=0.001224 | TrainAcc=0.7624
# Fold 2 Epoch 300: TotalLoss=0.428842 | Sup=0.428764 | Recon=0.000866 | TrainAcc=0.8020
# Fold 2 Epoch 400: TotalLoss=0.394238 | Sup=0.394172 | Recon=0.000727 | TrainAcc=0.8020
# Fold 2 Epoch 500: TotalLoss=0.374985 | Sup=0.374924 | Recon=0.000677 | TrainAcc=0.8020
# Fold 2 Epoch 600: TotalLoss=0.361921 | Sup=0.361862 | Recon=0.000661 | TrainAcc=0.8020
# Fold 2 Epoch 700: TotalLoss=0.341624 | Sup=0.341565 | Recon=0.000651 | TrainAcc=0.8218
# Fold 2 Epoch 800: TotalLoss=0.340795 | Sup=0.340736 | Recon=0.000650 | TrainAcc=0.8119
# Fold 2 Epoch 900: TotalLoss=0.313583 | Sup=0.313524 | Recon=0.000655 | TrainAcc=0.8317
# Fold 2 Epoch 1000: TotalLoss=0.305292 | Sup=0.305234 | Recon=0.000646 | TrainAcc=0.8119
# Fold 2 Epoch 1100: TotalLoss=0.301169 | Sup=0.301111 | Recon=0.000643 | TrainAcc=0.8218
# Fold 2 Epoch 1200: TotalLoss=0.278017 | Sup=0.277958 | Recon=0.000652 | TrainAcc=0.8614
# Fold 2 Epoch 1300: TotalLoss=0.277328 | Sup=0.277270 | Recon=0.000652 | TrainAcc=0.8218
# Fold 2 Epoch 1400: TotalLoss=0.269009 | Sup=0.268950 | Recon=0.000652 | TrainAcc=0.9109
# Fold 2 Epoch 1500: TotalLoss=0.257801 | Sup=0.257742 | Recon=0.000653 | TrainAcc=0.8911
# Fold 2 Epoch 1600: TotalLoss=0.248184 | Sup=0.248125 | Recon=0.000648 | TrainAcc=0.8317
# Fold 2 Epoch 1700: TotalLoss=0.234355 | Sup=0.234296 | Recon=0.000652 | TrainAcc=0.8317
# Fold 2 Epoch 1800: TotalLoss=0.228182 | Sup=0.228124 | Recon=0.000651 | TrainAcc=0.8218
# Fold 2 Epoch 1900: TotalLoss=0.227664 | Sup=0.227605 | Recon=0.000651 | TrainAcc=0.8218
# Fold 2 Epoch 2000: TotalLoss=0.207535 | Sup=0.207476 | Recon=0.000651 | TrainAcc=0.8218
# Fold 2 → Acc=0.7500 | Prec=0.5714 | Rec=0.8571 | F1=0.6857 | AUC=0.9036 | CE Loss=0.4426
#
# === Fold 3 ===
# Train Control: 68, Train Patient: 33
# Fold 3 Epoch 1: TotalLoss=0.690786 | Sup=0.687982 | Recon=0.031156 | TrainAcc=0.3267
# Fold 3 Epoch 100: TotalLoss=0.485598 | Sup=0.485374 | Recon=0.002496 | TrainAcc=0.7228
# Fold 3 Epoch 200: TotalLoss=0.447050 | Sup=0.446937 | Recon=0.001254 | TrainAcc=0.7723
# Fold 3 Epoch 300: TotalLoss=0.408955 | Sup=0.408875 | Recon=0.000882 | TrainAcc=0.7525
# Fold 3 Epoch 400: TotalLoss=0.393260 | Sup=0.393194 | Recon=0.000732 | TrainAcc=0.7327
# Fold 3 Epoch 500: TotalLoss=0.360072 | Sup=0.360011 | Recon=0.000681 | TrainAcc=0.7426
# Fold 3 Epoch 600: TotalLoss=0.338804 | Sup=0.338744 | Recon=0.000662 | TrainAcc=0.8416
# Fold 3 Epoch 700: TotalLoss=0.315222 | Sup=0.315163 | Recon=0.000658 | TrainAcc=0.8416
# Fold 3 Epoch 800: TotalLoss=0.289284 | Sup=0.289227 | Recon=0.000644 | TrainAcc=0.8317
# Fold 3 Epoch 900: TotalLoss=0.272198 | Sup=0.272139 | Recon=0.000654 | TrainAcc=0.8614
# Fold 3 Epoch 1000: TotalLoss=0.267854 | Sup=0.267796 | Recon=0.000650 | TrainAcc=0.8416
# Fold 3 Epoch 1100: TotalLoss=0.247516 | Sup=0.247458 | Recon=0.000650 | TrainAcc=0.8515
# Fold 3 Epoch 1200: TotalLoss=0.241890 | Sup=0.241831 | Recon=0.000654 | TrainAcc=0.8416
# Fold 3 Epoch 1300: TotalLoss=0.229289 | Sup=0.229229 | Recon=0.000659 | TrainAcc=0.9010
# Fold 3 Epoch 1400: TotalLoss=0.200361 | Sup=0.200303 | Recon=0.000653 | TrainAcc=0.8515
# Fold 3 Epoch 1500: TotalLoss=0.187501 | Sup=0.187443 | Recon=0.000649 | TrainAcc=0.8911
# Fold 3 Epoch 1600: TotalLoss=0.184792 | Sup=0.184733 | Recon=0.000656 | TrainAcc=0.8713
# Fold 3 Epoch 1700: TotalLoss=0.164436 | Sup=0.164377 | Recon=0.000659 | TrainAcc=0.8713
# Fold 3 Epoch 1800: TotalLoss=0.156901 | Sup=0.156842 | Recon=0.000656 | TrainAcc=0.9109
# Fold 3 Epoch 1900: TotalLoss=0.151508 | Sup=0.151449 | Recon=0.000657 | TrainAcc=0.7921
# Fold 3 Epoch 2000: TotalLoss=0.130348 | Sup=0.130289 | Recon=0.000655 | TrainAcc=0.9208
# Fold 3 → Acc=0.8636 | Prec=0.8333 | Rec=0.7143 | F1=0.7692 | AUC=0.9548 | CE Loss=0.2638
#
# === Fold 4 ===
# Train Control: 68, Train Patient: 33
# Fold 4 Epoch 1: TotalLoss=0.729438 | Sup=0.726941 | Recon=0.027743 | TrainAcc=0.6733
# Fold 4 Epoch 100: TotalLoss=0.524012 | Sup=0.523815 | Recon=0.002189 | TrainAcc=0.7228
# Fold 4 Epoch 200: TotalLoss=0.482666 | Sup=0.482559 | Recon=0.001192 | TrainAcc=0.7525
# Fold 4 Epoch 300: TotalLoss=0.468624 | Sup=0.468546 | Recon=0.000868 | TrainAcc=0.7723
# Fold 4 Epoch 400: TotalLoss=0.435860 | Sup=0.435795 | Recon=0.000730 | TrainAcc=0.7921
# Fold 4 Epoch 500: TotalLoss=0.414036 | Sup=0.413975 | Recon=0.000681 | TrainAcc=0.8119
# Fold 4 Epoch 600: TotalLoss=0.388422 | Sup=0.388362 | Recon=0.000664 | TrainAcc=0.8218
# Fold 4 Epoch 700: TotalLoss=0.364883 | Sup=0.364824 | Recon=0.000654 | TrainAcc=0.7822
# Fold 4 Epoch 800: TotalLoss=0.334198 | Sup=0.334139 | Recon=0.000654 | TrainAcc=0.7921
# Fold 4 Epoch 900: TotalLoss=0.338941 | Sup=0.338883 | Recon=0.000652 | TrainAcc=0.8020
# Fold 4 Epoch 1000: TotalLoss=0.321090 | Sup=0.321031 | Recon=0.000653 | TrainAcc=0.8119
# Fold 4 Epoch 1100: TotalLoss=0.303082 | Sup=0.303024 | Recon=0.000654 | TrainAcc=0.8416
# Fold 4 Epoch 1200: TotalLoss=0.277166 | Sup=0.277107 | Recon=0.000649 | TrainAcc=0.7921
# Fold 4 Epoch 1300: TotalLoss=0.268031 | Sup=0.267973 | Recon=0.000652 | TrainAcc=0.8317
# Fold 4 Epoch 1400: TotalLoss=0.260783 | Sup=0.260725 | Recon=0.000647 | TrainAcc=0.8317
# Fold 4 Epoch 1500: TotalLoss=0.239224 | Sup=0.239165 | Recon=0.000654 | TrainAcc=0.8218
# Fold 4 Epoch 1600: TotalLoss=0.220554 | Sup=0.220495 | Recon=0.000651 | TrainAcc=0.8614
# Fold 4 Epoch 1700: TotalLoss=0.202217 | Sup=0.202158 | Recon=0.000654 | TrainAcc=0.8614
# Fold 4 Epoch 1800: TotalLoss=0.216802 | Sup=0.216744 | Recon=0.000650 | TrainAcc=0.8614
# Fold 4 Epoch 1900: TotalLoss=0.200177 | Sup=0.200118 | Recon=0.000656 | TrainAcc=0.8515
# Fold 4 Epoch 2000: TotalLoss=0.180183 | Sup=0.180125 | Recon=0.000651 | TrainAcc=0.8812
# Fold 4 → Acc=0.7500 | Prec=0.6667 | Rec=0.4286 | F1=0.5217 | AUC=0.8595 | CE Loss=0.4163
#
# === Fold 5 ===
# Train Control: 68, Train Patient: 33
# Fold 5 Epoch 1: TotalLoss=0.687400 | Sup=0.684387 | Recon=0.033475 | TrainAcc=0.6733
# Fold 5 Epoch 100: TotalLoss=0.498409 | Sup=0.498190 | Recon=0.002440 | TrainAcc=0.7129
# Fold 5 Epoch 200: TotalLoss=0.473794 | Sup=0.473683 | Recon=0.001233 | TrainAcc=0.7129
# Fold 5 Epoch 300: TotalLoss=0.447516 | Sup=0.447437 | Recon=0.000874 | TrainAcc=0.8317
# Fold 5 Epoch 400: TotalLoss=0.404347 | Sup=0.404281 | Recon=0.000730 | TrainAcc=0.8020
# Fold 5 Epoch 500: TotalLoss=0.384268 | Sup=0.384206 | Recon=0.000683 | TrainAcc=0.8020
# Fold 5 Epoch 600: TotalLoss=0.349847 | Sup=0.349788 | Recon=0.000654 | TrainAcc=0.8119
# Fold 5 Epoch 700: TotalLoss=0.336056 | Sup=0.335998 | Recon=0.000649 | TrainAcc=0.7822
# Fold 5 Epoch 800: TotalLoss=0.320819 | Sup=0.320761 | Recon=0.000641 | TrainAcc=0.8119
# Fold 5 Epoch 900: TotalLoss=0.298650 | Sup=0.298592 | Recon=0.000647 | TrainAcc=0.8614
# Fold 5 Epoch 1000: TotalLoss=0.293784 | Sup=0.293726 | Recon=0.000645 | TrainAcc=0.8317
# Fold 5 Epoch 1100: TotalLoss=0.263151 | Sup=0.263094 | Recon=0.000641 | TrainAcc=0.8317
# Fold 5 Epoch 1200: TotalLoss=0.266631 | Sup=0.266573 | Recon=0.000650 | TrainAcc=0.8812
# Fold 5 Epoch 1300: TotalLoss=0.226627 | Sup=0.226569 | Recon=0.000644 | TrainAcc=0.8713
# Fold 5 Epoch 1400: TotalLoss=0.222775 | Sup=0.222716 | Recon=0.000649 | TrainAcc=0.8713
# Fold 5 Epoch 1500: TotalLoss=0.207876 | Sup=0.207818 | Recon=0.000644 | TrainAcc=0.8713
# Fold 5 Epoch 1600: TotalLoss=0.198999 | Sup=0.198940 | Recon=0.000656 | TrainAcc=0.8119
# Fold 5 Epoch 1700: TotalLoss=0.183232 | Sup=0.183173 | Recon=0.000656 | TrainAcc=0.8911
# Fold 5 Epoch 1800: TotalLoss=0.168201 | Sup=0.168143 | Recon=0.000649 | TrainAcc=0.9010
# Fold 5 Epoch 1900: TotalLoss=0.159743 | Sup=0.159684 | Recon=0.000658 | TrainAcc=0.8812
# Fold 5 Epoch 2000: TotalLoss=0.140444 | Sup=0.140385 | Recon=0.000654 | TrainAcc=0.8119
# Fold 5 → Acc=0.7955 | Prec=0.8571 | Rec=0.4286 | F1=0.5714 | AUC=0.8619 | CE Loss=0.6964
#
# === Fold 6 ===
# Train Control: 68, Train Patient: 33
# Fold 6 Epoch 1: TotalLoss=0.665118 | Sup=0.662115 | Recon=0.033365 | TrainAcc=0.6733
# Fold 6 Epoch 100: TotalLoss=0.469622 | Sup=0.469417 | Recon=0.002282 | TrainAcc=0.7822
# Fold 6 Epoch 200: TotalLoss=0.452218 | Sup=0.452108 | Recon=0.001224 | TrainAcc=0.7525
# Fold 6 Epoch 300: TotalLoss=0.409921 | Sup=0.409842 | Recon=0.000874 | TrainAcc=0.7921
# Fold 6 Epoch 400: TotalLoss=0.394113 | Sup=0.394046 | Recon=0.000740 | TrainAcc=0.8218
# Fold 6 Epoch 500: TotalLoss=0.360977 | Sup=0.360915 | Recon=0.000682 | TrainAcc=0.7921
# Fold 6 Epoch 600: TotalLoss=0.356184 | Sup=0.356125 | Recon=0.000660 | TrainAcc=0.7822
# Fold 6 Epoch 700: TotalLoss=0.325337 | Sup=0.325278 | Recon=0.000645 | TrainAcc=0.8416
# Fold 6 Epoch 800: TotalLoss=0.319757 | Sup=0.319699 | Recon=0.000647 | TrainAcc=0.8416
# Fold 6 Epoch 900: TotalLoss=0.288491 | Sup=0.288433 | Recon=0.000643 | TrainAcc=0.8416
# Fold 6 Epoch 1000: TotalLoss=0.258716 | Sup=0.258657 | Recon=0.000652 | TrainAcc=0.8317
# Fold 6 Epoch 1100: TotalLoss=0.257803 | Sup=0.257745 | Recon=0.000646 | TrainAcc=0.8218
# Fold 6 Epoch 1200: TotalLoss=0.241358 | Sup=0.241299 | Recon=0.000655 | TrainAcc=0.8416
# Fold 6 Epoch 1300: TotalLoss=0.224268 | Sup=0.224210 | Recon=0.000651 | TrainAcc=0.8020
# Fold 6 Epoch 1400: TotalLoss=0.218231 | Sup=0.218173 | Recon=0.000647 | TrainAcc=0.8317
# Fold 6 Epoch 1500: TotalLoss=0.200840 | Sup=0.200781 | Recon=0.000655 | TrainAcc=0.8515
# Fold 6 Epoch 1600: TotalLoss=0.184369 | Sup=0.184310 | Recon=0.000657 | TrainAcc=0.8515
# Fold 6 Epoch 1700: TotalLoss=0.182133 | Sup=0.182074 | Recon=0.000655 | TrainAcc=0.8812
# Fold 6 Epoch 1800: TotalLoss=0.171660 | Sup=0.171601 | Recon=0.000655 | TrainAcc=0.9109
# Fold 6 Epoch 1900: TotalLoss=0.164540 | Sup=0.164480 | Recon=0.000659 | TrainAcc=0.8812
# Fold 6 Epoch 2000: TotalLoss=0.161203 | Sup=0.161144 | Recon=0.000657 | TrainAcc=0.9109
# Fold 6 → Acc=0.8409 | Prec=1.0000 | Rec=0.5000 | F1=0.6667 | AUC=0.8857 | CE Loss=0.4417
#
# === Fold 7 ===
# Train Control: 68, Train Patient: 33
# Fold 7 Epoch 1: TotalLoss=0.618151 | Sup=0.615375 | Recon=0.030844 | TrainAcc=0.6733
# Fold 7 Epoch 100: TotalLoss=0.472175 | Sup=0.471975 | Recon=0.002217 | TrainAcc=0.7228
# Fold 7 Epoch 200: TotalLoss=0.436357 | Sup=0.436247 | Recon=0.001223 | TrainAcc=0.7624
# Fold 7 Epoch 300: TotalLoss=0.411943 | Sup=0.411866 | Recon=0.000854 | TrainAcc=0.7822
# Fold 7 Epoch 400: TotalLoss=0.377480 | Sup=0.377415 | Recon=0.000724 | TrainAcc=0.7723
# Fold 7 Epoch 500: TotalLoss=0.353123 | Sup=0.353062 | Recon=0.000681 | TrainAcc=0.8218
# Fold 7 Epoch 600: TotalLoss=0.316103 | Sup=0.316043 | Recon=0.000670 | TrainAcc=0.8218
# Fold 7 Epoch 700: TotalLoss=0.303690 | Sup=0.303631 | Recon=0.000656 | TrainAcc=0.8218
# Fold 7 Epoch 800: TotalLoss=0.284663 | Sup=0.284604 | Recon=0.000660 | TrainAcc=0.8614
# Fold 7 Epoch 900: TotalLoss=0.264663 | Sup=0.264604 | Recon=0.000661 | TrainAcc=0.8713
# Fold 7 Epoch 1000: TotalLoss=0.240114 | Sup=0.240055 | Recon=0.000657 | TrainAcc=0.8713
# Fold 7 Epoch 1100: TotalLoss=0.220489 | Sup=0.220430 | Recon=0.000655 | TrainAcc=0.9109
# Fold 7 Epoch 1200: TotalLoss=0.212051 | Sup=0.211992 | Recon=0.000658 | TrainAcc=0.8515
# Fold 7 Epoch 1300: TotalLoss=0.210827 | Sup=0.210768 | Recon=0.000664 | TrainAcc=0.9109
# Fold 7 Epoch 1400: TotalLoss=0.189888 | Sup=0.189829 | Recon=0.000656 | TrainAcc=0.9307
# Fold 7 Epoch 1500: TotalLoss=0.180270 | Sup=0.180211 | Recon=0.000659 | TrainAcc=0.9109
# Fold 7 Epoch 1600: TotalLoss=0.168061 | Sup=0.168001 | Recon=0.000667 | TrainAcc=0.9307
# Fold 7 Epoch 1700: TotalLoss=0.160772 | Sup=0.160712 | Recon=0.000666 | TrainAcc=0.9208
# Fold 7 Epoch 1800: TotalLoss=0.144788 | Sup=0.144728 | Recon=0.000665 | TrainAcc=0.8020
# Fold 7 Epoch 1900: TotalLoss=0.137853 | Sup=0.137793 | Recon=0.000666 | TrainAcc=0.9307
# Fold 7 Epoch 2000: TotalLoss=0.127976 | Sup=0.127917 | Recon=0.000659 | TrainAcc=0.8812
# Fold 7 → Acc=0.8409 | Prec=0.7059 | Rec=0.8571 | F1=0.7742 | AUC=0.8143 | CE Loss=0.9660
#
# === Fold 8 ===
# Train Control: 68, Train Patient: 33
# Fold 8 Epoch 1: TotalLoss=0.667961 | Sup=0.665064 | Recon=0.032181 | TrainAcc=0.3267
# Fold 8 Epoch 100: TotalLoss=0.486277 | Sup=0.486070 | Recon=0.002299 | TrainAcc=0.7030
# Fold 8 Epoch 200: TotalLoss=0.472289 | Sup=0.472172 | Recon=0.001302 | TrainAcc=0.7624
# Fold 8 Epoch 300: TotalLoss=0.457545 | Sup=0.457464 | Recon=0.000894 | TrainAcc=0.7723
# Fold 8 Epoch 400: TotalLoss=0.424390 | Sup=0.424324 | Recon=0.000739 | TrainAcc=0.7624
# Fold 8 Epoch 500: TotalLoss=0.391257 | Sup=0.391196 | Recon=0.000686 | TrainAcc=0.7921
# Fold 8 Epoch 600: TotalLoss=0.371434 | Sup=0.371374 | Recon=0.000661 | TrainAcc=0.7723
# Fold 8 Epoch 700: TotalLoss=0.352484 | Sup=0.352425 | Recon=0.000662 | TrainAcc=0.7921
# Fold 8 Epoch 800: TotalLoss=0.339724 | Sup=0.339665 | Recon=0.000654 | TrainAcc=0.8119
# Fold 8 Epoch 900: TotalLoss=0.309498 | Sup=0.309440 | Recon=0.000652 | TrainAcc=0.7921
# Fold 8 Epoch 1000: TotalLoss=0.307199 | Sup=0.307141 | Recon=0.000645 | TrainAcc=0.7228
# Fold 8 Epoch 1100: TotalLoss=0.285261 | Sup=0.285202 | Recon=0.000650 | TrainAcc=0.8416
# Fold 8 Epoch 1200: TotalLoss=0.254944 | Sup=0.254885 | Recon=0.000654 | TrainAcc=0.7921
# Fold 8 Epoch 1300: TotalLoss=0.248230 | Sup=0.248172 | Recon=0.000649 | TrainAcc=0.8218
# Fold 8 Epoch 1400: TotalLoss=0.237905 | Sup=0.237846 | Recon=0.000654 | TrainAcc=0.7723
# Fold 8 Epoch 1500: TotalLoss=0.207842 | Sup=0.207784 | Recon=0.000649 | TrainAcc=0.8515
# Fold 8 Epoch 1600: TotalLoss=0.190140 | Sup=0.190082 | Recon=0.000651 | TrainAcc=0.8119
# Fold 8 Epoch 1700: TotalLoss=0.189259 | Sup=0.189200 | Recon=0.000651 | TrainAcc=0.9010
# Fold 8 Epoch 1800: TotalLoss=0.178216 | Sup=0.178156 | Recon=0.000659 | TrainAcc=0.8119
# Fold 8 Epoch 1900: TotalLoss=0.180644 | Sup=0.180585 | Recon=0.000655 | TrainAcc=0.8218
# Fold 8 Epoch 2000: TotalLoss=0.156795 | Sup=0.156736 | Recon=0.000656 | TrainAcc=0.7822
# Fold 8 → Acc=0.8182 | Prec=0.6364 | Rec=1.0000 | F1=0.7778 | AUC=0.9548 | CE Loss=0.4068
#
# === Fold 9 ===
# Train Control: 68, Train Patient: 33
# Fold 9 Epoch 1: TotalLoss=0.732960 | Sup=0.730477 | Recon=0.027595 | TrainAcc=0.6733
# Fold 9 Epoch 100: TotalLoss=0.473923 | Sup=0.473727 | Recon=0.002172 | TrainAcc=0.7327
# Fold 9 Epoch 200: TotalLoss=0.453522 | Sup=0.453414 | Recon=0.001207 | TrainAcc=0.7624
# Fold 9 Epoch 300: TotalLoss=0.435887 | Sup=0.435810 | Recon=0.000857 | TrainAcc=0.7624
# Fold 9 Epoch 400: TotalLoss=0.417332 | Sup=0.417266 | Recon=0.000733 | TrainAcc=0.7624
# Fold 9 Epoch 500: TotalLoss=0.389778 | Sup=0.389717 | Recon=0.000679 | TrainAcc=0.7921
# Fold 9 Epoch 600: TotalLoss=0.373721 | Sup=0.373662 | Recon=0.000657 | TrainAcc=0.8119
# Fold 9 Epoch 700: TotalLoss=0.365292 | Sup=0.365234 | Recon=0.000652 | TrainAcc=0.8119
# Fold 9 Epoch 800: TotalLoss=0.345053 | Sup=0.344994 | Recon=0.000655 | TrainAcc=0.8119
# Fold 9 Epoch 900: TotalLoss=0.321521 | Sup=0.321462 | Recon=0.000655 | TrainAcc=0.8416
# Fold 9 Epoch 1000: TotalLoss=0.312220 | Sup=0.312160 | Recon=0.000657 | TrainAcc=0.8218
# Fold 9 Epoch 1100: TotalLoss=0.306386 | Sup=0.306327 | Recon=0.000656 | TrainAcc=0.7921
# Fold 9 Epoch 1200: TotalLoss=0.274340 | Sup=0.274281 | Recon=0.000655 | TrainAcc=0.8416
# Fold 9 Epoch 1300: TotalLoss=0.264129 | Sup=0.264071 | Recon=0.000650 | TrainAcc=0.8218
# Fold 9 Epoch 1400: TotalLoss=0.261130 | Sup=0.261071 | Recon=0.000659 | TrainAcc=0.8317
# Fold 9 Epoch 1500: TotalLoss=0.236867 | Sup=0.236808 | Recon=0.000654 | TrainAcc=0.7822
# Fold 9 Epoch 1600: TotalLoss=0.227244 | Sup=0.227184 | Recon=0.000662 | TrainAcc=0.8317
# Fold 9 Epoch 1700: TotalLoss=0.224361 | Sup=0.224301 | Recon=0.000665 | TrainAcc=0.8614
# Fold 9 Epoch 1800: TotalLoss=0.206309 | Sup=0.206249 | Recon=0.000669 | TrainAcc=0.8515
# Fold 9 Epoch 1900: TotalLoss=0.194449 | Sup=0.194389 | Recon=0.000665 | TrainAcc=0.8020
# Fold 9 Epoch 2000: TotalLoss=0.191326 | Sup=0.191266 | Recon=0.000670 | TrainAcc=0.8119
# Fold 9 → Acc=0.7273 | Prec=0.5417 | Rec=0.9286 | F1=0.6842 | AUC=0.8464 | CE Loss=0.5833
#
# ...
# Fold 13 Epoch 1700: TotalLoss=0.164047 | Sup=0.160651 | Recon=0.000424 | TrainAcc=0.9307
# Fold 13 Epoch 1800: TotalLoss=0.152331 | Sup=0.148951 | Recon=0.000423 | TrainAcc=0.9307
# Fold 13 Epoch 1900: TotalLoss=0.146808 | Sup=0.143546 | Recon=0.000408 | TrainAcc=0.8614
# Fold 13 Epoch 2000: TotalLoss=0.126369 | Sup=0.123232 | Recon=0.000392 | TrainAcc=0.9208
# Fold 13 → Acc=0.9091 | Prec=0.8571 | Rec=0.8571 | F1=0.8571 | AUC=0.9667 | CE Loss=0.2203
#
# === Fold 14 ===
# Train Control: 68, Train Patient: 33
# Fold 14 Epoch 1: TotalLoss=1.060987 | Sup=0.819373 | Recon=0.030202 | TrainAcc=0.3267
# Fold 14 Epoch 100: TotalLoss=0.509128 | Sup=0.490920 | Recon=0.002276 | TrainAcc=0.7327
# Fold 14 Epoch 200: TotalLoss=0.492043 | Sup=0.480899 | Recon=0.001393 | TrainAcc=0.7426
# Fold 14 Epoch 300: TotalLoss=0.463903 | Sup=0.455711 | Recon=0.001024 | TrainAcc=0.7624
# Fold 14 Epoch 400: TotalLoss=0.447293 | Sup=0.440431 | Recon=0.000858 | TrainAcc=0.7822
# Fold 14 Epoch 500: TotalLoss=0.418019 | Sup=0.412106 | Recon=0.000739 | TrainAcc=0.8020
# Fold 14 Epoch 600: TotalLoss=0.407032 | Sup=0.401670 | Recon=0.000670 | TrainAcc=0.8020
# Fold 14 Epoch 700: TotalLoss=0.372956 | Sup=0.367815 | Recon=0.000643 | TrainAcc=0.7921
# Fold 14 Epoch 800: TotalLoss=0.354546 | Sup=0.349692 | Recon=0.000607 | TrainAcc=0.8119
# Fold 14 Epoch 900: TotalLoss=0.340260 | Sup=0.335697 | Recon=0.000570 | TrainAcc=0.8119
# Fold 14 Epoch 1000: TotalLoss=0.328142 | Sup=0.323670 | Recon=0.000559 | TrainAcc=0.8317
# Fold 14 Epoch 1100: TotalLoss=0.312311 | Sup=0.308078 | Recon=0.000529 | TrainAcc=0.8020
# Fold 14 Epoch 1200: TotalLoss=0.289559 | Sup=0.285451 | Recon=0.000514 | TrainAcc=0.8515
# Fold 14 Epoch 1300: TotalLoss=0.273056 | Sup=0.269106 | Recon=0.000494 | TrainAcc=0.8515
# Fold 14 Epoch 1400: TotalLoss=0.261935 | Sup=0.258094 | Recon=0.000480 | TrainAcc=0.8614
# Fold 14 Epoch 1500: TotalLoss=0.250945 | Sup=0.247188 | Recon=0.000470 | TrainAcc=0.8614
# Fold 14 Epoch 1600: TotalLoss=0.235952 | Sup=0.232286 | Recon=0.000458 | TrainAcc=0.8614
# Fold 14 Epoch 1700: TotalLoss=0.217111 | Sup=0.213642 | Recon=0.000434 | TrainAcc=0.8713
# Fold 14 Epoch 1800: TotalLoss=0.208032 | Sup=0.204619 | Recon=0.000427 | TrainAcc=0.8812
# Fold 14 Epoch 1900: TotalLoss=0.199581 | Sup=0.196279 | Recon=0.000413 | TrainAcc=0.8614
# Fold 14 Epoch 2000: TotalLoss=0.177894 | Sup=0.174676 | Recon=0.000402 | TrainAcc=0.8317
# Fold 14 → Acc=0.8409 | Prec=1.0000 | Rec=0.5000 | F1=0.6667 | AUC=0.9190 | CE Loss=0.4042
#
# === Fold 15 ===
# Train Control: 68, Train Patient: 33
# Fold 15 Epoch 1: TotalLoss=0.876056 | Sup=0.611096 | Recon=0.033120 | TrainAcc=0.6733
# Fold 15 Epoch 100: TotalLoss=0.488222 | Sup=0.469949 | Recon=0.002284 | TrainAcc=0.7525
# Fold 15 Epoch 200: TotalLoss=0.455504 | Sup=0.444323 | Recon=0.001398 | TrainAcc=0.7921
# Fold 15 Epoch 300: TotalLoss=0.429977 | Sup=0.421567 | Recon=0.001051 | TrainAcc=0.8020
# Fold 15 Epoch 400: TotalLoss=0.400701 | Sup=0.393772 | Recon=0.000866 | TrainAcc=0.8218
# Fold 15 Epoch 500: TotalLoss=0.373171 | Sup=0.367203 | Recon=0.000746 | TrainAcc=0.8317
# Fold 15 Epoch 600: TotalLoss=0.337386 | Sup=0.331888 | Recon=0.000687 | TrainAcc=0.8119
# Fold 15 Epoch 700: TotalLoss=0.319894 | Sup=0.314654 | Recon=0.000655 | TrainAcc=0.8317
# Fold 15 Epoch 800: TotalLoss=0.307660 | Sup=0.302761 | Recon=0.000612 | TrainAcc=0.8416
# Fold 15 Epoch 900: TotalLoss=0.293416 | Sup=0.288757 | Recon=0.000582 | TrainAcc=0.8713
# Fold 15 Epoch 1000: TotalLoss=0.266420 | Sup=0.261950 | Recon=0.000559 | TrainAcc=0.8614
# Fold 15 Epoch 1100: TotalLoss=0.245488 | Sup=0.241182 | Recon=0.000538 | TrainAcc=0.8416
# Fold 15 Epoch 1200: TotalLoss=0.224463 | Sup=0.220291 | Recon=0.000521 | TrainAcc=0.8812
# Fold 15 Epoch 1300: TotalLoss=0.223820 | Sup=0.219756 | Recon=0.000508 | TrainAcc=0.8812
# Fold 15 Epoch 1400: TotalLoss=0.199391 | Sup=0.195520 | Recon=0.000484 | TrainAcc=0.8713
# Fold 15 Epoch 1500: TotalLoss=0.182628 | Sup=0.178784 | Recon=0.000480 | TrainAcc=0.9406
# Fold 15 Epoch 1600: TotalLoss=0.171882 | Sup=0.168174 | Recon=0.000463 | TrainAcc=0.8515
# Fold 15 Epoch 1700: TotalLoss=0.158671 | Sup=0.155066 | Recon=0.000451 | TrainAcc=0.9505
# Fold 15 Epoch 1800: TotalLoss=0.149684 | Sup=0.146248 | Recon=0.000430 | TrainAcc=0.9406
# Fold 15 Epoch 1900: TotalLoss=0.127160 | Sup=0.123823 | Recon=0.000417 | TrainAcc=0.9406
# Fold 15 Epoch 2000: TotalLoss=0.132233 | Sup=0.129023 | Recon=0.000401 | TrainAcc=0.8713
# Fold 15 → Acc=0.9091 | Prec=0.9167 | Rec=0.7857 | F1=0.8462 | AUC=0.9524 | CE Loss=0.2776
#
# === Fold 16 ===
# Train Control: 68, Train Patient: 33
# Fold 16 Epoch 1: TotalLoss=0.790479 | Sup=0.574010 | Recon=0.027059 | TrainAcc=0.6733
# Fold 16 Epoch 100: TotalLoss=0.485503 | Sup=0.468616 | Recon=0.002111 | TrainAcc=0.7426
# Fold 16 Epoch 200: TotalLoss=0.441287 | Sup=0.430770 | Recon=0.001315 | TrainAcc=0.7723
# Fold 16 Epoch 300: TotalLoss=0.401836 | Sup=0.393704 | Recon=0.001016 | TrainAcc=0.7822
# Fold 16 Epoch 400: TotalLoss=0.374049 | Sup=0.367232 | Recon=0.000852 | TrainAcc=0.8020
# Fold 16 Epoch 500: TotalLoss=0.357659 | Sup=0.351892 | Recon=0.000721 | TrainAcc=0.8020
# Fold 16 Epoch 600: TotalLoss=0.331008 | Sup=0.325661 | Recon=0.000668 | TrainAcc=0.8416
# Fold 16 Epoch 700: TotalLoss=0.308543 | Sup=0.303543 | Recon=0.000625 | TrainAcc=0.8317
# Fold 16 Epoch 800: TotalLoss=0.297723 | Sup=0.292988 | Recon=0.000592 | TrainAcc=0.7921
# Fold 16 Epoch 900: TotalLoss=0.289836 | Sup=0.285297 | Recon=0.000567 | TrainAcc=0.8416
# Fold 16 Epoch 1000: TotalLoss=0.266701 | Sup=0.262432 | Recon=0.000534 | TrainAcc=0.8515
# Fold 16 Epoch 1100: TotalLoss=0.265287 | Sup=0.261151 | Recon=0.000517 | TrainAcc=0.8218
# Fold 16 Epoch 1200: TotalLoss=0.255688 | Sup=0.251712 | Recon=0.000497 | TrainAcc=0.8515
# Fold 16 Epoch 1300: TotalLoss=0.232387 | Sup=0.228521 | Recon=0.000483 | TrainAcc=0.8614
# Fold 16 Epoch 1400: TotalLoss=0.218612 | Sup=0.214848 | Recon=0.000471 | TrainAcc=0.8515
# Fold 16 Epoch 1500: TotalLoss=0.209099 | Sup=0.205450 | Recon=0.000456 | TrainAcc=0.8713
# Fold 16 Epoch 1600: TotalLoss=0.210114 | Sup=0.206632 | Recon=0.000435 | TrainAcc=0.8614
# Fold 16 Epoch 1700: TotalLoss=0.197457 | Sup=0.194087 | Recon=0.000421 | TrainAcc=0.8614
# Fold 16 Epoch 1800: TotalLoss=0.180149 | Sup=0.176845 | Recon=0.000413 | TrainAcc=0.7426
# Fold 16 Epoch 1900: TotalLoss=0.175764 | Sup=0.172633 | Recon=0.000391 | TrainAcc=0.9010
# Fold 16 Epoch 2000: TotalLoss=0.163722 | Sup=0.160665 | Recon=0.000382 | TrainAcc=0.8812
# Fold 16 → Acc=0.8182 | Prec=0.7500 | Rec=0.6429 | F1=0.6923 | AUC=0.9071 | CE Loss=0.4607
#
# === Fold 17 ===
# Train Control: 68, Train Patient: 33
# Fold 17 Epoch 1: TotalLoss=0.882935 | Sup=0.642788 | Recon=0.030018 | TrainAcc=0.6733
# Fold 17 Epoch 100: TotalLoss=0.536119 | Sup=0.519862 | Recon=0.002032 | TrainAcc=0.6931
# Fold 17 Epoch 200: TotalLoss=0.479944 | Sup=0.469375 | Recon=0.001321 | TrainAcc=0.7525
# Fold 17 Epoch 300: TotalLoss=0.452702 | Sup=0.444612 | Recon=0.001011 | TrainAcc=0.7525
# Fold 17 Epoch 400: TotalLoss=0.413803 | Sup=0.407384 | Recon=0.000802 | TrainAcc=0.7921
# Fold 17 Epoch 500: TotalLoss=0.383352 | Sup=0.377411 | Recon=0.000743 | TrainAcc=0.8020
# Fold 17 Epoch 600: TotalLoss=0.370470 | Sup=0.365029 | Recon=0.000680 | TrainAcc=0.7921
# Fold 17 Epoch 700: TotalLoss=0.335675 | Sup=0.330657 | Recon=0.000627 | TrainAcc=0.8218
# Fold 17 Epoch 800: TotalLoss=0.338571 | Sup=0.333825 | Recon=0.000593 | TrainAcc=0.8317
# Fold 17 Epoch 900: TotalLoss=0.310235 | Sup=0.305768 | Recon=0.000558 | TrainAcc=0.8317
# Fold 17 Epoch 1000: TotalLoss=0.284682 | Sup=0.280365 | Recon=0.000540 | TrainAcc=0.8218
# Fold 17 Epoch 1100: TotalLoss=0.265255 | Sup=0.261097 | Recon=0.000520 | TrainAcc=0.8416
# Fold 17 Epoch 1200: TotalLoss=0.268913 | Sup=0.264903 | Recon=0.000501 | TrainAcc=0.8317
# Fold 17 Epoch 1300: TotalLoss=0.250250 | Sup=0.246426 | Recon=0.000478 | TrainAcc=0.8713
# Fold 17 Epoch 1400: TotalLoss=0.237083 | Sup=0.233415 | Recon=0.000459 | TrainAcc=0.8416
# Fold 17 Epoch 1500: TotalLoss=0.227175 | Sup=0.223537 | Recon=0.000455 | TrainAcc=0.8416
# Fold 17 Epoch 1600: TotalLoss=0.228275 | Sup=0.224812 | Recon=0.000433 | TrainAcc=0.8812
# Fold 17 Epoch 1700: TotalLoss=0.209053 | Sup=0.205709 | Recon=0.000418 | TrainAcc=0.8416
# Fold 17 Epoch 1800: TotalLoss=0.189694 | Sup=0.186407 | Recon=0.000411 | TrainAcc=0.8416
# Fold 17 Epoch 1900: TotalLoss=0.181545 | Sup=0.178366 | Recon=0.000397 | TrainAcc=0.7921
# Fold 17 Epoch 2000: TotalLoss=0.175866 | Sup=0.172776 | Recon=0.000386 | TrainAcc=0.8713
# Fold 17 → Acc=0.8182 | Prec=0.8750 | Rec=0.5000 | F1=0.6364 | AUC=0.9548 | CE Loss=0.2980
#
# === Fold 18 ===
# Train Control: 68, Train Patient: 33
# Fold 18 Epoch 1: TotalLoss=0.957740 | Sup=0.690334 | Recon=0.033426 | TrainAcc=0.6733
# Fold 18 Epoch 100: TotalLoss=0.502523 | Sup=0.483404 | Recon=0.002390 | TrainAcc=0.7525
# Fold 18 Epoch 200: TotalLoss=0.457809 | Sup=0.446102 | Recon=0.001463 | TrainAcc=0.7822
# Fold 18 Epoch 300: TotalLoss=0.438394 | Sup=0.429948 | Recon=0.001056 | TrainAcc=0.7822
# Fold 18 Epoch 400: TotalLoss=0.406264 | Sup=0.399574 | Recon=0.000836 | TrainAcc=0.8218
# Fold 18 Epoch 500: TotalLoss=0.377416 | Sup=0.371684 | Recon=0.000717 | TrainAcc=0.8317
# Fold 18 Epoch 600: TotalLoss=0.366836 | Sup=0.361593 | Recon=0.000655 | TrainAcc=0.8416
# Fold 18 Epoch 700: TotalLoss=0.345288 | Sup=0.340309 | Recon=0.000622 | TrainAcc=0.8119
# Fold 18 Epoch 800: TotalLoss=0.312815 | Sup=0.308101 | Recon=0.000589 | TrainAcc=0.8416
# Fold 18 Epoch 900: TotalLoss=0.293864 | Sup=0.289291 | Recon=0.000572 | TrainAcc=0.8218
# Fold 18 Epoch 1000: TotalLoss=0.276327 | Sup=0.271928 | Recon=0.000550 | TrainAcc=0.8317
# Fold 18 Epoch 1100: TotalLoss=0.266806 | Sup=0.262571 | Recon=0.000529 | TrainAcc=0.8416
# Fold 18 Epoch 1200: TotalLoss=0.252001 | Sup=0.247910 | Recon=0.000511 | TrainAcc=0.8317
# Fold 18 Epoch 1300: TotalLoss=0.236224 | Sup=0.232264 | Recon=0.000495 | TrainAcc=0.8317
# Fold 18 Epoch 1400: TotalLoss=0.225250 | Sup=0.221324 | Recon=0.000491 | TrainAcc=0.8515
# Fold 18 Epoch 1500: TotalLoss=0.216495 | Sup=0.212703 | Recon=0.000474 | TrainAcc=0.8911
# Fold 18 Epoch 1600: TotalLoss=0.199708 | Sup=0.196059 | Recon=0.000456 | TrainAcc=0.9109
# Fold 18 Epoch 1700: TotalLoss=0.191013 | Sup=0.187422 | Recon=0.000449 | TrainAcc=0.9109
# Fold 18 Epoch 1800: TotalLoss=0.185060 | Sup=0.181607 | Recon=0.000432 | TrainAcc=0.9010
# Fold 18 Epoch 1900: TotalLoss=0.179212 | Sup=0.175868 | Recon=0.000418 | TrainAcc=0.9109
# Fold 18 Epoch 2000: TotalLoss=0.177300 | Sup=0.174002 | Recon=0.000412 | TrainAcc=0.8812
# Fold 18 → Acc=0.8636 | Prec=0.7857 | Rec=0.7857 | F1=0.7857 | AUC=0.9310 | CE Loss=0.2974
#
# === Fold 19 ===
# Train Control: 68, Train Patient: 33
# Fold 19 Epoch 1: TotalLoss=0.892246 | Sup=0.659738 | Recon=0.029063 | TrainAcc=0.6733
# Fold 19 Epoch 100: TotalLoss=0.494620 | Sup=0.477462 | Recon=0.002145 | TrainAcc=0.7129
# Fold 19 Epoch 200: TotalLoss=0.457773 | Sup=0.446976 | Recon=0.001350 | TrainAcc=0.8020
# Fold 19 Epoch 300: TotalLoss=0.431449 | Sup=0.423155 | Recon=0.001037 | TrainAcc=0.8020
# Fold 19 Epoch 400: TotalLoss=0.389642 | Sup=0.383129 | Recon=0.000814 | TrainAcc=0.8119
# Fold 19 Epoch 500: TotalLoss=0.356798 | Sup=0.350862 | Recon=0.000742 | TrainAcc=0.8317
# Fold 19 Epoch 600: TotalLoss=0.339908 | Sup=0.334607 | Recon=0.000663 | TrainAcc=0.8614
# Fold 19 Epoch 700: TotalLoss=0.315441 | Sup=0.310566 | Recon=0.000609 | TrainAcc=0.8614
# Fold 19 Epoch 800: TotalLoss=0.297611 | Sup=0.292897 | Recon=0.000589 | TrainAcc=0.8515
# Fold 19 Epoch 900: TotalLoss=0.274722 | Sup=0.270212 | Recon=0.000564 | TrainAcc=0.8812
# Fold 19 Epoch 1000: TotalLoss=0.274038 | Sup=0.269670 | Recon=0.000546 | TrainAcc=0.8515
# Fold 19 Epoch 1100: TotalLoss=0.258220 | Sup=0.254014 | Recon=0.000526 | TrainAcc=0.8812
# Fold 19 Epoch 1200: TotalLoss=0.244179 | Sup=0.240089 | Recon=0.000511 | TrainAcc=0.8515
# Fold 19 Epoch 1300: TotalLoss=0.222973 | Sup=0.219066 | Recon=0.000488 | TrainAcc=0.8713
# Fold 19 Epoch 1400: TotalLoss=0.209961 | Sup=0.206210 | Recon=0.000469 | TrainAcc=0.8911
# Fold 19 Epoch 1500: TotalLoss=0.200580 | Sup=0.196939 | Recon=0.000455 | TrainAcc=0.8713
# Fold 19 Epoch 1600: TotalLoss=0.194161 | Sup=0.190694 | Recon=0.000433 | TrainAcc=0.8812
# Fold 19 Epoch 1700: TotalLoss=0.194604 | Sup=0.191172 | Recon=0.000429 | TrainAcc=0.8713
# Fold 19 Epoch 1800: TotalLoss=0.173445 | Sup=0.170075 | Recon=0.000421 | TrainAcc=0.8812
# Fold 19 Epoch 1900: TotalLoss=0.173209 | Sup=0.169983 | Recon=0.000403 | TrainAcc=0.9208
# Fold 19 Epoch 2000: TotalLoss=0.149510 | Sup=0.146346 | Recon=0.000396 | TrainAcc=0.9307
# Fold 19 → Acc=0.8182 | Prec=0.7143 | Rec=0.7143 | F1=0.7143 | AUC=0.8643 | CE Loss=0.4540
#
# === Fold 20 ===
# Train Control: 68, Train Patient: 33
# Fold 20 Epoch 1: TotalLoss=0.967924 | Sup=0.741967 | Recon=0.028245 | TrainAcc=0.6733
# Fold 20 Epoch 100: TotalLoss=0.512719 | Sup=0.495564 | Recon=0.002144 | TrainAcc=0.7228
# Fold 20 Epoch 200: TotalLoss=0.477558 | Sup=0.466870 | Recon=0.001336 | TrainAcc=0.7327
# Fold 20 Epoch 300: TotalLoss=0.448771 | Sup=0.440625 | Recon=0.001018 | TrainAcc=0.7624
# Fold 20 Epoch 400: TotalLoss=0.412183 | Sup=0.405549 | Recon=0.000829 | TrainAcc=0.7822
# Fold 20 Epoch 500: TotalLoss=0.385738 | Sup=0.379876 | Recon=0.000733 | TrainAcc=0.7921
# Fold 20 Epoch 600: TotalLoss=0.380692 | Sup=0.375552 | Recon=0.000643 | TrainAcc=0.7822
# Fold 20 Epoch 700: TotalLoss=0.348822 | Sup=0.343943 | Recon=0.000610 | TrainAcc=0.8020
# Fold 20 Epoch 800: TotalLoss=0.333075 | Sup=0.328506 | Recon=0.000571 | TrainAcc=0.8218
# Fold 20 Epoch 900: TotalLoss=0.325088 | Sup=0.320638 | Recon=0.000556 | TrainAcc=0.8218
# Fold 20 Epoch 1000: TotalLoss=0.293182 | Sup=0.288981 | Recon=0.000525 | TrainAcc=0.8614
# Fold 20 Epoch 1100: TotalLoss=0.284669 | Sup=0.280664 | Recon=0.000501 | TrainAcc=0.8515
# Fold 20 Epoch 1200: TotalLoss=0.267321 | Sup=0.263437 | Recon=0.000486 | TrainAcc=0.8317
# Fold 20 Epoch 1300: TotalLoss=0.261184 | Sup=0.257375 | Recon=0.000476 | TrainAcc=0.8218
# Fold 20 Epoch 1400: TotalLoss=0.237366 | Sup=0.233664 | Recon=0.000463 | TrainAcc=0.8614
# Fold 20 Epoch 1500: TotalLoss=0.248144 | Sup=0.244474 | Recon=0.000459 | TrainAcc=0.8812
# Fold 20 Epoch 1600: TotalLoss=0.234020 | Sup=0.230461 | Recon=0.000445 | TrainAcc=0.9010
# Fold 20 Epoch 1700: TotalLoss=0.222188 | Sup=0.218754 | Recon=0.000429 | TrainAcc=0.8515
# Fold 20 Epoch 1800: TotalLoss=0.211458 | Sup=0.208049 | Recon=0.000426 | TrainAcc=0.8812
# Fold 20 Epoch 1900: TotalLoss=0.193686 | Sup=0.190400 | Recon=0.000411 | TrainAcc=0.9010
# Fold 20 Epoch 2000: TotalLoss=0.181377 | Sup=0.178194 | Recon=0.000398 | TrainAcc=0.8713
# Fold 20 → Acc=0.8636 | Prec=0.7500 | Rec=0.8571 | F1=0.8000 | AUC=0.8952 | CE Loss=0.4329
#
# === Average Results for λ = 8 ===
# Accuracy:  0.8341
# Precision: 0.7490
# Recall:    0.7679
# F1-score:  0.7428
# CE Loss:   0.4440
# AUC:       0.9021
#
#
# ====================== FINAL SUMMARY ACROSS ALL λ ======================
# Lambda   | Accuracy  | Precision | Recall   | F1-score  | AUC      | CE Loss
# ------------------------------------------------------------------------
# 0.001    | 0.8250    | 0.7467    | 0.7429   | 0.7178    | 0.9042   | 0.4682
# 0.005    | 0.8227    | 0.7636    | 0.7429   | 0.7202    | 0.8989   | 0.4752
# 0.009    | 0.8114    | 0.7638    | 0.6929   | 0.6744    | 0.9014   | 0.4600
# 0.01     | 0.8250    | 0.7798    | 0.6821   | 0.6908    | 0.9013   | 0.4525
# 0.05     | 0.8330    | 0.7762    | 0.7321   | 0.7231    | 0.9044   | 0.4436
# 0.09     | 0.8125    | 0.7678    | 0.6893   | 0.6922    | 0.8978   | 0.4820
# 0.1      | 0.8250    | 0.7729    | 0.7143   | 0.6980    | 0.9037   | 0.4619
# 0.3      | 0.8307    | 0.7588    | 0.7250   | 0.7124    | 0.9020   | 0.4351
# 0.5      | 0.8239    | 0.7818    | 0.6893   | 0.6976    | 0.9027   | 0.4422
# 0.9      | 0.8148    | 0.7657    | 0.7071   | 0.7026    | 0.8990   | 0.4869
# 1        | 0.8170    | 0.7510    | 0.7036   | 0.7023    | 0.8985   | 0.4600
# 2        | 0.8227    | 0.7518    | 0.7179   | 0.7012    | 0.9005   | 0.4539
# 5        | 0.8318    | 0.7806    | 0.7286   | 0.7164    | 0.9020   | 0.4633
# 8        | 0.8341    | 0.7490    | 0.7679   | 0.7428    | 0.9021   | 0.4440
