# %%
import os
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, log_loss
from torch_geometric.data import Data
from torch_geometric.nn import GCNConv

device = 'cuda' if torch.cuda.is_available() else 'cpu'
print("Device:", device)

control_path = "/home/snu/Downloads/NIFD_Patients_FA_Histogram_Feature.npy"
patient_path = "/home/snu/Downloads/NIFD_Control_FA_Histogram_Feature.npy"

Histogram_feature_Control_FA_array = np.load(control_path, allow_pickle=True)
Histogram_feature_Patient_FA_array = np.load(patient_path, allow_pickle=True)

X = np.vstack([Histogram_feature_Control_FA_array, Histogram_feature_Patient_FA_array])
y = np.hstack([
    np.zeros(Histogram_feature_Control_FA_array.shape[0], dtype=np.int64),
    np.ones(Histogram_feature_Patient_FA_array.shape[0], dtype=np.int64)
])

num_nodes, num_feats = X.shape
print(f"Features: {X.shape}, Labels: {y.shape}")

rng = np.random.RandomState(42)
perm = rng.permutation(num_nodes)
X = X[perm]
y = y[perm]

def create_adj(F_data, alpha=1):
    norms = np.linalg.norm(F_data, axis=1, keepdims=True)
    norms[norms == 0] = 1.0
    F_norm = F_data / norms
    W = np.dot(F_norm, F_norm.T)
    W = np.where(W >= alpha, 1.0, 0.0).astype(np.float32)
    if W.max() > 0:
        W = W / W.max()
    return W

alpha = 0.8
W = create_adj(X, alpha=alpha)
np.fill_diagonal(W, 1.0)

def load_data(adj, node_feats):
    node_feats = torch.from_numpy(node_feats).float()
    rows, cols = np.nonzero(adj > 0)
    edge_index = torch.from_numpy(np.vstack([rows, cols]).astype(np.int64))
    return Data(x=node_feats, edge_index=edge_index)

data = load_data(W, X).to(device)
print(data)

class GCN_AE(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim, num_nodes, device, activ="RELU", dropout=0.25):
        super(GCN_AE, self).__init__()
        self.device = device
        self.dropout = dropout
        self.conv1 = GCNConv(input_dim, hidden_dim)
        self.conv2 = GCNConv(hidden_dim, output_dim)
        self.conv3 = GCNConv(hidden_dim, num_nodes)
        activations = {
            "SELU": F.selu,
            "SiLU": F.silu,
            "GELU": F.gelu,
            "RELU": F.relu,
            "ELU": F.elu
        }
        self.act = activations.get(activ, F.relu)

    def forward(self, x, edge_index):
        h = self.conv1(x, edge_index)
        h1 = self.act(h)
        logits = self.conv2(h1, edge_index)
        h2 = torch.sigmoid(logits)
        A_hat = self.conv3(h1, edge_index)
        A_pred = torch.sigmoid(A_hat)
        return h2, A_pred, h1

def auto_loss(A_pred: torch.Tensor, A_tilde: torch.Tensor, eps: float = 1e-12) -> torch.Tensor:
    if A_pred.dim() not in (2, 3):
        raise ValueError("A_pred must be shape (n,n) or (B,n,n)")
    if A_pred.shape != A_tilde.shape:
        raise ValueError("A_pred and A_tilde must have the same shape")
    if A_pred.dim() == 2:
        n = A_pred.size(0)
        D = A_tilde.sum(dim=1)
        D_inv_sqrt = torch.rsqrt(D + eps)
        D_inv_sqrt_mat = torch.diag(D_inv_sqrt)
        S = D_inv_sqrt_mat @ A_tilde @ D_inv_sqrt_mat
        A_pred_clamped = A_pred.clamp(min=eps, max=1.0)
        loss = - (S * torch.log(A_pred_clamped)).mean()
        return loss
    else:
        B, n, _ = A_pred.shape
        D = A_tilde.sum(dim=2)
        D_inv_sqrt = torch.rsqrt(D + eps)
        D_inv_sqrt_mat = torch.diag_embed(D_inv_sqrt)
        S = D_inv_sqrt_mat.bmm(A_tilde).bmm(D_inv_sqrt_mat)
        A_pred_clamped = A_pred.clamp(min=eps, max=1.0)
        loss = - (S * torch.log(A_pred_clamped)).mean()
        return loss

feats_dim = num_feats
hidden_dim = 512
num_classes = 2
num_epochs = 2000
lr = 1e-4
weight_decay = 1e-4
batch_print_freq = 100
lambda_recon = 0.001

sss = StratifiedShuffleSplit(n_splits=20, test_size=0.1, random_state=42)
accuracies, precisions, recalls, f1_scores, aucs, ce_losses = [], [], [], [], [], []
y_all = y.copy()

for fold, (train_val_idx, test_idx_global) in enumerate(sss.split(X, y_all), start=1):
    print(f"\n=== Fold {fold} ===")
    control_idx = np.where(y_all == 0)[0]
    patient_idx = np.where(y_all == 1)[0]
    sss_class = StratifiedShuffleSplit(n_splits=20, test_size=0.5, random_state=fold)
    control_train_idx, _ = next(sss_class.split(X[control_idx], y_all[control_idx]))
    patient_train_idx, _ = next(sss_class.split(X[patient_idx], y_all[patient_idx]))
    control_train = control_idx[control_train_idx]
    patient_train = patient_idx[patient_train_idx]
    train_idx_final = np.concatenate([control_train, patient_train])
    np.random.shuffle(train_idx_final)
    print(f"Train Control: {len(control_train)}, Train Patient: {len(patient_train)}")

    train_idx_t = torch.from_numpy(train_idx_final).long().to(device)
    y_train_tensor = torch.from_numpy(y_all[train_idx_final]).long().to(device)

    model = GCN_AE(feats_dim, hidden_dim, num_classes, num_nodes, device, activ="RELU", dropout=0.25).to(device)
    optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
    ce_loss_fn = nn.CrossEntropyLoss()
    data = load_data(W, X).to(device)
    A_tilde = torch.from_numpy(W).float().to(device)

    for epoch in range(1, num_epochs + 1):
        model.train()
        optimizer.zero_grad()
        logits, recon_x, _ = model(data.x, data.edge_index)
        loss_sup = ce_loss_fn(logits[train_idx_t], y_train_tensor)
        loss_recon = auto_loss(recon_x, A_tilde)
        total_loss = loss_sup + lambda_recon * loss_recon
        if torch.isnan(total_loss) or torch.isinf(total_loss):
            print(f"NaN/Inf detected at fold {fold} epoch {epoch}. Aborting epoch.")
            break
        total_loss.backward()
        optimizer.step()
        if epoch % batch_print_freq == 0 or epoch == 1:
            model.eval()
            with torch.no_grad():
                logits_eval, _, _ = model(data.x, data.edge_index)
                preds_train = logits_eval[train_idx_t].argmax(dim=1)
                acc_train = accuracy_score(y_train_tensor.cpu(), preds_train.cpu())
            print(f"Fold {fold} Epoch {epoch}: TotalLoss={total_loss.item():.6f} | Sup={loss_sup.item():.6f} | Recon={loss_recon.item():.6f} | TrainAcc={acc_train:.4f}")

    model.eval()
    with torch.no_grad():
        out_logits, _, _ = model(data.x, data.edge_index)
        preds = out_logits.argmax(dim=1).cpu().numpy()
        probs = F.softmax(out_logits, dim=1)[:, 1].cpu().numpy()

    y_test = y_all[test_idx_global]
    y_pred_test = preds[test_idx_global]
    y_prob_test = probs[test_idx_global]

    acc = accuracy_score(y_test, y_pred_test)
    prec = precision_score(y_test, y_pred_test, zero_division=0)
    rec = recall_score(y_test, y_pred_test, zero_division=0)
    f1 = f1_score(y_test, y_pred_test, zero_division=0)
    try:
        auc = roc_auc_score(y_test, y_prob_test)
    except ValueError:
        auc = float('nan')
    ce = log_loss(y_test, y_prob_test)

    accuracies.append(acc)
    precisions.append(prec)
    recalls.append(rec)
    f1_scores.append(f1)
    aucs.append(auc)
    ce_losses.append(ce)

    print(f"Fold {fold} → Acc={acc:.4f} | Prec={prec:.4f} | Rec={rec:.4f} | F1={f1:.4f} | AUC={auc:.4f} | CE Loss={ce:.4f}")

print("\n=== Average Results Across 20 Folds ===")
print(f"Accuracy:  {np.mean(accuracies):.4f} ± {np.std(accuracies):.4f}")
print(f"Precision: {np.mean(precisions):.4f} ± {np.std(precisions):.4f}")
print(f"Recall:    {np.mean(recalls):.4f} ± {np.std(recalls):.4f}")
print(f"F1-score:  {np.mean(f1_scores):.4f} ± {np.std(f1_scores):.4f}")
print(f"AUC:       {np.nanmean(aucs):.4f} ± {np.nanstd(aucs):.4f}")
print(f"CE Loss:   {np.mean(ce_losses):.4f} ± {np.std(ce_losses):.4f}")
# Out:
# Device: cuda
# Features: (146, 180), Labels: (146,)
# Data(x=[146, 180], edge_index=[2, 13046])
#
# === Fold 1 ===
# Train Control: 49, Train Patient: 24
# Fold 1 Epoch 1: TotalLoss=0.695710 | Sup=0.695705 | Recon=0.004641 | TrainAcc=0.3151
# Fold 1 Epoch 100: TotalLoss=0.642760 | Sup=0.642755 | Recon=0.004650 | TrainAcc=0.6712
# Fold 1 Epoch 200: TotalLoss=0.632128 | Sup=0.632124 | Recon=0.004656 | TrainAcc=0.6712
# Fold 1 Epoch 300: TotalLoss=0.630076 | Sup=0.630071 | Recon=0.004656 | TrainAcc=0.6712
# Fold 1 Epoch 400: TotalLoss=0.628564 | Sup=0.628559 | Recon=0.004655 | TrainAcc=0.6712
# Fold 1 Epoch 500: TotalLoss=0.626698 | Sup=0.626693 | Recon=0.004652 | TrainAcc=0.6712
# Fold 1 Epoch 600: TotalLoss=0.624331 | Sup=0.624326 | Recon=0.004649 | TrainAcc=0.6712
# Fold 1 Epoch 700: TotalLoss=0.621509 | Sup=0.621504 | Recon=0.004646 | TrainAcc=0.6712
# Fold 1 Epoch 800: TotalLoss=0.618283 | Sup=0.618278 | Recon=0.004644 | TrainAcc=0.6712
# Fold 1 Epoch 900: TotalLoss=0.614708 | Sup=0.614703 | Recon=0.004641 | TrainAcc=0.6712
# Fold 1 Epoch 1000: TotalLoss=0.610962 | Sup=0.610957 | Recon=0.004639 | TrainAcc=0.6712
# Fold 1 Epoch 1100: TotalLoss=0.607088 | Sup=0.607084 | Recon=0.004637 | TrainAcc=0.6712
# Fold 1 Epoch 1200: TotalLoss=0.603248 | Sup=0.603244 | Recon=0.004635 | TrainAcc=0.6849
# Fold 1 Epoch 1300: TotalLoss=0.599627 | Sup=0.599622 | Recon=0.004633 | TrainAcc=0.6849
# Fold 1 Epoch 1400: TotalLoss=0.596373 | Sup=0.596368 | Recon=0.004632 | TrainAcc=0.6986
# Fold 1 Epoch 1500: TotalLoss=0.593555 | Sup=0.593550 | Recon=0.004631 | TrainAcc=0.7123
# Fold 1 Epoch 1600: TotalLoss=0.591179 | Sup=0.591174 | Recon=0.004630 | TrainAcc=0.7260
# Fold 1 Epoch 1700: TotalLoss=0.589185 | Sup=0.589181 | Recon=0.004629 | TrainAcc=0.7260
# Fold 1 Epoch 1800: TotalLoss=0.587537 | Sup=0.587532 | Recon=0.004629 | TrainAcc=0.7260
# Fold 1 Epoch 1900: TotalLoss=0.586173 | Sup=0.586169 | Recon=0.004628 | TrainAcc=0.7260
# Fold 1 Epoch 2000: TotalLoss=0.585043 | Sup=0.585038 | Recon=0.004628 | TrainAcc=0.7260
# Fold 1 → Acc=0.6000 | Prec=0.0000 | Rec=0.0000 | F1=0.0000 | AUC=0.8400 | CE Loss=0.5923
#
# === Fold 2 ===
# Train Control: 49, Train Patient: 24
# Fold 2 Epoch 1: TotalLoss=0.692938 | Sup=0.692933 | Recon=0.004647 | TrainAcc=0.6712
# Fold 2 Epoch 100: TotalLoss=0.646246 | Sup=0.646242 | Recon=0.004671 | TrainAcc=0.6712
# Fold 2 Epoch 200: TotalLoss=0.636360 | Sup=0.636355 | Recon=0.004679 | TrainAcc=0.6712
# Fold 2 Epoch 300: TotalLoss=0.633552 | Sup=0.633547 | Recon=0.004674 | TrainAcc=0.6712
# Fold 2 Epoch 400: TotalLoss=0.631000 | Sup=0.630996 | Recon=0.004666 | TrainAcc=0.6712
# Fold 2 Epoch 500: TotalLoss=0.627830 | Sup=0.627825 | Recon=0.004659 | TrainAcc=0.6712
# Fold 2 Epoch 600: TotalLoss=0.623963 | Sup=0.623958 | Recon=0.004653 | TrainAcc=0.6712
# Fold 2 Epoch 700: TotalLoss=0.619555 | Sup=0.619550 | Recon=0.004648 | TrainAcc=0.6712
# Fold 2 Epoch 800: TotalLoss=0.614837 | Sup=0.614832 | Recon=0.004644 | TrainAcc=0.6712
# Fold 2 Epoch 900: TotalLoss=0.610102 | Sup=0.610097 | Recon=0.004641 | TrainAcc=0.6712
# Fold 2 Epoch 1000: TotalLoss=0.605571 | Sup=0.605566 | Recon=0.004637 | TrainAcc=0.6712
# Fold 2 Epoch 1100: TotalLoss=0.601288 | Sup=0.601283 | Recon=0.004635 | TrainAcc=0.6712
# Fold 2 Epoch 1200: TotalLoss=0.597351 | Sup=0.597346 | Recon=0.004633 | TrainAcc=0.6849
# Fold 2 Epoch 1300: TotalLoss=0.593867 | Sup=0.593862 | Recon=0.004631 | TrainAcc=0.6986
# Fold 2 Epoch 1400: TotalLoss=0.590899 | Sup=0.590894 | Recon=0.004630 | TrainAcc=0.6986
# Fold 2 Epoch 1500: TotalLoss=0.588402 | Sup=0.588397 | Recon=0.004629 | TrainAcc=0.6986
# Fold 2 Epoch 1600: TotalLoss=0.586339 | Sup=0.586334 | Recon=0.004629 | TrainAcc=0.6986
# Fold 2 Epoch 1700: TotalLoss=0.584655 | Sup=0.584650 | Recon=0.004628 | TrainAcc=0.6986
# Fold 2 Epoch 1800: TotalLoss=0.583283 | Sup=0.583278 | Recon=0.004628 | TrainAcc=0.7123
# Fold 2 Epoch 1900: TotalLoss=0.582179 | Sup=0.582175 | Recon=0.004628 | TrainAcc=0.6986
# Fold 2 Epoch 2000: TotalLoss=0.581283 | Sup=0.581278 | Recon=0.004627 | TrainAcc=0.6986
# Fold 2 → Acc=0.7333 | Prec=0.6667 | Rec=0.4000 | F1=0.5000 | AUC=0.7200 | CE Loss=0.5865
#
# === Fold 3 ===
# Train Control: 49, Train Patient: 24
# Fold 3 Epoch 1: TotalLoss=0.693759 | Sup=0.693754 | Recon=0.004630 | TrainAcc=0.5479
# Fold 3 Epoch 100: TotalLoss=0.648323 | Sup=0.648318 | Recon=0.004633 | TrainAcc=0.6712
# Fold 3 Epoch 200: TotalLoss=0.640109 | Sup=0.640104 | Recon=0.004632 | TrainAcc=0.6712
# Fold 3 Epoch 300: TotalLoss=0.636749 | Sup=0.636744 | Recon=0.004632 | TrainAcc=0.6712
# Fold 3 Epoch 400: TotalLoss=0.633083 | Sup=0.633079 | Recon=0.004632 | TrainAcc=0.6712
# Fold 3 Epoch 500: TotalLoss=0.628245 | Sup=0.628240 | Recon=0.004631 | TrainAcc=0.6712
# Fold 3 Epoch 600: TotalLoss=0.622227 | Sup=0.622222 | Recon=0.004629 | TrainAcc=0.6712
# Fold 3 Epoch 700: TotalLoss=0.615471 | Sup=0.615466 | Recon=0.004627 | TrainAcc=0.6712
# Fold 3 Epoch 800: TotalLoss=0.608510 | Sup=0.608505 | Recon=0.004626 | TrainAcc=0.6712
# Fold 3 Epoch 900: TotalLoss=0.601846 | Sup=0.601841 | Recon=0.004625 | TrainAcc=0.6712
# Fold 3 Epoch 1000: TotalLoss=0.595774 | Sup=0.595769 | Recon=0.004624 | TrainAcc=0.6849
# Fold 3 Epoch 1100: TotalLoss=0.590399 | Sup=0.590394 | Recon=0.004624 | TrainAcc=0.6986
# Fold 3 Epoch 1200: TotalLoss=0.585758 | Sup=0.585754 | Recon=0.004624 | TrainAcc=0.6986
# Fold 3 Epoch 1300: TotalLoss=0.581808 | Sup=0.581804 | Recon=0.004624 | TrainAcc=0.7123
# Fold 3 Epoch 1400: TotalLoss=0.578557 | Sup=0.578552 | Recon=0.004624 | TrainAcc=0.7123
# Fold 3 Epoch 1500: TotalLoss=0.575944 | Sup=0.575940 | Recon=0.004624 | TrainAcc=0.6986
# Fold 3 Epoch 1600: TotalLoss=0.573863 | Sup=0.573859 | Recon=0.004624 | TrainAcc=0.7123
# Fold 3 Epoch 1700: TotalLoss=0.572195 | Sup=0.572191 | Recon=0.004624 | TrainAcc=0.7123
# Fold 3 Epoch 1800: TotalLoss=0.570843 | Sup=0.570838 | Recon=0.004624 | TrainAcc=0.7123
# Fold 3 Epoch 1900: TotalLoss=0.569750 | Sup=0.569746 | Recon=0.004625 | TrainAcc=0.7123
# Fold 3 Epoch 2000: TotalLoss=0.568856 | Sup=0.568851 | Recon=0.004625 | TrainAcc=0.7123
# Fold 3 → Acc=0.7333 | Prec=0.6667 | Rec=0.4000 | F1=0.5000 | AUC=0.9000 | CE Loss=0.5486
#
# === Fold 4 ===
# Train Control: 49, Train Patient: 24
# Fold 4 Epoch 1: TotalLoss=0.696441 | Sup=0.696436 | Recon=0.004626 | TrainAcc=0.3288
# Fold 4 Epoch 100: TotalLoss=0.647418 | Sup=0.647413 | Recon=0.004610 | TrainAcc=0.6712
# Fold 4 Epoch 200: TotalLoss=0.637944 | Sup=0.637939 | Recon=0.004606 | TrainAcc=0.6712
# Fold 4 Epoch 300: TotalLoss=0.634927 | Sup=0.634923 | Recon=0.004606 | TrainAcc=0.6712
# Fold 4 Epoch 400: TotalLoss=0.631868 | Sup=0.631863 | Recon=0.004605 | TrainAcc=0.6712
# Fold 4 Epoch 500: TotalLoss=0.627949 | Sup=0.627944 | Recon=0.004606 | TrainAcc=0.6712
# Fold 4 Epoch 600: TotalLoss=0.623294 | Sup=0.623289 | Recon=0.004607 | TrainAcc=0.6712
# Fold 4 Epoch 700: TotalLoss=0.618191 | Sup=0.618187 | Recon=0.004609 | TrainAcc=0.6712
# Fold 4 Epoch 800: TotalLoss=0.613033 | Sup=0.613028 | Recon=0.004611 | TrainAcc=0.6712
# Fold 4 Epoch 900: TotalLoss=0.608230 | Sup=0.608225 | Recon=0.004613 | TrainAcc=0.6712
# Fold 4 Epoch 1000: TotalLoss=0.603967 | Sup=0.603962 | Recon=0.004615 | TrainAcc=0.6712
# Fold 4 Epoch 1100: TotalLoss=0.600253 | Sup=0.600248 | Recon=0.004617 | TrainAcc=0.6712
# Fold 4 Epoch 1200: TotalLoss=0.597055 | Sup=0.597051 | Recon=0.004618 | TrainAcc=0.6712
# Fold 4 Epoch 1300: TotalLoss=0.594381 | Sup=0.594377 | Recon=0.004620 | TrainAcc=0.6849
# Fold 4 Epoch 1400: TotalLoss=0.592188 | Sup=0.592184 | Recon=0.004621 | TrainAcc=0.6986
# Fold 4 Epoch 1500: TotalLoss=0.590410 | Sup=0.590405 | Recon=0.004622 | TrainAcc=0.6986
# Fold 4 Epoch 1600: TotalLoss=0.588968 | Sup=0.588963 | Recon=0.004623 | TrainAcc=0.6986
# Fold 4 Epoch 1700: TotalLoss=0.587785 | Sup=0.587780 | Recon=0.004624 | TrainAcc=0.6986
# Fold 4 Epoch 1800: TotalLoss=0.586811 | Sup=0.586806 | Recon=0.004624 | TrainAcc=0.6849
# Fold 4 Epoch 1900: TotalLoss=0.586004 | Sup=0.586000 | Recon=0.004625 | TrainAcc=0.6986
# Fold 4 Epoch 2000: TotalLoss=0.585325 | Sup=0.585321 | Recon=0.004625 | TrainAcc=0.6986
# Fold 4 → Acc=0.6667 | Prec=0.0000 | Rec=0.0000 | F1=0.0000 | AUC=0.6800 | CE Loss=0.6135
#
# === Fold 5 ===
# Train Control: 49, Train Patient: 24
# Fold 5 Epoch 1: TotalLoss=0.694328 | Sup=0.694324 | Recon=0.004609 | TrainAcc=0.3288
# Fold 5 Epoch 100: TotalLoss=0.650934 | Sup=0.650929 | Recon=0.004602 | TrainAcc=0.6712
# Fold 5 Epoch 200: TotalLoss=0.641642 | Sup=0.641638 | Recon=0.004597 | TrainAcc=0.6712
# Fold 5 Epoch 300: TotalLoss=0.638816 | Sup=0.638812 | Recon=0.004595 | TrainAcc=0.6712
# Fold 5 Epoch 400: TotalLoss=0.636198 | Sup=0.636193 | Recon=0.004595 | TrainAcc=0.6712
# Fold 5 Epoch 500: TotalLoss=0.632977 | Sup=0.632972 | Recon=0.004596 | TrainAcc=0.6712
# Fold 5 Epoch 600: TotalLoss=0.629103 | Sup=0.629098 | Recon=0.004598 | TrainAcc=0.6712
# Fold 5 Epoch 700: TotalLoss=0.624803 | Sup=0.624798 | Recon=0.004601 | TrainAcc=0.6712
# Fold 5 Epoch 800: TotalLoss=0.620214 | Sup=0.620210 | Recon=0.004604 | TrainAcc=0.6712
# Fold 5 Epoch 900: TotalLoss=0.615545 | Sup=0.615540 | Recon=0.004609 | TrainAcc=0.6712
# Fold 5 Epoch 1000: TotalLoss=0.610930 | Sup=0.610925 | Recon=0.004613 | TrainAcc=0.6712
# Fold 5 Epoch 1100: TotalLoss=0.606539 | Sup=0.606535 | Recon=0.004616 | TrainAcc=0.6712
# Fold 5 Epoch 1200: TotalLoss=0.602662 | Sup=0.602657 | Recon=0.004619 | TrainAcc=0.6849
# Fold 5 Epoch 1300: TotalLoss=0.599411 | Sup=0.599406 | Recon=0.004621 | TrainAcc=0.6849
# Fold 5 Epoch 1400: TotalLoss=0.596718 | Sup=0.596713 | Recon=0.004622 | TrainAcc=0.6712
# Fold 5 Epoch 1500: TotalLoss=0.594502 | Sup=0.594497 | Recon=0.004623 | TrainAcc=0.6849
# Fold 5 Epoch 1600: TotalLoss=0.592716 | Sup=0.592711 | Recon=0.004624 | TrainAcc=0.6849
# Fold 5 Epoch 1700: TotalLoss=0.591302 | Sup=0.591298 | Recon=0.004624 | TrainAcc=0.6849
# Fold 5 Epoch 1800: TotalLoss=0.590186 | Sup=0.590181 | Recon=0.004625 | TrainAcc=0.6986
# Fold 5 Epoch 1900: TotalLoss=0.589294 | Sup=0.589290 | Recon=0.004625 | TrainAcc=0.6986
# Fold 5 Epoch 2000: TotalLoss=0.588561 | Sup=0.588556 | Recon=0.004625 | TrainAcc=0.6986
# Fold 5 → Acc=0.8667 | Prec=1.0000 | Rec=0.6000 | F1=0.7500 | AUC=0.8800 | CE Loss=0.5582
#
# === Fold 6 ===
# Train Control: 49, Train Patient: 24
# Fold 6 Epoch 1: TotalLoss=0.691090 | Sup=0.691086 | Recon=0.004645 | TrainAcc=0.6712
# Fold 6 Epoch 100: TotalLoss=0.644932 | Sup=0.644928 | Recon=0.004648 | TrainAcc=0.6712
# Fold 6 Epoch 200: TotalLoss=0.636010 | Sup=0.636005 | Recon=0.004646 | TrainAcc=0.6712
# Fold 6 Epoch 300: TotalLoss=0.632504 | Sup=0.632499 | Recon=0.004641 | TrainAcc=0.6712
# Fold 6 Epoch 400: TotalLoss=0.628674 | Sup=0.628669 | Recon=0.004637 | TrainAcc=0.6712
# Fold 6 Epoch 500: TotalLoss=0.623802 | Sup=0.623798 | Recon=0.004635 | TrainAcc=0.6712
# Fold 6 Epoch 600: TotalLoss=0.617736 | Sup=0.617732 | Recon=0.004634 | TrainAcc=0.6712
# Fold 6 Epoch 700: TotalLoss=0.610581 | Sup=0.610577 | Recon=0.004633 | TrainAcc=0.6712
# Fold 6 Epoch 800: TotalLoss=0.602681 | Sup=0.602676 | Recon=0.004631 | TrainAcc=0.6712
# Fold 6 Epoch 900: TotalLoss=0.594482 | Sup=0.594477 | Recon=0.004630 | TrainAcc=0.6849
# Fold 6 Epoch 1000: TotalLoss=0.586480 | Sup=0.586475 | Recon=0.004629 | TrainAcc=0.6986
# Fold 6 Epoch 1100: TotalLoss=0.578961 | Sup=0.578957 | Recon=0.004629 | TrainAcc=0.6986
# Fold 6 Epoch 1200: TotalLoss=0.572144 | Sup=0.572139 | Recon=0.004628 | TrainAcc=0.7260
# Fold 6 Epoch 1300: TotalLoss=0.566194 | Sup=0.566189 | Recon=0.004627 | TrainAcc=0.7260
# Fold 6 Epoch 1400: TotalLoss=0.561198 | Sup=0.561193 | Recon=0.004627 | TrainAcc=0.7260
# Fold 6 Epoch 1500: TotalLoss=0.557100 | Sup=0.557096 | Recon=0.004627 | TrainAcc=0.7397
# Fold 6 Epoch 1600: TotalLoss=0.553748 | Sup=0.553744 | Recon=0.004626 | TrainAcc=0.7397
# Fold 6 Epoch 1700: TotalLoss=0.551024 | Sup=0.551019 | Recon=0.004626 | TrainAcc=0.7397
# Fold 6 Epoch 1800: TotalLoss=0.548834 | Sup=0.548829 | Recon=0.004626 | TrainAcc=0.7397
# Fold 6 Epoch 1900: TotalLoss=0.547070 | Sup=0.547065 | Recon=0.004626 | TrainAcc=0.7397
# Fold 6 Epoch 2000: TotalLoss=0.545640 | Sup=0.545635 | Recon=0.004626 | TrainAcc=0.7397
# Fold 6 → Acc=0.7333 | Prec=0.6000 | Rec=0.6000 | F1=0.6000 | AUC=0.7200 | CE Loss=0.6111
#
# === Fold 7 ===
# Train Control: 49, Train Patient: 24
# Fold 7 Epoch 1: TotalLoss=0.686648 | Sup=0.686643 | Recon=0.004651 | TrainAcc=0.6712
# Fold 7 Epoch 100: TotalLoss=0.642696 | Sup=0.642692 | Recon=0.004640 | TrainAcc=0.6712
# Fold 7 Epoch 200: TotalLoss=0.634322 | Sup=0.634318 | Recon=0.004636 | TrainAcc=0.6712
# Fold 7 Epoch 300: TotalLoss=0.632022 | Sup=0.632018 | Recon=0.004636 | TrainAcc=0.6712
# Fold 7 Epoch 400: TotalLoss=0.629895 | Sup=0.629891 | Recon=0.004636 | TrainAcc=0.6712
# Fold 7 Epoch 500: TotalLoss=0.627167 | Sup=0.627163 | Recon=0.004637 | TrainAcc=0.6712
# Fold 7 Epoch 600: TotalLoss=0.623598 | Sup=0.623593 | Recon=0.004637 | TrainAcc=0.6712
# Fold 7 Epoch 700: TotalLoss=0.618988 | Sup=0.618983 | Recon=0.004636 | TrainAcc=0.6712
# Fold 7 Epoch 800: TotalLoss=0.613296 | Sup=0.613291 | Recon=0.004635 | TrainAcc=0.6712
# Fold 7 Epoch 900: TotalLoss=0.606649 | Sup=0.606644 | Recon=0.004635 | TrainAcc=0.6712
# Fold 7 Epoch 1000: TotalLoss=0.599355 | Sup=0.599350 | Recon=0.004633 | TrainAcc=0.6849
# Fold 7 Epoch 1100: TotalLoss=0.591849 | Sup=0.591844 | Recon=0.004632 | TrainAcc=0.7123
# Fold 7 Epoch 1200: TotalLoss=0.584466 | Sup=0.584461 | Recon=0.004631 | TrainAcc=0.7123
# Fold 7 Epoch 1300: TotalLoss=0.577636 | Sup=0.577631 | Recon=0.004631 | TrainAcc=0.7123
# Fold 7 Epoch 1400: TotalLoss=0.571677 | Sup=0.571672 | Recon=0.004630 | TrainAcc=0.7397
# Fold 7 Epoch 1500: TotalLoss=0.566634 | Sup=0.566629 | Recon=0.004629 | TrainAcc=0.7808
# Fold 7 Epoch 1600: TotalLoss=0.562433 | Sup=0.562428 | Recon=0.004628 | TrainAcc=0.7534
# Fold 7 Epoch 1700: TotalLoss=0.558966 | Sup=0.558961 | Recon=0.004627 | TrainAcc=0.7534
# Fold 7 Epoch 1800: TotalLoss=0.556149 | Sup=0.556145 | Recon=0.004626 | TrainAcc=0.7397
# Fold 7 Epoch 1900: TotalLoss=0.553863 | Sup=0.553859 | Recon=0.004625 | TrainAcc=0.7397
# Fold 7 Epoch 2000: TotalLoss=0.551987 | Sup=0.551982 | Recon=0.004625 | TrainAcc=0.7397
# Fold 7 → Acc=0.8000 | Prec=1.0000 | Rec=0.4000 | F1=0.5714 | AUC=0.7000 | CE Loss=0.5827
#
# === Fold 8 ===
# Train Control: 49, Train Patient: 24
# Fold 8 Epoch 1: TotalLoss=0.694280 | Sup=0.694275 | Recon=0.004635 | TrainAcc=0.3288
# Fold 8 Epoch 100: TotalLoss=0.647567 | Sup=0.647562 | Recon=0.004655 | TrainAcc=0.6712
# Fold 8 Epoch 200: TotalLoss=0.637525 | Sup=0.637521 | Recon=0.004658 | TrainAcc=0.6712
# Fold 8 Epoch 300: TotalLoss=0.634805 | Sup=0.634800 | Recon=0.004654 | TrainAcc=0.6712
# Fold 8 Epoch 400: TotalLoss=0.632420 | Sup=0.632415 | Recon=0.004649 | TrainAcc=0.6712
# Fold 8 Epoch 500: TotalLoss=0.629463 | Sup=0.629458 | Recon=0.004643 | TrainAcc=0.6712
# Fold 8 Epoch 600: TotalLoss=0.625868 | Sup=0.625863 | Recon=0.004640 | TrainAcc=0.6712
# Fold 8 Epoch 700: TotalLoss=0.621603 | Sup=0.621598 | Recon=0.004637 | TrainAcc=0.6712
# Fold 8 Epoch 800: TotalLoss=0.616853 | Sup=0.616848 | Recon=0.004635 | TrainAcc=0.6712
# Fold 8 Epoch 900: TotalLoss=0.611760 | Sup=0.611755 | Recon=0.004633 | TrainAcc=0.6712
# Fold 8 Epoch 1000: TotalLoss=0.606393 | Sup=0.606389 | Recon=0.004632 | TrainAcc=0.6712
# Fold 8 Epoch 1100: TotalLoss=0.600971 | Sup=0.600966 | Recon=0.004631 | TrainAcc=0.6849
# Fold 8 Epoch 1200: TotalLoss=0.595739 | Sup=0.595734 | Recon=0.004630 | TrainAcc=0.6986
# Fold 8 Epoch 1300: TotalLoss=0.590872 | Sup=0.590868 | Recon=0.004629 | TrainAcc=0.7123
# Fold 8 Epoch 1400: TotalLoss=0.586473 | Sup=0.586468 | Recon=0.004628 | TrainAcc=0.7260
# Fold 8 Epoch 1500: TotalLoss=0.582562 | Sup=0.582557 | Recon=0.004628 | TrainAcc=0.7260
# Fold 8 Epoch 1600: TotalLoss=0.579186 | Sup=0.579181 | Recon=0.004627 | TrainAcc=0.7260
# Fold 8 Epoch 1700: TotalLoss=0.576374 | Sup=0.576369 | Recon=0.004627 | TrainAcc=0.7534
# Fold 8 Epoch 1800: TotalLoss=0.574073 | Sup=0.574068 | Recon=0.004627 | TrainAcc=0.7534
# Fold 8 Epoch 1900: TotalLoss=0.572204 | Sup=0.572200 | Recon=0.004627 | TrainAcc=0.7534
# Fold 8 Epoch 2000: TotalLoss=0.570690 | Sup=0.570686 | Recon=0.004627 | TrainAcc=0.7671
# Fold 8 → Acc=0.8000 | Prec=1.0000 | Rec=0.4000 | F1=0.5714 | AUC=0.8200 | CE Loss=0.5834
#
# === Fold 9 ===
# Train Control: 49, Train Patient: 24
# Fold 9 Epoch 1: TotalLoss=0.696408 | Sup=0.696403 | Recon=0.004630 | TrainAcc=0.3288
# Fold 9 Epoch 100: TotalLoss=0.646077 | Sup=0.646072 | Recon=0.004605 | TrainAcc=0.6712
# Fold 9 Epoch 200: TotalLoss=0.635712 | Sup=0.635708 | Recon=0.004596 | TrainAcc=0.6712
# Fold 9 Epoch 300: TotalLoss=0.633640 | Sup=0.633636 | Recon=0.004596 | TrainAcc=0.6712
# Fold 9 Epoch 400: TotalLoss=0.632219 | Sup=0.632214 | Recon=0.004598 | TrainAcc=0.6712
# Fold 9 Epoch 500: TotalLoss=0.630496 | Sup=0.630491 | Recon=0.004602 | TrainAcc=0.6712
# Fold 9 Epoch 600: TotalLoss=0.628321 | Sup=0.628317 | Recon=0.004605 | TrainAcc=0.6712
# Fold 9 Epoch 700: TotalLoss=0.625656 | Sup=0.625651 | Recon=0.004608 | TrainAcc=0.6712
# Fold 9 Epoch 800: TotalLoss=0.622511 | Sup=0.622506 | Recon=0.004611 | TrainAcc=0.6712
# Fold 9 Epoch 900: TotalLoss=0.618982 | Sup=0.618977 | Recon=0.004615 | TrainAcc=0.6712
# Fold 9 Epoch 1000: TotalLoss=0.615161 | Sup=0.615157 | Recon=0.004618 | TrainAcc=0.6712
# Fold 9 Epoch 1100: TotalLoss=0.611246 | Sup=0.611242 | Recon=0.004620 | TrainAcc=0.6712
# Fold 9 Epoch 1200: TotalLoss=0.607417 | Sup=0.607413 | Recon=0.004622 | TrainAcc=0.6849
# Fold 9 Epoch 1300: TotalLoss=0.603843 | Sup=0.603838 | Recon=0.004623 | TrainAcc=0.6986
# Fold 9 Epoch 1400: TotalLoss=0.600620 | Sup=0.600616 | Recon=0.004624 | TrainAcc=0.6986
# Fold 9 Epoch 1500: TotalLoss=0.597825 | Sup=0.597820 | Recon=0.004625 | TrainAcc=0.6986
# Fold 9 Epoch 1600: TotalLoss=0.595468 | Sup=0.595464 | Recon=0.004626 | TrainAcc=0.6986
# Fold 9 Epoch 1700: TotalLoss=0.593474 | Sup=0.593469 | Recon=0.004626 | TrainAcc=0.6986
# Fold 9 Epoch 1800: TotalLoss=0.591837 | Sup=0.591832 | Recon=0.004626 | TrainAcc=0.6986
# Fold 9 Epoch 1900: TotalLoss=0.590497 | Sup=0.590492 | Recon=0.004627 | TrainAcc=0.6986
# Fold 9 Epoch 2000: TotalLoss=0.589407 | Sup=0.589402 | Recon=0.004627 | TrainAcc=0.6986
# Fold 9 → Acc=0.6667 | Prec=0.0000 | Rec=0.0000 | F1=0.0000 | AUC=0.7800 | CE Loss=0.5915
#
# === Fold 10 ===
# Train Control: 49, Train Patient: 24
# Fold 10 Epoch 1: TotalLoss=0.687678 | Sup=0.687673 | Recon=0.004648 | TrainAcc=0.6712
# Fold 10 Epoch 100: TotalLoss=0.643797 | Sup=0.643792 | Recon=0.004648 | TrainAcc=0.6712
# Fold 10 Epoch 200: TotalLoss=0.635474 | Sup=0.635470 | Recon=0.004652 | TrainAcc=0.6712
# Fold 10 Epoch 300: TotalLoss=0.633702 | Sup=0.633697 | Recon=0.004653 | TrainAcc=0.6712
# Fold 10 Epoch 400: TotalLoss=0.632333 | Sup=0.632328 | Recon=0.004650 | TrainAcc=0.6712
# Fold 10 Epoch 500: TotalLoss=0.630678 | Sup=0.630673 | Recon=0.004648 | TrainAcc=0.6712
# Fold 10 Epoch 600: TotalLoss=0.628675 | Sup=0.628670 | Recon=0.004646 | TrainAcc=0.6712
# Fold 10 Epoch 700: TotalLoss=0.626285 | Sup=0.626281 | Recon=0.004643 | TrainAcc=0.6712
# Fold 10 Epoch 800: TotalLoss=0.623609 | Sup=0.623605 | Recon=0.004640 | TrainAcc=0.6712
# Fold 10 Epoch 900: TotalLoss=0.620674 | Sup=0.620670 | Recon=0.004638 | TrainAcc=0.6712
# Fold 10 Epoch 1000: TotalLoss=0.617562 | Sup=0.617557 | Recon=0.004636 | TrainAcc=0.6712
# Fold 10 Epoch 1100: TotalLoss=0.614379 | Sup=0.614375 | Recon=0.004634 | TrainAcc=0.6712
# Fold 10 Epoch 1200: TotalLoss=0.611289 | Sup=0.611285 | Recon=0.004632 | TrainAcc=0.6712
# Fold 10 Epoch 1300: TotalLoss=0.608364 | Sup=0.608360 | Recon=0.004631 | TrainAcc=0.6712
# Fold 10 Epoch 1400: TotalLoss=0.605619 | Sup=0.605614 | Recon=0.004629 | TrainAcc=0.6575
# Fold 10 Epoch 1500: TotalLoss=0.603086 | Sup=0.603081 | Recon=0.004628 | TrainAcc=0.6575
# Fold 10 Epoch 1600: TotalLoss=0.600831 | Sup=0.600826 | Recon=0.004627 | TrainAcc=0.6712
# Fold 10 Epoch 1700: TotalLoss=0.598857 | Sup=0.598852 | Recon=0.004627 | TrainAcc=0.6712
# Fold 10 Epoch 1800: TotalLoss=0.597146 | Sup=0.597141 | Recon=0.004626 | TrainAcc=0.6849
# Fold 10 Epoch 1900: TotalLoss=0.595693 | Sup=0.595688 | Recon=0.004626 | TrainAcc=0.6849
# Fold 10 Epoch 2000: TotalLoss=0.594459 | Sup=0.594454 | Recon=0.004626 | TrainAcc=0.7260
# Fold 10 → Acc=0.8000 | Prec=1.0000 | Rec=0.4000 | F1=0.5714 | AUC=0.9200 | CE Loss=0.5478
#
# === Fold 11 ===
# Train Control: 49, Train Patient: 24
# Fold 11 Epoch 1: TotalLoss=0.692303 | Sup=0.692299 | Recon=0.004629 | TrainAcc=0.6712
# Fold 11 Epoch 100: TotalLoss=0.645353 | Sup=0.645348 | Recon=0.004633 | TrainAcc=0.6712
# Fold 11 Epoch 200: TotalLoss=0.637482 | Sup=0.637478 | Recon=0.004632 | TrainAcc=0.6712
# Fold 11 Epoch 300: TotalLoss=0.635064 | Sup=0.635060 | Recon=0.004631 | TrainAcc=0.6712
# Fold 11 Epoch 400: TotalLoss=0.632329 | Sup=0.632324 | Recon=0.004633 | TrainAcc=0.6712
# Fold 11 Epoch 500: TotalLoss=0.628703 | Sup=0.628699 | Recon=0.004634 | TrainAcc=0.6712
# Fold 11 Epoch 600: TotalLoss=0.624140 | Sup=0.624135 | Recon=0.004633 | TrainAcc=0.6712
# Fold 11 Epoch 700: TotalLoss=0.618727 | Sup=0.618722 | Recon=0.004633 | TrainAcc=0.6712
# Fold 11 Epoch 800: TotalLoss=0.612595 | Sup=0.612590 | Recon=0.004632 | TrainAcc=0.6712
# Fold 11 Epoch 900: TotalLoss=0.606137 | Sup=0.606132 | Recon=0.004631 | TrainAcc=0.6712
# Fold 11 Epoch 1000: TotalLoss=0.599678 | Sup=0.599674 | Recon=0.004630 | TrainAcc=0.6849
# Fold 11 Epoch 1100: TotalLoss=0.593608 | Sup=0.593603 | Recon=0.004630 | TrainAcc=0.6986
# Fold 11 Epoch 1200: TotalLoss=0.588174 | Sup=0.588169 | Recon=0.004629 | TrainAcc=0.7123
# Fold 11 Epoch 1300: TotalLoss=0.583493 | Sup=0.583488 | Recon=0.004628 | TrainAcc=0.7123
# Fold 11 Epoch 1400: TotalLoss=0.579586 | Sup=0.579581 | Recon=0.004628 | TrainAcc=0.7260
# Fold 11 Epoch 1500: TotalLoss=0.576426 | Sup=0.576422 | Recon=0.004628 | TrainAcc=0.7397
# Fold 11 Epoch 1600: TotalLoss=0.573930 | Sup=0.573925 | Recon=0.004627 | TrainAcc=0.7260
# Fold 11 Epoch 1700: TotalLoss=0.571985 | Sup=0.571980 | Recon=0.004627 | TrainAcc=0.7260
# Fold 11 Epoch 1800: TotalLoss=0.570465 | Sup=0.570460 | Recon=0.004627 | TrainAcc=0.7260
# Fold 11 Epoch 1900: TotalLoss=0.569265 | Sup=0.569260 | Recon=0.004627 | TrainAcc=0.7123
# Fold 11 Epoch 2000: TotalLoss=0.568295 | Sup=0.568291 | Recon=0.004627 | TrainAcc=0.7260
# Fold 11 → Acc=0.7333 | Prec=0.6667 | Rec=0.4000 | F1=0.5000 | AUC=0.8200 | CE Loss=0.5745
#
# === Fold 12 ===
# Train Control: 49, Train Patient: 24
# Fold 12 Epoch 1: TotalLoss=0.694147 | Sup=0.694142 | Recon=0.004629 | TrainAcc=0.3836
# Fold 12 Epoch 100: TotalLoss=0.640024 | Sup=0.640019 | Recon=0.004624 | TrainAcc=0.6712
# Fold 12 Epoch 200: TotalLoss=0.630593 | Sup=0.630588 | Recon=0.004619 | TrainAcc=0.6712
# Fold 12 Epoch 300: TotalLoss=0.628213 | Sup=0.628208 | Recon=0.004617 | TrainAcc=0.6712
# Fold 12 Epoch 400: TotalLoss=0.625824 | Sup=0.625820 | Recon=0.004617 | TrainAcc=0.6712
# Fold 12 Epoch 500: TotalLoss=0.622652 | Sup=0.622648 | Recon=0.004618 | TrainAcc=0.6712
# Fold 12 Epoch 600: TotalLoss=0.618413 | Sup=0.618408 | Recon=0.004618 | TrainAcc=0.6712
# Fold 12 Epoch 700: TotalLoss=0.612952 | Sup=0.612948 | Recon=0.004619 | TrainAcc=0.6712
# Fold 12 Epoch 800: TotalLoss=0.606344 | Sup=0.606339 | Recon=0.004620 | TrainAcc=0.6712
# Fold 12 Epoch 900: TotalLoss=0.598980 | Sup=0.598975 | Recon=0.004621 | TrainAcc=0.6712
# Fold 12 Epoch 1000: TotalLoss=0.591181 | Sup=0.591176 | Recon=0.004622 | TrainAcc=0.6849
# Fold 12 Epoch 1100: TotalLoss=0.583450 | Sup=0.583445 | Recon=0.004623 | TrainAcc=0.7123
# Fold 12 Epoch 1200: TotalLoss=0.576169 | Sup=0.576164 | Recon=0.004624 | TrainAcc=0.7123
# Fold 12 Epoch 1300: TotalLoss=0.569636 | Sup=0.569631 | Recon=0.004625 | TrainAcc=0.7260
# Fold 12 Epoch 1400: TotalLoss=0.563954 | Sup=0.563949 | Recon=0.004625 | TrainAcc=0.7260
# Fold 12 Epoch 1500: TotalLoss=0.559080 | Sup=0.559075 | Recon=0.004625 | TrainAcc=0.7397
# Fold 12 Epoch 1600: TotalLoss=0.554943 | Sup=0.554938 | Recon=0.004625 | TrainAcc=0.7397
# Fold 12 Epoch 1700: TotalLoss=0.551470 | Sup=0.551465 | Recon=0.004624 | TrainAcc=0.7808
# Fold 12 Epoch 1800: TotalLoss=0.548570 | Sup=0.548566 | Recon=0.004624 | TrainAcc=0.8219
# Fold 12 Epoch 1900: TotalLoss=0.546136 | Sup=0.546131 | Recon=0.004623 | TrainAcc=0.7945
# Fold 12 Epoch 2000: TotalLoss=0.544035 | Sup=0.544030 | Recon=0.004623 | TrainAcc=0.7945
# Fold 12 → Acc=0.7333 | Prec=1.0000 | Rec=0.2000 | F1=0.3333 | AUC=0.8400 | CE Loss=0.5562
#
# === Fold 13 ===
# Train Control: 49, Train Patient: 24
# Fold 13 Epoch 1: TotalLoss=0.691884 | Sup=0.691879 | Recon=0.004621 | TrainAcc=0.6712
# Fold 13 Epoch 100: TotalLoss=0.639519 | Sup=0.639514 | Recon=0.004618 | TrainAcc=0.6712
# Fold 13 Epoch 200: TotalLoss=0.629237 | Sup=0.629232 | Recon=0.004613 | TrainAcc=0.6712
# Fold 13 Epoch 300: TotalLoss=0.626716 | Sup=0.626712 | Recon=0.004613 | TrainAcc=0.6712
# Fold 13 Epoch 400: TotalLoss=0.624356 | Sup=0.624351 | Recon=0.004615 | TrainAcc=0.6712
# Fold 13 Epoch 500: TotalLoss=0.621290 | Sup=0.621286 | Recon=0.004618 | TrainAcc=0.6712
# Fold 13 Epoch 600: TotalLoss=0.617362 | Sup=0.617357 | Recon=0.004621 | TrainAcc=0.6712
# Fold 13 Epoch 700: TotalLoss=0.612667 | Sup=0.612663 | Recon=0.004624 | TrainAcc=0.6712
# Fold 13 Epoch 800: TotalLoss=0.607506 | Sup=0.607501 | Recon=0.004626 | TrainAcc=0.6712
# Fold 13 Epoch 900: TotalLoss=0.602196 | Sup=0.602191 | Recon=0.004627 | TrainAcc=0.6712
# Fold 13 Epoch 1000: TotalLoss=0.596956 | Sup=0.596951 | Recon=0.004628 | TrainAcc=0.6849
# Fold 13 Epoch 1100: TotalLoss=0.592070 | Sup=0.592065 | Recon=0.004629 | TrainAcc=0.6986
# Fold 13 Epoch 1200: TotalLoss=0.587696 | Sup=0.587691 | Recon=0.004629 | TrainAcc=0.6986
# Fold 13 Epoch 1300: TotalLoss=0.583901 | Sup=0.583897 | Recon=0.004628 | TrainAcc=0.7123
# Fold 13 Epoch 1400: TotalLoss=0.580727 | Sup=0.580723 | Recon=0.004628 | TrainAcc=0.7123
# Fold 13 Epoch 1500: TotalLoss=0.578101 | Sup=0.578097 | Recon=0.004628 | TrainAcc=0.7123
# Fold 13 Epoch 1600: TotalLoss=0.575989 | Sup=0.575985 | Recon=0.004627 | TrainAcc=0.7123
# Fold 13 Epoch 1700: TotalLoss=0.574310 | Sup=0.574305 | Recon=0.004627 | TrainAcc=0.7123
# Fold 13 Epoch 1800: TotalLoss=0.572966 | Sup=0.572961 | Recon=0.004627 | TrainAcc=0.6986
# Fold 13 Epoch 1900: TotalLoss=0.571869 | Sup=0.571865 | Recon=0.004627 | TrainAcc=0.7123
# Fold 13 Epoch 2000: TotalLoss=0.570955 | Sup=0.570951 | Recon=0.004627 | TrainAcc=0.7123
# Fold 13 → Acc=0.7333 | Prec=1.0000 | Rec=0.2000 | F1=0.3333 | AUC=0.8400 | CE Loss=0.5555
#
# === Fold 14 ===
# Train Control: 49, Train Patient: 24
# Fold 14 Epoch 1: TotalLoss=0.690780 | Sup=0.690775 | Recon=0.004647 | TrainAcc=0.6712
# Fold 14 Epoch 100: TotalLoss=0.643627 | Sup=0.643623 | Recon=0.004636 | TrainAcc=0.6712
# Fold 14 Epoch 200: TotalLoss=0.634479 | Sup=0.634474 | Recon=0.004629 | TrainAcc=0.6712
# Fold 14 Epoch 300: TotalLoss=0.630954 | Sup=0.630949 | Recon=0.004626 | TrainAcc=0.6712
# Fold 14 Epoch 400: TotalLoss=0.627059 | Sup=0.627054 | Recon=0.004626 | TrainAcc=0.6712
# Fold 14 Epoch 500: TotalLoss=0.622279 | Sup=0.622275 | Recon=0.004626 | TrainAcc=0.6712
# Fold 14 Epoch 600: TotalLoss=0.616638 | Sup=0.616633 | Recon=0.004626 | TrainAcc=0.6712
# Fold 14 Epoch 700: TotalLoss=0.610332 | Sup=0.610327 | Recon=0.004626 | TrainAcc=0.6712
# Fold 14 Epoch 800: TotalLoss=0.603692 | Sup=0.603687 | Recon=0.004625 | TrainAcc=0.6712
# Fold 14 Epoch 900: TotalLoss=0.597190 | Sup=0.597186 | Recon=0.004624 | TrainAcc=0.6712
# Fold 14 Epoch 1000: TotalLoss=0.591177 | Sup=0.591173 | Recon=0.004624 | TrainAcc=0.6986
# Fold 14 Epoch 1100: TotalLoss=0.585771 | Sup=0.585766 | Recon=0.004624 | TrainAcc=0.6986
# Fold 14 Epoch 1200: TotalLoss=0.581102 | Sup=0.581097 | Recon=0.004624 | TrainAcc=0.7260
# Fold 14 Epoch 1300: TotalLoss=0.577218 | Sup=0.577214 | Recon=0.004624 | TrainAcc=0.7260
# Fold 14 Epoch 1400: TotalLoss=0.574054 | Sup=0.574049 | Recon=0.004624 | TrainAcc=0.7260
# Fold 14 Epoch 1500: TotalLoss=0.571516 | Sup=0.571511 | Recon=0.004624 | TrainAcc=0.7397
# Fold 14 Epoch 1600: TotalLoss=0.569514 | Sup=0.569510 | Recon=0.004625 | TrainAcc=0.7397
# Fold 14 Epoch 1700: TotalLoss=0.567957 | Sup=0.567953 | Recon=0.004625 | TrainAcc=0.7534
# Fold 14 Epoch 1800: TotalLoss=0.566739 | Sup=0.566734 | Recon=0.004625 | TrainAcc=0.7534
# Fold 14 Epoch 1900: TotalLoss=0.565761 | Sup=0.565756 | Recon=0.004626 | TrainAcc=0.7671
# Fold 14 Epoch 2000: TotalLoss=0.564960 | Sup=0.564956 | Recon=0.004626 | TrainAcc=0.7808
# Fold 14 → Acc=0.7333 | Prec=0.6667 | Rec=0.4000 | F1=0.5000 | AUC=0.7600 | CE Loss=0.6078
#
# === Fold 15 ===
# Train Control: 49, Train Patient: 24
# Fold 15 Epoch 1: TotalLoss=0.692506 | Sup=0.692502 | Recon=0.004622 | TrainAcc=0.6712
# Fold 15 Epoch 100: TotalLoss=0.647533 | Sup=0.647529 | Recon=0.004616 | TrainAcc=0.6712
# Fold 15 Epoch 200: TotalLoss=0.639648 | Sup=0.639644 | Recon=0.004616 | TrainAcc=0.6712
# Fold 15 Epoch 300: TotalLoss=0.637062 | Sup=0.637057 | Recon=0.004616 | TrainAcc=0.6712
# Fold 15 Epoch 400: TotalLoss=0.634404 | Sup=0.634400 | Recon=0.004615 | TrainAcc=0.6712
# Fold 15 Epoch 500: TotalLoss=0.631109 | Sup=0.631105 | Recon=0.004615 | TrainAcc=0.6712
# Fold 15 Epoch 600: TotalLoss=0.627173 | Sup=0.627169 | Recon=0.004615 | TrainAcc=0.6712
# Fold 15 Epoch 700: TotalLoss=0.622658 | Sup=0.622653 | Recon=0.004616 | TrainAcc=0.6712
# Fold 15 Epoch 800: TotalLoss=0.617907 | Sup=0.617903 | Recon=0.004618 | TrainAcc=0.6712
# Fold 15 Epoch 900: TotalLoss=0.613268 | Sup=0.613264 | Recon=0.004620 | TrainAcc=0.6712
# Fold 15 Epoch 1000: TotalLoss=0.608882 | Sup=0.608877 | Recon=0.004622 | TrainAcc=0.6712
# Fold 15 Epoch 1100: TotalLoss=0.604869 | Sup=0.604864 | Recon=0.004623 | TrainAcc=0.6712
# Fold 15 Epoch 1200: TotalLoss=0.601304 | Sup=0.601300 | Recon=0.004624 | TrainAcc=0.6712
# Fold 15 Epoch 1300: TotalLoss=0.598220 | Sup=0.598215 | Recon=0.004625 | TrainAcc=0.6849
# Fold 15 Epoch 1400: TotalLoss=0.595580 | Sup=0.595575 | Recon=0.004626 | TrainAcc=0.6849
# Fold 15 Epoch 1500: TotalLoss=0.593341 | Sup=0.593336 | Recon=0.004627 | TrainAcc=0.6849
# Fold 15 Epoch 1600: TotalLoss=0.591457 | Sup=0.591453 | Recon=0.004627 | TrainAcc=0.6986
# Fold 15 Epoch 1700: TotalLoss=0.589893 | Sup=0.589888 | Recon=0.004628 | TrainAcc=0.6986
# Fold 15 Epoch 1800: TotalLoss=0.588609 | Sup=0.588604 | Recon=0.004628 | TrainAcc=0.6849
# Fold 15 Epoch 1900: TotalLoss=0.587547 | Sup=0.587542 | Recon=0.004628 | TrainAcc=0.6986
# Fold 15 Epoch 2000: TotalLoss=0.586674 | Sup=0.586670 | Recon=0.004628 | TrainAcc=0.7123
# Fold 15 → Acc=0.6000 | Prec=0.3333 | Rec=0.2000 | F1=0.2500 | AUC=0.6400 | CE Loss=0.6099
#
# === Fold 16 ===
# Train Control: 49, Train Patient: 24
# Fold 16 Epoch 1: TotalLoss=0.691161 | Sup=0.691156 | Recon=0.004634 | TrainAcc=0.6712
# Fold 16 Epoch 100: TotalLoss=0.643861 | Sup=0.643857 | Recon=0.004631 | TrainAcc=0.6712
# Fold 16 Epoch 200: TotalLoss=0.634584 | Sup=0.634579 | Recon=0.004632 | TrainAcc=0.6712
# Fold 16 Epoch 300: TotalLoss=0.631696 | Sup=0.631691 | Recon=0.004639 | TrainAcc=0.6712
# Fold 16 Epoch 400: TotalLoss=0.628874 | Sup=0.628870 | Recon=0.004646 | TrainAcc=0.6712
# Fold 16 Epoch 500: TotalLoss=0.625319 | Sup=0.625314 | Recon=0.004651 | TrainAcc=0.6712
# Fold 16 Epoch 600: TotalLoss=0.621065 | Sup=0.621061 | Recon=0.004653 | TrainAcc=0.6712
# Fold 16 Epoch 700: TotalLoss=0.616389 | Sup=0.616385 | Recon=0.004652 | TrainAcc=0.6712
# Fold 16 Epoch 800: TotalLoss=0.611629 | Sup=0.611624 | Recon=0.004650 | TrainAcc=0.6712
# Fold 16 Epoch 900: TotalLoss=0.607055 | Sup=0.607051 | Recon=0.004646 | TrainAcc=0.6712
# Fold 16 Epoch 1000: TotalLoss=0.602889 | Sup=0.602884 | Recon=0.004642 | TrainAcc=0.6712
# Fold 16 Epoch 1100: TotalLoss=0.599184 | Sup=0.599179 | Recon=0.004638 | TrainAcc=0.6712
# Fold 16 Epoch 1200: TotalLoss=0.595906 | Sup=0.595901 | Recon=0.004635 | TrainAcc=0.6849
# Fold 16 Epoch 1300: TotalLoss=0.593059 | Sup=0.593054 | Recon=0.004632 | TrainAcc=0.6849
# Fold 16 Epoch 1400: TotalLoss=0.590600 | Sup=0.590596 | Recon=0.004630 | TrainAcc=0.7123
# Fold 16 Epoch 1500: TotalLoss=0.588494 | Sup=0.588490 | Recon=0.004628 | TrainAcc=0.7123
# Fold 16 Epoch 1600: TotalLoss=0.586682 | Sup=0.586677 | Recon=0.004626 | TrainAcc=0.7123
# Fold 16 Epoch 1700: TotalLoss=0.585149 | Sup=0.585144 | Recon=0.004625 | TrainAcc=0.7123
# Fold 16 Epoch 1800: TotalLoss=0.583858 | Sup=0.583853 | Recon=0.004624 | TrainAcc=0.7123
# Fold 16 Epoch 1900: TotalLoss=0.582749 | Sup=0.582745 | Recon=0.004624 | TrainAcc=0.7260
# Fold 16 Epoch 2000: TotalLoss=0.581795 | Sup=0.581790 | Recon=0.004623 | TrainAcc=0.7260
# Fold 16 → Acc=0.6667 | Prec=0.0000 | Rec=0.0000 | F1=0.0000 | AUC=0.7000 | CE Loss=0.6135
#
# === Fold 17 ===
# Train Control: 49, Train Patient: 24
# Fold 17 Epoch 1: TotalLoss=0.694817 | Sup=0.694812 | Recon=0.004638 | TrainAcc=0.3288
# Fold 17 Epoch 100: TotalLoss=0.651278 | Sup=0.651273 | Recon=0.004642 | TrainAcc=0.6712
# Fold 17 Epoch 200: TotalLoss=0.641943 | Sup=0.641938 | Recon=0.004637 | TrainAcc=0.6712
# Fold 17 Epoch 300: TotalLoss=0.639480 | Sup=0.639475 | Recon=0.004634 | TrainAcc=0.6712
# Fold 17 Epoch 400: TotalLoss=0.637571 | Sup=0.637567 | Recon=0.004632 | TrainAcc=0.6712
# Fold 17 Epoch 500: TotalLoss=0.635293 | Sup=0.635288 | Recon=0.004631 | TrainAcc=0.6712
# Fold 17 Epoch 600: TotalLoss=0.632481 | Sup=0.632476 | Recon=0.004631 | TrainAcc=0.6712
# Fold 17 Epoch 700: TotalLoss=0.629200 | Sup=0.629196 | Recon=0.004631 | TrainAcc=0.6712
# Fold 17 Epoch 800: TotalLoss=0.625534 | Sup=0.625530 | Recon=0.004630 | TrainAcc=0.6712
# Fold 17 Epoch 900: TotalLoss=0.621756 | Sup=0.621752 | Recon=0.004630 | TrainAcc=0.6712
# Fold 17 Epoch 1000: TotalLoss=0.618054 | Sup=0.618050 | Recon=0.004629 | TrainAcc=0.6712
# Fold 17 Epoch 1100: TotalLoss=0.614532 | Sup=0.614527 | Recon=0.004629 | TrainAcc=0.6712
# Fold 17 Epoch 1200: TotalLoss=0.611303 | Sup=0.611298 | Recon=0.004628 | TrainAcc=0.6849
# Fold 17 Epoch 1300: TotalLoss=0.608421 | Sup=0.608416 | Recon=0.004628 | TrainAcc=0.6712
# Fold 17 Epoch 1400: TotalLoss=0.605875 | Sup=0.605871 | Recon=0.004627 | TrainAcc=0.6712
# Fold 17 Epoch 1500: TotalLoss=0.603684 | Sup=0.603680 | Recon=0.004627 | TrainAcc=0.6712
# Fold 17 Epoch 1600: TotalLoss=0.601835 | Sup=0.601830 | Recon=0.004627 | TrainAcc=0.6712
# Fold 17 Epoch 1700: TotalLoss=0.600267 | Sup=0.600262 | Recon=0.004627 | TrainAcc=0.6712
# Fold 17 Epoch 1800: TotalLoss=0.598940 | Sup=0.598935 | Recon=0.004627 | TrainAcc=0.6849
# Fold 17 Epoch 1900: TotalLoss=0.597814 | Sup=0.597809 | Recon=0.004627 | TrainAcc=0.6849
# Fold 17 Epoch 2000: TotalLoss=0.596873 | Sup=0.596868 | Recon=0.004627 | TrainAcc=0.6849
# Fold 17 → Acc=0.6667 | Prec=0.0000 | Rec=0.0000 | F1=0.0000 | AUC=0.8600 | CE Loss=0.5786
#
# === Fold 18 ===
# Train Control: 49, Train Patient: 24
# Fold 18 Epoch 1: TotalLoss=0.695661 | Sup=0.695657 | Recon=0.004612 | TrainAcc=0.3288
# Fold 18 Epoch 100: TotalLoss=0.639179 | Sup=0.639174 | Recon=0.004595 | TrainAcc=0.6712
# Fold 18 Epoch 200: TotalLoss=0.629933 | Sup=0.629928 | Recon=0.004591 | TrainAcc=0.6712
# Fold 18 Epoch 300: TotalLoss=0.628437 | Sup=0.628433 | Recon=0.004596 | TrainAcc=0.6712
# Fold 18 Epoch 400: TotalLoss=0.627390 | Sup=0.627385 | Recon=0.004601 | TrainAcc=0.6712
# Fold 18 Epoch 500: TotalLoss=0.626089 | Sup=0.626084 | Recon=0.004606 | TrainAcc=0.6712
# Fold 18 Epoch 600: TotalLoss=0.624377 | Sup=0.624373 | Recon=0.004609 | TrainAcc=0.6712
# Fold 18 Epoch 700: TotalLoss=0.622118 | Sup=0.622114 | Recon=0.004613 | TrainAcc=0.6712
# Fold 18 Epoch 800: TotalLoss=0.619205 | Sup=0.619200 | Recon=0.004616 | TrainAcc=0.6712
# Fold 18 Epoch 900: TotalLoss=0.615600 | Sup=0.615596 | Recon=0.004619 | TrainAcc=0.6712
# Fold 18 Epoch 1000: TotalLoss=0.611241 | Sup=0.611236 | Recon=0.004622 | TrainAcc=0.6712
# Fold 18 Epoch 1100: TotalLoss=0.606101 | Sup=0.606096 | Recon=0.004623 | TrainAcc=0.6712
# Fold 18 Epoch 1200: TotalLoss=0.600296 | Sup=0.600291 | Recon=0.004625 | TrainAcc=0.6712
# Fold 18 Epoch 1300: TotalLoss=0.594128 | Sup=0.594123 | Recon=0.004626 | TrainAcc=0.6849
# Fold 18 Epoch 1400: TotalLoss=0.588046 | Sup=0.588042 | Recon=0.004626 | TrainAcc=0.7123
# Fold 18 Epoch 1500: TotalLoss=0.582339 | Sup=0.582334 | Recon=0.004627 | TrainAcc=0.7123
# Fold 18 Epoch 1600: TotalLoss=0.577221 | Sup=0.577216 | Recon=0.004627 | TrainAcc=0.7397
# Fold 18 Epoch 1700: TotalLoss=0.572831 | Sup=0.572826 | Recon=0.004627 | TrainAcc=0.7534
# Fold 18 Epoch 1800: TotalLoss=0.569109 | Sup=0.569104 | Recon=0.004626 | TrainAcc=0.7397
# Fold 18 Epoch 1900: TotalLoss=0.565991 | Sup=0.565987 | Recon=0.004626 | TrainAcc=0.7534
# Fold 18 Epoch 2000: TotalLoss=0.563362 | Sup=0.563358 | Recon=0.004626 | TrainAcc=0.7808
# Fold 18 → Acc=0.8000 | Prec=1.0000 | Rec=0.4000 | F1=0.5714 | AUC=0.7600 | CE Loss=0.5460
#
# === Fold 19 ===
# Train Control: 49, Train Patient: 24
# Fold 19 Epoch 1: TotalLoss=0.692072 | Sup=0.692067 | Recon=0.004641 | TrainAcc=0.6712
# Fold 19 Epoch 100: TotalLoss=0.641234 | Sup=0.641229 | Recon=0.004626 | TrainAcc=0.6712
# Fold 19 Epoch 200: TotalLoss=0.632096 | Sup=0.632091 | Recon=0.004623 | TrainAcc=0.6712
# Fold 19 Epoch 300: TotalLoss=0.628538 | Sup=0.628533 | Recon=0.004626 | TrainAcc=0.6712
# Fold 19 Epoch 400: TotalLoss=0.624472 | Sup=0.624467 | Recon=0.004629 | TrainAcc=0.6712
# Fold 19 Epoch 500: TotalLoss=0.619203 | Sup=0.619198 | Recon=0.004630 | TrainAcc=0.6712
# Fold 19 Epoch 600: TotalLoss=0.613115 | Sup=0.613111 | Recon=0.004630 | TrainAcc=0.6712
# Fold 19 Epoch 700: TotalLoss=0.606925 | Sup=0.606920 | Recon=0.004628 | TrainAcc=0.6712
# Fold 19 Epoch 800: TotalLoss=0.601205 | Sup=0.601201 | Recon=0.004627 | TrainAcc=0.6712
# Fold 19 Epoch 900: TotalLoss=0.596291 | Sup=0.596287 | Recon=0.004625 | TrainAcc=0.6712
# Fold 19 Epoch 1000: TotalLoss=0.592201 | Sup=0.592196 | Recon=0.004624 | TrainAcc=0.6712
# Fold 19 Epoch 1100: TotalLoss=0.588895 | Sup=0.588890 | Recon=0.004623 | TrainAcc=0.6712
# Fold 19 Epoch 1200: TotalLoss=0.586220 | Sup=0.586216 | Recon=0.004623 | TrainAcc=0.6712
# Fold 19 Epoch 1300: TotalLoss=0.583999 | Sup=0.583995 | Recon=0.004622 | TrainAcc=0.6849
# Fold 19 Epoch 1400: TotalLoss=0.582140 | Sup=0.582135 | Recon=0.004622 | TrainAcc=0.6849
# Fold 19 Epoch 1500: TotalLoss=0.580572 | Sup=0.580568 | Recon=0.004622 | TrainAcc=0.6986
# Fold 19 Epoch 1600: TotalLoss=0.579217 | Sup=0.579212 | Recon=0.004622 | TrainAcc=0.7123
# Fold 19 Epoch 1700: TotalLoss=0.578017 | Sup=0.578012 | Recon=0.004622 | TrainAcc=0.7123
# Fold 19 Epoch 1800: TotalLoss=0.576927 | Sup=0.576922 | Recon=0.004622 | TrainAcc=0.7123
# Fold 19 Epoch 1900: TotalLoss=0.575935 | Sup=0.575930 | Recon=0.004622 | TrainAcc=0.7123
# Fold 19 Epoch 2000: TotalLoss=0.575009 | Sup=0.575004 | Recon=0.004622 | TrainAcc=0.6986
# Fold 19 → Acc=0.6667 | Prec=0.0000 | Rec=0.0000 | F1=0.0000 | AUC=0.7200 | CE Loss=0.5969
#
# === Fold 20 ===
# Train Control: 49, Train Patient: 24
# Fold 20 Epoch 1: TotalLoss=0.692563 | Sup=0.692559 | Recon=0.004641 | TrainAcc=0.6712
# Fold 20 Epoch 100: TotalLoss=0.639887 | Sup=0.639883 | Recon=0.004668 | TrainAcc=0.6712
# Fold 20 Epoch 200: TotalLoss=0.630760 | Sup=0.630755 | Recon=0.004677 | TrainAcc=0.6712
# Fold 20 Epoch 300: TotalLoss=0.628576 | Sup=0.628571 | Recon=0.004673 | TrainAcc=0.6712
# Fold 20 Epoch 400: TotalLoss=0.626584 | Sup=0.626580 | Recon=0.004666 | TrainAcc=0.6712
# Fold 20 Epoch 500: TotalLoss=0.624187 | Sup=0.624182 | Recon=0.004659 | TrainAcc=0.6712
# Fold 20 Epoch 600: TotalLoss=0.621236 | Sup=0.621231 | Recon=0.004653 | TrainAcc=0.6712
# Fold 20 Epoch 700: TotalLoss=0.617753 | Sup=0.617748 | Recon=0.004648 | TrainAcc=0.6712
# Fold 20 Epoch 800: TotalLoss=0.613885 | Sup=0.613880 | Recon=0.004644 | TrainAcc=0.6712
# Fold 20 Epoch 900: TotalLoss=0.609683 | Sup=0.609678 | Recon=0.004641 | TrainAcc=0.6712
# Fold 20 Epoch 1000: TotalLoss=0.605264 | Sup=0.605259 | Recon=0.004639 | TrainAcc=0.6712
# Fold 20 Epoch 1100: TotalLoss=0.600808 | Sup=0.600803 | Recon=0.004636 | TrainAcc=0.6849
# Fold 20 Epoch 1200: TotalLoss=0.596504 | Sup=0.596499 | Recon=0.004635 | TrainAcc=0.6986
# Fold 20 Epoch 1300: TotalLoss=0.592410 | Sup=0.592405 | Recon=0.004633 | TrainAcc=0.7123
# Fold 20 Epoch 1400: TotalLoss=0.588624 | Sup=0.588619 | Recon=0.004632 | TrainAcc=0.7260
# Fold 20 Epoch 1500: TotalLoss=0.585223 | Sup=0.585219 | Recon=0.004631 | TrainAcc=0.7260
# Fold 20 Epoch 1600: TotalLoss=0.582254 | Sup=0.582250 | Recon=0.004631 | TrainAcc=0.7260
# Fold 20 Epoch 1700: TotalLoss=0.579719 | Sup=0.579714 | Recon=0.004630 | TrainAcc=0.7260
# Fold 20 Epoch 1800: TotalLoss=0.577564 | Sup=0.577559 | Recon=0.004629 | TrainAcc=0.7260
# Fold 20 Epoch 1900: TotalLoss=0.575700 | Sup=0.575695 | Recon=0.004628 | TrainAcc=0.7397
# Fold 20 Epoch 2000: TotalLoss=0.574089 | Sup=0.574085 | Recon=0.004627 | TrainAcc=0.7534
# Fold 20 → Acc=0.8667 | Prec=1.0000 | Rec=0.6000 | F1=0.7500 | AUC=0.9200 | CE Loss=0.4949
#
# === Average Results Across 20 Folds ===
# Accuracy:  0.7300 ± 0.0745
# Precision: 0.5800 ± 0.4196
# Recall:    0.2800 ± 0.2135
# F1-score:  0.3651 ± 0.2655
# AUC:       0.7910 ± 0.0823
# CE Loss:   0.5775 ± 0.0296
