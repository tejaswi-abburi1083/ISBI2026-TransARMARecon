# %%
import os
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as nnFn
import torch.optim as optim
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, log_loss
from torch_geometric.data import Data
from torch_geometric.nn import ARMAConv

device = 'cuda' if torch.cuda.is_available() else 'cpu'
print("Device:", device)

control_path = "/home/snu/Downloads/NIFD_Patients_FA_Histogram_Feature.npy"
patient_path = "/home/snu/Downloads/NIFD_Control_FA_Histogram_Feature.npy"

Histogram_feature_Control_FA_array = np.load(control_path, allow_pickle=True)
Histogram_feature_Patient_FA_array = np.load(patient_path, allow_pickle=True)

X = np.vstack([Histogram_feature_Control_FA_array, Histogram_feature_Patient_FA_array])
y = np.hstack([
    np.zeros(Histogram_feature_Control_FA_array.shape[0], dtype=np.int64),
    np.ones(Histogram_feature_Patient_FA_array.shape[0], dtype=np.int64)
])

num_nodes, num_feats = X.shape
print(f"Features: {X.shape}, Labels: {y.shape}")

# Shuffle for reproducibility
rng = np.random.RandomState(42)
perm = rng.permutation(num_nodes)
X = X[perm]
y = y[perm]

def create_adj(F_data, alpha=1):
    norms = np.linalg.norm(F_data, axis=1, keepdims=True)
    norms[norms == 0] = 1.0
    F_norm = F_data / norms
    W = np.dot(F_norm, F_norm.T)
    W = np.where(W >= alpha, 1.0, 0.0).astype(np.float32)
    if W.max() > 0:
        W = W / W.max()
    return W

alpha = 0.5
W = create_adj(X, alpha=alpha)
np.fill_diagonal(W, 1.0)

def load_data(adj, node_feats):
    node_feats = torch.from_numpy(node_feats).float()
    rows, cols = np.nonzero(adj > 0)
    edge_index = torch.from_numpy(np.vstack([rows, cols]).astype(np.int64))
    return Data(x=node_feats, edge_index=edge_index)

data = load_data(W, X).to(device)
print(data)

class ARMA_AE(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim, device, activ="RELU", dropout=0.25):
        super(ARMA_AE, self).__init__()
        self.device = device
        self.conv1 = ARMAConv(input_dim, hidden_dim, num_stacks=1, num_layers=1)
        self.bn1 = nn.BatchNorm1d(hidden_dim)
        self.dropout = nn.Dropout(dropout)
        self.fc = nn.Linear(hidden_dim, output_dim)

        self.decoder = nn.Sequential(
            nn.Linear(hidden_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, input_dim)
        )

        activations = {
            "SELU": nnFn.selu,
            "SiLU": nnFn.silu,
            "GELU": nnFn.gelu,
            "RELU": nnFn.relu,
            "ELU": nnFn.elu
        }
        self.act = activations.get(activ, nnFn.relu)

    def forward(self, x, edge_index):
        h = self.conv1(x, edge_index)
        h = self.bn1(h)
        h = self.act(h)
        h = self.dropout(h)
        logits = self.fc(h)
        recon = self.decoder(h)
        return logits, recon, h


feats_dim = num_feats
hidden_dim = 512
num_classes = 2
num_epochs = 2000
lr = 1e-4
weight_decay = 1e-4
batch_print_freq = 100
lambda_recon = 0.001

sss = StratifiedShuffleSplit(n_splits=20, test_size=0.3, random_state=42)
accuracies, precisions, recalls, f1_scores, aucs, ce_losses = [], [], [], [], [], []
y_all = y.copy()

for fold, (train_val_idx, test_idx_global) in enumerate(sss.split(X, y_all), start=1):
    print(f"\n=== Fold {fold} ===")
    control_idx = np.where(y_all == 0)[0]
    patient_idx = np.where(y_all == 1)[0]
    sss_class = StratifiedShuffleSplit(n_splits=20, test_size=0.3, random_state=fold)
    control_train_idx, _ = next(sss_class.split(X[control_idx], y_all[control_idx]))
    patient_train_idx, _ = next(sss_class.split(X[patient_idx], y_all[patient_idx]))
    control_train = control_idx[control_train_idx]
    patient_train = patient_idx[patient_train_idx]
    train_idx_final = np.concatenate([control_train, patient_train])
    np.random.shuffle(train_idx_final)

    print(f"Train Control: {len(control_train)}, Train Patient: {len(patient_train)}")
    train_idx_t = torch.from_numpy(train_idx_final).long().to(device)
    y_train_tensor = torch.from_numpy(y_all[train_idx_final]).long().to(device)

    model = ARMA_AE(feats_dim, hidden_dim, num_classes, device, activ="RELU", dropout=0.25).to(device)
    optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
    ce_loss_fn = nn.CrossEntropyLoss()
    recon_loss_fn = nn.MSELoss()
    data = load_data(W, X).to(device)

    for epoch in range(1, num_epochs + 1):
        model.train()
        optimizer.zero_grad()
        logits, recon_x, _ = model(data.x, data.edge_index)

        loss_sup = ce_loss_fn(logits[train_idx_t], y_train_tensor)
        loss_recon = recon_loss_fn(recon_x, data.x)
        total_loss = loss_sup + lambda_recon * loss_recon

        if torch.isnan(total_loss) or torch.isinf(total_loss):
            print(f"NaN/Inf detected at fold {fold} epoch {epoch}. Aborting epoch.")
            break

        total_loss.backward()
        optimizer.step()

        if epoch % batch_print_freq == 0 or epoch == 1:
            model.eval()
            with torch.no_grad():
                logits_eval, _, _ = model(data.x, data.edge_index)
                preds_train = logits_eval[train_idx_t].argmax(dim=1)
                acc_train = accuracy_score(y_train_tensor.cpu(), preds_train.cpu())
            print(f"Fold {fold} Epoch {epoch}: TotalLoss={total_loss.item():.6f} | Sup={loss_sup.item():.6f} | Recon={loss_recon.item():.6f} | TrainAcc={acc_train:.4f}")

    model.eval()
    with torch.no_grad():
        out_logits, _, _ = model(data.x, data.edge_index)
        preds = out_logits.argmax(dim=1).cpu().numpy()
        probs = nnFn.softmax(out_logits, dim=1)[:, 1].cpu().numpy()

    y_test = y_all[test_idx_global]
    y_pred_test = preds[test_idx_global]
    y_prob_test = probs[test_idx_global]

    acc = accuracy_score(y_test, y_pred_test)
    prec = precision_score(y_test, y_pred_test, zero_division=0)
    rec = recall_score(y_test, y_pred_test, zero_division=0)
    f1 = f1_score(y_test, y_pred_test, zero_division=0)
    try:
        auc = roc_auc_score(y_test, y_prob_test)
    except ValueError:
        auc = float('nan')
    ce = log_loss(y_test, y_prob_test)

    accuracies.append(acc)
    precisions.append(prec)
    recalls.append(rec)
    f1_scores.append(f1)
    aucs.append(auc)
    ce_losses.append(ce)

    print(f"Fold {fold} → Acc={acc:.4f} | Prec={prec:.4f} | Rec={rec:.4f} | F1={f1:.4f} | AUC={auc:.4f} | CE Loss={ce:.4f}")


print("\n=== Average Results Across 20 Folds ===")
print(f"Accuracy:  {np.mean(accuracies):.4f} ± {np.std(accuracies):.4f}")
print(f"Precision: {np.mean(precisions):.4f} ± {np.std(precisions):.4f}")
print(f"Recall:    {np.mean(recalls):.4f} ± {np.std(recalls):.4f}")
print(f"F1-score:  {np.mean(f1_scores):.4f} ± {np.std(f1_scores):.4f}")
print(f"CE Loss:   {np.mean(ce_losses):.4f} ± {np.std(ce_losses):.4f}")
print(f"AUC:       {np.nanmean(aucs):.4f} ± {np.nanstd(aucs):.4f}")
# Out:
# Device: cuda
# Features: (146, 180), Labels: (146,)
# Data(x=[146, 180], edge_index=[2, 21256])
#
# === Fold 1 ===
# Train Control: 68, Train Patient: 33
# Fold 1 Epoch 1: TotalLoss=0.839457 | Sup=0.839420 | Recon=0.037650 | TrainAcc=0.3267
# Fold 1 Epoch 100: TotalLoss=0.174284 | Sup=0.174273 | Recon=0.011044 | TrainAcc=0.9901
# Fold 1 Epoch 200: TotalLoss=0.065289 | Sup=0.065283 | Recon=0.005946 | TrainAcc=1.0000
# Fold 1 Epoch 300: TotalLoss=0.029307 | Sup=0.029303 | Recon=0.004690 | TrainAcc=1.0000
# Fold 1 Epoch 400: TotalLoss=0.015028 | Sup=0.015024 | Recon=0.004496 | TrainAcc=1.0000
# Fold 1 Epoch 500: TotalLoss=0.009284 | Sup=0.009280 | Recon=0.004542 | TrainAcc=1.0000
# Fold 1 Epoch 600: TotalLoss=0.006267 | Sup=0.006263 | Recon=0.004616 | TrainAcc=1.0000
# Fold 1 Epoch 700: TotalLoss=0.003171 | Sup=0.003166 | Recon=0.004666 | TrainAcc=1.0000
# Fold 1 Epoch 800: TotalLoss
| TrainAcc=1.0000
# Fold 7 Epoch 2000: TotalLoss=0.000105 | Sup=0.000100 | Recon=0.004694 | TrainAcc=1.0000
# Fold 7 → Acc=0.8864 | Prec=0.8000 | Rec=0.8571 | F1=0.8276 | AUC=0.9500 | CE Loss=0.4161
#
# === Fold 8 ===
# Train Control: 68, Train Patient: 33
# Fold 8 Epoch 1: TotalLoss=0.656693 | Sup=0.656656 | Recon=0.036852 | TrainAcc=0.6733
# Fold 8 Epoch 100: TotalLoss=0.162997 | Sup=0.162986 | Recon=0.011022 | TrainAcc=0.9901
# Fold 8 Epoch 200: TotalLoss=0.043729 | Sup=0.043723 | Recon=0.005801 | TrainAcc=1.0000
# Fold 8 Epoch 300: TotalLoss=0.020143 | Sup=0.020138 | Recon=0.004529 | TrainAcc=1.0000
# Fold 8 Epoch 400: TotalLoss=0.009997 | Sup=0.009993 | Recon=0.004370 | TrainAcc=1.0000
# Fold 8 Epoch 500: TotalLoss=0.005638 | Sup=0.005634 | Recon=0.004477 | TrainAcc=1.0000
# Fold 8 Epoch 600: TotalLoss=0.003423 | Sup=0.003418 | Recon=0.004581 | TrainAcc=1.0000
# Fold 8 Epoch 700: TotalLoss=0.002387 | Sup=0.002382 | Recon=0.004646 | TrainAcc=1.0000
# Fold 8 Epoch 800: TotalLoss=0.001911 | Sup=0.001906 | Recon=0.004677 | TrainAcc=1.0000
# Fold 8 Epoch 900: TotalLoss=0.001418 | Sup=0.001413 | Recon=0.004690 | TrainAcc=1.0000
# Fold 8 Epoch 1000: TotalLoss=0.000845 | Sup=0.000840 | Recon=0.004695 | TrainAcc=1.0000
# Fold 8 Epoch 1100: TotalLoss=0.000821 | Sup=0.000817 | Recon=0.004695 | TrainAcc=1.0000
# Fold 8 Epoch 1200: TotalLoss=0.000541 | Sup=0.000536 | Recon=0.004695 | TrainAcc=1.0000
# Fold 8 Epoch 1300: TotalLoss=0.000376 | Sup=0.000371 | Recon=0.004695 | TrainAcc=1.0000
# Fold 8 Epoch 1400: TotalLoss=0.000439 | Sup=0.000434 | Recon=0.004695 | TrainAcc=1.0000
# Fold 8 Epoch 1500: TotalLoss=0.000231 | Sup=0.000226 | Recon=0.004695 | TrainAcc=1.0000
# Fold 8 Epoch 1600: TotalLoss=0.000317 | Sup=0.000312 | Recon=0.004694 | TrainAcc=1.0000
# Fold 8 Epoch 1700: TotalLoss=0.000216 | Sup=0.000211 | Recon=0.004694 | TrainAcc=1.0000
# Fold 8 Epoch 1800: TotalLoss=0.000214 | Sup=0.000209 | Recon=0.004694 | TrainAcc=1.0000
# Fold 8 Epoch 1900: TotalLoss=0.000229 | Sup=0.000225 | Recon=0.004694 | TrainAcc=1.0000
# Fold 8 Epoch 2000: TotalLoss=0.000248 | Sup=0.000243 | Recon=0.004694 | TrainAcc=1.0000
# Fold 8 → Acc=0.9318 | Prec=0.8667 | Rec=0.9286 | F1=0.8966 | AUC=0.9952 | CE Loss=0.1490
#
# === Fold 9 ===
# Train Control: 68, Train Patient: 33
# Fold 9 Epoch 1: TotalLoss=1.033895 | Sup=1.033854 | Recon=0.040721 | TrainAcc=0.3267
# Fold 9 Epoch 100: TotalLoss=0.238006 | Sup=0.237994 | Recon=0.011102 | TrainAcc=0.9901
# Fold 9 Epoch 200: TotalLoss=0.083826 | Sup=0.083820 | Recon=0.006069 | TrainAcc=1.0000
# Fold 9 Epoch 300: TotalLoss=0.032774 | Sup=0.032770 | Recon=0.004735 | TrainAcc=1.0000
# Fold 9 Epoch 400: TotalLoss=0.015648 | Sup=0.015643 | Recon=0.004549 | TrainAcc=1.0000
# Fold 9 Epoch 500: TotalLoss=0.009339 | Sup=0.009334 | Recon=0.004600 | TrainAcc=1.0000
# Fold 9 Epoch 600: TotalLoss=0.006801 | Sup=0.006796 | Recon=0.004671 | TrainAcc=1.0000
# Fold 9 Epoch 700: TotalLoss=0.003986 | Sup=0.003981 | Recon=0.004706 | TrainAcc=1.0000
# Fold 9 Epoch 800: TotalLoss=0.002732 | Sup=0.002728 | Recon=0.004717 | TrainAcc=1.0000
# Fold 9 Epoch 900: TotalLoss=0.002345 | Sup=0.002340 | Recon=0.004716 | TrainAcc=1.0000
# Fold 9 Epoch 1000: TotalLoss=0.001549 | Sup=0.001544 | Recon=0.004710 | TrainAcc=1.0000
# Fold 9 Epoch 1100: TotalLoss=0.001363 | Sup=0.001358 | Recon=0.004705 | TrainAcc=1.0000
# Fold 9 Epoch 1200: TotalLoss=0.000848 | Sup=0.000843 | Recon=0.004701 | TrainAcc=1.0000
# Fold 9 Epoch 1300: TotalLoss=0.000685 | Sup=0.000680 | Recon=0.004698 | TrainAcc=1.0000
# Fold 9 Epoch 1400: TotalLoss=0.000616 | Sup=0.000611 | Recon=0.004697 | TrainAcc=1.0000
# Fold 9 Epoch 1500: TotalLoss=0.000516 | Sup=0.000512 | Recon=0.004696 | TrainAcc=1.0000
# Fold 9 Epoch 1600: TotalLoss=0.000334 | Sup=0.000330 | Recon=0.004695 | TrainAcc=1.0000
# Fold 9 Epoch 1700: TotalLoss=0.000293 | Sup=0.000289 | Recon=0.004695 | TrainAcc=1.0000
# Fold 9 Epoch 1800: TotalLoss=0.000306 | Sup=0.000301 | Recon=0.004695 | TrainAcc=1.0000
# Fold 9 Epoch 1900: TotalLoss=0.000236 | Sup=0.000231 | Recon=0.004695 | TrainAcc=1.0000
# Fold 9 Epoch 2000: TotalLoss=0.000170 | Sup=0.000166 | Recon=0.004694 | TrainAcc=1.0000
# Fold 9 → Acc=0.9545 | Prec=1.0000 | Rec=0.8571 | F1=0.9231 | AUC=0.9976 | CE Loss=0.0861
#
# === Fold 10 ===
# Train Control: 68, Train Patient: 33
# Fold 10 Epoch 1: TotalLoss=0.703776 | Sup=0.703738 | Recon=0.038006 | TrainAcc=0.6733
# Fold 10 Epoch 100: TotalLoss=0.165281 | Sup=0.165270 | Recon=0.010965 | TrainAcc=1.0000
# Fold 10 Epoch 200: TotalLoss=0.047513 | Sup=0.047507 | Recon=0.005819 | TrainAcc=1.0000
# Fold 10 Epoch 300: TotalLoss
| TrainAcc=1.0000
# Fold 20 Epoch 2000: TotalLoss=0.000203 | Sup=0.000198 | Recon=0.004694 | TrainAcc=1.0000
# Fold 20 → Acc=0.9091 | Prec=0.8571 | Rec=0.8571 | F1=0.8571 | AUC=0.9690 | CE Loss=0.3463
#
# === Average Results Across 20 Folds ===
# Accuracy:  0.9182 ± 0.0308
# Precision: 0.8905 ± 0.0565
# Recall:    0.8500 ± 0.0779
# F1-score:  0.8675 ± 0.0538
# CE Loss:   0.2037 ± 0.0929
# AUC:       0.9787 ± 0.0132

# %%
feats_dim = num_feats
hidden_dim = 512
num_classes = 2
num_epochs = 2000
lr = 1e-4
weight_decay = 1e-4
batch_print_freq = 100

# Lambda values to test
lambda_list = [0.001, 0.005, 0.009, 0.01, 0.05, 0.09, 0.1, 0.3, 0.5, 0.9, 1, 2, 5, 8]

# === Cross-validation setup ===
sss = StratifiedShuffleSplit(n_splits=20, test_size=0.3, random_state=42)
y_all = y.copy()

# To store all results for each lambda
lambda_results = []

# === Outer loop for lambda sweep ===
for lambda_recon in lambda_list:
    print(f"\n\n====================== λ_recon = {lambda_recon} ======================")

    accuracies, precisions, recalls, f1_scores, aucs, ce_losses = [], [], [], [], [], []

    for fold, (train_val_idx, test_idx_global) in enumerate(sss.split(X, y_all), start=1):
        print(f"\n=== Fold {fold} ===")

        control_idx = np.where(y_all == 0)[0]
        patient_idx = np.where(y_all == 1)[0]
        sss_class = StratifiedShuffleSplit(n_splits=20, test_size=0.3, random_state=fold)
        control_train_idx, _ = next(sss_class.split(X[control_idx], y_all[control_idx]))
        patient_train_idx, _ = next(sss_class.split(X[patient_idx], y_all[patient_idx]))
        control_train = control_idx[control_train_idx]
        patient_train = patient_idx[patient_train_idx]
        train_idx_final = np.concatenate([control_train, patient_train])
        np.random.shuffle(train_idx_final)

        print(f"Train Control: {len(control_train)}, Train Patient: {len(patient_train)}")

        train_idx_t = torch.from_numpy(train_idx_final).long().to(device)
        y_train_tensor = torch.from_numpy(y_all[train_idx_final]).long().to(device)

        model = ARMA_AE(feats_dim, hidden_dim, num_classes, device, activ="RELU", dropout=0.25).to(device)
        optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
        ce_loss_fn = nn.CrossEntropyLoss()
        recon_loss_fn = nn.MSELoss()
        data = load_data(W, X).to(device)

        for epoch in range(1, num_epochs + 1):
            model.train()
            optimizer.zero_grad()
            logits, recon_x, _ = model(data.x, data.edge_index)

            loss_sup = ce_loss_fn(logits[train_idx_t], y_train_tensor)
            loss_recon = recon_loss_fn(recon_x, data.x)
            total_loss = loss_sup + lambda_recon * loss_recon

            if torch.isnan(total_loss) or torch.isinf(total_loss):
                print(f"NaN/Inf detected at fold {fold} epoch {epoch}. Aborting epoch.")
                break

            total_loss.backward()
            optimizer.step()

            if epoch % batch_print_freq == 0 or epoch == 1:
                model.eval()
                with torch.no_grad():
                    logits_eval, _, _ = model(data.x, data.edge_index)
                    preds_train = logits_eval[train_idx_t].argmax(dim=1)
                    acc_train = accuracy_score(y_train_tensor.cpu(), preds_train.cpu())
                print(f"Fold {fold} Epoch {epoch}: TotalLoss={total_loss.item():.6f} | Sup={loss_sup.item():.6f} | Recon={loss_recon.item():.6f} | TrainAcc={acc_train:.4f}")

        # === Evaluation ===
        model.eval()
        with torch.no_grad():
            out_logits, _, _ = model(data.x, data.edge_index)
            preds = out_logits.argmax(dim=1).cpu().numpy()
            probs = nnFn.softmax(out_logits, dim=1)[:, 1].cpu().numpy()

        y_test = y_all[test_idx_global]
        y_pred_test = preds[test_idx_global]
        y_prob_test = probs[test_idx_global]

        acc = accuracy_score(y_test, y_pred_test)
        prec = precision_score(y_test, y_pred_test, zero_division=0)
        rec = recall_score(y_test, y_pred_test, zero_division=0)
        f1 = f1_score(y_test, y_pred_test, zero_division=0)
        try:
            auc = roc_auc_score(y_test, y_prob_test)
        except ValueError:
            auc = float('nan')
        ce = log_loss(y_test, y_prob_test)

        accuracies.append(acc)
        precisions.append(prec)
        recalls.append(rec)
        f1_scores.append(f1)
        aucs.append(auc)
        ce_losses.append(ce)

        print(f"Fold {fold} → Acc={acc:.4f} | Prec={prec:.4f} | Rec={rec:.4f} | F1={f1:.4f} | AUC={auc:.4f} | CE Loss={ce:.4f}")

    # === Store average results for this λ ===
    avg_results = {
        "lambda": lambda_recon,
        "Accuracy": np.mean(accuracies),
        "Precision": np.mean(precisions),
        "Recall": np.mean(recalls),
        "F1-score": np.mean(f1_scores),
        "CE Loss": np.mean(ce_losses),
        "AUC": np.nanmean(aucs)
    }
    lambda_results.append(avg_results)

    print("\n=== Average Results for λ =", lambda_recon, "===")
    print(f"Accuracy:  {avg_results['Accuracy']:.4f}")
    print(f"Precision: {avg_results['Precision']:.4f}")
    print(f"Recall:    {avg_results['Recall']:.4f}")
    print(f"F1-score:  {avg_results['F1-score']:.4f}")
    print(f"CE Loss:   {avg_results['CE Loss']:.4f}")
    print(f"AUC:       {avg_results['AUC']:.4f}")


# === FINAL SUMMARY ACROSS ALL λ ===
print("\n\n====================== FINAL SUMMARY ACROSS ALL λ ======================")
print(f"{'Lambda':<8} | {'Accuracy':<9} | {'Precision':<9} | {'Recall':<8} | {'F1-score':<9} | {'AUC':<8} | {'CE Loss':<8}")
print("-" * 72)
for res in lambda_results:
    print(f"{res['lambda']:<8} | {res['Accuracy']:<9.4f} | {res['Precision']:<9.4f} | {res['Recall']:<8.4f} | {res['F1-score']:<9.4f} | {res['AUC']:<8.4f} | {res['CE Loss']:<8.4f}")
# Out:
# Streaming output truncated to the last 5000 lines.
# === Fold 6 ===
# Train Control: 68, Train Patient: 33
# Fold 6 Epoch 1: TotalLoss=0.692956 | Sup=0.690881 | Recon=0.041494 | TrainAcc=0.4059
# Fold 6 Epoch 100: TotalLoss=0.163174 | Sup=0.162966 | Recon=0.004157 | TrainAcc=0.9901
# Fold 6 Epoch 200: TotalLoss=0.044674 | Sup=0.044581 | Recon=0.001848 | TrainAcc=1.0000
# Fold 6 Epoch 300: TotalLoss=0.021561 | Sup=0.021510 | Recon=0.001008 | TrainAcc=1.0000
# Fold 6 Epoch 400: TotalLoss=0.010928 | Sup=0.010896 | Recon=0.000657 | TrainAcc=1.0000
# Fold 6 Epoch 500: TotalLoss=0.005491 | Sup=0.005463 | Recon=0.000560 | TrainAcc=1.0000
# Fold 6 Epoch 600: TotalLoss=0.003514 | Sup=0.003486 | Recon=0.000558 | TrainAcc=1.0000
# Fold 6 Epoch 700: TotalLoss=0.002793 | Sup=0.002764 | Recon=0.000579 | TrainAcc=1.0000
# Fold 6 Epoch 800: TotalLoss=0.001575 | Sup=0.001545 | Recon=0.000603 | TrainAcc=1.0000
# Fold 6 Epoch 900: TotalLoss=0.001344 | Sup=0.001314 | Recon=0.000615 | TrainAcc=1.0000
# Fold 6 Epoch 1000: TotalLoss=0.000931 | Sup=0.000899 | Recon=0.000645 | TrainAcc=1.0000
# Fold 6 Epoch 1100: TotalLoss=0.000580 | Sup=0.000547 | Recon=0.000657 | TrainAcc=1.0000
# Fold 6 Epoch 1200: TotalLoss=0.000467 | Sup=0.000434 | Recon=0.000652 | TrainAcc=1.0000
# Fold 6 Epoch 1300: TotalLoss=0.000428 | Sup=0.000394 | Recon=0.000663 | TrainAcc=1.0000
# Fold 6 Epoch 1400: TotalLoss=0.000269 | Sup=0.000236 | Recon=0.000654 | TrainAcc=1.0000
# Fold 6 Epoch 1500: TotalLoss=0.000259 | Sup=0.000226 | Recon=0.000668 | TrainAcc=1.0000
# Fold 6 Epoch 1600: TotalLoss=0.000184 | Sup=0.000150 | Recon=0.000669 | TrainAcc=1.0000
# Fold 6 Epoch 1700: TotalLoss=0.000158 | Sup=0.000125 | Recon=0.000671 | TrainAcc=1.0000
# Fold 6 Epoch 1800: TotalLoss=0.000193 | Sup=0.000159 | Recon=0.000673 | TrainAcc=1.0000
# Fold 6 Epoch 1900: TotalLoss=0.000134 | Sup=0.000101 | Recon=0.000672 | TrainAcc=1.0000
# Fold 6 Epoch 2000: TotalLoss=0.000142 | Sup=0.000109 | Recon=0.000670 | TrainAcc=1.0000
# Fold 6 → Acc=0.9318 | Prec=0.9231 | Rec=0.8571 | F1=0.8889 | AUC=0.9929 | CE Loss=0.1507
#
# === Fold 7 ===
# Train Control: 68, Train Patient: 33
# Fold 7 Epoch 1: TotalLoss=0.681162 | Sup=0.679282 | Recon=0.037614 | TrainAcc=0.6733
# Fold 7 Epoch 100: TotalLoss=0.172844 | Sup=0.172643 | Recon=0.004028 | TrainAcc=0.9802
# Fold 7 Epoch 200: TotalLoss=0.052900 | Sup=0.052812 | Recon=0.001760 | TrainAcc=1.0000
# Fold 7 Epoch 300: TotalLoss=0.022726 | Sup=0.022679 | Recon=0.000945 | TrainAcc=1.0000
# Fold 7 Epoch 400: TotalLoss=0.013744 | Sup=0.013711 | Recon=0.000647 | TrainAcc=1.0000
# Fold 7 Epoch 500: TotalLoss=0.007846 | Sup=0.007818 | Recon=0.000566 | TrainAcc=1.0000
# Fold 7 Epoch 600: TotalLoss=0.003614 | Sup=0.003586 | Recon=0.000563 | TrainAcc=1.0000
# Fold 7 Epoch 700: TotalLoss=0.002686 | Sup=0.002657 | Recon=0.000584 | TrainAcc=1.0000
# Fold 7 Epoch 800: TotalLoss=0.001768 | Sup=0.001738 | Recon=0.000602 | TrainAcc=1.0000
# Fold 7 Epoch 900: TotalLoss=0.001211 | Sup=0.001181 | Recon=0.000618 | TrainAcc=1.0000
# Fold 7 Epoch 1000: TotalLoss=0.001049 | Sup=0.001017 | Recon=0.000642 | TrainAcc=1.0000
# Fold 7 Epoch 1100: TotalLoss=0.000882 | Sup=0.000849 | Recon=0.000652 | TrainAcc=1.0000
# Fold 7 Epoch 1200: TotalLoss=0.000672 | Sup=0.000639 | Recon=0.000659 | TrainAcc=1.0000
# Fold 7 Epoch 1300: TotalLoss=0.000455 | Sup=0.000422 | Recon=0.000666 | TrainAcc=1.0000
# Fold 7 Epoch 1400: TotalLoss=0.000449 | Sup=0.000416 | Recon=0.000659 | TrainAcc=1.0000
# Fold 7 Epoch 1500: TotalLoss=0.000287 | Sup=0.000253 | Recon=0.000670 | TrainAcc=1.0000
# Fold 7 Epoch 1600: TotalLoss=0.000299 | Sup=0.000265 | Recon=0.000673 | TrainAcc=1.0000
# Fold 7 Epoch 1700: TotalLoss=0.000215 | Sup=0.000181 | Recon=0.000671 | TrainAcc=1.0000
# Fold 7 Epoch 1800: TotalLoss=0.000207 | Sup=0.000174 | Recon=0.000676 | TrainAcc=1.0000
# Fold 7 Epoch 1900: TotalLoss=0.000217 | Sup=0.000183 | Recon=0.000676 | TrainAcc=1.0000
# Fold 7 Epoch 2000: TotalLoss=0.000167 | Sup=0.000132 | Recon=0.000683 | TrainAcc=1.0000
# Fold 7 → Acc=0.8409 | Prec=0.7333 | Rec=0.7857 | F1=0.7586 | AUC=0.9524 | CE Loss=0.4151
#
# === Fold 8 ===
# Train Control: 68, Train Patient: 33
# Fold 8 Epoch 1: TotalLoss=0.658795 | Sup=0.656819 | Recon=0.039533 | TrainAcc=0.5545
# Fold 8 Epoch 100: TotalLoss=0.161922 | Sup=0.161719 | Recon=0.004070 | TrainAcc=0.9901
# Fold 8 Epoch 200: TotalLoss=0.048670 | Sup=0.048579 | Recon=0.001816 | TrainAcc=1.0000
# Fold 8 Epoch 300: TotalLoss=0
| TrainAcc=1.0000
# Fold 16 Epoch 1800: TotalLoss=0.000190 | Sup=0.000157 | Recon=0.000660 | TrainAcc=1.0000
# Fold 16 Epoch 1900: TotalLoss=0.000224 | Sup=0.000191 | Recon=0.000663 | TrainAcc=1.0000
# Fold 16 Epoch 2000: TotalLoss=0.000143 | Sup=0.000110 | Recon=0.000661 | TrainAcc=1.0000
# Fold 16 → Acc=0.9318 | Prec=1.0000 | Rec=0.7857 | F1=0.8800 | AUC=0.9833 | CE Loss=0.1781
#
# === Fold 17 ===
# Train Control: 68, Train Patient: 33
# Fold 17 Epoch 1: TotalLoss=0.634348 | Sup=0.632358 | Recon=0.039793 | TrainAcc=0.6634
# Fold 17 Epoch 100: TotalLoss=0.169585 | Sup=0.169388 | Recon=0.003946 | TrainAcc=1.0000
# Fold 17 Epoch 200: TotalLoss=0.043562 | Sup=0.043472 | Recon=0.001805 | TrainAcc=1.0000
# Fold 17 Epoch 300: TotalLoss=0.018617 | Sup=0.018569 | Recon=0.000963 | TrainAcc=1.0000
# Fold 17 Epoch 400: TotalLoss=0.009878 | Sup=0.009844 | Recon=0.000682 | TrainAcc=1.0000
# Fold 17 Epoch 500: TotalLoss=0.006864 | Sup=0.006835 | Recon=0.000582 | TrainAcc=1.0000
# Fold 17 Epoch 600: TotalLoss=0.004190 | Sup=0.004161 | Recon=0.000575 | TrainAcc=1.0000
# Fold 17 Epoch 700: TotalLoss=0.003286 | Sup=0.003256 | Recon=0.000602 | TrainAcc=1.0000
# Fold 17 Epoch 800: TotalLoss=0.002076 | Sup=0.002045 | Recon=0.000614 | TrainAcc=1.0000
# Fold 17 Epoch 900: TotalLoss=0.001568 | Sup=0.001536 | Recon=0.000647 | TrainAcc=1.0000
# Fold 17 Epoch 1000: TotalLoss=0.001030 | Sup=0.000997 | Recon=0.000659 | TrainAcc=1.0000
# Fold 17 Epoch 1100: TotalLoss=0.000750 | Sup=0.000717 | Recon=0.000666 | TrainAcc=1.0000
# Fold 17 Epoch 1200: TotalLoss=0.000539 | Sup=0.000505 | Recon=0.000672 | TrainAcc=1.0000
# Fold 17 Epoch 1300: TotalLoss=0.000379 | Sup=0.000345 | Recon=0.000673 | TrainAcc=1.0000
# Fold 17 Epoch 1400: TotalLoss=0.000259 | Sup=0.000225 | Recon=0.000669 | TrainAcc=1.0000
# Fold 17 Epoch 1500: TotalLoss=0.000241 | Sup=0.000207 | Recon=0.000675 | TrainAcc=1.0000
# Fold 17 Epoch 1600: TotalLoss=0.000218 | Sup=0.000184 | Recon=0.000679 | TrainAcc=1.0000
# Fold 17 Epoch 1700: TotalLoss=0.000188 | Sup=0.000154 | Recon=0.000681 | TrainAcc=1.0000
# Fold 17 Epoch 1800: TotalLoss=0.000150 | Sup=0.000116 | Recon=0.000676 | TrainAcc=1.0000
# Fold 17 Epoch 1900: TotalLoss=0.000197 | Sup=0.000163 | Recon=0.000682 | TrainAcc=1.0000
# Fold 17 Epoch 2000: TotalLoss=0.000143 | Sup=0.000109 | Recon=0.000675 | TrainAcc=1.0000
# Fold 17 → Acc=0.9545 | Prec=1.0000 | Rec=0.8571 | F1=0.9231 | AUC=0.9881 | CE Loss=0.1137
#
# === Fold 18 ===
# Train Control: 68, Train Patient: 33
# Fold 18 Epoch 1: TotalLoss=0.736248 | Sup=0.734161 | Recon=0.041752 | TrainAcc=0.4851
# Fold 18 Epoch 100: TotalLoss=0.168321 | Sup=0.168108 | Recon=0.004261 | TrainAcc=1.0000
# Fold 18 Epoch 200: TotalLoss=0.048893 | Sup=0.048800 | Recon=0.001851 | TrainAcc=1.0000
# Fold 18 Epoch 300: TotalLoss=0.017579 | Sup=0.017529 | Recon=0.000994 | TrainAcc=1.0000
# Fold 18 Epoch 400: TotalLoss=0.009688 | Sup=0.009655 | Recon=0.000656 | TrainAcc=1.0000
# Fold 18 Epoch 500: TotalLoss=0.006345 | Sup=0.006317 | Recon=0.000568 | TrainAcc=1.0000
# Fold 18 Epoch 600: TotalLoss=0.004451 | Sup=0.004423 | Recon=0.000560 | TrainAcc=1.0000
# Fold 18 Epoch 700: TotalLoss=0.002429 | Sup=0.002400 | Recon=0.000571 | TrainAcc=1.0000
# Fold 18 Epoch 800: TotalLoss=0.001775 | Sup=0.001745 | Recon=0.000599 | TrainAcc=1.0000
# Fold 18 Epoch 900: TotalLoss=0.001570 | Sup=0.001539 | Recon=0.000621 | TrainAcc=1.0000
# Fold 18 Epoch 1000: TotalLoss=0.000971 | Sup=0.000939 | Recon=0.000629 | TrainAcc=1.0000
# Fold 18 Epoch 1100: TotalLoss=0.000782 | Sup=0.000750 | Recon=0.000642 | TrainAcc=1.0000
# Fold 18 Epoch 1200: TotalLoss=0.000612 | Sup=0.000580 | Recon=0.000650 | TrainAcc=1.0000
# Fold 18 Epoch 1300: TotalLoss=0.000378 | Sup=0.000346 | Recon=0.000645 | TrainAcc=1.0000
# Fold 18 Epoch 1400: TotalLoss=0.000313 | Sup=0.000280 | Recon=0.000665 | TrainAcc=1.0000
# Fold 18 Epoch 1500: TotalLoss=0.000258 | Sup=0.000225 | Recon=0.000660 | TrainAcc=1.0000
# Fold 18 Epoch 1600: TotalLoss=0.000213 | Sup=0.000180 | Recon=0.000662 | TrainAcc=1.0000
# Fold 18 Epoch 1700: TotalLoss=0.000180 | Sup=0.000147 | Recon=0.000664 | TrainAcc=1.0000
# Fold 18 Epoch 1800: TotalLoss=0.000165 | Sup=0.000132 | Recon=0.000671 | TrainAcc=1.0000
# Fold 18 Epoch 1900: TotalLoss=0.000147 | Sup=0.000113 | Recon=0.000675 | TrainAcc=1.0000
# Fold 18 Epoch 2000: TotalLoss=0.000120 | Sup=0.000086 | Recon=0.000674 | TrainAcc=1.0000
# Fold 18 → Acc=0.9318 | Prec=0.8667 | Rec=0.9286 | F1=0.8966 | AUC=0.9905 | CE Loss=0.2689
#
# === Fold 19 ===
# Train Control: 68, Train Patient: 33
# Fold 19 Epoch 1: TotalLoss=0.843642 | Sup=0.841751 | Recon=0.037820 | TrainAcc=0.2970
# Fold 19 Epoch 100: TotalLoss=0.199859 | Sup=0.199666 | Recon=0.003864 | TrainAcc=0.9901
# Fold 19 Epoch 200: TotalLoss=0.064108 | Sup=0.064019 | Recon=0.001777 | TrainAcc=1.0000
# Fold 19 Epoch 300: TotalLoss=0.022352 | Sup=0.022306 | Recon=0.000933 | TrainAcc=1.0000
# Fold 19 Epoch 400: TotalLoss=0.012655 | Sup=0.012623 | Recon=0.000649 | TrainAcc=1.0000
# Fold 19 Epoch 500: TotalLoss=0.007574 | Sup=0.007546 | Recon=0.000565 | TrainAcc=1.0000
# Fold 19 Epoch 600: TotalLoss=0.003875 | Sup=0.003847 | Recon=0.000562 | TrainAcc=1.0000
# Fold 19 Epoch 700: TotalLoss=0.002512 | Sup=0.002483 | Recon=0.000577 | TrainAcc=1.0000
# Fold 19 Epoch 800: TotalLoss=0.001834 | Sup=0.001804 | Recon=0.000603 | TrainAcc=1.0000
# Fold 19 Epoch 900: TotalLoss=0.001486 | Sup=0.001455 | Recon=0.000622 | TrainAcc=1.0000
# Fold 19 Epoch 1000: TotalLoss=0.001143 | Sup=0.001111 | Recon=0.000633 | TrainAcc=1.0000
# Fold 19 Epoch 1100: TotalLoss=0.000780 | Sup=0.000748 | Recon=0.000640 | TrainAcc=1.0000
# Fold 19 Epoch 1200: TotalLoss=0.000644 | Sup=0.000612 | Recon=0.000648 | TrainAcc=1.0000
# Fold 19 Epoch 1300: TotalLoss=0.000623 | Sup=0.000590 | Recon=0.000657 | TrainAcc=1.0000
# Fold 19 Epoch 1400: TotalLoss=0.000529 | Sup=0.000496 | Recon=0.000660 | TrainAcc=1.0000
# Fold 19 Epoch 1500: TotalLoss=0.000397 | Sup=0.000364 | Recon=0.000658 | TrainAcc=1.0000
# Fold 19 Epoch 1600: TotalLoss=0.000326 | Sup=0.000293 | Recon=0.000658 | TrainAcc=1.0000
# Fold 19 Epoch 1700: TotalLoss=0.000257 | Sup=0.000224 | Recon=0.000659 | TrainAcc=1.0000
# Fold 19 Epoch 1800: TotalLoss=0.000254 | Sup=0.000221 | Recon=0.000669 | TrainAcc=1.0000
# Fold 19 Epoch 1900: TotalLoss=0.000197 | Sup=0.000164 | Recon=0.000666 | TrainAcc=1.0000
# Fold 19 Epoch 2000: TotalLoss=0.000210 | Sup=0.000177 | Recon=0.000662 | TrainAcc=1.0000
# Fold 19 → Acc=0.8636 | Prec=0.8333 | Rec=0.7143 | F1=0.7692 | AUC=0.9381 | CE Loss=0.2944
#
# === Fold 20 ===
# Train Control: 68, Train Patient: 33
# Fold 20 Epoch 1: TotalLoss=0.930992 | Sup=0.929115 | Recon=0.037535 | TrainAcc=0.4653
# Fold 20 Epoch 100: TotalLoss=0.197599 | Sup=0.197409 | Recon=0.003793 | TrainAcc=0.9901
# Fold 20 Epoch 200: TotalLoss=0.081731 | Sup=0.081646 | Recon=0.001701 | TrainAcc=1.0000
# Fold 20 Epoch 300: TotalLoss=0.033953 | Sup=0.033905 | Recon=0.000955 | TrainAcc=1.0000
# Fold 20 Epoch 400: TotalLoss=0.015640 | Sup=0.015607 | Recon=0.000649 | TrainAcc=1.0000
# Fold 20 Epoch 500: TotalLoss=0.010424 | Sup=0.010395 | Recon=0.000579 | TrainAcc=1.0000
# Fold 20 Epoch 600: TotalLoss=0.006167 | Sup=0.006139 | Recon=0.000568 | TrainAcc=1.0000
# Fold 20 Epoch 700: TotalLoss=0.004765 | Sup=0.004735 | Recon=0.000593 | TrainAcc=1.0000
# Fold 20 Epoch 800: TotalLoss=0.003141 | Sup=0.003111 | Recon=0.000611 | TrainAcc=1.0000
# Fold 20 Epoch 900: TotalLoss=0.002344 | Sup=0.002312 | Recon=0.000631 | TrainAcc=1.0000
# Fold 20 Epoch 1000: TotalLoss=0.001580 | Sup=0.001548 | Recon=0.000642 | TrainAcc=1.0000
# Fold 20 Epoch 1100: TotalLoss=0.001176 | Sup=0.001143 | Recon=0.000647 | TrainAcc=1.0000
# Fold 20 Epoch 1200: TotalLoss=0.000912 | Sup=0.000880 | Recon=0.000652 | TrainAcc=1.0000
# Fold 20 Epoch 1300: TotalLoss=0.000753 | Sup=0.000720 | Recon=0.000659 | TrainAcc=1.0000
# Fold 20 Epoch 1400: TotalLoss=0.000586 | Sup=0.000553 | Recon=0.000666 | TrainAcc=1.0000
# Fold 20 Epoch 1500: TotalLoss=0.000610 | Sup=0.000577 | Recon=0.000670 | TrainAcc=1.0000
# Fold 20 Epoch 1600: TotalLoss=0.000494 | Sup=0.000461 | Recon=0.000663 | TrainAcc=1.0000
# Fold 20 Epoch 1700: TotalLoss=0.000355 | Sup=0.000322 | Recon=0.000666 | TrainAcc=1.0000
# Fold 20 Epoch 1800: TotalLoss=0.000267 | Sup=0.000233 | Recon=0.000668 | TrainAcc=1.0000
# Fold 20 Epoch 1900: TotalLoss=0.000313 | Sup=0.000279 | Recon=0.000669 | TrainAcc=1.0000
# Fold 20 Epoch 2000: TotalLoss=0.000219 | Sup=0.000185 | Recon=0.000671 | TrainAcc=1.0000
# Fold 20 → Acc=0.9091 | Prec=0.8571 | Rec=0.8571 | F1=0.8571 | AUC=0.9690 | CE Loss=0.3496
#
# === Average Results for λ = 0.05 ===
# Accuracy:  0.9182
# Precision: 0.9007
# Recall:    0.8393
# F1-score:  0.8665
# CE Loss:   0.1983
# AUC:       0.9808
#
#
# ====================== λ_recon = 0.09 ======================
#
# === Fold 1 ===
# Train Control: 68, Train Patient: 33
# Fold 1 Epoch 1: TotalLoss=0.720912 | Sup=0.717476 | Recon=0.038173 | TrainAcc=0.3465
# Fold 1 Epoch 100: TotalLoss=0.173256 | Sup=0.172935 | Recon=0.003564 | TrainAcc=1.0000
# Fold 1 Epoch 200: TotalLoss=0.056632 | Sup=0.056483 | Recon=0.001657 | TrainAcc=1.0000
# Fold 1 Epoch 300: TotalLoss=0.025317 | Sup=0.025235 | Recon=0.000915 | TrainAcc=1.0000
# Fold 1 Epoch 400: TotalLoss=0.011217 | Sup=0.011162 | Recon=0.000611 | TrainAcc=1.0000
# Fold 1 Epoch 500: TotalLoss=0.006320 | Sup=0.006277 | Recon=0.000474 | TrainAcc=1.0000
# Fold 1 Epoch 600: TotalLoss=0.004273 | Sup=0.004234 | Recon=0.000439 | TrainAcc=1.0000
# Fold 1 Epoch 700: TotalLoss=0.002740 | Sup=0.002699 | Recon=0.000448 | TrainAcc=1.0000
# Fold 1 Epoch 800: TotalLoss=0.001647 | Sup=0.001607 | Recon=0.000450 | TrainAcc=1.0000
# Fold 1 Epoch 900: TotalLoss=0.001091 | Sup=0.001048 | Recon=0.000469 | TrainAcc=1.0000
# Fold 1 Epoch 1000: TotalLoss=0.000897 | Sup=0.000852 | Recon=0.000493 | TrainAcc=1.0000
# Fold 1 Epoch 1100: TotalLoss=0.000816 | Sup=0.000771 | Recon=0.000497 | TrainAcc=1.0000
# Fold 1 Epoch 1200: TotalLoss=0.000849 | Sup=0.000804 | Recon=0.000504 | TrainAcc=1.0000
# Fold 1 Epoch 1300: TotalLoss=0.000578 | Sup=0.000531 | Recon=0.000517 | TrainAcc=1.0000
# Fold 1 Epoch 1400: TotalLoss=0.000351 | Sup=0.000303 | Recon=0.000524 | TrainAcc=1.0000
# Fold 1 Epoch 1500: TotalLoss=0.000343 | Sup=0.000295 | Recon=0.000527 | TrainAcc=1.0000
# Fold 1 Epoch 1600: TotalLoss=0.000328 | Sup=0.000281 | Recon=0.000525 | TrainAcc=1.0000
# Fold 1 Epoch 1700: TotalLoss=0.000273 | Sup=0.000225 | Recon=0.000527 | TrainAcc=1.0000
# Fold 1 Epoch 1800: TotalLoss=0.000245 | Sup=0.000197 | Recon=0.000532 | TrainAcc=1.0000
# Fold 1 Epoch 1900: TotalLoss=0.000254 | Sup=0.000205 | Recon=0.000539 | TrainAcc=1.0000
# Fold 1 Epoch 2000: TotalLoss=0.000197 | Sup=0.000149 | Recon=0.000537 | TrainAcc=1.0000
# Fold 1 → Acc=0.8409 | Prec=0.8182 | Rec=0.6429 | F1=0.7200 | AUC=0.9667 | CE Loss=0.3896
#
# === Fold 2 ===
# Train Control: 68, Train Patient: 33
# Fold 2 Epoch 1: TotalLoss=0.780577 | Sup=0.777180 | Recon=0.037745 | TrainAcc=0.5842
# Fold 2 Epoch 100: TotalLoss=0.152864 | Sup=0.152548 | Recon=0.003502 | TrainAcc=1.0000
# Fold 2 Epoch 200: TotalLoss=0.052339 | Sup=0.052191 | Recon=0.001641 | TrainAcc=1.0000
# Fold 2 Epoch 300: TotalLoss=0.019066 | Sup=0.018984 | Recon=0.000921 | TrainAcc=1.0000
# Fold 2 Epoch 400: TotalLoss=0.010622 | Sup=0.010568 | Recon=0.000605 | TrainAcc=1.0000
# Fold 2 Epoch 500: TotalLoss=0.005992 | Sup=0.005951 | Recon=0.000460 | TrainAcc=1.0000
# Fold 2 Epoch 600: TotalLoss=0.003748 | Sup=0.003708 | Recon=0.000447 | TrainAcc=1.0000
# Fold 2 Epoch 700: TotalLoss=0.002420 | Sup=0.002380 | Recon=0.000441 | TrainAcc=1.0000
# Fold 2 Epoch 800: TotalLoss=0.001803 | Sup=0.001762 | Recon=0.000461 | TrainAcc=1.0000
# Fold 2 Epoch 900: TotalLoss=0.001373 | Sup=0.001329 | Recon=0.000484 | TrainAcc=1.0000
# Fold 2 Epoch 1000: TotalLoss=0.001250 | Sup=0.001206 | Recon=0.000491 | TrainAcc=1.0000
# Fold 2 Epoch 1100: TotalLoss=0.000877 | Sup=0.000832 | Recon=0.000502 | TrainAcc=1.0000
# Fold 2 Epoch 1200: TotalLoss=0.001038 | Sup=0.000991 | Recon=0.000520 | TrainAcc=1.0000
# Fold 2 Epoch 1300: TotalLoss=0.000658 | Sup=0.000611 | Recon=0.000523 | TrainAcc=1.0000
# Fold 2 Epoch 1400: TotalLoss=0.000487 | Sup=0.000440 | Recon=0.000523 | TrainAcc=1.0000
# Fold 2 Epoch 1500: TotalLoss=0.000454 | Sup=0.000407 | Recon=0.000531 | TrainAcc=1.0000
# Fold 2 Epoch 1600: TotalLoss=0.000417 | Sup=0.000368 | Recon=0.000538 | TrainAcc=1.0000
# Fold 2 Epoch 1700: TotalLoss=0.000331 | Sup=0.000282 | Recon=0.000536 | TrainAcc=1.0000
# Fold 2 Epoch 1800: TotalLoss=0.000301 | Sup=0.000252 | Recon=0.000544 | TrainAcc=1.0000
# Fold 2 Epoch 1900: TotalLoss=0.000282 | Sup=0.000233 | Recon=0.000539 | TrainAcc=1.0000
# Fold 2 Epoch 2000: TotalLoss=0.000209 | Sup=0.000161 | Recon=0.000543 | TrainAcc=1.0000
# Fold 2 → Acc=0.9091 | Prec=0.8571 | Rec=0.8571 | F1=0.8571 | AUC=0.9833 | CE Loss=0.1461
#
# === Fold 3 ===
# Train Control: 68, Train Patient: 33
# Fold 3 Epoch 1: TotalLoss=0.807584 | Sup=0.804263 | Recon=0.036898 | TrainAcc=0.3366
# Fold 3 Epoch 100: TotalLoss=0.168566 | Sup=0.168240 | Recon=0.003625 | TrainAcc=1.0000
# Fold 3 Epoch 200: TotalLoss=0.055845 | Sup=0.055696 | Recon=0.001661 | TrainAcc=1.0000
# Fold 3 Epoch 300: TotalLoss=0.023601 | Sup=0.023518 | Recon=0.000918 | TrainAcc=1.0000
# Fold 3 Epoch 400: TotalLoss=0.014192 | Sup=0.014137 | Recon=0.000613 | TrainAcc=1.0000
# Fold 3 Epoch 500: TotalLoss=0.008003 | Sup=0.007961 | Recon=0.000471 | TrainAcc=1.0000
# Fold 3 Epoch 600: TotalLoss=0.005100 | Sup=0.005059 | Recon=0.000454 | TrainAcc=1.0000
# Fold 3 Epoch 700: TotalLoss=0.003648 | Sup=0.003609 | Recon=0.000439 | TrainAcc=1.0000
# Fold 3 Epoch 800: TotalLoss=0.002360 | Sup=0.002319 | Recon=0.000457 | TrainAcc=1.0000
# Fold 3 Epoch 900: TotalLoss=0.001373 | Sup=0.001329 | Recon=0.000480 | TrainAcc=1.0000
# Fold 3 Epoch 1000: TotalLoss=0.001100 | Sup=0.001056 | Recon=0.000490 | TrainAcc=1.0000
# Fold 3 Epoch 1100: TotalLoss=0.000914 | Sup=0.000868 | Recon=0.000503 | TrainAcc=1.0000
# Fold 3 Epoch 1200: TotalLoss=0.000537 | Sup=0.000490 | Recon=0.000513 | TrainAcc=1.0000
# Fold 3 Epoch 1300: TotalLoss=0.000617 | Sup=0.000570 | Recon=0.000525 | TrainAcc=1.0000
# Fold 3 Epoch 1400: TotalLoss=0.000392 | Sup=0.000345 | Recon=0.000523 | TrainAcc=1.0000
# Fold 3 Epoch 1500: TotalLoss=0.000307 | Sup=0.000259 | Recon=0.000527 | TrainAcc=1.0000
# Fold 3 Epoch 1600: TotalLoss=0.000257 | Sup=0.000209 | Recon=0.000534 | TrainAcc=1.0000
# Fold 3 Epoch 1700: TotalLoss=0.000170 | Sup=0.000122 | Recon=0.000533 | TrainAcc=1.0000
# Fold 3 Epoch 1800: TotalLoss=0.000156 | Sup=0.000108 | Recon=0.000540 | TrainAcc=1.0000
# Fold 3 Epoch 1900: TotalLoss=0.000135 | Sup=0.000087 | Recon=0.000541 | TrainAcc=1.0000
# Fold 3 Epoch 2000: TotalLoss=0.000146 | Sup=0.000098 | Recon=0.000535 | TrainAcc=1.0000
# Fold 3 → Acc=0.8864 | Prec=0.8462 | Rec=0.7857 | F1=0.8148 | AUC=0.9857 | CE Loss=0.1949
#
# === Fold 4 ===
# Train Control: 68, Train Patient: 33
# Fold 4 Epoch 1: TotalLoss=0.694912 | Sup=0.691565 | Recon=0.037187 | TrainAcc=0.6733
# Fold 4 Epoch 100: TotalLoss=0.171453 | Sup=0.171130 | Recon=0.003594 | TrainAcc=1.0000
# Fold 4 Epoch 200: TotalLoss=0.047059 | Sup=0.046911 | Recon=0.001645 | TrainAcc=1.0000
# Fold 4 Epoch 300: TotalLoss=0.020570 | Sup=0.020488 | Recon=0.000911 | TrainAcc=1.0000
# Fold 4 Epoch 400: TotalLoss=0.011424 | Sup=0.011369 | Recon=0.000603 | TrainAcc=1.0000
# Fold 4 Epoch 500: TotalLoss=0.006568 | Sup=0.006526 | Recon=0.000470 | TrainAcc=1.0000
# Fold 4 Epoch 600: TotalLoss=0.004590 | Sup=0.004551 | Recon=0.000435 | TrainAcc=1.0000
# Fold 4 Epoch 700: TotalLoss=0.003226 | Sup=0.003186 | Recon=0.000446 | TrainAcc=1.0000
# Fold 4 Epoch 800: TotalLoss=0.002472 | Sup=0.002430 | Recon=0.000465 | TrainAcc=1.0000
# Fold 4 Epoch 900: TotalLoss=0.001889 | Sup=0.001845 | Recon=0.000487 | TrainAcc=1.0000
# Fold 4 Epoch 1000: TotalLoss=0.001128 | Sup=0.001084 | Recon=0.000495 | TrainAcc=1.0000
# Fold 4 Epoch 1100: TotalLoss=0.000836 | Sup=0.000790 | Recon=0.000508 | TrainAcc=1.0000
# Fold 4 Epoch 1200: TotalLoss=0.000627 | Sup=0.000580 | Recon=0.000519 | TrainAcc=1.0000
# Fold 4 Epoch 1300: TotalLoss=0.000595 | Sup=0.000548 | Recon=0.000527 | TrainAcc=1.0000
# Fold 4 Epoch 1400: TotalLoss=0.000332 | Sup=0.000284 | Recon=0.000535 | TrainAcc=1.0000
# Fold 4 Epoch 1500: TotalLoss=0.000412 | Sup=0.000363 | Recon=0.000541 | TrainAcc=1.0000
# Fold 4 Epoch 1600: TotalLoss=0.000262 | Sup=0.000214 | Recon=0.000538 | TrainAcc=1.0000
# Fold 4 Epoch 1700: TotalLoss=0.000227 | Sup=0.000179 | Recon=0.000538 | TrainAcc=1.0000
# Fold 4 Epoch 1800: TotalLoss=0.000238 | Sup=0.000188 | Recon=0.000550 | TrainAcc=1.0000
# Fold 4 Epoch 1900: TotalLoss=0.000198 | Sup=0.000149 | Recon=0.000546 | TrainAcc=1.0000
# Fold 4 Epoch 2000: TotalLoss=0.000148 | Sup=0.000099 | Recon=0.000545 | TrainAcc=1.0000
# Fold 4 → Acc=0.9773 | Prec=1.0000 | Rec=0.9286 | F1=0.9630 | AUC=0.9976 | CE Loss=0.0667
#
# === Fold 5 ===
# Train Control: 68, Train Patient: 33
# Fold 5 Epoch 1: TotalLoss=0.756170 | Sup=0.752822 | Recon=0.037201 | TrainAcc=0.6634
# Fold 5 Epoch 100: TotalLoss=0.151794 | Sup=0.151457 | Recon=0.003742 | TrainAcc=1.0000
# Fold 5 Epoch 200: TotalLoss=0.048273 | Sup=0.048121 | Recon=0.001689 | TrainAcc=1.0000
# Fold 5 Epoch 300: TotalLoss=0.021331 | Sup=0.021245 | Recon=0.000951 | TrainAcc=1.0000
# Fold 5 Epoch 400: TotalLoss=0.010759 | Sup=0.010703 | Recon=0.000613 | TrainAcc=1.0000
# Fold 5 Epoch 500: TotalLoss=0.006248 | Sup=0.006204 | Recon=0.000479 | TrainAcc=1.0000
# Fold 5 Epoch 600: TotalLoss=0.004518 | Sup=0.004478 | Recon=0.000435 | TrainAcc=1.0000
# Fold 5 Epoch 700: TotalLoss=0.002689 | Sup=0.002650 | Recon=0.000439 | TrainAcc=1.0000
# Fold 5 Epoch 800: TotalLoss=0.001575 | Sup=0.001533 | Recon=0.000466 | TrainAcc=1.0000
# Fold 5 Epoch 900: TotalLoss=0.000984 | Sup=0.000940 | Recon=0.000483 | TrainAcc=1.0000
# Fold 5 Epoch 1000: TotalLoss=0.000763 | Sup=0.000719 | Recon=0.000494 | TrainAcc=1.0000
# Fold 5 Epoch 1100: TotalLoss=0.000496 | Sup=0.000450 | Recon=0.000512 | TrainAcc=1.0000
# Fold 5 Epoch 1200: TotalLoss=0.000485 | Sup=0.000438 | Recon=0.000523 | TrainAcc=1.0000
# Fold 5 Epoch 1300: TotalLoss=0.000381 | Sup=0.000333 | Recon=0.000529 | TrainAcc=1.0000
# Fold 5 Epoch 1400: TotalLoss=0.000334 | Sup=0.000286 | Recon=0.000532 | TrainAcc=1.0000
# Fold 5 Epoch 1500: TotalLoss=0.000271 | Sup=0.000223 | Recon=0.000534 | TrainAcc=1.0000
# Fold 5 Epoch 1600: TotalLoss=0.000184 | Sup=0.000135 | Recon=0.000544 | TrainAcc=1.0000
# Fold 5 Epoch 1700: TotalLoss=0.000177 | Sup=0.000128 | Recon=0.000543 | TrainAcc=1.0000
# Fold 5 Epoch 1800: TotalLoss=0.000235 | Sup=0.000185 | Recon=0.000547 | TrainAcc=1.0000
# Fold 5 Epoch 1900: TotalLoss=0.000184 | Sup=0.000134 | Recon=0.000547 | TrainAcc=1.0000
# Fold 5 Epoch 2000: TotalLoss=0.000145 | Sup=0.000096 | Recon=0.000546 | TrainAcc=1.0000
# Fold 5 → Acc=0.9318 | Prec=0.8667 | Rec=0.9286 | F1=0.8966 | AUC=0.9833 | CE Loss=0.1979
#
# === Fold 6 ===
# Train Control: 68, Train Patient: 33
# Fold 6 Epoch 1: TotalLoss=0.695674 | Sup=0.692537 | Recon=0.034855 | TrainAcc=0.6832
# Fold 6 Epoch 100: TotalLoss=0.190511 | Sup=0.190199 | Recon=0.003464 | TrainAcc=0.9802
# Fold 6 Epoch 200: TotalLoss=0.056684 | Sup=0.056537 | Recon=0.001623 | TrainAcc=1.0000
# Fold 6 Epoch 300: TotalLoss=0.023096 | Sup=0.023015 | Recon=0.000902 | TrainAcc=1.0000
# Fold 6 Epoch 400: TotalLoss=0.010286 | Sup=0.010234 | Recon=0.000579 | TrainAcc=1.0000
# Fold 6 Epoch 500: TotalLoss=0.007053 | Sup=0.007009 | Recon=0.000481 | TrainAcc=1.0000
# Fold 6 Epoch 600: TotalLoss=0.002895 | Sup=0.002856 | Recon=0.000438 | TrainAcc=1.0000
# Fold 6 Epoch 700: TotalLoss=0.002401 | Sup=0.002362 | Recon=0.000442 | TrainAcc=1.0000
# Fold 6 Epoch 800: TotalLoss=0.001696 | Sup=0.001654 | Recon=0.000460 | TrainAcc=1.0000
# Fold 6 Epoch 900: TotalLoss=0.001226 | Sup=0.001182 | Recon=0.000490 | TrainAcc=1.0000
# Fold 6 Epoch 1000: TotalLoss=0.000979 | Sup=0.000934 | Recon=0.000501 | TrainAcc=1.0000
# Fold 6 Epoch 1100: TotalLoss=0.000789 | Sup=0.000743 | Recon=0.000503 | TrainAcc=1.0000
# Fold 6 Epoch 1200: TotalLoss=0.000685 | Sup=0.000638 | Recon=0.000513 | TrainAcc=1.0000
# Fold 6 Epoch 1300: TotalLoss=0.000617 | Sup=0.000568 | Recon=0.000539 | TrainAcc=1.0000
# Fold 6 Epoch 1400: TotalLoss=0.000452 | Sup=0.000403 | Recon=0.000541 | TrainAcc=1.0000
# Fold 6 Epoch 1500: TotalLoss=0.000354 | Sup=0.000306 | Recon=0.000536 | TrainAcc=1.0000
# Fold 6 Epoch 1600: TotalLoss=0.000354 | Sup=0.000305 | Recon=0.000546 | TrainAcc=1.0000
# Fold 6 Epoch 1700: TotalLoss=0.000348 | Sup=0.000299 | Recon=0.000544 | TrainAcc=1.0000
# Fold 6 Epoch 1800: TotalLoss=0.000281 | Sup=0.000231 | Recon=0.000558 | TrainAcc=1.0000
# Fold 6 Epoch 1900: TotalLoss=0.000237 | Sup=0.000187 | Recon=0.000549 | TrainAcc=1.0000
# Fold 6 Epoch 2000: TotalLoss=0.000188 | Sup=0.000139 | Recon=0.000542 | TrainAcc=1.0000
# Fold 6 → Acc=0.9318 | Prec=0.9231 | Rec=0.8571 | F1=0.8889 | AUC=0.9881 | CE Loss=0.1494
#
# === Fold 7 ===
# Train Control: 68, Train Patient: 33
# Fold 7 Epoch 1: TotalLoss=0.685322 | Sup=0.681641 | Recon=0.040895 | TrainAcc=0.6733
# Fold 7 Epoch 100: TotalLoss=0.162813 | Sup=0.162469 | Recon=0.003815 | TrainAcc=1.0000
# Fold 7 Epoch 200: TotalLoss=0.056623 | Sup=0.056470 | Recon=0.001692 | TrainAcc=1.0000
# Fold 7 Epoch 300: TotalLoss=0.023426 | Sup=0.023340 | Recon=0.000955 | TrainAcc=1.0000
# Fold 7 Epoch 400: TotalLoss=0.012789 | Sup=0.012732 | Recon=0.000635 | TrainAcc=1.0000
# Fold 7 Epoch 500: TotalLoss=0.007615 | Sup=0.007572 | Recon=0.000485 | TrainAcc=1.0000
# Fold 7 Epoch 600: TotalLoss=0.003958 | Sup=0.003917 | Recon=0.000457 | TrainAcc=1.0000
# Fold 7 Epoch 700: TotalLoss=0.002566 | Sup=0.002526 | Recon=0.000441 | TrainAcc=1.0000
# Fold 7 Epoch 800: TotalLoss=0.001850 | Sup=0.001808 | Recon=0.000461 | TrainAcc=1.0000
# Fold 7 Epoch 900: TotalLoss=0.001376 | Sup=0.001332 | Recon=0.000482 | TrainAcc=1.0000
# Fold 7 Epoch 1000: TotalLoss=0.000813 | Sup=0.000770 | Recon=0.000481 | TrainAcc=1.0000
# Fold 7 Epoch 1100: TotalLoss=0.000678 | Sup=0.000632 | Recon=0.000507 | TrainAcc=1.0000
# Fold 7 Epoch 1200: TotalLoss=0.000472 | Sup=0.000426 | Recon=0.000518 | TrainAcc=1.0000
# Fold 7 Epoch 1300: TotalLoss=0.000465 | Sup=0.000418 | Recon=0.000522 | TrainAcc=1.0000
# Fold 7 Epoch 1400: TotalLoss=0.000425 | Sup=0.000377 | Recon=0.000524 | TrainAcc=1.0000
# Fold 7 Epoch 1500: TotalLoss=0.000253 | Sup=0.000205 | Recon=0.000529 | TrainAcc=1.0000
# Fold 7 Epoch 1600: TotalLoss=0.000254 | Sup=0.000206 | Recon=0.000532 | TrainAcc=1.0000
# Fold 7 Epoch 1700: TotalLoss=0.000236 | Sup=0.000187 | Recon=0.000541 | TrainAcc=1.0000
# Fold 7 Epoch 1800: TotalLoss=0.000177 | Sup=0.000128 | Recon=0.000542 | TrainAcc=1.0000
# Fold 7 Epoch 1900: TotalLoss=0.000203 | Sup=0.000153 | Recon=0.000552 | TrainAcc=1.0000
# Fold 7 Epoch 2000: TotalLoss=0.000154 | Sup=0.000106 | Recon=0.000539 | TrainAcc=1.0000
# Fold 7 → Acc=0.8864 | Prec=0.8000 | Rec=0.8571 | F1=0.8276 | AUC=0.9595 | CE Loss=0.3388
#
# === Fold 8 ===
# Train Control: 68, Train Patient: 33
# Fold 8 Epoch 1: TotalLoss=0.777347 | Sup=0.774074 | Recon=0.036363 | TrainAcc=0.3267
# Fold 8 Epoch 100: TotalLoss=0.211614 | Sup=0.211296 | Recon=0.003529 | TrainAcc=0.9703
# Fold 8 Epoch 200: TotalLoss=0.063333 | Sup=0.063184 | Recon=0.001651 | TrainAcc=1.0000
# Fold 8 Epoch 300: TotalLoss=0.025331 | Sup=0.025249 | Recon=0.000908 | TrainAcc=1.0000
# Fold 8 Epoch 400: TotalLoss=0.013340 | Sup=0.013287 | Recon=0.000592 | TrainAcc=1.0000
# Fold 8 Epoch 500: TotalLoss=0.007153 | Sup=0.007111 | Recon=0.000466 | TrainAcc=1.0000
# Fold 8 Epoch 600: TotalLoss=0.003622 | Sup=0.003584 | Recon=0.000429 | TrainAcc=1.0000
# Fold 8 Epoch 700: TotalLoss=0.002486 | Sup=0.002447 | Recon=0.000440 | TrainAcc=1.0000
# Fold 8 Epoch 800: TotalLoss=0.001920 | Sup=0.001879 | Recon=0.000462 | TrainAcc=1.0000
# Fold 8 Epoch 900: TotalLoss=0.001352 | Sup=0.001309 | Recon=0.000473 | TrainAcc=1.0000
# Fold 8 Epoch 1000: TotalLoss=0.000990 | Sup=0.000946 | Recon=0.000486 | TrainAcc=1.0000
# Fold 8 Epoch 1100: TotalLoss=0.000949 | Sup=0.000902 | Recon=0.000516 | TrainAcc=1.0000
# Fold 8 Epoch 1200: TotalLoss=0.000722 | Sup=0.000676 | Recon=0.000514 | TrainAcc=1.0000
# Fold 8 Epoch 1300: TotalLoss=0.000531 | Sup=0.000483 | Recon=0.000532 | TrainAcc=1.0000
# Fold 8 Epoch 1400: TotalLoss=0.000525 | Sup=0.000476 | Recon=0.000541 | TrainAcc=1.0000
# Fold 8 Epoch 1500: TotalLoss=0.000372 | Sup=0.000324 | Recon=0.000539 | TrainAcc=1.0000
# Fold 8 Epoch 1600: TotalLoss=0.000385 | Sup=0.000336 | Recon=0.000546 | TrainAcc=1.0000
# Fold 8 Epoch 1700: TotalLoss=0.000251 | Sup=0.000203 | Recon=0.000539 | TrainAcc=1.0000
# Fold 8 Epoch 1800: TotalLoss=0.000228 | Sup=0.000179 | Recon=0.000546 | TrainAcc=1.0000
# Fold 8 Epoch 1900: TotalLoss=0.000193 | Sup=0.000143 | Recon=0.000558 | TrainAcc=1.0000
# Fold 8 Epoch 2000: TotalLoss=0.000207 | Sup=0.000157 | Recon=0.000556 | TrainAcc=1.0000
# Fold 8 → Acc=0.9318 | Prec=0.8667 | Rec=0.9286 | F1=0.8966 | AUC=0.9929 | CE Loss=0.1719
#
# === Fold 9 ===
# Train Control: 68, Train Patient: 33
# Fold 9 Epoch 1: TotalLoss=0.813469 | Sup=0.809997 | Recon=0.038575 | TrainAcc=0.6436
# Fold 9 Epoch 100: TotalLoss=0.197279 | Sup=0.196945 | Recon=0.003709 | TrainAcc=1.0000
# Fold 9 Epoch 200: TotalLoss=0.064121 | Sup=0.063969 | Recon=0.001698 | TrainAcc=1.0000
# Fold 9 Epoch 300: TotalLoss=0.023905 | Sup=0.023824 | Recon=0.000899 | TrainAcc=1.0000
# Fold 9 Epoch 400: TotalLoss=0.014938 | Sup=0.014884 | Recon=0.000601 | TrainAcc=1.0000
# Fold 9 Epoch 500: TotalLoss=0.007893 | Sup=0.007850 | Recon=0.000476 | TrainAcc=1.0000
# Fold 9 Epoch 600: TotalLoss=0.005157 | Sup=0.005118 | Recon=0.000435 | TrainAcc=1.0000
# Fold 9 Epoch 700: TotalLoss=0.002898 | Sup=0.002859 | Recon=0.000427 | TrainAcc=1.0000
# Fold 9 Epoch 800: TotalLoss=0.002007 | Sup=0.001966 | Recon=0.000457 | TrainAcc=1.0000
# Fold 9 Epoch 900: TotalLoss=0.001526 | Sup=0.001484 | Recon=0.000468 | TrainAcc=1.0000
# Fold 9 Epoch 1000: TotalLoss=0.001248 | Sup=0.001204 | Recon=0.000482 | TrainAcc=1.0000
# Fold 9 Epoch 1100: TotalLoss=0.000925 | Sup=0.000880 | Recon=0.000496 | TrainAcc=1.0000
# Fold 9 Epoch 1200: TotalLoss=0.000652 | Sup=0.000606 | Recon=0.000510 | TrainAcc=1.0000
# Fold 9 Epoch 1300: TotalLoss=0.000614 | Sup=0.000567 | Recon=0.000515 | TrainAcc=1.0000
# Fold 9 Epoch 1400: TotalLoss=0.000459 | Sup=0.000413 | Recon=0.000519 | TrainAcc=1.0000
# Fold 9 Epoch 1500: TotalLoss=0.000433 | Sup=0.000385 | Recon=0.000530 | TrainAcc=1.0000
# Fold 9 Epoch 1600: TotalLoss=0.000370 | Sup=0.000321 | Recon=0.000544 | TrainAcc=1.0000
# Fold 9 Epoch 1700: TotalLoss=0.000308 | Sup=0.000259 | Recon=0.000542 | TrainAcc=1.0000
# Fold 9 Epoch 1800: TotalLoss=0.000267 | Sup=0.000218 | Recon=0.000540 | TrainAcc=1.0000
# Fold 9 Epoch 1900: TotalLoss=0.000260 | Sup=0.000211 | Recon=0.000549 | TrainAcc=1.0000
# Fold 9 Epoch 2000: TotalLoss=0.000304 | Sup=0.000255 | Recon=0.000539 | TrainAcc=1.0000
# Fold 9 → Acc=0.9545 | Prec=1.0000 | Rec=0.8571 | F1=0.9231 | AUC=1.0000 | CE Loss=0.0724
#
# ...
# Fold 13 Epoch 1700: TotalLoss=0.001899 | Sup=0.000292 | Recon=0.000201 | TrainAcc=1.0000
# Fold 13 Epoch 1800: TotalLoss=0.001608 | Sup=0.000177 | Recon=0.000179 | TrainAcc=1.0000
# Fold 13 Epoch 1900: TotalLoss=0.001484 | Sup=0.000210 | Recon=0.000159 | TrainAcc=1.0000
# Fold 13 Epoch 2000: TotalLoss=0.001317 | Sup=0.000134 | Recon=0.000148 | TrainAcc=1.0000
# Fold 13 → Acc=0.9545 | Prec=1.0000 | Rec=0.8571 | F1=0.9231 | AUC=0.9786 | CE Loss=0.1552
#
# === Fold 14 ===
# Train Control: 68, Train Patient: 33
# Fold 14 Epoch 1: TotalLoss=1.008859 | Sup=0.692299 | Recon=0.039570 | TrainAcc=0.3267
# Fold 14 Epoch 100: TotalLoss=0.208587 | Sup=0.182181 | Recon=0.003301 | TrainAcc=0.9901
# Fold 14 Epoch 200: TotalLoss=0.065857 | Sup=0.050675 | Recon=0.001898 | TrainAcc=1.0000
# Fold 14 Epoch 300: TotalLoss=0.033240 | Sup=0.023361 | Recon=0.001235 | TrainAcc=1.0000
# Fold 14 Epoch 400: TotalLoss=0.020605 | Sup=0.013168 | Recon=0.000930 | TrainAcc=1.0000
# Fold 14 Epoch 500: TotalLoss=0.012870 | Sup=0.006818 | Recon=0.000757 | TrainAcc=1.0000
# Fold 14 Epoch 600: TotalLoss=0.009937 | Sup=0.004706 | Recon=0.000654 | TrainAcc=1.0000
# Fold 14 Epoch 700: TotalLoss=0.007997 | Sup=0.003432 | Recon=0.000571 | TrainAcc=1.0000
# Fold 14 Epoch 800: TotalLoss=0.006698 | Sup=0.002624 | Recon=0.000509 | TrainAcc=1.0000
# Fold 14 Epoch 900: TotalLoss=0.005530 | Sup=0.001894 | Recon=0.000455 | TrainAcc=1.0000
# Fold 14 Epoch 1000: TotalLoss=0.004443 | Sup=0.001167 | Recon=0.000410 | TrainAcc=1.0000
# Fold 14 Epoch 1100: TotalLoss=0.003987 | Sup=0.000978 | Recon=0.000376 | TrainAcc=1.0000
# Fold 14 Epoch 1200: TotalLoss=0.003312 | Sup=0.000639 | Recon=0.000334 | TrainAcc=1.0000
# Fold 14 Epoch 1300: TotalLoss=0.002877 | Sup=0.000476 | Recon=0.000300 | TrainAcc=1.0000
# Fold 14 Epoch 1400: TotalLoss=0.002716 | Sup=0.000418 | Recon=0.000287 | TrainAcc=1.0000
# Fold 14 Epoch 1500: TotalLoss=0.002440 | Sup=0.000447 | Recon=0.000249 | TrainAcc=1.0000
# Fold 14 Epoch 1600: TotalLoss=0.002088 | Sup=0.000263 | Recon=0.000228 | TrainAcc=1.0000
# Fold 14 Epoch 1700: TotalLoss=0.001906 | Sup=0.000272 | Recon=0.000204 | TrainAcc=1.0000
# Fold 14 Epoch 1800: TotalLoss=0.001679 | Sup=0.000245 | Recon=0.000179 | TrainAcc=1.0000
# Fold 14 Epoch 1900: TotalLoss=0.001498 | Sup=0.000150 | Recon=0.000168 | TrainAcc=1.0000
# Fold 14 Epoch 2000: TotalLoss=0.001404 | Sup=0.000210 | Recon=0.000149 | TrainAcc=1.0000
# Fold 14 → Acc=0.8864 | Prec=0.8462 | Rec=0.7857 | F1=0.8148 | AUC=0.9714 | CE Loss=0.2920
#
# === Fold 15 ===
# Train Control: 68, Train Patient: 33
# Fold 15 Epoch 1: TotalLoss=1.076750 | Sup=0.767872 | Recon=0.038610 | TrainAcc=0.3267
# Fold 15 Epoch 100: TotalLoss=0.233239 | Sup=0.208403 | Recon=0.003104 | TrainAcc=1.0000
# Fold 15 Epoch 200: TotalLoss=0.081349 | Sup=0.067062 | Recon=0.001786 | TrainAcc=1.0000
# Fold 15 Epoch 300: TotalLoss=0.037186 | Sup=0.027764 | Recon=0.001178 | TrainAcc=1.0000
# Fold 15 Epoch 400: TotalLoss=0.019851 | Sup=0.012739 | Recon=0.000889 | TrainAcc=1.0000
# Fold 15 Epoch 500: TotalLoss=0.013941 | Sup=0.007974 | Recon=0.000746 | TrainAcc=1.0000
# Fold 15 Epoch 600: TotalLoss=0.010903 | Sup=0.005854 | Recon=0.000631 | TrainAcc=1.0000
# Fold 15 Epoch 700: TotalLoss=0.008626 | Sup=0.004106 | Recon=0.000565 | TrainAcc=1.0000
# Fold 15 Epoch 800: TotalLoss=0.007424 | Sup=0.003416 | Recon=0.000501 | TrainAcc=1.0000
# Fold 15 Epoch 900: TotalLoss=0.005995 | Sup=0.002420 | Recon=0.000447 | TrainAcc=1.0000
# Fold 15 Epoch 1000: TotalLoss=0.004724 | Sup=0.001488 | Recon=0.000405 | TrainAcc=1.0000
# Fold 15 Epoch 1100: TotalLoss=0.004044 | Sup=0.001114 | Recon=0.000366 | TrainAcc=1.0000
# Fold 15 Epoch 1200: TotalLoss=0.003199 | Sup=0.000618 | Recon=0.000323 | TrainAcc=1.0000
# Fold 15 Epoch 1300: TotalLoss=0.002966 | Sup=0.000567 | Recon=0.000300 | TrainAcc=1.0000
# Fold 15 Epoch 1400: TotalLoss=0.002659 | Sup=0.000436 | Recon=0.000278 | TrainAcc=1.0000
# Fold 15 Epoch 1500: TotalLoss=0.002281 | Sup=0.000331 | Recon=0.000244 | TrainAcc=1.0000
# Fold 15 Epoch 1600: TotalLoss=0.001996 | Sup=0.000258 | Recon=0.000217 | TrainAcc=1.0000
# Fold 15 Epoch 1700: TotalLoss=0.001747 | Sup=0.000183 | Recon=0.000195 | TrainAcc=1.0000
# Fold 15 Epoch 1800: TotalLoss=0.001610 | Sup=0.000173 | Recon=0.000180 | TrainAcc=1.0000
# Fold 15 Epoch 1900: TotalLoss=0.001546 | Sup=0.000170 | Recon=0.000172 | TrainAcc=1.0000
# Fold 15 Epoch 2000: TotalLoss=0.001403 | Sup=0.000154 | Recon=0.000156 | TrainAcc=1.0000
# Fold 15 → Acc=0.9091 | Prec=0.8571 | Rec=0.8571 | F1=0.8571 | AUC=0.9833 | CE Loss=0.2436
#
# === Fold 16 ===
# Train Control: 68, Train Patient: 33
# Fold 16 Epoch 1: TotalLoss=1.059450 | Sup=0.727973 | Recon=0.041435 | TrainAcc=0.5248
# Fold 16 Epoch 100: TotalLoss=0.229899 | Sup=0.202977 | Recon=0.003365 | TrainAcc=0.9901
# Fold 16 Epoch 200: TotalLoss=0.077761 | Sup=0.063377 | Recon=0.001798 | TrainAcc=1.0000
# Fold 16 Epoch 300: TotalLoss=0.038450 | Sup=0.028825 | Recon=0.001203 | TrainAcc=1.0000
# Fold 16 Epoch 400: TotalLoss=0.022063 | Sup=0.014929 | Recon=0.000892 | TrainAcc=1.0000
# Fold 16 Epoch 500: TotalLoss=0.013587 | Sup=0.007591 | Recon=0.000749 | TrainAcc=1.0000
# Fold 16 Epoch 600: TotalLoss=0.010159 | Sup=0.005050 | Recon=0.000639 | TrainAcc=1.0000
# Fold 16 Epoch 700: TotalLoss=0.008373 | Sup=0.003709 | Recon=0.000583 | TrainAcc=1.0000
# Fold 16 Epoch 800: TotalLoss=0.006667 | Sup=0.002597 | Recon=0.000509 | TrainAcc=1.0000
# Fold 16 Epoch 900: TotalLoss=0.005798 | Sup=0.001998 | Recon=0.000475 | TrainAcc=1.0000
# Fold 16 Epoch 1000: TotalLoss=0.004521 | Sup=0.001220 | Recon=0.000413 | TrainAcc=1.0000
# Fold 16 Epoch 1100: TotalLoss=0.004034 | Sup=0.000956 | Recon=0.000385 | TrainAcc=1.0000
# Fold 16 Epoch 1200: TotalLoss=0.003427 | Sup=0.000666 | Recon=0.000345 | TrainAcc=1.0000
# Fold 16 Epoch 1300: TotalLoss=0.002885 | Sup=0.000437 | Recon=0.000306 | TrainAcc=1.0000
# Fold 16 Epoch 1400: TotalLoss=0.002639 | Sup=0.000372 | Recon=0.000283 | TrainAcc=1.0000
# Fold 16 Epoch 1500: TotalLoss=0.002321 | Sup=0.000288 | Recon=0.000254 | TrainAcc=1.0000
# Fold 16 Epoch 1600: TotalLoss=0.002026 | Sup=0.000228 | Recon=0.000225 | TrainAcc=1.0000
# Fold 16 Epoch 1700: TotalLoss=0.001905 | Sup=0.000220 | Recon=0.000211 | TrainAcc=1.0000
# Fold 16 Epoch 1800: TotalLoss=0.001702 | Sup=0.000211 | Recon=0.000186 | TrainAcc=1.0000
# Fold 16 Epoch 1900: TotalLoss=0.001570 | Sup=0.000196 | Recon=0.000172 | TrainAcc=1.0000
# Fold 16 Epoch 2000: TotalLoss=0.001452 | Sup=0.000179 | Recon=0.000159 | TrainAcc=1.0000
# Fold 16 → Acc=0.9318 | Prec=1.0000 | Rec=0.7857 | F1=0.8800 | AUC=0.9786 | CE Loss=0.2398
#
# === Fold 17 ===
# Train Control: 68, Train Patient: 33
# Fold 17 Epoch 1: TotalLoss=0.985886 | Sup=0.672246 | Recon=0.039205 | TrainAcc=0.6733
# Fold 17 Epoch 100: TotalLoss=0.237930 | Sup=0.210369 | Recon=0.003445 | TrainAcc=1.0000
# Fold 17 Epoch 200: TotalLoss=0.082534 | Sup=0.067049 | Recon=0.001936 | TrainAcc=1.0000
# Fold 17 Epoch 300: TotalLoss=0.034692 | Sup=0.025070 | Recon=0.001203 | TrainAcc=1.0000
# Fold 17 Epoch 400: TotalLoss=0.019520 | Sup=0.012431 | Recon=0.000886 | TrainAcc=1.0000
# Fold 17 Epoch 500: TotalLoss=0.014246 | Sup=0.008330 | Recon=0.000740 | TrainAcc=1.0000
# Fold 17 Epoch 600: TotalLoss=0.009580 | Sup=0.004452 | Recon=0.000641 | TrainAcc=1.0000
# Fold 17 Epoch 700: TotalLoss=0.007847 | Sup=0.003418 | Recon=0.000554 | TrainAcc=1.0000
# Fold 17 Epoch 800: TotalLoss=0.006369 | Sup=0.002321 | Recon=0.000506 | TrainAcc=1.0000
# Fold 17 Epoch 900: TotalLoss=0.005530 | Sup=0.001873 | Recon=0.000457 | TrainAcc=1.0000
# Fold 17 Epoch 1000: TotalLoss=0.004461 | Sup=0.001121 | Recon=0.000418 | TrainAcc=1.0000
# Fold 17 Epoch 1100: TotalLoss=0.003860 | Sup=0.000847 | Recon=0.000377 | TrainAcc=1.0000
# Fold 17 Epoch 1200: TotalLoss=0.003270 | Sup=0.000506 | Recon=0.000345 | TrainAcc=1.0000
# Fold 17 Epoch 1300: TotalLoss=0.002892 | Sup=0.000439 | Recon=0.000307 | TrainAcc=1.0000
# Fold 17 Epoch 1400: TotalLoss=0.002638 | Sup=0.000335 | Recon=0.000288 | TrainAcc=1.0000
# Fold 17 Epoch 1500: TotalLoss=0.002326 | Sup=0.000230 | Recon=0.000262 | TrainAcc=1.0000
# Fold 17 Epoch 1600: TotalLoss=0.002074 | Sup=0.000164 | Recon=0.000239 | TrainAcc=1.0000
# Fold 17 Epoch 1700: TotalLoss=0.001890 | Sup=0.000156 | Recon=0.000217 | TrainAcc=1.0000
# Fold 17 Epoch 1800: TotalLoss=0.001730 | Sup=0.000148 | Recon=0.000198 | TrainAcc=1.0000
# Fold 17 Epoch 1900: TotalLoss=0.001555 | Sup=0.000122 | Recon=0.000179 | TrainAcc=1.0000
# Fold 17 Epoch 2000: TotalLoss=0.001412 | Sup=0.000119 | Recon=0.000162 | TrainAcc=1.0000
# Fold 17 → Acc=0.9318 | Prec=0.9231 | Rec=0.8571 | F1=0.8889 | AUC=0.9810 | CE Loss=0.1778
#
# === Fold 18 ===
# Train Control: 68, Train Patient: 33
# Fold 18 Epoch 1: TotalLoss=0.966537 | Sup=0.673512 | Recon=0.036628 | TrainAcc=0.6535
# Fold 18 Epoch 100: TotalLoss=0.197607 | Sup=0.171042 | Recon=0.003321 | TrainAcc=1.0000
# Fold 18 Epoch 200: TotalLoss=0.067630 | Sup=0.054126 | Recon=0.001688 | TrainAcc=1.0000
# Fold 18 Epoch 300: TotalLoss=0.033123 | Sup=0.023856 | Recon=0.001158 | TrainAcc=1.0000
# Fold 18 Epoch 400: TotalLoss=0.020141 | Sup=0.013088 | Recon=0.000882 | TrainAcc=1.0000
# Fold 18 Epoch 500: TotalLoss=0.013506 | Sup=0.007823 | Recon=0.000710 | TrainAcc=1.0000
# Fold 18 Epoch 600: TotalLoss=0.009850 | Sup=0.004782 | Recon=0.000634 | TrainAcc=1.0000
# Fold 18 Epoch 700: TotalLoss=0.007493 | Sup=0.003106 | Recon=0.000548 | TrainAcc=1.0000
# Fold 18 Epoch 800: TotalLoss=0.006569 | Sup=0.002625 | Recon=0.000493 | TrainAcc=1.0000
# Fold 18 Epoch 900: TotalLoss=0.005207 | Sup=0.001649 | Recon=0.000445 | TrainAcc=1.0000
# Fold 18 Epoch 1000: TotalLoss=0.004396 | Sup=0.001132 | Recon=0.000408 | TrainAcc=1.0000
# Fold 18 Epoch 1100: TotalLoss=0.003870 | Sup=0.000901 | Recon=0.000371 | TrainAcc=1.0000
# Fold 18 Epoch 1200: TotalLoss=0.003384 | Sup=0.000649 | Recon=0.000342 | TrainAcc=1.0000
# Fold 18 Epoch 1300: TotalLoss=0.002850 | Sup=0.000471 | Recon=0.000297 | TrainAcc=1.0000
# Fold 18 Epoch 1400: TotalLoss=0.002964 | Sup=0.000668 | Recon=0.000287 | TrainAcc=1.0000
# Fold 18 Epoch 1500: TotalLoss=0.002424 | Sup=0.000361 | Recon=0.000258 | TrainAcc=1.0000
# Fold 18 Epoch 1600: TotalLoss=0.002219 | Sup=0.000340 | Recon=0.000235 | TrainAcc=1.0000
# Fold 18 Epoch 1700: TotalLoss=0.001978 | Sup=0.000278 | Recon=0.000213 | TrainAcc=1.0000
# Fold 18 Epoch 1800: TotalLoss=0.001734 | Sup=0.000218 | Recon=0.000189 | TrainAcc=1.0000
# Fold 18 Epoch 1900: TotalLoss=0.001587 | Sup=0.000219 | Recon=0.000171 | TrainAcc=1.0000
# Fold 18 Epoch 2000: TotalLoss=0.001416 | Sup=0.000169 | Recon=0.000156 | TrainAcc=1.0000
# Fold 18 → Acc=0.9318 | Prec=0.8667 | Rec=0.9286 | F1=0.8966 | AUC=0.9857 | CE Loss=0.2571
#
# === Fold 19 ===
# Train Control: 68, Train Patient: 33
# Fold 19 Epoch 1: TotalLoss=1.071300 | Sup=0.779496 | Recon=0.036476 | TrainAcc=0.3267
# Fold 19 Epoch 100: TotalLoss=0.235654 | Sup=0.210706 | Recon=0.003119 | TrainAcc=0.9802
# Fold 19 Epoch 200: TotalLoss=0.086486 | Sup=0.072630 | Recon=0.001732 | TrainAcc=1.0000
# Fold 19 Epoch 300: TotalLoss=0.044574 | Sup=0.034948 | Recon=0.001203 | TrainAcc=1.0000
# Fold 19 Epoch 400: TotalLoss=0.022246 | Sup=0.014992 | Recon=0.000907 | TrainAcc=1.0000
# Fold 19 Epoch 500: TotalLoss=0.014812 | Sup=0.008883 | Recon=0.000741 | TrainAcc=1.0000
# Fold 19 Epoch 600: TotalLoss=0.010551 | Sup=0.005562 | Recon=0.000624 | TrainAcc=1.0000
# Fold 19 Epoch 700: TotalLoss=0.008320 | Sup=0.003920 | Recon=0.000550 | TrainAcc=1.0000
# Fold 19 Epoch 800: TotalLoss=0.006586 | Sup=0.002747 | Recon=0.000480 | TrainAcc=1.0000
# Fold 19 Epoch 900: TotalLoss=0.005288 | Sup=0.001801 | Recon=0.000436 | TrainAcc=1.0000
# Fold 19 Epoch 1000: TotalLoss=0.004661 | Sup=0.001482 | Recon=0.000397 | TrainAcc=1.0000
# Fold 19 Epoch 1100: TotalLoss=0.003896 | Sup=0.001118 | Recon=0.000347 | TrainAcc=1.0000
# Fold 19 Epoch 1200: TotalLoss=0.003081 | Sup=0.000619 | Recon=0.000308 | TrainAcc=1.0000
# Fold 19 Epoch 1300: TotalLoss=0.002831 | Sup=0.000578 | Recon=0.000282 | TrainAcc=1.0000
# Fold 19 Epoch 1400: TotalLoss=0.002537 | Sup=0.000472 | Recon=0.000258 | TrainAcc=1.0000
# Fold 19 Epoch 1500: TotalLoss=0.002094 | Sup=0.000267 | Recon=0.000228 | TrainAcc=1.0000
# Fold 19 Epoch 1600: TotalLoss=0.001898 | Sup=0.000200 | Recon=0.000212 | TrainAcc=1.0000
# Fold 19 Epoch 1700: TotalLoss=0.001697 | Sup=0.000183 | Recon=0.000189 | TrainAcc=1.0000
# Fold 19 Epoch 1800: TotalLoss=0.001535 | Sup=0.000167 | Recon=0.000171 | TrainAcc=1.0000
# Fold 19 Epoch 1900: TotalLoss=0.001423 | Sup=0.000154 | Recon=0.000159 | TrainAcc=1.0000
# Fold 19 Epoch 2000: TotalLoss=0.001310 | Sup=0.000118 | Recon=0.000149 | TrainAcc=1.0000
# Fold 19 → Acc=0.8409 | Prec=0.7692 | Rec=0.7143 | F1=0.7407 | AUC=0.9357 | CE Loss=0.3640
#
# === Fold 20 ===
# Train Control: 68, Train Patient: 33
# Fold 20 Epoch 1: TotalLoss=1.080124 | Sup=0.799954 | Recon=0.035021 | TrainAcc=0.3366
# Fold 20 Epoch 100: TotalLoss=0.246854 | Sup=0.221203 | Recon=0.003206 | TrainAcc=0.9901
# Fold 20 Epoch 200: TotalLoss=0.084796 | Sup=0.071152 | Recon=0.001705 | TrainAcc=1.0000
# Fold 20 Epoch 300: TotalLoss=0.036971 | Sup=0.027574 | Recon=0.001175 | TrainAcc=1.0000
# Fold 20 Epoch 400: TotalLoss=0.020834 | Sup=0.013882 | Recon=0.000869 | TrainAcc=1.0000
# Fold 20 Epoch 500: TotalLoss=0.013583 | Sup=0.007981 | Recon=0.000700 | TrainAcc=1.0000
# Fold 20 Epoch 600: TotalLoss=0.009918 | Sup=0.005118 | Recon=0.000600 | TrainAcc=1.0000
# Fold 20 Epoch 700: TotalLoss=0.006964 | Sup=0.002745 | Recon=0.000527 | TrainAcc=1.0000
# Fold 20 Epoch 800: TotalLoss=0.005894 | Sup=0.002070 | Recon=0.000478 | TrainAcc=1.0000
# Fold 20 Epoch 900: TotalLoss=0.005051 | Sup=0.001549 | Recon=0.000438 | TrainAcc=1.0000
# Fold 20 Epoch 1000: TotalLoss=0.004273 | Sup=0.001167 | Recon=0.000388 | TrainAcc=1.0000
# Fold 20 Epoch 1100: TotalLoss=0.003809 | Sup=0.000978 | Recon=0.000354 | TrainAcc=1.0000
# Fold 20 Epoch 1200: TotalLoss=0.003196 | Sup=0.000660 | Recon=0.000317 | TrainAcc=1.0000
# Fold 20 Epoch 1300: TotalLoss=0.002724 | Sup=0.000464 | Recon=0.000283 | TrainAcc=1.0000
# Fold 20 Epoch 1400: TotalLoss=0.002534 | Sup=0.000434 | Recon=0.000263 | TrainAcc=1.0000
# Fold 20 Epoch 1500: TotalLoss=0.002300 | Sup=0.000444 | Recon=0.000232 | TrainAcc=1.0000
# Fold 20 Epoch 1600: TotalLoss=0.002093 | Sup=0.000340 | Recon=0.000219 | TrainAcc=1.0000
# Fold 20 Epoch 1700: TotalLoss=0.001912 | Sup=0.000358 | Recon=0.000194 | TrainAcc=1.0000
# Fold 20 Epoch 1800: TotalLoss=0.001675 | Sup=0.000271 | Recon=0.000175 | TrainAcc=1.0000
# Fold 20 Epoch 1900: TotalLoss=0.001485 | Sup=0.000180 | Recon=0.000163 | TrainAcc=1.0000
# Fold 20 Epoch 2000: TotalLoss=0.001306 | Sup=0.000158 | Recon=0.000143 | TrainAcc=1.0000
# Fold 20 → Acc=0.9091 | Prec=0.8571 | Rec=0.8571 | F1=0.8571 | AUC=0.9714 | CE Loss=0.3020
#
# === Average Results for λ = 8 ===
# Accuracy:  0.9148
# Precision: 0.8902
# Recall:    0.8393
# F1-score:  0.8620
# CE Loss:   0.2221
# AUC:       0.9793
#
#
# ====================== FINAL SUMMARY ACROSS ALL λ ======================
# Lambda   | Accuracy  | Precision | Recall   | F1-score  | AUC      | CE Loss
# ------------------------------------------------------------------------
# 0.001    | 0.9148    | 0.8876    | 0.8429   | 0.8627    | 0.9804   | 0.2096
# 0.005    | 0.9148    | 0.8940    | 0.8357   | 0.8609    | 0.9786   | 0.2057
# 0.009    | 0.9125    | 0.8924    | 0.8286   | 0.8568    | 0.9786   | 0.2131
# 0.01     | 0.9102    | 0.8850    | 0.8286   | 0.8539    | 0.9789   | 0.2056
# 0.05     | 0.9182    | 0.9007    | 0.8393   | 0.8665    | 0.9808   | 0.1983
# 0.09     | 0.9136    | 0.8832    | 0.8429   | 0.8604    | 0.9795   | 0.2073
# 0.1      | 0.9102    | 0.8780    | 0.8393   | 0.8559    | 0.9790   | 0.2113
# 0.3      | 0.9170    | 0.8995    | 0.8393   | 0.8654    | 0.9776   | 0.2124
# 0.5      | 0.9125    | 0.8866    | 0.8357   | 0.8583    | 0.9804   | 0.2095
# 0.9      | 0.9170    | 0.8932    | 0.8429   | 0.8647    | 0.9800   | 0.2196
# 1        | 0.9159    | 0.9000    | 0.8321   | 0.8623    | 0.9798   | 0.2067
# 2        | 0.9125    | 0.8893    | 0.8321   | 0.8572    | 0.9790   | 0.2233
# 5        | 0.9102    | 0.8815    | 0.8321   | 0.8543    | 0.9799   | 0.2236
# 8        | 0.9148    | 0.8902    | 0.8393   | 0.8620    | 0.9793   | 0.2221
