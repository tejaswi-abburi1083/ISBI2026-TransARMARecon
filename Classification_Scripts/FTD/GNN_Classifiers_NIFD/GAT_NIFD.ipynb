# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import torch
import torch.nn as nn
import torch.nn.functional as nnFn
import torch.optim as optim
import numpy as np
import random
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from torch_geometric.data import Data
from torch_geometric.nn import GATConv
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score,
    f1_score, roc_auc_score, log_loss
)

# %%
# === Load Patients ===
fa_patients_path = "/home/snu/Downloads/NIFD_Patients_FA_Histogram_Feature.npy"
Patients_FA_array = np.load(fa_patients_path, allow_pickle=True)

# === Load Controls ===
fa_controls_path = "/home/snu/Downloads/NIFD_Control_FA_Histogram_Feature.npy"
Controls_FA_array = np.load(fa_controls_path, allow_pickle=True)

print("Patients Shape:", Patients_FA_array.shape)
print("Controls Shape:", Controls_FA_array.shape)

# === Combine features and labels ===
X = np.vstack([Controls_FA_array, Patients_FA_array])
y = np.hstack([
    np.zeros(Controls_FA_array.shape[0], dtype=np.int64),  # 0 = Control
    np.ones(Patients_FA_array.shape[0], dtype=np.int64)    # 1 = Patient
])

# Shuffle
np.random.seed(42)
perm = np.random.permutation(X.shape[0])
X = X[perm]
y = y[perm]
# Out:
# Patients Shape: (98, 180)
# Controls Shape: (48, 180)

# %%
class GAT_Supervised(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim, heads=4, activ="RELU", dropout=0.2):
        super(GAT_Supervised, self).__init__()
        self.conv1 = GATConv(input_dim, hidden_dim, heads=heads, concat=True, dropout=dropout)
        self.bn1 = nn.BatchNorm1d(hidden_dim * heads)
        self.dropout = nn.Dropout(dropout)
        self.fc = nn.Linear(hidden_dim * heads, output_dim)
        activations = {
            "SELU": nnFn.selu,
            "SiLU": nnFn.silu,
            "GELU": nnFn.gelu,
            "RELU": nnFn.relu,
            "ELU": nnFn.elu
        }
        self.act = activations.get(activ, nnFn.elu)

    def forward(self, data):
        x, edge_index = data.x, data.edge_index
        x = self.conv1(x, edge_index)
        x = self.bn1(x)
        x = self.act(x)
        x = self.dropout(x)
        logits = self.fc(x)
        return logits

# %%
def create_adj(F, alpha=1):
    F_norm = F / np.linalg.norm(F, axis=1, keepdims=True)
    W = np.dot(F_norm, F_norm.T)
    W = np.where(W >= alpha, 1, 0).astype(np.float32)
    W = W / W.max()
    return W

def load_data(adj, node_feats):
    node_feats = torch.from_numpy(node_feats).float()
    edge_index = torch.from_numpy(np.array(np.nonzero((adj > 0))))
    return Data(x=node_feats, edge_index=edge_index)

# %%
num_nodes, num_feats = X.shape
print(f"Number of features: {num_feats}")
# Out:
# Number of features: 180

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
alpha = 0.8
feats_dim = num_feats
hidden_dim = 512
num_classes = 2
num_epochs = 2000
lr = 0.0001
weight_decay = 1e-4
batch_print_freq = 100

# %%
W = create_adj(X, alpha)
data = load_data(W, X).to(device)
A_tensor = torch.from_numpy(W).float().to(device)
print(data)
# Out:
# Data(x=[146, 180], edge_index=[2, 13046])

# %%
sss = StratifiedShuffleSplit(n_splits=20, test_size=0.3, random_state=42)

accuracies, precisions, recalls, f1_scores, aucs, ce_losses = [], [], [], [], [], []

for fold, (train_idx, test_idx) in enumerate(sss.split(X, y), start=1):
    print(f"\n=== Fold {fold} ===")

    train_idx_t = torch.from_numpy(train_idx).long().to(device)
    y_train_tensor = torch.from_numpy(y[train_idx]).long().to(device)

    model = GAT_Supervised(feats_dim, hidden_dim, num_classes).to(device)
    optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
    ce_loss = nn.CrossEntropyLoss()


    for epoch in range(1, num_epochs + 1):
        model.train()
        optimizer.zero_grad()

        logits = model(data)
        loss = ce_loss(logits[train_idx_t], y_train_tensor)
        loss.backward()
        optimizer.step()

        if epoch % batch_print_freq == 0 or epoch == 1:
            model.eval()
            with torch.no_grad():
                preds_train = logits[train_idx_t].argmax(dim=1)
                acc_train = accuracy_score(y_train_tensor.cpu(), preds_train.cpu())
            print(f"Fold {fold} Epoch {epoch}: "
                  f"Loss={loss.item():.6f} | TrainAcc={acc_train:.4f}")


    model.eval()
    with torch.no_grad():
        out = model(data)
        preds = out.argmax(dim=1).cpu().numpy()
        probs = torch.softmax(out, dim=1)[:, 1].cpu().numpy()  # Probability for class 1

    y_test = y[test_idx]
    y_pred_test = preds[test_idx]
    y_prob_test = probs[test_idx]


    acc = accuracy_score(y_test, y_pred_test)
    prec = precision_score(y_test, y_pred_test, zero_division=0)
    rec = recall_score(y_test, y_pred_test, zero_division=0)
    f1 = f1_score(y_test, y_pred_test, zero_division=0)
    auc = roc_auc_score(y_test, y_prob_test)
    ce = log_loss(y_test, y_prob_test)

    accuracies.append(acc)
    precisions.append(prec)
    recalls.append(rec)
    f1_scores.append(f1)
    aucs.append(auc)
    ce_losses.append(ce)

    print(f"Fold {fold} → "
          f"Acc={acc:.4f} | Prec={prec:.4f} | Rec={rec:.4f} | "
          f"F1={f1:.4f} | AUC={auc:.4f} | CE Loss={ce:.4f}")


print("\n=== Average Results Across 20 Folds ===")
print(f"Accuracy:  {np.mean(accuracies):.4f} ± {np.std(accuracies):.4f}")
print(f"Precision: {np.mean(precisions):.4f} ± {np.std(precisions):.4f}")
print(f"Recall:    {np.mean(recalls):.4f} ± {np.std(recalls):.4f}")
print(f"F1-score:  {np.mean(f1_scores):.4f} ± {np.std(f1_scores):.4f}")
print(f"CE Loss:   {np.mean(ce_losses):.4f} ± {np.std(ce_losses):.4f}")
print(f"AUC:       {np.mean(aucs):.4f} ± {np.std(aucs):.4f}")
# Out:
# === Fold 1 ===
# Fold 1 Epoch 1: Loss=0.651226 | TrainAcc=0.5490
# Fold 1 Epoch 100: Loss=0.392863 | TrainAcc=0.8137
# Fold 1 Epoch 200: Loss=0.333650 | TrainAcc=0.8235
# Fold 1 Epoch 300: Loss=0.235861 | TrainAcc=0.9314
# Fold 1 Epoch 400: Loss=0.154531 | TrainAcc=0.9412
# Fold 1 Epoch 500: Loss=0.066759 | TrainAcc=0.9804
# Fold 1 Epoch 600: Loss=0.034721 | TrainAcc=1.0000
# Fold 1 Epoch 700: Loss=0.022856 | TrainAcc=1.0000
# Fold 1 Epoch 800: Loss=0.013757 | TrainAcc=1.0000
# Fold 1 Epoch 900: Loss=0.014432 | TrainAcc=1.0000
# Fold 1 Epoch 1000: Loss=0.005211 | TrainAcc=1.0000
# Fold 1 Epoch 1100: Loss=0.005181 | TrainAcc=1.0000
# Fold 1 Epoch 1200: Loss=0.002485 | TrainAcc=1.0000
# Fold 1 Epoch 1300: Loss=0.004052 | TrainAcc=1.0000
# Fold 1 Epoch 1400: Loss=0.004338 | TrainAcc=1.0000
# Fold 1 Epoch 1500: Loss=0.003115 | TrainAcc=1.0000
# Fold 1 Epoch 1600: Loss=0.001928 | TrainAcc=1.0000
# Fold 1 Epoch 1700: Loss=0.005113 | TrainAcc=1.0000
# Fold 1 Epoch 1800: Loss=0.002997 | TrainAcc=1.0000
# Fold 1 Epoch 1900: Loss=0.001681 | TrainAcc=1.0000
# Fold 1 Epoch 2000: Loss=0.001709 | TrainAcc=1.0000
# Fold 1 → Acc=0.7500 | Prec=0.7714 | Rec=0.9000 | F1=0.8308 | AUC=0.7667 | CE Loss=1.7320
#
# === Fold 2 ===
# Fold 2 Epoch 1: Loss=0.695134 | TrainAcc=0.5490
# Fold 2 Epoch 100: Loss=0.487674 | TrainAcc=0.7353
# Fold 2 Epoch 200: Loss=0.412033 | TrainAcc=0.8333
# Fold 2 Epoch 300: Loss=0.382700 | TrainAcc=0.8235
# Fold 2 Epoch 400: Loss=0.328181 | TrainAcc=0.8529
# Fold 2 Epoch 500: Loss=0.261871 | TrainAcc=0.8922
# Fold 2 Epoch 600: Loss=0.098514 | TrainAcc=0.9902
# Fold 2 Epoch 700: Loss=0.064700 | TrainAcc=0.9902
# Fold 2 Epoch 800: Loss=0.042176 | TrainAcc=0.9902
# Fold 2 Epoch 900: Loss=0.030482 | TrainAcc=0.9902
# Fold 2 Epoch 1000: Loss=0.016719 | TrainAcc=0.9902
# Fold 2 Epoch 1100: Loss=0.015702 | TrainAcc=1.0000
# Fold 2 Epoch 1200: Loss=0.007232 | TrainAcc=1.0000
# Fold 2 Epoch 1300: Loss=0.005423 | TrainAcc=1.0000
# Fold 2 Epoch 1400: Loss=0.003416 | TrainAcc=1.0000
# Fold 2 Epoch 1500: Loss=0.008000 | TrainAcc=1.0000
# Fold 2 Epoch 1600: Loss=0.003604 | TrainAcc=1.0000
# Fold 2 Epoch 1700: Loss=0.008760 | TrainAcc=1.0000
# Fold 2 Epoch 1800: Loss=0.014822 | TrainAcc=0.9902
# Fold 2 Epoch 1900: Loss=0.002142 | TrainAcc=1.0000
# Fold 2 Epoch 2000: Loss=0.002947 | TrainAcc=1.0000
# Fold 2 → Acc=0.7955 | Prec=0.8000 | Rec=0.9333 | F1=0.8615 | AUC=0.8619 | CE Loss=1.1887
#
# === Fold 3 ===
# Fold 3 Epoch 1: Loss=0.806754 | TrainAcc=0.3431
# Fold 3 Epoch 100: Loss=0.409272 | TrainAcc=0.8039
# Fold 3 Epoch 200: Loss=0.359823 | TrainAcc=0.8333
# Fold 3 Epoch 300: Loss=0.278038 | TrainAcc=0.8725
# Fold 3 Epoch 400: Loss=0.148795 | TrainAcc=0.9510
# Fold 3 Epoch 500: Loss=0.046570 | TrainAcc=1.0000
# Fold 3 Epoch 600: Loss=0.046029 | TrainAcc=0.9902
# Fold 3 Epoch 700: Loss=0.024338 | TrainAcc=1.0000
# Fold 3 Epoch 800: Loss=0.017229 | TrainAcc=1.0000
# Fold 3 Epoch 900: Loss=0.005983 | TrainAcc=1.0000
# Fold 3 Epoch 1000: Loss=0.005542 | TrainAcc=1.0000
# Fold 3 Epoch 1100: Loss=0.008618 | TrainAcc=1.0000
# Fold 3 Epoch 1200: Loss=0.004908 | TrainAcc=1.0000
# Fold 3 Epoch 1300: Loss=0.002914 | TrainAcc=1.0000
# Fold 3 Epoch 1400: Loss=0.002078 | TrainAcc=1.0000
# Fold 3 Epoch 1500: Loss=0.004344 | TrainAcc=1.0000
# Fold 3 Epoch 1600: Loss=0.003633 | TrainAcc=1.0000
# Fold 3 Epoch 1700: Loss=0.000893 | TrainAcc=1.0000
# Fold 3 Epoch 1800: Loss=0.003037 | TrainAcc=1.0000
# Fold 3 Epoch 1900: Loss=0.000891 | TrainAcc=1.0000
# Fold 3 Epoch 2000: Loss=0.000779 | TrainAcc=1.0000
# Fold 3 → Acc=0.6591 | Prec=0.8000 | Rec=0.6667 | F1=0.7273 | AUC=0.7190 | CE Loss=2.2973
#
# === Fold 4 ===
# Fold 4 Epoch 1: Loss=0.695029 | TrainAcc=0.4902
# Fold 4 Epoch 100: Loss=0.422443 | TrainAcc=0.8039
# Fold 4 Epoch 200: Loss=0.383760 | TrainAcc=0.8333
# Fold 4 Epoch 300: Loss=0.298730 | TrainAcc=0.8431
# Fold 4 Epoch 400: Loss=0.187177 | TrainAcc=0.9412
# Fold 4 Epoch 500: Loss=0.099063 | TrainAcc=0.9608
# Fold 4 Epoch 600: Loss=0.060942 | TrainAcc=0.9706
# Fold 4 Epoch 700: Loss=0.030654 | TrainAcc=1.0000
# Fold 4 Epoch 800: Loss=0.026602 | TrainAcc=0.9902
# Fold 4 Epoch 900: Loss=0.009299 | TrainAcc=1.0000
# Fold 4 Epoch 1000: Loss=0.008947 | TrainAcc=1.0000
# Fold 4 Epoch 1100: Loss=0.006087 | TrainAcc=1.0000
# Fold 4 Epoch 1200: Loss=0.003337 | TrainAcc=1.0000
# Fold 4 Epoch 1300: Loss=0.003216 | TrainAcc=1.0000
# Fold 4 Epoch 1400: Loss=0.002303 | TrainAcc=1.0000
# Fold 4 Epoch 1500: Loss=0.001952 | TrainAcc=1.0000
# Fold 4 Epoch 1600: Loss=0.007371 | TrainAcc=1.0000
# Fold 4 Epoch 1700: Loss=0.001158 | TrainAcc=1.0000
# Fold 4 Epoch 1800: Loss=0.001039 | TrainAcc=1.0000
# Fold 4 Epoch 1900: Loss=0.033866 | TrainAcc=0.9902
# Fold 4 Epoch 2000: Loss=0.000773 | TrainAcc=1.0000
# Fold 4 → Acc=0.7500 | Prec=0.8065 | Rec=0.8333 | F1=0.8197 | AUC=0.7405 | CE Loss=2.0593
#
# === Fold 5 ===
# Fold 5 Epoch 1: Loss=0.857104 | TrainAcc=0.4314
# Fold 5 Epoch 100: Loss=0.437042 | TrainAcc=0.7745
# Fold 5 Epoch 200: Loss=0.358160 | TrainAcc=0.8333
# Fold 5 Epoch 300: Loss=0.288050 | TrainAcc=0.8824
# Fold 5 Epoch 400: Loss=0.202143 | TrainAcc=0.9216
# Fold 5 Epoch 500: Loss=0.093367 | TrainAcc=0.9902
# Fold 5 Epoch 600: Loss=0.068496 | TrainAcc=0.9804
# Fold 5 Epoch 700: Loss=0.031584 | TrainAcc=1.0000
# Fold 5 Epoch 800: Loss=0.027354 | TrainAcc=1.0000
# Fold 5 Epoch 900: Loss=0.016092 | TrainAcc=1.0000
# Fold 5 Epoch 1000: Loss=0.005352 | TrainAcc=1.0000
# Fold 5 Epoch 1100: Loss=0.014266 | TrainAcc=1.0000
# Fold 5 Epoch 1200: Loss=0.013218 | TrainAcc=1.0000
# Fold 5 Epoch 1300: Loss=0.007680 | TrainAcc=1.0000
# Fold 5 Epoch 1400: Loss=0.007472 | TrainAcc=1.0000
# Fold 5 Epoch 1500: Loss=0.002630 | TrainAcc=1.0000
# Fold 5 Epoch 1600: Loss=0.007935 | TrainAcc=1.0000
# Fold 5 Epoch 1700: Loss=0.002863 | TrainAcc=1.0000
# Fold 5 Epoch 1800: Loss=0.004011 | TrainAcc=1.0000
# Fold 5 Epoch 1900: Loss=0.002913 | TrainAcc=1.0000
# Fold 5 Epoch 2000: Loss=0.003104 | TrainAcc=1.0000
# Fold 5 → Acc=0.6364 | Prec=0.7500 | Rec=0.7000 | F1=0.7241 | AUC=0.6952 | CE Loss=1.6053
#
# === Fold 6 ===
# Fold 6 Epoch 1: Loss=0.772163 | TrainAcc=0.4608
# Fold 6 Epoch 100: Loss=0.418891 | TrainAcc=0.7843
# Fold 6 Epoch 200: Loss=0.366015 | TrainAcc=0.8235
# Fold 6 Epoch 300: Loss=0.260392 | TrainAcc=0.9020
# Fold 6 Epoch 400: Loss=0.127176 | TrainAcc=0.9608
# Fold 6 Epoch 500: Loss=0.060119 | TrainAcc=0.9902
# Fold 6 Epoch 600: Loss=0.046706 | TrainAcc=0.9902
# Fold 6 Epoch 700: Loss=0.043536 | TrainAcc=0.9804
# Fold 6 Epoch 800: Loss=0.007244 | TrainAcc=1.0000
# Fold 6 Epoch 900: Loss=0.004639 | TrainAcc=1.0000
# Fold 6 Epoch 1000: Loss=0.009448 | TrainAcc=1.0000
# Fold 6 Epoch 1100: Loss=0.004544 | TrainAcc=1.0000
# Fold 6 Epoch 1200: Loss=0.002988 | TrainAcc=1.0000
# Fold 6 Epoch 1300: Loss=0.006868 | TrainAcc=1.0000
# Fold 6 Epoch 1400: Loss=0.001801 | TrainAcc=1.0000
# Fold 6 Epoch 1500: Loss=0.012107 | TrainAcc=0.9902
# Fold 6 Epoch 1600: Loss=0.003733 | TrainAcc=1.0000
# Fold 6 Epoch 1700: Loss=0.002275 | TrainAcc=1.0000
# Fold 6 Epoch 1800: Loss=0.001136 | TrainAcc=1.0000
# Fold 6 Epoch 1900: Loss=0.004790 | TrainAcc=1.0000
# Fold 6 Epoch 2000: Loss=0.001318 | TrainAcc=1.0000
# Fold 6 → Acc=0.7500 | Prec=0.7879 | Rec=0.8667 | F1=0.8254 | AUC=0.7333 | CE Loss=2.2558
#
# === Fold 7 ===
# Fold 7 Epoch 1: Loss=0.683171 | TrainAcc=0.5392
# Fold 7 Epoch 100: Loss=0.422196 | TrainAcc=0.7647
# Fold 7 Epoch 200: Loss=0.332942 | TrainAcc=0.8431
# Fold 7 Epoch 300: Loss=0.269622 | TrainAcc=0.8922
# Fold 7 Epoch 400: Loss=0.155139 | TrainAcc=0.9412
# Fold 7 Epoch 500: Loss=0.081858 | TrainAcc=0.9902
# Fold 7 Epoch 600: Loss=0.032667 | TrainAcc=1.0000
# Fold 7 Epoch 700: Loss=0.023472 | TrainAcc=1.0000
# Fold 7 Epoch 800: Loss=0.014757 | TrainAcc=1.0000
# Fold 7 Epoch 900: Loss=0.016019 | TrainAcc=1.0000
# Fold 7 Epoch 1000: Loss=0.006699 | TrainAcc=1.0000
# Fold 7 Epoch 1100: Loss=0.013071 | TrainAcc=1.0000
# Fold 7 Epoch 1200: Loss=0.002373 | TrainAcc=1.0000
# Fold 7 Epoch 1300: Loss=0.001776 | TrainAcc=1.0000
# Fold 7 Epoch 1400: Loss=0.001247 | TrainAcc=1.0000
# Fold 7 Epoch 1500: Loss=0.002893 | TrainAcc=1.0000
# Fold 7 Epoch 1600: Loss=0.000661 | TrainAcc=1.0000
# Fold 7 Epoch 1700: Loss=0.003797 | TrainAcc=1.0000
# Fold 7 Epoch 1800: Loss=0.001442 | TrainAcc=1.0000
# Fold 7 Epoch 1900: Loss=0.000729 | TrainAcc=1.0000
# Fold 7 Epoch 2000: Loss=0.000987 | TrainAcc=1.0000
# Fold 7 → Acc=0.6818 | Prec=0.8333 | Rec=0.6667 | F1=0.7407 | AUC=0.7357 | CE Loss=1.9981
#
# === Fold 8 ===
# Fold 8 Epoch 1: Loss=0.723594 | TrainAcc=0.4608
# Fold 8 Epoch 100: Loss=0.422266 | TrainAcc=0.7843
# Fold 8 Epoch 200: Loss=0.380262 | TrainAcc=0.8333
# Fold 8 Epoch 300: Loss=0.305366 | TrainAcc=0.8431
# Fold 8 Epoch 400: Loss=0.222088 | TrainAcc=0.9020
# Fold 8 Epoch 500: Loss=0.084599 | TrainAcc=0.9804
# Fold 8 Epoch 600: Loss=0.055701 | TrainAcc=0.9902
# Fold 8 Epoch 700: Loss=0.024532 | TrainAcc=1.0000
# Fold 8 Epoch 800: Loss=0.017101 | TrainAcc=1.0000
# Fold 8 Epoch 900: Loss=0.011367 | TrainAcc=1.0000
# Fold 8 Epoch 1000: Loss=0.010994 | TrainAcc=1.0000
# Fold 8 Epoch 1100: Loss=0.004569 | TrainAcc=1.0000
# Fold 8 Epoch 1200: Loss=0.003923 | TrainAcc=1.0000
# Fold 8 Epoch 1300: Loss=0.003236 | TrainAcc=1.0000
# Fold 8 Epoch 1400: Loss=0.001878 | TrainAcc=1.0000
# Fold 8 Epoch 1500: Loss=0.003456 | TrainAcc=1.0000
# Fold 8 Epoch 1600: Loss=0.000759 | TrainAcc=1.0000
# Fold 8 Epoch 1700: Loss=0.002182 | TrainAcc=1.0000
# Fold 8 Epoch 1800: Loss=0.000854 | TrainAcc=1.0000
# Fold 8 Epoch 1900: Loss=0.000618 | TrainAcc=1.0000
# Fold 8 Epoch 2000: Loss=0.000815 | TrainAcc=1.0000
# Fold 8 → Acc=0.6591 | Prec=0.7778 | Rec=0.7000 | F1=0.7368 | AUC=0.7429 | CE Loss=1.8190
#
# === Fold 9 ===
# Fold 9 Epoch 1: Loss=0.633094 | TrainAcc=0.6471
# Fold 9 Epoch 100: Loss=0.437015 | TrainAcc=0.8431
# Fold 9 Epoch 200: Loss=0.409941 | TrainAcc=0.8137
# Fold 9 Epoch 300: Loss=0.316694 | TrainAcc=0.8725
# Fold 9 Epoch 400: Loss=0.196082 | TrainAcc=0.9412
# Fold 9 Epoch 500: Loss=0.080366 | TrainAcc=0.9706
# Fold 9 Epoch 600: Loss=0.033080 | TrainAcc=1.0000
# Fold 9 Epoch 700: Loss=0.035369 | TrainAcc=1.0000
# Fold 9 Epoch 800: Loss=0.017184 | TrainAcc=1.0000
# Fold 9 Epoch 900: Loss=0.015671 | TrainAcc=1.0000
# Fold 9 Epoch 1000: Loss=0.004533 | TrainAcc=1.0000
# Fold 9 Epoch 1100: Loss=0.006762 | TrainAcc=1.0000
# Fold 9 Epoch 1200: Loss=0.004880 | TrainAcc=1.0000
# Fold 9 Epoch 1300: Loss=0.002660 | TrainAcc=1.0000
# Fold 9 Epoch 1400: Loss=0.001194 | TrainAcc=1.0000
# Fold 9 Epoch 1500: Loss=0.005579 | TrainAcc=1.0000
# Fold 9 Epoch 1600: Loss=0.001467 | TrainAcc=1.0000
# Fold 9 Epoch 1700: Loss=0.003179 | TrainAcc=1.0000
# Fold 9 Epoch 1800: Loss=0.002058 | TrainAcc=1.0000
# Fold 9 Epoch 1900: Loss=0.001523 | TrainAcc=1.0000
# Fold 9 Epoch 2000: Loss=0.001002 | TrainAcc=1.0000
# Fold 9 → Acc=0.7045 | Prec=0.7742 | Rec=0.8000 | F1=0.7869 | AUC=0.7976 | CE Loss=1.6609
#
# === Fold 10 ===
# Fold 10 Epoch 1: Loss=0.843562 | TrainAcc=0.3333
# Fold 10 Epoch 100: Loss=0.440895 | TrainAcc=0.7843
# Fold 10 Epoch 200: Loss=0.386654 | TrainAcc=0.8137
# Fold 10 Epoch 300: Loss=0.281959 | TrainAcc=0.9020
# Fold 10 Epoch 400: Loss=0.163333 | TrainAcc=0.9510
# Fold 10 Epoch 500: Loss=0.117912 | TrainAcc=0.9706
# Fold 10 Epoch 600: Loss=0.077175 | TrainAcc=0.9706
# Fold 10 Epoch 700: Loss=0.030171 | TrainAcc=1.0000
# Fold 10 Epoch 800: Loss=0.016509 | TrainAcc=1.0000
# Fold 10 Epoch 900: Loss=0.016303 | TrainAcc=0.9902
# Fold 10 Epoch 1000: Loss=0.011205 | TrainAcc=1.0000
# Fold 10 Epoch 1100: Loss=0.009966 | TrainAcc=1.0000
# Fold 10 Epoch 1200: Loss=0.005321 | TrainAcc=1.0000
# Fold 10 Epoch 1300: Loss=0.004012 | TrainAcc=1.0000
# Fold 10 Epoch 1400: Loss=0.009457 | TrainAcc=0.9902
# Fold 10 Epoch 1500: Loss=0.002756 | TrainAcc=1.0000
# Fold 10 Epoch 1600: Loss=0.007138 | TrainAcc=1.0000
# Fold 10 Epoch 1700: Loss=0.005682 | TrainAcc=1.0000
# Fold 10 Epoch 1800: Loss=0.002157 | TrainAcc=1.0000
# Fold 10 Epoch 1900: Loss=0.005742 | TrainAcc=1.0000
# Fold 10 Epoch 2000: Loss=0.003732 | TrainAcc=1.0000
# Fold 10 → Acc=0.7273 | Prec=0.8750 | Rec=0.7000 | F1=0.7778 | AUC=0.8548 | CE Loss=1.0878
#
# === Fold 11 ===
# Fold 11 Epoch 1: Loss=0.708454 | TrainAcc=0.4902
# Fold 11 Epoch 100: Loss=0.464677 | TrainAcc=0.7745
# Fold 11 Epoch 200: Loss=0.423545 | TrainAcc=0.8137
# Fold 11 Epoch 300: Loss=0.363804 | TrainAcc=0.8235
# Fold 11 Epoch 400: Loss=0.266239 | TrainAcc=0.9118
# Fold 11 Epoch 500: Loss=0.138968 | TrainAcc=0.9608
# Fold 11 Epoch 600: Loss=0.113787 | TrainAcc=0.9510
# Fold 11 Epoch 700: Loss=0.056849 | TrainAcc=0.9804
# Fold 11 Epoch 800: Loss=0.049379 | TrainAcc=0.9902
# Fold 11 Epoch 900: Loss=0.022644 | TrainAcc=1.0000
# Fold 11 Epoch 1000: Loss=0.025539 | TrainAcc=0.9902
# Fold 11 Epoch 1100: Loss=0.013190 | TrainAcc=0.9902
# Fold 11 Epoch 1200: Loss=0.003229 | TrainAcc=1.0000
# Fold 11 Epoch 1300: Loss=0.004919 | TrainAcc=1.0000
# Fold 11 Epoch 1400: Loss=0.005277 | TrainAcc=1.0000
# Fold 11 Epoch 1500: Loss=0.003196 | TrainAcc=1.0000
# Fold 11 Epoch 1600: Loss=0.001566 | TrainAcc=1.0000
# Fold 11 Epoch 1700: Loss=0.007329 | TrainAcc=1.0000
# Fold 11 Epoch 1800: Loss=0.003218 | TrainAcc=1.0000
# Fold 11 Epoch 1900: Loss=0.001085 | TrainAcc=1.0000
# Fold 11 Epoch 2000: Loss=0.001217 | TrainAcc=1.0000
# Fold 11 → Acc=0.7500 | Prec=0.8065 | Rec=0.8333 | F1=0.8197 | AUC=0.7667 | CE Loss=1.6702
#
# === Fold 12 ===
# Fold 12 Epoch 1: Loss=0.790537 | TrainAcc=0.3333
# Fold 12 Epoch 100: Loss=0.469901 | TrainAcc=0.7451
# Fold 12 Epoch 200: Loss=0.416023 | TrainAcc=0.8039
# Fold 12 Epoch 300: Loss=0.333053 | TrainAcc=0.8725
# Fold 12 Epoch 400: Loss=0.179732 | TrainAcc=0.9510
# Fold 12 Epoch 500: Loss=0.087169 | TrainAcc=1.0000
# Fold 12 Epoch 600: Loss=0.079699 | TrainAcc=0.9706
# Fold 12 Epoch 700: Loss=0.025069 | TrainAcc=1.0000
# Fold 12 Epoch 800: Loss=0.020872 | TrainAcc=0.9902
# Fold 12 Epoch 900: Loss=0.007943 | TrainAcc=1.0000
# Fold 12 Epoch 1000: Loss=0.013187 | TrainAcc=1.0000
# Fold 12 Epoch 1100: Loss=0.003414 | TrainAcc=1.0000
# Fold 12 Epoch 1200: Loss=0.006036 | TrainAcc=1.0000
# Fold 12 Epoch 1300: Loss=0.002836 | TrainAcc=1.0000
# Fold 12 Epoch 1400: Loss=0.003902 | TrainAcc=1.0000
# Fold 12 Epoch 1500: Loss=0.005592 | TrainAcc=1.0000
# Fold 12 Epoch 1600: Loss=0.002040 | TrainAcc=1.0000
# Fold 12 Epoch 1700: Loss=0.003279 | TrainAcc=1.0000
# Fold 12 Epoch 1800: Loss=0.001189 | TrainAcc=1.0000
# Fold 12 Epoch 1900: Loss=0.001495 | TrainAcc=1.0000
# Fold 12 Epoch 2000: Loss=0.002079 | TrainAcc=1.0000
# Fold 12 → Acc=0.7045 | Prec=0.8400 | Rec=0.7000 | F1=0.7636 | AUC=0.7714 | CE Loss=1.7422
#
# === Fold 13 ===
# Fold 13 Epoch 1: Loss=0.860224 | TrainAcc=0.3627
# Fold 13 Epoch 100: Loss=0.443500 | TrainAcc=0.7843
# Fold 13 Epoch 200: Loss=0.405146 | TrainAcc=0.7941
# Fold 13 Epoch 300: Loss=0.296030 | TrainAcc=0.8922
# Fold 13 Epoch 400: Loss=0.212605 | TrainAcc=0.9118
# Fold 13 Epoch 500: Loss=0.121407 | TrainAcc=0.9510
# Fold 13 Epoch 600: Loss=0.056372 | TrainAcc=0.9902
# Fold 13 Epoch 700: Loss=0.035508 | TrainAcc=1.0000
# Fold 13 Epoch 800: Loss=0.014243 | TrainAcc=1.0000
# Fold 13 Epoch 900: Loss=0.032640 | TrainAcc=0.9804
# Fold 13 Epoch 1000: Loss=0.006724 | TrainAcc=1.0000
# Fold 13 Epoch 1100: Loss=0.007947 | TrainAcc=1.0000
# Fold 13 Epoch 1200: Loss=0.004974 | TrainAcc=1.0000
# Fold 13 Epoch 1300: Loss=0.014432 | TrainAcc=0.9902
# Fold 13 Epoch 1400: Loss=0.003764 | TrainAcc=1.0000
# Fold 13 Epoch 1500: Loss=0.002401 | TrainAcc=1.0000
# Fold 13 Epoch 1600: Loss=0.004827 | TrainAcc=1.0000
# Fold 13 Epoch 1700: Loss=0.012020 | TrainAcc=0.9902
# Fold 13 Epoch 1800: Loss=0.001492 | TrainAcc=1.0000
# Fold 13 Epoch 1900: Loss=0.001281 | TrainAcc=1.0000
# Fold 13 Epoch 2000: Loss=0.001802 | TrainAcc=1.0000
# Fold 13 → Acc=0.7727 | Prec=0.9167 | Rec=0.7333 | F1=0.8148 | AUC=0.8405 | CE Loss=1.4945
#
# === Fold 14 ===
# Fold 14 Epoch 1: Loss=0.729496 | TrainAcc=0.3922
# Fold 14 Epoch 100: Loss=0.465364 | TrainAcc=0.7647
# Fold 14 Epoch 200: Loss=0.390722 | TrainAcc=0.8333
# Fold 14 Epoch 300: Loss=0.276943 | TrainAcc=0.8824
# Fold 14 Epoch 400: Loss=0.169875 | TrainAcc=0.9706
# Fold 14 Epoch 500: Loss=0.102460 | TrainAcc=0.9804
# Fold 14 Epoch 600: Loss=0.047405 | TrainAcc=1.0000
# Fold 14 Epoch 700: Loss=0.034031 | TrainAcc=0.9902
# Fold 14 Epoch 800: Loss=0.020229 | TrainAcc=1.0000
# Fold 14 Epoch 900: Loss=0.010507 | TrainAcc=1.0000
# Fold 14 Epoch 1000: Loss=0.031724 | TrainAcc=0.9902
# Fold 14 Epoch 1100: Loss=0.003753 | TrainAcc=1.0000
# Fold 14 Epoch 1200: Loss=0.007960 | TrainAcc=1.0000
# Fold 14 Epoch 1300: Loss=0.005653 | TrainAcc=1.0000
# Fold 14 Epoch 1400: Loss=0.002453 | TrainAcc=1.0000
# Fold 14 Epoch 1500: Loss=0.007150 | TrainAcc=1.0000
# Fold 14 Epoch 1600: Loss=0.020528 | TrainAcc=0.9902
# Fold 14 Epoch 1700: Loss=0.006534 | TrainAcc=1.0000
# Fold 14 Epoch 1800: Loss=0.001914 | TrainAcc=1.0000
# Fold 14 Epoch 1900: Loss=0.004081 | TrainAcc=1.0000
# Fold 14 Epoch 2000: Loss=0.000924 | TrainAcc=1.0000
# Fold 14 → Acc=0.6591 | Prec=0.7419 | Rec=0.7667 | F1=0.7541 | AUC=0.7048 | CE Loss=2.0829
#
# === Fold 15 ===
# Fold 15 Epoch 1: Loss=0.758740 | TrainAcc=0.4216
# Fold 15 Epoch 100: Loss=0.457133 | TrainAcc=0.7647
# Fold 15 Epoch 200: Loss=0.375621 | TrainAcc=0.8039
# Fold 15 Epoch 300: Loss=0.282973 | TrainAcc=0.9216
# Fold 15 Epoch 400: Loss=0.208227 | TrainAcc=0.9314
# Fold 15 Epoch 500: Loss=0.130528 | TrainAcc=0.9608
# Fold 15 Epoch 600: Loss=0.086980 | TrainAcc=0.9804
# Fold 15 Epoch 700: Loss=0.051244 | TrainAcc=0.9902
# Fold 15 Epoch 800: Loss=0.020150 | TrainAcc=1.0000
# Fold 15 Epoch 900: Loss=0.009298 | TrainAcc=1.0000
# Fold 15 Epoch 1000: Loss=0.017725 | TrainAcc=1.0000
# Fold 15 Epoch 1100: Loss=0.019771 | TrainAcc=0.9902
# Fold 15 Epoch 1200: Loss=0.004255 | TrainAcc=1.0000
# Fold 15 Epoch 1300: Loss=0.011968 | TrainAcc=0.9902
# Fold 15 Epoch 1400: Loss=0.005295 | TrainAcc=1.0000
# Fold 15 Epoch 1500: Loss=0.004308 | TrainAcc=1.0000
# Fold 15 Epoch 1600: Loss=0.002573 | TrainAcc=1.0000
# Fold 15 Epoch 1700: Loss=0.003252 | TrainAcc=1.0000
# Fold 15 Epoch 1800: Loss=0.003187 | TrainAcc=1.0000
# Fold 15 Epoch 1900: Loss=0.002312 | TrainAcc=1.0000
# Fold 15 Epoch 2000: Loss=0.001414 | TrainAcc=1.0000
# Fold 15 → Acc=0.7273 | Prec=0.8462 | Rec=0.7333 | F1=0.7857 | AUC=0.8405 | CE Loss=1.5861
#
# === Fold 16 ===
# Fold 16 Epoch 1: Loss=1.132943 | TrainAcc=0.3725
# Fold 16 Epoch 100: Loss=0.447278 | TrainAcc=0.7549
# Fold 16 Epoch 200: Loss=0.370238 | TrainAcc=0.8627
# Fold 16 Epoch 300: Loss=0.291753 | TrainAcc=0.8725
# Fold 16 Epoch 400: Loss=0.207814 | TrainAcc=0.9020
# Fold 16 Epoch 500: Loss=0.097171 | TrainAcc=0.9608
# Fold 16 Epoch 600: Loss=0.081284 | TrainAcc=0.9608
# Fold 16 Epoch 700: Loss=0.027221 | TrainAcc=1.0000
# Fold 16 Epoch 800: Loss=0.014389 | TrainAcc=1.0000
# Fold 16 Epoch 900: Loss=0.015164 | TrainAcc=1.0000
# Fold 16 Epoch 1000: Loss=0.020118 | TrainAcc=1.0000
# Fold 16 Epoch 1100: Loss=0.009434 | TrainAcc=1.0000
# Fold 16 Epoch 1200: Loss=0.004598 | TrainAcc=1.0000
# Fold 16 Epoch 1300: Loss=0.003997 | TrainAcc=1.0000
# Fold 16 Epoch 1400: Loss=0.005877 | TrainAcc=1.0000
# Fold 16 Epoch 1500: Loss=0.001292 | TrainAcc=1.0000
# Fold 16 Epoch 1600: Loss=0.002134 | TrainAcc=1.0000
# Fold 16 Epoch 1700: Loss=0.004339 | TrainAcc=1.0000
# Fold 16 Epoch 1800: Loss=0.001946 | TrainAcc=1.0000
# Fold 16 Epoch 1900: Loss=0.001185 | TrainAcc=1.0000
# Fold 16 Epoch 2000: Loss=0.002747 | TrainAcc=1.0000
# Fold 16 → Acc=0.6818 | Prec=0.7105 | Rec=0.9000 | F1=0.7941 | AUC=0.7571 | CE Loss=2.2075
#
# === Fold 17 ===
# Fold 17 Epoch 1: Loss=0.682849 | TrainAcc=0.5490
# Fold 17 Epoch 100: Loss=0.459203 | TrainAcc=0.7843
# Fold 17 Epoch 200: Loss=0.387995 | TrainAcc=0.8333
# Fold 17 Epoch 300: Loss=0.319365 | TrainAcc=0.8529
# Fold 17 Epoch 400: Loss=0.182210 | TrainAcc=0.9314
# Fold 17 Epoch 500: Loss=0.101858 | TrainAcc=0.9902
# Fold 17 Epoch 600: Loss=0.042437 | TrainAcc=1.0000
# Fold 17 Epoch 700: Loss=0.038570 | TrainAcc=0.9902
# Fold 17 Epoch 800: Loss=0.038506 | TrainAcc=0.9902
# Fold 17 Epoch 900: Loss=0.018956 | TrainAcc=0.9902
# Fold 17 Epoch 1000: Loss=0.025874 | TrainAcc=0.9902
# Fold 17 Epoch 1100: Loss=0.006560 | TrainAcc=1.0000
# Fold 17 Epoch 1200: Loss=0.010460 | TrainAcc=1.0000
# Fold 17 Epoch 1300: Loss=0.003864 | TrainAcc=1.0000
# Fold 17 Epoch 1400: Loss=0.004886 | TrainAcc=1.0000
# Fold 17 Epoch 1500: Loss=0.006308 | TrainAcc=1.0000
# Fold 17 Epoch 1600: Loss=0.004303 | TrainAcc=1.0000
# Fold 17 Epoch 1700: Loss=0.003784 | TrainAcc=1.0000
# Fold 17 Epoch 1800: Loss=0.006252 | TrainAcc=1.0000
# Fold 17 Epoch 1900: Loss=0.001129 | TrainAcc=1.0000
# Fold 17 Epoch 2000: Loss=0.010148 | TrainAcc=1.0000
# Fold 17 → Acc=0.7045 | Prec=0.7931 | Rec=0.7667 | F1=0.7797 | AUC=0.7643 | CE Loss=1.3397
#
# === Fold 18 ===
# Fold 18 Epoch 1: Loss=0.734981 | TrainAcc=0.4608
# Fold 18 Epoch 100: Loss=0.471664 | TrainAcc=0.6863
# Fold 18 Epoch 200: Loss=0.403322 | TrainAcc=0.8137
# Fold 18 Epoch 300: Loss=0.298767 | TrainAcc=0.8922
# Fold 18 Epoch 400: Loss=0.178725 | TrainAcc=0.9412
# Fold 18 Epoch 500: Loss=0.103876 | TrainAcc=0.9902
# Fold 18 Epoch 600: Loss=0.054819 | TrainAcc=0.9902
# Fold 18 Epoch 700: Loss=0.026053 | TrainAcc=1.0000
# Fold 18 Epoch 800: Loss=0.020466 | TrainAcc=1.0000
# Fold 18 Epoch 900: Loss=0.010457 | TrainAcc=1.0000
# Fold 18 Epoch 1000: Loss=0.016237 | TrainAcc=1.0000
# Fold 18 Epoch 1100: Loss=0.010029 | TrainAcc=1.0000
# Fold 18 Epoch 1200: Loss=0.011621 | TrainAcc=1.0000
# Fold 18 Epoch 1300: Loss=0.004754 | TrainAcc=1.0000
# Fold 18 Epoch 1400: Loss=0.002257 | TrainAcc=1.0000
# Fold 18 Epoch 1500: Loss=0.007552 | TrainAcc=1.0000
# Fold 18 Epoch 1600: Loss=0.008570 | TrainAcc=1.0000
# Fold 18 Epoch 1700: Loss=0.004270 | TrainAcc=1.0000
# Fold 18 Epoch 1800: Loss=0.000868 | TrainAcc=1.0000
# Fold 18 Epoch 1900: Loss=0.003038 | TrainAcc=1.0000
# Fold 18 Epoch 2000: Loss=0.000947 | TrainAcc=1.0000
# Fold 18 → Acc=0.7045 | Prec=0.7429 | Rec=0.8667 | F1=0.8000 | AUC=0.7857 | CE Loss=1.4417
#
# === Fold 19 ===
# Fold 19 Epoch 1: Loss=0.723187 | TrainAcc=0.4804
# Fold 19 Epoch 100: Loss=0.412714 | TrainAcc=0.7941
# Fold 19 Epoch 200: Loss=0.349149 | TrainAcc=0.8235
# Fold 19 Epoch 300: Loss=0.244610 | TrainAcc=0.9314
# Fold 19 Epoch 400: Loss=0.164891 | TrainAcc=0.9412
# Fold 19 Epoch 500: Loss=0.082092 | TrainAcc=0.9706
# Fold 19 Epoch 600: Loss=0.054755 | TrainAcc=0.9902
# Fold 19 Epoch 700: Loss=0.016025 | TrainAcc=1.0000
# Fold 19 Epoch 800: Loss=0.013127 | TrainAcc=1.0000
# Fold 19 Epoch 900: Loss=0.008750 | TrainAcc=1.0000
# Fold 19 Epoch 1000: Loss=0.008538 | TrainAcc=1.0000
# Fold 19 Epoch 1100: Loss=0.006120 | TrainAcc=1.0000
# Fold 19 Epoch 1200: Loss=0.004148 | TrainAcc=1.0000
# Fold 19 Epoch 1300: Loss=0.002811 | TrainAcc=1.0000
# Fold 19 Epoch 1400: Loss=0.001741 | TrainAcc=1.0000
# Fold 19 Epoch 1500: Loss=0.002005 | TrainAcc=1.0000
# Fold 19 Epoch 1600: Loss=0.001461 | TrainAcc=1.0000
# Fold 19 Epoch 1700: Loss=0.001241 | TrainAcc=1.0000
# Fold 19 Epoch 1800: Loss=0.002043 | TrainAcc=1.0000
# Fold 19 Epoch 1900: Loss=0.001110 | TrainAcc=1.0000
# Fold 19 Epoch 2000: Loss=0.001503 | TrainAcc=1.0000
# Fold 19 → Acc=0.6591 | Prec=0.8000 | Rec=0.6667 | F1=0.7273 | AUC=0.7500 | CE Loss=1.6746
#
# === Fold 20 ===
# Fold 20 Epoch 1: Loss=0.746135 | TrainAcc=0.5490
# Fold 20 Epoch 100: Loss=0.471196 | TrainAcc=0.7647
# Fold 20 Epoch 200: Loss=0.434680 | TrainAcc=0.8137
# Fold 20 Epoch 300: Loss=0.337466 | TrainAcc=0.8725
# Fold 20 Epoch 400: Loss=0.227722 | TrainAcc=0.9216
# Fold 20 Epoch 500: Loss=0.123480 | TrainAcc=0.9706
# Fold 20 Epoch 600: Loss=0.049040 | TrainAcc=0.9804
# Fold 20 Epoch 700: Loss=0.033343 | TrainAcc=0.9902
# Fold 20 Epoch 800: Loss=0.016212 | TrainAcc=1.0000
# Fold 20 Epoch 900: Loss=0.018035 | TrainAcc=1.0000
# Fold 20 Epoch 1000: Loss=0.016365 | TrainAcc=1.0000
# Fold 20 Epoch 1100: Loss=0.009531 | TrainAcc=1.0000
# Fold 20 Epoch 1200: Loss=0.004322 | TrainAcc=1.0000
# Fold 20 Epoch 1300: Loss=0.007002 | TrainAcc=1.0000
# Fold 20 Epoch 1400: Loss=0.004336 | TrainAcc=1.0000
# Fold 20 Epoch 1500: Loss=0.006449 | TrainAcc=1.0000
# Fold 20 Epoch 1600: Loss=0.006290 | TrainAcc=1.0000
# Fold 20 Epoch 1700: Loss=0.004130 | TrainAcc=1.0000
# Fold 20 Epoch 1800: Loss=0.002499 | TrainAcc=1.0000
# Fold 20 Epoch 1900: Loss=0.001341 | TrainAcc=1.0000
# Fold 20 Epoch 2000: Loss=0.004852 | TrainAcc=1.0000
# Fold 20 → Acc=0.6818 | Prec=0.7353 | Rec=0.8333 | F1=0.7812 | AUC=0.7726 | CE Loss=1.8705
#
# === Average Results Across 20 Folds ===
# Accuracy:  0.7080 ± 0.0427
# Precision: 0.7955 ± 0.0486
# Recall:    0.7783 ± 0.0852
# F1-score:  0.7826 ± 0.0382
# CE Loss:   1.7407 ± 0.3317
# AUC:       0.7701 ± 0.0468

# %%
sss = StratifiedShuffleSplit(n_splits=20, test_size=0.5, random_state=42)

accuracies, precisions, recalls, f1_scores, aucs, ce_losses = [], [], [], [], [], []

for fold, (train_idx, test_idx) in enumerate(sss.split(X, y), start=1):
    print(f"\n=== Fold {fold} ===")

    train_idx_t = torch.from_numpy(train_idx).long().to(device)
    y_train_tensor = torch.from_numpy(y[train_idx]).long().to(device)

    model = GAT_Supervised(feats_dim, hidden_dim, num_classes).to(device)
    optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
    ce_loss = nn.CrossEntropyLoss()


    for epoch in range(1, num_epochs + 1):
        model.train()
        optimizer.zero_grad()

        logits = model(data)
        loss = ce_loss(logits[train_idx_t], y_train_tensor)
        loss.backward()
        optimizer.step()

        if epoch % batch_print_freq == 0 or epoch == 1:
            model.eval()
            with torch.no_grad():
                preds_train = logits[train_idx_t].argmax(dim=1)
                acc_train = accuracy_score(y_train_tensor.cpu(), preds_train.cpu())
            print(f"Fold {fold} Epoch {epoch}: "
                  f"Loss={loss.item():.6f} | TrainAcc={acc_train:.4f}")


    model.eval()
    with torch.no_grad():
        out = model(data)
        preds = out.argmax(dim=1).cpu().numpy()
        probs = torch.softmax(out, dim=1)[:, 1].cpu().numpy()  # Probability for class 1

    y_test = y[test_idx]
    y_pred_test = preds[test_idx]
    y_prob_test = probs[test_idx]


    acc = accuracy_score(y_test, y_pred_test)
    prec = precision_score(y_test, y_pred_test, zero_division=0)
    rec = recall_score(y_test, y_pred_test, zero_division=0)
    f1 = f1_score(y_test, y_pred_test, zero_division=0)
    auc = roc_auc_score(y_test, y_prob_test)
    ce = log_loss(y_test, y_prob_test)

    accuracies.append(acc)
    precisions.append(prec)
    recalls.append(rec)
    f1_scores.append(f1)
    aucs.append(auc)
    ce_losses.append(ce)

    print(f"Fold {fold} → "
          f"Acc={acc:.4f} | Prec={prec:.4f} | Rec={rec:.4f} | "
          f"F1={f1:.4f} | AUC={auc:.4f} | CE Loss={ce:.4f}")


print("\n=== Average Results Across 20 Folds ===")
print(f"Accuracy:  {np.mean(accuracies):.4f} ± {np.std(accuracies):.4f}")
print(f"Precision: {np.mean(precisions):.4f} ± {np.std(precisions):.4f}")
print(f"Recall:    {np.mean(recalls):.4f} ± {np.std(recalls):.4f}")
print(f"F1-score:  {np.mean(f1_scores):.4f} ± {np.std(f1_scores):.4f}")
print(f"CE Loss:   {np.mean(ce_losses):.4f} ± {np.std(ce_losses):.4f}")
print(f"AUC:       {np.mean(aucs):.4f} ± {np.std(aucs):.4f}")
# Out:
# === Fold 1 ===
# Fold 1 Epoch 1: Loss=0.640196 | TrainAcc=0.6712
# Fold 1 Epoch 100: Loss=0.401629 | TrainAcc=0.7945
# Fold 1 Epoch 200: Loss=0.290209 | TrainAcc=0.9178
# Fold 1 Epoch 300: Loss=0.222786 | TrainAcc=0.9041
# Fold 1 Epoch 400: Loss=0.126291 | TrainAcc=0.9452
# Fold 1 Epoch 500: Loss=0.083843 | TrainAcc=0.9726
# Fold 1 Epoch 600: Loss=0.037839 | TrainAcc=1.0000
# Fold 1 Epoch 700: Loss=0.023084 | TrainAcc=1.0000
# Fold 1 Epoch 800: Loss=0.016331 | TrainAcc=1.0000
# Fold 1 Epoch 900: Loss=0.007925 | TrainAcc=1.0000
# Fold 1 Epoch 1000: Loss=0.006124 | TrainAcc=1.0000
# Fold 1 Epoch 1100: Loss=0.006260 | TrainAcc=1.0000
# Fold 1 Epoch 1200: Loss=0.007383 | TrainAcc=1.0000
# Fold 1 Epoch 1300: Loss=0.001403 | TrainAcc=1.0000
# Fold 1 Epoch 1400: Loss=0.003296 | TrainAcc=1.0000
# Fold 1 Epoch 1500: Loss=0.002572 | TrainAcc=1.0000
# Fold 1 Epoch 1600: Loss=0.001223 | TrainAcc=1.0000
# Fold 1 Epoch 1700: Loss=0.003836 | TrainAcc=1.0000
# Fold 1 Epoch 1800: Loss=0.001315 | TrainAcc=1.0000
# Fold 1 Epoch 1900: Loss=0.001687 | TrainAcc=1.0000
# Fold 1 Epoch 2000: Loss=0.001282 | TrainAcc=1.0000
# Fold 1 → Acc=0.7260 | Prec=0.7636 | Rec=0.8571 | F1=0.8077 | AUC=0.7900 | CE Loss=1.7234
#
# === Fold 2 ===
# Fold 2 Epoch 1: Loss=0.768762 | TrainAcc=0.4795
# Fold 2 Epoch 100: Loss=0.434218 | TrainAcc=0.7945
# Fold 2 Epoch 200: Loss=0.379046 | TrainAcc=0.8493
# Fold 2 Epoch 300: Loss=0.239225 | TrainAcc=0.9452
# Fold 2 Epoch 400: Loss=0.151676 | TrainAcc=0.9452
# Fold 2 Epoch 500: Loss=0.089970 | TrainAcc=0.9863
# Fold 2 Epoch 600: Loss=0.033781 | TrainAcc=1.0000
# Fold 2 Epoch 700: Loss=0.020226 | TrainAcc=1.0000
# Fold 2 Epoch 800: Loss=0.009960 | TrainAcc=1.0000
# Fold 2 Epoch 900: Loss=0.005099 | TrainAcc=1.0000
# Fold 2 Epoch 1000: Loss=0.014976 | TrainAcc=1.0000
# Fold 2 Epoch 1100: Loss=0.004744 | TrainAcc=1.0000
# Fold 2 Epoch 1200: Loss=0.003294 | TrainAcc=1.0000
# Fold 2 Epoch 1300: Loss=0.008548 | TrainAcc=1.0000
# Fold 2 Epoch 1400: Loss=0.003390 | TrainAcc=1.0000
# Fold 2 Epoch 1500: Loss=0.002024 | TrainAcc=1.0000
# Fold 2 Epoch 1600: Loss=0.001986 | TrainAcc=1.0000
# Fold 2 Epoch 1700: Loss=0.006341 | TrainAcc=1.0000
# Fold 2 Epoch 1800: Loss=0.001202 | TrainAcc=1.0000
# Fold 2 Epoch 1900: Loss=0.000963 | TrainAcc=1.0000
# Fold 2 Epoch 2000: Loss=0.002394 | TrainAcc=1.0000
# Fold 2 → Acc=0.6849 | Prec=0.7500 | Rec=0.7959 | F1=0.7723 | AUC=0.7347 | CE Loss=1.8571
#
# === Fold 3 ===
# Fold 3 Epoch 1: Loss=0.907753 | TrainAcc=0.3151
# Fold 3 Epoch 100: Loss=0.407279 | TrainAcc=0.7808
# Fold 3 Epoch 200: Loss=0.314145 | TrainAcc=0.8630
# Fold 3 Epoch 300: Loss=0.219164 | TrainAcc=0.8904
# Fold 3 Epoch 400: Loss=0.113071 | TrainAcc=0.9589
# Fold 3 Epoch 500: Loss=0.033707 | TrainAcc=1.0000
# Fold 3 Epoch 600: Loss=0.009015 | TrainAcc=1.0000
# Fold 3 Epoch 700: Loss=0.019586 | TrainAcc=1.0000
# Fold 3 Epoch 800: Loss=0.009634 | TrainAcc=1.0000
# Fold 3 Epoch 900: Loss=0.003799 | TrainAcc=1.0000
# Fold 3 Epoch 1000: Loss=0.004214 | TrainAcc=1.0000
# Fold 3 Epoch 1100: Loss=0.003820 | TrainAcc=1.0000
# Fold 3 Epoch 1200: Loss=0.001716 | TrainAcc=1.0000
# Fold 3 Epoch 1300: Loss=0.001504 | TrainAcc=1.0000
# Fold 3 Epoch 1400: Loss=0.001469 | TrainAcc=1.0000
# Fold 3 Epoch 1500: Loss=0.003410 | TrainAcc=1.0000
# Fold 3 Epoch 1600: Loss=0.001213 | TrainAcc=1.0000
# Fold 3 Epoch 1700: Loss=0.001270 | TrainAcc=1.0000
# Fold 3 Epoch 1800: Loss=0.000637 | TrainAcc=1.0000
# Fold 3 Epoch 1900: Loss=0.000436 | TrainAcc=1.0000
# Fold 3 Epoch 2000: Loss=0.000724 | TrainAcc=1.0000
# Fold 3 → Acc=0.6712 | Prec=0.7551 | Rec=0.7551 | F1=0.7551 | AUC=0.7611 | CE Loss=2.1946
#
# === Fold 4 ===
# Fold 4 Epoch 1: Loss=0.668648 | TrainAcc=0.5616
# Fold 4 Epoch 100: Loss=0.319385 | TrainAcc=0.8493
# Fold 4 Epoch 200: Loss=0.249826 | TrainAcc=0.8767
# Fold 4 Epoch 300: Loss=0.160781 | TrainAcc=0.9315
# Fold 4 Epoch 400: Loss=0.093413 | TrainAcc=0.9726
# Fold 4 Epoch 500: Loss=0.060530 | TrainAcc=0.9863
# Fold 4 Epoch 600: Loss=0.021357 | TrainAcc=1.0000
# Fold 4 Epoch 700: Loss=0.020240 | TrainAcc=1.0000
# Fold 4 Epoch 800: Loss=0.008626 | TrainAcc=1.0000
# Fold 4 Epoch 900: Loss=0.005395 | TrainAcc=1.0000
# Fold 4 Epoch 1000: Loss=0.003808 | TrainAcc=1.0000
# Fold 4 Epoch 1100: Loss=0.009197 | TrainAcc=1.0000
# Fold 4 Epoch 1200: Loss=0.001968 | TrainAcc=1.0000
# Fold 4 Epoch 1300: Loss=0.001766 | TrainAcc=1.0000
# Fold 4 Epoch 1400: Loss=0.016041 | TrainAcc=0.9863
# Fold 4 Epoch 1500: Loss=0.002364 | TrainAcc=1.0000
# Fold 4 Epoch 1600: Loss=0.001808 | TrainAcc=1.0000
# Fold 4 Epoch 1700: Loss=0.005791 | TrainAcc=1.0000
# Fold 4 Epoch 1800: Loss=0.000834 | TrainAcc=1.0000
# Fold 4 Epoch 1900: Loss=0.001903 | TrainAcc=1.0000
# Fold 4 Epoch 2000: Loss=0.001163 | TrainAcc=1.0000
# Fold 4 → Acc=0.6986 | Prec=0.7288 | Rec=0.8776 | F1=0.7963 | AUC=0.6276 | CE Loss=2.5293
#
# === Fold 5 ===
# Fold 5 Epoch 1: Loss=0.620187 | TrainAcc=0.6301
# Fold 5 Epoch 100: Loss=0.393677 | TrainAcc=0.8219
# Fold 5 Epoch 200: Loss=0.336996 | TrainAcc=0.8493
# Fold 5 Epoch 300: Loss=0.187745 | TrainAcc=0.8904
# Fold 5 Epoch 400: Loss=0.086139 | TrainAcc=0.9863
# Fold 5 Epoch 500: Loss=0.039204 | TrainAcc=1.0000
# Fold 5 Epoch 600: Loss=0.022995 | TrainAcc=1.0000
# Fold 5 Epoch 700: Loss=0.022156 | TrainAcc=1.0000
# Fold 5 Epoch 800: Loss=0.006802 | TrainAcc=1.0000
# Fold 5 Epoch 900: Loss=0.008135 | TrainAcc=1.0000
# Fold 5 Epoch 1000: Loss=0.009094 | TrainAcc=1.0000
# Fold 5 Epoch 1100: Loss=0.003896 | TrainAcc=1.0000
# Fold 5 Epoch 1200: Loss=0.001831 | TrainAcc=1.0000
# Fold 5 Epoch 1300: Loss=0.002896 | TrainAcc=1.0000
# Fold 5 Epoch 1400: Loss=0.001476 | TrainAcc=1.0000
# Fold 5 Epoch 1500: Loss=0.002738 | TrainAcc=1.0000
# Fold 5 Epoch 1600: Loss=0.000727 | TrainAcc=1.0000
# Fold 5 Epoch 1700: Loss=0.002034 | TrainAcc=1.0000
# Fold 5 Epoch 1800: Loss=0.001736 | TrainAcc=1.0000
# Fold 5 Epoch 1900: Loss=0.000589 | TrainAcc=1.0000
# Fold 5 Epoch 2000: Loss=0.001436 | TrainAcc=1.0000
# Fold 5 → Acc=0.6712 | Prec=0.7551 | Rec=0.7551 | F1=0.7551 | AUC=0.7245 | CE Loss=1.7842
#
# === Fold 6 ===
# Fold 6 Epoch 1: Loss=0.595003 | TrainAcc=0.6438
# Fold 6 Epoch 100: Loss=0.370032 | TrainAcc=0.8219
# Fold 6 Epoch 200: Loss=0.311385 | TrainAcc=0.9041
# Fold 6 Epoch 300: Loss=0.201029 | TrainAcc=0.9452
# Fold 6 Epoch 400: Loss=0.093409 | TrainAcc=1.0000
# Fold 6 Epoch 500: Loss=0.035859 | TrainAcc=1.0000
# Fold 6 Epoch 600: Loss=0.024414 | TrainAcc=0.9863
# Fold 6 Epoch 700: Loss=0.008586 | TrainAcc=1.0000
# Fold 6 Epoch 800: Loss=0.008572 | TrainAcc=1.0000
# Fold 6 Epoch 900: Loss=0.008142 | TrainAcc=1.0000
# Fold 6 Epoch 1000: Loss=0.007536 | TrainAcc=1.0000
# Fold 6 Epoch 1100: Loss=0.003101 | TrainAcc=1.0000
# Fold 6 Epoch 1200: Loss=0.001587 | TrainAcc=1.0000
# Fold 6 Epoch 1300: Loss=0.003311 | TrainAcc=1.0000
# Fold 6 Epoch 1400: Loss=0.021255 | TrainAcc=0.9863
# Fold 6 Epoch 1500: Loss=0.001085 | TrainAcc=1.0000
# Fold 6 Epoch 1600: Loss=0.002161 | TrainAcc=1.0000
# Fold 6 Epoch 1700: Loss=0.000553 | TrainAcc=1.0000
# Fold 6 Epoch 1800: Loss=0.000468 | TrainAcc=1.0000
# Fold 6 Epoch 1900: Loss=0.000863 | TrainAcc=1.0000
# Fold 6 Epoch 2000: Loss=0.001655 | TrainAcc=1.0000
# Fold 6 → Acc=0.6986 | Prec=0.8000 | Rec=0.7347 | F1=0.7660 | AUC=0.7662 | CE Loss=1.8999
#
# === Fold 7 ===
# Fold 7 Epoch 1: Loss=0.648302 | TrainAcc=0.6164
# Fold 7 Epoch 100: Loss=0.416674 | TrainAcc=0.7808
# Fold 7 Epoch 200: Loss=0.392375 | TrainAcc=0.8356
# Fold 7 Epoch 300: Loss=0.293780 | TrainAcc=0.8767
# Fold 7 Epoch 400: Loss=0.167674 | TrainAcc=0.9589
# Fold 7 Epoch 500: Loss=0.071327 | TrainAcc=0.9863
# Fold 7 Epoch 600: Loss=0.030297 | TrainAcc=1.0000
# Fold 7 Epoch 700: Loss=0.032068 | TrainAcc=0.9863
# Fold 7 Epoch 800: Loss=0.004318 | TrainAcc=1.0000
# Fold 7 Epoch 900: Loss=0.010078 | TrainAcc=1.0000
# Fold 7 Epoch 1000: Loss=0.007520 | TrainAcc=1.0000
# Fold 7 Epoch 1100: Loss=0.003508 | TrainAcc=1.0000
# Fold 7 Epoch 1200: Loss=0.003998 | TrainAcc=1.0000
# Fold 7 Epoch 1300: Loss=0.001560 | TrainAcc=1.0000
# Fold 7 Epoch 1400: Loss=0.005477 | TrainAcc=1.0000
# Fold 7 Epoch 1500: Loss=0.004181 | TrainAcc=1.0000
# Fold 7 Epoch 1600: Loss=0.007986 | TrainAcc=1.0000
# Fold 7 Epoch 1700: Loss=0.002295 | TrainAcc=1.0000
# Fold 7 Epoch 1800: Loss=0.001323 | TrainAcc=1.0000
# Fold 7 Epoch 1900: Loss=0.000906 | TrainAcc=1.0000
# Fold 7 Epoch 2000: Loss=0.000541 | TrainAcc=1.0000
# Fold 7 → Acc=0.6164 | Prec=0.7333 | Rec=0.6735 | F1=0.7021 | AUC=0.6650 | CE Loss=2.1070
#
# === Fold 8 ===
# Fold 8 Epoch 1: Loss=0.835935 | TrainAcc=0.4658
# Fold 8 Epoch 100: Loss=0.417584 | TrainAcc=0.7808
# Fold 8 Epoch 200: Loss=0.343074 | TrainAcc=0.8630
# Fold 8 Epoch 300: Loss=0.297624 | TrainAcc=0.8767
# Fold 8 Epoch 400: Loss=0.158068 | TrainAcc=0.9726
# Fold 8 Epoch 500: Loss=0.053797 | TrainAcc=1.0000
# Fold 8 Epoch 600: Loss=0.048664 | TrainAcc=0.9863
# Fold 8 Epoch 700: Loss=0.016240 | TrainAcc=1.0000
# Fold 8 Epoch 800: Loss=0.008517 | TrainAcc=1.0000
# Fold 8 Epoch 900: Loss=0.027040 | TrainAcc=1.0000
# Fold 8 Epoch 1000: Loss=0.002790 | TrainAcc=1.0000
# Fold 8 Epoch 1100: Loss=0.001871 | TrainAcc=1.0000
# Fold 8 Epoch 1200: Loss=0.002905 | TrainAcc=1.0000
# Fold 8 Epoch 1300: Loss=0.007254 | TrainAcc=1.0000
# Fold 8 Epoch 1400: Loss=0.000769 | TrainAcc=1.0000
# Fold 8 Epoch 1500: Loss=0.001511 | TrainAcc=1.0000
# Fold 8 Epoch 1600: Loss=0.001052 | TrainAcc=1.0000
# Fold 8 Epoch 1700: Loss=0.000756 | TrainAcc=1.0000
# Fold 8 Epoch 1800: Loss=0.000779 | TrainAcc=1.0000
# Fold 8 Epoch 1900: Loss=0.000318 | TrainAcc=1.0000
# Fold 8 Epoch 2000: Loss=0.000514 | TrainAcc=1.0000
# Fold 8 → Acc=0.6849 | Prec=0.7826 | Rec=0.7347 | F1=0.7579 | AUC=0.7517 | CE Loss=1.8474
#
# === Fold 9 ===
# Fold 9 Epoch 1: Loss=0.833016 | TrainAcc=0.3288
# Fold 9 Epoch 100: Loss=0.409480 | TrainAcc=0.7671
# Fold 9 Epoch 200: Loss=0.342678 | TrainAcc=0.8630
# Fold 9 Epoch 300: Loss=0.228070 | TrainAcc=0.9041
# Fold 9 Epoch 400: Loss=0.099770 | TrainAcc=1.0000
# Fold 9 Epoch 500: Loss=0.036696 | TrainAcc=1.0000
# Fold 9 Epoch 600: Loss=0.017213 | TrainAcc=1.0000
# Fold 9 Epoch 700: Loss=0.010056 | TrainAcc=1.0000
# Fold 9 Epoch 800: Loss=0.006891 | TrainAcc=1.0000
# Fold 9 Epoch 900: Loss=0.005882 | TrainAcc=1.0000
# Fold 9 Epoch 1000: Loss=0.005820 | TrainAcc=1.0000
# Fold 9 Epoch 1100: Loss=0.003715 | TrainAcc=1.0000
# Fold 9 Epoch 1200: Loss=0.004037 | TrainAcc=1.0000
# Fold 9 Epoch 1300: Loss=0.001062 | TrainAcc=1.0000
# Fold 9 Epoch 1400: Loss=0.001839 | TrainAcc=1.0000
# Fold 9 Epoch 1500: Loss=0.001664 | TrainAcc=1.0000
# Fold 9 Epoch 1600: Loss=0.002081 | TrainAcc=1.0000
# Fold 9 Epoch 1700: Loss=0.000615 | TrainAcc=1.0000
# Fold 9 Epoch 1800: Loss=0.001370 | TrainAcc=1.0000
# Fold 9 Epoch 1900: Loss=0.000625 | TrainAcc=1.0000
# Fold 9 Epoch 2000: Loss=0.001856 | TrainAcc=1.0000
# Fold 9 → Acc=0.6986 | Prec=0.7872 | Rec=0.7551 | F1=0.7708 | AUC=0.7789 | CE Loss=1.5426
#
# === Fold 10 ===
# Fold 10 Epoch 1: Loss=0.748642 | TrainAcc=0.4658
# Fold 10 Epoch 100: Loss=0.421116 | TrainAcc=0.7397
# Fold 10 Epoch 200: Loss=0.335360 | TrainAcc=0.8082
# Fold 10 Epoch 300: Loss=0.204799 | TrainAcc=0.9178
# Fold 10 Epoch 400: Loss=0.080859 | TrainAcc=1.0000
# Fold 10 Epoch 500: Loss=0.028650 | TrainAcc=1.0000
# Fold 10 Epoch 600: Loss=0.021159 | TrainAcc=1.0000
# Fold 10 Epoch 700: Loss=0.022029 | TrainAcc=1.0000
# Fold 10 Epoch 800: Loss=0.012701 | TrainAcc=1.0000
# Fold 10 Epoch 900: Loss=0.009554 | TrainAcc=1.0000
# Fold 10 Epoch 1000: Loss=0.003777 | TrainAcc=1.0000
# Fold 10 Epoch 1100: Loss=0.002666 | TrainAcc=1.0000
# Fold 10 Epoch 1200: Loss=0.003818 | TrainAcc=1.0000
# Fold 10 Epoch 1300: Loss=0.004050 | TrainAcc=1.0000
# Fold 10 Epoch 1400: Loss=0.001349 | TrainAcc=1.0000
# Fold 10 Epoch 1500: Loss=0.001276 | TrainAcc=1.0000
# Fold 10 Epoch 1600: Loss=0.002114 | TrainAcc=1.0000
# Fold 10 Epoch 1700: Loss=0.000793 | TrainAcc=1.0000
# Fold 10 Epoch 1800: Loss=0.006719 | TrainAcc=1.0000
# Fold 10 Epoch 1900: Loss=0.000759 | TrainAcc=1.0000
# Fold 10 Epoch 2000: Loss=0.000390 | TrainAcc=1.0000
# Fold 10 → Acc=0.6575 | Prec=0.7400 | Rec=0.7551 | F1=0.7475 | AUC=0.7024 | CE Loss=2.4230
#
# === Fold 11 ===
# Fold 11 Epoch 1: Loss=0.633012 | TrainAcc=0.5479
# Fold 11 Epoch 100: Loss=0.434203 | TrainAcc=0.7671
# Fold 11 Epoch 200: Loss=0.313916 | TrainAcc=0.9178
# Fold 11 Epoch 300: Loss=0.231175 | TrainAcc=0.9315
# Fold 11 Epoch 400: Loss=0.141631 | TrainAcc=0.9452
# Fold 11 Epoch 500: Loss=0.056433 | TrainAcc=1.0000
# Fold 11 Epoch 600: Loss=0.029597 | TrainAcc=1.0000
# Fold 11 Epoch 700: Loss=0.022371 | TrainAcc=1.0000
# Fold 11 Epoch 800: Loss=0.009111 | TrainAcc=1.0000
# Fold 11 Epoch 900: Loss=0.008844 | TrainAcc=1.0000
# Fold 11 Epoch 1000: Loss=0.004581 | TrainAcc=1.0000
# Fold 11 Epoch 1100: Loss=0.004286 | TrainAcc=1.0000
# Fold 11 Epoch 1200: Loss=0.004742 | TrainAcc=1.0000
# Fold 11 Epoch 1300: Loss=0.001866 | TrainAcc=1.0000
# Fold 11 Epoch 1400: Loss=0.000892 | TrainAcc=1.0000
# Fold 11 Epoch 1500: Loss=0.001718 | TrainAcc=1.0000
# Fold 11 Epoch 1600: Loss=0.002847 | TrainAcc=1.0000
# Fold 11 Epoch 1700: Loss=0.003152 | TrainAcc=1.0000
# Fold 11 Epoch 1800: Loss=0.002397 | TrainAcc=1.0000
# Fold 11 Epoch 1900: Loss=0.001085 | TrainAcc=1.0000
# Fold 11 Epoch 2000: Loss=0.000875 | TrainAcc=1.0000
# Fold 11 → Acc=0.6986 | Prec=0.9091 | Rec=0.6122 | F1=0.7317 | AUC=0.7372 | CE Loss=2.0982
#
# === Fold 12 ===
# Fold 12 Epoch 1: Loss=0.746447 | TrainAcc=0.4110
# Fold 12 Epoch 100: Loss=0.431322 | TrainAcc=0.7671
# Fold 12 Epoch 200: Loss=0.367104 | TrainAcc=0.8767
# Fold 12 Epoch 300: Loss=0.292406 | TrainAcc=0.8767
# Fold 12 Epoch 400: Loss=0.191399 | TrainAcc=0.9589
# Fold 12 Epoch 500: Loss=0.063287 | TrainAcc=1.0000
# Fold 12 Epoch 600: Loss=0.020218 | TrainAcc=1.0000
# Fold 12 Epoch 700: Loss=0.008239 | TrainAcc=1.0000
# Fold 12 Epoch 800: Loss=0.004864 | TrainAcc=1.0000
# Fold 12 Epoch 900: Loss=0.003973 | TrainAcc=1.0000
# Fold 12 Epoch 1000: Loss=0.003079 | TrainAcc=1.0000
# Fold 12 Epoch 1100: Loss=0.002812 | TrainAcc=1.0000
# Fold 12 Epoch 1200: Loss=0.001469 | TrainAcc=1.0000
# Fold 12 Epoch 1300: Loss=0.001676 | TrainAcc=1.0000
# Fold 12 Epoch 1400: Loss=0.004526 | TrainAcc=1.0000
# Fold 12 Epoch 1500: Loss=0.000766 | TrainAcc=1.0000
# Fold 12 Epoch 1600: Loss=0.002080 | TrainAcc=1.0000
# Fold 12 Epoch 1700: Loss=0.004078 | TrainAcc=1.0000
# Fold 12 Epoch 1800: Loss=0.000916 | TrainAcc=1.0000
# Fold 12 Epoch 1900: Loss=0.001291 | TrainAcc=1.0000
# Fold 12 Epoch 2000: Loss=0.000681 | TrainAcc=1.0000
# Fold 12 → Acc=0.7534 | Prec=0.8298 | Rec=0.7959 | F1=0.8125 | AUC=0.8427 | CE Loss=1.1976
#
# === Fold 13 ===
# Fold 13 Epoch 1: Loss=0.798246 | TrainAcc=0.5342
# Fold 13 Epoch 100: Loss=0.453451 | TrainAcc=0.7260
# Fold 13 Epoch 200: Loss=0.387554 | TrainAcc=0.8356
# Fold 13 Epoch 300: Loss=0.327287 | TrainAcc=0.8219
# Fold 13 Epoch 400: Loss=0.211387 | TrainAcc=0.9315
# Fold 13 Epoch 500: Loss=0.098557 | TrainAcc=0.9863
# Fold 13 Epoch 600: Loss=0.046176 | TrainAcc=1.0000
# Fold 13 Epoch 700: Loss=0.012285 | TrainAcc=1.0000
# Fold 13 Epoch 800: Loss=0.010177 | TrainAcc=1.0000
# Fold 13 Epoch 900: Loss=0.008590 | TrainAcc=1.0000
# Fold 13 Epoch 1000: Loss=0.006880 | TrainAcc=1.0000
# Fold 13 Epoch 1100: Loss=0.003508 | TrainAcc=1.0000
# Fold 13 Epoch 1200: Loss=0.003261 | TrainAcc=1.0000
# Fold 13 Epoch 1300: Loss=0.001392 | TrainAcc=1.0000
# Fold 13 Epoch 1400: Loss=0.002626 | TrainAcc=1.0000
# Fold 13 Epoch 1500: Loss=0.001951 | TrainAcc=1.0000
# Fold 13 Epoch 1600: Loss=0.002264 | TrainAcc=1.0000
# Fold 13 Epoch 1700: Loss=0.001219 | TrainAcc=1.0000
# Fold 13 Epoch 1800: Loss=0.001690 | TrainAcc=1.0000
# Fold 13 Epoch 1900: Loss=0.001718 | TrainAcc=1.0000
# Fold 13 Epoch 2000: Loss=0.000737 | TrainAcc=1.0000
# Fold 13 → Acc=0.6438 | Prec=0.7447 | Rec=0.7143 | F1=0.7292 | AUC=0.6416 | CE Loss=2.0746
#
# === Fold 14 ===
# Fold 14 Epoch 1: Loss=0.655372 | TrainAcc=0.6301
# Fold 14 Epoch 100: Loss=0.406772 | TrainAcc=0.7945
# Fold 14 Epoch 200: Loss=0.373592 | TrainAcc=0.8219
# Fold 14 Epoch 300: Loss=0.250780 | TrainAcc=0.9041
# Fold 14 Epoch 400: Loss=0.179678 | TrainAcc=0.9041
# Fold 14 Epoch 500: Loss=0.066595 | TrainAcc=0.9863
# Fold 14 Epoch 600: Loss=0.038373 | TrainAcc=0.9863
# Fold 14 Epoch 700: Loss=0.025165 | TrainAcc=0.9863
# Fold 14 Epoch 800: Loss=0.012235 | TrainAcc=1.0000
# Fold 14 Epoch 900: Loss=0.014273 | TrainAcc=1.0000
# Fold 14 Epoch 1000: Loss=0.010303 | TrainAcc=1.0000
# Fold 14 Epoch 1100: Loss=0.003848 | TrainAcc=1.0000
# Fold 14 Epoch 1200: Loss=0.005058 | TrainAcc=1.0000
# Fold 14 Epoch 1300: Loss=0.005842 | TrainAcc=1.0000
# Fold 14 Epoch 1400: Loss=0.002136 | TrainAcc=1.0000
# Fold 14 Epoch 1500: Loss=0.001813 | TrainAcc=1.0000
# Fold 14 Epoch 1600: Loss=0.000618 | TrainAcc=1.0000
# Fold 14 Epoch 1700: Loss=0.000898 | TrainAcc=1.0000
# Fold 14 Epoch 1800: Loss=0.000951 | TrainAcc=1.0000
# Fold 14 Epoch 1900: Loss=0.004854 | TrainAcc=1.0000
# Fold 14 Epoch 2000: Loss=0.001918 | TrainAcc=1.0000
# Fold 14 → Acc=0.6986 | Prec=0.8000 | Rec=0.7347 | F1=0.7660 | AUC=0.7747 | CE Loss=1.7679
#
# === Fold 15 ===
# Fold 15 Epoch 1: Loss=0.747755 | TrainAcc=0.4247
# Fold 15 Epoch 100: Loss=0.416372 | TrainAcc=0.8082
# Fold 15 Epoch 200: Loss=0.347135 | TrainAcc=0.9041
# Fold 15 Epoch 300: Loss=0.217948 | TrainAcc=0.9452
# Fold 15 Epoch 400: Loss=0.093823 | TrainAcc=1.0000
# Fold 15 Epoch 500: Loss=0.050787 | TrainAcc=0.9863
# Fold 15 Epoch 600: Loss=0.030434 | TrainAcc=1.0000
# Fold 15 Epoch 700: Loss=0.012973 | TrainAcc=1.0000
# Fold 15 Epoch 800: Loss=0.010412 | TrainAcc=1.0000
# Fold 15 Epoch 900: Loss=0.012157 | TrainAcc=1.0000
# Fold 15 Epoch 1000: Loss=0.025564 | TrainAcc=0.9863
# Fold 15 Epoch 1100: Loss=0.002252 | TrainAcc=1.0000
# Fold 15 Epoch 1200: Loss=0.004778 | TrainAcc=1.0000
# Fold 15 Epoch 1300: Loss=0.001327 | TrainAcc=1.0000
# Fold 15 Epoch 1400: Loss=0.005614 | TrainAcc=1.0000
# Fold 15 Epoch 1500: Loss=0.007268 | TrainAcc=1.0000
# Fold 15 Epoch 1600: Loss=0.001477 | TrainAcc=1.0000
# Fold 15 Epoch 1700: Loss=0.000823 | TrainAcc=1.0000
# Fold 15 Epoch 1800: Loss=0.000790 | TrainAcc=1.0000
# Fold 15 Epoch 1900: Loss=0.000530 | TrainAcc=1.0000
# Fold 15 Epoch 2000: Loss=0.000990 | TrainAcc=1.0000
# Fold 15 → Acc=0.6575 | Prec=0.7727 | Rec=0.6939 | F1=0.7312 | AUC=0.7662 | CE Loss=1.7220
#
# === Fold 16 ===
# Fold 16 Epoch 1: Loss=0.753222 | TrainAcc=0.4521
# Fold 16 Epoch 100: Loss=0.426005 | TrainAcc=0.7945
# Fold 16 Epoch 200: Loss=0.380144 | TrainAcc=0.8219
# Fold 16 Epoch 300: Loss=0.313450 | TrainAcc=0.8630
# Fold 16 Epoch 400: Loss=0.205486 | TrainAcc=0.9315
# Fold 16 Epoch 500: Loss=0.114246 | TrainAcc=0.9452
# Fold 16 Epoch 600: Loss=0.050878 | TrainAcc=1.0000
# Fold 16 Epoch 700: Loss=0.027598 | TrainAcc=1.0000
# Fold 16 Epoch 800: Loss=0.022235 | TrainAcc=1.0000
# Fold 16 Epoch 900: Loss=0.024957 | TrainAcc=1.0000
# Fold 16 Epoch 1000: Loss=0.009058 | TrainAcc=1.0000
# Fold 16 Epoch 1100: Loss=0.013242 | TrainAcc=1.0000
# Fold 16 Epoch 1200: Loss=0.008759 | TrainAcc=1.0000
# Fold 16 Epoch 1300: Loss=0.003419 | TrainAcc=1.0000
# Fold 16 Epoch 1400: Loss=0.002799 | TrainAcc=1.0000
# Fold 16 Epoch 1500: Loss=0.003257 | TrainAcc=1.0000
# Fold 16 Epoch 1600: Loss=0.007049 | TrainAcc=1.0000
# Fold 16 Epoch 1700: Loss=0.004842 | TrainAcc=1.0000
# Fold 16 Epoch 1800: Loss=0.002505 | TrainAcc=1.0000
# Fold 16 Epoch 1900: Loss=0.027322 | TrainAcc=0.9863
# Fold 16 Epoch 2000: Loss=0.001956 | TrainAcc=1.0000
# Fold 16 → Acc=0.7260 | Prec=0.8085 | Rec=0.7755 | F1=0.7917 | AUC=0.8104 | CE Loss=1.1061
#
# === Fold 17 ===
# Fold 17 Epoch 1: Loss=0.649215 | TrainAcc=0.6164
# Fold 17 Epoch 100: Loss=0.425154 | TrainAcc=0.8219
# Fold 17 Epoch 200: Loss=0.330113 | TrainAcc=0.8493
# Fold 17 Epoch 300: Loss=0.203208 | TrainAcc=0.9178
# Fold 17 Epoch 400: Loss=0.111387 | TrainAcc=0.9863
# Fold 17 Epoch 500: Loss=0.039277 | TrainAcc=1.0000
# Fold 17 Epoch 600: Loss=0.018274 | TrainAcc=1.0000
# Fold 17 Epoch 700: Loss=0.018727 | TrainAcc=1.0000
# Fold 17 Epoch 800: Loss=0.004465 | TrainAcc=1.0000
# Fold 17 Epoch 900: Loss=0.004374 | TrainAcc=1.0000
# Fold 17 Epoch 1000: Loss=0.001799 | TrainAcc=1.0000
# Fold 17 Epoch 1100: Loss=0.011002 | TrainAcc=1.0000
# Fold 17 Epoch 1200: Loss=0.002699 | TrainAcc=1.0000
# Fold 17 Epoch 1300: Loss=0.001869 | TrainAcc=1.0000
# Fold 17 Epoch 1400: Loss=0.002382 | TrainAcc=1.0000
# Fold 17 Epoch 1500: Loss=0.002154 | TrainAcc=1.0000
# Fold 17 Epoch 1600: Loss=0.003141 | TrainAcc=1.0000
# Fold 17 Epoch 1700: Loss=0.000738 | TrainAcc=1.0000
# Fold 17 Epoch 1800: Loss=0.005509 | TrainAcc=1.0000
# Fold 17 Epoch 1900: Loss=0.000974 | TrainAcc=1.0000
# Fold 17 Epoch 2000: Loss=0.000754 | TrainAcc=1.0000
# Fold 17 → Acc=0.6849 | Prec=0.7407 | Rec=0.8163 | F1=0.7767 | AUC=0.7160 | CE Loss=2.1334
#
# === Fold 18 ===
# Fold 18 Epoch 1: Loss=0.717101 | TrainAcc=0.5342
# Fold 18 Epoch 100: Loss=0.441883 | TrainAcc=0.7397
# Fold 18 Epoch 200: Loss=0.362552 | TrainAcc=0.8493
# Fold 18 Epoch 300: Loss=0.283219 | TrainAcc=0.9041
# Fold 18 Epoch 400: Loss=0.154045 | TrainAcc=0.9589
# Fold 18 Epoch 500: Loss=0.090378 | TrainAcc=0.9863
# Fold 18 Epoch 600: Loss=0.029804 | TrainAcc=1.0000
# Fold 18 Epoch 700: Loss=0.020799 | TrainAcc=1.0000
# Fold 18 Epoch 800: Loss=0.008644 | TrainAcc=1.0000
# Fold 18 Epoch 900: Loss=0.010991 | TrainAcc=1.0000
# Fold 18 Epoch 1000: Loss=0.013313 | TrainAcc=1.0000
# Fold 18 Epoch 1100: Loss=0.004900 | TrainAcc=1.0000
# Fold 18 Epoch 1200: Loss=0.019302 | TrainAcc=1.0000
# Fold 18 Epoch 1300: Loss=0.003801 | TrainAcc=1.0000
# Fold 18 Epoch 1400: Loss=0.003939 | TrainAcc=1.0000
# Fold 18 Epoch 1500: Loss=0.000893 | TrainAcc=1.0000
# Fold 18 Epoch 1600: Loss=0.001626 | TrainAcc=1.0000
# Fold 18 Epoch 1700: Loss=0.004684 | TrainAcc=1.0000
# Fold 18 Epoch 1800: Loss=0.001111 | TrainAcc=1.0000
# Fold 18 Epoch 1900: Loss=0.002857 | TrainAcc=1.0000
# Fold 18 Epoch 2000: Loss=0.001054 | TrainAcc=1.0000
# Fold 18 → Acc=0.7397 | Prec=0.8571 | Rec=0.7347 | F1=0.7912 | AUC=0.7810 | CE Loss=1.5084
#
# === Fold 19 ===
# Fold 19 Epoch 1: Loss=0.711233 | TrainAcc=0.5205
# Fold 19 Epoch 100: Loss=0.343511 | TrainAcc=0.8493
# Fold 19 Epoch 200: Loss=0.302218 | TrainAcc=0.8630
# Fold 19 Epoch 300: Loss=0.211749 | TrainAcc=0.9178
# Fold 19 Epoch 400: Loss=0.093510 | TrainAcc=0.9589
# Fold 19 Epoch 500: Loss=0.023923 | TrainAcc=1.0000
# Fold 19 Epoch 600: Loss=0.013315 | TrainAcc=1.0000
# Fold 19 Epoch 700: Loss=0.010756 | TrainAcc=1.0000
# Fold 19 Epoch 800: Loss=0.011768 | TrainAcc=1.0000
# Fold 19 Epoch 900: Loss=0.013297 | TrainAcc=1.0000
# Fold 19 Epoch 1000: Loss=0.002344 | TrainAcc=1.0000
# Fold 19 Epoch 1100: Loss=0.001597 | TrainAcc=1.0000
# Fold 19 Epoch 1200: Loss=0.001205 | TrainAcc=1.0000
# Fold 19 Epoch 1300: Loss=0.003151 | TrainAcc=1.0000
# Fold 19 Epoch 1400: Loss=0.001092 | TrainAcc=1.0000
# Fold 19 Epoch 1500: Loss=0.000830 | TrainAcc=1.0000
# Fold 19 Epoch 1600: Loss=0.001537 | TrainAcc=1.0000
# Fold 19 Epoch 1700: Loss=0.001068 | TrainAcc=1.0000
# Fold 19 Epoch 1800: Loss=0.000511 | TrainAcc=1.0000
# Fold 19 Epoch 1900: Loss=0.000601 | TrainAcc=1.0000
# Fold 19 Epoch 2000: Loss=0.002315 | TrainAcc=1.0000
# Fold 19 → Acc=0.6849 | Prec=0.7955 | Rec=0.7143 | F1=0.7527 | AUC=0.6977 | CE Loss=2.3128
#
# === Fold 20 ===
# Fold 20 Epoch 1: Loss=0.656904 | TrainAcc=0.6027
# Fold 20 Epoch 100: Loss=0.424585 | TrainAcc=0.7808
# Fold 20 Epoch 200: Loss=0.368801 | TrainAcc=0.7945
# Fold 20 Epoch 300: Loss=0.267398 | TrainAcc=0.8767
# Fold 20 Epoch 400: Loss=0.129303 | TrainAcc=0.9726
# Fold 20 Epoch 500: Loss=0.070839 | TrainAcc=0.9863
# Fold 20 Epoch 600: Loss=0.045042 | TrainAcc=0.9863
# Fold 20 Epoch 700: Loss=0.024611 | TrainAcc=1.0000
# Fold 20 Epoch 800: Loss=0.021848 | TrainAcc=1.0000
# Fold 20 Epoch 900: Loss=0.009872 | TrainAcc=1.0000
# Fold 20 Epoch 1000: Loss=0.003685 | TrainAcc=1.0000
# Fold 20 Epoch 1100: Loss=0.002917 | TrainAcc=1.0000
# Fold 20 Epoch 1200: Loss=0.005844 | TrainAcc=1.0000
# Fold 20 Epoch 1300: Loss=0.001826 | TrainAcc=1.0000
# Fold 20 Epoch 1400: Loss=0.003042 | TrainAcc=1.0000
# Fold 20 Epoch 1500: Loss=0.009151 | TrainAcc=1.0000
# Fold 20 Epoch 1600: Loss=0.002361 | TrainAcc=1.0000
# Fold 20 Epoch 1700: Loss=0.001447 | TrainAcc=1.0000
# Fold 20 Epoch 1800: Loss=0.001899 | TrainAcc=1.0000
# Fold 20 Epoch 1900: Loss=0.001753 | TrainAcc=1.0000
# Fold 20 Epoch 2000: Loss=0.000920 | TrainAcc=1.0000
# Fold 20 → Acc=0.6575 | Prec=0.7000 | Rec=0.8571 | F1=0.7706 | AUC=0.7406 | CE Loss=1.8289
#
# === Average Results Across 20 Folds ===
# Accuracy:  0.6877 ± 0.0323
# Precision: 0.7777 ± 0.0474
# Recall:    0.7571 ± 0.0629
# F1-score:  0.7642 ± 0.0273
# CE Loss:   1.8829 ± 0.3603
# AUC:       0.7405 ± 0.0531

# %%
sss = StratifiedShuffleSplit(n_splits=20, test_size=0.1, random_state=42)

accuracies, precisions, recalls, f1_scores, aucs, ce_losses = [], [], [], [], [], []

for fold, (train_idx, test_idx) in enumerate(sss.split(X, y), start=1):
    print(f"\n=== Fold {fold} ===")

    train_idx_t = torch.from_numpy(train_idx).long().to(device)
    y_train_tensor = torch.from_numpy(y[train_idx]).long().to(device)

    model = GAT_Supervised(feats_dim, hidden_dim, num_classes).to(device)
    optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
    ce_loss = nn.CrossEntropyLoss()


    for epoch in range(1, num_epochs + 1):
        model.train()
        optimizer.zero_grad()

        logits = model(data)
        loss = ce_loss(logits[train_idx_t], y_train_tensor)
        loss.backward()
        optimizer.step()

        if epoch % batch_print_freq == 0 or epoch == 1:
            model.eval()
            with torch.no_grad():
                preds_train = logits[train_idx_t].argmax(dim=1)
                acc_train = accuracy_score(y_train_tensor.cpu(), preds_train.cpu())
            print(f"Fold {fold} Epoch {epoch}: "
                  f"Loss={loss.item():.6f} | TrainAcc={acc_train:.4f}")


    model.eval()
    with torch.no_grad():
        out = model(data)
        preds = out.argmax(dim=1).cpu().numpy()
        probs = torch.softmax(out, dim=1)[:, 1].cpu().numpy()  # Probability for class 1

    y_test = y[test_idx]
    y_pred_test = preds[test_idx]
    y_prob_test = probs[test_idx]


    acc = accuracy_score(y_test, y_pred_test)
    prec = precision_score(y_test, y_pred_test, zero_division=0)
    rec = recall_score(y_test, y_pred_test, zero_division=0)
    f1 = f1_score(y_test, y_pred_test, zero_division=0)
    auc = roc_auc_score(y_test, y_prob_test)
    ce = log_loss(y_test, y_prob_test)

    accuracies.append(acc)
    precisions.append(prec)
    recalls.append(rec)
    f1_scores.append(f1)
    aucs.append(auc)
    ce_losses.append(ce)

    print(f"Fold {fold} → "
          f"Acc={acc:.4f} | Prec={prec:.4f} | Rec={rec:.4f} | "
          f"F1={f1:.4f} | AUC={auc:.4f} | CE Loss={ce:.4f}")


print("\n=== Average Results Across 20 Folds ===")
print(f"Accuracy:  {np.mean(accuracies):.4f} ± {np.std(accuracies):.4f}")
print(f"Precision: {np.mean(precisions):.4f} ± {np.std(precisions):.4f}")
print(f"Recall:    {np.mean(recalls):.4f} ± {np.std(recalls):.4f}")
print(f"F1-score:  {np.mean(f1_scores):.4f} ± {np.std(f1_scores):.4f}")
print(f"CE Loss:   {np.mean(ce_losses):.4f} ± {np.std(ce_losses):.4f}")
print(f"AUC:       {np.mean(aucs):.4f} ± {np.std(aucs):.4f}")
# Out:
# === Fold 1 ===
# Fold 1 Epoch 1: Loss=0.897835 | TrainAcc=0.3359
# Fold 1 Epoch 100: Loss=0.464834 | TrainAcc=0.7405
# Fold 1 Epoch 200: Loss=0.420849 | TrainAcc=0.8092
# Fold 1 Epoch 300: Loss=0.347383 | TrainAcc=0.8550
# Fold 1 Epoch 400: Loss=0.245149 | TrainAcc=0.9237
# Fold 1 Epoch 500: Loss=0.167214 | TrainAcc=0.9389
# Fold 1 Epoch 600: Loss=0.146634 | TrainAcc=0.9618
# Fold 1 Epoch 700: Loss=0.063118 | TrainAcc=0.9847
# Fold 1 Epoch 800: Loss=0.025078 | TrainAcc=1.0000
# Fold 1 Epoch 900: Loss=0.049229 | TrainAcc=0.9771
# Fold 1 Epoch 1000: Loss=0.030973 | TrainAcc=0.9924
# Fold 1 Epoch 1100: Loss=0.021783 | TrainAcc=0.9924
# Fold 1 Epoch 1200: Loss=0.010087 | TrainAcc=1.0000
# Fold 1 Epoch 1300: Loss=0.008423 | TrainAcc=1.0000
# Fold 1 Epoch 1400: Loss=0.007220 | TrainAcc=1.0000
# Fold 1 Epoch 1500: Loss=0.014991 | TrainAcc=0.9924
# Fold 1 Epoch 1600: Loss=0.002679 | TrainAcc=1.0000
# Fold 1 Epoch 1700: Loss=0.004697 | TrainAcc=1.0000
# Fold 1 Epoch 1800: Loss=0.005159 | TrainAcc=1.0000
# Fold 1 Epoch 1900: Loss=0.002006 | TrainAcc=1.0000
# Fold 1 Epoch 2000: Loss=0.004197 | TrainAcc=1.0000
# Fold 1 → Acc=0.6000 | Prec=0.7000 | Rec=0.7000 | F1=0.7000 | AUC=0.7200 | CE Loss=1.1836
#
# === Fold 2 ===
# Fold 2 Epoch 1: Loss=0.711635 | TrainAcc=0.5954
# Fold 2 Epoch 100: Loss=0.448623 | TrainAcc=0.7786
# Fold 2 Epoch 200: Loss=0.373156 | TrainAcc=0.8473
# Fold 2 Epoch 300: Loss=0.303172 | TrainAcc=0.8702
# Fold 2 Epoch 400: Loss=0.206465 | TrainAcc=0.9160
# Fold 2 Epoch 500: Loss=0.098610 | TrainAcc=0.9771
# Fold 2 Epoch 600: Loss=0.048896 | TrainAcc=0.9847
# Fold 2 Epoch 700: Loss=0.030779 | TrainAcc=1.0000
# Fold 2 Epoch 800: Loss=0.018563 | TrainAcc=0.9924
# Fold 2 Epoch 900: Loss=0.008829 | TrainAcc=1.0000
# Fold 2 Epoch 1000: Loss=0.005367 | TrainAcc=1.0000
# Fold 2 Epoch 1100: Loss=0.013354 | TrainAcc=1.0000
# Fold 2 Epoch 1200: Loss=0.003482 | TrainAcc=1.0000
# Fold 2 Epoch 1300: Loss=0.006628 | TrainAcc=1.0000
# Fold 2 Epoch 1400: Loss=0.008845 | TrainAcc=1.0000
# Fold 2 Epoch 1500: Loss=0.002057 | TrainAcc=1.0000
# Fold 2 Epoch 1600: Loss=0.004227 | TrainAcc=1.0000
# Fold 2 Epoch 1700: Loss=0.001506 | TrainAcc=1.0000
# Fold 2 Epoch 1800: Loss=0.004177 | TrainAcc=1.0000
# Fold 2 Epoch 1900: Loss=0.003794 | TrainAcc=1.0000
# Fold 2 Epoch 2000: Loss=0.001795 | TrainAcc=1.0000
# Fold 2 → Acc=0.8000 | Prec=0.8889 | Rec=0.8000 | F1=0.8421 | AUC=0.8000 | CE Loss=2.2525
#
# === Fold 3 ===
# Fold 3 Epoch 1: Loss=0.747254 | TrainAcc=0.3740
# Fold 3 Epoch 100: Loss=0.451959 | TrainAcc=0.7710
# Fold 3 Epoch 200: Loss=0.394531 | TrainAcc=0.8321
# Fold 3 Epoch 300: Loss=0.345449 | TrainAcc=0.8473
# Fold 3 Epoch 400: Loss=0.257894 | TrainAcc=0.9008
# Fold 3 Epoch 500: Loss=0.163537 | TrainAcc=0.9542
# Fold 3 Epoch 600: Loss=0.097483 | TrainAcc=0.9847
# Fold 3 Epoch 700: Loss=0.073253 | TrainAcc=0.9695
# Fold 3 Epoch 800: Loss=0.026743 | TrainAcc=1.0000
# Fold 3 Epoch 900: Loss=0.017922 | TrainAcc=1.0000
# Fold 3 Epoch 1000: Loss=0.013627 | TrainAcc=1.0000
# Fold 3 Epoch 1100: Loss=0.016000 | TrainAcc=0.9924
# Fold 3 Epoch 1200: Loss=0.014925 | TrainAcc=1.0000
# Fold 3 Epoch 1300: Loss=0.022845 | TrainAcc=0.9924
# Fold 3 Epoch 1400: Loss=0.019441 | TrainAcc=0.9924
# Fold 3 Epoch 1500: Loss=0.007834 | TrainAcc=1.0000
# Fold 3 Epoch 1600: Loss=0.004949 | TrainAcc=1.0000
# Fold 3 Epoch 1700: Loss=0.009125 | TrainAcc=0.9924
# Fold 3 Epoch 1800: Loss=0.004105 | TrainAcc=1.0000
# Fold 3 Epoch 1900: Loss=0.005121 | TrainAcc=1.0000
# Fold 3 Epoch 2000: Loss=0.002971 | TrainAcc=1.0000
# Fold 3 → Acc=0.7333 | Prec=0.8750 | Rec=0.7000 | F1=0.7778 | AUC=0.9200 | CE Loss=0.8836
#
# === Fold 4 ===
# Fold 4 Epoch 1: Loss=0.736061 | TrainAcc=0.4275
# Fold 4 Epoch 100: Loss=0.445142 | TrainAcc=0.7786
# Fold 4 Epoch 200: Loss=0.373062 | TrainAcc=0.8473
# Fold 4 Epoch 300: Loss=0.277173 | TrainAcc=0.9237
# Fold 4 Epoch 400: Loss=0.187056 | TrainAcc=0.9160
# Fold 4 Epoch 500: Loss=0.109553 | TrainAcc=0.9618
# Fold 4 Epoch 600: Loss=0.059714 | TrainAcc=0.9847
# Fold 4 Epoch 700: Loss=0.024974 | TrainAcc=1.0000
# Fold 4 Epoch 800: Loss=0.023506 | TrainAcc=0.9924
# Fold 4 Epoch 900: Loss=0.018676 | TrainAcc=1.0000
# Fold 4 Epoch 1000: Loss=0.011867 | TrainAcc=1.0000
# Fold 4 Epoch 1100: Loss=0.006801 | TrainAcc=1.0000
# Fold 4 Epoch 1200: Loss=0.004787 | TrainAcc=1.0000
# Fold 4 Epoch 1300: Loss=0.019624 | TrainAcc=0.9924
# Fold 4 Epoch 1400: Loss=0.009796 | TrainAcc=1.0000
# Fold 4 Epoch 1500: Loss=0.003183 | TrainAcc=1.0000
# Fold 4 Epoch 1600: Loss=0.012649 | TrainAcc=0.9924
# Fold 4 Epoch 1700: Loss=0.003752 | TrainAcc=1.0000
# Fold 4 Epoch 1800: Loss=0.001166 | TrainAcc=1.0000
# Fold 4 Epoch 1900: Loss=0.002787 | TrainAcc=1.0000
# Fold 4 Epoch 2000: Loss=0.001557 | TrainAcc=1.0000
# Fold 4 → Acc=0.7333 | Prec=0.7500 | Rec=0.9000 | F1=0.8182 | AUC=0.8200 | CE Loss=1.7778
#
# === Fold 5 ===
# Fold 5 Epoch 1: Loss=0.712544 | TrainAcc=0.4962
# Fold 5 Epoch 100: Loss=0.437319 | TrainAcc=0.7939
# Fold 5 Epoch 200: Loss=0.407129 | TrainAcc=0.8015
# Fold 5 Epoch 300: Loss=0.346476 | TrainAcc=0.8473
# Fold 5 Epoch 400: Loss=0.267818 | TrainAcc=0.9160
# Fold 5 Epoch 500: Loss=0.136403 | TrainAcc=0.9695
# Fold 5 Epoch 600: Loss=0.075259 | TrainAcc=0.9847
# Fold 5 Epoch 700: Loss=0.050324 | TrainAcc=0.9847
# Fold 5 Epoch 800: Loss=0.035079 | TrainAcc=0.9924
# Fold 5 Epoch 900: Loss=0.018715 | TrainAcc=1.0000
# Fold 5 Epoch 1000: Loss=0.017246 | TrainAcc=0.9924
# Fold 5 Epoch 1100: Loss=0.019039 | TrainAcc=0.9924
# Fold 5 Epoch 1200: Loss=0.019672 | TrainAcc=0.9924
# Fold 5 Epoch 1300: Loss=0.009164 | TrainAcc=1.0000
# Fold 5 Epoch 1400: Loss=0.005459 | TrainAcc=1.0000
# Fold 5 Epoch 1500: Loss=0.004484 | TrainAcc=1.0000
# Fold 5 Epoch 1600: Loss=0.005577 | TrainAcc=1.0000
# Fold 5 Epoch 1700: Loss=0.005048 | TrainAcc=1.0000
# Fold 5 Epoch 1800: Loss=0.003976 | TrainAcc=1.0000
# Fold 5 Epoch 1900: Loss=0.003259 | TrainAcc=1.0000
# Fold 5 Epoch 2000: Loss=0.003858 | TrainAcc=1.0000
# Fold 5 → Acc=0.8000 | Prec=0.8889 | Rec=0.8000 | F1=0.8421 | AUC=0.9000 | CE Loss=0.9193
#
# === Fold 6 ===
# Fold 6 Epoch 1: Loss=0.820346 | TrainAcc=0.3588
# Fold 6 Epoch 100: Loss=0.455104 | TrainAcc=0.7328
# Fold 6 Epoch 200: Loss=0.402604 | TrainAcc=0.8321
# Fold 6 Epoch 300: Loss=0.345332 | TrainAcc=0.8397
# Fold 6 Epoch 400: Loss=0.208853 | TrainAcc=0.9389
# Fold 6 Epoch 500: Loss=0.105979 | TrainAcc=0.9695
# Fold 6 Epoch 600: Loss=0.086270 | TrainAcc=0.9695
# Fold 6 Epoch 700: Loss=0.039394 | TrainAcc=0.9924
# Fold 6 Epoch 800: Loss=0.038512 | TrainAcc=0.9847
# Fold 6 Epoch 900: Loss=0.033691 | TrainAcc=0.9924
# Fold 6 Epoch 1000: Loss=0.015647 | TrainAcc=1.0000
# Fold 6 Epoch 1100: Loss=0.003687 | TrainAcc=1.0000
# Fold 6 Epoch 1200: Loss=0.007901 | TrainAcc=1.0000
# Fold 6 Epoch 1300: Loss=0.009172 | TrainAcc=1.0000
# Fold 6 Epoch 1400: Loss=0.002385 | TrainAcc=1.0000
# Fold 6 Epoch 1500: Loss=0.002394 | TrainAcc=1.0000
# Fold 6 Epoch 1600: Loss=0.001967 | TrainAcc=1.0000
# Fold 6 Epoch 1700: Loss=0.004993 | TrainAcc=1.0000
# Fold 6 Epoch 1800: Loss=0.001093 | TrainAcc=1.0000
# Fold 6 Epoch 1900: Loss=0.001338 | TrainAcc=1.0000
# Fold 6 Epoch 2000: Loss=0.000945 | TrainAcc=1.0000
# Fold 6 → Acc=0.6667 | Prec=0.7778 | Rec=0.7000 | F1=0.7368 | AUC=0.6200 | CE Loss=2.3746
#
# === Fold 7 ===
# Fold 7 Epoch 1: Loss=0.762496 | TrainAcc=0.4809
# Fold 7 Epoch 100: Loss=0.443542 | TrainAcc=0.7786
# Fold 7 Epoch 200: Loss=0.389291 | TrainAcc=0.8244
# Fold 7 Epoch 300: Loss=0.308689 | TrainAcc=0.8168
# Fold 7 Epoch 400: Loss=0.202533 | TrainAcc=0.9160
# Fold 7 Epoch 500: Loss=0.107163 | TrainAcc=0.9847
# Fold 7 Epoch 600: Loss=0.075538 | TrainAcc=0.9771
# Fold 7 Epoch 700: Loss=0.042592 | TrainAcc=0.9847
# Fold 7 Epoch 800: Loss=0.018623 | TrainAcc=1.0000
# Fold 7 Epoch 900: Loss=0.017994 | TrainAcc=1.0000
# Fold 7 Epoch 1000: Loss=0.019498 | TrainAcc=0.9847
# Fold 7 Epoch 1100: Loss=0.007744 | TrainAcc=1.0000
# Fold 7 Epoch 1200: Loss=0.006351 | TrainAcc=1.0000
# Fold 7 Epoch 1300: Loss=0.008069 | TrainAcc=1.0000
# Fold 7 Epoch 1400: Loss=0.019201 | TrainAcc=0.9847
# Fold 7 Epoch 1500: Loss=0.005381 | TrainAcc=1.0000
# Fold 7 Epoch 1600: Loss=0.002209 | TrainAcc=1.0000
# Fold 7 Epoch 1700: Loss=0.007217 | TrainAcc=1.0000
# Fold 7 Epoch 1800: Loss=0.003114 | TrainAcc=1.0000
# Fold 7 Epoch 1900: Loss=0.002501 | TrainAcc=1.0000
# Fold 7 Epoch 2000: Loss=0.001483 | TrainAcc=1.0000
# Fold 7 → Acc=0.6000 | Prec=0.7500 | Rec=0.6000 | F1=0.6667 | AUC=0.6800 | CE Loss=2.7717
#
# === Fold 8 ===
# Fold 8 Epoch 1: Loss=0.730425 | TrainAcc=0.4198
# Fold 8 Epoch 100: Loss=0.422127 | TrainAcc=0.7786
# Fold 8 Epoch 200: Loss=0.363267 | TrainAcc=0.8244
# Fold 8 Epoch 300: Loss=0.278742 | TrainAcc=0.8855
# Fold 8 Epoch 400: Loss=0.166366 | TrainAcc=0.9542
# Fold 8 Epoch 500: Loss=0.091271 | TrainAcc=0.9695
# Fold 8 Epoch 600: Loss=0.045971 | TrainAcc=1.0000
# Fold 8 Epoch 700: Loss=0.032906 | TrainAcc=0.9847
# Fold 8 Epoch 800: Loss=0.020639 | TrainAcc=1.0000
# Fold 8 Epoch 900: Loss=0.014482 | TrainAcc=1.0000
# Fold 8 Epoch 1000: Loss=0.008470 | TrainAcc=1.0000
# Fold 8 Epoch 1100: Loss=0.008975 | TrainAcc=1.0000
# Fold 8 Epoch 1200: Loss=0.006042 | TrainAcc=1.0000
# Fold 8 Epoch 1300: Loss=0.002689 | TrainAcc=1.0000
# Fold 8 Epoch 1400: Loss=0.001340 | TrainAcc=1.0000
# Fold 8 Epoch 1500: Loss=0.005221 | TrainAcc=1.0000
# Fold 8 Epoch 1600: Loss=0.007957 | TrainAcc=1.0000
# Fold 8 Epoch 1700: Loss=0.002520 | TrainAcc=1.0000
# Fold 8 Epoch 1800: Loss=0.001681 | TrainAcc=1.0000
# Fold 8 Epoch 1900: Loss=0.001627 | TrainAcc=1.0000
# Fold 8 Epoch 2000: Loss=0.000596 | TrainAcc=1.0000
# Fold 8 → Acc=0.7333 | Prec=0.7500 | Rec=0.9000 | F1=0.8182 | AUC=0.7400 | CE Loss=2.7680
#
# === Fold 9 ===
# Fold 9 Epoch 1: Loss=0.666947 | TrainAcc=0.6412
# Fold 9 Epoch 100: Loss=0.462625 | TrainAcc=0.7710
# Fold 9 Epoch 200: Loss=0.412740 | TrainAcc=0.8092
# Fold 9 Epoch 300: Loss=0.308554 | TrainAcc=0.8626
# Fold 9 Epoch 400: Loss=0.202493 | TrainAcc=0.9237
# Fold 9 Epoch 500: Loss=0.099403 | TrainAcc=0.9542
# Fold 9 Epoch 600: Loss=0.045250 | TrainAcc=1.0000
# Fold 9 Epoch 700: Loss=0.065651 | TrainAcc=0.9847
# Fold 9 Epoch 800: Loss=0.034375 | TrainAcc=0.9924
# Fold 9 Epoch 900: Loss=0.034217 | TrainAcc=0.9847
# Fold 9 Epoch 1000: Loss=0.017733 | TrainAcc=0.9924
# Fold 9 Epoch 1100: Loss=0.010183 | TrainAcc=1.0000
# Fold 9 Epoch 1200: Loss=0.005697 | TrainAcc=1.0000
# Fold 9 Epoch 1300: Loss=0.010405 | TrainAcc=0.9924
# Fold 9 Epoch 1400: Loss=0.005608 | TrainAcc=1.0000
# Fold 9 Epoch 1500: Loss=0.002722 | TrainAcc=1.0000
# Fold 9 Epoch 1600: Loss=0.005770 | TrainAcc=1.0000
# Fold 9 Epoch 1700: Loss=0.002419 | TrainAcc=1.0000
# Fold 9 Epoch 1800: Loss=0.002638 | TrainAcc=1.0000
# Fold 9 Epoch 1900: Loss=0.002129 | TrainAcc=1.0000
# Fold 9 Epoch 2000: Loss=0.000923 | TrainAcc=1.0000
# Fold 9 → Acc=0.5333 | Prec=0.6667 | Rec=0.6000 | F1=0.6316 | AUC=0.6000 | CE Loss=2.6373
#
# === Fold 10 ===
# Fold 10 Epoch 1: Loss=0.700766 | TrainAcc=0.4885
# Fold 10 Epoch 100: Loss=0.471595 | TrainAcc=0.7634
# Fold 10 Epoch 200: Loss=0.371897 | TrainAcc=0.8550
# Fold 10 Epoch 300: Loss=0.268263 | TrainAcc=0.8855
# Fold 10 Epoch 400: Loss=0.175847 | TrainAcc=0.9466
# Fold 10 Epoch 500: Loss=0.103679 | TrainAcc=0.9847
# Fold 10 Epoch 600: Loss=0.076330 | TrainAcc=0.9771
# Fold 10 Epoch 700: Loss=0.030046 | TrainAcc=1.0000
# Fold 10 Epoch 800: Loss=0.028863 | TrainAcc=1.0000
# Fold 10 Epoch 900: Loss=0.021839 | TrainAcc=1.0000
# Fold 10 Epoch 1000: Loss=0.012647 | TrainAcc=1.0000
# Fold 10 Epoch 1100: Loss=0.013232 | TrainAcc=1.0000
# Fold 10 Epoch 1200: Loss=0.003749 | TrainAcc=1.0000
# Fold 10 Epoch 1300: Loss=0.005688 | TrainAcc=1.0000
# Fold 10 Epoch 1400: Loss=0.004136 | TrainAcc=1.0000
# Fold 10 Epoch 1500: Loss=0.003534 | TrainAcc=1.0000
# Fold 10 Epoch 1600: Loss=0.003183 | TrainAcc=1.0000
# Fold 10 Epoch 1700: Loss=0.001784 | TrainAcc=1.0000
# Fold 10 Epoch 1800: Loss=0.003478 | TrainAcc=1.0000
# Fold 10 Epoch 1900: Loss=0.001277 | TrainAcc=1.0000
# Fold 10 Epoch 2000: Loss=0.001947 | TrainAcc=1.0000
# Fold 10 → Acc=0.8000 | Prec=0.8889 | Rec=0.8000 | F1=0.8421 | AUC=0.8200 | CE Loss=1.4003
#
# === Fold 11 ===
# Fold 11 Epoch 1: Loss=0.648181 | TrainAcc=0.6412
# Fold 11 Epoch 100: Loss=0.413121 | TrainAcc=0.7939
# Fold 11 Epoch 200: Loss=0.353202 | TrainAcc=0.8550
# Fold 11 Epoch 300: Loss=0.270156 | TrainAcc=0.8855
# Fold 11 Epoch 400: Loss=0.182740 | TrainAcc=0.9313
# Fold 11 Epoch 500: Loss=0.093493 | TrainAcc=0.9695
# Fold 11 Epoch 600: Loss=0.033609 | TrainAcc=1.0000
# Fold 11 Epoch 700: Loss=0.030943 | TrainAcc=0.9924
# Fold 11 Epoch 800: Loss=0.025059 | TrainAcc=1.0000
# Fold 11 Epoch 900: Loss=0.007475 | TrainAcc=1.0000
# Fold 11 Epoch 1000: Loss=0.010426 | TrainAcc=1.0000
# Fold 11 Epoch 1100: Loss=0.005912 | TrainAcc=1.0000
# Fold 11 Epoch 1200: Loss=0.004877 | TrainAcc=1.0000
# Fold 11 Epoch 1300: Loss=0.008724 | TrainAcc=1.0000
# Fold 11 Epoch 1400: Loss=0.003667 | TrainAcc=1.0000
# Fold 11 Epoch 1500: Loss=0.001647 | TrainAcc=1.0000
# Fold 11 Epoch 1600: Loss=0.002391 | TrainAcc=1.0000
# Fold 11 Epoch 1700: Loss=0.005175 | TrainAcc=1.0000
# Fold 11 Epoch 1800: Loss=0.001460 | TrainAcc=1.0000
# Fold 11 Epoch 1900: Loss=0.002451 | TrainAcc=1.0000
# Fold 11 Epoch 2000: Loss=0.014783 | TrainAcc=0.9924
# Fold 11 → Acc=0.6667 | Prec=0.7273 | Rec=0.8000 | F1=0.7619 | AUC=0.7000 | CE Loss=2.5712
#
# === Fold 12 ===
# Fold 12 Epoch 1: Loss=0.722612 | TrainAcc=0.4809
# Fold 12 Epoch 100: Loss=0.452462 | TrainAcc=0.7557
# Fold 12 Epoch 200: Loss=0.391837 | TrainAcc=0.7939
# Fold 12 Epoch 300: Loss=0.305084 | TrainAcc=0.8473
# Fold 12 Epoch 400: Loss=0.202532 | TrainAcc=0.9466
# Fold 12 Epoch 500: Loss=0.092220 | TrainAcc=0.9847
# Fold 12 Epoch 600: Loss=0.058942 | TrainAcc=1.0000
# Fold 12 Epoch 700: Loss=0.040383 | TrainAcc=0.9924
# Fold 12 Epoch 800: Loss=0.027153 | TrainAcc=0.9924
# Fold 12 Epoch 900: Loss=0.011299 | TrainAcc=1.0000
# Fold 12 Epoch 1000: Loss=0.016616 | TrainAcc=0.9924
# Fold 12 Epoch 1100: Loss=0.021450 | TrainAcc=1.0000
# Fold 12 Epoch 1200: Loss=0.016420 | TrainAcc=0.9924
# Fold 12 Epoch 1300: Loss=0.006425 | TrainAcc=1.0000
# Fold 12 Epoch 1400: Loss=0.010960 | TrainAcc=0.9924
# Fold 12 Epoch 1500: Loss=0.004271 | TrainAcc=1.0000
# Fold 12 Epoch 1600: Loss=0.002588 | TrainAcc=1.0000
# Fold 12 Epoch 1700: Loss=0.001860 | TrainAcc=1.0000
# Fold 12 Epoch 1800: Loss=0.003266 | TrainAcc=1.0000
# Fold 12 Epoch 1900: Loss=0.005889 | TrainAcc=1.0000
# Fold 12 Epoch 2000: Loss=0.001495 | TrainAcc=1.0000
# Fold 12 → Acc=0.6000 | Prec=0.7000 | Rec=0.7000 | F1=0.7000 | AUC=0.7200 | CE Loss=1.9446
#
# === Fold 13 ===
# Fold 13 Epoch 1: Loss=0.745003 | TrainAcc=0.4198
# Fold 13 Epoch 100: Loss=0.471992 | TrainAcc=0.7481
# Fold 13 Epoch 200: Loss=0.401130 | TrainAcc=0.8092
# Fold 13 Epoch 300: Loss=0.330427 | TrainAcc=0.8626
# Fold 13 Epoch 400: Loss=0.213250 | TrainAcc=0.9237
# Fold 13 Epoch 500: Loss=0.121696 | TrainAcc=0.9771
# Fold 13 Epoch 600: Loss=0.091135 | TrainAcc=0.9618
# Fold 13 Epoch 700: Loss=0.033551 | TrainAcc=1.0000
# Fold 13 Epoch 800: Loss=0.029746 | TrainAcc=1.0000
# Fold 13 Epoch 900: Loss=0.021774 | TrainAcc=0.9924
# Fold 13 Epoch 1000: Loss=0.024777 | TrainAcc=1.0000
# Fold 13 Epoch 1100: Loss=0.012557 | TrainAcc=1.0000
# Fold 13 Epoch 1200: Loss=0.006877 | TrainAcc=1.0000
# Fold 13 Epoch 1300: Loss=0.004797 | TrainAcc=1.0000
# Fold 13 Epoch 1400: Loss=0.005538 | TrainAcc=1.0000
# Fold 13 Epoch 1500: Loss=0.002684 | TrainAcc=1.0000
# Fold 13 Epoch 1600: Loss=0.002724 | TrainAcc=1.0000
# Fold 13 Epoch 1700: Loss=0.001584 | TrainAcc=1.0000
# Fold 13 Epoch 1800: Loss=0.012704 | TrainAcc=0.9924
# Fold 13 Epoch 1900: Loss=0.004119 | TrainAcc=1.0000
# Fold 13 Epoch 2000: Loss=0.002156 | TrainAcc=1.0000
# Fold 13 → Acc=0.8000 | Prec=0.7692 | Rec=1.0000 | F1=0.8696 | AUC=0.8800 | CE Loss=1.2111
#
# === Fold 14 ===
# Fold 14 Epoch 1: Loss=0.727635 | TrainAcc=0.3740
# Fold 14 Epoch 100: Loss=0.434729 | TrainAcc=0.7786
# Fold 14 Epoch 200: Loss=0.376067 | TrainAcc=0.8397
# Fold 14 Epoch 300: Loss=0.293728 | TrainAcc=0.9008
# Fold 14 Epoch 400: Loss=0.203619 | TrainAcc=0.9313
# Fold 14 Epoch 500: Loss=0.126869 | TrainAcc=0.9542
# Fold 14 Epoch 600: Loss=0.100387 | TrainAcc=0.9695
# Fold 14 Epoch 700: Loss=0.037200 | TrainAcc=0.9924
# Fold 14 Epoch 800: Loss=0.021550 | TrainAcc=1.0000
# Fold 14 Epoch 900: Loss=0.028270 | TrainAcc=0.9924
# Fold 14 Epoch 1000: Loss=0.013483 | TrainAcc=1.0000
# Fold 14 Epoch 1100: Loss=0.007926 | TrainAcc=1.0000
# Fold 14 Epoch 1200: Loss=0.007704 | TrainAcc=1.0000
# Fold 14 Epoch 1300: Loss=0.006356 | TrainAcc=1.0000
# Fold 14 Epoch 1400: Loss=0.010608 | TrainAcc=1.0000
# Fold 14 Epoch 1500: Loss=0.004213 | TrainAcc=1.0000
# Fold 14 Epoch 1600: Loss=0.006315 | TrainAcc=1.0000
# Fold 14 Epoch 1700: Loss=0.010960 | TrainAcc=1.0000
# Fold 14 Epoch 1800: Loss=0.004432 | TrainAcc=1.0000
# Fold 14 Epoch 1900: Loss=0.001996 | TrainAcc=1.0000
# Fold 14 Epoch 2000: Loss=0.002523 | TrainAcc=1.0000
# Fold 14 → Acc=0.6667 | Prec=0.7778 | Rec=0.7000 | F1=0.7368 | AUC=0.7000 | CE Loss=2.7072
#
# === Fold 15 ===
# Fold 15 Epoch 1: Loss=0.763023 | TrainAcc=0.4427
# Fold 15 Epoch 100: Loss=0.448300 | TrainAcc=0.7481
# Fold 15 Epoch 200: Loss=0.375816 | TrainAcc=0.8321
# Fold 15 Epoch 300: Loss=0.300790 | TrainAcc=0.8550
# Fold 15 Epoch 400: Loss=0.228584 | TrainAcc=0.9160
# Fold 15 Epoch 500: Loss=0.168334 | TrainAcc=0.9313
# Fold 15 Epoch 600: Loss=0.074741 | TrainAcc=1.0000
# Fold 15 Epoch 700: Loss=0.046004 | TrainAcc=0.9924
# Fold 15 Epoch 800: Loss=0.037178 | TrainAcc=0.9924
# Fold 15 Epoch 900: Loss=0.025243 | TrainAcc=0.9924
# Fold 15 Epoch 1000: Loss=0.017033 | TrainAcc=0.9924
# Fold 15 Epoch 1100: Loss=0.008400 | TrainAcc=1.0000
# Fold 15 Epoch 1200: Loss=0.017706 | TrainAcc=0.9924
# Fold 15 Epoch 1300: Loss=0.003583 | TrainAcc=1.0000
# Fold 15 Epoch 1400: Loss=0.002300 | TrainAcc=1.0000
# Fold 15 Epoch 1500: Loss=0.003759 | TrainAcc=1.0000
# Fold 15 Epoch 1600: Loss=0.002353 | TrainAcc=1.0000
# Fold 15 Epoch 1700: Loss=0.003791 | TrainAcc=1.0000
# Fold 15 Epoch 1800: Loss=0.003429 | TrainAcc=1.0000
# Fold 15 Epoch 1900: Loss=0.006877 | TrainAcc=0.9924
# Fold 15 Epoch 2000: Loss=0.008130 | TrainAcc=1.0000
# Fold 15 → Acc=0.8000 | Prec=0.8182 | Rec=0.9000 | F1=0.8571 | AUC=0.8600 | CE Loss=0.9328
#
# === Fold 16 ===
# Fold 16 Epoch 1: Loss=0.656563 | TrainAcc=0.5878
# Fold 16 Epoch 100: Loss=0.451936 | TrainAcc=0.7863
# Fold 16 Epoch 200: Loss=0.386386 | TrainAcc=0.7939
# Fold 16 Epoch 300: Loss=0.298533 | TrainAcc=0.8855
# Fold 16 Epoch 400: Loss=0.222106 | TrainAcc=0.9084
# Fold 16 Epoch 500: Loss=0.121864 | TrainAcc=0.9466
# Fold 16 Epoch 600: Loss=0.073148 | TrainAcc=0.9771
# Fold 16 Epoch 700: Loss=0.049164 | TrainAcc=0.9847
# Fold 16 Epoch 800: Loss=0.019923 | TrainAcc=1.0000
# Fold 16 Epoch 900: Loss=0.027844 | TrainAcc=0.9924
# Fold 16 Epoch 1000: Loss=0.016952 | TrainAcc=1.0000
# Fold 16 Epoch 1100: Loss=0.010377 | TrainAcc=1.0000
# Fold 16 Epoch 1200: Loss=0.002985 | TrainAcc=1.0000
# Fold 16 Epoch 1300: Loss=0.009090 | TrainAcc=1.0000
# Fold 16 Epoch 1400: Loss=0.003462 | TrainAcc=1.0000
# Fold 16 Epoch 1500: Loss=0.005979 | TrainAcc=1.0000
# Fold 16 Epoch 1600: Loss=0.001798 | TrainAcc=1.0000
# Fold 16 Epoch 1700: Loss=0.004719 | TrainAcc=1.0000
# Fold 16 Epoch 1800: Loss=0.002466 | TrainAcc=1.0000
# Fold 16 Epoch 1900: Loss=0.002841 | TrainAcc=1.0000
# Fold 16 Epoch 2000: Loss=0.011478 | TrainAcc=0.9924
# Fold 16 → Acc=0.8000 | Prec=0.8889 | Rec=0.8000 | F1=0.8421 | AUC=0.9000 | CE Loss=0.8802
#
# === Fold 17 ===
# Fold 17 Epoch 1: Loss=0.713820 | TrainAcc=0.5038
# Fold 17 Epoch 100: Loss=0.454657 | TrainAcc=0.7634
# Fold 17 Epoch 200: Loss=0.383556 | TrainAcc=0.8015
# Fold 17 Epoch 300: Loss=0.281980 | TrainAcc=0.8779
# Fold 17 Epoch 400: Loss=0.188872 | TrainAcc=0.9237
# Fold 17 Epoch 500: Loss=0.101058 | TrainAcc=0.9618
# Fold 17 Epoch 600: Loss=0.038689 | TrainAcc=1.0000
# Fold 17 Epoch 700: Loss=0.043257 | TrainAcc=0.9771
# Fold 17 Epoch 800: Loss=0.032365 | TrainAcc=0.9847
# Fold 17 Epoch 900: Loss=0.021465 | TrainAcc=1.0000
# Fold 17 Epoch 1000: Loss=0.012522 | TrainAcc=1.0000
# Fold 17 Epoch 1100: Loss=0.006213 | TrainAcc=1.0000
# Fold 17 Epoch 1200: Loss=0.008455 | TrainAcc=1.0000
# Fold 17 Epoch 1300: Loss=0.004091 | TrainAcc=1.0000
# Fold 17 Epoch 1400: Loss=0.006807 | TrainAcc=1.0000
# Fold 17 Epoch 1500: Loss=0.001991 | TrainAcc=1.0000
# Fold 17 Epoch 1600: Loss=0.007434 | TrainAcc=1.0000
# Fold 17 Epoch 1700: Loss=0.001812 | TrainAcc=1.0000
# Fold 17 Epoch 1800: Loss=0.002696 | TrainAcc=1.0000
# Fold 17 Epoch 1900: Loss=0.002352 | TrainAcc=1.0000
# Fold 17 Epoch 2000: Loss=0.001677 | TrainAcc=1.0000
# Fold 17 → Acc=0.5333 | Prec=0.6667 | Rec=0.6000 | F1=0.6316 | AUC=0.5400 | CE Loss=3.2590
#
# === Fold 18 ===
# Fold 18 Epoch 1: Loss=0.673677 | TrainAcc=0.6183
# Fold 18 Epoch 100: Loss=0.447023 | TrainAcc=0.7710
# Fold 18 Epoch 200: Loss=0.369966 | TrainAcc=0.8244
# Fold 18 Epoch 300: Loss=0.285760 | TrainAcc=0.8855
# Fold 18 Epoch 400: Loss=0.225534 | TrainAcc=0.9160
# Fold 18 Epoch 500: Loss=0.116074 | TrainAcc=0.9695
# Fold 18 Epoch 600: Loss=0.079778 | TrainAcc=0.9695
# Fold 18 Epoch 700: Loss=0.049401 | TrainAcc=0.9847
# Fold 18 Epoch 800: Loss=0.040909 | TrainAcc=0.9924
# Fold 18 Epoch 900: Loss=0.007441 | TrainAcc=1.0000
# Fold 18 Epoch 1000: Loss=0.013244 | TrainAcc=1.0000
# Fold 18 Epoch 1100: Loss=0.007685 | TrainAcc=1.0000
# Fold 18 Epoch 1200: Loss=0.006747 | TrainAcc=1.0000
# Fold 18 Epoch 1300: Loss=0.004228 | TrainAcc=1.0000
# Fold 18 Epoch 1400: Loss=0.001763 | TrainAcc=1.0000
# Fold 18 Epoch 1500: Loss=0.002507 | TrainAcc=1.0000
# Fold 18 Epoch 1600: Loss=0.003478 | TrainAcc=1.0000
# Fold 18 Epoch 1700: Loss=0.003331 | TrainAcc=1.0000
# Fold 18 Epoch 1800: Loss=0.002581 | TrainAcc=1.0000
# Fold 18 Epoch 1900: Loss=0.002278 | TrainAcc=1.0000
# Fold 18 Epoch 2000: Loss=0.002026 | TrainAcc=1.0000
# Fold 18 → Acc=0.7333 | Prec=1.0000 | Rec=0.6000 | F1=0.7500 | AUC=0.8200 | CE Loss=1.6275
#
# === Fold 19 ===
# Fold 19 Epoch 1: Loss=0.705419 | TrainAcc=0.4962
# Fold 19 Epoch 100: Loss=0.451320 | TrainAcc=0.7481
# Fold 19 Epoch 200: Loss=0.390244 | TrainAcc=0.8321
# Fold 19 Epoch 300: Loss=0.345053 | TrainAcc=0.8244
# Fold 19 Epoch 400: Loss=0.262902 | TrainAcc=0.9008
# Fold 19 Epoch 500: Loss=0.148681 | TrainAcc=0.9389
# Fold 19 Epoch 600: Loss=0.098029 | TrainAcc=0.9924
# Fold 19 Epoch 700: Loss=0.047538 | TrainAcc=1.0000
# Fold 19 Epoch 800: Loss=0.049692 | TrainAcc=0.9695
# Fold 19 Epoch 900: Loss=0.041658 | TrainAcc=0.9847
# Fold 19 Epoch 1000: Loss=0.012970 | TrainAcc=1.0000
# Fold 19 Epoch 1100: Loss=0.023694 | TrainAcc=1.0000
# Fold 19 Epoch 1200: Loss=0.017683 | TrainAcc=0.9924
# Fold 19 Epoch 1300: Loss=0.006861 | TrainAcc=1.0000
# Fold 19 Epoch 1400: Loss=0.008199 | TrainAcc=1.0000
# Fold 19 Epoch 1500: Loss=0.010171 | TrainAcc=1.0000
# Fold 19 Epoch 1600: Loss=0.009391 | TrainAcc=1.0000
# Fold 19 Epoch 1700: Loss=0.012919 | TrainAcc=0.9924
# Fold 19 Epoch 1800: Loss=0.006864 | TrainAcc=1.0000
# Fold 19 Epoch 1900: Loss=0.006913 | TrainAcc=1.0000
# Fold 19 Epoch 2000: Loss=0.003492 | TrainAcc=1.0000
# Fold 19 → Acc=0.6667 | Prec=0.8571 | Rec=0.6000 | F1=0.7059 | AUC=0.7200 | CE Loss=1.7375
#
# === Fold 20 ===
# Fold 20 Epoch 1: Loss=0.647208 | TrainAcc=0.6260
# Fold 20 Epoch 100: Loss=0.454422 | TrainAcc=0.7634
# Fold 20 Epoch 200: Loss=0.378398 | TrainAcc=0.8244
# Fold 20 Epoch 300: Loss=0.257376 | TrainAcc=0.9008
# Fold 20 Epoch 400: Loss=0.182848 | TrainAcc=0.9160
# Fold 20 Epoch 500: Loss=0.141993 | TrainAcc=0.9618
# Fold 20 Epoch 600: Loss=0.077582 | TrainAcc=0.9695
# Fold 20 Epoch 700: Loss=0.050462 | TrainAcc=0.9924
# Fold 20 Epoch 800: Loss=0.035762 | TrainAcc=0.9771
# Fold 20 Epoch 900: Loss=0.019370 | TrainAcc=1.0000
# Fold 20 Epoch 1000: Loss=0.006519 | TrainAcc=1.0000
# Fold 20 Epoch 1100: Loss=0.010616 | TrainAcc=1.0000
# Fold 20 Epoch 1200: Loss=0.012171 | TrainAcc=0.9924
# Fold 20 Epoch 1300: Loss=0.004107 | TrainAcc=1.0000
# Fold 20 Epoch 1400: Loss=0.003144 | TrainAcc=1.0000
# Fold 20 Epoch 1500: Loss=0.003439 | TrainAcc=1.0000
# Fold 20 Epoch 1600: Loss=0.002984 | TrainAcc=1.0000
# Fold 20 Epoch 1700: Loss=0.006066 | TrainAcc=1.0000
# Fold 20 Epoch 1800: Loss=0.003665 | TrainAcc=1.0000
# Fold 20 Epoch 1900: Loss=0.008512 | TrainAcc=1.0000
# Fold 20 Epoch 2000: Loss=0.002760 | TrainAcc=1.0000
# Fold 20 → Acc=0.6667 | Prec=0.7273 | Rec=0.8000 | F1=0.7619 | AUC=0.7200 | CE Loss=1.5861
#
# === Average Results Across 20 Folds ===
# Accuracy:  0.6967 ± 0.0881
# Precision: 0.7934 ± 0.0882
# Recall:    0.7500 ± 0.1162
# F1-score:  0.7646 ± 0.0735
# CE Loss:   1.8713 ± 0.7336
# AUC:       0.7590 ± 0.1038
