# %%
import os
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as nnFn
import torch.optim as optim
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, log_loss
from torch_geometric.data import Data
from torch_geometric.nn import ChebConv

device = 'cuda' if torch.cuda.is_available() else 'cpu'
print("Device:", device)

control_path = "/home/snu/Downloads/NIFD_Patients_FA_Histogram_Feature.npy"
patient_path = "/home/snu/Downloads/NIFD_Control_FA_Histogram_Feature.npy"

Histogram_feature_Control_FA_array = np.load(control_path, allow_pickle=True)
Histogram_feature_Patient_FA_array = np.load(patient_path, allow_pickle=True)

X = np.vstack([Histogram_feature_Control_FA_array, Histogram_feature_Patient_FA_array])
y = np.hstack([
    np.zeros(Histogram_feature_Control_FA_array.shape[0], dtype=np.int64),
    np.ones(Histogram_feature_Patient_FA_array.shape[0], dtype=np.int64)
])

num_nodes, num_feats = X.shape
print(f"Features: {X.shape}, Labels: {y.shape}")

# Shuffle for reproducibility
rng = np.random.RandomState(42)
perm = rng.permutation(num_nodes)
X = X[perm]
y = y[perm]

def create_adj(F_data, alpha=1):
    norms = np.linalg.norm(F_data, axis=1, keepdims=True)
    norms[norms == 0] = 1.0
    F_norm = F_data / norms
    W = np.dot(F_norm, F_norm.T)
    W = np.where(W >= alpha, 1.0, 0.0).astype(np.float32)
    if W.max() > 0:
        W = W / W.max()
    return W

alpha = 0.5
W = create_adj(X, alpha=alpha)
np.fill_diagonal(W, 1.0)

def load_data(adj, node_feats):
    node_feats = torch.from_numpy(node_feats).float()
    rows, cols = np.nonzero(adj > 0)
    edge_index = torch.from_numpy(np.vstack([rows, cols]).astype(np.int64))
    return Data(x=node_feats, edge_index=edge_index)

data = load_data(W, X).to(device)
print(data)

class Cheb_AE(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim, device, activ="RELU", dropout=0.25, K=3):
        super(Cheb_AE, self).__init__()
        self.device = device

        self.conv1 = ChebConv(input_dim, hidden_dim, K=K)
        self.bn1 = nn.BatchNorm1d(hidden_dim)
        self.dropout = nn.Dropout(dropout)
        self.fc = nn.Linear(hidden_dim, output_dim)


        self.decoder = nn.Sequential(
            nn.Linear(hidden_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, input_dim)
        )

        activations = {
            "SELU": nnFn.selu,
            "SiLU": nnFn.silu,
            "GELU": nnFn.gelu,
            "RELU": nnFn.relu,
            "ELU": nnFn.elu
        }
        self.act = activations.get(activ, nnFn.relu)

    def forward(self, x, edge_index):
        # Encoder
        h = self.conv1(x, edge_index)
        h = self.bn1(h)
        h = self.act(h)
        h = self.dropout(h)

        # Classification
        logits = self.fc(h)

        # Reconstruction
        recon = self.decoder(h)

        return logits, recon, h



feats_dim = num_feats
hidden_dim = 512
num_classes = 2
num_epochs = 2000
lr = 1e-4
weight_decay = 1e-4
batch_print_freq = 100
lambda_recon = 0.05

sss = StratifiedShuffleSplit(n_splits=20, test_size=0.3, random_state=42)
accuracies, precisions, recalls, f1_scores, aucs, ce_losses = [], [], [], [], [], []
y_all = y.copy()

for fold, (train_val_idx, test_idx_global) in enumerate(sss.split(X, y_all), start=1):
    print(f"\n=== Fold {fold} ===")
    control_idx = np.where(y_all == 0)[0]
    patient_idx = np.where(y_all == 1)[0]
    sss_class = StratifiedShuffleSplit(n_splits=20, test_size=0.3, random_state=fold)
    control_train_idx, _ = next(sss_class.split(X[control_idx], y_all[control_idx]))
    patient_train_idx, _ = next(sss_class.split(X[patient_idx], y_all[patient_idx]))
    control_train = control_idx[control_train_idx]
    patient_train = patient_idx[patient_train_idx]
    train_idx_final = np.concatenate([control_train, patient_train])
    np.random.shuffle(train_idx_final)

    print(f"Train Control: {len(control_train)}, Train Patient: {len(patient_train)}")
    train_idx_t = torch.from_numpy(train_idx_final).long().to(device)
    y_train_tensor = torch.from_numpy(y_all[train_idx_final]).long().to(device)

    model = Cheb_AE(feats_dim, hidden_dim, num_classes, device, activ="RELU", dropout=0.25, K=3).to(device)
    optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
    ce_loss_fn = nn.CrossEntropyLoss()
    recon_loss_fn = nn.MSELoss()
    data = load_data(W, X).to(device)

    for epoch in range(1, num_epochs + 1):
        model.train()
        optimizer.zero_grad()
        logits, recon_x, _ = model(data.x, data.edge_index)

        loss_sup = ce_loss_fn(logits[train_idx_t], y_train_tensor)
        loss_recon = recon_loss_fn(recon_x, data.x)
        total_loss = loss_sup + lambda_recon * loss_recon

        if torch.isnan(total_loss) or torch.isinf(total_loss):
            print(f"NaN/Inf detected at fold {fold} epoch {epoch}. Aborting epoch.")
            break

        total_loss.backward()
        optimizer.step()

        if epoch % batch_print_freq == 0 or epoch == 1:
            model.eval()
            with torch.no_grad():
                logits_eval, _, _ = model(data.x, data.edge_index)
                preds_train = logits_eval[train_idx_t].argmax(dim=1)
                acc_train = accuracy_score(y_train_tensor.cpu(), preds_train.cpu())
            print(f"Fold {fold} Epoch {epoch}: TotalLoss={total_loss.item():.6f} | Sup={loss_sup.item():.6f} | Recon={loss_recon.item():.6f} | TrainAcc={acc_train:.4f}")

    model.eval()
    with torch.no_grad():
        out_logits, _, _ = model(data.x, data.edge_index)
        preds = out_logits.argmax(dim=1).cpu().numpy()
        probs = nnFn.softmax(out_logits, dim=1)[:, 1].cpu().numpy()

    y_test = y_all[test_idx_global]
    y_pred_test = preds[test_idx_global]
    y_prob_test = probs[test_idx_global]

    acc = accuracy_score(y_test, y_pred_test)
    prec = precision_score(y_test, y_pred_test, zero_division=0)
    rec = recall_score(y_test, y_pred_test, zero_division=0)
    f1 = f1_score(y_test, y_pred_test, zero_division=0)
    try:
        auc = roc_auc_score(y_test, y_prob_test)
    except ValueError:
        auc = float('nan')
    ce = log_loss(y_test, y_prob_test)

    accuracies.append(acc)
    precisions.append(prec)
    recalls.append(rec)
    f1_scores.append(f1)
    aucs.append(auc)
    ce_losses.append(ce)

    print(f"Fold {fold} → Acc={acc:.4f} | Prec={prec:.4f} | Rec={rec:.4f} | F1={f1:.4f} | AUC={auc:.4f} | CE Loss={ce:.4f}")


print("\n=== Average Results Across 20 Folds ===")
print(f"Accuracy:  {np.mean(accuracies):.4f} ± {np.std(accuracies):.4f}")
print(f"Precision: {np.mean(precisions):.4f} ± {np.std(precisions):.4f}")
print(f"Recall:    {np.mean(recalls):.4f} ± {np.std(recalls):.4f}")
print(f"F1-score:  {np.mean(f1_scores):.4f} ± {np.std(f1_scores):.4f}")
print(f"CE Loss:   {np.mean(ce_losses):.4f} ± {np.std(ce_losses):.4f}")
print(f"AUC:       {np.nanmean(aucs):.4f} ± {np.nanstd(aucs):.4f}")
# Out:
# Device: cuda
# Features: (146, 180), Labels: (146,)
# Data(x=[146, 180], edge_index=[2, 21256])
#
# === Fold 1 ===
# Train Control: 68, Train Patient: 33
# Fold 1 Epoch 1: TotalLoss=0.668963 | Sup=0.666957 | Recon=0.040116 | TrainAcc=0.6733
# Fold 1 Epoch 100: TotalLoss=0.134438 | Sup=0.134261 | Recon=0.003533 | TrainAcc=1.0000
# Fold 1 Epoch 200: TotalLoss=0.036148 | Sup=0.036066 | Recon=0.001636 | TrainAcc=1.0000
# Fold 1 Epoch 300: TotalLoss=0.014569 | Sup=0.014523 | Recon=0.000918 | TrainAcc=1.0000
# Fold 1 Epoch 400: TotalLoss=0.008602 | Sup=0.008572 | Recon=0.000600 | TrainAcc=1.0000
# Fold 1 Epoch 500: TotalLoss=0
| TrainAcc=1.0000
# Fold 3 Epoch 1000: TotalLoss=0.001375 | Sup=0.001345 | Recon=0.000596 | TrainAcc=1.0000
# Fold 3 Epoch 1100: TotalLoss=0.001034 | Sup=0.001004 | Recon=0.000603 | TrainAcc=1.0000
# Fold 3 Epoch 1200: TotalLoss=0.000992 | Sup=0.000962 | Recon=0.000615 | TrainAcc=1.0000
# Fold 3 Epoch 1300: TotalLoss=0.000704 | Sup=0.000673 | Recon=0.000615 | TrainAcc=1.0000
# Fold 3 Epoch 1400: TotalLoss=0.000767 | Sup=0.000735 | Recon=0.000627 | TrainAcc=1.0000
# Fold 3 Epoch 1500: TotalLoss=0.000669 | Sup=0.000638 | Recon=0.000624 | TrainAcc=1.0000
# Fold 3 Epoch 1600: TotalLoss=0.000568 | Sup=0.000537 | Recon=0.000635 | TrainAcc=1.0000
# Fold 3 Epoch 1700: TotalLoss=0.000512 | Sup=0.000480 | Recon=0.000635 | TrainAcc=1.0000
# Fold 3 Epoch 1800: TotalLoss=0.000511 | Sup=0.000479 | Recon=0.000643 | TrainAcc=1.0000
# Fold 3 Epoch 1900: TotalLoss=0.000419 | Sup=0.000388 | Recon=0.000638 | TrainAcc=1.0000
# Fold 3 Epoch 2000: TotalLoss=0.000436 | Sup=0.000404 | Recon=0.000643 | TrainAcc=1.0000
# Fold 3 → Acc=0.8864 | Prec=0.8462 | Rec=0.7857 | F1=0.8148 | AUC=0.9833 | CE Loss=0.3017
#
# === Fold 4 ===
# Train Control: 68, Train Patient: 33
# Fold 4 Epoch 1: TotalLoss=0.809829 | Sup=0.807666 | Recon=0.043256 | TrainAcc=0.3267
# Fold 4 Epoch 100: TotalLoss=0.135615 | Sup=0.135445 | Recon=0.003404 | TrainAcc=1.0000
# Fold 4 Epoch 200: TotalLoss=0.040572 | Sup=0.040493 | Recon=0.001584 | TrainAcc=1.0000
# Fold 4 Epoch 300: TotalLoss=0.017068 | Sup=0.017024 | Recon=0.000894 | TrainAcc=1.0000
# Fold 4 Epoch 400: TotalLoss=0.010179 | Sup=0.010149 | Recon=0.000595 | TrainAcc=1.0000
# Fold 4 Epoch 500: TotalLoss=0.005595 | Sup=0.005570 | Recon=0.000507 | TrainAcc=1.0000
# Fold 4 Epoch 600: TotalLoss=0.004121 | Sup=0.004096 | Recon=0.000508 | TrainAcc=1.0000
# Fold 4 Epoch 700: TotalLoss=0.002583 | Sup=0.002557 | Recon=0.000523 | TrainAcc=1.0000
# Fold 4 Epoch 800: TotalLoss=0.002304 | Sup=0.002277 | Recon=0.000551 | TrainAcc=1.0000
# Fold 4 Epoch 900: TotalLoss=0.001820 | Sup=0.001791 | Recon=0.000575 | TrainAcc=1.0000
# Fold 4 Epoch 1000: TotalLoss=0.001450 | Sup=0.001421 | Recon=0.000588 | TrainAcc=1.0000
# Fold 4 Epoch 1100: TotalLoss=0.001238 | Sup=0.001208 | Recon=0.000596 | TrainAcc=1.0000
# Fold 4 Epoch 1200: TotalLoss=0.001304 | Sup=0.001273 | Recon=0.000612 | TrainAcc=1.0000
# Fold 4 Epoch 1300: TotalLoss=0.000955 | Sup=0.000924 | Recon=0.000617 | TrainAcc=1.0000
# Fold 4 Epoch 1400: TotalLoss=0.000807 | Sup=0.000776 | Recon=0.000620 | TrainAcc=1.0000
# Fold 4 Epoch 1500: TotalLoss=0.000705 | Sup=0.000674 | Recon=0.000625 | TrainAcc=1.0000
# Fold 4 Epoch 1600: TotalLoss=0.000679 | Sup=0.000648 | Recon=0.000627 | TrainAcc=1.0000
# Fold 4 Epoch 1700: TotalLoss=0.000618 | Sup=0.000586 | Recon=0.000636 | TrainAcc=1.0000
# Fold 4 Epoch 1800: TotalLoss=0.000572 | Sup=0.000540 | Recon=0.000633 | TrainAcc=1.0000
# Fold 4 Epoch 1900: TotalLoss=0.000533 | Sup=0.000501 | Recon=0.000638 | TrainAcc=1.0000
# Fold 4 Epoch 2000: TotalLoss=0.000436 | Sup=0.000405 | Recon=0.000632 | TrainAcc=1.0000
# Fold 4 → Acc=0.9773 | Prec=1.0000 | Rec=0.9286 | F1=0.9630 | AUC=0.9881 | CE Loss=0.1018
#
# === Fold 5 ===
# Train Control: 68, Train Patient: 33
# Fold 5 Epoch 1: TotalLoss=0.730512 | Sup=0.728099 | Recon=0.048264 | TrainAcc=0.6436
# Fold 5 Epoch 100: TotalLoss=0.149753 | Sup=0.149567 | Recon=0.003706 | TrainAcc=1.0000
# Fold 5 Epoch 200: TotalLoss=0.041701 | Sup=0.041615 | Recon=0.001724 | TrainAcc=1.0000
# Fold 5 Epoch 300: TotalLoss=0.015995 | Sup=0.015947 | Recon=0.000952 | TrainAcc=1.0000
# Fold 5 Epoch 400: TotalLoss=0.008458 | Sup=0.008427 | Recon=0.000629 | TrainAcc=1.0000
# Fold 5 Epoch 500: TotalLoss=0.006237 | Sup=0.006211 | Recon=0.000530 | TrainAcc=1.0000
# Fold 5 Epoch 600: TotalLoss=0.003704 | Sup=0.003677 | Recon=0.000525 | TrainAcc=1.0000
# Fold 5 Epoch 700: TotalLoss=0.003025 | Sup=0.002997 | Recon=0.000547 | TrainAcc=1.0000
# Fold 5 Epoch 800: TotalLoss=0.002528 | Sup=0.002499 | Recon=0.000572 | TrainAcc=1.0000
# Fold 5 Epoch 900: TotalLoss=0.001751 | Sup=0.001722 | Recon=0.000591 | TrainAcc=1.0000
# Fold 5 Epoch 1000: TotalLoss=0.001517 | Sup=0.001487 | Recon=0.000606 | TrainAcc=1.0000
# Fold 5 Epoch 1100: TotalLoss=0.001408 | Sup=0.001377 | Recon=0.000624 | TrainAcc=1.0000
# Fold 5 Epoch 1200: TotalLoss=0.001132 | Sup=0.001101 | Recon=0.000622 | TrainAcc=1.0000
# Fold 5 Epoch 1300: TotalLoss=0.000965 | Sup=0.000933 | Recon=0.000633 | TrainAcc=1.0000
# Fold 5 Epoch 1400: TotalLoss=0.000978 | Sup=0.000946 | Recon=0.000638 | TrainAcc=1.0000
# Fold 5 Epoch 1500: TotalLoss=0.000680 | Sup=0.000648 | Recon=0.000637 | TrainAcc=1.0000
# Fold 5 Epoch 1600: TotalLoss=0.000725 | Sup=0.000693 | Recon=0.000649 | TrainAcc=1.0000
# Fold 5 Epoch 1700: TotalLoss=0.000652 | Sup=0.000619 | Recon=0.000649 | TrainAcc=1.0000
# Fold 5 Epoch 1800: TotalLoss=0.000562 | Sup=0.000530 | Recon=0.000653 | TrainAcc=1.0000
# Fold 5 Epoch 1900: TotalLoss=0.000545 | Sup=0.000512 | Recon=0.000657 | TrainAcc=1.0000
# Fold 5 Epoch 2000: TotalLoss=0.000478 | Sup=0.000445 | Recon=0.000653 | TrainAcc=1.0000
# Fold 5 → Acc=0.9318 | Prec=0.8667 | Rec=0.9286 | F1=0.8966 | AUC=0.9833 | CE Loss=0.2882
#
# === Fold 6 ===
# Train Control: 68, Train Patient: 33
# Fold 6 Epoch 1: TotalLoss=0.798199 | Sup=0.795952 | Recon=0.044935 | TrainAcc=0.6139
# Fold 6 Epoch 100: TotalLoss=0.145501 | Sup=0.145320 | Recon=0.003631 | TrainAcc=1.0000
# Fold 6 Epoch 200: TotalLoss=0.040088 | Sup=0.040005 | Recon=0.001659 | TrainAcc=1.0000
# Fold 6 Epoch 300: TotalLoss=0.016462 | Sup=0.016416 | Recon=0.000922 | TrainAcc=1.0000
# Fold 6 Epoch 400: TotalLoss=0.008794 | Sup=0.008764 | Recon=0.000609 | TrainAcc=1.0000
# Fold 6 Epoch 500: TotalLoss=0.005254 | Sup=0.005228 | Recon=0.000517 | TrainAcc=1.0000
# Fold 6 Epoch 600: TotalLoss=0.003667 | Sup=0.003641 | Recon=0.000515 | TrainAcc=1.0000
# Fold 6 Epoch 700: TotalLoss=0.002964 | Sup=0.002937 | Recon=0.000532 | TrainAcc=1.0000
# Fold 6 Epoch 800: TotalLoss=0.002256 | Sup=0.002228 | Recon=0.000561 | TrainAcc=1.0000
# Fold 6 Epoch 900: TotalLoss=0.001673 | Sup=0.001645 | Recon=0.000577 | TrainAcc=1.0000
# Fold 6 Epoch 1000: TotalLoss=0.001498 | Sup=0.001469 | Recon=0.000587 | TrainAcc=1.0000
# Fold 6 Epoch 1100: TotalLoss=0.001309 | Sup=0.001279 | Recon=0.000601 | TrainAcc=1.0000
# Fold 6 Epoch 1200: TotalLoss=0.001057 | Sup=0.001026 | Recon=0.000615 | TrainAcc=1.0000
# Fold 6 Epoch 1300: TotalLoss=0.000919 | Sup=0.000888 | Recon=0.000620 | TrainAcc=1.0000
# Fold 6 Epoch 1400: TotalLoss=0.000769 | Sup=0.000737 | Recon=0.000626 | TrainAcc=1.0000
# Fold 6 Epoch 1500: TotalLoss=0.000885 | Sup=0.000854 | Recon=0.000628 | TrainAcc=1.0000
# Fold 6 Epoch 1600: TotalLoss=0.000623 | Sup=0.000591 | Recon=0.000632 | TrainAcc=1.0000
# Fold 6 Epoch 1700: TotalLoss=0.000659 | Sup=0.000628 | Recon=0.000634 | TrainAcc=1.0000
# Fold 6 Epoch 1800: TotalLoss=0.000561 | Sup=0.000529 | Recon=0.000640 | TrainAcc=1.0000
# Fold 6 Epoch 1900: TotalLoss=0.000474 | Sup=0.000443 | Recon=0.000636 | TrainAcc=1.0000
# Fold 6 Epoch 2000: TotalLoss=0.000510 | Sup=0.000478 | Recon=0.000643 | TrainAcc=1.0000
# Fold 6 → Acc=0.9318 | Prec=0.9231 | Rec=0.8571 | F1=0.8889 | AUC=0.9905 | CE Loss=0.2054
#
# === Fold 7 ===
# Train Control: 68, Train Patient: 33
# Fold 7 Epoch 1: TotalLoss=0.775566 | Sup=0.773383 | Recon=0.043654 | TrainAcc=0.5644
# Fold 7 Epoch 100: TotalLoss=0.146448 | Sup=0.146266 | Recon=0.003640 | TrainAcc=1.0000
# Fold 7 Epoch 200: TotalLoss=0.040315 | Sup=0.040231 | Recon=0.001683 | TrainAcc=1.0000
# Fold 7 Epoch 300: TotalLoss=0.015746 | Sup=0.015699 | Recon=0.000931 | TrainAcc=1.0000
# Fold 7 Epoch 400: TotalLoss=0.009138 | Sup=0.009107 | Recon=0.000614 | TrainAcc=1.0000
# Fold 7 Epoch 500: TotalLoss=0.005628 | Sup=0.005602 | Recon=0.000512 | TrainAcc=1.0000
# Fold 7 Epoch 600: TotalLoss=0.003599 | Sup=0.003573 | Recon=0.000516 | TrainAcc=1.0000
# Fold 7 Epoch 700: TotalLoss=0.003408 | Sup=0.003381 | Recon=0.000542 | TrainAcc=1.0000
# Fold 7 Epoch 800: TotalLoss=0.002330 | Sup=0.002302 | Recon=0.000569 | TrainAcc=1.0000
# Fold 7 Epoch 900: TotalLoss=0.001957 | Sup=0.001928 | Recon=0.000582 | TrainAcc=1.0000
# Fold 7 Epoch 1000: TotalLoss=0.001593 | Sup=0.001563 | Recon=0.000602 | TrainAcc=1.0000
# Fold 7 Epoch 1100: TotalLoss=0.001246 | Sup=0.001215 | Recon=0.000615 | TrainAcc=1.0000
# Fold 7 Epoch 1200: TotalLoss=0.001081 | Sup=0.001050 | Recon=0.000630 | TrainAcc=1.0000
# Fold 7 Epoch 1300: TotalLoss=0.000933 | Sup=0.000902 | Recon=0.000635 | TrainAcc=1.0000
# Fold 7 Epoch 1400: TotalLoss=0.000866 | Sup=0.000835 | Recon=0.000637 | TrainAcc=1.0000
# Fold 7 Epoch 1500: TotalLoss=0.000809 | Sup=0.000776 | Recon=0.000652 | TrainAcc=1.0000
# Fold 7 Epoch 1600: TotalLoss=0.000614 | Sup=0.000582 | Recon=0.000644 | TrainAcc=1.0000
# Fold 7 Epoch 1700: TotalLoss=0.000637 | Sup=0.000605 | Recon=0.000652 | TrainAcc=1.0000
# Fold 7 Epoch 1800: TotalLoss=0.000554 | Sup=0.000521 | Recon=0.000652 | TrainAcc=1.0000
# Fold 7 Epoch 1900: TotalLoss=0.000466 | Sup=0.000433 | Recon=0.000657 | TrainAcc=1.0000
# Fold 7 Epoch 2000: TotalLoss=0.000462 | Sup=0.000429 | Recon=0.000663 | TrainAcc=1.0000
# Fold 7 → Acc=0.8409 | Prec=0.7333 | Rec=0.7857 | F1=0.7586 | AUC=0.9452 | CE Loss=0.5154
#
# === Fold 8 ===
# Train Control: 68, Train Patient: 33
# Fold 8 Epoch 1: TotalLoss=0.647820 | Sup=0.645548 | Recon=0.045429 | TrainAcc=0.6337
# Fold 8 Epoch 100: TotalLoss=0.140302 | Sup=0.140115 | Recon=0.003740 | TrainAcc=1.0000
# Fold 8 Epoch 200: TotalLoss=0.032337 | Sup=0.032253 | Recon=0.001678 | TrainAcc=1.0000
# Fold 8 Epoch 300: TotalLoss=0.013280 | Sup=0.013234 | Recon=0.000925 | TrainAcc=1.0000
# Fold 8 Epoch 400: TotalLoss=0.007187 | Sup=0.007156 | Recon=0.000624 | TrainAcc=1.0000
# Fold 8 Epoch 500: TotalLoss=0.004700 | Sup=0.004674 | Recon=0.000523 | TrainAcc=1.0000
# Fold 8 Epoch 600: TotalLoss=0.003248 | Sup=0.003222 | Recon=0.000512 | TrainAcc=1.0000
# Fold 8 Epoch 700: TotalLoss=0.002977 | Sup=0.002950 | Recon=0.000538 | TrainAcc=1.0000
# Fold 8 Epoch 800: TotalLoss=0.002102 | Sup=0.002073 | Recon=0.000567 | TrainAcc=1.0000
# Fold 8 Epoch 900: TotalLoss=0.001555 | Sup=0.001526 | Recon=0.000581 | TrainAcc=1.0000
# Fold 8 Epoch 1000: TotalLoss=0.001262 | Sup=0.001232 | Recon=0.000590 | TrainAcc=1.0000
# Fold 8 Epoch 1100: TotalLoss=0.001006 | Sup=0.000976 | Recon=0.000601 | TrainAcc=1.0000
# Fold 8 Epoch 1200: TotalLoss=0.000925 | Sup=0.000893 | Recon=0.000624 | TrainAcc=1.0000
# Fold 8 Epoch 1300: TotalLoss=0.000833 | Sup=0.000802 | Recon=0.000621 | TrainAcc=1.0000
# Fold 8 Epoch 1400: TotalLoss=0.000659 | Sup=0.000627 | Recon=0.000628 | TrainAcc=1.0000
# Fold 8 Epoch 1500: TotalLoss=0.000672 | Sup=0.000641 | Recon=0.000628 | TrainAcc=1.0000
# Fold 8 Epoch 1600: TotalLoss=0.000603 | Sup=0.000571 | Recon=0.000641 | TrainAcc=1.0000
# Fold 8 Epoch 1700: TotalLoss=0.000592 | Sup=0.000560 | Recon=0.000639 | TrainAcc=1.0000
# Fold 8 Epoch 1800: TotalLoss=0.000476 | Sup=0.000444 | Recon=0.000642 | TrainAcc=1.0000
# Fold 8 Epoch 1900: TotalLoss=0.000417 | Sup=0.000386 | Recon=0.000638 | TrainAcc=1.0000
# Fold 8 Epoch 2000: TotalLoss=0.000379 | Sup=0.000347 | Recon=0.000636 | TrainAcc=1.0000
# Fold 8 → Acc=0.9318 | Prec=0.8667 | Rec=0.9286 | F1=0.8966 | AUC=0.9929 | CE Loss=0.1775
#
# === Fold 9 ===
# Train Control: 68, Train Patient: 33
# Fold 9 Epoch 1: TotalLoss=0.647090 | Sup=0.644759 | Recon=0.046607 | TrainAcc=0.7129
# Fold 9 Epoch 100: TotalLoss=0.121530 | Sup=0.121352 | Recon=0.003579 | TrainAcc=1.0000
# Fold 9 Epoch 200: TotalLoss=0.030683 | Sup=0.030598 | Recon=0.001693 | TrainAcc=1.0000
# Fold 9 Epoch 300: TotalLoss=0.012611 | Sup=0.012564 | Recon=0.000931 | TrainAcc=1.0000
# Fold 9 Epoch 400: TotalLoss=0.007111 | Sup=0.007081 | Recon=0.000611 | TrainAcc=1.0000
# Fold 9 Epoch 500: TotalLoss=0.004422 | Sup=0.004395 | Recon=0.000525 | TrainAcc=1.0000
# Fold 9 Epoch 600: TotalLoss=0.002951 | Sup=0.002925 | Recon=0.000519 | TrainAcc=1.0000
# Fold 9 Epoch 700: TotalLoss=0.002492 | Sup=0.002465 | Recon=0.000541 | TrainAcc=1.0000
# Fold 9 Epoch 800: TotalLoss=0.001668 | Sup=0.001640 | Recon=0.000570 | TrainAcc=1.0000
# Fold 9 Epoch 900: TotalLoss=0.001481 | Sup=0.001452 | Recon=0.000585 | TrainAcc=1.0000
# Fold 9 Epoch 1000: TotalLoss=0.001285 | Sup=0.001254 | Recon=0.000613 | TrainAcc=1.0000
# Fold 9 Epoch 1100: TotalLoss=0.001186 | Sup=0.001155 | Recon=0.000618 | TrainAcc=1.0000
# Fold 9 Epoch 1200: TotalLoss=0.000896 | Sup=0.000864 | Recon=0.000626 | TrainAcc=1.0000
# Fold 9 Epoch 1300: TotalLoss=0.000760 | Sup=0.000728 | Recon=0.000632 | TrainAcc=1.0000
# Fold 9 Epoch 1400: TotalLoss=0.000748 | Sup=0.000716 | Recon=0.000631 | TrainAcc=1.0000
# Fold 9 Epoch 1500: TotalLoss=0.000642 | Sup=0.000610 | Recon=0.000640 | TrainAcc=1.0000
# Fold 9 Epoch 1600: TotalLoss=0.000674 | Sup=0.000642 | Recon=0.000649 | TrainAcc=1.0000
# Fold 9 Epoch 1700: TotalLoss=0.000579 | Sup=0.000547 | Recon=0.000642 | TrainAcc=1.0000
# Fold 9 Epoch 1800: TotalLoss=0.000534 | Sup=0.000502 | Recon=0.000654 | TrainAcc=1.0000
# Fold 9 Epoch 1900: TotalLoss=0.000487 | Sup=0.000454 | Recon=0.000658 | TrainAcc=1.0000
# Fold 9 Epoch 2000: TotalLoss=0.000426 | Sup=0.000393 | Recon=0.000656 | TrainAcc=1.0000
# Fold 9 → Acc=1.0000 | Prec=1.0000 | Rec=1.0000 | F1=1.0000 | AUC=1.0000 | CE Loss=0.0239
#
# === Fold 10 ===
# Train Control: 68, Train Patient: 33
# Fold 10 Epoch 1: TotalLoss=0.744870 | Sup=0.742787 | Recon=0.041648 | TrainAcc=0.3267
# Fold 10 Epoch 100: TotalLoss=0.114273 | Sup=0.114088 | Recon=0.003710 | TrainAcc=1.0000
# Fold 10 Epoch 200: TotalLoss=0.031941 | Sup=0.031855 | Recon=0.001705 | TrainAcc=1.0000
# Fold 10 Epoch 300: TotalLoss=0.013538 | Sup=0.013491 | Recon=0.000934 | TrainAcc=1.0000
# Fold 10 Epoch 400: TotalLoss=0.007758 | Sup=0.007727 | Recon=0.000624 | TrainAcc=1.0000
# Fold 10 Epoch 500: TotalLoss=0.004793 | Sup=0.004767 | Recon=0.000521 | TrainAcc=1.0000
# Fold 10 Epoch 600: TotalLoss=0.003732 | Sup=0.003706 | Recon=0.000511 | TrainAcc=1.0000
# Fold 10 Epoch 700: TotalLoss=0.002746 | Sup=0.002719 | Recon=0.000540 | TrainAcc=1.0000
# Fold 10 Epoch 800: TotalLoss=0.001955 | Sup=0.001926 | Recon=0.000568 | TrainAcc=1.0000
# Fold 10 Epoch 900: TotalLoss=0.001702 | Sup=0.001672 | Recon=0.000586 | TrainAcc=1.0000
# Fold 10 Epoch 1000: TotalLoss=0.001533 | Sup=0.001503 | Recon=0.000608 | TrainAcc=1.0000
# Fold 10 Epoch 1100: TotalLoss=0.001216 | Sup=0.001185 | Recon=0.000615 | TrainAcc=1.0000
# Fold 10 Epoch 1200: TotalLoss=0.000945 | Sup=0.000914 | Recon=0.000622 | TrainAcc=1.0000
# Fold 10 Epoch 1300: TotalLoss=0.000818 | Sup=0.000786 | Recon=0.000634 | TrainAcc=1.0000
# Fold 10 Epoch 1400: TotalLoss=0.000784 | Sup=0.000753 | Recon=0.000633 | TrainAcc=1.0000
# Fold 10 Epoch 1500: TotalLoss=0.000659 | Sup=0.000627 | Recon=0.000641 | TrainAcc=1.0000
# Fold 10 Epoch 1600: TotalLoss=0.000566 | Sup=0.000534 | Recon=0.000644 | TrainAcc=1.0000
# Fold 10 Epoch 1700: TotalLoss=0.000544 | Sup=0.000512 | Recon=0.000643 | TrainAcc=1.0000
# Fold 10 Epoch 1800: TotalLoss=0.000501 | Sup=0.000468 | Recon=0.000649 | TrainAcc=1.0000
# Fold 10 Epoch 1900: TotalLoss=0.000506 | Sup=0.000474 | Recon=0.000652 | TrainAcc=1.0000
# Fold 10 Epoch 2000: TotalLoss=0.000433 | Sup=0.000401 | Recon=0.000650 | TrainAcc=1.0000
# Fold 10 → Acc=0.8864 | Prec=0.7647 | Rec=0.9286 | F1=0.8387 | AUC=0.9690 | CE Loss=0.2907
#
# === Fold 11 ===
# Train Control: 68, Train Patient: 33
# Fold 11 Epoch 1: TotalLoss=0.800745 | Sup=0.798419 | Recon=0.046519 | TrainAcc=0.6436
# Fold 11 Epoch 100: TotalLoss=0.161107 | Sup=0.160925 | Recon=0.003645 | TrainAcc=1.0000
# Fold 11 Epoch 200: TotalLoss=0.044872 | Sup=0.044789 | Recon=0.001668 | TrainAcc=1.0000
# Fold 11 Epoch 300: TotalLoss=0.018585 | Sup=0.018538 | Recon=0.000928 | TrainAcc=1.0000
# Fold 11 Epoch 400: TotalLoss=0.010266 | Sup=0.010235 | Recon=0.000618 | TrainAcc=1.0000
# Fold 11 Epoch 500: TotalLoss=0.005890 | Sup=0.005865 | Recon=0.000510 | TrainAcc=1.0000
# Fold 11 Epoch 600: TotalLoss=0.004095 | Sup=0.004069 | Recon=0.000505 | TrainAcc=1.0000
# Fold 11 Epoch 700: TotalLoss=0.003214 | Sup=0.003187 | Recon=0.000526 | TrainAcc=1.0000
# Fold 11 Epoch 800: TotalLoss=0.002282 | Sup=0.002254 | Recon=0.000552 | TrainAcc=1.0000
# Fold 11 Epoch 900: TotalLoss=0.001719 | Sup=0.001690 | Recon=0.000574 | TrainAcc=1.0000
# Fold 11 Epoch 1000: TotalLoss=0.001669 | Sup=0.001639 | Recon=0.000586 | TrainAcc=1.0000
# Fold 11 Epoch 1100: TotalLoss=0.001437 | Sup=0.001407 | Recon=0.000608 | TrainAcc=1.0000
# Fold 11 Epoch 1200: TotalLoss=0.001103 | Sup=0.001073 | Recon=0.000616 | TrainAcc=1.0000
# Fold 11 Epoch 1300: TotalLoss=0.000967 | Sup=0.000936 | Recon=0.000617 | TrainAcc=1.0000
# Fold 11 Epoch 1400: TotalLoss=0.000866 | Sup=0.000835 | Recon=0.000622 | TrainAcc=1.0000
# Fold 11 Epoch 1500: TotalLoss=0.000781 | Sup=0.000749 | Recon=0.000630 | TrainAcc=1.0000
# Fold 11 Epoch 1600: TotalLoss=0.000694 | Sup=0.000662 | Recon=0.000634 | TrainAcc=1.0000
# Fold 11 Epoch 1700: TotalLoss=0.000635 | Sup=0.000603 | Recon=0.000639 | TrainAcc=1.0000
# Fold 11 Epoch 1800: TotalLoss=0.000602 | Sup=0.000570 | Recon=0.000638 | TrainAcc=1.0000
# Fold 11 Epoch 1900: TotalLoss=0.000494 | Sup=0.000462 | Recon=0.000634 | TrainAcc=1.0000
# Fold 11 Epoch 2000: TotalLoss=0.000499 | Sup=0.000466 | Recon=0.000642 | TrainAcc=1.0000
# Fold 11 → Acc=0.9091 | Prec=0.8571 | Rec=0.8571 | F1=0.8571 | AUC=0.9881 | CE Loss=0.1493
#
# === Fold 12 ===
# Train Control: 68, Train Patient: 33
# Fold 12 Epoch 1: TotalLoss=0.686396 | Sup=0.683880 | Recon=0.050327 | TrainAcc=0.3465
# Fold 12 Epoch 100: TotalLoss=0.124749 | Sup=0.124562 | Recon=0.003744 | TrainAcc=1.0000
# Fold 12 Epoch 200: TotalLoss=0.034615 | Sup=0.034529 | Recon=0.001727 | TrainAcc=1.0000
# Fold 12 Epoch 300: TotalLoss=0.015786 | Sup=0.015739 | Recon=0.000956 | TrainAcc=1.0000
# Fold 12 Epoch 400: TotalLoss=0
| TrainAcc=1.0000
# Fold 14 Epoch 500: TotalLoss=0.004856 | Sup=0.004830 | Recon=0.000520 | TrainAcc=1.0000
# Fold 14 Epoch 600: TotalLoss=0.003923 | Sup=0.003896 | Recon=0.000523 | TrainAcc=1.0000
# Fold 14 Epoch 700: TotalLoss=0.002943 | Sup=0.002916 | Recon=0.000550 | TrainAcc=1.0000
# Fold 14 Epoch 800: TotalLoss=0.001863 | Sup=0.001834 | Recon=0.000578 | TrainAcc=1.0000
# Fold 14 Epoch 900: TotalLoss=0.001803 | Sup=0.001774 | Recon=0.000586 | TrainAcc=1.0000
# Fold 14 Epoch 1000: TotalLoss=0.001183 | Sup=0.001153 | Recon=0.000602 | TrainAcc=1.0000
# Fold 14 Epoch 1100: TotalLoss=0.001059 | Sup=0.001028 | Recon=0.000616 | TrainAcc=1.0000
# Fold 14 Epoch 1200: TotalLoss=0.001008 | Sup=0.000976 | Recon=0.000624 | TrainAcc=1.0000
# Fold 14 Epoch 1300: TotalLoss=0.000790 | Sup=0.000759 | Recon=0.000625 | TrainAcc=1.0000
# Fold 14 Epoch 1400: TotalLoss=0.000752 | Sup=0.000720 | Recon=0.000631 | TrainAcc=1.0000
# Fold 14 Epoch 1500: TotalLoss=0.000670 | Sup=0.000638 | Recon=0.000638 | TrainAcc=1.0000
# Fold 14 Epoch 1600: TotalLoss=0.000631 | Sup=0.000599 | Recon=0.000634 | TrainAcc=1.0000
# Fold 14 Epoch 1700: TotalLoss=0.000494 | Sup=0.000462 | Recon=0.000635 | TrainAcc=1.0000
# Fold 14 Epoch 1800: TotalLoss=0.000518 | Sup=0.000486 | Recon=0.000647 | TrainAcc=1.0000
# Fold 14 Epoch 1900: TotalLoss=0.000430 | Sup=0.000398 | Recon=0.000643 | TrainAcc=1.0000
# Fold 14 Epoch 2000: TotalLoss=0.000456 | Sup=0.000423 | Recon=0.000649 | TrainAcc=1.0000
# Fold 14 → Acc=0.9091 | Prec=0.8571 | Rec=0.8571 | F1=0.8571 | AUC=0.9714 | CE Loss=0.3132
#
# === Fold 15 ===
# Train Control: 68, Train Patient: 33
# Fold 15 Epoch 1: TotalLoss=0.694821 | Sup=0.692906 | Recon=0.038301 | TrainAcc=0.6733
# Fold 15 Epoch 100: TotalLoss=0.126520 | Sup=0.126347 | Recon=0.003467 | TrainAcc=1.0000
# Fold 15 Epoch 200: TotalLoss=0.035101 | Sup=0.035022 | Recon=0.001592 | TrainAcc=1.0000
# Fold 15 Epoch 300: TotalLoss=0.013980 | Sup=0.013936 | Recon=0.000885 | TrainAcc=1.0000
# Fold 15 Epoch 400: TotalLoss=0.007432 | Sup=0.007402 | Recon=0.000597 | TrainAcc=1.0000
# Fold 15 Epoch 500: TotalLoss=0.004587 | Sup=0.004561 | Recon=0.000520 | TrainAcc=1.0000
# Fold 15 Epoch 600: TotalLoss=0.002859 | Sup=0.002833 | Recon=0.000520 | TrainAcc=1.0000
# Fold 15 Epoch 700: TotalLoss=0.001886 | Sup=0.001858 | Recon=0.000549 | TrainAcc=1.0000
# Fold 15 Epoch 800: TotalLoss=0.002010 | Sup=0.001982 | Recon=0.000575 | TrainAcc=1.0000
# Fold 15 Epoch 900: TotalLoss=0.001567 | Sup=0.001537 | Recon=0.000592 | TrainAcc=1.0000
# Fold 15 Epoch 1000: TotalLoss=0.001201 | Sup=0.001171 | Recon=0.000613 | TrainAcc=1.0000
# Fold 15 Epoch 1100: TotalLoss=0.001012 | Sup=0.000981 | Recon=0.000618 | TrainAcc=1.0000
# Fold 15 Epoch 1200: TotalLoss=0.001014 | Sup=0.000982 | Recon=0.000625 | TrainAcc=1.0000
# Fold 15 Epoch 1300: TotalLoss=0.000797 | Sup=0.000766 | Recon=0.000636 | TrainAcc=1.0000
# Fold 15 Epoch 1400: TotalLoss=0.000681 | Sup=0.000649 | Recon=0.000633 | TrainAcc=1.0000
# Fold 15 Epoch 1500: TotalLoss=0.000663 | Sup=0.000631 | Recon=0.000640 | TrainAcc=1.0000
# Fold 15 Epoch 1600: TotalLoss=0.000552 | Sup=0.000520 | Recon=0.000646 | TrainAcc=1.0000
# Fold 15 Epoch 1700: TotalLoss=0.000591 | Sup=0.000559 | Recon=0.000641 | TrainAcc=1.0000
# Fold 15 Epoch 1800: TotalLoss=0.000534 | Sup=0.000502 | Recon=0.000640 | TrainAcc=1.0000
# Fold 15 Epoch 1900: TotalLoss=0.000454 | Sup=0.000421 | Recon=0.000648 | TrainAcc=1.0000
# Fold 15 Epoch 2000: TotalLoss=0.000448 | Sup=0.000415 | Recon=0.000655 | TrainAcc=1.0000
# Fold 15 → Acc=0.9091 | Prec=0.8571 | Rec=0.8571 | F1=0.8571 | AUC=0.9500 | CE Loss=0.3781
#
# === Fold 16 ===
# Train Control: 68, Train Patient: 33
# Fold 16 Epoch 1: TotalLoss=0.709982 | Sup=0.707612 | Recon=0.047407 | TrainAcc=0.6733
# Fold 16 Epoch 100: TotalLoss=0.139612 | Sup=0.139425 | Recon=0.003751 | TrainAcc=0.9901
# Fold 16 Epoch 200: TotalLoss=0.034130 | Sup=0.034045 | Recon=0.001711 | TrainAcc=1.0000
# Fold 16 Epoch 300: TotalLoss=0.015082 | Sup=0.015035 | Recon=0.000947 | TrainAcc=1.0000
# Fold 16 Epoch 400: TotalLoss=0.007981 | Sup=0.007949 | Recon=0.000633 | TrainAcc=1.0000
# Fold 16 Epoch 500: TotalLoss=0.005045 | Sup=0.005018 | Recon=0.000526 | TrainAcc=1.0000
# Fold 16 Epoch 600: TotalLoss=0.003698 | Sup=0.003672 | Recon=0.000513 | TrainAcc=1.0000
# Fold 16 Epoch 700: TotalLoss=0.002310 | Sup=0.002284 | Recon=0.000538 | TrainAcc=1.0000
# Fold 16 Epoch 800: TotalLoss=0.002328 | Sup=0.002300 | Recon=0.000570 | TrainAcc=1.0000
# Fold 16 Epoch 900: TotalLoss=0.001664 | Sup=0.001635 | Recon=0.000592 | TrainAcc=1.0000
# Fold 16 Epoch 1000: TotalLoss=0.001440 | Sup=0.001409 | Recon=0.000602 | TrainAcc=1.0000
# Fold 16 Epoch 1100: TotalLoss=0.001172 | Sup=0.001142 | Recon=0.000613 | TrainAcc=1.0000
# Fold 16 Epoch 1200: TotalLoss=0.000919 | Sup=0.000888 | Recon=0.000618 | TrainAcc=1.0000
# Fold 16 Epoch 1300: TotalLoss=0
#
# === Average Results Across 20 Folds ===
# Accuracy:  0.9125 ± 0.0408
# Precision: 0.8618 ± 0.0744
# Recall:    0.8679 ± 0.0724
# F1-score:  0.8633 ± 0.0640
# CE Loss:   0.2700 ± 0.1208
# AUC:       0.9729 ± 0.0189

# %%
feats_dim = num_feats
hidden_dim = 512
num_classes = 2
num_epochs = 2000
lr = 1e-4
weight_decay = 1e-4
batch_print_freq = 100

# Lambda values to test
lambda_list = [0.001, 0.005, 0.009, 0.01, 0.05, 0.09, 0.1, 0.3, 0.5, 0.9, 1, 2, 5, 8]

# === Cross-validation setup ===
sss = StratifiedShuffleSplit(n_splits=20, test_size=0.3, random_state=42)
y_all = y.copy()

# To store all results for each lambda
lambda_results = []

# === Outer loop for lambda sweep ===
for lambda_recon in lambda_list:
    print(f"\n\n====================== λ_recon = {lambda_recon} ======================")

    accuracies, precisions, recalls, f1_scores, aucs, ce_losses = [], [], [], [], [], []

    for fold, (train_val_idx, test_idx_global) in enumerate(sss.split(X, y_all), start=1):
        print(f"\n=== Fold {fold} ===")

        control_idx = np.where(y_all == 0)[0]
        patient_idx = np.where(y_all == 1)[0]
        sss_class = StratifiedShuffleSplit(n_splits=20, test_size=0.3, random_state=fold)
        control_train_idx, _ = next(sss_class.split(X[control_idx], y_all[control_idx]))
        patient_train_idx, _ = next(sss_class.split(X[patient_idx], y_all[patient_idx]))
        control_train = control_idx[control_train_idx]
        patient_train = patient_idx[patient_train_idx]
        train_idx_final = np.concatenate([control_train, patient_train])
        np.random.shuffle(train_idx_final)

        print(f"Train Control: {len(control_train)}, Train Patient: {len(patient_train)}")

        train_idx_t = torch.from_numpy(train_idx_final).long().to(device)
        y_train_tensor = torch.from_numpy(y_all[train_idx_final]).long().to(device)

        model = Cheb_AE(feats_dim, hidden_dim, num_classes, device, activ="RELU", dropout=0.25, K=3).to(device)
        optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
        ce_loss_fn = nn.CrossEntropyLoss()
        recon_loss_fn = nn.MSELoss()
        data = load_data(W, X).to(device)

        for epoch in range(1, num_epochs + 1):
            model.train()
            optimizer.zero_grad()
            logits, recon_x, _ = model(data.x, data.edge_index)

            loss_sup = ce_loss_fn(logits[train_idx_t], y_train_tensor)
            loss_recon = recon_loss_fn(recon_x, data.x)
            total_loss = loss_sup + lambda_recon * loss_recon

            if torch.isnan(total_loss) or torch.isinf(total_loss):
                print(f"NaN/Inf detected at fold {fold} epoch {epoch}. Aborting epoch.")
                break

            total_loss.backward()
            optimizer.step()

            if epoch % batch_print_freq == 0 or epoch == 1:
                model.eval()
                with torch.no_grad():
                    logits_eval, _, _ = model(data.x, data.edge_index)
                    preds_train = logits_eval[train_idx_t].argmax(dim=1)
                    acc_train = accuracy_score(y_train_tensor.cpu(), preds_train.cpu())
                print(f"Fold {fold} Epoch {epoch}: TotalLoss={total_loss.item():.6f} | Sup={loss_sup.item():.6f} | Recon={loss_recon.item():.6f} | TrainAcc={acc_train:.4f}")

        # === Evaluation ===
        model.eval()
        with torch.no_grad():
            out_logits, _, _ = model(data.x, data.edge_index)
            preds = out_logits.argmax(dim=1).cpu().numpy()
            probs = nnFn.softmax(out_logits, dim=1)[:, 1].cpu().numpy()

        y_test = y_all[test_idx_global]
        y_pred_test = preds[test_idx_global]
        y_prob_test = probs[test_idx_global]

        acc = accuracy_score(y_test, y_pred_test)
        prec = precision_score(y_test, y_pred_test, zero_division=0)
        rec = recall_score(y_test, y_pred_test, zero_division=0)
        f1 = f1_score(y_test, y_pred_test, zero_division=0)
        try:
            auc = roc_auc_score(y_test, y_prob_test)
        except ValueError:
            auc = float('nan')
        ce = log_loss(y_test, y_prob_test)

        accuracies.append(acc)
        precisions.append(prec)
        recalls.append(rec)
        f1_scores.append(f1)
        aucs.append(auc)
        ce_losses.append(ce)

        print(f"Fold {fold} → Acc={acc:.4f} | Prec={prec:.4f} | Rec={rec:.4f} | F1={f1:.4f} | AUC={auc:.4f} | CE Loss={ce:.4f}")

    # === Store average results for this λ ===
    avg_results = {
        "lambda": lambda_recon,
        "Accuracy": np.mean(accuracies),
        "Precision": np.mean(precisions),
        "Recall": np.mean(recalls),
        "F1-score": np.mean(f1_scores),
        "CE Loss": np.mean(ce_losses),
        "AUC": np.nanmean(aucs)
    }
    lambda_results.append(avg_results)

    print("\n=== Average Results for λ =", lambda_recon, "===")
    print(f"Accuracy:  {avg_results['Accuracy']:.4f}")
    print(f"Precision: {avg_results['Precision']:.4f}")
    print(f"Recall:    {avg_results['Recall']:.4f}")
    print(f"F1-score:  {avg_results['F1-score']:.4f}")
    print(f"CE Loss:   {avg_results['CE Loss']:.4f}")
    print(f"AUC:       {avg_results['AUC']:.4f}")


# === FINAL SUMMARY ACROSS ALL λ ===
print("\n\n====================== FINAL SUMMARY ACROSS ALL λ ======================")
print(f"{'Lambda':<8} | {'Accuracy':<9} | {'Precision':<9} | {'Recall':<8} | {'F1-score':<9} | {'AUC':<8} | {'CE Loss':<8}")
print("-" * 72)
for res in lambda_results:
    print(f"{res['lambda']:<8} | {res['Accuracy']:<9.4f} | {res['Precision']:<9.4f} | {res['Recall']:<8.4f} | {res['F1-score']:<9.4f} | {res['AUC']:<8.4f} | {res['CE Loss']:<8.4f}")
# Out:
# Streaming output truncated to the last 5000 lines.
# === Fold 6 ===
# Train Control: 68, Train Patient: 33
# Fold 6 Epoch 1: TotalLoss=0.712071 | Sup=0.709887 | Recon=0.043684 | TrainAcc=0.6832
# Fold 6 Epoch 100: TotalLoss=0.128800 | Sup=0.128624 | Recon=0.003526 | TrainAcc=1.0000
# Fold 6 Epoch 200: TotalLoss=0.040498 | Sup=0.040417 | Recon=0.001613 | TrainAcc=1.0000
# Fold 6 Epoch 300: TotalLoss=0.015388 | Sup=0.015343 | Recon=0.000917 | TrainAcc=1.0000
# Fold 6 Epoch 400: TotalLoss=0.008766 | Sup=0.008735 | Recon=0.000633 | TrainAcc=1.0000
# Fold 6 Epoch 500: TotalLoss=0.005522 | Sup=0.005495 | Recon=0.000528 | TrainAcc=1.0000
# Fold 6 Epoch 600: TotalLoss=0.003616 | Sup=0.003590 | Recon=0.000515 | TrainAcc=1.0000
# Fold 6 Epoch 700: TotalLoss=0.003233 | Sup=0.003205 | Recon=0.000552 | TrainAcc=1.0000
# Fold 6 Epoch 800: TotalLoss=0.002262 | Sup=0.002234 | Recon=0.000566 | TrainAcc=1.0000
# Fold 6 Epoch 900: TotalLoss=0.001971 | Sup=0.001941 | Recon=0.000595 | TrainAcc=1.0000
# Fold 6 Epoch 1000: TotalLoss=0.001734 | Sup=0.001704 | Recon=0.000608 | TrainAcc=1.0000
# Fold 6 Epoch 1100: TotalLoss=0.001297 | Sup=0.001266 | Recon=0.000614 | TrainAcc=1.0000
# Fold 6 Epoch 1200: TotalLoss=0.001050 | Sup=0.001018 | Recon=0.000625 | TrainAcc=1.0000
# Fold 6 Epoch 1300: TotalLoss=0.001027 | Sup=0.000995 | Recon=0.000636 | TrainAcc=1.0000
# Fold 6 Epoch 1400: TotalLoss=0.000882 | Sup=0.000850 | Recon=0.000639 | TrainAcc=1.0000
# Fold 6 Epoch 1500: TotalLoss=0.000776 | Sup=0.000744 | Recon=0.000640 | TrainAcc=1.0000
# Fold 6 Epoch 1600: TotalLoss=0.000730 | Sup=0.000697 | Recon=0.000651 | TrainAcc=1.0000
# Fold 6 Epoch 1700: TotalLoss=0.000632 | Sup=0.000599 | Recon=0.000642 | TrainAcc=1.0000
# Fold 6 Epoch 1800: TotalLoss=0.000570 | Sup=0.000538 | Recon=0.000649 | TrainAcc=1.0000
# Fold 6 Epoch 1900: TotalLoss=0.000483 | Sup=0.000451 | Recon=0.000643 | TrainAcc=1.0000
# Fold 6 Epoch 2000: TotalLoss=0.000490 | Sup=0.000457 | Recon=0.000658 | TrainAcc=1.0000
# Fold 6 → Acc=0.9318 | Prec=0.9231 | Rec=0.8571 | F1=0.8889 | AUC=0.9881 | CE Loss=0.2375
#
# === Fold 7 ===
# Train Control: 68, Train Patient: 33
# Fold 7 Epoch 1: TotalLoss=0.701533 | Sup=0.699278 | Recon=0.045111 | TrainAcc=0.6733
# Fold 7 Epoch 100: TotalLoss=0.133807 | Sup=0.133623 | Recon=0.003665 | TrainAcc=1.0000
# Fold 7 Epoch 200: TotalLoss=0.037891 | Sup=0.037808 | Recon=0.001663 | TrainAcc=1.0000
# Fold 7 Epoch 300: TotalLoss=0.015391 | Sup=0.015344 | Recon=0.000933 | TrainAcc=1.0000
# Fold 7 Epoch 400: TotalLoss=0.008747 | Sup=0.008715 | Recon=0.000624 | TrainAcc=1.0000
# Fold 7 Epoch 500: TotalLoss=0.005703 | Sup=0.005677 | Recon=0.000519 | TrainAcc=1.0000
# Fold 7 Epoch 600: TotalLoss=0.003926 | Sup=0.003900 | Recon=0.000521 | TrainAcc=1.0000
# Fold 7 Epoch 700: TotalLoss=0.002919 | Sup=0.002893 | Recon=0.000535 | TrainAcc=1.0000
# Fold 7 Epoch 800: TotalLoss=0.002052 | Sup=0.002024 | Recon=0.000561 | TrainAcc=1.0000
# Fold 7 Epoch 900: TotalLoss=0.001591 | Sup=0.001561 | Recon=0.000585 | TrainAcc=1.0000
# Fold 7 Epoch 1000: TotalLoss=0.001347 | Sup=0.001316 | Recon=0.000612 | TrainAcc=1.0000
# Fold 7 Epoch 1100: TotalLoss=0.001253 | Sup=0.001222 | Recon=0.000618 | TrainAcc=1.0000
# Fold 7 Epoch 1200: TotalLoss=0.000932 | Sup=0.000901 | Recon=0.000628 | TrainAcc=1.0000
# Fold 7 Epoch 1300: TotalLoss=0.000808 | Sup=0.000777 | Recon=0.000627 | TrainAcc=1.0000
# Fold 7 Epoch 1400: TotalLoss=0.000765 | Sup=0.000733 | Recon=0.000638 | TrainAcc=1.0000
# Fold 7 Epoch 1500: TotalLoss=0.000631 | Sup=0.000599 | Recon=0.000641 | TrainAcc=1.0000
# Fold 7 Epoch 1600: TotalLoss=0.000627 | Sup=0.000595 | Recon=0.000644 | TrainAcc=1.0000
# Fold 7 Epoch 1700: TotalLoss=0.000609 | Sup=0.000576 | Recon=0.000652 | TrainAcc=1.0000
# Fold 7 Epoch 1800: TotalLoss=0.000435 | Sup=0.000403 | Recon=0.000652 | TrainAcc=1.0000
# Fold 7 Epoch 1900: TotalLoss=0.000466 | Sup=0.000433 | Recon=0.000656 | TrainAcc=1.0000
# Fold 7 Epoch 2000: TotalLoss=0.000508 | Sup=0.000475 | Recon=0.000658 | TrainAcc=1.0000
# Fold 7 → Acc=0.8409 | Prec=0.7333 | Rec=0.7857 | F1=0.7586 | AUC=0.9476 | CE Loss=0.5110
#
# === Fold 8 ===
# Train Control: 68, Train Patient: 33
# Fold 8 Epoch 1: TotalLoss=0.663399 | Sup=0.661170 | Recon=0.044593 | TrainAcc=0.6733
# Fold 8 Epoch 100: TotalLoss=0.116868 | Sup=0.116686 | Recon=0.003645 | TrainAcc=1.0000
# Fold 8 Epoch 200: TotalLoss=0.031700 | Sup=0.031616 | Recon=0.001664 | TrainAcc=1.0000
# Fold 8 Epoch 300: TotalLoss=0
| TrainAcc=1.0000
# Fold 16 Epoch 2000: TotalLoss=0.000543 | Sup=0.000511 | Recon=0.000634 | TrainAcc=1.0000
# Fold 16 → Acc=0.9091 | Prec=0.9167 | Rec=0.7857 | F1=0.8462 | AUC=0.9762 | CE Loss=0.2204
#
# === Fold 17 ===
# Train Control: 68, Train Patient: 33
# Fold 17 Epoch 1: TotalLoss=1.096616 | Sup=1.094403 | Recon=0.044275 | TrainAcc=0.3465
# Fold 17 Epoch 100: TotalLoss=0.163895 | Sup=0.163715 | Recon=0.003593 | TrainAcc=1.0000
# Fold 17 Epoch 200: TotalLoss=0.060678 | Sup=0.060596 | Recon=0.001629 | TrainAcc=1.0000
# Fold 17 Epoch 300: TotalLoss=0.023838 | Sup=0.023792 | Recon=0.000912 | TrainAcc=1.0000
# Fold 17 Epoch 400: TotalLoss=0.013664 | Sup=0.013633 | Recon=0.000633 | TrainAcc=1.0000
# Fold 17 Epoch 500: TotalLoss=0.007671 | Sup=0.007645 | Recon=0.000519 | TrainAcc=1.0000
# Fold 17 Epoch 600: TotalLoss=0.005950 | Sup=0.005924 | Recon=0.000519 | TrainAcc=1.0000
# Fold 17 Epoch 700: TotalLoss=0.004513 | Sup=0.004486 | Recon=0.000540 | TrainAcc=1.0000
# Fold 17 Epoch 800: TotalLoss=0.003254 | Sup=0.003226 | Recon=0.000567 | TrainAcc=1.0000
# Fold 17 Epoch 900: TotalLoss=0.002819 | Sup=0.002790 | Recon=0.000588 | TrainAcc=1.0000
# Fold 17 Epoch 1000: TotalLoss=0.002112 | Sup=0.002083 | Recon=0.000598 | TrainAcc=1.0000
# Fold 17 Epoch 1100: TotalLoss=0.001977 | Sup=0.001946 | Recon=0.000615 | TrainAcc=1.0000
# Fold 17 Epoch 1200: TotalLoss=0.001518 | Sup=0.001488 | Recon=0.000615 | TrainAcc=1.0000
# Fold 17 Epoch 1300: TotalLoss=0.001376 | Sup=0.001345 | Recon=0.000622 | TrainAcc=1.0000
# Fold 17 Epoch 1400: TotalLoss=0.001162 | Sup=0.001131 | Recon=0.000627 | TrainAcc=1.0000
# Fold 17 Epoch 1500: TotalLoss=0.001186 | Sup=0.001155 | Recon=0.000632 | TrainAcc=1.0000
# Fold 17 Epoch 1600: TotalLoss=0.000840 | Sup=0.000808 | Recon=0.000632 | TrainAcc=1.0000
# Fold 17 Epoch 1700: TotalLoss=0.000842 | Sup=0.000811 | Recon=0.000637 | TrainAcc=1.0000
# Fold 17 Epoch 1800: TotalLoss=0.000786 | Sup=0.000754 | Recon=0.000641 | TrainAcc=1.0000
# Fold 17 Epoch 1900: TotalLoss=0.000694 | Sup=0.000662 | Recon=0.000643 | TrainAcc=1.0000
# Fold 17 Epoch 2000: TotalLoss=0.000676 | Sup=0.000644 | Recon=0.000645 | TrainAcc=1.0000
# Fold 17 → Acc=0.8864 | Prec=0.8000 | Rec=0.8571 | F1=0.8276 | AUC=0.9738 | CE Loss=0.2506
#
# === Fold 18 ===
# Train Control: 68, Train Patient: 33
# Fold 18 Epoch 1: TotalLoss=0.849211 | Sup=0.847215 | Recon=0.039924 | TrainAcc=0.4059
# Fold 18 Epoch 100: TotalLoss=0.145853 | Sup=0.145677 | Recon=0.003536 | TrainAcc=0.9901
# Fold 18 Epoch 200: TotalLoss=0.045302 | Sup=0.045221 | Recon=0.001616 | TrainAcc=1.0000
# Fold 18 Epoch 300: TotalLoss=0.016823 | Sup=0.016778 | Recon=0.000895 | TrainAcc=1.0000
# Fold 18 Epoch 400: TotalLoss=0.010132 | Sup=0.010102 | Recon=0.000602 | TrainAcc=1.0000
# Fold 18 Epoch 500: TotalLoss=0.006390 | Sup=0.006363 | Recon=0.000526 | TrainAcc=1.0000
# Fold 18 Epoch 600: TotalLoss=0.004922 | Sup=0.004896 | Recon=0.000526 | TrainAcc=1.0000
# Fold 18 Epoch 700: TotalLoss=0.003421 | Sup=0.003394 | Recon=0.000544 | TrainAcc=1.0000
# Fold 18 Epoch 800: TotalLoss=0.002074 | Sup=0.002045 | Recon=0.000567 | TrainAcc=1.0000
# Fold 18 Epoch 900: TotalLoss=0.002023 | Sup=0.001993 | Recon=0.000595 | TrainAcc=1.0000
# Fold 18 Epoch 1000: TotalLoss=0.001474 | Sup=0.001444 | Recon=0.000604 | TrainAcc=1.0000
# Fold 18 Epoch 1100: TotalLoss=0.001367 | Sup=0.001336 | Recon=0.000615 | TrainAcc=1.0000
# Fold 18 Epoch 1200: TotalLoss=0.001252 | Sup=0.001221 | Recon=0.000631 | TrainAcc=1.0000
# Fold 18 Epoch 1300: TotalLoss=0.001008 | Sup=0.000977 | Recon=0.000628 | TrainAcc=1.0000
# Fold 18 Epoch 1400: TotalLoss=0.000894 | Sup=0.000862 | Recon=0.000635 | TrainAcc=1.0000
# Fold 18 Epoch 1500: TotalLoss=0.000778 | Sup=0.000746 | Recon=0.000636 | TrainAcc=1.0000
# Fold 18 Epoch 1600: TotalLoss=0.000697 | Sup=0.000665 | Recon=0.000643 | TrainAcc=1.0000
# Fold 18 Epoch 1700: TotalLoss=0.000639 | Sup=0.000607 | Recon=0.000641 | TrainAcc=1.0000
# Fold 18 Epoch 1800: TotalLoss=0.000535 | Sup=0.000503 | Recon=0.000650 | TrainAcc=1.0000
# Fold 18 Epoch 1900: TotalLoss=0.000601 | Sup=0.000569 | Recon=0.000650 | TrainAcc=1.0000
# Fold 18 Epoch 2000: TotalLoss=0.000489 | Sup=0.000456 | Recon=0.000649 | TrainAcc=1.0000
# Fold 18 → Acc=0.9545 | Prec=0.8750 | Rec=1.0000 | F1=0.9333 | AUC=0.9690 | CE Loss=0.2854
#
# === Fold 19 ===
# Train Control: 68, Train Patient: 33
# Fold 19 Epoch 1: TotalLoss=0.737316 | Sup=0.735065 | Recon=0.045020 | TrainAcc=0.3267
# Fold 19 Epoch 100: TotalLoss=0.143683 | Sup=0.143502 | Recon=0.003625 | TrainAcc=1.0000
# Fold 19 Epoch 200: TotalLoss=0.042271 | Sup=0.042187 | Recon=0.001693 | TrainAcc=1.0000
# Fold 19 Epoch 300: TotalLoss=0.015648 | Sup=0.015601 | Recon=0.000926 | TrainAcc=1.0000
# Fold 19 Epoch 400: TotalLoss=0.008109 | Sup=0.008078 | Recon=0.000613 | TrainAcc=1.0000
# Fold 19 Epoch 500: TotalLoss=0.005428 | Sup=0.005402 | Recon=0.000524 | TrainAcc=1.0000
# Fold 19 Epoch 600: TotalLoss=0.003930 | Sup=0.003904 | Recon=0.000516 | TrainAcc=1.0000
# Fold 19 Epoch 700: TotalLoss=0.002865 | Sup=0.002838 | Recon=0.000542 | TrainAcc=1.0000
# Fold 19 Epoch 800: TotalLoss=0.002035 | Sup=0.002006 | Recon=0.000569 | TrainAcc=1.0000
# Fold 19 Epoch 900: TotalLoss=0.001675 | Sup=0.001645 | Recon=0.000594 | TrainAcc=1.0000
# Fold 19 Epoch 1000: TotalLoss=0.001310 | Sup=0.001280 | Recon=0.000604 | TrainAcc=1.0000
# Fold 19 Epoch 1100: TotalLoss=0.001284 | Sup=0.001253 | Recon=0.000614 | TrainAcc=1.0000
# Fold 19 Epoch 1200: TotalLoss=0.001114 | Sup=0.001083 | Recon=0.000625 | TrainAcc=1.0000
# Fold 19 Epoch 1300: TotalLoss=0.000929 | Sup=0.000898 | Recon=0.000635 | TrainAcc=1.0000
# Fold 19 Epoch 1400: TotalLoss=0.000769 | Sup=0.000737 | Recon=0.000639 | TrainAcc=1.0000
# Fold 19 Epoch 1500: TotalLoss=0.000683 | Sup=0.000650 | Recon=0.000643 | TrainAcc=1.0000
# Fold 19 Epoch 1600: TotalLoss=0.000631 | Sup=0.000599 | Recon=0.000640 | TrainAcc=1.0000
# Fold 19 Epoch 1700: TotalLoss=0.000639 | Sup=0.000606 | Recon=0.000647 | TrainAcc=1.0000
# Fold 19 Epoch 1800: TotalLoss=0.000550 | Sup=0.000518 | Recon=0.000648 | TrainAcc=1.0000
# Fold 19 Epoch 1900: TotalLoss=0.000594 | Sup=0.000562 | Recon=0.000656 | TrainAcc=1.0000
# Fold 19 Epoch 2000: TotalLoss=0.000396 | Sup=0.000363 | Recon=0.000650 | TrainAcc=1.0000
# Fold 19 → Acc=0.8636 | Prec=0.7857 | Rec=0.7857 | F1=0.7857 | AUC=0.9310 | CE Loss=0.4033
#
# === Fold 20 ===
# Train Control: 68, Train Patient: 33
# Fold 20 Epoch 1: TotalLoss=0.776703 | Sup=0.774611 | Recon=0.041834 | TrainAcc=0.6535
# Fold 20 Epoch 100: TotalLoss=0.138099 | Sup=0.137920 | Recon=0.003587 | TrainAcc=1.0000
# Fold 20 Epoch 200: TotalLoss=0.037583 | Sup=0.037499 | Recon=0.001669 | TrainAcc=1.0000
# Fold 20 Epoch 300: TotalLoss=0.015310 | Sup=0.015264 | Recon=0.000914 | TrainAcc=1.0000
# Fold 20 Epoch 400: TotalLoss=0.007493 | Sup=0.007463 | Recon=0.000610 | TrainAcc=1.0000
# Fold 20 Epoch 500: TotalLoss=0.005384 | Sup=0.005357 | Recon=0.000529 | TrainAcc=1.0000
# Fold 20 Epoch 600: TotalLoss=0.003480 | Sup=0.003454 | Recon=0.000519 | TrainAcc=1.0000
# Fold 20 Epoch 700: TotalLoss=0.002882 | Sup=0.002855 | Recon=0.000542 | TrainAcc=1.0000
# Fold 20 Epoch 800: TotalLoss=0.002033 | Sup=0.002005 | Recon=0.000568 | TrainAcc=1.0000
# Fold 20 Epoch 900: TotalLoss=0.001741 | Sup=0.001711 | Recon=0.000594 | TrainAcc=1.0000
# Fold 20 Epoch 1000: TotalLoss=0.001225 | Sup=0.001195 | Recon=0.000603 | TrainAcc=1.0000
# Fold 20 Epoch 1100: TotalLoss=0.001082 | Sup=0.001051 | Recon=0.000616 | TrainAcc=1.0000
# Fold 20 Epoch 1200: TotalLoss=0.000961 | Sup=0.000930 | Recon=0.000615 | TrainAcc=1.0000
# Fold 20 Epoch 1300: TotalLoss=0.000867 | Sup=0.000836 | Recon=0.000630 | TrainAcc=1.0000
# Fold 20 Epoch 1400: TotalLoss=0.000710 | Sup=0.000679 | Recon=0.000629 | TrainAcc=1.0000
# Fold 20 Epoch 1500: TotalLoss=0.000856 | Sup=0.000824 | Recon=0.000634 | TrainAcc=1.0000
# Fold 20 Epoch 1600: TotalLoss=0.000771 | Sup=0.000739 | Recon=0.000643 | TrainAcc=1.0000
# Fold 20 Epoch 1700: TotalLoss=0.000540 | Sup=0.000508 | Recon=0.000639 | TrainAcc=1.0000
# Fold 20 Epoch 1800: TotalLoss=0.000519 | Sup=0.000487 | Recon=0.000639 | TrainAcc=1.0000
# Fold 20 Epoch 1900: TotalLoss=0.000474 | Sup=0.000442 | Recon=0.000643 | TrainAcc=1.0000
# Fold 20 Epoch 2000: TotalLoss=0.000451 | Sup=0.000419 | Recon=0.000649 | TrainAcc=1.0000
# Fold 20 → Acc=0.8864 | Prec=0.8000 | Rec=0.8571 | F1=0.8276 | AUC=0.9333 | CE Loss=0.4192
#
# === Average Results for λ = 0.05 ===
# Accuracy:  0.9148
# Precision: 0.8636
# Recall:    0.8750
# F1-score:  0.8677
# CE Loss:   0.2659
# AUC:       0.9742
#
#
# ====================== λ_recon = 0.09 ======================
#
# === Fold 1 ===
# Train Control: 68, Train Patient: 33
# Fold 1 Epoch 1: TotalLoss=0.692599 | Sup=0.688539 | Recon=0.045104 | TrainAcc=0.6733
# Fold 1 Epoch 100: TotalLoss=0.133459 | Sup=0.133169 | Recon=0.003215 | TrainAcc=1.0000
# Fold 1 Epoch 200: TotalLoss=0.039876 | Sup=0.039739 | Recon=0.001526 | TrainAcc=1.0000
# Fold 1 Epoch 300: TotalLoss=0.015273 | Sup=0.015193 | Recon=0.000883 | TrainAcc=1.0000
# Fold 1 Epoch 400: TotalLoss=0.008265 | Sup=0.008212 | Recon=0.000591 | TrainAcc=1.0000
# Fold 1 Epoch 500: TotalLoss=0.005841 | Sup=0.005802 | Recon=0.000439 | TrainAcc=1.0000
# Fold 1 Epoch 600: TotalLoss=0.003723 | Sup=0.003687 | Recon=0.000401 | TrainAcc=1.0000
# Fold 1 Epoch 700: TotalLoss=0.002826 | Sup=0.002790 | Recon=0.000396 | TrainAcc=1.0000
# Fold 1 Epoch 800: TotalLoss=0.002078 | Sup=0.002041 | Recon=0.000412 | TrainAcc=1.0000
# Fold 1 Epoch 900: TotalLoss=0.001747 | Sup=0.001707 | Recon=0.000439 | TrainAcc=1.0000
# Fold 1 Epoch 1000: TotalLoss=0.001407 | Sup=0.001367 | Recon=0.000453 | TrainAcc=1.0000
# Fold 1 Epoch 1100: TotalLoss=0.001109 | Sup=0.001067 | Recon=0.000463 | TrainAcc=1.0000
# Fold 1 Epoch 1200: TotalLoss=0.001000 | Sup=0.000958 | Recon=0.000473 | TrainAcc=1.0000
# Fold 1 Epoch 1300: TotalLoss=0.000957 | Sup=0.000913 | Recon=0.000485 | TrainAcc=1.0000
# Fold 1 Epoch 1400: TotalLoss=0.000913 | Sup=0.000869 | Recon=0.000492 | TrainAcc=1.0000
# Fold 1 Epoch 1500: TotalLoss=0.000824 | Sup=0.000779 | Recon=0.000504 | TrainAcc=1.0000
# Fold 1 Epoch 1600: TotalLoss=0.000647 | Sup=0.000602 | Recon=0.000506 | TrainAcc=1.0000
# Fold 1 Epoch 1700: TotalLoss=0.000563 | Sup=0.000517 | Recon=0.000508 | TrainAcc=1.0000
# Fold 1 Epoch 1800: TotalLoss=0.000557 | Sup=0.000510 | Recon=0.000514 | TrainAcc=1.0000
# Fold 1 Epoch 1900: TotalLoss=0.000521 | Sup=0.000475 | Recon=0.000518 | TrainAcc=1.0000
# Fold 1 Epoch 2000: TotalLoss=0.000497 | Sup=0.000450 | Recon=0.000521 | TrainAcc=1.0000
# Fold 1 → Acc=0.8864 | Prec=0.8462 | Rec=0.7857 | F1=0.8148 | AUC=0.9571 | CE Loss=0.4657
#
# === Fold 2 ===
# Train Control: 68, Train Patient: 33
# Fold 2 Epoch 1: TotalLoss=0.666524 | Sup=0.662794 | Recon=0.041445 | TrainAcc=0.6733
# Fold 2 Epoch 100: TotalLoss=0.119449 | Sup=0.119174 | Recon=0.003057 | TrainAcc=1.0000
# Fold 2 Epoch 200: TotalLoss=0.034580 | Sup=0.034448 | Recon=0.001472 | TrainAcc=1.0000
# Fold 2 Epoch 300: TotalLoss=0.014234 | Sup=0.014155 | Recon=0.000872 | TrainAcc=1.0000
# Fold 2 Epoch 400: TotalLoss=0.007993 | Sup=0.007940 | Recon=0.000595 | TrainAcc=1.0000
# Fold 2 Epoch 500: TotalLoss=0.004068 | Sup=0.004027 | Recon=0.000457 | TrainAcc=1.0000
# Fold 2 Epoch 600: TotalLoss=0.002911 | Sup=0.002874 | Recon=0.000416 | TrainAcc=1.0000
# Fold 2 Epoch 700: TotalLoss=0.002225 | Sup=0.002188 | Recon=0.000406 | TrainAcc=1.0000
# Fold 2 Epoch 800: TotalLoss=0.001906 | Sup=0.001867 | Recon=0.000434 | TrainAcc=1.0000
# Fold 2 Epoch 900: TotalLoss=0.001715 | Sup=0.001675 | Recon=0.000448 | TrainAcc=1.0000
# Fold 2 Epoch 1000: TotalLoss=0.001314 | Sup=0.001272 | Recon=0.000464 | TrainAcc=1.0000
# Fold 2 Epoch 1100: TotalLoss=0.001026 | Sup=0.000983 | Recon=0.000478 | TrainAcc=1.0000
# Fold 2 Epoch 1200: TotalLoss=0.000963 | Sup=0.000919 | Recon=0.000491 | TrainAcc=1.0000
# Fold 2 Epoch 1300: TotalLoss=0.000824 | Sup=0.000779 | Recon=0.000501 | TrainAcc=1.0000
# Fold 2 Epoch 1400: TotalLoss=0.000727 | Sup=0.000681 | Recon=0.000507 | TrainAcc=1.0000
# Fold 2 Epoch 1500: TotalLoss=0.000691 | Sup=0.000645 | Recon=0.000509 | TrainAcc=1.0000
# Fold 2 Epoch 1600: TotalLoss=0.000670 | Sup=0.000623 | Recon=0.000525 | TrainAcc=1.0000
# Fold 2 Epoch 1700: TotalLoss=0.000519 | Sup=0.000472 | Recon=0.000522 | TrainAcc=1.0000
# Fold 2 Epoch 1800: TotalLoss=0.000530 | Sup=0.000482 | Recon=0.000525 | TrainAcc=1.0000
# Fold 2 Epoch 1900: TotalLoss=0.000454 | Sup=0.000406 | Recon=0.000528 | TrainAcc=1.0000
# Fold 2 Epoch 2000: TotalLoss=0.000439 | Sup=0.000392 | Recon=0.000532 | TrainAcc=1.0000
# Fold 2 → Acc=0.9091 | Prec=0.8571 | Rec=0.8571 | F1=0.8571 | AUC=0.9786 | CE Loss=0.2342
#
# === Fold 3 ===
# Train Control: 68, Train Patient: 33
# Fold 3 Epoch 1: TotalLoss=0.701912 | Sup=0.698060 | Recon=0.042801 | TrainAcc=0.5644
# Fold 3 Epoch 100: TotalLoss=0.121622 | Sup=0.121346 | Recon=0.003065 | TrainAcc=1.0000
# Fold 3 Epoch 200: TotalLoss=0.028172 | Sup=0.028039 | Recon=0.001477 | TrainAcc=1.0000
# Fold 3 Epoch 300: TotalLoss=0.012594 | Sup=0.012518 | Recon=0.000844 | TrainAcc=1.0000
# Fold 3 Epoch 400: TotalLoss=0.007092 | Sup=0.007039 | Recon=0.000583 | TrainAcc=1.0000
# Fold 3 Epoch 500: TotalLoss=0.004137 | Sup=0.004096 | Recon=0.000455 | TrainAcc=1.0000
# Fold 3 Epoch 600: TotalLoss=0.002784 | Sup=0.002747 | Recon=0.000414 | TrainAcc=1.0000
# Fold 3 Epoch 700: TotalLoss=0.002323 | Sup=0.002285 | Recon=0.000411 | TrainAcc=1.0000
# Fold 3 Epoch 800: TotalLoss=0.001653 | Sup=0.001614 | Recon=0.000428 | TrainAcc=1.0000
# Fold 3 Epoch 900: TotalLoss=0.001385 | Sup=0.001345 | Recon=0.000450 | TrainAcc=1.0000
# Fold 3 Epoch 1000: TotalLoss=0.001173 | Sup=0.001132 | Recon=0.000459 | TrainAcc=1.0000
# Fold 3 Epoch 1100: TotalLoss=0.001036 | Sup=0.000992 | Recon=0.000481 | TrainAcc=1.0000
# Fold 3 Epoch 1200: TotalLoss=0.000864 | Sup=0.000820 | Recon=0.000485 | TrainAcc=1.0000
# Fold 3 Epoch 1300: TotalLoss=0.000708 | Sup=0.000664 | Recon=0.000490 | TrainAcc=1.0000
# Fold 3 Epoch 1400: TotalLoss=0.000651 | Sup=0.000606 | Recon=0.000501 | TrainAcc=1.0000
# Fold 3 Epoch 1500: TotalLoss=0.000665 | Sup=0.000619 | Recon=0.000508 | TrainAcc=1.0000
# Fold 3 Epoch 1600: TotalLoss=0.000554 | Sup=0.000507 | Recon=0.000520 | TrainAcc=1.0000
# Fold 3 Epoch 1700: TotalLoss=0.000546 | Sup=0.000500 | Recon=0.000517 | TrainAcc=1.0000
# Fold 3 Epoch 1800: TotalLoss=0.000426 | Sup=0.000379 | Recon=0.000516 | TrainAcc=1.0000
# Fold 3 Epoch 1900: TotalLoss=0.000474 | Sup=0.000427 | Recon=0.000522 | TrainAcc=1.0000
# Fold 3 Epoch 2000: TotalLoss=0.000420 | Sup=0.000372 | Recon=0.000526 | TrainAcc=1.0000
# Fold 3 → Acc=0.8864 | Prec=0.8462 | Rec=0.7857 | F1=0.8148 | AUC=0.9857 | CE Loss=0.2869
#
# === Fold 4 ===
# Train Control: 68, Train Patient: 33
# Fold 4 Epoch 1: TotalLoss=0.783913 | Sup=0.780168 | Recon=0.041610 | TrainAcc=0.4455
# Fold 4 Epoch 100: TotalLoss=0.148753 | Sup=0.148470 | Recon=0.003146 | TrainAcc=1.0000
# Fold 4 Epoch 200: TotalLoss=0.038200 | Sup=0.038066 | Recon=0.001483 | TrainAcc=1.0000
# Fold 4 Epoch 300: TotalLoss=0.016442 | Sup=0.016367 | Recon=0.000836 | TrainAcc=1.0000
# Fold 4 Epoch 400: TotalLoss=0.008785 | Sup=0.008732 | Recon=0.000583 | TrainAcc=1.0000
# Fold 4 Epoch 500: TotalLoss=0.004970 | Sup=0.004929 | Recon=0.000447 | TrainAcc=1.0000
# Fold 4 Epoch 600: TotalLoss=0.004080 | Sup=0.004043 | Recon=0.000409 | TrainAcc=1.0000
# Fold 4 Epoch 700: TotalLoss=0.002938 | Sup=0.002901 | Recon=0.000407 | TrainAcc=1.0000
# Fold 4 Epoch 800: TotalLoss=0.002304 | Sup=0.002266 | Recon=0.000429 | TrainAcc=1.0000
# Fold 4 Epoch 900: TotalLoss=0.001862 | Sup=0.001823 | Recon=0.000438 | TrainAcc=1.0000
# Fold 4 Epoch 1000: TotalLoss=0.001562 | Sup=0.001520 | Recon=0.000461 | TrainAcc=1.0000
# Fold 4 Epoch 1100: TotalLoss=0.001384 | Sup=0.001342 | Recon=0.000471 | TrainAcc=1.0000
# Fold 4 Epoch 1200: TotalLoss=0.001277 | Sup=0.001233 | Recon=0.000484 | TrainAcc=1.0000
# Fold 4 Epoch 1300: TotalLoss=0.001013 | Sup=0.000969 | Recon=0.000488 | TrainAcc=1.0000
# Fold 4 Epoch 1400: TotalLoss=0.000842 | Sup=0.000797 | Recon=0.000496 | TrainAcc=1.0000
# Fold 4 Epoch 1500: TotalLoss=0.000762 | Sup=0.000716 | Recon=0.000506 | TrainAcc=1.0000
# Fold 4 Epoch 1600: TotalLoss=0.000708 | Sup=0.000662 | Recon=0.000506 | TrainAcc=1.0000
# Fold 4 Epoch 1700: TotalLoss=0.000614 | Sup=0.000568 | Recon=0.000509 | TrainAcc=1.0000
# Fold 4 Epoch 1800: TotalLoss=0.000616 | Sup=0.000570 | Recon=0.000514 | TrainAcc=1.0000
# Fold 4 Epoch 1900: TotalLoss=0.000575 | Sup=0.000528 | Recon=0.000517 | TrainAcc=1.0000
# Fold 4 Epoch 2000: TotalLoss=0.000535 | Sup=0.000488 | Recon=0.000526 | TrainAcc=1.0000
# Fold 4 → Acc=0.9773 | Prec=1.0000 | Rec=0.9286 | F1=0.9630 | AUC=0.9857 | CE Loss=0.1131
#
# === Fold 5 ===
# Train Control: 68, Train Patient: 33
# Fold 5 Epoch 1: TotalLoss=0.705569 | Sup=0.701561 | Recon=0.044537 | TrainAcc=0.6733
# Fold 5 Epoch 100: TotalLoss=0.136500 | Sup=0.136207 | Recon=0.003259 | TrainAcc=1.0000
# Fold 5 Epoch 200: TotalLoss=0.042906 | Sup=0.042771 | Recon=0.001495 | TrainAcc=1.0000
# Fold 5 Epoch 300: TotalLoss=0.016236 | Sup=0.016158 | Recon=0.000873 | TrainAcc=1.0000
# Fold 5 Epoch 400: TotalLoss=0.008202 | Sup=0.008149 | Recon=0.000589 | TrainAcc=1.0000
# Fold 5 Epoch 500: TotalLoss=0.006103 | Sup=0.006062 | Recon=0.000454 | TrainAcc=1.0000
# Fold 5 Epoch 600: TotalLoss=0.003692 | Sup=0.003656 | Recon=0.000403 | TrainAcc=1.0000
# Fold 5 Epoch 700: TotalLoss=0.003307 | Sup=0.003269 | Recon=0.000415 | TrainAcc=1.0000
# Fold 5 Epoch 800: TotalLoss=0.002338 | Sup=0.002300 | Recon=0.000427 | TrainAcc=1.0000
# Fold 5 Epoch 900: TotalLoss=0.002079 | Sup=0.002039 | Recon=0.000437 | TrainAcc=1.0000
# Fold 5 Epoch 1000: TotalLoss=0.001626 | Sup=0.001584 | Recon=0.000465 | TrainAcc=1.0000
# Fold 5 Epoch 1100: TotalLoss=0.001266 | Sup=0.001223 | Recon=0.000470 | TrainAcc=1.0000
# Fold 5 Epoch 1200: TotalLoss=0.001128 | Sup=0.001084 | Recon=0.000493 | TrainAcc=1.0000
# Fold 5 Epoch 1300: TotalLoss=0.001128 | Sup=0.001083 | Recon=0.000496 | TrainAcc=1.0000
# Fold 5 Epoch 1400: TotalLoss=0.000919 | Sup=0.000874 | Recon=0.000501 | TrainAcc=1.0000
# Fold 5 Epoch 1500: TotalLoss=0.000863 | Sup=0.000817 | Recon=0.000513 | TrainAcc=1.0000
# Fold 5 Epoch 1600: TotalLoss=0.000679 | Sup=0.000632 | Recon=0.000520 | TrainAcc=1.0000
# Fold 5 Epoch 1700: TotalLoss=0.000621 | Sup=0.000575 | Recon=0.000519 | TrainAcc=1.0000
# Fold 5 Epoch 1800: TotalLoss=0.000595 | Sup=0.000548 | Recon=0.000519 | TrainAcc=1.0000
# Fold 5 Epoch 1900: TotalLoss=0.000529 | Sup=0.000481 | Recon=0.000528 | TrainAcc=1.0000
# Fold 5 Epoch 2000: TotalLoss=0.000435 | Sup=0.000387 | Recon=0.000534 | TrainAcc=1.0000
# Fold 5 → Acc=0.9318 | Prec=0.8667 | Rec=0.9286 | F1=0.8966 | AUC=0.9857 | CE Loss=0.2897
#
# === Fold 6 ===
# Train Control: 68, Train Patient: 33
# Fold 6 Epoch 1: TotalLoss=0.706220 | Sup=0.702438 | Recon=0.042023 | TrainAcc=0.4653
# Fold 6 Epoch 100: TotalLoss=0.127355 | Sup=0.127071 | Recon=0.003156 | TrainAcc=1.0000
# Fold 6 Epoch 200: TotalLoss=0.035685 | Sup=0.035549 | Recon=0.001514 | TrainAcc=1.0000
# Fold 6 Epoch 300: TotalLoss=0.015960 | Sup=0.015881 | Recon=0.000879 | TrainAcc=1.0000
# Fold 6 Epoch 400: TotalLoss=0.008508 | Sup=0.008455 | Recon=0.000584 | TrainAcc=1.0000
# Fold 6 Epoch 500: TotalLoss=0.005123 | Sup=0.005082 | Recon=0.000447 | TrainAcc=1.0000
# Fold 6 Epoch 600: TotalLoss=0.003797 | Sup=0.003760 | Recon=0.000402 | TrainAcc=1.0000
# Fold 6 Epoch 700: TotalLoss=0.002674 | Sup=0.002637 | Recon=0.000413 | TrainAcc=1.0000
# Fold 6 Epoch 800: TotalLoss=0.002253 | Sup=0.002215 | Recon=0.000430 | TrainAcc=1.0000
# Fold 6 Epoch 900: TotalLoss=0.001358 | Sup=0.001318 | Recon=0.000441 | TrainAcc=1.0000
# Fold 6 Epoch 1000: TotalLoss=0.001352 | Sup=0.001311 | Recon=0.000456 | TrainAcc=1.0000
# Fold 6 Epoch 1100: TotalLoss=0.001214 | Sup=0.001172 | Recon=0.000473 | TrainAcc=1.0000
# Fold 6 Epoch 1200: TotalLoss=0.001112 | Sup=0.001068 | Recon=0.000487 | TrainAcc=1.0000
# Fold 6 Epoch 1300: TotalLoss=0.000919 | Sup=0.000875 | Recon=0.000490 | TrainAcc=1.0000
# Fold 6 Epoch 1400: TotalLoss=0.000775 | Sup=0.000731 | Recon=0.000497 | TrainAcc=1.0000
# Fold 6 Epoch 1500: TotalLoss=0.000685 | Sup=0.000639 | Recon=0.000510 | TrainAcc=1.0000
# Fold 6 Epoch 1600: TotalLoss=0.000635 | Sup=0.000589 | Recon=0.000511 | TrainAcc=1.0000
# Fold 6 Epoch 1700: TotalLoss=0.000590 | Sup=0.000544 | Recon=0.000514 | TrainAcc=1.0000
# Fold 6 Epoch 1800: TotalLoss=0.000529 | Sup=0.000482 | Recon=0.000522 | TrainAcc=1.0000
# Fold 6 Epoch 1900: TotalLoss=0.000487 | Sup=0.000440 | Recon=0.000516 | TrainAcc=1.0000
# Fold 6 Epoch 2000: TotalLoss=0.000534 | Sup=0.000487 | Recon=0.000530 | TrainAcc=1.0000
# Fold 6 → Acc=0.9318 | Prec=0.9231 | Rec=0.8571 | F1=0.8889 | AUC=0.9881 | CE Loss=0.2102
#
# === Fold 7 ===
# Train Control: 68, Train Patient: 33
# Fold 7 Epoch 1: TotalLoss=0.805786 | Sup=0.802200 | Recon=0.039841 | TrainAcc=0.3267
# Fold 7 Epoch 100: TotalLoss=0.148677 | Sup=0.148403 | Recon=0.003050 | TrainAcc=1.0000
# Fold 7 Epoch 200: TotalLoss=0.044741 | Sup=0.044612 | Recon=0.001434 | TrainAcc=1.0000
# Fold 7 Epoch 300: TotalLoss=0.018446 | Sup=0.018369 | Recon=0.000854 | TrainAcc=1.0000
# Fold 7 Epoch 400: TotalLoss=0.011167 | Sup=0.011116 | Recon=0.000572 | TrainAcc=1.0000
# Fold 7 Epoch 500: TotalLoss=0.005593 | Sup=0.005553 | Recon=0.000437 | TrainAcc=1.0000
# Fold 7 Epoch 600: TotalLoss=0.004333 | Sup=0.004296 | Recon=0.000409 | TrainAcc=1.0000
# Fold 7 Epoch 700: TotalLoss=0.003023 | Sup=0.002986 | Recon=0.000415 | TrainAcc=1.0000
# Fold 7 Epoch 800: TotalLoss=0.002310 | Sup=0.002272 | Recon=0.000427 | TrainAcc=1.0000
# Fold 7 Epoch 900: TotalLoss=0.001924 | Sup=0.001884 | Recon=0.000446 | TrainAcc=1.0000
# Fold 7 Epoch 1000: TotalLoss=0.001719 | Sup=0.001678 | Recon=0.000463 | TrainAcc=1.0000
# Fold 7 Epoch 1100: TotalLoss=0.001537 | Sup=0.001494 | Recon=0.000477 | TrainAcc=1.0000
# Fold 7 Epoch 1200: TotalLoss=0.001171 | Sup=0.001128 | Recon=0.000486 | TrainAcc=1.0000
# Fold 7 Epoch 1300: TotalLoss=0.001040 | Sup=0.000996 | Recon=0.000497 | TrainAcc=1.0000
# Fold 7 Epoch 1400: TotalLoss=0.001034 | Sup=0.000989 | Recon=0.000498 | TrainAcc=1.0000
# Fold 7 Epoch 1500: TotalLoss=0.000955 | Sup=0.000909 | Recon=0.000506 | TrainAcc=1.0000
# Fold 7 Epoch 1600: TotalLoss=0.000789 | Sup=0.000743 | Recon=0.000509 | TrainAcc=1.0000
# Fold 7 Epoch 1700: TotalLoss=0.000673 | Sup=0.000626 | Recon=0.000518 | TrainAcc=1.0000
# Fold 7 Epoch 1800: TotalLoss=0.000576 | Sup=0.000530 | Recon=0.000518 | TrainAcc=1.0000
# Fold 7 Epoch 1900: TotalLoss=0.000587 | Sup=0.000540 | Recon=0.000518 | TrainAcc=1.0000
# Fold 7 Epoch 2000: TotalLoss=0.000536 | Sup=0.000488 | Recon=0.000529 | TrainAcc=1.0000
# Fold 7 → Acc=0.8409 | Prec=0.7059 | Rec=0.8571 | F1=0.7742 | AUC=0.9381 | CE Loss=0.5399
#
# === Fold 8 ===
# Train Control: 68, Train Patient: 33
# Fold 8 Epoch 1: TotalLoss=0.811293 | Sup=0.807365 | Recon=0.043641 | TrainAcc=0.6535
# Fold 8 Epoch 100: TotalLoss=0.158570 | Sup=0.158281 | Recon=0.003220 | TrainAcc=0.9901
# Fold 8 Epoch 200: TotalLoss=0.049277 | Sup=0.049139 | Recon=0.001539 | TrainAcc=1.0000
# Fold 8 Epoch 300: TotalLoss=0.022820 | Sup=0.022742 | Recon=0.000873 | TrainAcc=1.0000
# Fold 8 Epoch 400: TotalLoss=0.011061 | Sup=0.011009 | Recon=0.000580 | TrainAcc=1.0000
# Fold 8 Epoch 500: TotalLoss=0.007206 | Sup=0.007166 | Recon=0.000453 | TrainAcc=1.0000
# Fold 8 Epoch 600: TotalLoss=0.005010 | Sup=0.004973 | Recon=0.000415 | TrainAcc=1.0000
# Fold 8 Epoch 700: TotalLoss=0.003740 | Sup=0.003704 | Recon=0.000405 | TrainAcc=1.0000
# Fold 8 Epoch 800: TotalLoss=0.002667 | Sup=0.002630 | Recon=0.000420 | TrainAcc=1.0000
# Fold 8 Epoch 900: TotalLoss=0.002075 | Sup=0.002036 | Recon=0.000430 | TrainAcc=1.0000
# Fold 8 Epoch 1000: TotalLoss=0.001938 | Sup=0.001897 | Recon=0.000457 | TrainAcc=1.0000
# Fold 8 Epoch 1100: TotalLoss=0.001643 | Sup=0.001600 | Recon=0.000468 | TrainAcc=1.0000
# Fold 8 Epoch 1200: TotalLoss=0.001321 | Sup=0.001278 | Recon=0.000476 | TrainAcc=1.0000
# Fold 8 Epoch 1300: TotalLoss=0.001078 | Sup=0.001034 | Recon=0.000486 | TrainAcc=1.0000
# Fold 8 Epoch 1400: TotalLoss=0.000971 | Sup=0.000927 | Recon=0.000490 | TrainAcc=1.0000
# Fold 8 Epoch 1500: TotalLoss=0.000855 | Sup=0.000810 | Recon=0.000502 | TrainAcc=1.0000
# Fold 8 Epoch 1600: TotalLoss=0.000774 | Sup=0.000728 | Recon=0.000502 | TrainAcc=1.0000
# Fold 8 Epoch 1700: TotalLoss=0.000753 | Sup=0.000706 | Recon=0.000513 | TrainAcc=1.0000
# Fold 8 Epoch 1800: TotalLoss=0.000678 | Sup=0.000632 | Recon=0.000515 | TrainAcc=1.0000
# Fold 8 Epoch 1900: TotalLoss=0.000663 | Sup=0.000617 | Recon=0.000516 | TrainAcc=1.0000
# Fold 8 Epoch 2000: TotalLoss=0.000565 | Sup=0.000518 | Recon=0.000518 | TrainAcc=1.0000
# Fold 8 → Acc=0.9318 | Prec=0.8667 | Rec=0.9286 | F1=0.8966 | AUC=0.9952 | CE Loss=0.1351
#
# === Fold 9 ===
# Train Control: 68, Train Patient: 33
# Fold 9 Epoch 1: TotalLoss=0.699327 | Sup=0.695637 | Recon=0.041006 | TrainAcc=0.3465
# Fold 9 Epoch 100: TotalLoss=0.140659 | Sup=0.140374 | Recon=0.003165 | TrainAcc=1.0000
# Fold 9 Epoch 200: TotalLoss=0.039804 | Sup=0.039669 | Recon=0.001501 | TrainAcc=1.0000
# Fold 9 Epoch 300: TotalLoss=0.016618 | Sup=0.016542 | Recon=0.000849 | TrainAcc=1.0000
# Fold 9 Epoch 400: TotalLoss=0.008497 | Sup=0.008445 | Recon=0.000576 | TrainAcc=1.0000
# Fold 9 Epoch 500: TotalLoss=0.005760 | Sup=0.005719 | Recon=0.000452 | TrainAcc=1.0000
# Fold 9 Epoch 600: TotalLoss=0.003808 | Sup=0.003771 | Recon=0.000409 | TrainAcc=1.0000
# Fold 9 Epoch 700: TotalLoss=0.002778 | Sup=0.002742 | Recon=0.000407 | TrainAcc=1.0000
# Fold 9 Epoch 800: TotalLoss=0.002179 | Sup=0.002140 | Recon=0.000427 | TrainAcc=1.0000
# Fold 9 Epoch 900: TotalLoss=0.001729 | Sup=0.001689 | Recon=0.000446 | TrainAcc=1.0000
# Fold 9 Epoch 1000: TotalLoss=0.001471 | Sup=0.001429 | Recon=0.000467 | TrainAcc=1.0000
# Fold 9 Epoch 1100: TotalLoss=0.001331 | Sup=0.001288 | Recon=0.000480 | TrainAcc=1.0000
# Fold 9 Epoch 1200: TotalLoss=0.001116 | Sup=0.001073 | Recon=0.000483 | TrainAcc=1.0000
# Fold 9 Epoch 1300: TotalLoss=0.000933 | Sup=0.000888 | Recon=0.000503 | TrainAcc=1.0000
# Fold 9 Epoch 1400: TotalLoss=0.000805 | Sup=0.000760 | Recon=0.000506 | TrainAcc=1.0000
# Fold 9 Epoch 1500: TotalLoss=0.000644 | Sup=0.000598 | Recon=0.000508 | TrainAcc=1.0000
# Fold 9 Epoch 1600: TotalLoss=0.000734 | Sup=0.000687 | Recon=0.000515 | TrainAcc=1.0000
# Fold 9 Epoch 1700: TotalLoss=0.000615 | Sup=0.000569 | Recon=0.000517 | TrainAcc=1.0000
# Fold 9 Epoch 1800: TotalLoss=0.000542 | Sup=0.000495 | Recon=0.000524 | TrainAcc=1.0000
# Fold 9 Epoch 1900: TotalLoss=0.000575 | Sup=0.000527 | Recon=0.000529 | TrainAcc=1.0000
# Fold 9 Epoch 2000: TotalLoss=0.000446 | Sup=0.000398 | Recon=0.000530 | TrainAcc=1.0000
# Fold 9 → Acc=1.0000 | Prec=1.0000 | Rec=1.0000 | F1=1.0000 | AUC=1.0000 | CE Loss=0.0231
#
# ...
# Fold 13 Epoch 1700: TotalLoss=0.002335 | Sup=0.000682 | Recon=0.000207 | TrainAcc=1.0000
# Fold 13 Epoch 1800: TotalLoss=0.002040 | Sup=0.000550 | Recon=0.000186 | TrainAcc=1.0000
# Fold 13 Epoch 1900: TotalLoss=0.001867 | Sup=0.000518 | Recon=0.000169 | TrainAcc=1.0000
# Fold 13 Epoch 2000: TotalLoss=0.001712 | Sup=0.000475 | Recon=0.000155 | TrainAcc=1.0000
# Fold 13 → Acc=0.9545 | Prec=0.9286 | Rec=0.9286 | F1=0.9286 | AUC=0.9929 | CE Loss=0.1149
#
# === Fold 14 ===
# Train Control: 68, Train Patient: 33
# Fold 14 Epoch 1: TotalLoss=1.071517 | Sup=0.738641 | Recon=0.041609 | TrainAcc=0.6733
# Fold 14 Epoch 100: TotalLoss=0.156058 | Sup=0.133451 | Recon=0.002826 | TrainAcc=1.0000
# Fold 14 Epoch 200: TotalLoss=0.050445 | Sup=0.038380 | Recon=0.001508 | TrainAcc=1.0000
# Fold 14 Epoch 300: TotalLoss=0.024173 | Sup=0.016121 | Recon=0.001007 | TrainAcc=1.0000
# Fold 14 Epoch 400: TotalLoss=0.015380 | Sup=0.008876 | Recon=0.000813 | TrainAcc=1.0000
# Fold 14 Epoch 500: TotalLoss=0.010455 | Sup=0.004899 | Recon=0.000695 | TrainAcc=1.0000
# Fold 14 Epoch 600: TotalLoss=0.008948 | Sup=0.003973 | Recon=0.000622 | TrainAcc=1.0000
# Fold 14 Epoch 700: TotalLoss=0.007370 | Sup=0.002912 | Recon=0.000557 | TrainAcc=1.0000
# Fold 14 Epoch 800: TotalLoss=0.006184 | Sup=0.002084 | Recon=0.000513 | TrainAcc=1.0000
# Fold 14 Epoch 900: TotalLoss=0.005426 | Sup=0.001742 | Recon=0.000460 | TrainAcc=1.0000
# Fold 14 Epoch 1000: TotalLoss=0.004805 | Sup=0.001524 | Recon=0.000410 | TrainAcc=1.0000
# Fold 14 Epoch 1100: TotalLoss=0.003938 | Sup=0.001121 | Recon=0.000352 | TrainAcc=1.0000
# Fold 14 Epoch 1200: TotalLoss=0.003579 | Sup=0.000947 | Recon=0.000329 | TrainAcc=1.0000
# Fold 14 Epoch 1300: TotalLoss=0.003292 | Sup=0.000954 | Recon=0.000292 | TrainAcc=1.0000
# Fold 14 Epoch 1400: TotalLoss=0.003006 | Sup=0.000815 | Recon=0.000274 | TrainAcc=1.0000
# Fold 14 Epoch 1500: TotalLoss=0.002636 | Sup=0.000631 | Recon=0.000251 | TrainAcc=1.0000
# Fold 14 Epoch 1600: TotalLoss=0.002485 | Sup=0.000621 | Recon=0.000233 | TrainAcc=1.0000
# Fold 14 Epoch 1700: TotalLoss=0.002218 | Sup=0.000531 | Recon=0.000211 | TrainAcc=1.0000
# Fold 14 Epoch 1800: TotalLoss=0.002044 | Sup=0.000508 | Recon=0.000192 | TrainAcc=1.0000
# Fold 14 Epoch 1900: TotalLoss=0.001970 | Sup=0.000527 | Recon=0.000180 | TrainAcc=1.0000
# Fold 14 Epoch 2000: TotalLoss=0.001800 | Sup=0.000477 | Recon=0.000165 | TrainAcc=1.0000
# Fold 14 → Acc=0.8864 | Prec=0.8462 | Rec=0.7857 | F1=0.8148 | AUC=0.9738 | CE Loss=0.3068
#
# === Fold 15 ===
# Train Control: 68, Train Patient: 33
# Fold 15 Epoch 1: TotalLoss=1.231428 | Sup=0.862928 | Recon=0.046063 | TrainAcc=0.6733
# Fold 15 Epoch 100: TotalLoss=0.177968 | Sup=0.154033 | Recon=0.002992 | TrainAcc=1.0000
# Fold 15 Epoch 200: TotalLoss=0.062433 | Sup=0.049573 | Recon=0.001608 | TrainAcc=1.0000
# Fold 15 Epoch 300: TotalLoss=0.030226 | Sup=0.021423 | Recon=0.001100 | TrainAcc=1.0000
# Fold 15 Epoch 400: TotalLoss=0.017033 | Sup=0.010224 | Recon=0.000851 | TrainAcc=1.0000
# Fold 15 Epoch 500: TotalLoss=0.013087 | Sup=0.007371 | Recon=0.000714 | TrainAcc=1.0000
# Fold 15 Epoch 600: TotalLoss=0.009920 | Sup=0.004922 | Recon=0.000625 | TrainAcc=1.0000
# Fold 15 Epoch 700: TotalLoss=0.008190 | Sup=0.003765 | Recon=0.000553 | TrainAcc=1.0000
# Fold 15 Epoch 800: TotalLoss=0.006854 | Sup=0.002925 | Recon=0.000491 | TrainAcc=1.0000
# Fold 15 Epoch 900: TotalLoss=0.005600 | Sup=0.002057 | Recon=0.000443 | TrainAcc=1.0000
# Fold 15 Epoch 1000: TotalLoss=0.004982 | Sup=0.001762 | Recon=0.000402 | TrainAcc=1.0000
# Fold 15 Epoch 1100: TotalLoss=0.004422 | Sup=0.001498 | Recon=0.000365 | TrainAcc=1.0000
# Fold 15 Epoch 1200: TotalLoss=0.004031 | Sup=0.001322 | Recon=0.000339 | TrainAcc=1.0000
# Fold 15 Epoch 1300: TotalLoss=0.003483 | Sup=0.001038 | Recon=0.000306 | TrainAcc=1.0000
# Fold 15 Epoch 1400: TotalLoss=0.003263 | Sup=0.000955 | Recon=0.000288 | TrainAcc=1.0000
# Fold 15 Epoch 1500: TotalLoss=0.002874 | Sup=0.000794 | Recon=0.000260 | TrainAcc=1.0000
# Fold 15 Epoch 1600: TotalLoss=0.002535 | Sup=0.000625 | Recon=0.000239 | TrainAcc=1.0000
# Fold 15 Epoch 1700: TotalLoss=0.002464 | Sup=0.000745 | Recon=0.000215 | TrainAcc=1.0000
# Fold 15 Epoch 1800: TotalLoss=0.002231 | Sup=0.000678 | Recon=0.000194 | TrainAcc=1.0000
# Fold 15 Epoch 1900: TotalLoss=0.002005 | Sup=0.000565 | Recon=0.000180 | TrainAcc=1.0000
# Fold 15 Epoch 2000: TotalLoss=0.001867 | Sup=0.000521 | Recon=0.000168 | TrainAcc=1.0000
# Fold 15 → Acc=0.9091 | Prec=0.8571 | Rec=0.8571 | F1=0.8571 | AUC=0.9762 | CE Loss=0.3159
#
# === Fold 16 ===
# Train Control: 68, Train Patient: 33
# Fold 16 Epoch 1: TotalLoss=0.979602 | Sup=0.650464 | Recon=0.041142 | TrainAcc=0.6733
# Fold 16 Epoch 100: TotalLoss=0.152690 | Sup=0.129962 | Recon=0.002841 | TrainAcc=1.0000
# Fold 16 Epoch 200: TotalLoss=0.046665 | Sup=0.033767 | Recon=0.001612 | TrainAcc=1.0000
# Fold 16 Epoch 300: TotalLoss=0.024177 | Sup=0.015381 | Recon=0.001099 | TrainAcc=1.0000
# Fold 16 Epoch 400: TotalLoss=0.015213 | Sup=0.008677 | Recon=0.000817 | TrainAcc=1.0000
# Fold 16 Epoch 500: TotalLoss=0.011483 | Sup=0.005803 | Recon=0.000710 | TrainAcc=1.0000
# Fold 16 Epoch 600: TotalLoss=0.008888 | Sup=0.004106 | Recon=0.000598 | TrainAcc=1.0000
# Fold 16 Epoch 700: TotalLoss=0.007307 | Sup=0.003052 | Recon=0.000532 | TrainAcc=1.0000
# Fold 16 Epoch 800: TotalLoss=0.005950 | Sup=0.002146 | Recon=0.000475 | TrainAcc=1.0000
# Fold 16 Epoch 900: TotalLoss=0.004921 | Sup=0.001542 | Recon=0.000422 | TrainAcc=1.0000
# Fold 16 Epoch 1000: TotalLoss=0.004281 | Sup=0.001240 | Recon=0.000380 | TrainAcc=1.0000
# Fold 16 Epoch 1100: TotalLoss=0.003825 | Sup=0.001078 | Recon=0.000343 | TrainAcc=1.0000
# Fold 16 Epoch 1200: TotalLoss=0.003472 | Sup=0.001027 | Recon=0.000306 | TrainAcc=1.0000
# Fold 16 Epoch 1300: TotalLoss=0.003138 | Sup=0.000936 | Recon=0.000275 | TrainAcc=1.0000
# Fold 16 Epoch 1400: TotalLoss=0.002747 | Sup=0.000716 | Recon=0.000254 | TrainAcc=1.0000
# Fold 16 Epoch 1500: TotalLoss=0.002452 | Sup=0.000596 | Recon=0.000232 | TrainAcc=1.0000
# Fold 16 Epoch 1600: TotalLoss=0.002200 | Sup=0.000520 | Recon=0.000210 | TrainAcc=1.0000
# Fold 16 Epoch 1700: TotalLoss=0.002066 | Sup=0.000485 | Recon=0.000198 | TrainAcc=1.0000
# Fold 16 Epoch 1800: TotalLoss=0.001994 | Sup=0.000535 | Recon=0.000182 | TrainAcc=1.0000
# Fold 16 Epoch 1900: TotalLoss=0.001836 | Sup=0.000499 | Recon=0.000167 | TrainAcc=1.0000
# Fold 16 Epoch 2000: TotalLoss=0.001610 | Sup=0.000382 | Recon=0.000153 | TrainAcc=1.0000
# Fold 16 → Acc=0.9091 | Prec=0.9167 | Rec=0.7857 | F1=0.8462 | AUC=0.9762 | CE Loss=0.2822
#
# === Fold 17 ===
# Train Control: 68, Train Patient: 33
# Fold 17 Epoch 1: TotalLoss=1.019284 | Sup=0.679146 | Recon=0.042517 | TrainAcc=0.5347
# Fold 17 Epoch 100: TotalLoss=0.140809 | Sup=0.117033 | Recon=0.002972 | TrainAcc=1.0000
# Fold 17 Epoch 200: TotalLoss=0.044273 | Sup=0.031965 | Recon=0.001539 | TrainAcc=1.0000
# Fold 17 Epoch 300: TotalLoss=0.021434 | Sup=0.013398 | Recon=0.001005 | TrainAcc=1.0000
# Fold 17 Epoch 400: TotalLoss=0.013078 | Sup=0.007009 | Recon=0.000759 | TrainAcc=1.0000
# Fold 17 Epoch 500: TotalLoss=0.010057 | Sup=0.004680 | Recon=0.000672 | TrainAcc=1.0000
# Fold 17 Epoch 600: TotalLoss=0.008211 | Sup=0.003464 | Recon=0.000593 | TrainAcc=1.0000
# Fold 17 Epoch 700: TotalLoss=0.006988 | Sup=0.002622 | Recon=0.000546 | TrainAcc=1.0000
# Fold 17 Epoch 800: TotalLoss=0.006051 | Sup=0.001987 | Recon=0.000508 | TrainAcc=1.0000
# Fold 17 Epoch 900: TotalLoss=0.005294 | Sup=0.001557 | Recon=0.000467 | TrainAcc=1.0000
# Fold 17 Epoch 1000: TotalLoss=0.004586 | Sup=0.001171 | Recon=0.000427 | TrainAcc=1.0000
# Fold 17 Epoch 1100: TotalLoss=0.004125 | Sup=0.000981 | Recon=0.000393 | TrainAcc=1.0000
# Fold 17 Epoch 1200: TotalLoss=0.003716 | Sup=0.000883 | Recon=0.000354 | TrainAcc=1.0000
# Fold 17 Epoch 1300: TotalLoss=0.003390 | Sup=0.000757 | Recon=0.000329 | TrainAcc=1.0000
# Fold 17 Epoch 1400: TotalLoss=0.003105 | Sup=0.000743 | Recon=0.000295 | TrainAcc=1.0000
# Fold 17 Epoch 1500: TotalLoss=0.002771 | Sup=0.000627 | Recon=0.000268 | TrainAcc=1.0000
# Fold 17 Epoch 1600: TotalLoss=0.002426 | Sup=0.000522 | Recon=0.000238 | TrainAcc=1.0000
# Fold 17 Epoch 1700: TotalLoss=0.002213 | Sup=0.000473 | Recon=0.000217 | TrainAcc=1.0000
# Fold 17 Epoch 1800: TotalLoss=0.002006 | Sup=0.000448 | Recon=0.000195 | TrainAcc=1.0000
# Fold 17 Epoch 1900: TotalLoss=0.001871 | Sup=0.000435 | Recon=0.000179 | TrainAcc=1.0000
# Fold 17 Epoch 2000: TotalLoss=0.001720 | Sup=0.000404 | Recon=0.000165 | TrainAcc=1.0000
# Fold 17 → Acc=0.8864 | Prec=0.8000 | Rec=0.8571 | F1=0.8276 | AUC=0.9738 | CE Loss=0.2698
#
# === Fold 18 ===
# Train Control: 68, Train Patient: 33
# Fold 18 Epoch 1: TotalLoss=1.107841 | Sup=0.734463 | Recon=0.046672 | TrainAcc=0.6238
# Fold 18 Epoch 100: TotalLoss=0.143670 | Sup=0.117977 | Recon=0.003212 | TrainAcc=1.0000
# Fold 18 Epoch 200: TotalLoss=0.046959 | Sup=0.033946 | Recon=0.001627 | TrainAcc=1.0000
# Fold 18 Epoch 300: TotalLoss=0.022447 | Sup=0.014145 | Recon=0.001038 | TrainAcc=1.0000
# Fold 18 Epoch 400: TotalLoss=0.014028 | Sup=0.007613 | Recon=0.000802 | TrainAcc=1.0000
# Fold 18 Epoch 500: TotalLoss=0.010587 | Sup=0.005160 | Recon=0.000678 | TrainAcc=1.0000
# Fold 18 Epoch 600: TotalLoss=0.008167 | Sup=0.003423 | Recon=0.000593 | TrainAcc=1.0000
# Fold 18 Epoch 700: TotalLoss=0.006567 | Sup=0.002552 | Recon=0.000502 | TrainAcc=1.0000
# Fold 18 Epoch 800: TotalLoss=0.005478 | Sup=0.001974 | Recon=0.000438 | TrainAcc=1.0000
# Fold 18 Epoch 900: TotalLoss=0.004803 | Sup=0.001595 | Recon=0.000401 | TrainAcc=1.0000
# Fold 18 Epoch 1000: TotalLoss=0.004153 | Sup=0.001242 | Recon=0.000364 | TrainAcc=1.0000
# Fold 18 Epoch 1100: TotalLoss=0.003922 | Sup=0.001248 | Recon=0.000334 | TrainAcc=1.0000
# Fold 18 Epoch 1200: TotalLoss=0.003487 | Sup=0.001076 | Recon=0.000301 | TrainAcc=1.0000
# Fold 18 Epoch 1300: TotalLoss=0.003067 | Sup=0.000829 | Recon=0.000280 | TrainAcc=1.0000
# Fold 18 Epoch 1400: TotalLoss=0.002831 | Sup=0.000741 | Recon=0.000261 | TrainAcc=1.0000
# Fold 18 Epoch 1500: TotalLoss=0.002494 | Sup=0.000574 | Recon=0.000240 | TrainAcc=1.0000
# Fold 18 Epoch 1600: TotalLoss=0.002500 | Sup=0.000644 | Recon=0.000232 | TrainAcc=1.0000
# Fold 18 Epoch 1700: TotalLoss=0.002307 | Sup=0.000582 | Recon=0.000216 | TrainAcc=1.0000
# Fold 18 Epoch 1800: TotalLoss=0.002175 | Sup=0.000534 | Recon=0.000205 | TrainAcc=1.0000
# Fold 18 Epoch 1900: TotalLoss=0.001969 | Sup=0.000448 | Recon=0.000190 | TrainAcc=1.0000
# Fold 18 Epoch 2000: TotalLoss=0.001853 | Sup=0.000419 | Recon=0.000179 | TrainAcc=1.0000
# Fold 18 → Acc=0.9318 | Prec=0.8667 | Rec=0.9286 | F1=0.8966 | AUC=0.9643 | CE Loss=0.2834
#
# === Fold 19 ===
# Train Control: 68, Train Patient: 33
# Fold 19 Epoch 1: TotalLoss=1.214578 | Sup=0.828257 | Recon=0.048290 | TrainAcc=0.3663
# Fold 19 Epoch 100: TotalLoss=0.180378 | Sup=0.156126 | Recon=0.003031 | TrainAcc=1.0000
# Fold 19 Epoch 200: TotalLoss=0.065773 | Sup=0.052710 | Recon=0.001633 | TrainAcc=1.0000
# Fold 19 Epoch 300: TotalLoss=0.030824 | Sup=0.021869 | Recon=0.001119 | TrainAcc=1.0000
# Fold 19 Epoch 400: TotalLoss=0.017776 | Sup=0.010718 | Recon=0.000882 | TrainAcc=1.0000
# Fold 19 Epoch 500: TotalLoss=0.014223 | Sup=0.008197 | Recon=0.000753 | TrainAcc=1.0000
# Fold 19 Epoch 600: TotalLoss=0.010312 | Sup=0.005169 | Recon=0.000643 | TrainAcc=1.0000
# Fold 19 Epoch 700: TotalLoss=0.008295 | Sup=0.003892 | Recon=0.000550 | TrainAcc=1.0000
# Fold 19 Epoch 800: TotalLoss=0.007004 | Sup=0.003074 | Recon=0.000491 | TrainAcc=1.0000
# Fold 19 Epoch 900: TotalLoss=0.005740 | Sup=0.002277 | Recon=0.000433 | TrainAcc=1.0000
# Fold 19 Epoch 1000: TotalLoss=0.004949 | Sup=0.001759 | Recon=0.000399 | TrainAcc=1.0000
# Fold 19 Epoch 1100: TotalLoss=0.004471 | Sup=0.001540 | Recon=0.000366 | TrainAcc=1.0000
# Fold 19 Epoch 1200: TotalLoss=0.003846 | Sup=0.001266 | Recon=0.000322 | TrainAcc=1.0000
# Fold 19 Epoch 1300: TotalLoss=0.003507 | Sup=0.001091 | Recon=0.000302 | TrainAcc=1.0000
# Fold 19 Epoch 1400: TotalLoss=0.003216 | Sup=0.000961 | Recon=0.000282 | TrainAcc=1.0000
# Fold 19 Epoch 1500: TotalLoss=0.002932 | Sup=0.000856 | Recon=0.000259 | TrainAcc=1.0000
# Fold 19 Epoch 1600: TotalLoss=0.002836 | Sup=0.000911 | Recon=0.000241 | TrainAcc=1.0000
# Fold 19 Epoch 1700: TotalLoss=0.002386 | Sup=0.000693 | Recon=0.000212 | TrainAcc=1.0000
# Fold 19 Epoch 1800: TotalLoss=0.002214 | Sup=0.000640 | Recon=0.000197 | TrainAcc=1.0000
# Fold 19 Epoch 1900: TotalLoss=0.001998 | Sup=0.000540 | Recon=0.000182 | TrainAcc=1.0000
# Fold 19 Epoch 2000: TotalLoss=0.001906 | Sup=0.000570 | Recon=0.000167 | TrainAcc=1.0000
# Fold 19 → Acc=0.8182 | Prec=0.6875 | Rec=0.7857 | F1=0.7333 | AUC=0.9381 | CE Loss=0.4281
#
# === Fold 20 ===
# Train Control: 68, Train Patient: 33
# Fold 20 Epoch 1: TotalLoss=1.084139 | Sup=0.763696 | Recon=0.040055 | TrainAcc=0.3267
# Fold 20 Epoch 100: TotalLoss=0.168633 | Sup=0.145365 | Recon=0.002908 | TrainAcc=1.0000
# Fold 20 Epoch 200: TotalLoss=0.056858 | Sup=0.044732 | Recon=0.001516 | TrainAcc=1.0000
# Fold 20 Epoch 300: TotalLoss=0.026472 | Sup=0.018125 | Recon=0.001043 | TrainAcc=1.0000
# Fold 20 Epoch 400: TotalLoss=0.015620 | Sup=0.009207 | Recon=0.000802 | TrainAcc=1.0000
# Fold 20 Epoch 500: TotalLoss=0.011459 | Sup=0.005729 | Recon=0.000716 | TrainAcc=1.0000
# Fold 20 Epoch 600: TotalLoss=0.008787 | Sup=0.003799 | Recon=0.000623 | TrainAcc=1.0000
# Fold 20 Epoch 700: TotalLoss=0.007327 | Sup=0.002993 | Recon=0.000542 | TrainAcc=1.0000
# Fold 20 Epoch 800: TotalLoss=0.006092 | Sup=0.002340 | Recon=0.000469 | TrainAcc=1.0000
# Fold 20 Epoch 900: TotalLoss=0.005208 | Sup=0.001900 | Recon=0.000414 | TrainAcc=1.0000
# Fold 20 Epoch 1000: TotalLoss=0.004650 | Sup=0.001723 | Recon=0.000366 | TrainAcc=1.0000
# Fold 20 Epoch 1100: TotalLoss=0.004020 | Sup=0.001333 | Recon=0.000336 | TrainAcc=1.0000
# Fold 20 Epoch 1200: TotalLoss=0.003423 | Sup=0.001028 | Recon=0.000299 | TrainAcc=1.0000
# Fold 20 Epoch 1300: TotalLoss=0.003180 | Sup=0.000913 | Recon=0.000283 | TrainAcc=1.0000
# Fold 20 Epoch 1400: TotalLoss=0.002883 | Sup=0.000789 | Recon=0.000262 | TrainAcc=1.0000
# Fold 20 Epoch 1500: TotalLoss=0.002717 | Sup=0.000801 | Recon=0.000239 | TrainAcc=1.0000
# Fold 20 Epoch 1600: TotalLoss=0.002583 | Sup=0.000818 | Recon=0.000221 | TrainAcc=1.0000
# Fold 20 Epoch 1700: TotalLoss=0.002421 | Sup=0.000756 | Recon=0.000208 | TrainAcc=1.0000
# Fold 20 Epoch 1800: TotalLoss=0.001984 | Sup=0.000490 | Recon=0.000187 | TrainAcc=1.0000
# Fold 20 Epoch 1900: TotalLoss=0.001952 | Sup=0.000556 | Recon=0.000174 | TrainAcc=1.0000
# Fold 20 Epoch 2000: TotalLoss=0.001753 | Sup=0.000483 | Recon=0.000159 | TrainAcc=1.0000
# Fold 20 → Acc=0.8864 | Prec=0.8000 | Rec=0.8571 | F1=0.8276 | AUC=0.9333 | CE Loss=0.4166
#
# === Average Results for λ = 8 ===
# Accuracy:  0.9068
# Precision: 0.8509
# Recall:    0.8643
# F1-score:  0.8560
# CE Loss:   0.2657
# AUC:       0.9750
#
#
# ====================== FINAL SUMMARY ACROSS ALL λ ======================
# Lambda   | Accuracy  | Precision | Recall   | F1-score  | AUC      | CE Loss
# ------------------------------------------------------------------------
# 0.001    | 0.9057    | 0.8517    | 0.8607   | 0.8542    | 0.9761   | 0.2645
# 0.005    | 0.9102    | 0.8584    | 0.8679   | 0.8613    | 0.9760   | 0.2637
# 0.009    | 0.9102    | 0.8597    | 0.8643   | 0.8602    | 0.9736   | 0.2706
# 0.01     | 0.9080    | 0.8534    | 0.8643   | 0.8571    | 0.9757   | 0.2685
# 0.05     | 0.9148    | 0.8636    | 0.8750   | 0.8677    | 0.9742   | 0.2659
# 0.09     | 0.9091    | 0.8595    | 0.8607   | 0.8582    | 0.9746   | 0.2676
# 0.1      | 0.9125    | 0.8669    | 0.8643   | 0.8635    | 0.9743   | 0.2689
# 0.3      | 0.9102    | 0.8559    | 0.8679   | 0.8604    | 0.9745   | 0.2678
# 0.5      | 0.9057    | 0.8547    | 0.8536   | 0.8524    | 0.9736   | 0.2676
# 0.9      | 0.9068    | 0.8517    | 0.8643   | 0.8561    | 0.9760   | 0.2668
# 1        | 0.9102    | 0.8571    | 0.8679   | 0.8608    | 0.9756   | 0.2618
# 2        | 0.9114    | 0.8643    | 0.8607   | 0.8611    | 0.9752   | 0.2658
# 5        | 0.9057    | 0.8514    | 0.8571   | 0.8522    | 0.9760   | 0.2693
# 8        | 0.9068    | 0.8509    | 0.8643   | 0.8560    | 0.9750   | 0.2657
