# %%
import torch
import torch.nn as nn
import torch.nn.functional as nnFn
import torch.optim as optim
import numpy as np
import random
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from torch_geometric.data import Data
from torch_geometric.nn import ARMAConv
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score,
    f1_score, roc_auc_score, log_loss
)

# %%
fa_feature_path = "/home/snu/Downloads/Histogram_CN_FA_20bin_updated.npy"
Histogram_feature_CN_FA_array = np.load(fa_feature_path, allow_pickle=True)

fa_feature_path = "/home/snu/Downloads/Histogram_AD_FA_20bin_updated.npy"
Histogram_feature_AD_FA_array = np.load(fa_feature_path, allow_pickle=True)

X = np.vstack([Histogram_feature_CN_FA_array, Histogram_feature_AD_FA_array])
y = np.hstack([
    np.zeros(Histogram_feature_CN_FA_array.shape[0], dtype=np.int64),
    np.ones(Histogram_feature_AD_FA_array.shape[0], dtype=np.int64)
])

num_nodes, num_feats = X.shape
print(f"Features: {X.shape}, Labels: {y.shape}")
# Out:
# Features: (223, 180), Labels: (223,)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch_geometric.nn import ARMAConv

class ARMA_Supervised(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim, activ="SELU"):
        super(ARMA_Supervised, self).__init__()
        self.conv1 = ARMAConv(input_dim, hidden_dim, num_stacks=1, num_layers=1)
        self.bn1 = nn.BatchNorm1d(hidden_dim)
        self.dropout = nn.Dropout(0.2)
        self.fc = nn.Linear(hidden_dim, output_dim)
        activations = {
            "SELU": F.selu,
            "SiLU": F.silu,
            "GELU": F.gelu,
            "RELU": F.relu,
            "ELU": F.elu
        }
        self.act = activations.get(activ, F.elu)

    def forward(self, data):
        x, edge_index = data.x, data.edge_index
        x = self.conv1(x, edge_index)
        x = self.bn1(x)
        x = self.act(x)
        x = self.dropout(x)
        logits = self.fc(x)
        return logits

# %%
def create_adj(F, alpha=1):
    F_norm = F / np.linalg.norm(F, axis=1, keepdims=True)
    W = np.dot(F_norm, F_norm.T)
    W = np.where(W >= alpha, 1, 0).astype(np.float32)
    W = W / W.max()
    return W

def load_data(adj, node_feats):
    node_feats = torch.from_numpy(node_feats).float()
    edge_index = torch.from_numpy(np.array(np.nonzero((adj > 0))))
    return Data(x=node_feats, edge_index=edge_index)

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
alpha = 0.8
feats_dim = num_feats
hidden_dim = 512
num_classes = 2
num_epochs = 2000
lr = 0.0001
weight_decay = 1e-4
batch_print_freq = 100

# %%
W = create_adj(X, alpha)
data = load_data(W, X).to(device)
A_tensor = torch.from_numpy(W).float().to(device)
print(data)
# Out:
# Data(x=[223, 180], edge_index=[2, 41689])

# %%
sss = StratifiedShuffleSplit(n_splits=20, test_size=0.3, random_state=42)

accuracies, precisions, recalls, f1_scores, aucs, ce_losses = [], [], [], [], [], []

for fold, (train_idx, test_idx) in enumerate(sss.split(X, y), start=1):
    print(f"\n=== Fold {fold} ===")

    train_idx_t = torch.from_numpy(train_idx).long().to(device)
    y_train_tensor = torch.from_numpy(y[train_idx]).long().to(device)

    model = ARMA_Supervised(feats_dim, hidden_dim, num_classes, "SELU").to(device)
    optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
    ce_loss = nn.CrossEntropyLoss()


    for epoch in range(1, num_epochs + 1):
        model.train()
        optimizer.zero_grad()

        logits = model(data)
        loss = ce_loss(logits[train_idx_t], y_train_tensor)
        loss.backward()
        optimizer.step()

        if epoch % batch_print_freq == 0 or epoch == 1:
            model.eval()
            with torch.no_grad():
                preds_train = logits[train_idx_t].argmax(dim=1)
                acc_train = accuracy_score(y_train_tensor.cpu(), preds_train.cpu())
            print(f"Fold {fold} Epoch {epoch}: "
                  f"Loss={loss.item():.6f} | TrainAcc={acc_train:.4f}")


    model.eval()
    with torch.no_grad():
        out = model(data)
        preds = out.argmax(dim=1).cpu().numpy()
        probs = torch.softmax(out, dim=1)[:, 1].cpu().numpy()  # Probability for class 1

    y_test = y[test_idx]
    y_pred_test = preds[test_idx]
    y_prob_test = probs[test_idx]


    acc = accuracy_score(y_test, y_pred_test)
    prec = precision_score(y_test, y_pred_test, zero_division=0)
    rec = recall_score(y_test, y_pred_test, zero_division=0)
    f1 = f1_score(y_test, y_pred_test, zero_division=0)
    auc = roc_auc_score(y_test, y_prob_test)
    ce = log_loss(y_test, y_prob_test)

    accuracies.append(acc)
    precisions.append(prec)
    recalls.append(rec)
    f1_scores.append(f1)
    aucs.append(auc)
    ce_losses.append(ce)

    print(f"Fold {fold} → "
          f"Acc={acc:.4f} | Prec={prec:.4f} | Rec={rec:.4f} | "
          f"F1={f1:.4f} | AUC={auc:.4f} | CE Loss={ce:.4f}")


print("\n=== Average Results Across 20 Folds ===")
print(f"Accuracy:  {np.mean(accuracies):.4f} ± {np.std(accuracies):.4f}")
print(f"Precision: {np.mean(precisions):.4f} ± {np.std(precisions):.4f}")
print(f"Recall:    {np.mean(recalls):.4f} ± {np.std(recalls):.4f}")
print(f"F1-score:  {np.mean(f1_scores):.4f} ± {np.std(f1_scores):.4f}")
print(f"CE Loss:   {np.mean(ce_losses):.4f} ± {np.std(ce_losses):.4f}")
print(f"AUC:       {np.mean(aucs):.4f} ± {np.std(aucs):.4f}")
# Out:
# === Fold 1 ===
# Fold 1 Epoch 1: Loss=0.725840 | TrainAcc=0.4872
# Fold 1 Epoch 100: Loss=0.177154 | TrainAcc=0.9679
# Fold 1 Epoch 200: Loss=0.059224 | TrainAcc=1.0000
# Fold 1 Epoch 300: Loss=0.024500 | TrainAcc=1.0000
# Fold 1 Epoch 400: Loss=0.011046 | TrainAcc=1.0000
# Fold 1 Epoch 500: Loss=0.006245 | TrainAcc=1.0000
# Fold 1 Epoch 600: Loss=0.004076 | TrainAcc=1.0000
# Fold 1 Epoch 700: Loss=0.002450 | TrainAcc=1.0000
# Fold 1 Epoch 800: Loss=0.001832 | TrainAcc=1.0000
# Fold 1 Epoch 900: Loss=0.001336 | TrainAcc=1.0000
# Fold 1 Epoch 1000: Loss=0.001072 | TrainAcc=1.0000
# Fold 1 Epoch 1100: Loss=0.000788 | TrainAcc=1.0000
# Fold 1 Epoch 1200: Loss=0.000550 | TrainAcc=1.0000
# Fold 1 Epoch 1300: Loss=0.000421 | TrainAcc=1.0000
# Fold 1 Epoch 1400: Loss=0.000311 | TrainAcc=1.0000
# Fold 1 Epoch 1500: Loss=0.000290 | TrainAcc=1.0000
# Fold 1 Epoch 1600: Loss=0.000229 | TrainAcc=1.0000
# Fold 1 Epoch 1700: Loss=0.000250 | TrainAcc=1.0000
# Fold 1 Epoch 1800: Loss=0.000194 | TrainAcc=1.0000
# Fold 1 Epoch 1900: Loss=0.000213 | TrainAcc=1.0000
# Fold 1 Epoch 2000: Loss=0.000158 | TrainAcc=1.0000
# Fold 1 → Acc=0.8507 | Prec=0.7742 | Rec=0.8889 | F1=0.8276 | AUC=0.9343 | CE Loss=0.5195
#
# === Fold 2 ===
# Fold 2 Epoch 1: Loss=0.714863 | TrainAcc=0.5256
# Fold 2 Epoch 100: Loss=0.147689 | TrainAcc=0.9808
# Fold 2 Epoch 200: Loss=0.047529 | TrainAcc=1.0000
# Fold 2 Epoch 300: Loss=0.017712 | TrainAcc=1.0000
# Fold 2 Epoch 400: Loss=0.008857 | TrainAcc=1.0000
# Fold 2 Epoch 500: Loss=0.006076 | TrainAcc=1.0000
# Fold 2 Epoch 600: Loss=0.003685 | TrainAcc=1.0000
# Fold 2 Epoch 700: Loss=0.002591 | TrainAcc=1.0000
# Fold 2 Epoch 800: Loss=0.001817 | TrainAcc=1.0000
# Fold 2 Epoch 900: Loss=0.001384 | TrainAcc=1.0000
# Fold 2 Epoch 1000: Loss=0.001035 | TrainAcc=1.0000
# Fold 2 Epoch 1100: Loss=0.001129 | TrainAcc=1.0000
# Fold 2 Epoch 1200: Loss=0.000890 | TrainAcc=1.0000
# Fold 2 Epoch 1300: Loss=0.000710 | TrainAcc=1.0000
# Fold 2 Epoch 1400: Loss=0.000682 | TrainAcc=1.0000
# Fold 2 Epoch 1500: Loss=0.000488 | TrainAcc=1.0000
# Fold 2 Epoch 1600: Loss=0.000373 | TrainAcc=1.0000
# Fold 2 Epoch 1700: Loss=0.000343 | TrainAcc=1.0000
# Fold 2 Epoch 1800: Loss=0.000245 | TrainAcc=1.0000
# Fold 2 Epoch 1900: Loss=0.000236 | TrainAcc=1.0000
# Fold 2 Epoch 2000: Loss=0.000206 | TrainAcc=1.0000
# Fold 2 → Acc=0.7164 | Prec=0.6538 | Rec=0.6296 | F1=0.6415 | AUC=0.8486 | CE Loss=1.2212
#
# === Fold 3 ===
# Fold 3 Epoch 1: Loss=0.844097 | TrainAcc=0.4038
# Fold 3 Epoch 100: Loss=0.177275 | TrainAcc=0.9615
# Fold 3 Epoch 200: Loss=0.056860 | TrainAcc=1.0000
# Fold 3 Epoch 300: Loss=0.021397 | TrainAcc=1.0000
# Fold 3 Epoch 400: Loss=0.011006 | TrainAcc=1.0000
# Fold 3 Epoch 500: Loss=0.006492 | TrainAcc=1.0000
# Fold 3 Epoch 600: Loss=0.004500 | TrainAcc=1.0000
# Fold 3 Epoch 700: Loss=0.003068 | TrainAcc=1.0000
# Fold 3 Epoch 800: Loss=0.002245 | TrainAcc=1.0000
# Fold 3 Epoch 900: Loss=0.001520 | TrainAcc=1.0000
# Fold 3 Epoch 1000: Loss=0.001095 | TrainAcc=1.0000
# Fold 3 Epoch 1100: Loss=0.001109 | TrainAcc=1.0000
# Fold 3 Epoch 1200: Loss=0.000670 | TrainAcc=1.0000
# Fold 3 Epoch 1300: Loss=0.000528 | TrainAcc=1.0000
# Fold 3 Epoch 1400: Loss=0.000471 | TrainAcc=1.0000
# Fold 3 Epoch 1500: Loss=0.000400 | TrainAcc=1.0000
# Fold 3 Epoch 1600: Loss=0.000311 | TrainAcc=1.0000
# Fold 3 Epoch 1700: Loss=0.000261 | TrainAcc=1.0000
# Fold 3 Epoch 1800: Loss=0.000225 | TrainAcc=1.0000
# Fold 3 Epoch 1900: Loss=0.000295 | TrainAcc=1.0000
# Fold 3 Epoch 2000: Loss=0.000182 | TrainAcc=1.0000
# Fold 3 → Acc=0.7015 | Prec=0.6207 | Rec=0.6667 | F1=0.6429 | AUC=0.8463 | CE Loss=0.9093
#
# === Fold 4 ===
# Fold 4 Epoch 1: Loss=0.982877 | TrainAcc=0.3269
# Fold 4 Epoch 100: Loss=0.193433 | TrainAcc=0.9679
# Fold 4 Epoch 200: Loss=0.071714 | TrainAcc=1.0000
# Fold 4 Epoch 300: Loss=0.026168 | TrainAcc=1.0000
# Fold 4 Epoch 400: Loss=0.013585 | TrainAcc=1.0000
# Fold 4 Epoch 500: Loss=0.007549 | TrainAcc=1.0000
# Fold 4 Epoch 600: Loss=0.005240 | TrainAcc=1.0000
# Fold 4 Epoch 700: Loss=0.003764 | TrainAcc=1.0000
# Fold 4 Epoch 800: Loss=0.002489 | TrainAcc=1.0000
# Fold 4 Epoch 900: Loss=0.001876 | TrainAcc=1.0000
# Fold 4 Epoch 1000: Loss=0.001825 | TrainAcc=1.0000
# Fold 4 Epoch 1100: Loss=0.001138 | TrainAcc=1.0000
# Fold 4 Epoch 1200: Loss=0.001114 | TrainAcc=1.0000
# Fold 4 Epoch 1300: Loss=0.000967 | TrainAcc=1.0000
# Fold 4 Epoch 1400: Loss=0.000608 | TrainAcc=1.0000
# Fold 4 Epoch 1500: Loss=0.000470 | TrainAcc=1.0000
# Fold 4 Epoch 1600: Loss=0.000423 | TrainAcc=1.0000
# Fold 4 Epoch 1700: Loss=0.000406 | TrainAcc=1.0000
# Fold 4 Epoch 1800: Loss=0.000303 | TrainAcc=1.0000
# Fold 4 Epoch 1900: Loss=0.000297 | TrainAcc=1.0000
# Fold 4 Epoch 2000: Loss=0.000325 | TrainAcc=1.0000
# Fold 4 → Acc=0.8209 | Prec=0.7586 | Rec=0.8148 | F1=0.7857 | AUC=0.8954 | CE Loss=0.8094
#
# === Fold 5 ===
# Fold 5 Epoch 1: Loss=0.818170 | TrainAcc=0.4551
# Fold 5 Epoch 100: Loss=0.214372 | TrainAcc=0.9487
# Fold 5 Epoch 200: Loss=0.075304 | TrainAcc=0.9936
# Fold 5 Epoch 300: Loss=0.030071 | TrainAcc=1.0000
# Fold 5 Epoch 400: Loss=0.015978 | TrainAcc=1.0000
# Fold 5 Epoch 500: Loss=0.009697 | TrainAcc=1.0000
# Fold 5 Epoch 600: Loss=0.005547 | TrainAcc=1.0000
# Fold 5 Epoch 700: Loss=0.004248 | TrainAcc=1.0000
# Fold 5 Epoch 800: Loss=0.002555 | TrainAcc=1.0000
# Fold 5 Epoch 900: Loss=0.001997 | TrainAcc=1.0000
# Fold 5 Epoch 1000: Loss=0.001450 | TrainAcc=1.0000
# Fold 5 Epoch 1100: Loss=0.001334 | TrainAcc=1.0000
# Fold 5 Epoch 1200: Loss=0.001024 | TrainAcc=1.0000
# Fold 5 Epoch 1300: Loss=0.000789 | TrainAcc=1.0000
# Fold 5 Epoch 1400: Loss=0.000766 | TrainAcc=1.0000
# Fold 5 Epoch 1500: Loss=0.000542 | TrainAcc=1.0000
# Fold 5 Epoch 1600: Loss=0.000402 | TrainAcc=1.0000
# Fold 5 Epoch 1700: Loss=0.000385 | TrainAcc=1.0000
# Fold 5 Epoch 1800: Loss=0.000318 | TrainAcc=1.0000
# Fold 5 Epoch 1900: Loss=0.000304 | TrainAcc=1.0000
# Fold 5 Epoch 2000: Loss=0.000278 | TrainAcc=1.0000
# Fold 5 → Acc=0.9104 | Prec=0.9200 | Rec=0.8519 | F1=0.8846 | AUC=0.9380 | CE Loss=0.3832
#
# === Fold 6 ===
# Fold 6 Epoch 1: Loss=0.896768 | TrainAcc=0.4038
# Fold 6 Epoch 100: Loss=0.172756 | TrainAcc=0.9487
# Fold 6 Epoch 200: Loss=0.055606 | TrainAcc=1.0000
# Fold 6 Epoch 300: Loss=0.024834 | TrainAcc=1.0000
# Fold 6 Epoch 400: Loss=0.014488 | TrainAcc=1.0000
# Fold 6 Epoch 500: Loss=0.006025 | TrainAcc=1.0000
# Fold 6 Epoch 600: Loss=0.004274 | TrainAcc=1.0000
# Fold 6 Epoch 700: Loss=0.002786 | TrainAcc=1.0000
# Fold 6 Epoch 800: Loss=0.002016 | TrainAcc=1.0000
# Fold 6 Epoch 900: Loss=0.001301 | TrainAcc=1.0000
# Fold 6 Epoch 1000: Loss=0.000927 | TrainAcc=1.0000
# Fold 6 Epoch 1100: Loss=0.000726 | TrainAcc=1.0000
# Fold 6 Epoch 1200: Loss=0.000479 | TrainAcc=1.0000
# Fold 6 Epoch 1300: Loss=0.000574 | TrainAcc=1.0000
# Fold 6 Epoch 1400: Loss=0.000354 | TrainAcc=1.0000
# Fold 6 Epoch 1500: Loss=0.000332 | TrainAcc=1.0000
# Fold 6 Epoch 1600: Loss=0.000254 | TrainAcc=1.0000
# Fold 6 Epoch 1700: Loss=0.000190 | TrainAcc=1.0000
# Fold 6 Epoch 1800: Loss=0.000150 | TrainAcc=1.0000
# Fold 6 Epoch 1900: Loss=0.000197 | TrainAcc=1.0000
# Fold 6 Epoch 2000: Loss=0.000146 | TrainAcc=1.0000
# Fold 6 → Acc=0.7015 | Prec=0.6296 | Rec=0.6296 | F1=0.6296 | AUC=0.8005 | CE Loss=1.1239
#
# === Fold 7 ===
# Fold 7 Epoch 1: Loss=0.689309 | TrainAcc=0.5577
# Fold 7 Epoch 100: Loss=0.162693 | TrainAcc=0.9679
# Fold 7 Epoch 200: Loss=0.054378 | TrainAcc=1.0000
# Fold 7 Epoch 300: Loss=0.018741 | TrainAcc=1.0000
# Fold 7 Epoch 400: Loss=0.009224 | TrainAcc=1.0000
# Fold 7 Epoch 500: Loss=0.005393 | TrainAcc=1.0000
# Fold 7 Epoch 600: Loss=0.003683 | TrainAcc=1.0000
# Fold 7 Epoch 700: Loss=0.002630 | TrainAcc=1.0000
# Fold 7 Epoch 800: Loss=0.002127 | TrainAcc=1.0000
# Fold 7 Epoch 900: Loss=0.001238 | TrainAcc=1.0000
# Fold 7 Epoch 1000: Loss=0.001051 | TrainAcc=1.0000
# Fold 7 Epoch 1100: Loss=0.001048 | TrainAcc=1.0000
# Fold 7 Epoch 1200: Loss=0.000760 | TrainAcc=1.0000
# Fold 7 Epoch 1300: Loss=0.000705 | TrainAcc=1.0000
# Fold 7 Epoch 1400: Loss=0.000523 | TrainAcc=1.0000
# Fold 7 Epoch 1500: Loss=0.000512 | TrainAcc=1.0000
# Fold 7 Epoch 1600: Loss=0.000454 | TrainAcc=1.0000
# Fold 7 Epoch 1700: Loss=0.000364 | TrainAcc=1.0000
# Fold 7 Epoch 1800: Loss=0.000314 | TrainAcc=1.0000
# Fold 7 Epoch 1900: Loss=0.000299 | TrainAcc=1.0000
# Fold 7 Epoch 2000: Loss=0.000229 | TrainAcc=1.0000
# Fold 7 → Acc=0.8060 | Prec=0.7500 | Rec=0.7778 | F1=0.7636 | AUC=0.8417 | CE Loss=0.8951
#
# === Fold 8 ===
# Fold 8 Epoch 1: Loss=0.653117 | TrainAcc=0.6154
# Fold 8 Epoch 100: Loss=0.145924 | TrainAcc=0.9744
# Fold 8 Epoch 200: Loss=0.043308 | TrainAcc=1.0000
# Fold 8 Epoch 300: Loss=0.015798 | TrainAcc=1.0000
# Fold 8 Epoch 400: Loss=0.007492 | TrainAcc=1.0000
# Fold 8 Epoch 500: Loss=0.004201 | TrainAcc=1.0000
# Fold 8 Epoch 600: Loss=0.003105 | TrainAcc=1.0000
# Fold 8 Epoch 700: Loss=0.001870 | TrainAcc=1.0000
# Fold 8 Epoch 800: Loss=0.001437 | TrainAcc=1.0000
# Fold 8 Epoch 900: Loss=0.001287 | TrainAcc=1.0000
# Fold 8 Epoch 1000: Loss=0.000887 | TrainAcc=1.0000
# Fold 8 Epoch 1100: Loss=0.000679 | TrainAcc=1.0000
# Fold 8 Epoch 1200: Loss=0.000546 | TrainAcc=1.0000
# Fold 8 Epoch 1300: Loss=0.000407 | TrainAcc=1.0000
# Fold 8 Epoch 1400: Loss=0.000426 | TrainAcc=1.0000
# Fold 8 Epoch 1500: Loss=0.000300 | TrainAcc=1.0000
# Fold 8 Epoch 1600: Loss=0.000255 | TrainAcc=1.0000
# Fold 8 Epoch 1700: Loss=0.000224 | TrainAcc=1.0000
# Fold 8 Epoch 1800: Loss=0.000173 | TrainAcc=1.0000
# Fold 8 Epoch 1900: Loss=0.000175 | TrainAcc=1.0000
# Fold 8 Epoch 2000: Loss=0.000178 | TrainAcc=1.0000
# Fold 8 → Acc=0.8209 | Prec=0.7027 | Rec=0.9630 | F1=0.8125 | AUC=0.9079 | CE Loss=1.0309
#
# === Fold 9 ===
# Fold 9 Epoch 1: Loss=0.632632 | TrainAcc=0.6154
# Fold 9 Epoch 100: Loss=0.155487 | TrainAcc=0.9615
# Fold 9 Epoch 200: Loss=0.045831 | TrainAcc=1.0000
# Fold 9 Epoch 300: Loss=0.020622 | TrainAcc=1.0000
# Fold 9 Epoch 400: Loss=0.009458 | TrainAcc=1.0000
# Fold 9 Epoch 500: Loss=0.005708 | TrainAcc=1.0000
# Fold 9 Epoch 600: Loss=0.003139 | TrainAcc=1.0000
# Fold 9 Epoch 700: Loss=0.002111 | TrainAcc=1.0000
# Fold 9 Epoch 800: Loss=0.001850 | TrainAcc=1.0000
# Fold 9 Epoch 900: Loss=0.001284 | TrainAcc=1.0000
# Fold 9 Epoch 1000: Loss=0.000915 | TrainAcc=1.0000
# Fold 9 Epoch 1100: Loss=0.000655 | TrainAcc=1.0000
# Fold 9 Epoch 1200: Loss=0.000508 | TrainAcc=1.0000
# Fold 9 Epoch 1300: Loss=0.000484 | TrainAcc=1.0000
# Fold 9 Epoch 1400: Loss=0.000366 | TrainAcc=1.0000
# Fold 9 Epoch 1500: Loss=0.000297 | TrainAcc=1.0000
# Fold 9 Epoch 1600: Loss=0.000230 | TrainAcc=1.0000
# Fold 9 Epoch 1700: Loss=0.000195 | TrainAcc=1.0000
# Fold 9 Epoch 1800: Loss=0.000164 | TrainAcc=1.0000
# Fold 9 Epoch 1900: Loss=0.000156 | TrainAcc=1.0000
# Fold 9 Epoch 2000: Loss=0.000163 | TrainAcc=1.0000
# Fold 9 → Acc=0.8507 | Prec=0.8148 | Rec=0.8148 | F1=0.8148 | AUC=0.8593 | CE Loss=0.8134
#
# === Fold 10 ===
# Fold 10 Epoch 1: Loss=0.693996 | TrainAcc=0.5833
# Fold 10 Epoch 100: Loss=0.159586 | TrainAcc=0.9679
# Fold 10 Epoch 200: Loss=0.055279 | TrainAcc=1.0000
# Fold 10 Epoch 300: Loss=0.020359 | TrainAcc=1.0000
# Fold 10 Epoch 400: Loss=0.011176 | TrainAcc=1.0000
# Fold 10 Epoch 500: Loss=0.006451 | TrainAcc=1.0000
# Fold 10 Epoch 600: Loss=0.003646 | TrainAcc=1.0000
# Fold 10 Epoch 700: Loss=0.002676 | TrainAcc=1.0000
# Fold 10 Epoch 800: Loss=0.001779 | TrainAcc=1.0000
# Fold 10 Epoch 900: Loss=0.001472 | TrainAcc=1.0000
# Fold 10 Epoch 1000: Loss=0.001396 | TrainAcc=1.0000
# Fold 10 Epoch 1100: Loss=0.000794 | TrainAcc=1.0000
# Fold 10 Epoch 1200: Loss=0.000611 | TrainAcc=1.0000
# Fold 10 Epoch 1300: Loss=0.000583 | TrainAcc=1.0000
# Fold 10 Epoch 1400: Loss=0.000404 | TrainAcc=1.0000
# Fold 10 Epoch 1500: Loss=0.000346 | TrainAcc=1.0000
# Fold 10 Epoch 1600: Loss=0.000333 | TrainAcc=1.0000
# Fold 10 Epoch 1700: Loss=0.000251 | TrainAcc=1.0000
# Fold 10 Epoch 1800: Loss=0.000265 | TrainAcc=1.0000
# Fold 10 Epoch 1900: Loss=0.000239 | TrainAcc=1.0000
# Fold 10 Epoch 2000: Loss=0.000210 | TrainAcc=1.0000
# Fold 10 → Acc=0.7910 | Prec=0.7826 | Rec=0.6667 | F1=0.7200 | AUC=0.8620 | CE Loss=0.8682
#
# === Fold 11 ===
# Fold 11 Epoch 1: Loss=0.913473 | TrainAcc=0.3654
# Fold 11 Epoch 100: Loss=0.187817 | TrainAcc=0.9551
# Fold 11 Epoch 200: Loss=0.061385 | TrainAcc=1.0000
# Fold 11 Epoch 300: Loss=0.027068 | TrainAcc=1.0000
# Fold 11 Epoch 400: Loss=0.013719 | TrainAcc=1.0000
# Fold 11 Epoch 500: Loss=0.007590 | TrainAcc=1.0000
# Fold 11 Epoch 600: Loss=0.005222 | TrainAcc=1.0000
# Fold 11 Epoch 700: Loss=0.003865 | TrainAcc=1.0000
# Fold 11 Epoch 800: Loss=0.002192 | TrainAcc=1.0000
# Fold 11 Epoch 900: Loss=0.001643 | TrainAcc=1.0000
# Fold 11 Epoch 1000: Loss=0.001369 | TrainAcc=1.0000
# Fold 11 Epoch 1100: Loss=0.001313 | TrainAcc=1.0000
# Fold 11 Epoch 1200: Loss=0.000833 | TrainAcc=1.0000
# Fold 11 Epoch 1300: Loss=0.000679 | TrainAcc=1.0000
# Fold 11 Epoch 1400: Loss=0.000562 | TrainAcc=1.0000
# Fold 11 Epoch 1500: Loss=0.000555 | TrainAcc=1.0000
# Fold 11 Epoch 1600: Loss=0.000352 | TrainAcc=1.0000
# Fold 11 Epoch 1700: Loss=0.000320 | TrainAcc=1.0000
# Fold 11 Epoch 1800: Loss=0.000291 | TrainAcc=1.0000
# Fold 11 Epoch 1900: Loss=0.000269 | TrainAcc=1.0000
# Fold 11 Epoch 2000: Loss=0.000258 | TrainAcc=1.0000
# Fold 11 → Acc=0.7612 | Prec=0.7037 | Rec=0.7037 | F1=0.7037 | AUC=0.8648 | CE Loss=0.9131
#
# === Fold 12 ===
# Fold 12 Epoch 1: Loss=0.765619 | TrainAcc=0.5192
# Fold 12 Epoch 100: Loss=0.151871 | TrainAcc=0.9744
# Fold 12 Epoch 200: Loss=0.050152 | TrainAcc=1.0000
# Fold 12 Epoch 300: Loss=0.021560 | TrainAcc=1.0000
# Fold 12 Epoch 400: Loss=0.009619 | TrainAcc=1.0000
# Fold 12 Epoch 500: Loss=0.005768 | TrainAcc=1.0000
# Fold 12 Epoch 600: Loss=0.004823 | TrainAcc=1.0000
# Fold 12 Epoch 700: Loss=0.002994 | TrainAcc=1.0000
# Fold 12 Epoch 800: Loss=0.002346 | TrainAcc=1.0000
# Fold 12 Epoch 900: Loss=0.001630 | TrainAcc=1.0000
# Fold 12 Epoch 1000: Loss=0.001359 | TrainAcc=1.0000
# Fold 12 Epoch 1100: Loss=0.001212 | TrainAcc=1.0000
# Fold 12 Epoch 1200: Loss=0.000867 | TrainAcc=1.0000
# Fold 12 Epoch 1300: Loss=0.000800 | TrainAcc=1.0000
# Fold 12 Epoch 1400: Loss=0.000653 | TrainAcc=1.0000
# Fold 12 Epoch 1500: Loss=0.000499 | TrainAcc=1.0000
# Fold 12 Epoch 1600: Loss=0.000375 | TrainAcc=1.0000
# Fold 12 Epoch 1700: Loss=0.000415 | TrainAcc=1.0000
# Fold 12 Epoch 1800: Loss=0.000250 | TrainAcc=1.0000
# Fold 12 Epoch 1900: Loss=0.000228 | TrainAcc=1.0000
# Fold 12 Epoch 2000: Loss=0.000220 | TrainAcc=1.0000
# Fold 12 → Acc=0.7761 | Prec=0.7143 | Rec=0.7407 | F1=0.7273 | AUC=0.8630 | CE Loss=0.8514
#
# === Fold 13 ===
# Fold 13 Epoch 1: Loss=0.782328 | TrainAcc=0.4679
# Fold 13 Epoch 100: Loss=0.178642 | TrainAcc=0.9679
# Fold 13 Epoch 200: Loss=0.055372 | TrainAcc=1.0000
# Fold 13 Epoch 300: Loss=0.023218 | TrainAcc=1.0000
# Fold 13 Epoch 400: Loss=0.009747 | TrainAcc=1.0000
# Fold 13 Epoch 500: Loss=0.005835 | TrainAcc=1.0000
# Fold 13 Epoch 600: Loss=0.004153 | TrainAcc=1.0000
# Fold 13 Epoch 700: Loss=0.002708 | TrainAcc=1.0000
# Fold 13 Epoch 800: Loss=0.002036 | TrainAcc=1.0000
# Fold 13 Epoch 900: Loss=0.001414 | TrainAcc=1.0000
# Fold 13 Epoch 1000: Loss=0.000936 | TrainAcc=1.0000
# Fold 13 Epoch 1100: Loss=0.000644 | TrainAcc=1.0000
# Fold 13 Epoch 1200: Loss=0.000528 | TrainAcc=1.0000
# Fold 13 Epoch 1300: Loss=0.000478 | TrainAcc=1.0000
# Fold 13 Epoch 1400: Loss=0.000348 | TrainAcc=1.0000
# Fold 13 Epoch 1500: Loss=0.000247 | TrainAcc=1.0000
# Fold 13 Epoch 1600: Loss=0.000283 | TrainAcc=1.0000
# Fold 13 Epoch 1700: Loss=0.000232 | TrainAcc=1.0000
# Fold 13 Epoch 1800: Loss=0.000136 | TrainAcc=1.0000
# Fold 13 Epoch 1900: Loss=0.000141 | TrainAcc=1.0000
# Fold 13 Epoch 2000: Loss=0.000132 | TrainAcc=1.0000
# Fold 13 → Acc=0.8060 | Prec=0.7333 | Rec=0.8148 | F1=0.7719 | AUC=0.9111 | CE Loss=0.6994
#
# === Fold 14 ===
# Fold 14 Epoch 1: Loss=0.759935 | TrainAcc=0.4808
# Fold 14 Epoch 100: Loss=0.168876 | TrainAcc=0.9615
# Fold 14 Epoch 200: Loss=0.056095 | TrainAcc=1.0000
# Fold 14 Epoch 300: Loss=0.018429 | TrainAcc=1.0000
# Fold 14 Epoch 400: Loss=0.011459 | TrainAcc=1.0000
# Fold 14 Epoch 500: Loss=0.007590 | TrainAcc=1.0000
# Fold 14 Epoch 600: Loss=0.004172 | TrainAcc=1.0000
# Fold 14 Epoch 700: Loss=0.002887 | TrainAcc=1.0000
# Fold 14 Epoch 800: Loss=0.002448 | TrainAcc=1.0000
# Fold 14 Epoch 900: Loss=0.001659 | TrainAcc=1.0000
# Fold 14 Epoch 1000: Loss=0.001269 | TrainAcc=1.0000
# Fold 14 Epoch 1100: Loss=0.000969 | TrainAcc=1.0000
# Fold 14 Epoch 1200: Loss=0.000721 | TrainAcc=1.0000
# Fold 14 Epoch 1300: Loss=0.000632 | TrainAcc=1.0000
# Fold 14 Epoch 1400: Loss=0.000755 | TrainAcc=1.0000
# Fold 14 Epoch 1500: Loss=0.000551 | TrainAcc=1.0000
# Fold 14 Epoch 1600: Loss=0.000385 | TrainAcc=1.0000
# Fold 14 Epoch 1700: Loss=0.000347 | TrainAcc=1.0000
# Fold 14 Epoch 1800: Loss=0.000342 | TrainAcc=1.0000
# Fold 14 Epoch 1900: Loss=0.000286 | TrainAcc=1.0000
# Fold 14 Epoch 2000: Loss=0.000293 | TrainAcc=1.0000
# Fold 14 → Acc=0.8209 | Prec=0.8261 | Rec=0.7037 | F1=0.7600 | AUC=0.8667 | CE Loss=0.8188
#
# === Fold 15 ===
# Fold 15 Epoch 1: Loss=0.722430 | TrainAcc=0.4808
# Fold 15 Epoch 100: Loss=0.164998 | TrainAcc=0.9744
# Fold 15 Epoch 200: Loss=0.049330 | TrainAcc=1.0000
# Fold 15 Epoch 300: Loss=0.022033 | TrainAcc=1.0000
# Fold 15 Epoch 400: Loss=0.010395 | TrainAcc=1.0000
# Fold 15 Epoch 500: Loss=0.005841 | TrainAcc=1.0000
# Fold 15 Epoch 600: Loss=0.003922 | TrainAcc=1.0000
# Fold 15 Epoch 700: Loss=0.002781 | TrainAcc=1.0000
# Fold 15 Epoch 800: Loss=0.002101 | TrainAcc=1.0000
# Fold 15 Epoch 900: Loss=0.001449 | TrainAcc=1.0000
# Fold 15 Epoch 1000: Loss=0.000984 | TrainAcc=1.0000
# Fold 15 Epoch 1100: Loss=0.000826 | TrainAcc=1.0000
# Fold 15 Epoch 1200: Loss=0.000774 | TrainAcc=1.0000
# Fold 15 Epoch 1300: Loss=0.000584 | TrainAcc=1.0000
# Fold 15 Epoch 1400: Loss=0.000439 | TrainAcc=1.0000
# Fold 15 Epoch 1500: Loss=0.000321 | TrainAcc=1.0000
# Fold 15 Epoch 1600: Loss=0.000274 | TrainAcc=1.0000
# Fold 15 Epoch 1700: Loss=0.000240 | TrainAcc=1.0000
# Fold 15 Epoch 1800: Loss=0.000285 | TrainAcc=1.0000
# Fold 15 Epoch 1900: Loss=0.000234 | TrainAcc=1.0000
# Fold 15 Epoch 2000: Loss=0.000200 | TrainAcc=1.0000
# Fold 15 → Acc=0.8507 | Prec=0.7931 | Rec=0.8519 | F1=0.8214 | AUC=0.9060 | CE Loss=0.7058
#
# === Fold 16 ===
# Fold 16 Epoch 1: Loss=0.758239 | TrainAcc=0.5128
# Fold 16 Epoch 100: Loss=0.160854 | TrainAcc=0.9679
# Fold 16 Epoch 200: Loss=0.053259 | TrainAcc=1.0000
# Fold 16 Epoch 300: Loss=0.019441 | TrainAcc=1.0000
# Fold 16 Epoch 400: Loss=0.011350 | TrainAcc=1.0000
# Fold 16 Epoch 500: Loss=0.006548 | TrainAcc=1.0000
# Fold 16 Epoch 600: Loss=0.003314 | TrainAcc=1.0000
# Fold 16 Epoch 700: Loss=0.002876 | TrainAcc=1.0000
# Fold 16 Epoch 800: Loss=0.001861 | TrainAcc=1.0000
# Fold 16 Epoch 900: Loss=0.001460 | TrainAcc=1.0000
# Fold 16 Epoch 1000: Loss=0.001097 | TrainAcc=1.0000
# Fold 16 Epoch 1100: Loss=0.001093 | TrainAcc=1.0000
# Fold 16 Epoch 1200: Loss=0.000769 | TrainAcc=1.0000
# Fold 16 Epoch 1300: Loss=0.000589 | TrainAcc=1.0000
# Fold 16 Epoch 1400: Loss=0.000483 | TrainAcc=1.0000
# Fold 16 Epoch 1500: Loss=0.000411 | TrainAcc=1.0000
# Fold 16 Epoch 1600: Loss=0.000390 | TrainAcc=1.0000
# Fold 16 Epoch 1700: Loss=0.000344 | TrainAcc=1.0000
# Fold 16 Epoch 1800: Loss=0.000243 | TrainAcc=1.0000
# Fold 16 Epoch 1900: Loss=0.000221 | TrainAcc=1.0000
# Fold 16 Epoch 2000: Loss=0.000203 | TrainAcc=1.0000
# Fold 16 → Acc=0.8209 | Prec=0.7586 | Rec=0.8148 | F1=0.7857 | AUC=0.8519 | CE Loss=1.0786
#
# === Fold 17 ===
# Fold 17 Epoch 1: Loss=0.714653 | TrainAcc=0.5385
# Fold 17 Epoch 100: Loss=0.154680 | TrainAcc=0.9679
# Fold 17 Epoch 200: Loss=0.046983 | TrainAcc=1.0000
# Fold 17 Epoch 300: Loss=0.017809 | TrainAcc=1.0000
# Fold 17 Epoch 400: Loss=0.009388 | TrainAcc=1.0000
# Fold 17 Epoch 500: Loss=0.004689 | TrainAcc=1.0000
# Fold 17 Epoch 600: Loss=0.003297 | TrainAcc=1.0000
# Fold 17 Epoch 700: Loss=0.002304 | TrainAcc=1.0000
# Fold 17 Epoch 800: Loss=0.001870 | TrainAcc=1.0000
# Fold 17 Epoch 900: Loss=0.001047 | TrainAcc=1.0000
# Fold 17 Epoch 1000: Loss=0.001146 | TrainAcc=1.0000
# Fold 17 Epoch 1100: Loss=0.000840 | TrainAcc=1.0000
# Fold 17 Epoch 1200: Loss=0.000837 | TrainAcc=1.0000
# Fold 17 Epoch 1300: Loss=0.000535 | TrainAcc=1.0000
# Fold 17 Epoch 1400: Loss=0.000392 | TrainAcc=1.0000
# Fold 17 Epoch 1500: Loss=0.000317 | TrainAcc=1.0000
# Fold 17 Epoch 1600: Loss=0.000280 | TrainAcc=1.0000
# Fold 17 Epoch 1700: Loss=0.000218 | TrainAcc=1.0000
# Fold 17 Epoch 1800: Loss=0.000176 | TrainAcc=1.0000
# Fold 17 Epoch 1900: Loss=0.000185 | TrainAcc=1.0000
# Fold 17 Epoch 2000: Loss=0.000172 | TrainAcc=1.0000
# Fold 17 → Acc=0.7463 | Prec=0.6667 | Rec=0.7407 | F1=0.7018 | AUC=0.8037 | CE Loss=1.1113
#
# === Fold 18 ===
# Fold 18 Epoch 1: Loss=0.844660 | TrainAcc=0.3974
# Fold 18 Epoch 100: Loss=0.181212 | TrainAcc=0.9679
# Fold 18 Epoch 200: Loss=0.075902 | TrainAcc=0.9936
# Fold 18 Epoch 300: Loss=0.026178 | TrainAcc=1.0000
# Fold 18 Epoch 400: Loss=0.013929 | TrainAcc=1.0000
# Fold 18 Epoch 500: Loss=0.007551 | TrainAcc=1.0000
# Fold 18 Epoch 600: Loss=0.005110 | TrainAcc=1.0000
# Fold 18 Epoch 700: Loss=0.002759 | TrainAcc=1.0000
# Fold 18 Epoch 800: Loss=0.002224 | TrainAcc=1.0000
# Fold 18 Epoch 900: Loss=0.001663 | TrainAcc=1.0000
# Fold 18 Epoch 1000: Loss=0.001404 | TrainAcc=1.0000
# Fold 18 Epoch 1100: Loss=0.000958 | TrainAcc=1.0000
# Fold 18 Epoch 1200: Loss=0.000715 | TrainAcc=1.0000
# Fold 18 Epoch 1300: Loss=0.000504 | TrainAcc=1.0000
# Fold 18 Epoch 1400: Loss=0.000488 | TrainAcc=1.0000
# Fold 18 Epoch 1500: Loss=0.000370 | TrainAcc=1.0000
# Fold 18 Epoch 1600: Loss=0.000403 | TrainAcc=1.0000
# Fold 18 Epoch 1700: Loss=0.000275 | TrainAcc=1.0000
# Fold 18 Epoch 1800: Loss=0.000272 | TrainAcc=1.0000
# Fold 18 Epoch 1900: Loss=0.000209 | TrainAcc=1.0000
# Fold 18 Epoch 2000: Loss=0.000202 | TrainAcc=1.0000
# Fold 18 → Acc=0.8657 | Prec=0.8462 | Rec=0.8148 | F1=0.8302 | AUC=0.8870 | CE Loss=0.7391
#
# === Fold 19 ===
# Fold 19 Epoch 1: Loss=0.743307 | TrainAcc=0.5128
# Fold 19 Epoch 100: Loss=0.185364 | TrainAcc=0.9487
# Fold 19 Epoch 200: Loss=0.058288 | TrainAcc=1.0000
# Fold 19 Epoch 300: Loss=0.021078 | TrainAcc=1.0000
# Fold 19 Epoch 400: Loss=0.009611 | TrainAcc=1.0000
# Fold 19 Epoch 500: Loss=0.005785 | TrainAcc=1.0000
# Fold 19 Epoch 600: Loss=0.004151 | TrainAcc=1.0000
# Fold 19 Epoch 700: Loss=0.003128 | TrainAcc=1.0000
# Fold 19 Epoch 800: Loss=0.001692 | TrainAcc=1.0000
# Fold 19 Epoch 900: Loss=0.001380 | TrainAcc=1.0000
# Fold 19 Epoch 1000: Loss=0.001113 | TrainAcc=1.0000
# Fold 19 Epoch 1100: Loss=0.000846 | TrainAcc=1.0000
# Fold 19 Epoch 1200: Loss=0.000606 | TrainAcc=1.0000
# Fold 19 Epoch 1300: Loss=0.000483 | TrainAcc=1.0000
# Fold 19 Epoch 1400: Loss=0.000379 | TrainAcc=1.0000
# Fold 19 Epoch 1500: Loss=0.000303 | TrainAcc=1.0000
# Fold 19 Epoch 1600: Loss=0.000235 | TrainAcc=1.0000
# Fold 19 Epoch 1700: Loss=0.000217 | TrainAcc=1.0000
# Fold 19 Epoch 1800: Loss=0.000186 | TrainAcc=1.0000
# Fold 19 Epoch 1900: Loss=0.000191 | TrainAcc=1.0000
# Fold 19 Epoch 2000: Loss=0.000178 | TrainAcc=1.0000
# Fold 19 → Acc=0.8060 | Prec=0.7188 | Rec=0.8519 | F1=0.7797 | AUC=0.9037 | CE Loss=0.8096
#
# === Fold 20 ===
# Fold 20 Epoch 1: Loss=0.558078 | TrainAcc=0.7500
# Fold 20 Epoch 100: Loss=0.124491 | TrainAcc=0.9808
# Fold 20 Epoch 200: Loss=0.036471 | TrainAcc=1.0000
# Fold 20 Epoch 300: Loss=0.014860 | TrainAcc=1.0000
# Fold 20 Epoch 400: Loss=0.007618 | TrainAcc=1.0000
# Fold 20 Epoch 500: Loss=0.004479 | TrainAcc=1.0000
# Fold 20 Epoch 600: Loss=0.002694 | TrainAcc=1.0000
# Fold 20 Epoch 700: Loss=0.001735 | TrainAcc=1.0000
# Fold 20 Epoch 800: Loss=0.001205 | TrainAcc=1.0000
# Fold 20 Epoch 900: Loss=0.000848 | TrainAcc=1.0000
# Fold 20 Epoch 1000: Loss=0.000504 | TrainAcc=1.0000
# Fold 20 Epoch 1100: Loss=0.000372 | TrainAcc=1.0000
# Fold 20 Epoch 1200: Loss=0.000299 | TrainAcc=1.0000
# Fold 20 Epoch 1300: Loss=0.000258 | TrainAcc=1.0000
# Fold 20 Epoch 1400: Loss=0.000239 | TrainAcc=1.0000
# Fold 20 Epoch 1500: Loss=0.000247 | TrainAcc=1.0000
# Fold 20 Epoch 1600: Loss=0.000169 | TrainAcc=1.0000
# Fold 20 Epoch 1700: Loss=0.000138 | TrainAcc=1.0000
# Fold 20 Epoch 1800: Loss=0.000149 | TrainAcc=1.0000
# Fold 20 Epoch 1900: Loss=0.000126 | TrainAcc=1.0000
# Fold 20 Epoch 2000: Loss=0.000125 | TrainAcc=1.0000
# Fold 20 → Acc=0.7761 | Prec=0.7308 | Rec=0.7037 | F1=0.7170 | AUC=0.8250 | CE Loss=0.9387
#
# === Average Results Across 20 Folds ===
# Accuracy:  0.8000 ± 0.0539
# Precision: 0.7449 ± 0.0728
# Recall:    0.7722 ± 0.0886
# F1-score:  0.7561 ± 0.0678
# CE Loss:   0.8620 ± 0.1961
# AUC:       0.8708 ± 0.0380
