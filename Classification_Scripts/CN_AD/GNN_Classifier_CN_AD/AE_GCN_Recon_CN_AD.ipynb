# %%
import os
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, log_loss
from torch_geometric.data import Data
from torch_geometric.nn import GCNConv

device = 'cuda' if torch.cuda.is_available() else 'cpu'
print("Device:", device)

cn_path = "/home/snu/Downloads/Histogram_CN_FA_20bin_updated.npy"
ad_path = "/home/snu/Downloads/Histogram_AD_FA_20bin_updated.npy"

Histogram_feature_CN_FA_array = np.load(cn_path, allow_pickle=True)
Histogram_feature_AD_FA_array = np.load(ad_path, allow_pickle=True)

X = np.vstack([Histogram_feature_CN_FA_array, Histogram_feature_AD_FA_array])
y = np.hstack([
    np.zeros(Histogram_feature_CN_FA_array.shape[0], dtype=np.int64),
    np.ones(Histogram_feature_AD_FA_array.shape[0], dtype=np.int64)
])

num_nodes, num_feats = X.shape
print(f"Features: {X.shape}, Labels: {y.shape}")

rng = np.random.RandomState(42)
perm = rng.permutation(num_nodes)
X = X[perm]
y = y[perm]

def create_adj(F_data, alpha=1):
    norms = np.linalg.norm(F_data, axis=1, keepdims=True)
    norms[norms == 0] = 1.0
    F_norm = F_data / norms
    W = np.dot(F_norm, F_norm.T)
    W = np.where(W >= alpha, 1.0, 0.0).astype(np.float32)
    if W.max() > 0:
        W = W / W.max()
    return W

alpha = 0.8
W = create_adj(X, alpha=alpha)
np.fill_diagonal(W, 1.0)

def load_data(adj, node_feats):
    node_feats = torch.from_numpy(node_feats).float()
    rows, cols = np.nonzero(adj > 0)
    edge_index = torch.from_numpy(np.vstack([rows, cols]).astype(np.int64))
    return Data(x=node_feats, edge_index=edge_index)

data = load_data(W, X).to(device)
print(data)

class GCN_AE(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim, num_nodes, device, activ="RELU", dropout=0.25):
        super(GCN_AE, self).__init__()
        self.device = device
        self.dropout = dropout
        self.conv1 = GCNConv(input_dim, hidden_dim)
        self.conv2 = GCNConv(hidden_dim, output_dim)
        self.conv3 = GCNConv(hidden_dim, num_nodes)
        activations = {
            "SELU": F.selu,
            "SiLU": F.silu,
            "GELU": F.gelu,
            "RELU": F.relu,
            "ELU": F.elu
        }
        self.act = activations.get(activ, F.relu)

    def forward(self, x, edge_index):
        h = self.conv1(x, edge_index)
        h1 = self.act(h)
        logits = self.conv2(h1, edge_index)
        h2 = torch.sigmoid(logits)
        A_hat = self.conv3(h1, edge_index)
        A_pred = torch.sigmoid(A_hat)
        return h2, A_pred, h1

def auto_loss(A_pred: torch.Tensor, A_tilde: torch.Tensor, eps: float = 1e-12) -> torch.Tensor:
    if A_pred.dim() not in (2, 3):
        raise ValueError("A_pred must be shape (n,n) or (B,n,n)")
    if A_pred.shape != A_tilde.shape:
        raise ValueError("A_pred and A_tilde must have the same shape")
    if A_pred.dim() == 2:
        n = A_pred.size(0)
        D = A_tilde.sum(dim=1)
        D_inv_sqrt = torch.rsqrt(D + eps)
        D_inv_sqrt_mat = torch.diag(D_inv_sqrt)
        S = D_inv_sqrt_mat @ A_tilde @ D_inv_sqrt_mat
        A_pred_clamped = A_pred.clamp(min=eps, max=1.0)
        loss = - (S * torch.log(A_pred_clamped)).mean()
        return loss
    else:
        B, n, _ = A_pred.shape
        D = A_tilde.sum(dim=2)
        D_inv_sqrt = torch.rsqrt(D + eps)
        D_inv_sqrt_mat = torch.diag_embed(D_inv_sqrt)
        S = D_inv_sqrt_mat.bmm(A_tilde).bmm(D_inv_sqrt_mat)
        A_pred_clamped = A_pred.clamp(min=eps, max=1.0)
        loss = - (S * torch.log(A_pred_clamped)).mean()
        return loss

feats_dim = num_feats
hidden_dim = 512
num_classes = 2
num_epochs = 2000
lr = 1e-4
weight_decay = 1e-4
batch_print_freq = 100
lambda_recon = 0.5

sss = StratifiedShuffleSplit(n_splits=20, test_size=0.5, random_state=42)
accuracies, precisions, recalls, f1_scores, aucs, ce_losses = [], [], [], [], [], []
y_all = y.copy()

for fold, (train_val_idx, test_idx_global) in enumerate(sss.split(X, y_all), start=1):
    print(f"\n=== Fold {fold} ===")
    cn_idx = np.where(y_all == 0)[0]
    ad_idx = np.where(y_all == 1)[0]
    sss_class = StratifiedShuffleSplit(n_splits=20, test_size=0.5, random_state=fold)
    cn_train_idx, _ = next(sss_class.split(X[cn_idx], y_all[cn_idx]))
    ad_train_idx, _ = next(sss_class.split(X[ad_idx], y_all[ad_idx]))
    cn_train = cn_idx[cn_train_idx]
    ad_train = ad_idx[ad_train_idx]
    train_idx_final = np.concatenate([cn_train, ad_train])
    np.random.shuffle(train_idx_final)
    print(f"Train CN: {len(cn_train)}, Train AD: {len(ad_train)}")

    train_idx_t = torch.from_numpy(train_idx_final).long().to(device)
    y_train_tensor = torch.from_numpy(y_all[train_idx_final]).long().to(device)

    model = GCN_AE(feats_dim, hidden_dim, num_classes, num_nodes, device, activ="RELU", dropout=0.25).to(device)
    optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
    ce_loss_fn = nn.CrossEntropyLoss()
    data = load_data(W, X).to(device)
    A_tilde = torch.from_numpy(W).float().to(device)

    for epoch in range(1, num_epochs + 1):
        model.train()
        optimizer.zero_grad()
        logits, recon_x, _ = model(data.x, data.edge_index)
        loss_sup = ce_loss_fn(logits[train_idx_t], y_train_tensor)
        loss_recon = auto_loss(recon_x, A_tilde)
        total_loss = loss_sup + lambda_recon * loss_recon
        if torch.isnan(total_loss) or torch.isinf(total_loss):
            print(f"NaN/Inf detected at fold {fold} epoch {epoch}. Aborting epoch.")
            break
        total_loss.backward()
        optimizer.step()
        if epoch % batch_print_freq == 0 or epoch == 1:
            model.eval()
            with torch.no_grad():
                logits_eval, _, _ = model(data.x, data.edge_index)
                preds_train = logits_eval[train_idx_t].argmax(dim=1)
                acc_train = accuracy_score(y_train_tensor.cpu(), preds_train.cpu())
            print(f"Fold {fold} Epoch {epoch}: TotalLoss={total_loss.item():.6f} | Sup={loss_sup.item():.6f} | Recon={loss_recon.item():.6f} | TrainAcc={acc_train:.4f}")

    model.eval()
    with torch.no_grad():
        out_logits, _, _ = model(data.x, data.edge_index)
        preds = out_logits.argmax(dim=1).cpu().numpy()
        probs = F.softmax(out_logits, dim=1)[:, 1].cpu().numpy()

    y_test = y_all[test_idx_global]
    y_pred_test = preds[test_idx_global]
    y_prob_test = probs[test_idx_global]

    acc = accuracy_score(y_test, y_pred_test)
    prec = precision_score(y_test, y_pred_test, zero_division=0)
    rec = recall_score(y_test, y_pred_test, zero_division=0)
    f1 = f1_score(y_test, y_pred_test, zero_division=0)
    try:
        auc = roc_auc_score(y_test, y_prob_test)
    except ValueError:
        auc = float('nan')
    ce = log_loss(y_test, y_prob_test)

    accuracies.append(acc)
    precisions.append(prec)
    recalls.append(rec)
    f1_scores.append(f1)
    aucs.append(auc)
    ce_losses.append(ce)

    print(f"Fold {fold} → Acc={acc:.4f} | Prec={prec:.4f} | Rec={rec:.4f} | F1={f1:.4f} | AUC={auc:.4f} | CE Loss={ce:.4f}")

print("\n=== Average Results Across 20 Folds ===")
print(f"Accuracy:  {np.mean(accuracies):.4f} ± {np.std(accuracies):.4f}")
print(f"Precision: {np.mean(precisions):.4f} ± {np.std(precisions):.4f}")
print(f"Recall:    {np.mean(recalls):.4f} ± {np.std(recalls):.4f}")
print(f"F1-score:  {np.mean(f1_scores):.4f} ± {np.std(f1_scores):.4f}")
print(f"AUC:       {np.nanmean(aucs):.4f} ± {np.nanstd(aucs):.4f}")
print(f"CE Loss:   {np.mean(ce_losses):.4f} ± {np.std(ce_losses):.4f}")
# Out:
# Device: cuda
# Features: (223, 180), Labels: (223,)
# Data(x=[223, 180], edge_index=[2, 41689])
#
# === Fold 1 ===
# Train CN: 66, Train AD: 45
# Fold 1 Epoch 1: TotalLoss=0.694888 | Sup=0.693365 | Recon=0.003048 | TrainAcc=0.6036
# Fold 1 Epoch 100: TotalLoss=0.669804 | Sup=0.668305 | Recon=0.002999 | TrainAcc=0.5946
# Fold 1 Epoch 200: TotalLoss=0.664917 | Sup=0.663456 | Recon=0.002922 | TrainAcc=0.6036
# Fold 1 Epoch 300: TotalLoss=0.661828 | Sup=0.660395 | Recon=0.002867 | TrainAcc=0.6036
# Fold 1 Epoch 400: TotalLoss=0.659023 | Sup=0.657611 | Recon=0.002824 | TrainAcc=0.6036
# Fold 1 Epoch 500: TotalLoss=0.656004 | Sup=0.654609 | Recon=0.002789 | TrainAcc=0.6036
# Fold 1 Epoch 600: TotalLoss=0.652380 | Sup=0.651000 | Recon=0.002760 | TrainAcc=0.6126
# Fold 1 Epoch 700: TotalLoss=0.647944 | Sup=0.646578 | Recon=0.002733 | TrainAcc=0.6126
# Fold 1 Epoch 800: TotalLoss=0.642617 | Sup=0.641264 | Recon=0.002706 | TrainAcc=0.6486
# Fold 1 Epoch 900: TotalLoss=0.636514 | Sup=0.635175 | Recon=0.002679 | TrainAcc=0.6577
# Fold 1 Epoch 1000: TotalLoss=0.629931 | Sup=0.628605 | Recon=0.002651 | TrainAcc=0.6757
# Fold 1 Epoch 1100: TotalLoss=0.623180 | Sup=0.621868 | Recon=0.002622 | TrainAcc=0.6757
# Fold 1 Epoch 1200: TotalLoss=0.616530 | Sup=0.615233 | Recon=0.002594 | TrainAcc=0.6847
# Fold 1 Epoch 1300: TotalLoss=0.610193 | Sup=0.608910 | Recon=0.002565 | TrainAcc=0.6847
# Fold 1 Epoch 1400: TotalLoss=0.604292 | Sup=0.603023 | Recon=0.002539 | TrainAcc=0.6937
# Fold 1 Epoch 1500: TotalLoss=0.598897 | Sup=0.597637 | Recon=0.002520 | TrainAcc=0.7117
# Fold 1 Epoch 1600: TotalLoss=0.593998 | Sup=0.592745 | Recon=0.002507 | TrainAcc=0.7207
# Fold 1 Epoch 1700: TotalLoss=0.589547 | Sup=0.588298 | Recon=0.002497 | TrainAcc=0.7297
# Fold 1 Epoch 1800: TotalLoss=0.585533 | Sup=0.584289 | Recon=0.002487 | TrainAcc=0.7297
# Fold 1 Epoch 1900: TotalLoss=0.581946 | Sup=0.580710 | Recon=0.002473 | TrainAcc=0.7297
# Fold 1 Epoch 2000: TotalLoss=0.578712 | Sup=0.577484 | Recon=0.002455 | TrainAcc=0.7387
# Fold 1 → Acc=0.7321 | Prec=0.8000 | Rec=0.4444 | F1=0.5714 | AUC=0.8224 | CE Loss=0.5821
#
# === Fold 2 ===
# Train CN: 66, Train AD: 45
# Fold 2 Epoch 1: TotalLoss=0.696773 | Sup=0.695242 | Recon=0.003061 | TrainAcc=0.4054
# Fold 2 Epoch 100: TotalLoss=0.672488 | Sup=0.670983 | Recon=0.003009 | TrainAcc=0.6036
# Fold 2 Epoch 200: TotalLoss=0.668408 | Sup=0.666938 | Recon=0.002939 | TrainAcc=0.6036
# Fold 2 Epoch 300: TotalLoss=0.665789 | Sup=0.664345 | Recon=0.002888 | TrainAcc=0.6036
# Fold 2 Epoch 400: TotalLoss=0.663449 | Sup=0.662025 | Recon=0.002849 | TrainAcc=0.6036
# Fold 2 Epoch 500: TotalLoss=0.660984 | Sup=0.659576 | Recon=0.002816 | TrainAcc=0.6036
# Fold 2 Epoch 600: TotalLoss=0.658079 | Sup=0.656685 | Recon=0.002787 | TrainAcc=0.6126
# Fold 2 Epoch 700: TotalLoss=0.654484 | Sup=0.653104 | Recon=0.002759 | TrainAcc=0.6126
# Fold 2 Epoch 800: TotalLoss=0.650093 | Sup=0.648728 | Recon=0.002732 | TrainAcc=0.6306
# Fold 2 Epoch 900: TotalLoss=0.644907 | Sup=0.643555 | Recon=0.002704 | TrainAcc=0.6306
# Fold 2 Epoch 1000: TotalLoss=0.639107 | Sup=0.637768 | Recon=0.002676 | TrainAcc=0.6577
# Fold 2 Epoch 1100: TotalLoss=0.632960 | Sup=0.631636 | Recon=0.002648 | TrainAcc=0.6667
# Fold 2 Epoch 1200: TotalLoss=0.626768 | Sup=0.625458 | Recon=0.002621 | TrainAcc=0.6757
# Fold 2 Epoch 1300: TotalLoss=0.620786 | Sup=0.619488 | Recon=0.002595 | TrainAcc=0.6757
# Fold 2 Epoch 1400: TotalLoss=0.615184 | Sup=0.613898 | Recon=0.002571 | TrainAcc=0.6847
# Fold 2 Epoch 1500: TotalLoss=0.610068 | Sup=0.608793 | Recon=0.002549 | TrainAcc=0.6937
# Fold 2 Epoch 1600: TotalLoss=0.605515 | Sup=0.604249 | Recon=0.002532 | TrainAcc=0.6937
# Fold 2 Epoch 1700: TotalLoss=0.601510 | Sup=0.600249 | Recon=0.002523 | TrainAcc=0.6937
# Fold 2 Epoch 1800: TotalLoss=0.597991 | Sup=0.596733 | Recon=0.002517 | TrainAcc=0.7027
# Fold 2 Epoch 1900: TotalLoss=0.594882 | Sup=0.593628 | Recon=0.002509 | TrainAcc=0.6937
# Fold 2 Epoch 2000: TotalLoss=0.592124 | Sup=0.590875 | Recon=0.002498 | TrainAcc=0.6937
# Fold 2 → Acc=0.7321 | Prec=0.7586 | Rec=0.4889 | F1=0.5946 | AUC=0.8292 | CE Loss=0.5735
#
# === Fold 3 ===
# Train CN: 66, Train AD: 45
# Fold 3 Epoch 1: TotalLoss=0.691855 | Sup=0.690328 | Recon=0.003054 | TrainAcc=0.5946
# Fold 3 Epoch 100: TotalLoss=0.672743 | Sup=0.671242 | Recon=0.003002 | TrainAcc=0.5946
# Fold 3 Epoch 200: TotalLoss=0.671393 | Sup=0.669920 | Recon=0.002946 | TrainAcc=0.5946
# Fold 3 Epoch 300: TotalLoss=0.670368 | Sup=0.668913 | Recon=0.002910 | TrainAcc=0.5946
# Fold 3 Epoch 400: TotalLoss=0.668881 | Sup=0.667440 | Recon=0.002882 | TrainAcc=0.5946
# Fold 3 Epoch 500: TotalLoss=0.666844 | Sup=0.665413 | Recon=0.002860 | TrainAcc=0.5946
# Fold 3 Epoch 600: TotalLoss=0.664112 | Sup=0.662691 | Recon=0.002842 | TrainAcc=0.5946
# Fold 3 Epoch 700: TotalLoss=0.660500 | Sup=0.659086 | Recon=0.002827 | TrainAcc=0.6036
# Fold 3 Epoch 800: TotalLoss=0.655860 | Sup=0.654454 | Recon=0.002812 | TrainAcc=0.6126
# Fold 3 Epoch 900: TotalLoss=0.650121 | Sup=0.648725 | Recon=0.002792 | TrainAcc=0.6216
# Fold 3 Epoch 1000: TotalLoss=0.643367 | Sup=0.641987 | Recon=0.002760 | TrainAcc=0.6577
# Fold 3 Epoch 1100: TotalLoss=0.635849 | Sup=0.634493 | Recon=0.002711 | TrainAcc=0.6667
# Fold 3 Epoch 1200: TotalLoss=0.627896 | Sup=0.626573 | Recon=0.002646 | TrainAcc=0.6667
# Fold 3 Epoch 1300: TotalLoss=0.619833 | Sup=0.618549 | Recon=0.002568 | TrainAcc=0.6757
# Fold 3 Epoch 1400: TotalLoss=0.612007 | Sup=0.610766 | Recon=0.002481 | TrainAcc=0.6847
# Fold 3 Epoch 1500: TotalLoss=0.604684 | Sup=0.603489 | Recon=0.002391 | TrainAcc=0.7117
# Fold 3 Epoch 1600: TotalLoss=0.597930 | Sup=0.596778 | Recon=0.002302 | TrainAcc=0.7117
# Fold 3 Epoch 1700: TotalLoss=0.591834 | Sup=0.590725 | Recon=0.002218 | TrainAcc=0.7117
# Fold 3 Epoch 1800: TotalLoss=0.586405 | Sup=0.585335 | Recon=0.002140 | TrainAcc=0.7207
# Fold 3 Epoch 1900: TotalLoss=0.581582 | Sup=0.580548 | Recon=0.002069 | TrainAcc=0.7207
# Fold 3 Epoch 2000: TotalLoss=0.577326 | Sup=0.576323 | Recon=0.002005 | TrainAcc=0.7297
# Fold 3 → Acc=0.7589 | Prec=0.8462 | Rec=0.4889 | F1=0.6197 | AUC=0.8534 | CE Loss=0.5735
#
# === Fold 4 ===
# Train CN: 66, Train AD: 45
# Fold 4 Epoch 1: TotalLoss=0.692068 | Sup=0.690540 | Recon=0.003057 | TrainAcc=0.5946
# Fold 4 Epoch 100: TotalLoss=0.675731 | Sup=0.674228 | Recon=0.003006 | TrainAcc=0.6036
# Fold 4 Epoch 200: TotalLoss=0.672956 | Sup=0.671482 | Recon=0.002948 | TrainAcc=0.6036
# Fold 4 Epoch 300: TotalLoss=0.670737 | Sup=0.669283 | Recon=0.002907 | TrainAcc=0.6036
# Fold 4 Epoch 400: TotalLoss=0.668733 | Sup=0.667296 | Recon=0.002875 | TrainAcc=0.6036
# Fold 4 Epoch 500: TotalLoss=0.666695 | Sup=0.665271 | Recon=0.002848 | TrainAcc=0.5946
# Fold 4 Epoch 600: TotalLoss=0.664365 | Sup=0.662952 | Recon=0.002826 | TrainAcc=0.6036
# Fold 4 Epoch 700: TotalLoss=0.661543 | Sup=0.660139 | Recon=0.002807 | TrainAcc=0.5946
# Fold 4 Epoch 800: TotalLoss=0.658080 | Sup=0.656685 | Recon=0.002790 | TrainAcc=0.6036
# Fold 4 Epoch 900: TotalLoss=0.653926 | Sup=0.652539 | Recon=0.002774 | TrainAcc=0.6036
# Fold 4 Epoch 1000: TotalLoss=0.649117 | Sup=0.647738 | Recon=0.002758 | TrainAcc=0.6216
# Fold 4 Epoch 1100: TotalLoss=0.643756 | Sup=0.642386 | Recon=0.002740 | TrainAcc=0.6216
# Fold 4 Epoch 1200: TotalLoss=0.637978 | Sup=0.636619 | Recon=0.002717 | TrainAcc=0.6306
# Fold 4 Epoch 1300: TotalLoss=0.631920 | Sup=0.630577 | Recon=0.002685 | TrainAcc=0.6486
# Fold 4 Epoch 1400: TotalLoss=0.625733 | Sup=0.624411 | Recon=0.002643 | TrainAcc=0.6757
# Fold 4 Epoch 1500: TotalLoss=0.619580 | Sup=0.618286 | Recon=0.002589 | TrainAcc=0.6847
# Fold 4 Epoch 1600: TotalLoss=0.613628 | Sup=0.612365 | Recon=0.002526 | TrainAcc=0.7027
# Fold 4 Epoch 1700: TotalLoss=0.608020 | Sup=0.606791 | Recon=0.002457 | TrainAcc=0.7207
# Fold 4 Epoch 1800: TotalLoss=0.602856 | Sup=0.601663 | Recon=0.002387 | TrainAcc=0.7297
# Fold 4 Epoch 1900: TotalLoss=0.598210 | Sup=0.597050 | Recon=0.002321 | TrainAcc=0.7117
# Fold 4 Epoch 2000: TotalLoss=0.594088 | Sup=0.592958 | Recon=0.002261 | TrainAcc=0.7207
# Fold 4 → Acc=0.7500 | Prec=0.7931 | Rec=0.5111 | F1=0.6216 | AUC=0.8227 | CE Loss=0.5760
#
# === Fold 5 ===
# Train CN: 66, Train AD: 45
# Fold 5 Epoch 1: TotalLoss=0.692232 | Sup=0.690702 | Recon=0.003059 | TrainAcc=0.5946
# Fold 5 Epoch 100: TotalLoss=0.672348 | Sup=0.670845 | Recon=0.003006 | TrainAcc=0.5946
# Fold 5 Epoch 200: TotalLoss=0.669852 | Sup=0.668376 | Recon=0.002951 | TrainAcc=0.6036
# Fold 5 Epoch 300: TotalLoss=0.667730 | Sup=0.666275 | Recon=0.002912 | TrainAcc=0.6036
# Fold 5 Epoch 400: TotalLoss=0.665838 | Sup=0.664398 | Recon=0.002880 | TrainAcc=0.6036
# Fold 5 Epoch 500: TotalLoss=0.663985 | Sup=0.662557 | Recon=0.002855 | TrainAcc=0.6036
# Fold 5 Epoch 600: TotalLoss=0.661962 | Sup=0.660544 | Recon=0.002836 | TrainAcc=0.5946
# Fold 5 Epoch 700: TotalLoss=0.659619 | Sup=0.658208 | Recon=0.002822 | TrainAcc=0.6036
# Fold 5 Epoch 800: TotalLoss=0.656834 | Sup=0.655429 | Recon=0.002809 | TrainAcc=0.5946
# Fold 5 Epoch 900: TotalLoss=0.653564 | Sup=0.652165 | Recon=0.002797 | TrainAcc=0.6216
# Fold 5 Epoch 1000: TotalLoss=0.649817 | Sup=0.648425 | Recon=0.002783 | TrainAcc=0.6306
# Fold 5 Epoch 1100: TotalLoss=0.645626 | Sup=0.644244 | Recon=0.002764 | TrainAcc=0.6486
# Fold 5 Epoch 1200: TotalLoss=0.641111 | Sup=0.639743 | Recon=0.002737 | TrainAcc=0.6486
# Fold 5 Epoch 1300: TotalLoss=0.636427 | Sup=0.635077 | Recon=0.002700 | TrainAcc=0.6486
# Fold 5 Epoch 1400: TotalLoss=0.631715 | Sup=0.630389 | Recon=0.002651 | TrainAcc=0.6577
# Fold 5 Epoch 1500: TotalLoss=0.627099 | Sup=0.625802 | Recon=0.002594 | TrainAcc=0.6667
# Fold 5 Epoch 1600: TotalLoss=0.622661 | Sup=0.621395 | Recon=0.002531 | TrainAcc=0.6757
# Fold 5 Epoch 1700: TotalLoss=0.618453 | Sup=0.617221 | Recon=0.002464 | TrainAcc=0.6757
# Fold 5 Epoch 1800: TotalLoss=0.614498 | Sup=0.613300 | Recon=0.002397 | TrainAcc=0.6757
# Fold 5 Epoch 1900: TotalLoss=0.610813 | Sup=0.609646 | Recon=0.002332 | TrainAcc=0.6847
# Fold 5 Epoch 2000: TotalLoss=0.607434 | Sup=0.606299 | Recon=0.002271 | TrainAcc=0.6847
# Fold 5 → Acc=0.7054 | Prec=0.8000 | Rec=0.3556 | F1=0.4923 | AUC=0.8282 | CE Loss=0.5977
#
# === Fold 6 ===
# Train CN: 66, Train AD: 45
# Fold 6 Epoch 1: TotalLoss=0.694627 | Sup=0.693095 | Recon=0.003064 | TrainAcc=0.5946
# Fold 6 Epoch 100: TotalLoss=0.673294 | Sup=0.671778 | Recon=0.003032 | TrainAcc=0.5946
# Fold 6 Epoch 200: TotalLoss=0.671661 | Sup=0.670176 | Recon=0.002970 | TrainAcc=0.5946
# Fold 6 Epoch 300: TotalLoss=0.670511 | Sup=0.669048 | Recon=0.002928 | TrainAcc=0.5946
# Fold 6 Epoch 400: TotalLoss=0.668825 | Sup=0.667377 | Recon=0.002896 | TrainAcc=0.5946
# Fold 6 Epoch 500: TotalLoss=0.666443 | Sup=0.665008 | Recon=0.002869 | TrainAcc=0.5856
# Fold 6 Epoch 600: TotalLoss=0.663315 | Sup=0.661892 | Recon=0.002845 | TrainAcc=0.5856
# Fold 6 Epoch 700: TotalLoss=0.659367 | Sup=0.657955 | Recon=0.002823 | TrainAcc=0.5856
# Fold 6 Epoch 800: TotalLoss=0.654505 | Sup=0.653103 | Recon=0.002804 | TrainAcc=0.6126
# Fold 6 Epoch 900: TotalLoss=0.648699 | Sup=0.647306 | Recon=0.002785 | TrainAcc=0.6306
# Fold 6 Epoch 1000: TotalLoss=0.641979 | Sup=0.640597 | Recon=0.002765 | TrainAcc=0.6577
# Fold 6 Epoch 1100: TotalLoss=0.634516 | Sup=0.633148 | Recon=0.002736 | TrainAcc=0.6667
# Fold 6 Epoch 1200: TotalLoss=0.626527 | Sup=0.625182 | Recon=0.002691 | TrainAcc=0.6847
# Fold 6 Epoch 1300: TotalLoss=0.618383 | Sup=0.617070 | Recon=0.002626 | TrainAcc=0.6847
# Fold 6 Epoch 1400: TotalLoss=0.610411 | Sup=0.609137 | Recon=0.002546 | TrainAcc=0.7027
# Fold 6 Epoch 1500: TotalLoss=0.602901 | Sup=0.601672 | Recon=0.002458 | TrainAcc=0.7117
# Fold 6 Epoch 1600: TotalLoss=0.596029 | Sup=0.594844 | Recon=0.002370 | TrainAcc=0.7207
# Fold 6 Epoch 1700: TotalLoss=0.589876 | Sup=0.588732 | Recon=0.002288 | TrainAcc=0.7297
# Fold 6 Epoch 1800: TotalLoss=0.584405 | Sup=0.583299 | Recon=0.002213 | TrainAcc=0.7297
# Fold 6 Epoch 1900: TotalLoss=0.579596 | Sup=0.578523 | Recon=0.002147 | TrainAcc=0.7207
# Fold 6 Epoch 2000: TotalLoss=0.575403 | Sup=0.574359 | Recon=0.002088 | TrainAcc=0.7297
# Fold 6 → Acc=0.7232 | Prec=0.7500 | Rec=0.4667 | F1=0.5753 | AUC=0.8244 | CE Loss=0.5870
#
# === Fold 7 ===
# Train CN: 66, Train AD: 45
# Fold 7 Epoch 1: TotalLoss=0.692036 | Sup=0.690504 | Recon=0.003064 | TrainAcc=0.5946
# Fold 7 Epoch 100: TotalLoss=0.668923 | Sup=0.667414 | Recon=0.003017 | TrainAcc=0.5946
# Fold 7 Epoch 200: TotalLoss=0.664862 | Sup=0.663388 | Recon=0.002949 | TrainAcc=0.6036
# Fold 7 Epoch 300: TotalLoss=0.661778 | Sup=0.660329 | Recon=0.002898 | TrainAcc=0.6036
# Fold 7 Epoch 400: TotalLoss=0.658822 | Sup=0.657393 | Recon=0.002857 | TrainAcc=0.6036
# Fold 7 Epoch 500: TotalLoss=0.655624 | Sup=0.654212 | Recon=0.002824 | TrainAcc=0.5946
# Fold 7 Epoch 600: TotalLoss=0.651830 | Sup=0.650432 | Recon=0.002796 | TrainAcc=0.6126
# Fold 7 Epoch 700: TotalLoss=0.647222 | Sup=0.645837 | Recon=0.002770 | TrainAcc=0.6306
# Fold 7 Epoch 800: TotalLoss=0.641682 | Sup=0.640309 | Recon=0.002745 | TrainAcc=0.6396
# Fold 7 Epoch 900: TotalLoss=0.635290 | Sup=0.633931 | Recon=0.002717 | TrainAcc=0.6577
# Fold 7 Epoch 1000: TotalLoss=0.628209 | Sup=0.626865 | Recon=0.002688 | TrainAcc=0.6667
# Fold 7 Epoch 1100: TotalLoss=0.620724 | Sup=0.619395 | Recon=0.002658 | TrainAcc=0.6847
# Fold 7 Epoch 1200: TotalLoss=0.613182 | Sup=0.611867 | Recon=0.002629 | TrainAcc=0.6847
# Fold 7 Epoch 1300: TotalLoss=0.605908 | Sup=0.604607 | Recon=0.002602 | TrainAcc=0.6847
# Fold 7 Epoch 1400: TotalLoss=0.599145 | Sup=0.597856 | Recon=0.002576 | TrainAcc=0.7027
# Fold 7 Epoch 1500: TotalLoss=0.593017 | Sup=0.591745 | Recon=0.002544 | TrainAcc=0.7387
# Fold 7 Epoch 1600: TotalLoss=0.587561 | Sup=0.586308 | Recon=0.002506 | TrainAcc=0.7477
# Fold 7 Epoch 1700: TotalLoss=0.582773 | Sup=0.581540 | Recon=0.002465 | TrainAcc=0.7568
# Fold 7 Epoch 1800: TotalLoss=0.578610 | Sup=0.577399 | Recon=0.002423 | TrainAcc=0.7568
# Fold 7 Epoch 1900: TotalLoss=0.574988 | Sup=0.573796 | Recon=0.002383 | TrainAcc=0.7748
# Fold 7 Epoch 2000: TotalLoss=0.571812 | Sup=0.570640 | Recon=0.002345 | TrainAcc=0.7748
# Fold 7 → Acc=0.6964 | Prec=0.7619 | Rec=0.3556 | F1=0.4848 | AUC=0.8181 | CE Loss=0.5779
#
# === Fold 8 ===
# Train CN: 66, Train AD: 45
# Fold 8 Epoch 1: TotalLoss=0.696203 | Sup=0.694676 | Recon=0.003056 | TrainAcc=0.4054
# Fold 8 Epoch 100: TotalLoss=0.670109 | Sup=0.668599 | Recon=0.003019 | TrainAcc=0.6036
# Fold 8 Epoch 200: TotalLoss=0.665373 | Sup=0.663897 | Recon=0.002952 | TrainAcc=0.6036
# Fold 8 Epoch 300: TotalLoss=0.662299 | Sup=0.660850 | Recon=0.002899 | TrainAcc=0.6036
# Fold 8 Epoch 400: TotalLoss=0.659378 | Sup=0.657949 | Recon=0.002857 | TrainAcc=0.6036
# Fold 8 Epoch 500: TotalLoss=0.656134 | Sup=0.654724 | Recon=0.002821 | TrainAcc=0.6036
# Fold 8 Epoch 600: TotalLoss=0.652177 | Sup=0.650782 | Recon=0.002790 | TrainAcc=0.6216
# Fold 8 Epoch 700: TotalLoss=0.647263 | Sup=0.645883 | Recon=0.002760 | TrainAcc=0.6306
# Fold 8 Epoch 800: TotalLoss=0.641321 | Sup=0.639956 | Recon=0.002729 | TrainAcc=0.6486
# Fold 8 Epoch 900: TotalLoss=0.634429 | Sup=0.633081 | Recon=0.002696 | TrainAcc=0.6486
# Fold 8 Epoch 1000: TotalLoss=0.626836 | Sup=0.625505 | Recon=0.002663 | TrainAcc=0.6757
# Fold 8 Epoch 1100: TotalLoss=0.618889 | Sup=0.617575 | Recon=0.002629 | TrainAcc=0.6937
# Fold 8 Epoch 1200: TotalLoss=0.610990 | Sup=0.609692 | Recon=0.002595 | TrainAcc=0.6937
# Fold 8 Epoch 1300: TotalLoss=0.603479 | Sup=0.602199 | Recon=0.002559 | TrainAcc=0.6937
# Fold 8 Epoch 1400: TotalLoss=0.596559 | Sup=0.595295 | Recon=0.002527 | TrainAcc=0.7027
# Fold 8 Epoch 1500: TotalLoss=0.590342 | Sup=0.589090 | Recon=0.002502 | TrainAcc=0.7117
# Fold 8 Epoch 1600: TotalLoss=0.584861 | Sup=0.583620 | Recon=0.002483 | TrainAcc=0.7207
# Fold 8 Epoch 1700: TotalLoss=0.580066 | Sup=0.578834 | Recon=0.002464 | TrainAcc=0.7117
# Fold 8 Epoch 1800: TotalLoss=0.575860 | Sup=0.574640 | Recon=0.002440 | TrainAcc=0.7207
# Fold 8 Epoch 1900: TotalLoss=0.572157 | Sup=0.570950 | Recon=0.002414 | TrainAcc=0.7207
# Fold 8 Epoch 2000: TotalLoss=0.568837 | Sup=0.567644 | Recon=0.002385 | TrainAcc=0.7207
# Fold 8 → Acc=0.7411 | Prec=0.8077 | Rec=0.4667 | F1=0.5915 | AUC=0.8403 | CE Loss=0.5683
#
# === Fold 9 ===
# Train CN: 66, Train AD: 45
# Fold 9 Epoch 1: TotalLoss=0.695284 | Sup=0.693758 | Recon=0.003052 | TrainAcc=0.3784
# Fold 9 Epoch 100: TotalLoss=0.676933 | Sup=0.675431 | Recon=0.003003 | TrainAcc=0.5946
# Fold 9 Epoch 200: TotalLoss=0.676134 | Sup=0.674658 | Recon=0.002952 | TrainAcc=0.5946
# Fold 9 Epoch 300: TotalLoss=0.675629 | Sup=0.674170 | Recon=0.002919 | TrainAcc=0.5946
# Fold 9 Epoch 400: TotalLoss=0.674912 | Sup=0.673465 | Recon=0.002894 | TrainAcc=0.5946
# Fold 9 Epoch 500: TotalLoss=0.673908 | Sup=0.672471 | Recon=0.002873 | TrainAcc=0.5946
# Fold 9 Epoch 600: TotalLoss=0.672537 | Sup=0.671109 | Recon=0.002856 | TrainAcc=0.5946
# Fold 9 Epoch 700: TotalLoss=0.670740 | Sup=0.669319 | Recon=0.002842 | TrainAcc=0.5946
# Fold 9 Epoch 800: TotalLoss=0.668478 | Sup=0.667063 | Recon=0.002830 | TrainAcc=0.5856
# Fold 9 Epoch 900: TotalLoss=0.665725 | Sup=0.664315 | Recon=0.002819 | TrainAcc=0.5946
# Fold 9 Epoch 1000: TotalLoss=0.662487 | Sup=0.661083 | Recon=0.002808 | TrainAcc=0.5946
# Fold 9 Epoch 1100: TotalLoss=0.658779 | Sup=0.657383 | Recon=0.002793 | TrainAcc=0.6036
# Fold 9 Epoch 1200: TotalLoss=0.654656 | Sup=0.653272 | Recon=0.002770 | TrainAcc=0.6126
# Fold 9 Epoch 1300: TotalLoss=0.650226 | Sup=0.648858 | Recon=0.002736 | TrainAcc=0.6306
# Fold 9 Epoch 1400: TotalLoss=0.645612 | Sup=0.644268 | Recon=0.002688 | TrainAcc=0.6306
# Fold 9 Epoch 1500: TotalLoss=0.640952 | Sup=0.639639 | Recon=0.002627 | TrainAcc=0.6306
# Fold 9 Epoch 1600: TotalLoss=0.636362 | Sup=0.635083 | Recon=0.002557 | TrainAcc=0.6486
# Fold 9 Epoch 1700: TotalLoss=0.631912 | Sup=0.630672 | Recon=0.002480 | TrainAcc=0.6577
# Fold 9 Epoch 1800: TotalLoss=0.627642 | Sup=0.626441 | Recon=0.002401 | TrainAcc=0.6577
# Fold 9 Epoch 1900: TotalLoss=0.623593 | Sup=0.622432 | Recon=0.002322 | TrainAcc=0.6757
# Fold 9 Epoch 2000: TotalLoss=0.619833 | Sup=0.618710 | Recon=0.002247 | TrainAcc=0.6577
# Fold 9 → Acc=0.7679 | Prec=0.8519 | Rec=0.5111 | F1=0.6389 | AUC=0.8965 | CE Loss=0.5773
#
# === Fold 10 ===
# Train CN: 66, Train AD: 45
# Fold 10 Epoch 1: TotalLoss=0.695007 | Sup=0.693476 | Recon=0.003062 | TrainAcc=0.5946
# Fold 10 Epoch 100: TotalLoss=0.677027 | Sup=0.675519 | Recon=0.003016 | TrainAcc=0.5946
# Fold 10 Epoch 200: TotalLoss=0.676067 | Sup=0.674588 | Recon=0.002956 | TrainAcc=0.5946
# Fold 10 Epoch 300: TotalLoss=0.675631 | Sup=0.674172 | Recon=0.002918 | TrainAcc=0.5946
# Fold 10 Epoch 400: TotalLoss=0.674987 | Sup=0.673542 | Recon=0.002889 | TrainAcc=0.5946
# Fold 10 Epoch 500: TotalLoss=0.674069 | Sup=0.672636 | Recon=0.002866 | TrainAcc=0.5946
# Fold 10 Epoch 600: TotalLoss=0.672848 | Sup=0.671424 | Recon=0.002848 | TrainAcc=0.5946
# Fold 10 Epoch 700: TotalLoss=0.671297 | Sup=0.669881 | Recon=0.002832 | TrainAcc=0.5856
# Fold 10 Epoch 800: TotalLoss=0.669378 | Sup=0.667969 | Recon=0.002818 | TrainAcc=0.5856
# Fold 10 Epoch 900: TotalLoss=0.667088 | Sup=0.665685 | Recon=0.002807 | TrainAcc=0.5856
# Fold 10 Epoch 1000: TotalLoss=0.664445 | Sup=0.663047 | Recon=0.002796 | TrainAcc=0.6126
# Fold 10 Epoch 1100: TotalLoss=0.661475 | Sup=0.660083 | Recon=0.002783 | TrainAcc=0.6216
# Fold 10 Epoch 1200: TotalLoss=0.658212 | Sup=0.656828 | Recon=0.002767 | TrainAcc=0.6216
# Fold 10 Epoch 1300: TotalLoss=0.654663 | Sup=0.653291 | Recon=0.002744 | TrainAcc=0.6216
# Fold 10 Epoch 1400: TotalLoss=0.650947 | Sup=0.649590 | Recon=0.002714 | TrainAcc=0.6306
# Fold 10 Epoch 1500: TotalLoss=0.647186 | Sup=0.645847 | Recon=0.002677 | TrainAcc=0.6306
# Fold 10 Epoch 1600: TotalLoss=0.643454 | Sup=0.642137 | Recon=0.002634 | TrainAcc=0.6216
# Fold 10 Epoch 1700: TotalLoss=0.639785 | Sup=0.638493 | Recon=0.002585 | TrainAcc=0.6216
# Fold 10 Epoch 1800: TotalLoss=0.636178 | Sup=0.634912 | Recon=0.002531 | TrainAcc=0.6306
# Fold 10 Epoch 1900: TotalLoss=0.632609 | Sup=0.631373 | Recon=0.002473 | TrainAcc=0.6486
# Fold 10 Epoch 2000: TotalLoss=0.629064 | Sup=0.627859 | Recon=0.002409 | TrainAcc=0.6486
# Fold 10 → Acc=0.7321 | Prec=0.8261 | Rec=0.4222 | F1=0.5588 | AUC=0.8668 | CE Loss=0.5894
#
# === Fold 11 ===
# Train CN: 66, Train AD: 45
# Fold 11 Epoch 1: TotalLoss=0.694686 | Sup=0.693162 | Recon=0.003047 | TrainAcc=0.5946
# Fold 11 Epoch 100: TotalLoss=0.671967 | Sup=0.670467 | Recon=0.003000 | TrainAcc=0.5946
# Fold 11 Epoch 200: TotalLoss=0.670164 | Sup=0.668695 | Recon=0.002936 | TrainAcc=0.5946
# Fold 11 Epoch 300: TotalLoss=0.669180 | Sup=0.667732 | Recon=0.002896 | TrainAcc=0.5946
# Fold 11 Epoch 400: TotalLoss=0.667780 | Sup=0.666347 | Recon=0.002866 | TrainAcc=0.5946
# Fold 11 Epoch 500: TotalLoss=0.665854 | Sup=0.664434 | Recon=0.002841 | TrainAcc=0.5946
# Fold 11 Epoch 600: TotalLoss=0.663328 | Sup=0.661918 | Recon=0.002819 | TrainAcc=0.5946
# Fold 11 Epoch 700: TotalLoss=0.660123 | Sup=0.658724 | Recon=0.002799 | TrainAcc=0.6036
# Fold 11 Epoch 800: TotalLoss=0.656127 | Sup=0.654737 | Recon=0.002779 | TrainAcc=0.6216
# Fold 11 Epoch 900: TotalLoss=0.651283 | Sup=0.649903 | Recon=0.002759 | TrainAcc=0.6306
# Fold 11 Epoch 1000: TotalLoss=0.645663 | Sup=0.644294 | Recon=0.002737 | TrainAcc=0.6396
# Fold 11 Epoch 1100: TotalLoss=0.639472 | Sup=0.638115 | Recon=0.002715 | TrainAcc=0.6486
# Fold 11 Epoch 1200: TotalLoss=0.632972 | Sup=0.631626 | Recon=0.002691 | TrainAcc=0.6667
# Fold 11 Epoch 1300: TotalLoss=0.626431 | Sup=0.625099 | Recon=0.002663 | TrainAcc=0.6757
# Fold 11 Epoch 1400: TotalLoss=0.620050 | Sup=0.618736 | Recon=0.002628 | TrainAcc=0.6757
# Fold 11 Epoch 1500: TotalLoss=0.614006 | Sup=0.612713 | Recon=0.002586 | TrainAcc=0.6937
# Fold 11 Epoch 1600: TotalLoss=0.608420 | Sup=0.607150 | Recon=0.002539 | TrainAcc=0.7207
# Fold 11 Epoch 1700: TotalLoss=0.603367 | Sup=0.602122 | Recon=0.002489 | TrainAcc=0.7207
# Fold 11 Epoch 1800: TotalLoss=0.598858 | Sup=0.597639 | Recon=0.002438 | TrainAcc=0.7207
# Fold 11 Epoch 1900: TotalLoss=0.594872 | Sup=0.593678 | Recon=0.002389 | TrainAcc=0.7297
# Fold 11 Epoch 2000: TotalLoss=0.591344 | Sup=0.590173 | Recon=0.002343 | TrainAcc=0.7297
# Fold 11 → Acc=0.7054 | Prec=0.7500 | Rec=0.4000 | F1=0.5217 | AUC=0.8315 | CE Loss=0.5820
#
# === Fold 12 ===
# Train CN: 66, Train AD: 45
# Fold 12 Epoch 1: TotalLoss=0.697965 | Sup=0.696436 | Recon=0.003059 | TrainAcc=0.4054
# Fold 12 Epoch 100: TotalLoss=0.675071 | Sup=0.673569 | Recon=0.003003 | TrainAcc=0.6036
# Fold 12 Epoch 200: TotalLoss=0.671749 | Sup=0.670278 | Recon=0.002942 | TrainAcc=0.6036
# Fold 12 Epoch 300: TotalLoss=0.669593 | Sup=0.668143 | Recon=0.002900 | TrainAcc=0.6036
# Fold 12 Epoch 400: TotalLoss=0.667694 | Sup=0.666261 | Recon=0.002866 | TrainAcc=0.6036
# Fold 12 Epoch 500: TotalLoss=0.665714 | Sup=0.664294 | Recon=0.002838 | TrainAcc=0.6036
# Fold 12 Epoch 600: TotalLoss=0.663417 | Sup=0.662010 | Recon=0.002814 | TrainAcc=0.6036
# Fold 12 Epoch 700: TotalLoss=0.660662 | Sup=0.659266 | Recon=0.002792 | TrainAcc=0.5946
# Fold 12 Epoch 800: TotalLoss=0.657285 | Sup=0.655899 | Recon=0.002772 | TrainAcc=0.6036
# Fold 12 Epoch 900: TotalLoss=0.653221 | Sup=0.651845 | Recon=0.002751 | TrainAcc=0.6126
# Fold 12 Epoch 1000: TotalLoss=0.648500 | Sup=0.647135 | Recon=0.002730 | TrainAcc=0.6306
# Fold 12 Epoch 1100: TotalLoss=0.643228 | Sup=0.641875 | Recon=0.002706 | TrainAcc=0.6306
# Fold 12 Epoch 1200: TotalLoss=0.637562 | Sup=0.636221 | Recon=0.002682 | TrainAcc=0.6396
# Fold 12 Epoch 1300: TotalLoss=0.631697 | Sup=0.630368 | Recon=0.002658 | TrainAcc=0.6396
# Fold 12 Epoch 1400: TotalLoss=0.625849 | Sup=0.624531 | Recon=0.002634 | TrainAcc=0.6667
# Fold 12 Epoch 1500: TotalLoss=0.620174 | Sup=0.618869 | Recon=0.002610 | TrainAcc=0.6847
# Fold 12 Epoch 1600: TotalLoss=0.614773 | Sup=0.613482 | Recon=0.002582 | TrainAcc=0.6847
# Fold 12 Epoch 1700: TotalLoss=0.609664 | Sup=0.608390 | Recon=0.002548 | TrainAcc=0.7027
# Fold 12 Epoch 1800: TotalLoss=0.604855 | Sup=0.603602 | Recon=0.002507 | TrainAcc=0.7117
# Fold 12 Epoch 1900: TotalLoss=0.600432 | Sup=0.599201 | Recon=0.002464 | TrainAcc=0.7117
# Fold 12 Epoch 2000: TotalLoss=0.596395 | Sup=0.595186 | Recon=0.002419 | TrainAcc=0.7117
# Fold 12 → Acc=0.7321 | Prec=0.7778 | Rec=0.4667 | F1=0.5833 | AUC=0.8184 | CE Loss=0.5901
#
# === Fold 13 ===
# Train CN: 66, Train AD: 45
# Fold 13 Epoch 1: TotalLoss=0.696269 | Sup=0.694743 | Recon=0.003051 | TrainAcc=0.4054
# Fold 13 Epoch 100: TotalLoss=0.669296 | Sup=0.667801 | Recon=0.002990 | TrainAcc=0.5946
# Fold 13 Epoch 200: TotalLoss=0.664757 | Sup=0.663295 | Recon=0.002924 | TrainAcc=0.6036
# Fold 13 Epoch 300: TotalLoss=0.661406 | Sup=0.659966 | Recon=0.002880 | TrainAcc=0.6036
# Fold 13 Epoch 400: TotalLoss=0.657972 | Sup=0.656548 | Recon=0.002848 | TrainAcc=0.6036
# Fold 13 Epoch 500: TotalLoss=0.653928 | Sup=0.652517 | Recon=0.002822 | TrainAcc=0.6126
# Fold 13 Epoch 600: TotalLoss=0.648901 | Sup=0.647501 | Recon=0.002800 | TrainAcc=0.6126
# Fold 13 Epoch 700: TotalLoss=0.642633 | Sup=0.641244 | Recon=0.002779 | TrainAcc=0.6396
# Fold 13 Epoch 800: TotalLoss=0.635081 | Sup=0.633704 | Recon=0.002755 | TrainAcc=0.6577
# Fold 13 Epoch 900: TotalLoss=0.626444 | Sup=0.625080 | Recon=0.002728 | TrainAcc=0.6847
# Fold 13 Epoch 1000: TotalLoss=0.617178 | Sup=0.615829 | Recon=0.002698 | TrainAcc=0.6937
# Fold 13 Epoch 1100: TotalLoss=0.607792 | Sup=0.606460 | Recon=0.002664 | TrainAcc=0.6937
# Fold 13 Epoch 1200: TotalLoss=0.598724 | Sup=0.597413 | Recon=0.002620 | TrainAcc=0.7117
# Fold 13 Epoch 1300: TotalLoss=0.590329 | Sup=0.589044 | Recon=0.002570 | TrainAcc=0.7297
# Fold 13 Epoch 1400: TotalLoss=0.582778 | Sup=0.581520 | Recon=0.002516 | TrainAcc=0.7387
# Fold 13 Epoch 1500: TotalLoss=0.576105 | Sup=0.574874 | Recon=0.002462 | TrainAcc=0.7658
# Fold 13 Epoch 1600: TotalLoss=0.570239 | Sup=0.569035 | Recon=0.002409 | TrainAcc=0.7568
# Fold 13 Epoch 1700: TotalLoss=0.565073 | Sup=0.563894 | Recon=0.002358 | TrainAcc=0.7477
# Fold 13 Epoch 1800: TotalLoss=0.560512 | Sup=0.559356 | Recon=0.002311 | TrainAcc=0.7568
# Fold 13 Epoch 1900: TotalLoss=0.556485 | Sup=0.555350 | Recon=0.002269 | TrainAcc=0.7568
# Fold 13 Epoch 2000: TotalLoss=0.552926 | Sup=0.551811 | Recon=0.002229 | TrainAcc=0.7568
# Fold 13 → Acc=0.7411 | Prec=0.7857 | Rec=0.4889 | F1=0.6027 | AUC=0.7803 | CE Loss=0.5851
#
# === Fold 14 ===
# Train CN: 66, Train AD: 45
# Fold 14 Epoch 1: TotalLoss=0.690574 | Sup=0.689047 | Recon=0.003054 | TrainAcc=0.5946
# Fold 14 Epoch 100: TotalLoss=0.670711 | Sup=0.669207 | Recon=0.003008 | TrainAcc=0.5946
# Fold 14 Epoch 200: TotalLoss=0.669361 | Sup=0.667888 | Recon=0.002947 | TrainAcc=0.5946
# Fold 14 Epoch 300: TotalLoss=0.668210 | Sup=0.666756 | Recon=0.002908 | TrainAcc=0.5946
# Fold 14 Epoch 400: TotalLoss=0.666514 | Sup=0.665075 | Recon=0.002878 | TrainAcc=0.5946
# Fold 14 Epoch 500: TotalLoss=0.664154 | Sup=0.662727 | Recon=0.002854 | TrainAcc=0.5946
# Fold 14 Epoch 600: TotalLoss=0.660978 | Sup=0.659561 | Recon=0.002834 | TrainAcc=0.6036
# Fold 14 Epoch 700: TotalLoss=0.656783 | Sup=0.655374 | Recon=0.002818 | TrainAcc=0.6036
# Fold 14 Epoch 800: TotalLoss=0.651499 | Sup=0.650099 | Recon=0.002801 | TrainAcc=0.6306
# Fold 14 Epoch 900: TotalLoss=0.645147 | Sup=0.643756 | Recon=0.002781 | TrainAcc=0.6396
# Fold 14 Epoch 1000: TotalLoss=0.637883 | Sup=0.636508 | Recon=0.002750 | TrainAcc=0.6667
# Fold 14 Epoch 1100: TotalLoss=0.630058 | Sup=0.628706 | Recon=0.002705 | TrainAcc=0.6667
# Fold 14 Epoch 1200: TotalLoss=0.622055 | Sup=0.620733 | Recon=0.002644 | TrainAcc=0.6757
# Fold 14 Epoch 1300: TotalLoss=0.614185 | Sup=0.612899 | Recon=0.002572 | TrainAcc=0.6847
# Fold 14 Epoch 1400: TotalLoss=0.606724 | Sup=0.605478 | Recon=0.002493 | TrainAcc=0.7027
# Fold 14 Epoch 1500: TotalLoss=0.599839 | Sup=0.598633 | Recon=0.002412 | TrainAcc=0.7297
# Fold 14 Epoch 1600: TotalLoss=0.593637 | Sup=0.592471 | Recon=0.002334 | TrainAcc=0.7387
# Fold 14 Epoch 1700: TotalLoss=0.588118 | Sup=0.586988 | Recon=0.002260 | TrainAcc=0.7297
# Fold 14 Epoch 1800: TotalLoss=0.583230 | Sup=0.582133 | Recon=0.002193 | TrainAcc=0.7207
# Fold 14 Epoch 1900: TotalLoss=0.578906 | Sup=0.577839 | Recon=0.002133 | TrainAcc=0.7207
# Fold 14 Epoch 2000: TotalLoss=0.575043 | Sup=0.574003 | Recon=0.002080 | TrainAcc=0.7117
# Fold 14 → Acc=0.6696 | Prec=0.7000 | Rec=0.3111 | F1=0.4308 | AUC=0.7579 | CE Loss=0.6081
#
# === Fold 15 ===
# Train CN: 66, Train AD: 45
# Fold 15 Epoch 1: TotalLoss=0.696504 | Sup=0.694972 | Recon=0.003064 | TrainAcc=0.4054
# Fold 15 Epoch 100: TotalLoss=0.674597 | Sup=0.673088 | Recon=0.003018 | TrainAcc=0.5946
# Fold 15 Epoch 200: TotalLoss=0.672246 | Sup=0.670773 | Recon=0.002946 | TrainAcc=0.5946
# Fold 15 Epoch 300: TotalLoss=0.670890 | Sup=0.669439 | Recon=0.002900 | TrainAcc=0.5946
# Fold 15 Epoch 400: TotalLoss=0.668894 | Sup=0.667460 | Recon=0.002868 | TrainAcc=0.5946
# Fold 15 Epoch 500: TotalLoss=0.666128 | Sup=0.664707 | Recon=0.002842 | TrainAcc=0.5946
# Fold 15 Epoch 600: TotalLoss=0.662410 | Sup=0.661000 | Recon=0.002820 | TrainAcc=0.5946
# Fold 15 Epoch 700: TotalLoss=0.657628 | Sup=0.656228 | Recon=0.002800 | TrainAcc=0.5946
# Fold 15 Epoch 800: TotalLoss=0.651741 | Sup=0.650350 | Recon=0.002782 | TrainAcc=0.6126
# Fold 15 Epoch 900: TotalLoss=0.644678 | Sup=0.643297 | Recon=0.002762 | TrainAcc=0.6396
# Fold 15 Epoch 1000: TotalLoss=0.636502 | Sup=0.635133 | Recon=0.002738 | TrainAcc=0.6667
# Fold 15 Epoch 1100: TotalLoss=0.627474 | Sup=0.626122 | Recon=0.002704 | TrainAcc=0.6667
# Fold 15 Epoch 1200: TotalLoss=0.618030 | Sup=0.616702 | Recon=0.002656 | TrainAcc=0.6757
# Fold 15 Epoch 1300: TotalLoss=0.608515 | Sup=0.607218 | Recon=0.002594 | TrainAcc=0.7027
# Fold 15 Epoch 1400: TotalLoss=0.599341 | Sup=0.598080 | Recon=0.002522 | TrainAcc=0.7207
# Fold 15 Epoch 1500: TotalLoss=0.590754 | Sup=0.589532 | Recon=0.002444 | TrainAcc=0.7297
# Fold 15 Epoch 1600: TotalLoss=0.582905 | Sup=0.581722 | Recon=0.002366 | TrainAcc=0.7477
# Fold 15 Epoch 1700: TotalLoss=0.575868 | Sup=0.574723 | Recon=0.002291 | TrainAcc=0.7477
# Fold 15 Epoch 1800: TotalLoss=0.569629 | Sup=0.568518 | Recon=0.002221 | TrainAcc=0.7387
# Fold 15 Epoch 1900: TotalLoss=0.564142 | Sup=0.563062 | Recon=0.002159 | TrainAcc=0.7568
# Fold 15 Epoch 2000: TotalLoss=0.559306 | Sup=0.558255 | Recon=0.002103 | TrainAcc=0.7568
# Fold 15 → Acc=0.6875 | Prec=0.6923 | Rec=0.4000 | F1=0.5070 | AUC=0.7624 | CE Loss=0.6098
#
# === Fold 16 ===
# Train CN: 66, Train AD: 45
# Fold 16 Epoch 1: TotalLoss=0.694406 | Sup=0.692878 | Recon=0.003058 | TrainAcc=0.6036
# Fold 16 Epoch 100: TotalLoss=0.673112 | Sup=0.671603 | Recon=0.003019 | TrainAcc=0.6036
# Fold 16 Epoch 200: TotalLoss=0.669448 | Sup=0.667969 | Recon=0.002958 | TrainAcc=0.6036
# Fold 16 Epoch 300: TotalLoss=0.666864 | Sup=0.665408 | Recon=0.002912 | TrainAcc=0.6036
# Fold 16 Epoch 400: TotalLoss=0.664503 | Sup=0.663066 | Recon=0.002874 | TrainAcc=0.6036
# Fold 16 Epoch 500: TotalLoss=0.661896 | Sup=0.660475 | Recon=0.002843 | TrainAcc=0.6126
# Fold 16 Epoch 600: TotalLoss=0.658731 | Sup=0.657324 | Recon=0.002814 | TrainAcc=0.6036
# Fold 16 Epoch 700: TotalLoss=0.654834 | Sup=0.653440 | Recon=0.002787 | TrainAcc=0.6216
# Fold 16 Epoch 800: TotalLoss=0.650101 | Sup=0.648721 | Recon=0.002760 | TrainAcc=0.6216
# Fold 16 Epoch 900: TotalLoss=0.644592 | Sup=0.643226 | Recon=0.002732 | TrainAcc=0.6306
# Fold 16 Epoch 1000: TotalLoss=0.638457 | Sup=0.637106 | Recon=0.002704 | TrainAcc=0.6306
# Fold 16 Epoch 1100: TotalLoss=0.631924 | Sup=0.630587 | Recon=0.002673 | TrainAcc=0.6486
# Fold 16 Epoch 1200: TotalLoss=0.625180 | Sup=0.623859 | Recon=0.002642 | TrainAcc=0.6577
# Fold 16 Epoch 1300: TotalLoss=0.618432 | Sup=0.617125 | Recon=0.002615 | TrainAcc=0.6847
# Fold 16 Epoch 1400: TotalLoss=0.611855 | Sup=0.610560 | Recon=0.002590 | TrainAcc=0.6937
# Fold 16 Epoch 1500: TotalLoss=0.605578 | Sup=0.604295 | Recon=0.002567 | TrainAcc=0.7207
# Fold 16 Epoch 1600: TotalLoss=0.599656 | Sup=0.598385 | Recon=0.002542 | TrainAcc=0.7117
# Fold 16 Epoch 1700: TotalLoss=0.594156 | Sup=0.592900 | Recon=0.002512 | TrainAcc=0.7207
# Fold 16 Epoch 1800: TotalLoss=0.589109 | Sup=0.587872 | Recon=0.002475 | TrainAcc=0.7297
# Fold 16 Epoch 1900: TotalLoss=0.584526 | Sup=0.583310 | Recon=0.002432 | TrainAcc=0.7297
# Fold 16 Epoch 2000: TotalLoss=0.580377 | Sup=0.579184 | Recon=0.002387 | TrainAcc=0.7387
# Fold 16 → Acc=0.7411 | Prec=0.8333 | Rec=0.4444 | F1=0.5797 | AUC=0.8274 | CE Loss=0.5797
#
# === Fold 17 ===
# Train CN: 66, Train AD: 45
# Fold 17 Epoch 1: TotalLoss=0.695456 | Sup=0.693928 | Recon=0.003058 | TrainAcc=0.4054
# Fold 17 Epoch 100: TotalLoss=0.674689 | Sup=0.673187 | Recon=0.003003 | TrainAcc=0.5946
# Fold 17 Epoch 200: TotalLoss=0.672509 | Sup=0.671042 | Recon=0.002933 | TrainAcc=0.5946
# Fold 17 Epoch 300: TotalLoss=0.671615 | Sup=0.670171 | Recon=0.002887 | TrainAcc=0.5946
# Fold 17 Epoch 400: TotalLoss=0.670255 | Sup=0.668828 | Recon=0.002854 | TrainAcc=0.5946
# Fold 17 Epoch 500: TotalLoss=0.668313 | Sup=0.666899 | Recon=0.002827 | TrainAcc=0.5946
# Fold 17 Epoch 600: TotalLoss=0.665715 | Sup=0.664313 | Recon=0.002804 | TrainAcc=0.5946
# Fold 17 Epoch 700: TotalLoss=0.662384 | Sup=0.660992 | Recon=0.002783 | TrainAcc=0.5946
# Fold 17 Epoch 800: TotalLoss=0.658233 | Sup=0.656851 | Recon=0.002763 | TrainAcc=0.6126
# Fold 17 Epoch 900: TotalLoss=0.653320 | Sup=0.651950 | Recon=0.002742 | TrainAcc=0.6216
# Fold 17 Epoch 1000: TotalLoss=0.647698 | Sup=0.646338 | Recon=0.002720 | TrainAcc=0.6396
# Fold 17 Epoch 1100: TotalLoss=0.641409 | Sup=0.640060 | Recon=0.002697 | TrainAcc=0.6396
# Fold 17 Epoch 1200: TotalLoss=0.634594 | Sup=0.633258 | Recon=0.002672 | TrainAcc=0.6486
# Fold 17 Epoch 1300: TotalLoss=0.627454 | Sup=0.626131 | Recon=0.002646 | TrainAcc=0.6577
# Fold 17 Epoch 1400: TotalLoss=0.620210 | Sup=0.618902 | Recon=0.002616 | TrainAcc=0.6847
# Fold 17 Epoch 1500: TotalLoss=0.613119 | Sup=0.611829 | Recon=0.002580 | TrainAcc=0.7027
# Fold 17 Epoch 1600: TotalLoss=0.606432 | Sup=0.605162 | Recon=0.002538 | TrainAcc=0.7027
# Fold 17 Epoch 1700: TotalLoss=0.600285 | Sup=0.599040 | Recon=0.002491 | TrainAcc=0.7027
# Fold 17 Epoch 1800: TotalLoss=0.594746 | Sup=0.593526 | Recon=0.002440 | TrainAcc=0.7207
# Fold 17 Epoch 1900: TotalLoss=0.589789 | Sup=0.588594 | Recon=0.002391 | TrainAcc=0.7027
# Fold 17 Epoch 2000: TotalLoss=0.585378 | Sup=0.584207 | Recon=0.002343 | TrainAcc=0.7027
# Fold 17 → Acc=0.7679 | Prec=0.7879 | Rec=0.5778 | F1=0.6667 | AUC=0.8474 | CE Loss=0.5629
#
# === Fold 18 ===
# Train CN: 66, Train AD: 45
# Fold 18 Epoch 1: TotalLoss=0.694874 | Sup=0.693347 | Recon=0.003053 | TrainAcc=0.5856
# Fold 18 Epoch 100: TotalLoss=0.673402 | Sup=0.671898 | Recon=0.003006 | TrainAcc=0.5946
# Fold 18 Epoch 200: TotalLoss=0.671828 | Sup=0.670358 | Recon=0.002941 | TrainAcc=0.5946
# Fold 18 Epoch 300: TotalLoss=0.671050 | Sup=0.669599 | Recon=0.002901 | TrainAcc=0.5946
# Fold 18 Epoch 400: TotalLoss=0.669917 | Sup=0.668481 | Recon=0.002872 | TrainAcc=0.5946
# Fold 18 Epoch 500: TotalLoss=0.668339 | Sup=0.666915 | Recon=0.002849 | TrainAcc=0.5946
# Fold 18 Epoch 600: TotalLoss=0.666229 | Sup=0.664814 | Recon=0.002830 | TrainAcc=0.5856
# Fold 18 Epoch 700: TotalLoss=0.663517 | Sup=0.662110 | Recon=0.002814 | TrainAcc=0.5946
# Fold 18 Epoch 800: TotalLoss=0.660210 | Sup=0.658810 | Recon=0.002800 | TrainAcc=0.5946
# Fold 18 Epoch 900: TotalLoss=0.656318 | Sup=0.654925 | Recon=0.002787 | TrainAcc=0.6396
# Fold 18 Epoch 1000: TotalLoss=0.651882 | Sup=0.650497 | Recon=0.002769 | TrainAcc=0.6396
# Fold 18 Epoch 1100: TotalLoss=0.646984 | Sup=0.645612 | Recon=0.002744 | TrainAcc=0.6486
# Fold 18 Epoch 1200: TotalLoss=0.641739 | Sup=0.640385 | Recon=0.002709 | TrainAcc=0.6577
# Fold 18 Epoch 1300: TotalLoss=0.636273 | Sup=0.634940 | Recon=0.002665 | TrainAcc=0.6577
# Fold 18 Epoch 1400: TotalLoss=0.630699 | Sup=0.629394 | Recon=0.002610 | TrainAcc=0.6577
# Fold 18 Epoch 1500: TotalLoss=0.625169 | Sup=0.623896 | Recon=0.002547 | TrainAcc=0.6577
# Fold 18 Epoch 1600: TotalLoss=0.619811 | Sup=0.618572 | Recon=0.002478 | TrainAcc=0.6757
# Fold 18 Epoch 1700: TotalLoss=0.614702 | Sup=0.613499 | Recon=0.002406 | TrainAcc=0.6757
# Fold 18 Epoch 1800: TotalLoss=0.609986 | Sup=0.608818 | Recon=0.002336 | TrainAcc=0.6757
# Fold 18 Epoch 1900: TotalLoss=0.605748 | Sup=0.604612 | Recon=0.002271 | TrainAcc=0.6847
# Fold 18 Epoch 2000: TotalLoss=0.602001 | Sup=0.600896 | Recon=0.002212 | TrainAcc=0.6937
# Fold 18 → Acc=0.7500 | Prec=0.9048 | Rec=0.4222 | F1=0.5758 | AUC=0.8308 | CE Loss=0.5822
#
# === Fold 19 ===
# Train CN: 66, Train AD: 45
# Fold 19 Epoch 1: TotalLoss=0.695107 | Sup=0.693580 | Recon=0.003054 | TrainAcc=0.5946
# Fold 19 Epoch 100: TotalLoss=0.676009 | Sup=0.674505 | Recon=0.003008 | TrainAcc=0.5946
# Fold 19 Epoch 200: TotalLoss=0.675089 | Sup=0.673612 | Recon=0.002955 | TrainAcc=0.5946
# Fold 19 Epoch 300: TotalLoss=0.674319 | Sup=0.672859 | Recon=0.002920 | TrainAcc=0.5946
# Fold 19 Epoch 400: TotalLoss=0.673141 | Sup=0.671696 | Recon=0.002891 | TrainAcc=0.5946
# Fold 19 Epoch 500: TotalLoss=0.671497 | Sup=0.670064 | Recon=0.002866 | TrainAcc=0.5856
# Fold 19 Epoch 600: TotalLoss=0.669341 | Sup=0.667919 | Recon=0.002844 | TrainAcc=0.5946
# Fold 19 Epoch 700: TotalLoss=0.666621 | Sup=0.665210 | Recon=0.002823 | TrainAcc=0.5946
# Fold 19 Epoch 800: TotalLoss=0.663295 | Sup=0.661894 | Recon=0.002803 | TrainAcc=0.5946
# Fold 19 Epoch 900: TotalLoss=0.659362 | Sup=0.657969 | Recon=0.002784 | TrainAcc=0.6036
# Fold 19 Epoch 1000: TotalLoss=0.654853 | Sup=0.653470 | Recon=0.002766 | TrainAcc=0.6216
# Fold 19 Epoch 1100: TotalLoss=0.649843 | Sup=0.648468 | Recon=0.002749 | TrainAcc=0.6306
# Fold 19 Epoch 1200: TotalLoss=0.644439 | Sup=0.643073 | Recon=0.002732 | TrainAcc=0.6396
# Fold 19 Epoch 1300: TotalLoss=0.638791 | Sup=0.637437 | Recon=0.002708 | TrainAcc=0.6396
# Fold 19 Epoch 1400: TotalLoss=0.633078 | Sup=0.631743 | Recon=0.002671 | TrainAcc=0.6577
# Fold 19 Epoch 1500: TotalLoss=0.627447 | Sup=0.626138 | Recon=0.002619 | TrainAcc=0.6757
# Fold 19 Epoch 1600: TotalLoss=0.622066 | Sup=0.620788 | Recon=0.002556 | TrainAcc=0.6757
# Fold 19 Epoch 1700: TotalLoss=0.617065 | Sup=0.615821 | Recon=0.002487 | TrainAcc=0.6937
# Fold 19 Epoch 1800: TotalLoss=0.612493 | Sup=0.611284 | Recon=0.002418 | TrainAcc=0.6847
# Fold 19 Epoch 1900: TotalLoss=0.608367 | Sup=0.607192 | Recon=0.002351 | TrainAcc=0.6757
# Fold 19 Epoch 2000: TotalLoss=0.604667 | Sup=0.603523 | Recon=0.002288 | TrainAcc=0.6937
# Fold 19 → Acc=0.7054 | Prec=0.7500 | Rec=0.4000 | F1=0.5217 | AUC=0.8350 | CE Loss=0.5933
#
# === Fold 20 ===
# Train CN: 66, Train AD: 45
# Fold 20 Epoch 1: TotalLoss=0.692533 | Sup=0.691002 | Recon=0.003061 | TrainAcc=0.5946
# Fold 20 Epoch 100: TotalLoss=0.673664 | Sup=0.672152 | Recon=0.003024 | TrainAcc=0.5946
# Fold 20 Epoch 200: TotalLoss=0.672271 | Sup=0.670791 | Recon=0.002961 | TrainAcc=0.5946
# Fold 20 Epoch 300: TotalLoss=0.671418 | Sup=0.669959 | Recon=0.002918 | TrainAcc=0.5946
# Fold 20 Epoch 400: TotalLoss=0.670197 | Sup=0.668754 | Recon=0.002885 | TrainAcc=0.5946
# Fold 20 Epoch 500: TotalLoss=0.668521 | Sup=0.667093 | Recon=0.002857 | TrainAcc=0.5946
# Fold 20 Epoch 600: TotalLoss=0.666294 | Sup=0.664877 | Recon=0.002834 | TrainAcc=0.5856
# Fold 20 Epoch 700: TotalLoss=0.663428 | Sup=0.662021 | Recon=0.002813 | TrainAcc=0.5946
# Fold 20 Epoch 800: TotalLoss=0.659844 | Sup=0.658447 | Recon=0.002793 | TrainAcc=0.6036
# Fold 20 Epoch 900: TotalLoss=0.655538 | Sup=0.654150 | Recon=0.002775 | TrainAcc=0.6216
# Fold 20 Epoch 1000: TotalLoss=0.650531 | Sup=0.649152 | Recon=0.002757 | TrainAcc=0.6306
# Fold 20 Epoch 1100: TotalLoss=0.644863 | Sup=0.643495 | Recon=0.002737 | TrainAcc=0.6396
# Fold 20 Epoch 1200: TotalLoss=0.638676 | Sup=0.637319 | Recon=0.002713 | TrainAcc=0.6577
# Fold 20 Epoch 1300: TotalLoss=0.632115 | Sup=0.630774 | Recon=0.002681 | TrainAcc=0.6667
# Fold 20 Epoch 1400: TotalLoss=0.625370 | Sup=0.624051 | Recon=0.002638 | TrainAcc=0.6667
# Fold 20 Epoch 1500: TotalLoss=0.618737 | Sup=0.617446 | Recon=0.002583 | TrainAcc=0.6937
# Fold 20 Epoch 1600: TotalLoss=0.612461 | Sup=0.611200 | Recon=0.002521 | TrainAcc=0.7027
# Fold 20 Epoch 1700: TotalLoss=0.606648 | Sup=0.605420 | Recon=0.002455 | TrainAcc=0.7027
# Fold 20 Epoch 1800: TotalLoss=0.601379 | Sup=0.600184 | Recon=0.002390 | TrainAcc=0.7027
# Fold 20 Epoch 1900: TotalLoss=0.596668 | Sup=0.595504 | Recon=0.002329 | TrainAcc=0.6937
# Fold 20 Epoch 2000: TotalLoss=0.592456 | Sup=0.591321 | Recon=0.002269 | TrainAcc=0.7117
# Fold 20 → Acc=0.6875 | Prec=0.7273 | Rec=0.3556 | F1=0.4776 | AUC=0.8229 | CE Loss=0.5987
#
# === Average Results Across 20 Folds ===
# Accuracy:  0.7263 ± 0.0273
# Precision: 0.7852 ± 0.0509
# Recall:    0.4389 ± 0.0640
# F1-score:  0.5608 ± 0.0591
# AUC:       0.8258 ± 0.0309
# CE Loss:   0.5847 ± 0.0120
