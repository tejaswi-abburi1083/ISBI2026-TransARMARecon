# %%
import os
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as nnFn
import torch.optim as optim
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, log_loss
from torch_geometric.data import Data
from torch_geometric.nn import ARMAConv

device = 'cuda' if torch.cuda.is_available() else 'cpu'
print("Device:", device)

cn_path = "/home/snu/Downloads/Histogram_CN_FA_20bin_updated.npy"
ad_path = "/home/snu/Downloads/Histogram_AD_FA_20bin_updated.npy"
Histogram_feature_CN_FA_array = np.load(cn_path, allow_pickle=True)
Histogram_feature_AD_FA_array = np.load(ad_path, allow_pickle=True)

X = np.vstack([Histogram_feature_CN_FA_array, Histogram_feature_AD_FA_array])
y = np.hstack([
    np.zeros(Histogram_feature_CN_FA_array.shape[0], dtype=np.int64),  # CN → 0
    np.ones(Histogram_feature_AD_FA_array.shape[0], dtype=np.int64)    # AD → 1
])

num_nodes, num_feats = X.shape
print(f"Features: {X.shape}, Labels: {y.shape}")

# Shuffle for reproducibility
rng = np.random.RandomState(42)
perm = rng.permutation(num_nodes)
X = X[perm]
y = y[perm]

def create_adj(F_data, alpha=1):
    norms = np.linalg.norm(F_data, axis=1, keepdims=True)
    norms[norms == 0] = 1.0
    F_norm = F_data / norms
    W = np.dot(F_norm, F_norm.T)
    W = np.where(W >= alpha, 1.0, 0.0).astype(np.float32)
    if W.max() > 0:
        W = W / W.max()
    return W

alpha = 0.8
W = create_adj(X, alpha=alpha)
np.fill_diagonal(W, 1.0)

def load_data(adj, node_feats):
    node_feats = torch.from_numpy(node_feats).float()
    rows, cols = np.nonzero(adj > 0)
    edge_index = torch.from_numpy(np.vstack([rows, cols]).astype(np.int64))
    return Data(x=node_feats, edge_index=edge_index)

data = load_data(W, X).to(device)
print(data)

class ARMA_AE(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim, device, activ="RELU", dropout=0.25):
        super(ARMA_AE, self).__init__()
        self.device = device
        self.conv1 = ARMAConv(input_dim, hidden_dim, num_stacks=1, num_layers=1)
        self.bn1 = nn.BatchNorm1d(hidden_dim)
        self.dropout = nn.Dropout(dropout)
        self.fc = nn.Linear(hidden_dim, output_dim)

        self.decoder = nn.Sequential(
            nn.Linear(hidden_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, input_dim)
        )

        activations = {
            "SELU": nnFn.selu,
            "SiLU": nnFn.silu,
            "GELU": nnFn.gelu,
            "RELU": nnFn.relu,
            "ELU": nnFn.elu
        }
        self.act = activations.get(activ, nnFn.relu)

    def forward(self, x, edge_index):
        h = self.conv1(x, edge_index)
        h = self.bn1(h)
        h = self.act(h)
        h = self.dropout(h)
        logits = self.fc(h)
        recon = self.decoder(h)
        return logits, recon, h


feats_dim = num_feats
hidden_dim = 512
num_classes = 2
num_epochs = 2000
lr = 1e-4
weight_decay = 1e-4
batch_print_freq = 100
lambda_recon = 2

sss = StratifiedShuffleSplit(n_splits=20, test_size=0.3, random_state=42)
accuracies, precisions, recalls, f1_scores, aucs, ce_losses = [], [], [], [], [], []
y_all = y.copy()

for fold, (train_val_idx, test_idx_global) in enumerate(sss.split(X, y_all), start=1):
    print(f"\n=== Fold {fold} ===")
    cn_idx = np.where(y_all == 0)[0]
    ad_idx = np.where(y_all == 1)[0]
    sss_class = StratifiedShuffleSplit(n_splits=20, test_size=0.3, random_state=fold)
    cn_train_idx, _ = next(sss_class.split(X[cn_idx], y_all[cn_idx]))
    ad_train_idx, _ = next(sss_class.split(X[ad_idx], y_all[ad_idx]))
    cn_train = cn_idx[cn_train_idx]
    ad_train = ad_idx[ad_train_idx]
    train_idx_final = np.concatenate([cn_train, ad_train])
    np.random.shuffle(train_idx_final)

    print(f"Train CN: {len(cn_train)}, Train AD: {len(ad_train)}")
    train_idx_t = torch.from_numpy(train_idx_final).long().to(device)
    y_train_tensor = torch.from_numpy(y_all[train_idx_final]).long().to(device)

    model = ARMA_AE(feats_dim, hidden_dim, num_classes, device, activ="RELU", dropout=0.25).to(device)
    optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
    ce_loss_fn = nn.CrossEntropyLoss()
    recon_loss_fn = nn.MSELoss()
    data = load_data(W, X).to(device)

    for epoch in range(1, num_epochs + 1):
        model.train()
        optimizer.zero_grad()
        logits, recon_x, _ = model(data.x, data.edge_index)

        loss_sup = ce_loss_fn(logits[train_idx_t], y_train_tensor)
        loss_recon = recon_loss_fn(recon_x, data.x)
        total_loss = loss_sup + lambda_recon * loss_recon

        if torch.isnan(total_loss) or torch.isinf(total_loss):
            print(f"NaN/Inf detected at fold {fold} epoch {epoch}. Aborting epoch.")
            break

        total_loss.backward()
        optimizer.step()

        if epoch % batch_print_freq == 0 or epoch == 1:
            model.eval()
            with torch.no_grad():
                logits_eval, _, _ = model(data.x, data.edge_index)
                preds_train = logits_eval[train_idx_t].argmax(dim=1)
                acc_train = accuracy_score(y_train_tensor.cpu(), preds_train.cpu())
            print(f"Fold {fold} Epoch {epoch}: TotalLoss={total_loss.item():.6f} | Sup={loss_sup.item():.6f} | Recon={loss_recon.item():.6f} | TrainAcc={acc_train:.4f}")

    model.eval()
    with torch.no_grad():
        out_logits, _, _ = model(data.x, data.edge_index)
        preds = out_logits.argmax(dim=1).cpu().numpy()
        probs = nnFn.softmax(out_logits, dim=1)[:, 1].cpu().numpy()

    y_test = y_all[test_idx_global]
    y_pred_test = preds[test_idx_global]
    y_prob_test = probs[test_idx_global]

    acc = accuracy_score(y_test, y_pred_test)
    prec = precision_score(y_test, y_pred_test, zero_division=0)
    rec = recall_score(y_test, y_pred_test, zero_division=0)
    f1 = f1_score(y_test, y_pred_test, zero_division=0)
    try:
        auc = roc_auc_score(y_test, y_prob_test)
    except ValueError:
        auc = float('nan')
    ce = log_loss(y_test, y_prob_test)

    accuracies.append(acc)
    precisions.append(prec)
    recalls.append(rec)
    f1_scores.append(f1)
    aucs.append(auc)
    ce_losses.append(ce)

    print(f"Fold {fold} → Acc={acc:.4f} | Prec={prec:.4f} | Rec={rec:.4f} | F1={f1:.4f} | AUC={auc:.4f} | CE Loss={ce:.4f}")


print("\n=== Average Results Across 20 Folds ===")
print(f"Accuracy:  {np.mean(accuracies):.4f} ± {np.std(accuracies):.4f}")
print(f"Precision: {np.mean(precisions):.4f} ± {np.std(precisions):.4f}")
print(f"Recall:    {np.mean(recalls):.4f} ± {np.std(recalls):.4f}")
print(f"F1-score:  {np.mean(f1_scores):.4f} ± {np.std(f1_scores):.4f}")
print(f"CE Loss:   {np.mean(ce_losses):.4f} ± {np.std(ce_losses):.4f}")
print(f"AUC:       {np.nanmean(aucs):.4f} ± {np.nanstd(aucs):.4f}")
# Out:
# Device: cuda
# Features: (223, 180), Labels: (223,)
# Data(x=[223, 180], edge_index=[2, 41689])
#
# === Fold 1 ===
# Train CN: 93, Train AD: 63
# Fold 1 Epoch 1: TotalLoss=0.771648 | Sup=0.700005 | Recon=0.035822 | TrainAcc=0.5641
# Fold 1 Epoch 100: TotalLoss=0.210393 | Sup=0.204427 | Recon=0.002983 | TrainAcc=0.9551
# Fold 1 Epoch 200: TotalLoss=0.070400 | Sup=0.067568 | Recon=0.001416 | TrainAcc=1.0000
# Fold 1 Epoch 300: TotalLoss=0.029030 | Sup=0.027165 | Recon=0.000932 | TrainAcc=1.0000
# Fold 1 Epoch 400: TotalLoss=0.014070 | Sup=0.012748 | Recon=0.000661 | TrainAcc=1.0000
# Fold 1 Epoch 500: TotalLoss=0.008865 | Sup=0.007817 | Recon=0.000524 | TrainAcc=1.0000
# Fold 1 Epoch 600: TotalLoss=0.006052 | Sup=0.005153 | Recon=0.000449 | TrainAcc=1.0000
# Fold 1 Epoch 700: TotalLoss=0.003496 | Sup=0.002701 | Recon=0.000398 | TrainAcc=1.0000
# Fold 1 Epoch 800: TotalLoss=0.003369 | Sup=0.002661 | Recon=0.000354 | TrainAcc=1.0000
# Fold 1 Epoch 900: TotalLoss
| TrainAcc=1.0000
# Fold 11 Epoch 2000: TotalLoss=0.000353 | Sup=0.000132 | Recon=0.000110 | TrainAcc=1.0000
# Fold 11 → Acc=0.9552 | Prec=0.9615 | Rec=0.9259 | F1=0.9434 | AUC=0.9667 | CE Loss=0.3261
#
# === Fold 12 ===
# Train CN: 93, Train AD: 63
# Fold 12 Epoch 1: TotalLoss=0.807194 | Sup=0.727151 | Recon=0.040022 | TrainAcc=0.4038
# Fold 12 Epoch 100: TotalLoss=0.216330 | Sup=0.210068 | Recon=0.003131 | TrainAcc=0.9551
# Fold 12 Epoch 200: TotalLoss=0.082305 | Sup=0.079277 | Recon=0.001514 | TrainAcc=1.0000
# Fold 12 Epoch 300: TotalLoss=0.030030 | Sup=0.028243 | Recon=0.000893 | TrainAcc=1.0000
# Fold 12 Epoch 400: TotalLoss=0.017120 | Sup=0.015805 | Recon=0.000657 | TrainAcc=1.0000
# Fold 12 Epoch 500: TotalLoss=0.010527 | Sup=0.009461 | Recon=0.000533 | TrainAcc=1.0000
# Fold 12 Epoch 600: TotalLoss=0.006599 | Sup=0.005692 | Recon=0.000454 | TrainAcc=1.0000
# Fold 12 Epoch 700: TotalLoss=0.003818 | Sup=0.003028 | Recon=0.000395 | TrainAcc=1.0000
# Fold 12 Epoch 800: TotalLoss=0.003577 | Sup=0.002877 | Recon=0.000350 | TrainAcc=1.0000
# Fold 12 Epoch 900: TotalLoss=0.002682 | Sup=0.002066 | Recon=0.000308 | TrainAcc=1.0000
# Fold 12 Epoch 1000: TotalLoss=0.001823 | Sup=0.001272 | Recon=0.000275 | TrainAcc=1.0000
# Fold 12 Epoch 1100: TotalLoss=0.001503 | Sup=0.001012 | Recon=0.000246 | TrainAcc=1.0000
# Fold 12 Epoch 1200: TotalLoss=0.001211 | Sup=0.000761 | Recon=0.000225 | TrainAcc=1.0000
# Fold 12 Epoch 1300: TotalLoss=0.001019 | Sup=0.000596 | Recon=0.000212 | TrainAcc=1.0000
# Fold 12 Epoch 1400: TotalLoss=0.000765 | Sup=0.000385 | Recon=0.000190 | TrainAcc=1.0000
# Fold 12 Epoch 1500: TotalLoss=0.000717 | Sup=0.000366 | Recon=0.000176 | TrainAcc=1.0000
# Fold 12 Epoch 1600: TotalLoss=0.000637 | Sup=0.000311 | Recon=0.000163 | TrainAcc=1.0000
# Fold 12 Epoch 1700: TotalLoss=0.000598 | Sup=0.000298 | Recon=0.000150 | TrainAcc=1.0000
# Fold 12 Epoch 1800: TotalLoss=0.000448 | Sup=0.000174 | Recon=0.000137 | TrainAcc=1.0000
# Fold 12 Epoch 1900: TotalLoss=0.000421 | Sup=0.000163 | Recon=0.000129 | TrainAcc=1.0000
# Fold 12 Epoch 2000: TotalLoss=0.000429 | Sup=0.000180 | Recon=0.000124 | TrainAcc=1.0000
# Fold 12 → Acc=0.9701 | Prec=0.9310 | Rec=1.0000 | F1=0.9643 | AUC=0.9944 | CE Loss=0.1104
#
# === Fold 13 ===
# Train CN: 93, Train AD: 63
# Fold 13 Epoch 1: TotalLoss=0.863975 | Sup=0.789796 | Recon=0.037089 | TrainAcc=0.3462
# Fold 13 Epoch 100: TotalLoss=0.201958 | Sup=0.195629 | Recon=0.003165 | TrainAcc=0.9615
# Fold 13 Epoch 200: TotalLoss=0.070502 | Sup=0.067491 | Recon=0.001505 | TrainAcc=1.0000
# Fold 13 Epoch 300: TotalLoss=0.027447 | Sup=0.025558 | Recon=0.000944 | TrainAcc=1.0000
# Fold 13 Epoch 400: TotalLoss=0.013968 | Sup=0.012640 | Recon=0.000664 | TrainAcc=1.0000
# Fold 13 Epoch 500: TotalLoss=0.008118 | Sup=0.007032 | Recon=0.000543 | TrainAcc=1.0000
# Fold 13 Epoch 600: TotalLoss=0.006268 | Sup=0.005361 | Recon=0.000453 | TrainAcc=1.0000
# Fold 13 Epoch 700: TotalLoss=0.004415 | Sup=0.003653 | Recon=0.000381 | TrainAcc=1.0000
# Fold 13 Epoch 800: TotalLoss=0.003031 | Sup=0.002376 | Recon=0.000327 | TrainAcc=1.0000
# Fold 13 Epoch 900: TotalLoss=0.002094 | Sup=0.001518 | Recon=0.000288 | TrainAcc=1.0000
# Fold 13 Epoch 1000: TotalLoss=0.001767 | Sup=0.001239 | Recon=0.000264 | TrainAcc=1.0000
# Fold 13 Epoch 1100: TotalLoss=0.001447 | Sup=0.000976 | Recon=0.000236 | TrainAcc=1.0000
# Fold 13 Epoch 1200: TotalLoss=0.001148 | Sup=0.000719 | Recon=0.000214 | TrainAcc=1.0000
# Fold 13 Epoch 1300: TotalLoss=0.000980 | Sup=0.000589 | Recon=0.000196 | TrainAcc=1.0000
# Fold 13 Epoch 1400: TotalLoss=0.000840 | Sup=0.000483 | Recon=0.000179 | TrainAcc=1.0000
# Fold 13 Epoch 1500: TotalLoss=0.000717 | Sup=0.000394 | Recon=0.000161 | TrainAcc=1.0000
# Fold 13 Epoch 1600: TotalLoss=0.000660 | Sup=0.000363 | Recon=0.000149 | TrainAcc=1.0000
# Fold 13 Epoch 1700: TotalLoss=0.000576 | Sup=0.000289 | Recon=0.000144 | TrainAcc=1.0000
# Fold 13 Epoch 1800: TotalLoss=0.000477 | Sup=0.000222 | Recon=0.000128 | TrainAcc=1.0000
# Fold 13 Epoch 1900: TotalLoss=0.000659 | Sup=0.000417 | Recon=0.000121 | TrainAcc=1.0000
# Fold 13 Epoch 2000: TotalLoss=0.000460 | Sup=0.000228 | Recon=0.000116 | TrainAcc=1.0000
# Fold 13 → Acc=0.9851 | Prec=1.0000 | Rec=0.9630 | F1=0.9811 | AUC=1.0000 | CE Loss=0.0361
#
# === Fold 14 ===
# Train CN: 93, Train AD: 63
# Fold 14 Epoch 1: TotalLoss=0.810989 | Sup=0.733255 | Recon=0.038867 | TrainAcc=0.5962
# Fold 14 Epoch 100: TotalLoss=0.234962 | Sup=0.228071 | Recon=0.003445 | TrainAcc=0.9423
# Fold 14 Epoch 200: TotalLoss=0.078925 | Sup=0.075506 | Recon=0.001709 | TrainAcc=1.0000
# Fold 14 Epoch 300: TotalLoss=0.030469 | Sup=0.028467 | Recon=0.001001 | TrainAcc=1.0000
# Fold 14 Epoch 400: TotalLoss=0.015510 | Sup=0.014064 | Recon=0.000723 | TrainAcc=1.0000
# Fold 14 Epoch 500: TotalLoss=0.008702 | Sup=0.007621 | Recon=0.000541 | TrainAcc=1.0000
# Fold 14 Epoch 600: TotalLoss=0.006272 | Sup=0.005372 | Recon=0.000450 | TrainAcc=1.0000
# Fold 14 Epoch 700: TotalLoss=0.004285 | Sup=0.003510 | Recon=0.000388 | TrainAcc=1.0000
# Fold 14 Epoch 800: TotalLoss=0.003596 | Sup=0.002912 | Recon=0.000342 | TrainAcc=1.0000
# Fold 14 Epoch 900: TotalLoss=0.002551 | Sup=0.001929 | Recon=0.000311 | TrainAcc=1.0000
# Fold 14 Epoch 1000: TotalLoss=0.002182 | Sup=0.001593 | Recon=0.000294 | TrainAcc=1.0000
# Fold 14 Epoch 1100: TotalLoss=0.001787 | Sup=0.001261 | Recon=0.000263 | TrainAcc=1.0000
# Fold 14 Epoch 1200: TotalLoss=0.001463 | Sup=0.000974 | Recon=0.000245 | TrainAcc=1.0000
# Fold 14 Epoch 1300: TotalLoss=0.001208 | Sup=0.000767 | Recon=0.000220 | TrainAcc=1.0000
# Fold 14 Epoch 1400: TotalLoss=0.000905 | Sup=0.000506 | Recon=0.000200 | TrainAcc=1.0000
# Fold 14 Epoch 1500: TotalLoss=0.000939 | Sup=0.000572 | Recon=0.000183 | TrainAcc=1.0000
# Fold 14 Epoch 1600: TotalLoss=0.000829 | Sup=0.000498 | Recon=0.000166 | TrainAcc=1.0000
# Fold 14 Epoch 1700: TotalLoss=0.000695 | Sup=0.000392 | Recon=0.000152 | TrainAcc=1.0000
# Fold 14 Epoch 1800: TotalLoss=0.000583 | Sup=0.000303 | Recon=0.000140 | TrainAcc=1.0000
# Fold 14 Epoch 1900: TotalLoss=0.000476 | Sup=0.000218 | Recon=0.000129 | TrainAcc=1.0000
# Fold 14 Epoch 2000: TotalLoss=0.000453 | Sup=0.000212 | Recon=0.000121 | TrainAcc=1.0000
# Fold 14 → Acc=0.9552 | Prec=1.0000 | Rec=0.8889 | F1=0.9412 | AUC=0.9852 | CE Loss=0.2177
#
# === Fold 15 ===
# Train CN: 93, Train AD: 63
# Fold 15 Epoch 1: TotalLoss=0.821234 | Sup=0.744219 | Recon=0.038507 | TrainAcc=0.5705
# Fold 15 Epoch 100: TotalLoss=0.206538 | Sup=0.199780 | Recon=0.003379 | TrainAcc=0.9551
# Fold 15 Epoch 200: TotalLoss=0.073828 | Sup=0.070744 | Recon=0.001542 | TrainAcc=1.0000
# Fold 15 Epoch 300: TotalLoss=0.029503 | Sup=0.027629 | Recon=0.000937 | TrainAcc=1.0000
# Fold 15 Epoch 400: TotalLoss=0.014578 | Sup=0.013211 | Recon=0.000684 | TrainAcc=1.0000
# Fold 15 Epoch 500: TotalLoss=0.009930 | Sup=0.008843 | Recon=0.000544 | TrainAcc=1.0000
# Fold 15 Epoch 600: TotalLoss=0.006219 | Sup=0.005283 | Recon=0.000468 | TrainAcc=1.0000
# Fold 15 Epoch 700: TotalLoss=0.004007 | Sup=0.003205 | Recon=0.000401 | TrainAcc=1.0000
# Fold 15 Epoch 800: TotalLoss=0.003118 | Sup=0.002401 | Recon=0.000358 | TrainAcc=1.0000
# Fold 15 Epoch 900: TotalLoss=0.002276 | Sup=0.001635 | Recon=0.000321 | TrainAcc=1.0000
# Fold 15 Epoch 1000: TotalLoss=0.001674 | Sup=0.001084 | Recon=0.000295 | TrainAcc=1.0000
# Fold 15 Epoch 1100: TotalLoss=0.001388 | Sup=0.000858 | Recon=0.000265 | TrainAcc=1.0000
# Fold 15 Epoch 1200: TotalLoss=0.001111 | Sup=0.000640 | Recon=0.000236 | TrainAcc=1.0000
# Fold 15 Epoch 1300: TotalLoss=0.001001 | Sup=0.000573 | Recon=0.000214 | TrainAcc=1.0000
# Fold 15 Epoch 1400: TotalLoss=0.000857 | Sup=0.000459 | Recon=0.000199 | TrainAcc=1.0000
# Fold 15 Epoch 1500: TotalLoss=0.000738 | Sup=0.000375 | Recon=0.000182 | TrainAcc=1.0000
# Fold 15 Epoch 1600: TotalLoss=0.000605 | Sup=0.000281 | Recon=0.000162 | TrainAcc=1.0000
# Fold 15 Epoch 1700: TotalLoss=0.000685 | Sup=0.000376 | Recon=0.000154 | TrainAcc=1.0000
# Fold 15 Epoch 1800: TotalLoss=0.000583 | Sup=0.000293 | Recon=0.000145 | TrainAcc=1.0000
# Fold 15 Epoch 1900: TotalLoss=0.000488 | Sup=0.000218 | Recon=0.000135 | TrainAcc=1.0000
# Fold 15 Epoch 2000: TotalLoss=0.000470 | Sup=0.000220 | Recon=0.000125 | TrainAcc=1.0000
# Fold 15 → Acc=0.8955 | Prec=0.8846 | Rec=0.8519 | F1=0.8679 | AUC=0.9602 | CE Loss=0.4418
#
# === Fold 16 ===
# Train CN: 93, Train AD: 63
# Fold 16 Epoch 1: TotalLoss=0.830484 | Sup=0.757236 | Recon=0.036624 | TrainAcc=0.5962
# Fold 16 Epoch 100: TotalLoss=0.210259 | Sup=0.204008 | Recon=0.003126 | TrainAcc=0.9551
# Fold 16 Epoch 200: TotalLoss=0.073053 | Sup=0.070190 | Recon=0.001431 | TrainAcc=1.0000
# Fold 16 Epoch 300: TotalLoss=0.029564 | Sup=0.027724 | Recon=0.000920 | TrainAcc=1.0000
# Fold 16 Epoch 400: TotalLoss=0.016053 | Sup=0.014805 | Recon=0.000624 | TrainAcc=1.0000
# Fold 16 Epoch 500: TotalLoss=0.008790 | Sup=0.007770 | Recon=0.000510 | TrainAcc=1.0000
# Fold 16 Epoch 600: TotalLoss=0.006126 | Sup=0.005279 | Recon=0.000423 | TrainAcc=1.0000
# Fold 16 Epoch 700: TotalLoss=0.004919 | Sup=0.004158 | Recon=0.000380 | TrainAcc=1.0000
# Fold 16 Epoch 800: TotalLoss=0.003095 | Sup=0.002427 | Recon=0.000334 | TrainAcc=1.0000
# Fold 16 Epoch 900: TotalLoss=0.002719 | Sup=0.002116 | Recon=0.000301 | TrainAcc=1.0000
# Fold 16 Epoch 1000: TotalLoss=0.001831 | Sup=0.001279 | Recon=0.000276 | TrainAcc=1.0000
# Fold 16 Epoch 1100: TotalLoss=0.001563 | Sup=0.001069 | Recon=0.000247 | TrainAcc=1.0000
# Fold 16 Epoch 1200: TotalLoss=0.001168 | Sup=0.000714 | Recon=0.000227 | TrainAcc=1.0000
# Fold 16 Epoch 1300: TotalLoss=0.001036 | Sup=0.000632 | Recon=0.000202 | TrainAcc=1.0000
# Fold 16 Epoch 1400: TotalLoss=0.000806 | Sup=0.000441 | Recon=0.000183 | TrainAcc=1.0000
# Fold 16 Epoch 1500: TotalLoss=0.000667 | Sup=0.000343 | Recon=0.000162 | TrainAcc=1.0000
# Fold 16 Epoch 1600: TotalLoss=0.000660 | Sup=0.000356 | Recon=0.000152 | TrainAcc=1.0000
# Fold 16 Epoch 1700: TotalLoss=0.000516 | Sup=0.000236 | Recon=0.000140 | TrainAcc=1.0000
# Fold 16 Epoch 1800: TotalLoss=0.000554 | Sup=0.000287 | Recon=0.000133 | TrainAcc=1.0000
# Fold 16 Epoch 1900: TotalLoss=0.000448 | Sup=0.000198 | Recon=0.000125 | TrainAcc=1.0000
# Fold 16 Epoch 2000: TotalLoss=0.000395 | Sup=0.000172 | Recon=0.000111 | TrainAcc=1.0000
# Fold 16 → Acc=0.9254 | Prec=0.8667 | Rec=0.9630 | F1=0.9123 | AUC=0.9880 | CE Loss=0.2463
#
# === Fold 17 ===
# Train CN: 93, Train AD: 63
# Fold 17 Epoch 1: TotalLoss=0.890775 | Sup=0.814388 | Recon=0.038194 | TrainAcc=0.5962
# Fold 17 Epoch 100: TotalLoss=0.216866 | Sup=0.210650 | Recon=0.003108 | TrainAcc=0.9551
# Fold 17 Epoch 200: TotalLoss=0.071925 | Sup=0.069072 | Recon=0.001427 | TrainAcc=1.0000
# Fold 17 Epoch 300: TotalLoss=0.030486 | Sup=0.028615 | Recon=0.000936 | TrainAcc=1.0000
# Fold 17 Epoch 400: TotalLoss=0.015685 | Sup=0.014271 | Recon=0.000707 | TrainAcc=1.0000
# Fold 17 Epoch 500: TotalLoss=0.008939 | Sup=0.007822 | Recon=0.000558 | TrainAcc=1.0000
# Fold 17 Epoch 600: TotalLoss=0.006474 | Sup=0.005530 | Recon=0.000472 | TrainAcc=1.0000
# Fold 17 Epoch 700: TotalLoss=0.004715 | Sup=0.003913 | Recon=0.000401 | TrainAcc=1.0000
# Fold 17 Epoch 800: TotalLoss=0.003351 | Sup=0.002656 | Recon=0.000348 | TrainAcc=1.0000
# Fold 17 Epoch 900: TotalLoss=0.002561 | Sup=0.001957 | Recon=0.000302 | TrainAcc=1.0000
# Fold 17 Epoch 1000: TotalLoss=0.001951 | Sup=0.001395 | Recon=0.000278 | TrainAcc=1.0000
# Fold 17 Epoch 1100: TotalLoss=0.001330 | Sup=0.000838 | Recon=0.000246 | TrainAcc=1.0000
# Fold 17 Epoch 1200: TotalLoss=0.001392 | Sup=0.000940 | Recon=0.000226 | TrainAcc=1.0000
# Fold 17 Epoch 1300: TotalLoss=0.000908 | Sup=0.000498 | Recon=0.000205 | TrainAcc=1.0000
# Fold 17 Epoch 1400: TotalLoss=0.000776 | Sup=0.000387 | Recon=0.000194 | TrainAcc=1.0000
# Fold 17 Epoch 1500: TotalLoss=0.000739 | Sup=0.000387 | Recon=0.000176 | TrainAcc=1.0000
# Fold 17 Epoch 1600: TotalLoss=0.000560 | Sup=0.000241 | Recon=0.000159 | TrainAcc=1.0000
# Fold 17 Epoch 1700: TotalLoss=0.000581 | Sup=0.000288 | Recon=0.000146 | TrainAcc=1.0000
# Fold 17 Epoch 1800: TotalLoss=0.000641 | Sup=0.000361 | Recon=0.000140 | TrainAcc=1.0000
# Fold 17 Epoch 1900: TotalLoss=0.000396 | Sup=0.000134 | Recon=0.000131 | TrainAcc=1.0000
# Fold 17 Epoch 2000: TotalLoss=0.000411 | Sup=0.000172 | Recon=0.000120 | TrainAcc=1.0000
# Fold 17 → Acc=0.9403 | Prec=0.9259 | Rec=0.9259 | F1=0.9259 | AUC=0.9870 | CE Loss=0.2256
#
# === Fold 18 ===
# Train CN: 93, Train AD: 63
# Fold 18 Epoch 1: TotalLoss=0.808562 | Sup=0.736923 | Recon=0.035820 | TrainAcc=0.4038
# Fold 18 Epoch 100: TotalLoss=0.236648 | Sup=0.230584 | Recon=0.003032 | TrainAcc=0.9551
# Fold 18 Epoch 200: TotalLoss=0.081360 | Sup=0.078195 | Recon=0.001583 | TrainAcc=1.0000
# Fold 18 Epoch 300: TotalLoss=0.030880 | Sup=0.028983 | Recon=0.000949 | TrainAcc=1.0000
# Fold 18 Epoch 400: TotalLoss=0.015499 | Sup=0.014145 | Recon=0.000677 | TrainAcc=1.0000
# Fold 18 Epoch 500: TotalLoss=0.008979 | Sup=0.007888 | Recon=0.000545 | TrainAcc=1.0000
# Fold 18 Epoch 600: TotalLoss=0.006591 | Sup=0.005664 | Recon=0.000464 | TrainAcc=1.0000
# Fold 18 Epoch 700: TotalLoss=0.004742 | Sup=0.003961 | Recon=0.000391 | TrainAcc=1.0000
# Fold 18 Epoch 800: TotalLoss=0.003589 | Sup=0.002903 | Recon=0.000343 | TrainAcc=1.0000
# Fold 18 Epoch 900: TotalLoss=0.002470 | Sup=0.001862 | Recon=0.000304 | TrainAcc=1.0000
# Fold 18 Epoch 1000: TotalLoss=0.002339 | Sup=0.001778 | Recon=0.000280 | TrainAcc=1.0000
# Fold 18 Epoch 1100: TotalLoss=0.001621 | Sup=0.001123 | Recon=0.000249 | TrainAcc=1.0000
# Fold 18 Epoch 1200: TotalLoss=0.001134 | Sup=0.000699 | Recon=0.000217 | TrainAcc=1.0000
# Fold 18 Epoch 1300: TotalLoss=0.001084 | Sup=0.000684 | Recon=0.000200 | TrainAcc=1.0000
# Fold 18 Epoch 1400: TotalLoss=0.000966 | Sup=0.000597 | Recon=0.000184 | TrainAcc=1.0000
# Fold 18 Epoch 1500: TotalLoss=0.000764 | Sup=0.000431 | Recon=0.000166 | TrainAcc=1.0000
# Fold 18 Epoch 1600: TotalLoss=0.000652 | Sup=0.000349 | Recon=0.000151 | TrainAcc=1.0000
# Fold 18 Epoch 1700: TotalLoss=0.000686 | Sup=0.000395 | Recon=0.000146 | TrainAcc=1.0000
# Fold 18 Epoch 1800: TotalLoss=0.000520 | Sup=0.000250 | Recon=0.000135 | TrainAcc=1.0000
# Fold 18 Epoch 1900: TotalLoss=0.000547 | Sup=0.000300 | Recon=0.000124 | TrainAcc=1.0000
# Fold 18 Epoch 2000: TotalLoss=0.000482 | Sup=0.000241 | Recon=0.000121 | TrainAcc=1.0000
# Fold 18 → Acc=0.9701 | Prec=0.9630 | Rec=0.9630 | F1=0.9630 | AUC=0.9917 | CE Loss=0.1236
#
# === Fold 19 ===
# Train CN: 93, Train AD: 63
# Fold 19 Epoch 1: TotalLoss=0.888560 | Sup=0.807262 | Recon=0.040649 | TrainAcc=0.3974
# Fold 19 Epoch 100: TotalLoss=0.224025 | Sup=0.217680 | Recon=0.003172 | TrainAcc=0.9487
# Fold 19 Epoch 200: TotalLoss=0.078160 | Sup=0.075172 | Recon=0.001494 | TrainAcc=1.0000
# Fold 19 Epoch 300: TotalLoss=0.030899 | Sup=0.028990 | Recon=0.000955 | TrainAcc=1.0000
# Fold 19 Epoch 400: TotalLoss=0.015467 | Sup=0.014042 | Recon=0.000713 | TrainAcc=1.0000
# Fold 19 Epoch 500: TotalLoss=0.008855 | Sup=0.007654 | Recon=0.000601 | TrainAcc=1.0000
# Fold 19 Epoch 600: TotalLoss=0.005731 | Sup=0.004708 | Recon=0.000511 | TrainAcc=1.0000
# Fold 19 Epoch 700: TotalLoss=0.004226 | Sup=0.003337 | Recon=0.000444 | TrainAcc=1.0000
# Fold 19 Epoch 800: TotalLoss=0.002988 | Sup=0.002226 | Recon=0.000381 | TrainAcc=1.0000
# Fold 19 Epoch 900: TotalLoss=0.002126 | Sup=0.001470 | Recon=0.000328 | TrainAcc=1.0000
# Fold 19 Epoch 1000: TotalLoss=0.001701 | Sup=0.001126 | Recon=0.000287 | TrainAcc=1.0000
# Fold 19 Epoch 1100: TotalLoss=0.001318 | Sup=0.000782 | Recon=0.000268 | TrainAcc=1.0000
# Fold 19 Epoch 1200: TotalLoss=0.001022 | Sup=0.000565 | Recon=0.000228 | TrainAcc=1.0000
# Fold 19 Epoch 1300: TotalLoss=0.000893 | Sup=0.000476 | Recon=0.000209 | TrainAcc=1.0000
# Fold 19 Epoch 1400: TotalLoss=0.000792 | Sup=0.000417 | Recon=0.000187 | TrainAcc=1.0000
# Fold 19 Epoch 1500: TotalLoss=0.000755 | Sup=0.000412 | Recon=0.000171 | TrainAcc=1.0000
# Fold 19 Epoch 1600: TotalLoss=0.000535 | Sup=0.000226 | Recon=0.000155 | TrainAcc=1.0000
# Fold 19 Epoch 1700: TotalLoss=0.000503 | Sup=0.000218 | Recon=0.000143 | TrainAcc=1.0000
# Fold 19 Epoch 1800: TotalLoss=0.000459 | Sup=0.000189 | Recon=0.000135 | TrainAcc=1.0000
# Fold 19 Epoch 1900: TotalLoss=0.000466 | Sup=0.000200 | Recon=0.000133 | TrainAcc=1.0000
# Fold 19 Epoch 2000: TotalLoss=0.000378 | Sup=0.000147 | Recon=0.000115 | TrainAcc=1.0000
# Fold 19 → Acc=0.9254 | Prec=0.8667 | Rec=0.9630 | F1=0.9123 | AUC=0.9870 | CE Loss=0.2317
#
# === Fold 20 ===
# Train CN: 93, Train AD: 63
# Fold 20 Epoch 1: TotalLoss=0.727342 | Sup=0.646883 | Recon=0.040229 | TrainAcc=0.5962
# Fold 20 Epoch 100: TotalLoss=0.185921 | Sup=0.179610 | Recon=0.003156 | TrainAcc=0.9615
# Fold 20 Epoch 200: TotalLoss=0.063490 | Sup=0.060389 | Recon=0.001551 | TrainAcc=1.0000
# Fold 20 Epoch 300: TotalLoss=0.025133 | Sup=0.023273 | Recon=0.000930 | TrainAcc=1.0000
# Fold 20 Epoch 400: TotalLoss=0.013983 | Sup=0.012682 | Recon=0.000651 | TrainAcc=1.0000
# Fold 20 Epoch 500: TotalLoss=0.009130 | Sup=0.008062 | Recon=0.000534 | TrainAcc=1.0000
# Fold 20 Epoch 600: TotalLoss=0.005669 | Sup=0.004767 | Recon=0.000451 | TrainAcc=1.0000
# Fold 20 Epoch 700: TotalLoss=0.004023 | Sup=0.003178 | Recon=0.000422 | TrainAcc=1.0000
# Fold 20 Epoch 800: TotalLoss=0.002970 | Sup=0.002223 | Recon=0.000373 | TrainAcc=1.0000
# Fold 20 Epoch 900: TotalLoss=0.002381 | Sup=0.001734 | Recon=0.000323 | TrainAcc=1.0000
# Fold 20 Epoch 1000: TotalLoss=0.001742 | Sup=0.001141 | Recon=0.000300 | TrainAcc=1.0000
# Fold 20 Epoch 1100: TotalLoss=0.001570 | Sup=0.001015 | Recon=0.000278 | TrainAcc=1.0000
# Fold 20 Epoch 1200: TotalLoss=0.001097 | Sup=0.000616 | Recon=0.000241 | TrainAcc=1.0000
# Fold 20 Epoch 1300: TotalLoss=0.000978 | Sup=0.000538 | Recon=0.000220 | TrainAcc=1.0000
# Fold 20 Epoch 1400: TotalLoss=0.000815 | Sup=0.000419 | Recon=0.000198 | TrainAcc=1.0000
# Fold 20 Epoch 1500: TotalLoss=0.000689 | Sup=0.000332 | Recon=0.000179 | TrainAcc=1.0000
# Fold 20 Epoch 1600: TotalLoss=0.000522 | Sup=0.000211 | Recon=0.000156 | TrainAcc=1.0000
# Fold 20 Epoch 1700: TotalLoss=0.000539 | Sup=0.000251 | Recon=0.000144 | TrainAcc=1.0000
# Fold 20 Epoch 1800: TotalLoss=0.000442 | Sup=0.000174 | Recon=0.000134 | TrainAcc=1.0000
# Fold 20 Epoch 1900: TotalLoss=0.000409 | Sup=0.000160 | Recon=0.000124 | TrainAcc=1.0000
# Fold 20 Epoch 2000: TotalLoss=0.000373 | Sup=0.000139 | Recon=0.000117 | TrainAcc=1.0000
# Fold 20 → Acc=0.9403 | Prec=0.8710 | Rec=1.0000 | F1=0.9310 | AUC=0.9731 | CE Loss=0.2893
#
# === Average Results Across 20 Folds ===
# Accuracy:  0.9522 ± 0.0214
# Precision: 0.9352 ± 0.0447
# Recall:    0.9500 ± 0.0357
# F1-score:  0.9415 ± 0.0259
# CE Loss:   0.1935 ± 0.1019
# AUC:       0.9871 ± 0.0108

# %%
feats_dim = num_feats
hidden_dim = 512
num_classes = 2
num_epochs = 2000
lr = 1e-4
weight_decay = 1e-4
batch_print_freq = 100

# Lambda values to test
lambda_list = [0.001, 0.005, 0.009, 0.01, 0.05, 0.09, 0.1, 0.3, 0.5, 0.9, 1, 2, 5, 8]

# === Cross-validation setup ===
sss = StratifiedShuffleSplit(n_splits=20, test_size=0.3, random_state=42)
y_all = y.copy()

# To store all results for each lambda
lambda_results = []

# === Outer loop for lambda sweep ===
for lambda_recon in lambda_list:
    print(f"\n\n====================== λ_recon = {lambda_recon} ======================")

    accuracies, precisions, recalls, f1_scores, aucs, ce_losses = [], [], [], [], [], []

    for fold, (train_val_idx, test_idx_global) in enumerate(sss.split(X, y_all), start=1):
        print(f"\n=== Fold {fold} ===")

        control_idx = np.where(y_all == 0)[0]
        patient_idx = np.where(y_all == 1)[0]
        sss_class = StratifiedShuffleSplit(n_splits=20, test_size=0.3, random_state=fold)
        control_train_idx, _ = next(sss_class.split(X[control_idx], y_all[control_idx]))
        patient_train_idx, _ = next(sss_class.split(X[patient_idx], y_all[patient_idx]))
        control_train = control_idx[control_train_idx]
        patient_train = patient_idx[patient_train_idx]
        train_idx_final = np.concatenate([control_train, patient_train])
        np.random.shuffle(train_idx_final)

        print(f"Train Control: {len(control_train)}, Train Patient: {len(patient_train)}")

        train_idx_t = torch.from_numpy(train_idx_final).long().to(device)
        y_train_tensor = torch.from_numpy(y_all[train_idx_final]).long().to(device)

        model = ARMA_AE(feats_dim, hidden_dim, num_classes, device, activ="RELU", dropout=0.25).to(device)
        optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
        ce_loss_fn = nn.CrossEntropyLoss()
        recon_loss_fn = nn.MSELoss()
        data = load_data(W, X).to(device)

        for epoch in range(1, num_epochs + 1):
            model.train()
            optimizer.zero_grad()
            logits, recon_x, _ = model(data.x, data.edge_index)

            loss_sup = ce_loss_fn(logits[train_idx_t], y_train_tensor)
            loss_recon = recon_loss_fn(recon_x, data.x)
            total_loss = loss_sup + lambda_recon * loss_recon

            if torch.isnan(total_loss) or torch.isinf(total_loss):
                print(f"NaN/Inf detected at fold {fold} epoch {epoch}. Aborting epoch.")
                break

            total_loss.backward()
            optimizer.step()

            if epoch % batch_print_freq == 0 or epoch == 1:
                model.eval()
                with torch.no_grad():
                    logits_eval, _, _ = model(data.x, data.edge_index)
                    preds_train = logits_eval[train_idx_t].argmax(dim=1)
                    acc_train = accuracy_score(y_train_tensor.cpu(), preds_train.cpu())
                print(f"Fold {fold} Epoch {epoch}: TotalLoss={total_loss.item():.6f} | Sup={loss_sup.item():.6f} | Recon={loss_recon.item():.6f} | TrainAcc={acc_train:.4f}")

        # === Evaluation ===
        model.eval()
        with torch.no_grad():
            out_logits, _, _ = model(data.x, data.edge_index)
            preds = out_logits.argmax(dim=1).cpu().numpy()
            probs = nnFn.softmax(out_logits, dim=1)[:, 1].cpu().numpy()

        y_test = y_all[test_idx_global]
        y_pred_test = preds[test_idx_global]
        y_prob_test = probs[test_idx_global]

        acc = accuracy_score(y_test, y_pred_test)
        prec = precision_score(y_test, y_pred_test, zero_division=0)
        rec = recall_score(y_test, y_pred_test, zero_division=0)
        f1 = f1_score(y_test, y_pred_test, zero_division=0)
        try:
            auc = roc_auc_score(y_test, y_prob_test)
        except ValueError:
            auc = float('nan')
        ce = log_loss(y_test, y_prob_test)

        accuracies.append(acc)
        precisions.append(prec)
        recalls.append(rec)
        f1_scores.append(f1)
        aucs.append(auc)
        ce_losses.append(ce)

        print(f"Fold {fold} → Acc={acc:.4f} | Prec={prec:.4f} | Rec={rec:.4f} | F1={f1:.4f} | AUC={auc:.4f} | CE Loss={ce:.4f}")

    # === Store average results for this λ ===
    avg_results = {
        "lambda": lambda_recon,
        "Accuracy": np.mean(accuracies),
        "Precision": np.mean(precisions),
        "Recall": np.mean(recalls),
        "F1-score": np.mean(f1_scores),
        "CE Loss": np.mean(ce_losses),
        "AUC": np.nanmean(aucs)
    }
    lambda_results.append(avg_results)

    print("\n=== Average Results for λ =", lambda_recon, "===")
    print(f"Accuracy:  {avg_results['Accuracy']:.4f}")
    print(f"Precision: {avg_results['Precision']:.4f}")
    print(f"Recall:    {avg_results['Recall']:.4f}")
    print(f"F1-score:  {avg_results['F1-score']:.4f}")
    print(f"CE Loss:   {avg_results['CE Loss']:.4f}")
    print(f"AUC:       {avg_results['AUC']:.4f}")


# === FINAL SUMMARY ACROSS ALL λ ===
print("\n\n====================== FINAL SUMMARY ACROSS ALL λ ======================")
print(f"{'Lambda':<8} | {'Accuracy':<9} | {'Precision':<9} | {'Recall':<8} | {'F1-score':<9} | {'AUC':<8} | {'CE Loss':<8}")
print("-" * 72)
for res in lambda_results:
    print(f"{res['lambda']:<8} | {res['Accuracy']:<9.4f} | {res['Precision']:<9.4f} | {res['Recall']:<8.4f} | {res['F1-score']:<9.4f} | {res['AUC']:<8.4f} | {res['CE Loss']:<8.4f}")
# Out:
# Streaming output truncated to the last 5000 lines.
# === Fold 6 ===
# Train Control: 93, Train Patient: 63
# Fold 6 Epoch 1: TotalLoss=0.798377 | Sup=0.796564 | Recon=0.036253 | TrainAcc=0.4231
# Fold 6 Epoch 100: TotalLoss=0.201800 | Sup=0.201611 | Recon=0.003775 | TrainAcc=0.9551
# Fold 6 Epoch 200: TotalLoss=0.069460 | Sup=0.069382 | Recon=0.001568 | TrainAcc=1.0000
# Fold 6 Epoch 300: TotalLoss=0.026920 | Sup=0.026879 | Recon=0.000832 | TrainAcc=1.0000
# Fold 6 Epoch 400: TotalLoss=0.012256 | Sup=0.012229 | Recon=0.000536 | TrainAcc=1.0000
# Fold 6 Epoch 500: TotalLoss=0.006733 | Sup=0.006712 | Recon=0.000429 | TrainAcc=1.0000
# Fold 6 Epoch 600: TotalLoss=0.005634 | Sup=0.005614 | Recon=0.000410 | TrainAcc=1.0000
# Fold 6 Epoch 700: TotalLoss=0.003106 | Sup=0.003085 | Recon=0.000417 | TrainAcc=1.0000
# Fold 6 Epoch 800: TotalLoss=0.002007 | Sup=0.001986 | Recon=0.000429 | TrainAcc=1.0000
# Fold 6 Epoch 900: TotalLoss=0.001194 | Sup=0.001172 | Recon=0.000434 | TrainAcc=1.0000
# Fold 6 Epoch 1000: TotalLoss=0.000928 | Sup=0.000906 | Recon=0.000450 | TrainAcc=1.0000
# Fold 6 Epoch 1100: TotalLoss=0.000650 | Sup=0.000627 | Recon=0.000460 | TrainAcc=1.0000
# Fold 6 Epoch 1200: TotalLoss=0.000565 | Sup=0.000542 | Recon=0.000461 | TrainAcc=1.0000
# Fold 6 Epoch 1300: TotalLoss=0.000376 | Sup=0.000353 | Recon=0.000459 | TrainAcc=1.0000
# Fold 6 Epoch 1400: TotalLoss=0.000297 | Sup=0.000274 | Recon=0.000463 | TrainAcc=1.0000
# Fold 6 Epoch 1500: TotalLoss=0.000238 | Sup=0.000215 | Recon=0.000459 | TrainAcc=1.0000
# Fold 6 Epoch 1600: TotalLoss=0.000196 | Sup=0.000173 | Recon=0.000464 | TrainAcc=1.0000
# Fold 6 Epoch 1700: TotalLoss=0.000185 | Sup=0.000162 | Recon=0.000460 | TrainAcc=1.0000
# Fold 6 Epoch 1800: TotalLoss=0.000144 | Sup=0.000121 | Recon=0.000466 | TrainAcc=1.0000
# Fold 6 Epoch 1900: TotalLoss=0.000142 | Sup=0.000119 | Recon=0.000466 | TrainAcc=1.0000
# Fold 6 Epoch 2000: TotalLoss=0.000139 | Sup=0.000116 | Recon=0.000468 | TrainAcc=1.0000
# Fold 6 → Acc=0.9701 | Prec=1.0000 | Rec=0.9259 | F1=0.9615 | AUC=0.9963 | CE Loss=0.1208
#
# === Fold 7 ===
# Train Control: 93, Train Patient: 63
# Fold 7 Epoch 1: TotalLoss=0.779245 | Sup=0.777491 | Recon=0.035079 | TrainAcc=0.3974
# Fold 7 Epoch 100: TotalLoss=0.208594 | Sup=0.208405 | Recon=0.003794 | TrainAcc=0.9551
# Fold 7 Epoch 200: TotalLoss=0.069659 | Sup=0.069581 | Recon=0.001556 | TrainAcc=1.0000
# Fold 7 Epoch 300: TotalLoss=0.026863 | Sup=0.026822 | Recon=0.000809 | TrainAcc=1.0000
# Fold 7 Epoch 400: TotalLoss=0.014701 | Sup=0.014674 | Recon=0.000539 | TrainAcc=1.0000
# Fold 7 Epoch 500: TotalLoss=0
| TrainAcc=1.0000
# Fold 13 Epoch 1100: TotalLoss=0.001241 | Sup=0.001219 | Recon=0.000445 | TrainAcc=1.0000
# Fold 13 Epoch 1200: TotalLoss=0.000980 | Sup=0.000957 | Recon=0.000453 | TrainAcc=1.0000
# Fold 13 Epoch 1300: TotalLoss=0.000806 | Sup=0.000783 | Recon=0.000454 | TrainAcc=1.0000
# Fold 13 Epoch 1400: TotalLoss=0.000603 | Sup=0.000580 | Recon=0.000458 | TrainAcc=1.0000
# Fold 13 Epoch 1500: TotalLoss=0.000454 | Sup=0.000432 | Recon=0.000452 | TrainAcc=1.0000
# Fold 13 Epoch 1600: TotalLoss=0.000483 | Sup=0.000460 | Recon=0.000457 | TrainAcc=1.0000
# Fold 13 Epoch 1700: TotalLoss=0.000381 | Sup=0.000358 | Recon=0.000456 | TrainAcc=1.0000
# Fold 13 Epoch 1800: TotalLoss=0.000286 | Sup=0.000263 | Recon=0.000462 | TrainAcc=1.0000
# Fold 13 Epoch 1900: TotalLoss=0.000355 | Sup=0.000332 | Recon=0.000466 | TrainAcc=1.0000
# Fold 13 Epoch 2000: TotalLoss=0.000235 | Sup=0.000211 | Recon=0.000462 | TrainAcc=1.0000
# Fold 13 → Acc=0.9701 | Prec=0.9310 | Rec=1.0000 | F1=0.9643 | AUC=0.9991 | CE Loss=0.0549
#
# === Fold 14 ===
# Train Control: 93, Train Patient: 63
# Fold 14 Epoch 1: TotalLoss=0.741172 | Sup=0.739363 | Recon=0.036196 | TrainAcc=0.5962
# Fold 14 Epoch 100: TotalLoss=0.213357 | Sup=0.213162 | Recon=0.003918 | TrainAcc=0.9551
# Fold 14 Epoch 200: TotalLoss=0.069963 | Sup=0.069877 | Recon=0.001726 | TrainAcc=1.0000
# Fold 14 Epoch 300: TotalLoss=0.025561 | Sup=0.025517 | Recon=0.000882 | TrainAcc=1.0000
# Fold 14 Epoch 400: TotalLoss=0.012212 | Sup=0.012185 | Recon=0.000543 | TrainAcc=1.0000
# Fold 14 Epoch 500: TotalLoss=0.007825 | Sup=0.007803 | Recon=0.000440 | TrainAcc=1.0000
# Fold 14 Epoch 600: TotalLoss=0.004969 | Sup=0.004949 | Recon=0.000408 | TrainAcc=1.0000
# Fold 14 Epoch 700: TotalLoss=0.003468 | Sup=0.003448 | Recon=0.000406 | TrainAcc=1.0000
# Fold 14 Epoch 800: TotalLoss=0.002277 | Sup=0.002255 | Recon=0.000428 | TrainAcc=1.0000
# Fold 14 Epoch 900: TotalLoss=0.001679 | Sup=0.001657 | Recon=0.000440 | TrainAcc=1.0000
# Fold 14 Epoch 1000: TotalLoss=0.000930 | Sup=0.000907 | Recon=0.000448 | TrainAcc=1.0000
# Fold 14 Epoch 1100: TotalLoss=0.000789 | Sup=0.000766 | Recon=0.000452 | TrainAcc=1.0000
# Fold 14 Epoch 1200: TotalLoss=0.000534 | Sup=0.000512 | Recon=0.000453 | TrainAcc=1.0000
# Fold 14 Epoch 1300: TotalLoss=0.000363 | Sup=0.000340 | Recon=0.000457 | TrainAcc=1.0000
# Fold 14 Epoch 1400: TotalLoss=0.000351 | Sup=0.000327 | Recon=0.000468 | TrainAcc=1.0000
# Fold 14 Epoch 1500: TotalLoss=0.000328 | Sup=0.000305 | Recon=0.000472 | TrainAcc=1.0000
# Fold 14 Epoch 1600: TotalLoss=0.000208 | Sup=0.000184 | Recon=0.000464 | TrainAcc=1.0000
# Fold 14 Epoch 1700: TotalLoss=0.000251 | Sup=0.000228 | Recon=0.000466 | TrainAcc=1.0000
# Fold 14 Epoch 1800: TotalLoss=0.000184 | Sup=0.000160 | Recon=0.000476 | TrainAcc=1.0000
# Fold 14 Epoch 1900: TotalLoss=0.000158 | Sup=0.000134 | Recon=0.000472 | TrainAcc=1.0000
# Fold 14 Epoch 2000: TotalLoss=0.000143 | Sup=0.000119 | Recon=0.000470 | TrainAcc=1.0000
# Fold 14 → Acc=0.9552 | Prec=1.0000 | Rec=0.8889 | F1=0.9412 | AUC=0.9824 | CE Loss=0.2300
#
# === Fold 15 ===
# Train Control: 93, Train Patient: 63
# Fold 15 Epoch 1: TotalLoss=0.855065 | Sup=0.853271 | Recon=0.035879 | TrainAcc=0.5833
# Fold 15 Epoch 100: TotalLoss=0.186085 | Sup=0.185911 | Recon=0.003477 | TrainAcc=0.9615
# Fold 15 Epoch 200: TotalLoss=0.069414 | Sup=0.069338 | Recon=0.001536 | TrainAcc=1.0000
# Fold 15 Epoch 300: TotalLoss=0.025453 | Sup=0.025412 | Recon=0.000809 | TrainAcc=1.0000
# Fold 15 Epoch 400: TotalLoss=0.012234 | Sup=0.012208 | Recon=0.000522 | TrainAcc=1.0000
# Fold 15 Epoch 500: TotalLoss=0.007336 | Sup=0.007315 | Recon=0.000423 | TrainAcc=1.0000
# Fold 15 Epoch 600: TotalLoss=0.004106 | Sup=0.004086 | Recon=0.000409 | TrainAcc=1.0000
# Fold 15 Epoch 700: TotalLoss=0.002528 | Sup=0.002508 | Recon=0.000415 | TrainAcc=1.0000
# Fold 15 Epoch 800: TotalLoss=0.001781 | Sup=0.001759 | Recon=0.000437 | TrainAcc=1.0000
# Fold 15 Epoch 900: TotalLoss=0.001130 | Sup=0.001108 | Recon=0.000448 | TrainAcc=1.0000
# Fold 15 Epoch 1000: TotalLoss=0.000820 | Sup=0.000797 | Recon=0.000452 | TrainAcc=1.0000
# Fold 15 Epoch 1100: TotalLoss=0.000597 | Sup=0.000574 | Recon=0.000456 | TrainAcc=1.0000
# Fold 15 Epoch 1200: TotalLoss=0.000407 | Sup=0.000384 | Recon=0.000454 | TrainAcc=1.0000
# Fold 15 Epoch 1300: TotalLoss=0
| TrainAcc=1.0000
# Fold 19 Epoch 1900: TotalLoss=0.000184 | Sup=0.000161 | Recon=0.000467 | TrainAcc=1.0000
# Fold 19 Epoch 2000: TotalLoss=0.000162 | Sup=0.000138 | Recon=0.000470 | TrainAcc=1.0000
# Fold 19 → Acc=0.9254 | Prec=0.8667 | Rec=0.9630 | F1=0.9123 | AUC=0.9880 | CE Loss=0.2573
#
# === Fold 20 ===
# Train Control: 93, Train Patient: 63
# Fold 20 Epoch 1: TotalLoss=0.687658 | Sup=0.685868 | Recon=0.035807 | TrainAcc=0.5962
# Fold 20 Epoch 100: TotalLoss=0.190886 | Sup=0.190697 | Recon=0.003789 | TrainAcc=0.9679
# Fold 20 Epoch 200: TotalLoss=0.059140 | Sup=0.059059 | Recon=0.001632 | TrainAcc=1.0000
# Fold 20 Epoch 300: TotalLoss=0.020350 | Sup=0.020310 | Recon=0.000814 | TrainAcc=1.0000
# Fold 20 Epoch 400: TotalLoss=0.011725 | Sup=0.011700 | Recon=0.000518 | TrainAcc=1.0000
# Fold 20 Epoch 500: TotalLoss=0.006632 | Sup=0.006610 | Recon=0.000435 | TrainAcc=1.0000
# Fold 20 Epoch 600: TotalLoss=0.004352 | Sup=0.004332 | Recon=0.000415 | TrainAcc=1.0000
# Fold 20 Epoch 700: TotalLoss=0.003036 | Sup=0.003015 | Recon=0.000430 | TrainAcc=1.0000
# Fold 20 Epoch 800: TotalLoss=0.001700 | Sup=0.001679 | Recon=0.000433 | TrainAcc=1.0000
# Fold 20 Epoch 900: TotalLoss=0.001403 | Sup=0.001381 | Recon=0.000448 | TrainAcc=1.0000
# Fold 20 Epoch 1000: TotalLoss=0.000953 | Sup=0.000930 | Recon=0.000453 | TrainAcc=1.0000
# Fold 20 Epoch 1100: TotalLoss=0.000688 | Sup=0.000665 | Recon=0.000458 | TrainAcc=1.0000
# Fold 20 Epoch 1200: TotalLoss=0.000606 | Sup=0.000583 | Recon=0.000464 | TrainAcc=1.0000
# Fold 20 Epoch 1300: TotalLoss=0.000455 | Sup=0.000431 | Recon=0.000463 | TrainAcc=1.0000
# Fold 20 Epoch 1400: TotalLoss=0.000324 | Sup=0.000301 | Recon=0.000468 | TrainAcc=1.0000
# Fold 20 Epoch 1500: TotalLoss=0.000299 | Sup=0.000275 | Recon=0.000470 | TrainAcc=1.0000
# Fold 20 Epoch 1600: TotalLoss=0.000253 | Sup=0.000229 | Recon=0.000476 | TrainAcc=1.0000
# Fold 20 Epoch 1700: TotalLoss=0.000235 | Sup=0.000212 | Recon=0.000471 | TrainAcc=1.0000
# Fold 20 Epoch 1800: TotalLoss=0.000201 | Sup=0.000178 | Recon=0.000468 | TrainAcc=1.0000
# Fold 20 Epoch 1900: TotalLoss=0.000212 | Sup=0.000188 | Recon=0.000470 | TrainAcc=1.0000
# Fold 20 Epoch 2000: TotalLoss=0.000184 | Sup=0.000160 | Recon=0.000469 | TrainAcc=1.0000
# Fold 20 → Acc=0.9403 | Prec=0.8710 | Rec=1.0000 | F1=0.9310 | AUC=0.9722 | CE Loss=0.2953
#
# === Average Results for λ = 0.05 ===
# Accuracy:  0.9463
# Precision: 0.9263
# Recall:    0.9444
# F1-score:  0.9341
# CE Loss:   0.1913
# AUC:       0.9867
#
#
# ====================== λ_recon = 0.09 ======================
#
# === Fold 1 ===
# Train Control: 93, Train Patient: 63
# Fold 1 Epoch 1: TotalLoss=0.706870 | Sup=0.703278 | Recon=0.039912 | TrainAcc=0.4038
# Fold 1 Epoch 100: TotalLoss=0.201121 | Sup=0.200804 | Recon=0.003516 | TrainAcc=0.9487
# Fold 1 Epoch 200: TotalLoss=0.063567 | Sup=0.063430 | Recon=0.001526 | TrainAcc=1.0000
# Fold 1 Epoch 300: TotalLoss=0.023930 | Sup=0.023854 | Recon=0.000837 | TrainAcc=1.0000
# Fold 1 Epoch 400: TotalLoss=0.012880 | Sup=0.012830 | Recon=0.000555 | TrainAcc=1.0000
# Fold 1 Epoch 500: TotalLoss=0.007741 | Sup=0.007703 | Recon=0.000420 | TrainAcc=1.0000
# Fold 1 Epoch 600: TotalLoss=0.005340 | Sup=0.005308 | Recon=0.000364 | TrainAcc=1.0000
# Fold 1 Epoch 700: TotalLoss=0.003316 | Sup=0.003285 | Recon=0.000341 | TrainAcc=1.0000
# Fold 1 Epoch 800: TotalLoss=0.002694 | Sup=0.002663 | Recon=0.000346 | TrainAcc=1.0000
# Fold 1 Epoch 900: TotalLoss=0.001632 | Sup=0.001600 | Recon=0.000353 | TrainAcc=1.0000
# Fold 1 Epoch 1000: TotalLoss=0.001276 | Sup=0.001244 | Recon=0.000359 | TrainAcc=1.0000
# Fold 1 Epoch 1100: TotalLoss=0.001015 | Sup=0.000982 | Recon=0.000365 | TrainAcc=1.0000
# Fold 1 Epoch 1200: TotalLoss=0.000788 | Sup=0.000755 | Recon=0.000370 | TrainAcc=1.0000
# Fold 1 Epoch 1300: TotalLoss=0.000809 | Sup=0.000774 | Recon=0.000380 | TrainAcc=1.0000
# Fold 1 Epoch 1400: TotalLoss=0.000569 | Sup=0.000534 | Recon=0.000388 | TrainAcc=1.0000
# Fold 1 Epoch 1500: TotalLoss=0.000605 | Sup=0.000570 | Recon=0.000385 | TrainAcc=1.0000
# Fold 1 Epoch 1600: TotalLoss=0.000454 | Sup=0.000418 | Recon=0.000390 | TrainAcc=1.0000
# Fold 1 Epoch 1700: TotalLoss=0.000340 | Sup=0.000305 | Recon=0.000392 | TrainAcc=1.0000
# Fold 1 Epoch 1800: TotalLoss=0.000422 | Sup=0.000387 | Recon=0.000392 | TrainAcc=1.0000
# Fold 1 Epoch 1900: TotalLoss=0.000316 | Sup=0.000281 | Recon=0.000390 | TrainAcc=1.0000
# Fold 1 Epoch 2000: TotalLoss=0.000308 | Sup=0.000272 | Recon=0.000399 | TrainAcc=1.0000
# Fold 1 → Acc=0.9254 | Prec=0.8667 | Rec=0.9630 | F1=0.9123 | AUC=0.9676 | CE Loss=0.3764
#
# === Fold 2 ===
# Train Control: 93, Train Patient: 63
# Fold 2 Epoch 1: TotalLoss=0.734416 | Sup=0.730603 | Recon=0.042368 | TrainAcc=0.7051
# Fold 2 Epoch 100: TotalLoss=0.213218 | Sup=0.212900 | Recon=0.003543 | TrainAcc=0.9487
# Fold 2 Epoch 200: TotalLoss=0.069283 | Sup=0.069134 | Recon=0.001656 | TrainAcc=1.0000
# Fold 2 Epoch 300: TotalLoss=0.029348 | Sup=0.029270 | Recon=0.000873 | TrainAcc=1.0000
# Fold 2 Epoch 400: TotalLoss=0.013709 | Sup=0.013656 | Recon=0.000589 | TrainAcc=1.0000
# Fold 2 Epoch 500: TotalLoss=0.007688 | Sup=0.007650 | Recon=0.000427 | TrainAcc=1.0000
# Fold 2 Epoch 600: TotalLoss=0.005619 | Sup=0.005584 | Recon=0.000385 | TrainAcc=1.0000
# Fold 2 Epoch 700: TotalLoss=0.004282 | Sup=0.004250 | Recon=0.000357 | TrainAcc=1.0000
# Fold 2 Epoch 800: TotalLoss=0.002632 | Sup=0.002600 | Recon=0.000349 | TrainAcc=1.0000
# Fold 2 Epoch 900: TotalLoss=0.002030 | Sup=0.001998 | Recon=0.000357 | TrainAcc=1.0000
# Fold 2 Epoch 1000: TotalLoss=0.001408 | Sup=0.001376 | Recon=0.000356 | TrainAcc=1.0000
# Fold 2 Epoch 1100: TotalLoss=0.001155 | Sup=0.001122 | Recon=0.000366 | TrainAcc=1.0000
# Fold 2 Epoch 1200: TotalLoss=0.001141 | Sup=0.001106 | Recon=0.000379 | TrainAcc=1.0000
# Fold 2 Epoch 1300: TotalLoss=0.000659 | Sup=0.000625 | Recon=0.000377 | TrainAcc=1.0000
# Fold 2 Epoch 1400: TotalLoss=0.000459 | Sup=0.000425 | Recon=0.000383 | TrainAcc=1.0000
# Fold 2 Epoch 1500: TotalLoss=0.000477 | Sup=0.000442 | Recon=0.000389 | TrainAcc=1.0000
# Fold 2 Epoch 1600: TotalLoss=0.000330 | Sup=0.000294 | Recon=0.000390 | TrainAcc=1.0000
# Fold 2 Epoch 1700: TotalLoss=0.000339 | Sup=0.000304 | Recon=0.000391 | TrainAcc=1.0000
# Fold 2 Epoch 1800: TotalLoss=0.000309 | Sup=0.000273 | Recon=0.000390 | TrainAcc=1.0000
# Fold 2 Epoch 1900: TotalLoss=0.000248 | Sup=0.000212 | Recon=0.000400 | TrainAcc=1.0000
# Fold 2 Epoch 2000: TotalLoss=0.000235 | Sup=0.000199 | Recon=0.000396 | TrainAcc=1.0000
# Fold 2 → Acc=0.9552 | Prec=0.9286 | Rec=0.9630 | F1=0.9455 | AUC=0.9880 | CE Loss=0.1737
#
# === Fold 3 ===
# Train Control: 93, Train Patient: 63
# Fold 3 Epoch 1: TotalLoss=0.665136 | Sup=0.661487 | Recon=0.040547 | TrainAcc=0.5962
# Fold 3 Epoch 100: TotalLoss=0.194934 | Sup=0.194609 | Recon=0.003613 | TrainAcc=0.9615
# Fold 3 Epoch 200: TotalLoss=0.062526 | Sup=0.062382 | Recon=0.001604 | TrainAcc=1.0000
# Fold 3 Epoch 300: TotalLoss=0.027248 | Sup=0.027167 | Recon=0.000894 | TrainAcc=1.0000
# Fold 3 Epoch 400: TotalLoss=0.012617 | Sup=0.012568 | Recon=0.000544 | TrainAcc=1.0000
# Fold 3 Epoch 500: TotalLoss=0.007344 | Sup=0.007306 | Recon=0.000413 | TrainAcc=1.0000
# Fold 3 Epoch 600: TotalLoss=0.004743 | Sup=0.004711 | Recon=0.000355 | TrainAcc=1.0000
# Fold 3 Epoch 700: TotalLoss=0.003951 | Sup=0.003919 | Recon=0.000350 | TrainAcc=1.0000
# Fold 3 Epoch 800: TotalLoss=0.002290 | Sup=0.002259 | Recon=0.000342 | TrainAcc=1.0000
# Fold 3 Epoch 900: TotalLoss=0.001451 | Sup=0.001419 | Recon=0.000350 | TrainAcc=1.0000
# Fold 3 Epoch 1000: TotalLoss=0.001009 | Sup=0.000977 | Recon=0.000360 | TrainAcc=1.0000
# Fold 3 Epoch 1100: TotalLoss=0.000791 | Sup=0.000758 | Recon=0.000370 | TrainAcc=1.0000
# Fold 3 Epoch 1200: TotalLoss=0.000621 | Sup=0.000587 | Recon=0.000372 | TrainAcc=1.0000
# Fold 3 Epoch 1300: TotalLoss=0.000423 | Sup=0.000390 | Recon=0.000372 | TrainAcc=1.0000
# Fold 3 Epoch 1400: TotalLoss=0.000402 | Sup=0.000368 | Recon=0.000382 | TrainAcc=1.0000
# Fold 3 Epoch 1500: TotalLoss=0.000338 | Sup=0.000302 | Recon=0.000390 | TrainAcc=1.0000
# Fold 3 Epoch 1600: TotalLoss=0.000265 | Sup=0.000230 | Recon=0.000391 | TrainAcc=1.0000
# Fold 3 Epoch 1700: TotalLoss=0.000269 | Sup=0.000233 | Recon=0.000394 | TrainAcc=1.0000
# Fold 3 Epoch 1800: TotalLoss=0.000205 | Sup=0.000170 | Recon=0.000393 | TrainAcc=1.0000
# Fold 3 Epoch 1900: TotalLoss=0.000184 | Sup=0.000149 | Recon=0.000388 | TrainAcc=1.0000
# Fold 3 Epoch 2000: TotalLoss=0.000154 | Sup=0.000118 | Recon=0.000396 | TrainAcc=1.0000
# Fold 3 → Acc=0.9851 | Prec=1.0000 | Rec=0.9630 | F1=0.9811 | AUC=0.9898 | CE Loss=0.1265
#
# === Fold 4 ===
# Train Control: 93, Train Patient: 63
# Fold 4 Epoch 1: TotalLoss=0.705638 | Sup=0.702400 | Recon=0.035971 | TrainAcc=0.5962
# Fold 4 Epoch 100: TotalLoss=0.169321 | Sup=0.169008 | Recon=0.003480 | TrainAcc=0.9679
# Fold 4 Epoch 200: TotalLoss=0.058858 | Sup=0.058727 | Recon=0.001458 | TrainAcc=1.0000
# Fold 4 Epoch 300: TotalLoss=0.020605 | Sup=0.020531 | Recon=0.000825 | TrainAcc=1.0000
# Fold 4 Epoch 400: TotalLoss=0.013207 | Sup=0.013160 | Recon=0.000526 | TrainAcc=1.0000
# Fold 4 Epoch 500: TotalLoss=0.006735 | Sup=0.006700 | Recon=0.000397 | TrainAcc=1.0000
# Fold 4 Epoch 600: TotalLoss=0.004932 | Sup=0.004900 | Recon=0.000357 | TrainAcc=1.0000
# Fold 4 Epoch 700: TotalLoss=0.003493 | Sup=0.003462 | Recon=0.000339 | TrainAcc=1.0000
# Fold 4 Epoch 800: TotalLoss=0.002435 | Sup=0.002404 | Recon=0.000345 | TrainAcc=1.0000
# Fold 4 Epoch 900: TotalLoss=0.001516 | Sup=0.001484 | Recon=0.000356 | TrainAcc=1.0000
# Fold 4 Epoch 1000: TotalLoss=0.001158 | Sup=0.001126 | Recon=0.000358 | TrainAcc=1.0000
# Fold 4 Epoch 1100: TotalLoss=0.000799 | Sup=0.000766 | Recon=0.000367 | TrainAcc=1.0000
# Fold 4 Epoch 1200: TotalLoss=0.000709 | Sup=0.000676 | Recon=0.000371 | TrainAcc=1.0000
# Fold 4 Epoch 1300: TotalLoss=0.000624 | Sup=0.000589 | Recon=0.000386 | TrainAcc=1.0000
# Fold 4 Epoch 1400: TotalLoss=0.000423 | Sup=0.000389 | Recon=0.000382 | TrainAcc=1.0000
# Fold 4 Epoch 1500: TotalLoss=0.000413 | Sup=0.000378 | Recon=0.000387 | TrainAcc=1.0000
# Fold 4 Epoch 1600: TotalLoss=0.000327 | Sup=0.000291 | Recon=0.000391 | TrainAcc=1.0000
# Fold 4 Epoch 1700: TotalLoss=0.000258 | Sup=0.000222 | Recon=0.000391 | TrainAcc=1.0000
# Fold 4 Epoch 1800: TotalLoss=0.000271 | Sup=0.000235 | Recon=0.000395 | TrainAcc=1.0000
# Fold 4 Epoch 1900: TotalLoss=0.000231 | Sup=0.000196 | Recon=0.000396 | TrainAcc=1.0000
# Fold 4 Epoch 2000: TotalLoss=0.000172 | Sup=0.000136 | Recon=0.000401 | TrainAcc=1.0000
# Fold 4 → Acc=0.9552 | Prec=0.9286 | Rec=0.9630 | F1=0.9455 | AUC=0.9880 | CE Loss=0.1725
#
# === Fold 5 ===
# Train Control: 93, Train Patient: 63
# Fold 5 Epoch 1: TotalLoss=0.684468 | Sup=0.680494 | Recon=0.044153 | TrainAcc=0.5962
# Fold 5 Epoch 100: TotalLoss=0.198572 | Sup=0.198222 | Recon=0.003885 | TrainAcc=0.9679
# Fold 5 Epoch 200: TotalLoss=0.060916 | Sup=0.060764 | Recon=0.001689 | TrainAcc=1.0000
# Fold 5 Epoch 300: TotalLoss=0.023255 | Sup=0.023174 | Recon=0.000901 | TrainAcc=1.0000
# Fold 5 Epoch 400: TotalLoss=0.011099 | Sup=0.011047 | Recon=0.000578 | TrainAcc=1.0000
# Fold 5 Epoch 500: TotalLoss=0.007021 | Sup=0.006982 | Recon=0.000429 | TrainAcc=1.0000
# Fold 5 Epoch 600: TotalLoss=0.004536 | Sup=0.004502 | Recon=0.000381 | TrainAcc=1.0000
# Fold 5 Epoch 700: TotalLoss=0.002912 | Sup=0.002880 | Recon=0.000347 | TrainAcc=1.0000
# Fold 5 Epoch 800: TotalLoss=0.001915 | Sup=0.001884 | Recon=0.000346 | TrainAcc=1.0000
# Fold 5 Epoch 900: TotalLoss=0.001470 | Sup=0.001439 | Recon=0.000346 | TrainAcc=1.0000
# Fold 5 Epoch 1000: TotalLoss=0.001015 | Sup=0.000982 | Recon=0.000360 | TrainAcc=1.0000
# Fold 5 Epoch 1100: TotalLoss=0.000977 | Sup=0.000944 | Recon=0.000369 | TrainAcc=1.0000
# Fold 5 Epoch 1200: TotalLoss=0.000689 | Sup=0.000655 | Recon=0.000380 | TrainAcc=1.0000
# Fold 5 Epoch 1300: TotalLoss=0.000596 | Sup=0.000562 | Recon=0.000383 | TrainAcc=1.0000
# Fold 5 Epoch 1400: TotalLoss=0.000447 | Sup=0.000412 | Recon=0.000385 | TrainAcc=1.0000
# Fold 5 Epoch 1500: TotalLoss=0.000472 | Sup=0.000436 | Recon=0.000390 | TrainAcc=1.0000
# Fold 5 Epoch 1600: TotalLoss=0.000395 | Sup=0.000360 | Recon=0.000390 | TrainAcc=1.0000
# Fold 5 Epoch 1700: TotalLoss=0.000306 | Sup=0.000271 | Recon=0.000392 | TrainAcc=1.0000
# Fold 5 Epoch 1800: TotalLoss=0.000288 | Sup=0.000252 | Recon=0.000402 | TrainAcc=1.0000
# Fold 5 Epoch 1900: TotalLoss=0.000249 | Sup=0.000214 | Recon=0.000397 | TrainAcc=1.0000
# Fold 5 Epoch 2000: TotalLoss=0.000241 | Sup=0.000205 | Recon=0.000401 | TrainAcc=1.0000
# Fold 5 → Acc=0.9254 | Prec=0.8929 | Rec=0.9259 | F1=0.9091 | AUC=0.9935 | CE Loss=0.1298
#
# === Fold 6 ===
# Train Control: 93, Train Patient: 63
# Fold 6 Epoch 1: TotalLoss=0.763255 | Sup=0.759848 | Recon=0.037851 | TrainAcc=0.5962
# Fold 6 Epoch 100: TotalLoss=0.207580 | Sup=0.207288 | Recon=0.003243 | TrainAcc=0.9615
# Fold 6 Epoch 200: TotalLoss=0.072993 | Sup=0.072859 | Recon=0.001479 | TrainAcc=1.0000
# Fold 6 Epoch 300: TotalLoss=0.027207 | Sup=0.027133 | Recon=0.000815 | TrainAcc=1.0000
# Fold 6 Epoch 400: TotalLoss=0.013659 | Sup=0.013610 | Recon=0.000544 | TrainAcc=1.0000
# Fold 6 Epoch 500: TotalLoss=0.007769 | Sup=0.007733 | Recon=0.000402 | TrainAcc=1.0000
# Fold 6 Epoch 600: TotalLoss=0.005363 | Sup=0.005331 | Recon=0.000356 | TrainAcc=1.0000
# Fold 6 Epoch 700: TotalLoss=0.003545 | Sup=0.003514 | Recon=0.000347 | TrainAcc=1.0000
# Fold 6 Epoch 800: TotalLoss=0.001966 | Sup=0.001936 | Recon=0.000339 | TrainAcc=1.0000
# Fold 6 Epoch 900: TotalLoss=0.001579 | Sup=0.001547 | Recon=0.000356 | TrainAcc=1.0000
# Fold 6 Epoch 1000: TotalLoss=0.001221 | Sup=0.001188 | Recon=0.000363 | TrainAcc=1.0000
# Fold 6 Epoch 1100: TotalLoss=0.000962 | Sup=0.000929 | Recon=0.000367 | TrainAcc=1.0000
# Fold 6 Epoch 1200: TotalLoss=0.000869 | Sup=0.000835 | Recon=0.000374 | TrainAcc=1.0000
# Fold 6 Epoch 1300: TotalLoss=0.000596 | Sup=0.000562 | Recon=0.000382 | TrainAcc=1.0000
# Fold 6 Epoch 1400: TotalLoss=0.000491 | Sup=0.000456 | Recon=0.000385 | TrainAcc=1.0000
# Fold 6 Epoch 1500: TotalLoss=0.000406 | Sup=0.000371 | Recon=0.000388 | TrainAcc=1.0000
# Fold 6 Epoch 1600: TotalLoss=0.000342 | Sup=0.000307 | Recon=0.000390 | TrainAcc=1.0000
# Fold 6 Epoch 1700: TotalLoss=0.000270 | Sup=0.000235 | Recon=0.000392 | TrainAcc=1.0000
# Fold 6 Epoch 1800: TotalLoss=0.000211 | Sup=0.000176 | Recon=0.000391 | TrainAcc=1.0000
# Fold 6 Epoch 1900: TotalLoss=0.000226 | Sup=0.000191 | Recon=0.000394 | TrainAcc=1.0000
# Fold 6 Epoch 2000: TotalLoss=0.000201 | Sup=0.000166 | Recon=0.000386 | TrainAcc=1.0000
# Fold 6 → Acc=0.9851 | Prec=1.0000 | Rec=0.9630 | F1=0.9811 | AUC=0.9963 | CE Loss=0.1066
#
# === Fold 7 ===
# Train Control: 93, Train Patient: 63
# Fold 7 Epoch 1: TotalLoss=0.699919 | Sup=0.696234 | Recon=0.040953 | TrainAcc=0.6026
# Fold 7 Epoch 100: TotalLoss=0.202834 | Sup=0.202500 | Recon=0.003706 | TrainAcc=0.9551
# Fold 7 Epoch 200: TotalLoss=0.066856 | Sup=0.066714 | Recon=0.001573 | TrainAcc=1.0000
# Fold 7 Epoch 300: TotalLoss=0.026706 | Sup=0.026629 | Recon=0.000850 | TrainAcc=1.0000
# Fold 7 Epoch 400: TotalLoss=0.012469 | Sup=0.012419 | Recon=0.000555 | TrainAcc=1.0000
# Fold 7 Epoch 500: TotalLoss=0.007329 | Sup=0.007292 | Recon=0.000415 | TrainAcc=1.0000
# Fold 7 Epoch 600: TotalLoss=0.004701 | Sup=0.004669 | Recon=0.000359 | TrainAcc=1.0000
# Fold 7 Epoch 700: TotalLoss=0.003420 | Sup=0.003390 | Recon=0.000340 | TrainAcc=1.0000
# Fold 7 Epoch 800: TotalLoss=0.002526 | Sup=0.002495 | Recon=0.000342 | TrainAcc=1.0000
# Fold 7 Epoch 900: TotalLoss=0.001849 | Sup=0.001817 | Recon=0.000352 | TrainAcc=1.0000
# Fold 7 Epoch 1000: TotalLoss=0.001152 | Sup=0.001120 | Recon=0.000357 | TrainAcc=1.0000
# Fold 7 Epoch 1100: TotalLoss=0.000768 | Sup=0.000735 | Recon=0.000364 | TrainAcc=1.0000
# Fold 7 Epoch 1200: TotalLoss=0.000682 | Sup=0.000648 | Recon=0.000378 | TrainAcc=1.0000
# Fold 7 Epoch 1300: TotalLoss=0.000592 | Sup=0.000558 | Recon=0.000380 | TrainAcc=1.0000
# Fold 7 Epoch 1400: TotalLoss=0.000429 | Sup=0.000395 | Recon=0.000383 | TrainAcc=1.0000
# Fold 7 Epoch 1500: TotalLoss=0.000415 | Sup=0.000380 | Recon=0.000388 | TrainAcc=1.0000
# Fold 7 Epoch 1600: TotalLoss=0.000376 | Sup=0.000341 | Recon=0.000390 | TrainAcc=1.0000
# Fold 7 Epoch 1700: TotalLoss=0.000288 | Sup=0.000253 | Recon=0.000390 | TrainAcc=1.0000
# Fold 7 Epoch 1800: TotalLoss=0.000231 | Sup=0.000196 | Recon=0.000391 | TrainAcc=1.0000
# Fold 7 Epoch 1900: TotalLoss=0.000221 | Sup=0.000185 | Recon=0.000399 | TrainAcc=1.0000
# Fold 7 Epoch 2000: TotalLoss=0.000195 | Sup=0.000158 | Recon=0.000403 | TrainAcc=1.0000
# Fold 7 → Acc=0.9701 | Prec=1.0000 | Rec=0.9259 | F1=0.9615 | AUC=0.9963 | CE Loss=0.1720
#
# === Fold 8 ===
# Train Control: 93, Train Patient: 63
# Fold 8 Epoch 1: TotalLoss=0.681883 | Sup=0.678256 | Recon=0.040300 | TrainAcc=0.5962
# Fold 8 Epoch 100: TotalLoss=0.231651 | Sup=0.231321 | Recon=0.003672 | TrainAcc=0.9551
# Fold 8 Epoch 200: TotalLoss=0.067243 | Sup=0.067097 | Recon=0.001620 | TrainAcc=1.0000
# Fold 8 Epoch 300: TotalLoss=0.025704 | Sup=0.025625 | Recon=0.000885 | TrainAcc=1.0000
# Fold 8 Epoch 400: TotalLoss=0.012823 | Sup=0.012771 | Recon=0.000581 | TrainAcc=1.0000
# Fold 8 Epoch 500: TotalLoss=0.007074 | Sup=0.007036 | Recon=0.000431 | TrainAcc=1.0000
# Fold 8 Epoch 600: TotalLoss=0.004846 | Sup=0.004813 | Recon=0.000369 | TrainAcc=1.0000
# Fold 8 Epoch 700: TotalLoss=0.003206 | Sup=0.003174 | Recon=0.000359 | TrainAcc=1.0000
# Fold 8 Epoch 800: TotalLoss=0.002780 | Sup=0.002748 | Recon=0.000353 | TrainAcc=1.0000
# Fold 8 Epoch 900: TotalLoss=0.001700 | Sup=0.001668 | Recon=0.000361 | TrainAcc=1.0000
# Fold 8 Epoch 1000: TotalLoss=0.001209 | Sup=0.001176 | Recon=0.000367 | TrainAcc=1.0000
# Fold 8 Epoch 1100: TotalLoss=0.000964 | Sup=0.000930 | Recon=0.000380 | TrainAcc=1.0000
# Fold 8 Epoch 1200: TotalLoss=0.000787 | Sup=0.000752 | Recon=0.000385 | TrainAcc=1.0000
# Fold 8 Epoch 1300: TotalLoss=0.000674 | Sup=0.000639 | Recon=0.000394 | TrainAcc=1.0000
# Fold 8 Epoch 1400: TotalLoss=0.000433 | Sup=0.000397 | Recon=0.000400 | TrainAcc=1.0000
# Fold 8 Epoch 1500: TotalLoss=0.000329 | Sup=0.000294 | Recon=0.000397 | TrainAcc=1.0000
# Fold 8 Epoch 1600: TotalLoss=0.000312 | Sup=0.000276 | Recon=0.000400 | TrainAcc=1.0000
# Fold 8 Epoch 1700: TotalLoss=0.000258 | Sup=0.000222 | Recon=0.000404 | TrainAcc=1.0000
# Fold 8 Epoch 1800: TotalLoss=0.000253 | Sup=0.000217 | Recon=0.000406 | TrainAcc=1.0000
# Fold 8 Epoch 1900: TotalLoss=0.000216 | Sup=0.000180 | Recon=0.000401 | TrainAcc=1.0000
# Fold 8 Epoch 2000: TotalLoss=0.000204 | Sup=0.000168 | Recon=0.000404 | TrainAcc=1.0000
# Fold 8 → Acc=0.9552 | Prec=0.9615 | Rec=0.9259 | F1=0.9434 | AUC=0.9963 | CE Loss=0.1111
#
# === Fold 9 ===
# Train Control: 93, Train Patient: 63
# Fold 9 Epoch 1: TotalLoss=0.755837 | Sup=0.752392 | Recon=0.038280 | TrainAcc=0.5962
# Fold 9 Epoch 100: TotalLoss=0.217973 | Sup=0.217646 | Recon=0.003630 | TrainAcc=0.9487
# Fold 9 Epoch 200: TotalLoss=0.079041 | Sup=0.078893 | Recon=0.001643 | TrainAcc=1.0000
# Fold 9 Epoch 300: TotalLoss=0.028701 | Sup=0.028622 | Recon=0.000881 | TrainAcc=1.0000
# Fold 9 Epoch 400: TotalLoss=0.014158 | Sup=0.014107 | Recon=0.000565 | TrainAcc=1.0000
# Fold 9 Epoch 500: TotalLoss=0.007689 | Sup=0.007653 | Recon=0.000408 | TrainAcc=1.0000
# Fold 9 Epoch 600: TotalLoss=0.005167 | Sup=0.005134 | Recon=0.000361 | TrainAcc=1.0000
# Fold 9 Epoch 700: TotalLoss=0.003346 | Sup=0.003315 | Recon=0.000343 | TrainAcc=1.0000
# Fold 9 Epoch 800: TotalLoss=0.001891 | Sup=0.001860 | Recon=0.000339 | TrainAcc=1.0000
# Fold 9 Epoch 900: TotalLoss=0.001284 | Sup=0.001253 | Recon=0.000346 | TrainAcc=1.0000
# Fold 9 Epoch 1000: TotalLoss=0.001006 | Sup=0.000974 | Recon=0.000353 | TrainAcc=1.0000
# Fold 9 Epoch 1100: TotalLoss=0.000594 | Sup=0.000561 | Recon=0.000369 | TrainAcc=1.0000
# Fold 9 Epoch 1200: TotalLoss=0.000456 | Sup=0.000422 | Recon=0.000370 | TrainAcc=1.0000
# Fold 9 Epoch 1300: TotalLoss=0.000310 | Sup=0.000277 | Recon=0.000374 | TrainAcc=1.0000
# Fold 9 Epoch 1400: TotalLoss=0.000296 | Sup=0.000262 | Recon=0.000380 | TrainAcc=1.0000
# Fold 9 Epoch 1500: TotalLoss=0.000266 | Sup=0.000232 | Recon=0.000385 | TrainAcc=1.0000
# Fold 9 Epoch 1600: TotalLoss=0.000228 | Sup=0.000193 | Recon=0.000386 | TrainAcc=1.0000
# Fold 9 Epoch 1700: TotalLoss=0.000192 | Sup=0.000157 | Recon=0.000392 | TrainAcc=1.0000
# Fold 9 Epoch 1800: TotalLoss=0.000202 | Sup=0.000166 | Recon=0.000392 | TrainAcc=1.0000
# Fold 9 Epoch 1900: TotalLoss=0.000156 | Sup=0.000121 | Recon=0.000389 | TrainAcc=1.0000
# Fold 9 Epoch 2000: TotalLoss=0.000187 | Sup=0.000151 | Recon=0.000397 | TrainAcc=1.0000
# Fold 9 → Acc=0.9701 | Prec=0.9630 | Rec=0.9630 | F1=0.9630 | AUC=0.9935 | CE Loss=0.0983
#
# ...
# Fold 13 Epoch 1700: TotalLoss=0.002157 | Sup=0.000471 | Recon=0.000211 | TrainAcc=1.0000
# Fold 13 Epoch 1800: TotalLoss=0.001893 | Sup=0.000334 | Recon=0.000195 | TrainAcc=1.0000
# Fold 13 Epoch 1900: TotalLoss=0.001770 | Sup=0.000298 | Recon=0.000184 | TrainAcc=1.0000
# Fold 13 Epoch 2000: TotalLoss=0.001662 | Sup=0.000274 | Recon=0.000174 | TrainAcc=1.0000
# Fold 13 → Acc=0.9851 | Prec=0.9643 | Rec=1.0000 | F1=0.9818 | AUC=0.9991 | CE Loss=0.0450
#
# === Fold 14 ===
# Train Control: 93, Train Patient: 63
# Fold 14 Epoch 1: TotalLoss=1.119937 | Sup=0.804247 | Recon=0.039461 | TrainAcc=0.4038
# Fold 14 Epoch 100: TotalLoss=0.252496 | Sup=0.229373 | Recon=0.002890 | TrainAcc=0.9551
# Fold 14 Epoch 200: TotalLoss=0.087835 | Sup=0.076132 | Recon=0.001463 | TrainAcc=1.0000
# Fold 14 Epoch 300: TotalLoss=0.039439 | Sup=0.032132 | Recon=0.000913 | TrainAcc=1.0000
# Fold 14 Epoch 400: TotalLoss=0.020824 | Sup=0.015431 | Recon=0.000674 | TrainAcc=1.0000
# Fold 14 Epoch 500: TotalLoss=0.013779 | Sup=0.009281 | Recon=0.000562 | TrainAcc=1.0000
# Fold 14 Epoch 600: TotalLoss=0.010186 | Sup=0.006286 | Recon=0.000488 | TrainAcc=1.0000
# Fold 14 Epoch 700: TotalLoss=0.007669 | Sup=0.004168 | Recon=0.000438 | TrainAcc=1.0000
# Fold 14 Epoch 800: TotalLoss=0.006258 | Sup=0.003220 | Recon=0.000380 | TrainAcc=1.0000
# Fold 14 Epoch 900: TotalLoss=0.004855 | Sup=0.002010 | Recon=0.000356 | TrainAcc=1.0000
# Fold 14 Epoch 1000: TotalLoss=0.004120 | Sup=0.001496 | Recon=0.000328 | TrainAcc=1.0000
# Fold 14 Epoch 1100: TotalLoss=0.003554 | Sup=0.001059 | Recon=0.000312 | TrainAcc=1.0000
# Fold 14 Epoch 1200: TotalLoss=0.003222 | Sup=0.000938 | Recon=0.000285 | TrainAcc=1.0000
# Fold 14 Epoch 1300: TotalLoss=0.002936 | Sup=0.000703 | Recon=0.000279 | TrainAcc=1.0000
# Fold 14 Epoch 1400: TotalLoss=0.002903 | Sup=0.000802 | Recon=0.000263 | TrainAcc=1.0000
# Fold 14 Epoch 1500: TotalLoss=0.002481 | Sup=0.000466 | Recon=0.000252 | TrainAcc=1.0000
# Fold 14 Epoch 1600: TotalLoss=0.002374 | Sup=0.000474 | Recon=0.000238 | TrainAcc=1.0000
# Fold 14 Epoch 1700: TotalLoss=0.002182 | Sup=0.000360 | Recon=0.000228 | TrainAcc=1.0000
# Fold 14 Epoch 1800: TotalLoss=0.002053 | Sup=0.000362 | Recon=0.000211 | TrainAcc=1.0000
# Fold 14 Epoch 1900: TotalLoss=0.001878 | Sup=0.000283 | Recon=0.000199 | TrainAcc=1.0000
# Fold 14 Epoch 2000: TotalLoss=0.001812 | Sup=0.000312 | Recon=0.000188 | TrainAcc=1.0000
# Fold 14 → Acc=0.9552 | Prec=1.0000 | Rec=0.8889 | F1=0.9412 | AUC=0.9833 | CE Loss=0.2343
#
# === Fold 15 ===
# Train Control: 93, Train Patient: 63
# Fold 15 Epoch 1: TotalLoss=1.061197 | Sup=0.762087 | Recon=0.037389 | TrainAcc=0.6154
# Fold 15 Epoch 100: TotalLoss=0.232178 | Sup=0.209636 | Recon=0.002818 | TrainAcc=0.9487
# Fold 15 Epoch 200: TotalLoss=0.091336 | Sup=0.080365 | Recon=0.001371 | TrainAcc=1.0000
# Fold 15 Epoch 300: TotalLoss=0.037221 | Sup=0.030116 | Recon=0.000888 | TrainAcc=1.0000
# Fold 15 Epoch 400: TotalLoss=0.018839 | Sup=0.013527 | Recon=0.000664 | TrainAcc=1.0000
# Fold 15 Epoch 500: TotalLoss=0.013223 | Sup=0.008864 | Recon=0.000545 | TrainAcc=1.0000
# Fold 15 Epoch 600: TotalLoss=0.009209 | Sup=0.005344 | Recon=0.000483 | TrainAcc=1.0000
# Fold 15 Epoch 700: TotalLoss=0.007552 | Sup=0.004073 | Recon=0.000435 | TrainAcc=1.0000
# Fold 15 Epoch 800: TotalLoss=0.005634 | Sup=0.002533 | Recon=0.000388 | TrainAcc=1.0000
# Fold 15 Epoch 900: TotalLoss=0.005010 | Sup=0.002078 | Recon=0.000366 | TrainAcc=1.0000
# Fold 15 Epoch 1000: TotalLoss=0.004045 | Sup=0.001378 | Recon=0.000333 | TrainAcc=1.0000
# Fold 15 Epoch 1100: TotalLoss=0.003852 | Sup=0.001344 | Recon=0.000314 | TrainAcc=1.0000
# Fold 15 Epoch 1200: TotalLoss=0.003144 | Sup=0.000767 | Recon=0.000297 | TrainAcc=1.0000
# Fold 15 Epoch 1300: TotalLoss=0.002843 | Sup=0.000648 | Recon=0.000274 | TrainAcc=1.0000
# Fold 15 Epoch 1400: TotalLoss=0.002665 | Sup=0.000579 | Recon=0.000261 | TrainAcc=1.0000
# Fold 15 Epoch 1500: TotalLoss=0.002322 | Sup=0.000372 | Recon=0.000244 | TrainAcc=1.0000
# Fold 15 Epoch 1600: TotalLoss=0.002221 | Sup=0.000352 | Recon=0.000234 | TrainAcc=1.0000
# Fold 15 Epoch 1700: TotalLoss=0.002011 | Sup=0.000269 | Recon=0.000218 | TrainAcc=1.0000
# Fold 15 Epoch 1800: TotalLoss=0.002009 | Sup=0.000356 | Recon=0.000207 | TrainAcc=1.0000
# Fold 15 Epoch 1900: TotalLoss=0.001757 | Sup=0.000221 | Recon=0.000192 | TrainAcc=1.0000
# Fold 15 Epoch 2000: TotalLoss=0.001659 | Sup=0.000207 | Recon=0.000182 | TrainAcc=1.0000
# Fold 15 → Acc=0.8955 | Prec=0.8846 | Rec=0.8519 | F1=0.8679 | AUC=0.9528 | CE Loss=0.4186
#
# === Fold 16 ===
# Train Control: 93, Train Patient: 63
# Fold 16 Epoch 1: TotalLoss=1.145087 | Sup=0.822679 | Recon=0.040301 | TrainAcc=0.5962
# Fold 16 Epoch 100: TotalLoss=0.265324 | Sup=0.241465 | Recon=0.002982 | TrainAcc=0.9359
# Fold 16 Epoch 200: TotalLoss=0.095364 | Sup=0.084113 | Recon=0.001406 | TrainAcc=1.0000
# Fold 16 Epoch 300: TotalLoss=0.040682 | Sup=0.033485 | Recon=0.000900 | TrainAcc=1.0000
# Fold 16 Epoch 400: TotalLoss=0.023022 | Sup=0.017518 | Recon=0.000688 | TrainAcc=1.0000
# Fold 16 Epoch 500: TotalLoss=0.013971 | Sup=0.009437 | Recon=0.000567 | TrainAcc=1.0000
# Fold 16 Epoch 600: TotalLoss=0.010460 | Sup=0.006646 | Recon=0.000477 | TrainAcc=1.0000
# Fold 16 Epoch 700: TotalLoss=0.007573 | Sup=0.004171 | Recon=0.000425 | TrainAcc=1.0000
# Fold 16 Epoch 800: TotalLoss=0.005613 | Sup=0.002568 | Recon=0.000381 | TrainAcc=1.0000
# Fold 16 Epoch 900: TotalLoss=0.004868 | Sup=0.002014 | Recon=0.000357 | TrainAcc=1.0000
# Fold 16 Epoch 1000: TotalLoss=0.004356 | Sup=0.001711 | Recon=0.000331 | TrainAcc=1.0000
# Fold 16 Epoch 1100: TotalLoss=0.003437 | Sup=0.001045 | Recon=0.000299 | TrainAcc=1.0000
# Fold 16 Epoch 1200: TotalLoss=0.002967 | Sup=0.000760 | Recon=0.000276 | TrainAcc=1.0000
# Fold 16 Epoch 1300: TotalLoss=0.002649 | Sup=0.000542 | Recon=0.000263 | TrainAcc=1.0000
# Fold 16 Epoch 1400: TotalLoss=0.002502 | Sup=0.000547 | Recon=0.000244 | TrainAcc=1.0000
# Fold 16 Epoch 1500: TotalLoss=0.002328 | Sup=0.000460 | Recon=0.000233 | TrainAcc=1.0000
# Fold 16 Epoch 1600: TotalLoss=0.002114 | Sup=0.000382 | Recon=0.000216 | TrainAcc=1.0000
# Fold 16 Epoch 1700: TotalLoss=0.001967 | Sup=0.000297 | Recon=0.000209 | TrainAcc=1.0000
# Fold 16 Epoch 1800: TotalLoss=0.001920 | Sup=0.000337 | Recon=0.000198 | TrainAcc=1.0000
# Fold 16 Epoch 1900: TotalLoss=0.001693 | Sup=0.000255 | Recon=0.000180 | TrainAcc=1.0000
# Fold 16 Epoch 2000: TotalLoss=0.001535 | Sup=0.000189 | Recon=0.000168 | TrainAcc=1.0000
# Fold 16 → Acc=0.8955 | Prec=0.8125 | Rec=0.9630 | F1=0.8814 | AUC=0.9917 | CE Loss=0.2277
#
# === Fold 17 ===
# Train Control: 93, Train Patient: 63
# Fold 17 Epoch 1: TotalLoss=1.032224 | Sup=0.702716 | Recon=0.041188 | TrainAcc=0.5962
# Fold 17 Epoch 100: TotalLoss=0.218976 | Sup=0.194858 | Recon=0.003015 | TrainAcc=0.9487
# Fold 17 Epoch 200: TotalLoss=0.078442 | Sup=0.067470 | Recon=0.001371 | TrainAcc=1.0000
# Fold 17 Epoch 300: TotalLoss=0.034517 | Sup=0.027574 | Recon=0.000868 | TrainAcc=1.0000
# Fold 17 Epoch 400: TotalLoss=0.018038 | Sup=0.012750 | Recon=0.000661 | TrainAcc=1.0000
# Fold 17 Epoch 500: TotalLoss=0.011900 | Sup=0.007479 | Recon=0.000553 | TrainAcc=1.0000
# Fold 17 Epoch 600: TotalLoss=0.008291 | Sup=0.004367 | Recon=0.000490 | TrainAcc=1.0000
# Fold 17 Epoch 700: TotalLoss=0.006991 | Sup=0.003525 | Recon=0.000433 | TrainAcc=1.0000
# Fold 17 Epoch 800: TotalLoss=0.005336 | Sup=0.002145 | Recon=0.000399 | TrainAcc=1.0000
# Fold 17 Epoch 900: TotalLoss=0.004335 | Sup=0.001435 | Recon=0.000363 | TrainAcc=1.0000
# Fold 17 Epoch 1000: TotalLoss=0.004175 | Sup=0.001432 | Recon=0.000343 | TrainAcc=1.0000
# Fold 17 Epoch 1100: TotalLoss=0.003698 | Sup=0.001128 | Recon=0.000321 | TrainAcc=1.0000
# Fold 17 Epoch 1200: TotalLoss=0.003103 | Sup=0.000706 | Recon=0.000300 | TrainAcc=1.0000
# Fold 17 Epoch 1300: TotalLoss=0.002976 | Sup=0.000705 | Recon=0.000284 | TrainAcc=1.0000
# Fold 17 Epoch 1400: TotalLoss=0.002655 | Sup=0.000500 | Recon=0.000269 | TrainAcc=1.0000
# Fold 17 Epoch 1500: TotalLoss=0.002388 | Sup=0.000403 | Recon=0.000248 | TrainAcc=1.0000
# Fold 17 Epoch 1600: TotalLoss=0.002224 | Sup=0.000345 | Recon=0.000235 | TrainAcc=1.0000
# Fold 17 Epoch 1700: TotalLoss=0.002042 | Sup=0.000300 | Recon=0.000218 | TrainAcc=1.0000
# Fold 17 Epoch 1800: TotalLoss=0.001948 | Sup=0.000277 | Recon=0.000209 | TrainAcc=1.0000
# Fold 17 Epoch 1900: TotalLoss=0.001867 | Sup=0.000317 | Recon=0.000194 | TrainAcc=1.0000
# Fold 17 Epoch 2000: TotalLoss=0.001667 | Sup=0.000219 | Recon=0.000181 | TrainAcc=1.0000
# Fold 17 → Acc=0.9552 | Prec=0.9615 | Rec=0.9259 | F1=0.9434 | AUC=0.9880 | CE Loss=0.2012
#
# === Fold 18 ===
# Train Control: 93, Train Patient: 63
# Fold 18 Epoch 1: TotalLoss=1.177775 | Sup=0.861187 | Recon=0.039573 | TrainAcc=0.4038
# Fold 18 Epoch 100: TotalLoss=0.276703 | Sup=0.254021 | Recon=0.002835 | TrainAcc=0.9423
# Fold 18 Epoch 200: TotalLoss=0.101957 | Sup=0.091023 | Recon=0.001367 | TrainAcc=0.9936
# Fold 18 Epoch 300: TotalLoss=0.042997 | Sup=0.036055 | Recon=0.000868 | TrainAcc=1.0000
# Fold 18 Epoch 400: TotalLoss=0.024499 | Sup=0.019106 | Recon=0.000674 | TrainAcc=1.0000
# Fold 18 Epoch 500: TotalLoss=0.015854 | Sup=0.011375 | Recon=0.000560 | TrainAcc=1.0000
# Fold 18 Epoch 600: TotalLoss=0.010108 | Sup=0.006161 | Recon=0.000493 | TrainAcc=1.0000
# Fold 18 Epoch 700: TotalLoss=0.007682 | Sup=0.004071 | Recon=0.000451 | TrainAcc=1.0000
# Fold 18 Epoch 800: TotalLoss=0.006864 | Sup=0.003591 | Recon=0.000409 | TrainAcc=1.0000
# Fold 18 Epoch 900: TotalLoss=0.005161 | Sup=0.002231 | Recon=0.000366 | TrainAcc=1.0000
# Fold 18 Epoch 1000: TotalLoss=0.004327 | Sup=0.001593 | Recon=0.000342 | TrainAcc=1.0000
# Fold 18 Epoch 1100: TotalLoss=0.003730 | Sup=0.001157 | Recon=0.000322 | TrainAcc=1.0000
# Fold 18 Epoch 1200: TotalLoss=0.003535 | Sup=0.001092 | Recon=0.000305 | TrainAcc=1.0000
# Fold 18 Epoch 1300: TotalLoss=0.002992 | Sup=0.000677 | Recon=0.000289 | TrainAcc=1.0000
# Fold 18 Epoch 1400: TotalLoss=0.002758 | Sup=0.000545 | Recon=0.000277 | TrainAcc=1.0000
# Fold 18 Epoch 1500: TotalLoss=0.002542 | Sup=0.000454 | Recon=0.000261 | TrainAcc=1.0000
# Fold 18 Epoch 1600: TotalLoss=0.002347 | Sup=0.000376 | Recon=0.000246 | TrainAcc=1.0000
# Fold 18 Epoch 1700: TotalLoss=0.002169 | Sup=0.000328 | Recon=0.000230 | TrainAcc=1.0000
# Fold 18 Epoch 1800: TotalLoss=0.002162 | Sup=0.000391 | Recon=0.000221 | TrainAcc=1.0000
# Fold 18 Epoch 1900: TotalLoss=0.002051 | Sup=0.000375 | Recon=0.000209 | TrainAcc=1.0000
# Fold 18 Epoch 2000: TotalLoss=0.001869 | Sup=0.000308 | Recon=0.000195 | TrainAcc=1.0000
# Fold 18 → Acc=0.9701 | Prec=1.0000 | Rec=0.9259 | F1=0.9615 | AUC=0.9917 | CE Loss=0.1144
#
# === Fold 19 ===
# Train Control: 93, Train Patient: 63
# Fold 19 Epoch 1: TotalLoss=1.025482 | Sup=0.742252 | Recon=0.035404 | TrainAcc=0.4038
# Fold 19 Epoch 100: TotalLoss=0.250902 | Sup=0.227910 | Recon=0.002874 | TrainAcc=0.9487
# Fold 19 Epoch 200: TotalLoss=0.094159 | Sup=0.083911 | Recon=0.001281 | TrainAcc=1.0000
# Fold 19 Epoch 300: TotalLoss=0.041046 | Sup=0.034291 | Recon=0.000844 | TrainAcc=1.0000
# Fold 19 Epoch 400: TotalLoss=0.021175 | Sup=0.015890 | Recon=0.000661 | TrainAcc=1.0000
# Fold 19 Epoch 500: TotalLoss=0.013587 | Sup=0.009165 | Recon=0.000553 | TrainAcc=1.0000
# Fold 19 Epoch 600: TotalLoss=0.010873 | Sup=0.006889 | Recon=0.000498 | TrainAcc=1.0000
# Fold 19 Epoch 700: TotalLoss=0.007658 | Sup=0.004157 | Recon=0.000438 | TrainAcc=1.0000
# Fold 19 Epoch 800: TotalLoss=0.006227 | Sup=0.003079 | Recon=0.000394 | TrainAcc=1.0000
# Fold 19 Epoch 900: TotalLoss=0.004910 | Sup=0.001995 | Recon=0.000364 | TrainAcc=1.0000
# Fold 19 Epoch 1000: TotalLoss=0.004020 | Sup=0.001375 | Recon=0.000331 | TrainAcc=1.0000
# Fold 19 Epoch 1100: TotalLoss=0.003814 | Sup=0.001288 | Recon=0.000316 | TrainAcc=1.0000
# Fold 19 Epoch 1200: TotalLoss=0.003501 | Sup=0.001118 | Recon=0.000298 | TrainAcc=1.0000
# Fold 19 Epoch 1300: TotalLoss=0.003041 | Sup=0.000748 | Recon=0.000287 | TrainAcc=1.0000
# Fold 19 Epoch 1400: TotalLoss=0.002668 | Sup=0.000538 | Recon=0.000266 | TrainAcc=1.0000
# Fold 19 Epoch 1500: TotalLoss=0.002457 | Sup=0.000442 | Recon=0.000252 | TrainAcc=1.0000
# Fold 19 Epoch 1600: TotalLoss=0.002236 | Sup=0.000296 | Recon=0.000242 | TrainAcc=1.0000
# Fold 19 Epoch 1700: TotalLoss=0.002119 | Sup=0.000336 | Recon=0.000223 | TrainAcc=1.0000
# Fold 19 Epoch 1800: TotalLoss=0.001874 | Sup=0.000212 | Recon=0.000208 | TrainAcc=1.0000
# Fold 19 Epoch 1900: TotalLoss=0.001823 | Sup=0.000242 | Recon=0.000198 | TrainAcc=1.0000
# Fold 19 Epoch 2000: TotalLoss=0.001713 | Sup=0.000252 | Recon=0.000183 | TrainAcc=1.0000
# Fold 19 → Acc=0.8955 | Prec=0.8125 | Rec=0.9630 | F1=0.8814 | AUC=0.9880 | CE Loss=0.2653
#
# === Fold 20 ===
# Train Control: 93, Train Patient: 63
# Fold 20 Epoch 1: TotalLoss=1.040838 | Sup=0.742684 | Recon=0.037269 | TrainAcc=0.5000
# Fold 20 Epoch 100: TotalLoss=0.243223 | Sup=0.219892 | Recon=0.002916 | TrainAcc=0.9551
# Fold 20 Epoch 200: TotalLoss=0.084963 | Sup=0.074453 | Recon=0.001314 | TrainAcc=1.0000
# Fold 20 Epoch 300: TotalLoss=0.033962 | Sup=0.027408 | Recon=0.000819 | TrainAcc=1.0000
# Fold 20 Epoch 400: TotalLoss=0.020240 | Sup=0.015004 | Recon=0.000655 | TrainAcc=1.0000
# Fold 20 Epoch 500: TotalLoss=0.013538 | Sup=0.009101 | Recon=0.000555 | TrainAcc=1.0000
# Fold 20 Epoch 600: TotalLoss=0.009791 | Sup=0.005678 | Recon=0.000514 | TrainAcc=1.0000
# Fold 20 Epoch 700: TotalLoss=0.006725 | Sup=0.003038 | Recon=0.000461 | TrainAcc=1.0000
# Fold 20 Epoch 800: TotalLoss=0.006094 | Sup=0.002756 | Recon=0.000417 | TrainAcc=1.0000
# Fold 20 Epoch 900: TotalLoss=0.004784 | Sup=0.001707 | Recon=0.000385 | TrainAcc=1.0000
# Fold 20 Epoch 1000: TotalLoss=0.004296 | Sup=0.001468 | Recon=0.000354 | TrainAcc=1.0000
# Fold 20 Epoch 1100: TotalLoss=0.003626 | Sup=0.000931 | Recon=0.000337 | TrainAcc=1.0000
# Fold 20 Epoch 1200: TotalLoss=0.003407 | Sup=0.000819 | Recon=0.000324 | TrainAcc=1.0000
# Fold 20 Epoch 1300: TotalLoss=0.002972 | Sup=0.000579 | Recon=0.000299 | TrainAcc=1.0000
# Fold 20 Epoch 1400: TotalLoss=0.002751 | Sup=0.000428 | Recon=0.000290 | TrainAcc=1.0000
# Fold 20 Epoch 1500: TotalLoss=0.002678 | Sup=0.000502 | Recon=0.000272 | TrainAcc=1.0000
# Fold 20 Epoch 1600: TotalLoss=0.002302 | Sup=0.000332 | Recon=0.000246 | TrainAcc=1.0000
# Fold 20 Epoch 1700: TotalLoss=0.002096 | Sup=0.000255 | Recon=0.000230 | TrainAcc=1.0000
# Fold 20 Epoch 1800: TotalLoss=0.002055 | Sup=0.000286 | Recon=0.000221 | TrainAcc=1.0000
# Fold 20 Epoch 1900: TotalLoss=0.001866 | Sup=0.000263 | Recon=0.000200 | TrainAcc=1.0000
# Fold 20 Epoch 2000: TotalLoss=0.001674 | Sup=0.000197 | Recon=0.000185 | TrainAcc=1.0000
# Fold 20 → Acc=0.9403 | Prec=0.8710 | Rec=1.0000 | F1=0.9310 | AUC=0.9722 | CE Loss=0.2999
#
# === Average Results for λ = 8 ===
# Accuracy:  0.9463
# Precision: 0.9280
# Recall:    0.9444
# F1-score:  0.9346
# CE Loss:   0.1948
# AUC:       0.9867
#
#
# ====================== FINAL SUMMARY ACROSS ALL λ ======================
# Lambda   | Accuracy  | Precision | Recall   | F1-score  | AUC      | CE Loss
# ------------------------------------------------------------------------
# 0.001    | 0.9500    | 0.9372    | 0.9426   | 0.9385    | 0.9867   | 0.1921
# 0.005    | 0.9463    | 0.9240    | 0.9481   | 0.9343    | 0.9865   | 0.1983
# 0.009    | 0.9463    | 0.9283    | 0.9426   | 0.9343    | 0.9863   | 0.1935
# 0.01     | 0.9455    | 0.9250    | 0.9444   | 0.9334    | 0.9866   | 0.1982
# 0.05     | 0.9463    | 0.9263    | 0.9444   | 0.9341    | 0.9867   | 0.1913
# 0.09     | 0.9507    | 0.9318    | 0.9500   | 0.9397    | 0.9869   | 0.1947
# 0.1      | 0.9455    | 0.9230    | 0.9463   | 0.9336    | 0.9875   | 0.1922
# 0.3      | 0.9478    | 0.9276    | 0.9481   | 0.9365    | 0.9870   | 0.1876
# 0.5      | 0.9485    | 0.9304    | 0.9463   | 0.9370    | 0.9872   | 0.1930
# 0.9      | 0.9440    | 0.9253    | 0.9407   | 0.9317    | 0.9867   | 0.1942
# 1        | 0.9485    | 0.9285    | 0.9481   | 0.9371    | 0.9870   | 0.1912
# 2        | 0.9515    | 0.9395    | 0.9426   | 0.9398    | 0.9867   | 0.1943
# 5        | 0.9470    | 0.9298    | 0.9426   | 0.9349    | 0.9867   | 0.1926
# 8        | 0.9463    | 0.9280    | 0.9444   | 0.9346    | 0.9867   | 0.1948
