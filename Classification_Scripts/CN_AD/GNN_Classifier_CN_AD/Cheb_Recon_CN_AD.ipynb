# %%
import os
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as nnFn
import torch.optim as optim
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, log_loss
from torch_geometric.data import Data
from torch_geometric.nn import ChebConv

device = 'cuda' if torch.cuda.is_available() else 'cpu'
print("Device:", device)

cn_path = "/home/snu/Downloads/Histogram_CN_FA_20bin_updated.npy"
ad_path = "/home/snu/Downloads/Histogram_AD_FA_20bin_updated.npy"

Histogram_feature_CN_FA_array = np.load(cn_path, allow_pickle=True)
Histogram_feature_AD_FA_array = np.load(ad_path, allow_pickle=True)

X = np.vstack([Histogram_feature_CN_FA_array, Histogram_feature_AD_FA_array])
y = np.hstack([
    np.zeros(Histogram_feature_CN_FA_array.shape[0], dtype=np.int64),  # CN → 0
    np.ones(Histogram_feature_AD_FA_array.shape[0], dtype=np.int64)    # AD → 1
])

num_nodes, num_feats = X.shape
print(f"Features: {X.shape}, Labels: {y.shape}")

# Shuffle for reproducibility
rng = np.random.RandomState(42)
perm = rng.permutation(num_nodes)
X = X[perm]
y = y[perm]

def create_adj(F_data, alpha=1):
    norms = np.linalg.norm(F_data, axis=1, keepdims=True)
    norms[norms == 0] = 1.0
    F_norm = F_data / norms
    W = np.dot(F_norm, F_norm.T)
    W = np.where(W >= alpha, 1.0, 0.0).astype(np.float32)
    if W.max() > 0:
        W = W / W.max()
    return W

alpha = 0.8
W = create_adj(X, alpha=alpha)
np.fill_diagonal(W, 1.0)

def load_data(adj, node_feats):
    node_feats = torch.from_numpy(node_feats).float()
    rows, cols = np.nonzero(adj > 0)
    edge_index = torch.from_numpy(np.vstack([rows, cols]).astype(np.int64))
    return Data(x=node_feats, edge_index=edge_index)

data = load_data(W, X).to(device)
print(data)

class Cheb_AE(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim, device, activ="RELU", dropout=0.25, K=3):
        super(Cheb_AE, self).__init__()
        self.device = device

        self.conv1 = ChebConv(input_dim, hidden_dim, K=K)
        self.bn1 = nn.BatchNorm1d(hidden_dim)
        self.dropout = nn.Dropout(dropout)
        self.fc = nn.Linear(hidden_dim, output_dim)


        self.decoder = nn.Sequential(
            nn.Linear(hidden_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, input_dim)
        )

        activations = {
            "SELU": nnFn.selu,
            "SiLU": nnFn.silu,
            "GELU": nnFn.gelu,
            "RELU": nnFn.relu,
            "ELU": nnFn.elu
        }
        self.act = activations.get(activ, nnFn.relu)

    def forward(self, x, edge_index):
        # Encoder
        h = self.conv1(x, edge_index)
        h = self.bn1(h)
        h = self.act(h)
        h = self.dropout(h)

        # Classification
        logits = self.fc(h)

        # Reconstruction
        recon = self.decoder(h)

        return logits, recon, h


feats_dim = num_feats
hidden_dim = 512
num_classes = 2
num_epochs = 2000
lr = 1e-4
weight_decay = 1e-4
batch_print_freq = 100
lambda_recon = 0.9

sss = StratifiedShuffleSplit(n_splits=20, test_size=0.3, random_state=42)
accuracies, precisions, recalls, f1_scores, aucs, ce_losses = [], [], [], [], [], []
y_all = y.copy()

for fold, (train_val_idx, test_idx_global) in enumerate(sss.split(X, y_all), start=1):
    print(f"\n=== Fold {fold} ===")
    cn_idx = np.where(y_all == 0)[0]
    ad_idx = np.where(y_all == 1)[0]
    sss_class = StratifiedShuffleSplit(n_splits=20, test_size=0.3, random_state=fold)
    cn_train_idx, _ = next(sss_class.split(X[cn_idx], y_all[cn_idx]))
    ad_train_idx, _ = next(sss_class.split(X[ad_idx], y_all[ad_idx]))
    cn_train = cn_idx[cn_train_idx]
    ad_train = ad_idx[ad_train_idx]
    train_idx_final = np.concatenate([cn_train, ad_train])
    np.random.shuffle(train_idx_final)

    print(f"Train CN: {len(cn_train)}, Train AD: {len(ad_train)}")
    train_idx_t = torch.from_numpy(train_idx_final).long().to(device)
    y_train_tensor = torch.from_numpy(y_all[train_idx_final]).long().to(device)

    model = Cheb_AE(feats_dim, hidden_dim, num_classes, device, activ="RELU", dropout=0.25, K=3).to(device)
    optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
    ce_loss_fn = nn.CrossEntropyLoss()
    recon_loss_fn = nn.MSELoss()
    data = load_data(W, X).to(device)

    for epoch in range(1, num_epochs + 1):
        model.train()
        optimizer.zero_grad()
        logits, recon_x, _ = model(data.x, data.edge_index)

        loss_sup = ce_loss_fn(logits[train_idx_t], y_train_tensor)
        loss_recon = recon_loss_fn(recon_x, data.x)
        total_loss = loss_sup + lambda_recon * loss_recon

        if torch.isnan(total_loss) or torch.isinf(total_loss):
            print(f"NaN/Inf detected at fold {fold} epoch {epoch}. Aborting epoch.")
            break

        total_loss.backward()
        optimizer.step()

        if epoch % batch_print_freq == 0 or epoch == 1:
            model.eval()
            with torch.no_grad():
                logits_eval, _, _ = model(data.x, data.edge_index)
                preds_train = logits_eval[train_idx_t].argmax(dim=1)
                acc_train = accuracy_score(y_train_tensor.cpu(), preds_train.cpu())
            print(f"Fold {fold} Epoch {epoch}: TotalLoss={total_loss.item():.6f} | Sup={loss_sup.item():.6f} | Recon={loss_recon.item():.6f} | TrainAcc={acc_train:.4f}")

    model.eval()
    with torch.no_grad():
        out_logits, _, _ = model(data.x, data.edge_index)
        preds = out_logits.argmax(dim=1).cpu().numpy()
        probs = nnFn.softmax(out_logits, dim=1)[:, 1].cpu().numpy()

    y_test = y_all[test_idx_global]
    y_pred_test = preds[test_idx_global]
    y_prob_test = probs[test_idx_global]

    acc = accuracy_score(y_test, y_pred_test)
    prec = precision_score(y_test, y_pred_test, zero_division=0)
    rec = recall_score(y_test, y_pred_test, zero_division=0)
    f1 = f1_score(y_test, y_pred_test, zero_division=0)
    try:
        auc = roc_auc_score(y_test, y_prob_test)
    except ValueError:
        auc = float('nan')
    ce = log_loss(y_test, y_prob_test)

    accuracies.append(acc)
    precisions.append(prec)
    recalls.append(rec)
    f1_scores.append(f1)
    aucs.append(auc)
    ce_losses.append(ce)

    print(f"Fold {fold} → Acc={acc:.4f} | Prec={prec:.4f} | Rec={rec:.4f} | F1={f1:.4f} | AUC={auc:.4f} | CE Loss={ce:.4f}")


print("\n=== Average Results Across 20 Folds ===")
print(f"Accuracy:  {np.mean(accuracies):.4f} ± {np.std(accuracies):.4f}")
print(f"Precision: {np.mean(precisions):.4f} ± {np.std(precisions):.4f}")
print(f"Recall:    {np.mean(recalls):.4f} ± {np.std(recalls):.4f}")
print(f"F1-score:  {np.mean(f1_scores):.4f} ± {np.std(f1_scores):.4f}")
print(f"CE Loss:   {np.mean(ce_losses):.4f} ± {np.std(ce_losses):.4f}")
print(f"AUC:       {np.nanmean(aucs):.4f} ± {np.nanstd(aucs):.4f}")
# Out:
# Device: cuda
# Features: (223, 180), Labels: (223,)
# Data(x=[223, 180], edge_index=[2, 41689])
#
# === Fold 1 ===
# Train CN: 93, Train AD: 63
# Fold 1 Epoch 1: TotalLoss=0.724491 | Sup=0.687517 | Recon=0.041082 | TrainAcc=0.5128
# Fold 1 Epoch 100: TotalLoss=0.159500 | Sup=0.157312 | Recon=0.002431 | TrainAcc=0.9744
# Fold 1 Epoch 200: TotalLoss=0.042496 | Sup=0.041470 | Recon=0.001140 | TrainAcc=1.0000
# Fold 1 Epoch 300: TotalLoss=0.016112 | Sup=0.015470 | Recon=0.000713 | TrainAcc=1.0000
# Fold 1 Epoch 400: TotalLoss=0.008331 | Sup=0.007857 | Recon=0.000527 | TrainAcc=1.0000
# Fold 1 Epoch 500: TotalLoss=0.005737 | Sup=0.005366 | Recon=0.000412 | TrainAcc=1.0000
# Fold 1 Epoch 600: TotalLoss=0.003690 | Sup=0.003403 | Recon=0.000319 | TrainAcc=1.0000
# Fold 1 Epoch 700: TotalLoss=0.002724 | Sup=0.002483 | Recon=0.000268 | TrainAcc=1.0000
# Fold 1 Epoch 800: TotalLoss=0.002306 | Sup=0.002091 | Recon=0.000239 | TrainAcc=1.0000
# Fold 1 Epoch 900: TotalLoss=0.001682 | Sup=0.001493 | Recon=0.000210 | TrainAcc=1.0000
# Fold 1 Epoch 1000: TotalLoss=0.001438 | Sup=0.001269 | Recon=0.000188 | TrainAcc=1.0000
# Fold 1 Epoch 1100: TotalLoss=0.001332 | Sup=0.001179 | Recon=0.000169 | TrainAcc=1.0000
# Fold 1 Epoch 1200: TotalLoss=0.001040 | Sup=0.000902 | Recon=0.000153 | TrainAcc=1.0000
# Fold 1 Epoch 1300: TotalLoss=0.000879 | Sup=0.000749 | Recon=0.000145 | TrainAcc=1.0000
# Fold 1 Epoch 1400: TotalLoss=0.000760 | Sup=0.000633 | Recon=0.000141 | TrainAcc=1.0000
# Fold 1 Epoch 1500: TotalLoss=0.000705 | Sup=0.000583 | Recon=0.000136 | TrainAcc=1.0000
# Fold 1 Epoch 1600: TotalLoss=0.000710 | Sup=0.000589 | Recon=0.000135 | TrainAcc=1.0000
# Fold 1 Epoch 1700: TotalLoss=0.000646 | Sup=0.000526 | Recon=0.000133 | TrainAcc=1.0000
# Fold 1 Epoch 1800: TotalLoss=0.000655 | Sup=0.000534 | Recon=0.000134 | TrainAcc=1.0000
# Fold 1 Epoch 1900: TotalLoss=0.000560 | Sup=0.000446 | Recon=0.000127 | TrainAcc=1.0000
# Fold 1 Epoch 2000: TotalLoss=0.000532 | Sup=0.000420 | Recon=0.000124 | TrainAcc=1.0000
# Fold 1 → Acc=0.9403 | Prec=0.8966 | Rec=0.9630 | F1=0.9286 | AUC=0.9713 | CE Loss=0.3401
#
# === Fold 2 ===
# Train CN: 93, Train AD: 63
# Fold 2 Epoch 1: TotalLoss=0.811037 | Sup=0.771862 | Recon=0.043528 | TrainAcc=0.3910
# Fold 2 Epoch 100: TotalLoss=0.163279 | Sup=0.160967 | Recon=0.002569 | TrainAcc=0.9808
# Fold 2 Epoch 200: TotalLoss=0.053215 | Sup=0.052123 | Recon=0.001214 | TrainAcc=1.0000
# Fold 2 Epoch 300: TotalLoss=0.020555 | Sup=0.019943 | Recon=0.000680 | TrainAcc=1.0000
# Fold 2 Epoch 400: TotalLoss=0.010153 | Sup=0.009683 | Recon=0.000522 | TrainAcc=1.0000
# Fold 2 Epoch 500: TotalLoss=0.006077 | Sup=0.005705 | Recon=0.000413 | TrainAcc=1.0000
# Fold 2 Epoch 600: TotalLoss=0.004907 | Sup=0.004591 | Recon=0.000351 | TrainAcc=1.0000
# Fold 2 Epoch 700: TotalLoss=0.003030 | Sup=0.002774 | Recon=0.000285 | TrainAcc=1.0000
# Fold 2 Epoch 800: TotalLoss=0.002677 | Sup=0.002459 | Recon=0.000243 | TrainAcc=1.0000
# Fold 2 Epoch 900: TotalLoss=0.002552 | Sup=0.002360 | Recon=0.000213 | TrainAcc=1.0000
# Fold 2 Epoch 1000: TotalLoss=0.001552 | Sup=0.001378 | Recon=0.000193 | TrainAcc=1.0000
# Fold 2 Epoch 1100: TotalLoss=0.001402 | Sup=0.001247 | Recon=0.000171 | TrainAcc=1.0000
# Fold 2 Epoch 1200: TotalLoss=0.001252 | Sup=0.001110 | Recon=0.000157 | TrainAcc=1.0000
# Fold 2 Epoch 1300: TotalLoss=0.001270 | Sup=0.001135 | Recon=0.000149 | TrainAcc=1.0000
# Fold 2 Epoch 1400: TotalLoss=0.001004 | Sup=0.000880 | Recon=0.000138 | TrainAcc=1.0000
# Fold 2 Epoch 1500: TotalLoss=0.001049 | Sup=0.000928 | Recon=0.000134 | TrainAcc=1.0000
# Fold 2 Epoch 1600: TotalLoss=0.000776 | Sup=0.000658 | Recon=0.000131 | TrainAcc=1.0000
# Fold 2 Epoch 1700: TotalLoss=0.000720 | Sup=0.000605 | Recon=0.000127 | TrainAcc=1.0000
# Fold 2 Epoch 1800: TotalLoss=0.000681 | Sup=0.000567 | Recon=0.000126 | TrainAcc=1.0000
# Fold 2 Epoch 1900: TotalLoss=0.000640 | Sup=0.000527 | Recon=0.000126 | TrainAcc=1.0000
# Fold 2 Epoch 2000: TotalLoss=0.000574 | Sup=0.000464 | Recon=0.000123 | TrainAcc=1.0000
# Fold 2 → Acc=0.9552 | Prec=0.9286 | Rec=0.9630 | F1=0.9455 | AUC=0.9889 | CE Loss=0.1961
#
# === Fold 3 ===
# Train CN: 93, Train AD: 63
# Fold 3 Epoch 1: TotalLoss=0.786366 | Sup=0.745291 | Recon=0.045639 | TrainAcc=0.5962
# Fold 3 Epoch 100: TotalLoss=0.175227 | Sup=0.172849 | Recon=0.002642 | TrainAcc=0.9679
# Fold 3 Epoch 200: TotalLoss=0.045035 | Sup=0.044006 | Recon=0.001142 | TrainAcc=1.0000
# Fold 3 Epoch 300: TotalLoss=0.017520 | Sup=0.016858 | Recon=0.000735 | TrainAcc=1.0000
# Fold 3 Epoch 400: TotalLoss=0.009455 | Sup=0.008998 | Recon=0.000508 | TrainAcc=1.0000
# Fold 3 Epoch 500: TotalLoss=0.005734 | Sup=0.005374 | Recon=0.000399 | TrainAcc=1.0000
# Fold 3 Epoch 600: TotalLoss=0.004151 | Sup=0.003866 | Recon=0.000317 | TrainAcc=1.0000
# Fold 3 Epoch 700: TotalLoss
| TrainAcc=1.0000
# Fold 5 Epoch 800: TotalLoss=0.002404 | Sup=0.002194 | Recon=0.000233 | TrainAcc=1.0000
# Fold 5 Epoch 900: TotalLoss=0.002092 | Sup=0.001909 | Recon=0.000203 | TrainAcc=1.0000
# Fold 5 Epoch 1000: TotalLoss=0.001588 | Sup=0.001425 | Recon=0.000181 | TrainAcc=1.0000
# Fold 5 Epoch 1100: TotalLoss=0.001283 | Sup=0.001135 | Recon=0.000165 | TrainAcc=1.0000
# Fold 5 Epoch 1200: TotalLoss=0.001155 | Sup=0.001014 | Recon=0.000156 | TrainAcc=1.0000
# Fold 5 Epoch 1300: TotalLoss=0.000990 | Sup=0.000862 | Recon=0.000142 | TrainAcc=1.0000
# Fold 5 Epoch 1400: TotalLoss=0.001040 | Sup=0.000914 | Recon=0.000140 | TrainAcc=1.0000
# Fold 5 Epoch 1500: TotalLoss=0.000901 | Sup=0.000780 | Recon=0.000134 | TrainAcc=1.0000
# Fold 5 Epoch 1600: TotalLoss=0.000803 | Sup=0.000689 | Recon=0.000128 | TrainAcc=1.0000
# Fold 5 Epoch 1700: TotalLoss=0.000671 | Sup=0.000553 | Recon=0.000130 | TrainAcc=1.0000
# Fold 5 Epoch 1800: TotalLoss=0.000657 | Sup=0.000539 | Recon=0.000131 | TrainAcc=1.0000
# Fold 5 Epoch 1900: TotalLoss=0.000662 | Sup=0.000547 | Recon=0.000128 | TrainAcc=1.0000
# Fold 5 Epoch 2000: TotalLoss=0.000533 | Sup=0.000421 | Recon=0.000125 | TrainAcc=1.0000
# Fold 5 → Acc=0.9403 | Prec=0.9259 | Rec=0.9259 | F1=0.9259 | AUC=0.9907 | CE Loss=0.1620
#
# === Fold 6 ===
# Train CN: 93, Train AD: 63
# Fold 6 Epoch 1: TotalLoss=0.774656 | Sup=0.737839 | Recon=0.040908 | TrainAcc=0.3974
# Fold 6 Epoch 100: TotalLoss=0.150098 | Sup=0.147774 | Recon=0.002582 | TrainAcc=0.9744
# Fold 6 Epoch 200: TotalLoss=0.041034 | Sup=0.040020 | Recon=0.001127 | TrainAcc=1.0000
# Fold 6 Epoch 300: TotalLoss=0.016434 | Sup=0.015843 | Recon=0.000656 | TrainAcc=1.0000
# Fold 6 Epoch 400: TotalLoss=0.009995 | Sup=0.009525 | Recon=0.000521 | TrainAcc=1.0000
# Fold 6 Epoch 500: TotalLoss=0.006173 | Sup=0.005806 | Recon=0.000407 | TrainAcc=1.0000
# Fold 6 Epoch 600: TotalLoss=0.004217 | Sup=0.003929 | Recon=0.000320 | TrainAcc=1.0000
# Fold 6 Epoch 700: TotalLoss=0.002928 | Sup=0.002683 | Recon=0.000272 | TrainAcc=1.0000
# Fold 6 Epoch 800: TotalLoss=0.002417 | Sup=0.002210 | Recon=0.000230 | TrainAcc=1.0000
# Fold 6 Epoch 900: TotalLoss=0.002104 | Sup=0.001920 | Recon=0.000204 | TrainAcc=1.0000
# Fold 6 Epoch 1000: TotalLoss=0.001585 | Sup=0.001420 | Recon=0.000183 | TrainAcc=1.0000
# Fold 6 Epoch 1100: TotalLoss=0.001342 | Sup=0.001193 | Recon=0.000165 | TrainAcc=1.0000
# Fold 6 Epoch 1200: TotalLoss=0.001174 | Sup=0.001033 | Recon=0.000156 | TrainAcc=1.0000
# Fold 6 Epoch 1300: TotalLoss=0.001035 | Sup=0.000902 | Recon=0.000147 | TrainAcc=1.0000
# Fold 6 Epoch 1400: TotalLoss=0.000842 | Sup=0.000718 | Recon=0.000138 | TrainAcc=1.0000
# Fold 6 Epoch 1500: TotalLoss=0.000843 | Sup=0.000719 | Recon=0.000138 | TrainAcc=1.0000
# Fold 6 Epoch 1600: TotalLoss=0.000780 | Sup=0.000662 | Recon=0.000132 | TrainAcc=1.0000
# Fold 6 Epoch 1700: TotalLoss=0.000677 | Sup=0.000563 | Recon=0.000127 | TrainAcc=1.0000
# Fold 6 Epoch 1800: TotalLoss=0.000662 | Sup=0.000548 | Recon=0.000127 | TrainAcc=1.0000
# Fold 6 Epoch 1900: TotalLoss=0.000588 | Sup=0.000473 | Recon=0.000128 | TrainAcc=1.0000
# Fold 6 Epoch 2000: TotalLoss=0.000538 | Sup=0.000425 | Recon=0.000125 | TrainAcc=1.0000
# Fold 6 → Acc=0.9851 | Prec=1.0000 | Rec=0.9630 | F1=0.9811 | AUC=0.9833 | CE Loss=0.1407
#
# === Fold 7 ===
# Train CN: 93, Train AD: 63
# Fold 7 Epoch 1: TotalLoss=0.765820 | Sup=0.732730 | Recon=0.036767 | TrainAcc=0.4038
# Fold 7 Epoch 100: TotalLoss=0.168688 | Sup=0.166492 | Recon=0.002440 | TrainAcc=0.9744
# Fold 7 Epoch 200: TotalLoss=0.047307 | Sup=0.046323 | Recon=0.001094 | TrainAcc=1.0000
# Fold 7 Epoch 300: TotalLoss=0.017864 | Sup=0.017217 | Recon=0.000719 | TrainAcc=1.0000
# Fold 7 Epoch 400: TotalLoss=0.010192 | Sup=0.009730 | Recon=0.000514 | TrainAcc=1.0000
# Fold 7 Epoch 500: TotalLoss=0.006022 | Sup=0.005682 | Recon=0.000378 | TrainAcc=1.0000
# Fold 7 Epoch 600: TotalLoss=0.004514 | Sup=0.004228 | Recon=0.000317 | TrainAcc=1.0000
# Fold 7 Epoch 700: TotalLoss=0.003447 | Sup=0.003207 | Recon=0.000267 | TrainAcc=1.0000
# Fold 7 Epoch 800: TotalLoss=0.002362 | Sup=0.002161 | Recon=0.000223 | TrainAcc=1.0000
# Fold 7 Epoch 900: TotalLoss=0.001839 | Sup=0.001663 | Recon=0.000195 | TrainAcc=1.0000
# Fold 7 Epoch 1000: TotalLoss=0.001733 | Sup=0.001572 | Recon=0.000179 | TrainAcc=1.0000
# Fold 7 Epoch 1100: TotalLoss=0.001474 | Sup=0.001326 | Recon=0.000164 | TrainAcc=1.0000
# Fold 7 Epoch 1200: TotalLoss=0.001168 | Sup=0.001036 | Recon=0.000147 | TrainAcc=1.0000
# Fold 7 Epoch 1300: TotalLoss=0.001040 | Sup=0.000912 | Recon=0.000141 | TrainAcc=1.0000
# Fold 7 Epoch 1400: TotalLoss=0.001015 | Sup=0.000891 | Recon=0.000138 | TrainAcc=1.0000
# Fold 7 Epoch 1500: TotalLoss=0.000893 | Sup=0.000775 | Recon=0.000131 | TrainAcc=1.0000
# Fold 7 Epoch 1600: TotalLoss=0.000737 | Sup=0.000617 | Recon=0.000133 | TrainAcc=1.0000
# Fold 7 Epoch 1700: TotalLoss=0.000698 | Sup=0.000586 | Recon=0.000125 | TrainAcc=1.0000
# Fold 7 Epoch 1800: TotalLoss=0.000629 | Sup=0.000517 | Recon=0.000125 | TrainAcc=1.0000
# Fold 7 Epoch 1900: TotalLoss=0.000576 | Sup=0.000464 | Recon=0.000125 | TrainAcc=1.0000
# Fold 7 Epoch 2000: TotalLoss=0.000570 | Sup=0.000460 | Recon=0.000122 | TrainAcc=1.0000
# Fold 7 → Acc=0.9403 | Prec=0.9600 | Rec=0.8889 | F1=0.9231 | AUC=0.9935 | CE Loss=0.2064
#
# === Fold 8 ===
# Train CN: 93, Train AD: 63
# Fold 8 Epoch 1: TotalLoss=0.851571 | Sup=0.817459 | Recon=0.037902 | TrainAcc=0.4038
# Fold 8 Epoch 100: TotalLoss=0.194216 | Sup=0.192144 | Recon=0.002303 | TrainAcc=0.9679
# Fold 8 Epoch 200: TotalLoss=0.052395 | Sup=0.051383 | Recon=0.001125 | TrainAcc=1.0000
# Fold 8 Epoch 300: TotalLoss=0.020948 | Sup=0.020300 | Recon=0.000720 | TrainAcc=1.0000
# Fold 8 Epoch 400: TotalLoss=0.011141 | Sup=0.010664 | Recon=0.000530 | TrainAcc=1.0000
# Fold 8 Epoch 500: TotalLoss=0.007580 | Sup=0.007223 | Recon=0.000397 | TrainAcc=1.0000
# Fold 8 Epoch 600: TotalLoss=0.004549 | Sup=0.004261 | Recon=0.000321 | TrainAcc=1.0000
# Fold 8 Epoch 700: TotalLoss=0.003620 | Sup=0.003375 | Recon=0.000272 | TrainAcc=1.0000
# Fold 8 Epoch 800: TotalLoss=0.002710 | Sup=0.002501 | Recon=0.000233 | TrainAcc=1.0000
# Fold 8 Epoch 900: TotalLoss=0.002321 | Sup=0.002143 | Recon=0.000197 | TrainAcc=1.0000
# Fold 8 Epoch 1000: TotalLoss=0.001700 | Sup=0.001539 | Recon=0.000180 | TrainAcc=1.0000
# Fold 8 Epoch 1100: TotalLoss=0.001502 | Sup=0.001355 | Recon=0.000163 | TrainAcc=1.0000
# Fold 8 Epoch 1200: TotalLoss=0.001340 | Sup=0.001206 | Recon=0.000149 | TrainAcc=1.0000
# Fold 8 Epoch 1300: TotalLoss=0.001158 | Sup=0.001032 | Recon=0.000140 | TrainAcc=1.0000
# Fold 8 Epoch 1400: TotalLoss=0.001010 | Sup=0.000893 | Recon=0.000130 | TrainAcc=1.0000
# Fold 8 Epoch 1500: TotalLoss=0.000919 | Sup=0.000803 | Recon=0.000129 | TrainAcc=1.0000
# Fold 8 Epoch 1600: TotalLoss=0.000841 | Sup=0.000730 | Recon=0.000123 | TrainAcc=1.0000
# Fold 8 Epoch 1700: TotalLoss=0.000743 | Sup=0.000634 | Recon=0.000121 | TrainAcc=1.0000
# Fold 8 Epoch 1800: TotalLoss=0.000678 | Sup=0.000567 | Recon=0.000123 | TrainAcc=1.0000
# Fold 8 Epoch 1900: TotalLoss=0.000701 | Sup=0.000593 | Recon=0.000120 | TrainAcc=1.0000
# Fold 8 Epoch 2000: TotalLoss=0.000641 | Sup=0.000535 | Recon=0.000118 | TrainAcc=1.0000
# Fold 8 → Acc=0.9552 | Prec=0.9615 | Rec=0.9259 | F1=0.9434 | AUC=0.9917 | CE Loss=0.1624
#
# === Fold 9 ===
# Train CN: 93, Train AD: 63
# Fold 9 Epoch 1: TotalLoss=0.799819 | Sup=0.762453 | Recon=0.041517 | TrainAcc=0.3974
# Fold 9 Epoch 100: TotalLoss=0.159701 | Sup=0.157481 | Recon=0.002467 | TrainAcc=0.9744
# Fold 9 Epoch 200: TotalLoss=0.048145 | Sup=0.047103 | Recon=0.001158 | TrainAcc=1.0000
# Fold 9 Epoch 300: TotalLoss=0.018494 | Sup=0.017920 | Recon=0.000638 | TrainAcc=1.0000
# Fold 9 Epoch 400: TotalLoss=0.010247 | Sup=0.009848 | Recon=0.000442 | TrainAcc=1.0000
# Fold 9 Epoch 500: TotalLoss=0.006063 | Sup=0.005747 | Recon=0.000351 | TrainAcc=1.0000
# Fold 9 Epoch 600: TotalLoss=0.004609 | Sup=0.004343 | Recon=0.000295 | TrainAcc=1.0000
# Fold 9 Epoch 700: TotalLoss=0.003247 | Sup=0.003020 | Recon=0.000253 | TrainAcc=1.0000
# Fold 9 Epoch 800: TotalLoss=0.002353 | Sup=0.002156 | Recon=0.000218 | TrainAcc=1.0000
# Fold 9 Epoch 900: TotalLoss=0.002318 | Sup=0.002139 | Recon=0.000199 | TrainAcc=1.0000
# Fold 9 Epoch 1000: TotalLoss=0.001715 | Sup=0.001556 | Recon=0.000177 | TrainAcc=1.0000
# Fold 9 Epoch 1100: TotalLoss=0.001399 | Sup=0.001254 | Recon=0.000162 | TrainAcc=1.0000
# Fold 9 Epoch 1200: TotalLoss=0.001183 | Sup=0.001045 | Recon=0.000153 | TrainAcc=1.0000
# Fold 9 Epoch 1300: TotalLoss=0.001176 | Sup=0.001043 | Recon=0.000147 | TrainAcc=1.0000
# Fold 9 Epoch 1400: TotalLoss=0.000910 | Sup=0.000788 | Recon=0.000136 | TrainAcc=1.0000
# Fold 9 Epoch 1500: TotalLoss=0.
| TrainAcc=1.0000
# Fold 11 Epoch 1700: TotalLoss=0.000707 | Sup=0.000593 | Recon=0.000127 | TrainAcc=1.0000
# Fold 11 Epoch 1800: TotalLoss=0.000691 | Sup=0.000577 | Recon=0.000127 | TrainAcc=1.0000
# Fold 11 Epoch 1900: TotalLoss=0.000624 | Sup=0.000514 | Recon=0.000122 | TrainAcc=1.0000
# Fold 11 Epoch 2000: TotalLoss=0.000550 | Sup=0.000438 | Recon=0.000123 | TrainAcc=1.0000
# Fold 11 → Acc=0.9403 | Prec=0.9600 | Rec=0.8889 | F1=0.9231 | AUC=0.9519 | CE Loss=0.3611
#
# === Fold 12 ===
# Train CN: 93, Train AD: 63
# Fold 12 Epoch 1: TotalLoss=0.821880 | Sup=0.788415 | Recon=0.037183 | TrainAcc=0.3974
# Fold 12 Epoch 100: TotalLoss=0.178557 | Sup=0.176420 | Recon=0.002375 | TrainAcc=0.9615
# Fold 12 Epoch 200: TotalLoss=0.050528 | Sup=0.049530 | Recon=0.001109 | TrainAcc=1.0000
# Fold 12 Epoch 300: TotalLoss=0.021864 | Sup=0.021233 | Recon=0.000702 | TrainAcc=1.0000
# Fold 12 Epoch 400: TotalLoss=0.010574 | Sup=0.010131 | Recon=0.000492 | TrainAcc=1.0000
# Fold 12 Epoch 500: TotalLoss=0.006928 | Sup=0.006575 | Recon=0.000392 | TrainAcc=1.0000
# Fold 12 Epoch 600: TotalLoss=0.004468 | Sup=0.004176 | Recon=0.000325 | TrainAcc=1.0000
# Fold 12 Epoch 700: TotalLoss=0.003407 | Sup=0.003165 | Recon=0.000268 | TrainAcc=1.0000
# Fold 12 Epoch 800: TotalLoss=0.002721 | Sup=0.002509 | Recon=0.000236 | TrainAcc=1.0000
# Fold 12 Epoch 900: TotalLoss=0.002218 | Sup=0.002035 | Recon=0.000203 | TrainAcc=1.0000
# Fold 12 Epoch 1000: TotalLoss=0.001906 | Sup=0.001747 | Recon=0.000176 | TrainAcc=1.0000
# Fold 12 Epoch 1100: TotalLoss=0.001513 | Sup=0.001366 | Recon=0.000163 | TrainAcc=1.0000
# Fold 12 Epoch 1200: TotalLoss=0.001249 | Sup=0.001118 | Recon=0.000145 | TrainAcc=1.0000
# Fold 12 Epoch 1300: TotalLoss=0.001080 | Sup=0.000954 | Recon=0.000139 | TrainAcc=1.0000
# Fold 12 Epoch 1400: TotalLoss=0.001054 | Sup=0.000932 | Recon=0.000136 | TrainAcc=1.0000
# Fold 12 Epoch 1500: TotalLoss=0.000903 | Sup=0.000784 | Recon=0.000131 | TrainAcc=1.0000
# Fold 12 Epoch 1600: TotalLoss=0.000937 | Sup=0.000819 | Recon=0.000132 | TrainAcc=1.0000
# Fold 12 Epoch 1700: TotalLoss=0.000821 | Sup=0.000705 | Recon=0.000129 | TrainAcc=1.0000
# Fold 12 Epoch 1800: TotalLoss=0.000729 | Sup=0.000616 | Recon=0.000126 | TrainAcc=1.0000
# Fold 12 Epoch 1900: TotalLoss=0.000632 | Sup=0.000517 | Recon=0.000128 | TrainAcc=1.0000
# Fold 12 Epoch 2000: TotalLoss=0.000625 | Sup=0.000515 | Recon=0.000123 | TrainAcc=1.0000
# Fold 12 → Acc=0.9701 | Prec=0.9310 | Rec=1.0000 | F1=0.9643 | AUC=0.9963 | CE Loss=0.1109
#
# === Fold 13 ===
# Train CN: 93, Train AD: 63
# Fold 13 Epoch 1: TotalLoss=0.670387 | Sup=0.632779 | Recon=0.041787 | TrainAcc=0.6603
# Fold 13 Epoch 100: TotalLoss=0.130965 | Sup=0.128865 | Recon=0.002333 | TrainAcc=0.9744
# Fold 13 Epoch 200: TotalLoss=0.034578 | Sup=0.033609 | Recon=0.001077 | TrainAcc=1.0000
# Fold 13 Epoch 300: TotalLoss=0.015884 | Sup=0.015249 | Recon=0.000705 | TrainAcc=1.0000
# Fold 13 Epoch 400: TotalLoss=0.008082 | Sup=0.007618 | Recon=0.000515 | TrainAcc=1.0000
# Fold 13 Epoch 500: TotalLoss=0.005256 | Sup=0.004895 | Recon=0.000401 | TrainAcc=1.0000
# Fold 13 Epoch 600: TotalLoss=0.003623 | Sup=0.003334 | Recon=0.000322 | TrainAcc=1.0000
# Fold 13 Epoch 700: TotalLoss=0.002793 | Sup=0.002552 | Recon=0.000268 | TrainAcc=1.0000
# Fold 13 Epoch 800: TotalLoss=0.002114 | Sup=0.001905 | Recon=0.000232 | TrainAcc=1.0000
# Fold 13 Epoch 900: TotalLoss=0.001772 | Sup=0.001594 | Recon=0.000198 | TrainAcc=1.0000
# Fold 13 Epoch 1000: TotalLoss=0.001473 | Sup=0.001313 | Recon=0.000177 | TrainAcc=1.0000
# Fold 13 Epoch 1100: TotalLoss=0.001397 | Sup=0.001246 | Recon=0.000167 | TrainAcc=1.0000
# Fold 13 Epoch 1200: TotalLoss=0.001062 | Sup=0.000927 | Recon=0.000150 | TrainAcc=1.0000
# Fold 13 Epoch 1300: TotalLoss=0.000967 | Sup=0.000840 | Recon=0.000141 | TrainAcc=1.0000
# Fold 13 Epoch 1400: TotalLoss=0.000861 | Sup=0.000737 | Recon=0.000139 | TrainAcc=1.0000
# Fold 13 Epoch 1500: TotalLoss=0.000830 | Sup=0.000709 | Recon=0.000134 | TrainAcc=1.0000
# Fold 13 Epoch 1600: TotalLoss=0.000783 | Sup=0.000666 | Recon=0.000130 | TrainAcc=1.0000
# Fold 13 Epoch 1700: TotalLoss=0.000698 | Sup=0.000586 | Recon=0.000125 | TrainAcc=1.0000
# Fold 13 Epoch 1800: TotalLoss=0.000609 | Sup=0.000498 | Recon=0.000123 | TrainAcc=1.0000
# Fold 13 Epoch 1900: TotalLoss=0.000539 | Sup=0.000426 | Recon=0.000125 | TrainAcc=1.0000
# Fold 13 Epoch 2000: TotalLoss=0.000554 | Sup=0.000443 | Recon=0.000123 | TrainAcc=1.0000
# Fold 13 → Acc=0.9851 | Prec=0.9643 | Rec=1.0000 | F1=0.9818 | AUC=1.0000 | CE Loss=0.0361
#
# === Fold 14 ===
# Train CN: 93, Train AD: 63
# Fold 14 Epoch 1: TotalLoss=0.941019 | Sup=0.904352 | Recon=0.040741 | TrainAcc=0.3590
# Fold 14 Epoch 100: TotalLoss=0.191568 | Sup=0.189352 | Recon=0.002463 | TrainAcc=0.9551
# Fold 14 Epoch 200: TotalLoss=0.053466 | Sup=0.052420 | Recon=0.001163 | TrainAcc=1.0000
# Fold 14 Epoch 300: TotalLoss=0.023065 | Sup=0.022381 | Recon=0.000760 | TrainAcc=1.0000
# Fold 14 Epoch 400: TotalLoss=0.011222 | Sup=0.010733 | Recon=0.000543 | TrainAcc=1.0000
# Fold 14 Epoch 500: TotalLoss=0.007382 | Sup=0.007002 | Recon=0.000422 | TrainAcc=1.0000
# Fold 14 Epoch 600: TotalLoss=0.005041 | Sup=0.004739 | Recon=0.000336 | TrainAcc=1.0000
# Fold 14 Epoch 700: TotalLoss=0.003307 | Sup=0.003056 | Recon=0.000279 | TrainAcc=1.0000
# Fold 14 Epoch 800: TotalLoss=0.002673 | Sup=0.002462 | Recon=0.000234 | TrainAcc=1.0000
# Fold 14 Epoch 900: TotalLoss=0.002381 | Sup=0.002194 | Recon=0.000208 | TrainAcc=1.0000
# Fold 14 Epoch 1000: TotalLoss=0.001988 | Sup=0.001817 | Recon=0.000190 | TrainAcc=1.0000
# Fold 14 Epoch 1100: TotalLoss=0.001500 | Sup=0.001346 | Recon=0.000171 | TrainAcc=1.0000
# Fold 14 Epoch 1200: TotalLoss=0.001338 | Sup=0.001198 | Recon=0.000156 | TrainAcc=1.0000
# Fold 14 Epoch 1300: TotalLoss=0.001199 | Sup=0.001067 | Recon=0.000146 | TrainAcc=1.0000
# Fold 14 Epoch 1400: TotalLoss=0.001109 | Sup=0.000983 | Recon=0.000140 | TrainAcc=1.0000
# Fold 14 Epoch 1500: TotalLoss=0.000972 | Sup=0.000849 | Recon=0.000137 | TrainAcc=1.0000
# Fold 14 Epoch 1600: TotalLoss=0.000879 | Sup=0.000763 | Recon=0.000128 | TrainAcc=1.0000
# Fold 14 Epoch 1700: TotalLoss=0.000768 | Sup=0.000653 | Recon=0.000128 | TrainAcc=1.0000
# Fold 14 Epoch 1800: TotalLoss=0.000741 | Sup=0.000626 | Recon=0.000128 | TrainAcc=1.0000
# Fold 14 Epoch 1900: TotalLoss=0.000664 | Sup=0.000550 | Recon=0.000126 | TrainAcc=1.0000
# Fold 14 Epoch 2000: TotalLoss=0.000616 | Sup=0.000503 | Recon=0.000126 | TrainAcc=1.0000
# Fold 14 → Acc=0.9403 | Prec=0.9600 | Rec=0.8889 | F1=0.9231 | AUC=0.9787 | CE Loss=0.2522
#
# === Fold 15 ===
# Train CN: 93, Train AD: 63
# Fold 15 Epoch 1: TotalLoss=0.743902 | Sup=0.708705 | Recon=0.039108 | TrainAcc=0.6026
# Fold 15 Epoch 100: TotalLoss=0.131647 | Sup=0.129449 | Recon=0.002442 | TrainAcc=0.9744
# Fold 15 Epoch 200: TotalLoss=0.033977 | Sup=0.033013 | Recon=0.001070 | TrainAcc=1.0000
# Fold 15 Epoch 300: TotalLoss=0.013053 | Sup=0.012443 | Recon=0.000678 | TrainAcc=1.0000
# Fold 15 Epoch 400: TotalLoss=0.008517 | Sup=0.008071 | Recon=0.000496 | TrainAcc=1.0000
# Fold 15 Epoch 500: TotalLoss=0.004970 | Sup=0.004609 | Recon=0.000401 | TrainAcc=1.0000
# Fold 15 Epoch 600: TotalLoss=0.003788 | Sup=0.003493 | Recon=0.000328 | TrainAcc=1.0000
# Fold 15 Epoch 700: TotalLoss=0.002381 | Sup=0.002136 | Recon=0.000273 | TrainAcc=1.0000
# Fold 15 Epoch 800: TotalLoss=0.002251 | Sup=0.002030 | Recon=0.000245 | TrainAcc=1.0000
# Fold 15 Epoch 900: TotalLoss=0.001822 | Sup=0.001630 | Recon=0.000213 | TrainAcc=1.0000
# Fold 15 Epoch 1000: TotalLoss=0.001483 | Sup=0.001313 | Recon=0.000189 | TrainAcc=1.0000
# Fold 15 Epoch 1100: TotalLoss=0.001204 | Sup=0.001055 | Recon=0.000166 | TrainAcc=1.0000
# Fold 15 Epoch 1200: TotalLoss=0.000962 | Sup=0.000820 | Recon=0.000158 | TrainAcc=1.0000
# Fold 15 Epoch 1300: TotalLoss=0.000936 | Sup=0.000806 | Recon=0.000145 | TrainAcc=1.0000
# Fold 15 Epoch 1400: TotalLoss=0.000738 | Sup=0.000613 | Recon=0.000139 | TrainAcc=1.0000
# Fold 15 Epoch 1500: TotalLoss=0.000750 | Sup=0.000629 | Recon=0.000134 | TrainAcc=1.0000
# Fold 15 Epoch 1600: TotalLoss=0.000652 | Sup=0.000534 | Recon=0.000131 | TrainAcc=1.0000
# Fold 15 Epoch 1700: TotalLoss=0.000593 | Sup=0.000478 | Recon=0.000127 | TrainAcc=1.0000
# Fold 15 Epoch 1800: TotalLoss=0.000595 | Sup=0.000478 | Recon=0.000130 | TrainAcc=1.0000
# Fold 15 Epoch 1900: TotalLoss=0.000512 | Sup=0.000397 | Recon=0.000127 | TrainAcc=1.0000
# Fold 15 Epoch 2000: TotalLoss=0.000500 | Sup=0.000387 | Recon=0.000125 | TrainAcc=1.0000
# Fold 15 → Acc=0.8806 | Prec=0.8519 | Rec=0.8519 | F1=0.8519 | AUC=0.9398 | CE Loss=0.5404
#
# === Fold 16 ===
# Train CN: 93, Train AD: 63
# Fold 16 Epoch 1: TotalLoss=0.809233 | Sup=0.771008 | Recon=0.042472 | TrainAcc=0.4038
# Fold 16 Epoch 100: TotalLoss=0.145649 | Sup=0.143353 | Recon=0.002551 | TrainAcc=0.9615
# Fold 16 Epoch 200: TotalLoss=0.043780 | Sup=0.042739 | Recon=0.001157 | TrainAcc=1.0000
# Fold 16 Epoch 300: TotalLoss=0.018574 | Sup=0.017936 | Recon=0.000709 | TrainAcc=1.0000
# Fold 16 Epoch 400: TotalLoss=0.008624 | Sup=0.008153 | Recon=0.000524 | TrainAcc=1.0000
# Fold 16 Epoch 500: TotalLoss=0.005833 | Sup=0.005466 | Recon=0.000408 | TrainAcc=1.0000
# Fold 16 Epoch 600: TotalLoss=0.004503 | Sup=0.004218 | Recon=0.000317 | TrainAcc=1.0000
# Fold 16 Epoch 700: TotalLoss=0.003033 | Sup=0.002793 | Recon=0.000267 | TrainAcc=1.0000
# Fold 16 Epoch 800: TotalLoss=0.002667 | Sup=0.002463 | Recon=0.000227 | TrainAcc=1.0000
# Fold 16 Epoch 900: TotalLoss=0.001871 | Sup=0.001690 | Recon=0.000200 | TrainAcc=1.0000
# Fold 16 Epoch 1000: TotalLoss=0.001757 | Sup=0.001596 | Recon=0.000178 | TrainAcc=1.0000
# Fold 16 Epoch 1100: TotalLoss=0.001418 | Sup=0.001272 | Recon=0.000163 | TrainAcc=1.0000
# Fold 16 Epoch 1200: TotalLoss=0.001147 | Sup=0.001007 | Recon=0.000156 | TrainAcc=1.0000
# Fold 16 Epoch 1300: TotalLoss=0.001065 | Sup=0.000934 | Recon=0.000145 | TrainAcc=1.0000
# Fold 16 Epoch 1400: TotalLoss=0.000877 | Sup=0.000752 | Recon=0.000139 | TrainAcc=1.0000
# Fold 16 Epoch 1500: TotalLoss=0.000820 | Sup=0.000699 | Recon=0.000134 | TrainAcc=1.0000
# Fold 16 Epoch 1600: TotalLoss=0.000823 | Sup=0.000703 | Recon=0.000133 | TrainAcc=1.0000
# Fold 16 Epoch 1700: TotalLoss=0.000716 | Sup=0.000600 | Recon=0.000129 | TrainAcc=1.0000
# Fold 16 Epoch 1800: TotalLoss=0.000635 | Sup=0.000522 | Recon=0.000126 | TrainAcc=1.0000
# Fold 16 Epoch 1900: TotalLoss=0.000678 | Sup=0.000564 | Recon=0.000127 | TrainAcc=1.0000
# Fold 16 Epoch 2000: TotalLoss=0.000609 | Sup=0.000494 | Recon=0.000128 | TrainAcc=1.0000
# Fold 16 → Acc=0.9104 | Prec=0.8387 | Rec=0.9630 | F1=0.8966 | AUC=0.9889 | CE Loss=0.2518
#
# === Fold 17 ===
# Train CN: 93, Train AD: 63
# Fold 17 Epoch 1: TotalLoss=0.861968 | Sup=0.827244 | Recon=0.038583 | TrainAcc=0.4038
# Fold 17 Epoch 100: TotalLoss=0.150232 | Sup=0.148161 | Recon=0.002301 | TrainAcc=0.9679
# Fold 17 Epoch 200: TotalLoss=0.047191 | Sup=0.046260 | Recon=0.001035 | TrainAcc=1.0000
# Fold 17 Epoch 300: TotalLoss=0.018829 | Sup=0.018224 | Recon=0.000672 | TrainAcc=1.0000
# Fold 17 Epoch 400: TotalLoss=0.010197 | Sup=0.009748 | Recon=0.000500 | TrainAcc=1.0000
# Fold 17 Epoch 500: TotalLoss=0.006127 | Sup=0.005779 | Recon=0.000387 | TrainAcc=1.0000
# Fold 17 Epoch 600: TotalLoss=0.004723 | Sup=0.004445 | Recon=0.000309 | TrainAcc=1.0000
# Fold 17 Epoch 700: TotalLoss=0.003161 | Sup=0.002927 | Recon=0.000261 | TrainAcc=1.0000
# Fold 17 Epoch 800: TotalLoss=0.002908 | Sup=0.002713 | Recon=0.000217 | TrainAcc=1.0000
# Fold 17 Epoch 900: TotalLoss=0.002129 | Sup=0.001961 | Recon=0.000187 | TrainAcc=1.0000
# Fold 17 Epoch 1000: TotalLoss=0.001651 | Sup=0.001500 | Recon=0.000168 | TrainAcc=1.0000
# Fold 17 Epoch 1100: TotalLoss=0.001524 | Sup=0.001386 | Recon=0.000154 | TrainAcc=1.0000
# Fold 17 Epoch 1200: TotalLoss=0.001226 | Sup=0.001097 | Recon=0.000143 | TrainAcc=1.0000
# Fold 17 Epoch 1300: TotalLoss=0.001173 | Sup=0.001044 | Recon=0.000144 | TrainAcc=1.0000
# Fold 17 Epoch 1400: TotalLoss=0.000980 | Sup=0.000857 | Recon=0.000137 | TrainAcc=1.0000
# Fold 17 Epoch 1500: TotalLoss=0.000873 | Sup=0.000755 | Recon=0.000131 | TrainAcc=1.0000
# Fold 17 Epoch 1600: TotalLoss=0.000781 | Sup=0.000665 | Recon=0.000129 | TrainAcc=1.0000
# Fold 17 Epoch 1700: TotalLoss=0.000813 | Sup=0.000700 | Recon=0.000125 | TrainAcc=1.0000
# Fold 17 Epoch 1800: TotalLoss=0.000739 | Sup=0.000625 | Recon=0.000127 | TrainAcc=1.0000
# Fold 17 Epoch 1900: TotalLoss=0.000643 | Sup=0.000529 | Recon=0.000127 | TrainAcc=1.0000
# Fold 17 Epoch 2000: TotalLoss=0.000621 | Sup=0.000510 | Recon=0.000123 | TrainAcc=1.0000
# Fold 17 → Acc=0.9403 | Prec=0.9259 | Rec=0.9259 | F1=0.9259 | AUC=0.9833 | CE Loss=0.2882
#
# === Fold 18 ===
# Train CN: 93, Train AD: 63
# Fold 18 Epoch 1: TotalLoss=0.722966 | Sup=0.691392 | Recon=0.035082 | TrainAcc=0.4615
# Fold 18 Epoch 100: TotalLoss=0.148918 | Sup=0.146841 | Recon=0.002308 | TrainAcc=0.9679
# Fold 18 Epoch 200: TotalLoss=0.040909 | Sup=0.039971 | Recon=0.001042 | TrainAcc=1.0000
# Fold 18 Epoch 300: TotalLoss=0.017684 | Sup=0.017089 | Recon=0.000661 | TrainAcc=1.0000
# Fold 18 Epoch 400: TotalLoss=0.009146 | Sup=0.008694 | Recon=0.000502 | TrainAcc=1.0000
# Fold 18 Epoch 500: TotalLoss=0.005977 | Sup=0.005615 | Recon=0.000402 | TrainAcc=1.0000
# Fold 18 Epoch 600: TotalLoss=0.004109 | Sup=0.003820 | Recon=0.000322 | TrainAcc=1.0000
# Fold 18 Epoch 700: TotalLoss=0.002823 | Sup=0.002590 | Recon=0.000259 | TrainAcc=1.0000
# Fold 18 Epoch 800: TotalLoss=0.002137 | Sup=0.001940 | Recon=0.000219 | TrainAcc=1.0000
# Fold 18 Epoch 900: TotalLoss=0.001956 | Sup=0.001777 | Recon=0.000198 | TrainAcc=1.0000
# Fold 18 Epoch 1000: TotalLoss=0.001684 | Sup=0.001526 | Recon=0.000175 | TrainAcc=1.0000
# Fold 18 Epoch 1100: TotalLoss=0.001258 | Sup=0.001117 | Recon=0.000157 | TrainAcc=1.0000
# Fold 18 Epoch 1200: TotalLoss=0.001109 | Sup=0.000978 | Recon=0.000145 | TrainAcc=1.0000
# Fold 18 Epoch 1300: TotalLoss=0.000985 | Sup=0.000859 | Recon=0.000140 | TrainAcc=1.0000
# Fold 18 Epoch 1400: TotalLoss=0.001065 | Sup=0.000943 | Recon=0.000136 | TrainAcc=1.0000
# Fold 18 Epoch 1500: TotalLoss=0.000791 | Sup=0.000675 | Recon=0.000129 | TrainAcc=1.0000
# Fold 18 Epoch 1600: TotalLoss=0.000752 | Sup=0.000637 | Recon=0.000128 | TrainAcc=1.0000
# Fold 18 Epoch 1700: TotalLoss=0.000754 | Sup=0.000639 | Recon=0.000127 | TrainAcc=1.0000
# Fold 18 Epoch 1800: TotalLoss=0.000613 | Sup=0.000506 | Recon=0.000119 | TrainAcc=1.0000
# Fold 18 Epoch 1900: TotalLoss=0.000622 | Sup=0.000509 | Recon=0.000126 | TrainAcc=1.0000
# Fold 18 Epoch 2000: TotalLoss=0.000567 | Sup=0.000456 | Recon=0.000124 | TrainAcc=1.0000
# Fold 18 → Acc=0.9403 | Prec=0.9259 | Rec=0.9259 | F1=0.9259 | AUC=0.9907 | CE Loss=0.1583
#
# === Fold 19 ===
# Train CN: 93, Train AD: 63
# Fold 19 Epoch 1: TotalLoss=0.700991 | Sup=0.659963 | Recon=0.045586 | TrainAcc=0.5833
# Fold 19 Epoch 100: TotalLoss=0.142711 | Sup=0.140379 | Recon=0.002591 | TrainAcc=0.9744
# Fold 19 Epoch 200: TotalLoss=0.038267 | Sup=0.037284 | Recon=0.001093 | TrainAcc=1.0000
# Fold 19 Epoch 300: TotalLoss=0.014440 | Sup=0.013876 | Recon=0.000627 | TrainAcc=1.0000
# Fold 19 Epoch 400: TotalLoss=0.008891 | Sup=0.008443 | Recon=0.000497 | TrainAcc=1.0000
# Fold 19 Epoch 500: TotalLoss=0.005029 | Sup=0.004680 | Recon=0.000387 | TrainAcc=1.0000
# Fold 19 Epoch 600: TotalLoss=0.003888 | Sup=0.003599 | Recon=0.000321 | TrainAcc=1.0000
# Fold 19 Epoch 700: TotalLoss=0.002774 | Sup=0.002520 | Recon=0.000282 | TrainAcc=1.0000
# Fold 19 Epoch 800: TotalLoss=0.002208 | Sup=0.001988 | Recon=0.000245 | TrainAcc=1.0000
# Fold 19 Epoch 900: TotalLoss=0.001741 | Sup=0.001544 | Recon=0.000220 | TrainAcc=1.0000
# Fold 19 Epoch 1000: TotalLoss=0.001410 | Sup=0.001238 | Recon=0.000191 | TrainAcc=1.0000
# Fold 19 Epoch 1100: TotalLoss=0.001159 | Sup=0.001001 | Recon=0.000176 | TrainAcc=1.0000
# Fold 19 Epoch 1200: TotalLoss=0.001030 | Sup=0.000884 | Recon=0.000162 | TrainAcc=1.0000
# Fold 19 Epoch 1300: TotalLoss=0.000921 | Sup=0.000787 | Recon=0.000150 | TrainAcc=1.0000
# Fold 19 Epoch 1400: TotalLoss=0.000800 | Sup=0.000673 | Recon=0.000141 | TrainAcc=1.0000
# Fold 19 Epoch 1500: TotalLoss=0.000765 | Sup=0.000641 | Recon=0.000137 | TrainAcc=1.0000
# Fold 19 Epoch 1600: TotalLoss=0.000653 | Sup=0.000532 | Recon=0.000134 | TrainAcc=1.0000
# Fold 19 Epoch 1700: TotalLoss=0.000647 | Sup=0.000533 | Recon=0.000127 | TrainAcc=1.0000
# Fold 19 Epoch 1800: TotalLoss=0.000560 | Sup=0.000447 | Recon=0.000125 | TrainAcc=1.0000
# Fold 19 Epoch 1900: TotalLoss=0.000515 | Sup=0.000404 | Recon=0.000123 | TrainAcc=1.0000
# Fold 19 Epoch 2000: TotalLoss=0.000585 | Sup=0.000472 | Recon=0.000126 | TrainAcc=1.0000
# Fold 19 → Acc=0.9104 | Prec=0.8387 | Rec=0.9630 | F1=0.8966 | AUC=0.9880 | CE Loss=0.2713
#
# === Fold 20 ===
# Train CN: 93, Train AD: 63
# Fold 20 Epoch 1: TotalLoss=0.735549 | Sup=0.697197 | Recon=0.042614 | TrainAcc=0.5833
# Fold 20 Epoch 100: TotalLoss=0.132518 | Sup=0.130281 | Recon=0.002485 | TrainAcc=0.9936
# Fold 20 Epoch 200: TotalLoss=0.036595 | Sup=0.035559 | Recon=0.001151 | TrainAcc=1.0000
# Fold 20 Epoch 300: TotalLoss=0.014516 | Sup=0.013841 | Recon=0.000750 | TrainAcc=1.0000
# Fold 20 Epoch 400: TotalLoss=0.008543 | Sup=0.008046 | Recon=0.000552 | TrainAcc=1.0000
# Fold 20 Epoch 500: TotalLoss=0.005512 | Sup=0.005123 | Recon=0.000432 | TrainAcc=1.0000
# Fold 20 Epoch 600: TotalLoss=0.003507 | Sup=0.003180 | Recon=0.000363 | TrainAcc=1.0000
# Fold 20 Epoch 700: TotalLoss=0.002657 | Sup=0.002383 | Recon=0.000304 | TrainAcc=1.0000
# Fold 20 Epoch 800: TotalLoss=0.002059 | Sup=0.001834 | Recon=0.000251 | TrainAcc=1.0000
# Fold 20 Epoch 900: TotalLoss=0.001686 | Sup=0.001485 | Recon=0.000223 | TrainAcc=1.0000
# Fold 20 Epoch 1000: TotalLoss=0.001437 | Sup=0.001266 | Recon=0.000191 | TrainAcc=1.0000
# Fold 20 Epoch 1100: TotalLoss=0.001268 | Sup=0.001112 | Recon=0.000174 | TrainAcc=1.0000
# Fold 20 Epoch 1200: TotalLoss=0.001125 | Sup=0.000982 | Recon=0.000160 | TrainAcc=1.0000
# Fold 20 Epoch 1300: TotalLoss=0.000928 | Sup=0.000794 | Recon=0.000149 | TrainAcc=1.0000
# Fold 20 Epoch 1400: TotalLoss=0.000881 | Sup=0.000753 | Recon=0.000143 | TrainAcc=1.0000
# Fold 20 Epoch 1500: TotalLoss=0.000792 | Sup=0.000668 | Recon=0.000138 | TrainAcc=1.0000
# Fold 20 Epoch 1600: TotalLoss=0.000676 | Sup=0.000556 | Recon=0.000134 | TrainAcc=1.0000
# Fold 20 Epoch 1700: TotalLoss=0.000671 | Sup=0.000553 | Recon=0.000131 | TrainAcc=1.0000
# Fold 20 Epoch 1800: TotalLoss=0.000593 | Sup=0.000476 | Recon=0.000129 | TrainAcc=1.0000
# Fold 20 Epoch 1900: TotalLoss=0.000550 | Sup=0.000437 | Recon=0.000126 | TrainAcc=1.0000
# Fold 20 Epoch 2000: TotalLoss=0.000512 | Sup=0.000401 | Recon=0.000123 | TrainAcc=1.0000
# Fold 20 → Acc=0.9403 | Prec=0.8710 | Rec=1.0000 | F1=0.9310 | AUC=0.9704 | CE Loss=0.3363
#
# === Average Results Across 20 Folds ===
# Accuracy:  0.9433 ± 0.0243
# Precision: 0.9196 ± 0.0442
# Recall:    0.9444 ± 0.0414
# F1-score:  0.9308 ± 0.0293
# CE Loss:   0.2203 ± 0.1113
# AUC:       0.9832 ± 0.0148

# %%
feats_dim = num_feats
hidden_dim = 512
num_classes = 2
num_epochs = 2000
lr = 1e-4
weight_decay = 1e-4
batch_print_freq = 100

# Lambda values to test
lambda_list = [0.001, 0.005, 0.009, 0.01, 0.05, 0.09, 0.1, 0.3, 0.5, 0.9, 1, 2, 5, 8]

# === Cross-validation setup ===
sss = StratifiedShuffleSplit(n_splits=20, test_size=0.3, random_state=42)
y_all = y.copy()

# To store all results for each lambda
lambda_results = []

# === Outer loop for lambda sweep ===
for lambda_recon in lambda_list:
    print(f"\n\n====================== λ_recon = {lambda_recon} ======================")

    accuracies, precisions, recalls, f1_scores, aucs, ce_losses = [], [], [], [], [], []

    for fold, (train_val_idx, test_idx_global) in enumerate(sss.split(X, y_all), start=1):
        print(f"\n=== Fold {fold} ===")

        control_idx = np.where(y_all == 0)[0]
        patient_idx = np.where(y_all == 1)[0]
        sss_class = StratifiedShuffleSplit(n_splits=20, test_size=0.3, random_state=fold)
        control_train_idx, _ = next(sss_class.split(X[control_idx], y_all[control_idx]))
        patient_train_idx, _ = next(sss_class.split(X[patient_idx], y_all[patient_idx]))
        control_train = control_idx[control_train_idx]
        patient_train = patient_idx[patient_train_idx]
        train_idx_final = np.concatenate([control_train, patient_train])
        np.random.shuffle(train_idx_final)

        print(f"Train Control: {len(control_train)}, Train Patient: {len(patient_train)}")

        train_idx_t = torch.from_numpy(train_idx_final).long().to(device)
        y_train_tensor = torch.from_numpy(y_all[train_idx_final]).long().to(device)

        model = Cheb_AE(feats_dim, hidden_dim, num_classes, device, activ="RELU", dropout=0.25, K=3).to(device)
        optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
        ce_loss_fn = nn.CrossEntropyLoss()
        recon_loss_fn = nn.MSELoss()
        data = load_data(W, X).to(device)

        for epoch in range(1, num_epochs + 1):
            model.train()
            optimizer.zero_grad()
            logits, recon_x, _ = model(data.x, data.edge_index)

            loss_sup = ce_loss_fn(logits[train_idx_t], y_train_tensor)
            loss_recon = recon_loss_fn(recon_x, data.x)
            total_loss = loss_sup + lambda_recon * loss_recon

            if torch.isnan(total_loss) or torch.isinf(total_loss):
                print(f"NaN/Inf detected at fold {fold} epoch {epoch}. Aborting epoch.")
                break

            total_loss.backward()
            optimizer.step()

            if epoch % batch_print_freq == 0 or epoch == 1:
                model.eval()
                with torch.no_grad():
                    logits_eval, _, _ = model(data.x, data.edge_index)
                    preds_train = logits_eval[train_idx_t].argmax(dim=1)
                    acc_train = accuracy_score(y_train_tensor.cpu(), preds_train.cpu())
                print(f"Fold {fold} Epoch {epoch}: TotalLoss={total_loss.item():.6f} | Sup={loss_sup.item():.6f} | Recon={loss_recon.item():.6f} | TrainAcc={acc_train:.4f}")

        # === Evaluation ===
        model.eval()
        with torch.no_grad():
            out_logits, _, _ = model(data.x, data.edge_index)
            preds = out_logits.argmax(dim=1).cpu().numpy()
            probs = nnFn.softmax(out_logits, dim=1)[:, 1].cpu().numpy()

        y_test = y_all[test_idx_global]
        y_pred_test = preds[test_idx_global]
        y_prob_test = probs[test_idx_global]

        acc = accuracy_score(y_test, y_pred_test)
        prec = precision_score(y_test, y_pred_test, zero_division=0)
        rec = recall_score(y_test, y_pred_test, zero_division=0)
        f1 = f1_score(y_test, y_pred_test, zero_division=0)
        try:
            auc = roc_auc_score(y_test, y_prob_test)
        except ValueError:
            auc = float('nan')
        ce = log_loss(y_test, y_prob_test)

        accuracies.append(acc)
        precisions.append(prec)
        recalls.append(rec)
        f1_scores.append(f1)
        aucs.append(auc)
        ce_losses.append(ce)

        print(f"Fold {fold} → Acc={acc:.4f} | Prec={prec:.4f} | Rec={rec:.4f} | F1={f1:.4f} | AUC={auc:.4f} | CE Loss={ce:.4f}")

    # === Store average results for this λ ===
    avg_results = {
        "lambda": lambda_recon,
        "Accuracy": np.mean(accuracies),
        "Precision": np.mean(precisions),
        "Recall": np.mean(recalls),
        "F1-score": np.mean(f1_scores),
        "CE Loss": np.mean(ce_losses),
        "AUC": np.nanmean(aucs)
    }
    lambda_results.append(avg_results)

    print("\n=== Average Results for λ =", lambda_recon, "===")
    print(f"Accuracy:  {avg_results['Accuracy']:.4f}")
    print(f"Precision: {avg_results['Precision']:.4f}")
    print(f"Recall:    {avg_results['Recall']:.4f}")
    print(f"F1-score:  {avg_results['F1-score']:.4f}")
    print(f"CE Loss:   {avg_results['CE Loss']:.4f}")
    print(f"AUC:       {avg_results['AUC']:.4f}")


# === FINAL SUMMARY ACROSS ALL λ ===
print("\n\n====================== FINAL SUMMARY ACROSS ALL λ ======================")
print(f"{'Lambda':<8} | {'Accuracy':<9} | {'Precision':<9} | {'Recall':<8} | {'F1-score':<9} | {'AUC':<8} | {'CE Loss':<8}")
print("-" * 72)
for res in lambda_results:
    print(f"{res['lambda']:<8} | {res['Accuracy']:<9.4f} | {res['Precision']:<9.4f} | {res['Recall']:<8.4f} | {res['F1-score']:<9.4f} | {res['AUC']:<8.4f} | {res['CE Loss']:<8.4f}")
# Out:
# Streaming output truncated to the last 5000 lines.
# === Fold 6 ===
# Train Control: 93, Train Patient: 63
# Fold 6 Epoch 1: TotalLoss=0.704426 | Sup=0.702540 | Recon=0.037722 | TrainAcc=0.5962
# Fold 6 Epoch 100: TotalLoss=0.137242 | Sup=0.137079 | Recon=0.003250 | TrainAcc=0.9936
# Fold 6 Epoch 200: TotalLoss=0.036175 | Sup=0.036104 | Recon=0.001429 | TrainAcc=1.0000
# Fold 6 Epoch 300: TotalLoss=0.014568 | Sup=0.014531 | Recon=0.000752 | TrainAcc=1.0000
# Fold 6 Epoch 400: TotalLoss=0.007775 | Sup=0.007751 | Recon=0.000490 | TrainAcc=1.0000
# Fold 6 Epoch 500: TotalLoss=0.005569 | Sup=0.005549 | Recon=0.000398 | TrainAcc=1.0000
# Fold 6 Epoch 600: TotalLoss=0.003536 | Sup=0.003516 | Recon=0.000390 | TrainAcc=1.0000
# Fold 6 Epoch 700: TotalLoss=0.002288 | Sup=0.002268 | Recon=0.000405 | TrainAcc=1.0000
# Fold 6 Epoch 800: TotalLoss=0.002057 | Sup=0.002036 | Recon=0.000424 | TrainAcc=1.0000
# Fold 6 Epoch 900: TotalLoss=0.001265 | Sup=0.001244 | Recon=0.000432 | TrainAcc=1.0000
# Fold 6 Epoch 1000: TotalLoss=0.001487 | Sup=0.001465 | Recon=0.000444 | TrainAcc=1.0000
# Fold 6 Epoch 1100: TotalLoss=0.001127 | Sup=0.001104 | Recon=0.000450 | TrainAcc=1.0000
# Fold 6 Epoch 1200: TotalLoss=0.000885 | Sup=0.000862 | Recon=0.000455 | TrainAcc=1.0000
# Fold 6 Epoch 1300: TotalLoss=0.000896 | Sup=0.000873 | Recon=0.000461 | TrainAcc=1.0000
# Fold 6 Epoch 1400: TotalLoss=0.000731 | Sup=0.000708 | Recon=0.000466 | TrainAcc=1.0000
# Fold 6 Epoch 1500: TotalLoss=0.000657 | Sup=0.000634 | Recon=0.000463 | TrainAcc=1.0000
# Fold 6 Epoch 1600: TotalLoss=0.000543 | Sup=0.000520 | Recon=0.000466 | TrainAcc=1.0000
# Fold 6 Epoch 1700: TotalLoss=0.000579 | Sup=0.000556 | Recon=0.000468 | TrainAcc=1.0000
# Fold 6 Epoch 1800: TotalLoss=0.000539 | Sup=0.000515 | Recon=0.000470 | TrainAcc=1.0000
# Fold 6 Epoch 1900: TotalLoss=0.000454 | Sup=0.000431 | Recon=0.000474 | TrainAcc=1.0000
# Fold 6 Epoch 2000: TotalLoss=0.000416 | Sup=0.000392 | Recon=0.000470 | TrainAcc=1.0000
# Fold 6 → Acc=0.9851 | Prec=1.0000 | Rec=0.9630 | F1=0.9811 | AUC=0.9963 | CE Loss=0.1194
#
# === Fold 7 ===
# Train Control: 93, Train Patient: 63
# Fold 7 Epoch 1: TotalLoss=0.681218 | Sup=0.679091 | Recon=0.042524 | TrainAcc=0.4231
# Fold 7 Epoch 100: TotalLoss=0.143377 | Sup=0.143213 | Recon=0.003265 | TrainAcc=0.9744
# Fold 7 Epoch 200: TotalLoss=0.040589 | Sup=0.040517 | Recon=0.001430 | TrainAcc=1.0000
# Fold 7 Epoch 300: TotalLoss=0.016069 | Sup=0.016029 | Recon=0.000780 | TrainAcc=1.0000
# Fold 7 Epoch 400: TotalLoss=0.008942 | Sup=0.008916 | Recon=0.000511 | TrainAcc=1.0000
# Fold 7 Epoch 500: TotalLoss=0.005169 | Sup=0.005148 | Recon=0.000411 | TrainAcc=1.0000
# Fold 7 Epoch 600: TotalLoss=0.003697 | Sup=0.003677 | Recon=0.000394 | TrainAcc=1.0000
# Fold 7 Epoch 700: TotalLoss=0.002979 | Sup=0.002959 | Recon=0.000409 | TrainAcc=1.0000
# Fold 7 Epoch 800: TotalLoss=0.001915 | Sup=0.001894 | Recon=0.000425 | TrainAcc=1.0000
# Fold 7 Epoch 900: TotalLoss=0.001807 | Sup=0.001785 | Recon=0.000441 | TrainAcc=1.0000
# Fold 7 Epoch 1000: TotalLoss=0.001484 | Sup=0.001462 | Recon=0.000452 | TrainAcc=1.0000
# Fold 7 Epoch 1100: TotalLoss=0.001292 | Sup=0.001268 | Recon=0.000461 | TrainAcc=1.0000
# Fold 7 Epoch 1200: TotalLoss=0.001054 | Sup=0.001031 | Recon=0.000462 | TrainAcc=1.0000
# Fold 7 Epoch 1300: TotalLoss=0.000918 | Sup=0.000895 | Recon=0.000467 | TrainAcc=1.0000
# Fold 7 Epoch 1400: TotalLoss=0.000870 | Sup=0.000846 | Recon=0.000471 | TrainAcc=1.0000
# Fold 7 Epoch 1500: TotalLoss=0.000748 | Sup=0.000725 | Recon=0.000469 | TrainAcc=1.0000
# Fold 7 Epoch 1600: TotalLoss=0.000646 | Sup=0.000623 | Recon=0.000468 | TrainAcc=1.0000
# Fold 7 Epoch 1700: TotalLoss=0.000674 | Sup=0.000650 | Recon=0.000475 | TrainAcc=1.0000
# Fold 7 Epoch 1800: TotalLoss=0.000557 | Sup=0.000533 | Recon=0.000479 | TrainAcc=1.0000
# Fold 7 Epoch 1900: TotalLoss=0.000542 | Sup=0.000518 | Recon=0.000481 | TrainAcc=1.0000
# Fold 7 Epoch 2000: TotalLoss=0.000470 | Sup=0.000446 | Recon=0.000482 | TrainAcc=1.0000
# Fold 7 → Acc=0.9254 | Prec=0.9231 | Rec=0.8889 | F1=0.9057 | AUC=0.9880 | CE Loss=0.2555
#
# === Fold 8 ===
# Train Control: 93, Train Patient: 63
# Fold 8 Epoch 1: TotalLoss=0.753838 | Sup=0.751726 | Recon=0.042246 | TrainAcc=0.6282
# Fold 8 Epoch 100: TotalLoss=0.186397 | Sup=0.186236 | Recon=0.003229 | TrainAcc=0.9744
# Fold 8 Epoch 200: TotalLoss=0.049385 | Sup=0.049312 | Recon=0.001471 | TrainAcc=1.0000
# Fold 8 Epoch 300: TotalLoss=0.019286 | Sup=0.019247 | Recon=0.000779 | TrainAcc=1.0000
# Fold 8 Epoch 400: TotalLoss=0.009216 | Sup=0.009191 | Recon=0.000504 | TrainAcc=1.0000
# Fold 8 Epoch 500: TotalLoss=0.005876 | Sup=0.005856 | Recon=0.000402 | TrainAcc=1.0000
# Fold 8 Epoch 600: TotalLoss=0.004563 | Sup=0.004544 | Recon=0.000384 | TrainAcc=1.0000
# Fold 8 Epoch 700: TotalLoss=0.002904 | Sup=0.002884 | Recon=0.000399 | TrainAcc=1.0000
# Fold 8 Epoch 800: TotalLoss=0.002228 | Sup=0.002207 | Recon=0.000416 | TrainAcc=1.0000
# Fold 8 Epoch 900: TotalLoss=0.001876 | Sup=0.001855 | Recon=0.000433 | TrainAcc=1.0000
# Fold 8 Epoch 1000: TotalLoss=0.001644 | Sup=0.001622 | Recon=0.000445 | TrainAcc=1.0000
# Fold 8 Epoch 1100: TotalLoss=0.001131 | Sup=0.001109 | Recon=0.000449 | TrainAcc=1.0000
# Fold 8 Epoch 1200: TotalLoss=0.001064 | Sup=0.001042 | Recon=0.000455 | TrainAcc=1.0000
# Fold 8 Epoch 1300: TotalLoss=0.000921 | Sup=0.000898 | Recon=0.000462 | TrainAcc=1.0000
# Fold 8 Epoch 1400: TotalLoss=0.000893 | Sup=0.000870 | Recon=0.000465 | TrainAcc=1.0000
# Fold 8 Epoch 1500: TotalLoss=0.000771 | Sup=0.000747 | Recon=0.000465 | TrainAcc=1.0000
# Fold 8 Epoch 1600: TotalLoss=0.000621 | Sup=0.000598 | Recon=0.000466 | TrainAcc=1.0000
# Fold 8 Epoch 1700: TotalLoss=0.000579 | Sup=0.000555 | Recon=0.000472 | TrainAcc=1.0000
# Fold 8 Epoch 1800: TotalLoss=0.000555 | Sup=0.000531 | Recon=0.000473 | TrainAcc=1.0000
# Fold 8 Epoch 1900: TotalLoss=0.000557 | Sup=0.000533 | Recon=0.000478 | TrainAcc=1.0000
# Fold 8 Epoch 2000: TotalLoss=0.000545 | Sup=0.000521 | Recon=0.000478 | TrainAcc=1.0000
# Fold 8 → Acc=0.9552 | Prec=0.9615 | Rec=0.9259 | F1=0.9434 | AUC=0.9907 | CE Loss=0.1834
#
# === Fold 9 ===
# Train Control: 93, Train Patient: 63
# Fold 9 Epoch 1: TotalLoss=0.681571 | Sup=0.679472 | Recon=0.041980 | TrainAcc=0.5833
# Fold 9 Epoch 100: TotalLoss=0.147160 | Sup=0.146995 | Recon=0.003301 | TrainAcc=0.9744
# Fold 9 Epoch 200: TotalLoss=0.040684 | Sup=0.040610 | Recon=0.001482 | TrainAcc=1.0000
# Fold 9 Epoch 300: TotalLoss=0.016629 | Sup=0.016590 | Recon=0.000780 | TrainAcc=1.0000
# Fold 9 Epoch 400: TotalLoss=0.007059 | Sup=0.007035 | Recon=0.000494 | TrainAcc=1.0000
# Fold 9 Epoch 500: TotalLoss=0.005152 | Sup=0.005132 | Recon=0.000406 | TrainAcc=1.0000
# Fold 9 Epoch 600: TotalLoss=0
| TrainAcc=1.0000
# Fold 13 Epoch 800: TotalLoss=0.002334 | Sup=0.002313 | Recon=0.000424 | TrainAcc=1.0000
# Fold 13 Epoch 900: TotalLoss=0.002131 | Sup=0.002110 | Recon=0.000435 | TrainAcc=1.0000
# Fold 13 Epoch 1000: TotalLoss=0.001448 | Sup=0.001425 | Recon=0.000447 | TrainAcc=1.0000
# Fold 13 Epoch 1100: TotalLoss=0.001259 | Sup=0.001236 | Recon=0.000451 | TrainAcc=1.0000
# Fold 13 Epoch 1200: TotalLoss=0.001295 | Sup=0.001272 | Recon=0.000460 | TrainAcc=1.0000
# Fold 13 Epoch 1300: TotalLoss=0.000957 | Sup=0.000934 | Recon=0.000461 | TrainAcc=1.0000
# Fold 13 Epoch 1400: TotalLoss=0.000773 | Sup=0.000750 | Recon=0.000461 | TrainAcc=1.0000
# Fold 13 Epoch 1500: TotalLoss=0.000907 | Sup=0.000883 | Recon=0.000470 | TrainAcc=1.0000
# Fold 13 Epoch 1600: TotalLoss=0.000750 | Sup=0.000727 | Recon=0.000467 | TrainAcc=1.0000
# Fold 13 Epoch 1700: TotalLoss=0.000684 | Sup=0.000661 | Recon=0.000471 | TrainAcc=1.0000
# Fold 13 Epoch 1800: TotalLoss=0.000601 | Sup=0.000577 | Recon=0.000475 | TrainAcc=1.0000
# Fold 13 Epoch 1900: TotalLoss=0.000505 | Sup=0.000481 | Recon=0.000471 | TrainAcc=1.0000
# Fold 13 Epoch 2000: TotalLoss=0.000467 | Sup=0.000443 | Recon=0.000476 | TrainAcc=1.0000
# Fold 13 → Acc=0.9851 | Prec=0.9643 | Rec=1.0000 | F1=0.9818 | AUC=1.0000 | CE Loss=0.0349
#
# === Fold 14 ===
# Train Control: 93, Train Patient: 63
# Fold 14 Epoch 1: TotalLoss=0.595667 | Sup=0.593518 | Recon=0.042983 | TrainAcc=0.6987
# Fold 14 Epoch 100: TotalLoss=0.133790 | Sup=0.133626 | Recon=0.003273 | TrainAcc=0.9936
# Fold 14 Epoch 200: TotalLoss=0.030588 | Sup=0.030515 | Recon=0.001465 | TrainAcc=1.0000
# Fold 14 Epoch 300: TotalLoss=0.013805 | Sup=0.013764 | Recon=0.000802 | TrainAcc=1.0000
# Fold 14 Epoch 400: TotalLoss=0.007418 | Sup=0.007393 | Recon=0.000501 | TrainAcc=1.0000
# Fold 14 Epoch 500: TotalLoss=0.004397 | Sup=0.004376 | Recon=0.000404 | TrainAcc=1.0000
# Fold 14 Epoch 600: TotalLoss=0.003008 | Sup=0.002988 | Recon=0.000389 | TrainAcc=1.0000
# Fold 14 Epoch 700: TotalLoss=0.002135 | Sup=0.002115 | Recon=0.000403 | TrainAcc=1.0000
# Fold 14 Epoch 800: TotalLoss=0.001721 | Sup=0.001700 | Recon=0.000420 | TrainAcc=1.0000
# Fold 14 Epoch 900: TotalLoss=0.001271 | Sup=0.001249 | Recon=0.000436 | TrainAcc=1.0000
# Fold 14 Epoch 1000: TotalLoss=0.001135 | Sup=0.001112 | Recon=0.000449 | TrainAcc=1.0000
# Fold 14 Epoch 1100: TotalLoss=0.000941 | Sup=0.000918 | Recon=0.000457 | TrainAcc=1.0000
# Fold 14 Epoch 1200: TotalLoss=0.000875 | Sup=0.000852 | Recon=0.000462 | TrainAcc=1.0000
# Fold 14 Epoch 1300: TotalLoss=0.000805 | Sup=0.000782 | Recon=0.000466 | TrainAcc=1.0000
# Fold 14 Epoch 1400: TotalLoss=0.000687 | Sup=0.000664 | Recon=0.000470 | TrainAcc=1.0000
# Fold 14 Epoch 1500: TotalLoss=0.000654 | Sup=0.000631 | Recon=0.000476 | TrainAcc=1.0000
# Fold 14 Epoch 1600: TotalLoss=0.000553 | Sup=0.000529 | Recon=0.000474 | TrainAcc=1.0000
# Fold 14 Epoch 1700: TotalLoss=0.000503 | Sup=0.000479 | Recon=0.000482 | TrainAcc=1.0000
# Fold 14 Epoch 1800: TotalLoss=0.000461 | Sup=0.000437 | Recon=0.000475 | TrainAcc=1.0000
# Fold 14 Epoch 1900: TotalLoss=0.000410 | Sup=0.000386 | Recon=0.000481 | TrainAcc=1.0000
# Fold 14 Epoch 2000: TotalLoss=0.000487 | Sup=0.000463 | Recon=0.000483 | TrainAcc=1.0000
# Fold 14 → Acc=0.9403 | Prec=0.9600 | Rec=0.8889 | F1=0.9231 | AUC=0.9574 | CE Loss=0.2898
#
# === Fold 15 ===
# Train Control: 93, Train Patient: 63
# Fold 15 Epoch 1: TotalLoss=0.789620 | Sup=0.787521 | Recon=0.041969 | TrainAcc=0.5962
# Fold 15 Epoch 100: TotalLoss=0.137431 | Sup=0.137269 | Recon=0.003250 | TrainAcc=0.9679
# Fold 15 Epoch 200: TotalLoss=0.037696 | Sup=0.037624 | Recon=0.001441 | TrainAcc=1.0000
# Fold 15 Epoch 300: TotalLoss=0.016231 | Sup=0.016192 | Recon=0.000780 | TrainAcc=1.0000
# Fold 15 Epoch 400: TotalLoss=0.007730 | Sup=0.007705 | Recon=0.000502 | TrainAcc=1.0000
# Fold 15 Epoch 500: TotalLoss=0.005696 | Sup=0.005676 | Recon=0.000400 | TrainAcc=1.0000
# Fold 15 Epoch 600: TotalLoss=0.003647 | Sup=0.003628 | Recon=0.000389 | TrainAcc=1.0000
# Fold 15 Epoch 700: TotalLoss=0.002778 | Sup=0.002758 | Recon=0.000404 | TrainAcc=1.0000
# Fold 15 Epoch 800: TotalLoss=0.002254 | Sup=0.002233 | Recon=0.000420 | TrainAcc=1.0000
# Fold 15 Epoch 900: TotalLoss=0.001762 | Sup=0.001740 | Recon=0.000435 | TrainAcc=1.0000
# Fold 15 Epoch 1000: TotalLoss=0.001609 | Sup=0.001587 | Recon=0.000443 | TrainAcc=1.0000
# Fold 15 Epoch 1100: TotalLoss=0
| TrainAcc=1.0000
# Fold 17 Epoch 1400: TotalLoss=0.000839 | Sup=0.000815 | Recon=0.000463 | TrainAcc=1.0000
# Fold 17 Epoch 1500: TotalLoss=0.000711 | Sup=0.000688 | Recon=0.000471 | TrainAcc=1.0000
# Fold 17 Epoch 1600: TotalLoss=0.000669 | Sup=0.000645 | Recon=0.000474 | TrainAcc=1.0000
# Fold 17 Epoch 1700: TotalLoss=0.000606 | Sup=0.000582 | Recon=0.000474 | TrainAcc=1.0000
# Fold 17 Epoch 1800: TotalLoss=0.000552 | Sup=0.000528 | Recon=0.000481 | TrainAcc=1.0000
# Fold 17 Epoch 1900: TotalLoss=0.000481 | Sup=0.000457 | Recon=0.000477 | TrainAcc=1.0000
# Fold 17 Epoch 2000: TotalLoss=0.000445 | Sup=0.000421 | Recon=0.000479 | TrainAcc=1.0000
# Fold 17 → Acc=0.9403 | Prec=0.9259 | Rec=0.9259 | F1=0.9259 | AUC=0.9861 | CE Loss=0.2605
#
# === Fold 18 ===
# Train Control: 93, Train Patient: 63
# Fold 18 Epoch 1: TotalLoss=0.704347 | Sup=0.702445 | Recon=0.038042 | TrainAcc=0.4103
# Fold 18 Epoch 100: TotalLoss=0.161317 | Sup=0.161156 | Recon=0.003220 | TrainAcc=0.9744
# Fold 18 Epoch 200: TotalLoss=0.042713 | Sup=0.042642 | Recon=0.001438 | TrainAcc=1.0000
# Fold 18 Epoch 300: TotalLoss=0.016860 | Sup=0.016822 | Recon=0.000762 | TrainAcc=1.0000
# Fold 18 Epoch 400: TotalLoss=0.009696 | Sup=0.009672 | Recon=0.000485 | TrainAcc=1.0000
# Fold 18 Epoch 500: TotalLoss=0.005283 | Sup=0.005263 | Recon=0.000403 | TrainAcc=1.0000
# Fold 18 Epoch 600: TotalLoss=0.003959 | Sup=0.003939 | Recon=0.000397 | TrainAcc=1.0000
# Fold 18 Epoch 700: TotalLoss=0.002896 | Sup=0.002875 | Recon=0.000412 | TrainAcc=1.0000
# Fold 18 Epoch 800: TotalLoss=0.002251 | Sup=0.002230 | Recon=0.000428 | TrainAcc=1.0000
# Fold 18 Epoch 900: TotalLoss=0.001573 | Sup=0.001551 | Recon=0.000442 | TrainAcc=1.0000
# Fold 18 Epoch 1000: TotalLoss=0.001539 | Sup=0.001517 | Recon=0.000456 | TrainAcc=1.0000
# Fold 18 Epoch 1100: TotalLoss=0.001201 | Sup=0.001178 | Recon=0.000461 | TrainAcc=1.0000
# Fold 18 Epoch 1200: TotalLoss=0.001106 | Sup=0.001082 | Recon=0.000465 | TrainAcc=1.0000
# Fold 18 Epoch 1300: TotalLoss=0.000873 | Sup=0.000850 | Recon=0.000470 | TrainAcc=1.0000
# Fold 18 Epoch 1400: TotalLoss=0.000837 | Sup=0.000813 | Recon=0.000472 | TrainAcc=1.0000
# Fold 18 Epoch 1500: TotalLoss=0.000793 | Sup=0.000770 | Recon=0.000478 | TrainAcc=1.0000
# Fold 18 Epoch 1600: TotalLoss=0.000656 | Sup=0.000632 | Recon=0.000482 | TrainAcc=1.0000
# Fold 18 Epoch 1700: TotalLoss=0.000542 | Sup=0.000518 | Recon=0.000482 | TrainAcc=1.0000
# Fold 18 Epoch 1800: TotalLoss=0.000581 | Sup=0.000557 | Recon=0.000481 | TrainAcc=1.0000
# Fold 18 Epoch 1900: TotalLoss=0.000547 | Sup=0.000523 | Recon=0.000480 | TrainAcc=1.0000
# Fold 18 Epoch 2000: TotalLoss=0.000479 | Sup=0.000454 | Recon=0.000488 | TrainAcc=1.0000
# Fold 18 → Acc=0.9552 | Prec=0.9286 | Rec=0.9630 | F1=0.9455 | AUC=0.9824 | CE Loss=0.1762
#
# === Fold 19 ===
# Train Control: 93, Train Patient: 63
# Fold 19 Epoch 1: TotalLoss=0.702404 | Sup=0.700426 | Recon=0.039574 | TrainAcc=0.5641
# Fold 19 Epoch 100: TotalLoss=0.152008 | Sup=0.151848 | Recon=0.003198 | TrainAcc=0.9744
# Fold 19 Epoch 200: TotalLoss=0.038266 | Sup=0.038196 | Recon=0.001389 | TrainAcc=1.0000
# Fold 19 Epoch 300: TotalLoss=0.014059 | Sup=0.014021 | Recon=0.000770 | TrainAcc=1.0000
# Fold 19 Epoch 400: TotalLoss=0.007917 | Sup=0.007893 | Recon=0.000494 | TrainAcc=1.0000
# Fold 19 Epoch 500: TotalLoss=0.004170 | Sup=0.004150 | Recon=0.000400 | TrainAcc=1.0000
# Fold 19 Epoch 600: TotalLoss=0.004003 | Sup=0.003983 | Recon=0.000392 | TrainAcc=1.0000
# Fold 19 Epoch 700: TotalLoss=0.002657 | Sup=0.002637 | Recon=0.000408 | TrainAcc=1.0000
# Fold 19 Epoch 800: TotalLoss=0.001845 | Sup=0.001824 | Recon=0.000423 | TrainAcc=1.0000
# Fold 19 Epoch 900: TotalLoss=0.001374 | Sup=0.001352 | Recon=0.000437 | TrainAcc=1.0000
# Fold 19 Epoch 1000: TotalLoss=0.001227 | Sup=0.001204 | Recon=0.000450 | TrainAcc=1.0000
# Fold 19 Epoch 1100: TotalLoss=0.000938 | Sup=0.000916 | Recon=0.000457 | TrainAcc=1.0000
# Fold 19 Epoch 1200: TotalLoss=0.001080 | Sup=0.001057 | Recon=0.000470 | TrainAcc=1.0000
# Fold 19 Epoch 1300: TotalLoss=0.000860 | Sup=0.000836 | Recon=0.000469 | TrainAcc=1.0000
# Fold 19 Epoch 1400: TotalLoss=0.000828 | Sup=0.000804 | Recon=0.000472 | TrainAcc=1.0000
# Fold 19 Epoch 1500: TotalLoss=0.000635 | Sup=0.000611 | Recon=0.000470 | TrainAcc=1.0000
# Fold 19 Epoch 1600: TotalLoss=0.000559 | Sup=0.000535 | Recon=0.000475 | TrainAcc=1.0000
# Fold 19 Epoch 1700: TotalLoss=0.000628 | Sup=0.000604 | Recon=0.000479 | TrainAcc=1.0000
# Fold 19 Epoch 1800: TotalLoss=0.000474 | Sup=0.000450 | Recon=0.000477 | TrainAcc=1.0000
# Fold 19 Epoch 1900: TotalLoss=0.000413 | Sup=0.000389 | Recon=0.000485 | TrainAcc=1.0000
# Fold 19 Epoch 2000: TotalLoss=0.000463 | Sup=0.000439 | Recon=0.000484 | TrainAcc=1.0000
# Fold 19 → Acc=0.9104 | Prec=0.8387 | Rec=0.9630 | F1=0.8966 | AUC=0.9861 | CE Loss=0.2852
#
# === Fold 20 ===
# Train Control: 93, Train Patient: 63
# Fold 20 Epoch 1: TotalLoss=0.757953 | Sup=0.755678 | Recon=0.045505 | TrainAcc=0.4615
# Fold 20 Epoch 100: TotalLoss=0.147846 | Sup=0.147674 | Recon=0.003438 | TrainAcc=0.9744
# Fold 20 Epoch 200: TotalLoss=0.035923 | Sup=0.035848 | Recon=0.001508 | TrainAcc=1.0000
# Fold 20 Epoch 300: TotalLoss=0.015491 | Sup=0.015451 | Recon=0.000800 | TrainAcc=1.0000
# Fold 20 Epoch 400: TotalLoss=0.008392 | Sup=0.008366 | Recon=0.000514 | TrainAcc=1.0000
# Fold 20 Epoch 500: TotalLoss=0.005172 | Sup=0.005151 | Recon=0.000410 | TrainAcc=1.0000
# Fold 20 Epoch 600: TotalLoss=0.003761 | Sup=0.003741 | Recon=0.000399 | TrainAcc=1.0000
# Fold 20 Epoch 700: TotalLoss=0.002843 | Sup=0.002823 | Recon=0.000402 | TrainAcc=1.0000
# Fold 20 Epoch 800: TotalLoss=0.002303 | Sup=0.002282 | Recon=0.000423 | TrainAcc=1.0000
# Fold 20 Epoch 900: TotalLoss=0.001700 | Sup=0.001678 | Recon=0.000433 | TrainAcc=1.0000
# Fold 20 Epoch 1000: TotalLoss=0.001481 | Sup=0.001458 | Recon=0.000452 | TrainAcc=1.0000
# Fold 20 Epoch 1100: TotalLoss=0.001253 | Sup=0.001230 | Recon=0.000453 | TrainAcc=1.0000
# Fold 20 Epoch 1200: TotalLoss=0.001050 | Sup=0.001028 | Recon=0.000459 | TrainAcc=1.0000
# Fold 20 Epoch 1300: TotalLoss=0.000867 | Sup=0.000844 | Recon=0.000464 | TrainAcc=1.0000
# Fold 20 Epoch 1400: TotalLoss=0.000864 | Sup=0.000840 | Recon=0.000466 | TrainAcc=1.0000
# Fold 20 Epoch 1500: TotalLoss=0.000758 | Sup=0.000734 | Recon=0.000470 | TrainAcc=1.0000
# Fold 20 Epoch 1600: TotalLoss=0.000698 | Sup=0.000674 | Recon=0.000474 | TrainAcc=1.0000
# Fold 20 Epoch 1700: TotalLoss=0.000533 | Sup=0.000510 | Recon=0.000476 | TrainAcc=1.0000
# Fold 20 Epoch 1800: TotalLoss=0.000485 | Sup=0.000461 | Recon=0.000473 | TrainAcc=1.0000
# Fold 20 Epoch 1900: TotalLoss=0.000446 | Sup=0.000422 | Recon=0.000475 | TrainAcc=1.0000
# Fold 20 Epoch 2000: TotalLoss=0.000478 | Sup=0.000454 | Recon=0.000478 | TrainAcc=1.0000
# Fold 20 → Acc=0.9403 | Prec=0.8710 | Rec=1.0000 | F1=0.9310 | AUC=0.9704 | CE Loss=0.3178
#
# === Average Results for λ = 0.05 ===
# Accuracy:  0.9448
# Precision: 0.9219
# Recall:    0.9463
# F1-score:  0.9326
# CE Loss:   0.2256
# AUC:       0.9824
#
#
# ====================== λ_recon = 0.09 ======================
#
# === Fold 1 ===
# Train Control: 93, Train Patient: 63
# Fold 1 Epoch 1: TotalLoss=0.732927 | Sup=0.729213 | Recon=0.041264 | TrainAcc=0.6026
# Fold 1 Epoch 100: TotalLoss=0.153425 | Sup=0.153164 | Recon=0.002899 | TrainAcc=0.9679
# Fold 1 Epoch 200: TotalLoss=0.043922 | Sup=0.043804 | Recon=0.001310 | TrainAcc=1.0000
# Fold 1 Epoch 300: TotalLoss=0.016836 | Sup=0.016770 | Recon=0.000737 | TrainAcc=1.0000
# Fold 1 Epoch 400: TotalLoss=0.008775 | Sup=0.008730 | Recon=0.000494 | TrainAcc=1.0000
# Fold 1 Epoch 500: TotalLoss=0.005708 | Sup=0.005675 | Recon=0.000377 | TrainAcc=1.0000
# Fold 1 Epoch 600: TotalLoss=0.003908 | Sup=0.003878 | Recon=0.000333 | TrainAcc=1.0000
# Fold 1 Epoch 700: TotalLoss=0.002811 | Sup=0.002782 | Recon=0.000326 | TrainAcc=1.0000
# Fold 1 Epoch 800: TotalLoss=0.002007 | Sup=0.001977 | Recon=0.000336 | TrainAcc=1.0000
# Fold 1 Epoch 900: TotalLoss=0.001789 | Sup=0.001758 | Recon=0.000347 | TrainAcc=1.0000
# Fold 1 Epoch 1000: TotalLoss=0.001485 | Sup=0.001453 | Recon=0.000356 | TrainAcc=1.0000
# Fold 1 Epoch 1100: TotalLoss=0.001256 | Sup=0.001223 | Recon=0.000365 | TrainAcc=1.0000
# Fold 1 Epoch 1200: TotalLoss=0.001043 | Sup=0.001009 | Recon=0.000374 | TrainAcc=1.0000
# Fold 1 Epoch 1300: TotalLoss=0.000804 | Sup=0.000769 | Recon=0.000382 | TrainAcc=1.0000
# Fold 1 Epoch 1400: TotalLoss=0.000821 | Sup=0.000787 | Recon=0.000384 | TrainAcc=1.0000
# Fold 1 Epoch 1500: TotalLoss=0.
| TrainAcc=1.0000
# Fold 3 Epoch 1600: TotalLoss=0.000697 | Sup=0.000662 | Recon=0.000385 | TrainAcc=1.0000
# Fold 3 Epoch 1700: TotalLoss=0.000596 | Sup=0.000561 | Recon=0.000391 | TrainAcc=1.0000
# Fold 3 Epoch 1800: TotalLoss=0.000610 | Sup=0.000575 | Recon=0.000394 | TrainAcc=1.0000
# Fold 3 Epoch 1900: TotalLoss=0.000570 | Sup=0.000534 | Recon=0.000400 | TrainAcc=1.0000
# Fold 3 Epoch 2000: TotalLoss=0.000584 | Sup=0.000548 | Recon=0.000400 | TrainAcc=1.0000
# Fold 3 → Acc=0.9552 | Prec=0.9286 | Rec=0.9630 | F1=0.9455 | AUC=0.9731 | CE Loss=0.2043
#
# === Fold 4 ===
# Train Control: 93, Train Patient: 63
# Fold 4 Epoch 1: TotalLoss=0.664892 | Sup=0.661241 | Recon=0.040575 | TrainAcc=0.4038
# Fold 4 Epoch 100: TotalLoss=0.116242 | Sup=0.115976 | Recon=0.002949 | TrainAcc=0.9936
# Fold 4 Epoch 200: TotalLoss=0.030512 | Sup=0.030396 | Recon=0.001281 | TrainAcc=1.0000
# Fold 4 Epoch 300: TotalLoss=0.012800 | Sup=0.012734 | Recon=0.000726 | TrainAcc=1.0000
# Fold 4 Epoch 400: TotalLoss=0.007410 | Sup=0.007367 | Recon=0.000482 | TrainAcc=1.0000
# Fold 4 Epoch 500: TotalLoss=0.004543 | Sup=0.004509 | Recon=0.000373 | TrainAcc=1.0000
# Fold 4 Epoch 600: TotalLoss=0.002897 | Sup=0.002867 | Recon=0.000327 | TrainAcc=1.0000
# Fold 4 Epoch 700: TotalLoss=0.002311 | Sup=0.002282 | Recon=0.000328 | TrainAcc=1.0000
# Fold 4 Epoch 800: TotalLoss=0.001897 | Sup=0.001867 | Recon=0.000338 | TrainAcc=1.0000
# Fold 4 Epoch 900: TotalLoss=0.001734 | Sup=0.001703 | Recon=0.000348 | TrainAcc=1.0000
# Fold 4 Epoch 1000: TotalLoss=0.001211 | Sup=0.001178 | Recon=0.000361 | TrainAcc=1.0000
# Fold 4 Epoch 1100: TotalLoss=0.000972 | Sup=0.000938 | Recon=0.000370 | TrainAcc=1.0000
# Fold 4 Epoch 1200: TotalLoss=0.001014 | Sup=0.000980 | Recon=0.000380 | TrainAcc=1.0000
# Fold 4 Epoch 1300: TotalLoss=0.000782 | Sup=0.000747 | Recon=0.000384 | TrainAcc=1.0000
# Fold 4 Epoch 1400: TotalLoss=0.000737 | Sup=0.000701 | Recon=0.000391 | TrainAcc=1.0000
# Fold 4 Epoch 1500: TotalLoss=0.000659 | Sup=0.000624 | Recon=0.000396 | TrainAcc=1.0000
# Fold 4 Epoch 1600: TotalLoss=0.000618 | Sup=0.000582 | Recon=0.000404 | TrainAcc=1.0000
# Fold 4 Epoch 1700: TotalLoss=0.000520 | Sup=0.000484 | Recon=0.000402 | TrainAcc=1.0000
# Fold 4 Epoch 1800: TotalLoss=0.000569 | Sup=0.000533 | Recon=0.000403 | TrainAcc=1.0000
# Fold 4 Epoch 1900: TotalLoss=0.000473 | Sup=0.000437 | Recon=0.000407 | TrainAcc=1.0000
# Fold 4 Epoch 2000: TotalLoss=0.000419 | Sup=0.000382 | Recon=0.000410 | TrainAcc=1.0000
# Fold 4 → Acc=0.9403 | Prec=0.8966 | Rec=0.9630 | F1=0.9286 | AUC=0.9917 | CE Loss=0.1578
#
# === Fold 5 ===
# Train Control: 93, Train Patient: 63
# Fold 5 Epoch 1: TotalLoss=0.714287 | Sup=0.709871 | Recon=0.049067 | TrainAcc=0.5641
# Fold 5 Epoch 100: TotalLoss=0.154970 | Sup=0.154694 | Recon=0.003069 | TrainAcc=0.9808
# Fold 5 Epoch 200: TotalLoss=0.040899 | Sup=0.040779 | Recon=0.001335 | TrainAcc=1.0000
# Fold 5 Epoch 300: TotalLoss=0.016215 | Sup=0.016147 | Recon=0.000756 | TrainAcc=1.0000
# Fold 5 Epoch 400: TotalLoss=0.009505 | Sup=0.009460 | Recon=0.000508 | TrainAcc=1.0000
# Fold 5 Epoch 500: TotalLoss=0.005111 | Sup=0.005076 | Recon=0.000385 | TrainAcc=1.0000
# Fold 5 Epoch 600: TotalLoss=0.003892 | Sup=0.003862 | Recon=0.000334 | TrainAcc=1.0000
# Fold 5 Epoch 700: TotalLoss=0.002753 | Sup=0.002724 | Recon=0.000323 | TrainAcc=1.0000
# Fold 5 Epoch 800: TotalLoss=0.002176 | Sup=0.002147 | Recon=0.000330 | TrainAcc=1.0000
# Fold 5 Epoch 900: TotalLoss=0.001630 | Sup=0.001600 | Recon=0.000341 | TrainAcc=1.0000
# Fold 5 Epoch 1000: TotalLoss=0.001487 | Sup=0.001456 | Recon=0.000350 | TrainAcc=1.0000
# Fold 5 Epoch 1100: TotalLoss=0.001164 | Sup=0.001132 | Recon=0.000363 | TrainAcc=1.0000
# Fold 5 Epoch 1200: TotalLoss=0.001009 | Sup=0.000976 | Recon=0.000366 | TrainAcc=1.0000
# Fold 5 Epoch 1300: TotalLoss=0.000891 | Sup=0.000857 | Recon=0.000373 | TrainAcc=1.0000
# Fold 5 Epoch 1400: TotalLoss=0.000884 | Sup=0.000849 | Recon=0.000383 | TrainAcc=1.0000
# Fold 5 Epoch 1500: TotalLoss=0.000669 | Sup=0.000635 | Recon=0.000384 | TrainAcc=1.0000
# Fold 5 Epoch 1600: TotalLoss=0.000697 | Sup=0.000662 | Recon=0.000391 | TrainAcc=1.0000
# Fold 5 Epoch 1700: TotalLoss=0.000568 | Sup=0.000532 | Recon=0.000392 | TrainAcc=1.0000
# Fold 5 Epoch 1800: TotalLoss=0.000512 | Sup=0.000477 | Recon=0.000396 | TrainAcc=1.0000
# Fold 5 Epoch 1900: TotalLoss=0.000478 | Sup=0.000442 | Recon=0.000398 | TrainAcc=1.0000
# Fold 5 Epoch 2000: TotalLoss=0.000493 | Sup=0.000457 | Recon=0.000398 | TrainAcc=1.0000
# Fold 5 → Acc=0.9403 | Prec=0.9259 | Rec=0.9259 | F1=0.9259 | AUC=0.9898 | CE Loss=0.1845
#
# === Fold 6 ===
# Train Control: 93, Train Patient: 63
# Fold 6 Epoch 1: TotalLoss=0.702769 | Sup=0.698706 | Recon=0.045141 | TrainAcc=0.5449
# Fold 6 Epoch 100: TotalLoss=0.141270 | Sup=0.141009 | Recon=0.002898 | TrainAcc=0.9808
# Fold 6 Epoch 200: TotalLoss=0.037687 | Sup=0.037570 | Recon=0.001294 | TrainAcc=1.0000
# Fold 6 Epoch 300: TotalLoss=0.014853 | Sup=0.014785 | Recon=0.000754 | TrainAcc=1.0000
# Fold 6 Epoch 400: TotalLoss=0.007900 | Sup=0.007856 | Recon=0.000492 | TrainAcc=1.0000
# Fold 6 Epoch 500: TotalLoss=0.005147 | Sup=0.005113 | Recon=0.000379 | TrainAcc=1.0000
# Fold 6 Epoch 600: TotalLoss=0.003216 | Sup=0.003186 | Recon=0.000338 | TrainAcc=1.0000
# Fold 6 Epoch 700: TotalLoss=0.002528 | Sup=0.002498 | Recon=0.000331 | TrainAcc=1.0000
# Fold 6 Epoch 800: TotalLoss=0.001959 | Sup=0.001929 | Recon=0.000334 | TrainAcc=1.0000
# Fold 6 Epoch 900: TotalLoss=0.001448 | Sup=0.001417 | Recon=0.000344 | TrainAcc=1.0000
# Fold 6 Epoch 1000: TotalLoss=0.001286 | Sup=0.001254 | Recon=0.000353 | TrainAcc=1.0000
# Fold 6 Epoch 1100: TotalLoss=0.001263 | Sup=0.001230 | Recon=0.000369 | TrainAcc=1.0000
# Fold 6 Epoch 1200: TotalLoss=0.001072 | Sup=0.001038 | Recon=0.000378 | TrainAcc=1.0000
# Fold 6 Epoch 1300: TotalLoss=0.000858 | Sup=0.000824 | Recon=0.000383 | TrainAcc=1.0000
# Fold 6 Epoch 1400: TotalLoss=0.000775 | Sup=0.000740 | Recon=0.000388 | TrainAcc=1.0000
# Fold 6 Epoch 1500: TotalLoss=0.000761 | Sup=0.000726 | Recon=0.000386 | TrainAcc=1.0000
# Fold 6 Epoch 1600: TotalLoss=0.000611 | Sup=0.000576 | Recon=0.000393 | TrainAcc=1.0000
# Fold 6 Epoch 1700: TotalLoss=0.000561 | Sup=0.000525 | Recon=0.000399 | TrainAcc=1.0000
# Fold 6 Epoch 1800: TotalLoss=0.000524 | Sup=0.000488 | Recon=0.000401 | TrainAcc=1.0000
# Fold 6 Epoch 1900: TotalLoss=0.000497 | Sup=0.000461 | Recon=0.000404 | TrainAcc=1.0000
# Fold 6 Epoch 2000: TotalLoss=0.000529 | Sup=0.000492 | Recon=0.000407 | TrainAcc=1.0000
# Fold 6 → Acc=0.9851 | Prec=1.0000 | Rec=0.9630 | F1=0.9811 | AUC=0.9824 | CE Loss=0.1456
#
# === Fold 7 ===
# Train Control: 93, Train Patient: 63
# Fold 7 Epoch 1: TotalLoss=0.644490 | Sup=0.640631 | Recon=0.042880 | TrainAcc=0.6026
# Fold 7 Epoch 100: TotalLoss=0.145245 | Sup=0.144990 | Recon=0.002835 | TrainAcc=0.9744
# Fold 7 Epoch 200: TotalLoss=0.043793 | Sup=0.043680 | Recon=0.001253 | TrainAcc=1.0000
# Fold 7 Epoch 300: TotalLoss=0.016644 | Sup=0.016576 | Recon=0.000757 | TrainAcc=1.0000
# Fold 7 Epoch 400: TotalLoss=0.008388 | Sup=0.008342 | Recon=0.000503 | TrainAcc=1.0000
# Fold 7 Epoch 500: TotalLoss=0.004842 | Sup=0.004809 | Recon=0.000370 | TrainAcc=1.0000
# Fold 7 Epoch 600: TotalLoss=0.003702 | Sup=0.003672 | Recon=0.000330 | TrainAcc=1.0000
# Fold 7 Epoch 700: TotalLoss=0.002410 | Sup=0.002381 | Recon=0.000321 | TrainAcc=1.0000
# Fold 7 Epoch 800: TotalLoss=0.001920 | Sup=0.001891 | Recon=0.000329 | TrainAcc=1.0000
# Fold 7 Epoch 900: TotalLoss=0.001561 | Sup=0.001529 | Recon=0.000348 | TrainAcc=1.0000
# Fold 7 Epoch 1000: TotalLoss=0.001484 | Sup=0.001453 | Recon=0.000352 | TrainAcc=1.0000
# Fold 7 Epoch 1100: TotalLoss=0.000977 | Sup=0.000944 | Recon=0.000362 | TrainAcc=1.0000
# Fold 7 Epoch 1200: TotalLoss=0.001081 | Sup=0.001047 | Recon=0.000373 | TrainAcc=1.0000
# Fold 7 Epoch 1300: TotalLoss=0.000897 | Sup=0.000863 | Recon=0.000377 | TrainAcc=1.0000
# Fold 7 Epoch 1400: TotalLoss=0.000744 | Sup=0.000709 | Recon=0.000385 | TrainAcc=1.0000
# Fold 7 Epoch 1500: TotalLoss=0.000716 | Sup=0.000681 | Recon=0.000387 | TrainAcc=1.0000
# Fold 7 Epoch 1600: TotalLoss=0.000592 | Sup=0.000557 | Recon=0.000390 | TrainAcc=1.0000
# Fold 7 Epoch 1700: TotalLoss=0.000569 | Sup=0.000534 | Recon=0.000396 | TrainAcc=1.0000
# Fold 7 Epoch 1800: TotalLoss=0.000561 | Sup=0.000526 | Recon=0.000399 | TrainAcc=1.0000
# Fold 7 Epoch 1900: TotalLoss=0.000511 | Sup=0.000475 | Recon=0.000402 | TrainAcc=1.0000
# Fold 7 Epoch 2000: TotalLoss=0.000466 | Sup=0.000429 | Recon=0.000407 | TrainAcc=1.0000
# Fold 7 → Acc=0.9403 | Prec=0.9600 | Rec=0.8889 | F1=0.9231 | AUC=0.9889 | CE Loss=0.2310
#
# === Fold 8 ===
# Train Control: 93, Train Patient: 63
# Fold 8 Epoch 1: TotalLoss=0.737924 | Sup=0.734324 | Recon=0.040004 | TrainAcc=0.5962
# Fold 8 Epoch 100: TotalLoss=0.162905 | Sup=0.162656 | Recon=0.002773 | TrainAcc=0.9744
# Fold 8 Epoch 200: TotalLoss=0.040433 | Sup=0.040321 | Recon=0.001246 | TrainAcc=1.0000
# Fold 8 Epoch 300: TotalLoss=0.016614 | Sup=0.016550 | Recon=0.000709 | TrainAcc=1.0000
# Fold 8 Epoch 400: TotalLoss=0.009148 | Sup=0.009104 | Recon=0.000490 | TrainAcc=1.0000
# Fold 8 Epoch 500: TotalLoss=0.005232 | Sup=0.005199 | Recon=0.000365 | TrainAcc=1.0000
# Fold 8 Epoch 600: TotalLoss=0.003927 | Sup=0.003898 | Recon=0.000328 | TrainAcc=1.0000
# Fold 8 Epoch 700: TotalLoss=0.002684 | Sup=0.002656 | Recon=0.000312 | TrainAcc=1.0000
# Fold 8 Epoch 800: TotalLoss=0.002148 | Sup=0.002119 | Recon=0.000324 | TrainAcc=1.0000
# Fold 8 Epoch 900: TotalLoss=0.001671 | Sup=0.001640 | Recon=0.000344 | TrainAcc=1.0000
# Fold 8 Epoch 1000: TotalLoss=0.001467 | Sup=0.001435 | Recon=0.000354 | TrainAcc=1.0000
# Fold 8 Epoch 1100: TotalLoss=0.001319 | Sup=0.001287 | Recon=0.000360 | TrainAcc=1.0000
# Fold 8 Epoch 1200: TotalLoss=0.001050 | Sup=0.001017 | Recon=0.000365 | TrainAcc=1.0000
# Fold 8 Epoch 1300: TotalLoss=0.000942 | Sup=0.000908 | Recon=0.000373 | TrainAcc=1.0000
# Fold 8 Epoch 1400: TotalLoss=0.000907 | Sup=0.000873 | Recon=0.000380 | TrainAcc=1.0000
# Fold 8 Epoch 1500: TotalLoss=0.000710 | Sup=0.000675 | Recon=0.000389 | TrainAcc=1.0000
# Fold 8 Epoch 1600: TotalLoss=0.000610 | Sup=0.000575 | Recon=0.000386 | TrainAcc=1.0000
# Fold 8 Epoch 1700: TotalLoss=0.000636 | Sup=0.000601 | Recon=0.000392 | TrainAcc=1.0000
# Fold 8 Epoch 1800: TotalLoss=0.000584 | Sup=0.000548 | Recon=0.000395 | TrainAcc=1.0000
# Fold 8 Epoch 1900: TotalLoss=0.000523 | Sup=0.000487 | Recon=0.000397 | TrainAcc=1.0000
# Fold 8 Epoch 2000: TotalLoss=0.000462 | Sup=0.000426 | Recon=0.000396 | TrainAcc=1.0000
# Fold 8 → Acc=0.9552 | Prec=0.9615 | Rec=0.9259 | F1=0.9434 | AUC=0.9935 | CE Loss=0.1593
#
# === Fold 9 ===
# Train Control: 93, Train Patient: 63
# Fold 9 Epoch 1: TotalLoss=0.830199 | Sup=0.826275 | Recon=0.043601 | TrainAcc=0.4038
# Fold 9 Epoch 100: TotalLoss=0.155190 | Sup=0.154926 | Recon=0.002926 | TrainAcc=0.9744
# Fold 9 Epoch 200: TotalLoss=0.052531 | Sup=0.052414 | Recon=0.001300 | TrainAcc=1.0000
# Fold 9 Epoch 300: TotalLoss=0.021085 | Sup=0.021020 | Recon=0.000723 | TrainAcc=1.0000
# Fold 9 Epoch 400: TotalLoss=0.010859 | Sup=0.010816 | Recon=0.000477 | TrainAcc=1.0000
# Fold 9 Epoch 500: TotalLoss=0.007322 | Sup=0.007288 | Recon=0.000371 | TrainAcc=1.0000
# Fold 9 Epoch 600: TotalLoss=0.004383 | Sup=0.004354 | Recon=0.000322 | TrainAcc=1.0000
# Fold 9 Epoch 700: TotalLoss=0.003408 | Sup=0.003379 | Recon=0.000317 | TrainAcc=1.0000
# Fold 9 Epoch 800: TotalLoss=0.002629 | Sup=0.002599 | Recon=0.000328 | TrainAcc=1.0000
# Fold 9 Epoch 900: TotalLoss=0.002220 | Sup=0.002190 | Recon=0.000340 | TrainAcc=1.0000
# Fold 9 Epoch 1000: TotalLoss=0.001679 | Sup=0.001648 | Recon=0.000349 | TrainAcc=1.0000
# Fold 9 Epoch 1100: TotalLoss=0.001616 | Sup=0.001584 | Recon=0.000357 | TrainAcc=1.0000
# Fold 9 Epoch 1200: TotalLoss=0.001256 | Sup=0.001222 | Recon=0.000371 | TrainAcc=1.0000
# Fold 9 Epoch 1300: TotalLoss=0.001076 | Sup=0.001043 | Recon=0.000373 | TrainAcc=1.0000
# Fold 9 Epoch 1400: TotalLoss=0.000970 | Sup=0.000936 | Recon=0.000380 | TrainAcc=1.0000
# Fold 9 Epoch 1500: TotalLoss=0.000927 | Sup=0.000892 | Recon=0.000382 | TrainAcc=1.0000
# Fold 9 Epoch 1600: TotalLoss=0.000803 | Sup=0.000768 | Recon=0.000387 | TrainAcc=1.0000
# Fold 9 Epoch 1700: TotalLoss=0.000670 | Sup=0.000634 | Recon=0.000394 | TrainAcc=1.0000
# Fold 9 Epoch 1800: TotalLoss=0.000697 | Sup=0.000662 | Recon=0.000398 | TrainAcc=1.0000
# Fold 9 Epoch 1900: TotalLoss=0.000638 | Sup=0.000602 | Recon=0.000396 | TrainAcc=1.0000
# Fold 9 Epoch 2000: TotalLoss=0.000592 | Sup=0.000556 | Recon=0.000402 | TrainAcc=1.0000
# Fold 9 → Acc=0.9254 | Prec=0.9231 | Rec=0.8889 | F1=0.9057 | AUC=0.9917 | CE Loss=0.1248
#
# ...
# Fold 13 Epoch 1700: TotalLoss=0.002142 | Sup=0.000651 | Recon=0.000186 | TrainAcc=1.0000
# Fold 13 Epoch 1800: TotalLoss=0.001999 | Sup=0.000586 | Recon=0.000177 | TrainAcc=1.0000
# Fold 13 Epoch 1900: TotalLoss=0.001908 | Sup=0.000618 | Recon=0.000161 | TrainAcc=1.0000
# Fold 13 Epoch 2000: TotalLoss=0.001644 | Sup=0.000471 | Recon=0.000147 | TrainAcc=1.0000
# Fold 13 → Acc=0.9851 | Prec=0.9643 | Rec=1.0000 | F1=0.9818 | AUC=1.0000 | CE Loss=0.0308
#
# === Fold 14 ===
# Train Control: 93, Train Patient: 63
# Fold 14 Epoch 1: TotalLoss=1.010750 | Sup=0.694351 | Recon=0.039550 | TrainAcc=0.6154
# Fold 14 Epoch 100: TotalLoss=0.175454 | Sup=0.156365 | Recon=0.002386 | TrainAcc=0.9744
# Fold 14 Epoch 200: TotalLoss=0.049073 | Sup=0.039773 | Recon=0.001162 | TrainAcc=1.0000
# Fold 14 Epoch 300: TotalLoss=0.021057 | Sup=0.014995 | Recon=0.000758 | TrainAcc=1.0000
# Fold 14 Epoch 400: TotalLoss=0.013400 | Sup=0.008652 | Recon=0.000594 | TrainAcc=1.0000
# Fold 14 Epoch 500: TotalLoss=0.009142 | Sup=0.004980 | Recon=0.000520 | TrainAcc=1.0000
# Fold 14 Epoch 600: TotalLoss=0.006841 | Sup=0.003188 | Recon=0.000457 | TrainAcc=1.0000
# Fold 14 Epoch 700: TotalLoss=0.005748 | Sup=0.002482 | Recon=0.000408 | TrainAcc=1.0000
# Fold 14 Epoch 800: TotalLoss=0.005020 | Sup=0.002116 | Recon=0.000363 | TrainAcc=1.0000
# Fold 14 Epoch 900: TotalLoss=0.004197 | Sup=0.001690 | Recon=0.000313 | TrainAcc=1.0000
# Fold 14 Epoch 1000: TotalLoss=0.003664 | Sup=0.001365 | Recon=0.000287 | TrainAcc=1.0000
# Fold 14 Epoch 1100: TotalLoss=0.003229 | Sup=0.001052 | Recon=0.000272 | TrainAcc=1.0000
# Fold 14 Epoch 1200: TotalLoss=0.002942 | Sup=0.000930 | Recon=0.000252 | TrainAcc=1.0000
# Fold 14 Epoch 1300: TotalLoss=0.002748 | Sup=0.000833 | Recon=0.000239 | TrainAcc=1.0000
# Fold 14 Epoch 1400: TotalLoss=0.002542 | Sup=0.000759 | Recon=0.000223 | TrainAcc=1.0000
# Fold 14 Epoch 1500: TotalLoss=0.002275 | Sup=0.000608 | Recon=0.000208 | TrainAcc=1.0000
# Fold 14 Epoch 1600: TotalLoss=0.002149 | Sup=0.000589 | Recon=0.000195 | TrainAcc=1.0000
# Fold 14 Epoch 1700: TotalLoss=0.002044 | Sup=0.000621 | Recon=0.000178 | TrainAcc=1.0000
# Fold 14 Epoch 1800: TotalLoss=0.001833 | Sup=0.000551 | Recon=0.000160 | TrainAcc=1.0000
# Fold 14 Epoch 1900: TotalLoss=0.001637 | Sup=0.000443 | Recon=0.000149 | TrainAcc=1.0000
# Fold 14 Epoch 2000: TotalLoss=0.001521 | Sup=0.000413 | Recon=0.000138 | TrainAcc=1.0000
# Fold 14 → Acc=0.9403 | Prec=0.9600 | Rec=0.8889 | F1=0.9231 | AUC=0.9713 | CE Loss=0.2387
#
# === Fold 15 ===
# Train Control: 93, Train Patient: 63
# Fold 15 Epoch 1: TotalLoss=1.095105 | Sup=0.749871 | Recon=0.043154 | TrainAcc=0.4103
# Fold 15 Epoch 100: TotalLoss=0.164427 | Sup=0.142775 | Recon=0.002706 | TrainAcc=0.9615
# Fold 15 Epoch 200: TotalLoss=0.051801 | Sup=0.041894 | Recon=0.001238 | TrainAcc=1.0000
# Fold 15 Epoch 300: TotalLoss=0.021870 | Sup=0.015703 | Recon=0.000771 | TrainAcc=1.0000
# Fold 15 Epoch 400: TotalLoss=0.014047 | Sup=0.009299 | Recon=0.000594 | TrainAcc=1.0000
# Fold 15 Epoch 500: TotalLoss=0.009926 | Sup=0.005826 | Recon=0.000513 | TrainAcc=1.0000
# Fold 15 Epoch 600: TotalLoss=0.007298 | Sup=0.003676 | Recon=0.000453 | TrainAcc=1.0000
# Fold 15 Epoch 700: TotalLoss=0.006128 | Sup=0.002826 | Recon=0.000413 | TrainAcc=1.0000
# Fold 15 Epoch 800: TotalLoss=0.005417 | Sup=0.002288 | Recon=0.000391 | TrainAcc=1.0000
# Fold 15 Epoch 900: TotalLoss=0.004613 | Sup=0.001728 | Recon=0.000361 | TrainAcc=1.0000
# Fold 15 Epoch 1000: TotalLoss=0.004114 | Sup=0.001416 | Recon=0.000337 | TrainAcc=1.0000
# Fold 15 Epoch 1100: TotalLoss=0.003712 | Sup=0.001213 | Recon=0.000312 | TrainAcc=1.0000
# Fold 15 Epoch 1200: TotalLoss=0.003160 | Sup=0.000898 | Recon=0.000283 | TrainAcc=1.0000
# Fold 15 Epoch 1300: TotalLoss=0.003109 | Sup=0.001052 | Recon=0.000257 | TrainAcc=1.0000
# Fold 15 Epoch 1400: TotalLoss=0.002664 | Sup=0.000765 | Recon=0.000237 | TrainAcc=1.0000
# Fold 15 Epoch 1500: TotalLoss=0.002617 | Sup=0.000835 | Recon=0.000223 | TrainAcc=1.0000
# Fold 15 Epoch 1600: TotalLoss=0.002263 | Sup=0.000627 | Recon=0.000204 | TrainAcc=1.0000
# Fold 15 Epoch 1700: TotalLoss=0.002243 | Sup=0.000676 | Recon=0.000196 | TrainAcc=1.0000
# Fold 15 Epoch 1800: TotalLoss=0.002099 | Sup=0.000622 | Recon=0.000185 | TrainAcc=1.0000
# Fold 15 Epoch 1900: TotalLoss=0.001838 | Sup=0.000482 | Recon=0.000169 | TrainAcc=1.0000
# Fold 15 Epoch 2000: TotalLoss=0.001706 | Sup=0.000427 | Recon=0.000160 | TrainAcc=1.0000
# Fold 15 → Acc=0.8806 | Prec=0.8800 | Rec=0.8148 | F1=0.8462 | AUC=0.9370 | CE Loss=0.5421
#
# === Fold 16 ===
# Train Control: 93, Train Patient: 63
# Fold 16 Epoch 1: TotalLoss=1.106741 | Sup=0.760396 | Recon=0.043293 | TrainAcc=0.5256
# Fold 16 Epoch 100: TotalLoss=0.172987 | Sup=0.153624 | Recon=0.002420 | TrainAcc=0.9551
# Fold 16 Epoch 200: TotalLoss=0.056830 | Sup=0.047486 | Recon=0.001168 | TrainAcc=1.0000
# Fold 16 Epoch 300: TotalLoss=0.023807 | Sup=0.017592 | Recon=0.000777 | TrainAcc=1.0000
# Fold 16 Epoch 400: TotalLoss=0.015491 | Sup=0.010701 | Recon=0.000599 | TrainAcc=1.0000
# Fold 16 Epoch 500: TotalLoss=0.010839 | Sup=0.006667 | Recon=0.000521 | TrainAcc=1.0000
# Fold 16 Epoch 600: TotalLoss=0.008168 | Sup=0.004280 | Recon=0.000486 | TrainAcc=1.0000
# Fold 16 Epoch 700: TotalLoss=0.006629 | Sup=0.003177 | Recon=0.000431 | TrainAcc=1.0000
# Fold 16 Epoch 800: TotalLoss=0.005256 | Sup=0.002108 | Recon=0.000394 | TrainAcc=1.0000
# Fold 16 Epoch 900: TotalLoss=0.004656 | Sup=0.001687 | Recon=0.000371 | TrainAcc=1.0000
# Fold 16 Epoch 1000: TotalLoss=0.004309 | Sup=0.001554 | Recon=0.000344 | TrainAcc=1.0000
# Fold 16 Epoch 1100: TotalLoss=0.003842 | Sup=0.001296 | Recon=0.000318 | TrainAcc=1.0000
# Fold 16 Epoch 1200: TotalLoss=0.003482 | Sup=0.001172 | Recon=0.000289 | TrainAcc=1.0000
# Fold 16 Epoch 1300: TotalLoss=0.003067 | Sup=0.000977 | Recon=0.000261 | TrainAcc=1.0000
# Fold 16 Epoch 1400: TotalLoss=0.002733 | Sup=0.000853 | Recon=0.000235 | TrainAcc=1.0000
# Fold 16 Epoch 1500: TotalLoss=0.002523 | Sup=0.000785 | Recon=0.000217 | TrainAcc=1.0000
# Fold 16 Epoch 1600: TotalLoss=0.002287 | Sup=0.000718 | Recon=0.000196 | TrainAcc=1.0000
# Fold 16 Epoch 1700: TotalLoss=0.002049 | Sup=0.000598 | Recon=0.000181 | TrainAcc=1.0000
# Fold 16 Epoch 1800: TotalLoss=0.001869 | Sup=0.000522 | Recon=0.000168 | TrainAcc=1.0000
# Fold 16 Epoch 1900: TotalLoss=0.001818 | Sup=0.000536 | Recon=0.000160 | TrainAcc=1.0000
# Fold 16 Epoch 2000: TotalLoss=0.001628 | Sup=0.000437 | Recon=0.000149 | TrainAcc=1.0000
# Fold 16 → Acc=0.8955 | Prec=0.8125 | Rec=0.9630 | F1=0.8814 | AUC=0.9907 | CE Loss=0.2545
#
# === Fold 17 ===
# Train Control: 93, Train Patient: 63
# Fold 17 Epoch 1: TotalLoss=1.225685 | Sup=0.870268 | Recon=0.044427 | TrainAcc=0.3974
# Fold 17 Epoch 100: TotalLoss=0.183201 | Sup=0.163302 | Recon=0.002487 | TrainAcc=0.9808
# Fold 17 Epoch 200: TotalLoss=0.059867 | Sup=0.050583 | Recon=0.001160 | TrainAcc=1.0000
# Fold 17 Epoch 300: TotalLoss=0.026753 | Sup=0.020810 | Recon=0.000743 | TrainAcc=1.0000
# Fold 17 Epoch 400: TotalLoss=0.016353 | Sup=0.011721 | Recon=0.000579 | TrainAcc=1.0000
# Fold 17 Epoch 500: TotalLoss=0.011377 | Sup=0.007318 | Recon=0.000507 | TrainAcc=1.0000
# Fold 17 Epoch 600: TotalLoss=0.008693 | Sup=0.005067 | Recon=0.000453 | TrainAcc=1.0000
# Fold 17 Epoch 700: TotalLoss=0.006901 | Sup=0.003689 | Recon=0.000402 | TrainAcc=1.0000
# Fold 17 Epoch 800: TotalLoss=0.005638 | Sup=0.002699 | Recon=0.000367 | TrainAcc=1.0000
# Fold 17 Epoch 900: TotalLoss=0.004745 | Sup=0.002008 | Recon=0.000342 | TrainAcc=1.0000
# Fold 17 Epoch 1000: TotalLoss=0.004473 | Sup=0.001956 | Recon=0.000315 | TrainAcc=1.0000
# Fold 17 Epoch 1100: TotalLoss=0.003992 | Sup=0.001651 | Recon=0.000293 | TrainAcc=1.0000
# Fold 17 Epoch 1200: TotalLoss=0.003551 | Sup=0.001358 | Recon=0.000274 | TrainAcc=1.0000
# Fold 17 Epoch 1300: TotalLoss=0.003133 | Sup=0.001081 | Recon=0.000257 | TrainAcc=1.0000
# Fold 17 Epoch 1400: TotalLoss=0.002872 | Sup=0.000918 | Recon=0.000244 | TrainAcc=1.0000
# Fold 17 Epoch 1500: TotalLoss=0.002874 | Sup=0.001001 | Recon=0.000234 | TrainAcc=1.0000
# Fold 17 Epoch 1600: TotalLoss=0.002487 | Sup=0.000751 | Recon=0.000217 | TrainAcc=1.0000
# Fold 17 Epoch 1700: TotalLoss=0.002299 | Sup=0.000651 | Recon=0.000206 | TrainAcc=1.0000
# Fold 17 Epoch 1800: TotalLoss=0.002175 | Sup=0.000627 | Recon=0.000194 | TrainAcc=1.0000
# Fold 17 Epoch 1900: TotalLoss=0.002037 | Sup=0.000590 | Recon=0.000181 | TrainAcc=1.0000
# Fold 17 Epoch 2000: TotalLoss=0.001835 | Sup=0.000488 | Recon=0.000168 | TrainAcc=1.0000
# Fold 17 → Acc=0.9403 | Prec=0.9259 | Rec=0.9259 | F1=0.9259 | AUC=0.9870 | CE Loss=0.2399
#
# === Fold 18 ===
# Train Control: 93, Train Patient: 63
# Fold 18 Epoch 1: TotalLoss=1.006052 | Sup=0.737096 | Recon=0.033620 | TrainAcc=0.4038
# Fold 18 Epoch 100: TotalLoss=0.184881 | Sup=0.167451 | Recon=0.002179 | TrainAcc=0.9551
# Fold 18 Epoch 200: TotalLoss=0.060102 | Sup=0.052258 | Recon=0.000980 | TrainAcc=1.0000
# Fold 18 Epoch 300: TotalLoss=0.023182 | Sup=0.018084 | Recon=0.000637 | TrainAcc=1.0000
# Fold 18 Epoch 400: TotalLoss=0.014879 | Sup=0.010618 | Recon=0.000533 | TrainAcc=1.0000
# Fold 18 Epoch 500: TotalLoss=0.010131 | Sup=0.006398 | Recon=0.000467 | TrainAcc=1.0000
# Fold 18 Epoch 600: TotalLoss=0.007995 | Sup=0.004553 | Recon=0.000430 | TrainAcc=1.0000
# Fold 18 Epoch 700: TotalLoss=0.006032 | Sup=0.002899 | Recon=0.000392 | TrainAcc=1.0000
# Fold 18 Epoch 800: TotalLoss=0.005163 | Sup=0.002307 | Recon=0.000357 | TrainAcc=1.0000
# Fold 18 Epoch 900: TotalLoss=0.004908 | Sup=0.002196 | Recon=0.000339 | TrainAcc=1.0000
# Fold 18 Epoch 1000: TotalLoss=0.004080 | Sup=0.001534 | Recon=0.000318 | TrainAcc=1.0000
# Fold 18 Epoch 1100: TotalLoss=0.003618 | Sup=0.001233 | Recon=0.000298 | TrainAcc=1.0000
# Fold 18 Epoch 1200: TotalLoss=0.003281 | Sup=0.001114 | Recon=0.000271 | TrainAcc=1.0000
# Fold 18 Epoch 1300: TotalLoss=0.003037 | Sup=0.001039 | Recon=0.000250 | TrainAcc=1.0000
# Fold 18 Epoch 1400: TotalLoss=0.002696 | Sup=0.000872 | Recon=0.000228 | TrainAcc=1.0000
# Fold 18 Epoch 1500: TotalLoss=0.002338 | Sup=0.000682 | Recon=0.000207 | TrainAcc=1.0000
# Fold 18 Epoch 1600: TotalLoss=0.002284 | Sup=0.000730 | Recon=0.000194 | TrainAcc=1.0000
# Fold 18 Epoch 1700: TotalLoss=0.001988 | Sup=0.000546 | Recon=0.000180 | TrainAcc=1.0000
# Fold 18 Epoch 1800: TotalLoss=0.001892 | Sup=0.000556 | Recon=0.000167 | TrainAcc=1.0000
# Fold 18 Epoch 1900: TotalLoss=0.001788 | Sup=0.000538 | Recon=0.000156 | TrainAcc=1.0000
# Fold 18 Epoch 2000: TotalLoss=0.001520 | Sup=0.000394 | Recon=0.000141 | TrainAcc=1.0000
# Fold 18 → Acc=0.9403 | Prec=0.9259 | Rec=0.9259 | F1=0.9259 | AUC=0.9917 | CE Loss=0.1642
#
# === Fold 19 ===
# Train Control: 93, Train Patient: 63
# Fold 19 Epoch 1: TotalLoss=1.070025 | Sup=0.752253 | Recon=0.039721 | TrainAcc=0.4038
# Fold 19 Epoch 100: TotalLoss=0.186712 | Sup=0.167527 | Recon=0.002398 | TrainAcc=0.9744
# Fold 19 Epoch 200: TotalLoss=0.053180 | Sup=0.044016 | Recon=0.001145 | TrainAcc=1.0000
# Fold 19 Epoch 300: TotalLoss=0.024369 | Sup=0.018337 | Recon=0.000754 | TrainAcc=1.0000
# Fold 19 Epoch 400: TotalLoss=0.015462 | Sup=0.010594 | Recon=0.000609 | TrainAcc=1.0000
# Fold 19 Epoch 500: TotalLoss=0.010175 | Sup=0.005914 | Recon=0.000533 | TrainAcc=1.0000
# Fold 19 Epoch 600: TotalLoss=0.007995 | Sup=0.004250 | Recon=0.000468 | TrainAcc=1.0000
# Fold 19 Epoch 700: TotalLoss=0.006127 | Sup=0.002783 | Recon=0.000418 | TrainAcc=1.0000
# Fold 19 Epoch 800: TotalLoss=0.005462 | Sup=0.002375 | Recon=0.000386 | TrainAcc=1.0000
# Fold 19 Epoch 900: TotalLoss=0.004920 | Sup=0.002054 | Recon=0.000358 | TrainAcc=1.0000
# Fold 19 Epoch 1000: TotalLoss=0.004109 | Sup=0.001461 | Recon=0.000331 | TrainAcc=1.0000
# Fold 19 Epoch 1100: TotalLoss=0.003727 | Sup=0.001272 | Recon=0.000307 | TrainAcc=1.0000
# Fold 19 Epoch 1200: TotalLoss=0.003237 | Sup=0.000968 | Recon=0.000284 | TrainAcc=1.0000
# Fold 19 Epoch 1300: TotalLoss=0.003003 | Sup=0.000929 | Recon=0.000259 | TrainAcc=1.0000
# Fold 19 Epoch 1400: TotalLoss=0.002780 | Sup=0.000821 | Recon=0.000245 | TrainAcc=1.0000
# Fold 19 Epoch 1500: TotalLoss=0.002507 | Sup=0.000677 | Recon=0.000229 | TrainAcc=1.0000
# Fold 19 Epoch 1600: TotalLoss=0.002397 | Sup=0.000660 | Recon=0.000217 | TrainAcc=1.0000
# Fold 19 Epoch 1700: TotalLoss=0.002272 | Sup=0.000635 | Recon=0.000205 | TrainAcc=1.0000
# Fold 19 Epoch 1800: TotalLoss=0.002082 | Sup=0.000558 | Recon=0.000190 | TrainAcc=1.0000
# Fold 19 Epoch 1900: TotalLoss=0.001892 | Sup=0.000486 | Recon=0.000176 | TrainAcc=1.0000
# Fold 19 Epoch 2000: TotalLoss=0.001801 | Sup=0.000489 | Recon=0.000164 | TrainAcc=1.0000
# Fold 19 → Acc=0.8955 | Prec=0.8125 | Rec=0.9630 | F1=0.8814 | AUC=0.9889 | CE Loss=0.2440
#
# === Fold 20 ===
# Train Control: 93, Train Patient: 63
# Fold 20 Epoch 1: TotalLoss=1.070132 | Sup=0.766142 | Recon=0.037999 | TrainAcc=0.3910
# Fold 20 Epoch 100: TotalLoss=0.180174 | Sup=0.160788 | Recon=0.002423 | TrainAcc=0.9744
# Fold 20 Epoch 200: TotalLoss=0.055565 | Sup=0.045738 | Recon=0.001228 | TrainAcc=1.0000
# Fold 20 Epoch 300: TotalLoss=0.023573 | Sup=0.017294 | Recon=0.000785 | TrainAcc=1.0000
# Fold 20 Epoch 400: TotalLoss=0.014937 | Sup=0.010066 | Recon=0.000609 | TrainAcc=1.0000
# Fold 20 Epoch 500: TotalLoss=0.010315 | Sup=0.006164 | Recon=0.000519 | TrainAcc=1.0000
# Fold 20 Epoch 600: TotalLoss=0.008043 | Sup=0.004388 | Recon=0.000457 | TrainAcc=1.0000
# Fold 20 Epoch 700: TotalLoss=0.006313 | Sup=0.002982 | Recon=0.000416 | TrainAcc=1.0000
# Fold 20 Epoch 800: TotalLoss=0.005413 | Sup=0.002315 | Recon=0.000387 | TrainAcc=1.0000
# Fold 20 Epoch 900: TotalLoss=0.004840 | Sup=0.001996 | Recon=0.000356 | TrainAcc=1.0000
# Fold 20 Epoch 1000: TotalLoss=0.004107 | Sup=0.001450 | Recon=0.000332 | TrainAcc=1.0000
# Fold 20 Epoch 1100: TotalLoss=0.003794 | Sup=0.001355 | Recon=0.000305 | TrainAcc=1.0000
# Fold 20 Epoch 1200: TotalLoss=0.003410 | Sup=0.001116 | Recon=0.000287 | TrainAcc=1.0000
# Fold 20 Epoch 1300: TotalLoss=0.003203 | Sup=0.001063 | Recon=0.000267 | TrainAcc=1.0000
# Fold 20 Epoch 1400: TotalLoss=0.002729 | Sup=0.000782 | Recon=0.000243 | TrainAcc=1.0000
# Fold 20 Epoch 1500: TotalLoss=0.002505 | Sup=0.000676 | Recon=0.000229 | TrainAcc=1.0000
# Fold 20 Epoch 1600: TotalLoss=0.002322 | Sup=0.000641 | Recon=0.000210 | TrainAcc=1.0000
# Fold 20 Epoch 1700: TotalLoss=0.002256 | Sup=0.000652 | Recon=0.000201 | TrainAcc=1.0000
# Fold 20 Epoch 1800: TotalLoss=0.002106 | Sup=0.000606 | Recon=0.000187 | TrainAcc=1.0000
# Fold 20 Epoch 1900: TotalLoss=0.001987 | Sup=0.000558 | Recon=0.000179 | TrainAcc=1.0000
# Fold 20 Epoch 2000: TotalLoss=0.001779 | Sup=0.000448 | Recon=0.000166 | TrainAcc=1.0000
# Fold 20 → Acc=0.9403 | Prec=0.8710 | Rec=1.0000 | F1=0.9310 | AUC=0.9704 | CE Loss=0.3259
#
# === Average Results for λ = 8 ===
# Accuracy:  0.9418
# Precision: 0.9184
# Recall:    0.9426
# F1-score:  0.9289
# CE Loss:   0.2181
# AUC:       0.9823
#
#
# ====================== FINAL SUMMARY ACROSS ALL λ ======================
# Lambda   | Accuracy  | Precision | Recall   | F1-score  | AUC      | CE Loss
# ------------------------------------------------------------------------
# 0.001    | 0.9455    | 0.9248    | 0.9444   | 0.9334    | 0.9830   | 0.2160
# 0.005    | 0.9425    | 0.9177    | 0.9444   | 0.9299    | 0.9828   | 0.2183
# 0.009    | 0.9448    | 0.9213    | 0.9463   | 0.9327    | 0.9819   | 0.2236
# 0.01     | 0.9455    | 0.9234    | 0.9463   | 0.9335    | 0.9818   | 0.2224
# 0.05     | 0.9448    | 0.9219    | 0.9463   | 0.9326    | 0.9824   | 0.2256
# 0.09     | 0.9440    | 0.9226    | 0.9426   | 0.9315    | 0.9816   | 0.2280
# 0.1      | 0.9455    | 0.9233    | 0.9463   | 0.9334    | 0.9825   | 0.2236
# 0.3      | 0.9448    | 0.9217    | 0.9463   | 0.9326    | 0.9825   | 0.2196
# 0.5      | 0.9425    | 0.9169    | 0.9463   | 0.9302    | 0.9825   | 0.2247
# 0.9      | 0.9478    | 0.9254    | 0.9500   | 0.9364    | 0.9828   | 0.2185
# 1        | 0.9440    | 0.9214    | 0.9444   | 0.9314    | 0.9852   | 0.2218
# 2        | 0.9425    | 0.9193    | 0.9426   | 0.9297    | 0.9832   | 0.2189
# 5        | 0.9433    | 0.9202    | 0.9444   | 0.9309    | 0.9837   | 0.2178
# 8        | 0.9418    | 0.9184    | 0.9426   | 0.9289    | 0.9823   | 0.2181
