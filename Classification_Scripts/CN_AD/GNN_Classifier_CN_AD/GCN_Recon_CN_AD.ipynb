# %%
import os
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as nnFn
import torch.optim as optim
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, log_loss
from torch_geometric.data import Data
from torch_geometric.nn import GCNConv

device = 'cuda' if torch.cuda.is_available() else 'cpu'
print("Device:", device)

cn_path = "/home/snu/Downloads/Histogram_CN_FA_20bin_updated.npy"
ad_path = "/home/snu/Downloads/Histogram_AD_FA_20bin_updated.npy"


Histogram_feature_CN_FA_array = np.load(cn_path, allow_pickle=True)
Histogram_feature_AD_FA_array = np.load(ad_path, allow_pickle=True)

X = np.vstack([Histogram_feature_CN_FA_array, Histogram_feature_AD_FA_array])
y = np.hstack([
    np.zeros(Histogram_feature_CN_FA_array.shape[0], dtype=np.int64),  # CN → 0
    np.ones(Histogram_feature_AD_FA_array.shape[0], dtype=np.int64)    # AD → 1
])

num_nodes, num_feats = X.shape
print(f"Features: {X.shape}, Labels: {y.shape}")

# Shuffle for reproducibility
rng = np.random.RandomState(42)
perm = rng.permutation(num_nodes)
X = X[perm]
y = y[perm]

def create_adj(F_data, alpha=1):
    norms = np.linalg.norm(F_data, axis=1, keepdims=True)
    norms[norms == 0] = 1.0
    F_norm = F_data / norms
    W = np.dot(F_norm, F_norm.T)
    W = np.where(W >= alpha, 1.0, 0.0).astype(np.float32)
    if W.max() > 0:
        W = W / W.max()
    return W

alpha = 0.8
W = create_adj(X, alpha=alpha)
np.fill_diagonal(W, 1.0)

def load_data(adj, node_feats):
    node_feats = torch.from_numpy(node_feats).float()
    rows, cols = np.nonzero(adj > 0)
    edge_index = torch.from_numpy(np.vstack([rows, cols]).astype(np.int64))
    return Data(x=node_feats, edge_index=edge_index)

data = load_data(W, X).to(device)
print(data)

class GCN_AE(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim, device, activ="RELU", dropout=0.25):
        super(GCN_AE, self).__init__()
        self.device = device

        # --- Encoder ---
        self.conv1 = GCNConv(input_dim, hidden_dim)
        self.bn1 = nn.BatchNorm1d(hidden_dim)
        self.dropout = nn.Dropout(dropout)
        self.fc = nn.Linear(hidden_dim, output_dim)

        # --- Decoder ---
        self.decoder = nn.Sequential(
            nn.Linear(hidden_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, input_dim)
        )

        # --- Activation ---
        activations = {
            "SELU": nnFn.selu,
            "SiLU": nnFn.silu,
            "GELU": nnFn.gelu,
            "RELU": nnFn.relu,
            "ELU": nnFn.elu
        }
        self.act = activations.get(activ, nnFn.relu)

    def forward(self, x, edge_index):
        # Encoder
        h = self.conv1(x, edge_index)
        h = self.bn1(h)
        h = self.act(h)
        h = self.dropout(h)

        # Classification
        logits = self.fc(h)

        # Reconstruction
        recon = self.decoder(h)

        return logits, recon, h


feats_dim = num_feats
hidden_dim = 512
num_classes = 2
num_epochs = 2000
lr = 1e-4
weight_decay = 1e-4
batch_print_freq = 100
lambda_recon = 0.01

sss = StratifiedShuffleSplit(n_splits=20, test_size=0.3, random_state=42)
accuracies, precisions, recalls, f1_scores, aucs, ce_losses = [], [], [], [], [], []
y_all = y.copy()

for fold, (train_val_idx, test_idx_global) in enumerate(sss.split(X, y_all), start=1):
    print(f"\n=== Fold {fold} ===")
    cn_idx = np.where(y_all == 0)[0]
    ad_idx = np.where(y_all == 1)[0]
    sss_class = StratifiedShuffleSplit(n_splits=20, test_size=0.3, random_state=fold)
    cn_train_idx, _ = next(sss_class.split(X[cn_idx], y_all[cn_idx]))
    ad_train_idx, _ = next(sss_class.split(X[ad_idx], y_all[ad_idx]))
    cn_train = cn_idx[cn_train_idx]
    ad_train = ad_idx[ad_train_idx]
    train_idx_final = np.concatenate([cn_train, ad_train])
    np.random.shuffle(train_idx_final)

    print(f"Train CN: {len(cn_train)}, Train AD: {len(ad_train)}")
    train_idx_t = torch.from_numpy(train_idx_final).long().to(device)
    y_train_tensor = torch.from_numpy(y_all[train_idx_final]).long().to(device)

    model = GCN_AE(feats_dim, hidden_dim, num_classes, device, activ="RELU", dropout=0.25).to(device)
    optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
    ce_loss_fn = nn.CrossEntropyLoss()
    recon_loss_fn = nn.MSELoss()
    data = load_data(W, X).to(device)

    for epoch in range(1, num_epochs + 1):
        model.train()
        optimizer.zero_grad()
        logits, recon_x, _ = model(data.x, data.edge_index)

        loss_sup = ce_loss_fn(logits[train_idx_t], y_train_tensor)
        loss_recon = recon_loss_fn(recon_x, data.x)
        total_loss = loss_sup + lambda_recon * loss_recon

        if torch.isnan(total_loss) or torch.isinf(total_loss):
            print(f"NaN/Inf detected at fold {fold} epoch {epoch}. Aborting epoch.")
            break

        total_loss.backward()
        optimizer.step()

        if epoch % batch_print_freq == 0 or epoch == 1:
            model.eval()
            with torch.no_grad():
                logits_eval, _, _ = model(data.x, data.edge_index)
                preds_train = logits_eval[train_idx_t].argmax(dim=1)
                acc_train = accuracy_score(y_train_tensor.cpu(), preds_train.cpu())
            print(f"Fold {fold} Epoch {epoch}: TotalLoss={total_loss.item():.6f} | Sup={loss_sup.item():.6f} | Recon={loss_recon.item():.6f} | TrainAcc={acc_train:.4f}")

    model.eval()
    with torch.no_grad():
        out_logits, _, _ = model(data.x, data.edge_index)
        preds = out_logits.argmax(dim=1).cpu().numpy()
        probs = nnFn.softmax(out_logits, dim=1)[:, 1].cpu().numpy()

    y_test = y_all[test_idx_global]
    y_pred_test = preds[test_idx_global]
    y_prob_test = probs[test_idx_global]

    acc = accuracy_score(y_test, y_pred_test)
    prec = precision_score(y_test, y_pred_test, zero_division=0)
    rec = recall_score(y_test, y_pred_test, zero_division=0)
    f1 = f1_score(y_test, y_pred_test, zero_division=0)
    try:
        auc = roc_auc_score(y_test, y_prob_test)
    except ValueError:
        auc = float('nan')
    ce = log_loss(y_test, y_prob_test)

    accuracies.append(acc)
    precisions.append(prec)
    recalls.append(rec)
    f1_scores.append(f1)
    aucs.append(auc)
    ce_losses.append(ce)

    print(f"Fold {fold} → Acc={acc:.4f} | Prec={prec:.4f} | Rec={rec:.4f} | F1={f1:.4f} | AUC={auc:.4f} | CE Loss={ce:.4f}")


print("\n=== Average Results Across 20 Folds ===")
print(f"Accuracy:  {np.mean(accuracies):.4f} ± {np.std(accuracies):.4f}")
print(f"Precision: {np.mean(precisions):.4f} ± {np.std(precisions):.4f}")
print(f"Recall:    {np.mean(recalls):.4f} ± {np.std(recalls):.4f}")
print(f"F1-score:  {np.mean(f1_scores):.4f} ± {np.std(f1_scores):.4f}")
print(f"CE Loss:   {np.mean(ce_losses):.4f} ± {np.std(ce_losses):.4f}")
print(f"AUC:       {np.nanmean(aucs):.4f} ± {np.nanstd(aucs):.4f}")
# Out:
# Device: cuda
# Features: (223, 180), Labels: (223,)
# Data(x=[223, 180], edge_index=[2, 41689])
#
# === Fold 1 ===
# Train CN: 93, Train AD: 63
# Fold 1 Epoch 1: TotalLoss=0.726871 | Sup=0.726519 | Recon=0.035201 | TrainAcc=0.5962
# Fold 1 Epoch 100: TotalLoss=0.454486 | Sup=0.454447 | Recon=0.003960 | TrainAcc=0.7821
# Fold 1 Epoch 200: TotalLoss=0.440659 | Sup=0.440640 | Recon=0.001911 | TrainAcc=0.7949
# Fold 1 Epoch 300: TotalLoss=0.431431 | Sup=0.431417 | Recon=0.001326 | TrainAcc=0.8013
# Fold 1 Epoch 400: TotalLoss=0.416499 | Sup=0.416488 | Recon=0.001099 | TrainAcc=0.7949
# Fold 1 Epoch 500: TotalLoss=0.413585 | Sup=0.413574 | Recon=0.001028 | TrainAcc=0.8141
# Fold 1 Epoch 600: TotalLoss=0.396148 | Sup=0.396138 | Recon=0.000997 | TrainAcc=0.8205
# Fold 1 Epoch 700: TotalLoss=0.384025 | Sup=0.384015 | Recon=0.001003 | TrainAcc=0.8141
# Fold 1 Epoch 800: TotalLoss=0.376182 | Sup=0.376172 | Recon=0.001010 | TrainAcc=0.8013
# Fold 1 Epoch 900: TotalLoss=0.362660 | Sup=0.362649 | Recon=0.001024 | TrainAcc=0.8269
# Fold 1 Epoch 1000: TotalLoss=0.354045 | Sup=0.354035 | Recon=0.001032 | TrainAcc=0.8333
# Fold 1 Epoch 1100: TotalLoss=0.348750 | Sup=0.348739 | Recon=0.001041 | TrainAcc=0.8397
# Fold 1 Epoch 1200: TotalLoss=0.337893 | Sup=0.337883 | Recon=0.001052 | TrainAcc=0.8205
# Fold 1 Epoch 1300: TotalLoss=0.338727 | Sup=0.338717 | Recon=0.001072 | TrainAcc=0.8462
# Fold 1 Epoch 1400: TotalLoss=0.324782 | Sup=0.324772 | Recon=0.001083 | TrainAcc=0.8526
# Fold 1 Epoch 1500: TotalLoss=0.312177 | Sup=0.312166 | Recon=0.001087 | TrainAcc=0.8397
# Fold 1 Epoch 1600: TotalLoss=0.302179 | Sup=0.302167 | Recon=0.001102 | TrainAcc=0.8526
# Fold 1 Epoch 1700: TotalLoss=0.292083 | Sup=0.292072 | Recon=0.001116 | TrainAcc=0.8333
# Fold 1 Epoch 1800: TotalLoss=0.310579 | Sup=0.310568 | Recon=0.001121 | TrainAcc=0.8718
# Fold 1 Epoch 1900: TotalLoss=0.271702 | Sup=0.271691 | Recon=0.001126 | TrainAcc=0.8526
# Fold 1 Epoch 2000: TotalLoss=0.276849 | Sup=0.276838 | Recon=0.001139 | TrainAcc=0.8846
# Fold 1 → Acc=0.8507 | Prec=0.8148 | Rec=0.8148 | F1=0.8148 | AUC=0.8935 | CE Loss=0.4466
#
# === Fold 2 ===
# Train CN: 93, Train AD: 63
# Fold 2 Epoch 1: TotalLoss=0.709474 | Sup=0.709141 | Recon=0.033251 | TrainAcc=0.5962
# Fold 2 Epoch 100: TotalLoss=0.478274 | Sup=0.478237 | Recon=0.003768 | TrainAcc=0.7821
# Fold 2 Epoch 200: TotalLoss=0.451179 | Sup=0.451159 | Recon=0.001919 | TrainAcc=0.7821
# Fold 2 Epoch 300: TotalLoss=0.430990 | Sup=0.430977 | Recon=0.001339 | TrainAcc=0.7885
# Fold 2 Epoch 400: TotalLoss=0.433497 | Sup=0.433486 | Recon=0.001093 | TrainAcc=0.8141
# Fold 2 Epoch 500: TotalLoss=0.414110 | Sup=0.414100 | Recon=0.001029 | TrainAcc=0.7885
# Fold 2 Epoch 600: TotalLoss=0.398257 | Sup=0.398247 | Recon=0.001007 | TrainAcc=0.8269
# Fold 2 Epoch 700: TotalLoss=0.392752 | Sup=0.392742 | Recon=0.001010 | TrainAcc=0.8205
# Fold 2 Epoch 800: TotalLoss=0.384007 | Sup=0.383997 | Recon=0.001019 | TrainAcc=0.7628
# Fold 2 Epoch 900: TotalLoss=0.378765 | Sup=0.378755 | Recon=0.001033 | TrainAcc=0.8333
# Fold 2 Epoch 1000: TotalLoss=0.366549 | Sup=0.366539 | Recon=0.001041 | TrainAcc=0.8397
# Fold 2 Epoch 1100: TotalLoss=0.357972 | Sup=0.357962 | Recon=0.001045 | TrainAcc=0.8013
# Fold 2 Epoch 1200: TotalLoss=0.348999 | Sup=0.348988 | Recon=0.001062 | TrainAcc=0.8269
# Fold 2 Epoch 1300: TotalLoss=0.329293 | Sup=0.329282 | Recon=0.001066 | TrainAcc=0.7949
# Fold 2 Epoch 1400: TotalLoss=0.328045 | Sup=0.328034 | Recon=0.001088 | TrainAcc=0.7949
# Fold 2 Epoch 1500: TotalLoss=0.308716 | Sup=0.308705 | Recon=0.001098 | TrainAcc=0.8333
# Fold 2 Epoch 1600: TotalLoss=0.298385 | Sup=0.298374 | Recon=0.001109 | TrainAcc=0.8333
# Fold 2 Epoch 1700: TotalLoss=0.292459 | Sup=0.292448 | Recon=0.001117 | TrainAcc=0.8462
# Fold 2 Epoch 1800: TotalLoss=0.286663 | Sup=0.286652 | Recon=0.001126 | TrainAcc=0.8333
# Fold 2 Epoch 1900: TotalLoss=0.272658 | Sup=0.272647 | Recon=0.001135 | TrainAcc=0.8782
# Fold 2 Epoch 2000: TotalLoss=0.264929 | Sup=0.264917 | Recon=0.001147 | TrainAcc=0.8590
# Fold 2 → Acc=0.7910 | Prec=0.8824 | Rec=0.5556 | F1=0.6818 | AUC=0.8935 | CE Loss=0.4467
#
# === Fold 3 ===
# Train CN: 93, Train AD: 63
# Fold 3 Epoch 1: TotalLoss=0.658954 | Sup=0.658607 | Recon=0.034689 | TrainAcc=0.4038
# Fold 3 Epoch 100: TotalLoss=0.423422 | Sup=0.423385 | Recon=0.003754 | TrainAcc=0.8013
# Fold 3 Epoch 200: TotalLoss=0.398399 | Sup=0.398381 | Recon=0.001847 | TrainAcc=0.8205
# Fold 3 Epoch 300: TotalLoss=0.373466 | Sup=0.373453 | Recon=0.001259 | TrainAcc=0.8269
# Fold 3 Epoch 400: TotalLoss=0.350544 | Sup=0.350534 | Recon=0.001063 | TrainAcc=0.8526
# Fold 3 Epoch 500: TotalLoss=0.333432 | Sup=0.333422 | Recon=0.001006 | TrainAcc=0.8462
# Fold 3 Epoch 600: TotalLoss=0.320565 | Sup=0.320555 | Recon=0.000990 | TrainAcc=0.8590
# Fold 3 Epoch 700: TotalLoss=0.306081 | Sup=0.306071 | Recon=0.000985 | TrainAcc=0.8526
# Fold 3 Epoch 800: TotalLoss=0.297392 | Sup=0.297382 | Recon=0.000998 | TrainAcc=0.8654
# Fold 3 Epoch 900: TotalLoss=0.281643 | Sup=0.281632 | Recon=0.001006 | TrainAcc=0.8462
# Fold 3 Epoch 1000: TotalLoss=0.288363 | Sup=0.288352 | Recon=0.001022 | TrainAcc=0.8654
# Fold 3 Epoch 1100: TotalLoss=0.270237 | Sup=0.270226 | Recon=0.001037 | TrainAcc=0.8910
# Fold 3 Epoch 1200: TotalLoss=0.272035 | Sup=0.272024 | Recon=0.001056 | TrainAcc=0.8526
# Fold 3 Epoch 1300: TotalLoss=0.247325 | Sup=0.247315 | Recon=0.001065 | TrainAcc=0.8846
# Fold 3 Epoch 1400: TotalLoss=0.249359 | Sup=0.249348 | Recon=0.001074 | TrainAcc=0.9038
# Fold 3 Epoch 1500: TotalLoss=0.244435 | Sup=0.244425 | Recon=0.001090 | TrainAcc=0.8910
# Fold 3 Epoch 1600: TotalLoss=0.228152 | Sup=0.228141 | Recon=0.001097 | TrainAcc=0.8269
# Fold 3 Epoch 1700: TotalLoss=0.218324 | Sup=0.218313 | Recon=0.001105 | TrainAcc=0.8910
# Fold 3 Epoch 1800: TotalLoss=0.216231 | Sup=0.216220 | Recon=0.001115 | TrainAcc=0.8846
# Fold 3 Epoch 1900: TotalLoss=0.217501 | Sup=0.217490 | Recon=0.001119 | TrainAcc=0.8974
# Fold 3 Epoch 2000: TotalLoss=0.200057 | Sup=0.200046 | Recon=0.001121 | TrainAcc=0.9103
# Fold 3 → Acc=0.9104 | Prec=0.9200 | Rec=0.8519 | F1=0.8846 | AUC=0.9519 | CE Loss=0.2627
#
# === Fold 4 ===
# Train CN: 93, Train AD: 63
# Fold 4 Epoch 1: TotalLoss=0.838374 | Sup=0.838071 | Recon=0.030234 | TrainAcc=0.5897
# Fold 4 Epoch 100: TotalLoss=0.475735 | Sup=0.475697 | Recon=0.003761 | TrainAcc=0.7692
# Fold 4 Epoch 200: TotalLoss=0.453957 | Sup=0.453939 | Recon=0.001829 | TrainAcc=0.7885
# Fold 4 Epoch 300: TotalLoss=0.445908 | Sup=0.445895 | Recon=0.001270 | TrainAcc=0.7885
# Fold 4 Epoch 400: TotalLoss=0.408074 | Sup=0.408063 | Recon=0.001066 | TrainAcc=0.8013
# Fold 4 Epoch 500: TotalLoss=0.399667 | Sup=0.399656 | Recon=0.001020 | TrainAcc=0.8077
# Fold 4 Epoch 600: TotalLoss=0.381726 | Sup=0.381716 | Recon=0.000996 | TrainAcc=0.8141
# Fold 4 Epoch 700: TotalLoss=0.363199 | Sup=0.363188 | Recon=0.001006 | TrainAcc=0.8397
# Fold 4 Epoch 800: TotalLoss=0.352064 | Sup=0.352054 | Recon=0.001018 | TrainAcc=0.8397
# Fold 4 Epoch 900: TotalLoss=0.347698 | Sup=0.347688 | Recon=0.001021 | TrainAcc=0.8526
# Fold 4 Epoch 1000: TotalLoss=0.324933 | Sup=0.324923 | Recon=0.001036 | TrainAcc=0.8526
# Fold 4 Epoch 1100: TotalLoss=0.317193 | Sup=0.317183 | Recon=0.001047 | TrainAcc=0.8462
# Fold 4 Epoch 1200: TotalLoss=0.306612 | Sup=0.306602 | Recon=0.001055 | TrainAcc=0.8654
# Fold 4 Epoch 1300: TotalLoss=0.304544 | Sup=0.304533 | Recon=0.001060 | TrainAcc=0.8462
# Fold 4 Epoch 1400: TotalLoss=0.290697 | Sup=0.290687 | Recon=0.001062 | TrainAcc=0.8654
# Fold 4 Epoch 1500: TotalLoss=0.286963 | Sup=0.286952 | Recon=0.001076 | TrainAcc=0.8718
# Fold 4 Epoch 1600: TotalLoss=0.275433 | Sup=0.275422 | Recon=0.001089 | TrainAcc=0.8910
# Fold 4 Epoch 1700: TotalLoss=0.258727 | Sup=0.258716 | Recon=0.001094 | TrainAcc=0.8846
# Fold 4 Epoch 1800: TotalLoss=0.260224 | Sup=0.260213 | Recon=0.001101 | TrainAcc=0.8718
# Fold 4 Epoch 1900: TotalLoss=0.255242 | Sup=0.255231 | Recon=0.001108 | TrainAcc=0.8590
# Fold 4 Epoch 2000: TotalLoss=0.234769 | Sup=0.234758 | Recon=0.001112 | TrainAcc=0.8526
# Fold 4 → Acc=0.8209 | Prec=0.7419 | Rec=0.8519 | F1=0.7931 | AUC=0.8838 | CE Loss=0.4552
#
# === Fold 5 ===
# Train CN: 93, Train AD: 63
# Fold 5 Epoch 1: TotalLoss=0.682029 | Sup=0.681678 | Recon=0.035122 | TrainAcc=0.4038
# Fold 5 Epoch 100: TotalLoss=0.477454 | Sup=0.477411 | Recon=0.004350 | TrainAcc=0.7756
# Fold 5 Epoch 200: TotalLoss=0.453569 | Sup=0.453549 | Recon=0.001986 | TrainAcc=0.8013
# Fold 5 Epoch 300: TotalLoss=0.435901 | Sup=0.435887 | Recon=0.001353 | TrainAcc=0.8013
# Fold 5 Epoch 400: TotalLoss=0.430835 | Sup=0.430824 | Recon=0.001122 | TrainAcc=0.7949
# Fold 5 Epoch 500: TotalLoss=0.405348 | Sup=0.405338 | Recon=0.001030 | TrainAcc=0.8269
# Fold 5 Epoch 600: TotalLoss=0.395369 | Sup=0.395359 | Recon=0.001005 | TrainAcc=0.8141
# Fold 5 Epoch 700: TotalLoss=0.391946 | Sup=0.391935 | Recon=0.001000 | TrainAcc=0.8205
# Fold 5 Epoch 800: TotalLoss=0.386846 | Sup=0.386835 | Recon=0.001022 | TrainAcc=0.8077
# Fold 5 Epoch 900: TotalLoss=0.370186 | Sup=0.370176 | Recon=0.001024 | TrainAcc=0.7885
# Fold 5 Epoch 1000: TotalLoss=0.353153 | Sup=0.353142 | Recon=0.001041 | TrainAcc=0.8205
# Fold 5 Epoch 1100: TotalLoss=0.348046 | Sup=0.348035 | Recon=0.001057 | TrainAcc=0.8333
# Fold 5 Epoch 1200: TotalLoss=0.337660 | Sup=0.337649 | Recon=0.001064 | TrainAcc=0.8462
# Fold 5 Epoch 1300: TotalLoss=0.330176 | Sup=0.330166 | Recon=0.001075 | TrainAcc=0.8397
# Fold 5 Epoch 1400: TotalLoss=0.324134 | Sup=0.324123 | Recon=0.001093 | TrainAcc=0.8462
# Fold 5 Epoch 1500: TotalLoss=0.311624 | Sup=0.311612 | Recon=0.001109 | TrainAcc=0.8526
# Fold 5 Epoch 1600: TotalLoss=0.285609 | Sup=0.285598 | Recon=0.001118 | TrainAcc=0.8397
# Fold 5 Epoch 1700: TotalLoss=0.296704 | Sup=0.296693 | Recon=0.001129 | TrainAcc=0.7949
# Fold 5 Epoch 1800: TotalLoss=0.276100 | Sup=0.276088 | Recon=0.001145 | TrainAcc=0.8590
# Fold 5 Epoch 1900: TotalLoss=0.276794 | Sup=0.276783 | Recon=0.001157 | TrainAcc=0.7885
# Fold 5 Epoch 2000: TotalLoss=0.262619 | Sup=0.262607 | Recon=0.001158 | TrainAcc=0.8397
# Fold 5 → Acc=0.8358 | Prec=0.7857 | Rec=0.8148 | F1=0.8000 | AUC=0.8829 | CE Loss=0.5526
#
# === Fold 6 ===
# Train CN: 93, Train AD: 63
# Fold 6 Epoch 1: TotalLoss=0.743275 | Sup=0.742948 | Recon=0.032674 | TrainAcc=0.4038
# Fold 6 Epoch 100: TotalLoss=0.469147 | Sup=0.469107 | Recon=0.004001 | TrainAcc=0.7885
# Fold 6 Epoch 200: TotalLoss=0.432477 | Sup=0.432458 | Recon=0.001861 | TrainAcc=0.8077
# Fold 6 Epoch 300: TotalLoss=0.410491 | Sup=0.410478 | Recon=0.001274 | TrainAcc=0.8205
# Fold 6 Epoch 400: TotalLoss=0.382634 | Sup=0.382623 | Recon=0.001077 | TrainAcc=0.8141
# Fold 6 Epoch 500: TotalLoss=0.365945 | Sup=0.365935 | Recon=0.001020 | TrainAcc=0.8526
# Fold 6 Epoch 600: TotalLoss=0.355449 | Sup=0.355439 | Recon=0.001001 | TrainAcc=0.8205
# Fold 6 Epoch 700: TotalLoss=0.348020 | Sup=0.348011 | Recon=0.000988 | TrainAcc=0.8077
# Fold 6 Epoch 800: TotalLoss=0.333193 | Sup=0.333183 | Recon=0.000995 | TrainAcc=0.8397
# Fold 6 Epoch 900: TotalLoss=0.310956 | Sup=0.310946 | Recon=0.000997 | TrainAcc=0.8526
# Fold 6 Epoch 1000: TotalLoss=0.307726 | Sup=0.307716 | Recon=0.001007 | TrainAcc=0.8654
# Fold 6 Epoch 1100: TotalLoss=0.297261 | Sup=0.297251 | Recon=0.001017 | TrainAcc=0.8846
# Fold 6 Epoch 1200: TotalLoss=0.295833 | Sup=0.295822 | Recon=0.001030 | TrainAcc=0.8269
# Fold 6 Epoch 1300: TotalLoss=0.281324 | Sup=0.281314 | Recon=0.001028 | TrainAcc=0.8782
# Fold 6 Epoch 1400: TotalLoss=0.270250 | Sup=0.270240 | Recon=0.001032 | TrainAcc=0.8718
# Fold 6 Epoch 1500: TotalLoss=0.263725 | Sup=0.263714 | Recon=0.001040 | TrainAcc=0.8654
# Fold 6 Epoch 1600: TotalLoss=0.250811 | Sup=0.250800 | Recon=0.001049 | TrainAcc=0.8782
# Fold 6 Epoch 1700: TotalLoss=0.249302 | Sup=0.249292 | Recon=0.001067 | TrainAcc=0.8654
# Fold 6 Epoch 1800: TotalLoss=0.242441 | Sup=0.242430 | Recon=0.001072 | TrainAcc=0.8910
# Fold 6 Epoch 1900: TotalLoss=0.233325 | Sup=0.233314 | Recon=0.001088 | TrainAcc=0.8013
# Fold 6 Epoch 2000: TotalLoss=0.227154 | Sup=0.227143 | Recon=0.001096 | TrainAcc=0.8654
# Fold 6 → Acc=0.8358 | Prec=0.7857 | Rec=0.8148 | F1=0.8000 | AUC=0.9176 | CE Loss=0.3338
#
# === Fold 7 ===
# Train CN: 93, Train AD: 63
# Fold 7 Epoch 1: TotalLoss=0.700538 | Sup=0.700221 | Recon=0.031705 | TrainAcc=0.6026
# Fold 7 Epoch 100: TotalLoss=0.477211 | Sup=0.477169 | Recon=0.004219 | TrainAcc=0.7692
# Fold 7 Epoch 200: TotalLoss=0.458579 | Sup=0.458559 | Recon=0.001946 | TrainAcc=0.8013
# Fold 7 Epoch 300: TotalLoss=0.440440 | Sup=0.440426 | Recon=0.001338 | TrainAcc=0.7756
# Fold 7 Epoch 400: TotalLoss=0.428914 | Sup=0.428903 | Recon=0.001117 | TrainAcc=0.7949
# Fold 7 Epoch 500: TotalLoss=0.416512 | Sup=0.416501 | Recon=0.001033 | TrainAcc=0.8205
# Fold 7 Epoch 600: TotalLoss=0.411497 | Sup=0.411487 | Recon=0.001011 | TrainAcc=0.7949
# Fold 7 Epoch 700: TotalLoss=0.385104 | Sup=0.385093 | Recon=0.001005 | TrainAcc=0.8013
# Fold 7 Epoch 800: TotalLoss=0.369842 | Sup=0.369832 | Recon=0.001008 | TrainAcc=0.8141
# Fold 7 Epoch 900: TotalLoss=0.372218 | Sup=0.372208 | Recon=0.001017 | TrainAcc=0.8333
# Fold 7 Epoch 1000: TotalLoss=0.355454 | Sup=0.355444 | Recon=0.001013 | TrainAcc=0.8269
# Fold 7 Epoch 1100: TotalLoss=0.342705 | Sup=0.342695 | Recon=0.001035 | TrainAcc=0.8397
# Fold 7 Epoch 1200: TotalLoss=0.344655 | Sup=0.344645 | Recon=0.001039 | TrainAcc=0.7692
# Fold 7 Epoch 1300: TotalLoss=0.338248 | Sup=0.338238 | Recon=0.001040 | TrainAcc=0.8397
# Fold 7 Epoch 1400: TotalLoss=0.323991 | Sup=0.323980 | Recon=0.001060 | TrainAcc=0.8397
# Fold 7 Epoch 1500: TotalLoss=0.297576 | Sup=0.297566 | Recon=0.001074 | TrainAcc=0.8526
# Fold 7 Epoch 1600: TotalLoss=0.297426 | Sup=0.297415 | Recon=0.001085 | TrainAcc=0.8846
# Fold 7 Epoch 1700: TotalLoss=0.298383 | Sup=0.298372 | Recon=0.001100 | TrainAcc=0.8462
# Fold 7 Epoch 1800: TotalLoss=0.273402 | Sup=0.273391 | Recon=0.001103 | TrainAcc=0.6923
# Fold 7 Epoch 1900: TotalLoss=0.268981 | Sup=0.268970 | Recon=0.001110 | TrainAcc=0.8782
# Fold 7 Epoch 2000: TotalLoss=0.259064 | Sup=0.259053 | Recon=0.001119 | TrainAcc=0.7949
# Fold 7 → Acc=0.7761 | Prec=0.6765 | Rec=0.8519 | F1=0.7541 | AUC=0.8852 | CE Loss=0.4416
#
# === Fold 8 ===
# Train CN: 93, Train AD: 63
# Fold 8 Epoch 1: TotalLoss=0.769721 | Sup=0.769415 | Recon=0.030567 | TrainAcc=0.3526
# Fold 8 Epoch 100: TotalLoss=0.487652 | Sup=0.487617 | Recon=0.003529 | TrainAcc=0.7821
# Fold 8 Epoch 200: TotalLoss=0.466692 | Sup=0.466674 | Recon=0.001776 | TrainAcc=0.7692
# Fold 8 Epoch 300: TotalLoss=0.450840 | Sup=0.450827 | Recon=0.001230 | TrainAcc=0.8013
# Fold 8 Epoch 400: TotalLoss=0.434950 | Sup=0.434940 | Recon=0.001027 | TrainAcc=0.8077
# Fold 8 Epoch 500: TotalLoss=0.420824 | Sup=0.420815 | Recon=0.000967 | TrainAcc=0.8333
# Fold 8 Epoch 600: TotalLoss=0.410152 | Sup=0.410142 | Recon=0.000969 | TrainAcc=0.8269
# Fold 8 Epoch 700: TotalLoss=0.409354 | Sup=0.409344 | Recon=0.000971 | TrainAcc=0.8269
# Fold 8 Epoch 800: TotalLoss=0.397542 | Sup=0.397532 | Recon=0.000977 | TrainAcc=0.8013
# Fold 8 Epoch 900: TotalLoss=0.381035 | Sup=0.381025 | Recon=0.000982 | TrainAcc=0.8269
# Fold 8 Epoch 1000: TotalLoss=0.366332 | Sup=0.366322 | Recon=0.000996 | TrainAcc=0.8205
# Fold 8 Epoch 1100: TotalLoss=0.345877 | Sup=0.345866 | Recon=0.001015 | TrainAcc=0.8269
# Fold 8 Epoch 1200: TotalLoss=0.337684 | Sup=0.337674 | Recon=0.001021 | TrainAcc=0.8462
# Fold 8 Epoch 1300: TotalLoss=0.343481 | Sup=0.343470 | Recon=0.001031 | TrainAcc=0.8462
# Fold 8 Epoch 1400: TotalLoss=0.326685 | Sup=0.326675 | Recon=0.001032 | TrainAcc=0.8462
# Fold 8 Epoch 1500: TotalLoss=0.325257 | Sup=0.325246 | Recon=0.001040 | TrainAcc=0.8397
# Fold 8 Epoch 1600: TotalLoss=0.318774 | Sup=0.318763 | Recon=0.001051 | TrainAcc=0.8718
# Fold 8 Epoch 1700: TotalLoss=0.318213 | Sup=0.318202 | Recon=0.001064 | TrainAcc=0.8462
# Fold 8 Epoch 1800: TotalLoss=0.302615 | Sup=0.302604 | Recon=0.001068 | TrainAcc=0.8718
# Fold 8 Epoch 1900: TotalLoss=0.282656 | Sup=0.282645 | Recon=0.001077 | TrainAcc=0.8526
# Fold 8 Epoch 2000: TotalLoss=0.281532 | Sup=0.281521 | Recon=0.001087 | TrainAcc=0.8526
# Fold 8 → Acc=0.8209 | Prec=0.8947 | Rec=0.6296 | F1=0.7391 | AUC=0.8894 | CE Loss=0.3862
#
# === Fold 9 ===
# Train CN: 93, Train AD: 63
# Fold 9 Epoch 1: TotalLoss=0.687977 | Sup=0.687659 | Recon=0.031797 | TrainAcc=0.6026
# Fold 9 Epoch 100: TotalLoss=0.461570 | Sup=0.461531 | Recon=0.003845 | TrainAcc=0.7821
# Fold 9 Epoch 200: TotalLoss=0.440579 | Sup=0.440561 | Recon=0.001763 | TrainAcc=0.8077
# Fold 9 Epoch 300: TotalLoss=0.431761 | Sup=0.431749 | Recon=0.001201 | TrainAcc=0.8013
# Fold 9 Epoch 400: TotalLoss=0.413055 | Sup=0.413045 | Recon=0.001012 | TrainAcc=0.8205
# Fold 9 Epoch 500: TotalLoss=0.408304 | Sup=0.408294 | Recon=0.000967 | TrainAcc=0.8077
# Fold 9 Epoch 600: TotalLoss=0.396520 | Sup=0.396511 | Recon=0.000944 | TrainAcc=0.8205
# Fold 9 Epoch 700: TotalLoss=0.390919 | Sup=0.390910 | Recon=0.000952 | TrainAcc=0.8333
# Fold 9 Epoch 800: TotalLoss=0.374488 | Sup=0.374479 | Recon=0.000962 | TrainAcc=0.8526
# Fold 9 Epoch 900: TotalLoss=0.373289 | Sup=0.373279 | Recon=0.000979 | TrainAcc=0.8333
# Fold 9 Epoch 1000: TotalLoss=0.360512 | Sup=0.360502 | Recon=0.000987 | TrainAcc=0.8141
# Fold 9 Epoch 1100: TotalLoss=0.349279 | Sup=0.349269 | Recon=0.000997 | TrainAcc=0.8205
# Fold 9 Epoch 1200: TotalLoss=0.344572 | Sup=0.344562 | Recon=0.001004 | TrainAcc=0.8654
# Fold 9 Epoch 1300: TotalLoss=0.327363 | Sup=0.327353 | Recon=0.001028 | TrainAcc=0.7885
# Fold 9 Epoch 1400: TotalLoss=0.325108 | Sup=0.325097 | Recon=0.001034 | TrainAcc=0.8205
# Fold 9 Epoch 1500: TotalLoss=0.307545 | Sup=0.307534 | Recon=0.001041 | TrainAcc=0.8077
# Fold 9 Epoch 1600: TotalLoss=0.309929 | Sup=0.309919 | Recon=0.001051 | TrainAcc=0.8654
# Fold 9 Epoch 1700: TotalLoss=0.297457 | Sup=0.297447 | Recon=0.001066 | TrainAcc=0.8077
# Fold 9 Epoch 1800: TotalLoss=0.285990 | Sup=0.285980 | Recon=0.001066 | TrainAcc=0.7756
# Fold 9 Epoch 1900: TotalLoss=0.274504 | Sup=0.274493 | Recon=0.001078 | TrainAcc=0.8141
# Fold 9 Epoch 2000: TotalLoss=0.265363 | Sup=0.265352 | Recon=0.001084 | TrainAcc=0.8590
# Fold 9 → Acc=0.7761 | Prec=0.7308 | Rec=0.7037 | F1=0.7170 | AUC=0.8181 | CE Loss=0.6602
#
# === Fold 10 ===
# Train CN: 93, Train AD: 63
# Fold 10 Epoch 1: TotalLoss=0.762846 | Sup=0.762524 | Recon=0.032202 | TrainAcc=0.6154
# Fold 10 Epoch 100: TotalLoss=0.458001 | Sup=0.457961 | Recon=0.003957 | TrainAcc=0.7949
# Fold 10 Epoch 200: TotalLoss=0.443804 | Sup=0.443785 | Recon=0.001998 | TrainAcc=0.8141
# Fold 10 Epoch 300: TotalLoss=0.414715 | Sup=0.414702 | Recon=0.001303 | TrainAcc=0.8077
# Fold 10 Epoch 400: TotalLoss=0.403901 | Sup=0.403890 | Recon=0.001097 | TrainAcc=0.8269
# Fold 10 Epoch 500: TotalLoss=0.392835 | Sup=0.392825 | Recon=0.001016 | TrainAcc=0.8205
# Fold 10 Epoch 600: TotalLoss=0.389108 | Sup=0.389098 | Recon=0.000998 | TrainAcc=0.8333
# Fold 10 Epoch 700: TotalLoss=0.371776 | Sup=0.371766 | Recon=0.000991 | TrainAcc=0.8205
# Fold 10 Epoch 800: TotalLoss=0.371912 | Sup=0.371902 | Recon=0.000982 | TrainAcc=0.8397
# Fold 10 Epoch 900: TotalLoss=0.351329 | Sup=0.351319 | Recon=0.001002 | TrainAcc=0.8397
# Fold 10 Epoch 1000: TotalLoss=0.347720 | Sup=0.347710 | Recon=0.001013 | TrainAcc=0.8462
# Fold 10 Epoch 1100: TotalLoss=0.345818 | Sup=0.345807 | Recon=0.001020 | TrainAcc=0.8526
# Fold 10 Epoch 1200: TotalLoss=0.335254 | Sup=0.335243 | Recon=0.001036 | TrainAcc=0.8462
# Fold 10 Epoch 1300: TotalLoss=0.343038 | Sup=0.343027 | Recon=0.001038 | TrainAcc=0.8590
# Fold 10 Epoch 1400: TotalLoss=0.322805 | Sup=0.322794 | Recon=0.001047 | TrainAcc=0.8397
# Fold 10 Epoch 1500: TotalLoss=0.312311 | Sup=0.312300 | Recon=0.001055 | TrainAcc=0.8141
# Fold 10 Epoch 1600: TotalLoss=0.300235 | Sup=0.300224 | Recon=0.001069 | TrainAcc=0.8333
# Fold 10 Epoch 1700: TotalLoss=0.300302 | Sup=0.300291 | Recon=0.001072 | TrainAcc=0.8718
# Fold 10 Epoch 1800: TotalLoss=0.289484 | Sup=0.289473 | Recon=0.001075 | TrainAcc=0.8590
# Fold 10 Epoch 1900: TotalLoss=0.292827 | Sup=0.292816 | Recon=0.001075 | TrainAcc=0.8654
# Fold 10 Epoch 2000: TotalLoss=0.275561 | Sup=0.275550 | Recon=0.001098 | TrainAcc=0.8782
# Fold 10 → Acc=0.8507 | Prec=0.9048 | Rec=0.7037 | F1=0.7917 | AUC=0.8491 | CE Loss=0.4389
#
# === Fold 11 ===
# Train CN: 93, Train AD: 63
# Fold 11 Epoch 1: TotalLoss=0.671869 | Sup=0.671479 | Recon=0.039022 | TrainAcc=0.3974
# Fold 11 Epoch 100: TotalLoss=0.462774 | Sup=0.462733 | Recon=0.004036 | TrainAcc=0.7756
# Fold 11 Epoch 200: TotalLoss=0.443251 | Sup=0.443231 | Recon=0.001978 | TrainAcc=0.7821
# Fold 11 Epoch 300: TotalLoss=0.423400 | Sup=0.423387 | Recon=0.001312 | TrainAcc=0.7949
# Fold 11 Epoch 400: TotalLoss=0.397443 | Sup=0.397432 | Recon=0.001098 | TrainAcc=0.8269
# Fold 11 Epoch 500: TotalLoss=0.379543 | Sup=0.379533 | Recon=0.001024 | TrainAcc=0.8397
# Fold 11 Epoch 600: TotalLoss=0.366869 | Sup=0.366859 | Recon=0.001013 | TrainAcc=0.8269
# Fold 11 Epoch 700: TotalLoss=0.357460 | Sup=0.357450 | Recon=0.001000 | TrainAcc=0.8141
# Fold 11 Epoch 800: TotalLoss=0.342382 | Sup=0.342372 | Recon=0.001005 | TrainAcc=0.8333
# Fold 11 Epoch 900: TotalLoss=0.321201 | Sup=0.321191 | Recon=0.001013 | TrainAcc=0.8462
# Fold 11 Epoch 1000: TotalLoss=0.332585 | Sup=0.332575 | Recon=0.001015 | TrainAcc=0.8590
# Fold 11 Epoch 1100: TotalLoss=0.313485 | Sup=0.313475 | Recon=0.001020 | TrainAcc=0.8526
# Fold 11 Epoch 1200: TotalLoss=0.290425 | Sup=0.290415 | Recon=0.001027 | TrainAcc=0.8269
# Fold 11 Epoch 1300: TotalLoss=0.284318 | Sup=0.284308 | Recon=0.001040 | TrainAcc=0.8782
# Fold 11 Epoch 1400: TotalLoss=0.281271 | Sup=0.281260 | Recon=0.001055 | TrainAcc=0.8590
# Fold 11 Epoch 1500: TotalLoss=0.272360 | Sup=0.272350 | Recon=0.001053 | TrainAcc=0.8205
# Fold 11 Epoch 1600: TotalLoss=0.276263 | Sup=0.276252 | Recon=0.001067 | TrainAcc=0.8269
# Fold 11 Epoch 1700: TotalLoss=0.247647 | Sup=0.247636 | Recon=0.001081 | TrainAcc=0.8654
# Fold 11 Epoch 1800: TotalLoss=0.244801 | Sup=0.244790 | Recon=0.001086 | TrainAcc=0.8846
# Fold 11 Epoch 1900: TotalLoss=0.237562 | Sup=0.237551 | Recon=0.001081 | TrainAcc=0.8974
# Fold 11 Epoch 2000: TotalLoss=0.236025 | Sup=0.236014 | Recon=0.001090 | TrainAcc=0.9103
# Fold 11 → Acc=0.8806 | Prec=0.8800 | Rec=0.8148 | F1=0.8462 | AUC=0.8991 | CE Loss=0.4120
#
# === Fold 12 ===
# Train CN: 93, Train AD: 63
# Fold 12 Epoch 1: TotalLoss=0.733289 | Sup=0.732980 | Recon=0.030953 | TrainAcc=0.4038
# Fold 12 Epoch 100: TotalLoss=0.468296 | Sup=0.468256 | Recon=0.003987 | TrainAcc=0.7949
# Fold 12 Epoch 200: TotalLoss=0.450916 | Sup=0.450897 | Recon=0.001976 | TrainAcc=0.8205
# Fold 12 Epoch 300: TotalLoss=0.426813 | Sup=0.426800 | Recon=0.001319 | TrainAcc=0.8205
# Fold 12 Epoch 400: TotalLoss=0.405607 | Sup=0.405596 | Recon=0.001118 | TrainAcc=0.8205
# Fold 12 Epoch 500: TotalLoss=0.391224 | Sup=0.391213 | Recon=0.001048 | TrainAcc=0.8077
# Fold 12 Epoch 600: TotalLoss=0.372357 | Sup=0.372347 | Recon=0.001028 | TrainAcc=0.8269
# Fold 12 Epoch 700: TotalLoss=0.371837 | Sup=0.371826 | Recon=0.001027 | TrainAcc=0.8269
# Fold 12 Epoch 800: TotalLoss=0.365197 | Sup=0.365187 | Recon=0.001016 | TrainAcc=0.8397
# Fold 12 Epoch 900: TotalLoss=0.353777 | Sup=0.353767 | Recon=0.001022 | TrainAcc=0.8462
# Fold 12 Epoch 1000: TotalLoss=0.343040 | Sup=0.343030 | Recon=0.001028 | TrainAcc=0.8397
# Fold 12 Epoch 1100: TotalLoss=0.336156 | Sup=0.336146 | Recon=0.001049 | TrainAcc=0.8462
# Fold 12 Epoch 1200: TotalLoss=0.326884 | Sup=0.326873 | Recon=0.001056 | TrainAcc=0.8462
# Fold 12 Epoch 1300: TotalLoss=0.314312 | Sup=0.314302 | Recon=0.001071 | TrainAcc=0.8269
# Fold 12 Epoch 1400: TotalLoss=0.311226 | Sup=0.311215 | Recon=0.001086 | TrainAcc=0.8333
# Fold 12 Epoch 1500: TotalLoss=0.299699 | Sup=0.299688 | Recon=0.001096 | TrainAcc=0.8462
# Fold 12 Epoch 1600: TotalLoss=0.299573 | Sup=0.299562 | Recon=0.001109 | TrainAcc=0.8077
# Fold 12 Epoch 1700: TotalLoss=0.290652 | Sup=0.290641 | Recon=0.001116 | TrainAcc=0.8462
# Fold 12 Epoch 1800: TotalLoss=0.277004 | Sup=0.276993 | Recon=0.001141 | TrainAcc=0.8718
# Fold 12 Epoch 1900: TotalLoss=0.266588 | Sup=0.266577 | Recon=0.001141 | TrainAcc=0.8654
# Fold 12 Epoch 2000: TotalLoss=0.263375 | Sup=0.263363 | Recon=0.001147 | TrainAcc=0.8462
# Fold 12 → Acc=0.8209 | Prec=0.8947 | Rec=0.6296 | F1=0.7391 | AUC=0.9069 | CE Loss=0.3811
#
# === Fold 13 ===
# Train CN: 93, Train AD: 63
# Fold 13 Epoch 1: TotalLoss=0.756338 | Sup=0.756011 | Recon=0.032770 | TrainAcc=0.4038
# Fold 13 Epoch 100: TotalLoss=0.438950 | Sup=0.438911 | Recon=0.003905 | TrainAcc=0.7949
# Fold 13 Epoch 200: TotalLoss=0.418145 | Sup=0.418126 | Recon=0.001916 | TrainAcc=0.8141
# Fold 13 Epoch 300: TotalLoss=0.398764 | Sup=0.398751 | Recon=0.001247 | TrainAcc=0.7949
# Fold 13 Epoch 400: TotalLoss=0.392844 | Sup=0.392833 | Recon=0.001058 | TrainAcc=0.8333
# Fold 13 Epoch 500: TotalLoss=0.379948 | Sup=0.379938 | Recon=0.001008 | TrainAcc=0.8141
# Fold 13 Epoch 600: TotalLoss=0.371467 | Sup=0.371457 | Recon=0.000988 | TrainAcc=0.8397
# Fold 13 Epoch 700: TotalLoss=0.353686 | Sup=0.353676 | Recon=0.000993 | TrainAcc=0.8462
# Fold 13 Epoch 800: TotalLoss=0.349498 | Sup=0.349488 | Recon=0.000994 | TrainAcc=0.8333
# Fold 13 Epoch 900: TotalLoss=0.347127 | Sup=0.347117 | Recon=0.001013 | TrainAcc=0.8269
# Fold 13 Epoch 1000: TotalLoss=0.323706 | Sup=0.323695 | Recon=0.001022 | TrainAcc=0.8526
# Fold 13 Epoch 1100: TotalLoss=0.314305 | Sup=0.314295 | Recon=0.001027 | TrainAcc=0.8654
# Fold 13 Epoch 1200: TotalLoss=0.306603 | Sup=0.306592 | Recon=0.001047 | TrainAcc=0.8718
# Fold 13 Epoch 1300: TotalLoss=0.297855 | Sup=0.297845 | Recon=0.001052 | TrainAcc=0.8462
# Fold 13 Epoch 1400: TotalLoss=0.284852 | Sup=0.284841 | Recon=0.001074 | TrainAcc=0.8718
# Fold 13 Epoch 1500: TotalLoss=0.281557 | Sup=0.281546 | Recon=0.001091 | TrainAcc=0.8846
# Fold 13 Epoch 1600: TotalLoss=0.259218 | Sup=0.259207 | Recon=0.001107 | TrainAcc=0.8141
# Fold 13 Epoch 1700: TotalLoss=0.247183 | Sup=0.247172 | Recon=0.001119 | TrainAcc=0.8462
# Fold 13 Epoch 1800: TotalLoss=0.250136 | Sup=0.250125 | Recon=0.001136 | TrainAcc=0.8526
# Fold 13 Epoch 1900: TotalLoss=0.234279 | Sup=0.234267 | Recon=0.001158 | TrainAcc=0.8910
# Fold 13 Epoch 2000: TotalLoss=0.234939 | Sup=0.234927 | Recon=0.001161 | TrainAcc=0.8590
# Fold 13 → Acc=0.8955 | Prec=0.9167 | Rec=0.8148 | F1=0.8627 | AUC=0.9458 | CE Loss=0.2732
#
# === Fold 14 ===
# Train CN: 93, Train AD: 63
# Fold 14 Epoch 1: TotalLoss=0.664198 | Sup=0.663878 | Recon=0.031991 | TrainAcc=0.5962
# Fold 14 Epoch 100: TotalLoss=0.475145 | Sup=0.475107 | Recon=0.003852 | TrainAcc=0.8077
# Fold 14 Epoch 200: TotalLoss=0.460564 | Sup=0.460545 | Recon=0.001895 | TrainAcc=0.8013
# Fold 14 Epoch 300: TotalLoss=0.449978 | Sup=0.449965 | Recon=0.001297 | TrainAcc=0.8013
# Fold 14 Epoch 400: TotalLoss=0.430088 | Sup=0.430077 | Recon=0.001093 | TrainAcc=0.8077
# Fold 14 Epoch 500: TotalLoss=0.416939 | Sup=0.416928 | Recon=0.001043 | TrainAcc=0.8141
# Fold 14 Epoch 600: TotalLoss=0.407713 | Sup=0.407703 | Recon=0.001012 | TrainAcc=0.8141
# Fold 14 Epoch 700: TotalLoss=0.392048 | Sup=0.392038 | Recon=0.001013 | TrainAcc=0.8205
# Fold 14 Epoch 800: TotalLoss=0.388969 | Sup=0.388959 | Recon=0.001013 | TrainAcc=0.8013
# Fold 14 Epoch 900: TotalLoss=0.373218 | Sup=0.373208 | Recon=0.001024 | TrainAcc=0.8397
# Fold 14 Epoch 1000: TotalLoss=0.362698 | Sup=0.362688 | Recon=0.001033 | TrainAcc=0.8141
# Fold 14 Epoch 1100: TotalLoss=0.349606 | Sup=0.349596 | Recon=0.001050 | TrainAcc=0.8205
# Fold 14 Epoch 1200: TotalLoss=0.344903 | Sup=0.344893 | Recon=0.001054 | TrainAcc=0.8526
# Fold 14 Epoch 1300: TotalLoss=0.334240 | Sup=0.334230 | Recon=0.001067 | TrainAcc=0.8269
# Fold 14 Epoch 1400: TotalLoss=0.326341 | Sup=0.326330 | Recon=0.001082 | TrainAcc=0.8333
# Fold 14 Epoch 1500: TotalLoss=0.312500 | Sup=0.312490 | Recon=0.001091 | TrainAcc=0.8333
# Fold 14 Epoch 1600: TotalLoss=0.300889 | Sup=0.300878 | Recon=0.001097 | TrainAcc=0.8526
# Fold 14 Epoch 1700: TotalLoss=0.281439 | Sup=0.281428 | Recon=0.001117 | TrainAcc=0.8782
# Fold 14 Epoch 1800: TotalLoss=0.273776 | Sup=0.273765 | Recon=0.001121 | TrainAcc=0.8910
# Fold 14 Epoch 1900: TotalLoss=0.268110 | Sup=0.268099 | Recon=0.001136 | TrainAcc=0.8718
# Fold 14 Epoch 2000: TotalLoss=0.257555 | Sup=0.257543 | Recon=0.001143 | TrainAcc=0.8333
# Fold 14 → Acc=0.8358 | Prec=0.7667 | Rec=0.8519 | F1=0.8070 | AUC=0.9324 | CE Loss=0.3460
#
# === Fold 15 ===
# Train CN: 93, Train AD: 63
# Fold 15 Epoch 1: TotalLoss=0.692720 | Sup=0.692332 | Recon=0.038825 | TrainAcc=0.4038
# Fold 15 Epoch 100: TotalLoss=0.406040 | Sup=0.406000 | Recon=0.004001 | TrainAcc=0.8269
# Fold 15 Epoch 200: TotalLoss=0.397391 | Sup=0.397372 | Recon=0.001903 | TrainAcc=0.8205
# Fold 15 Epoch 300: TotalLoss=0.382659 | Sup=0.382646 | Recon=0.001300 | TrainAcc=0.8205
# Fold 15 Epoch 400: TotalLoss=0.353024 | Sup=0.353013 | Recon=0.001105 | TrainAcc=0.8397
# Fold 15 Epoch 500: TotalLoss=0.348281 | Sup=0.348271 | Recon=0.001036 | TrainAcc=0.8526
# Fold 15 Epoch 600: TotalLoss=0.327790 | Sup=0.327779 | Recon=0.001027 | TrainAcc=0.8526
# Fold 15 Epoch 700: TotalLoss=0.315481 | Sup=0.315471 | Recon=0.001029 | TrainAcc=0.8462
# Fold 15 Epoch 800: TotalLoss=0.306919 | Sup=0.306909 | Recon=0.001021 | TrainAcc=0.8718
# Fold 15 Epoch 900: TotalLoss=0.296530 | Sup=0.296520 | Recon=0.001024 | TrainAcc=0.8782
# Fold 15 Epoch 1000: TotalLoss=0.296152 | Sup=0.296141 | Recon=0.001037 | TrainAcc=0.8782
# Fold 15 Epoch 1100: TotalLoss=0.286132 | Sup=0.286122 | Recon=0.001057 | TrainAcc=0.8526
# Fold 15 Epoch 1200: TotalLoss=0.277878 | Sup=0.277867 | Recon=0.001059 | TrainAcc=0.8782
# Fold 15 Epoch 1300: TotalLoss=0.264834 | Sup=0.264824 | Recon=0.001065 | TrainAcc=0.8654
# Fold 15 Epoch 1400: TotalLoss=0.248376 | Sup=0.248365 | Recon=0.001065 | TrainAcc=0.8846
# Fold 15 Epoch 1500: TotalLoss=0.243826 | Sup=0.243816 | Recon=0.001077 | TrainAcc=0.8526
# Fold 15 Epoch 1600: TotalLoss=0.233936 | Sup=0.233926 | Recon=0.001075 | TrainAcc=0.8654
# Fold 15 Epoch 1700: TotalLoss=0.225927 | Sup=0.225916 | Recon=0.001091 | TrainAcc=0.7949
# Fold 15 Epoch 1800: TotalLoss=0.233606 | Sup=0.233595 | Recon=0.001094 | TrainAcc=0.8846
# Fold 15 Epoch 1900: TotalLoss=0.223904 | Sup=0.223893 | Recon=0.001104 | TrainAcc=0.8846
# Fold 15 Epoch 2000: TotalLoss=0.200740 | Sup=0.200728 | Recon=0.001110 | TrainAcc=0.8397
# Fold 15 → Acc=0.7612 | Prec=0.6571 | Rec=0.8519 | F1=0.7419 | AUC=0.8699 | CE Loss=0.7013
#
# === Fold 16 ===
# Train CN: 93, Train AD: 63
# Fold 16 Epoch 1: TotalLoss=0.741546 | Sup=0.741268 | Recon=0.027811 | TrainAcc=0.4038
# Fold 16 Epoch 100: TotalLoss=0.454348 | Sup=0.454311 | Recon=0.003684 | TrainAcc=0.8013
# Fold 16 Epoch 200: TotalLoss=0.437301 | Sup=0.437283 | Recon=0.001778 | TrainAcc=0.8141
# Fold 16 Epoch 300: TotalLoss=0.423141 | Sup=0.423129 | Recon=0.001243 | TrainAcc=0.8077
# Fold 16 Epoch 400: TotalLoss=0.402595 | Sup=0.402585 | Recon=0.001047 | TrainAcc=0.8077
# Fold 16 Epoch 500: TotalLoss=0.383275 | Sup=0.383265 | Recon=0.001008 | TrainAcc=0.8205
# Fold 16 Epoch 600: TotalLoss=0.381472 | Sup=0.381462 | Recon=0.000987 | TrainAcc=0.8333
# Fold 16 Epoch 700: TotalLoss=0.369917 | Sup=0.369907 | Recon=0.000991 | TrainAcc=0.8397
# Fold 16 Epoch 800: TotalLoss=0.354946 | Sup=0.354936 | Recon=0.000994 | TrainAcc=0.8333
# Fold 16 Epoch 900: TotalLoss=0.347085 | Sup=0.347075 | Recon=0.001006 | TrainAcc=0.8397
# Fold 16 Epoch 1000: TotalLoss=0.356765 | Sup=0.356755 | Recon=0.001008 | TrainAcc=0.8269
# Fold 16 Epoch 1100: TotalLoss=0.337038 | Sup=0.337028 | Recon=0.001020 | TrainAcc=0.8654
# Fold 16 Epoch 1200: TotalLoss=0.342203 | Sup=0.342193 | Recon=0.001026 | TrainAcc=0.8397
# Fold 16 Epoch 1300: TotalLoss=0.322571 | Sup=0.322560 | Recon=0.001033 | TrainAcc=0.8526
# Fold 16 Epoch 1400: TotalLoss=0.321086 | Sup=0.321075 | Recon=0.001035 | TrainAcc=0.8654
# Fold 16 Epoch 1500: TotalLoss=0.308276 | Sup=0.308266 | Recon=0.001040 | TrainAcc=0.8590
# Fold 16 Epoch 1600: TotalLoss=0.307346 | Sup=0.307336 | Recon=0.001050 | TrainAcc=0.8526
# Fold 16 Epoch 1700: TotalLoss=0.299308 | Sup=0.299297 | Recon=0.001058 | TrainAcc=0.8590
# Fold 16 Epoch 1800: TotalLoss=0.292970 | Sup=0.292960 | Recon=0.001054 | TrainAcc=0.8718
# Fold 16 Epoch 1900: TotalLoss=0.289858 | Sup=0.289848 | Recon=0.001056 | TrainAcc=0.7949
# Fold 16 Epoch 2000: TotalLoss=0.270541 | Sup=0.270531 | Recon=0.001072 | TrainAcc=0.8590
# Fold 16 → Acc=0.7761 | Prec=0.8000 | Rec=0.5926 | F1=0.6809 | AUC=0.8435 | CE Loss=0.4899
#
# === Fold 17 ===
# Train CN: 93, Train AD: 63
# Fold 17 Epoch 1: TotalLoss=0.633003 | Sup=0.632712 | Recon=0.029144 | TrainAcc=0.5962
# Fold 17 Epoch 100: TotalLoss=0.461080 | Sup=0.461042 | Recon=0.003802 | TrainAcc=0.7885
# Fold 17 Epoch 200: TotalLoss=0.430855 | Sup=0.430836 | Recon=0.001926 | TrainAcc=0.8141
# Fold 17 Epoch 300: TotalLoss=0.401001 | Sup=0.400988 | Recon=0.001323 | TrainAcc=0.8333
# Fold 17 Epoch 400: TotalLoss=0.391048 | Sup=0.391037 | Recon=0.001097 | TrainAcc=0.8013
# Fold 17 Epoch 500: TotalLoss=0.369449 | Sup=0.369438 | Recon=0.001056 | TrainAcc=0.8397
# Fold 17 Epoch 600: TotalLoss=0.363971 | Sup=0.363961 | Recon=0.001028 | TrainAcc=0.8141
# Fold 17 Epoch 700: TotalLoss=0.344022 | Sup=0.344012 | Recon=0.001033 | TrainAcc=0.8590
# Fold 17 Epoch 800: TotalLoss=0.333530 | Sup=0.333519 | Recon=0.001034 | TrainAcc=0.8590
# Fold 17 Epoch 900: TotalLoss=0.322596 | Sup=0.322585 | Recon=0.001040 | TrainAcc=0.8526
# Fold 17 Epoch 1000: TotalLoss=0.315940 | Sup=0.315929 | Recon=0.001054 | TrainAcc=0.8654
# Fold 17 Epoch 1100: TotalLoss=0.313837 | Sup=0.313827 | Recon=0.001066 | TrainAcc=0.8654
# Fold 17 Epoch 1200: TotalLoss=0.295781 | Sup=0.295770 | Recon=0.001073 | TrainAcc=0.8654
# Fold 17 Epoch 1300: TotalLoss=0.292269 | Sup=0.292258 | Recon=0.001084 | TrainAcc=0.8654
# Fold 17 Epoch 1400: TotalLoss=0.280548 | Sup=0.280537 | Recon=0.001087 | TrainAcc=0.8590
# Fold 17 Epoch 1500: TotalLoss=0.282449 | Sup=0.282438 | Recon=0.001098 | TrainAcc=0.8718
# Fold 17 Epoch 1600: TotalLoss=0.287474 | Sup=0.287463 | Recon=0.001108 | TrainAcc=0.8269
# Fold 17 Epoch 1700: TotalLoss=0.251104 | Sup=0.251093 | Recon=0.001124 | TrainAcc=0.8718
# Fold 17 Epoch 1800: TotalLoss=0.245432 | Sup=0.245421 | Recon=0.001123 | TrainAcc=0.7244
# Fold 17 Epoch 1900: TotalLoss=0.246367 | Sup=0.246356 | Recon=0.001125 | TrainAcc=0.8782
# Fold 17 Epoch 2000: TotalLoss=0.232582 | Sup=0.232571 | Recon=0.001136 | TrainAcc=0.8910
# Fold 17 → Acc=0.9403 | Prec=0.9600 | Rec=0.8889 | F1=0.9231 | AUC=0.9352 | CE Loss=0.3052
#
# === Fold 18 ===
# Train CN: 93, Train AD: 63
# Fold 18 Epoch 1: TotalLoss=0.728261 | Sup=0.727929 | Recon=0.033141 | TrainAcc=0.6218
# Fold 18 Epoch 100: TotalLoss=0.494697 | Sup=0.494659 | Recon=0.003829 | TrainAcc=0.7692
# Fold 18 Epoch 200: TotalLoss=0.466996 | Sup=0.466978 | Recon=0.001792 | TrainAcc=0.7949
# Fold 18 Epoch 300: TotalLoss=0.449689 | Sup=0.449676 | Recon=0.001241 | TrainAcc=0.7949
# Fold 18 Epoch 400: TotalLoss=0.439318 | Sup=0.439308 | Recon=0.001064 | TrainAcc=0.8141
# Fold 18 Epoch 500: TotalLoss=0.421223 | Sup=0.421213 | Recon=0.000998 | TrainAcc=0.8077
# Fold 18 Epoch 600: TotalLoss=0.411404 | Sup=0.411394 | Recon=0.001004 | TrainAcc=0.8077
# Fold 18 Epoch 700: TotalLoss=0.399199 | Sup=0.399189 | Recon=0.001000 | TrainAcc=0.8013
# Fold 18 Epoch 800: TotalLoss=0.393370 | Sup=0.393360 | Recon=0.001017 | TrainAcc=0.8077
# Fold 18 Epoch 900: TotalLoss=0.389173 | Sup=0.389163 | Recon=0.001029 | TrainAcc=0.8077
# Fold 18 Epoch 1000: TotalLoss=0.363984 | Sup=0.363974 | Recon=0.001048 | TrainAcc=0.7949
# Fold 18 Epoch 1100: TotalLoss=0.360302 | Sup=0.360291 | Recon=0.001062 | TrainAcc=0.8397
# Fold 18 Epoch 1200: TotalLoss=0.342870 | Sup=0.342860 | Recon=0.001076 | TrainAcc=0.8333
# Fold 18 Epoch 1300: TotalLoss=0.324340 | Sup=0.324329 | Recon=0.001087 | TrainAcc=0.7949
# Fold 18 Epoch 1400: TotalLoss=0.331975 | Sup=0.331964 | Recon=0.001103 | TrainAcc=0.8269
# Fold 18 Epoch 1500: TotalLoss=0.312342 | Sup=0.312331 | Recon=0.001108 | TrainAcc=0.8269
# Fold 18 Epoch 1600: TotalLoss=0.310363 | Sup=0.310352 | Recon=0.001114 | TrainAcc=0.7179
# Fold 18 Epoch 1700: TotalLoss=0.296417 | Sup=0.296405 | Recon=0.001123 | TrainAcc=0.8718
# Fold 18 Epoch 1800: TotalLoss=0.281111 | Sup=0.281099 | Recon=0.001134 | TrainAcc=0.8397
# Fold 18 Epoch 1900: TotalLoss=0.262330 | Sup=0.262319 | Recon=0.001138 | TrainAcc=0.8269
# Fold 18 Epoch 2000: TotalLoss=0.257886 | Sup=0.257874 | Recon=0.001144 | TrainAcc=0.7756
# Fold 18 → Acc=0.7761 | Prec=0.6765 | Rec=0.8519 | F1=0.7541 | AUC=0.9019 | CE Loss=0.4071
#
# === Fold 19 ===
# Train CN: 93, Train AD: 63
# Fold 19 Epoch 1: TotalLoss=0.679659 | Sup=0.679344 | Recon=0.031424 | TrainAcc=0.5962
# Fold 19 Epoch 100: TotalLoss=0.457701 | Sup=0.457665 | Recon=0.003593 | TrainAcc=0.7949
# Fold 19 Epoch 200: TotalLoss=0.423455 | Sup=0.423437 | Recon=0.001782 | TrainAcc=0.8077
# Fold 19 Epoch 300: TotalLoss=0.411988 | Sup=0.411976 | Recon=0.001223 | TrainAcc=0.7885
# Fold 19 Epoch 400: TotalLoss=0.400513 | Sup=0.400503 | Recon=0.001054 | TrainAcc=0.8333
# Fold 19 Epoch 500: TotalLoss=0.388263 | Sup=0.388253 | Recon=0.001022 | TrainAcc=0.8397
# Fold 19 Epoch 600: TotalLoss=0.376462 | Sup=0.376452 | Recon=0.001007 | TrainAcc=0.8205
# Fold 19 Epoch 700: TotalLoss=0.381526 | Sup=0.381515 | Recon=0.001009 | TrainAcc=0.8333
# Fold 19 Epoch 800: TotalLoss=0.355241 | Sup=0.355231 | Recon=0.001022 | TrainAcc=0.8205
# Fold 19 Epoch 900: TotalLoss=0.345758 | Sup=0.345747 | Recon=0.001031 | TrainAcc=0.8590
# Fold 19 Epoch 1000: TotalLoss=0.347460 | Sup=0.347450 | Recon=0.001040 | TrainAcc=0.8654
# Fold 19 Epoch 1100: TotalLoss=0.331110 | Sup=0.331100 | Recon=0.001047 | TrainAcc=0.8397
# Fold 19 Epoch 1200: TotalLoss=0.322321 | Sup=0.322310 | Recon=0.001060 | TrainAcc=0.8333
# Fold 19 Epoch 1300: TotalLoss=0.311848 | Sup=0.311838 | Recon=0.001066 | TrainAcc=0.8526
# Fold 19 Epoch 1400: TotalLoss=0.301687 | Sup=0.301676 | Recon=0.001067 | TrainAcc=0.8526
# Fold 19 Epoch 1500: TotalLoss=0.290534 | Sup=0.290523 | Recon=0.001082 | TrainAcc=0.8590
# Fold 19 Epoch 1600: TotalLoss=0.288201 | Sup=0.288190 | Recon=0.001094 | TrainAcc=0.7949
# Fold 19 Epoch 1700: TotalLoss=0.277871 | Sup=0.277860 | Recon=0.001097 | TrainAcc=0.8590
# Fold 19 Epoch 1800: TotalLoss=0.269292 | Sup=0.269281 | Recon=0.001097 | TrainAcc=0.6923
# Fold 19 Epoch 1900: TotalLoss=0.263796 | Sup=0.263785 | Recon=0.001108 | TrainAcc=0.8205
# Fold 19 Epoch 2000: TotalLoss=0.260963 | Sup=0.260952 | Recon=0.001116 | TrainAcc=0.8910
# Fold 19 → Acc=0.8657 | Prec=0.8462 | Rec=0.8148 | F1=0.8302 | AUC=0.8963 | CE Loss=0.4726
#
# === Fold 20 ===
# Train CN: 93, Train AD: 63
# Fold 20 Epoch 1: TotalLoss=0.797899 | Sup=0.797579 | Recon=0.032021 | TrainAcc=0.4038
# Fold 20 Epoch 100: TotalLoss=0.459434 | Sup=0.459397 | Recon=0.003717 | TrainAcc=0.7756
# Fold 20 Epoch 200: TotalLoss=0.434525 | Sup=0.434506 | Recon=0.001895 | TrainAcc=0.7821
# Fold 20 Epoch 300: TotalLoss=0.409303 | Sup=0.409290 | Recon=0.001273 | TrainAcc=0.8013
# Fold 20 Epoch 400: TotalLoss=0.387452 | Sup=0.387441 | Recon=0.001077 | TrainAcc=0.8333
# Fold 20 Epoch 500: TotalLoss=0.374680 | Sup=0.374670 | Recon=0.001015 | TrainAcc=0.8205
# Fold 20 Epoch 600: TotalLoss=0.355606 | Sup=0.355595 | Recon=0.001019 | TrainAcc=0.8397
# Fold 20 Epoch 700: TotalLoss=0.347178 | Sup=0.347168 | Recon=0.001023 | TrainAcc=0.8333
# Fold 20 Epoch 800: TotalLoss=0.341568 | Sup=0.341558 | Recon=0.001035 | TrainAcc=0.8269
# Fold 20 Epoch 900: TotalLoss=0.312219 | Sup=0.312209 | Recon=0.001052 | TrainAcc=0.8782
# Fold 20 Epoch 1000: TotalLoss=0.306095 | Sup=0.306084 | Recon=0.001073 | TrainAcc=0.8333
# Fold 20 Epoch 1100: TotalLoss=0.299379 | Sup=0.299368 | Recon=0.001081 | TrainAcc=0.8590
# Fold 20 Epoch 1200: TotalLoss=0.290959 | Sup=0.290948 | Recon=0.001092 | TrainAcc=0.8846
# Fold 20 Epoch 1300: TotalLoss=0.285637 | Sup=0.285626 | Recon=0.001091 | TrainAcc=0.8718
# Fold 20 Epoch 1400: TotalLoss=0.265075 | Sup=0.265064 | Recon=0.001105 | TrainAcc=0.8910
# Fold 20 Epoch 1500: TotalLoss=0.262957 | Sup=0.262946 | Recon=0.001116 | TrainAcc=0.8846
# Fold 20 Epoch 1600: TotalLoss=0.245791 | Sup=0.245780 | Recon=0.001127 | TrainAcc=0.8910
# Fold 20 Epoch 1700: TotalLoss=0.245940 | Sup=0.245929 | Recon=0.001133 | TrainAcc=0.8846
# Fold 20 Epoch 1800: TotalLoss=0.231783 | Sup=0.231772 | Recon=0.001133 | TrainAcc=0.7500
# Fold 20 Epoch 1900: TotalLoss=0.215931 | Sup=0.215920 | Recon=0.001140 | TrainAcc=0.8526
# Fold 20 Epoch 2000: TotalLoss=0.219482 | Sup=0.219471 | Recon=0.001146 | TrainAcc=0.8846
# Fold 20 → Acc=0.8507 | Prec=0.7742 | Rec=0.8889 | F1=0.8276 | AUC=0.8972 | CE Loss=0.7060
#
# === Average Results Across 20 Folds ===
# Accuracy:  0.8336 ± 0.0480
# Precision: 0.8155 ± 0.0879
# Recall:    0.7796 ± 0.1011
# F1-score:  0.7895 ± 0.0626
# CE Loss:   0.4459 ± 0.1243
# AUC:       0.8947 ± 0.0326

# %%
feats_dim = num_feats
hidden_dim = 512
num_classes = 2
num_epochs = 2000
lr = 1e-4
weight_decay = 1e-4
batch_print_freq = 100

# Lambda values to test
lambda_list = [0.001, 0.005, 0.009, 0.01, 0.05, 0.09, 0.1, 0.3, 0.5, 0.9, 1, 2, 5, 8]

# === Cross-validation setup ===
sss = StratifiedShuffleSplit(n_splits=20, test_size=0.3, random_state=42)
y_all = y.copy()

# To store all results for each lambda
lambda_results = []

# === Outer loop for lambda sweep ===
for lambda_recon in lambda_list:
    print(f"\n\n====================== λ_recon = {lambda_recon} ======================")

    accuracies, precisions, recalls, f1_scores, aucs, ce_losses = [], [], [], [], [], []

    for fold, (train_val_idx, test_idx_global) in enumerate(sss.split(X, y_all), start=1):
        print(f"\n=== Fold {fold} ===")

        control_idx = np.where(y_all == 0)[0]
        patient_idx = np.where(y_all == 1)[0]
        sss_class = StratifiedShuffleSplit(n_splits=20, test_size=0.3, random_state=fold)
        control_train_idx, _ = next(sss_class.split(X[control_idx], y_all[control_idx]))
        patient_train_idx, _ = next(sss_class.split(X[patient_idx], y_all[patient_idx]))
        control_train = control_idx[control_train_idx]
        patient_train = patient_idx[patient_train_idx]
        train_idx_final = np.concatenate([control_train, patient_train])
        np.random.shuffle(train_idx_final)

        print(f"Train Control: {len(control_train)}, Train Patient: {len(patient_train)}")

        train_idx_t = torch.from_numpy(train_idx_final).long().to(device)
        y_train_tensor = torch.from_numpy(y_all[train_idx_final]).long().to(device)

        model = GCN_AE(feats_dim, hidden_dim, num_classes, device, activ="RELU", dropout=0.25).to(device)
        optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
        ce_loss_fn = nn.CrossEntropyLoss()
        recon_loss_fn = nn.MSELoss()
        data = load_data(W, X).to(device)

        for epoch in range(1, num_epochs + 1):
            model.train()
            optimizer.zero_grad()
            logits, recon_x, _ = model(data.x, data.edge_index)

            loss_sup = ce_loss_fn(logits[train_idx_t], y_train_tensor)
            loss_recon = recon_loss_fn(recon_x, data.x)
            total_loss = loss_sup + lambda_recon * loss_recon

            if torch.isnan(total_loss) or torch.isinf(total_loss):
                print(f"NaN/Inf detected at fold {fold} epoch {epoch}. Aborting epoch.")
                break

            total_loss.backward()
            optimizer.step()

            if epoch % batch_print_freq == 0 or epoch == 1:
                model.eval()
                with torch.no_grad():
                    logits_eval, _, _ = model(data.x, data.edge_index)
                    preds_train = logits_eval[train_idx_t].argmax(dim=1)
                    acc_train = accuracy_score(y_train_tensor.cpu(), preds_train.cpu())
                print(f"Fold {fold} Epoch {epoch}: TotalLoss={total_loss.item():.6f} | Sup={loss_sup.item():.6f} | Recon={loss_recon.item():.6f} | TrainAcc={acc_train:.4f}")

        # === Evaluation ===
        model.eval()
        with torch.no_grad():
            out_logits, _, _ = model(data.x, data.edge_index)
            preds = out_logits.argmax(dim=1).cpu().numpy()
            probs = nnFn.softmax(out_logits, dim=1)[:, 1].cpu().numpy()

        y_test = y_all[test_idx_global]
        y_pred_test = preds[test_idx_global]
        y_prob_test = probs[test_idx_global]

        acc = accuracy_score(y_test, y_pred_test)
        prec = precision_score(y_test, y_pred_test, zero_division=0)
        rec = recall_score(y_test, y_pred_test, zero_division=0)
        f1 = f1_score(y_test, y_pred_test, zero_division=0)
        try:
            auc = roc_auc_score(y_test, y_prob_test)
        except ValueError:
            auc = float('nan')
        ce = log_loss(y_test, y_prob_test)

        accuracies.append(acc)
        precisions.append(prec)
        recalls.append(rec)
        f1_scores.append(f1)
        aucs.append(auc)
        ce_losses.append(ce)

        print(f"Fold {fold} → Acc={acc:.4f} | Prec={prec:.4f} | Rec={rec:.4f} | F1={f1:.4f} | AUC={auc:.4f} | CE Loss={ce:.4f}")

    # === Store average results for this λ ===
    avg_results = {
        "lambda": lambda_recon,
        "Accuracy": np.mean(accuracies),
        "Precision": np.mean(precisions),
        "Recall": np.mean(recalls),
        "F1-score": np.mean(f1_scores),
        "CE Loss": np.mean(ce_losses),
        "AUC": np.nanmean(aucs)
    }
    lambda_results.append(avg_results)

    print("\n=== Average Results for λ =", lambda_recon, "===")
    print(f"Accuracy:  {avg_results['Accuracy']:.4f}")
    print(f"Precision: {avg_results['Precision']:.4f}")
    print(f"Recall:    {avg_results['Recall']:.4f}")
    print(f"F1-score:  {avg_results['F1-score']:.4f}")
    print(f"CE Loss:   {avg_results['CE Loss']:.4f}")
    print(f"AUC:       {avg_results['AUC']:.4f}")


# === FINAL SUMMARY ACROSS ALL λ ===
print("\n\n====================== FINAL SUMMARY ACROSS ALL λ ======================")
print(f"{'Lambda':<8} | {'Accuracy':<9} | {'Precision':<9} | {'Recall':<8} | {'F1-score':<9} | {'AUC':<8} | {'CE Loss':<8}")
print("-" * 72)
for res in lambda_results:
    print(f"{res['lambda']:<8} | {res['Accuracy']:<9.4f} | {res['Precision']:<9.4f} | {res['Recall']:<8.4f} | {res['F1-score']:<9.4f} | {res['AUC']:<8.4f} | {res['CE Loss']:<8.4f}")
# Out:
# Streaming output truncated to the last 5000 lines.
# === Fold 6 ===
# Train Control: 93, Train Patient: 63
# Fold 6 Epoch 1: TotalLoss=0.714168 | Sup=0.712622 | Recon=0.030922 | TrainAcc=0.5962
# Fold 6 Epoch 100: TotalLoss=0.468489 | Sup=0.468372 | Recon=0.002344 | TrainAcc=0.7821
# Fold 6 Epoch 200: TotalLoss=0.434445 | Sup=0.434392 | Recon=0.001047 | TrainAcc=0.7949
# Fold 6 Epoch 300: TotalLoss=0.406412 | Sup=0.406376 | Recon=0.000716 | TrainAcc=0.8141
# Fold 6 Epoch 400: TotalLoss=0.381861 | Sup=0.381833 | Recon=0.000570 | TrainAcc=0.8333
# Fold 6 Epoch 500: TotalLoss=0.366689 | Sup=0.366663 | Recon=0.000525 | TrainAcc=0.8397
# Fold 6 Epoch 600: TotalLoss=0.360134 | Sup=0.360109 | Recon=0.000493 | TrainAcc=0.8590
# Fold 6 Epoch 700: TotalLoss=0.332275 | Sup=0.332250 | Recon=0.000497 | TrainAcc=0.8654
# Fold 6 Epoch 800: TotalLoss=0.319618 | Sup=0.319594 | Recon=0.000490 | TrainAcc=0.8462
# Fold 6 Epoch 900: TotalLoss=0.309439 | Sup=0.309414 | Recon=0.000493 | TrainAcc=0.8718
# Fold 6 Epoch 1000: TotalLoss=0.297207 | Sup=0.297182 | Recon=0.000493 | TrainAcc=0.8526
# Fold 6 Epoch 1100: TotalLoss=0.289717 | Sup=0.289692 | Recon=0.000500 | TrainAcc=0.8462
# Fold 6 Epoch 1200: TotalLoss=0.279091 | Sup=0.279065 | Recon=0.000504 | TrainAcc=0.8782
# Fold 6 Epoch 1300: TotalLoss=0.279533 | Sup=0.279508 | Recon=0.000499 | TrainAcc=0.8782
# Fold 6 Epoch 1400: TotalLoss=0.270223 | Sup=0.270198 | Recon=0.000502 | TrainAcc=0.8654
# Fold 6 Epoch 1500: TotalLoss=0.254929 | Sup=0.254904 | Recon=0.000510 | TrainAcc=0.8269
# Fold 6 Epoch 1600: TotalLoss=0.242166 | Sup=0.242140 | Recon=0.000512 | TrainAcc=0.8974
# Fold 6 Epoch 1700: TotalLoss=0.243121 | Sup=0.243095 | Recon=0.000518 | TrainAcc=0.8141
# Fold 6 Epoch 1800: TotalLoss=0.230826 | Sup=0.230800 | Recon=0.000519 | TrainAcc=0.9038
# Fold 6 Epoch 1900: TotalLoss=0.230400 | Sup=0.230374 | Recon=0.000521 | TrainAcc=0.8910
# Fold 6 Epoch 2000: TotalLoss=0.206832 | Sup=0.206806 | Recon=0.000527 | TrainAcc=0.8974
# Fold 6 → Acc=0.8806 | Prec=1.0000 | Rec=0.7037 | F1=0.8261 | AUC=0.9111 | CE Loss=0.3451
#
# === Fold 7 ===
# Train Control: 93, Train Patient: 63
# Fold 7 Epoch 1: TotalLoss=0.697907 | Sup=0.696291 | Recon=0.032322 | TrainAcc=0.4038
# Fold 7 Epoch 100: TotalLoss=0.496285 | Sup=0.496154 | Recon=0.002615 | TrainAcc=0.7756
# Fold 7 Epoch 200: TotalLoss=0.449172 | Sup=0.449114 | Recon=0.001148 | TrainAcc=0.8013
# Fold 7 Epoch 300: TotalLoss=0.435351 | Sup=0.435311 | Recon=0.000797 | TrainAcc=0.7949
# Fold 7 Epoch 400: TotalLoss=0.420345 | Sup=0.420315 | Recon=0.000603 | TrainAcc=0.8013
# Fold 7 Epoch 500: TotalLoss=0.410346 | Sup=0.410319 | Recon=0.000548 | TrainAcc=0.7821
# Fold 7 Epoch 600: TotalLoss=0.398199 | Sup=0.398174 | Recon=0.000517 | TrainAcc=0.8141
# Fold 7 Epoch 700: TotalLoss=0.381866 | Sup=0.381840 | Recon=0.000506 | TrainAcc=0.8205
# Fold 7 Epoch 800: TotalLoss=0.377793 | Sup=0.377769 | Recon=0.000492 | TrainAcc=0.8077
# Fold 7 Epoch 900: TotalLoss=0.378374 | Sup=0.378349 | Recon=0.000500 | TrainAcc=0.7821
# Fold 7 Epoch 1000: TotalLoss=0.364296 | Sup=0.364271 | Recon=0.000500 | TrainAcc=0.8333
# Fold 7 Epoch 1100: TotalLoss=0.342565 | Sup=0.342540 | Recon=0.000499 | TrainAcc=0.8333
# Fold 7 Epoch 1200: TotalLoss=0.334017 | Sup=0.333992 | Recon=0.000497 | TrainAcc=0.8269
# Fold 7 Epoch 1300: TotalLoss=0.337878 | Sup=0.337853 | Recon=0.000504 | TrainAcc=0.8397
# Fold 7 Epoch 1400: TotalLoss=0.322401 | Sup=0.322376 | Recon=0.000496 | TrainAcc=0.8141
# Fold 7 Epoch 1500: TotalLoss=0.314870 | Sup=0.314845 | Recon=0.000498 | TrainAcc=0.8654
# Fold 7 Epoch 1600: TotalLoss=0.304862 | Sup=0.304837 | Recon=0.000503 | TrainAcc=0.8269
# Fold 7 Epoch 1700: TotalLoss=0.290728 | Sup=0.290703 | Recon=0.000501 | TrainAcc=0.8397
# Fold 7 Epoch 1800: TotalLoss=0.284869 | Sup=0.284844 | Recon=0.000507 | TrainAcc=0.8718
# Fold 7 Epoch 1900: TotalLoss=0.270161 | Sup=0.270136 | Recon=0.000504 | TrainAcc=0.8782
# Fold 7 Epoch 2000: TotalLoss=0.263803 | Sup=0.263777 | Recon=0.000504 | TrainAcc=0.8974
# Fold 7 → Acc=0.8657 | Prec=0.9500 | Rec=0.7037 | F1=0.8085 | AUC=0.8884 | CE Loss=0.3692
#
# === Fold 8 ===
# Train Control: 93, Train Patient: 63
# Fold 8 Epoch 1: TotalLoss=0.715091 | Sup=0.713280 | Recon=0.036213 | TrainAcc=0.5962
# Fold 8 Epoch 100: TotalLoss=0.472687 | Sup=0.472562 | Recon=0.002497 | TrainAcc=0.7692
# Fold 8 Epoch 200: TotalLoss=0.458418 | Sup=0.458359 | Recon=0.001172 | TrainAcc=0.7885
# Fold 8 Epoch 300: TotalLoss=0.440316 | Sup=0.440277 | Recon=0.000767 | TrainAcc=0.8013
# Fold 8 Epoch 400: TotalLoss=0.421928 | Sup=0.421899 | Recon=0.000590 | TrainAcc=0.8013
# Fold 8 Epoch 500: TotalLoss=0.410595 | Sup=0.410568 | Recon=0.000544 | TrainAcc=0.8333
# Fold 8 Epoch 600: TotalLoss=0.394981 | Sup=0.394955 | Recon=0.000512 | TrainAcc=0.8269
# Fold 8 Epoch 700: TotalLoss=0.396915 | Sup=0.396890 | Recon=0.000501 | TrainAcc=0.8397
# Fold 8 Epoch 800: TotalLoss=0.377072 | Sup=0.377048 | Recon=0.000497 | TrainAcc=0.8397
# Fold 8 Epoch 900: TotalLoss=0.363885 | Sup=0.363860 | Recon=0.000501 | TrainAcc=0.8333
# Fold 8 Epoch 1000: TotalLoss=0.351075 | Sup=0.351051 | Recon=0.000497 | TrainAcc=0.8462
# Fold 8 Epoch 1100: TotalLoss=0.338795 | Sup=0.338770 | Recon=0.000499 | TrainAcc=0.8397
# Fold 8 Epoch 1200: TotalLoss=0.329825 | Sup=0.329800 | Recon=0.000501 | TrainAcc=0.8397
# Fold 8 Epoch 1300: TotalLoss=0.311879 | Sup=0.311854 | Recon=0.000504 | TrainAcc=0.8269
# Fold 8 Epoch 1400: TotalLoss=0.326905 | Sup=0.326879 | Recon=0.000502 | TrainAcc=0.8462
# Fold 8 Epoch 1500: TotalLoss=0.294336 | Sup=0.294311 | Recon=0.000505 | TrainAcc=0.8526
# Fold 8 Epoch 1600: TotalLoss=0.295551 | Sup=0.295525 | Recon=0.000507 | TrainAcc=0.8590
# Fold 8 Epoch 1700: TotalLoss=0.296451 | Sup=0.296425 | Recon=0.000508 | TrainAcc=0.8526
# Fold 8 Epoch 1800: TotalLoss=0.281546 | Sup=0.281521 | Recon=0.000507 | TrainAcc=0.7628
# Fold 8 Epoch 1900: TotalLoss=0.270834 | Sup=0.270808 | Recon=0.000513 | TrainAcc=0.8205
# Fold 8 Epoch 2000: TotalLoss=0.254179 | Sup=0.254153 | Recon=0.000514 | TrainAcc=0.8654
# Fold 8 → Acc=0.8358 | Prec=0.9000 | Rec=0.6667 | F1=0.7660 | AUC=0.8963 | CE Loss=0.3983
#
# === Fold 9 ===
# Train Control: 93, Train Patient: 63
# Fold 9 Epoch 1: TotalLoss=0.762747 | Sup=0.761033 | Recon=0.034275 | TrainAcc=0.5962
# Fold 9 Epoch 100: TotalLoss=0.469022 | Sup=0.468897 | Recon=0.002496 | TrainAcc=0.7885
# Fold 9 Epoch 200: TotalLoss=0.443794 | Sup=0.443736 | Recon=0.001160 | TrainAcc=0.8013
# Fold 9 Epoch 300: TotalLoss=0.432063 | Sup=0.432026 | Recon=0.000740 | TrainAcc=0.7949
# Fold 9 Epoch 400: TotalLoss=0.414020 | Sup=0.413989 | Recon=0.000612 | TrainAcc=0.8013
# Fold 9 Epoch 500: TotalLoss=0.404496 | Sup=0.404469 | Recon=0.000525 | TrainAcc=0.8397
# Fold 9 Epoch 600: TotalLoss=0.394736 | Sup=0.394711 | Recon=0.000512 | TrainAcc=0.8397
# Fold 9 Epoch 700: TotalLoss=0.394523 | Sup=0.394498 | Recon=0.000495 | TrainAcc=0.8141
# Fold 9 Epoch 800: TotalLoss=0.384539 | Sup=0.384514 | Recon=0.000489 | TrainAcc=0.8526
# Fold 9 Epoch 900: TotalLoss=0.369166 | Sup=0.369142 | Recon=0.000491 | TrainAcc=0.8526
# Fold 9 Epoch 1000: TotalLoss=0.370989 | Sup=0.370964 | Recon=0.000492 | TrainAcc=0.8590
# Fold 9 Epoch 1100: TotalLoss=0.361221 | Sup=0.361196 | Recon=0.000494 | TrainAcc=0.8397
# Fold 9 Epoch 1200: TotalLoss=0.357694 | Sup=0.357669 | Recon=0.000492 | TrainAcc=0.8526
# Fold 9 Epoch 1300: TotalLoss=0.341888 | Sup=0.341863 | Recon=0.000498 | TrainAcc=0.8077
# Fold 9 Epoch 1400: TotalLoss=0.335470 | Sup=0.335445 | Recon=0.000496 | TrainAcc=0.8462
# Fold 9 Epoch 1500: TotalLoss=0.325173 | Sup=0.325148 | Recon=0.000500 | TrainAcc=0.8526
# Fold 9 Epoch 1600: TotalLoss=0.327580 | Sup=0.327555 | Recon=0.000494 | TrainAcc=0.8077
# Fold 9 Epoch 1700: TotalLoss=0.320689 | Sup=0.320664 | Recon=0.000503 | TrainAcc=0.8333
# Fold 9 Epoch 1800: TotalLoss=0.301924 | Sup=0.301899 | Recon=0.000506 | TrainAcc=0.8526
# Fold 9 Epoch 1900: TotalLoss=0.299016 | Sup=0.298991 | Recon=0.000505 | TrainAcc=0.8462
# Fold 9 Epoch 2000: TotalLoss=0.275001 | Sup=0.274976 | Recon=0.000507 | TrainAcc=0.8013
# Fold 9 → Acc=0.8060 | Prec=1.0000 | Rec=0.5185 | F1=0.6829 | AUC=0.8380 | CE Loss=0.6639
#
# === Fold 10 ===
# Train Control: 93, Train Patient: 63
# Fold 10 Epoch 1: TotalLoss=0.786236 | Sup=0.784505 | Recon=0.034618 | TrainAcc=0.5962
# Fold 10 Epoch 100: TotalLoss=0.455274 | Sup=0.455139 | Recon=0.002712 | TrainAcc=0.7885
# Fold 10 Epoch 200: TotalLoss=0.439239 | Sup=0.439183 | Recon=0.001115 | TrainAcc=0.8013
# Fold 10 Epoch 300: TotalLoss=0.426756 | Sup=0.426719 | Recon=0.000752 | TrainAcc=0.8205
# Fold 10 Epoch 400: TotalLoss=0.406931 | Sup=0.406901 | Recon=0.000589 | TrainAcc=0.8205
# Fold 10 Epoch 500: TotalLoss=0.395673 | Sup=0.395647 | Recon=0.000526 | TrainAcc=0.8269
# Fold 10 Epoch 600: TotalLoss=0.383248 | Sup=0.383223 | Recon=0.000495 | TrainAcc=0.8269
# Fold 10 Epoch 700: TotalLoss=0.375903 | Sup=0.375879 | Recon=0.000490 | TrainAcc=0.8333
# Fold 10 Epoch 800: TotalLoss=0.372421 | Sup=0.372397 | Recon=0.000480 | TrainAcc=0.8590
# Fold 10 Epoch 900: TotalLoss=0.364592 | Sup=0.364568 | Recon=0.000481 | TrainAcc=0.8590
# Fold 10 Epoch 1000: TotalLoss=0.354641 | Sup=0.354617 | Recon=0.000483 | TrainAcc=0.8013
# Fold 10 Epoch 1100: TotalLoss=0.351518 | Sup=0.351494 | Recon=0.000491 | TrainAcc=0.8397
# Fold 10 Epoch 1200: TotalLoss=0.340626 | Sup=0.340602 | Recon=0.000486 | TrainAcc=0.8462
# Fold 10 Epoch 1300: TotalLoss=0.329677 | Sup=0.329652 | Recon=0.000487 | TrainAcc=0.8526
# Fold 10 Epoch 1400: TotalLoss=0.315682 | Sup=0.315657 | Recon=0.000492 | TrainAcc=0.8654
# Fold 10 Epoch 1500: TotalLoss=0.312773 | Sup=0.312748 | Recon=0.000496 | TrainAcc=0.8654
# Fold 10 Epoch 1600: TotalLoss=0.306380 | Sup=0.306355 | Recon=0.000496 | TrainAcc=0.8718
# Fold 10 Epoch 1700: TotalLoss=0.297803 | Sup=0.297778 | Recon=0.000497 | TrainAcc=0.8590
# Fold 10 Epoch 1800: TotalLoss=0.296936 | Sup=0.296911 | Recon=0.000502 | TrainAcc=0.8141
# Fold 10 Epoch 1900: TotalLoss=0.277733 | Sup=0.277708 | Recon=0.000502 | TrainAcc=0.7949
# Fold 10 Epoch 2000: TotalLoss=0.274766 | Sup=0.274741 | Recon=0.000502 | TrainAcc=0.8526
# Fold 10 → Acc=0.8209 | Prec=0.8571 | Rec=0.6667 | F1=0.7500 | AUC=0.8444 | CE Loss=0.4505
#
# === Fold 11 ===
# Train Control: 93, Train Patient: 63
# Fold 11 Epoch 1: TotalLoss=0.759330 | Sup=0.757903 | Recon=0.028530 | TrainAcc=0.5962
# Fold 11 Epoch 100: TotalLoss=0.468317 | Sup=0.468202 | Recon=0.002298 | TrainAcc=0.7756
# Fold 11 Epoch 200: TotalLoss=0.445478 | Sup=0.445425 | Recon=0.001048 | TrainAcc=0.7821
# Fold 11 Epoch 300: TotalLoss=0.419899 | Sup=0.419864 | Recon=0.000701 | TrainAcc=0.7949
# Fold 11 Epoch 400: TotalLoss=0.409252 | Sup=0.409223 | Recon=0.000570 | TrainAcc=0.8013
# Fold 11 Epoch 500: TotalLoss=0.387104 | Sup=0.387078 | Recon=0.000523 | TrainAcc=0.8397
# Fold 11 Epoch 600: TotalLoss=0.374056 | Sup=0.374031 | Recon=0.000500 | TrainAcc=0.8462
# Fold 11 Epoch 700: TotalLoss=0.363450 | Sup=0.363426 | Recon=0.000491 | TrainAcc=0.8205
# Fold 11 Epoch 800: TotalLoss=0.344012 | Sup=0.343988 | Recon=0.000494 | TrainAcc=0.8462
# Fold 11 Epoch 900: TotalLoss=0.344751 | Sup=0.344726 | Recon=0.000491 | TrainAcc=0.8526
# Fold 11 Epoch 1000: TotalLoss=0.332184 | Sup=0.332159 | Recon=0.000494 | TrainAcc=0.8654
# Fold 11 Epoch 1100: TotalLoss=0.311586 | Sup=0.311561 | Recon=0.000499 | TrainAcc=0.8526
# Fold 11 Epoch 1200: TotalLoss=0.303226 | Sup=0.303201 | Recon=0.000503 | TrainAcc=0.8462
# Fold 11 Epoch 1300: TotalLoss=0.304625 | Sup=0.304600 | Recon=0.000498 | TrainAcc=0.8590
# Fold 11 Epoch 1400: TotalLoss=0.299762 | Sup=0.299737 | Recon=0.000504 | TrainAcc=0.8590
# Fold 11 Epoch 1500: TotalLoss=0.294693 | Sup=0.294668 | Recon=0.000498 | TrainAcc=0.8654
# Fold 11 Epoch 1600: TotalLoss=0.272397 | Sup=0.272372 | Recon=0.000502 | TrainAcc=0.8782
# Fold 11 Epoch 1700: TotalLoss=0.272919 | Sup=0.272893 | Recon=0.000506 | TrainAcc=0.8718
# Fold 11 Epoch 1800: TotalLoss=0.261629 | Sup=0.261603 | Recon=0.000510 | TrainAcc=0.8590
# Fold 11 Epoch 1900: TotalLoss=0.249920 | Sup=0.249894 | Recon=0.000511 | TrainAcc=0.8910
# Fold 11 Epoch 2000: TotalLoss=0.246114 | Sup=0.246089 | Recon=0.000514 | TrainAcc=0.8782
# Fold 11 → Acc=0.8657 | Prec=0.9091 | Rec=0.7407 | F1=0.8163 | AUC=0.8519 | CE Loss=0.5649
#
# === Fold 12 ===
# Train Control: 93, Train Patient: 63
# Fold 12 Epoch 1: TotalLoss=0.682298 | Sup=0.680713 | Recon=0.031709 | TrainAcc=0.4038
# Fold 12 Epoch 100: TotalLoss=0.465384 | Sup=0.465260 | Recon=0.002469 | TrainAcc=0.7756
# Fold 12 Epoch 200: TotalLoss=0.436443 | Sup=0.436382 | Recon=0.001216 | TrainAcc=0.7949
# Fold 12 Epoch 300: TotalLoss=0.409434 | Sup=0.409397 | Recon=0.000740 | TrainAcc=0.8205
# Fold 12 Epoch 400: TotalLoss=0.398192 | Sup=0.398163 | Recon=0.000588 | TrainAcc=0.8269
# Fold 12 Epoch 500: TotalLoss=0.384468 | Sup=0.384442 | Recon=0.000524 | TrainAcc=0.8205
# Fold 12 Epoch 600: TotalLoss=0.381377 | Sup=0.381352 | Recon=0.000500 | TrainAcc=0.8205
# Fold 12 Epoch 700: TotalLoss=0.370302 | Sup=0.370277 | Recon=0.000496 | TrainAcc=0.8462
# Fold 12 Epoch 800: TotalLoss=0.365405 | Sup=0.365380 | Recon=0.000494 | TrainAcc=0.8397
# Fold 12 Epoch 900: TotalLoss=0.351422 | Sup=0.351397 | Recon=0.000489 | TrainAcc=0.8269
# Fold 12 Epoch 1000: TotalLoss=0.343601 | Sup=0.343576 | Recon=0.000494 | TrainAcc=0.8462
# Fold 12 Epoch 1100: TotalLoss=0.333066 | Sup=0.333041 | Recon=0.000490 | TrainAcc=0.8462
# Fold 12 Epoch 1200: TotalLoss=0.316646 | Sup=0.316622 | Recon=0.000493 | TrainAcc=0.8269
# Fold 12 Epoch 1300: TotalLoss=0.306267 | Sup=0.306243 | Recon=0.000494 | TrainAcc=0.8141
# Fold 12 Epoch 1400: TotalLoss=0.304688 | Sup=0.304663 | Recon=0.000494 | TrainAcc=0.8718
# Fold 12 Epoch 1500: TotalLoss=0.286451 | Sup=0.286426 | Recon=0.000500 | TrainAcc=0.8462
# Fold 12 Epoch 1600: TotalLoss=0.292041 | Sup=0.292017 | Recon=0.000497 | TrainAcc=0.8718
# Fold 12 Epoch 1700: TotalLoss=0.274939 | Sup=0.274914 | Recon=0.000503 | TrainAcc=0.8526
# Fold 12 Epoch 1800: TotalLoss=0.279395 | Sup=0.279369 | Recon=0.000505 | TrainAcc=0.8333
# Fold 12 Epoch 1900: TotalLoss=0.248500 | Sup=0.248475 | Recon=0.000512 | TrainAcc=0.8910
# Fold 12 Epoch 2000: TotalLoss=0.259797 | Sup=0.259772 | Recon=0.000506 | TrainAcc=0.8782
# Fold 12 → Acc=0.8358 | Prec=0.7857 | Rec=0.8148 | F1=0.8000 | AUC=0.8968 | CE Loss=0.3878
#
# === Fold 13 ===
# Train Control: 93, Train Patient: 63
# Fold 13 Epoch 1: TotalLoss=0.726589 | Sup=0.724782 | Recon=0.036123 | TrainAcc=0.4038
# Fold 13 Epoch 100: TotalLoss=0.430017 | Sup=0.429890 | Recon=0.002535 | TrainAcc=0.8141
# Fold 13 Epoch 200: TotalLoss=0.402270 | Sup=0.402211 | Recon=0.001191 | TrainAcc=0.7821
# Fold 13 Epoch 300: TotalLoss=0.402474 | Sup=0.402438 | Recon=0.000722 | TrainAcc=0.8333
# Fold 13 Epoch 400: TotalLoss=0.383133 | Sup=0.383104 | Recon=0.000583 | TrainAcc=0.8333
# Fold 13 Epoch 500: TotalLoss=0.386942 | Sup=0.386916 | Recon=0.000526 | TrainAcc=0.8077
# Fold 13 Epoch 600: TotalLoss=0.365363 | Sup=0.365338 | Recon=0.000499 | TrainAcc=0.8333
# Fold 13 Epoch 700: TotalLoss=0.356846 | Sup=0.356821 | Recon=0.000489 | TrainAcc=0.8526
# Fold 13 Epoch 800: TotalLoss=0.342412 | Sup=0.342387 | Recon=0.000498 | TrainAcc=0.8077
# Fold 13 Epoch 900: TotalLoss=0.337127 | Sup=0.337103 | Recon=0.000488 | TrainAcc=0.8590
# Fold 13 Epoch 1000: TotalLoss=0.333285 | Sup=0.333261 | Recon=0.000491 | TrainAcc=0.8526
# Fold 13 Epoch 1100: TotalLoss=0.311101 | Sup=0.311077 | Recon=0.000489 | TrainAcc=0.8205
# Fold 13 Epoch 1200: TotalLoss=0.310316 | Sup=0.310292 | Recon=0.000495 | TrainAcc=0.8333
# Fold 13 Epoch 1300: TotalLoss=0.295258 | Sup=0.295233 | Recon=0.000490 | TrainAcc=0.8333
# Fold 13 Epoch 1400: TotalLoss=0.284010 | Sup=0.283985 | Recon=0.000493 | TrainAcc=0.8526
# Fold 13 Epoch 1500: TotalLoss=0.271792 | Sup=0.271767 | Recon=0.000502 | TrainAcc=0.8590
# Fold 13 Epoch 1600: TotalLoss=0.270618 | Sup=0.270593 | Recon=0.000503 | TrainAcc=0.7885
# Fold 13 Epoch 1700: TotalLoss=0.253409 | Sup=0.253384 | Recon=0.000501 | TrainAcc=0.8782
# Fold 13 Epoch 1800: TotalLoss=0.238259 | Sup=0.238234 | Recon=0.000505 | TrainAcc=0.8590
# Fold 13 Epoch 1900: TotalLoss=0.229778 | Sup=0.229752 | Recon=0.000508 | TrainAcc=0.8910
# Fold 13 Epoch 2000: TotalLoss=0.217445 | Sup=0.217419 | Recon=0.000509 | TrainAcc=0.8974
# Fold 13 → Acc=0.8955 | Prec=0.9167 | Rec=0.8148 | F1=0.8627 | AUC=0.9426 | CE Loss=0.2871
#
# === Fold 14 ===
# Train Control: 93, Train Patient: 63
# Fold 14 Epoch 1: TotalLoss=0.750929 | Sup=0.749261 | Recon=0.033378 | TrainAcc=0.4038
# Fold 14 Epoch 100: TotalLoss=0.478239 | Sup=0.478120 | Recon=0.002384 | TrainAcc=0.7885
# Fold 14 Epoch 200: TotalLoss=0.461487 | Sup=0.461427 | Recon=0.001206 | TrainAcc=0.7885
# Fold 14 Epoch 300: TotalLoss=0.448386 | Sup=0.448351 | Recon=0.000699 | TrainAcc=0.8013
# Fold 14 Epoch 400: TotalLoss=0.434827 | Sup=0.434797 | Recon=0.000590 | TrainAcc=0.8013
# Fold 14 Epoch 500: TotalLoss=0.420759 | Sup=0.420733 | Recon=0.000517 | TrainAcc=0.8205
# Fold 14 Epoch 600: TotalLoss=0.410174 | Sup=0.410149 | Recon=0.000500 | TrainAcc=0.8141
# Fold 14 Epoch 700: TotalLoss=0.402527 | Sup=0.402503 | Recon=0.000484 | TrainAcc=0.7949
# Fold 14 Epoch 800: TotalLoss=0.400840 | Sup=0.400816 | Recon=0.000481 | TrainAcc=0.8013
# Fold 14 Epoch 900: TotalLoss=0.383778 | Sup=0.383754 | Recon=0.000483 | TrainAcc=0.8397
# Fold 14 Epoch 1000: TotalLoss=0.371227 | Sup=0.371203 | Recon=0.000487 | TrainAcc=0.8397
# Fold 14 Epoch 1100: TotalLoss=0.366793 | Sup=0.366768 | Recon=0.000484 | TrainAcc=0.8397
# Fold 14 Epoch 1200: TotalLoss=0.357866 | Sup=0.357841 | Recon=0.000491 | TrainAcc=0.8397
# Fold 14 Epoch 1300: TotalLoss=0.343124 | Sup=0.343099 | Recon=0.000494 | TrainAcc=0.8526
# Fold 14 Epoch 1400: TotalLoss=0.331931 | Sup=0.331906 | Recon=0.000492 | TrainAcc=0.8269
# Fold 14 Epoch 1500: TotalLoss=0.325249 | Sup=0.325224 | Recon=0.000495 | TrainAcc=0.8462
# Fold 14 Epoch 1600: TotalLoss=0.312255 | Sup=0.312230 | Recon=0.000499 | TrainAcc=0.8718
# Fold 14 Epoch 1700: TotalLoss=0.296270 | Sup=0.296245 | Recon=0.000500 | TrainAcc=0.8397
# Fold 14 Epoch 1800: TotalLoss=0.302219 | Sup=0.302194 | Recon=0.000505 | TrainAcc=0.8333
# Fold 14 Epoch 1900: TotalLoss=0.285800 | Sup=0.285774 | Recon=0.000510 | TrainAcc=0.8782
# Fold 14 Epoch 2000: TotalLoss=0.282087 | Sup=0.282061 | Recon=0.000507 | TrainAcc=0.8846
# Fold 14 → Acc=0.8806 | Prec=0.9130 | Rec=0.7778 | F1=0.8400 | AUC=0.9398 | CE Loss=0.2834
#
# === Fold 15 ===
# Train Control: 93, Train Patient: 63
# Fold 15 Epoch 1: TotalLoss=0.704154 | Sup=0.702640 | Recon=0.030269 | TrainAcc=0.5962
# Fold 15 Epoch 100: TotalLoss=0.413093 | Sup=0.412966 | Recon=0.002542 | TrainAcc=0.8077
# Fold 15 Epoch 200: TotalLoss=0.393067 | Sup=0.393009 | Recon=0.001150 | TrainAcc=0.8205
# Fold 15 Epoch 300: TotalLoss=0.377187 | Sup=0.377151 | Recon=0.000715 | TrainAcc=0.8462
# Fold 15 Epoch 400: TotalLoss=0.359825 | Sup=0.359796 | Recon=0.000586 | TrainAcc=0.8333
# Fold 15 Epoch 500: TotalLoss=0.341946 | Sup=0.341919 | Recon=0.000532 | TrainAcc=0.8462
# Fold 15 Epoch 600: TotalLoss=0.329679 | Sup=0.329654 | Recon=0.000503 | TrainAcc=0.8590
# Fold 15 Epoch 700: TotalLoss=0.311915 | Sup=0.311890 | Recon=0.000503 | TrainAcc=0.8654
# Fold 15 Epoch 800: TotalLoss=0.301734 | Sup=0.301710 | Recon=0.000493 | TrainAcc=0.8718
# Fold 15 Epoch 900: TotalLoss=0.306208 | Sup=0.306183 | Recon=0.000497 | TrainAcc=0.8782
# Fold 15 Epoch 1000: TotalLoss=0.287347 | Sup=0.287322 | Recon=0.000507 | TrainAcc=0.8526
# Fold 15 Epoch 1100: TotalLoss=0.276372 | Sup=0.276347 | Recon=0.000506 | TrainAcc=0.8782
# Fold 15 Epoch 1200: TotalLoss=0.277065 | Sup=0.277040 | Recon=0.000514 | TrainAcc=0.8590
# Fold 15 Epoch 1300: TotalLoss=0.273668 | Sup=0.273643 | Recon=0.000506 | TrainAcc=0.8846
# Fold 15 Epoch 1400: TotalLoss=0.271299 | Sup=0.271274 | Recon=0.000504 | TrainAcc=0.8910
# Fold 15 Epoch 1500: TotalLoss=0.248326 | Sup=0.248301 | Recon=0.000509 | TrainAcc=0.8782
# Fold 15 Epoch 1600: TotalLoss=0.244257 | Sup=0.244232 | Recon=0.000508 | TrainAcc=0.8910
# Fold 15 Epoch 1700: TotalLoss=0.235854 | Sup=0.235828 | Recon=0.000513 | TrainAcc=0.8846
# Fold 15 Epoch 1800: TotalLoss=0.236759 | Sup=0.236734 | Recon=0.000513 | TrainAcc=0.8910
# Fold 15 Epoch 1900: TotalLoss=0.212732 | Sup=0.212706 | Recon=0.000519 | TrainAcc=0.8846
# Fold 15 Epoch 2000: TotalLoss=0.214142 | Sup=0.214116 | Recon=0.000518 | TrainAcc=0.8974
# Fold 15 → Acc=0.8209 | Prec=0.8571 | Rec=0.6667 | F1=0.7500 | AUC=0.8764 | CE Loss=0.6295
#
# === Fold 16 ===
# Train Control: 93, Train Patient: 63
# Fold 16 Epoch 1: TotalLoss=0.697760 | Sup=0.696205 | Recon=0.031103 | TrainAcc=0.4038
# Fold 16 Epoch 100: TotalLoss=0.449775 | Sup=0.449666 | Recon=0.002173 | TrainAcc=0.8077
# Fold 16 Epoch 200: TotalLoss=0.427288 | Sup=0.427234 | Recon=0.001082 | TrainAcc=0.8141
# Fold 16 Epoch 300: TotalLoss=0.413837 | Sup=0.413801 | Recon=0.000720 | TrainAcc=0.8269
# Fold 16 Epoch 400: TotalLoss=0.403559 | Sup=0.403530 | Recon=0.000583 | TrainAcc=0.8269
# Fold 16 Epoch 500: TotalLoss=0.394207 | Sup=0.394181 | Recon=0.000527 | TrainAcc=0.8397
# Fold 16 Epoch 600: TotalLoss=0.375632 | Sup=0.375607 | Recon=0.000511 | TrainAcc=0.8205
# Fold 16 Epoch 700: TotalLoss=0.371310 | Sup=0.371285 | Recon=0.000500 | TrainAcc=0.8397
# Fold 16 Epoch 800: TotalLoss=0.352709 | Sup=0.352684 | Recon=0.000504 | TrainAcc=0.8397
# Fold 16 Epoch 900: TotalLoss=0.355748 | Sup=0.355724 | Recon=0.000493 | TrainAcc=0.8269
# Fold 16 Epoch 1000: TotalLoss=0.345300 | Sup=0.345276 | Recon=0.000495 | TrainAcc=0.8718
# Fold 16 Epoch 1100: TotalLoss=0.335275 | Sup=0.335250 | Recon=0.000494 | TrainAcc=0.8462
# Fold 16 Epoch 1200: TotalLoss=0.335878 | Sup=0.335853 | Recon=0.000499 | TrainAcc=0.8526
# Fold 16 Epoch 1300: TotalLoss=0.319132 | Sup=0.319108 | Recon=0.000498 | TrainAcc=0.8397
# Fold 16 Epoch 1400: TotalLoss=0.322226 | Sup=0.322201 | Recon=0.000496 | TrainAcc=0.8333
# Fold 16 Epoch 1500: TotalLoss=0.306163 | Sup=0.306138 | Recon=0.000496 | TrainAcc=0.8397
# Fold 16 Epoch 1600: TotalLoss=0.318317 | Sup=0.318292 | Recon=0.000502 | TrainAcc=0.8205
# Fold 16 Epoch 1700: TotalLoss=0.300400 | Sup=0.300375 | Recon=0.000501 | TrainAcc=0.8718
# Fold 16 Epoch 1800: TotalLoss=0.296688 | Sup=0.296663 | Recon=0.000500 | TrainAcc=0.8397
# Fold 16 Epoch 1900: TotalLoss=0.282203 | Sup=0.282177 | Recon=0.000507 | TrainAcc=0.8526
# Fold 16 Epoch 2000: TotalLoss=0.282725 | Sup=0.282700 | Recon=0.000502 | TrainAcc=0.8526
# Fold 16 → Acc=0.7761 | Prec=0.8333 | Rec=0.5556 | F1=0.6667 | AUC=0.8435 | CE Loss=0.4757
#
# === Fold 17 ===
# Train Control: 93, Train Patient: 63
# Fold 17 Epoch 1: TotalLoss=0.714406 | Sup=0.713030 | Recon=0.027526 | TrainAcc=0.4038
# Fold 17 Epoch 100: TotalLoss=0.452986 | Sup=0.452864 | Recon=0.002434 | TrainAcc=0.7821
# Fold 17 Epoch 200: TotalLoss=0.426268 | Sup=0.426212 | Recon=0.001110 | TrainAcc=0.8013
# Fold 17 Epoch 300: TotalLoss=0.410217 | Sup=0.410178 | Recon=0.000774 | TrainAcc=0.8205
# Fold 17 Epoch 400: TotalLoss=0.386951 | Sup=0.386922 | Recon=0.000578 | TrainAcc=0.8397
# Fold 17 Epoch 500: TotalLoss=0.376327 | Sup=0.376301 | Recon=0.000522 | TrainAcc=0.8397
# Fold 17 Epoch 600: TotalLoss=0.360707 | Sup=0.360682 | Recon=0.000499 | TrainAcc=0.8397
# Fold 17 Epoch 700: TotalLoss=0.342135 | Sup=0.342110 | Recon=0.000499 | TrainAcc=0.8590
# Fold 17 Epoch 800: TotalLoss=0.337978 | Sup=0.337954 | Recon=0.000493 | TrainAcc=0.8077
# Fold 17 Epoch 900: TotalLoss=0.334959 | Sup=0.334934 | Recon=0.000493 | TrainAcc=0.8526
# Fold 17 Epoch 1000: TotalLoss=0.326606 | Sup=0.326582 | Recon=0.000495 | TrainAcc=0.8654
# Fold 17 Epoch 1100: TotalLoss=0.308514 | Sup=0.308490 | Recon=0.000497 | TrainAcc=0.8526
# Fold 17 Epoch 1200: TotalLoss=0.305010 | Sup=0.304985 | Recon=0.000497 | TrainAcc=0.8077
# Fold 17 Epoch 1300: TotalLoss=0.304580 | Sup=0.304556 | Recon=0.000498 | TrainAcc=0.8718
# Fold 17 Epoch 1400: TotalLoss=0.296047 | Sup=0.296022 | Recon=0.000497 | TrainAcc=0.7500
# Fold 17 Epoch 1500: TotalLoss=0.278799 | Sup=0.278774 | Recon=0.000496 | TrainAcc=0.8782
# Fold 17 Epoch 1600: TotalLoss=0.277917 | Sup=0.277892 | Recon=0.000501 | TrainAcc=0.8397
# Fold 17 Epoch 1700: TotalLoss=0.262952 | Sup=0.262927 | Recon=0.000500 | TrainAcc=0.8333
# Fold 17 Epoch 1800: TotalLoss=0.261452 | Sup=0.261427 | Recon=0.000501 | TrainAcc=0.8910
# Fold 17 Epoch 1900: TotalLoss=0.250650 | Sup=0.250625 | Recon=0.000510 | TrainAcc=0.8846
# Fold 17 Epoch 2000: TotalLoss=0.241545 | Sup=0.241520 | Recon=0.000501 | TrainAcc=0.8782
# Fold 17 → Acc=0.8657 | Prec=0.9500 | Rec=0.7037 | F1=0.8085 | AUC=0.9361 | CE Loss=0.3400
#
# === Fold 18 ===
# Train Control: 93, Train Patient: 63
# Fold 18 Epoch 1: TotalLoss=0.751589 | Sup=0.749982 | Recon=0.032134 | TrainAcc=0.4038
# Fold 18 Epoch 100: TotalLoss=0.494630 | Sup=0.494519 | Recon=0.002223 | TrainAcc=0.7628
# Fold 18 Epoch 200: TotalLoss=0.466223 | Sup=0.466167 | Recon=0.001109 | TrainAcc=0.7885
# Fold 18 Epoch 300: TotalLoss=0.450252 | Sup=0.450216 | Recon=0.000736 | TrainAcc=0.7885
# Fold 18 Epoch 400: TotalLoss=0.439206 | Sup=0.439176 | Recon=0.000597 | TrainAcc=0.7885
# Fold 18 Epoch 500: TotalLoss=0.416084 | Sup=0.416056 | Recon=0.000544 | TrainAcc=0.8013
# Fold 18 Epoch 600: TotalLoss=0.407677 | Sup=0.407652 | Recon=0.000511 | TrainAcc=0.8205
# Fold 18 Epoch 700: TotalLoss=0.393769 | Sup=0.393744 | Recon=0.000498 | TrainAcc=0.8077
# Fold 18 Epoch 800: TotalLoss=0.394448 | Sup=0.394423 | Recon=0.000507 | TrainAcc=0.8333
# Fold 18 Epoch 900: TotalLoss=0.382860 | Sup=0.382835 | Recon=0.000507 | TrainAcc=0.8205
# Fold 18 Epoch 1000: TotalLoss=0.365291 | Sup=0.365266 | Recon=0.000518 | TrainAcc=0.8141
# Fold 18 Epoch 1100: TotalLoss=0.362150 | Sup=0.362125 | Recon=0.000505 | TrainAcc=0.8333
# Fold 18 Epoch 1200: TotalLoss=0.338640 | Sup=0.338614 | Recon=0.000511 | TrainAcc=0.8462
# Fold 18 Epoch 1300: TotalLoss=0.323144 | Sup=0.323118 | Recon=0.000513 | TrainAcc=0.8590
# Fold 18 Epoch 1400: TotalLoss=0.317083 | Sup=0.317057 | Recon=0.000514 | TrainAcc=0.8397
# Fold 18 Epoch 1500: TotalLoss=0.306370 | Sup=0.306344 | Recon=0.000514 | TrainAcc=0.8526
# Fold 18 Epoch 1600: TotalLoss=0.306628 | Sup=0.306602 | Recon=0.000517 | TrainAcc=0.8141
# Fold 18 Epoch 1700: TotalLoss=0.287829 | Sup=0.287803 | Recon=0.000516 | TrainAcc=0.8654
# Fold 18 Epoch 1800: TotalLoss=0.281502 | Sup=0.281476 | Recon=0.000520 | TrainAcc=0.8462
# Fold 18 Epoch 1900: TotalLoss=0.264375 | Sup=0.264349 | Recon=0.000525 | TrainAcc=0.8397
# Fold 18 Epoch 2000: TotalLoss=0.255443 | Sup=0.255417 | Recon=0.000528 | TrainAcc=0.8462
# Fold 18 → Acc=0.8507 | Prec=0.8148 | Rec=0.8148 | F1=0.8148 | AUC=0.9074 | CE Loss=0.3550
#
# === Fold 19 ===
# Train Control: 93, Train Patient: 63
# Fold 19 Epoch 1: TotalLoss=0.715689 | Sup=0.714157 | Recon=0.030642 | TrainAcc=0.3974
# Fold 19 Epoch 100: TotalLoss=0.455091 | Sup=0.454961 | Recon=0.002595 | TrainAcc=0.7949
# Fold 19 Epoch 200: TotalLoss=0.432106 | Sup=0.432053 | Recon=0.001054 | TrainAcc=0.8077
# Fold 19 Epoch 300: TotalLoss=0.407586 | Sup=0.407551 | Recon=0.000705 | TrainAcc=0.7949
# Fold 19 Epoch 400: TotalLoss=0.391673 | Sup=0.391643 | Recon=0.000589 | TrainAcc=0.8333
# Fold 19 Epoch 500: TotalLoss=0.381807 | Sup=0.381781 | Recon=0.000522 | TrainAcc=0.8077
# Fold 19 Epoch 600: TotalLoss=0.364902 | Sup=0.364877 | Recon=0.000501 | TrainAcc=0.8397
# Fold 19 Epoch 700: TotalLoss=0.358622 | Sup=0.358597 | Recon=0.000491 | TrainAcc=0.8333
# Fold 19 Epoch 800: TotalLoss=0.355521 | Sup=0.355497 | Recon=0.000487 | TrainAcc=0.8397
# Fold 19 Epoch 900: TotalLoss=0.345179 | Sup=0.345154 | Recon=0.000492 | TrainAcc=0.8526
# Fold 19 Epoch 1000: TotalLoss=0.326264 | Sup=0.326239 | Recon=0.000498 | TrainAcc=0.8462
# Fold 19 Epoch 1100: TotalLoss=0.329468 | Sup=0.329444 | Recon=0.000494 | TrainAcc=0.8333
# Fold 19 Epoch 1200: TotalLoss=0.315923 | Sup=0.315898 | Recon=0.000497 | TrainAcc=0.8462
# Fold 19 Epoch 1300: TotalLoss=0.305412 | Sup=0.305388 | Recon=0.000495 | TrainAcc=0.8397
# Fold 19 Epoch 1400: TotalLoss=0.303049 | Sup=0.303024 | Recon=0.000496 | TrainAcc=0.8269
# Fold 19 Epoch 1500: TotalLoss=0.283533 | Sup=0.283508 | Recon=0.000502 | TrainAcc=0.8077
# Fold 19 Epoch 1600: TotalLoss=0.290671 | Sup=0.290646 | Recon=0.000503 | TrainAcc=0.8141
# Fold 19 Epoch 1700: TotalLoss=0.270514 | Sup=0.270489 | Recon=0.000502 | TrainAcc=0.8141
# Fold 19 Epoch 1800: TotalLoss=0.265886 | Sup=0.265861 | Recon=0.000510 | TrainAcc=0.8654
# Fold 19 Epoch 1900: TotalLoss=0.255287 | Sup=0.255262 | Recon=0.000509 | TrainAcc=0.8654
# Fold 19 Epoch 2000: TotalLoss=0.252172 | Sup=0.252146 | Recon=0.000507 | TrainAcc=0.8782
# Fold 19 → Acc=0.8657 | Prec=0.9091 | Rec=0.7407 | F1=0.8163 | AUC=0.8981 | CE Loss=0.4728
#
# === Fold 20 ===
# Train Control: 93, Train Patient: 63
# Fold 20 Epoch 1: TotalLoss=0.698489 | Sup=0.696890 | Recon=0.031985 | TrainAcc=0.4038
# Fold 20 Epoch 100: TotalLoss=0.449404 | Sup=0.449278 | Recon=0.002524 | TrainAcc=0.7692
# Fold 20 Epoch 200: TotalLoss=0.423001 | Sup=0.422948 | Recon=0.001062 | TrainAcc=0.7885
# Fold 20 Epoch 300: TotalLoss=0.402285 | Sup=0.402249 | Recon=0.000725 | TrainAcc=0.8141
# Fold 20 Epoch 400: TotalLoss=0.382116 | Sup=0.382087 | Recon=0.000579 | TrainAcc=0.8333
# Fold 20 Epoch 500: TotalLoss=0.370442 | Sup=0.370416 | Recon=0.000516 | TrainAcc=0.8141
# Fold 20 Epoch 600: TotalLoss=0.354369 | Sup=0.354345 | Recon=0.000493 | TrainAcc=0.8590
# Fold 20 Epoch 700: TotalLoss=0.335633 | Sup=0.335608 | Recon=0.000494 | TrainAcc=0.8526
# Fold 20 Epoch 800: TotalLoss=0.323116 | Sup=0.323092 | Recon=0.000485 | TrainAcc=0.8526
# Fold 20 Epoch 900: TotalLoss=0.315811 | Sup=0.315786 | Recon=0.000498 | TrainAcc=0.8654
# Fold 20 Epoch 1000: TotalLoss=0.301250 | Sup=0.301225 | Recon=0.000492 | TrainAcc=0.8590
# Fold 20 Epoch 1100: TotalLoss=0.291491 | Sup=0.291467 | Recon=0.000494 | TrainAcc=0.8718
# Fold 20 Epoch 1200: TotalLoss=0.289620 | Sup=0.289595 | Recon=0.000515 | TrainAcc=0.8269
# Fold 20 Epoch 1300: TotalLoss=0.271266 | Sup=0.271240 | Recon=0.000505 | TrainAcc=0.8782
# Fold 20 Epoch 1400: TotalLoss=0.258726 | Sup=0.258701 | Recon=0.000504 | TrainAcc=0.8333
# Fold 20 Epoch 1500: TotalLoss=0.261386 | Sup=0.261360 | Recon=0.000504 | TrainAcc=0.8910
# Fold 20 Epoch 1600: TotalLoss=0.245358 | Sup=0.245332 | Recon=0.000509 | TrainAcc=0.8974
# Fold 20 Epoch 1700: TotalLoss=0.241390 | Sup=0.241364 | Recon=0.000510 | TrainAcc=0.8974
# Fold 20 Epoch 1800: TotalLoss=0.223003 | Sup=0.222978 | Recon=0.000503 | TrainAcc=0.8462
# Fold 20 Epoch 1900: TotalLoss=0.220717 | Sup=0.220692 | Recon=0.000515 | TrainAcc=0.9103
# Fold 20 Epoch 2000: TotalLoss=0.208121 | Sup=0.208096 | Recon=0.000516 | TrainAcc=0.8526
# Fold 20 → Acc=0.7761 | Prec=0.6667 | Rec=0.8889 | F1=0.7619 | AUC=0.8889 | CE Loss=0.7117
#
# === Average Results for λ = 0.05 ===
# Accuracy:  0.8373
# Precision: 0.8724
# Recall:    0.7204
# F1-score:  0.7755
# CE Loss:   0.4559
# AUC:       0.8923
#
#
# ====================== λ_recon = 0.09 ======================
#
# === Fold 1 ===
# Train Control: 93, Train Patient: 63
# Fold 1 Epoch 1: TotalLoss=0.858796 | Sup=0.855690 | Recon=0.034507 | TrainAcc=0.3974
# Fold 1 Epoch 100: TotalLoss=0.461663 | Sup=0.461472 | Recon=0.002124 | TrainAcc=0.7949
# Fold 1 Epoch 200: TotalLoss=0.456861 | Sup=0.456767 | Recon=0.001050 | TrainAcc=0.8077
# Fold 1 Epoch 300: TotalLoss=0.437062 | Sup=0.436999 | Recon=0.000693 | TrainAcc=0.8077
# Fold 1 Epoch 400: TotalLoss=0.420610 | Sup=0.420561 | Recon=0.000551 | TrainAcc=0.8013
# Fold 1 Epoch 500: TotalLoss=0.417136 | Sup=0.417092 | Recon=0.000494 | TrainAcc=0.8141
# Fold 1 Epoch 600: TotalLoss=0.394170 | Sup=0.394129 | Recon=0.000461 | TrainAcc=0.8141
# Fold 1 Epoch 700: TotalLoss=0.391533 | Sup=0.391493 | Recon=0.000450 | TrainAcc=0.8205
# Fold 1 Epoch 800: TotalLoss=0.378732 | Sup=0.378692 | Recon=0.000448 | TrainAcc=0.8269
# Fold 1 Epoch 900: TotalLoss=0.368137 | Sup=0.368097 | Recon=0.000442 | TrainAcc=0.8333
# Fold 1 Epoch 1000: TotalLoss=0.359093 | Sup=0.359053 | Recon=0.000441 | TrainAcc=0.8205
# Fold 1 Epoch 1100: TotalLoss=0.352014 | Sup=0.351974 | Recon=0.000437 | TrainAcc=0.8141
# Fold 1 Epoch 1200: TotalLoss=0.355537 | Sup=0.355498 | Recon=0.000441 | TrainAcc=0.8333
# Fold 1 Epoch 1300: TotalLoss=0.347557 | Sup=0.347517 | Recon=0.000449 | TrainAcc=0.8141
# Fold 1 Epoch 1400: TotalLoss=0.334832 | Sup=0.334793 | Recon=0.000442 | TrainAcc=0.8654
# Fold 1 Epoch 1500: TotalLoss=0.314567 | Sup=0.314527 | Recon=0.000445 | TrainAcc=0.8590
# Fold 1 Epoch 1600: TotalLoss=0.324797 | Sup=0.324757 | Recon=0.000442 | TrainAcc=0.8590
# Fold 1 Epoch 1700: TotalLoss=0.320403 | Sup=0.320363 | Recon=0.000443 | TrainAcc=0.8590
# Fold 1 Epoch 1800: TotalLoss=0.290546 | Sup=0.290506 | Recon=0.000444 | TrainAcc=0.8205
# Fold 1 Epoch 1900: TotalLoss=0.290293 | Sup=0.290253 | Recon=0.000451 | TrainAcc=0.8718
# Fold 1 Epoch 2000: TotalLoss=0.283644 | Sup=0.283604 | Recon=0.000446 | TrainAcc=0.8718
# Fold 1 → Acc=0.8060 | Prec=0.7917 | Rec=0.7037 | F1=0.7451 | AUC=0.8884 | CE Loss=0.4562
#
# === Fold 2 ===
# Train Control: 93, Train Patient: 63
# Fold 2 Epoch 1: TotalLoss=0.712503 | Sup=0.709935 | Recon=0.028536 | TrainAcc=0.5962
# Fold 2 Epoch 100: TotalLoss=0.475591 | Sup=0.475386 | Recon=0.002270 | TrainAcc=0.7756
# Fold 2 Epoch 200: TotalLoss=0.448398 | Sup=0.448296 | Recon=0.001134 | TrainAcc=0.8013
# Fold 2 Epoch 300: TotalLoss=0.431810 | Sup=0.431747 | Recon=0.000704 | TrainAcc=0.8141
# Fold 2 Epoch 400: TotalLoss=0.431971 | Sup=0.431920 | Recon=0.000558 | TrainAcc=0.8077
# Fold 2 Epoch 500: TotalLoss=0.420767 | Sup=0.420724 | Recon=0.000486 | TrainAcc=0.8013
# Fold 2 Epoch 600: TotalLoss=0.403181 | Sup=0.403141 | Recon=0.000453 | TrainAcc=0.7692
# Fold 2 Epoch 700: TotalLoss=0.393217 | Sup=0.393176 | Recon=0.000450 | TrainAcc=0.7692
# Fold 2 Epoch 800: TotalLoss=0.379503 | Sup=0.379463 | Recon=0.000445 | TrainAcc=0.7756
# Fold 2 Epoch 900: TotalLoss=0.380060 | Sup=0.380020 | Recon=0.000444 | TrainAcc=0.8013
# Fold 2 Epoch 1000: TotalLoss=0.362645 | Sup=0.362605 | Recon=0.000443 | TrainAcc=0.8269
# Fold 2 Epoch 1100: TotalLoss=0.357052 | Sup=0.357012 | Recon=0.000445 | TrainAcc=0.8526
# Fold 2 Epoch 1200: TotalLoss=0.344453 | Sup=0.344413 | Recon=0.000443 | TrainAcc=0.8269
# Fold 2 Epoch 1300: TotalLoss=0.334727 | Sup=0.334687 | Recon=0.000445 | TrainAcc=0.8269
# Fold 2 Epoch 1400: TotalLoss=0.329353 | Sup=0.329313 | Recon=0.000446 | TrainAcc=0.8462
# Fold 2 Epoch 1500: TotalLoss=0.315046 | Sup=0.315006 | Recon=0.000444 | TrainAcc=0.8397
# Fold 2 Epoch 1600: TotalLoss=0.303626 | Sup=0.303586 | Recon=0.000448 | TrainAcc=0.8397
# Fold 2 Epoch 1700: TotalLoss=0.305339 | Sup=0.305298 | Recon=0.000449 | TrainAcc=0.8526
# Fold 2 Epoch 1800: TotalLoss=0.273971 | Sup=0.273931 | Recon=0.000448 | TrainAcc=0.8333
# Fold 2 Epoch 1900: TotalLoss=0.269926 | Sup=0.269886 | Recon=0.000449 | TrainAcc=0.8269
# Fold 2 Epoch 2000: TotalLoss=0.266260 | Sup=0.266220 | Recon=0.000445 | TrainAcc=0.8397
# Fold 2 → Acc=0.7910 | Prec=0.8824 | Rec=0.5556 | F1=0.6818 | AUC=0.8898 | CE Loss=0.4615
#
# === Fold 3 ===
# Train Control: 93, Train Patient: 63
# Fold 3 Epoch 1: TotalLoss=0.687801 | Sup=0.684904 | Recon=0.032190 | TrainAcc=0.5962
# Fold 3 Epoch 100: TotalLoss=0.424728 | Sup=0.424520 | Recon=0.002308 | TrainAcc=0.8013
# Fold 3 Epoch 200: TotalLoss=0.409349 | Sup=0.409257 | Recon=0.001032 | TrainAcc=0.8205
# Fold 3 Epoch 300: TotalLoss=0.377235 | Sup=0.377174 | Recon=0.000683 | TrainAcc=0.8333
# Fold 3 Epoch 400: TotalLoss=0.352421 | Sup=0.352370 | Recon=0.000558 | TrainAcc=0.8462
# Fold 3 Epoch 500: TotalLoss=0.339080 | Sup=0.339034 | Recon=0.000507 | TrainAcc=0.8462
# Fold 3 Epoch 600: TotalLoss=0.335905 | Sup=0.335863 | Recon=0.000468 | TrainAcc=0.8590
# Fold 3 Epoch 700: TotalLoss=0.324816 | Sup=0.324776 | Recon=0.000451 | TrainAcc=0.8526
# Fold 3 Epoch 800: TotalLoss=0.294907 | Sup=0.294867 | Recon=0.000446 | TrainAcc=0.8718
# Fold 3 Epoch 900: TotalLoss=0.297767 | Sup=0.297727 | Recon=0.000450 | TrainAcc=0.8718
# Fold 3 Epoch 1000: TotalLoss=0.284443 | Sup=0.284402 | Recon=0.000448 | TrainAcc=0.8718
# Fold 3 Epoch 1100: TotalLoss=0.274414 | Sup=0.274374 | Recon=0.000445 | TrainAcc=0.8974
# Fold 3 Epoch 1200: TotalLoss=0.271625 | Sup=0.271585 | Recon=0.000445 | TrainAcc=0.8654
# Fold 3 Epoch 1300: TotalLoss=0.265832 | Sup=0.265791 | Recon=0.000451 | TrainAcc=0.9038
# Fold 3 Epoch 1400: TotalLoss=0.250348 | Sup=0.250308 | Recon=0.000448 | TrainAcc=0.8846
# Fold 3 Epoch 1500: TotalLoss=0.251696 | Sup=0.251656 | Recon=0.000448 | TrainAcc=0.8910
# Fold 3 Epoch 1600: TotalLoss=0.242642 | Sup=0.242602 | Recon=0.000449 | TrainAcc=0.8974
# Fold 3 Epoch 1700: TotalLoss=0.230657 | Sup=0.230617 | Recon=0.000447 | TrainAcc=0.8910
# Fold 3 Epoch 1800: TotalLoss=0.224119 | Sup=0.224079 | Recon=0.000450 | TrainAcc=0.9038
# Fold 3 Epoch 1900: TotalLoss=0.227636 | Sup=0.227596 | Recon=0.000445 | TrainAcc=0.9038
# Fold 3 Epoch 2000: TotalLoss=0.210568 | Sup=0.210528 | Recon=0.000442 | TrainAcc=0.8846
# Fold 3 → Acc=0.9104 | Prec=0.9565 | Rec=0.8148 | F1=0.8800 | AUC=0.9537 | CE Loss=0.2471
#
# === Fold 4 ===
# Train Control: 93, Train Patient: 63
# Fold 4 Epoch 1: TotalLoss=0.739277 | Sup=0.736142 | Recon=0.034833 | TrainAcc=0.3654
# Fold 4 Epoch 100: TotalLoss=0.458286 | Sup=0.458086 | Recon=0.002216 | TrainAcc=0.7692
# Fold 4 Epoch 200: TotalLoss=0.441678 | Sup=0.441581 | Recon=0.001078 | TrainAcc=0.7756
# Fold 4 Epoch 300: TotalLoss=0.431982 | Sup=0.431920 | Recon=0.000696 | TrainAcc=0.7692
# Fold 4 Epoch 400: TotalLoss=0.404586 | Sup=0.404536 | Recon=0.000557 | TrainAcc=0.8077
# Fold 4 Epoch 500: TotalLoss=0.390365 | Sup=0.390322 | Recon=0.000482 | TrainAcc=0.8141
# Fold 4 Epoch 600: TotalLoss=0.373615 | Sup=0.373574 | Recon=0.000459 | TrainAcc=0.8333
# Fold 4 Epoch 700: TotalLoss=0.363582 | Sup=0.363542 | Recon=0.000447 | TrainAcc=0.8526
# Fold 4 Epoch 800: TotalLoss=0.341367 | Sup=0.341328 | Recon=0.000443 | TrainAcc=0.8397
# Fold 4 Epoch 900: TotalLoss=0.329733 | Sup=0.329693 | Recon=0.000442 | TrainAcc=0.8333
# Fold 4 Epoch 1000: TotalLoss=0.337579 | Sup=0.337539 | Recon=0.000440 | TrainAcc=0.8397
# Fold 4 Epoch 1100: TotalLoss=0.324157 | Sup=0.324117 | Recon=0.000440 | TrainAcc=0.8205
# Fold 4 Epoch 1200: TotalLoss=0.300972 | Sup=0.300931 | Recon=0.000455 | TrainAcc=0.8718
# Fold 4 Epoch 1300: TotalLoss=0.287716 | Sup=0.287676 | Recon=0.000441 | TrainAcc=0.8718
# Fold 4 Epoch 1400: TotalLoss=0.280112 | Sup=0.280071 | Recon=0.000447 | TrainAcc=0.8782
# Fold 4 Epoch 1500: TotalLoss=0.273549 | Sup=0.273510 | Recon=0.000445 | TrainAcc=0.8654
# Fold 4 Epoch 1600: TotalLoss=0.267257 | Sup=0.267217 | Recon=0.000442 | TrainAcc=0.8782
# Fold 4 Epoch 1700: TotalLoss=0.259704 | Sup=0.259664 | Recon=0.000446 | TrainAcc=0.8718
# Fold 4 Epoch 1800: TotalLoss=0.251201 | Sup=0.251161 | Recon=0.000443 | TrainAcc=0.8077
# Fold 4 Epoch 1900: TotalLoss=0.242681 | Sup=0.242641 | Recon=0.000448 | TrainAcc=0.8526
# Fold 4 Epoch 2000: TotalLoss=0.228539 | Sup=0.228498 | Recon=0.000447 | TrainAcc=0.7628
# Fold 4 → Acc=0.7463 | Prec=0.6316 | Rec=0.8889 | F1=0.7385 | AUC=0.8894 | CE Loss=0.5552
#
# === Fold 5 ===
# Train Control: 93, Train Patient: 63
# Fold 5 Epoch 1: TotalLoss=0.777397 | Sup=0.774505 | Recon=0.032127 | TrainAcc=0.4038
# Fold 5 Epoch 100: TotalLoss=0.494482 | Sup=0.494271 | Recon=0.002340 | TrainAcc=0.7692
# Fold 5 Epoch 200: TotalLoss=0.461226 | Sup=0.461125 | Recon=0.001124 | TrainAcc=0.8013
# Fold 5 Epoch 300: TotalLoss=0.439501 | Sup=0.439438 | Recon=0.000691 | TrainAcc=0.7821
# Fold 5 Epoch 400: TotalLoss=0.419191 | Sup=0.419142 | Recon=0.000545 | TrainAcc=0.7949
# Fold 5 Epoch 500: TotalLoss=0.414062 | Sup=0.414018 | Recon=0.000485 | TrainAcc=0.7885
# Fold 5 Epoch 600: TotalLoss=0.396046 | Sup=0.396005 | Recon=0.000457 | TrainAcc=0.7949
# Fold 5 Epoch 700: TotalLoss=0.386536 | Sup=0.386496 | Recon=0.000447 | TrainAcc=0.8269
# Fold 5 Epoch 800: TotalLoss=0.396724 | Sup=0.396685 | Recon=0.000443 | TrainAcc=0.8205
# Fold 5 Epoch 900: TotalLoss=0.373868 | Sup=0.373829 | Recon=0.000440 | TrainAcc=0.8269
# Fold 5 Epoch 1000: TotalLoss=0.362408 | Sup=0.362368 | Recon=0.000438 | TrainAcc=0.8333
# Fold 5 Epoch 1100: TotalLoss=0.349143 | Sup=0.349104 | Recon=0.000439 | TrainAcc=0.8718
# Fold 5 Epoch 1200: TotalLoss=0.337933 | Sup=0.337894 | Recon=0.000438 | TrainAcc=0.8397
# Fold 5 Epoch 1300: TotalLoss=0.322757 | Sup=0.322718 | Recon=0.000441 | TrainAcc=0.8462
# Fold 5 Epoch 1400: TotalLoss=0.324549 | Sup=0.324509 | Recon=0.000444 | TrainAcc=0.8526
# Fold 5 Epoch 1500: TotalLoss=0.310799 | Sup=0.310760 | Recon=0.000440 | TrainAcc=0.8077
# Fold 5 Epoch 1600: TotalLoss=0.303615 | Sup=0.303575 | Recon=0.000442 | TrainAcc=0.8526
# Fold 5 Epoch 1700: TotalLoss=0.297540 | Sup=0.297500 | Recon=0.000442 | TrainAcc=0.8590
# Fold 5 Epoch 1800: TotalLoss=0.291179 | Sup=0.291140 | Recon=0.000442 | TrainAcc=0.8205
# Fold 5 Epoch 1900: TotalLoss=0.274600 | Sup=0.274560 | Recon=0.000445 | TrainAcc=0.8782
# Fold 5 Epoch 2000: TotalLoss=0.263963 | Sup=0.263923 | Recon=0.000446 | TrainAcc=0.7115
# Fold 5 → Acc=0.6567 | Prec=0.5455 | Rec=0.8889 | F1=0.6761 | AUC=0.8796 | CE Loss=0.7200
#
# === Fold 6 ===
# Train Control: 93, Train Patient: 63
# Fold 6 Epoch 1: TotalLoss=0.728803 | Sup=0.726027 | Recon=0.030838 | TrainAcc=0.5962
# Fold 6 Epoch 100: TotalLoss=0.469782 | Sup=0.469550 | Recon=0.002582 | TrainAcc=0.7692
# Fold 6 Epoch 200: TotalLoss=0.438145 | Sup=0.438039 | Recon=0.001177 | TrainAcc=0.8077
# Fold 6 Epoch 300: TotalLoss=0.405159 | Sup=0.405093 | Recon=0.000732 | TrainAcc=0.8205
# Fold 6 Epoch 400: TotalLoss=0.381367 | Sup=0.381316 | Recon=0.000569 | TrainAcc=0.8333
# Fold 6 Epoch 500: TotalLoss=0.366889 | Sup=0.366845 | Recon=0.000494 | TrainAcc=0.8397
# Fold 6 Epoch 600: TotalLoss=0.353020 | Sup=0.352978 | Recon=0.000463 | TrainAcc=0.8462
# Fold 6 Epoch 700: TotalLoss=0.336920 | Sup=0.336880 | Recon=0.000453 | TrainAcc=0.8590
# Fold 6 Epoch 800: TotalLoss=0.327957 | Sup=0.327917 | Recon=0.000448 | TrainAcc=0.8462
# Fold 6 Epoch 900: TotalLoss=0.315448 | Sup=0.315408 | Recon=0.000440 | TrainAcc=0.8462
# Fold 6 Epoch 1000: TotalLoss=0.310514 | Sup=0.310475 | Recon=0.000440 | TrainAcc=0.8269
# Fold 6 Epoch 1100: TotalLoss=0.298684 | Sup=0.298644 | Recon=0.000443 | TrainAcc=0.8590
# Fold 6 Epoch 1200: TotalLoss=0.286284 | Sup=0.286244 | Recon=0.000444 | TrainAcc=0.8846
# Fold 6 Epoch 1300: TotalLoss=0.277932 | Sup=0.277892 | Recon=0.000443 | TrainAcc=0.8846
# Fold 6 Epoch 1400: TotalLoss=0.279960 | Sup=0.279919 | Recon=0.000448 | TrainAcc=0.8654
# Fold 6 Epoch 1500: TotalLoss=0.259640 | Sup=0.259600 | Recon=0.000444 | TrainAcc=0.8846
# Fold 6 Epoch 1600: TotalLoss=0.263514 | Sup=0.263473 | Recon=0.000448 | TrainAcc=0.8910
# Fold 6 Epoch 1700: TotalLoss=0.247988 | Sup=0.247948 | Recon=0.000446 | TrainAcc=0.8526
# Fold 6 Epoch 1800: TotalLoss=0.244843 | Sup=0.244804 | Recon=0.000443 | TrainAcc=0.8974
# Fold 6 Epoch 1900: TotalLoss=0.239911 | Sup=0.239871 | Recon=0.000447 | TrainAcc=0.8910
# Fold 6 Epoch 2000: TotalLoss=0.220858 | Sup=0.220818 | Recon=0.000448 | TrainAcc=0.8526
# Fold 6 → Acc=0.8507 | Prec=1.0000 | Rec=0.6296 | F1=0.7727 | AUC=0.9245 | CE Loss=0.3877
#
# === Fold 7 ===
# Train Control: 93, Train Patient: 63
# Fold 7 Epoch 1: TotalLoss=0.773634 | Sup=0.770748 | Recon=0.032065 | TrainAcc=0.3974
# Fold 7 Epoch 100: TotalLoss=0.485794 | Sup=0.485582 | Recon=0.002358 | TrainAcc=0.7692
# Fold 7 Epoch 200: TotalLoss=0.449830 | Sup=0.449731 | Recon=0.001105 | TrainAcc=0.7949
# Fold 7 Epoch 300: TotalLoss=0.440094 | Sup=0.440032 | Recon=0.000689 | TrainAcc=0.8077
# Fold 7 Epoch 400: TotalLoss=0.441907 | Sup=0.441858 | Recon=0.000545 | TrainAcc=0.8141
# Fold 7 Epoch 500: TotalLoss=0.429941 | Sup=0.429895 | Recon=0.000504 | TrainAcc=0.8205
# Fold 7 Epoch 600: TotalLoss=0.415202 | Sup=0.415160 | Recon=0.000465 | TrainAcc=0.8205
# Fold 7 Epoch 700: TotalLoss=0.401696 | Sup=0.401656 | Recon=0.000450 | TrainAcc=0.8269
# Fold 7 Epoch 800: TotalLoss=0.391439 | Sup=0.391399 | Recon=0.000443 | TrainAcc=0.8141
# Fold 7 Epoch 900: TotalLoss=0.375354 | Sup=0.375314 | Recon=0.000446 | TrainAcc=0.7885
# Fold 7 Epoch 1000: TotalLoss=0.381698 | Sup=0.381658 | Recon=0.000445 | TrainAcc=0.8269
# Fold 7 Epoch 1100: TotalLoss=0.366759 | Sup=0.366719 | Recon=0.000447 | TrainAcc=0.8269
# Fold 7 Epoch 1200: TotalLoss=0.344791 | Sup=0.344751 | Recon=0.000448 | TrainAcc=0.8397
# Fold 7 Epoch 1300: TotalLoss=0.356237 | Sup=0.356197 | Recon=0.000448 | TrainAcc=0.8333
# Fold 7 Epoch 1400: TotalLoss=0.326761 | Sup=0.326721 | Recon=0.000446 | TrainAcc=0.8526
# Fold 7 Epoch 1500: TotalLoss=0.329014 | Sup=0.328974 | Recon=0.000446 | TrainAcc=0.8397
# Fold 7 Epoch 1600: TotalLoss=0.336405 | Sup=0.336364 | Recon=0.000451 | TrainAcc=0.8526
# Fold 7 Epoch 1700: TotalLoss=0.303953 | Sup=0.303912 | Recon=0.000450 | TrainAcc=0.8590
# Fold 7 Epoch 1800: TotalLoss=0.293091 | Sup=0.293051 | Recon=0.000443 | TrainAcc=0.7692
# Fold 7 Epoch 1900: TotalLoss=0.294688 | Sup=0.294647 | Recon=0.000449 | TrainAcc=0.8718
# Fold 7 Epoch 2000: TotalLoss=0.294424 | Sup=0.294384 | Recon=0.000449 | TrainAcc=0.8654
# Fold 7 → Acc=0.8358 | Prec=0.7857 | Rec=0.8148 | F1=0.8000 | AUC=0.8856 | CE Loss=0.3924
#
# === Fold 8 ===
# Train Control: 93, Train Patient: 63
# Fold 8 Epoch 1: TotalLoss=0.770598 | Sup=0.767736 | Recon=0.031796 | TrainAcc=0.4167
# Fold 8 Epoch 100: TotalLoss=0.489385 | Sup=0.489149 | Recon=0.002614 | TrainAcc=0.7692
# Fold 8 Epoch 200: TotalLoss=0.471925 | Sup=0.471826 | Recon=0.001099 | TrainAcc=0.7949
# Fold 8 Epoch 300: TotalLoss=0.449519 | Sup=0.449456 | Recon=0.000698 | TrainAcc=0.8077
# Fold 8 Epoch 400: TotalLoss=0.434248 | Sup=0.434198 | Recon=0.000560 | TrainAcc=0.8077
# Fold 8 Epoch 500: TotalLoss=0.420048 | Sup=0.420004 | Recon=0.000489 | TrainAcc=0.8013
# Fold 8 Epoch 600: TotalLoss=0.405774 | Sup=0.405731 | Recon=0.000472 | TrainAcc=0.8077
# Fold 8 Epoch 700: TotalLoss=0.394022 | Sup=0.393981 | Recon=0.000450 | TrainAcc=0.8205
# Fold 8 Epoch 800: TotalLoss=0.384454 | Sup=0.384414 | Recon=0.000449 | TrainAcc=0.8269
# Fold 8 Epoch 900: TotalLoss=0.375567 | Sup=0.375527 | Recon=0.000447 | TrainAcc=0.8333
# Fold 8 Epoch 1000: TotalLoss=0.363158 | Sup=0.363118 | Recon=0.000446 | TrainAcc=0.8462
# Fold 8 Epoch 1100: TotalLoss=0.348768 | Sup=0.348728 | Recon=0.000441 | TrainAcc=0.8397
# Fold 8 Epoch 1200: TotalLoss=0.333147 | Sup=0.333107 | Recon=0.000442 | TrainAcc=0.8526
# Fold 8 Epoch 1300: TotalLoss=0.335087 | Sup=0.335047 | Recon=0.000450 | TrainAcc=0.7308
# Fold 8 Epoch 1400: TotalLoss=0.318634 | Sup=0.318594 | Recon=0.000445 | TrainAcc=0.8462
# Fold 8 Epoch 1500: TotalLoss=0.317374 | Sup=0.317334 | Recon=0.000444 | TrainAcc=0.8205
# Fold 8 Epoch 1600: TotalLoss=0.296461 | Sup=0.296421 | Recon=0.000447 | TrainAcc=0.8654
# Fold 8 Epoch 1700: TotalLoss=0.294595 | Sup=0.294554 | Recon=0.000448 | TrainAcc=0.8782
# Fold 8 Epoch 1800: TotalLoss=0.295330 | Sup=0.295290 | Recon=0.000448 | TrainAcc=0.8782
# Fold 8 Epoch 1900: TotalLoss=0.279905 | Sup=0.279865 | Recon=0.000446 | TrainAcc=0.8654
# Fold 8 Epoch 2000: TotalLoss=0.270210 | Sup=0.270170 | Recon=0.000447 | TrainAcc=0.6795
# Fold 8 → Acc=0.6866 | Prec=0.5714 | Rec=0.8889 | F1=0.6957 | AUC=0.8815 | CE Loss=0.6254
#
# === Fold 9 ===
# Train Control: 93, Train Patient: 63
# Fold 9 Epoch 1: TotalLoss=0.687590 | Sup=0.684409 | Recon=0.035336 | TrainAcc=0.4038
# Fold 9 Epoch 100: TotalLoss=0.468082 | Sup=0.467853 | Recon=0.002544 | TrainAcc=0.7756
# Fold 9 Epoch 200: TotalLoss=0.443037 | Sup=0.442931 | Recon=0.001185 | TrainAcc=0.7949
# Fold 9 Epoch 300: TotalLoss=0.433424 | Sup=0.433362 | Recon=0.000692 | TrainAcc=0.7821
# Fold 9 Epoch 400: TotalLoss=0.412003 | Sup=0.411953 | Recon=0.000558 | TrainAcc=0.8077
# Fold 9 Epoch 500: TotalLoss=0.405004 | Sup=0.404959 | Recon=0.000495 | TrainAcc=0.8269
# Fold 9 Epoch 600: TotalLoss=0.390600 | Sup=0.390558 | Recon=0.000460 | TrainAcc=0.8333
# Fold 9 Epoch 700: TotalLoss=0.384239 | Sup=0.384199 | Recon=0.000443 | TrainAcc=0.8205
# Fold 9 Epoch 800: TotalLoss=0.381675 | Sup=0.381635 | Recon=0.000443 | TrainAcc=0.8205
# Fold 9 Epoch 900: TotalLoss=0.369047 | Sup=0.369008 | Recon=0.000436 | TrainAcc=0.8397
# Fold 9 Epoch 1000: TotalLoss=0.360451 | Sup=0.360411 | Recon=0.000436 | TrainAcc=0.8397
# Fold 9 Epoch 1100: TotalLoss=0.358479 | Sup=0.358440 | Recon=0.000437 | TrainAcc=0.8397
# Fold 9 Epoch 1200: TotalLoss=0.347842 | Sup=0.347803 | Recon=0.000438 | TrainAcc=0.8654
# Fold 9 Epoch 1300: TotalLoss=0.333798 | Sup=0.333758 | Recon=0.000440 | TrainAcc=0.8590
# Fold 9 Epoch 1400: TotalLoss=0.332908 | Sup=0.332869 | Recon=0.000439 | TrainAcc=0.8205
# Fold 9 Epoch 1500: TotalLoss=0.311615 | Sup=0.311575 | Recon=0.000441 | TrainAcc=0.8333
# Fold 9 Epoch 1600: TotalLoss=0.313848 | Sup=0.313808 | Recon=0.000444 | TrainAcc=0.8654
# Fold 9 Epoch 1700: TotalLoss=0.298869 | Sup=0.298829 | Recon=0.000442 | TrainAcc=0.8205
# Fold 9 Epoch 1800: TotalLoss=0.287442 | Sup=0.287402 | Recon=0.000444 | TrainAcc=0.7564
# Fold 9 Epoch 1900: TotalLoss=0.285089 | Sup=0.285050 | Recon=0.000442 | TrainAcc=0.6410
# Fold 9 Epoch 2000: TotalLoss=0.277857 | Sup=0.277817 | Recon=0.000446 | TrainAcc=0.8205
# Fold 9 → Acc=0.7164 | Prec=0.6333 | Rec=0.7037 | F1=0.6667 | AUC=0.8204 | CE Loss=0.6812
#
# ...
# Fold 13 Epoch 1700: TotalLoss=0.254737 | Sup=0.252246 | Recon=0.000311 | TrainAcc=0.8526
# Fold 13 Epoch 1800: TotalLoss=0.249004 | Sup=0.246546 | Recon=0.000307 | TrainAcc=0.8718
# Fold 13 Epoch 1900: TotalLoss=0.236311 | Sup=0.233884 | Recon=0.000303 | TrainAcc=0.9038
# Fold 13 Epoch 2000: TotalLoss=0.230025 | Sup=0.227604 | Recon=0.000303 | TrainAcc=0.8846
# Fold 13 → Acc=0.8507 | Prec=0.8148 | Rec=0.8148 | F1=0.8148 | AUC=0.9394 | CE Loss=0.3034
#
# === Fold 14 ===
# Train Control: 93, Train Patient: 63
# Fold 14 Epoch 1: TotalLoss=1.001650 | Sup=0.732911 | Recon=0.033592 | TrainAcc=0.5962
# Fold 14 Epoch 100: TotalLoss=0.497175 | Sup=0.479822 | Recon=0.002169 | TrainAcc=0.7821
# Fold 14 Epoch 200: TotalLoss=0.472172 | Sup=0.463756 | Recon=0.001052 | TrainAcc=0.8013
# Fold 14 Epoch 300: TotalLoss=0.460709 | Sup=0.454575 | Recon=0.000767 | TrainAcc=0.8013
# Fold 14 Epoch 400: TotalLoss=0.446005 | Sup=0.441219 | Recon=0.000598 | TrainAcc=0.8077
# Fold 14 Epoch 500: TotalLoss=0.423269 | Sup=0.419189 | Recon=0.000510 | TrainAcc=0.8141
# Fold 14 Epoch 600: TotalLoss=0.419484 | Sup=0.415623 | Recon=0.000483 | TrainAcc=0.8141
# Fold 14 Epoch 700: TotalLoss=0.409322 | Sup=0.405623 | Recon=0.000462 | TrainAcc=0.8205
# Fold 14 Epoch 800: TotalLoss=0.397755 | Sup=0.394228 | Recon=0.000441 | TrainAcc=0.8141
# Fold 14 Epoch 900: TotalLoss=0.396366 | Sup=0.393173 | Recon=0.000399 | TrainAcc=0.8141
# Fold 14 Epoch 1000: TotalLoss=0.380312 | Sup=0.377243 | Recon=0.000384 | TrainAcc=0.8141
# Fold 14 Epoch 1100: TotalLoss=0.373106 | Sup=0.370074 | Recon=0.000379 | TrainAcc=0.8077
# Fold 14 Epoch 1200: TotalLoss=0.358801 | Sup=0.355843 | Recon=0.000370 | TrainAcc=0.8205
# Fold 14 Epoch 1300: TotalLoss=0.347012 | Sup=0.344163 | Recon=0.000356 | TrainAcc=0.8590
# Fold 14 Epoch 1400: TotalLoss=0.345529 | Sup=0.342707 | Recon=0.000353 | TrainAcc=0.8397
# Fold 14 Epoch 1500: TotalLoss=0.329115 | Sup=0.326384 | Recon=0.000341 | TrainAcc=0.8269
# Fold 14 Epoch 1600: TotalLoss=0.312784 | Sup=0.310150 | Recon=0.000329 | TrainAcc=0.8141
# Fold 14 Epoch 1700: TotalLoss=0.316932 | Sup=0.314328 | Recon=0.000325 | TrainAcc=0.8269
# Fold 14 Epoch 1800: TotalLoss=0.304060 | Sup=0.301482 | Recon=0.000322 | TrainAcc=0.8077
# Fold 14 Epoch 1900: TotalLoss=0.287196 | Sup=0.284670 | Recon=0.000316 | TrainAcc=0.8397
# Fold 14 Epoch 2000: TotalLoss=0.277786 | Sup=0.275257 | Recon=0.000316 | TrainAcc=0.8333
# Fold 14 → Acc=0.8358 | Prec=0.7667 | Rec=0.8519 | F1=0.8070 | AUC=0.9384 | CE Loss=0.3225
#
# === Fold 15 ===
# Train Control: 93, Train Patient: 63
# Fold 15 Epoch 1: TotalLoss=1.012834 | Sup=0.788619 | Recon=0.028027 | TrainAcc=0.4038
# Fold 15 Epoch 100: TotalLoss=0.442395 | Sup=0.425282 | Recon=0.002139 | TrainAcc=0.8141
# Fold 15 Epoch 200: TotalLoss=0.405168 | Sup=0.396512 | Recon=0.001082 | TrainAcc=0.8269
# Fold 15 Epoch 300: TotalLoss=0.387235 | Sup=0.381371 | Recon=0.000733 | TrainAcc=0.8205
# Fold 15 Epoch 400: TotalLoss=0.369169 | Sup=0.364313 | Recon=0.000607 | TrainAcc=0.8205
# Fold 15 Epoch 500: TotalLoss=0.354187 | Sup=0.349852 | Recon=0.000542 | TrainAcc=0.8462
# Fold 15 Epoch 600: TotalLoss=0.346168 | Sup=0.342025 | Recon=0.000518 | TrainAcc=0.8590
# Fold 15 Epoch 700: TotalLoss=0.337464 | Sup=0.333902 | Recon=0.000445 | TrainAcc=0.8590
# Fold 15 Epoch 800: TotalLoss=0.312921 | Sup=0.309635 | Recon=0.000411 | TrainAcc=0.8654
# Fold 15 Epoch 900: TotalLoss=0.310494 | Sup=0.307300 | Recon=0.000399 | TrainAcc=0.8654
# Fold 15 Epoch 1000: TotalLoss=0.296218 | Sup=0.293122 | Recon=0.000387 | TrainAcc=0.8782
# Fold 15 Epoch 1100: TotalLoss=0.294561 | Sup=0.291592 | Recon=0.000371 | TrainAcc=0.8590
# Fold 15 Epoch 1200: TotalLoss=0.276934 | Sup=0.274030 | Recon=0.000363 | TrainAcc=0.8718
# Fold 15 Epoch 1300: TotalLoss=0.271626 | Sup=0.268814 | Recon=0.000352 | TrainAcc=0.8718
# Fold 15 Epoch 1400: TotalLoss=0.273726 | Sup=0.270947 | Recon=0.000347 | TrainAcc=0.8910
# Fold 15 Epoch 1500: TotalLoss=0.258089 | Sup=0.255461 | Recon=0.000328 | TrainAcc=0.8910
# Fold 15 Epoch 1600: TotalLoss=0.254778 | Sup=0.252122 | Recon=0.000332 | TrainAcc=0.8974
# Fold 15 Epoch 1700: TotalLoss=0.242142 | Sup=0.239584 | Recon=0.000320 | TrainAcc=0.8462
# Fold 15 Epoch 1800: TotalLoss=0.237767 | Sup=0.235263 | Recon=0.000313 | TrainAcc=0.8910
# Fold 15 Epoch 1900: TotalLoss=0.232833 | Sup=0.230341 | Recon=0.000312 | TrainAcc=0.9038
# Fold 15 Epoch 2000: TotalLoss=0.229573 | Sup=0.227150 | Recon=0.000303 | TrainAcc=0.8782
# Fold 15 → Acc=0.8060 | Prec=0.8500 | Rec=0.6296 | F1=0.7234 | AUC=0.8662 | CE Loss=0.6858
#
# === Fold 16 ===
# Train Control: 93, Train Patient: 63
# Fold 16 Epoch 1: TotalLoss=0.981089 | Sup=0.726083 | Recon=0.031876 | TrainAcc=0.4038
# Fold 16 Epoch 100: TotalLoss=0.465412 | Sup=0.446880 | Recon=0.002317 | TrainAcc=0.7949
# Fold 16 Epoch 200: TotalLoss=0.440968 | Sup=0.431567 | Recon=0.001175 | TrainAcc=0.8077
# Fold 16 Epoch 300: TotalLoss=0.431291 | Sup=0.424826 | Recon=0.000808 | TrainAcc=0.8141
# Fold 16 Epoch 400: TotalLoss=0.414956 | Sup=0.409588 | Recon=0.000671 | TrainAcc=0.8205
# Fold 16 Epoch 500: TotalLoss=0.408309 | Sup=0.403520 | Recon=0.000599 | TrainAcc=0.8333
# Fold 16 Epoch 600: TotalLoss=0.394077 | Sup=0.390069 | Recon=0.000501 | TrainAcc=0.8397
# Fold 16 Epoch 700: TotalLoss=0.371439 | Sup=0.367858 | Recon=0.000448 | TrainAcc=0.8333
# Fold 16 Epoch 800: TotalLoss=0.371659 | Sup=0.368272 | Recon=0.000423 | TrainAcc=0.8333
# Fold 16 Epoch 900: TotalLoss=0.370534 | Sup=0.367370 | Recon=0.000395 | TrainAcc=0.7949
# Fold 16 Epoch 1000: TotalLoss=0.348404 | Sup=0.345149 | Recon=0.000407 | TrainAcc=0.8397
# Fold 16 Epoch 1100: TotalLoss=0.338209 | Sup=0.335202 | Recon=0.000376 | TrainAcc=0.8333
# Fold 16 Epoch 1200: TotalLoss=0.324826 | Sup=0.321944 | Recon=0.000360 | TrainAcc=0.8654
# Fold 16 Epoch 1300: TotalLoss=0.343733 | Sup=0.340948 | Recon=0.000348 | TrainAcc=0.7628
# Fold 16 Epoch 1400: TotalLoss=0.319548 | Sup=0.316831 | Recon=0.000340 | TrainAcc=0.8462
# Fold 16 Epoch 1500: TotalLoss=0.299491 | Sup=0.296785 | Recon=0.000338 | TrainAcc=0.8013
# Fold 16 Epoch 1600: TotalLoss=0.308901 | Sup=0.306250 | Recon=0.000331 | TrainAcc=0.8718
# Fold 16 Epoch 1700: TotalLoss=0.306433 | Sup=0.303835 | Recon=0.000325 | TrainAcc=0.7756
# Fold 16 Epoch 1800: TotalLoss=0.296527 | Sup=0.293929 | Recon=0.000325 | TrainAcc=0.8654
# Fold 16 Epoch 1900: TotalLoss=0.292214 | Sup=0.289721 | Recon=0.000312 | TrainAcc=0.8590
# Fold 16 Epoch 2000: TotalLoss=0.285210 | Sup=0.282718 | Recon=0.000311 | TrainAcc=0.8654
# Fold 16 → Acc=0.8060 | Prec=0.7692 | Rec=0.7407 | F1=0.7547 | AUC=0.8491 | CE Loss=0.5015
#
# === Fold 17 ===
# Train Control: 93, Train Patient: 63
# Fold 17 Epoch 1: TotalLoss=0.971266 | Sup=0.687683 | Recon=0.035448 | TrainAcc=0.5962
# Fold 17 Epoch 100: TotalLoss=0.474978 | Sup=0.453503 | Recon=0.002684 | TrainAcc=0.7821
# Fold 17 Epoch 200: TotalLoss=0.426485 | Sup=0.418334 | Recon=0.001019 | TrainAcc=0.8077
# Fold 17 Epoch 300: TotalLoss=0.408234 | Sup=0.402047 | Recon=0.000773 | TrainAcc=0.8397
# Fold 17 Epoch 400: TotalLoss=0.393024 | Sup=0.387919 | Recon=0.000638 | TrainAcc=0.8397
# Fold 17 Epoch 500: TotalLoss=0.377798 | Sup=0.373546 | Recon=0.000531 | TrainAcc=0.8397
# Fold 17 Epoch 600: TotalLoss=0.360700 | Sup=0.356952 | Recon=0.000469 | TrainAcc=0.8397
# Fold 17 Epoch 700: TotalLoss=0.344303 | Sup=0.340793 | Recon=0.000439 | TrainAcc=0.8590
# Fold 17 Epoch 800: TotalLoss=0.335667 | Sup=0.332535 | Recon=0.000391 | TrainAcc=0.8590
# Fold 17 Epoch 900: TotalLoss=0.340983 | Sup=0.337931 | Recon=0.000382 | TrainAcc=0.8718
# Fold 17 Epoch 1000: TotalLoss=0.323721 | Sup=0.320704 | Recon=0.000377 | TrainAcc=0.8590
# Fold 17 Epoch 1100: TotalLoss=0.327971 | Sup=0.325072 | Recon=0.000362 | TrainAcc=0.8013
# Fold 17 Epoch 1200: TotalLoss=0.315841 | Sup=0.312993 | Recon=0.000356 | TrainAcc=0.8782
# Fold 17 Epoch 1300: TotalLoss=0.305609 | Sup=0.302795 | Recon=0.000352 | TrainAcc=0.8462
# Fold 17 Epoch 1400: TotalLoss=0.297322 | Sup=0.294621 | Recon=0.000338 | TrainAcc=0.8718
# Fold 17 Epoch 1500: TotalLoss=0.283623 | Sup=0.280930 | Recon=0.000337 | TrainAcc=0.8718
# Fold 17 Epoch 1600: TotalLoss=0.278157 | Sup=0.275530 | Recon=0.000328 | TrainAcc=0.8397
# Fold 17 Epoch 1700: TotalLoss=0.267989 | Sup=0.265404 | Recon=0.000323 | TrainAcc=0.8846
# Fold 17 Epoch 1800: TotalLoss=0.272726 | Sup=0.270211 | Recon=0.000314 | TrainAcc=0.8782
# Fold 17 Epoch 1900: TotalLoss=0.256856 | Sup=0.254382 | Recon=0.000309 | TrainAcc=0.8782
# Fold 17 Epoch 2000: TotalLoss=0.242980 | Sup=0.240579 | Recon=0.000300 | TrainAcc=0.8782
# Fold 17 → Acc=0.8657 | Prec=0.9500 | Rec=0.7037 | F1=0.8085 | AUC=0.9407 | CE Loss=0.3295
#
# === Fold 18 ===
# Train Control: 93, Train Patient: 63
# Fold 18 Epoch 1: TotalLoss=0.926261 | Sup=0.685985 | Recon=0.030035 | TrainAcc=0.6346
# Fold 18 Epoch 100: TotalLoss=0.504791 | Sup=0.486776 | Recon=0.002252 | TrainAcc=0.7628
# Fold 18 Epoch 200: TotalLoss=0.477068 | Sup=0.468210 | Recon=0.001107 | TrainAcc=0.7821
# Fold 18 Epoch 300: TotalLoss=0.453589 | Sup=0.447561 | Recon=0.000753 | TrainAcc=0.7949
# Fold 18 Epoch 400: TotalLoss=0.441699 | Sup=0.436357 | Recon=0.000668 | TrainAcc=0.8077
# Fold 18 Epoch 500: TotalLoss=0.426508 | Sup=0.422003 | Recon=0.000563 | TrainAcc=0.8205
# Fold 18 Epoch 600: TotalLoss=0.419903 | Sup=0.415941 | Recon=0.000495 | TrainAcc=0.8141
# Fold 18 Epoch 700: TotalLoss=0.405800 | Sup=0.402229 | Recon=0.000446 | TrainAcc=0.8077
# Fold 18 Epoch 800: TotalLoss=0.394294 | Sup=0.391025 | Recon=0.000409 | TrainAcc=0.8013
# Fold 18 Epoch 900: TotalLoss=0.374240 | Sup=0.371138 | Recon=0.000388 | TrainAcc=0.8269
# Fold 18 Epoch 1000: TotalLoss=0.368800 | Sup=0.365800 | Recon=0.000375 | TrainAcc=0.8397
# Fold 18 Epoch 1100: TotalLoss=0.361258 | Sup=0.358364 | Recon=0.000362 | TrainAcc=0.8269
# Fold 18 Epoch 1200: TotalLoss=0.345671 | Sup=0.342817 | Recon=0.000357 | TrainAcc=0.8333
# Fold 18 Epoch 1300: TotalLoss=0.329582 | Sup=0.326906 | Recon=0.000334 | TrainAcc=0.8462
# Fold 18 Epoch 1400: TotalLoss=0.318413 | Sup=0.315763 | Recon=0.000331 | TrainAcc=0.8205
# Fold 18 Epoch 1500: TotalLoss=0.308862 | Sup=0.306250 | Recon=0.000327 | TrainAcc=0.8590
# Fold 18 Epoch 1600: TotalLoss=0.291027 | Sup=0.288469 | Recon=0.000320 | TrainAcc=0.8333
# Fold 18 Epoch 1700: TotalLoss=0.289138 | Sup=0.286631 | Recon=0.000313 | TrainAcc=0.8333
# Fold 18 Epoch 1800: TotalLoss=0.264560 | Sup=0.262088 | Recon=0.000309 | TrainAcc=0.8269
# Fold 18 Epoch 1900: TotalLoss=0.268957 | Sup=0.266544 | Recon=0.000302 | TrainAcc=0.7756
# Fold 18 Epoch 2000: TotalLoss=0.253865 | Sup=0.251471 | Recon=0.000299 | TrainAcc=0.8846
# Fold 18 → Acc=0.8358 | Prec=0.9000 | Rec=0.6667 | F1=0.7660 | AUC=0.8954 | CE Loss=0.3718
#
# === Fold 19 ===
# Train Control: 93, Train Patient: 63
# Fold 19 Epoch 1: TotalLoss=0.969198 | Sup=0.685085 | Recon=0.035514 | TrainAcc=0.4038
# Fold 19 Epoch 100: TotalLoss=0.475313 | Sup=0.457175 | Recon=0.002267 | TrainAcc=0.7885
# Fold 19 Epoch 200: TotalLoss=0.444901 | Sup=0.435871 | Recon=0.001129 | TrainAcc=0.8013
# Fold 19 Epoch 300: TotalLoss=0.418752 | Sup=0.412574 | Recon=0.000772 | TrainAcc=0.8269
# Fold 19 Epoch 400: TotalLoss=0.399880 | Sup=0.395092 | Recon=0.000599 | TrainAcc=0.8333
# Fold 19 Epoch 500: TotalLoss=0.393512 | Sup=0.389271 | Recon=0.000530 | TrainAcc=0.8333
# Fold 19 Epoch 600: TotalLoss=0.375080 | Sup=0.371462 | Recon=0.000452 | TrainAcc=0.8205
# Fold 19 Epoch 700: TotalLoss=0.375999 | Sup=0.372597 | Recon=0.000425 | TrainAcc=0.8397
# Fold 19 Epoch 800: TotalLoss=0.357031 | Sup=0.353790 | Recon=0.000405 | TrainAcc=0.8333
# Fold 19 Epoch 900: TotalLoss=0.354273 | Sup=0.351171 | Recon=0.000388 | TrainAcc=0.8269
# Fold 19 Epoch 1000: TotalLoss=0.333722 | Sup=0.330740 | Recon=0.000373 | TrainAcc=0.8397
# Fold 19 Epoch 1100: TotalLoss=0.332556 | Sup=0.329655 | Recon=0.000363 | TrainAcc=0.8397
# Fold 19 Epoch 1200: TotalLoss=0.325788 | Sup=0.323005 | Recon=0.000348 | TrainAcc=0.8397
# Fold 19 Epoch 1300: TotalLoss=0.315796 | Sup=0.313072 | Recon=0.000340 | TrainAcc=0.8526
# Fold 19 Epoch 1400: TotalLoss=0.302078 | Sup=0.299381 | Recon=0.000337 | TrainAcc=0.8462
# Fold 19 Epoch 1500: TotalLoss=0.298474 | Sup=0.295864 | Recon=0.000326 | TrainAcc=0.8526
# Fold 19 Epoch 1600: TotalLoss=0.292092 | Sup=0.289512 | Recon=0.000322 | TrainAcc=0.8526
# Fold 19 Epoch 1700: TotalLoss=0.279115 | Sup=0.276569 | Recon=0.000318 | TrainAcc=0.8654
# Fold 19 Epoch 1800: TotalLoss=0.285100 | Sup=0.282602 | Recon=0.000312 | TrainAcc=0.8205
# Fold 19 Epoch 1900: TotalLoss=0.277238 | Sup=0.274794 | Recon=0.000306 | TrainAcc=0.8205
# Fold 19 Epoch 2000: TotalLoss=0.266519 | Sup=0.264037 | Recon=0.000310 | TrainAcc=0.8205
# Fold 19 → Acc=0.7910 | Prec=0.8824 | Rec=0.5556 | F1=0.6818 | AUC=0.9065 | CE Loss=0.5894
#
# === Fold 20 ===
# Train Control: 93, Train Patient: 63
# Fold 20 Epoch 1: TotalLoss=0.979186 | Sup=0.722160 | Recon=0.032128 | TrainAcc=0.5962
# Fold 20 Epoch 100: TotalLoss=0.469228 | Sup=0.451738 | Recon=0.002186 | TrainAcc=0.7821
# Fold 20 Epoch 200: TotalLoss=0.429433 | Sup=0.421126 | Recon=0.001038 | TrainAcc=0.7885
# Fold 20 Epoch 300: TotalLoss=0.410282 | Sup=0.404645 | Recon=0.000705 | TrainAcc=0.8269
# Fold 20 Epoch 400: TotalLoss=0.396911 | Sup=0.392238 | Recon=0.000584 | TrainAcc=0.8205
# Fold 20 Epoch 500: TotalLoss=0.376785 | Sup=0.372786 | Recon=0.000500 | TrainAcc=0.8141
# Fold 20 Epoch 600: TotalLoss=0.356499 | Sup=0.352995 | Recon=0.000438 | TrainAcc=0.8333
# Fold 20 Epoch 700: TotalLoss=0.347476 | Sup=0.344202 | Recon=0.000409 | TrainAcc=0.8397
# Fold 20 Epoch 800: TotalLoss=0.337934 | Sup=0.334901 | Recon=0.000379 | TrainAcc=0.8462
# Fold 20 Epoch 900: TotalLoss=0.326866 | Sup=0.323934 | Recon=0.000366 | TrainAcc=0.8462
# Fold 20 Epoch 1000: TotalLoss=0.314557 | Sup=0.311674 | Recon=0.000360 | TrainAcc=0.8846
# Fold 20 Epoch 1100: TotalLoss=0.301709 | Sup=0.298892 | Recon=0.000352 | TrainAcc=0.8718
# Fold 20 Epoch 1200: TotalLoss=0.296811 | Sup=0.294056 | Recon=0.000344 | TrainAcc=0.8846
# Fold 20 Epoch 1300: TotalLoss=0.284293 | Sup=0.281635 | Recon=0.000332 | TrainAcc=0.8782
# Fold 20 Epoch 1400: TotalLoss=0.279505 | Sup=0.276864 | Recon=0.000330 | TrainAcc=0.8654
# Fold 20 Epoch 1500: TotalLoss=0.261824 | Sup=0.259248 | Recon=0.000322 | TrainAcc=0.8397
# Fold 20 Epoch 1600: TotalLoss=0.255535 | Sup=0.253014 | Recon=0.000315 | TrainAcc=0.8974
# Fold 20 Epoch 1700: TotalLoss=0.252167 | Sup=0.249667 | Recon=0.000313 | TrainAcc=0.9103
# Fold 20 Epoch 1800: TotalLoss=0.234304 | Sup=0.231876 | Recon=0.000304 | TrainAcc=0.8846
# Fold 20 Epoch 1900: TotalLoss=0.227502 | Sup=0.225107 | Recon=0.000299 | TrainAcc=0.8590
# Fold 20 Epoch 2000: TotalLoss=0.223649 | Sup=0.221297 | Recon=0.000294 | TrainAcc=0.8974
# Fold 20 → Acc=0.8657 | Prec=0.9091 | Rec=0.7407 | F1=0.8163 | AUC=0.9000 | CE Loss=0.6040
#
# === Average Results for λ = 8 ===
# Accuracy:  0.8201
# Precision: 0.8314
# Recall:    0.7222
# F1-score:  0.7618
# CE Loss:   0.4593
# AUC:       0.8956
#
#
# ====================== FINAL SUMMARY ACROSS ALL λ ======================
# Lambda   | Accuracy  | Precision | Recall   | F1-score  | AUC      | CE Loss
# ------------------------------------------------------------------------
# 0.001    | 0.8291    | 0.8459    | 0.7426   | 0.7779    | 0.8941   | 0.4610
# 0.005    | 0.8231    | 0.8582    | 0.7185   | 0.7666    | 0.8967   | 0.4697
# 0.009    | 0.8142    | 0.8451    | 0.6944   | 0.7436    | 0.8919   | 0.4749
# 0.01     | 0.8313    | 0.8604    | 0.7241   | 0.7764    | 0.8919   | 0.4527
# 0.05     | 0.8373    | 0.8724    | 0.7204   | 0.7755    | 0.8923   | 0.4559
# 0.09     | 0.8119    | 0.7962    | 0.7722   | 0.7704    | 0.8928   | 0.4728
# 0.1      | 0.8216    | 0.8240    | 0.7556   | 0.7719    | 0.8905   | 0.4680
# 0.3      | 0.8239    | 0.8488    | 0.7130   | 0.7651    | 0.8945   | 0.4429
# 0.5      | 0.8157    | 0.8493    | 0.7037   | 0.7513    | 0.8971   | 0.4681
# 0.9      | 0.8313    | 0.8527    | 0.7352   | 0.7797    | 0.8939   | 0.4526
# 1        | 0.8388    | 0.8775    | 0.7130   | 0.7763    | 0.8946   | 0.4621
# 2        | 0.8299    | 0.8716    | 0.7037   | 0.7642    | 0.8923   | 0.4582
# 5        | 0.8425    | 0.8746    | 0.7278   | 0.7862    | 0.8945   | 0.4371
# 8        | 0.8201    | 0.8314    | 0.7222   | 0.7618    | 0.8956   | 0.4593
